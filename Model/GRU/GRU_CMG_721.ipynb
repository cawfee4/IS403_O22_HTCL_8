# %% [markdown]
# # Model: GRU (Gated Recurrent Unit)  - Stock Token: CMG - Test/Train/Vaildation: 70/20/10
# - Dataset: 1313 rows x 7 columns (01/03/2019 - 31/05/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 797.59
# - MAE: 589.42
# - MAPE: 1.74 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

plt.style.use("default")

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 0  # 7 2 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830
# ...           ...
# 2024-05-27  59000
# 2024-05-28  62100
# 2024-05-29  60000
# 2024-05-30  59200
# 2024-05-31  60900
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((908, 10), (908,), (251, 10), (251,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(100),
        Dense(32, activation="relu"),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 100)            │        30,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,165 (133.46 KB)
#  Trainable params: 34,165 (133.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0284 - mean_absolute_error: 0.1225 - val_loss: 0.0094 - val_mean_absolute_error: 0.0947
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0286 - val_loss: 4.4685e-04 - val_mean_absolute_error: 0.0182
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2718e-04 - mean_absolute_error: 0.0132 - val_loss: 1.8642e-04 - val_mean_absolute_error: 0.0097
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5025e-04 - mean_absolute_error: 0.0110 - val_loss: 1.9400e-04 - val_mean_absolute_error: 0.0098
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6614e-04 - mean_absolute_error: 0.0109 - val_loss: 2.3711e-04 - val_mean_absolute_error: 0.0113
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7135e-04 - mean_absolute_error: 0.0114 - val_loss: 2.2940e-04 - val_mean_absolute_error: 0.0111
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4037e-04 - mean_absolute_error: 0.0110 - val_loss: 1.6509e-04 - val_mean_absolute_error: 0.0091
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2732e-04 - mean_absolute_error: 0.0103 - val_loss: 1.6098e-04 - val_mean_absolute_error: 0.0091
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3892e-04 - mean_absolute_error: 0.0109 - val_loss: 1.5531e-04 - val_mean_absolute_error: 0.0088
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2601e-04 - mean_absolute_error: 0.0104 - val_loss: 1.5187e-04 - val_mean_absolute_error: 0.0087
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1085e-04 - mean_absolute_error: 0.0099 - val_loss: 1.5136e-04 - val_mean_absolute_error: 0.0089
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0477e-04 - mean_absolute_error: 0.0098 - val_loss: 1.7135e-04 - val_mean_absolute_error: 0.0093
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2313e-04 - mean_absolute_error: 0.0104 - val_loss: 2.6917e-04 - val_mean_absolute_error: 0.0137
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5410e-04 - mean_absolute_error: 0.0112 - val_loss: 2.3862e-04 - val_mean_absolute_error: 0.0121
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9972e-04 - mean_absolute_error: 0.0098 - val_loss: 1.4865e-04 - val_mean_absolute_error: 0.0086
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0429e-04 - mean_absolute_error: 0.0098 - val_loss: 1.3860e-04 - val_mean_absolute_error: 0.0084
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0699e-04 - mean_absolute_error: 0.0099 - val_loss: 1.3833e-04 - val_mean_absolute_error: 0.0083
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1160e-04 - mean_absolute_error: 0.0104 - val_loss: 3.1539e-04 - val_mean_absolute_error: 0.0149
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9718e-04 - mean_absolute_error: 0.0095 - val_loss: 1.6391e-04 - val_mean_absolute_error: 0.0094
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7191e-04 - mean_absolute_error: 0.0089 - val_loss: 1.6936e-04 - val_mean_absolute_error: 0.0096
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7557e-04 - mean_absolute_error: 0.0093 - val_loss: 1.3469e-04 - val_mean_absolute_error: 0.0083
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6388e-04 - mean_absolute_error: 0.0087 - val_loss: 1.3396e-04 - val_mean_absolute_error: 0.0083
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5430e-04 - mean_absolute_error: 0.0086 - val_loss: 1.4355e-04 - val_mean_absolute_error: 0.0087
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9101e-04 - mean_absolute_error: 0.0097 - val_loss: 1.3958e-04 - val_mean_absolute_error: 0.0085
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6473e-04 - mean_absolute_error: 0.0087 - val_loss: 1.6112e-04 - val_mean_absolute_error: 0.0096
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7485e-04 - mean_absolute_error: 0.0094 - val_loss: 1.9171e-04 - val_mean_absolute_error: 0.0107
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7562e-04 - mean_absolute_error: 0.0095 - val_loss: 1.3831e-04 - val_mean_absolute_error: 0.0085
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8924e-04 - mean_absolute_error: 0.0098 - val_loss: 1.4125e-04 - val_mean_absolute_error: 0.0087
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8689e-04 - mean_absolute_error: 0.0096 - val_loss: 1.2859e-04 - val_mean_absolute_error: 0.0080
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6577e-04 - mean_absolute_error: 0.0089 - val_loss: 1.5516e-04 - val_mean_absolute_error: 0.0092
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5468e-04 - mean_absolute_error: 0.0089 - val_loss: 1.6507e-04 - val_mean_absolute_error: 0.0097
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7940e-04 - mean_absolute_error: 0.0094 - val_loss: 2.2753e-04 - val_mean_absolute_error: 0.0123
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1130e-04 - mean_absolute_error: 0.0105 - val_loss: 1.2740e-04 - val_mean_absolute_error: 0.0080
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7313e-04 - mean_absolute_error: 0.0093 - val_loss: 1.8711e-04 - val_mean_absolute_error: 0.0107
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9748e-04 - mean_absolute_error: 0.0101 - val_loss: 1.2557e-04 - val_mean_absolute_error: 0.0078
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7393e-04 - mean_absolute_error: 0.0089 - val_loss: 2.5665e-04 - val_mean_absolute_error: 0.0133
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7152e-04 - mean_absolute_error: 0.0093 - val_loss: 1.5585e-04 - val_mean_absolute_error: 0.0093
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8896e-04 - mean_absolute_error: 0.0096 - val_loss: 1.6510e-04 - val_mean_absolute_error: 0.0097
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6918e-04 - mean_absolute_error: 0.0091 - val_loss: 1.4945e-04 - val_mean_absolute_error: 0.0091
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6655e-04 - mean_absolute_error: 0.0093 - val_loss: 1.3086e-04 - val_mean_absolute_error: 0.0083
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6023e-04 - mean_absolute_error: 0.0090 - val_loss: 1.8982e-04 - val_mean_absolute_error: 0.0109
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6078e-04 - mean_absolute_error: 0.0089 - val_loss: 1.4819e-04 - val_mean_absolute_error: 0.0091
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6809e-04 - mean_absolute_error: 0.0089 - val_loss: 1.3431e-04 - val_mean_absolute_error: 0.0085
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5286e-04 - mean_absolute_error: 0.0085 - val_loss: 1.5195e-04 - val_mean_absolute_error: 0.0092
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4615e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2678e-04 - val_mean_absolute_error: 0.0081
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6924e-04 - mean_absolute_error: 0.0088 - val_loss: 2.1023e-04 - val_mean_absolute_error: 0.0117
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8373e-04 - mean_absolute_error: 0.0093 - val_loss: 1.3037e-04 - val_mean_absolute_error: 0.0082
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5531e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2934e-04 - val_mean_absolute_error: 0.0083
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7068e-04 - mean_absolute_error: 0.0092 - val_loss: 1.3460e-04 - val_mean_absolute_error: 0.0086
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4567e-04 - mean_absolute_error: 0.0084 - val_loss: 1.5704e-04 - val_mean_absolute_error: 0.0095
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7768e-04 - mean_absolute_error: 0.0096 - val_loss: 1.8171e-04 - val_mean_absolute_error: 0.0105
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7754e-04 - mean_absolute_error: 0.0096 - val_loss: 1.2538e-04 - val_mean_absolute_error: 0.0081
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3573e-04 - mean_absolute_error: 0.0079 - val_loss: 1.2329e-04 - val_mean_absolute_error: 0.0080
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8307e-04 - mean_absolute_error: 0.0091 - val_loss: 1.3408e-04 - val_mean_absolute_error: 0.0084
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5222e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2943e-04 - val_mean_absolute_error: 0.0081
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5170e-04 - mean_absolute_error: 0.0086 - val_loss: 1.5335e-04 - val_mean_absolute_error: 0.0093
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6314e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2364e-04 - val_mean_absolute_error: 0.0081
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7461e-04 - mean_absolute_error: 0.0098 - val_loss: 1.5163e-04 - val_mean_absolute_error: 0.0094
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6058e-04 - mean_absolute_error: 0.0085 - val_loss: 2.4634e-04 - val_mean_absolute_error: 0.0130
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8457e-04 - mean_absolute_error: 0.0096 - val_loss: 1.2666e-04 - val_mean_absolute_error: 0.0082
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4037e-04 - mean_absolute_error: 0.0082 - val_loss: 1.5479e-04 - val_mean_absolute_error: 0.0095
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0074e-04 - mean_absolute_error: 0.0101 - val_loss: 1.6754e-04 - val_mean_absolute_error: 0.0100
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5524e-04 - mean_absolute_error: 0.0089 - val_loss: 1.3224e-04 - val_mean_absolute_error: 0.0086
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6984e-04 - mean_absolute_error: 0.0092 - val_loss: 1.9747e-04 - val_mean_absolute_error: 0.0113
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8365e-04 - mean_absolute_error: 0.0096 - val_loss: 1.9355e-04 - val_mean_absolute_error: 0.0111
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0193e-04 - mean_absolute_error: 0.0106 - val_loss: 1.6110e-04 - val_mean_absolute_error: 0.0098
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7015e-04 - mean_absolute_error: 0.0091 - val_loss: 1.2443e-04 - val_mean_absolute_error: 0.0083
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7278e-04 - mean_absolute_error: 0.0092 - val_loss: 1.4042e-04 - val_mean_absolute_error: 0.0090
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9564e-04 - mean_absolute_error: 0.0099 - val_loss: 3.5800e-04 - val_mean_absolute_error: 0.0165
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9072e-04 - mean_absolute_error: 0.0103 - val_loss: 1.9378e-04 - val_mean_absolute_error: 0.0111
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6757e-04 - mean_absolute_error: 0.0095 - val_loss: 1.3416e-04 - val_mean_absolute_error: 0.0087
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6128e-04 - mean_absolute_error: 0.0095 - val_loss: 1.3495e-04 - val_mean_absolute_error: 0.0085
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6530e-04 - mean_absolute_error: 0.0089 - val_loss: 1.3847e-04 - val_mean_absolute_error: 0.0089
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5287e-04 - mean_absolute_error: 0.0084 - val_loss: 1.4967e-04 - val_mean_absolute_error: 0.0094
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7040e-04 - mean_absolute_error: 0.0092 - val_loss: 2.1877e-04 - val_mean_absolute_error: 0.0120
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5113e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2849e-04 - val_mean_absolute_error: 0.0085
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6197e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2824e-04 - val_mean_absolute_error: 0.0084
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3432e-04 - mean_absolute_error: 0.0076 - val_loss: 1.2844e-04 - val_mean_absolute_error: 0.0085
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4639e-04 - mean_absolute_error: 0.0082 - val_loss: 1.3741e-04 - val_mean_absolute_error: 0.0089
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3861e-04 - mean_absolute_error: 0.0085 - val_loss: 1.3274e-04 - val_mean_absolute_error: 0.0083
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2173e-04 - mean_absolute_error: 0.0076 - val_loss: 1.2003e-04 - val_mean_absolute_error: 0.0078
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2925e-04 - mean_absolute_error: 0.0077 - val_loss: 1.9319e-04 - val_mean_absolute_error: 0.0110
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4453e-04 - mean_absolute_error: 0.0085 - val_loss: 1.6041e-04 - val_mean_absolute_error: 0.0099
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7463e-04 - mean_absolute_error: 0.0092 - val_loss: 2.3820e-04 - val_mean_absolute_error: 0.0127
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7266e-04 - mean_absolute_error: 0.0094 - val_loss: 1.1917e-04 - val_mean_absolute_error: 0.0079
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3927e-04 - mean_absolute_error: 0.0082 - val_loss: 1.1909e-04 - val_mean_absolute_error: 0.0081
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5075e-04 - mean_absolute_error: 0.0085 - val_loss: 1.5938e-04 - val_mean_absolute_error: 0.0099
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2842e-04 - mean_absolute_error: 0.0081 - val_loss: 2.0390e-04 - val_mean_absolute_error: 0.0117
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6911e-04 - mean_absolute_error: 0.0094 - val_loss: 1.2062e-04 - val_mean_absolute_error: 0.0081
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4765e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2253e-04 - val_mean_absolute_error: 0.0079
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4354e-04 - mean_absolute_error: 0.0086 - val_loss: 1.3166e-04 - val_mean_absolute_error: 0.0087
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6044e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2686e-04 - val_mean_absolute_error: 0.0082
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3134e-04 - mean_absolute_error: 0.0077 - val_loss: 1.7319e-04 - val_mean_absolute_error: 0.0104
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7572e-04 - mean_absolute_error: 0.0095 - val_loss: 1.3136e-04 - val_mean_absolute_error: 0.0087
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5289e-04 - mean_absolute_error: 0.0086 - val_loss: 1.8750e-04 - val_mean_absolute_error: 0.0107
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5761e-04 - mean_absolute_error: 0.0085 - val_loss: 1.6094e-04 - val_mean_absolute_error: 0.0095
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2614e-04 - mean_absolute_error: 0.0080 - val_loss: 1.9779e-04 - val_mean_absolute_error: 0.0111
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7104e-04 - mean_absolute_error: 0.0093 - val_loss: 3.5261e-04 - val_mean_absolute_error: 0.0163
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8592e-04 - mean_absolute_error: 0.0099 - val_loss: 1.6300e-04 - val_mean_absolute_error: 0.0097
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4925e-04 - mean_absolute_error: 0.0082 - val_loss: 1.3091e-04 - val_mean_absolute_error: 0.0087
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5772e-04 - mean_absolute_error: 0.0085 - val_loss: 1.1928e-04 - val_mean_absolute_error: 0.0080
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4393e-04 - mean_absolute_error: 0.0081 - val_loss: 1.3561e-04 - val_mean_absolute_error: 0.0089
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3860e-04 - mean_absolute_error: 0.0082 - val_loss: 1.4078e-04 - val_mean_absolute_error: 0.0088
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5390e-04 - mean_absolute_error: 0.0085 - val_loss: 1.3071e-04 - val_mean_absolute_error: 0.0087
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4324e-04 - mean_absolute_error: 0.0081 - val_loss: 1.3804e-04 - val_mean_absolute_error: 0.0086
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2817e-04 - mean_absolute_error: 0.0077 - val_loss: 1.2250e-04 - val_mean_absolute_error: 0.0083
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4954e-04 - mean_absolute_error: 0.0083 - val_loss: 1.1905e-04 - val_mean_absolute_error: 0.0080
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5475e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2913e-04 - val_mean_absolute_error: 0.0086
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4358e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2356e-04 - val_mean_absolute_error: 0.0081
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5233e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2342e-04 - val_mean_absolute_error: 0.0081
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3063e-04 - mean_absolute_error: 0.0077 - val_loss: 1.2515e-04 - val_mean_absolute_error: 0.0082
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3992e-04 - mean_absolute_error: 0.0080 - val_loss: 2.1515e-04 - val_mean_absolute_error: 0.0118
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4601e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2025e-04 - val_mean_absolute_error: 0.0081
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4183e-04 - mean_absolute_error: 0.0085 - val_loss: 1.7229e-04 - val_mean_absolute_error: 0.0101
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5209e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2141e-04 - val_mean_absolute_error: 0.0082
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4063e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2279e-04 - val_mean_absolute_error: 0.0081
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3633e-04 - mean_absolute_error: 0.0083 - val_loss: 1.3568e-04 - val_mean_absolute_error: 0.0086
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5067e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2282e-04 - val_mean_absolute_error: 0.0082
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3772e-04 - mean_absolute_error: 0.0080 - val_loss: 1.7426e-04 - val_mean_absolute_error: 0.0105
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7697e-04 - mean_absolute_error: 0.0094 - val_loss: 2.1742e-04 - val_mean_absolute_error: 0.0118
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5344e-04 - mean_absolute_error: 0.0088 - val_loss: 2.6072e-04 - val_mean_absolute_error: 0.0134
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6437e-04 - mean_absolute_error: 0.0090 - val_loss: 1.3256e-04 - val_mean_absolute_error: 0.0088
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4255e-04 - mean_absolute_error: 0.0083 - val_loss: 1.6256e-04 - val_mean_absolute_error: 0.0100
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4595e-04 - mean_absolute_error: 0.0085 - val_loss: 2.0647e-04 - val_mean_absolute_error: 0.0114
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4172e-04 - mean_absolute_error: 0.0082 - val_loss: 1.5118e-04 - val_mean_absolute_error: 0.0092
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3813e-04 - mean_absolute_error: 0.0079 - val_loss: 1.4255e-04 - val_mean_absolute_error: 0.0092
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5368e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2098e-04 - val_mean_absolute_error: 0.0081
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6746e-04 - mean_absolute_error: 0.0090 - val_loss: 2.2166e-04 - val_mean_absolute_error: 0.0120
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5753e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2284e-04 - val_mean_absolute_error: 0.0082
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4531e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2565e-04 - val_mean_absolute_error: 0.0082
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2872e-04 - mean_absolute_error: 0.0076 - val_loss: 1.3507e-04 - val_mean_absolute_error: 0.0086
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5829e-04 - mean_absolute_error: 0.0089 - val_loss: 1.3387e-04 - val_mean_absolute_error: 0.0086
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4425e-04 - mean_absolute_error: 0.0085 - val_loss: 1.3540e-04 - val_mean_absolute_error: 0.0086
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3233e-04 - mean_absolute_error: 0.0078 - val_loss: 1.5675e-04 - val_mean_absolute_error: 0.0094
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6884e-04 - mean_absolute_error: 0.0087 - val_loss: 1.4215e-04 - val_mean_absolute_error: 0.0091
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7131e-04 - mean_absolute_error: 0.0093 - val_loss: 1.2305e-04 - val_mean_absolute_error: 0.0083
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4572e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2075e-04 - val_mean_absolute_error: 0.0081
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5456e-04 - mean_absolute_error: 0.0086 - val_loss: 1.4218e-04 - val_mean_absolute_error: 0.0090
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5619e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2771e-04 - val_mean_absolute_error: 0.0086
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4769e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2295e-04 - val_mean_absolute_error: 0.0082
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3587e-04 - mean_absolute_error: 0.0082 - val_loss: 1.4721e-04 - val_mean_absolute_error: 0.0091
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5247e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2063e-04 - val_mean_absolute_error: 0.0081
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3769e-04 - mean_absolute_error: 0.0080 - val_loss: 1.4905e-04 - val_mean_absolute_error: 0.0091
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2567e-04 - mean_absolute_error: 0.0077 - val_loss: 1.6072e-04 - val_mean_absolute_error: 0.0098
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5277e-04 - mean_absolute_error: 0.0090 - val_loss: 1.2486e-04 - val_mean_absolute_error: 0.0083
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4499e-04 - mean_absolute_error: 0.0084 - val_loss: 2.8728e-04 - val_mean_absolute_error: 0.0143
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7849e-04 - mean_absolute_error: 0.0094 - val_loss: 1.2430e-04 - val_mean_absolute_error: 0.0083
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6281e-04 - mean_absolute_error: 0.0088 - val_loss: 1.3270e-04 - val_mean_absolute_error: 0.0088
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5675e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2324e-04 - val_mean_absolute_error: 0.0083
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2104e-04 - mean_absolute_error: 0.0076 - val_loss: 1.5612e-04 - val_mean_absolute_error: 0.0096
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8336e-04 - mean_absolute_error: 0.0098 - val_loss: 1.2955e-04 - val_mean_absolute_error: 0.0086
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4533e-04 - mean_absolute_error: 0.0084 - val_loss: 2.1306e-04 - val_mean_absolute_error: 0.0117
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5473e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2177e-04 - val_mean_absolute_error: 0.0082
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3802e-04 - mean_absolute_error: 0.0079 - val_loss: 1.2127e-04 - val_mean_absolute_error: 0.0082
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4951e-04 - mean_absolute_error: 0.0083 - val_loss: 1.4447e-04 - val_mean_absolute_error: 0.0089
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3382e-04 - mean_absolute_error: 0.0079 - val_loss: 1.8519e-04 - val_mean_absolute_error: 0.0106
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5081e-04 - mean_absolute_error: 0.0090 - val_loss: 1.2606e-04 - val_mean_absolute_error: 0.0083
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3400e-04 - mean_absolute_error: 0.0077 - val_loss: 1.5004e-04 - val_mean_absolute_error: 0.0092
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2698e-04 - mean_absolute_error: 0.0078 - val_loss: 1.9149e-04 - val_mean_absolute_error: 0.0111
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3534e-04 - mean_absolute_error: 0.0082 - val_loss: 1.9528e-04 - val_mean_absolute_error: 0.0110
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3971e-04 - mean_absolute_error: 0.0079 - val_loss: 1.5506e-04 - val_mean_absolute_error: 0.0094
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6536e-04 - mean_absolute_error: 0.0091 - val_loss: 2.6944e-04 - val_mean_absolute_error: 0.0137
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6603e-04 - mean_absolute_error: 0.0089 - val_loss: 1.5012e-04 - val_mean_absolute_error: 0.0092
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4610e-04 - mean_absolute_error: 0.0086 - val_loss: 1.6426e-04 - val_mean_absolute_error: 0.0097
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4098e-04 - mean_absolute_error: 0.0082 - val_loss: 1.7629e-04 - val_mean_absolute_error: 0.0102
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4247e-04 - mean_absolute_error: 0.0086 - val_loss: 1.4181e-04 - val_mean_absolute_error: 0.0091
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0434e-04 - mean_absolute_error: 0.0108 - val_loss: 1.2754e-04 - val_mean_absolute_error: 0.0086
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6137e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2080e-04 - val_mean_absolute_error: 0.0081
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5346e-04 - mean_absolute_error: 0.0088 - val_loss: 1.6308e-04 - val_mean_absolute_error: 0.0100
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4473e-04 - mean_absolute_error: 0.0088 - val_loss: 1.9556e-04 - val_mean_absolute_error: 0.0112
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4180e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2066e-04 - val_mean_absolute_error: 0.0081
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8485e-04 - mean_absolute_error: 0.0097 - val_loss: 4.6715e-04 - val_mean_absolute_error: 0.0195
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7351e-04 - mean_absolute_error: 0.0128 - val_loss: 2.0104e-04 - val_mean_absolute_error: 0.0115
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7841e-04 - mean_absolute_error: 0.0095 - val_loss: 1.2360e-04 - val_mean_absolute_error: 0.0083
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4851e-04 - mean_absolute_error: 0.0083 - val_loss: 1.3433e-04 - val_mean_absolute_error: 0.0085
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2922e-04 - mean_absolute_error: 0.0078 - val_loss: 1.4822e-04 - val_mean_absolute_error: 0.0091
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3015e-04 - mean_absolute_error: 0.0079 - val_loss: 2.7042e-04 - val_mean_absolute_error: 0.0136
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8482e-04 - mean_absolute_error: 0.0090 - val_loss: 1.3367e-04 - val_mean_absolute_error: 0.0088
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3310e-04 - mean_absolute_error: 0.0078 - val_loss: 1.3600e-04 - val_mean_absolute_error: 0.0089
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3325e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2968e-04 - val_mean_absolute_error: 0.0084
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3068e-04 - mean_absolute_error: 0.0078 - val_loss: 1.3389e-04 - val_mean_absolute_error: 0.0085
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4129e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2534e-04 - val_mean_absolute_error: 0.0084
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5486e-04 - mean_absolute_error: 0.0084 - val_loss: 2.0740e-04 - val_mean_absolute_error: 0.0115
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5870e-04 - mean_absolute_error: 0.0092 - val_loss: 1.3672e-04 - val_mean_absolute_error: 0.0087
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3324e-04 - mean_absolute_error: 0.0079 - val_loss: 1.6657e-04 - val_mean_absolute_error: 0.0098
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3400e-04 - mean_absolute_error: 0.0079 - val_loss: 1.3107e-04 - val_mean_absolute_error: 0.0087
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6287e-04 - mean_absolute_error: 0.0087 - val_loss: 2.5289e-04 - val_mean_absolute_error: 0.0132
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9823e-04 - mean_absolute_error: 0.0095 - val_loss: 2.1144e-04 - val_mean_absolute_error: 0.0116
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3874e-04 - mean_absolute_error: 0.0085 - val_loss: 1.9591e-04 - val_mean_absolute_error: 0.0110
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3533e-04 - mean_absolute_error: 0.0080 - val_loss: 1.3719e-04 - val_mean_absolute_error: 0.0087
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4077e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2855e-04 - val_mean_absolute_error: 0.0084
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6516e-04 - mean_absolute_error: 0.0089 - val_loss: 1.3339e-04 - val_mean_absolute_error: 0.0088
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4959e-04 - mean_absolute_error: 0.0089 - val_loss: 1.2336e-04 - val_mean_absolute_error: 0.0083
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4602e-04 - mean_absolute_error: 0.0085 - val_loss: 1.6589e-04 - val_mean_absolute_error: 0.0098
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7972e-04 - mean_absolute_error: 0.0093 - val_loss: 1.2264e-04 - val_mean_absolute_error: 0.0082
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4736e-04 - mean_absolute_error: 0.0084 - val_loss: 2.1759e-04 - val_mean_absolute_error: 0.0118
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6413e-04 - mean_absolute_error: 0.0090 - val_loss: 1.2785e-04 - val_mean_absolute_error: 0.0086
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4839e-04 - mean_absolute_error: 0.0089 - val_loss: 1.2392e-04 - val_mean_absolute_error: 0.0084
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4651e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2241e-04 - val_mean_absolute_error: 0.0082
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6545e-04 - mean_absolute_error: 0.0092 - val_loss: 1.3660e-04 - val_mean_absolute_error: 0.0087

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5380e-04 - mean_absolute_error: 0.0092
# Test Loss: [0.0001366041979053989, 0.008683178573846817]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 636159.019769965
# RMSE: 797.595774669077
# MAE: 589.4199996887451
# MAPE: 1.7369095929983476 %
#
# Model evalution on validate set
# MSE: 5038303.845342336
# RMSE: 2244.6166366090974
# MAE: 1478.2956159607438
# MAPE: 3.0958664101602413 %

# %% [markdown]
# ## 4. Forecast the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Forecast the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
y_pred_30_days
# Out:
# array([[59617.68 ],
#        [59599.535],
#        [59719.758],
#        [59672.91 ],
#        [59694.14 ],
#        [59676.613],
#        [59684.715],
#        [59680.01 ],
#        [59682.89 ],
#        [59681.375],
#        [59682.25 ],
#        [59681.746],
#        [59682.035],
#        [59681.867],
#        [59681.96 ],
#        [59681.91 ],
#        [59681.94 ],
#        [59681.92 ],
#        [59681.93 ],
#        [59681.92 ],
#        [59681.92 ],
#        [59681.92 ],
#        [59681.93 ],
#        [59681.93 ],
#        [59681.92 ],
#        [59681.92 ],
#        [59681.93 ],
#        [59681.93 ],
#        [59681.92 ],
#        [59681.92 ],
#        [59681.93 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(16, 9))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
