# %% [markdown]
# # Model: GRU (Gated Recurrent Unit)  - Stock Token: CMG - Test/Train/Vaildation: 70/20/10
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1033.81
# - MAE: 718.97
# - MAPE: 2.23 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 0  # 7 2 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830
# ...           ...
# 2024-02-26  40000
# 2024-02-27  40200
# 2024-02-28  40000
# 2024-02-29  39950
# 2024-03-01  41200
#
# [1252 rows x 1 columns]

# %%
df.shape
# Out:
# (1252, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1247    40000
# 1248    40200
# 1249    40000
# 1250    39950
# 1251    41200
# Name: close, Length: 1252, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((865, 10), (865,), (239, 10), (239,), (115, 10), (115,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(100),
        Dense(32, activation="relu"),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 100)            │        30,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,165 (133.46 KB)
#  Trainable params: 34,165 (133.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0324 - mean_absolute_error: 0.1213 - val_loss: 0.0014 - val_mean_absolute_error: 0.0308
# Epoch 2/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.3071e-04 - mean_absolute_error: 0.0220 - val_loss: 6.6506e-04 - val_mean_absolute_error: 0.0168
# Epoch 3/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4744e-04 - mean_absolute_error: 0.0146 - val_loss: 8.2647e-04 - val_mean_absolute_error: 0.0220
# Epoch 4/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6639e-04 - mean_absolute_error: 0.0187 - val_loss: 6.4918e-04 - val_mean_absolute_error: 0.0169
# Epoch 5/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6634e-04 - mean_absolute_error: 0.0152 - val_loss: 7.3340e-04 - val_mean_absolute_error: 0.0191
# Epoch 6/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7340e-04 - mean_absolute_error: 0.0147 - val_loss: 5.9053e-04 - val_mean_absolute_error: 0.0160
# Epoch 7/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7236e-04 - mean_absolute_error: 0.0132 - val_loss: 6.2331e-04 - val_mean_absolute_error: 0.0169
# Epoch 8/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3857e-04 - mean_absolute_error: 0.0145 - val_loss: 5.6666e-04 - val_mean_absolute_error: 0.0161
# Epoch 9/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8351e-04 - mean_absolute_error: 0.0155 - val_loss: 5.4374e-04 - val_mean_absolute_error: 0.0155
# Epoch 10/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7060e-04 - mean_absolute_error: 0.0132 - val_loss: 5.6583e-04 - val_mean_absolute_error: 0.0159
# Epoch 11/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7727e-04 - mean_absolute_error: 0.0133 - val_loss: 6.3273e-04 - val_mean_absolute_error: 0.0188
# Epoch 12/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9781e-04 - mean_absolute_error: 0.0136 - val_loss: 7.0218e-04 - val_mean_absolute_error: 0.0208
# Epoch 13/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2195e-04 - mean_absolute_error: 0.0143 - val_loss: 9.0653e-04 - val_mean_absolute_error: 0.0253
# Epoch 14/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0385e-04 - mean_absolute_error: 0.0185 - val_loss: 5.1238e-04 - val_mean_absolute_error: 0.0152
# Epoch 15/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5880e-04 - mean_absolute_error: 0.0130 - val_loss: 5.2192e-04 - val_mean_absolute_error: 0.0157
# Epoch 16/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4801e-04 - mean_absolute_error: 0.0128 - val_loss: 7.4435e-04 - val_mean_absolute_error: 0.0221
# Epoch 17/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6095e-04 - mean_absolute_error: 0.0185 - val_loss: 5.1091e-04 - val_mean_absolute_error: 0.0150
# Epoch 18/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3747e-04 - mean_absolute_error: 0.0123 - val_loss: 5.6133e-04 - val_mean_absolute_error: 0.0174
# Epoch 19/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9174e-04 - mean_absolute_error: 0.0138 - val_loss: 5.7252e-04 - val_mean_absolute_error: 0.0167
# Epoch 20/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6167e-04 - mean_absolute_error: 0.0133 - val_loss: 5.3314e-04 - val_mean_absolute_error: 0.0166
# Epoch 21/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7252e-04 - mean_absolute_error: 0.0136 - val_loss: 4.9324e-04 - val_mean_absolute_error: 0.0149
# Epoch 22/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6598e-04 - mean_absolute_error: 0.0133 - val_loss: 5.0400e-04 - val_mean_absolute_error: 0.0157
# Epoch 23/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6339e-04 - mean_absolute_error: 0.0126 - val_loss: 5.1852e-04 - val_mean_absolute_error: 0.0156
# Epoch 24/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9928e-04 - mean_absolute_error: 0.0119 - val_loss: 9.4617e-04 - val_mean_absolute_error: 0.0250
# Epoch 25/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6827e-04 - mean_absolute_error: 0.0152 - val_loss: 6.8626e-04 - val_mean_absolute_error: 0.0210
# Epoch 26/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4349e-04 - mean_absolute_error: 0.0135 - val_loss: 7.0596e-04 - val_mean_absolute_error: 0.0215
# Epoch 27/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8821e-04 - mean_absolute_error: 0.0141 - val_loss: 7.7520e-04 - val_mean_absolute_error: 0.0230
# Epoch 28/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4632e-04 - mean_absolute_error: 0.0154 - val_loss: 6.0914e-04 - val_mean_absolute_error: 0.0191
# Epoch 29/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4489e-04 - mean_absolute_error: 0.0127 - val_loss: 7.3161e-04 - val_mean_absolute_error: 0.0221
# Epoch 30/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6725e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0011 - val_mean_absolute_error: 0.0273
# Epoch 31/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9430e-04 - mean_absolute_error: 0.0165 - val_loss: 5.9853e-04 - val_mean_absolute_error: 0.0188
# Epoch 32/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4107e-04 - mean_absolute_error: 0.0127 - val_loss: 4.8450e-04 - val_mean_absolute_error: 0.0150
# Epoch 33/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3937e-04 - mean_absolute_error: 0.0129 - val_loss: 6.5067e-04 - val_mean_absolute_error: 0.0202
# Epoch 34/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9775e-04 - mean_absolute_error: 0.0143 - val_loss: 8.8897e-04 - val_mean_absolute_error: 0.0240
# Epoch 35/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9356e-04 - mean_absolute_error: 0.0146 - val_loss: 9.7040e-04 - val_mean_absolute_error: 0.0255
# Epoch 36/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1356e-04 - mean_absolute_error: 0.0148 - val_loss: 9.1056e-04 - val_mean_absolute_error: 0.0244
# Epoch 37/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4851e-04 - mean_absolute_error: 0.0138 - val_loss: 9.1982e-04 - val_mean_absolute_error: 0.0259
# Epoch 38/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9630e-04 - mean_absolute_error: 0.0142 - val_loss: 4.9090e-04 - val_mean_absolute_error: 0.0152
# Epoch 39/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2538e-04 - mean_absolute_error: 0.0122 - val_loss: 5.6180e-04 - val_mean_absolute_error: 0.0177
# Epoch 40/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0078e-04 - mean_absolute_error: 0.0115 - val_loss: 6.7687e-04 - val_mean_absolute_error: 0.0197
# Epoch 41/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4853e-04 - mean_absolute_error: 0.0130 - val_loss: 4.9414e-04 - val_mean_absolute_error: 0.0154
# Epoch 42/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1903e-04 - mean_absolute_error: 0.0123 - val_loss: 5.3261e-04 - val_mean_absolute_error: 0.0165
# Epoch 43/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1372e-04 - mean_absolute_error: 0.0125 - val_loss: 5.5779e-04 - val_mean_absolute_error: 0.0174
# Epoch 44/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1511e-04 - mean_absolute_error: 0.0148 - val_loss: 5.0058e-04 - val_mean_absolute_error: 0.0154
# Epoch 45/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9286e-04 - mean_absolute_error: 0.0118 - val_loss: 5.9021e-04 - val_mean_absolute_error: 0.0184
# Epoch 46/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4137e-04 - mean_absolute_error: 0.0137 - val_loss: 6.7368e-04 - val_mean_absolute_error: 0.0198
# Epoch 47/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0612e-04 - mean_absolute_error: 0.0126 - val_loss: 5.0413e-04 - val_mean_absolute_error: 0.0157
# Epoch 48/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2454e-04 - mean_absolute_error: 0.0126 - val_loss: 5.1574e-04 - val_mean_absolute_error: 0.0161
# Epoch 49/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9555e-04 - mean_absolute_error: 0.0120 - val_loss: 4.9339e-04 - val_mean_absolute_error: 0.0154
# Epoch 50/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1769e-04 - mean_absolute_error: 0.0119 - val_loss: 6.4805e-04 - val_mean_absolute_error: 0.0200
# Epoch 51/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5704e-04 - mean_absolute_error: 0.0135 - val_loss: 5.7608e-04 - val_mean_absolute_error: 0.0180
# Epoch 52/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1463e-04 - mean_absolute_error: 0.0121 - val_loss: 4.9487e-04 - val_mean_absolute_error: 0.0155
# Epoch 53/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4647e-04 - mean_absolute_error: 0.0133 - val_loss: 4.9156e-04 - val_mean_absolute_error: 0.0153
# Epoch 54/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1217e-04 - mean_absolute_error: 0.0121 - val_loss: 6.9377e-04 - val_mean_absolute_error: 0.0202
# Epoch 55/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0908e-04 - mean_absolute_error: 0.0147 - val_loss: 5.0293e-04 - val_mean_absolute_error: 0.0157
# Epoch 56/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2092e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0014 - val_mean_absolute_error: 0.0328
# Epoch 57/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8734e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0017 - val_mean_absolute_error: 0.0371
# Epoch 58/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9936e-04 - mean_absolute_error: 0.0201 - val_loss: 5.2815e-04 - val_mean_absolute_error: 0.0164
# Epoch 59/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6778e-04 - mean_absolute_error: 0.0138 - val_loss: 7.1032e-04 - val_mean_absolute_error: 0.0204
# Epoch 60/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2510e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0033 - val_mean_absolute_error: 0.0538
# Epoch 61/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - mean_absolute_error: 0.0326 - val_loss: 6.5465e-04 - val_mean_absolute_error: 0.0193
# Epoch 62/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3017e-04 - mean_absolute_error: 0.0175 - val_loss: 5.8808e-04 - val_mean_absolute_error: 0.0178
# Epoch 63/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3165e-04 - mean_absolute_error: 0.0127 - val_loss: 4.9721e-04 - val_mean_absolute_error: 0.0155
# Epoch 64/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2451e-04 - mean_absolute_error: 0.0127 - val_loss: 5.8540e-04 - val_mean_absolute_error: 0.0178
# Epoch 65/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2323e-04 - mean_absolute_error: 0.0127 - val_loss: 5.0284e-04 - val_mean_absolute_error: 0.0157
# Epoch 66/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8802e-04 - mean_absolute_error: 0.0115 - val_loss: 5.3435e-04 - val_mean_absolute_error: 0.0166
# Epoch 67/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5958e-04 - mean_absolute_error: 0.0111 - val_loss: 5.5285e-04 - val_mean_absolute_error: 0.0171
# Epoch 68/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1265e-04 - mean_absolute_error: 0.0120 - val_loss: 5.6916e-04 - val_mean_absolute_error: 0.0177
# Epoch 69/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1811e-04 - mean_absolute_error: 0.0119 - val_loss: 5.3496e-04 - val_mean_absolute_error: 0.0167
# Epoch 70/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3253e-04 - mean_absolute_error: 0.0134 - val_loss: 7.4136e-04 - val_mean_absolute_error: 0.0212
# Epoch 71/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6276e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0011 - val_mean_absolute_error: 0.0293
# Epoch 72/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8117e-04 - mean_absolute_error: 0.0164 - val_loss: 5.8187e-04 - val_mean_absolute_error: 0.0176
# Epoch 73/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0608e-04 - mean_absolute_error: 0.0123 - val_loss: 7.4618e-04 - val_mean_absolute_error: 0.0221
# Epoch 74/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5692e-04 - mean_absolute_error: 0.0134 - val_loss: 6.4865e-04 - val_mean_absolute_error: 0.0197
# Epoch 75/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0389e-04 - mean_absolute_error: 0.0122 - val_loss: 6.9026e-04 - val_mean_absolute_error: 0.0207
# Epoch 76/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8618e-04 - mean_absolute_error: 0.0140 - val_loss: 5.6350e-04 - val_mean_absolute_error: 0.0173
# Epoch 77/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0354e-04 - mean_absolute_error: 0.0123 - val_loss: 5.7206e-04 - val_mean_absolute_error: 0.0176
# Epoch 78/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4896e-04 - mean_absolute_error: 0.0134 - val_loss: 5.7578e-04 - val_mean_absolute_error: 0.0178
# Epoch 79/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2200e-04 - mean_absolute_error: 0.0125 - val_loss: 5.1930e-04 - val_mean_absolute_error: 0.0162
# Epoch 80/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9114e-04 - mean_absolute_error: 0.0123 - val_loss: 5.5992e-04 - val_mean_absolute_error: 0.0173
# Epoch 81/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2196e-04 - mean_absolute_error: 0.0125 - val_loss: 5.1180e-04 - val_mean_absolute_error: 0.0160
# Epoch 82/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1242e-04 - mean_absolute_error: 0.0122 - val_loss: 6.5733e-04 - val_mean_absolute_error: 0.0196
# Epoch 83/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1717e-04 - mean_absolute_error: 0.0122 - val_loss: 5.1017e-04 - val_mean_absolute_error: 0.0159
# Epoch 84/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7410e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0011 - val_mean_absolute_error: 0.0278
# Epoch 85/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0585e-04 - mean_absolute_error: 0.0199 - val_loss: 5.1441e-04 - val_mean_absolute_error: 0.0160
# Epoch 86/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3431e-04 - mean_absolute_error: 0.0129 - val_loss: 4.9653e-04 - val_mean_absolute_error: 0.0155
# Epoch 87/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2879e-04 - mean_absolute_error: 0.0126 - val_loss: 4.9780e-04 - val_mean_absolute_error: 0.0156
# Epoch 88/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3875e-04 - mean_absolute_error: 0.0123 - val_loss: 4.9488e-04 - val_mean_absolute_error: 0.0155
# Epoch 89/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3156e-04 - mean_absolute_error: 0.0127 - val_loss: 5.3570e-04 - val_mean_absolute_error: 0.0166
# Epoch 90/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8906e-04 - mean_absolute_error: 0.0118 - val_loss: 5.1915e-04 - val_mean_absolute_error: 0.0162
# Epoch 91/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1605e-04 - mean_absolute_error: 0.0122 - val_loss: 4.9728e-04 - val_mean_absolute_error: 0.0155
# Epoch 92/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0664e-04 - mean_absolute_error: 0.0119 - val_loss: 5.0249e-04 - val_mean_absolute_error: 0.0157
# Epoch 93/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4493e-04 - mean_absolute_error: 0.0128 - val_loss: 5.1284e-04 - val_mean_absolute_error: 0.0160
# Epoch 94/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0697e-04 - mean_absolute_error: 0.0118 - val_loss: 5.0886e-04 - val_mean_absolute_error: 0.0159
# Epoch 95/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9712e-04 - mean_absolute_error: 0.0115 - val_loss: 5.8773e-04 - val_mean_absolute_error: 0.0179
# Epoch 96/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0055e-04 - mean_absolute_error: 0.0119 - val_loss: 5.5591e-04 - val_mean_absolute_error: 0.0171
# Epoch 97/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7416e-04 - mean_absolute_error: 0.0113 - val_loss: 5.0631e-04 - val_mean_absolute_error: 0.0158
# Epoch 98/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8251e-04 - mean_absolute_error: 0.0116 - val_loss: 5.9233e-04 - val_mean_absolute_error: 0.0181
# Epoch 99/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8965e-04 - mean_absolute_error: 0.0120 - val_loss: 5.0566e-04 - val_mean_absolute_error: 0.0159
# Epoch 100/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9429e-04 - mean_absolute_error: 0.0118 - val_loss: 6.0795e-04 - val_mean_absolute_error: 0.0186
# Epoch 101/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6744e-04 - mean_absolute_error: 0.0142 - val_loss: 5.5485e-04 - val_mean_absolute_error: 0.0171
# Epoch 102/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5060e-04 - mean_absolute_error: 0.0108 - val_loss: 5.1855e-04 - val_mean_absolute_error: 0.0161
# Epoch 103/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0740e-04 - mean_absolute_error: 0.0119 - val_loss: 5.3737e-04 - val_mean_absolute_error: 0.0168
# Epoch 104/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3329e-04 - mean_absolute_error: 0.0123 - val_loss: 5.6599e-04 - val_mean_absolute_error: 0.0176
# Epoch 105/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7236e-04 - mean_absolute_error: 0.0114 - val_loss: 5.6408e-04 - val_mean_absolute_error: 0.0172
# Epoch 106/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8580e-04 - mean_absolute_error: 0.0139 - val_loss: 9.4019e-04 - val_mean_absolute_error: 0.0259
# Epoch 107/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5094e-04 - mean_absolute_error: 0.0135 - val_loss: 5.0991e-04 - val_mean_absolute_error: 0.0159
# Epoch 108/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9277e-04 - mean_absolute_error: 0.0114 - val_loss: 7.0575e-04 - val_mean_absolute_error: 0.0202
# Epoch 109/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8442e-04 - mean_absolute_error: 0.0188 - val_loss: 0.0011 - val_mean_absolute_error: 0.0287
# Epoch 110/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2916e-04 - mean_absolute_error: 0.0151 - val_loss: 5.3164e-04 - val_mean_absolute_error: 0.0165
# Epoch 111/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2058e-04 - mean_absolute_error: 0.0126 - val_loss: 5.1991e-04 - val_mean_absolute_error: 0.0160
# Epoch 112/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0830e-04 - mean_absolute_error: 0.0121 - val_loss: 5.2063e-04 - val_mean_absolute_error: 0.0162
# Epoch 113/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9188e-04 - mean_absolute_error: 0.0118 - val_loss: 5.1701e-04 - val_mean_absolute_error: 0.0161
# Epoch 114/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3697e-04 - mean_absolute_error: 0.0127 - val_loss: 5.8085e-04 - val_mean_absolute_error: 0.0176
# Epoch 115/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7270e-04 - mean_absolute_error: 0.0139 - val_loss: 9.3300e-04 - val_mean_absolute_error: 0.0258
# Epoch 116/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8598e-04 - mean_absolute_error: 0.0162 - val_loss: 5.4573e-04 - val_mean_absolute_error: 0.0169
# Epoch 117/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2209e-04 - mean_absolute_error: 0.0128 - val_loss: 6.2721e-04 - val_mean_absolute_error: 0.0191
# Epoch 118/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3195e-04 - mean_absolute_error: 0.0126 - val_loss: 5.2104e-04 - val_mean_absolute_error: 0.0162
# Epoch 119/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4966e-04 - mean_absolute_error: 0.0107 - val_loss: 7.7549e-04 - val_mean_absolute_error: 0.0226
# Epoch 120/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3367e-04 - mean_absolute_error: 0.0153 - val_loss: 5.0868e-04 - val_mean_absolute_error: 0.0159
# Epoch 121/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8378e-04 - mean_absolute_error: 0.0138 - val_loss: 6.2074e-04 - val_mean_absolute_error: 0.0189
# Epoch 122/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4947e-04 - mean_absolute_error: 0.0146 - val_loss: 5.0909e-04 - val_mean_absolute_error: 0.0159
# Epoch 123/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0338e-04 - mean_absolute_error: 0.0118 - val_loss: 6.2594e-04 - val_mean_absolute_error: 0.0190
# Epoch 124/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7515e-04 - mean_absolute_error: 0.0132 - val_loss: 5.1582e-04 - val_mean_absolute_error: 0.0161
# Epoch 125/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0892e-04 - mean_absolute_error: 0.0120 - val_loss: 6.9923e-04 - val_mean_absolute_error: 0.0209
# Epoch 126/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2117e-04 - mean_absolute_error: 0.0125 - val_loss: 5.5902e-04 - val_mean_absolute_error: 0.0173
# Epoch 127/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2833e-04 - mean_absolute_error: 0.0130 - val_loss: 5.1336e-04 - val_mean_absolute_error: 0.0160
# Epoch 128/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1723e-04 - mean_absolute_error: 0.0125 - val_loss: 5.7435e-04 - val_mean_absolute_error: 0.0176
# Epoch 129/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6353e-04 - mean_absolute_error: 0.0136 - val_loss: 5.5417e-04 - val_mean_absolute_error: 0.0170
# Epoch 130/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1771e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0020 - val_mean_absolute_error: 0.0402
# Epoch 131/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5494e-04 - mean_absolute_error: 0.0199 - val_loss: 5.6360e-04 - val_mean_absolute_error: 0.0172
# Epoch 132/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2187e-04 - mean_absolute_error: 0.0123 - val_loss: 5.6905e-04 - val_mean_absolute_error: 0.0175
# Epoch 133/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0908e-04 - mean_absolute_error: 0.0122 - val_loss: 5.0844e-04 - val_mean_absolute_error: 0.0158
# Epoch 134/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1375e-04 - mean_absolute_error: 0.0122 - val_loss: 5.0843e-04 - val_mean_absolute_error: 0.0158
# Epoch 135/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9402e-04 - mean_absolute_error: 0.0117 - val_loss: 6.8128e-04 - val_mean_absolute_error: 0.0198
# Epoch 136/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7024e-04 - mean_absolute_error: 0.0117 - val_loss: 5.4042e-04 - val_mean_absolute_error: 0.0167
# Epoch 137/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8350e-04 - mean_absolute_error: 0.0113 - val_loss: 6.2087e-04 - val_mean_absolute_error: 0.0186
# Epoch 138/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0481e-04 - mean_absolute_error: 0.0121 - val_loss: 5.2532e-04 - val_mean_absolute_error: 0.0163
# Epoch 139/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0424e-04 - mean_absolute_error: 0.0121 - val_loss: 5.3576e-04 - val_mean_absolute_error: 0.0166
# Epoch 140/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6650e-04 - mean_absolute_error: 0.0111 - val_loss: 6.0220e-04 - val_mean_absolute_error: 0.0184
# Epoch 141/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1382e-04 - mean_absolute_error: 0.0124 - val_loss: 5.2618e-04 - val_mean_absolute_error: 0.0164
# Epoch 142/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0408e-04 - mean_absolute_error: 0.0121 - val_loss: 5.2253e-04 - val_mean_absolute_error: 0.0162
# Epoch 143/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9175e-04 - mean_absolute_error: 0.0120 - val_loss: 5.9524e-04 - val_mean_absolute_error: 0.0181
# Epoch 144/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7775e-04 - mean_absolute_error: 0.0118 - val_loss: 5.8026e-04 - val_mean_absolute_error: 0.0177
# Epoch 145/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1291e-04 - mean_absolute_error: 0.0120 - val_loss: 6.0074e-04 - val_mean_absolute_error: 0.0185
# Epoch 146/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7286e-04 - mean_absolute_error: 0.0146 - val_loss: 6.4700e-04 - val_mean_absolute_error: 0.0192
# Epoch 147/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0118e-04 - mean_absolute_error: 0.0119 - val_loss: 5.7747e-04 - val_mean_absolute_error: 0.0176
# Epoch 148/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1029e-04 - mean_absolute_error: 0.0121 - val_loss: 6.0951e-04 - val_mean_absolute_error: 0.0186
# Epoch 149/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9952e-04 - mean_absolute_error: 0.0118 - val_loss: 5.8451e-04 - val_mean_absolute_error: 0.0180
# Epoch 150/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2876e-04 - mean_absolute_error: 0.0127 - val_loss: 5.3034e-04 - val_mean_absolute_error: 0.0165
# Epoch 151/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0622e-04 - mean_absolute_error: 0.0126 - val_loss: 5.1537e-04 - val_mean_absolute_error: 0.0160
# Epoch 152/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9054e-04 - mean_absolute_error: 0.0117 - val_loss: 5.6245e-04 - val_mean_absolute_error: 0.0173
# Epoch 153/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5996e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0016 - val_mean_absolute_error: 0.0362
# Epoch 154/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7120e-04 - mean_absolute_error: 0.0209 - val_loss: 5.2409e-04 - val_mean_absolute_error: 0.0163
# Epoch 155/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2835e-04 - mean_absolute_error: 0.0126 - val_loss: 5.1554e-04 - val_mean_absolute_error: 0.0159
# Epoch 156/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0462e-04 - mean_absolute_error: 0.0119 - val_loss: 6.3967e-04 - val_mean_absolute_error: 0.0194
# Epoch 157/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8212e-04 - mean_absolute_error: 0.0147 - val_loss: 5.6322e-04 - val_mean_absolute_error: 0.0172
# Epoch 158/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8201e-04 - mean_absolute_error: 0.0115 - val_loss: 5.1873e-04 - val_mean_absolute_error: 0.0161
# Epoch 159/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3702e-04 - mean_absolute_error: 0.0105 - val_loss: 5.7705e-04 - val_mean_absolute_error: 0.0175
# Epoch 160/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8586e-04 - mean_absolute_error: 0.0123 - val_loss: 5.8000e-04 - val_mean_absolute_error: 0.0178
# Epoch 161/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3442e-04 - mean_absolute_error: 0.0124 - val_loss: 7.9694e-04 - val_mean_absolute_error: 0.0222
# Epoch 162/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0582e-04 - mean_absolute_error: 0.0125 - val_loss: 5.4065e-04 - val_mean_absolute_error: 0.0167
# Epoch 163/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1516e-04 - mean_absolute_error: 0.0120 - val_loss: 5.2168e-04 - val_mean_absolute_error: 0.0161
# Epoch 164/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7310e-04 - mean_absolute_error: 0.0117 - val_loss: 5.9167e-04 - val_mean_absolute_error: 0.0181
# Epoch 165/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1058e-04 - mean_absolute_error: 0.0118 - val_loss: 5.1427e-04 - val_mean_absolute_error: 0.0159
# Epoch 166/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4835e-04 - mean_absolute_error: 0.0131 - val_loss: 5.2818e-04 - val_mean_absolute_error: 0.0163
# Epoch 167/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0272e-04 - mean_absolute_error: 0.0122 - val_loss: 5.9241e-04 - val_mean_absolute_error: 0.0178
# Epoch 168/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9760e-04 - mean_absolute_error: 0.0120 - val_loss: 8.1572e-04 - val_mean_absolute_error: 0.0226
# Epoch 169/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4879e-04 - mean_absolute_error: 0.0130 - val_loss: 8.8374e-04 - val_mean_absolute_error: 0.0239
# Epoch 170/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8357e-04 - mean_absolute_error: 0.0140 - val_loss: 5.3581e-04 - val_mean_absolute_error: 0.0164
# Epoch 171/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0593e-04 - mean_absolute_error: 0.0116 - val_loss: 5.2520e-04 - val_mean_absolute_error: 0.0160
# Epoch 172/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7203e-04 - mean_absolute_error: 0.0114 - val_loss: 5.3585e-04 - val_mean_absolute_error: 0.0164
# Epoch 173/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7516e-04 - mean_absolute_error: 0.0117 - val_loss: 5.7158e-04 - val_mean_absolute_error: 0.0173
# Epoch 174/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3756e-04 - mean_absolute_error: 0.0132 - val_loss: 6.8537e-04 - val_mean_absolute_error: 0.0198
# Epoch 175/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5925e-04 - mean_absolute_error: 0.0154 - val_loss: 6.6000e-04 - val_mean_absolute_error: 0.0198
# Epoch 176/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1160e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0013 - val_mean_absolute_error: 0.0310
# Epoch 177/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2304e-04 - mean_absolute_error: 0.0184 - val_loss: 5.3457e-04 - val_mean_absolute_error: 0.0162
# Epoch 178/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9969e-04 - mean_absolute_error: 0.0118 - val_loss: 5.3391e-04 - val_mean_absolute_error: 0.0162
# Epoch 179/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7246e-04 - mean_absolute_error: 0.0113 - val_loss: 6.5423e-04 - val_mean_absolute_error: 0.0196
# Epoch 180/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8568e-04 - mean_absolute_error: 0.0118 - val_loss: 5.8667e-04 - val_mean_absolute_error: 0.0177
# Epoch 181/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1846e-04 - mean_absolute_error: 0.0124 - val_loss: 5.5126e-04 - val_mean_absolute_error: 0.0169
# Epoch 182/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1292e-04 - mean_absolute_error: 0.0124 - val_loss: 6.2960e-04 - val_mean_absolute_error: 0.0186
# Epoch 183/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1515e-04 - mean_absolute_error: 0.0150 - val_loss: 5.2106e-04 - val_mean_absolute_error: 0.0160
# Epoch 184/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2576e-04 - mean_absolute_error: 0.0129 - val_loss: 5.2664e-04 - val_mean_absolute_error: 0.0161
# Epoch 185/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7442e-04 - mean_absolute_error: 0.0135 - val_loss: 7.8363e-04 - val_mean_absolute_error: 0.0219
# Epoch 186/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5118e-04 - mean_absolute_error: 0.0132 - val_loss: 5.8060e-04 - val_mean_absolute_error: 0.0176
# Epoch 187/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1981e-04 - mean_absolute_error: 0.0149 - val_loss: 5.4109e-04 - val_mean_absolute_error: 0.0162
# Epoch 188/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9629e-04 - mean_absolute_error: 0.0121 - val_loss: 5.5976e-04 - val_mean_absolute_error: 0.0168
# Epoch 189/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8586e-04 - mean_absolute_error: 0.0133 - val_loss: 6.4015e-04 - val_mean_absolute_error: 0.0187
# Epoch 190/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7469e-04 - mean_absolute_error: 0.0142 - val_loss: 5.2580e-04 - val_mean_absolute_error: 0.0159
# Epoch 191/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9713e-04 - mean_absolute_error: 0.0118 - val_loss: 5.2495e-04 - val_mean_absolute_error: 0.0160
# Epoch 192/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8485e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0010 - val_mean_absolute_error: 0.0264
# Epoch 193/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4517e-04 - mean_absolute_error: 0.0159 - val_loss: 5.9437e-04 - val_mean_absolute_error: 0.0178
# Epoch 194/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1513e-04 - mean_absolute_error: 0.0131 - val_loss: 6.6406e-04 - val_mean_absolute_error: 0.0198
# Epoch 195/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9167e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0015 - val_mean_absolute_error: 0.0336
# Epoch 196/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2794e-04 - mean_absolute_error: 0.0230 - val_loss: 5.8294e-04 - val_mean_absolute_error: 0.0178
# Epoch 197/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7978e-04 - mean_absolute_error: 0.0119 - val_loss: 5.3194e-04 - val_mean_absolute_error: 0.0163
# Epoch 198/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7669e-04 - mean_absolute_error: 0.0118 - val_loss: 5.2618e-04 - val_mean_absolute_error: 0.0160
# Epoch 199/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0792e-04 - mean_absolute_error: 0.0124 - val_loss: 6.1067e-04 - val_mean_absolute_error: 0.0181
# Epoch 200/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4930e-04 - mean_absolute_error: 0.0127 - val_loss: 5.8019e-04 - val_mean_absolute_error: 0.0175

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.0396e-04 - mean_absolute_error: 0.0224
# Test Loss: [0.0005801873048767447, 0.01745881326496601]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 239
# 250

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 1068756.1149899152
# RMSE: 1033.806613922505
# MAE: 718.9715448483264
# MAPE: 2.233169722320877 %
#
# Model evalution on validate set
# MSE: 683683.0734770402
# RMSE: 826.8513007046915
# MAE: 598.6052309782609
# MAPE: 1.5394534691260167 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
y_pred_30_days
# Out:
# array([[40760.125],
#        [40573.48 ],
#        [40663.613],
#        [40706.65 ],
#        [40620.527],
#        [40662.01 ],
#        [40645.586],
#        [40640.29 ],
#        [40651.   ],
#        [40643.895],
#        [40646.742],
#        [40647.15 ],
#        [40645.742],
#        [40646.863],
#        [40646.363],
#        [40646.375],
#        [40646.547],
#        [40646.383],
#        [40646.47 ],
#        [40646.457],
#        [40646.438],
#        [40646.465],
#        [40646.45 ],
#        [40646.45 ],
#        [40646.453],
#        [40646.45 ],
#        [40646.45 ],
#        [40646.453],
#        [40646.453],
#        [40646.453],
#        [40646.453]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
