# %% [markdown]
# # Model: GRU (Gated Recurrent Unit)  - Stock Token: CMG - Test/Train/Vaildation: 70/20/10
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1033.81
# - MAE: 718.97
# - MAPE: 2.23 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 0  # 7 2 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830
# ...           ...
# 2024-05-27  59000
# 2024-05-28  62100
# 2024-05-29  60000
# 2024-05-30  59200
# 2024-05-31  60900
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((908, 10), (908,), (251, 10), (251,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(100),
        Dense(32, activation="relu"),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 100)            │        30,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,165 (133.46 KB)
#  Trainable params: 34,165 (133.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 70ms/step - loss: 0.0459 - mean_absolute_error: 0.1585 - val_loss: 0.0176 - val_mean_absolute_error: 0.1296
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0030 - mean_absolute_error: 0.0381 - val_loss: 6.6945e-04 - val_mean_absolute_error: 0.0232
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.6427e-04 - mean_absolute_error: 0.0136 - val_loss: 2.0144e-04 - val_mean_absolute_error: 0.0100
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.7341e-04 - mean_absolute_error: 0.0116 - val_loss: 2.3187e-04 - val_mean_absolute_error: 0.0109
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.2652e-04 - mean_absolute_error: 0.0105 - val_loss: 2.2747e-04 - val_mean_absolute_error: 0.0108
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.3038e-04 - mean_absolute_error: 0.0103 - val_loss: 2.0866e-04 - val_mean_absolute_error: 0.0111
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.7628e-04 - mean_absolute_error: 0.0119 - val_loss: 2.6094e-04 - val_mean_absolute_error: 0.0122
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.3067e-04 - mean_absolute_error: 0.0103 - val_loss: 2.8542e-04 - val_mean_absolute_error: 0.0131
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.0245e-04 - mean_absolute_error: 0.0121 - val_loss: 1.8703e-04 - val_mean_absolute_error: 0.0104
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.4973e-04 - mean_absolute_error: 0.0111 - val_loss: 2.0140e-04 - val_mean_absolute_error: 0.0111
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.3336e-04 - mean_absolute_error: 0.0103 - val_loss: 2.1832e-04 - val_mean_absolute_error: 0.0109
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.1853e-04 - mean_absolute_error: 0.0102 - val_loss: 1.5194e-04 - val_mean_absolute_error: 0.0087
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.0251e-04 - mean_absolute_error: 0.0098 - val_loss: 1.7383e-04 - val_mean_absolute_error: 0.0094
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.1928e-04 - mean_absolute_error: 0.0102 - val_loss: 1.6254e-04 - val_mean_absolute_error: 0.0090
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.1459e-04 - mean_absolute_error: 0.0101 - val_loss: 1.6324e-04 - val_mean_absolute_error: 0.0096
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.2832e-04 - mean_absolute_error: 0.0103 - val_loss: 1.4214e-04 - val_mean_absolute_error: 0.0084
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.9909e-04 - mean_absolute_error: 0.0097 - val_loss: 1.5072e-04 - val_mean_absolute_error: 0.0090
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.9607e-04 - mean_absolute_error: 0.0100 - val_loss: 1.3833e-04 - val_mean_absolute_error: 0.0083
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.8765e-04 - mean_absolute_error: 0.0097 - val_loss: 2.5413e-04 - val_mean_absolute_error: 0.0128
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.9996e-04 - mean_absolute_error: 0.0097 - val_loss: 1.5448e-04 - val_mean_absolute_error: 0.0089
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.9402e-04 - mean_absolute_error: 0.0098 - val_loss: 2.6259e-04 - val_mean_absolute_error: 0.0132
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.0011e-04 - mean_absolute_error: 0.0100 - val_loss: 1.4717e-04 - val_mean_absolute_error: 0.0089
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.8938e-04 - mean_absolute_error: 0.0096 - val_loss: 1.3938e-04 - val_mean_absolute_error: 0.0083
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.9724e-04 - mean_absolute_error: 0.0095 - val_loss: 1.3065e-04 - val_mean_absolute_error: 0.0081
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.8205e-04 - mean_absolute_error: 0.0093 - val_loss: 1.3107e-04 - val_mean_absolute_error: 0.0081
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7251e-04 - mean_absolute_error: 0.0092 - val_loss: 1.6608e-04 - val_mean_absolute_error: 0.0096
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.7278e-04 - mean_absolute_error: 0.0091 - val_loss: 1.5723e-04 - val_mean_absolute_error: 0.0094
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.9692e-04 - mean_absolute_error: 0.0101 - val_loss: 1.3250e-04 - val_mean_absolute_error: 0.0082
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7702e-04 - mean_absolute_error: 0.0091 - val_loss: 1.3096e-04 - val_mean_absolute_error: 0.0081
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7595e-04 - mean_absolute_error: 0.0093 - val_loss: 1.4035e-04 - val_mean_absolute_error: 0.0085
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.7022e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2685e-04 - val_mean_absolute_error: 0.0080
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5986e-04 - mean_absolute_error: 0.0089 - val_loss: 1.6318e-04 - val_mean_absolute_error: 0.0097
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.2781e-04 - mean_absolute_error: 0.0111 - val_loss: 1.7382e-04 - val_mean_absolute_error: 0.0102
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.3827e-04 - mean_absolute_error: 0.0112 - val_loss: 1.2425e-04 - val_mean_absolute_error: 0.0078
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.5189e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2469e-04 - val_mean_absolute_error: 0.0079
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8077e-04 - mean_absolute_error: 0.0092 - val_loss: 2.8463e-04 - val_mean_absolute_error: 0.0143
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.8788e-04 - mean_absolute_error: 0.0098 - val_loss: 2.7683e-04 - val_mean_absolute_error: 0.0140
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6773e-04 - mean_absolute_error: 0.0091 - val_loss: 1.2247e-04 - val_mean_absolute_error: 0.0078
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.7366e-04 - mean_absolute_error: 0.0091 - val_loss: 1.3874e-04 - val_mean_absolute_error: 0.0085
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.9099e-04 - mean_absolute_error: 0.0099 - val_loss: 1.2869e-04 - val_mean_absolute_error: 0.0080
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.8637e-04 - mean_absolute_error: 0.0101 - val_loss: 1.2265e-04 - val_mean_absolute_error: 0.0078
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.9425e-04 - mean_absolute_error: 0.0099 - val_loss: 1.3917e-04 - val_mean_absolute_error: 0.0086
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6510e-04 - mean_absolute_error: 0.0090 - val_loss: 1.2138e-04 - val_mean_absolute_error: 0.0078
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.6039e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2185e-04 - val_mean_absolute_error: 0.0078
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.6024e-04 - mean_absolute_error: 0.0089 - val_loss: 1.2599e-04 - val_mean_absolute_error: 0.0080
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6838e-04 - mean_absolute_error: 0.0090 - val_loss: 1.2067e-04 - val_mean_absolute_error: 0.0077
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.6456e-04 - mean_absolute_error: 0.0089 - val_loss: 1.3167e-04 - val_mean_absolute_error: 0.0082
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7032e-04 - mean_absolute_error: 0.0091 - val_loss: 1.8935e-04 - val_mean_absolute_error: 0.0108
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.8274e-04 - mean_absolute_error: 0.0093 - val_loss: 1.2115e-04 - val_mean_absolute_error: 0.0078
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6581e-04 - mean_absolute_error: 0.0092 - val_loss: 3.5020e-04 - val_mean_absolute_error: 0.0164
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.3561e-04 - mean_absolute_error: 0.0113 - val_loss: 1.3294e-04 - val_mean_absolute_error: 0.0083
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4937e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2965e-04 - val_mean_absolute_error: 0.0082
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.7269e-04 - mean_absolute_error: 0.0093 - val_loss: 1.3851e-04 - val_mean_absolute_error: 0.0085
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4331e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2410e-04 - val_mean_absolute_error: 0.0079
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8230e-04 - mean_absolute_error: 0.0095 - val_loss: 1.2232e-04 - val_mean_absolute_error: 0.0079
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.5417e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2825e-04 - val_mean_absolute_error: 0.0081
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4302e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2156e-04 - val_mean_absolute_error: 0.0078
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7228e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2361e-04 - val_mean_absolute_error: 0.0079
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.8304e-04 - mean_absolute_error: 0.0096 - val_loss: 1.8665e-04 - val_mean_absolute_error: 0.0107
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6289e-04 - mean_absolute_error: 0.0091 - val_loss: 1.2007e-04 - val_mean_absolute_error: 0.0079
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.4406e-04 - mean_absolute_error: 0.0085 - val_loss: 1.3711e-04 - val_mean_absolute_error: 0.0088
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.7950e-04 - mean_absolute_error: 0.0098 - val_loss: 2.1387e-04 - val_mean_absolute_error: 0.0117
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.0432e-04 - mean_absolute_error: 0.0110 - val_loss: 1.2256e-04 - val_mean_absolute_error: 0.0081
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5467e-04 - mean_absolute_error: 0.0086 - val_loss: 1.7138e-04 - val_mean_absolute_error: 0.0101
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4901e-04 - mean_absolute_error: 0.0083 - val_loss: 1.5022e-04 - val_mean_absolute_error: 0.0094
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6396e-04 - mean_absolute_error: 0.0087 - val_loss: 1.3918e-04 - val_mean_absolute_error: 0.0089
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5958e-04 - mean_absolute_error: 0.0086 - val_loss: 1.7564e-04 - val_mean_absolute_error: 0.0103
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.6936e-04 - mean_absolute_error: 0.0093 - val_loss: 1.3799e-04 - val_mean_absolute_error: 0.0086
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.6125e-04 - mean_absolute_error: 0.0093 - val_loss: 1.7237e-04 - val_mean_absolute_error: 0.0101
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4559e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2906e-04 - val_mean_absolute_error: 0.0081
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.4696e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3093e-04 - val_mean_absolute_error: 0.0085
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7784e-04 - mean_absolute_error: 0.0092 - val_loss: 2.7333e-04 - val_mean_absolute_error: 0.0141
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1468e-04 - mean_absolute_error: 0.0111 - val_loss: 1.3705e-04 - val_mean_absolute_error: 0.0085
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5271e-04 - mean_absolute_error: 0.0087 - val_loss: 1.3299e-04 - val_mean_absolute_error: 0.0083
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.5048e-04 - mean_absolute_error: 0.0085 - val_loss: 2.1654e-04 - val_mean_absolute_error: 0.0119
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6001e-04 - mean_absolute_error: 0.0087 - val_loss: 1.3438e-04 - val_mean_absolute_error: 0.0084
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5692e-04 - mean_absolute_error: 0.0086 - val_loss: 1.3170e-04 - val_mean_absolute_error: 0.0083
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.6119e-04 - mean_absolute_error: 0.0085 - val_loss: 2.9724e-04 - val_mean_absolute_error: 0.0147
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8557e-04 - mean_absolute_error: 0.0098 - val_loss: 2.1884e-04 - val_mean_absolute_error: 0.0120
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.8933e-04 - mean_absolute_error: 0.0099 - val_loss: 3.5832e-04 - val_mean_absolute_error: 0.0166
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.9955e-04 - mean_absolute_error: 0.0102 - val_loss: 2.6682e-04 - val_mean_absolute_error: 0.0138
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.0569e-04 - mean_absolute_error: 0.0106 - val_loss: 1.1763e-04 - val_mean_absolute_error: 0.0078
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5204e-04 - mean_absolute_error: 0.0083 - val_loss: 2.1770e-04 - val_mean_absolute_error: 0.0122
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.5440e-04 - mean_absolute_error: 0.0090 - val_loss: 1.6717e-04 - val_mean_absolute_error: 0.0102
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.6029e-04 - mean_absolute_error: 0.0088 - val_loss: 1.7346e-04 - val_mean_absolute_error: 0.0101
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.7697e-04 - mean_absolute_error: 0.0094 - val_loss: 1.1774e-04 - val_mean_absolute_error: 0.0078
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6480e-04 - mean_absolute_error: 0.0088 - val_loss: 2.5089e-04 - val_mean_absolute_error: 0.0134
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.7673e-04 - mean_absolute_error: 0.0100 - val_loss: 1.1728e-04 - val_mean_absolute_error: 0.0078
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.4547e-04 - mean_absolute_error: 0.0081 - val_loss: 1.4550e-04 - val_mean_absolute_error: 0.0093
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4905e-04 - mean_absolute_error: 0.0087 - val_loss: 1.4193e-04 - val_mean_absolute_error: 0.0087
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.4154e-04 - mean_absolute_error: 0.0081 - val_loss: 1.1773e-04 - val_mean_absolute_error: 0.0079
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3663e-04 - mean_absolute_error: 0.0080 - val_loss: 1.6201e-04 - val_mean_absolute_error: 0.0100
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4764e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2041e-04 - val_mean_absolute_error: 0.0081
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4764e-04 - mean_absolute_error: 0.0086 - val_loss: 1.1790e-04 - val_mean_absolute_error: 0.0078
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2813e-04 - mean_absolute_error: 0.0077 - val_loss: 1.1878e-04 - val_mean_absolute_error: 0.0080
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3944e-04 - mean_absolute_error: 0.0081 - val_loss: 2.9136e-04 - val_mean_absolute_error: 0.0145
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.8627e-04 - mean_absolute_error: 0.0101 - val_loss: 1.2781e-04 - val_mean_absolute_error: 0.0081
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5469e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2876e-04 - val_mean_absolute_error: 0.0085
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.4087e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2748e-04 - val_mean_absolute_error: 0.0085
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.7089e-04 - mean_absolute_error: 0.0092 - val_loss: 1.1839e-04 - val_mean_absolute_error: 0.0079
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.4481e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2344e-04 - val_mean_absolute_error: 0.0083
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5201e-04 - mean_absolute_error: 0.0080 - val_loss: 1.3073e-04 - val_mean_absolute_error: 0.0086
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3319e-04 - mean_absolute_error: 0.0081 - val_loss: 1.5255e-04 - val_mean_absolute_error: 0.0092
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7483e-04 - mean_absolute_error: 0.0091 - val_loss: 1.2936e-04 - val_mean_absolute_error: 0.0086
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.7656e-04 - mean_absolute_error: 0.0094 - val_loss: 1.4988e-04 - val_mean_absolute_error: 0.0091
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5137e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2680e-04 - val_mean_absolute_error: 0.0081
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3076e-04 - mean_absolute_error: 0.0079 - val_loss: 1.5788e-04 - val_mean_absolute_error: 0.0099
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4870e-04 - mean_absolute_error: 0.0083 - val_loss: 1.8630e-04 - val_mean_absolute_error: 0.0110
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.4619e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2015e-04 - val_mean_absolute_error: 0.0079
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3025e-04 - mean_absolute_error: 0.0079 - val_loss: 1.2462e-04 - val_mean_absolute_error: 0.0080
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.2989e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2293e-04 - val_mean_absolute_error: 0.0082
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2790e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2486e-04 - val_mean_absolute_error: 0.0082
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3488e-04 - mean_absolute_error: 0.0081 - val_loss: 1.2383e-04 - val_mean_absolute_error: 0.0083
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.6654e-04 - mean_absolute_error: 0.0093 - val_loss: 1.2805e-04 - val_mean_absolute_error: 0.0085
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.5240e-04 - mean_absolute_error: 0.0085 - val_loss: 1.8589e-04 - val_mean_absolute_error: 0.0109
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4157e-04 - mean_absolute_error: 0.0083 - val_loss: 1.5179e-04 - val_mean_absolute_error: 0.0095
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3988e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2526e-04 - val_mean_absolute_error: 0.0084
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5759e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2638e-04 - val_mean_absolute_error: 0.0083
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4648e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2756e-04 - val_mean_absolute_error: 0.0084
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6901e-04 - mean_absolute_error: 0.0089 - val_loss: 1.3243e-04 - val_mean_absolute_error: 0.0088
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.7213e-04 - mean_absolute_error: 0.0092 - val_loss: 1.2650e-04 - val_mean_absolute_error: 0.0083
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.7054e-04 - mean_absolute_error: 0.0092 - val_loss: 1.4684e-04 - val_mean_absolute_error: 0.0093
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.6608e-04 - mean_absolute_error: 0.0090 - val_loss: 1.3621e-04 - val_mean_absolute_error: 0.0089
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.4876e-04 - mean_absolute_error: 0.0086 - val_loss: 1.3039e-04 - val_mean_absolute_error: 0.0083
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3955e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2147e-04 - val_mean_absolute_error: 0.0079
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3428e-04 - mean_absolute_error: 0.0079 - val_loss: 2.2928e-04 - val_mean_absolute_error: 0.0125
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.7645e-04 - mean_absolute_error: 0.0098 - val_loss: 1.2668e-04 - val_mean_absolute_error: 0.0085
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4670e-04 - mean_absolute_error: 0.0086 - val_loss: 2.4305e-04 - val_mean_absolute_error: 0.0127
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3407e-04 - mean_absolute_error: 0.0080 - val_loss: 1.6970e-04 - val_mean_absolute_error: 0.0103
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.6118e-04 - mean_absolute_error: 0.0091 - val_loss: 1.8169e-04 - val_mean_absolute_error: 0.0109
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.5080e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2238e-04 - val_mean_absolute_error: 0.0081
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5674e-04 - mean_absolute_error: 0.0085 - val_loss: 1.4489e-04 - val_mean_absolute_error: 0.0093
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5825e-04 - mean_absolute_error: 0.0087 - val_loss: 1.5780e-04 - val_mean_absolute_error: 0.0095
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6158e-04 - mean_absolute_error: 0.0093 - val_loss: 2.1752e-04 - val_mean_absolute_error: 0.0118
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.5136e-04 - mean_absolute_error: 0.0088 - val_loss: 1.3069e-04 - val_mean_absolute_error: 0.0086
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.4052e-04 - mean_absolute_error: 0.0083 - val_loss: 3.3483e-04 - val_mean_absolute_error: 0.0157
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6076e-04 - mean_absolute_error: 0.0092 - val_loss: 1.3447e-04 - val_mean_absolute_error: 0.0085
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4171e-04 - mean_absolute_error: 0.0082 - val_loss: 1.4934e-04 - val_mean_absolute_error: 0.0092
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3860e-04 - mean_absolute_error: 0.0081 - val_loss: 1.4375e-04 - val_mean_absolute_error: 0.0089
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4483e-04 - mean_absolute_error: 0.0082 - val_loss: 1.3052e-04 - val_mean_absolute_error: 0.0087
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.3695e-04 - mean_absolute_error: 0.0082 - val_loss: 1.5764e-04 - val_mean_absolute_error: 0.0094
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3762e-04 - mean_absolute_error: 0.0082 - val_loss: 2.1943e-04 - val_mean_absolute_error: 0.0119
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.7549e-04 - mean_absolute_error: 0.0096 - val_loss: 1.3614e-04 - val_mean_absolute_error: 0.0089
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4567e-04 - mean_absolute_error: 0.0084 - val_loss: 1.6238e-04 - val_mean_absolute_error: 0.0096
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.4083e-04 - mean_absolute_error: 0.0084 - val_loss: 1.5468e-04 - val_mean_absolute_error: 0.0093
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5939e-04 - mean_absolute_error: 0.0089 - val_loss: 1.2291e-04 - val_mean_absolute_error: 0.0083
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3031e-04 - mean_absolute_error: 0.0079 - val_loss: 2.3884e-04 - val_mean_absolute_error: 0.0126
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.9508e-04 - mean_absolute_error: 0.0105 - val_loss: 3.4346e-04 - val_mean_absolute_error: 0.0160
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5360e-04 - mean_absolute_error: 0.0091 - val_loss: 1.3614e-04 - val_mean_absolute_error: 0.0085
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.5380e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2029e-04 - val_mean_absolute_error: 0.0081
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.5777e-04 - mean_absolute_error: 0.0086 - val_loss: 1.3719e-04 - val_mean_absolute_error: 0.0090
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5961e-04 - mean_absolute_error: 0.0092 - val_loss: 1.3652e-04 - val_mean_absolute_error: 0.0087
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.4734e-04 - mean_absolute_error: 0.0083 - val_loss: 1.5255e-04 - val_mean_absolute_error: 0.0092
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.4161e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2500e-04 - val_mean_absolute_error: 0.0084
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6116e-04 - mean_absolute_error: 0.0092 - val_loss: 1.8657e-04 - val_mean_absolute_error: 0.0108
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.5861e-04 - mean_absolute_error: 0.0092 - val_loss: 1.2148e-04 - val_mean_absolute_error: 0.0081
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.6880e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2364e-04 - val_mean_absolute_error: 0.0082
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5451e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2249e-04 - val_mean_absolute_error: 0.0082
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.4965e-04 - mean_absolute_error: 0.0082 - val_loss: 1.6070e-04 - val_mean_absolute_error: 0.0099
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.6659e-04 - mean_absolute_error: 0.0095 - val_loss: 1.2700e-04 - val_mean_absolute_error: 0.0083
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.6468e-04 - mean_absolute_error: 0.0096 - val_loss: 1.2434e-04 - val_mean_absolute_error: 0.0082
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.3915e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2807e-04 - val_mean_absolute_error: 0.0085
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3913e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2514e-04 - val_mean_absolute_error: 0.0084
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.4423e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3181e-04 - val_mean_absolute_error: 0.0083
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.9373e-04 - mean_absolute_error: 0.0103 - val_loss: 1.3558e-04 - val_mean_absolute_error: 0.0086
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6603e-04 - mean_absolute_error: 0.0091 - val_loss: 1.4400e-04 - val_mean_absolute_error: 0.0089
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4614e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2377e-04 - val_mean_absolute_error: 0.0082
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4472e-04 - mean_absolute_error: 0.0083 - val_loss: 1.3028e-04 - val_mean_absolute_error: 0.0087
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.3502e-04 - mean_absolute_error: 0.0080 - val_loss: 1.3979e-04 - val_mean_absolute_error: 0.0090
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.5855e-04 - mean_absolute_error: 0.0087 - val_loss: 1.7160e-04 - val_mean_absolute_error: 0.0103
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4518e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2728e-04 - val_mean_absolute_error: 0.0084
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5584e-04 - mean_absolute_error: 0.0086 - val_loss: 1.4953e-04 - val_mean_absolute_error: 0.0094
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.7573e-04 - mean_absolute_error: 0.0095 - val_loss: 2.2535e-04 - val_mean_absolute_error: 0.0121
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7287e-04 - mean_absolute_error: 0.0093 - val_loss: 1.4573e-04 - val_mean_absolute_error: 0.0089
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4605e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2091e-04 - val_mean_absolute_error: 0.0082
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2937e-04 - mean_absolute_error: 0.0079 - val_loss: 1.5097e-04 - val_mean_absolute_error: 0.0092
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5953e-04 - mean_absolute_error: 0.0089 - val_loss: 1.2507e-04 - val_mean_absolute_error: 0.0083
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4527e-04 - mean_absolute_error: 0.0082 - val_loss: 1.3242e-04 - val_mean_absolute_error: 0.0085
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3457e-04 - mean_absolute_error: 0.0081 - val_loss: 2.2720e-04 - val_mean_absolute_error: 0.0122
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5756e-04 - mean_absolute_error: 0.0086 - val_loss: 3.0821e-04 - val_mean_absolute_error: 0.0149
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7107e-04 - mean_absolute_error: 0.0094 - val_loss: 1.9049e-04 - val_mean_absolute_error: 0.0108
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5510e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2063e-04 - val_mean_absolute_error: 0.0081
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3563e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2376e-04 - val_mean_absolute_error: 0.0084
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4583e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2398e-04 - val_mean_absolute_error: 0.0083
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4180e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2319e-04 - val_mean_absolute_error: 0.0082
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5339e-04 - mean_absolute_error: 0.0087 - val_loss: 1.4331e-04 - val_mean_absolute_error: 0.0089
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3017e-04 - mean_absolute_error: 0.0077 - val_loss: 1.7820e-04 - val_mean_absolute_error: 0.0103
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5013e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2703e-04 - val_mean_absolute_error: 0.0084
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4565e-04 - mean_absolute_error: 0.0087 - val_loss: 1.4956e-04 - val_mean_absolute_error: 0.0092
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.4126e-04 - mean_absolute_error: 0.0081 - val_loss: 1.8282e-04 - val_mean_absolute_error: 0.0105
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4959e-04 - mean_absolute_error: 0.0085 - val_loss: 1.4145e-04 - val_mean_absolute_error: 0.0089
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.3368e-04 - mean_absolute_error: 0.0080 - val_loss: 1.8216e-04 - val_mean_absolute_error: 0.0105
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5383e-04 - mean_absolute_error: 0.0088 - val_loss: 1.7889e-04 - val_mean_absolute_error: 0.0103
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2517e-04 - mean_absolute_error: 0.0079 - val_loss: 1.4452e-04 - val_mean_absolute_error: 0.0089
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6032e-04 - mean_absolute_error: 0.0088 - val_loss: 1.6573e-04 - val_mean_absolute_error: 0.0098
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.2813e-04 - mean_absolute_error: 0.0079 - val_loss: 1.5131e-04 - val_mean_absolute_error: 0.0095
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.3183e-04 - mean_absolute_error: 0.0083 - val_loss: 1.4008e-04 - val_mean_absolute_error: 0.0090
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.5904e-04 - mean_absolute_error: 0.0094 - val_loss: 1.2534e-04 - val_mean_absolute_error: 0.0083
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.3942e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2237e-04 - val_mean_absolute_error: 0.0082
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3045e-04 - mean_absolute_error: 0.0078 - val_loss: 1.2297e-04 - val_mean_absolute_error: 0.0083

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 138ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5726e-04 - mean_absolute_error: 0.0096
# Test Loss: [0.00012297346256673336, 0.008312190882861614]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 586330.583687163
# RMSE: 765.7222627605671
# MAE: 557.0072522410359
# MAPE: 1.6645775936928187 %
#
# Model evalution on validate set
# MSE: 3905950.7557775322
# RMSE: 1976.3478326897653
# MAE: 1253.1572507747933
# MAPE: 2.6214811564792453 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 659ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step

# %%
y_pred_30_days
# Out:
# array([[61337.215],
#        [61151.63 ],
#        [61484.707],
#        [61321.516],
#        [61367.406],
#        [61327.22 ],
#        [61342.457],
#        [61335.223],
#        [61339.496],
#        [61337.76 ],
#        [61338.69 ],
#        [61338.223],
#        [61338.44 ],
#        [61338.336],
#        [61338.387],
#        [61338.36 ],
#        [61338.37 ],
#        [61338.367],
#        [61338.37 ],
#        [61338.367],
#        [61338.37 ],
#        [61338.367],
#        [61338.367],
#        [61338.367],
#        [61338.37 ],
#        [61338.367],
#        [61338.37 ],
#        [61338.367],
#        [61338.37 ],
#        [61338.367],
#        [61338.37 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
