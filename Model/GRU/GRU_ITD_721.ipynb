# %% [markdown]
# # Model: GRU (Gated Recurrent Unit)  - Stock Token: FPT - Test/Train/Vaildation: 70/20/10
# - Dataset: 1313 rows x 7 columns (01/03/2019 - 31/05/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 320.34
# - MAE: 226.77
# - MAPE: 2.04 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

plt.style.use("default")

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 0  # 7 2 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170
# ...           ...
# 2024-05-27  11300
# 2024-05-28  12050
# 2024-05-29  12600
# 2024-05-30  12500
# 2024-05-31  12700
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        6900
# 1        7100
# 2        7100
# 3        7170
# 4        7170
#         ...
# 1308    11300
# 1309    12050
# 1310    12600
# 1311    12500
# 1312    12700
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((908, 10), (908,), (251, 10), (251,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(100),
        Dense(32, activation="relu"),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 100)            │        30,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,165 (133.46 KB)
#  Trainable params: 34,165 (133.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0654 - mean_absolute_error: 0.1663 - val_loss: 4.1539e-04 - val_mean_absolute_error: 0.0167
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.6496e-04 - mean_absolute_error: 0.0210 - val_loss: 3.4573e-04 - val_mean_absolute_error: 0.0144
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9653e-04 - mean_absolute_error: 0.0172 - val_loss: 2.8067e-04 - val_mean_absolute_error: 0.0117
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4963e-04 - mean_absolute_error: 0.0160 - val_loss: 4.5837e-04 - val_mean_absolute_error: 0.0180
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0164e-04 - mean_absolute_error: 0.0184 - val_loss: 3.4664e-04 - val_mean_absolute_error: 0.0138
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6745e-04 - mean_absolute_error: 0.0152 - val_loss: 2.6609e-04 - val_mean_absolute_error: 0.0117
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3428e-04 - mean_absolute_error: 0.0156 - val_loss: 2.5762e-04 - val_mean_absolute_error: 0.0113
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5251e-04 - mean_absolute_error: 0.0156 - val_loss: 2.7497e-04 - val_mean_absolute_error: 0.0118
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8555e-04 - mean_absolute_error: 0.0147 - val_loss: 2.5452e-04 - val_mean_absolute_error: 0.0115
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0648e-04 - mean_absolute_error: 0.0144 - val_loss: 2.9478e-04 - val_mean_absolute_error: 0.0132
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2833e-04 - mean_absolute_error: 0.0147 - val_loss: 2.8212e-04 - val_mean_absolute_error: 0.0128
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3339e-04 - mean_absolute_error: 0.0144 - val_loss: 3.1874e-04 - val_mean_absolute_error: 0.0134
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9828e-04 - mean_absolute_error: 0.0156 - val_loss: 4.4070e-04 - val_mean_absolute_error: 0.0177
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1737e-04 - mean_absolute_error: 0.0176 - val_loss: 5.2707e-04 - val_mean_absolute_error: 0.0191
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1837e-04 - mean_absolute_error: 0.0169 - val_loss: 2.3797e-04 - val_mean_absolute_error: 0.0110
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5815e-04 - mean_absolute_error: 0.0139 - val_loss: 2.4961e-04 - val_mean_absolute_error: 0.0116
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9253e-04 - mean_absolute_error: 0.0152 - val_loss: 2.4307e-04 - val_mean_absolute_error: 0.0113
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7695e-04 - mean_absolute_error: 0.0142 - val_loss: 4.8720e-04 - val_mean_absolute_error: 0.0183
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5607e-04 - mean_absolute_error: 0.0173 - val_loss: 2.3927e-04 - val_mean_absolute_error: 0.0111
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3084e-04 - mean_absolute_error: 0.0133 - val_loss: 3.6543e-04 - val_mean_absolute_error: 0.0151
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1557e-04 - mean_absolute_error: 0.0138 - val_loss: 3.0401e-04 - val_mean_absolute_error: 0.0137
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8386e-04 - mean_absolute_error: 0.0163 - val_loss: 3.6953e-04 - val_mean_absolute_error: 0.0158
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7183e-04 - mean_absolute_error: 0.0141 - val_loss: 3.4124e-04 - val_mean_absolute_error: 0.0149
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7080e-04 - mean_absolute_error: 0.0151 - val_loss: 2.5783e-04 - val_mean_absolute_error: 0.0121
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3394e-04 - mean_absolute_error: 0.0137 - val_loss: 2.6898e-04 - val_mean_absolute_error: 0.0125
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7177e-04 - mean_absolute_error: 0.0125 - val_loss: 2.3339e-04 - val_mean_absolute_error: 0.0110
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5671e-04 - mean_absolute_error: 0.0138 - val_loss: 2.9804e-04 - val_mean_absolute_error: 0.0136
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4997e-04 - mean_absolute_error: 0.0144 - val_loss: 2.7762e-04 - val_mean_absolute_error: 0.0128
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3482e-04 - mean_absolute_error: 0.0135 - val_loss: 2.3092e-04 - val_mean_absolute_error: 0.0108
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6478e-04 - mean_absolute_error: 0.0142 - val_loss: 2.7539e-04 - val_mean_absolute_error: 0.0127
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0926e-04 - mean_absolute_error: 0.0132 - val_loss: 2.6748e-04 - val_mean_absolute_error: 0.0124
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4293e-04 - mean_absolute_error: 0.0159 - val_loss: 2.2898e-04 - val_mean_absolute_error: 0.0108
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5340e-04 - mean_absolute_error: 0.0140 - val_loss: 2.2950e-04 - val_mean_absolute_error: 0.0108
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2672e-04 - mean_absolute_error: 0.0132 - val_loss: 2.5521e-04 - val_mean_absolute_error: 0.0119
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6986e-04 - mean_absolute_error: 0.0143 - val_loss: 2.4888e-04 - val_mean_absolute_error: 0.0116
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9827e-04 - mean_absolute_error: 0.0131 - val_loss: 2.3779e-04 - val_mean_absolute_error: 0.0112
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4511e-04 - mean_absolute_error: 0.0147 - val_loss: 2.2975e-04 - val_mean_absolute_error: 0.0108
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0580e-04 - mean_absolute_error: 0.0135 - val_loss: 2.2950e-04 - val_mean_absolute_error: 0.0108
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6898e-04 - mean_absolute_error: 0.0125 - val_loss: 2.5976e-04 - val_mean_absolute_error: 0.0121
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9230e-04 - mean_absolute_error: 0.0136 - val_loss: 3.5302e-04 - val_mean_absolute_error: 0.0153
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4965e-04 - mean_absolute_error: 0.0145 - val_loss: 2.3137e-04 - val_mean_absolute_error: 0.0108
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2009e-04 - mean_absolute_error: 0.0140 - val_loss: 2.3383e-04 - val_mean_absolute_error: 0.0110
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5280e-04 - mean_absolute_error: 0.0174 - val_loss: 2.6085e-04 - val_mean_absolute_error: 0.0121
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7082e-04 - mean_absolute_error: 0.0128 - val_loss: 4.7902e-04 - val_mean_absolute_error: 0.0186
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2181e-04 - mean_absolute_error: 0.0142 - val_loss: 2.3424e-04 - val_mean_absolute_error: 0.0110
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7495e-04 - mean_absolute_error: 0.0126 - val_loss: 2.7655e-04 - val_mean_absolute_error: 0.0127
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2778e-04 - mean_absolute_error: 0.0132 - val_loss: 2.6690e-04 - val_mean_absolute_error: 0.0123
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9280e-04 - mean_absolute_error: 0.0132 - val_loss: 3.0452e-04 - val_mean_absolute_error: 0.0137
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6635e-04 - mean_absolute_error: 0.0129 - val_loss: 2.3506e-04 - val_mean_absolute_error: 0.0109
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6671e-04 - mean_absolute_error: 0.0144 - val_loss: 5.0100e-04 - val_mean_absolute_error: 0.0190
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4504e-04 - mean_absolute_error: 0.0172 - val_loss: 3.4794e-04 - val_mean_absolute_error: 0.0151
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6335e-04 - mean_absolute_error: 0.0131 - val_loss: 3.5016e-04 - val_mean_absolute_error: 0.0148
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3762e-04 - mean_absolute_error: 0.0145 - val_loss: 5.1646e-04 - val_mean_absolute_error: 0.0191
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0349e-04 - mean_absolute_error: 0.0155 - val_loss: 2.4595e-04 - val_mean_absolute_error: 0.0114
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1447e-04 - mean_absolute_error: 0.0130 - val_loss: 2.6191e-04 - val_mean_absolute_error: 0.0120
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2038e-04 - mean_absolute_error: 0.0135 - val_loss: 2.4717e-04 - val_mean_absolute_error: 0.0115
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4887e-04 - mean_absolute_error: 0.0144 - val_loss: 2.4771e-04 - val_mean_absolute_error: 0.0116
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1512e-04 - mean_absolute_error: 0.0136 - val_loss: 3.2905e-04 - val_mean_absolute_error: 0.0144
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8671e-04 - mean_absolute_error: 0.0131 - val_loss: 3.7905e-04 - val_mean_absolute_error: 0.0159
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8151e-04 - mean_absolute_error: 0.0132 - val_loss: 3.7059e-04 - val_mean_absolute_error: 0.0156
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9625e-04 - mean_absolute_error: 0.0138 - val_loss: 5.3588e-04 - val_mean_absolute_error: 0.0198
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8967e-04 - mean_absolute_error: 0.0175 - val_loss: 2.6431e-04 - val_mean_absolute_error: 0.0122
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5170e-04 - mean_absolute_error: 0.0143 - val_loss: 2.4561e-04 - val_mean_absolute_error: 0.0114
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8211e-04 - mean_absolute_error: 0.0124 - val_loss: 3.0049e-04 - val_mean_absolute_error: 0.0135
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8901e-04 - mean_absolute_error: 0.0128 - val_loss: 4.2779e-04 - val_mean_absolute_error: 0.0172
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3316e-04 - mean_absolute_error: 0.0142 - val_loss: 2.4552e-04 - val_mean_absolute_error: 0.0114
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9400e-04 - mean_absolute_error: 0.0126 - val_loss: 2.4980e-04 - val_mean_absolute_error: 0.0115
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0344e-04 - mean_absolute_error: 0.0136 - val_loss: 2.3905e-04 - val_mean_absolute_error: 0.0111
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7483e-04 - mean_absolute_error: 0.0131 - val_loss: 3.2843e-04 - val_mean_absolute_error: 0.0141
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8375e-04 - mean_absolute_error: 0.0127 - val_loss: 2.4133e-04 - val_mean_absolute_error: 0.0112
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9630e-04 - mean_absolute_error: 0.0125 - val_loss: 2.5154e-04 - val_mean_absolute_error: 0.0116
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7465e-04 - mean_absolute_error: 0.0127 - val_loss: 2.6163e-04 - val_mean_absolute_error: 0.0120
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7655e-04 - mean_absolute_error: 0.0145 - val_loss: 3.0252e-04 - val_mean_absolute_error: 0.0132
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0394e-04 - mean_absolute_error: 0.0157 - val_loss: 5.0440e-04 - val_mean_absolute_error: 0.0188
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4123e-04 - mean_absolute_error: 0.0140 - val_loss: 2.4482e-04 - val_mean_absolute_error: 0.0114
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3015e-04 - mean_absolute_error: 0.0137 - val_loss: 2.4164e-04 - val_mean_absolute_error: 0.0112
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5076e-04 - mean_absolute_error: 0.0145 - val_loss: 2.5328e-04 - val_mean_absolute_error: 0.0117
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6919e-04 - mean_absolute_error: 0.0127 - val_loss: 3.7653e-04 - val_mean_absolute_error: 0.0157
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8489e-04 - mean_absolute_error: 0.0132 - val_loss: 5.4327e-04 - val_mean_absolute_error: 0.0198
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9395e-04 - mean_absolute_error: 0.0156 - val_loss: 4.3666e-04 - val_mean_absolute_error: 0.0173
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9802e-04 - mean_absolute_error: 0.0133 - val_loss: 3.1888e-04 - val_mean_absolute_error: 0.0139
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9138e-04 - mean_absolute_error: 0.0125 - val_loss: 2.5399e-04 - val_mean_absolute_error: 0.0117
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5089e-04 - mean_absolute_error: 0.0138 - val_loss: 2.6050e-04 - val_mean_absolute_error: 0.0119
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2591e-04 - mean_absolute_error: 0.0121 - val_loss: 3.0907e-04 - val_mean_absolute_error: 0.0136
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8714e-04 - mean_absolute_error: 0.0126 - val_loss: 2.4809e-04 - val_mean_absolute_error: 0.0114
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5701e-04 - mean_absolute_error: 0.0130 - val_loss: 3.3658e-04 - val_mean_absolute_error: 0.0145
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5015e-04 - mean_absolute_error: 0.0142 - val_loss: 2.5280e-04 - val_mean_absolute_error: 0.0116
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6461e-04 - mean_absolute_error: 0.0126 - val_loss: 2.4757e-04 - val_mean_absolute_error: 0.0114
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8669e-04 - mean_absolute_error: 0.0132 - val_loss: 2.5529e-04 - val_mean_absolute_error: 0.0117
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1816e-04 - mean_absolute_error: 0.0138 - val_loss: 2.5630e-04 - val_mean_absolute_error: 0.0118
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1499e-04 - mean_absolute_error: 0.0142 - val_loss: 2.7352e-04 - val_mean_absolute_error: 0.0123
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6445e-04 - mean_absolute_error: 0.0128 - val_loss: 2.4710e-04 - val_mean_absolute_error: 0.0114
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3911e-04 - mean_absolute_error: 0.0120 - val_loss: 3.3064e-04 - val_mean_absolute_error: 0.0141
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4233e-04 - mean_absolute_error: 0.0146 - val_loss: 4.2036e-04 - val_mean_absolute_error: 0.0169
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0567e-04 - mean_absolute_error: 0.0130 - val_loss: 3.9260e-04 - val_mean_absolute_error: 0.0161
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1692e-04 - mean_absolute_error: 0.0145 - val_loss: 2.6682e-04 - val_mean_absolute_error: 0.0121
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9006e-04 - mean_absolute_error: 0.0153 - val_loss: 2.6216e-04 - val_mean_absolute_error: 0.0120
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5741e-04 - mean_absolute_error: 0.0124 - val_loss: 2.6782e-04 - val_mean_absolute_error: 0.0122
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9459e-04 - mean_absolute_error: 0.0134 - val_loss: 3.6186e-04 - val_mean_absolute_error: 0.0152
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8683e-04 - mean_absolute_error: 0.0132 - val_loss: 2.5123e-04 - val_mean_absolute_error: 0.0115
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7909e-04 - mean_absolute_error: 0.0129 - val_loss: 2.5450e-04 - val_mean_absolute_error: 0.0117
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5109e-04 - mean_absolute_error: 0.0124 - val_loss: 3.9141e-04 - val_mean_absolute_error: 0.0160
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8514e-04 - mean_absolute_error: 0.0133 - val_loss: 2.5335e-04 - val_mean_absolute_error: 0.0116
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9886e-04 - mean_absolute_error: 0.0131 - val_loss: 2.5227e-04 - val_mean_absolute_error: 0.0116
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6732e-04 - mean_absolute_error: 0.0124 - val_loss: 2.5223e-04 - val_mean_absolute_error: 0.0116
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6257e-04 - mean_absolute_error: 0.0123 - val_loss: 2.4662e-04 - val_mean_absolute_error: 0.0113
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4156e-04 - mean_absolute_error: 0.0123 - val_loss: 2.5306e-04 - val_mean_absolute_error: 0.0116
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8924e-04 - mean_absolute_error: 0.0129 - val_loss: 2.4836e-04 - val_mean_absolute_error: 0.0114
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1974e-04 - mean_absolute_error: 0.0137 - val_loss: 3.0666e-04 - val_mean_absolute_error: 0.0135
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7920e-04 - mean_absolute_error: 0.0130 - val_loss: 2.7104e-04 - val_mean_absolute_error: 0.0122
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3247e-04 - mean_absolute_error: 0.0137 - val_loss: 3.2550e-04 - val_mean_absolute_error: 0.0141
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4912e-04 - mean_absolute_error: 0.0144 - val_loss: 2.8700e-04 - val_mean_absolute_error: 0.0128
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6144e-04 - mean_absolute_error: 0.0124 - val_loss: 2.5718e-04 - val_mean_absolute_error: 0.0117
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6581e-04 - mean_absolute_error: 0.0126 - val_loss: 3.6301e-04 - val_mean_absolute_error: 0.0152
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0774e-04 - mean_absolute_error: 0.0137 - val_loss: 2.4900e-04 - val_mean_absolute_error: 0.0114
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3820e-04 - mean_absolute_error: 0.0117 - val_loss: 3.5247e-04 - val_mean_absolute_error: 0.0147
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7124e-04 - mean_absolute_error: 0.0146 - val_loss: 4.7654e-04 - val_mean_absolute_error: 0.0182
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3236e-04 - mean_absolute_error: 0.0147 - val_loss: 3.1703e-04 - val_mean_absolute_error: 0.0137
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9715e-04 - mean_absolute_error: 0.0137 - val_loss: 2.9520e-04 - val_mean_absolute_error: 0.0130
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1655e-04 - mean_absolute_error: 0.0137 - val_loss: 2.5446e-04 - val_mean_absolute_error: 0.0117
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8751e-04 - mean_absolute_error: 0.0131 - val_loss: 3.0012e-04 - val_mean_absolute_error: 0.0133
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6923e-04 - mean_absolute_error: 0.0130 - val_loss: 2.6275e-04 - val_mean_absolute_error: 0.0120
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0611e-04 - mean_absolute_error: 0.0132 - val_loss: 2.5155e-04 - val_mean_absolute_error: 0.0115
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7873e-04 - mean_absolute_error: 0.0131 - val_loss: 4.9360e-04 - val_mean_absolute_error: 0.0185
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4376e-04 - mean_absolute_error: 0.0168 - val_loss: 4.9058e-04 - val_mean_absolute_error: 0.0186
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9248e-04 - mean_absolute_error: 0.0167 - val_loss: 2.7571e-04 - val_mean_absolute_error: 0.0124
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5995e-04 - mean_absolute_error: 0.0130 - val_loss: 2.9759e-04 - val_mean_absolute_error: 0.0132
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6075e-04 - mean_absolute_error: 0.0125 - val_loss: 2.4914e-04 - val_mean_absolute_error: 0.0114
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9527e-04 - mean_absolute_error: 0.0130 - val_loss: 2.9395e-04 - val_mean_absolute_error: 0.0131
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6267e-04 - mean_absolute_error: 0.0126 - val_loss: 2.9145e-04 - val_mean_absolute_error: 0.0130
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0112e-04 - mean_absolute_error: 0.0135 - val_loss: 2.8596e-04 - val_mean_absolute_error: 0.0127
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6999e-04 - mean_absolute_error: 0.0128 - val_loss: 3.2436e-04 - val_mean_absolute_error: 0.0141
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8182e-04 - mean_absolute_error: 0.0131 - val_loss: 3.6154e-04 - val_mean_absolute_error: 0.0152
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2968e-04 - mean_absolute_error: 0.0141 - val_loss: 3.6886e-04 - val_mean_absolute_error: 0.0154
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6643e-04 - mean_absolute_error: 0.0152 - val_loss: 3.5058e-04 - val_mean_absolute_error: 0.0147
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4358e-04 - mean_absolute_error: 0.0139 - val_loss: 3.7252e-04 - val_mean_absolute_error: 0.0155
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2820e-04 - mean_absolute_error: 0.0137 - val_loss: 2.6340e-04 - val_mean_absolute_error: 0.0120
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4854e-04 - mean_absolute_error: 0.0122 - val_loss: 2.7494e-04 - val_mean_absolute_error: 0.0124
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6479e-04 - mean_absolute_error: 0.0126 - val_loss: 3.6566e-04 - val_mean_absolute_error: 0.0151
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4497e-04 - mean_absolute_error: 0.0134 - val_loss: 2.5529e-04 - val_mean_absolute_error: 0.0116
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2634e-04 - mean_absolute_error: 0.0139 - val_loss: 3.3126e-04 - val_mean_absolute_error: 0.0143
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9185e-04 - mean_absolute_error: 0.0131 - val_loss: 3.0666e-04 - val_mean_absolute_error: 0.0135
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7015e-04 - mean_absolute_error: 0.0130 - val_loss: 2.5102e-04 - val_mean_absolute_error: 0.0115
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1961e-04 - mean_absolute_error: 0.0140 - val_loss: 2.9001e-04 - val_mean_absolute_error: 0.0128
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1597e-04 - mean_absolute_error: 0.0134 - val_loss: 2.6340e-04 - val_mean_absolute_error: 0.0120
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5393e-04 - mean_absolute_error: 0.0124 - val_loss: 2.8547e-04 - val_mean_absolute_error: 0.0127
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2812e-04 - mean_absolute_error: 0.0136 - val_loss: 4.2161e-04 - val_mean_absolute_error: 0.0166
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2994e-04 - mean_absolute_error: 0.0164 - val_loss: 5.8664e-04 - val_mean_absolute_error: 0.0207
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7856e-04 - mean_absolute_error: 0.0152 - val_loss: 2.9599e-04 - val_mean_absolute_error: 0.0130
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8113e-04 - mean_absolute_error: 0.0137 - val_loss: 2.4725e-04 - val_mean_absolute_error: 0.0114
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9980e-04 - mean_absolute_error: 0.0136 - val_loss: 2.5304e-04 - val_mean_absolute_error: 0.0116
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6751e-04 - mean_absolute_error: 0.0125 - val_loss: 2.4853e-04 - val_mean_absolute_error: 0.0114
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6132e-04 - mean_absolute_error: 0.0125 - val_loss: 2.6195e-04 - val_mean_absolute_error: 0.0119
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7831e-04 - mean_absolute_error: 0.0137 - val_loss: 2.9469e-04 - val_mean_absolute_error: 0.0130
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7261e-04 - mean_absolute_error: 0.0123 - val_loss: 2.5147e-04 - val_mean_absolute_error: 0.0115
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0288e-04 - mean_absolute_error: 0.0132 - val_loss: 2.5164e-04 - val_mean_absolute_error: 0.0116
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6820e-04 - mean_absolute_error: 0.0127 - val_loss: 2.8373e-04 - val_mean_absolute_error: 0.0126
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8589e-04 - mean_absolute_error: 0.0127 - val_loss: 3.3932e-04 - val_mean_absolute_error: 0.0145
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5731e-04 - mean_absolute_error: 0.0125 - val_loss: 2.7092e-04 - val_mean_absolute_error: 0.0122
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4518e-04 - mean_absolute_error: 0.0124 - val_loss: 5.0065e-04 - val_mean_absolute_error: 0.0188
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4703e-04 - mean_absolute_error: 0.0150 - val_loss: 2.4871e-04 - val_mean_absolute_error: 0.0114
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6949e-04 - mean_absolute_error: 0.0122 - val_loss: 2.5265e-04 - val_mean_absolute_error: 0.0116
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9695e-04 - mean_absolute_error: 0.0130 - val_loss: 2.7183e-04 - val_mean_absolute_error: 0.0122
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0000e-04 - mean_absolute_error: 0.0137 - val_loss: 2.8232e-04 - val_mean_absolute_error: 0.0126
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8398e-04 - mean_absolute_error: 0.0124 - val_loss: 2.4955e-04 - val_mean_absolute_error: 0.0114
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7340e-04 - mean_absolute_error: 0.0124 - val_loss: 3.1600e-04 - val_mean_absolute_error: 0.0138
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7764e-04 - mean_absolute_error: 0.0134 - val_loss: 2.6113e-04 - val_mean_absolute_error: 0.0118
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9058e-04 - mean_absolute_error: 0.0134 - val_loss: 2.6606e-04 - val_mean_absolute_error: 0.0120
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8797e-04 - mean_absolute_error: 0.0133 - val_loss: 2.5374e-04 - val_mean_absolute_error: 0.0116
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8399e-04 - mean_absolute_error: 0.0129 - val_loss: 2.5203e-04 - val_mean_absolute_error: 0.0115
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6588e-04 - mean_absolute_error: 0.0129 - val_loss: 2.9807e-04 - val_mean_absolute_error: 0.0132
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9546e-04 - mean_absolute_error: 0.0130 - val_loss: 3.0956e-04 - val_mean_absolute_error: 0.0137
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7592e-04 - mean_absolute_error: 0.0131 - val_loss: 2.6377e-04 - val_mean_absolute_error: 0.0120
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6081e-04 - mean_absolute_error: 0.0125 - val_loss: 2.7602e-04 - val_mean_absolute_error: 0.0124
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9612e-04 - mean_absolute_error: 0.0126 - val_loss: 2.4829e-04 - val_mean_absolute_error: 0.0114
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4879e-04 - mean_absolute_error: 0.0126 - val_loss: 2.5288e-04 - val_mean_absolute_error: 0.0115
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6191e-04 - mean_absolute_error: 0.0128 - val_loss: 2.4793e-04 - val_mean_absolute_error: 0.0114
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7993e-04 - mean_absolute_error: 0.0127 - val_loss: 2.8439e-04 - val_mean_absolute_error: 0.0127
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7791e-04 - mean_absolute_error: 0.0128 - val_loss: 2.7498e-04 - val_mean_absolute_error: 0.0123
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3114e-04 - mean_absolute_error: 0.0119 - val_loss: 2.6558e-04 - val_mean_absolute_error: 0.0120
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7740e-04 - mean_absolute_error: 0.0152 - val_loss: 3.5982e-04 - val_mean_absolute_error: 0.0152
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2057e-04 - mean_absolute_error: 0.0166 - val_loss: 2.5516e-04 - val_mean_absolute_error: 0.0117
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9504e-04 - mean_absolute_error: 0.0133 - val_loss: 5.6613e-04 - val_mean_absolute_error: 0.0202
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3294e-04 - mean_absolute_error: 0.0163 - val_loss: 4.1247e-04 - val_mean_absolute_error: 0.0166
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4777e-04 - mean_absolute_error: 0.0150 - val_loss: 2.8867e-04 - val_mean_absolute_error: 0.0129
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8604e-04 - mean_absolute_error: 0.0135 - val_loss: 2.5317e-04 - val_mean_absolute_error: 0.0116
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3020e-04 - mean_absolute_error: 0.0120 - val_loss: 2.5424e-04 - val_mean_absolute_error: 0.0116
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2651e-04 - mean_absolute_error: 0.0116 - val_loss: 2.8914e-04 - val_mean_absolute_error: 0.0129
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6901e-04 - mean_absolute_error: 0.0129 - val_loss: 2.6806e-04 - val_mean_absolute_error: 0.0121
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2440e-04 - mean_absolute_error: 0.0134 - val_loss: 3.2839e-04 - val_mean_absolute_error: 0.0142
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8733e-04 - mean_absolute_error: 0.0132 - val_loss: 2.7666e-04 - val_mean_absolute_error: 0.0124
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7936e-04 - mean_absolute_error: 0.0126 - val_loss: 2.6170e-04 - val_mean_absolute_error: 0.0119
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6643e-04 - mean_absolute_error: 0.0128 - val_loss: 2.5191e-04 - val_mean_absolute_error: 0.0115
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5228e-04 - mean_absolute_error: 0.0124 - val_loss: 2.5440e-04 - val_mean_absolute_error: 0.0116
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4360e-04 - mean_absolute_error: 0.0123 - val_loss: 2.7789e-04 - val_mean_absolute_error: 0.0125
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1403e-04 - mean_absolute_error: 0.0137 - val_loss: 3.6517e-04 - val_mean_absolute_error: 0.0151
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6481e-04 - mean_absolute_error: 0.0142 - val_loss: 2.9401e-04 - val_mean_absolute_error: 0.0130
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7952e-04 - mean_absolute_error: 0.0135 - val_loss: 2.5255e-04 - val_mean_absolute_error: 0.0116
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3482e-04 - mean_absolute_error: 0.0134 - val_loss: 2.8363e-04 - val_mean_absolute_error: 0.0128
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1620e-04 - mean_absolute_error: 0.0133 - val_loss: 2.4916e-04 - val_mean_absolute_error: 0.0115

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step - loss: 3.2563e-04 - mean_absolute_error: 0.0132
# Test Loss: [0.00024915646645240486, 0.01150052435696125]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 102617.2775417799
# RMSE: 320.3393162597746
# MAE: 226.7738732569721
# MAPE: 2.0395152389279056 %
#
# Model evalution on validate set
# MSE: 81378.13078549283
# RMSE: 285.2685240006209
# MAE: 187.7922100981405
# MAPE: 1.794977048624282 %

# %% [markdown]
# ## 4. Forecast the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
y_pred_30_days
# Out:
# array([[12725.648],
#        [12641.794],
#        [12727.835],
#        [12672.795],
#        [12715.686],
#        [12686.281],
#        [12708.169],
#        [12692.527],
#        [12703.909],
#        [12695.711],
#        [12701.657],
#        [12697.36 ],
#        [12700.469],
#        [12698.222],
#        [12699.846],
#        [12698.672],
#        [12699.521],
#        [12698.908],
#        [12699.352],
#        [12699.03 ],
#        [12699.262],
#        [12699.095],
#        [12699.216],
#        [12699.13 ],
#        [12699.192],
#        [12699.146],
#        [12699.179],
#        [12699.155],
#        [12699.173],
#        [12699.159],
#        [12699.17 ]], dtype=float32)

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(16, 9))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
