# %% [markdown]
# # Model: GRU (Gated Recurrent Unit)  - Stock Token: FPT - Test/Train/Vaildation: 70/20/10
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 351.96
# - MAE: 253.97
# - MAPE: 2.33 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 0  # 7 2 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170
# ...           ...
# 2024-02-26   9700
# 2024-02-27   9640
# 2024-02-28   9890
# 2024-02-29   9950
# 2024-03-01   9990
#
# [1252 rows x 1 columns]

# %%
df.shape
# Out:
# (1252, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       6900
# 1       7100
# 2       7100
# 3       7170
# 4       7170
#         ...
# 1247    9700
# 1248    9640
# 1249    9890
# 1250    9950
# 1251    9990
# Name: close, Length: 1252, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((865, 10), (865,), (239, 10), (239,), (115, 10), (115,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(100),
        Dense(32, activation="relu"),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 100)            │        30,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,165 (133.46 KB)
#  Trainable params: 34,165 (133.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0482 - mean_absolute_error: 0.1502 - val_loss: 3.8496e-04 - val_mean_absolute_error: 0.0137
# Epoch 2/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.3313e-04 - mean_absolute_error: 0.0229 - val_loss: 4.7765e-04 - val_mean_absolute_error: 0.0160
# Epoch 3/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0865e-04 - mean_absolute_error: 0.0182 - val_loss: 3.3791e-04 - val_mean_absolute_error: 0.0129
# Epoch 4/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2431e-04 - mean_absolute_error: 0.0163 - val_loss: 6.4774e-04 - val_mean_absolute_error: 0.0206
# Epoch 5/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3645e-04 - mean_absolute_error: 0.0197 - val_loss: 3.5089e-04 - val_mean_absolute_error: 0.0130
# Epoch 6/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2228e-04 - mean_absolute_error: 0.0176 - val_loss: 3.4098e-04 - val_mean_absolute_error: 0.0139
# Epoch 7/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4853e-04 - mean_absolute_error: 0.0176 - val_loss: 3.1392e-04 - val_mean_absolute_error: 0.0122
# Epoch 8/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8998e-04 - mean_absolute_error: 0.0161 - val_loss: 4.8161e-04 - val_mean_absolute_error: 0.0185
# Epoch 9/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2980e-04 - mean_absolute_error: 0.0159 - val_loss: 4.1950e-04 - val_mean_absolute_error: 0.0168
# Epoch 10/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8833e-04 - mean_absolute_error: 0.0153 - val_loss: 2.9096e-04 - val_mean_absolute_error: 0.0120
# Epoch 11/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7586e-04 - mean_absolute_error: 0.0149 - val_loss: 4.0777e-04 - val_mean_absolute_error: 0.0153
# Epoch 12/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0847e-04 - mean_absolute_error: 0.0195 - val_loss: 2.8733e-04 - val_mean_absolute_error: 0.0121
# Epoch 13/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2949e-04 - mean_absolute_error: 0.0145 - val_loss: 2.7865e-04 - val_mean_absolute_error: 0.0120
# Epoch 14/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9956e-04 - mean_absolute_error: 0.0158 - val_loss: 4.7289e-04 - val_mean_absolute_error: 0.0171
# Epoch 15/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7388e-04 - mean_absolute_error: 0.0172 - val_loss: 3.1710e-04 - val_mean_absolute_error: 0.0137
# Epoch 16/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2539e-04 - mean_absolute_error: 0.0144 - val_loss: 2.9193e-04 - val_mean_absolute_error: 0.0120
# Epoch 17/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2441e-04 - mean_absolute_error: 0.0148 - val_loss: 4.6933e-04 - val_mean_absolute_error: 0.0172
# Epoch 18/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9102e-04 - mean_absolute_error: 0.0164 - val_loss: 2.7029e-04 - val_mean_absolute_error: 0.0120
# Epoch 19/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8919e-04 - mean_absolute_error: 0.0141 - val_loss: 2.9482e-04 - val_mean_absolute_error: 0.0122
# Epoch 20/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8209e-04 - mean_absolute_error: 0.0150 - val_loss: 2.6229e-04 - val_mean_absolute_error: 0.0115
# Epoch 21/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3722e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0010 - val_mean_absolute_error: 0.0285
# Epoch 22/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - mean_absolute_error: 0.0274 - val_loss: 2.6552e-04 - val_mean_absolute_error: 0.0115
# Epoch 23/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0749e-04 - mean_absolute_error: 0.0142 - val_loss: 2.6758e-04 - val_mean_absolute_error: 0.0120
# Epoch 24/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5963e-04 - mean_absolute_error: 0.0138 - val_loss: 2.6206e-04 - val_mean_absolute_error: 0.0117
# Epoch 25/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7801e-04 - mean_absolute_error: 0.0142 - val_loss: 3.9330e-04 - val_mean_absolute_error: 0.0155
# Epoch 26/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0254 - val_loss: 2.8364e-04 - val_mean_absolute_error: 0.0120
# Epoch 27/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1794e-04 - mean_absolute_error: 0.0158 - val_loss: 3.8021e-04 - val_mean_absolute_error: 0.0151
# Epoch 28/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2440e-04 - mean_absolute_error: 0.0155 - val_loss: 2.9935e-04 - val_mean_absolute_error: 0.0126
# Epoch 29/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7115e-04 - mean_absolute_error: 0.0139 - val_loss: 2.6787e-04 - val_mean_absolute_error: 0.0116
# Epoch 30/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4329e-04 - mean_absolute_error: 0.0131 - val_loss: 2.5377e-04 - val_mean_absolute_error: 0.0112
# Epoch 31/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4426e-04 - mean_absolute_error: 0.0138 - val_loss: 2.4888e-04 - val_mean_absolute_error: 0.0112
# Epoch 32/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1880e-04 - mean_absolute_error: 0.0133 - val_loss: 2.6635e-04 - val_mean_absolute_error: 0.0121
# Epoch 33/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0208e-04 - mean_absolute_error: 0.0127 - val_loss: 3.6513e-04 - val_mean_absolute_error: 0.0149
# Epoch 34/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0219e-04 - mean_absolute_error: 0.0170 - val_loss: 2.9688e-04 - val_mean_absolute_error: 0.0127
# Epoch 35/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2102e-04 - mean_absolute_error: 0.0135 - val_loss: 2.4869e-04 - val_mean_absolute_error: 0.0112
# Epoch 36/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7451e-04 - mean_absolute_error: 0.0122 - val_loss: 3.3192e-04 - val_mean_absolute_error: 0.0139
# Epoch 37/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5150e-04 - mean_absolute_error: 0.0141 - val_loss: 2.5951e-04 - val_mean_absolute_error: 0.0115
# Epoch 38/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6144e-04 - mean_absolute_error: 0.0138 - val_loss: 2.7488e-04 - val_mean_absolute_error: 0.0125
# Epoch 39/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3194e-04 - mean_absolute_error: 0.0130 - val_loss: 2.4834e-04 - val_mean_absolute_error: 0.0113
# Epoch 40/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1737e-04 - mean_absolute_error: 0.0132 - val_loss: 7.3087e-04 - val_mean_absolute_error: 0.0237
# Epoch 41/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.3818e-04 - mean_absolute_error: 0.0229 - val_loss: 2.8543e-04 - val_mean_absolute_error: 0.0124
# Epoch 42/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3105e-04 - mean_absolute_error: 0.0134 - val_loss: 2.5395e-04 - val_mean_absolute_error: 0.0115
# Epoch 43/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3484e-04 - mean_absolute_error: 0.0138 - val_loss: 2.6905e-04 - val_mean_absolute_error: 0.0122
# Epoch 44/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5157e-04 - mean_absolute_error: 0.0143 - val_loss: 4.9852e-04 - val_mean_absolute_error: 0.0189
# Epoch 45/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4831e-04 - mean_absolute_error: 0.0167 - val_loss: 2.6400e-04 - val_mean_absolute_error: 0.0120
# Epoch 46/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4724e-04 - mean_absolute_error: 0.0135 - val_loss: 2.5146e-04 - val_mean_absolute_error: 0.0113
# Epoch 47/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3241e-04 - mean_absolute_error: 0.0139 - val_loss: 2.5169e-04 - val_mean_absolute_error: 0.0115
# Epoch 48/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3439e-04 - mean_absolute_error: 0.0141 - val_loss: 2.5096e-04 - val_mean_absolute_error: 0.0114
# Epoch 49/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2475e-04 - mean_absolute_error: 0.0132 - val_loss: 2.4688e-04 - val_mean_absolute_error: 0.0112
# Epoch 50/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7808e-04 - mean_absolute_error: 0.0122 - val_loss: 2.5900e-04 - val_mean_absolute_error: 0.0117
# Epoch 51/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1877e-04 - mean_absolute_error: 0.0152 - val_loss: 3.1535e-04 - val_mean_absolute_error: 0.0135
# Epoch 52/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0427e-04 - mean_absolute_error: 0.0135 - val_loss: 2.4899e-04 - val_mean_absolute_error: 0.0113
# Epoch 53/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1372e-04 - mean_absolute_error: 0.0160 - val_loss: 3.4760e-04 - val_mean_absolute_error: 0.0148
# Epoch 54/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5909e-04 - mean_absolute_error: 0.0141 - val_loss: 2.6985e-04 - val_mean_absolute_error: 0.0121
# Epoch 55/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9884e-04 - mean_absolute_error: 0.0127 - val_loss: 3.2941e-04 - val_mean_absolute_error: 0.0143
# Epoch 56/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3554e-04 - mean_absolute_error: 0.0140 - val_loss: 2.6376e-04 - val_mean_absolute_error: 0.0120
# Epoch 57/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0340e-04 - mean_absolute_error: 0.0134 - val_loss: 2.4914e-04 - val_mean_absolute_error: 0.0114
# Epoch 58/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6482e-04 - mean_absolute_error: 0.0120 - val_loss: 3.0827e-04 - val_mean_absolute_error: 0.0135
# Epoch 59/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1501e-04 - mean_absolute_error: 0.0131 - val_loss: 2.4956e-04 - val_mean_absolute_error: 0.0113
# Epoch 60/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9980e-04 - mean_absolute_error: 0.0125 - val_loss: 2.5810e-04 - val_mean_absolute_error: 0.0117
# Epoch 61/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6324e-04 - mean_absolute_error: 0.0126 - val_loss: 3.0191e-04 - val_mean_absolute_error: 0.0133
# Epoch 62/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5160e-04 - mean_absolute_error: 0.0124 - val_loss: 2.5672e-04 - val_mean_absolute_error: 0.0116
# Epoch 63/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1466e-04 - mean_absolute_error: 0.0128 - val_loss: 2.4972e-04 - val_mean_absolute_error: 0.0113
# Epoch 64/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1731e-04 - mean_absolute_error: 0.0119 - val_loss: 3.4466e-04 - val_mean_absolute_error: 0.0146
# Epoch 65/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2371e-04 - mean_absolute_error: 0.0139 - val_loss: 2.7542e-04 - val_mean_absolute_error: 0.0123
# Epoch 66/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0585e-04 - mean_absolute_error: 0.0132 - val_loss: 2.7852e-04 - val_mean_absolute_error: 0.0125
# Epoch 67/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0438e-04 - mean_absolute_error: 0.0132 - val_loss: 6.2433e-04 - val_mean_absolute_error: 0.0214
# Epoch 68/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3738e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0029 - val_mean_absolute_error: 0.0505
# Epoch 69/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - mean_absolute_error: 0.0374 - val_loss: 3.5959e-04 - val_mean_absolute_error: 0.0153
# Epoch 70/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6589e-04 - mean_absolute_error: 0.0161 - val_loss: 3.6861e-04 - val_mean_absolute_error: 0.0155
# Epoch 71/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3365e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0013 - val_mean_absolute_error: 0.0328
# Epoch 72/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - mean_absolute_error: 0.0352 - val_loss: 2.6882e-04 - val_mean_absolute_error: 0.0122
# Epoch 73/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6519e-04 - mean_absolute_error: 0.0157 - val_loss: 2.4610e-04 - val_mean_absolute_error: 0.0112
# Epoch 74/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7561e-04 - mean_absolute_error: 0.0126 - val_loss: 2.4850e-04 - val_mean_absolute_error: 0.0113
# Epoch 75/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1013e-04 - mean_absolute_error: 0.0130 - val_loss: 2.5580e-04 - val_mean_absolute_error: 0.0116
# Epoch 76/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1837e-04 - mean_absolute_error: 0.0130 - val_loss: 3.9383e-04 - val_mean_absolute_error: 0.0162
# Epoch 77/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4059e-04 - mean_absolute_error: 0.0143 - val_loss: 2.6398e-04 - val_mean_absolute_error: 0.0119
# Epoch 78/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0019e-04 - mean_absolute_error: 0.0129 - val_loss: 2.5163e-04 - val_mean_absolute_error: 0.0115
# Epoch 79/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5209e-04 - mean_absolute_error: 0.0140 - val_loss: 2.8019e-04 - val_mean_absolute_error: 0.0124
# Epoch 80/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0637e-04 - mean_absolute_error: 0.0140 - val_loss: 2.4906e-04 - val_mean_absolute_error: 0.0113
# Epoch 81/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5088e-04 - mean_absolute_error: 0.0125 - val_loss: 2.4915e-04 - val_mean_absolute_error: 0.0113
# Epoch 82/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0237e-04 - mean_absolute_error: 0.0130 - val_loss: 2.5098e-04 - val_mean_absolute_error: 0.0114
# Epoch 83/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4929e-04 - mean_absolute_error: 0.0116 - val_loss: 3.2128e-04 - val_mean_absolute_error: 0.0140
# Epoch 84/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3193e-04 - mean_absolute_error: 0.0134 - val_loss: 2.9964e-04 - val_mean_absolute_error: 0.0132
# Epoch 85/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8715e-04 - mean_absolute_error: 0.0126 - val_loss: 2.7644e-04 - val_mean_absolute_error: 0.0124
# Epoch 86/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8687e-04 - mean_absolute_error: 0.0129 - val_loss: 3.6502e-04 - val_mean_absolute_error: 0.0152
# Epoch 87/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1149e-04 - mean_absolute_error: 0.0130 - val_loss: 2.5881e-04 - val_mean_absolute_error: 0.0117
# Epoch 88/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8306e-04 - mean_absolute_error: 0.0132 - val_loss: 2.5822e-04 - val_mean_absolute_error: 0.0117
# Epoch 89/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6350e-04 - mean_absolute_error: 0.0123 - val_loss: 2.6678e-04 - val_mean_absolute_error: 0.0121
# Epoch 90/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8005e-04 - mean_absolute_error: 0.0123 - val_loss: 2.5693e-04 - val_mean_absolute_error: 0.0116
# Epoch 91/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8868e-04 - mean_absolute_error: 0.0134 - val_loss: 2.9867e-04 - val_mean_absolute_error: 0.0131
# Epoch 92/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1823e-04 - mean_absolute_error: 0.0133 - val_loss: 3.1307e-04 - val_mean_absolute_error: 0.0135
# Epoch 93/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3679e-04 - mean_absolute_error: 0.0118 - val_loss: 2.8654e-04 - val_mean_absolute_error: 0.0127
# Epoch 94/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7726e-04 - mean_absolute_error: 0.0128 - val_loss: 2.8231e-04 - val_mean_absolute_error: 0.0126
# Epoch 95/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0108e-04 - mean_absolute_error: 0.0131 - val_loss: 4.1171e-04 - val_mean_absolute_error: 0.0164
# Epoch 96/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6974e-04 - mean_absolute_error: 0.0173 - val_loss: 2.6246e-04 - val_mean_absolute_error: 0.0118
# Epoch 97/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6031e-04 - mean_absolute_error: 0.0173 - val_loss: 2.6078e-04 - val_mean_absolute_error: 0.0119
# Epoch 98/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8630e-04 - mean_absolute_error: 0.0124 - val_loss: 2.6262e-04 - val_mean_absolute_error: 0.0119
# Epoch 99/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8918e-04 - mean_absolute_error: 0.0131 - val_loss: 3.0822e-04 - val_mean_absolute_error: 0.0134
# Epoch 100/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3839e-04 - mean_absolute_error: 0.0141 - val_loss: 3.1394e-04 - val_mean_absolute_error: 0.0136
# Epoch 101/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8095e-04 - mean_absolute_error: 0.0125 - val_loss: 2.9809e-04 - val_mean_absolute_error: 0.0131
# Epoch 102/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8782e-04 - mean_absolute_error: 0.0131 - val_loss: 2.6232e-04 - val_mean_absolute_error: 0.0118
# Epoch 103/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9172e-04 - mean_absolute_error: 0.0134 - val_loss: 2.5976e-04 - val_mean_absolute_error: 0.0117
# Epoch 104/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4785e-04 - mean_absolute_error: 0.0117 - val_loss: 2.6588e-04 - val_mean_absolute_error: 0.0119
# Epoch 105/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8137e-04 - mean_absolute_error: 0.0121 - val_loss: 2.9964e-04 - val_mean_absolute_error: 0.0131
# Epoch 106/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9378e-04 - mean_absolute_error: 0.0128 - val_loss: 3.0157e-04 - val_mean_absolute_error: 0.0131
# Epoch 107/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0675e-04 - mean_absolute_error: 0.0133 - val_loss: 2.6495e-04 - val_mean_absolute_error: 0.0119
# Epoch 108/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5377e-04 - mean_absolute_error: 0.0121 - val_loss: 2.9988e-04 - val_mean_absolute_error: 0.0131
# Epoch 109/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2706e-04 - mean_absolute_error: 0.0139 - val_loss: 4.4101e-04 - val_mean_absolute_error: 0.0170
# Epoch 110/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1805e-04 - mean_absolute_error: 0.0173 - val_loss: 2.7340e-04 - val_mean_absolute_error: 0.0122
# Epoch 111/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6566e-04 - mean_absolute_error: 0.0130 - val_loss: 4.6256e-04 - val_mean_absolute_error: 0.0175
# Epoch 112/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0504e-04 - mean_absolute_error: 0.0157 - val_loss: 2.6474e-04 - val_mean_absolute_error: 0.0119
# Epoch 113/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8009e-04 - mean_absolute_error: 0.0125 - val_loss: 2.6662e-04 - val_mean_absolute_error: 0.0119
# Epoch 114/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8639e-04 - mean_absolute_error: 0.0127 - val_loss: 3.4145e-04 - val_mean_absolute_error: 0.0144
# Epoch 115/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5950e-04 - mean_absolute_error: 0.0181 - val_loss: 3.1081e-04 - val_mean_absolute_error: 0.0134
# Epoch 116/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7616e-04 - mean_absolute_error: 0.0135 - val_loss: 2.9507e-04 - val_mean_absolute_error: 0.0129
# Epoch 117/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3025e-04 - mean_absolute_error: 0.0117 - val_loss: 2.9931e-04 - val_mean_absolute_error: 0.0131
# Epoch 118/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6421e-04 - mean_absolute_error: 0.0144 - val_loss: 2.7634e-04 - val_mean_absolute_error: 0.0123
# Epoch 119/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5250e-04 - mean_absolute_error: 0.0119 - val_loss: 3.0688e-04 - val_mean_absolute_error: 0.0132
# Epoch 120/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7797e-04 - mean_absolute_error: 0.0132 - val_loss: 3.0364e-04 - val_mean_absolute_error: 0.0132
# Epoch 121/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9885e-04 - mean_absolute_error: 0.0136 - val_loss: 2.7040e-04 - val_mean_absolute_error: 0.0121
# Epoch 122/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4521e-04 - mean_absolute_error: 0.0119 - val_loss: 9.9160e-04 - val_mean_absolute_error: 0.0278
# Epoch 123/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - mean_absolute_error: 0.0286 - val_loss: 2.8784e-04 - val_mean_absolute_error: 0.0126
# Epoch 124/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2459e-04 - mean_absolute_error: 0.0144 - val_loss: 2.8378e-04 - val_mean_absolute_error: 0.0124
# Epoch 125/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7259e-04 - mean_absolute_error: 0.0127 - val_loss: 2.7612e-04 - val_mean_absolute_error: 0.0122
# Epoch 126/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7935e-04 - mean_absolute_error: 0.0130 - val_loss: 2.7540e-04 - val_mean_absolute_error: 0.0122
# Epoch 127/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5919e-04 - mean_absolute_error: 0.0130 - val_loss: 2.8511e-04 - val_mean_absolute_error: 0.0126
# Epoch 128/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9973e-04 - mean_absolute_error: 0.0134 - val_loss: 3.0183e-04 - val_mean_absolute_error: 0.0131
# Epoch 129/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1069e-04 - mean_absolute_error: 0.0156 - val_loss: 3.3795e-04 - val_mean_absolute_error: 0.0141
# Epoch 130/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5628e-04 - mean_absolute_error: 0.0128 - val_loss: 3.1900e-04 - val_mean_absolute_error: 0.0136
# Epoch 131/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5758e-04 - mean_absolute_error: 0.0124 - val_loss: 2.8056e-04 - val_mean_absolute_error: 0.0123
# Epoch 132/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1547e-04 - mean_absolute_error: 0.0132 - val_loss: 2.7617e-04 - val_mean_absolute_error: 0.0123
# Epoch 133/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4937e-04 - mean_absolute_error: 0.0147 - val_loss: 2.7515e-04 - val_mean_absolute_error: 0.0122
# Epoch 134/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8957e-04 - mean_absolute_error: 0.0129 - val_loss: 2.7420e-04 - val_mean_absolute_error: 0.0121
# Epoch 135/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8411e-04 - mean_absolute_error: 0.0122 - val_loss: 2.7419e-04 - val_mean_absolute_error: 0.0122
# Epoch 136/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2424e-04 - mean_absolute_error: 0.0115 - val_loss: 5.3094e-04 - val_mean_absolute_error: 0.0191
# Epoch 137/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8832e-04 - mean_absolute_error: 0.0216 - val_loss: 2.8235e-04 - val_mean_absolute_error: 0.0124
# Epoch 138/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1328e-04 - mean_absolute_error: 0.0136 - val_loss: 2.8373e-04 - val_mean_absolute_error: 0.0125
# Epoch 139/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7814e-04 - mean_absolute_error: 0.0124 - val_loss: 4.0754e-04 - val_mean_absolute_error: 0.0160
# Epoch 140/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3596e-04 - mean_absolute_error: 0.0137 - val_loss: 3.0317e-04 - val_mean_absolute_error: 0.0131
# Epoch 141/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1885e-04 - mean_absolute_error: 0.0136 - val_loss: 2.7407e-04 - val_mean_absolute_error: 0.0121
# Epoch 142/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8103e-04 - mean_absolute_error: 0.0130 - val_loss: 3.2333e-04 - val_mean_absolute_error: 0.0137
# Epoch 143/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8826e-04 - mean_absolute_error: 0.0128 - val_loss: 3.1796e-04 - val_mean_absolute_error: 0.0136
# Epoch 144/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5002e-04 - mean_absolute_error: 0.0128 - val_loss: 7.4072e-04 - val_mean_absolute_error: 0.0234
# Epoch 145/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0148e-04 - mean_absolute_error: 0.0210 - val_loss: 2.8801e-04 - val_mean_absolute_error: 0.0126
# Epoch 146/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6551e-04 - mean_absolute_error: 0.0129 - val_loss: 2.8165e-04 - val_mean_absolute_error: 0.0124
# Epoch 147/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5034e-04 - mean_absolute_error: 0.0142 - val_loss: 3.9019e-04 - val_mean_absolute_error: 0.0155
# Epoch 148/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7370e-04 - mean_absolute_error: 0.0135 - val_loss: 2.7509e-04 - val_mean_absolute_error: 0.0123
# Epoch 149/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8063e-04 - mean_absolute_error: 0.0130 - val_loss: 3.3955e-04 - val_mean_absolute_error: 0.0142
# Epoch 150/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8845e-04 - mean_absolute_error: 0.0135 - val_loss: 2.7203e-04 - val_mean_absolute_error: 0.0122
# Epoch 151/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8107e-04 - mean_absolute_error: 0.0123 - val_loss: 2.7639e-04 - val_mean_absolute_error: 0.0122
# Epoch 152/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6710e-04 - mean_absolute_error: 0.0121 - val_loss: 2.9651e-04 - val_mean_absolute_error: 0.0129
# Epoch 153/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1789e-04 - mean_absolute_error: 0.0139 - val_loss: 2.7382e-04 - val_mean_absolute_error: 0.0121
# Epoch 154/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6797e-04 - mean_absolute_error: 0.0125 - val_loss: 2.7217e-04 - val_mean_absolute_error: 0.0122
# Epoch 155/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8456e-04 - mean_absolute_error: 0.0125 - val_loss: 2.8586e-04 - val_mean_absolute_error: 0.0126
# Epoch 156/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8191e-04 - mean_absolute_error: 0.0136 - val_loss: 3.0055e-04 - val_mean_absolute_error: 0.0131
# Epoch 157/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2106e-04 - mean_absolute_error: 0.0131 - val_loss: 3.3026e-04 - val_mean_absolute_error: 0.0139
# Epoch 158/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0668e-04 - mean_absolute_error: 0.0129 - val_loss: 5.3221e-04 - val_mean_absolute_error: 0.0192
# Epoch 159/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4865e-04 - mean_absolute_error: 0.0183 - val_loss: 2.7277e-04 - val_mean_absolute_error: 0.0122
# Epoch 160/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0458e-04 - mean_absolute_error: 0.0142 - val_loss: 2.7492e-04 - val_mean_absolute_error: 0.0122
# Epoch 161/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8040e-04 - mean_absolute_error: 0.0129 - val_loss: 2.9695e-04 - val_mean_absolute_error: 0.0129
# Epoch 162/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6525e-04 - mean_absolute_error: 0.0129 - val_loss: 2.7813e-04 - val_mean_absolute_error: 0.0123
# Epoch 163/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2561e-04 - mean_absolute_error: 0.0117 - val_loss: 4.1303e-04 - val_mean_absolute_error: 0.0162
# Epoch 164/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0274e-04 - mean_absolute_error: 0.0129 - val_loss: 3.5607e-04 - val_mean_absolute_error: 0.0147
# Epoch 165/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0640e-04 - mean_absolute_error: 0.0136 - val_loss: 4.6599e-04 - val_mean_absolute_error: 0.0176
# Epoch 166/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8848e-04 - mean_absolute_error: 0.0137 - val_loss: 2.7490e-04 - val_mean_absolute_error: 0.0122
# Epoch 167/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6308e-04 - mean_absolute_error: 0.0123 - val_loss: 2.6900e-04 - val_mean_absolute_error: 0.0120
# Epoch 168/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2678e-04 - mean_absolute_error: 0.0144 - val_loss: 2.7685e-04 - val_mean_absolute_error: 0.0123
# Epoch 169/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9942e-04 - mean_absolute_error: 0.0134 - val_loss: 2.8337e-04 - val_mean_absolute_error: 0.0125
# Epoch 170/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3763e-04 - mean_absolute_error: 0.0148 - val_loss: 3.7365e-04 - val_mean_absolute_error: 0.0151
# Epoch 171/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6768e-04 - mean_absolute_error: 0.0148 - val_loss: 2.7330e-04 - val_mean_absolute_error: 0.0122
# Epoch 172/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7463e-04 - mean_absolute_error: 0.0123 - val_loss: 2.7666e-04 - val_mean_absolute_error: 0.0122
# Epoch 173/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1429e-04 - mean_absolute_error: 0.0135 - val_loss: 3.6945e-04 - val_mean_absolute_error: 0.0150
# Epoch 174/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4591e-04 - mean_absolute_error: 0.0141 - val_loss: 2.8543e-04 - val_mean_absolute_error: 0.0125
# Epoch 175/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0767e-04 - mean_absolute_error: 0.0141 - val_loss: 5.2357e-04 - val_mean_absolute_error: 0.0189
# Epoch 176/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2994e-04 - mean_absolute_error: 0.0187 - val_loss: 3.8357e-04 - val_mean_absolute_error: 0.0155
# Epoch 177/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5109e-04 - mean_absolute_error: 0.0146 - val_loss: 2.6924e-04 - val_mean_absolute_error: 0.0120
# Epoch 178/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0325e-04 - mean_absolute_error: 0.0126 - val_loss: 2.7858e-04 - val_mean_absolute_error: 0.0123
# Epoch 179/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8794e-04 - mean_absolute_error: 0.0137 - val_loss: 2.7713e-04 - val_mean_absolute_error: 0.0123
# Epoch 180/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6441e-04 - mean_absolute_error: 0.0124 - val_loss: 3.1121e-04 - val_mean_absolute_error: 0.0133
# Epoch 181/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9462e-04 - mean_absolute_error: 0.0141 - val_loss: 3.1921e-04 - val_mean_absolute_error: 0.0136
# Epoch 182/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6949e-04 - mean_absolute_error: 0.0125 - val_loss: 3.8859e-04 - val_mean_absolute_error: 0.0156
# Epoch 183/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2577e-04 - mean_absolute_error: 0.0179 - val_loss: 3.7927e-04 - val_mean_absolute_error: 0.0153
# Epoch 184/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5009e-04 - mean_absolute_error: 0.0142 - val_loss: 3.1431e-04 - val_mean_absolute_error: 0.0135
# Epoch 185/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6551e-04 - mean_absolute_error: 0.0132 - val_loss: 2.9422e-04 - val_mean_absolute_error: 0.0129
# Epoch 186/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3948e-04 - mean_absolute_error: 0.0120 - val_loss: 2.7784e-04 - val_mean_absolute_error: 0.0123
# Epoch 187/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2746e-04 - mean_absolute_error: 0.0139 - val_loss: 2.8273e-04 - val_mean_absolute_error: 0.0125
# Epoch 188/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6818e-04 - mean_absolute_error: 0.0127 - val_loss: 2.7119e-04 - val_mean_absolute_error: 0.0121
# Epoch 189/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5513e-04 - mean_absolute_error: 0.0123 - val_loss: 3.0190e-04 - val_mean_absolute_error: 0.0131
# Epoch 190/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9281e-04 - mean_absolute_error: 0.0128 - val_loss: 8.3337e-04 - val_mean_absolute_error: 0.0254
# Epoch 191/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - mean_absolute_error: 0.0288 - val_loss: 2.7654e-04 - val_mean_absolute_error: 0.0122
# Epoch 192/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1074e-04 - mean_absolute_error: 0.0174 - val_loss: 2.6540e-04 - val_mean_absolute_error: 0.0119
# Epoch 193/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4877e-04 - mean_absolute_error: 0.0119 - val_loss: 3.8061e-04 - val_mean_absolute_error: 0.0155
# Epoch 194/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9470e-04 - mean_absolute_error: 0.0139 - val_loss: 3.0649e-04 - val_mean_absolute_error: 0.0133
# Epoch 195/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5361e-04 - mean_absolute_error: 0.0126 - val_loss: 4.1207e-04 - val_mean_absolute_error: 0.0162
# Epoch 196/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - mean_absolute_error: 0.0245 - val_loss: 3.7987e-04 - val_mean_absolute_error: 0.0150
# Epoch 197/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5568e-04 - mean_absolute_error: 0.0154 - val_loss: 2.7694e-04 - val_mean_absolute_error: 0.0123
# Epoch 198/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2402e-04 - mean_absolute_error: 0.0137 - val_loss: 2.8363e-04 - val_mean_absolute_error: 0.0125
# Epoch 199/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8597e-04 - mean_absolute_error: 0.0126 - val_loss: 2.7065e-04 - val_mean_absolute_error: 0.0120
# Epoch 200/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7953e-04 - mean_absolute_error: 0.0121 - val_loss: 3.1592e-04 - val_mean_absolute_error: 0.0134

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8060e-04 - mean_absolute_error: 0.0150
# Test Loss: [0.0003159190237056464, 0.01343200821429491]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 239
# 250

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 123878.53259437853
# RMSE: 351.96382284885266
# MAE: 253.96611655007845
# MAPE: 2.327485101567018 %
#
# Model evalution on validate set
# MSE: 62696.883658624734
# RMSE: 250.39345769932714
# MAE: 184.20926460597826
# MAPE: 1.8512985229231456 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
y_pred_30_days
# Out:
# array([[9922.37 ],
#        [9928.23 ],
#        [9926.569],
#        [9929.021],
#        [9927.884],
#        [9928.483],
#        [9928.177],
#        [9928.357],
#        [9928.263],
#        [9928.314],
#        [9928.286],
#        [9928.302],
#        [9928.293],
#        [9928.299],
#        [9928.296],
#        [9928.297],
#        [9928.297],
#        [9928.297],
#        [9928.297],
#        [9928.297],
#        [9928.297],
#        [9928.297],
#        [9928.297],
#        [9928.297],
#        [9928.297],
#        [9928.297],
#        [9928.297],
#        [9928.297],
#        [9928.297],
#        [9928.297],
#        [9928.297]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
