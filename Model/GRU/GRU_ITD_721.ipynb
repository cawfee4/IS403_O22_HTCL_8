# %% [markdown]
# # Model: GRU (Gated Recurrent Unit)  - Stock Token: FPT - Test/Train/Vaildation: 70/20/10
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 351.96
# - MAE: 253.97
# - MAPE: 2.33 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 0  # 7 2 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170
# ...           ...
# 2024-05-27  11300
# 2024-05-28  12050
# 2024-05-29  12600
# 2024-05-30  12500
# 2024-05-31  12700
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        6900
# 1        7100
# 2        7100
# 3        7170
# 4        7170
#         ...
# 1308    11300
# 1309    12050
# 1310    12600
# 1311    12500
# 1312    12700
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((908, 10), (908,), (251, 10), (251,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(100),
        Dense(32, activation="relu"),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 100)            │        30,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,165 (133.46 KB)
#  Trainable params: 34,165 (133.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 0.0271 - mean_absolute_error: 0.1113 - val_loss: 0.0014 - val_mean_absolute_error: 0.0346
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0011 - mean_absolute_error: 0.0244 - val_loss: 2.8020e-04 - val_mean_absolute_error: 0.0117
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.3343e-04 - mean_absolute_error: 0.0184 - val_loss: 3.6686e-04 - val_mean_absolute_error: 0.0142
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.2146e-04 - mean_absolute_error: 0.0159 - val_loss: 2.7418e-04 - val_mean_absolute_error: 0.0118
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.3323e-04 - mean_absolute_error: 0.0153 - val_loss: 2.9531e-04 - val_mean_absolute_error: 0.0129
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.4572e-04 - mean_absolute_error: 0.0155 - val_loss: 2.9554e-04 - val_mean_absolute_error: 0.0130
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.1235e-04 - mean_absolute_error: 0.0152 - val_loss: 2.8808e-04 - val_mean_absolute_error: 0.0128
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.5282e-04 - mean_absolute_error: 0.0163 - val_loss: 2.5564e-04 - val_mean_absolute_error: 0.0114
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.2505e-04 - mean_absolute_error: 0.0142 - val_loss: 3.0275e-04 - val_mean_absolute_error: 0.0135
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.5872e-04 - mean_absolute_error: 0.0155 - val_loss: 2.4955e-04 - val_mean_absolute_error: 0.0112
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.6656e-04 - mean_absolute_error: 0.0134 - val_loss: 2.5772e-04 - val_mean_absolute_error: 0.0117
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.7242e-04 - mean_absolute_error: 0.0137 - val_loss: 2.4845e-04 - val_mean_absolute_error: 0.0112
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.3112e-04 - mean_absolute_error: 0.0144 - val_loss: 4.5828e-04 - val_mean_absolute_error: 0.0181
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.0119e-04 - mean_absolute_error: 0.0186 - val_loss: 2.6968e-04 - val_mean_absolute_error: 0.0119
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.1578e-04 - mean_absolute_error: 0.0145 - val_loss: 2.4420e-04 - val_mean_absolute_error: 0.0112
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.9969e-04 - mean_absolute_error: 0.0141 - val_loss: 2.4029e-04 - val_mean_absolute_error: 0.0111
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.5488e-04 - mean_absolute_error: 0.0132 - val_loss: 4.3529e-04 - val_mean_absolute_error: 0.0176
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.8154e-04 - mean_absolute_error: 0.0148 - val_loss: 2.6778e-04 - val_mean_absolute_error: 0.0120
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.0913e-04 - mean_absolute_error: 0.0153 - val_loss: 2.5398e-04 - val_mean_absolute_error: 0.0116
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.1543e-04 - mean_absolute_error: 0.0148 - val_loss: 2.4641e-04 - val_mean_absolute_error: 0.0115
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.7657e-04 - mean_absolute_error: 0.0125 - val_loss: 3.9788e-04 - val_mean_absolute_error: 0.0166
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.6266e-04 - mean_absolute_error: 0.0146 - val_loss: 3.3274e-04 - val_mean_absolute_error: 0.0147
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.4403e-04 - mean_absolute_error: 0.0141 - val_loss: 2.3565e-04 - val_mean_absolute_error: 0.0111
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.4723e-04 - mean_absolute_error: 0.0132 - val_loss: 3.2284e-04 - val_mean_absolute_error: 0.0144
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.7469e-04 - mean_absolute_error: 0.0144 - val_loss: 2.3515e-04 - val_mean_absolute_error: 0.0110
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.7689e-04 - mean_absolute_error: 0.0128 - val_loss: 4.2141e-04 - val_mean_absolute_error: 0.0172
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.5354e-04 - mean_absolute_error: 0.0146 - val_loss: 2.3558e-04 - val_mean_absolute_error: 0.0111
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.0818e-04 - mean_absolute_error: 0.0151 - val_loss: 3.0707e-04 - val_mean_absolute_error: 0.0134
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.7970e-04 - mean_absolute_error: 0.0149 - val_loss: 2.7033e-04 - val_mean_absolute_error: 0.0126
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.0636e-04 - mean_absolute_error: 0.0134 - val_loss: 2.9819e-04 - val_mean_absolute_error: 0.0132
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.9482e-04 - mean_absolute_error: 0.0145 - val_loss: 4.3047e-04 - val_mean_absolute_error: 0.0175
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.4276e-04 - mean_absolute_error: 0.0142 - val_loss: 2.3576e-04 - val_mean_absolute_error: 0.0111
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.4045e-04 - mean_absolute_error: 0.0138 - val_loss: 3.2195e-04 - val_mean_absolute_error: 0.0140
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5883e-04 - mean_absolute_error: 0.0138 - val_loss: 2.4156e-04 - val_mean_absolute_error: 0.0114
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.7988e-04 - mean_absolute_error: 0.0124 - val_loss: 4.0392e-04 - val_mean_absolute_error: 0.0162
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.3764e-04 - mean_absolute_error: 0.0157 - val_loss: 2.7100e-04 - val_mean_absolute_error: 0.0126
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.2949e-04 - mean_absolute_error: 0.0134 - val_loss: 2.3151e-04 - val_mean_absolute_error: 0.0109
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.7383e-04 - mean_absolute_error: 0.0127 - val_loss: 2.8766e-04 - val_mean_absolute_error: 0.0129
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.2949e-04 - mean_absolute_error: 0.0137 - val_loss: 2.2832e-04 - val_mean_absolute_error: 0.0107
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.3416e-04 - mean_absolute_error: 0.0133 - val_loss: 2.2818e-04 - val_mean_absolute_error: 0.0107
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.0863e-04 - mean_absolute_error: 0.0125 - val_loss: 3.1478e-04 - val_mean_absolute_error: 0.0141
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.1028e-04 - mean_absolute_error: 0.0129 - val_loss: 2.3170e-04 - val_mean_absolute_error: 0.0109
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.9369e-04 - mean_absolute_error: 0.0125 - val_loss: 2.4815e-04 - val_mean_absolute_error: 0.0117
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.9063e-04 - mean_absolute_error: 0.0127 - val_loss: 2.3862e-04 - val_mean_absolute_error: 0.0112
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.6606e-04 - mean_absolute_error: 0.0127 - val_loss: 5.6300e-04 - val_mean_absolute_error: 0.0204
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.6023e-04 - mean_absolute_error: 0.0163 - val_loss: 2.3037e-04 - val_mean_absolute_error: 0.0108
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.2833e-04 - mean_absolute_error: 0.0137 - val_loss: 3.5333e-04 - val_mean_absolute_error: 0.0149
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.2692e-04 - mean_absolute_error: 0.0137 - val_loss: 2.3465e-04 - val_mean_absolute_error: 0.0110
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.4855e-04 - mean_absolute_error: 0.0121 - val_loss: 4.2861e-04 - val_mean_absolute_error: 0.0173
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.5960e-04 - mean_absolute_error: 0.0147 - val_loss: 2.6270e-04 - val_mean_absolute_error: 0.0122
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.3213e-04 - mean_absolute_error: 0.0149 - val_loss: 2.3252e-04 - val_mean_absolute_error: 0.0109
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.1871e-04 - mean_absolute_error: 0.0136 - val_loss: 2.7993e-04 - val_mean_absolute_error: 0.0128
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9130e-04 - mean_absolute_error: 0.0127 - val_loss: 2.5126e-04 - val_mean_absolute_error: 0.0117
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.7006e-04 - mean_absolute_error: 0.0128 - val_loss: 2.4835e-04 - val_mean_absolute_error: 0.0115
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7709e-04 - mean_absolute_error: 0.0128 - val_loss: 3.6405e-04 - val_mean_absolute_error: 0.0155
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.1101e-04 - mean_absolute_error: 0.0135 - val_loss: 2.9791e-04 - val_mean_absolute_error: 0.0134
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.8284e-04 - mean_absolute_error: 0.0124 - val_loss: 2.7942e-04 - val_mean_absolute_error: 0.0127
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6947e-04 - mean_absolute_error: 0.0127 - val_loss: 2.4528e-04 - val_mean_absolute_error: 0.0114
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.6031e-04 - mean_absolute_error: 0.0124 - val_loss: 3.0834e-04 - val_mean_absolute_error: 0.0135
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.5079e-04 - mean_absolute_error: 0.0125 - val_loss: 2.5577e-04 - val_mean_absolute_error: 0.0118
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.8796e-04 - mean_absolute_error: 0.0127 - val_loss: 2.5615e-04 - val_mean_absolute_error: 0.0118
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.0556e-04 - mean_absolute_error: 0.0124 - val_loss: 2.5731e-04 - val_mean_absolute_error: 0.0119
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.4401e-04 - mean_absolute_error: 0.0136 - val_loss: 2.6201e-04 - val_mean_absolute_error: 0.0121
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.9901e-04 - mean_absolute_error: 0.0131 - val_loss: 2.6635e-04 - val_mean_absolute_error: 0.0122
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.4148e-04 - mean_absolute_error: 0.0144 - val_loss: 2.6020e-04 - val_mean_absolute_error: 0.0119
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.5387e-04 - mean_absolute_error: 0.0120 - val_loss: 2.5219e-04 - val_mean_absolute_error: 0.0117
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.1670e-04 - mean_absolute_error: 0.0147 - val_loss: 4.0384e-04 - val_mean_absolute_error: 0.0165
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.2748e-04 - mean_absolute_error: 0.0141 - val_loss: 2.9360e-04 - val_mean_absolute_error: 0.0130
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.1546e-04 - mean_absolute_error: 0.0138 - val_loss: 2.9509e-04 - val_mean_absolute_error: 0.0130
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.4299e-04 - mean_absolute_error: 0.0145 - val_loss: 2.8113e-04 - val_mean_absolute_error: 0.0127
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.5581e-04 - mean_absolute_error: 0.0126 - val_loss: 2.4763e-04 - val_mean_absolute_error: 0.0115
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.7023e-04 - mean_absolute_error: 0.0125 - val_loss: 2.4645e-04 - val_mean_absolute_error: 0.0114
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8895e-04 - mean_absolute_error: 0.0129 - val_loss: 2.4765e-04 - val_mean_absolute_error: 0.0114
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.7984e-04 - mean_absolute_error: 0.0125 - val_loss: 2.4605e-04 - val_mean_absolute_error: 0.0114
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.4977e-04 - mean_absolute_error: 0.0144 - val_loss: 2.6452e-04 - val_mean_absolute_error: 0.0120
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9560e-04 - mean_absolute_error: 0.0128 - val_loss: 2.5181e-04 - val_mean_absolute_error: 0.0116
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.0214e-04 - mean_absolute_error: 0.0128 - val_loss: 3.4811e-04 - val_mean_absolute_error: 0.0146
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.3663e-04 - mean_absolute_error: 0.0141 - val_loss: 2.4689e-04 - val_mean_absolute_error: 0.0114
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.9048e-04 - mean_absolute_error: 0.0131 - val_loss: 5.4689e-04 - val_mean_absolute_error: 0.0199
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7152e-04 - mean_absolute_error: 0.0131 - val_loss: 5.6300e-04 - val_mean_absolute_error: 0.0202
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.5597e-04 - mean_absolute_error: 0.0154 - val_loss: 3.9756e-04 - val_mean_absolute_error: 0.0162
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.0436e-04 - mean_absolute_error: 0.0134 - val_loss: 2.6191e-04 - val_mean_absolute_error: 0.0120
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.5838e-04 - mean_absolute_error: 0.0125 - val_loss: 2.4879e-04 - val_mean_absolute_error: 0.0115
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.0698e-04 - mean_absolute_error: 0.0136 - val_loss: 2.5334e-04 - val_mean_absolute_error: 0.0117
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.0841e-04 - mean_absolute_error: 0.0158 - val_loss: 3.3074e-04 - val_mean_absolute_error: 0.0143
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.7236e-04 - mean_absolute_error: 0.0131 - val_loss: 3.0640e-04 - val_mean_absolute_error: 0.0135
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.6699e-04 - mean_absolute_error: 0.0129 - val_loss: 2.8485e-04 - val_mean_absolute_error: 0.0126
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.5685e-04 - mean_absolute_error: 0.0128 - val_loss: 2.4839e-04 - val_mean_absolute_error: 0.0114
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.7039e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1564e-04 - val_mean_absolute_error: 0.0136
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9338e-04 - mean_absolute_error: 0.0139 - val_loss: 3.7485e-04 - val_mean_absolute_error: 0.0153
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.8497e-04 - mean_absolute_error: 0.0131 - val_loss: 2.5549e-04 - val_mean_absolute_error: 0.0117
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.2973e-04 - mean_absolute_error: 0.0116 - val_loss: 2.5012e-04 - val_mean_absolute_error: 0.0115
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.7407e-04 - mean_absolute_error: 0.0125 - val_loss: 2.5021e-04 - val_mean_absolute_error: 0.0114
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.6780e-04 - mean_absolute_error: 0.0121 - val_loss: 2.4850e-04 - val_mean_absolute_error: 0.0114
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.8035e-04 - mean_absolute_error: 0.0127 - val_loss: 3.0100e-04 - val_mean_absolute_error: 0.0133
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.3170e-04 - mean_absolute_error: 0.0121 - val_loss: 3.6071e-04 - val_mean_absolute_error: 0.0152
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.9359e-04 - mean_absolute_error: 0.0139 - val_loss: 2.6118e-04 - val_mean_absolute_error: 0.0119
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.0258e-04 - mean_absolute_error: 0.0139 - val_loss: 2.4928e-04 - val_mean_absolute_error: 0.0115
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.2719e-04 - mean_absolute_error: 0.0134 - val_loss: 2.9720e-04 - val_mean_absolute_error: 0.0130
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5708e-04 - mean_absolute_error: 0.0140 - val_loss: 2.6819e-04 - val_mean_absolute_error: 0.0122
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.7257e-04 - mean_absolute_error: 0.0145 - val_loss: 2.6231e-04 - val_mean_absolute_error: 0.0120
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.7987e-04 - mean_absolute_error: 0.0132 - val_loss: 2.6025e-04 - val_mean_absolute_error: 0.0119
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.5229e-04 - mean_absolute_error: 0.0123 - val_loss: 4.2607e-04 - val_mean_absolute_error: 0.0167
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.3087e-04 - mean_absolute_error: 0.0138 - val_loss: 2.5937e-04 - val_mean_absolute_error: 0.0119
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.5805e-04 - mean_absolute_error: 0.0125 - val_loss: 2.6745e-04 - val_mean_absolute_error: 0.0122
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.7010e-04 - mean_absolute_error: 0.0127 - val_loss: 2.9210e-04 - val_mean_absolute_error: 0.0129
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.1098e-04 - mean_absolute_error: 0.0132 - val_loss: 2.5545e-04 - val_mean_absolute_error: 0.0117
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.7387e-04 - mean_absolute_error: 0.0128 - val_loss: 2.7400e-04 - val_mean_absolute_error: 0.0123
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.9379e-04 - mean_absolute_error: 0.0134 - val_loss: 3.7477e-04 - val_mean_absolute_error: 0.0156
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.3817e-04 - mean_absolute_error: 0.0126 - val_loss: 2.9217e-04 - val_mean_absolute_error: 0.0129
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.1739e-04 - mean_absolute_error: 0.0132 - val_loss: 2.6422e-04 - val_mean_absolute_error: 0.0120
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.5064e-04 - mean_absolute_error: 0.0151 - val_loss: 2.7105e-04 - val_mean_absolute_error: 0.0124
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.9747e-04 - mean_absolute_error: 0.0129 - val_loss: 2.7726e-04 - val_mean_absolute_error: 0.0126
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.5963e-04 - mean_absolute_error: 0.0141 - val_loss: 2.5086e-04 - val_mean_absolute_error: 0.0116
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.1279e-04 - mean_absolute_error: 0.0139 - val_loss: 3.5072e-04 - val_mean_absolute_error: 0.0149
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.9010e-04 - mean_absolute_error: 0.0134 - val_loss: 2.5168e-04 - val_mean_absolute_error: 0.0116
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.4601e-04 - mean_absolute_error: 0.0123 - val_loss: 2.4816e-04 - val_mean_absolute_error: 0.0115
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.7355e-04 - mean_absolute_error: 0.0128 - val_loss: 2.6761e-04 - val_mean_absolute_error: 0.0121
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.5358e-04 - mean_absolute_error: 0.0121 - val_loss: 2.7278e-04 - val_mean_absolute_error: 0.0124
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.7460e-04 - mean_absolute_error: 0.0128 - val_loss: 2.6121e-04 - val_mean_absolute_error: 0.0119
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.7349e-04 - mean_absolute_error: 0.0128 - val_loss: 2.8302e-04 - val_mean_absolute_error: 0.0127
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.5340e-04 - mean_absolute_error: 0.0144 - val_loss: 2.8110e-04 - val_mean_absolute_error: 0.0127
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.8558e-04 - mean_absolute_error: 0.0128 - val_loss: 3.0855e-04 - val_mean_absolute_error: 0.0136
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.0184e-04 - mean_absolute_error: 0.0134 - val_loss: 2.5186e-04 - val_mean_absolute_error: 0.0115
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.1507e-04 - mean_absolute_error: 0.0139 - val_loss: 2.7847e-04 - val_mean_absolute_error: 0.0126
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9006e-04 - mean_absolute_error: 0.0136 - val_loss: 2.7825e-04 - val_mean_absolute_error: 0.0126
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.1668e-04 - mean_absolute_error: 0.0134 - val_loss: 2.5892e-04 - val_mean_absolute_error: 0.0118
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.6620e-04 - mean_absolute_error: 0.0130 - val_loss: 2.5722e-04 - val_mean_absolute_error: 0.0118
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.6571e-04 - mean_absolute_error: 0.0124 - val_loss: 3.2255e-04 - val_mean_absolute_error: 0.0141
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.8187e-04 - mean_absolute_error: 0.0150 - val_loss: 3.2559e-04 - val_mean_absolute_error: 0.0141
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.1501e-04 - mean_absolute_error: 0.0140 - val_loss: 3.0629e-04 - val_mean_absolute_error: 0.0135
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.2945e-04 - mean_absolute_error: 0.0121 - val_loss: 2.6494e-04 - val_mean_absolute_error: 0.0121
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.6452e-04 - mean_absolute_error: 0.0126 - val_loss: 2.5166e-04 - val_mean_absolute_error: 0.0116
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.6909e-04 - mean_absolute_error: 0.0125 - val_loss: 3.3138e-04 - val_mean_absolute_error: 0.0141
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.8081e-04 - mean_absolute_error: 0.0156 - val_loss: 2.8790e-04 - val_mean_absolute_error: 0.0127
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.9090e-04 - mean_absolute_error: 0.0136 - val_loss: 2.5437e-04 - val_mean_absolute_error: 0.0117
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.6372e-04 - mean_absolute_error: 0.0128 - val_loss: 2.7582e-04 - val_mean_absolute_error: 0.0125
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.1984e-04 - mean_absolute_error: 0.0119 - val_loss: 2.4848e-04 - val_mean_absolute_error: 0.0114
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.8800e-04 - mean_absolute_error: 0.0129 - val_loss: 3.0561e-04 - val_mean_absolute_error: 0.0135
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.0452e-04 - mean_absolute_error: 0.0131 - val_loss: 2.4618e-04 - val_mean_absolute_error: 0.0114
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.5147e-04 - mean_absolute_error: 0.0141 - val_loss: 2.6543e-04 - val_mean_absolute_error: 0.0121
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.0633e-04 - mean_absolute_error: 0.0136 - val_loss: 2.4926e-04 - val_mean_absolute_error: 0.0115
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8283e-04 - mean_absolute_error: 0.0126 - val_loss: 2.6567e-04 - val_mean_absolute_error: 0.0121
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.2185e-04 - mean_absolute_error: 0.0138 - val_loss: 2.4910e-04 - val_mean_absolute_error: 0.0114
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.6471e-04 - mean_absolute_error: 0.0126 - val_loss: 2.6504e-04 - val_mean_absolute_error: 0.0121
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.5191e-04 - mean_absolute_error: 0.0123 - val_loss: 3.4943e-04 - val_mean_absolute_error: 0.0149
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.7790e-04 - mean_absolute_error: 0.0138 - val_loss: 3.0822e-04 - val_mean_absolute_error: 0.0134
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.7108e-04 - mean_absolute_error: 0.0129 - val_loss: 3.1537e-04 - val_mean_absolute_error: 0.0137
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.2018e-04 - mean_absolute_error: 0.0120 - val_loss: 3.0558e-04 - val_mean_absolute_error: 0.0133
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.3808e-04 - mean_absolute_error: 0.0137 - val_loss: 2.9759e-04 - val_mean_absolute_error: 0.0133
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.5009e-04 - mean_absolute_error: 0.0129 - val_loss: 2.4884e-04 - val_mean_absolute_error: 0.0114
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7246e-04 - mean_absolute_error: 0.0130 - val_loss: 2.6248e-04 - val_mean_absolute_error: 0.0120
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.3794e-04 - mean_absolute_error: 0.0141 - val_loss: 2.4790e-04 - val_mean_absolute_error: 0.0114
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.9942e-04 - mean_absolute_error: 0.0133 - val_loss: 2.4720e-04 - val_mean_absolute_error: 0.0114
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.8010e-04 - mean_absolute_error: 0.0132 - val_loss: 3.5947e-04 - val_mean_absolute_error: 0.0152
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.7747e-04 - mean_absolute_error: 0.0133 - val_loss: 3.5744e-04 - val_mean_absolute_error: 0.0150
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.8007e-04 - mean_absolute_error: 0.0129 - val_loss: 2.4862e-04 - val_mean_absolute_error: 0.0114
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.2949e-04 - mean_absolute_error: 0.0142 - val_loss: 3.0287e-04 - val_mean_absolute_error: 0.0132
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.0282e-04 - mean_absolute_error: 0.0134 - val_loss: 2.6821e-04 - val_mean_absolute_error: 0.0121
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.4151e-04 - mean_absolute_error: 0.0142 - val_loss: 2.6783e-04 - val_mean_absolute_error: 0.0121
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.5122e-04 - mean_absolute_error: 0.0127 - val_loss: 2.7796e-04 - val_mean_absolute_error: 0.0124
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.0759e-04 - mean_absolute_error: 0.0142 - val_loss: 3.4578e-04 - val_mean_absolute_error: 0.0147
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.9662e-04 - mean_absolute_error: 0.0130 - val_loss: 2.6224e-04 - val_mean_absolute_error: 0.0120
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.1800e-04 - mean_absolute_error: 0.0133 - val_loss: 4.0379e-04 - val_mean_absolute_error: 0.0164
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.9138e-04 - mean_absolute_error: 0.0137 - val_loss: 2.5229e-04 - val_mean_absolute_error: 0.0116
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.4881e-04 - mean_absolute_error: 0.0121 - val_loss: 2.6377e-04 - val_mean_absolute_error: 0.0120
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.6888e-04 - mean_absolute_error: 0.0124 - val_loss: 2.6847e-04 - val_mean_absolute_error: 0.0121
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.8860e-04 - mean_absolute_error: 0.0132 - val_loss: 2.5446e-04 - val_mean_absolute_error: 0.0117
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.4539e-04 - mean_absolute_error: 0.0123 - val_loss: 2.5087e-04 - val_mean_absolute_error: 0.0115
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.5225e-04 - mean_absolute_error: 0.0122 - val_loss: 2.7060e-04 - val_mean_absolute_error: 0.0123
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.0993e-04 - mean_absolute_error: 0.0133 - val_loss: 4.0304e-04 - val_mean_absolute_error: 0.0161
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.2575e-04 - mean_absolute_error: 0.0144 - val_loss: 3.2311e-04 - val_mean_absolute_error: 0.0138
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.1411e-04 - mean_absolute_error: 0.0138 - val_loss: 2.5331e-04 - val_mean_absolute_error: 0.0117
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.4878e-04 - mean_absolute_error: 0.0124 - val_loss: 4.1145e-04 - val_mean_absolute_error: 0.0163
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.1285e-04 - mean_absolute_error: 0.0137 - val_loss: 2.9719e-04 - val_mean_absolute_error: 0.0132
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.9684e-04 - mean_absolute_error: 0.0128 - val_loss: 3.3983e-04 - val_mean_absolute_error: 0.0146
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.4579e-04 - mean_absolute_error: 0.0125 - val_loss: 2.4700e-04 - val_mean_absolute_error: 0.0114
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.6356e-04 - mean_absolute_error: 0.0126 - val_loss: 3.4458e-04 - val_mean_absolute_error: 0.0144
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.8895e-04 - mean_absolute_error: 0.0138 - val_loss: 2.5039e-04 - val_mean_absolute_error: 0.0115
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.7052e-04 - mean_absolute_error: 0.0130 - val_loss: 2.4485e-04 - val_mean_absolute_error: 0.0113
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8632e-04 - mean_absolute_error: 0.0125 - val_loss: 3.1605e-04 - val_mean_absolute_error: 0.0138
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6562e-04 - mean_absolute_error: 0.0133 - val_loss: 3.0000e-04 - val_mean_absolute_error: 0.0131
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.2968e-04 - mean_absolute_error: 0.0145 - val_loss: 2.5287e-04 - val_mean_absolute_error: 0.0116
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.7585e-04 - mean_absolute_error: 0.0129 - val_loss: 2.4627e-04 - val_mean_absolute_error: 0.0113
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6871e-04 - mean_absolute_error: 0.0123 - val_loss: 3.1981e-04 - val_mean_absolute_error: 0.0139
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.9871e-04 - mean_absolute_error: 0.0132 - val_loss: 4.1104e-04 - val_mean_absolute_error: 0.0166
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.2415e-04 - mean_absolute_error: 0.0150 - val_loss: 2.5824e-04 - val_mean_absolute_error: 0.0118
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.5118e-04 - mean_absolute_error: 0.0120 - val_loss: 2.4928e-04 - val_mean_absolute_error: 0.0115
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.1370e-04 - mean_absolute_error: 0.0117 - val_loss: 2.6672e-04 - val_mean_absolute_error: 0.0121
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.2763e-04 - mean_absolute_error: 0.0135 - val_loss: 2.7834e-04 - val_mean_absolute_error: 0.0125
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.8705e-04 - mean_absolute_error: 0.0129 - val_loss: 3.0992e-04 - val_mean_absolute_error: 0.0136
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.1753e-04 - mean_absolute_error: 0.0139 - val_loss: 2.4492e-04 - val_mean_absolute_error: 0.0113
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.4604e-04 - mean_absolute_error: 0.0124 - val_loss: 2.4437e-04 - val_mean_absolute_error: 0.0113
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.7231e-04 - mean_absolute_error: 0.0126 - val_loss: 2.5201e-04 - val_mean_absolute_error: 0.0116
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.2202e-04 - mean_absolute_error: 0.0141 - val_loss: 2.4655e-04 - val_mean_absolute_error: 0.0114
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.7422e-04 - mean_absolute_error: 0.0153 - val_loss: 4.5832e-04 - val_mean_absolute_error: 0.0178
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.2468e-04 - mean_absolute_error: 0.0143 - val_loss: 2.4776e-04 - val_mean_absolute_error: 0.0115
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.9163e-04 - mean_absolute_error: 0.0134 - val_loss: 3.1177e-04 - val_mean_absolute_error: 0.0137
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.6779e-04 - mean_absolute_error: 0.0127 - val_loss: 2.5025e-04 - val_mean_absolute_error: 0.0116
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.9722e-04 - mean_absolute_error: 0.0136 - val_loss: 2.4895e-04 - val_mean_absolute_error: 0.0115

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1912e-04 - mean_absolute_error: 0.0129
# Test Loss: [0.00024895023670978844, 0.011484142392873764]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 102689.95825234067
# RMSE: 320.45273949888565
# MAE: 228.5023811005976
# MAPE: 2.060338014437426 %
#
# Model evalution on validate set
# MSE: 77142.32097440514
# RMSE: 277.74506471655826
# MAE: 191.97624774018595
# MAPE: 1.8436868548936547 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 844ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step

# %%
y_pred_30_days
# Out:
# array([[12769.039],
#        [12698.341],
#        [12777.38 ],
#        [12733.202],
#        [12768.313],
#        [12747.608],
#        [12762.51 ],
#        [12752.786],
#        [12759.478],
#        [12755.057],
#        [12758.059],
#        [12756.049],
#        [12757.405],
#        [12756.495],
#        [12757.108],
#        [12756.695],
#        [12756.974],
#        [12756.786],
#        [12756.912],
#        [12756.828],
#        [12756.885],
#        [12756.847],
#        [12756.872],
#        [12756.855],
#        [12756.866],
#        [12756.859],
#        [12756.865],
#        [12756.861],
#        [12756.862],
#        [12756.861],
#        [12756.862]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
