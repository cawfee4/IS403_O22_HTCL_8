# %% [markdown]
# # Model: GRU (Gated Recurrent Unit)  - Stock Token: FPT - Test/Train/Vaildation: 60/20/20
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 510.9
# - MAE: 361.37
# - MAPE: 3.13 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 1  # 6 2 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170
# ...           ...
# 2024-02-26   9700
# 2024-02-27   9640
# 2024-02-28   9890
# 2024-02-29   9950
# 2024-03-01   9990
#
# [1252 rows x 1 columns]

# %%
df.shape
# Out:
# (1252, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       6900
# 1       7100
# 2       7100
# 3       7170
# 4       7170
#         ...
# 1247    9700
# 1248    9640
# 1249    9890
# 1250    9950
# 1251    9990
# Name: close, Length: 1252, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((740, 10), (740,), (239, 10), (239,), (240, 10), (240,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(100),
        Dense(32, activation="relu"),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 100)            │        30,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,165 (133.46 KB)
#  Trainable params: 34,165 (133.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0531 - mean_absolute_error: 0.1454 - val_loss: 0.0049 - val_mean_absolute_error: 0.0603
# Epoch 2/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019 - mean_absolute_error: 0.0283 - val_loss: 9.3733e-04 - val_mean_absolute_error: 0.0216
# Epoch 3/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6694e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0011 - val_mean_absolute_error: 0.0240
# Epoch 4/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9584e-04 - mean_absolute_error: 0.0167 - val_loss: 8.7244e-04 - val_mean_absolute_error: 0.0208
# Epoch 5/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6417e-04 - mean_absolute_error: 0.0149 - val_loss: 8.6625e-04 - val_mean_absolute_error: 0.0203
# Epoch 6/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0095e-04 - mean_absolute_error: 0.0156 - val_loss: 8.7539e-04 - val_mean_absolute_error: 0.0221
# Epoch 7/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9646e-04 - mean_absolute_error: 0.0165 - val_loss: 8.0298e-04 - val_mean_absolute_error: 0.0203
# Epoch 8/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0062e-04 - mean_absolute_error: 0.0152 - val_loss: 7.7640e-04 - val_mean_absolute_error: 0.0194
# Epoch 9/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5070e-04 - mean_absolute_error: 0.0149 - val_loss: 7.8286e-04 - val_mean_absolute_error: 0.0194
# Epoch 10/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4573e-04 - mean_absolute_error: 0.0160 - val_loss: 7.6564e-04 - val_mean_absolute_error: 0.0202
# Epoch 11/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8833e-04 - mean_absolute_error: 0.0158 - val_loss: 7.9318e-04 - val_mean_absolute_error: 0.0212
# Epoch 12/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1324e-04 - mean_absolute_error: 0.0178 - val_loss: 7.4621e-04 - val_mean_absolute_error: 0.0201
# Epoch 13/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2930e-04 - mean_absolute_error: 0.0163 - val_loss: 7.0214e-04 - val_mean_absolute_error: 0.0188
# Epoch 14/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4356e-04 - mean_absolute_error: 0.0152 - val_loss: 8.2729e-04 - val_mean_absolute_error: 0.0207
# Epoch 15/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6856e-04 - mean_absolute_error: 0.0132 - val_loss: 6.6737e-04 - val_mean_absolute_error: 0.0181
# Epoch 16/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4422e-04 - mean_absolute_error: 0.0140 - val_loss: 7.5989e-04 - val_mean_absolute_error: 0.0195
# Epoch 17/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7164e-04 - mean_absolute_error: 0.0133 - val_loss: 8.6116e-04 - val_mean_absolute_error: 0.0215
# Epoch 18/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6179e-04 - mean_absolute_error: 0.0153 - val_loss: 6.5830e-04 - val_mean_absolute_error: 0.0179
# Epoch 19/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2196e-04 - mean_absolute_error: 0.0137 - val_loss: 6.6522e-04 - val_mean_absolute_error: 0.0190
# Epoch 20/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0095e-04 - mean_absolute_error: 0.0139 - val_loss: 7.0774e-04 - val_mean_absolute_error: 0.0202
# Epoch 21/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1900e-04 - mean_absolute_error: 0.0151 - val_loss: 6.2434e-04 - val_mean_absolute_error: 0.0182
# Epoch 22/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6655e-04 - mean_absolute_error: 0.0130 - val_loss: 6.3814e-04 - val_mean_absolute_error: 0.0185
# Epoch 23/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0893e-04 - mean_absolute_error: 0.0138 - val_loss: 5.9647e-04 - val_mean_absolute_error: 0.0173
# Epoch 24/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1809e-04 - mean_absolute_error: 0.0123 - val_loss: 6.3830e-04 - val_mean_absolute_error: 0.0178
# Epoch 25/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6498e-04 - mean_absolute_error: 0.0127 - val_loss: 6.1535e-04 - val_mean_absolute_error: 0.0175
# Epoch 26/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3924e-04 - mean_absolute_error: 0.0130 - val_loss: 6.1008e-04 - val_mean_absolute_error: 0.0181
# Epoch 27/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1337e-04 - mean_absolute_error: 0.0138 - val_loss: 6.9452e-04 - val_mean_absolute_error: 0.0205
# Epoch 28/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0889e-04 - mean_absolute_error: 0.0132 - val_loss: 6.2075e-04 - val_mean_absolute_error: 0.0177
# Epoch 29/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7086e-04 - mean_absolute_error: 0.0114 - val_loss: 5.6597e-04 - val_mean_absolute_error: 0.0171
# Epoch 30/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5309e-04 - mean_absolute_error: 0.0142 - val_loss: 5.6275e-04 - val_mean_absolute_error: 0.0172
# Epoch 31/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9413e-04 - mean_absolute_error: 0.0135 - val_loss: 7.5262e-04 - val_mean_absolute_error: 0.0219
# Epoch 32/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1843e-04 - mean_absolute_error: 0.0176 - val_loss: 9.8534e-04 - val_mean_absolute_error: 0.0262
# Epoch 33/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2793e-04 - mean_absolute_error: 0.0157 - val_loss: 9.9964e-04 - val_mean_absolute_error: 0.0266
# Epoch 34/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8139e-04 - mean_absolute_error: 0.0169 - val_loss: 6.2500e-04 - val_mean_absolute_error: 0.0179
# Epoch 35/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2055e-04 - mean_absolute_error: 0.0131 - val_loss: 6.4029e-04 - val_mean_absolute_error: 0.0184
# Epoch 36/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1199e-04 - mean_absolute_error: 0.0125 - val_loss: 5.6903e-04 - val_mean_absolute_error: 0.0177
# Epoch 37/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1576e-04 - mean_absolute_error: 0.0145 - val_loss: 5.7359e-04 - val_mean_absolute_error: 0.0178
# Epoch 38/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3564e-04 - mean_absolute_error: 0.0127 - val_loss: 5.2513e-04 - val_mean_absolute_error: 0.0163
# Epoch 39/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0129e-04 - mean_absolute_error: 0.0118 - val_loss: 5.6168e-04 - val_mean_absolute_error: 0.0170
# Epoch 40/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7022e-04 - mean_absolute_error: 0.0128 - val_loss: 5.2610e-04 - val_mean_absolute_error: 0.0163
# Epoch 41/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3257e-04 - mean_absolute_error: 0.0112 - val_loss: 5.1722e-04 - val_mean_absolute_error: 0.0162
# Epoch 42/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0314e-04 - mean_absolute_error: 0.0123 - val_loss: 5.2564e-04 - val_mean_absolute_error: 0.0166
# Epoch 43/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9450e-04 - mean_absolute_error: 0.0125 - val_loss: 5.4894e-04 - val_mean_absolute_error: 0.0174
# Epoch 44/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5719e-04 - mean_absolute_error: 0.0137 - val_loss: 7.9298e-04 - val_mean_absolute_error: 0.0214
# Epoch 45/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4237e-04 - mean_absolute_error: 0.0147 - val_loss: 5.2233e-04 - val_mean_absolute_error: 0.0164
# Epoch 46/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5772e-04 - mean_absolute_error: 0.0123 - val_loss: 5.0899e-04 - val_mean_absolute_error: 0.0163
# Epoch 47/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7773e-04 - mean_absolute_error: 0.0127 - val_loss: 9.3121e-04 - val_mean_absolute_error: 0.0238
# Epoch 48/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6979e-04 - mean_absolute_error: 0.0155 - val_loss: 4.9341e-04 - val_mean_absolute_error: 0.0159
# Epoch 49/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2489e-04 - mean_absolute_error: 0.0131 - val_loss: 5.1361e-04 - val_mean_absolute_error: 0.0163
# Epoch 50/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3768e-04 - mean_absolute_error: 0.0120 - val_loss: 4.9695e-04 - val_mean_absolute_error: 0.0161
# Epoch 51/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0932e-04 - mean_absolute_error: 0.0127 - val_loss: 5.6587e-04 - val_mean_absolute_error: 0.0176
# Epoch 52/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7784e-04 - mean_absolute_error: 0.0125 - val_loss: 5.8749e-04 - val_mean_absolute_error: 0.0177
# Epoch 53/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8727e-04 - mean_absolute_error: 0.0118 - val_loss: 4.8669e-04 - val_mean_absolute_error: 0.0158
# Epoch 54/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4148e-04 - mean_absolute_error: 0.0115 - val_loss: 5.4271e-04 - val_mean_absolute_error: 0.0176
# Epoch 55/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3491e-04 - mean_absolute_error: 0.0117 - val_loss: 5.0551e-04 - val_mean_absolute_error: 0.0166
# Epoch 56/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8943e-04 - mean_absolute_error: 0.0126 - val_loss: 5.3654e-04 - val_mean_absolute_error: 0.0168
# Epoch 57/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5333e-04 - mean_absolute_error: 0.0118 - val_loss: 6.8646e-04 - val_mean_absolute_error: 0.0200
# Epoch 58/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5942e-04 - mean_absolute_error: 0.0128 - val_loss: 6.1283e-04 - val_mean_absolute_error: 0.0187
# Epoch 59/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9462e-04 - mean_absolute_error: 0.0135 - val_loss: 6.7154e-04 - val_mean_absolute_error: 0.0198
# Epoch 60/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6140e-04 - mean_absolute_error: 0.0127 - val_loss: 4.7510e-04 - val_mean_absolute_error: 0.0157
# Epoch 61/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2563e-04 - mean_absolute_error: 0.0133 - val_loss: 4.7804e-04 - val_mean_absolute_error: 0.0158
# Epoch 62/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4260e-04 - mean_absolute_error: 0.0115 - val_loss: 6.2630e-04 - val_mean_absolute_error: 0.0197
# Epoch 63/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0978e-04 - mean_absolute_error: 0.0136 - val_loss: 5.3535e-04 - val_mean_absolute_error: 0.0169
# Epoch 64/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5738e-04 - mean_absolute_error: 0.0120 - val_loss: 4.7387e-04 - val_mean_absolute_error: 0.0158
# Epoch 65/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6748e-04 - mean_absolute_error: 0.0119 - val_loss: 9.3637e-04 - val_mean_absolute_error: 0.0244
# Epoch 66/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9510e-04 - mean_absolute_error: 0.0162 - val_loss: 5.0302e-04 - val_mean_absolute_error: 0.0162
# Epoch 67/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1377e-04 - mean_absolute_error: 0.0113 - val_loss: 4.7202e-04 - val_mean_absolute_error: 0.0158
# Epoch 68/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9973e-04 - mean_absolute_error: 0.0105 - val_loss: 4.8984e-04 - val_mean_absolute_error: 0.0160
# Epoch 69/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1449e-04 - mean_absolute_error: 0.0131 - val_loss: 4.7441e-04 - val_mean_absolute_error: 0.0157
# Epoch 70/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6723e-04 - mean_absolute_error: 0.0125 - val_loss: 5.7754e-04 - val_mean_absolute_error: 0.0178
# Epoch 71/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4834e-04 - mean_absolute_error: 0.0130 - val_loss: 5.3455e-04 - val_mean_absolute_error: 0.0168
# Epoch 72/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2039e-04 - mean_absolute_error: 0.0113 - val_loss: 4.9771e-04 - val_mean_absolute_error: 0.0162
# Epoch 73/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1925e-04 - mean_absolute_error: 0.0109 - val_loss: 6.2834e-04 - val_mean_absolute_error: 0.0189
# Epoch 74/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8259e-04 - mean_absolute_error: 0.0130 - val_loss: 4.9062e-04 - val_mean_absolute_error: 0.0160
# Epoch 75/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2757e-04 - mean_absolute_error: 0.0119 - val_loss: 4.7325e-04 - val_mean_absolute_error: 0.0159
# Epoch 76/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3263e-04 - mean_absolute_error: 0.0117 - val_loss: 6.2346e-04 - val_mean_absolute_error: 0.0198
# Epoch 77/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8451e-04 - mean_absolute_error: 0.0127 - val_loss: 4.6237e-04 - val_mean_absolute_error: 0.0156
# Epoch 78/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9668e-04 - mean_absolute_error: 0.0121 - val_loss: 5.8642e-04 - val_mean_absolute_error: 0.0182
# Epoch 79/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6732e-04 - mean_absolute_error: 0.0123 - val_loss: 4.8233e-04 - val_mean_absolute_error: 0.0160
# Epoch 80/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6941e-04 - mean_absolute_error: 0.0101 - val_loss: 5.5900e-04 - val_mean_absolute_error: 0.0175
# Epoch 81/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8181e-04 - mean_absolute_error: 0.0124 - val_loss: 4.7681e-04 - val_mean_absolute_error: 0.0159
# Epoch 82/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3459e-04 - mean_absolute_error: 0.0112 - val_loss: 5.5834e-04 - val_mean_absolute_error: 0.0177
# Epoch 83/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4840e-04 - mean_absolute_error: 0.0119 - val_loss: 4.6086e-04 - val_mean_absolute_error: 0.0159
# Epoch 84/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7194e-04 - mean_absolute_error: 0.0125 - val_loss: 4.5305e-04 - val_mean_absolute_error: 0.0155
# Epoch 85/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5173e-04 - mean_absolute_error: 0.0123 - val_loss: 5.4503e-04 - val_mean_absolute_error: 0.0181
# Epoch 86/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5234e-04 - mean_absolute_error: 0.0149 - val_loss: 5.4767e-04 - val_mean_absolute_error: 0.0182
# Epoch 87/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8348e-04 - mean_absolute_error: 0.0145 - val_loss: 6.1646e-04 - val_mean_absolute_error: 0.0198
# Epoch 88/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4448e-04 - mean_absolute_error: 0.0151 - val_loss: 5.3040e-04 - val_mean_absolute_error: 0.0178
# Epoch 89/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9274e-04 - mean_absolute_error: 0.0131 - val_loss: 4.6884e-04 - val_mean_absolute_error: 0.0162
# Epoch 90/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5493e-04 - mean_absolute_error: 0.0124 - val_loss: 4.8636e-04 - val_mean_absolute_error: 0.0161
# Epoch 91/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2190e-04 - mean_absolute_error: 0.0114 - val_loss: 4.6009e-04 - val_mean_absolute_error: 0.0157
# Epoch 92/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7410e-04 - mean_absolute_error: 0.0127 - val_loss: 4.5142e-04 - val_mean_absolute_error: 0.0155
# Epoch 93/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4423e-04 - mean_absolute_error: 0.0124 - val_loss: 4.5255e-04 - val_mean_absolute_error: 0.0157
# Epoch 94/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8242e-04 - mean_absolute_error: 0.0121 - val_loss: 5.3709e-04 - val_mean_absolute_error: 0.0173
# Epoch 95/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5017e-04 - mean_absolute_error: 0.0120 - val_loss: 4.5894e-04 - val_mean_absolute_error: 0.0160
# Epoch 96/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2085e-04 - mean_absolute_error: 0.0113 - val_loss: 4.5991e-04 - val_mean_absolute_error: 0.0157
# Epoch 97/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5247e-04 - mean_absolute_error: 0.0121 - val_loss: 4.8508e-04 - val_mean_absolute_error: 0.0161
# Epoch 98/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9125e-04 - mean_absolute_error: 0.0108 - val_loss: 4.5517e-04 - val_mean_absolute_error: 0.0157
# Epoch 99/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5500e-04 - mean_absolute_error: 0.0114 - val_loss: 4.9629e-04 - val_mean_absolute_error: 0.0170
# Epoch 100/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6918e-04 - mean_absolute_error: 0.0119 - val_loss: 4.4859e-04 - val_mean_absolute_error: 0.0155
# Epoch 101/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6107e-04 - mean_absolute_error: 0.0122 - val_loss: 5.2748e-04 - val_mean_absolute_error: 0.0171
# Epoch 102/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1948e-04 - mean_absolute_error: 0.0119 - val_loss: 4.8432e-04 - val_mean_absolute_error: 0.0161
# Epoch 103/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1635e-04 - mean_absolute_error: 0.0115 - val_loss: 4.6100e-04 - val_mean_absolute_error: 0.0161
# Epoch 104/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0324e-04 - mean_absolute_error: 0.0118 - val_loss: 4.7061e-04 - val_mean_absolute_error: 0.0159
# Epoch 105/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3216e-04 - mean_absolute_error: 0.0122 - val_loss: 4.4979e-04 - val_mean_absolute_error: 0.0157
# Epoch 106/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4889e-04 - mean_absolute_error: 0.0117 - val_loss: 4.5392e-04 - val_mean_absolute_error: 0.0157
# Epoch 107/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6592e-04 - mean_absolute_error: 0.0104 - val_loss: 5.7651e-04 - val_mean_absolute_error: 0.0180
# Epoch 108/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9429e-04 - mean_absolute_error: 0.0141 - val_loss: 4.5311e-04 - val_mean_absolute_error: 0.0158
# Epoch 109/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5358e-04 - mean_absolute_error: 0.0122 - val_loss: 5.7699e-04 - val_mean_absolute_error: 0.0182
# Epoch 110/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5838e-04 - mean_absolute_error: 0.0125 - val_loss: 5.9357e-04 - val_mean_absolute_error: 0.0184
# Epoch 111/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4134e-04 - mean_absolute_error: 0.0120 - val_loss: 5.6944e-04 - val_mean_absolute_error: 0.0187
# Epoch 112/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6327e-04 - mean_absolute_error: 0.0124 - val_loss: 4.6887e-04 - val_mean_absolute_error: 0.0159
# Epoch 113/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7740e-04 - mean_absolute_error: 0.0127 - val_loss: 4.7368e-04 - val_mean_absolute_error: 0.0160
# Epoch 114/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9404e-04 - mean_absolute_error: 0.0137 - val_loss: 6.6047e-04 - val_mean_absolute_error: 0.0196
# Epoch 115/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9080e-04 - mean_absolute_error: 0.0135 - val_loss: 5.2676e-04 - val_mean_absolute_error: 0.0171
# Epoch 116/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8083e-04 - mean_absolute_error: 0.0132 - val_loss: 4.5401e-04 - val_mean_absolute_error: 0.0156
# Epoch 117/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4502e-04 - mean_absolute_error: 0.0121 - val_loss: 4.7687e-04 - val_mean_absolute_error: 0.0165
# Epoch 118/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0162e-04 - mean_absolute_error: 0.0132 - val_loss: 4.9078e-04 - val_mean_absolute_error: 0.0169
# Epoch 119/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3209e-04 - mean_absolute_error: 0.0121 - val_loss: 4.5571e-04 - val_mean_absolute_error: 0.0160
# Epoch 120/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8387e-04 - mean_absolute_error: 0.0118 - val_loss: 4.6119e-04 - val_mean_absolute_error: 0.0158
# Epoch 121/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4218e-04 - mean_absolute_error: 0.0119 - val_loss: 6.2035e-04 - val_mean_absolute_error: 0.0198
# Epoch 122/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5445e-04 - mean_absolute_error: 0.0152 - val_loss: 4.4846e-04 - val_mean_absolute_error: 0.0157
# Epoch 123/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5145e-04 - mean_absolute_error: 0.0123 - val_loss: 4.5772e-04 - val_mean_absolute_error: 0.0159
# Epoch 124/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2942e-04 - mean_absolute_error: 0.0119 - val_loss: 5.1763e-04 - val_mean_absolute_error: 0.0175
# Epoch 125/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9945e-04 - mean_absolute_error: 0.0129 - val_loss: 4.6924e-04 - val_mean_absolute_error: 0.0159
# Epoch 126/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6556e-04 - mean_absolute_error: 0.0123 - val_loss: 4.5364e-04 - val_mean_absolute_error: 0.0157
# Epoch 127/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6787e-04 - mean_absolute_error: 0.0121 - val_loss: 4.6591e-04 - val_mean_absolute_error: 0.0163
# Epoch 128/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2421e-04 - mean_absolute_error: 0.0110 - val_loss: 4.8320e-04 - val_mean_absolute_error: 0.0162
# Epoch 129/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3900e-04 - mean_absolute_error: 0.0119 - val_loss: 4.6796e-04 - val_mean_absolute_error: 0.0164
# Epoch 130/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6547e-04 - mean_absolute_error: 0.0125 - val_loss: 4.4791e-04 - val_mean_absolute_error: 0.0155
# Epoch 131/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9883e-04 - mean_absolute_error: 0.0104 - val_loss: 4.5159e-04 - val_mean_absolute_error: 0.0156
# Epoch 132/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4156e-04 - mean_absolute_error: 0.0115 - val_loss: 4.5736e-04 - val_mean_absolute_error: 0.0161
# Epoch 133/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7638e-04 - mean_absolute_error: 0.0126 - val_loss: 4.5318e-04 - val_mean_absolute_error: 0.0159
# Epoch 134/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4921e-04 - mean_absolute_error: 0.0118 - val_loss: 5.2190e-04 - val_mean_absolute_error: 0.0168
# Epoch 135/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0966e-04 - mean_absolute_error: 0.0115 - val_loss: 6.1339e-04 - val_mean_absolute_error: 0.0188
# Epoch 136/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8478e-04 - mean_absolute_error: 0.0139 - val_loss: 6.9024e-04 - val_mean_absolute_error: 0.0205
# Epoch 137/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2638e-04 - mean_absolute_error: 0.0149 - val_loss: 4.8141e-04 - val_mean_absolute_error: 0.0161
# Epoch 138/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4271e-04 - mean_absolute_error: 0.0118 - val_loss: 4.5862e-04 - val_mean_absolute_error: 0.0158
# Epoch 139/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3743e-04 - mean_absolute_error: 0.0124 - val_loss: 6.8267e-04 - val_mean_absolute_error: 0.0199
# Epoch 140/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7828e-04 - mean_absolute_error: 0.0147 - val_loss: 9.0379e-04 - val_mean_absolute_error: 0.0239
# Epoch 141/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4944e-04 - mean_absolute_error: 0.0154 - val_loss: 4.6547e-04 - val_mean_absolute_error: 0.0159
# Epoch 142/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4095e-04 - mean_absolute_error: 0.0119 - val_loss: 7.0901e-04 - val_mean_absolute_error: 0.0209
# Epoch 143/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3282e-04 - mean_absolute_error: 0.0154 - val_loss: 7.4912e-04 - val_mean_absolute_error: 0.0213
# Epoch 144/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8840e-04 - mean_absolute_error: 0.0142 - val_loss: 4.5509e-04 - val_mean_absolute_error: 0.0160
# Epoch 145/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4074e-04 - mean_absolute_error: 0.0120 - val_loss: 4.6912e-04 - val_mean_absolute_error: 0.0164
# Epoch 146/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7738e-04 - mean_absolute_error: 0.0125 - val_loss: 5.4422e-04 - val_mean_absolute_error: 0.0181
# Epoch 147/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9186e-04 - mean_absolute_error: 0.0134 - val_loss: 7.4452e-04 - val_mean_absolute_error: 0.0210
# Epoch 148/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3045e-04 - mean_absolute_error: 0.0143 - val_loss: 4.7317e-04 - val_mean_absolute_error: 0.0160
# Epoch 149/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7885e-04 - mean_absolute_error: 0.0125 - val_loss: 6.0544e-04 - val_mean_absolute_error: 0.0188
# Epoch 150/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4955e-04 - mean_absolute_error: 0.0129 - val_loss: 4.7494e-04 - val_mean_absolute_error: 0.0160
# Epoch 151/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1056e-04 - mean_absolute_error: 0.0115 - val_loss: 4.5023e-04 - val_mean_absolute_error: 0.0158
# Epoch 152/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8176e-04 - mean_absolute_error: 0.0104 - val_loss: 5.2649e-04 - val_mean_absolute_error: 0.0171
# Epoch 153/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0814e-04 - mean_absolute_error: 0.0121 - val_loss: 4.6332e-04 - val_mean_absolute_error: 0.0158
# Epoch 154/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3394e-04 - mean_absolute_error: 0.0115 - val_loss: 4.9841e-04 - val_mean_absolute_error: 0.0166
# Epoch 155/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4277e-04 - mean_absolute_error: 0.0133 - val_loss: 5.1737e-04 - val_mean_absolute_error: 0.0176
# Epoch 156/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5214e-04 - mean_absolute_error: 0.0127 - val_loss: 5.0108e-04 - val_mean_absolute_error: 0.0172
# Epoch 157/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0751e-04 - mean_absolute_error: 0.0121 - val_loss: 5.4967e-04 - val_mean_absolute_error: 0.0176
# Epoch 158/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7669e-04 - mean_absolute_error: 0.0133 - val_loss: 6.1915e-04 - val_mean_absolute_error: 0.0189
# Epoch 159/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5149e-04 - mean_absolute_error: 0.0126 - val_loss: 6.6437e-04 - val_mean_absolute_error: 0.0199
# Epoch 160/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1660e-04 - mean_absolute_error: 0.0138 - val_loss: 5.4960e-04 - val_mean_absolute_error: 0.0176
# Epoch 161/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1574e-04 - mean_absolute_error: 0.0115 - val_loss: 5.0088e-04 - val_mean_absolute_error: 0.0165
# Epoch 162/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3045e-04 - mean_absolute_error: 0.0117 - val_loss: 5.2432e-04 - val_mean_absolute_error: 0.0171
# Epoch 163/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1525e-04 - mean_absolute_error: 0.0114 - val_loss: 4.4586e-04 - val_mean_absolute_error: 0.0156
# Epoch 164/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8364e-04 - mean_absolute_error: 0.0120 - val_loss: 4.5835e-04 - val_mean_absolute_error: 0.0160
# Epoch 165/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8145e-04 - mean_absolute_error: 0.0119 - val_loss: 5.2086e-04 - val_mean_absolute_error: 0.0175
# Epoch 166/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1524e-04 - mean_absolute_error: 0.0115 - val_loss: 7.0901e-04 - val_mean_absolute_error: 0.0205
# Epoch 167/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7468e-04 - mean_absolute_error: 0.0135 - val_loss: 4.9232e-04 - val_mean_absolute_error: 0.0163
# Epoch 168/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2470e-04 - mean_absolute_error: 0.0113 - val_loss: 6.7795e-04 - val_mean_absolute_error: 0.0208
# Epoch 169/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3508e-04 - mean_absolute_error: 0.0150 - val_loss: 5.2209e-04 - val_mean_absolute_error: 0.0169
# Epoch 170/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6669e-04 - mean_absolute_error: 0.0127 - val_loss: 5.4560e-04 - val_mean_absolute_error: 0.0175
# Epoch 171/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7615e-04 - mean_absolute_error: 0.0129 - val_loss: 4.5110e-04 - val_mean_absolute_error: 0.0157
# Epoch 172/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8594e-04 - mean_absolute_error: 0.0107 - val_loss: 4.5003e-04 - val_mean_absolute_error: 0.0157
# Epoch 173/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5133e-04 - mean_absolute_error: 0.0117 - val_loss: 4.5760e-04 - val_mean_absolute_error: 0.0157
# Epoch 174/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1124e-04 - mean_absolute_error: 0.0111 - val_loss: 7.7335e-04 - val_mean_absolute_error: 0.0216
# Epoch 175/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3672e-04 - mean_absolute_error: 0.0151 - val_loss: 4.4517e-04 - val_mean_absolute_error: 0.0155
# Epoch 176/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3836e-04 - mean_absolute_error: 0.0111 - val_loss: 4.4966e-04 - val_mean_absolute_error: 0.0158
# Epoch 177/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0136e-04 - mean_absolute_error: 0.0127 - val_loss: 4.5699e-04 - val_mean_absolute_error: 0.0157
# Epoch 178/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5585e-04 - mean_absolute_error: 0.0120 - val_loss: 4.5738e-04 - val_mean_absolute_error: 0.0161
# Epoch 179/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0948e-04 - mean_absolute_error: 0.0108 - val_loss: 4.7990e-04 - val_mean_absolute_error: 0.0167
# Epoch 180/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8079e-04 - mean_absolute_error: 0.0119 - val_loss: 5.0609e-04 - val_mean_absolute_error: 0.0167
# Epoch 181/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0847e-04 - mean_absolute_error: 0.0137 - val_loss: 4.8383e-04 - val_mean_absolute_error: 0.0162
# Epoch 182/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2224e-04 - mean_absolute_error: 0.0123 - val_loss: 4.5318e-04 - val_mean_absolute_error: 0.0157
# Epoch 183/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3290e-04 - mean_absolute_error: 0.0115 - val_loss: 4.5729e-04 - val_mean_absolute_error: 0.0160
# Epoch 184/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5743e-04 - mean_absolute_error: 0.0119 - val_loss: 4.5970e-04 - val_mean_absolute_error: 0.0161
# Epoch 185/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9780e-04 - mean_absolute_error: 0.0111 - val_loss: 4.7609e-04 - val_mean_absolute_error: 0.0166
# Epoch 186/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4575e-04 - mean_absolute_error: 0.0119 - val_loss: 4.6865e-04 - val_mean_absolute_error: 0.0164
# Epoch 187/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4562e-04 - mean_absolute_error: 0.0122 - val_loss: 4.7725e-04 - val_mean_absolute_error: 0.0161
# Epoch 188/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7211e-04 - mean_absolute_error: 0.0125 - val_loss: 4.6273e-04 - val_mean_absolute_error: 0.0158
# Epoch 189/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6877e-04 - mean_absolute_error: 0.0129 - val_loss: 5.0676e-04 - val_mean_absolute_error: 0.0167
# Epoch 190/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2641e-04 - mean_absolute_error: 0.0112 - val_loss: 4.4627e-04 - val_mean_absolute_error: 0.0156
# Epoch 191/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2588e-04 - mean_absolute_error: 0.0113 - val_loss: 4.7602e-04 - val_mean_absolute_error: 0.0160
# Epoch 192/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0198e-04 - mean_absolute_error: 0.0111 - val_loss: 4.8561e-04 - val_mean_absolute_error: 0.0169
# Epoch 193/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7471e-04 - mean_absolute_error: 0.0130 - val_loss: 5.5274e-04 - val_mean_absolute_error: 0.0177
# Epoch 194/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3227e-04 - mean_absolute_error: 0.0121 - val_loss: 5.2921e-04 - val_mean_absolute_error: 0.0179
# Epoch 195/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9697e-04 - mean_absolute_error: 0.0178 - val_loss: 5.3016e-04 - val_mean_absolute_error: 0.0178
# Epoch 196/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4973e-04 - mean_absolute_error: 0.0159 - val_loss: 4.5898e-04 - val_mean_absolute_error: 0.0158
# Epoch 197/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1788e-04 - mean_absolute_error: 0.0110 - val_loss: 4.4457e-04 - val_mean_absolute_error: 0.0155
# Epoch 198/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6846e-04 - mean_absolute_error: 0.0133 - val_loss: 4.7137e-04 - val_mean_absolute_error: 0.0160
# Epoch 199/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0931e-04 - mean_absolute_error: 0.0113 - val_loss: 4.4743e-04 - val_mean_absolute_error: 0.0157
# Epoch 200/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4582e-04 - mean_absolute_error: 0.0113 - val_loss: 4.5460e-04 - val_mean_absolute_error: 0.0157

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step - loss: 6.1926e-04 - mean_absolute_error: 0.0187
# Test Loss: [0.0004546047712210566, 0.015714868903160095]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 239
# 250

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 261017.43207235215
# RMSE: 510.89865146851986
# MAE: 361.37246257191424
# MAPE: 3.1300469902199977 %
#
# Model evalution on validate set
# MSE: 62203.955590482554
# RMSE: 249.40720837714886
# MAE: 186.2534952799479
# MAPE: 1.7352382428981863 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
y_pred_30_days
# Out:
# array([[10029.52 ],
#        [10019.928],
#        [10030.788],
#        [10027.553],
#        [10030.379],
#        [10029.333],
#        [10029.967],
#        [10029.676],
#        [10029.838],
#        [10029.76 ],
#        [10029.802],
#        [10029.781],
#        [10029.792],
#        [10029.787],
#        [10029.789],
#        [10029.788],
#        [10029.788],
#        [10029.788],
#        [10029.788],
#        [10029.788],
#        [10029.788],
#        [10029.788],
#        [10029.788],
#        [10029.788],
#        [10029.788],
#        [10029.788],
#        [10029.788],
#        [10029.788],
#        [10029.788],
#        [10029.788],
#        [10029.788]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
