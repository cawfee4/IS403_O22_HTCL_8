# %% [markdown]
# # Model: GRU (Gated Recurrent Unit)  - Stock Token: FPT - Test/Train/Vaildation: 60/20/20
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 510.9
# - MAE: 361.37
# - MAPE: 3.13 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 1  # 6 2 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170
# ...           ...
# 2024-05-27  11300
# 2024-05-28  12050
# 2024-05-29  12600
# 2024-05-30  12500
# 2024-05-31  12700
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        6900
# 1        7100
# 2        7100
# 3        7170
# 4        7170
#         ...
# 1308    11300
# 1309    12050
# 1310    12600
# 1311    12500
# 1312    12700
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((776, 10), (776,), (251, 10), (251,), (253, 10), (253,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(100),
        Dense(32, activation="relu"),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 100)            │        30,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,165 (133.46 KB)
#  Trainable params: 34,165 (133.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 0.0779 - mean_absolute_error: 0.1869 - val_loss: 0.0011 - val_mean_absolute_error: 0.0277
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0029 - mean_absolute_error: 0.0394 - val_loss: 5.9296e-04 - val_mean_absolute_error: 0.0172
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.7054e-04 - mean_absolute_error: 0.0198 - val_loss: 5.7409e-04 - val_mean_absolute_error: 0.0171
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 7.2770e-04 - mean_absolute_error: 0.0167 - val_loss: 5.9154e-04 - val_mean_absolute_error: 0.0179
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.2463e-04 - mean_absolute_error: 0.0155 - val_loss: 5.6481e-04 - val_mean_absolute_error: 0.0172
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 7.5805e-04 - mean_absolute_error: 0.0166 - val_loss: 5.1472e-04 - val_mean_absolute_error: 0.0161
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 6.8346e-04 - mean_absolute_error: 0.0164 - val_loss: 4.9921e-04 - val_mean_absolute_error: 0.0160
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 6.7121e-04 - mean_absolute_error: 0.0154 - val_loss: 5.0533e-04 - val_mean_absolute_error: 0.0162
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.5079e-04 - mean_absolute_error: 0.0158 - val_loss: 5.1635e-04 - val_mean_absolute_error: 0.0167
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 6.1848e-04 - mean_absolute_error: 0.0145 - val_loss: 4.8980e-04 - val_mean_absolute_error: 0.0161
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.0785e-04 - mean_absolute_error: 0.0160 - val_loss: 5.2816e-04 - val_mean_absolute_error: 0.0172
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 6.1964e-04 - mean_absolute_error: 0.0155 - val_loss: 4.8109e-04 - val_mean_absolute_error: 0.0161
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.2775e-04 - mean_absolute_error: 0.0160 - val_loss: 4.6237e-04 - val_mean_absolute_error: 0.0157
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.4400e-04 - mean_absolute_error: 0.0141 - val_loss: 4.2335e-04 - val_mean_absolute_error: 0.0148
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.2861e-04 - mean_absolute_error: 0.0144 - val_loss: 4.4114e-04 - val_mean_absolute_error: 0.0153
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.4365e-04 - mean_absolute_error: 0.0132 - val_loss: 4.1060e-04 - val_mean_absolute_error: 0.0146
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.0791e-04 - mean_absolute_error: 0.0140 - val_loss: 7.6402e-04 - val_mean_absolute_error: 0.0228
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.8780e-04 - mean_absolute_error: 0.0160 - val_loss: 6.5506e-04 - val_mean_absolute_error: 0.0206
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.3511e-04 - mean_absolute_error: 0.0168 - val_loss: 4.7389e-04 - val_mean_absolute_error: 0.0166
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.9794e-04 - mean_absolute_error: 0.0147 - val_loss: 4.1252e-04 - val_mean_absolute_error: 0.0148
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.7082e-04 - mean_absolute_error: 0.0142 - val_loss: 3.8384e-04 - val_mean_absolute_error: 0.0142
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.4494e-04 - mean_absolute_error: 0.0131 - val_loss: 4.7230e-04 - val_mean_absolute_error: 0.0165
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.4361e-04 - mean_absolute_error: 0.0153 - val_loss: 3.8029e-04 - val_mean_absolute_error: 0.0141
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.9773e-04 - mean_absolute_error: 0.0163 - val_loss: 4.1249e-04 - val_mean_absolute_error: 0.0150
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.4683e-04 - mean_absolute_error: 0.0150 - val_loss: 3.6758e-04 - val_mean_absolute_error: 0.0139
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.8827e-04 - mean_absolute_error: 0.0140 - val_loss: 3.9605e-04 - val_mean_absolute_error: 0.0147
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.8849e-04 - mean_absolute_error: 0.0141 - val_loss: 6.5919e-04 - val_mean_absolute_error: 0.0209
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.2323e-04 - mean_absolute_error: 0.0154 - val_loss: 4.8957e-04 - val_mean_absolute_error: 0.0173
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.9211e-04 - mean_absolute_error: 0.0143 - val_loss: 4.0827e-04 - val_mean_absolute_error: 0.0153
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.7529e-04 - mean_absolute_error: 0.0139 - val_loss: 3.5680e-04 - val_mean_absolute_error: 0.0137
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.4246e-04 - mean_absolute_error: 0.0135 - val_loss: 4.1435e-04 - val_mean_absolute_error: 0.0152
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.3152e-04 - mean_absolute_error: 0.0150 - val_loss: 3.4996e-04 - val_mean_absolute_error: 0.0136
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.3232e-04 - mean_absolute_error: 0.0152 - val_loss: 3.5981e-04 - val_mean_absolute_error: 0.0138
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.7566e-04 - mean_absolute_error: 0.0141 - val_loss: 3.4825e-04 - val_mean_absolute_error: 0.0136
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.3204e-04 - mean_absolute_error: 0.0131 - val_loss: 4.1184e-04 - val_mean_absolute_error: 0.0154
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5821e-04 - mean_absolute_error: 0.0136 - val_loss: 3.7311e-04 - val_mean_absolute_error: 0.0143
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.6062e-04 - mean_absolute_error: 0.0122 - val_loss: 3.6229e-04 - val_mean_absolute_error: 0.0139
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.7305e-04 - mean_absolute_error: 0.0134 - val_loss: 3.3996e-04 - val_mean_absolute_error: 0.0135
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.1622e-04 - mean_absolute_error: 0.0128 - val_loss: 3.6322e-04 - val_mean_absolute_error: 0.0141
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.6630e-04 - mean_absolute_error: 0.0133 - val_loss: 3.8484e-04 - val_mean_absolute_error: 0.0147
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.0118e-04 - mean_absolute_error: 0.0125 - val_loss: 3.3706e-04 - val_mean_absolute_error: 0.0134
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.3573e-04 - mean_absolute_error: 0.0134 - val_loss: 3.4217e-04 - val_mean_absolute_error: 0.0135
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.3327e-04 - mean_absolute_error: 0.0129 - val_loss: 3.8862e-04 - val_mean_absolute_error: 0.0149
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.1769e-04 - mean_absolute_error: 0.0134 - val_loss: 3.3945e-04 - val_mean_absolute_error: 0.0134
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.4267e-04 - mean_absolute_error: 0.0140 - val_loss: 5.6011e-04 - val_mean_absolute_error: 0.0192
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.7276e-04 - mean_absolute_error: 0.0153 - val_loss: 3.8903e-04 - val_mean_absolute_error: 0.0149
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.4243e-04 - mean_absolute_error: 0.0133 - val_loss: 3.3744e-04 - val_mean_absolute_error: 0.0135
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.7937e-04 - mean_absolute_error: 0.0138 - val_loss: 4.6345e-04 - val_mean_absolute_error: 0.0169
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.0377e-04 - mean_absolute_error: 0.0153 - val_loss: 5.0026e-04 - val_mean_absolute_error: 0.0178
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.4302e-04 - mean_absolute_error: 0.0141 - val_loss: 3.7227e-04 - val_mean_absolute_error: 0.0146
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.9680e-04 - mean_absolute_error: 0.0126 - val_loss: 3.3070e-04 - val_mean_absolute_error: 0.0132
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.6297e-04 - mean_absolute_error: 0.0120 - val_loss: 3.6033e-04 - val_mean_absolute_error: 0.0142
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.2002e-04 - mean_absolute_error: 0.0132 - val_loss: 3.4444e-04 - val_mean_absolute_error: 0.0137
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9981e-04 - mean_absolute_error: 0.0122 - val_loss: 3.5482e-04 - val_mean_absolute_error: 0.0141
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.9881e-04 - mean_absolute_error: 0.0125 - val_loss: 3.1990e-04 - val_mean_absolute_error: 0.0130
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9843e-04 - mean_absolute_error: 0.0119 - val_loss: 3.2408e-04 - val_mean_absolute_error: 0.0131
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.2201e-04 - mean_absolute_error: 0.0131 - val_loss: 5.2790e-04 - val_mean_absolute_error: 0.0184
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.0486e-04 - mean_absolute_error: 0.0173 - val_loss: 6.0276e-04 - val_mean_absolute_error: 0.0199
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.3602e-04 - mean_absolute_error: 0.0143 - val_loss: 4.1939e-04 - val_mean_absolute_error: 0.0159
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.6636e-04 - mean_absolute_error: 0.0135 - val_loss: 3.3479e-04 - val_mean_absolute_error: 0.0136
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.0175e-04 - mean_absolute_error: 0.0130 - val_loss: 4.1089e-04 - val_mean_absolute_error: 0.0158
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.3758e-04 - mean_absolute_error: 0.0145 - val_loss: 3.2087e-04 - val_mean_absolute_error: 0.0131
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.5501e-04 - mean_absolute_error: 0.0140 - val_loss: 3.5785e-04 - val_mean_absolute_error: 0.0141
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.6155e-04 - mean_absolute_error: 0.0118 - val_loss: 3.1606e-04 - val_mean_absolute_error: 0.0130
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.2730e-04 - mean_absolute_error: 0.0113 - val_loss: 3.1554e-04 - val_mean_absolute_error: 0.0130
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.4739e-04 - mean_absolute_error: 0.0138 - val_loss: 3.3869e-04 - val_mean_absolute_error: 0.0137
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.3816e-04 - mean_absolute_error: 0.0140 - val_loss: 3.1484e-04 - val_mean_absolute_error: 0.0130
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.5363e-04 - mean_absolute_error: 0.0119 - val_loss: 3.5431e-04 - val_mean_absolute_error: 0.0143
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.0870e-04 - mean_absolute_error: 0.0132 - val_loss: 5.2687e-04 - val_mean_absolute_error: 0.0184
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.4247e-04 - mean_absolute_error: 0.0138 - val_loss: 3.2000e-04 - val_mean_absolute_error: 0.0131
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.1732e-04 - mean_absolute_error: 0.0110 - val_loss: 3.2227e-04 - val_mean_absolute_error: 0.0132
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.5825e-04 - mean_absolute_error: 0.0130 - val_loss: 3.4730e-04 - val_mean_absolute_error: 0.0139
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.5482e-04 - mean_absolute_error: 0.0116 - val_loss: 3.1376e-04 - val_mean_absolute_error: 0.0130
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.3824e-04 - mean_absolute_error: 0.0137 - val_loss: 5.2281e-04 - val_mean_absolute_error: 0.0185
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.9543e-04 - mean_absolute_error: 0.0139 - val_loss: 3.4314e-04 - val_mean_absolute_error: 0.0138
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.6756e-04 - mean_absolute_error: 0.0126 - val_loss: 3.9154e-04 - val_mean_absolute_error: 0.0152
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.3985e-04 - mean_absolute_error: 0.0125 - val_loss: 3.6779e-04 - val_mean_absolute_error: 0.0146
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.7374e-04 - mean_absolute_error: 0.0127 - val_loss: 6.1413e-04 - val_mean_absolute_error: 0.0203
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.2307e-04 - mean_absolute_error: 0.0142 - val_loss: 3.4188e-04 - val_mean_absolute_error: 0.0138
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.5997e-04 - mean_absolute_error: 0.0121 - val_loss: 3.3022e-04 - val_mean_absolute_error: 0.0135
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.3947e-04 - mean_absolute_error: 0.0114 - val_loss: 3.1084e-04 - val_mean_absolute_error: 0.0130
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.1825e-04 - mean_absolute_error: 0.0127 - val_loss: 3.0885e-04 - val_mean_absolute_error: 0.0129
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8367e-04 - mean_absolute_error: 0.0129 - val_loss: 3.3496e-04 - val_mean_absolute_error: 0.0136
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.4026e-04 - mean_absolute_error: 0.0124 - val_loss: 3.3582e-04 - val_mean_absolute_error: 0.0137
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.4736e-04 - mean_absolute_error: 0.0114 - val_loss: 4.2823e-04 - val_mean_absolute_error: 0.0162
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.6950e-04 - mean_absolute_error: 0.0132 - val_loss: 3.2902e-04 - val_mean_absolute_error: 0.0135
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.0143e-04 - mean_absolute_error: 0.0130 - val_loss: 3.1135e-04 - val_mean_absolute_error: 0.0130
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.5873e-04 - mean_absolute_error: 0.0115 - val_loss: 3.1763e-04 - val_mean_absolute_error: 0.0132
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.6262e-04 - mean_absolute_error: 0.0118 - val_loss: 3.3161e-04 - val_mean_absolute_error: 0.0136
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9177e-04 - mean_absolute_error: 0.0123 - val_loss: 3.1474e-04 - val_mean_absolute_error: 0.0131
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.8190e-04 - mean_absolute_error: 0.0125 - val_loss: 3.4459e-04 - val_mean_absolute_error: 0.0140
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.9816e-04 - mean_absolute_error: 0.0135 - val_loss: 4.4029e-04 - val_mean_absolute_error: 0.0165
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.8986e-04 - mean_absolute_error: 0.0129 - val_loss: 3.2920e-04 - val_mean_absolute_error: 0.0139
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.4425e-04 - mean_absolute_error: 0.0119 - val_loss: 3.1874e-04 - val_mean_absolute_error: 0.0133
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.4493e-04 - mean_absolute_error: 0.0117 - val_loss: 3.0981e-04 - val_mean_absolute_error: 0.0132
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.7365e-04 - mean_absolute_error: 0.0141 - val_loss: 3.3203e-04 - val_mean_absolute_error: 0.0136
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.5790e-04 - mean_absolute_error: 0.0124 - val_loss: 3.1192e-04 - val_mean_absolute_error: 0.0131
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.3060e-04 - mean_absolute_error: 0.0113 - val_loss: 3.2318e-04 - val_mean_absolute_error: 0.0134
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.8742e-04 - mean_absolute_error: 0.0107 - val_loss: 4.8445e-04 - val_mean_absolute_error: 0.0178
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.1541e-04 - mean_absolute_error: 0.0164 - val_loss: 3.7136e-04 - val_mean_absolute_error: 0.0147
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.0446e-04 - mean_absolute_error: 0.0134 - val_loss: 4.8883e-04 - val_mean_absolute_error: 0.0176
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.8658e-04 - mean_absolute_error: 0.0131 - val_loss: 3.1100e-04 - val_mean_absolute_error: 0.0134
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.0593e-04 - mean_absolute_error: 0.0133 - val_loss: 4.7934e-04 - val_mean_absolute_error: 0.0177
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.2103e-04 - mean_absolute_error: 0.0135 - val_loss: 3.0900e-04 - val_mean_absolute_error: 0.0131
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.3944e-04 - mean_absolute_error: 0.0133 - val_loss: 3.1607e-04 - val_mean_absolute_error: 0.0133
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.8507e-04 - mean_absolute_error: 0.0128 - val_loss: 4.4310e-04 - val_mean_absolute_error: 0.0164
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9412e-04 - mean_absolute_error: 0.0128 - val_loss: 3.0851e-04 - val_mean_absolute_error: 0.0131
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.7316e-04 - mean_absolute_error: 0.0125 - val_loss: 3.3241e-04 - val_mean_absolute_error: 0.0141
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.6651e-04 - mean_absolute_error: 0.0125 - val_loss: 3.1049e-04 - val_mean_absolute_error: 0.0133
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.0939e-04 - mean_absolute_error: 0.0118 - val_loss: 3.0837e-04 - val_mean_absolute_error: 0.0131
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.5794e-04 - mean_absolute_error: 0.0140 - val_loss: 3.3375e-04 - val_mean_absolute_error: 0.0141
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7721e-04 - mean_absolute_error: 0.0120 - val_loss: 3.5876e-04 - val_mean_absolute_error: 0.0143
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.3742e-04 - mean_absolute_error: 0.0114 - val_loss: 3.1521e-04 - val_mean_absolute_error: 0.0135
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.8241e-04 - mean_absolute_error: 0.0126 - val_loss: 3.6969e-04 - val_mean_absolute_error: 0.0151
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.1543e-04 - mean_absolute_error: 0.0133 - val_loss: 3.0621e-04 - val_mean_absolute_error: 0.0131
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.5111e-04 - mean_absolute_error: 0.0146 - val_loss: 3.7618e-04 - val_mean_absolute_error: 0.0152
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.1686e-04 - mean_absolute_error: 0.0139 - val_loss: 3.1779e-04 - val_mean_absolute_error: 0.0135
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.4349e-04 - mean_absolute_error: 0.0122 - val_loss: 3.2065e-04 - val_mean_absolute_error: 0.0137
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.5312e-04 - mean_absolute_error: 0.0121 - val_loss: 3.1951e-04 - val_mean_absolute_error: 0.0134
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.0329e-04 - mean_absolute_error: 0.0133 - val_loss: 3.7227e-04 - val_mean_absolute_error: 0.0147
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.7015e-04 - mean_absolute_error: 0.0120 - val_loss: 3.4528e-04 - val_mean_absolute_error: 0.0140
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.3220e-04 - mean_absolute_error: 0.0115 - val_loss: 3.8367e-04 - val_mean_absolute_error: 0.0150
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.8934e-04 - mean_absolute_error: 0.0137 - val_loss: 7.1184e-04 - val_mean_absolute_error: 0.0221
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.3808e-04 - mean_absolute_error: 0.0168 - val_loss: 7.7068e-04 - val_mean_absolute_error: 0.0234
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.9279e-04 - mean_absolute_error: 0.0158 - val_loss: 3.9578e-04 - val_mean_absolute_error: 0.0153
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.3813e-04 - mean_absolute_error: 0.0123 - val_loss: 3.1997e-04 - val_mean_absolute_error: 0.0134
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.5068e-04 - mean_absolute_error: 0.0121 - val_loss: 3.7990e-04 - val_mean_absolute_error: 0.0149
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.7643e-04 - mean_absolute_error: 0.0127 - val_loss: 3.0838e-04 - val_mean_absolute_error: 0.0131
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.5797e-04 - mean_absolute_error: 0.0126 - val_loss: 4.3504e-04 - val_mean_absolute_error: 0.0164
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7320e-04 - mean_absolute_error: 0.0128 - val_loss: 3.0884e-04 - val_mean_absolute_error: 0.0132
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8391e-04 - mean_absolute_error: 0.0120 - val_loss: 3.1335e-04 - val_mean_absolute_error: 0.0132
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.8364e-04 - mean_absolute_error: 0.0123 - val_loss: 3.2795e-04 - val_mean_absolute_error: 0.0139
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8423e-04 - mean_absolute_error: 0.0132 - val_loss: 3.1928e-04 - val_mean_absolute_error: 0.0134
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.3479e-04 - mean_absolute_error: 0.0116 - val_loss: 3.7532e-04 - val_mean_absolute_error: 0.0152
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.9678e-04 - mean_absolute_error: 0.0127 - val_loss: 3.3988e-04 - val_mean_absolute_error: 0.0139
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.2299e-04 - mean_absolute_error: 0.0136 - val_loss: 6.1049e-04 - val_mean_absolute_error: 0.0201
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.6570e-04 - mean_absolute_error: 0.0160 - val_loss: 4.8942e-04 - val_mean_absolute_error: 0.0176
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.3284e-04 - mean_absolute_error: 0.0144 - val_loss: 3.3494e-04 - val_mean_absolute_error: 0.0138
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.6753e-04 - mean_absolute_error: 0.0125 - val_loss: 3.7326e-04 - val_mean_absolute_error: 0.0147
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.4228e-04 - mean_absolute_error: 0.0117 - val_loss: 4.3565e-04 - val_mean_absolute_error: 0.0163
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.0499e-04 - mean_absolute_error: 0.0136 - val_loss: 3.6569e-04 - val_mean_absolute_error: 0.0149
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.1826e-04 - mean_absolute_error: 0.0128 - val_loss: 3.4770e-04 - val_mean_absolute_error: 0.0141
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.5359e-04 - mean_absolute_error: 0.0121 - val_loss: 4.1828e-04 - val_mean_absolute_error: 0.0162
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.9238e-04 - mean_absolute_error: 0.0148 - val_loss: 3.1329e-04 - val_mean_absolute_error: 0.0134
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.5269e-04 - mean_absolute_error: 0.0132 - val_loss: 3.1971e-04 - val_mean_absolute_error: 0.0134
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.1356e-04 - mean_absolute_error: 0.0132 - val_loss: 3.6660e-04 - val_mean_absolute_error: 0.0146
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.6954e-04 - mean_absolute_error: 0.0119 - val_loss: 3.1134e-04 - val_mean_absolute_error: 0.0132
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.7992e-04 - mean_absolute_error: 0.0125 - val_loss: 3.1166e-04 - val_mean_absolute_error: 0.0132
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.7940e-04 - mean_absolute_error: 0.0122 - val_loss: 3.2240e-04 - val_mean_absolute_error: 0.0137
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.5834e-04 - mean_absolute_error: 0.0124 - val_loss: 4.0676e-04 - val_mean_absolute_error: 0.0156
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.0331e-04 - mean_absolute_error: 0.0112 - val_loss: 3.3257e-04 - val_mean_absolute_error: 0.0137
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.2346e-04 - mean_absolute_error: 0.0114 - val_loss: 3.3629e-04 - val_mean_absolute_error: 0.0138
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.1907e-04 - mean_absolute_error: 0.0112 - val_loss: 3.6155e-04 - val_mean_absolute_error: 0.0144
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.9979e-04 - mean_absolute_error: 0.0126 - val_loss: 3.5627e-04 - val_mean_absolute_error: 0.0143
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.0013e-04 - mean_absolute_error: 0.0136 - val_loss: 3.5933e-04 - val_mean_absolute_error: 0.0144
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8812e-04 - mean_absolute_error: 0.0122 - val_loss: 3.9769e-04 - val_mean_absolute_error: 0.0157
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.1426e-04 - mean_absolute_error: 0.0131 - val_loss: 3.7411e-04 - val_mean_absolute_error: 0.0151
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.3988e-04 - mean_absolute_error: 0.0120 - val_loss: 3.2309e-04 - val_mean_absolute_error: 0.0138
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.5725e-04 - mean_absolute_error: 0.0123 - val_loss: 3.5345e-04 - val_mean_absolute_error: 0.0146
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.9100e-04 - mean_absolute_error: 0.0127 - val_loss: 3.2070e-04 - val_mean_absolute_error: 0.0137
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.3727e-04 - mean_absolute_error: 0.0123 - val_loss: 4.4052e-04 - val_mean_absolute_error: 0.0165
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.9166e-04 - mean_absolute_error: 0.0163 - val_loss: 6.0040e-04 - val_mean_absolute_error: 0.0200
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.2366e-04 - mean_absolute_error: 0.0145 - val_loss: 4.3769e-04 - val_mean_absolute_error: 0.0163
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.1999e-04 - mean_absolute_error: 0.0135 - val_loss: 3.2487e-04 - val_mean_absolute_error: 0.0135
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.5197e-04 - mean_absolute_error: 0.0117 - val_loss: 4.0501e-04 - val_mean_absolute_error: 0.0155
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.8300e-04 - mean_absolute_error: 0.0124 - val_loss: 3.7867e-04 - val_mean_absolute_error: 0.0149
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.8233e-04 - mean_absolute_error: 0.0133 - val_loss: 3.1225e-04 - val_mean_absolute_error: 0.0134
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.7280e-04 - mean_absolute_error: 0.0121 - val_loss: 3.1112e-04 - val_mean_absolute_error: 0.0133
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.3254e-04 - mean_absolute_error: 0.0116 - val_loss: 3.1001e-04 - val_mean_absolute_error: 0.0132
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.7780e-04 - mean_absolute_error: 0.0125 - val_loss: 3.1415e-04 - val_mean_absolute_error: 0.0133
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9834e-04 - mean_absolute_error: 0.0128 - val_loss: 3.6834e-04 - val_mean_absolute_error: 0.0150
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.9017e-04 - mean_absolute_error: 0.0125 - val_loss: 3.2207e-04 - val_mean_absolute_error: 0.0137
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.6162e-04 - mean_absolute_error: 0.0125 - val_loss: 3.0981e-04 - val_mean_absolute_error: 0.0132
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.7039e-04 - mean_absolute_error: 0.0124 - val_loss: 3.1239e-04 - val_mean_absolute_error: 0.0132
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.6675e-04 - mean_absolute_error: 0.0126 - val_loss: 4.7421e-04 - val_mean_absolute_error: 0.0172
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.5855e-04 - mean_absolute_error: 0.0130 - val_loss: 5.7123e-04 - val_mean_absolute_error: 0.0193
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.5827e-04 - mean_absolute_error: 0.0150 - val_loss: 3.8049e-04 - val_mean_absolute_error: 0.0150
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.0790e-04 - mean_absolute_error: 0.0134 - val_loss: 3.1323e-04 - val_mean_absolute_error: 0.0132
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.4848e-04 - mean_absolute_error: 0.0119 - val_loss: 3.1697e-04 - val_mean_absolute_error: 0.0133
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.3437e-04 - mean_absolute_error: 0.0114 - val_loss: 6.1889e-04 - val_mean_absolute_error: 0.0203
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.4419e-04 - mean_absolute_error: 0.0143 - val_loss: 3.5464e-04 - val_mean_absolute_error: 0.0142
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.6821e-04 - mean_absolute_error: 0.0126 - val_loss: 3.7958e-04 - val_mean_absolute_error: 0.0153
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.0373e-04 - mean_absolute_error: 0.0155 - val_loss: 6.9816e-04 - val_mean_absolute_error: 0.0218
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.4882e-04 - mean_absolute_error: 0.0138 - val_loss: 3.5404e-04 - val_mean_absolute_error: 0.0143
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.4728e-04 - mean_absolute_error: 0.0121 - val_loss: 3.7293e-04 - val_mean_absolute_error: 0.0147
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.7764e-04 - mean_absolute_error: 0.0125 - val_loss: 3.1622e-04 - val_mean_absolute_error: 0.0135
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.4719e-04 - mean_absolute_error: 0.0128 - val_loss: 3.8055e-04 - val_mean_absolute_error: 0.0149
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.2700e-04 - mean_absolute_error: 0.0114 - val_loss: 3.1287e-04 - val_mean_absolute_error: 0.0134
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.4419e-04 - mean_absolute_error: 0.0133 - val_loss: 3.1879e-04 - val_mean_absolute_error: 0.0134
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.0074e-04 - mean_absolute_error: 0.0125 - val_loss: 3.1796e-04 - val_mean_absolute_error: 0.0135
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.5247e-04 - mean_absolute_error: 0.0123 - val_loss: 3.1661e-04 - val_mean_absolute_error: 0.0134
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.6108e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1834e-04 - val_mean_absolute_error: 0.0136
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.1473e-04 - mean_absolute_error: 0.0125 - val_loss: 3.1528e-04 - val_mean_absolute_error: 0.0132
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.7015e-04 - mean_absolute_error: 0.0131 - val_loss: 3.7019e-04 - val_mean_absolute_error: 0.0147
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7510e-04 - mean_absolute_error: 0.0122 - val_loss: 4.0536e-04 - val_mean_absolute_error: 0.0156
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.4735e-04 - mean_absolute_error: 0.0135 - val_loss: 3.4860e-04 - val_mean_absolute_error: 0.0141
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.0688e-04 - mean_absolute_error: 0.0112 - val_loss: 3.0821e-04 - val_mean_absolute_error: 0.0131
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.4775e-04 - mean_absolute_error: 0.0118 - val_loss: 3.4066e-04 - val_mean_absolute_error: 0.0139
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.5730e-04 - mean_absolute_error: 0.0119 - val_loss: 3.7226e-04 - val_mean_absolute_error: 0.0147
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.1075e-04 - mean_absolute_error: 0.0133 - val_loss: 4.1438e-04 - val_mean_absolute_error: 0.0158

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7738e-04 - mean_absolute_error: 0.0166
# Test Loss: [0.0004143792320974171, 0.015801552683115005]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 190202.85322318514
# RMSE: 436.12252088511224
# MAE: 326.1382905876494
# MAPE: 3.0066213432148663 %
#
# Model evalution on validate set
# MSE: 95234.50584895244
# RMSE: 308.6008843943135
# MAE: 243.80894500370553
# MAPE: 2.3144465478935685 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step

# %%
y_pred_30_days
# Out:
# array([[12956.794 ],
#        [12831.822 ],
#        [12973.505 ],
#        [12881.35  ],
#        [12959.192 ],
#        [12907.845 ],
#        [12947.669 ],
#        [12918.83  ],
#        [12940.385 ],
#        [12924.669 ],
#        [12936.328 ],
#        [12927.753 ],
#        [12934.086 ],
#        [12929.421 ],
#        [12932.863 ],
#        [12930.325 ],
#        [12932.196 ],
#        [12930.816 ],
#        [12931.834 ],
#        [12931.085 ],
#        [12931.637 ],
#        [12931.2295],
#        [12931.53  ],
#        [12931.31  ],
#        [12931.472 ],
#        [12931.352 ],
#        [12931.441 ],
#        [12931.376 ],
#        [12931.424 ],
#        [12931.388 ],
#        [12931.415 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
