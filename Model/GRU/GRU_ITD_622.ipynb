# %% [markdown]
# # Model: GRU (Gated Recurrent Unit)  - Stock Token: FPT - Test/Train/Vaildation: 60/20/20
# - Dataset: 1313 rows x 7 columns (01/03/2019 - 31/05/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 411.55
# - MAE: 296.56
# - MAPE: 2.72 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

plt.style.use("default")

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 1  # 6 2 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170
# ...           ...
# 2024-05-27  11300
# 2024-05-28  12050
# 2024-05-29  12600
# 2024-05-30  12500
# 2024-05-31  12700
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        6900
# 1        7100
# 2        7100
# 3        7170
# 4        7170
#         ...
# 1308    11300
# 1309    12050
# 1310    12600
# 1311    12500
# 1312    12700
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((776, 10), (776,), (251, 10), (251,), (253, 10), (253,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(100),
        Dense(32, activation="relu"),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_2 (GRU)                     │ (None, 100)            │        30,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,165 (133.46 KB)
#  Trainable params: 34,165 (133.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0737 - mean_absolute_error: 0.1864 - val_loss: 8.1453e-04 - val_mean_absolute_error: 0.0224
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mean_absolute_error: 0.0429 - val_loss: 9.6884e-04 - val_mean_absolute_error: 0.0253
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0010 - mean_absolute_error: 0.0215 - val_loss: 5.6234e-04 - val_mean_absolute_error: 0.0171
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6167e-04 - mean_absolute_error: 0.0172 - val_loss: 5.5579e-04 - val_mean_absolute_error: 0.0172
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1343e-04 - mean_absolute_error: 0.0149 - val_loss: 5.7091e-04 - val_mean_absolute_error: 0.0178
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3967e-04 - mean_absolute_error: 0.0162 - val_loss: 4.9511e-04 - val_mean_absolute_error: 0.0159
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5808e-04 - mean_absolute_error: 0.0157 - val_loss: 4.7259e-04 - val_mean_absolute_error: 0.0154
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5116e-04 - mean_absolute_error: 0.0138 - val_loss: 6.2964e-04 - val_mean_absolute_error: 0.0196
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1163e-04 - mean_absolute_error: 0.0165 - val_loss: 4.4397e-04 - val_mean_absolute_error: 0.0150
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5658e-04 - mean_absolute_error: 0.0160 - val_loss: 4.9365e-04 - val_mean_absolute_error: 0.0164
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6774e-04 - mean_absolute_error: 0.0147 - val_loss: 4.4412e-04 - val_mean_absolute_error: 0.0154
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6906e-04 - mean_absolute_error: 0.0162 - val_loss: 4.1249e-04 - val_mean_absolute_error: 0.0146
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2987e-04 - mean_absolute_error: 0.0171 - val_loss: 4.0782e-04 - val_mean_absolute_error: 0.0146
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1750e-04 - mean_absolute_error: 0.0152 - val_loss: 5.2646e-04 - val_mean_absolute_error: 0.0176
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1845e-04 - mean_absolute_error: 0.0159 - val_loss: 3.9806e-04 - val_mean_absolute_error: 0.0144
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0630e-04 - mean_absolute_error: 0.0156 - val_loss: 3.9901e-04 - val_mean_absolute_error: 0.0145
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4787e-04 - mean_absolute_error: 0.0145 - val_loss: 3.8666e-04 - val_mean_absolute_error: 0.0143
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9512e-04 - mean_absolute_error: 0.0149 - val_loss: 4.3697e-04 - val_mean_absolute_error: 0.0155
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5905e-04 - mean_absolute_error: 0.0132 - val_loss: 3.9328e-04 - val_mean_absolute_error: 0.0146
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6474e-04 - mean_absolute_error: 0.0133 - val_loss: 4.0939e-04 - val_mean_absolute_error: 0.0149
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5771e-04 - mean_absolute_error: 0.0135 - val_loss: 3.6594e-04 - val_mean_absolute_error: 0.0139
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4654e-04 - mean_absolute_error: 0.0134 - val_loss: 3.8067e-04 - val_mean_absolute_error: 0.0142
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4015e-04 - mean_absolute_error: 0.0139 - val_loss: 4.6117e-04 - val_mean_absolute_error: 0.0164
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6042e-04 - mean_absolute_error: 0.0135 - val_loss: 3.6558e-04 - val_mean_absolute_error: 0.0139
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1395e-04 - mean_absolute_error: 0.0126 - val_loss: 5.6948e-04 - val_mean_absolute_error: 0.0192
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9204e-04 - mean_absolute_error: 0.0147 - val_loss: 3.5822e-04 - val_mean_absolute_error: 0.0137
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9728e-04 - mean_absolute_error: 0.0144 - val_loss: 6.0566e-04 - val_mean_absolute_error: 0.0200
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2629e-04 - mean_absolute_error: 0.0157 - val_loss: 3.4549e-04 - val_mean_absolute_error: 0.0135
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8677e-04 - mean_absolute_error: 0.0140 - val_loss: 3.9650e-04 - val_mean_absolute_error: 0.0149
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8734e-04 - mean_absolute_error: 0.0149 - val_loss: 3.9328e-04 - val_mean_absolute_error: 0.0149
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1078e-04 - mean_absolute_error: 0.0127 - val_loss: 5.2839e-04 - val_mean_absolute_error: 0.0182
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1789e-04 - mean_absolute_error: 0.0130 - val_loss: 3.4602e-04 - val_mean_absolute_error: 0.0135
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8935e-04 - mean_absolute_error: 0.0140 - val_loss: 3.9285e-04 - val_mean_absolute_error: 0.0149
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1103e-04 - mean_absolute_error: 0.0126 - val_loss: 3.3910e-04 - val_mean_absolute_error: 0.0135
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0057e-04 - mean_absolute_error: 0.0124 - val_loss: 4.0224e-04 - val_mean_absolute_error: 0.0153
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5327e-04 - mean_absolute_error: 0.0184 - val_loss: 9.3089e-04 - val_mean_absolute_error: 0.0259
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0425e-04 - mean_absolute_error: 0.0169 - val_loss: 3.3533e-04 - val_mean_absolute_error: 0.0133
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4278e-04 - mean_absolute_error: 0.0149 - val_loss: 3.8119e-04 - val_mean_absolute_error: 0.0147
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9439e-04 - mean_absolute_error: 0.0144 - val_loss: 3.7694e-04 - val_mean_absolute_error: 0.0146
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0029e-04 - mean_absolute_error: 0.0124 - val_loss: 3.5459e-04 - val_mean_absolute_error: 0.0139
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9839e-04 - mean_absolute_error: 0.0146 - val_loss: 3.7632e-04 - val_mean_absolute_error: 0.0146
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6064e-04 - mean_absolute_error: 0.0150 - val_loss: 3.2799e-04 - val_mean_absolute_error: 0.0131
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1179e-04 - mean_absolute_error: 0.0134 - val_loss: 4.2417e-04 - val_mean_absolute_error: 0.0159
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1987e-04 - mean_absolute_error: 0.0132 - val_loss: 3.2913e-04 - val_mean_absolute_error: 0.0133
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0546e-04 - mean_absolute_error: 0.0130 - val_loss: 3.2777e-04 - val_mean_absolute_error: 0.0132
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6798e-04 - mean_absolute_error: 0.0122 - val_loss: 3.3174e-04 - val_mean_absolute_error: 0.0133
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9165e-04 - mean_absolute_error: 0.0125 - val_loss: 3.2170e-04 - val_mean_absolute_error: 0.0131
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0412e-04 - mean_absolute_error: 0.0131 - val_loss: 4.1173e-04 - val_mean_absolute_error: 0.0155
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6327e-04 - mean_absolute_error: 0.0141 - val_loss: 3.3058e-04 - val_mean_absolute_error: 0.0133
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8020e-04 - mean_absolute_error: 0.0122 - val_loss: 5.0425e-04 - val_mean_absolute_error: 0.0181
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0603e-04 - mean_absolute_error: 0.0153 - val_loss: 3.2760e-04 - val_mean_absolute_error: 0.0134
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9532e-04 - mean_absolute_error: 0.0126 - val_loss: 3.2241e-04 - val_mean_absolute_error: 0.0131
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0021e-04 - mean_absolute_error: 0.0127 - val_loss: 3.2609e-04 - val_mean_absolute_error: 0.0132
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5585e-04 - mean_absolute_error: 0.0117 - val_loss: 3.2087e-04 - val_mean_absolute_error: 0.0131
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7937e-04 - mean_absolute_error: 0.0121 - val_loss: 6.6334e-04 - val_mean_absolute_error: 0.0212
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7266e-04 - mean_absolute_error: 0.0182 - val_loss: 4.7925e-04 - val_mean_absolute_error: 0.0173
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9775e-04 - mean_absolute_error: 0.0147 - val_loss: 4.2318e-04 - val_mean_absolute_error: 0.0162
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1892e-04 - mean_absolute_error: 0.0140 - val_loss: 3.1995e-04 - val_mean_absolute_error: 0.0131
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7241e-04 - mean_absolute_error: 0.0124 - val_loss: 4.2226e-04 - val_mean_absolute_error: 0.0159
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3895e-04 - mean_absolute_error: 0.0141 - val_loss: 3.1974e-04 - val_mean_absolute_error: 0.0131
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8333e-04 - mean_absolute_error: 0.0119 - val_loss: 3.1421e-04 - val_mean_absolute_error: 0.0130
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0711e-04 - mean_absolute_error: 0.0115 - val_loss: 3.1712e-04 - val_mean_absolute_error: 0.0131
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3579e-04 - mean_absolute_error: 0.0129 - val_loss: 3.2387e-04 - val_mean_absolute_error: 0.0134
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4303e-04 - mean_absolute_error: 0.0117 - val_loss: 3.3164e-04 - val_mean_absolute_error: 0.0135
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3733e-04 - mean_absolute_error: 0.0121 - val_loss: 3.1206e-04 - val_mean_absolute_error: 0.0130
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6735e-04 - mean_absolute_error: 0.0121 - val_loss: 3.5401e-04 - val_mean_absolute_error: 0.0142
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1468e-04 - mean_absolute_error: 0.0133 - val_loss: 3.5339e-04 - val_mean_absolute_error: 0.0144
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4405e-04 - mean_absolute_error: 0.0136 - val_loss: 3.1182e-04 - val_mean_absolute_error: 0.0130
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6406e-04 - mean_absolute_error: 0.0122 - val_loss: 3.1446e-04 - val_mean_absolute_error: 0.0133
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1870e-04 - mean_absolute_error: 0.0129 - val_loss: 3.1839e-04 - val_mean_absolute_error: 0.0133
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3864e-04 - mean_absolute_error: 0.0135 - val_loss: 5.1380e-04 - val_mean_absolute_error: 0.0180
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0123e-04 - mean_absolute_error: 0.0149 - val_loss: 3.1276e-04 - val_mean_absolute_error: 0.0130
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0160e-04 - mean_absolute_error: 0.0126 - val_loss: 3.6999e-04 - val_mean_absolute_error: 0.0150
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9254e-04 - mean_absolute_error: 0.0136 - val_loss: 3.2249e-04 - val_mean_absolute_error: 0.0135
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1587e-04 - mean_absolute_error: 0.0134 - val_loss: 3.1439e-04 - val_mean_absolute_error: 0.0131
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5568e-04 - mean_absolute_error: 0.0123 - val_loss: 3.0811e-04 - val_mean_absolute_error: 0.0130
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4291e-04 - mean_absolute_error: 0.0117 - val_loss: 3.1156e-04 - val_mean_absolute_error: 0.0130
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4040e-04 - mean_absolute_error: 0.0114 - val_loss: 3.6018e-04 - val_mean_absolute_error: 0.0144
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7588e-04 - mean_absolute_error: 0.0129 - val_loss: 4.1008e-04 - val_mean_absolute_error: 0.0157
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7056e-04 - mean_absolute_error: 0.0123 - val_loss: 3.1431e-04 - val_mean_absolute_error: 0.0131
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5523e-04 - mean_absolute_error: 0.0121 - val_loss: 3.1102e-04 - val_mean_absolute_error: 0.0130
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8688e-04 - mean_absolute_error: 0.0130 - val_loss: 3.1215e-04 - val_mean_absolute_error: 0.0131
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4117e-04 - mean_absolute_error: 0.0119 - val_loss: 3.0976e-04 - val_mean_absolute_error: 0.0130
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2180e-04 - mean_absolute_error: 0.0131 - val_loss: 3.0996e-04 - val_mean_absolute_error: 0.0132
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5596e-04 - mean_absolute_error: 0.0131 - val_loss: 3.0898e-04 - val_mean_absolute_error: 0.0130
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4968e-04 - mean_absolute_error: 0.0138 - val_loss: 3.2163e-04 - val_mean_absolute_error: 0.0137
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4298e-04 - mean_absolute_error: 0.0140 - val_loss: 4.7393e-04 - val_mean_absolute_error: 0.0172
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7968e-04 - mean_absolute_error: 0.0129 - val_loss: 4.0384e-04 - val_mean_absolute_error: 0.0156
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2371e-04 - mean_absolute_error: 0.0138 - val_loss: 3.2244e-04 - val_mean_absolute_error: 0.0136
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1325e-04 - mean_absolute_error: 0.0141 - val_loss: 4.3126e-04 - val_mean_absolute_error: 0.0162
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6007e-04 - mean_absolute_error: 0.0119 - val_loss: 6.1765e-04 - val_mean_absolute_error: 0.0202
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9957e-04 - mean_absolute_error: 0.0154 - val_loss: 3.1125e-04 - val_mean_absolute_error: 0.0131
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4935e-04 - mean_absolute_error: 0.0118 - val_loss: 3.1626e-04 - val_mean_absolute_error: 0.0132
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8364e-04 - mean_absolute_error: 0.0125 - val_loss: 3.1470e-04 - val_mean_absolute_error: 0.0132
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6677e-04 - mean_absolute_error: 0.0117 - val_loss: 3.4253e-04 - val_mean_absolute_error: 0.0139
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7511e-04 - mean_absolute_error: 0.0129 - val_loss: 3.4120e-04 - val_mean_absolute_error: 0.0138
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6021e-04 - mean_absolute_error: 0.0124 - val_loss: 3.4079e-04 - val_mean_absolute_error: 0.0142
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8006e-04 - mean_absolute_error: 0.0128 - val_loss: 4.9402e-04 - val_mean_absolute_error: 0.0177
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4424e-04 - mean_absolute_error: 0.0136 - val_loss: 3.7323e-04 - val_mean_absolute_error: 0.0151
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0509e-04 - mean_absolute_error: 0.0129 - val_loss: 3.1620e-04 - val_mean_absolute_error: 0.0132
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6368e-04 - mean_absolute_error: 0.0126 - val_loss: 4.4600e-04 - val_mean_absolute_error: 0.0166
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3666e-04 - mean_absolute_error: 0.0119 - val_loss: 3.5871e-04 - val_mean_absolute_error: 0.0148
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0229e-04 - mean_absolute_error: 0.0130 - val_loss: 3.2465e-04 - val_mean_absolute_error: 0.0134
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2482e-04 - mean_absolute_error: 0.0113 - val_loss: 3.1008e-04 - val_mean_absolute_error: 0.0132
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7044e-04 - mean_absolute_error: 0.0124 - val_loss: 3.9615e-04 - val_mean_absolute_error: 0.0153
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5724e-04 - mean_absolute_error: 0.0120 - val_loss: 3.1723e-04 - val_mean_absolute_error: 0.0135
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8682e-04 - mean_absolute_error: 0.0129 - val_loss: 3.8586e-04 - val_mean_absolute_error: 0.0151
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7725e-04 - mean_absolute_error: 0.0152 - val_loss: 4.9259e-04 - val_mean_absolute_error: 0.0177
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6495e-04 - mean_absolute_error: 0.0156 - val_loss: 3.1493e-04 - val_mean_absolute_error: 0.0132
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4990e-04 - mean_absolute_error: 0.0128 - val_loss: 3.3365e-04 - val_mean_absolute_error: 0.0139
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5456e-04 - mean_absolute_error: 0.0129 - val_loss: 3.2015e-04 - val_mean_absolute_error: 0.0134
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8739e-04 - mean_absolute_error: 0.0125 - val_loss: 3.1380e-04 - val_mean_absolute_error: 0.0132
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5333e-04 - mean_absolute_error: 0.0118 - val_loss: 3.1099e-04 - val_mean_absolute_error: 0.0132
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7427e-04 - mean_absolute_error: 0.0121 - val_loss: 3.1430e-04 - val_mean_absolute_error: 0.0132
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1185e-04 - mean_absolute_error: 0.0112 - val_loss: 3.2731e-04 - val_mean_absolute_error: 0.0135
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4213e-04 - mean_absolute_error: 0.0116 - val_loss: 3.1131e-04 - val_mean_absolute_error: 0.0132
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8152e-04 - mean_absolute_error: 0.0151 - val_loss: 4.3207e-04 - val_mean_absolute_error: 0.0166
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1221e-04 - mean_absolute_error: 0.0141 - val_loss: 3.9373e-04 - val_mean_absolute_error: 0.0153
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1996e-04 - mean_absolute_error: 0.0154 - val_loss: 3.2657e-04 - val_mean_absolute_error: 0.0135
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4257e-04 - mean_absolute_error: 0.0119 - val_loss: 3.1102e-04 - val_mean_absolute_error: 0.0132
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5101e-04 - mean_absolute_error: 0.0123 - val_loss: 3.2137e-04 - val_mean_absolute_error: 0.0134
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0807e-04 - mean_absolute_error: 0.0128 - val_loss: 3.4740e-04 - val_mean_absolute_error: 0.0145
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5781e-04 - mean_absolute_error: 0.0120 - val_loss: 3.0981e-04 - val_mean_absolute_error: 0.0132
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5266e-04 - mean_absolute_error: 0.0136 - val_loss: 3.0763e-04 - val_mean_absolute_error: 0.0132
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9743e-04 - mean_absolute_error: 0.0136 - val_loss: 3.3900e-04 - val_mean_absolute_error: 0.0139
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2079e-04 - mean_absolute_error: 0.0118 - val_loss: 3.4590e-04 - val_mean_absolute_error: 0.0144
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5667e-04 - mean_absolute_error: 0.0148 - val_loss: 3.3835e-04 - val_mean_absolute_error: 0.0142
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4248e-04 - mean_absolute_error: 0.0124 - val_loss: 3.1773e-04 - val_mean_absolute_error: 0.0134
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5141e-04 - mean_absolute_error: 0.0125 - val_loss: 3.5638e-04 - val_mean_absolute_error: 0.0143
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6967e-04 - mean_absolute_error: 0.0125 - val_loss: 3.2729e-04 - val_mean_absolute_error: 0.0136
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4014e-04 - mean_absolute_error: 0.0122 - val_loss: 3.0667e-04 - val_mean_absolute_error: 0.0131
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5823e-04 - mean_absolute_error: 0.0118 - val_loss: 3.1164e-04 - val_mean_absolute_error: 0.0132
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9056e-04 - mean_absolute_error: 0.0123 - val_loss: 3.0958e-04 - val_mean_absolute_error: 0.0131
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2902e-04 - mean_absolute_error: 0.0116 - val_loss: 3.1633e-04 - val_mean_absolute_error: 0.0133
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7331e-04 - mean_absolute_error: 0.0129 - val_loss: 3.1804e-04 - val_mean_absolute_error: 0.0136
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9551e-04 - mean_absolute_error: 0.0129 - val_loss: 3.1084e-04 - val_mean_absolute_error: 0.0133
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6795e-04 - mean_absolute_error: 0.0128 - val_loss: 3.7670e-04 - val_mean_absolute_error: 0.0149
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8817e-04 - mean_absolute_error: 0.0132 - val_loss: 4.2413e-04 - val_mean_absolute_error: 0.0160
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7947e-04 - mean_absolute_error: 0.0128 - val_loss: 3.2423e-04 - val_mean_absolute_error: 0.0137
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1185e-04 - mean_absolute_error: 0.0139 - val_loss: 4.4478e-04 - val_mean_absolute_error: 0.0165
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7630e-04 - mean_absolute_error: 0.0131 - val_loss: 3.1388e-04 - val_mean_absolute_error: 0.0134
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5765e-04 - mean_absolute_error: 0.0121 - val_loss: 3.6282e-04 - val_mean_absolute_error: 0.0149
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7692e-04 - mean_absolute_error: 0.0124 - val_loss: 3.5428e-04 - val_mean_absolute_error: 0.0143
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3304e-04 - mean_absolute_error: 0.0116 - val_loss: 3.1756e-04 - val_mean_absolute_error: 0.0133
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2782e-04 - mean_absolute_error: 0.0134 - val_loss: 3.1221e-04 - val_mean_absolute_error: 0.0134
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9682e-04 - mean_absolute_error: 0.0138 - val_loss: 3.0737e-04 - val_mean_absolute_error: 0.0132
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8240e-04 - mean_absolute_error: 0.0154 - val_loss: 3.9887e-04 - val_mean_absolute_error: 0.0155
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7121e-04 - mean_absolute_error: 0.0132 - val_loss: 3.1701e-04 - val_mean_absolute_error: 0.0133
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5701e-04 - mean_absolute_error: 0.0125 - val_loss: 3.3109e-04 - val_mean_absolute_error: 0.0141
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1490e-04 - mean_absolute_error: 0.0132 - val_loss: 3.1271e-04 - val_mean_absolute_error: 0.0132
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0799e-04 - mean_absolute_error: 0.0136 - val_loss: 4.1734e-04 - val_mean_absolute_error: 0.0158
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8636e-04 - mean_absolute_error: 0.0133 - val_loss: 3.1241e-04 - val_mean_absolute_error: 0.0132
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5485e-04 - mean_absolute_error: 0.0114 - val_loss: 3.1653e-04 - val_mean_absolute_error: 0.0135
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6923e-04 - mean_absolute_error: 0.0121 - val_loss: 5.2096e-04 - val_mean_absolute_error: 0.0182
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7789e-04 - mean_absolute_error: 0.0133 - val_loss: 3.6436e-04 - val_mean_absolute_error: 0.0145
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5308e-04 - mean_absolute_error: 0.0119 - val_loss: 3.1634e-04 - val_mean_absolute_error: 0.0133
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7225e-04 - mean_absolute_error: 0.0117 - val_loss: 3.7852e-04 - val_mean_absolute_error: 0.0149
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4918e-04 - mean_absolute_error: 0.0127 - val_loss: 3.6952e-04 - val_mean_absolute_error: 0.0147
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1376e-04 - mean_absolute_error: 0.0138 - val_loss: 3.5495e-04 - val_mean_absolute_error: 0.0142
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4546e-04 - mean_absolute_error: 0.0118 - val_loss: 3.4951e-04 - val_mean_absolute_error: 0.0145
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0416e-04 - mean_absolute_error: 0.0160 - val_loss: 3.1598e-04 - val_mean_absolute_error: 0.0136
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9306e-04 - mean_absolute_error: 0.0126 - val_loss: 3.6763e-04 - val_mean_absolute_error: 0.0150
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3862e-04 - mean_absolute_error: 0.0143 - val_loss: 3.9199e-04 - val_mean_absolute_error: 0.0152
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6357e-04 - mean_absolute_error: 0.0133 - val_loss: 4.4824e-04 - val_mean_absolute_error: 0.0166
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5371e-04 - mean_absolute_error: 0.0130 - val_loss: 3.8123e-04 - val_mean_absolute_error: 0.0150
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7595e-04 - mean_absolute_error: 0.0129 - val_loss: 3.5808e-04 - val_mean_absolute_error: 0.0143
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6544e-04 - mean_absolute_error: 0.0126 - val_loss: 5.3177e-04 - val_mean_absolute_error: 0.0185
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8278e-04 - mean_absolute_error: 0.0156 - val_loss: 3.5996e-04 - val_mean_absolute_error: 0.0144
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4608e-04 - mean_absolute_error: 0.0121 - val_loss: 3.1568e-04 - val_mean_absolute_error: 0.0133
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4428e-04 - mean_absolute_error: 0.0124 - val_loss: 3.1673e-04 - val_mean_absolute_error: 0.0136
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9315e-04 - mean_absolute_error: 0.0127 - val_loss: 3.5014e-04 - val_mean_absolute_error: 0.0146
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0417e-04 - mean_absolute_error: 0.0133 - val_loss: 5.0759e-04 - val_mean_absolute_error: 0.0180
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6956e-04 - mean_absolute_error: 0.0133 - val_loss: 3.5325e-04 - val_mean_absolute_error: 0.0143
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3850e-04 - mean_absolute_error: 0.0122 - val_loss: 3.5077e-04 - val_mean_absolute_error: 0.0142
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5541e-04 - mean_absolute_error: 0.0123 - val_loss: 3.1668e-04 - val_mean_absolute_error: 0.0135
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6183e-04 - mean_absolute_error: 0.0119 - val_loss: 3.4128e-04 - val_mean_absolute_error: 0.0142
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5619e-04 - mean_absolute_error: 0.0128 - val_loss: 4.7680e-04 - val_mean_absolute_error: 0.0172
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7018e-04 - mean_absolute_error: 0.0151 - val_loss: 5.1005e-04 - val_mean_absolute_error: 0.0180
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6638e-04 - mean_absolute_error: 0.0142 - val_loss: 3.0852e-04 - val_mean_absolute_error: 0.0131
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9550e-04 - mean_absolute_error: 0.0122 - val_loss: 3.5947e-04 - val_mean_absolute_error: 0.0144
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1503e-04 - mean_absolute_error: 0.0137 - val_loss: 4.4200e-04 - val_mean_absolute_error: 0.0164
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4504e-04 - mean_absolute_error: 0.0122 - val_loss: 4.4221e-04 - val_mean_absolute_error: 0.0165
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0205e-04 - mean_absolute_error: 0.0138 - val_loss: 3.2302e-04 - val_mean_absolute_error: 0.0138
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5150e-04 - mean_absolute_error: 0.0121 - val_loss: 3.7653e-04 - val_mean_absolute_error: 0.0152
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6336e-04 - mean_absolute_error: 0.0122 - val_loss: 3.4048e-04 - val_mean_absolute_error: 0.0142
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7073e-04 - mean_absolute_error: 0.0125 - val_loss: 3.9882e-04 - val_mean_absolute_error: 0.0154
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3449e-04 - mean_absolute_error: 0.0122 - val_loss: 3.4336e-04 - val_mean_absolute_error: 0.0140
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4624e-04 - mean_absolute_error: 0.0117 - val_loss: 3.1158e-04 - val_mean_absolute_error: 0.0133
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9257e-04 - mean_absolute_error: 0.0112 - val_loss: 3.3777e-04 - val_mean_absolute_error: 0.0142
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2349e-04 - mean_absolute_error: 0.0134 - val_loss: 4.5849e-04 - val_mean_absolute_error: 0.0168
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2340e-04 - mean_absolute_error: 0.0141 - val_loss: 4.2985e-04 - val_mean_absolute_error: 0.0162
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3790e-04 - mean_absolute_error: 0.0160 - val_loss: 3.2341e-04 - val_mean_absolute_error: 0.0135
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5367e-04 - mean_absolute_error: 0.0143 - val_loss: 3.5255e-04 - val_mean_absolute_error: 0.0146
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0972e-04 - mean_absolute_error: 0.0130 - val_loss: 3.2936e-04 - val_mean_absolute_error: 0.0140
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0690e-04 - mean_absolute_error: 0.0135 - val_loss: 3.6186e-04 - val_mean_absolute_error: 0.0144
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9429e-04 - mean_absolute_error: 0.0138 - val_loss: 4.1096e-04 - val_mean_absolute_error: 0.0157
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9035e-04 - mean_absolute_error: 0.0173 - val_loss: 7.2015e-04 - val_mean_absolute_error: 0.0224
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5618e-04 - mean_absolute_error: 0.0167 - val_loss: 3.7384e-04 - val_mean_absolute_error: 0.0151
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3190e-04 - mean_absolute_error: 0.0143 - val_loss: 3.0923e-04 - val_mean_absolute_error: 0.0132
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1366e-04 - mean_absolute_error: 0.0113 - val_loss: 3.3364e-04 - val_mean_absolute_error: 0.0137

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9051e-04 - mean_absolute_error: 0.0146
# Test Loss: [0.0003336374938953668, 0.013689005747437477]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 169370.21871625664
# RMSE: 411.546131941799
# MAE: 296.56399013321715
# MAPE: 2.7250190238546943 %
#
# Model evalution on validate set
# MSE: 76378.6821369729
# RMSE: 276.3669338704848
# MAE: 201.86054841897234
# MAPE: 1.91208761355828 %

# %% [markdown]
# ## 4. Forecast the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
y_pred_30_days
# Out:
# array([[12845.251 ],
#        [12754.657 ],
#        [12852.231 ],
#        [12794.585 ],
#        [12839.749 ],
#        [12812.128 ],
#        [12832.054 ],
#        [12818.737 ],
#        [12827.97  ],
#        [12821.737 ],
#        [12826.022 ],
#        [12823.1045],
#        [12825.101 ],
#        [12823.738 ],
#        [12824.67  ],
#        [12824.033 ],
#        [12824.469 ],
#        [12824.172 ],
#        [12824.375 ],
#        [12824.235 ],
#        [12824.331 ],
#        [12824.266 ],
#        [12824.311 ],
#        [12824.28  ],
#        [12824.301 ],
#        [12824.287 ],
#        [12824.297 ],
#        [12824.29  ],
#        [12824.295 ],
#        [12824.292 ],
#        [12824.294 ]], dtype=float32)

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(16, 9))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
