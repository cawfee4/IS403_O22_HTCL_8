# %% [markdown]
# # Model: GRU (Gated Recurrent Unit)  - Stock Token: FPT - Test/Train/Vaildation: 80/10/10
# - Dataset: 1313 rows x 7 columns (01/03/2019 - 31/05/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 267.89
# - MAE: 192.0015
# - MAPE: 1.79 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

plt.style.use("default")

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 2  # 8 1 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170
# ...           ...
# 2024-05-27  11300
# 2024-05-28  12050
# 2024-05-29  12600
# 2024-05-30  12500
# 2024-05-31  12700
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        6900
# 1        7100
# 2        7100
# 3        7170
# 4        7170
#         ...
# 1308    11300
# 1309    12050
# 1310    12600
# 1311    12500
# 1312    12700
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((1039, 10), (1039,), (120, 10), (120,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(100),
        Dense(32, activation="relu"),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 100)            │        30,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,165 (133.46 KB)
#  Trainable params: 34,165 (133.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0282 - mean_absolute_error: 0.1184 - val_loss: 0.0017 - val_mean_absolute_error: 0.0388
# Epoch 2/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6810e-04 - mean_absolute_error: 0.0230 - val_loss: 4.3276e-04 - val_mean_absolute_error: 0.0179
# Epoch 3/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5702e-04 - mean_absolute_error: 0.0180 - val_loss: 1.8679e-04 - val_mean_absolute_error: 0.0096
# Epoch 4/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3971e-04 - mean_absolute_error: 0.0162 - val_loss: 1.8817e-04 - val_mean_absolute_error: 0.0099
# Epoch 5/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8661e-04 - mean_absolute_error: 0.0155 - val_loss: 1.8202e-04 - val_mean_absolute_error: 0.0095
# Epoch 6/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9010e-04 - mean_absolute_error: 0.0153 - val_loss: 2.2220e-04 - val_mean_absolute_error: 0.0113
# Epoch 7/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0516e-04 - mean_absolute_error: 0.0169 - val_loss: 1.6875e-04 - val_mean_absolute_error: 0.0091
# Epoch 8/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8250e-04 - mean_absolute_error: 0.0151 - val_loss: 1.7821e-04 - val_mean_absolute_error: 0.0097
# Epoch 9/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8578e-04 - mean_absolute_error: 0.0161 - val_loss: 2.1681e-04 - val_mean_absolute_error: 0.0111
# Epoch 10/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0404e-04 - mean_absolute_error: 0.0153 - val_loss: 1.6388e-04 - val_mean_absolute_error: 0.0090
# Epoch 11/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6770e-04 - mean_absolute_error: 0.0170 - val_loss: 1.9249e-04 - val_mean_absolute_error: 0.0105
# Epoch 12/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1837e-04 - mean_absolute_error: 0.0132 - val_loss: 3.2968e-04 - val_mean_absolute_error: 0.0156
# Epoch 13/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6928e-04 - mean_absolute_error: 0.0142 - val_loss: 1.7011e-04 - val_mean_absolute_error: 0.0094
# Epoch 14/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7623e-04 - mean_absolute_error: 0.0141 - val_loss: 2.3759e-04 - val_mean_absolute_error: 0.0124
# Epoch 15/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4241e-04 - mean_absolute_error: 0.0158 - val_loss: 1.6717e-04 - val_mean_absolute_error: 0.0093
# Epoch 16/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1403e-04 - mean_absolute_error: 0.0149 - val_loss: 1.6228e-04 - val_mean_absolute_error: 0.0090
# Epoch 17/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6075e-04 - mean_absolute_error: 0.0139 - val_loss: 1.5746e-04 - val_mean_absolute_error: 0.0088
# Epoch 18/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7795e-04 - mean_absolute_error: 0.0141 - val_loss: 4.7287e-04 - val_mean_absolute_error: 0.0195
# Epoch 19/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1116e-04 - mean_absolute_error: 0.0159 - val_loss: 1.5528e-04 - val_mean_absolute_error: 0.0088
# Epoch 20/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9651e-04 - mean_absolute_error: 0.0152 - val_loss: 1.9576e-04 - val_mean_absolute_error: 0.0105
# Epoch 21/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9225e-04 - mean_absolute_error: 0.0149 - val_loss: 1.6593e-04 - val_mean_absolute_error: 0.0092
# Epoch 22/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5146e-04 - mean_absolute_error: 0.0139 - val_loss: 1.5642e-04 - val_mean_absolute_error: 0.0087
# Epoch 23/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6297e-04 - mean_absolute_error: 0.0141 - val_loss: 1.6142e-04 - val_mean_absolute_error: 0.0090
# Epoch 24/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5890e-04 - mean_absolute_error: 0.0141 - val_loss: 2.1486e-04 - val_mean_absolute_error: 0.0116
# Epoch 25/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7162e-04 - mean_absolute_error: 0.0124 - val_loss: 1.6660e-04 - val_mean_absolute_error: 0.0094
# Epoch 26/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0127e-04 - mean_absolute_error: 0.0131 - val_loss: 3.5523e-04 - val_mean_absolute_error: 0.0164
# Epoch 27/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2678e-04 - mean_absolute_error: 0.0143 - val_loss: 1.5104e-04 - val_mean_absolute_error: 0.0086
# Epoch 28/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0520e-04 - mean_absolute_error: 0.0129 - val_loss: 1.5717e-04 - val_mean_absolute_error: 0.0088
# Epoch 29/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1339e-04 - mean_absolute_error: 0.0133 - val_loss: 1.5311e-04 - val_mean_absolute_error: 0.0087
# Epoch 30/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9488e-04 - mean_absolute_error: 0.0149 - val_loss: 1.5529e-04 - val_mean_absolute_error: 0.0088
# Epoch 31/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9253e-04 - mean_absolute_error: 0.0130 - val_loss: 1.8303e-04 - val_mean_absolute_error: 0.0102
# Epoch 32/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7682e-04 - mean_absolute_error: 0.0127 - val_loss: 1.7809e-04 - val_mean_absolute_error: 0.0100
# Epoch 33/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2400e-04 - mean_absolute_error: 0.0143 - val_loss: 1.5548e-04 - val_mean_absolute_error: 0.0088
# Epoch 34/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2300e-04 - mean_absolute_error: 0.0119 - val_loss: 4.9455e-04 - val_mean_absolute_error: 0.0200
# Epoch 35/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6402e-04 - mean_absolute_error: 0.0151 - val_loss: 2.0399e-04 - val_mean_absolute_error: 0.0112
# Epoch 36/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0387e-04 - mean_absolute_error: 0.0133 - val_loss: 1.7489e-04 - val_mean_absolute_error: 0.0098
# Epoch 37/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5540e-04 - mean_absolute_error: 0.0122 - val_loss: 3.8259e-04 - val_mean_absolute_error: 0.0171
# Epoch 38/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2968e-04 - mean_absolute_error: 0.0142 - val_loss: 1.8714e-04 - val_mean_absolute_error: 0.0104
# Epoch 39/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4008e-04 - mean_absolute_error: 0.0124 - val_loss: 1.4831e-04 - val_mean_absolute_error: 0.0086
# Epoch 40/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2531e-04 - mean_absolute_error: 0.0138 - val_loss: 1.5577e-04 - val_mean_absolute_error: 0.0090
# Epoch 41/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3602e-04 - mean_absolute_error: 0.0135 - val_loss: 1.8107e-04 - val_mean_absolute_error: 0.0101
# Epoch 42/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1522e-04 - mean_absolute_error: 0.0114 - val_loss: 1.6586e-04 - val_mean_absolute_error: 0.0094
# Epoch 43/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4743e-04 - mean_absolute_error: 0.0123 - val_loss: 3.2654e-04 - val_mean_absolute_error: 0.0155
# Epoch 44/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5643e-04 - mean_absolute_error: 0.0153 - val_loss: 1.4888e-04 - val_mean_absolute_error: 0.0086
# Epoch 45/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7063e-04 - mean_absolute_error: 0.0126 - val_loss: 2.4114e-04 - val_mean_absolute_error: 0.0127
# Epoch 46/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4187e-04 - mean_absolute_error: 0.0125 - val_loss: 1.6689e-04 - val_mean_absolute_error: 0.0095
# Epoch 47/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8033e-04 - mean_absolute_error: 0.0132 - val_loss: 2.8091e-04 - val_mean_absolute_error: 0.0141
# Epoch 48/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5369e-04 - mean_absolute_error: 0.0165 - val_loss: 1.5687e-04 - val_mean_absolute_error: 0.0091
# Epoch 49/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3304e-04 - mean_absolute_error: 0.0142 - val_loss: 1.7661e-04 - val_mean_absolute_error: 0.0100
# Epoch 50/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4106e-04 - mean_absolute_error: 0.0126 - val_loss: 1.4707e-04 - val_mean_absolute_error: 0.0086
# Epoch 51/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6321e-04 - mean_absolute_error: 0.0123 - val_loss: 2.2760e-04 - val_mean_absolute_error: 0.0122
# Epoch 52/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0250e-04 - mean_absolute_error: 0.0132 - val_loss: 1.4850e-04 - val_mean_absolute_error: 0.0087
# Epoch 53/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8607e-04 - mean_absolute_error: 0.0128 - val_loss: 1.7681e-04 - val_mean_absolute_error: 0.0101
# Epoch 54/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3737e-04 - mean_absolute_error: 0.0123 - val_loss: 1.6189e-04 - val_mean_absolute_error: 0.0093
# Epoch 55/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0811e-04 - mean_absolute_error: 0.0135 - val_loss: 1.6941e-04 - val_mean_absolute_error: 0.0098
# Epoch 56/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5369e-04 - mean_absolute_error: 0.0122 - val_loss: 2.1303e-04 - val_mean_absolute_error: 0.0116
# Epoch 57/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1729e-04 - mean_absolute_error: 0.0140 - val_loss: 1.7982e-04 - val_mean_absolute_error: 0.0103
# Epoch 58/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8845e-04 - mean_absolute_error: 0.0132 - val_loss: 2.2483e-04 - val_mean_absolute_error: 0.0121
# Epoch 59/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4862e-04 - mean_absolute_error: 0.0126 - val_loss: 1.5379e-04 - val_mean_absolute_error: 0.0090
# Epoch 60/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5838e-04 - mean_absolute_error: 0.0125 - val_loss: 2.0247e-04 - val_mean_absolute_error: 0.0111
# Epoch 61/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6652e-04 - mean_absolute_error: 0.0128 - val_loss: 1.7664e-04 - val_mean_absolute_error: 0.0101
# Epoch 62/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4901e-04 - mean_absolute_error: 0.0127 - val_loss: 1.6323e-04 - val_mean_absolute_error: 0.0095
# Epoch 63/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7340e-04 - mean_absolute_error: 0.0133 - val_loss: 1.5321e-04 - val_mean_absolute_error: 0.0090
# Epoch 64/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9836e-04 - mean_absolute_error: 0.0134 - val_loss: 2.5582e-04 - val_mean_absolute_error: 0.0132
# Epoch 65/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6675e-04 - mean_absolute_error: 0.0134 - val_loss: 1.9000e-04 - val_mean_absolute_error: 0.0107
# Epoch 66/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0688e-04 - mean_absolute_error: 0.0139 - val_loss: 2.1934e-04 - val_mean_absolute_error: 0.0117
# Epoch 67/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3470e-04 - mean_absolute_error: 0.0125 - val_loss: 1.4789e-04 - val_mean_absolute_error: 0.0088
# Epoch 68/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4384e-04 - mean_absolute_error: 0.0143 - val_loss: 1.9198e-04 - val_mean_absolute_error: 0.0107
# Epoch 69/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9425e-04 - mean_absolute_error: 0.0138 - val_loss: 2.1522e-04 - val_mean_absolute_error: 0.0116
# Epoch 70/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9404e-04 - mean_absolute_error: 0.0136 - val_loss: 2.1776e-04 - val_mean_absolute_error: 0.0116
# Epoch 71/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8928e-04 - mean_absolute_error: 0.0155 - val_loss: 2.1913e-04 - val_mean_absolute_error: 0.0119
# Epoch 72/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9132e-04 - mean_absolute_error: 0.0135 - val_loss: 1.5951e-04 - val_mean_absolute_error: 0.0094
# Epoch 73/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8880e-04 - mean_absolute_error: 0.0131 - val_loss: 1.6215e-04 - val_mean_absolute_error: 0.0095
# Epoch 74/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4846e-04 - mean_absolute_error: 0.0121 - val_loss: 2.3069e-04 - val_mean_absolute_error: 0.0123
# Epoch 75/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8745e-04 - mean_absolute_error: 0.0159 - val_loss: 2.4833e-04 - val_mean_absolute_error: 0.0130
# Epoch 76/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0975e-04 - mean_absolute_error: 0.0137 - val_loss: 1.4720e-04 - val_mean_absolute_error: 0.0087
# Epoch 77/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7094e-04 - mean_absolute_error: 0.0130 - val_loss: 1.6725e-04 - val_mean_absolute_error: 0.0098
# Epoch 78/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6088e-04 - mean_absolute_error: 0.0129 - val_loss: 1.4684e-04 - val_mean_absolute_error: 0.0087
# Epoch 79/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1532e-04 - mean_absolute_error: 0.0135 - val_loss: 1.6762e-04 - val_mean_absolute_error: 0.0096
# Epoch 80/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7078e-04 - mean_absolute_error: 0.0134 - val_loss: 2.5332e-04 - val_mean_absolute_error: 0.0132
# Epoch 81/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9192e-04 - mean_absolute_error: 0.0135 - val_loss: 3.5047e-04 - val_mean_absolute_error: 0.0161
# Epoch 82/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9855e-04 - mean_absolute_error: 0.0136 - val_loss: 2.2724e-04 - val_mean_absolute_error: 0.0122
# Epoch 83/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1304e-04 - mean_absolute_error: 0.0138 - val_loss: 1.4889e-04 - val_mean_absolute_error: 0.0088
# Epoch 84/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6733e-04 - mean_absolute_error: 0.0128 - val_loss: 2.0399e-04 - val_mean_absolute_error: 0.0113
# Epoch 85/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8463e-04 - mean_absolute_error: 0.0131 - val_loss: 1.4993e-04 - val_mean_absolute_error: 0.0089
# Epoch 86/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1006e-04 - mean_absolute_error: 0.0141 - val_loss: 2.6218e-04 - val_mean_absolute_error: 0.0135
# Epoch 87/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5820e-04 - mean_absolute_error: 0.0145 - val_loss: 1.7692e-04 - val_mean_absolute_error: 0.0102
# Epoch 88/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0339e-04 - mean_absolute_error: 0.0135 - val_loss: 1.7880e-04 - val_mean_absolute_error: 0.0101
# Epoch 89/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0417e-04 - mean_absolute_error: 0.0134 - val_loss: 2.9070e-04 - val_mean_absolute_error: 0.0143
# Epoch 90/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2327e-04 - mean_absolute_error: 0.0141 - val_loss: 2.2622e-04 - val_mean_absolute_error: 0.0121
# Epoch 91/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1313e-04 - mean_absolute_error: 0.0142 - val_loss: 1.4779e-04 - val_mean_absolute_error: 0.0088
# Epoch 92/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5866e-04 - mean_absolute_error: 0.0127 - val_loss: 1.4930e-04 - val_mean_absolute_error: 0.0089
# Epoch 93/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8504e-04 - mean_absolute_error: 0.0132 - val_loss: 2.5438e-04 - val_mean_absolute_error: 0.0131
# Epoch 94/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4609e-04 - mean_absolute_error: 0.0147 - val_loss: 3.3727e-04 - val_mean_absolute_error: 0.0158
# Epoch 95/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2360e-04 - mean_absolute_error: 0.0145 - val_loss: 2.5380e-04 - val_mean_absolute_error: 0.0133
# Epoch 96/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7671e-04 - mean_absolute_error: 0.0137 - val_loss: 2.0171e-04 - val_mean_absolute_error: 0.0112
# Epoch 97/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0054e-04 - mean_absolute_error: 0.0135 - val_loss: 1.4848e-04 - val_mean_absolute_error: 0.0088
# Epoch 98/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5177e-04 - mean_absolute_error: 0.0124 - val_loss: 2.6510e-04 - val_mean_absolute_error: 0.0133
# Epoch 99/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7513e-04 - mean_absolute_error: 0.0134 - val_loss: 1.4986e-04 - val_mean_absolute_error: 0.0089
# Epoch 100/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8133e-04 - mean_absolute_error: 0.0127 - val_loss: 1.4896e-04 - val_mean_absolute_error: 0.0088
# Epoch 101/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4389e-04 - mean_absolute_error: 0.0143 - val_loss: 1.5775e-04 - val_mean_absolute_error: 0.0093
# Epoch 102/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6024e-04 - mean_absolute_error: 0.0125 - val_loss: 2.6829e-04 - val_mean_absolute_error: 0.0135
# Epoch 103/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2662e-04 - mean_absolute_error: 0.0145 - val_loss: 1.4951e-04 - val_mean_absolute_error: 0.0089
# Epoch 104/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8281e-04 - mean_absolute_error: 0.0136 - val_loss: 3.4506e-04 - val_mean_absolute_error: 0.0160
# Epoch 105/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6235e-04 - mean_absolute_error: 0.0152 - val_loss: 3.3771e-04 - val_mean_absolute_error: 0.0158
# Epoch 106/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4899e-04 - mean_absolute_error: 0.0143 - val_loss: 1.4987e-04 - val_mean_absolute_error: 0.0089
# Epoch 107/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2752e-04 - mean_absolute_error: 0.0135 - val_loss: 1.6109e-04 - val_mean_absolute_error: 0.0093
# Epoch 108/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7181e-04 - mean_absolute_error: 0.0127 - val_loss: 2.1447e-04 - val_mean_absolute_error: 0.0117
# Epoch 109/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6879e-04 - mean_absolute_error: 0.0128 - val_loss: 2.5205e-04 - val_mean_absolute_error: 0.0130
# Epoch 110/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0463e-04 - mean_absolute_error: 0.0136 - val_loss: 1.4737e-04 - val_mean_absolute_error: 0.0088
# Epoch 111/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7998e-04 - mean_absolute_error: 0.0132 - val_loss: 1.8014e-04 - val_mean_absolute_error: 0.0102
# Epoch 112/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5705e-04 - mean_absolute_error: 0.0127 - val_loss: 1.4957e-04 - val_mean_absolute_error: 0.0089
# Epoch 113/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0938e-04 - mean_absolute_error: 0.0120 - val_loss: 1.7713e-04 - val_mean_absolute_error: 0.0100
# Epoch 114/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4180e-04 - mean_absolute_error: 0.0122 - val_loss: 2.5078e-04 - val_mean_absolute_error: 0.0129
# Epoch 115/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0740e-04 - mean_absolute_error: 0.0142 - val_loss: 1.4960e-04 - val_mean_absolute_error: 0.0089
# Epoch 116/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1102e-04 - mean_absolute_error: 0.0141 - val_loss: 2.6075e-04 - val_mean_absolute_error: 0.0134
# Epoch 117/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1519e-04 - mean_absolute_error: 0.0147 - val_loss: 1.9014e-04 - val_mean_absolute_error: 0.0107
# Epoch 118/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8475e-04 - mean_absolute_error: 0.0132 - val_loss: 1.5234e-04 - val_mean_absolute_error: 0.0090
# Epoch 119/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9125e-04 - mean_absolute_error: 0.0129 - val_loss: 1.8811e-04 - val_mean_absolute_error: 0.0107
# Epoch 120/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6190e-04 - mean_absolute_error: 0.0128 - val_loss: 1.8397e-04 - val_mean_absolute_error: 0.0105
# Epoch 121/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0692e-04 - mean_absolute_error: 0.0138 - val_loss: 1.9923e-04 - val_mean_absolute_error: 0.0110
# Epoch 122/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4115e-04 - mean_absolute_error: 0.0124 - val_loss: 1.7909e-04 - val_mean_absolute_error: 0.0103
# Epoch 123/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5522e-04 - mean_absolute_error: 0.0125 - val_loss: 2.4067e-04 - val_mean_absolute_error: 0.0127
# Epoch 124/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4793e-04 - mean_absolute_error: 0.0129 - val_loss: 2.1723e-04 - val_mean_absolute_error: 0.0118
# Epoch 125/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8489e-04 - mean_absolute_error: 0.0137 - val_loss: 2.1755e-04 - val_mean_absolute_error: 0.0119
# Epoch 126/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0344e-04 - mean_absolute_error: 0.0137 - val_loss: 2.3344e-04 - val_mean_absolute_error: 0.0125
# Epoch 127/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8700e-04 - mean_absolute_error: 0.0130 - val_loss: 1.5953e-04 - val_mean_absolute_error: 0.0094
# Epoch 128/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2851e-04 - mean_absolute_error: 0.0137 - val_loss: 1.4928e-04 - val_mean_absolute_error: 0.0089
# Epoch 129/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1444e-04 - mean_absolute_error: 0.0137 - val_loss: 1.6907e-04 - val_mean_absolute_error: 0.0096
# Epoch 130/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6393e-04 - mean_absolute_error: 0.0131 - val_loss: 1.5226e-04 - val_mean_absolute_error: 0.0090
# Epoch 131/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7071e-04 - mean_absolute_error: 0.0128 - val_loss: 1.4776e-04 - val_mean_absolute_error: 0.0088
# Epoch 132/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9490e-04 - mean_absolute_error: 0.0134 - val_loss: 1.4753e-04 - val_mean_absolute_error: 0.0088
# Epoch 133/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6104e-04 - mean_absolute_error: 0.0126 - val_loss: 3.0518e-04 - val_mean_absolute_error: 0.0148
# Epoch 134/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4274e-04 - mean_absolute_error: 0.0147 - val_loss: 1.9618e-04 - val_mean_absolute_error: 0.0107
# Epoch 135/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5152e-04 - mean_absolute_error: 0.0152 - val_loss: 2.3368e-04 - val_mean_absolute_error: 0.0122
# Epoch 136/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1416e-04 - mean_absolute_error: 0.0157 - val_loss: 1.7810e-04 - val_mean_absolute_error: 0.0100
# Epoch 137/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1349e-04 - mean_absolute_error: 0.0139 - val_loss: 1.4804e-04 - val_mean_absolute_error: 0.0088
# Epoch 138/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2175e-04 - mean_absolute_error: 0.0119 - val_loss: 1.9136e-04 - val_mean_absolute_error: 0.0108
# Epoch 139/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1491e-04 - mean_absolute_error: 0.0137 - val_loss: 1.7136e-04 - val_mean_absolute_error: 0.0099
# Epoch 140/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6763e-04 - mean_absolute_error: 0.0131 - val_loss: 2.6442e-04 - val_mean_absolute_error: 0.0136
# Epoch 141/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7385e-04 - mean_absolute_error: 0.0132 - val_loss: 2.6227e-04 - val_mean_absolute_error: 0.0134
# Epoch 142/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8461e-04 - mean_absolute_error: 0.0139 - val_loss: 1.5024e-04 - val_mean_absolute_error: 0.0089
# Epoch 143/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6052e-04 - mean_absolute_error: 0.0129 - val_loss: 1.4978e-04 - val_mean_absolute_error: 0.0089
# Epoch 144/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2208e-04 - mean_absolute_error: 0.0120 - val_loss: 1.5730e-04 - val_mean_absolute_error: 0.0092
# Epoch 145/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7388e-04 - mean_absolute_error: 0.0126 - val_loss: 1.5456e-04 - val_mean_absolute_error: 0.0091
# Epoch 146/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5304e-04 - mean_absolute_error: 0.0123 - val_loss: 2.1942e-04 - val_mean_absolute_error: 0.0119
# Epoch 147/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7682e-04 - mean_absolute_error: 0.0133 - val_loss: 1.9646e-04 - val_mean_absolute_error: 0.0110
# Epoch 148/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0613e-04 - mean_absolute_error: 0.0135 - val_loss: 1.5346e-04 - val_mean_absolute_error: 0.0091
# Epoch 149/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7413e-04 - mean_absolute_error: 0.0133 - val_loss: 1.8369e-04 - val_mean_absolute_error: 0.0105
# Epoch 150/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4214e-04 - mean_absolute_error: 0.0126 - val_loss: 2.5363e-04 - val_mean_absolute_error: 0.0132
# Epoch 151/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6700e-04 - mean_absolute_error: 0.0132 - val_loss: 1.5255e-04 - val_mean_absolute_error: 0.0090
# Epoch 152/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6765e-04 - mean_absolute_error: 0.0129 - val_loss: 2.5764e-04 - val_mean_absolute_error: 0.0133
# Epoch 153/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2439e-04 - mean_absolute_error: 0.0133 - val_loss: 1.4802e-04 - val_mean_absolute_error: 0.0088
# Epoch 154/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9789e-04 - mean_absolute_error: 0.0133 - val_loss: 1.6264e-04 - val_mean_absolute_error: 0.0095
# Epoch 155/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8453e-04 - mean_absolute_error: 0.0131 - val_loss: 1.5975e-04 - val_mean_absolute_error: 0.0093
# Epoch 156/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4310e-04 - mean_absolute_error: 0.0126 - val_loss: 1.8363e-04 - val_mean_absolute_error: 0.0105
# Epoch 157/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4524e-04 - mean_absolute_error: 0.0128 - val_loss: 1.4962e-04 - val_mean_absolute_error: 0.0088
# Epoch 158/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0677e-04 - mean_absolute_error: 0.0139 - val_loss: 1.6657e-04 - val_mean_absolute_error: 0.0097
# Epoch 159/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4554e-04 - mean_absolute_error: 0.0128 - val_loss: 1.9782e-04 - val_mean_absolute_error: 0.0108
# Epoch 160/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8570e-04 - mean_absolute_error: 0.0133 - val_loss: 1.6766e-04 - val_mean_absolute_error: 0.0097
# Epoch 161/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4677e-04 - mean_absolute_error: 0.0125 - val_loss: 1.7564e-04 - val_mean_absolute_error: 0.0101
# Epoch 162/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5896e-04 - mean_absolute_error: 0.0128 - val_loss: 1.5918e-04 - val_mean_absolute_error: 0.0093
# Epoch 163/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6555e-04 - mean_absolute_error: 0.0131 - val_loss: 2.3246e-04 - val_mean_absolute_error: 0.0124
# Epoch 164/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1349e-04 - mean_absolute_error: 0.0145 - val_loss: 1.9904e-04 - val_mean_absolute_error: 0.0111
# Epoch 165/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7593e-04 - mean_absolute_error: 0.0127 - val_loss: 2.2112e-04 - val_mean_absolute_error: 0.0120
# Epoch 166/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1966e-04 - mean_absolute_error: 0.0138 - val_loss: 2.1840e-04 - val_mean_absolute_error: 0.0118
# Epoch 167/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9398e-04 - mean_absolute_error: 0.0133 - val_loss: 2.8382e-04 - val_mean_absolute_error: 0.0142
# Epoch 168/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2199e-04 - mean_absolute_error: 0.0147 - val_loss: 1.5645e-04 - val_mean_absolute_error: 0.0092
# Epoch 169/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2450e-04 - mean_absolute_error: 0.0118 - val_loss: 1.7235e-04 - val_mean_absolute_error: 0.0099
# Epoch 170/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9919e-04 - mean_absolute_error: 0.0134 - val_loss: 3.2405e-04 - val_mean_absolute_error: 0.0154
# Epoch 171/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8000e-04 - mean_absolute_error: 0.0133 - val_loss: 1.4724e-04 - val_mean_absolute_error: 0.0087
# Epoch 172/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0582e-04 - mean_absolute_error: 0.0142 - val_loss: 3.2193e-04 - val_mean_absolute_error: 0.0153
# Epoch 173/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4939e-04 - mean_absolute_error: 0.0127 - val_loss: 3.0630e-04 - val_mean_absolute_error: 0.0149
# Epoch 174/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1525e-04 - mean_absolute_error: 0.0148 - val_loss: 1.8307e-04 - val_mean_absolute_error: 0.0104
# Epoch 175/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5570e-04 - mean_absolute_error: 0.0125 - val_loss: 1.7571e-04 - val_mean_absolute_error: 0.0101
# Epoch 176/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6188e-04 - mean_absolute_error: 0.0129 - val_loss: 2.7390e-04 - val_mean_absolute_error: 0.0138
# Epoch 177/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6458e-04 - mean_absolute_error: 0.0157 - val_loss: 1.6455e-04 - val_mean_absolute_error: 0.0096
# Epoch 178/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6896e-04 - mean_absolute_error: 0.0125 - val_loss: 1.5328e-04 - val_mean_absolute_error: 0.0090
# Epoch 179/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6418e-04 - mean_absolute_error: 0.0127 - val_loss: 1.4817e-04 - val_mean_absolute_error: 0.0088
# Epoch 180/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3682e-04 - mean_absolute_error: 0.0123 - val_loss: 1.5069e-04 - val_mean_absolute_error: 0.0089
# Epoch 181/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5686e-04 - mean_absolute_error: 0.0146 - val_loss: 1.4829e-04 - val_mean_absolute_error: 0.0088
# Epoch 182/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8302e-04 - mean_absolute_error: 0.0135 - val_loss: 1.6016e-04 - val_mean_absolute_error: 0.0094
# Epoch 183/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4841e-04 - mean_absolute_error: 0.0124 - val_loss: 1.4823e-04 - val_mean_absolute_error: 0.0088
# Epoch 184/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9236e-04 - mean_absolute_error: 0.0134 - val_loss: 1.4920e-04 - val_mean_absolute_error: 0.0088
# Epoch 185/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9047e-04 - mean_absolute_error: 0.0135 - val_loss: 1.4675e-04 - val_mean_absolute_error: 0.0087
# Epoch 186/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2978e-04 - mean_absolute_error: 0.0144 - val_loss: 1.6179e-04 - val_mean_absolute_error: 0.0095
# Epoch 187/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5697e-04 - mean_absolute_error: 0.0125 - val_loss: 1.8954e-04 - val_mean_absolute_error: 0.0105
# Epoch 188/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2811e-04 - mean_absolute_error: 0.0139 - val_loss: 1.5017e-04 - val_mean_absolute_error: 0.0088
# Epoch 189/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4617e-04 - mean_absolute_error: 0.0123 - val_loss: 1.4762e-04 - val_mean_absolute_error: 0.0088
# Epoch 190/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9204e-04 - mean_absolute_error: 0.0133 - val_loss: 1.5685e-04 - val_mean_absolute_error: 0.0091
# Epoch 191/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6270e-04 - mean_absolute_error: 0.0132 - val_loss: 1.5059e-04 - val_mean_absolute_error: 0.0089
# Epoch 192/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6481e-04 - mean_absolute_error: 0.0130 - val_loss: 1.4728e-04 - val_mean_absolute_error: 0.0087
# Epoch 193/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6092e-04 - mean_absolute_error: 0.0129 - val_loss: 1.9466e-04 - val_mean_absolute_error: 0.0109
# Epoch 194/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7970e-04 - mean_absolute_error: 0.0136 - val_loss: 1.7188e-04 - val_mean_absolute_error: 0.0098
# Epoch 195/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6328e-04 - mean_absolute_error: 0.0129 - val_loss: 1.6988e-04 - val_mean_absolute_error: 0.0098
# Epoch 196/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7297e-04 - mean_absolute_error: 0.0128 - val_loss: 1.4806e-04 - val_mean_absolute_error: 0.0088
# Epoch 197/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1982e-04 - mean_absolute_error: 0.0118 - val_loss: 1.4933e-04 - val_mean_absolute_error: 0.0088
# Epoch 198/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6247e-04 - mean_absolute_error: 0.0131 - val_loss: 1.5836e-04 - val_mean_absolute_error: 0.0093
# Epoch 199/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6451e-04 - mean_absolute_error: 0.0129 - val_loss: 1.5816e-04 - val_mean_absolute_error: 0.0093
# Epoch 200/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9635e-04 - mean_absolute_error: 0.0145 - val_loss: 1.5886e-04 - val_mean_absolute_error: 0.0092

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0148e-04 - mean_absolute_error: 0.0082
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2375e-04 - mean_absolute_error: 0.0083
# Test Loss: [0.00015886250184848905, 0.009232244454324245]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 120
# 131

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 71770.3591739893
# RMSE: 267.89990513994087
# MAE: 192.00157063802084
# MAPE: 1.7982046647847023 %
#
# Model evalution on validate set
# MSE: 89773.19348187091
# RMSE: 299.6217506822075
# MAE: 192.65641141528926
# MAPE: 1.8382811784268145 %

# %% [markdown]
# ## 4. Forecast the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
y_pred_30_days
# Out:
# array([[12646.75  ],
#        [12612.3955],
#        [12649.751 ],
#        [12633.039 ],
#        [12644.554 ],
#        [12638.834 ],
#        [12642.466 ],
#        [12640.477 ],
#        [12641.662 ],
#        [12640.997 ],
#        [12641.387 ],
#        [12641.164 ],
#        [12641.294 ],
#        [12641.219 ],
#        [12641.262 ],
#        [12641.237 ],
#        [12641.252 ],
#        [12641.245 ],
#        [12641.249 ],
#        [12641.246 ],
#        [12641.248 ],
#        [12641.247 ],
#        [12641.247 ],
#        [12641.246 ],
#        [12641.247 ],
#        [12641.247 ],
#        [12641.246 ],
#        [12641.247 ],
#        [12641.247 ],
#        [12641.246 ],
#        [12641.247 ]], dtype=float32)

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(16, 9))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecast Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
