# %% [markdown]
# # Model: GRU (Gated Recurrent Unit)  - Stock Token: FPT - Test/Train/Vaildation: 80/10/10
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 291.95
# - MAE: 241.66
# - MAPE: 2.1 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 2  # 8 1 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170
# ...           ...
# 2024-02-26   9700
# 2024-02-27   9640
# 2024-02-28   9890
# 2024-02-29   9950
# 2024-03-01   9990
#
# [1252 rows x 1 columns]

# %%
df.shape
# Out:
# (1252, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       6900
# 1       7100
# 2       7100
# 3       7170
# 4       7170
#         ...
# 1247    9700
# 1248    9640
# 1249    9890
# 1250    9950
# 1251    9990
# Name: close, Length: 1252, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((990, 10), (990,), (114, 10), (114,), (115, 10), (115,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(100),
        Dense(32, activation="relu"),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 100)            │        30,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,165 (133.46 KB)
#  Trainable params: 34,165 (133.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0417 - mean_absolute_error: 0.1386 - val_loss: 2.7669e-04 - val_mean_absolute_error: 0.0143
# Epoch 2/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.8322e-04 - mean_absolute_error: 0.0246 - val_loss: 1.9606e-04 - val_mean_absolute_error: 0.0114
# Epoch 3/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0487e-04 - mean_absolute_error: 0.0180 - val_loss: 1.6788e-04 - val_mean_absolute_error: 0.0101
# Epoch 4/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3997e-04 - mean_absolute_error: 0.0151 - val_loss: 1.6899e-04 - val_mean_absolute_error: 0.0090
# Epoch 5/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8618e-04 - mean_absolute_error: 0.0156 - val_loss: 1.4977e-04 - val_mean_absolute_error: 0.0089
# Epoch 6/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9882e-04 - mean_absolute_error: 0.0158 - val_loss: 2.5281e-04 - val_mean_absolute_error: 0.0136
# Epoch 7/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0676e-04 - mean_absolute_error: 0.0163 - val_loss: 1.5951e-04 - val_mean_absolute_error: 0.0099
# Epoch 8/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4014e-04 - mean_absolute_error: 0.0155 - val_loss: 1.5610e-04 - val_mean_absolute_error: 0.0098
# Epoch 9/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1633e-04 - mean_absolute_error: 0.0144 - val_loss: 1.4273e-04 - val_mean_absolute_error: 0.0085
# Epoch 10/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6723e-04 - mean_absolute_error: 0.0152 - val_loss: 1.6712e-04 - val_mean_absolute_error: 0.0103
# Epoch 11/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7412e-04 - mean_absolute_error: 0.0144 - val_loss: 1.4063e-04 - val_mean_absolute_error: 0.0087
# Epoch 12/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3761e-04 - mean_absolute_error: 0.0139 - val_loss: 1.8285e-04 - val_mean_absolute_error: 0.0109
# Epoch 13/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7996e-04 - mean_absolute_error: 0.0162 - val_loss: 1.5614e-04 - val_mean_absolute_error: 0.0090
# Epoch 14/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3000e-04 - mean_absolute_error: 0.0141 - val_loss: 2.2277e-04 - val_mean_absolute_error: 0.0124
# Epoch 15/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6433e-04 - mean_absolute_error: 0.0141 - val_loss: 1.6765e-04 - val_mean_absolute_error: 0.0103
# Epoch 16/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3561e-04 - mean_absolute_error: 0.0132 - val_loss: 1.4365e-04 - val_mean_absolute_error: 0.0090
# Epoch 17/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8259e-04 - mean_absolute_error: 0.0141 - val_loss: 3.2836e-04 - val_mean_absolute_error: 0.0151
# Epoch 18/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8024e-04 - mean_absolute_error: 0.0170 - val_loss: 1.3818e-04 - val_mean_absolute_error: 0.0085
# Epoch 19/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0315e-04 - mean_absolute_error: 0.0132 - val_loss: 5.4342e-04 - val_mean_absolute_error: 0.0210
# Epoch 20/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2597e-04 - mean_absolute_error: 0.0156 - val_loss: 1.4082e-04 - val_mean_absolute_error: 0.0085
# Epoch 21/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0496e-04 - mean_absolute_error: 0.0128 - val_loss: 1.4143e-04 - val_mean_absolute_error: 0.0086
# Epoch 22/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1580e-04 - mean_absolute_error: 0.0132 - val_loss: 1.4597e-04 - val_mean_absolute_error: 0.0088
# Epoch 23/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0538e-04 - mean_absolute_error: 0.0153 - val_loss: 1.4818e-04 - val_mean_absolute_error: 0.0088
# Epoch 24/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1553e-04 - mean_absolute_error: 0.0135 - val_loss: 1.4231e-04 - val_mean_absolute_error: 0.0088
# Epoch 25/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5287e-04 - mean_absolute_error: 0.0136 - val_loss: 2.6299e-04 - val_mean_absolute_error: 0.0136
# Epoch 26/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9990e-04 - mean_absolute_error: 0.0134 - val_loss: 1.4189e-04 - val_mean_absolute_error: 0.0086
# Epoch 27/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2769e-04 - mean_absolute_error: 0.0135 - val_loss: 1.7060e-04 - val_mean_absolute_error: 0.0101
# Epoch 28/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8731e-04 - mean_absolute_error: 0.0148 - val_loss: 2.0531e-04 - val_mean_absolute_error: 0.0115
# Epoch 29/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3769e-04 - mean_absolute_error: 0.0137 - val_loss: 2.1732e-04 - val_mean_absolute_error: 0.0120
# Epoch 30/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1633e-04 - mean_absolute_error: 0.0133 - val_loss: 2.0076e-04 - val_mean_absolute_error: 0.0109
# Epoch 31/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1704e-04 - mean_absolute_error: 0.0137 - val_loss: 4.9808e-04 - val_mean_absolute_error: 0.0198
# Epoch 32/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5021e-04 - mean_absolute_error: 0.0145 - val_loss: 1.9802e-04 - val_mean_absolute_error: 0.0112
# Epoch 33/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4645e-04 - mean_absolute_error: 0.0140 - val_loss: 4.5417e-04 - val_mean_absolute_error: 0.0187
# Epoch 34/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0713e-04 - mean_absolute_error: 0.0140 - val_loss: 1.4606e-04 - val_mean_absolute_error: 0.0087
# Epoch 35/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8198e-04 - mean_absolute_error: 0.0127 - val_loss: 2.3737e-04 - val_mean_absolute_error: 0.0126
# Epoch 36/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6278e-04 - mean_absolute_error: 0.0150 - val_loss: 1.5476e-04 - val_mean_absolute_error: 0.0091
# Epoch 37/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9924e-04 - mean_absolute_error: 0.0131 - val_loss: 2.2713e-04 - val_mean_absolute_error: 0.0119
# Epoch 38/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9110e-04 - mean_absolute_error: 0.0150 - val_loss: 3.1601e-04 - val_mean_absolute_error: 0.0147
# Epoch 39/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8783e-04 - mean_absolute_error: 0.0152 - val_loss: 3.1961e-04 - val_mean_absolute_error: 0.0148
# Epoch 40/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8517e-04 - mean_absolute_error: 0.0147 - val_loss: 1.7276e-04 - val_mean_absolute_error: 0.0098
# Epoch 41/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9753e-04 - mean_absolute_error: 0.0129 - val_loss: 1.9837e-04 - val_mean_absolute_error: 0.0110
# Epoch 42/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7590e-04 - mean_absolute_error: 0.0126 - val_loss: 2.4250e-04 - val_mean_absolute_error: 0.0127
# Epoch 43/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4426e-04 - mean_absolute_error: 0.0143 - val_loss: 3.6271e-04 - val_mean_absolute_error: 0.0164
# Epoch 44/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2854e-04 - mean_absolute_error: 0.0138 - val_loss: 1.5716e-04 - val_mean_absolute_error: 0.0091
# Epoch 45/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4994e-04 - mean_absolute_error: 0.0122 - val_loss: 1.5688e-04 - val_mean_absolute_error: 0.0090
# Epoch 46/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9202e-04 - mean_absolute_error: 0.0132 - val_loss: 1.9822e-04 - val_mean_absolute_error: 0.0108
# Epoch 47/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7933e-04 - mean_absolute_error: 0.0129 - val_loss: 1.8420e-04 - val_mean_absolute_error: 0.0103
# Epoch 48/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0113e-04 - mean_absolute_error: 0.0135 - val_loss: 2.0016e-04 - val_mean_absolute_error: 0.0109
# Epoch 49/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8029e-04 - mean_absolute_error: 0.0150 - val_loss: 2.3039e-04 - val_mean_absolute_error: 0.0121
# Epoch 50/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4308e-04 - mean_absolute_error: 0.0127 - val_loss: 2.5933e-04 - val_mean_absolute_error: 0.0130
# Epoch 51/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1912e-04 - mean_absolute_error: 0.0137 - val_loss: 1.7463e-04 - val_mean_absolute_error: 0.0097
# Epoch 52/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6931e-04 - mean_absolute_error: 0.0130 - val_loss: 1.9366e-04 - val_mean_absolute_error: 0.0105
# Epoch 53/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9986e-04 - mean_absolute_error: 0.0130 - val_loss: 1.7391e-04 - val_mean_absolute_error: 0.0097
# Epoch 54/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5474e-04 - mean_absolute_error: 0.0124 - val_loss: 3.1270e-04 - val_mean_absolute_error: 0.0148
# Epoch 55/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2330e-04 - mean_absolute_error: 0.0137 - val_loss: 2.3025e-04 - val_mean_absolute_error: 0.0119
# Epoch 56/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7054e-04 - mean_absolute_error: 0.0130 - val_loss: 1.8520e-04 - val_mean_absolute_error: 0.0101
# Epoch 57/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6276e-04 - mean_absolute_error: 0.0122 - val_loss: 1.6756e-04 - val_mean_absolute_error: 0.0093
# Epoch 58/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0327e-04 - mean_absolute_error: 0.0135 - val_loss: 1.6568e-04 - val_mean_absolute_error: 0.0092
# Epoch 59/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3849e-04 - mean_absolute_error: 0.0121 - val_loss: 1.9349e-04 - val_mean_absolute_error: 0.0105
# Epoch 60/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4207e-04 - mean_absolute_error: 0.0122 - val_loss: 1.7621e-04 - val_mean_absolute_error: 0.0097
# Epoch 61/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6037e-04 - mean_absolute_error: 0.0127 - val_loss: 2.0503e-04 - val_mean_absolute_error: 0.0109
# Epoch 62/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1516e-04 - mean_absolute_error: 0.0138 - val_loss: 2.1279e-04 - val_mean_absolute_error: 0.0110
# Epoch 63/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5450e-04 - mean_absolute_error: 0.0128 - val_loss: 2.6210e-04 - val_mean_absolute_error: 0.0129
# Epoch 64/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3806e-04 - mean_absolute_error: 0.0139 - val_loss: 1.7138e-04 - val_mean_absolute_error: 0.0094
# Epoch 65/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5403e-04 - mean_absolute_error: 0.0122 - val_loss: 1.7410e-04 - val_mean_absolute_error: 0.0095
# Epoch 66/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5871e-04 - mean_absolute_error: 0.0123 - val_loss: 1.8647e-04 - val_mean_absolute_error: 0.0101
# Epoch 67/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6025e-04 - mean_absolute_error: 0.0124 - val_loss: 3.2645e-04 - val_mean_absolute_error: 0.0150
# Epoch 68/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7764e-04 - mean_absolute_error: 0.0130 - val_loss: 2.1069e-04 - val_mean_absolute_error: 0.0109
# Epoch 69/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4726e-04 - mean_absolute_error: 0.0138 - val_loss: 3.1148e-04 - val_mean_absolute_error: 0.0145
# Epoch 70/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4374e-04 - mean_absolute_error: 0.0126 - val_loss: 1.7755e-04 - val_mean_absolute_error: 0.0097
# Epoch 71/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7066e-04 - mean_absolute_error: 0.0127 - val_loss: 3.3904e-04 - val_mean_absolute_error: 0.0153
# Epoch 72/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1349e-04 - mean_absolute_error: 0.0138 - val_loss: 3.7676e-04 - val_mean_absolute_error: 0.0164
# Epoch 73/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0614e-04 - mean_absolute_error: 0.0139 - val_loss: 2.1406e-04 - val_mean_absolute_error: 0.0111
# Epoch 74/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0691e-04 - mean_absolute_error: 0.0138 - val_loss: 1.7384e-04 - val_mean_absolute_error: 0.0094
# Epoch 75/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3591e-04 - mean_absolute_error: 0.0148 - val_loss: 1.9347e-04 - val_mean_absolute_error: 0.0102
# Epoch 76/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2523e-04 - mean_absolute_error: 0.0146 - val_loss: 2.8012e-04 - val_mean_absolute_error: 0.0133
# Epoch 77/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3769e-04 - mean_absolute_error: 0.0137 - val_loss: 2.1350e-04 - val_mean_absolute_error: 0.0111
# Epoch 78/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6754e-04 - mean_absolute_error: 0.0129 - val_loss: 1.7782e-04 - val_mean_absolute_error: 0.0096
# Epoch 79/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3388e-04 - mean_absolute_error: 0.0121 - val_loss: 1.9416e-04 - val_mean_absolute_error: 0.0103
# Epoch 80/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4139e-04 - mean_absolute_error: 0.0144 - val_loss: 1.9476e-04 - val_mean_absolute_error: 0.0104
# Epoch 81/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8086e-04 - mean_absolute_error: 0.0129 - val_loss: 1.7667e-04 - val_mean_absolute_error: 0.0095
# Epoch 82/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1017e-04 - mean_absolute_error: 0.0130 - val_loss: 1.7757e-04 - val_mean_absolute_error: 0.0095
# Epoch 83/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6322e-04 - mean_absolute_error: 0.0127 - val_loss: 1.8491e-04 - val_mean_absolute_error: 0.0099
# Epoch 84/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4465e-04 - mean_absolute_error: 0.0127 - val_loss: 2.1198e-04 - val_mean_absolute_error: 0.0110
# Epoch 85/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0186e-04 - mean_absolute_error: 0.0137 - val_loss: 1.9000e-04 - val_mean_absolute_error: 0.0101
# Epoch 86/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5091e-04 - mean_absolute_error: 0.0125 - val_loss: 4.1365e-04 - val_mean_absolute_error: 0.0173
# Epoch 87/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7678e-04 - mean_absolute_error: 0.0158 - val_loss: 3.1305e-04 - val_mean_absolute_error: 0.0144
# Epoch 88/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1163e-04 - mean_absolute_error: 0.0135 - val_loss: 2.3541e-04 - val_mean_absolute_error: 0.0118
# Epoch 89/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6219e-04 - mean_absolute_error: 0.0127 - val_loss: 1.8067e-04 - val_mean_absolute_error: 0.0096
# Epoch 90/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9876e-04 - mean_absolute_error: 0.0141 - val_loss: 2.1566e-04 - val_mean_absolute_error: 0.0111
# Epoch 91/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5471e-04 - mean_absolute_error: 0.0126 - val_loss: 2.6238e-04 - val_mean_absolute_error: 0.0126
# Epoch 92/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1775e-04 - mean_absolute_error: 0.0141 - val_loss: 2.7861e-04 - val_mean_absolute_error: 0.0132
# Epoch 93/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8047e-04 - mean_absolute_error: 0.0135 - val_loss: 1.8694e-04 - val_mean_absolute_error: 0.0099
# Epoch 94/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0650e-04 - mean_absolute_error: 0.0136 - val_loss: 1.8615e-04 - val_mean_absolute_error: 0.0099
# Epoch 95/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3762e-04 - mean_absolute_error: 0.0121 - val_loss: 2.2336e-04 - val_mean_absolute_error: 0.0114
# Epoch 96/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9574e-04 - mean_absolute_error: 0.0137 - val_loss: 2.0907e-04 - val_mean_absolute_error: 0.0109
# Epoch 97/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9676e-04 - mean_absolute_error: 0.0132 - val_loss: 1.8771e-04 - val_mean_absolute_error: 0.0100
# Epoch 98/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6356e-04 - mean_absolute_error: 0.0136 - val_loss: 1.9517e-04 - val_mean_absolute_error: 0.0103
# Epoch 99/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6295e-04 - mean_absolute_error: 0.0134 - val_loss: 2.2527e-04 - val_mean_absolute_error: 0.0114
# Epoch 100/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9252e-04 - mean_absolute_error: 0.0132 - val_loss: 1.8824e-04 - val_mean_absolute_error: 0.0100
# Epoch 101/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7179e-04 - mean_absolute_error: 0.0128 - val_loss: 2.0670e-04 - val_mean_absolute_error: 0.0108
# Epoch 102/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3586e-04 - mean_absolute_error: 0.0126 - val_loss: 2.1856e-04 - val_mean_absolute_error: 0.0112
# Epoch 103/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2630e-04 - mean_absolute_error: 0.0142 - val_loss: 1.8077e-04 - val_mean_absolute_error: 0.0096
# Epoch 104/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9394e-04 - mean_absolute_error: 0.0136 - val_loss: 1.8822e-04 - val_mean_absolute_error: 0.0100
# Epoch 105/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6820e-04 - mean_absolute_error: 0.0126 - val_loss: 1.8558e-04 - val_mean_absolute_error: 0.0098
# Epoch 106/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3068e-04 - mean_absolute_error: 0.0119 - val_loss: 2.2198e-04 - val_mean_absolute_error: 0.0112
# Epoch 107/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3506e-04 - mean_absolute_error: 0.0147 - val_loss: 4.3257e-04 - val_mean_absolute_error: 0.0177
# Epoch 108/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5442e-04 - mean_absolute_error: 0.0151 - val_loss: 3.6410e-04 - val_mean_absolute_error: 0.0158
# Epoch 109/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7914e-04 - mean_absolute_error: 0.0155 - val_loss: 1.8465e-04 - val_mean_absolute_error: 0.0098
# Epoch 110/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8096e-04 - mean_absolute_error: 0.0133 - val_loss: 3.1499e-04 - val_mean_absolute_error: 0.0144
# Epoch 111/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7954e-04 - mean_absolute_error: 0.0133 - val_loss: 1.8702e-04 - val_mean_absolute_error: 0.0099
# Epoch 112/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6202e-04 - mean_absolute_error: 0.0146 - val_loss: 2.5546e-04 - val_mean_absolute_error: 0.0126
# Epoch 113/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0385e-04 - mean_absolute_error: 0.0135 - val_loss: 3.2732e-04 - val_mean_absolute_error: 0.0148
# Epoch 114/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6272e-04 - mean_absolute_error: 0.0130 - val_loss: 1.9558e-04 - val_mean_absolute_error: 0.0102
# Epoch 115/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9921e-04 - mean_absolute_error: 0.0134 - val_loss: 2.3427e-04 - val_mean_absolute_error: 0.0117
# Epoch 116/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4453e-04 - mean_absolute_error: 0.0122 - val_loss: 1.7996e-04 - val_mean_absolute_error: 0.0096
# Epoch 117/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4259e-04 - mean_absolute_error: 0.0122 - val_loss: 1.8129e-04 - val_mean_absolute_error: 0.0097
# Epoch 118/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4012e-04 - mean_absolute_error: 0.0123 - val_loss: 5.9973e-04 - val_mean_absolute_error: 0.0215
# Epoch 119/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5571e-04 - mean_absolute_error: 0.0163 - val_loss: 2.1274e-04 - val_mean_absolute_error: 0.0110
# Epoch 120/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7499e-04 - mean_absolute_error: 0.0127 - val_loss: 3.1602e-04 - val_mean_absolute_error: 0.0145
# Epoch 121/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0324e-04 - mean_absolute_error: 0.0136 - val_loss: 2.3552e-04 - val_mean_absolute_error: 0.0118
# Epoch 122/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3900e-04 - mean_absolute_error: 0.0145 - val_loss: 1.8126e-04 - val_mean_absolute_error: 0.0097
# Epoch 123/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8479e-04 - mean_absolute_error: 0.0137 - val_loss: 1.9833e-04 - val_mean_absolute_error: 0.0105
# Epoch 124/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6961e-04 - mean_absolute_error: 0.0126 - val_loss: 2.7062e-04 - val_mean_absolute_error: 0.0130
# Epoch 125/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3516e-04 - mean_absolute_error: 0.0147 - val_loss: 1.9512e-04 - val_mean_absolute_error: 0.0104
# Epoch 126/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8161e-04 - mean_absolute_error: 0.0132 - val_loss: 2.2928e-04 - val_mean_absolute_error: 0.0115
# Epoch 127/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1676e-04 - mean_absolute_error: 0.0133 - val_loss: 1.8151e-04 - val_mean_absolute_error: 0.0097
# Epoch 128/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2729e-04 - mean_absolute_error: 0.0132 - val_loss: 2.0598e-04 - val_mean_absolute_error: 0.0108
# Epoch 129/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8533e-04 - mean_absolute_error: 0.0132 - val_loss: 1.7791e-04 - val_mean_absolute_error: 0.0096
# Epoch 130/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0417e-04 - mean_absolute_error: 0.0118 - val_loss: 1.8107e-04 - val_mean_absolute_error: 0.0097
# Epoch 131/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1029e-04 - mean_absolute_error: 0.0136 - val_loss: 3.5488e-04 - val_mean_absolute_error: 0.0156
# Epoch 132/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2859e-04 - mean_absolute_error: 0.0141 - val_loss: 1.9066e-04 - val_mean_absolute_error: 0.0101
# Epoch 133/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7155e-04 - mean_absolute_error: 0.0134 - val_loss: 1.9422e-04 - val_mean_absolute_error: 0.0104
# Epoch 134/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0141e-04 - mean_absolute_error: 0.0137 - val_loss: 2.9425e-04 - val_mean_absolute_error: 0.0138
# Epoch 135/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6045e-04 - mean_absolute_error: 0.0128 - val_loss: 1.9221e-04 - val_mean_absolute_error: 0.0102
# Epoch 136/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9834e-04 - mean_absolute_error: 0.0135 - val_loss: 1.7976e-04 - val_mean_absolute_error: 0.0096
# Epoch 137/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6566e-04 - mean_absolute_error: 0.0124 - val_loss: 3.1096e-04 - val_mean_absolute_error: 0.0142
# Epoch 138/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1237e-04 - mean_absolute_error: 0.0135 - val_loss: 2.4759e-04 - val_mean_absolute_error: 0.0122
# Epoch 139/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9352e-04 - mean_absolute_error: 0.0131 - val_loss: 1.7944e-04 - val_mean_absolute_error: 0.0096
# Epoch 140/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7767e-04 - mean_absolute_error: 0.0133 - val_loss: 1.8000e-04 - val_mean_absolute_error: 0.0097
# Epoch 141/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8163e-04 - mean_absolute_error: 0.0134 - val_loss: 1.8198e-04 - val_mean_absolute_error: 0.0097
# Epoch 142/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9968e-04 - mean_absolute_error: 0.0136 - val_loss: 1.9152e-04 - val_mean_absolute_error: 0.0102
# Epoch 143/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9638e-04 - mean_absolute_error: 0.0132 - val_loss: 1.8347e-04 - val_mean_absolute_error: 0.0098
# Epoch 144/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7492e-04 - mean_absolute_error: 0.0122 - val_loss: 1.8424e-04 - val_mean_absolute_error: 0.0098
# Epoch 145/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9349e-04 - mean_absolute_error: 0.0132 - val_loss: 3.2230e-04 - val_mean_absolute_error: 0.0147
# Epoch 146/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2027e-04 - mean_absolute_error: 0.0143 - val_loss: 2.5782e-04 - val_mean_absolute_error: 0.0125
# Epoch 147/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1575e-04 - mean_absolute_error: 0.0134 - val_loss: 2.0482e-04 - val_mean_absolute_error: 0.0107
# Epoch 148/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0291e-04 - mean_absolute_error: 0.0135 - val_loss: 2.1913e-04 - val_mean_absolute_error: 0.0112
# Epoch 149/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8666e-04 - mean_absolute_error: 0.0136 - val_loss: 4.5250e-04 - val_mean_absolute_error: 0.0183
# Epoch 150/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3554e-04 - mean_absolute_error: 0.0150 - val_loss: 2.9923e-04 - val_mean_absolute_error: 0.0140
# Epoch 151/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1524e-04 - mean_absolute_error: 0.0141 - val_loss: 3.1883e-04 - val_mean_absolute_error: 0.0146
# Epoch 152/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6243e-04 - mean_absolute_error: 0.0154 - val_loss: 1.9785e-04 - val_mean_absolute_error: 0.0105
# Epoch 153/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5882e-04 - mean_absolute_error: 0.0146 - val_loss: 3.3029e-04 - val_mean_absolute_error: 0.0149
# Epoch 154/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1728e-04 - mean_absolute_error: 0.0141 - val_loss: 1.8097e-04 - val_mean_absolute_error: 0.0097
# Epoch 155/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0232e-04 - mean_absolute_error: 0.0136 - val_loss: 2.1879e-04 - val_mean_absolute_error: 0.0112
# Epoch 156/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6937e-04 - mean_absolute_error: 0.0135 - val_loss: 2.1466e-04 - val_mean_absolute_error: 0.0111
# Epoch 157/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7630e-04 - mean_absolute_error: 0.0152 - val_loss: 1.9440e-04 - val_mean_absolute_error: 0.0103
# Epoch 158/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6743e-04 - mean_absolute_error: 0.0129 - val_loss: 1.9420e-04 - val_mean_absolute_error: 0.0103
# Epoch 159/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2252e-04 - mean_absolute_error: 0.0139 - val_loss: 1.8753e-04 - val_mean_absolute_error: 0.0100
# Epoch 160/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6447e-04 - mean_absolute_error: 0.0131 - val_loss: 2.0372e-04 - val_mean_absolute_error: 0.0107
# Epoch 161/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1051e-04 - mean_absolute_error: 0.0139 - val_loss: 2.4898e-04 - val_mean_absolute_error: 0.0123
# Epoch 162/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7808e-04 - mean_absolute_error: 0.0136 - val_loss: 2.4568e-04 - val_mean_absolute_error: 0.0121
# Epoch 163/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7427e-04 - mean_absolute_error: 0.0134 - val_loss: 1.8024e-04 - val_mean_absolute_error: 0.0097
# Epoch 164/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3307e-04 - mean_absolute_error: 0.0141 - val_loss: 1.7709e-04 - val_mean_absolute_error: 0.0095
# Epoch 165/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0671e-04 - mean_absolute_error: 0.0142 - val_loss: 2.6908e-04 - val_mean_absolute_error: 0.0130
# Epoch 166/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9714e-04 - mean_absolute_error: 0.0136 - val_loss: 2.2609e-04 - val_mean_absolute_error: 0.0114
# Epoch 167/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8201e-04 - mean_absolute_error: 0.0130 - val_loss: 1.7836e-04 - val_mean_absolute_error: 0.0096
# Epoch 168/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0768e-04 - mean_absolute_error: 0.0136 - val_loss: 1.8647e-04 - val_mean_absolute_error: 0.0099
# Epoch 169/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5406e-04 - mean_absolute_error: 0.0124 - val_loss: 1.7978e-04 - val_mean_absolute_error: 0.0096
# Epoch 170/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7396e-04 - mean_absolute_error: 0.0132 - val_loss: 1.7730e-04 - val_mean_absolute_error: 0.0096
# Epoch 171/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1104e-04 - mean_absolute_error: 0.0146 - val_loss: 1.8613e-04 - val_mean_absolute_error: 0.0099
# Epoch 172/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7176e-04 - mean_absolute_error: 0.0125 - val_loss: 2.4804e-04 - val_mean_absolute_error: 0.0122
# Epoch 173/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3558e-04 - mean_absolute_error: 0.0125 - val_loss: 4.8296e-04 - val_mean_absolute_error: 0.0190
# Epoch 174/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7543e-04 - mean_absolute_error: 0.0134 - val_loss: 2.1863e-04 - val_mean_absolute_error: 0.0111
# Epoch 175/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8985e-04 - mean_absolute_error: 0.0135 - val_loss: 1.8667e-04 - val_mean_absolute_error: 0.0100
# Epoch 176/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2597e-04 - mean_absolute_error: 0.0140 - val_loss: 2.3167e-04 - val_mean_absolute_error: 0.0116
# Epoch 177/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0396e-04 - mean_absolute_error: 0.0140 - val_loss: 2.0678e-04 - val_mean_absolute_error: 0.0109
# Epoch 178/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9417e-04 - mean_absolute_error: 0.0135 - val_loss: 2.4586e-04 - val_mean_absolute_error: 0.0122
# Epoch 179/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6497e-04 - mean_absolute_error: 0.0127 - val_loss: 1.9665e-04 - val_mean_absolute_error: 0.0103
# Epoch 180/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7964e-04 - mean_absolute_error: 0.0129 - val_loss: 2.1362e-04 - val_mean_absolute_error: 0.0111
# Epoch 181/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7035e-04 - mean_absolute_error: 0.0132 - val_loss: 1.9261e-04 - val_mean_absolute_error: 0.0102
# Epoch 182/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3986e-04 - mean_absolute_error: 0.0126 - val_loss: 3.2041e-04 - val_mean_absolute_error: 0.0145
# Epoch 183/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2839e-04 - mean_absolute_error: 0.0138 - val_loss: 2.7486e-04 - val_mean_absolute_error: 0.0131
# Epoch 184/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2095e-04 - mean_absolute_error: 0.0142 - val_loss: 1.8336e-04 - val_mean_absolute_error: 0.0099
# Epoch 185/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9675e-04 - mean_absolute_error: 0.0133 - val_loss: 1.9197e-04 - val_mean_absolute_error: 0.0103
# Epoch 186/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4491e-04 - mean_absolute_error: 0.0122 - val_loss: 1.8611e-04 - val_mean_absolute_error: 0.0099
# Epoch 187/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4800e-04 - mean_absolute_error: 0.0125 - val_loss: 2.3293e-04 - val_mean_absolute_error: 0.0117
# Epoch 188/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7028e-04 - mean_absolute_error: 0.0125 - val_loss: 2.0093e-04 - val_mean_absolute_error: 0.0105
# Epoch 189/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9879e-04 - mean_absolute_error: 0.0140 - val_loss: 1.7846e-04 - val_mean_absolute_error: 0.0096
# Epoch 190/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7918e-04 - mean_absolute_error: 0.0130 - val_loss: 1.8410e-04 - val_mean_absolute_error: 0.0099
# Epoch 191/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0230e-04 - mean_absolute_error: 0.0139 - val_loss: 2.1208e-04 - val_mean_absolute_error: 0.0110
# Epoch 192/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7173e-04 - mean_absolute_error: 0.0132 - val_loss: 1.7856e-04 - val_mean_absolute_error: 0.0096
# Epoch 193/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2461e-04 - mean_absolute_error: 0.0117 - val_loss: 3.0937e-04 - val_mean_absolute_error: 0.0142
# Epoch 194/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3837e-04 - mean_absolute_error: 0.0148 - val_loss: 2.0761e-04 - val_mean_absolute_error: 0.0108
# Epoch 195/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6925e-04 - mean_absolute_error: 0.0154 - val_loss: 1.8247e-04 - val_mean_absolute_error: 0.0098
# Epoch 196/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9594e-04 - mean_absolute_error: 0.0130 - val_loss: 1.8340e-04 - val_mean_absolute_error: 0.0099
# Epoch 197/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8400e-04 - mean_absolute_error: 0.0129 - val_loss: 1.8030e-04 - val_mean_absolute_error: 0.0097
# Epoch 198/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6662e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1118e-04 - val_mean_absolute_error: 0.0143
# Epoch 199/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6244e-04 - mean_absolute_error: 0.0128 - val_loss: 1.7639e-04 - val_mean_absolute_error: 0.0095
# Epoch 200/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8214e-04 - mean_absolute_error: 0.0129 - val_loss: 2.8298e-04 - val_mean_absolute_error: 0.0134

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9343e-04 - mean_absolute_error: 0.0137
# Test Loss: [0.00028298431425355375, 0.01342322863638401]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 114
# 125

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 85235.93106173632
# RMSE: 291.9519327932876
# MAE: 241.66035327576753
# MAPE: 2.0978696154685195 %
#
# Model evalution on validate set
# MSE: 79421.19829873624
# RMSE: 281.8176685354136
# MAE: 216.57740319293478
# MAPE: 2.183682044682862 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
y_pred_30_days
# Out:
# array([[10117.239],
#        [10098.656],
#        [10120.937],
#        [10114.768],
#        [10121.568],
#        [10119.353],
#        [10120.868],
#        [10120.215],
#        [10120.627],
#        [10120.438],
#        [10120.547],
#        [10120.493],
#        [10120.522],
#        [10120.508],
#        [10120.516],
#        [10120.512],
#        [10120.514],
#        [10120.512],
#        [10120.513],
#        [10120.513],
#        [10120.513],
#        [10120.513],
#        [10120.513],
#        [10120.512],
#        [10120.513],
#        [10120.513],
#        [10120.513],
#        [10120.513],
#        [10120.513],
#        [10120.513],
#        [10120.513]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 0s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
