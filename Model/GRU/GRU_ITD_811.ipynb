# %% [markdown]
# # Model: GRU (Gated Recurrent Unit)  - Stock Token: FPT - Test/Train/Vaildation: 80/10/10
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 291.95
# - MAE: 241.66
# - MAPE: 2.1 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 2  # 8 1 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170
# ...           ...
# 2024-05-27  11300
# 2024-05-28  12050
# 2024-05-29  12600
# 2024-05-30  12500
# 2024-05-31  12700
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        6900
# 1        7100
# 2        7100
# 3        7170
# 4        7170
#         ...
# 1308    11300
# 1309    12050
# 1310    12600
# 1311    12500
# 1312    12700
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((1039, 10), (1039,), (120, 10), (120,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(100),
        Dense(32, activation="relu"),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 100)            │        30,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,165 (133.46 KB)
#  Trainable params: 34,165 (133.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 0.0710 - mean_absolute_error: 0.1894 - val_loss: 3.5940e-04 - val_mean_absolute_error: 0.0149
# Epoch 2/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0013 - mean_absolute_error: 0.0266 - val_loss: 3.8373e-04 - val_mean_absolute_error: 0.0164
# Epoch 3/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.1493e-04 - mean_absolute_error: 0.0188 - val_loss: 5.0345e-04 - val_mean_absolute_error: 0.0195
# Epoch 4/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.0369e-04 - mean_absolute_error: 0.0192 - val_loss: 3.2000e-04 - val_mean_absolute_error: 0.0147
# Epoch 5/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.6794e-04 - mean_absolute_error: 0.0173 - val_loss: 4.5810e-04 - val_mean_absolute_error: 0.0188
# Epoch 6/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.0760e-04 - mean_absolute_error: 0.0175 - val_loss: 1.7189e-04 - val_mean_absolute_error: 0.0092
# Epoch 7/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 7.1449e-04 - mean_absolute_error: 0.0177 - val_loss: 2.0118e-04 - val_mean_absolute_error: 0.0107
# Epoch 8/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.8060e-04 - mean_absolute_error: 0.0153 - val_loss: 1.8318e-04 - val_mean_absolute_error: 0.0099
# Epoch 9/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 6.2907e-04 - mean_absolute_error: 0.0166 - val_loss: 4.7064e-04 - val_mean_absolute_error: 0.0192
# Epoch 10/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.8754e-04 - mean_absolute_error: 0.0145 - val_loss: 1.8665e-04 - val_mean_absolute_error: 0.0101
# Epoch 11/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.0065e-04 - mean_absolute_error: 0.0142 - val_loss: 4.6279e-04 - val_mean_absolute_error: 0.0191
# Epoch 12/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.5792e-04 - mean_absolute_error: 0.0156 - val_loss: 3.0898e-04 - val_mean_absolute_error: 0.0149
# Epoch 13/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.5407e-04 - mean_absolute_error: 0.0151 - val_loss: 1.6501e-04 - val_mean_absolute_error: 0.0090
# Epoch 14/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.3281e-04 - mean_absolute_error: 0.0133 - val_loss: 2.6760e-04 - val_mean_absolute_error: 0.0135
# Epoch 15/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.8331e-04 - mean_absolute_error: 0.0141 - val_loss: 1.7795e-04 - val_mean_absolute_error: 0.0096
# Epoch 16/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.2075e-04 - mean_absolute_error: 0.0142 - val_loss: 2.6456e-04 - val_mean_absolute_error: 0.0134
# Epoch 17/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.4426e-04 - mean_absolute_error: 0.0136 - val_loss: 1.6583e-04 - val_mean_absolute_error: 0.0092
# Epoch 18/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.1272e-04 - mean_absolute_error: 0.0133 - val_loss: 4.9464e-04 - val_mean_absolute_error: 0.0199
# Epoch 19/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.4890e-04 - mean_absolute_error: 0.0141 - val_loss: 1.7332e-04 - val_mean_absolute_error: 0.0095
# Epoch 20/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.1805e-04 - mean_absolute_error: 0.0133 - val_loss: 1.9014e-04 - val_mean_absolute_error: 0.0104
# Epoch 21/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.7500e-04 - mean_absolute_error: 0.0145 - val_loss: 2.3110e-04 - val_mean_absolute_error: 0.0122
# Epoch 22/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.6015e-04 - mean_absolute_error: 0.0141 - val_loss: 2.8981e-04 - val_mean_absolute_error: 0.0144
# Epoch 23/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.6262e-04 - mean_absolute_error: 0.0140 - val_loss: 2.3110e-04 - val_mean_absolute_error: 0.0123
# Epoch 24/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.0489e-04 - mean_absolute_error: 0.0131 - val_loss: 1.5422e-04 - val_mean_absolute_error: 0.0087
# Epoch 25/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.1659e-04 - mean_absolute_error: 0.0136 - val_loss: 3.4346e-04 - val_mean_absolute_error: 0.0161
# Epoch 26/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.3989e-04 - mean_absolute_error: 0.0144 - val_loss: 1.9885e-04 - val_mean_absolute_error: 0.0107
# Epoch 27/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.2398e-04 - mean_absolute_error: 0.0141 - val_loss: 2.0900e-04 - val_mean_absolute_error: 0.0111
# Epoch 28/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.3855e-04 - mean_absolute_error: 0.0143 - val_loss: 1.5897e-04 - val_mean_absolute_error: 0.0091
# Epoch 29/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.8397e-04 - mean_absolute_error: 0.0130 - val_loss: 1.5504e-04 - val_mean_absolute_error: 0.0089
# Epoch 30/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.0591e-04 - mean_absolute_error: 0.0136 - val_loss: 1.5571e-04 - val_mean_absolute_error: 0.0087
# Epoch 31/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.9198e-04 - mean_absolute_error: 0.0135 - val_loss: 1.5849e-04 - val_mean_absolute_error: 0.0091
# Epoch 32/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.5798e-04 - mean_absolute_error: 0.0144 - val_loss: 1.5081e-04 - val_mean_absolute_error: 0.0086
# Epoch 33/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.2767e-04 - mean_absolute_error: 0.0133 - val_loss: 1.6778e-04 - val_mean_absolute_error: 0.0094
# Epoch 34/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.4874e-04 - mean_absolute_error: 0.0147 - val_loss: 2.8327e-04 - val_mean_absolute_error: 0.0139
# Epoch 35/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.5570e-04 - mean_absolute_error: 0.0143 - val_loss: 1.8814e-04 - val_mean_absolute_error: 0.0105
# Epoch 36/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.4616e-04 - mean_absolute_error: 0.0122 - val_loss: 1.8432e-04 - val_mean_absolute_error: 0.0103
# Epoch 37/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7475e-04 - mean_absolute_error: 0.0127 - val_loss: 2.3909e-04 - val_mean_absolute_error: 0.0123
# Epoch 38/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.2499e-04 - mean_absolute_error: 0.0142 - val_loss: 1.4939e-04 - val_mean_absolute_error: 0.0086
# Epoch 39/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.7320e-04 - mean_absolute_error: 0.0136 - val_loss: 2.1778e-04 - val_mean_absolute_error: 0.0116
# Epoch 40/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.2526e-04 - mean_absolute_error: 0.0142 - val_loss: 1.7074e-04 - val_mean_absolute_error: 0.0096
# Epoch 41/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.6799e-04 - mean_absolute_error: 0.0150 - val_loss: 2.8813e-04 - val_mean_absolute_error: 0.0143
# Epoch 42/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.4398e-04 - mean_absolute_error: 0.0144 - val_loss: 1.5011e-04 - val_mean_absolute_error: 0.0087
# Epoch 43/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.9752e-04 - mean_absolute_error: 0.0133 - val_loss: 1.5271e-04 - val_mean_absolute_error: 0.0088
# Epoch 44/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.5977e-04 - mean_absolute_error: 0.0124 - val_loss: 1.5346e-04 - val_mean_absolute_error: 0.0089
# Epoch 45/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.9626e-04 - mean_absolute_error: 0.0134 - val_loss: 2.2402e-04 - val_mean_absolute_error: 0.0121
# Epoch 46/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.8410e-04 - mean_absolute_error: 0.0134 - val_loss: 2.1841e-04 - val_mean_absolute_error: 0.0116
# Epoch 47/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.2752e-04 - mean_absolute_error: 0.0137 - val_loss: 1.4974e-04 - val_mean_absolute_error: 0.0086
# Epoch 48/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.3424e-04 - mean_absolute_error: 0.0119 - val_loss: 4.1802e-04 - val_mean_absolute_error: 0.0181
# Epoch 49/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.3197e-04 - mean_absolute_error: 0.0142 - val_loss: 1.6383e-04 - val_mean_absolute_error: 0.0094
# Epoch 50/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.1212e-04 - mean_absolute_error: 0.0138 - val_loss: 1.7428e-04 - val_mean_absolute_error: 0.0099
# Epoch 51/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.6662e-04 - mean_absolute_error: 0.0131 - val_loss: 1.4825e-04 - val_mean_absolute_error: 0.0086
# Epoch 52/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.3733e-04 - mean_absolute_error: 0.0123 - val_loss: 2.3643e-04 - val_mean_absolute_error: 0.0123
# Epoch 53/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.0161e-04 - mean_absolute_error: 0.0136 - val_loss: 1.5001e-04 - val_mean_absolute_error: 0.0087
# Epoch 54/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.1883e-04 - mean_absolute_error: 0.0134 - val_loss: 1.8043e-04 - val_mean_absolute_error: 0.0101
# Epoch 55/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.1250e-04 - mean_absolute_error: 0.0141 - val_loss: 2.0672e-04 - val_mean_absolute_error: 0.0114
# Epoch 56/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.3077e-04 - mean_absolute_error: 0.0147 - val_loss: 1.5362e-04 - val_mean_absolute_error: 0.0089
# Epoch 57/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.9783e-04 - mean_absolute_error: 0.0138 - val_loss: 1.8591e-04 - val_mean_absolute_error: 0.0105
# Epoch 58/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.9034e-04 - mean_absolute_error: 0.0136 - val_loss: 1.8565e-04 - val_mean_absolute_error: 0.0104
# Epoch 59/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.6534e-04 - mean_absolute_error: 0.0129 - val_loss: 1.4966e-04 - val_mean_absolute_error: 0.0087
# Epoch 60/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.6831e-04 - mean_absolute_error: 0.0126 - val_loss: 5.5028e-04 - val_mean_absolute_error: 0.0211
# Epoch 61/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5031e-04 - mean_absolute_error: 0.0150 - val_loss: 1.6634e-04 - val_mean_absolute_error: 0.0096
# Epoch 62/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.5596e-04 - mean_absolute_error: 0.0125 - val_loss: 1.4908e-04 - val_mean_absolute_error: 0.0088
# Epoch 63/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.5975e-04 - mean_absolute_error: 0.0126 - val_loss: 2.7284e-04 - val_mean_absolute_error: 0.0136
# Epoch 64/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.0583e-04 - mean_absolute_error: 0.0131 - val_loss: 1.5368e-04 - val_mean_absolute_error: 0.0090
# Epoch 65/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.6136e-04 - mean_absolute_error: 0.0126 - val_loss: 1.4719e-04 - val_mean_absolute_error: 0.0087
# Epoch 66/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7070e-04 - mean_absolute_error: 0.0138 - val_loss: 2.1067e-04 - val_mean_absolute_error: 0.0116
# Epoch 67/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.9508e-04 - mean_absolute_error: 0.0133 - val_loss: 2.7685e-04 - val_mean_absolute_error: 0.0139
# Epoch 68/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.5573e-04 - mean_absolute_error: 0.0131 - val_loss: 1.7098e-04 - val_mean_absolute_error: 0.0097
# Epoch 69/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.5225e-04 - mean_absolute_error: 0.0124 - val_loss: 4.3032e-04 - val_mean_absolute_error: 0.0183
# Epoch 70/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.1401e-04 - mean_absolute_error: 0.0160 - val_loss: 1.5792e-04 - val_mean_absolute_error: 0.0092
# Epoch 71/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.7335e-04 - mean_absolute_error: 0.0133 - val_loss: 1.4915e-04 - val_mean_absolute_error: 0.0088
# Epoch 72/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.0154e-04 - mean_absolute_error: 0.0136 - val_loss: 1.6721e-04 - val_mean_absolute_error: 0.0096
# Epoch 73/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.5518e-04 - mean_absolute_error: 0.0128 - val_loss: 1.7721e-04 - val_mean_absolute_error: 0.0102
# Epoch 74/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.8557e-04 - mean_absolute_error: 0.0130 - val_loss: 1.5096e-04 - val_mean_absolute_error: 0.0089
# Epoch 75/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.4802e-04 - mean_absolute_error: 0.0122 - val_loss: 1.7558e-04 - val_mean_absolute_error: 0.0101
# Epoch 76/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6732e-04 - mean_absolute_error: 0.0127 - val_loss: 2.1136e-04 - val_mean_absolute_error: 0.0115
# Epoch 77/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.8709e-04 - mean_absolute_error: 0.0128 - val_loss: 2.5315e-04 - val_mean_absolute_error: 0.0131
# Epoch 78/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.8014e-04 - mean_absolute_error: 0.0136 - val_loss: 1.5282e-04 - val_mean_absolute_error: 0.0090
# Epoch 79/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.1520e-04 - mean_absolute_error: 0.0144 - val_loss: 1.4878e-04 - val_mean_absolute_error: 0.0088
# Epoch 80/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6475e-04 - mean_absolute_error: 0.0126 - val_loss: 1.6489e-04 - val_mean_absolute_error: 0.0095
# Epoch 81/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.8779e-04 - mean_absolute_error: 0.0129 - val_loss: 1.8917e-04 - val_mean_absolute_error: 0.0107
# Epoch 82/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.5509e-04 - mean_absolute_error: 0.0149 - val_loss: 1.7960e-04 - val_mean_absolute_error: 0.0103
# Epoch 83/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.0541e-04 - mean_absolute_error: 0.0138 - val_loss: 1.4895e-04 - val_mean_absolute_error: 0.0088
# Epoch 84/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.4721e-04 - mean_absolute_error: 0.0126 - val_loss: 1.6244e-04 - val_mean_absolute_error: 0.0095
# Epoch 85/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.7028e-04 - mean_absolute_error: 0.0128 - val_loss: 1.7926e-04 - val_mean_absolute_error: 0.0102
# Epoch 86/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.6993e-04 - mean_absolute_error: 0.0146 - val_loss: 4.0504e-04 - val_mean_absolute_error: 0.0176
# Epoch 87/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.2985e-04 - mean_absolute_error: 0.0148 - val_loss: 1.7841e-04 - val_mean_absolute_error: 0.0102
# Epoch 88/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.3118e-04 - mean_absolute_error: 0.0145 - val_loss: 1.4874e-04 - val_mean_absolute_error: 0.0088
# Epoch 89/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.6411e-04 - mean_absolute_error: 0.0125 - val_loss: 1.5768e-04 - val_mean_absolute_error: 0.0093
# Epoch 90/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.2829e-04 - mean_absolute_error: 0.0120 - val_loss: 1.8616e-04 - val_mean_absolute_error: 0.0104
# Epoch 91/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.5683e-04 - mean_absolute_error: 0.0128 - val_loss: 1.7576e-04 - val_mean_absolute_error: 0.0101
# Epoch 92/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.4944e-04 - mean_absolute_error: 0.0123 - val_loss: 1.5238e-04 - val_mean_absolute_error: 0.0090
# Epoch 93/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.2803e-04 - mean_absolute_error: 0.0132 - val_loss: 1.4994e-04 - val_mean_absolute_error: 0.0088
# Epoch 94/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.4680e-04 - mean_absolute_error: 0.0121 - val_loss: 1.5381e-04 - val_mean_absolute_error: 0.0090
# Epoch 95/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.2339e-04 - mean_absolute_error: 0.0142 - val_loss: 1.7069e-04 - val_mean_absolute_error: 0.0097
# Epoch 96/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.0363e-04 - mean_absolute_error: 0.0138 - val_loss: 1.5359e-04 - val_mean_absolute_error: 0.0090
# Epoch 97/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.0392e-04 - mean_absolute_error: 0.0136 - val_loss: 1.5959e-04 - val_mean_absolute_error: 0.0094
# Epoch 98/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.2505e-04 - mean_absolute_error: 0.0123 - val_loss: 2.0195e-04 - val_mean_absolute_error: 0.0112
# Epoch 99/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.1335e-04 - mean_absolute_error: 0.0137 - val_loss: 1.5275e-04 - val_mean_absolute_error: 0.0090
# Epoch 100/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.2275e-04 - mean_absolute_error: 0.0136 - val_loss: 1.6748e-04 - val_mean_absolute_error: 0.0096
# Epoch 101/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8821e-04 - mean_absolute_error: 0.0128 - val_loss: 2.9053e-04 - val_mean_absolute_error: 0.0144
# Epoch 102/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.9161e-04 - mean_absolute_error: 0.0136 - val_loss: 1.5592e-04 - val_mean_absolute_error: 0.0092
# Epoch 103/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.2982e-04 - mean_absolute_error: 0.0139 - val_loss: 3.4397e-04 - val_mean_absolute_error: 0.0159
# Epoch 104/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5591e-04 - mean_absolute_error: 0.0149 - val_loss: 1.5069e-04 - val_mean_absolute_error: 0.0089
# Epoch 105/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.8142e-04 - mean_absolute_error: 0.0130 - val_loss: 1.6056e-04 - val_mean_absolute_error: 0.0094
# Epoch 106/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.8383e-04 - mean_absolute_error: 0.0133 - val_loss: 1.8178e-04 - val_mean_absolute_error: 0.0104
# Epoch 107/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.0105e-04 - mean_absolute_error: 0.0138 - val_loss: 1.9142e-04 - val_mean_absolute_error: 0.0107
# Epoch 108/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.2720e-04 - mean_absolute_error: 0.0121 - val_loss: 1.9559e-04 - val_mean_absolute_error: 0.0109
# Epoch 109/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.6764e-04 - mean_absolute_error: 0.0131 - val_loss: 1.9538e-04 - val_mean_absolute_error: 0.0109
# Epoch 110/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.1431e-04 - mean_absolute_error: 0.0134 - val_loss: 2.1419e-04 - val_mean_absolute_error: 0.0115
# Epoch 111/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.9850e-04 - mean_absolute_error: 0.0137 - val_loss: 1.7404e-04 - val_mean_absolute_error: 0.0100
# Epoch 112/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.2085e-04 - mean_absolute_error: 0.0135 - val_loss: 2.9690e-04 - val_mean_absolute_error: 0.0146
# Epoch 113/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.9606e-04 - mean_absolute_error: 0.0138 - val_loss: 1.8693e-04 - val_mean_absolute_error: 0.0104
# Epoch 114/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.9194e-04 - mean_absolute_error: 0.0136 - val_loss: 1.6139e-04 - val_mean_absolute_error: 0.0094
# Epoch 115/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.8528e-04 - mean_absolute_error: 0.0130 - val_loss: 1.5031e-04 - val_mean_absolute_error: 0.0089
# Epoch 116/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.9571e-04 - mean_absolute_error: 0.0135 - val_loss: 2.3422e-04 - val_mean_absolute_error: 0.0124
# Epoch 117/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8244e-04 - mean_absolute_error: 0.0135 - val_loss: 1.5182e-04 - val_mean_absolute_error: 0.0090
# Epoch 118/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.4732e-04 - mean_absolute_error: 0.0125 - val_loss: 5.5856e-04 - val_mean_absolute_error: 0.0212
# Epoch 119/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.2687e-04 - mean_absolute_error: 0.0193 - val_loss: 5.9183e-04 - val_mean_absolute_error: 0.0219
# Epoch 120/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.6760e-04 - mean_absolute_error: 0.0149 - val_loss: 1.6892e-04 - val_mean_absolute_error: 0.0098
# Epoch 121/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.5020e-04 - mean_absolute_error: 0.0124 - val_loss: 1.5222e-04 - val_mean_absolute_error: 0.0090
# Epoch 122/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8862e-04 - mean_absolute_error: 0.0135 - val_loss: 1.9680e-04 - val_mean_absolute_error: 0.0110
# Epoch 123/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.7321e-04 - mean_absolute_error: 0.0133 - val_loss: 1.5230e-04 - val_mean_absolute_error: 0.0089
# Epoch 124/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.5317e-04 - mean_absolute_error: 0.0129 - val_loss: 1.4841e-04 - val_mean_absolute_error: 0.0088
# Epoch 125/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.0153e-04 - mean_absolute_error: 0.0136 - val_loss: 1.6864e-04 - val_mean_absolute_error: 0.0097
# Epoch 126/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8179e-04 - mean_absolute_error: 0.0137 - val_loss: 1.9100e-04 - val_mean_absolute_error: 0.0106
# Epoch 127/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.1304e-04 - mean_absolute_error: 0.0138 - val_loss: 1.4830e-04 - val_mean_absolute_error: 0.0088
# Epoch 128/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.7624e-04 - mean_absolute_error: 0.0132 - val_loss: 2.9028e-04 - val_mean_absolute_error: 0.0142
# Epoch 129/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8631e-04 - mean_absolute_error: 0.0136 - val_loss: 1.4842e-04 - val_mean_absolute_error: 0.0088
# Epoch 130/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.7789e-04 - mean_absolute_error: 0.0133 - val_loss: 1.4882e-04 - val_mean_absolute_error: 0.0088
# Epoch 131/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.2128e-04 - mean_absolute_error: 0.0120 - val_loss: 1.5769e-04 - val_mean_absolute_error: 0.0093
# Epoch 132/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.5654e-04 - mean_absolute_error: 0.0126 - val_loss: 1.7957e-04 - val_mean_absolute_error: 0.0103
# Epoch 133/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.7380e-04 - mean_absolute_error: 0.0128 - val_loss: 1.7736e-04 - val_mean_absolute_error: 0.0100
# Epoch 134/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.0320e-04 - mean_absolute_error: 0.0138 - val_loss: 1.5520e-04 - val_mean_absolute_error: 0.0091
# Epoch 135/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.7357e-04 - mean_absolute_error: 0.0131 - val_loss: 1.6821e-04 - val_mean_absolute_error: 0.0098
# Epoch 136/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.8247e-04 - mean_absolute_error: 0.0131 - val_loss: 1.4926e-04 - val_mean_absolute_error: 0.0089
# Epoch 137/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.7749e-04 - mean_absolute_error: 0.0127 - val_loss: 1.5796e-04 - val_mean_absolute_error: 0.0093
# Epoch 138/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.9520e-04 - mean_absolute_error: 0.0133 - val_loss: 1.4637e-04 - val_mean_absolute_error: 0.0087
# Epoch 139/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.6813e-04 - mean_absolute_error: 0.0130 - val_loss: 1.4880e-04 - val_mean_absolute_error: 0.0088
# Epoch 140/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.7395e-04 - mean_absolute_error: 0.0127 - val_loss: 1.9712e-04 - val_mean_absolute_error: 0.0110
# Epoch 141/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.6189e-04 - mean_absolute_error: 0.0126 - val_loss: 3.0345e-04 - val_mean_absolute_error: 0.0148
# Epoch 142/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7894e-04 - mean_absolute_error: 0.0132 - val_loss: 2.2428e-04 - val_mean_absolute_error: 0.0121
# Epoch 143/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.0566e-04 - mean_absolute_error: 0.0138 - val_loss: 1.6038e-04 - val_mean_absolute_error: 0.0094
# Epoch 144/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.5431e-04 - mean_absolute_error: 0.0127 - val_loss: 1.5136e-04 - val_mean_absolute_error: 0.0090
# Epoch 145/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.6321e-04 - mean_absolute_error: 0.0125 - val_loss: 1.6349e-04 - val_mean_absolute_error: 0.0096
# Epoch 146/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.6498e-04 - mean_absolute_error: 0.0130 - val_loss: 2.7254e-04 - val_mean_absolute_error: 0.0137
# Epoch 147/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.0789e-04 - mean_absolute_error: 0.0140 - val_loss: 1.6831e-04 - val_mean_absolute_error: 0.0098
# Epoch 148/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.6693e-04 - mean_absolute_error: 0.0131 - val_loss: 1.4791e-04 - val_mean_absolute_error: 0.0088
# Epoch 149/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.4373e-04 - mean_absolute_error: 0.0123 - val_loss: 1.6480e-04 - val_mean_absolute_error: 0.0096
# Epoch 150/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.1238e-04 - mean_absolute_error: 0.0138 - val_loss: 1.5107e-04 - val_mean_absolute_error: 0.0089
# Epoch 151/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.8578e-04 - mean_absolute_error: 0.0133 - val_loss: 2.4389e-04 - val_mean_absolute_error: 0.0126
# Epoch 152/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.0799e-04 - mean_absolute_error: 0.0139 - val_loss: 1.5115e-04 - val_mean_absolute_error: 0.0089
# Epoch 153/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.6552e-04 - mean_absolute_error: 0.0126 - val_loss: 1.5294e-04 - val_mean_absolute_error: 0.0090
# Epoch 154/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.9316e-04 - mean_absolute_error: 0.0135 - val_loss: 1.6033e-04 - val_mean_absolute_error: 0.0094
# Epoch 155/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.3403e-04 - mean_absolute_error: 0.0118 - val_loss: 1.6160e-04 - val_mean_absolute_error: 0.0095
# Epoch 156/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.0158e-04 - mean_absolute_error: 0.0132 - val_loss: 2.0799e-04 - val_mean_absolute_error: 0.0114
# Epoch 157/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.5230e-04 - mean_absolute_error: 0.0133 - val_loss: 1.4812e-04 - val_mean_absolute_error: 0.0088
# Epoch 158/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.2632e-04 - mean_absolute_error: 0.0119 - val_loss: 1.8372e-04 - val_mean_absolute_error: 0.0104
# Epoch 159/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.7245e-04 - mean_absolute_error: 0.0135 - val_loss: 1.4824e-04 - val_mean_absolute_error: 0.0088
# Epoch 160/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.7096e-04 - mean_absolute_error: 0.0127 - val_loss: 1.5245e-04 - val_mean_absolute_error: 0.0090
# Epoch 161/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.4286e-04 - mean_absolute_error: 0.0125 - val_loss: 2.2649e-04 - val_mean_absolute_error: 0.0122
# Epoch 162/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.3134e-04 - mean_absolute_error: 0.0149 - val_loss: 2.4642e-04 - val_mean_absolute_error: 0.0129
# Epoch 163/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.0973e-04 - mean_absolute_error: 0.0146 - val_loss: 1.6974e-04 - val_mean_absolute_error: 0.0099
# Epoch 164/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.0173e-04 - mean_absolute_error: 0.0137 - val_loss: 2.4906e-04 - val_mean_absolute_error: 0.0130
# Epoch 165/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.2940e-04 - mean_absolute_error: 0.0143 - val_loss: 1.7051e-04 - val_mean_absolute_error: 0.0097
# Epoch 166/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.3907e-04 - mean_absolute_error: 0.0144 - val_loss: 1.9340e-04 - val_mean_absolute_error: 0.0108
# Epoch 167/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.8670e-04 - mean_absolute_error: 0.0147 - val_loss: 3.0981e-04 - val_mean_absolute_error: 0.0148
# Epoch 168/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.1510e-04 - mean_absolute_error: 0.0140 - val_loss: 1.4846e-04 - val_mean_absolute_error: 0.0088
# Epoch 169/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.7144e-04 - mean_absolute_error: 0.0124 - val_loss: 1.6739e-04 - val_mean_absolute_error: 0.0098
# Epoch 170/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.5797e-04 - mean_absolute_error: 0.0129 - val_loss: 2.4777e-04 - val_mean_absolute_error: 0.0129
# Epoch 171/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9432e-04 - mean_absolute_error: 0.0135 - val_loss: 1.7740e-04 - val_mean_absolute_error: 0.0102
# Epoch 172/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.5886e-04 - mean_absolute_error: 0.0126 - val_loss: 2.1853e-04 - val_mean_absolute_error: 0.0118
# Epoch 173/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.4525e-04 - mean_absolute_error: 0.0124 - val_loss: 1.5559e-04 - val_mean_absolute_error: 0.0091
# Epoch 174/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.5820e-04 - mean_absolute_error: 0.0130 - val_loss: 1.9429e-04 - val_mean_absolute_error: 0.0107
# Epoch 175/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.4639e-04 - mean_absolute_error: 0.0141 - val_loss: 1.7285e-04 - val_mean_absolute_error: 0.0100
# Epoch 176/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.9767e-04 - mean_absolute_error: 0.0134 - val_loss: 1.7404e-04 - val_mean_absolute_error: 0.0100
# Epoch 177/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.7871e-04 - mean_absolute_error: 0.0130 - val_loss: 1.4841e-04 - val_mean_absolute_error: 0.0088
# Epoch 178/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.4074e-04 - mean_absolute_error: 0.0122 - val_loss: 2.6274e-04 - val_mean_absolute_error: 0.0135
# Epoch 179/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.0652e-04 - mean_absolute_error: 0.0134 - val_loss: 1.6368e-04 - val_mean_absolute_error: 0.0095
# Epoch 180/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.7140e-04 - mean_absolute_error: 0.0135 - val_loss: 1.5956e-04 - val_mean_absolute_error: 0.0094
# Epoch 181/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.4959e-04 - mean_absolute_error: 0.0126 - val_loss: 2.0063e-04 - val_mean_absolute_error: 0.0111
# Epoch 182/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.4409e-04 - mean_absolute_error: 0.0125 - val_loss: 1.4845e-04 - val_mean_absolute_error: 0.0088
# Epoch 183/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.9921e-04 - mean_absolute_error: 0.0132 - val_loss: 1.7795e-04 - val_mean_absolute_error: 0.0102
# Epoch 184/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5806e-04 - mean_absolute_error: 0.0126 - val_loss: 1.4789e-04 - val_mean_absolute_error: 0.0088
# Epoch 185/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.5029e-04 - mean_absolute_error: 0.0125 - val_loss: 2.8580e-04 - val_mean_absolute_error: 0.0143
# Epoch 186/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.5768e-04 - mean_absolute_error: 0.0126 - val_loss: 1.6865e-04 - val_mean_absolute_error: 0.0098
# Epoch 187/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.4714e-04 - mean_absolute_error: 0.0126 - val_loss: 1.7061e-04 - val_mean_absolute_error: 0.0099
# Epoch 188/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.8058e-04 - mean_absolute_error: 0.0132 - val_loss: 1.5653e-04 - val_mean_absolute_error: 0.0092
# Epoch 189/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.9474e-04 - mean_absolute_error: 0.0131 - val_loss: 1.8834e-04 - val_mean_absolute_error: 0.0107
# Epoch 190/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.7340e-04 - mean_absolute_error: 0.0130 - val_loss: 2.1214e-04 - val_mean_absolute_error: 0.0116
# Epoch 191/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.5259e-04 - mean_absolute_error: 0.0128 - val_loss: 1.4783e-04 - val_mean_absolute_error: 0.0087
# Epoch 192/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.6317e-04 - mean_absolute_error: 0.0123 - val_loss: 1.8498e-04 - val_mean_absolute_error: 0.0105
# Epoch 193/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8873e-04 - mean_absolute_error: 0.0131 - val_loss: 1.9779e-04 - val_mean_absolute_error: 0.0110
# Epoch 194/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.2343e-04 - mean_absolute_error: 0.0142 - val_loss: 2.0229e-04 - val_mean_absolute_error: 0.0112
# Epoch 195/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.7947e-04 - mean_absolute_error: 0.0126 - val_loss: 1.4884e-04 - val_mean_absolute_error: 0.0088
# Epoch 196/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.9438e-04 - mean_absolute_error: 0.0135 - val_loss: 3.4882e-04 - val_mean_absolute_error: 0.0161
# Epoch 197/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.7257e-04 - mean_absolute_error: 0.0153 - val_loss: 1.6273e-04 - val_mean_absolute_error: 0.0095
# Epoch 198/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.4800e-04 - mean_absolute_error: 0.0124 - val_loss: 1.5224e-04 - val_mean_absolute_error: 0.0089
# Epoch 199/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.6572e-04 - mean_absolute_error: 0.0128 - val_loss: 1.4731e-04 - val_mean_absolute_error: 0.0087
# Epoch 200/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.0003e-04 - mean_absolute_error: 0.0136 - val_loss: 2.3465e-04 - val_mean_absolute_error: 0.0125

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9878e-04 - mean_absolute_error: 0.0115
# Test Loss: [0.00023464657715521753, 0.012450705282390118]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 120
# 131

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 99009.77489593028
# RMSE: 314.65818739694396
# MAE: 250.90537923177084
# MAPE: 2.3362644994995367 %
#
# Model evalution on validate set
# MSE: 82744.5398138062
# RMSE: 287.65350652096384
# MAE: 216.48188920454547
# MAPE: 2.1012601894933267 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step

# %%
y_pred_30_days
# Out:
# array([[12884.333 ],
#        [12783.953 ],
#        [12893.524 ],
#        [12826.541 ],
#        [12880.651 ],
#        [12846.952 ],
#        [12871.864 ],
#        [12854.772 ],
#        [12866.923 ],
#        [12858.522 ],
#        [12864.443 ],
#        [12860.309 ],
#        [12863.211 ],
#        [12861.181 ],
#        [12862.603 ],
#        [12861.607 ],
#        [12862.307 ],
#        [12861.816 ],
#        [12862.158 ],
#        [12861.918 ],
#        [12862.088 ],
#        [12861.97  ],
#        [12862.051 ],
#        [12861.993 ],
#        [12862.033 ],
#        [12862.005 ],
#        [12862.026 ],
#        [12862.012 ],
#        [12862.022 ],
#        [12862.015 ],
#        [12862.0205]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
