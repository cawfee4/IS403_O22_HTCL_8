# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

plt.style.use("default")

# %% [markdown]
# ## 1. Data preprocessing

# %%
split_type = [0.8,0.7,0.9]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 2  # 90% train, 10% test

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170
# ...           ...
# 2024-05-27  11300
# 2024-05-28  12050
# 2024-05-29  12600
# 2024-05-30  12500
# 2024-05-31  12700
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        6900
# 1        7100
# 2        7100
# 3        7170
# 4        7170
#         ...
# 1308    11300
# 1309    12050
# 1310    12600
# 1311    12500
# 1312    12700
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split] * len(df_scaled))
test_size = len(df_scaled) - train_size

# %%
# Splitting data into train, test set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size:]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test set
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1170, 10), (1170,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Input

UNITS = 64

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(UNITS),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 64)             │        12,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,929 (50.50 KB)
#  Trainable params: 12,929 (50.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0551 - mean_absolute_error: 0.1665
# Epoch 2/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0027 - mean_absolute_error: 0.0385
# Epoch 3/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5791e-04 - mean_absolute_error: 0.0176
# Epoch 4/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1653e-04 - mean_absolute_error: 0.0171
# Epoch 5/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5525e-04 - mean_absolute_error: 0.0159
# Epoch 6/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7400e-04 - mean_absolute_error: 0.0177
# Epoch 7/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5292e-04 - mean_absolute_error: 0.0153
# Epoch 8/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9767e-04 - mean_absolute_error: 0.0169
# Epoch 9/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7944e-04 - mean_absolute_error: 0.0157
# Epoch 10/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2394e-04 - mean_absolute_error: 0.0170
# Epoch 11/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3111e-04 - mean_absolute_error: 0.0147
# Epoch 12/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8870e-04 - mean_absolute_error: 0.0139
# Epoch 13/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6909e-04 - mean_absolute_error: 0.0142
# Epoch 14/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5704e-04 - mean_absolute_error: 0.0150
# Epoch 15/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4943e-04 - mean_absolute_error: 0.0138
# Epoch 16/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3387e-04 - mean_absolute_error: 0.0144
# Epoch 17/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9604e-04 - mean_absolute_error: 0.0140
# Epoch 18/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8014e-04 - mean_absolute_error: 0.0143
# Epoch 19/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1875e-04 - mean_absolute_error: 0.0149
# Epoch 20/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0321e-04 - mean_absolute_error: 0.0131
# Epoch 21/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1982e-04 - mean_absolute_error: 0.0150
# Epoch 22/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6854e-04 - mean_absolute_error: 0.0142
# Epoch 23/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7060e-04 - mean_absolute_error: 0.0139
# Epoch 24/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8907e-04 - mean_absolute_error: 0.0140
# Epoch 25/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4986e-04 - mean_absolute_error: 0.0133
# Epoch 26/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0464e-04 - mean_absolute_error: 0.0126
# Epoch 27/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8192e-04 - mean_absolute_error: 0.0125
# Epoch 28/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4681e-04 - mean_absolute_error: 0.0130
# Epoch 29/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9780e-04 - mean_absolute_error: 0.0151
# Epoch 30/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3341e-04 - mean_absolute_error: 0.0134
# Epoch 31/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6334e-04 - mean_absolute_error: 0.0142
# Epoch 32/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9619e-04 - mean_absolute_error: 0.0131
# Epoch 33/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4206e-04 - mean_absolute_error: 0.0138
# Epoch 34/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5848e-04 - mean_absolute_error: 0.0146
# Epoch 35/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9839e-04 - mean_absolute_error: 0.0135
# Epoch 36/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1075e-04 - mean_absolute_error: 0.0143
# Epoch 37/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9726e-04 - mean_absolute_error: 0.0128
# Epoch 38/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9662e-04 - mean_absolute_error: 0.0132
# Epoch 39/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7633e-04 - mean_absolute_error: 0.0126
# Epoch 40/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4782e-04 - mean_absolute_error: 0.0124
# Epoch 41/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8114e-04 - mean_absolute_error: 0.0127
# Epoch 42/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5815e-04 - mean_absolute_error: 0.0124
# Epoch 43/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9356e-04 - mean_absolute_error: 0.0129
# Epoch 44/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8261e-04 - mean_absolute_error: 0.0128
# Epoch 45/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6228e-04 - mean_absolute_error: 0.0149
# Epoch 46/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8229e-04 - mean_absolute_error: 0.0126
# Epoch 47/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8214e-04 - mean_absolute_error: 0.0124
# Epoch 48/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7801e-04 - mean_absolute_error: 0.0126
# Epoch 49/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9670e-04 - mean_absolute_error: 0.0128
# Epoch 50/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7076e-04 - mean_absolute_error: 0.0124
# Epoch 51/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3929e-04 - mean_absolute_error: 0.0138
# Epoch 52/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6373e-04 - mean_absolute_error: 0.0125
# Epoch 53/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1289e-04 - mean_absolute_error: 0.0136
# Epoch 54/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6743e-04 - mean_absolute_error: 0.0128
# Epoch 55/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3715e-04 - mean_absolute_error: 0.0136
# Epoch 56/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4522e-04 - mean_absolute_error: 0.0118
# Epoch 57/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9409e-04 - mean_absolute_error: 0.0131
# Epoch 58/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0533e-04 - mean_absolute_error: 0.0133
# Epoch 59/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9335e-04 - mean_absolute_error: 0.0129
# Epoch 60/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9526e-04 - mean_absolute_error: 0.0134
# Epoch 61/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5721e-04 - mean_absolute_error: 0.0123
# Epoch 62/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7812e-04 - mean_absolute_error: 0.0129
# Epoch 63/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3380e-04 - mean_absolute_error: 0.0120
# Epoch 64/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2493e-04 - mean_absolute_error: 0.0117
# Epoch 65/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6844e-04 - mean_absolute_error: 0.0127
# Epoch 66/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4280e-04 - mean_absolute_error: 0.0119
# Epoch 67/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7136e-04 - mean_absolute_error: 0.0128
# Epoch 68/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1250e-04 - mean_absolute_error: 0.0131
# Epoch 69/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9138e-04 - mean_absolute_error: 0.0138
# Epoch 70/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6381e-04 - mean_absolute_error: 0.0128
# Epoch 71/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9439e-04 - mean_absolute_error: 0.0114
# Epoch 72/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8523e-04 - mean_absolute_error: 0.0132
# Epoch 73/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6058e-04 - mean_absolute_error: 0.0124
# Epoch 74/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5752e-04 - mean_absolute_error: 0.0127
# Epoch 75/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8680e-04 - mean_absolute_error: 0.0127
# Epoch 76/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3149e-04 - mean_absolute_error: 0.0122
# Epoch 77/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4534e-04 - mean_absolute_error: 0.0120
# Epoch 78/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6944e-04 - mean_absolute_error: 0.0126
# Epoch 79/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2868e-04 - mean_absolute_error: 0.0118
# Epoch 80/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1631e-04 - mean_absolute_error: 0.0116
# Epoch 81/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3872e-04 - mean_absolute_error: 0.0121
# Epoch 82/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0166e-04 - mean_absolute_error: 0.0134
# Epoch 83/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1154e-04 - mean_absolute_error: 0.0134
# Epoch 84/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4278e-04 - mean_absolute_error: 0.0119
# Epoch 85/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9817e-04 - mean_absolute_error: 0.0115
# Epoch 86/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3267e-04 - mean_absolute_error: 0.0128
# Epoch 87/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0107e-04 - mean_absolute_error: 0.0131
# Epoch 88/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8982e-04 - mean_absolute_error: 0.0142
# Epoch 89/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2464e-04 - mean_absolute_error: 0.0120
# Epoch 90/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2277e-04 - mean_absolute_error: 0.0122
# Epoch 91/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7002e-04 - mean_absolute_error: 0.0131
# Epoch 92/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8202e-04 - mean_absolute_error: 0.0135
# Epoch 93/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2907e-04 - mean_absolute_error: 0.0122
# Epoch 94/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7514e-04 - mean_absolute_error: 0.0130
# Epoch 95/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1260e-04 - mean_absolute_error: 0.0116
# Epoch 96/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0579e-04 - mean_absolute_error: 0.0116
# Epoch 97/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6037e-04 - mean_absolute_error: 0.0133
# Epoch 98/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4934e-04 - mean_absolute_error: 0.0123
# Epoch 99/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4971e-04 - mean_absolute_error: 0.0127
# Epoch 100/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3424e-04 - mean_absolute_error: 0.0124
# Epoch 101/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6807e-04 - mean_absolute_error: 0.0132
# Epoch 102/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8654e-04 - mean_absolute_error: 0.0135
# Epoch 103/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2581e-04 - mean_absolute_error: 0.0116
# Epoch 104/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7590e-04 - mean_absolute_error: 0.0128
# Epoch 105/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6656e-04 - mean_absolute_error: 0.0123
# Epoch 106/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8104e-04 - mean_absolute_error: 0.0135
# Epoch 107/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0950e-04 - mean_absolute_error: 0.0116
# Epoch 108/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6235e-04 - mean_absolute_error: 0.0130
# Epoch 109/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4697e-04 - mean_absolute_error: 0.0128
# Epoch 110/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5791e-04 - mean_absolute_error: 0.0126
# Epoch 111/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9625e-04 - mean_absolute_error: 0.0115
# Epoch 112/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3060e-04 - mean_absolute_error: 0.0118
# Epoch 113/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2346e-04 - mean_absolute_error: 0.0120
# Epoch 114/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1349e-04 - mean_absolute_error: 0.0117
# Epoch 115/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8527e-04 - mean_absolute_error: 0.0128
# Epoch 116/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1760e-04 - mean_absolute_error: 0.0118
# Epoch 117/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2649e-04 - mean_absolute_error: 0.0121
# Epoch 118/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3351e-04 - mean_absolute_error: 0.0118
# Epoch 119/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7200e-04 - mean_absolute_error: 0.0130
# Epoch 120/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3175e-04 - mean_absolute_error: 0.0119
# Epoch 121/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5207e-04 - mean_absolute_error: 0.0124
# Epoch 122/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8958e-04 - mean_absolute_error: 0.0132
# Epoch 123/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3593e-04 - mean_absolute_error: 0.0121
# Epoch 124/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7078e-04 - mean_absolute_error: 0.0134
# Epoch 125/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9104e-04 - mean_absolute_error: 0.0133
# Epoch 126/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7909e-04 - mean_absolute_error: 0.0130
# Epoch 127/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4022e-04 - mean_absolute_error: 0.0124
# Epoch 128/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2355e-04 - mean_absolute_error: 0.0126
# Epoch 129/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6665e-04 - mean_absolute_error: 0.0137
# Epoch 130/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3852e-04 - mean_absolute_error: 0.0129
# Epoch 131/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3067e-04 - mean_absolute_error: 0.0121
# Epoch 132/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2739e-04 - mean_absolute_error: 0.0120
# Epoch 133/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4751e-04 - mean_absolute_error: 0.0125
# Epoch 134/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2796e-04 - mean_absolute_error: 0.0118
# Epoch 135/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2998e-04 - mean_absolute_error: 0.0117
# Epoch 136/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6974e-04 - mean_absolute_error: 0.0126
# Epoch 137/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8471e-04 - mean_absolute_error: 0.0137
# Epoch 138/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4921e-04 - mean_absolute_error: 0.0125
# Epoch 139/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3669e-04 - mean_absolute_error: 0.0126
# Epoch 140/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0615e-04 - mean_absolute_error: 0.0118
# Epoch 141/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4139e-04 - mean_absolute_error: 0.0125
# Epoch 142/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3254e-04 - mean_absolute_error: 0.0123
# Epoch 143/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7653e-04 - mean_absolute_error: 0.0129
# Epoch 144/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6624e-04 - mean_absolute_error: 0.0127
# Epoch 145/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4243e-04 - mean_absolute_error: 0.0123
# Epoch 146/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3838e-04 - mean_absolute_error: 0.0123
# Epoch 147/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1384e-04 - mean_absolute_error: 0.0116
# Epoch 148/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7318e-04 - mean_absolute_error: 0.0131
# Epoch 149/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9304e-04 - mean_absolute_error: 0.0114
# Epoch 150/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3859e-04 - mean_absolute_error: 0.0127
# Epoch 151/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4212e-04 - mean_absolute_error: 0.0133
# Epoch 152/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6881e-04 - mean_absolute_error: 0.0129
# Epoch 153/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4885e-04 - mean_absolute_error: 0.0124
# Epoch 154/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3028e-04 - mean_absolute_error: 0.0122
# Epoch 155/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1959e-04 - mean_absolute_error: 0.0120
# Epoch 156/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2741e-04 - mean_absolute_error: 0.0119
# Epoch 157/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2276e-04 - mean_absolute_error: 0.0150
# Epoch 158/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3271e-04 - mean_absolute_error: 0.0121
# Epoch 159/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5541e-04 - mean_absolute_error: 0.0125
# Epoch 160/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5339e-04 - mean_absolute_error: 0.0125
# Epoch 161/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8254e-04 - mean_absolute_error: 0.0129
# Epoch 162/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4241e-04 - mean_absolute_error: 0.0125
# Epoch 163/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4133e-04 - mean_absolute_error: 0.0125
# Epoch 164/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7753e-04 - mean_absolute_error: 0.0127
# Epoch 165/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1310e-04 - mean_absolute_error: 0.0122
# Epoch 166/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9049e-04 - mean_absolute_error: 0.0136
# Epoch 167/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5579e-04 - mean_absolute_error: 0.0128
# Epoch 168/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3882e-04 - mean_absolute_error: 0.0122
# Epoch 169/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1125e-04 - mean_absolute_error: 0.0118
# Epoch 170/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3450e-04 - mean_absolute_error: 0.0126
# Epoch 171/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4986e-04 - mean_absolute_error: 0.0124
# Epoch 172/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2529e-04 - mean_absolute_error: 0.0118
# Epoch 173/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1706e-04 - mean_absolute_error: 0.0119
# Epoch 174/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3982e-04 - mean_absolute_error: 0.0122
# Epoch 175/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5532e-04 - mean_absolute_error: 0.0128
# Epoch 176/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7419e-04 - mean_absolute_error: 0.0132
# Epoch 177/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7073e-04 - mean_absolute_error: 0.0130
# Epoch 178/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9995e-04 - mean_absolute_error: 0.0139
# Epoch 179/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6086e-04 - mean_absolute_error: 0.0128
# Epoch 180/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6867e-04 - mean_absolute_error: 0.0131
# Epoch 181/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7633e-04 - mean_absolute_error: 0.0138
# Epoch 182/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4095e-04 - mean_absolute_error: 0.0123
# Epoch 183/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7982e-04 - mean_absolute_error: 0.0133
# Epoch 184/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3131e-04 - mean_absolute_error: 0.0122
# Epoch 185/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0450e-04 - mean_absolute_error: 0.0121
# Epoch 186/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4711e-04 - mean_absolute_error: 0.0121
# Epoch 187/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3846e-04 - mean_absolute_error: 0.0123
# Epoch 188/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3234e-04 - mean_absolute_error: 0.0125
# Epoch 189/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5186e-04 - mean_absolute_error: 0.0126
# Epoch 190/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9153e-04 - mean_absolute_error: 0.0132
# Epoch 191/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7331e-04 - mean_absolute_error: 0.0129
# Epoch 192/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9383e-04 - mean_absolute_error: 0.0131
# Epoch 193/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9288e-04 - mean_absolute_error: 0.0129
# Epoch 194/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3230e-04 - mean_absolute_error: 0.0123
# Epoch 195/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6430e-04 - mean_absolute_error: 0.0127
# Epoch 196/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8726e-04 - mean_absolute_error: 0.0132
# Epoch 197/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5284e-04 - mean_absolute_error: 0.0124
# Epoch 198/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5580e-04 - mean_absolute_error: 0.0124
# Epoch 199/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5092e-04 - mean_absolute_error: 0.0130
# Epoch 200/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0344e-04 - mean_absolute_error: 0.0118

# %% [markdown]
# ### Predicting with test set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1420e-04 - mean_absolute_error: 0.0077
# Test Loss: [0.00015857892867643386, 0.008854900486767292]

# %%
# Splitting data into train, test set again to evaluate, because i shaped the data between 0 to 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 121
# 132

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)
# Out:
# Model evalution on test set
# MSE: 82420.3211101737
# RMSE: 287.0893956769802
# MAE: 187.53787609762398
# MAPE: 1.7912722596643873 %

# %% [markdown]
# ## 4. Forecast the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(test_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
y_pred_30_days
# Out:
# array([[12752.018 ],
#        [12674.797 ],
#        [12758.931 ],
#        [12709.122 ],
#        [12748.014 ],
#        [12723.164 ],
#        [12741.309 ],
#        [12728.943 ],
#        [12737.66  ],
#        [12731.645 ],
#        [12735.855 ],
#        [12732.931 ],
#        [12734.971 ],
#        [12733.551 ],
#        [12734.539 ],
#        [12733.854 ],
#        [12734.331 ],
#        [12733.996 ],
#        [12734.2295],
#        [12734.068 ],
#        [12734.181 ],
#        [12734.102 ],
#        [12734.156 ],
#        [12734.118 ],
#        [12734.1455],
#        [12734.128 ],
#        [12734.14  ],
#        [12734.132 ],
#        [12734.137 ],
#        [12734.133 ],
#        [12734.136 ]], dtype=float32)

# %% [markdown]
# ### Continue forecast the next 60/90 days

# %%
y_pred_60_days = forecast(test_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
y_pred_90_days = forecast(test_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")

    # Predict test
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        test_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Next {days} Days",
        linestyle="--",
    )

    plt.title(f"Forecast {stock_name[stock]} Stock Closing Price Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
