# %% [markdown]
# # Model: GRU (Gated Recurrent Unit)  - Stock Token: FPT - Test/Train/Vaildation: 60/20/20
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 2089.92
# - MAE: 1482.80
# - MAPE: 2.13 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 1  # 6 2 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#              close
# time
# 2019-03-01   19270
# 2019-03-04   19440
# 2019-03-05   19390
# 2019-03-06   19270
# 2019-03-07   19330
# ...            ...
# 2024-05-27  132800
# 2024-05-28  137000
# 2024-05-29  135700
# 2024-05-30  135000
# 2024-05-31  134600
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((776, 10), (776,), (251, 10), (251,), (253, 10), (253,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(100),
        Dense(32, activation="relu"),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 100)            │        30,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,165 (133.46 KB)
#  Trainable params: 34,165 (133.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 0.0199 - mean_absolute_error: 0.0977 - val_loss: 2.0481e-04 - val_mean_absolute_error: 0.0104
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 2.3047e-04 - mean_absolute_error: 0.0124 - val_loss: 2.6500e-04 - val_mean_absolute_error: 0.0127
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3790e-04 - mean_absolute_error: 0.0090 - val_loss: 1.7795e-04 - val_mean_absolute_error: 0.0092
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.7357e-05 - mean_absolute_error: 0.0066 - val_loss: 2.1973e-04 - val_mean_absolute_error: 0.0110
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 7.2842e-05 - mean_absolute_error: 0.0060 - val_loss: 1.9508e-04 - val_mean_absolute_error: 0.0100
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.8560e-05 - mean_absolute_error: 0.0060 - val_loss: 1.8007e-04 - val_mean_absolute_error: 0.0095
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.2379e-05 - mean_absolute_error: 0.0061 - val_loss: 1.6566e-04 - val_mean_absolute_error: 0.0088
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.5670e-05 - mean_absolute_error: 0.0058 - val_loss: 2.3436e-04 - val_mean_absolute_error: 0.0117
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.9563e-05 - mean_absolute_error: 0.0074 - val_loss: 1.6432e-04 - val_mean_absolute_error: 0.0089
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.8988e-05 - mean_absolute_error: 0.0056 - val_loss: 2.7609e-04 - val_mean_absolute_error: 0.0132
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 9.4645e-05 - mean_absolute_error: 0.0072 - val_loss: 1.5703e-04 - val_mean_absolute_error: 0.0085
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.6372e-05 - mean_absolute_error: 0.0056 - val_loss: 1.8482e-04 - val_mean_absolute_error: 0.0098
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.6658e-05 - mean_absolute_error: 0.0053 - val_loss: 2.6454e-04 - val_mean_absolute_error: 0.0129
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.7894e-05 - mean_absolute_error: 0.0066 - val_loss: 1.6524e-04 - val_mean_absolute_error: 0.0091
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.9541e-05 - mean_absolute_error: 0.0059 - val_loss: 1.7510e-04 - val_mean_absolute_error: 0.0095
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.5881e-05 - mean_absolute_error: 0.0055 - val_loss: 1.6691e-04 - val_mean_absolute_error: 0.0091
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 6.5864e-05 - mean_absolute_error: 0.0057 - val_loss: 2.8176e-04 - val_mean_absolute_error: 0.0136
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 7.0830e-05 - mean_absolute_error: 0.0058 - val_loss: 2.1667e-04 - val_mean_absolute_error: 0.0114
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.1388e-05 - mean_absolute_error: 0.0053 - val_loss: 1.5293e-04 - val_mean_absolute_error: 0.0087
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.4772e-05 - mean_absolute_error: 0.0050 - val_loss: 1.4273e-04 - val_mean_absolute_error: 0.0080
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.2972e-05 - mean_absolute_error: 0.0054 - val_loss: 1.4217e-04 - val_mean_absolute_error: 0.0080
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.6585e-05 - mean_absolute_error: 0.0057 - val_loss: 1.7385e-04 - val_mean_absolute_error: 0.0097
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.9233e-05 - mean_absolute_error: 0.0060 - val_loss: 1.5001e-04 - val_mean_absolute_error: 0.0085
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.8484e-05 - mean_absolute_error: 0.0053 - val_loss: 1.9013e-04 - val_mean_absolute_error: 0.0105
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 6.0386e-05 - mean_absolute_error: 0.0056 - val_loss: 1.5667e-04 - val_mean_absolute_error: 0.0088
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.0432e-05 - mean_absolute_error: 0.0055 - val_loss: 1.7275e-04 - val_mean_absolute_error: 0.0099
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 7.3148e-05 - mean_absolute_error: 0.0060 - val_loss: 1.5001e-04 - val_mean_absolute_error: 0.0086
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.2432e-05 - mean_absolute_error: 0.0055 - val_loss: 1.3522e-04 - val_mean_absolute_error: 0.0079
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.7676e-05 - mean_absolute_error: 0.0051 - val_loss: 1.4766e-04 - val_mean_absolute_error: 0.0085
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.7849e-05 - mean_absolute_error: 0.0054 - val_loss: 1.3327e-04 - val_mean_absolute_error: 0.0078
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 6.6680e-05 - mean_absolute_error: 0.0053 - val_loss: 1.3825e-04 - val_mean_absolute_error: 0.0080
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.6297e-05 - mean_absolute_error: 0.0049 - val_loss: 2.7100e-04 - val_mean_absolute_error: 0.0136
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.2117e-05 - mean_absolute_error: 0.0061 - val_loss: 1.7845e-04 - val_mean_absolute_error: 0.0101
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.2012e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2889e-04 - val_mean_absolute_error: 0.0076
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.0186e-05 - mean_absolute_error: 0.0049 - val_loss: 1.3467e-04 - val_mean_absolute_error: 0.0079
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.2819e-05 - mean_absolute_error: 0.0051 - val_loss: 1.3135e-04 - val_mean_absolute_error: 0.0077
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.8159e-05 - mean_absolute_error: 0.0049 - val_loss: 1.3055e-04 - val_mean_absolute_error: 0.0078
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.8121e-05 - mean_absolute_error: 0.0051 - val_loss: 1.5289e-04 - val_mean_absolute_error: 0.0092
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 7.6100e-05 - mean_absolute_error: 0.0060 - val_loss: 1.7632e-04 - val_mean_absolute_error: 0.0101
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.3620e-05 - mean_absolute_error: 0.0056 - val_loss: 1.2572e-04 - val_mean_absolute_error: 0.0075
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.7942e-05 - mean_absolute_error: 0.0050 - val_loss: 1.3014e-04 - val_mean_absolute_error: 0.0079
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.8970e-05 - mean_absolute_error: 0.0056 - val_loss: 1.2302e-04 - val_mean_absolute_error: 0.0073
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 5.3521e-05 - mean_absolute_error: 0.0052 - val_loss: 1.2270e-04 - val_mean_absolute_error: 0.0074
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.4493e-05 - mean_absolute_error: 0.0053 - val_loss: 1.4773e-04 - val_mean_absolute_error: 0.0088
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.1224e-05 - mean_absolute_error: 0.0056 - val_loss: 3.0610e-04 - val_mean_absolute_error: 0.0149
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.6992e-05 - mean_absolute_error: 0.0058 - val_loss: 1.4190e-04 - val_mean_absolute_error: 0.0085
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.5792e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2930e-04 - val_mean_absolute_error: 0.0077
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.9369e-05 - mean_absolute_error: 0.0048 - val_loss: 1.4114e-04 - val_mean_absolute_error: 0.0084
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.5825e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2513e-04 - val_mean_absolute_error: 0.0075
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.3594e-05 - mean_absolute_error: 0.0045 - val_loss: 1.2244e-04 - val_mean_absolute_error: 0.0075
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.1441e-05 - mean_absolute_error: 0.0047 - val_loss: 1.4263e-04 - val_mean_absolute_error: 0.0086
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.1315e-05 - mean_absolute_error: 0.0051 - val_loss: 1.2431e-04 - val_mean_absolute_error: 0.0074
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.0513e-05 - mean_absolute_error: 0.0049 - val_loss: 1.1916e-04 - val_mean_absolute_error: 0.0072
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.6356e-05 - mean_absolute_error: 0.0046 - val_loss: 1.6483e-04 - val_mean_absolute_error: 0.0100
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.6966e-05 - mean_absolute_error: 0.0057 - val_loss: 1.2393e-04 - val_mean_absolute_error: 0.0077
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.3643e-05 - mean_absolute_error: 0.0053 - val_loss: 1.6320e-04 - val_mean_absolute_error: 0.0096
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.9504e-05 - mean_absolute_error: 0.0048 - val_loss: 1.1763e-04 - val_mean_absolute_error: 0.0071
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.0056e-05 - mean_absolute_error: 0.0048 - val_loss: 1.1633e-04 - val_mean_absolute_error: 0.0071
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.4111e-05 - mean_absolute_error: 0.0049 - val_loss: 1.4026e-04 - val_mean_absolute_error: 0.0085
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.6774e-05 - mean_absolute_error: 0.0050 - val_loss: 1.3379e-04 - val_mean_absolute_error: 0.0084
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.4099e-05 - mean_absolute_error: 0.0062 - val_loss: 1.1825e-04 - val_mean_absolute_error: 0.0073
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.1054e-05 - mean_absolute_error: 0.0061 - val_loss: 1.1630e-04 - val_mean_absolute_error: 0.0071
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.0420e-05 - mean_absolute_error: 0.0048 - val_loss: 2.2399e-04 - val_mean_absolute_error: 0.0122
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.7452e-05 - mean_absolute_error: 0.0048 - val_loss: 1.2002e-04 - val_mean_absolute_error: 0.0073
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.3018e-05 - mean_absolute_error: 0.0044 - val_loss: 1.3785e-04 - val_mean_absolute_error: 0.0084
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.7696e-05 - mean_absolute_error: 0.0046 - val_loss: 1.5266e-04 - val_mean_absolute_error: 0.0095
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.6084e-05 - mean_absolute_error: 0.0057 - val_loss: 1.2006e-04 - val_mean_absolute_error: 0.0074
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.4650e-05 - mean_absolute_error: 0.0059 - val_loss: 1.5287e-04 - val_mean_absolute_error: 0.0095
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5719e-05 - mean_absolute_error: 0.0049 - val_loss: 1.4927e-04 - val_mean_absolute_error: 0.0091
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.2550e-05 - mean_absolute_error: 0.0063 - val_loss: 1.2145e-04 - val_mean_absolute_error: 0.0076
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.7968e-05 - mean_absolute_error: 0.0047 - val_loss: 1.5034e-04 - val_mean_absolute_error: 0.0094
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.0053e-05 - mean_absolute_error: 0.0051 - val_loss: 1.1662e-04 - val_mean_absolute_error: 0.0072
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.6218e-05 - mean_absolute_error: 0.0049 - val_loss: 1.6959e-04 - val_mean_absolute_error: 0.0103
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.3240e-05 - mean_absolute_error: 0.0064 - val_loss: 1.3309e-04 - val_mean_absolute_error: 0.0082
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.6443e-05 - mean_absolute_error: 0.0050 - val_loss: 1.4932e-04 - val_mean_absolute_error: 0.0091
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.6805e-05 - mean_absolute_error: 0.0051 - val_loss: 1.1207e-04 - val_mean_absolute_error: 0.0069
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.0742e-05 - mean_absolute_error: 0.0051 - val_loss: 1.4957e-04 - val_mean_absolute_error: 0.0091
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.4619e-05 - mean_absolute_error: 0.0046 - val_loss: 1.5909e-04 - val_mean_absolute_error: 0.0096
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.1261e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2347e-04 - val_mean_absolute_error: 0.0077
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 5.2666e-05 - mean_absolute_error: 0.0048 - val_loss: 1.1999e-04 - val_mean_absolute_error: 0.0074
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.0231e-05 - mean_absolute_error: 0.0050 - val_loss: 1.6159e-04 - val_mean_absolute_error: 0.0097
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 5.7168e-05 - mean_absolute_error: 0.0054 - val_loss: 1.1509e-04 - val_mean_absolute_error: 0.0072
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.8533e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1171e-04 - val_mean_absolute_error: 0.0070
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.0197e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1073e-04 - val_mean_absolute_error: 0.0069
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.1496e-05 - mean_absolute_error: 0.0049 - val_loss: 1.8306e-04 - val_mean_absolute_error: 0.0107
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.8920e-05 - mean_absolute_error: 0.0049 - val_loss: 1.1313e-04 - val_mean_absolute_error: 0.0071
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.4149e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1213e-04 - val_mean_absolute_error: 0.0070
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.6324e-05 - mean_absolute_error: 0.0046 - val_loss: 1.3913e-04 - val_mean_absolute_error: 0.0089
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.1263e-05 - mean_absolute_error: 0.0045 - val_loss: 1.1378e-04 - val_mean_absolute_error: 0.0071
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.2727e-05 - mean_absolute_error: 0.0052 - val_loss: 1.6754e-04 - val_mean_absolute_error: 0.0101
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.8488e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1978e-04 - val_mean_absolute_error: 0.0077
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.3586e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1153e-04 - val_mean_absolute_error: 0.0071
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.0685e-05 - mean_absolute_error: 0.0045 - val_loss: 1.1086e-04 - val_mean_absolute_error: 0.0070
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.5708e-05 - mean_absolute_error: 0.0050 - val_loss: 1.4315e-04 - val_mean_absolute_error: 0.0089
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.7853e-05 - mean_absolute_error: 0.0056 - val_loss: 1.4816e-04 - val_mean_absolute_error: 0.0094
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 6.1807e-05 - mean_absolute_error: 0.0057 - val_loss: 1.3238e-04 - val_mean_absolute_error: 0.0085
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.8713e-05 - mean_absolute_error: 0.0059 - val_loss: 1.3743e-04 - val_mean_absolute_error: 0.0088
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.6410e-05 - mean_absolute_error: 0.0050 - val_loss: 1.0875e-04 - val_mean_absolute_error: 0.0068
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.9075e-05 - mean_absolute_error: 0.0041 - val_loss: 1.2531e-04 - val_mean_absolute_error: 0.0081
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.4820e-05 - mean_absolute_error: 0.0051 - val_loss: 1.1401e-04 - val_mean_absolute_error: 0.0072
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.2264e-05 - mean_absolute_error: 0.0045 - val_loss: 1.3796e-04 - val_mean_absolute_error: 0.0086
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.6028e-05 - mean_absolute_error: 0.0046 - val_loss: 1.4150e-04 - val_mean_absolute_error: 0.0088
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.7104e-05 - mean_absolute_error: 0.0047 - val_loss: 2.0392e-04 - val_mean_absolute_error: 0.0119
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.4572e-05 - mean_absolute_error: 0.0053 - val_loss: 1.1144e-04 - val_mean_absolute_error: 0.0070
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.4003e-05 - mean_absolute_error: 0.0044 - val_loss: 1.3713e-04 - val_mean_absolute_error: 0.0086
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.7123e-05 - mean_absolute_error: 0.0047 - val_loss: 1.7930e-04 - val_mean_absolute_error: 0.0109
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 6.1763e-05 - mean_absolute_error: 0.0058 - val_loss: 1.6472e-04 - val_mean_absolute_error: 0.0100
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.7858e-05 - mean_absolute_error: 0.0051 - val_loss: 1.0808e-04 - val_mean_absolute_error: 0.0068
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.8184e-05 - mean_absolute_error: 0.0042 - val_loss: 1.3329e-04 - val_mean_absolute_error: 0.0086
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.7704e-05 - mean_absolute_error: 0.0061 - val_loss: 1.1678e-04 - val_mean_absolute_error: 0.0073
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.1370e-05 - mean_absolute_error: 0.0050 - val_loss: 1.0717e-04 - val_mean_absolute_error: 0.0068
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.3572e-05 - mean_absolute_error: 0.0049 - val_loss: 2.3969e-04 - val_mean_absolute_error: 0.0130
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.9531e-05 - mean_absolute_error: 0.0056 - val_loss: 1.1458e-04 - val_mean_absolute_error: 0.0075
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.6626e-05 - mean_absolute_error: 0.0051 - val_loss: 1.5216e-04 - val_mean_absolute_error: 0.0094
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.6307e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1096e-04 - val_mean_absolute_error: 0.0072
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.6405e-05 - mean_absolute_error: 0.0046 - val_loss: 1.0804e-04 - val_mean_absolute_error: 0.0070
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.3418e-05 - mean_absolute_error: 0.0051 - val_loss: 1.1919e-04 - val_mean_absolute_error: 0.0075
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.4886e-05 - mean_absolute_error: 0.0045 - val_loss: 1.1767e-04 - val_mean_absolute_error: 0.0075
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.1213e-05 - mean_absolute_error: 0.0051 - val_loss: 1.0906e-04 - val_mean_absolute_error: 0.0071
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.3307e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1063e-04 - val_mean_absolute_error: 0.0070
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.7759e-05 - mean_absolute_error: 0.0051 - val_loss: 1.0755e-04 - val_mean_absolute_error: 0.0069
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.4930e-05 - mean_absolute_error: 0.0046 - val_loss: 1.0581e-04 - val_mean_absolute_error: 0.0068
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.0317e-05 - mean_absolute_error: 0.0041 - val_loss: 1.1422e-04 - val_mean_absolute_error: 0.0072
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.5471e-05 - mean_absolute_error: 0.0049 - val_loss: 1.5613e-04 - val_mean_absolute_error: 0.0099
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.0013e-05 - mean_absolute_error: 0.0051 - val_loss: 1.4425e-04 - val_mean_absolute_error: 0.0091
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 5.8920e-05 - mean_absolute_error: 0.0057 - val_loss: 1.2044e-04 - val_mean_absolute_error: 0.0076
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.8015e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2118e-04 - val_mean_absolute_error: 0.0077
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.0343e-05 - mean_absolute_error: 0.0046 - val_loss: 1.8361e-04 - val_mean_absolute_error: 0.0109
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 6.3882e-05 - mean_absolute_error: 0.0062 - val_loss: 1.2242e-04 - val_mean_absolute_error: 0.0078
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.0646e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1891e-04 - val_mean_absolute_error: 0.0078
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.4801e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1165e-04 - val_mean_absolute_error: 0.0073
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.9976e-05 - mean_absolute_error: 0.0042 - val_loss: 1.0564e-04 - val_mean_absolute_error: 0.0067
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7988e-05 - mean_absolute_error: 0.0041 - val_loss: 1.0595e-04 - val_mean_absolute_error: 0.0067
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.8646e-05 - mean_absolute_error: 0.0048 - val_loss: 1.2295e-04 - val_mean_absolute_error: 0.0081
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.3699e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1393e-04 - val_mean_absolute_error: 0.0072
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.5075e-05 - mean_absolute_error: 0.0047 - val_loss: 1.0492e-04 - val_mean_absolute_error: 0.0067
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.9200e-05 - mean_absolute_error: 0.0049 - val_loss: 1.0449e-04 - val_mean_absolute_error: 0.0067
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.4678e-05 - mean_absolute_error: 0.0046 - val_loss: 1.0814e-04 - val_mean_absolute_error: 0.0071
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.2193e-05 - mean_absolute_error: 0.0048 - val_loss: 1.0465e-04 - val_mean_absolute_error: 0.0067
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.0337e-05 - mean_absolute_error: 0.0040 - val_loss: 1.2372e-04 - val_mean_absolute_error: 0.0079
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.4908e-05 - mean_absolute_error: 0.0044 - val_loss: 1.2402e-04 - val_mean_absolute_error: 0.0082
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.2134e-05 - mean_absolute_error: 0.0048 - val_loss: 1.6404e-04 - val_mean_absolute_error: 0.0100
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.1934e-05 - mean_absolute_error: 0.0051 - val_loss: 1.5663e-04 - val_mean_absolute_error: 0.0099
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.1778e-05 - mean_absolute_error: 0.0052 - val_loss: 1.2293e-04 - val_mean_absolute_error: 0.0078
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.0441e-05 - mean_absolute_error: 0.0043 - val_loss: 1.0704e-04 - val_mean_absolute_error: 0.0068
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.3304e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1698e-04 - val_mean_absolute_error: 0.0074
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.9778e-05 - mean_absolute_error: 0.0050 - val_loss: 1.0897e-04 - val_mean_absolute_error: 0.0069
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.3456e-05 - mean_absolute_error: 0.0047 - val_loss: 1.2208e-04 - val_mean_absolute_error: 0.0080
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.4781e-05 - mean_absolute_error: 0.0047 - val_loss: 1.0494e-04 - val_mean_absolute_error: 0.0067
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.3062e-05 - mean_absolute_error: 0.0045 - val_loss: 1.3245e-04 - val_mean_absolute_error: 0.0084
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.1356e-05 - mean_absolute_error: 0.0048 - val_loss: 1.0821e-04 - val_mean_absolute_error: 0.0071
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5103e-05 - mean_absolute_error: 0.0045 - val_loss: 1.1383e-04 - val_mean_absolute_error: 0.0075
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.9371e-05 - mean_absolute_error: 0.0049 - val_loss: 1.4550e-04 - val_mean_absolute_error: 0.0091
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.1990e-05 - mean_absolute_error: 0.0054 - val_loss: 1.1573e-04 - val_mean_absolute_error: 0.0074
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.8370e-05 - mean_absolute_error: 0.0041 - val_loss: 1.4610e-04 - val_mean_absolute_error: 0.0094
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.9051e-05 - mean_absolute_error: 0.0050 - val_loss: 1.0968e-04 - val_mean_absolute_error: 0.0072
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.2695e-05 - mean_absolute_error: 0.0045 - val_loss: 1.1150e-04 - val_mean_absolute_error: 0.0071
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.9731e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1939e-04 - val_mean_absolute_error: 0.0079
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.8783e-05 - mean_absolute_error: 0.0049 - val_loss: 1.2156e-04 - val_mean_absolute_error: 0.0078
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.4579e-05 - mean_absolute_error: 0.0045 - val_loss: 1.3833e-04 - val_mean_absolute_error: 0.0090
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.4922e-05 - mean_absolute_error: 0.0058 - val_loss: 1.5634e-04 - val_mean_absolute_error: 0.0099
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.5050e-05 - mean_absolute_error: 0.0055 - val_loss: 1.0559e-04 - val_mean_absolute_error: 0.0067
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.2048e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1525e-04 - val_mean_absolute_error: 0.0074
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.0522e-05 - mean_absolute_error: 0.0049 - val_loss: 2.1246e-04 - val_mean_absolute_error: 0.0121
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.7031e-05 - mean_absolute_error: 0.0046 - val_loss: 1.2178e-04 - val_mean_absolute_error: 0.0078
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.7528e-05 - mean_absolute_error: 0.0054 - val_loss: 2.7116e-04 - val_mean_absolute_error: 0.0144
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 7.5753e-05 - mean_absolute_error: 0.0064 - val_loss: 1.0812e-04 - val_mean_absolute_error: 0.0071
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.9238e-05 - mean_absolute_error: 0.0048 - val_loss: 1.0404e-04 - val_mean_absolute_error: 0.0066
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.3083e-05 - mean_absolute_error: 0.0045 - val_loss: 1.0457e-04 - val_mean_absolute_error: 0.0067
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.9336e-05 - mean_absolute_error: 0.0049 - val_loss: 1.2553e-04 - val_mean_absolute_error: 0.0083
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.8361e-05 - mean_absolute_error: 0.0042 - val_loss: 1.1027e-04 - val_mean_absolute_error: 0.0070
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.2621e-05 - mean_absolute_error: 0.0044 - val_loss: 1.0625e-04 - val_mean_absolute_error: 0.0068
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.3480e-05 - mean_absolute_error: 0.0042 - val_loss: 1.5014e-04 - val_mean_absolute_error: 0.0094
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.0093e-05 - mean_absolute_error: 0.0048 - val_loss: 1.0732e-04 - val_mean_absolute_error: 0.0070
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.9036e-05 - mean_absolute_error: 0.0042 - val_loss: 1.2721e-04 - val_mean_absolute_error: 0.0084
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.0058e-05 - mean_absolute_error: 0.0050 - val_loss: 1.0455e-04 - val_mean_absolute_error: 0.0067
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.6045e-05 - mean_absolute_error: 0.0045 - val_loss: 1.0548e-04 - val_mean_absolute_error: 0.0068
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.6923e-05 - mean_absolute_error: 0.0047 - val_loss: 1.5386e-04 - val_mean_absolute_error: 0.0096
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.7291e-05 - mean_absolute_error: 0.0050 - val_loss: 1.3296e-04 - val_mean_absolute_error: 0.0088
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.3110e-05 - mean_absolute_error: 0.0048 - val_loss: 1.0344e-04 - val_mean_absolute_error: 0.0066
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.6001e-05 - mean_absolute_error: 0.0054 - val_loss: 1.3809e-04 - val_mean_absolute_error: 0.0090
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.8186e-05 - mean_absolute_error: 0.0053 - val_loss: 1.0622e-04 - val_mean_absolute_error: 0.0069
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.1940e-05 - mean_absolute_error: 0.0045 - val_loss: 1.4393e-04 - val_mean_absolute_error: 0.0093
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.3901e-05 - mean_absolute_error: 0.0053 - val_loss: 1.6703e-04 - val_mean_absolute_error: 0.0102
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.7571e-05 - mean_absolute_error: 0.0052 - val_loss: 1.1558e-04 - val_mean_absolute_error: 0.0077
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.9064e-05 - mean_absolute_error: 0.0043 - val_loss: 1.0484e-04 - val_mean_absolute_error: 0.0067
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6465e-05 - mean_absolute_error: 0.0041 - val_loss: 1.6554e-04 - val_mean_absolute_error: 0.0102
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.1341e-05 - mean_absolute_error: 0.0055 - val_loss: 1.2498e-04 - val_mean_absolute_error: 0.0080
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.2231e-05 - mean_absolute_error: 0.0045 - val_loss: 1.0652e-04 - val_mean_absolute_error: 0.0068
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.2351e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1864e-04 - val_mean_absolute_error: 0.0076
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.7531e-05 - mean_absolute_error: 0.0048 - val_loss: 1.3821e-04 - val_mean_absolute_error: 0.0090
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.6755e-05 - mean_absolute_error: 0.0048 - val_loss: 1.5044e-04 - val_mean_absolute_error: 0.0094
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.5104e-05 - mean_absolute_error: 0.0046 - val_loss: 1.2987e-04 - val_mean_absolute_error: 0.0086
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.7517e-05 - mean_absolute_error: 0.0043 - val_loss: 1.1683e-04 - val_mean_absolute_error: 0.0077
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.0212e-05 - mean_absolute_error: 0.0048 - val_loss: 1.0946e-04 - val_mean_absolute_error: 0.0072
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.1007e-05 - mean_absolute_error: 0.0045 - val_loss: 1.3991e-04 - val_mean_absolute_error: 0.0091
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5198e-05 - mean_absolute_error: 0.0048 - val_loss: 1.0620e-04 - val_mean_absolute_error: 0.0068
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.1038e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1886e-04 - val_mean_absolute_error: 0.0079
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.9850e-05 - mean_absolute_error: 0.0055 - val_loss: 1.0480e-04 - val_mean_absolute_error: 0.0068
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.9759e-05 - mean_absolute_error: 0.0049 - val_loss: 1.0900e-04 - val_mean_absolute_error: 0.0070

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 192ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6897e-04 - mean_absolute_error: 0.0089
# Test Loss: [0.00010900094639509916, 0.006976599805057049]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 3010223.246898271
# RMSE: 1734.99949478329
# MAE: 1184.3646040836654
# MAPE: 1.7407321241477074 %
#
# Model evalution on validate set
# MSE: 5737622.5733145615
# RMSE: 2395.3334993930516
# MAE: 1679.013401679842
# MAPE: 1.658911008070445 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step

# %%
y_pred_30_days
# Out:
# array([[133052.4 ],
#        [133243.16],
#        [132929.12],
#        [132963.52],
#        [132873.06],
#        [132889.75],
#        [132868.77],
#        [132873.53],
#        [132868.17],
#        [132869.67],
#        [132868.34],
#        [132868.77],
#        [132868.42],
#        [132868.55],
#        [132868.47],
#        [132868.5 ],
#        [132868.47],
#        [132868.48],
#        [132868.48],
#        [132868.48],
#        [132868.48],
#        [132868.48],
#        [132868.48],
#        [132868.48],
#        [132868.48],
#        [132868.48],
#        [132868.48],
#        [132868.48],
#        [132868.48],
#        [132868.48],
#        [132868.48]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
