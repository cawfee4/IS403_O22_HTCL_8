# %% [markdown]
# # Model: GRU (Gated Recurrent Unit)  - Stock Token: FPT - Test/Train/Vaildation: 60/20/20
# - Dataset: 1313 rows x 7 columns (01/03/2019 - 31/05/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1723.26
# - MAE: 1175.64
# - MAPE: 1.72 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

plt.style.use("default")

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 1  # 6 2 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#              close
# time
# 2019-03-01   19270
# 2019-03-04   19440
# 2019-03-05   19390
# 2019-03-06   19270
# 2019-03-07   19330
# ...            ...
# 2024-05-27  132800
# 2024-05-28  137000
# 2024-05-29  135700
# 2024-05-30  135000
# 2024-05-31  134600
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((776, 10), (776,), (251, 10), (251,), (253, 10), (253,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(100),
        Dense(32, activation="relu"),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 100)            │        30,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,165 (133.46 KB)
#  Trainable params: 34,165 (133.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0188 - mean_absolute_error: 0.0959 - val_loss: 2.7163e-04 - val_mean_absolute_error: 0.0132
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8731e-04 - mean_absolute_error: 0.0151 - val_loss: 1.6518e-04 - val_mean_absolute_error: 0.0088
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3483e-04 - mean_absolute_error: 0.0083 - val_loss: 2.4506e-04 - val_mean_absolute_error: 0.0121
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4732e-05 - mean_absolute_error: 0.0062 - val_loss: 1.6305e-04 - val_mean_absolute_error: 0.0087
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1381e-05 - mean_absolute_error: 0.0060 - val_loss: 2.3384e-04 - val_mean_absolute_error: 0.0118
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.5585e-05 - mean_absolute_error: 0.0062 - val_loss: 1.5691e-04 - val_mean_absolute_error: 0.0085
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6910e-05 - mean_absolute_error: 0.0056 - val_loss: 2.0069e-04 - val_mean_absolute_error: 0.0105
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1030e-05 - mean_absolute_error: 0.0056 - val_loss: 1.8557e-04 - val_mean_absolute_error: 0.0099
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3470e-05 - mean_absolute_error: 0.0055 - val_loss: 1.9554e-04 - val_mean_absolute_error: 0.0104
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.8153e-05 - mean_absolute_error: 0.0058 - val_loss: 1.5222e-04 - val_mean_absolute_error: 0.0083
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.8650e-05 - mean_absolute_error: 0.0056 - val_loss: 2.2085e-04 - val_mean_absolute_error: 0.0115
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3680e-05 - mean_absolute_error: 0.0053 - val_loss: 1.4904e-04 - val_mean_absolute_error: 0.0082
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2944e-05 - mean_absolute_error: 0.0054 - val_loss: 1.5598e-04 - val_mean_absolute_error: 0.0086
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9589e-05 - mean_absolute_error: 0.0051 - val_loss: 1.9108e-04 - val_mean_absolute_error: 0.0105
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.9737e-05 - mean_absolute_error: 0.0064 - val_loss: 2.5934e-04 - val_mean_absolute_error: 0.0130
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8180e-05 - mean_absolute_error: 0.0075 - val_loss: 1.9584e-04 - val_mean_absolute_error: 0.0107
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7726e-05 - mean_absolute_error: 0.0059 - val_loss: 1.6576e-04 - val_mean_absolute_error: 0.0092
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4417e-05 - mean_absolute_error: 0.0051 - val_loss: 1.4300e-04 - val_mean_absolute_error: 0.0081
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9179e-05 - mean_absolute_error: 0.0054 - val_loss: 1.7459e-04 - val_mean_absolute_error: 0.0096
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5009e-05 - mean_absolute_error: 0.0063 - val_loss: 1.8798e-04 - val_mean_absolute_error: 0.0103
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1861e-05 - mean_absolute_error: 0.0053 - val_loss: 1.6945e-04 - val_mean_absolute_error: 0.0094
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8856e-05 - mean_absolute_error: 0.0052 - val_loss: 1.4870e-04 - val_mean_absolute_error: 0.0084
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5601e-05 - mean_absolute_error: 0.0057 - val_loss: 1.4441e-04 - val_mean_absolute_error: 0.0082
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1564e-05 - mean_absolute_error: 0.0054 - val_loss: 1.4151e-04 - val_mean_absolute_error: 0.0080
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7653e-05 - mean_absolute_error: 0.0050 - val_loss: 1.9869e-04 - val_mean_absolute_error: 0.0110
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5508e-05 - mean_absolute_error: 0.0056 - val_loss: 1.4797e-04 - val_mean_absolute_error: 0.0084
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8161e-05 - mean_absolute_error: 0.0050 - val_loss: 1.6682e-04 - val_mean_absolute_error: 0.0096
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3816e-05 - mean_absolute_error: 0.0052 - val_loss: 1.7928e-04 - val_mean_absolute_error: 0.0101
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7448e-05 - mean_absolute_error: 0.0055 - val_loss: 1.3395e-04 - val_mean_absolute_error: 0.0077
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8893e-05 - mean_absolute_error: 0.0062 - val_loss: 1.9173e-04 - val_mean_absolute_error: 0.0108
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.4510e-05 - mean_absolute_error: 0.0066 - val_loss: 1.3237e-04 - val_mean_absolute_error: 0.0076
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4845e-05 - mean_absolute_error: 0.0051 - val_loss: 1.3070e-04 - val_mean_absolute_error: 0.0075
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0722e-05 - mean_absolute_error: 0.0049 - val_loss: 1.3305e-04 - val_mean_absolute_error: 0.0077
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3514e-05 - mean_absolute_error: 0.0049 - val_loss: 1.3483e-04 - val_mean_absolute_error: 0.0079
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7771e-05 - mean_absolute_error: 0.0053 - val_loss: 1.3179e-04 - val_mean_absolute_error: 0.0077
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5166e-05 - mean_absolute_error: 0.0052 - val_loss: 1.6105e-04 - val_mean_absolute_error: 0.0093
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7865e-05 - mean_absolute_error: 0.0056 - val_loss: 1.4690e-04 - val_mean_absolute_error: 0.0086
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0438e-05 - mean_absolute_error: 0.0048 - val_loss: 1.3126e-04 - val_mean_absolute_error: 0.0078
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4707e-05 - mean_absolute_error: 0.0051 - val_loss: 1.8484e-04 - val_mean_absolute_error: 0.0105
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2029e-05 - mean_absolute_error: 0.0051 - val_loss: 1.3294e-04 - val_mean_absolute_error: 0.0079
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9633e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2746e-04 - val_mean_absolute_error: 0.0076
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8075e-05 - mean_absolute_error: 0.0047 - val_loss: 1.3290e-04 - val_mean_absolute_error: 0.0080
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9894e-05 - mean_absolute_error: 0.0048 - val_loss: 1.3242e-04 - val_mean_absolute_error: 0.0078
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8576e-05 - mean_absolute_error: 0.0047 - val_loss: 1.5037e-04 - val_mean_absolute_error: 0.0090
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.9582e-05 - mean_absolute_error: 0.0063 - val_loss: 1.2721e-04 - val_mean_absolute_error: 0.0076
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3965e-05 - mean_absolute_error: 0.0052 - val_loss: 1.2315e-04 - val_mean_absolute_error: 0.0073
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4653e-05 - mean_absolute_error: 0.0049 - val_loss: 1.7981e-04 - val_mean_absolute_error: 0.0103
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0379e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3753e-04 - val_mean_absolute_error: 0.0082
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3319e-05 - mean_absolute_error: 0.0051 - val_loss: 1.2433e-04 - val_mean_absolute_error: 0.0074
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0340e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2745e-04 - val_mean_absolute_error: 0.0075
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1475e-05 - mean_absolute_error: 0.0043 - val_loss: 1.2858e-04 - val_mean_absolute_error: 0.0076
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1592e-05 - mean_absolute_error: 0.0048 - val_loss: 1.3783e-04 - val_mean_absolute_error: 0.0083
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9793e-05 - mean_absolute_error: 0.0048 - val_loss: 1.4041e-04 - val_mean_absolute_error: 0.0086
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8922e-05 - mean_absolute_error: 0.0061 - val_loss: 1.5444e-04 - val_mean_absolute_error: 0.0094
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9380e-05 - mean_absolute_error: 0.0060 - val_loss: 1.8063e-04 - val_mean_absolute_error: 0.0107
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2542e-05 - mean_absolute_error: 0.0054 - val_loss: 1.5599e-04 - val_mean_absolute_error: 0.0093
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0954e-05 - mean_absolute_error: 0.0048 - val_loss: 1.3357e-04 - val_mean_absolute_error: 0.0081
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3318e-05 - mean_absolute_error: 0.0051 - val_loss: 1.2372e-04 - val_mean_absolute_error: 0.0074
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7419e-05 - mean_absolute_error: 0.0050 - val_loss: 1.3469e-04 - val_mean_absolute_error: 0.0082
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3401e-05 - mean_absolute_error: 0.0052 - val_loss: 1.1838e-04 - val_mean_absolute_error: 0.0073
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0241e-05 - mean_absolute_error: 0.0049 - val_loss: 1.2675e-04 - val_mean_absolute_error: 0.0079
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7648e-05 - mean_absolute_error: 0.0048 - val_loss: 1.3690e-04 - val_mean_absolute_error: 0.0085
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8141e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1793e-04 - val_mean_absolute_error: 0.0071
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0980e-05 - mean_absolute_error: 0.0048 - val_loss: 1.4064e-04 - val_mean_absolute_error: 0.0085
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4642e-05 - mean_absolute_error: 0.0044 - val_loss: 2.0613e-04 - val_mean_absolute_error: 0.0115
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0345e-05 - mean_absolute_error: 0.0061 - val_loss: 1.2756e-04 - val_mean_absolute_error: 0.0078
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8979e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1517e-04 - val_mean_absolute_error: 0.0071
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6607e-05 - mean_absolute_error: 0.0045 - val_loss: 1.1533e-04 - val_mean_absolute_error: 0.0070
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2990e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1966e-04 - val_mean_absolute_error: 0.0073
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6473e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1637e-04 - val_mean_absolute_error: 0.0072
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9023e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1504e-04 - val_mean_absolute_error: 0.0071
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2639e-05 - mean_absolute_error: 0.0051 - val_loss: 1.2614e-04 - val_mean_absolute_error: 0.0079
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9479e-05 - mean_absolute_error: 0.0048 - val_loss: 1.2303e-04 - val_mean_absolute_error: 0.0078
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5115e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1737e-04 - val_mean_absolute_error: 0.0073
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1267e-05 - mean_absolute_error: 0.0044 - val_loss: 1.5457e-04 - val_mean_absolute_error: 0.0096
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5257e-05 - mean_absolute_error: 0.0061 - val_loss: 1.1503e-04 - val_mean_absolute_error: 0.0071
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6213e-05 - mean_absolute_error: 0.0049 - val_loss: 1.2585e-04 - val_mean_absolute_error: 0.0078
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2216e-05 - mean_absolute_error: 0.0044 - val_loss: 1.3033e-04 - val_mean_absolute_error: 0.0081
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9670e-05 - mean_absolute_error: 0.0056 - val_loss: 1.1407e-04 - val_mean_absolute_error: 0.0071
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2718e-05 - mean_absolute_error: 0.0059 - val_loss: 1.1276e-04 - val_mean_absolute_error: 0.0070
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.9799e-05 - mean_absolute_error: 0.0069 - val_loss: 1.1466e-04 - val_mean_absolute_error: 0.0072
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6127e-05 - mean_absolute_error: 0.0043 - val_loss: 1.2126e-04 - val_mean_absolute_error: 0.0077
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1619e-05 - mean_absolute_error: 0.0048 - val_loss: 1.5070e-04 - val_mean_absolute_error: 0.0092
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7007e-05 - mean_absolute_error: 0.0061 - val_loss: 1.1241e-04 - val_mean_absolute_error: 0.0069
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1514e-05 - mean_absolute_error: 0.0045 - val_loss: 1.1187e-04 - val_mean_absolute_error: 0.0069
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9301e-05 - mean_absolute_error: 0.0048 - val_loss: 1.4667e-04 - val_mean_absolute_error: 0.0090
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3234e-05 - mean_absolute_error: 0.0051 - val_loss: 1.2886e-04 - val_mean_absolute_error: 0.0080
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6617e-05 - mean_absolute_error: 0.0047 - val_loss: 1.3017e-04 - val_mean_absolute_error: 0.0083
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3132e-05 - mean_absolute_error: 0.0052 - val_loss: 1.1220e-04 - val_mean_absolute_error: 0.0071
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7464e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1033e-04 - val_mean_absolute_error: 0.0069
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0870e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2753e-04 - val_mean_absolute_error: 0.0082
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5648e-05 - mean_absolute_error: 0.0054 - val_loss: 1.1069e-04 - val_mean_absolute_error: 0.0069
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9062e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1359e-04 - val_mean_absolute_error: 0.0072
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9840e-05 - mean_absolute_error: 0.0049 - val_loss: 1.3303e-04 - val_mean_absolute_error: 0.0083
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0271e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1267e-04 - val_mean_absolute_error: 0.0072
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8999e-05 - mean_absolute_error: 0.0048 - val_loss: 1.1829e-04 - val_mean_absolute_error: 0.0074
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0948e-05 - mean_absolute_error: 0.0045 - val_loss: 1.2657e-04 - val_mean_absolute_error: 0.0079
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1269e-05 - mean_absolute_error: 0.0054 - val_loss: 1.1840e-04 - val_mean_absolute_error: 0.0076
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1477e-05 - mean_absolute_error: 0.0051 - val_loss: 1.5883e-04 - val_mean_absolute_error: 0.0097
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1407e-05 - mean_absolute_error: 0.0053 - val_loss: 1.1411e-04 - val_mean_absolute_error: 0.0073
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5695e-05 - mean_absolute_error: 0.0046 - val_loss: 1.6357e-04 - val_mean_absolute_error: 0.0099
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4904e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2976e-04 - val_mean_absolute_error: 0.0084
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8301e-05 - mean_absolute_error: 0.0048 - val_loss: 1.0793e-04 - val_mean_absolute_error: 0.0068
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9864e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1390e-04 - val_mean_absolute_error: 0.0073
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0464e-05 - mean_absolute_error: 0.0052 - val_loss: 1.1049e-04 - val_mean_absolute_error: 0.0069
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3376e-05 - mean_absolute_error: 0.0043 - val_loss: 1.1908e-04 - val_mean_absolute_error: 0.0077
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2985e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1260e-04 - val_mean_absolute_error: 0.0072
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1086e-05 - mean_absolute_error: 0.0044 - val_loss: 1.0837e-04 - val_mean_absolute_error: 0.0068
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1174e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1429e-04 - val_mean_absolute_error: 0.0074
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8159e-05 - mean_absolute_error: 0.0049 - val_loss: 1.1771e-04 - val_mean_absolute_error: 0.0076
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9919e-05 - mean_absolute_error: 0.0061 - val_loss: 1.5269e-04 - val_mean_absolute_error: 0.0094
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0053e-05 - mean_absolute_error: 0.0061 - val_loss: 1.2318e-04 - val_mean_absolute_error: 0.0080
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7858e-05 - mean_absolute_error: 0.0053 - val_loss: 1.1020e-04 - val_mean_absolute_error: 0.0071
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1903e-05 - mean_absolute_error: 0.0043 - val_loss: 1.4400e-04 - val_mean_absolute_error: 0.0090
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8051e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1200e-04 - val_mean_absolute_error: 0.0070
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7759e-05 - mean_absolute_error: 0.0043 - val_loss: 1.3261e-04 - val_mean_absolute_error: 0.0084
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0803e-05 - mean_absolute_error: 0.0048 - val_loss: 1.6169e-04 - val_mean_absolute_error: 0.0099
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0486e-05 - mean_absolute_error: 0.0056 - val_loss: 2.0689e-04 - val_mean_absolute_error: 0.0121
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6158e-05 - mean_absolute_error: 0.0061 - val_loss: 1.1571e-04 - val_mean_absolute_error: 0.0073
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5520e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1630e-04 - val_mean_absolute_error: 0.0076
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3447e-05 - mean_absolute_error: 0.0046 - val_loss: 1.2127e-04 - val_mean_absolute_error: 0.0079
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0529e-05 - mean_absolute_error: 0.0056 - val_loss: 1.1939e-04 - val_mean_absolute_error: 0.0075
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9349e-05 - mean_absolute_error: 0.0043 - val_loss: 1.2519e-04 - val_mean_absolute_error: 0.0082
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8796e-05 - mean_absolute_error: 0.0047 - val_loss: 1.4947e-04 - val_mean_absolute_error: 0.0093
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1486e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1223e-04 - val_mean_absolute_error: 0.0071
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2016e-05 - mean_absolute_error: 0.0044 - val_loss: 1.0585e-04 - val_mean_absolute_error: 0.0067
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1503e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1126e-04 - val_mean_absolute_error: 0.0072
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6005e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1751e-04 - val_mean_absolute_error: 0.0077
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0506e-05 - mean_absolute_error: 0.0041 - val_loss: 1.3475e-04 - val_mean_absolute_error: 0.0088
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9695e-05 - mean_absolute_error: 0.0063 - val_loss: 1.2440e-04 - val_mean_absolute_error: 0.0079
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0755e-05 - mean_absolute_error: 0.0049 - val_loss: 1.0533e-04 - val_mean_absolute_error: 0.0067
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9067e-05 - mean_absolute_error: 0.0052 - val_loss: 1.7322e-04 - val_mean_absolute_error: 0.0105
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8239e-05 - mean_absolute_error: 0.0051 - val_loss: 1.0522e-04 - val_mean_absolute_error: 0.0067
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4390e-05 - mean_absolute_error: 0.0047 - val_loss: 1.0692e-04 - val_mean_absolute_error: 0.0069
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9649e-05 - mean_absolute_error: 0.0042 - val_loss: 1.0877e-04 - val_mean_absolute_error: 0.0070
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2874e-05 - mean_absolute_error: 0.0043 - val_loss: 1.0615e-04 - val_mean_absolute_error: 0.0068
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0735e-05 - mean_absolute_error: 0.0055 - val_loss: 1.0980e-04 - val_mean_absolute_error: 0.0069
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3398e-05 - mean_absolute_error: 0.0056 - val_loss: 1.0630e-04 - val_mean_absolute_error: 0.0068
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2947e-05 - mean_absolute_error: 0.0043 - val_loss: 1.0627e-04 - val_mean_absolute_error: 0.0069
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3876e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1179e-04 - val_mean_absolute_error: 0.0071
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0877e-05 - mean_absolute_error: 0.0045 - val_loss: 2.7603e-04 - val_mean_absolute_error: 0.0143
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.5059e-05 - mean_absolute_error: 0.0065 - val_loss: 1.0710e-04 - val_mean_absolute_error: 0.0067
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8299e-05 - mean_absolute_error: 0.0042 - val_loss: 1.5879e-04 - val_mean_absolute_error: 0.0098
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.8957e-05 - mean_absolute_error: 0.0064 - val_loss: 1.3489e-04 - val_mean_absolute_error: 0.0088
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5854e-05 - mean_absolute_error: 0.0063 - val_loss: 1.0592e-04 - val_mean_absolute_error: 0.0068
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9664e-05 - mean_absolute_error: 0.0042 - val_loss: 1.5209e-04 - val_mean_absolute_error: 0.0095
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4997e-05 - mean_absolute_error: 0.0047 - val_loss: 1.0526e-04 - val_mean_absolute_error: 0.0067
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7170e-05 - mean_absolute_error: 0.0054 - val_loss: 1.0783e-04 - val_mean_absolute_error: 0.0070
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2931e-05 - mean_absolute_error: 0.0044 - val_loss: 1.0562e-04 - val_mean_absolute_error: 0.0067
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2650e-05 - mean_absolute_error: 0.0043 - val_loss: 1.0551e-04 - val_mean_absolute_error: 0.0067
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9734e-05 - mean_absolute_error: 0.0043 - val_loss: 1.1947e-04 - val_mean_absolute_error: 0.0076
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5347e-05 - mean_absolute_error: 0.0049 - val_loss: 1.0547e-04 - val_mean_absolute_error: 0.0067
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9104e-05 - mean_absolute_error: 0.0042 - val_loss: 1.0921e-04 - val_mean_absolute_error: 0.0069
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3094e-05 - mean_absolute_error: 0.0051 - val_loss: 1.1516e-04 - val_mean_absolute_error: 0.0075
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0724e-05 - mean_absolute_error: 0.0051 - val_loss: 1.7635e-04 - val_mean_absolute_error: 0.0106
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2637e-05 - mean_absolute_error: 0.0055 - val_loss: 1.0803e-04 - val_mean_absolute_error: 0.0069
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6565e-05 - mean_absolute_error: 0.0055 - val_loss: 1.6450e-04 - val_mean_absolute_error: 0.0101
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2209e-05 - mean_absolute_error: 0.0049 - val_loss: 1.2324e-04 - val_mean_absolute_error: 0.0081
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2297e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1042e-04 - val_mean_absolute_error: 0.0070
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0943e-05 - mean_absolute_error: 0.0042 - val_loss: 1.0661e-04 - val_mean_absolute_error: 0.0068
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2083e-05 - mean_absolute_error: 0.0045 - val_loss: 1.0568e-04 - val_mean_absolute_error: 0.0067
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5790e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1580e-04 - val_mean_absolute_error: 0.0074
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8051e-05 - mean_absolute_error: 0.0042 - val_loss: 1.0502e-04 - val_mean_absolute_error: 0.0067
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6312e-05 - mean_absolute_error: 0.0041 - val_loss: 1.1824e-04 - val_mean_absolute_error: 0.0075
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1264e-05 - mean_absolute_error: 0.0045 - val_loss: 1.0482e-04 - val_mean_absolute_error: 0.0067
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3825e-05 - mean_absolute_error: 0.0051 - val_loss: 1.0604e-04 - val_mean_absolute_error: 0.0067
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1949e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1035e-04 - val_mean_absolute_error: 0.0072
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9417e-05 - mean_absolute_error: 0.0043 - val_loss: 1.2767e-04 - val_mean_absolute_error: 0.0084
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2990e-05 - mean_absolute_error: 0.0058 - val_loss: 1.0457e-04 - val_mean_absolute_error: 0.0067
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5354e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1181e-04 - val_mean_absolute_error: 0.0073
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1197e-05 - mean_absolute_error: 0.0047 - val_loss: 1.0481e-04 - val_mean_absolute_error: 0.0067
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4040e-05 - mean_absolute_error: 0.0045 - val_loss: 1.1238e-04 - val_mean_absolute_error: 0.0074
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1326e-05 - mean_absolute_error: 0.0053 - val_loss: 1.0483e-04 - val_mean_absolute_error: 0.0067
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4448e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1293e-04 - val_mean_absolute_error: 0.0074
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4134e-05 - mean_absolute_error: 0.0046 - val_loss: 1.3300e-04 - val_mean_absolute_error: 0.0085
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5738e-05 - mean_absolute_error: 0.0058 - val_loss: 1.1629e-04 - val_mean_absolute_error: 0.0074
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6347e-05 - mean_absolute_error: 0.0047 - val_loss: 1.3236e-04 - val_mean_absolute_error: 0.0087
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1167e-05 - mean_absolute_error: 0.0047 - val_loss: 1.0502e-04 - val_mean_absolute_error: 0.0067
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7796e-05 - mean_absolute_error: 0.0042 - val_loss: 1.5000e-04 - val_mean_absolute_error: 0.0094
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6490e-05 - mean_absolute_error: 0.0070 - val_loss: 1.6336e-04 - val_mean_absolute_error: 0.0102
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3384e-05 - mean_absolute_error: 0.0054 - val_loss: 2.7601e-04 - val_mean_absolute_error: 0.0144
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1096e-05 - mean_absolute_error: 0.0063 - val_loss: 1.1512e-04 - val_mean_absolute_error: 0.0074
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3685e-05 - mean_absolute_error: 0.0046 - val_loss: 2.6354e-04 - val_mean_absolute_error: 0.0139
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6490e-05 - mean_absolute_error: 0.0055 - val_loss: 1.1187e-04 - val_mean_absolute_error: 0.0073
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1734e-05 - mean_absolute_error: 0.0045 - val_loss: 1.0952e-04 - val_mean_absolute_error: 0.0071
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3822e-05 - mean_absolute_error: 0.0050 - val_loss: 1.0746e-04 - val_mean_absolute_error: 0.0068
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9419e-05 - mean_absolute_error: 0.0042 - val_loss: 1.0483e-04 - val_mean_absolute_error: 0.0067
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6117e-05 - mean_absolute_error: 0.0046 - val_loss: 1.0984e-04 - val_mean_absolute_error: 0.0070
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7739e-05 - mean_absolute_error: 0.0043 - val_loss: 1.5860e-04 - val_mean_absolute_error: 0.0098
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3537e-05 - mean_absolute_error: 0.0048 - val_loss: 1.0606e-04 - val_mean_absolute_error: 0.0068
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4521e-05 - mean_absolute_error: 0.0045 - val_loss: 1.0483e-04 - val_mean_absolute_error: 0.0067
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9209e-05 - mean_absolute_error: 0.0047 - val_loss: 1.2613e-04 - val_mean_absolute_error: 0.0081
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0435e-05 - mean_absolute_error: 0.0043 - val_loss: 1.1518e-04 - val_mean_absolute_error: 0.0076
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7374e-05 - mean_absolute_error: 0.0045 - val_loss: 1.2352e-04 - val_mean_absolute_error: 0.0079
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3057e-05 - mean_absolute_error: 0.0045 - val_loss: 1.1166e-04 - val_mean_absolute_error: 0.0071
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8333e-05 - mean_absolute_error: 0.0047 - val_loss: 2.4946e-04 - val_mean_absolute_error: 0.0135
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.5097e-05 - mean_absolute_error: 0.0066 - val_loss: 1.6097e-04 - val_mean_absolute_error: 0.0099
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6969e-05 - mean_absolute_error: 0.0051 - val_loss: 1.0752e-04 - val_mean_absolute_error: 0.0070
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0299e-05 - mean_absolute_error: 0.0043 - val_loss: 1.1566e-04 - val_mean_absolute_error: 0.0074
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2350e-05 - mean_absolute_error: 0.0043 - val_loss: 1.0659e-04 - val_mean_absolute_error: 0.0069

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7006e-04 - mean_absolute_error: 0.0089
# Test Loss: [0.00010658786050044, 0.006905909162014723]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 2969611.326429451
# RMSE: 1723.2560246317003
# MAE: 1175.6457762699204
# MAPE: 1.7214490405879146 %
#
# Model evalution on validate set
# MSE: 6595941.41197862
# RMSE: 2568.2564926382684
# MAE: 1829.8010128458498
# MAPE: 1.8107527987240344 %

# %% [markdown]
# ## 4. Forecast the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
y_pred_30_days
# Out:
# array([[133077.78],
#        [133469.47],
#        [133199.75],
#        [133327.4 ],
#        [133247.97],
#        [133286.23],
#        [133265.3 ],
#        [133276.25],
#        [133270.34],
#        [133273.47],
#        [133271.81],
#        [133272.69],
#        [133272.23],
#        [133272.45],
#        [133272.36],
#        [133272.39],
#        [133272.38],
#        [133272.39],
#        [133272.38],
#        [133272.39],
#        [133272.38],
#        [133272.38],
#        [133272.39],
#        [133272.38],
#        [133272.38],
#        [133272.38],
#        [133272.38],
#        [133272.38],
#        [133272.39],
#        [133272.38],
#        [133272.38]], dtype=float32)

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(16, 9))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
