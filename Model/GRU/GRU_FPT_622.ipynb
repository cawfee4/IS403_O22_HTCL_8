# %% [markdown]
# # Model: GRU (Gated Recurrent Unit)  - Stock Token: FPT - Test/Train/Vaildation: 60/20/20
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 2089.92
# - MAE: 1482.80
# - MAPE: 2.13 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 1  # 6 2 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#              close
# time
# 2019-03-01   19270
# 2019-03-04   19440
# 2019-03-05   19390
# 2019-03-06   19270
# 2019-03-07   19330
# ...            ...
# 2024-02-26  108000
# 2024-02-27  107900
# 2024-02-28  108500
# 2024-02-29  109000
# 2024-03-01  110800
#
# [1252 rows x 1 columns]

# %%
df.shape
# Out:
# (1252, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1247    108000
# 1248    107900
# 1249    108500
# 1250    109000
# 1251    110800
# Name: close, Length: 1252, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((740, 10), (740,), (239, 10), (239,), (240, 10), (240,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(100),
        Dense(32, activation="relu"),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 100)            │        30,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,165 (133.46 KB)
#  Trainable params: 34,165 (133.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0249 - mean_absolute_error: 0.1030 - val_loss: 0.0012 - val_mean_absolute_error: 0.0295
# Epoch 2/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8384e-04 - mean_absolute_error: 0.0191 - val_loss: 4.6067e-04 - val_mean_absolute_error: 0.0157
# Epoch 3/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0671e-04 - mean_absolute_error: 0.0071 - val_loss: 4.2451e-04 - val_mean_absolute_error: 0.0146
# Epoch 4/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.1212e-05 - mean_absolute_error: 0.0065 - val_loss: 4.2581e-04 - val_mean_absolute_error: 0.0147
# Epoch 5/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3285e-05 - mean_absolute_error: 0.0062 - val_loss: 4.9067e-04 - val_mean_absolute_error: 0.0164
# Epoch 6/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1032e-04 - mean_absolute_error: 0.0076 - val_loss: 4.4274e-04 - val_mean_absolute_error: 0.0152
# Epoch 7/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.1560e-05 - mean_absolute_error: 0.0065 - val_loss: 4.2037e-04 - val_mean_absolute_error: 0.0147
# Epoch 8/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3249e-04 - mean_absolute_error: 0.0085 - val_loss: 4.0052e-04 - val_mean_absolute_error: 0.0141
# Epoch 9/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3519e-05 - mean_absolute_error: 0.0062 - val_loss: 4.3383e-04 - val_mean_absolute_error: 0.0150
# Epoch 10/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1176e-05 - mean_absolute_error: 0.0067 - val_loss: 3.8668e-04 - val_mean_absolute_error: 0.0137
# Epoch 11/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0100e-04 - mean_absolute_error: 0.0069 - val_loss: 3.9260e-04 - val_mean_absolute_error: 0.0141
# Epoch 12/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3525e-05 - mean_absolute_error: 0.0061 - val_loss: 4.0609e-04 - val_mean_absolute_error: 0.0143
# Epoch 13/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6454e-05 - mean_absolute_error: 0.0067 - val_loss: 4.7452e-04 - val_mean_absolute_error: 0.0166
# Epoch 14/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6381e-05 - mean_absolute_error: 0.0071 - val_loss: 4.7511e-04 - val_mean_absolute_error: 0.0164
# Epoch 15/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1439e-04 - mean_absolute_error: 0.0075 - val_loss: 3.6794e-04 - val_mean_absolute_error: 0.0134
# Epoch 16/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7387e-05 - mean_absolute_error: 0.0061 - val_loss: 3.9200e-04 - val_mean_absolute_error: 0.0141
# Epoch 17/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5368e-05 - mean_absolute_error: 0.0063 - val_loss: 3.6114e-04 - val_mean_absolute_error: 0.0133
# Epoch 18/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.0172e-05 - mean_absolute_error: 0.0064 - val_loss: 3.6229e-04 - val_mean_absolute_error: 0.0134
# Epoch 19/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6235e-05 - mean_absolute_error: 0.0064 - val_loss: 5.8438e-04 - val_mean_absolute_error: 0.0197
# Epoch 20/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5182e-04 - mean_absolute_error: 0.0090 - val_loss: 4.0306e-04 - val_mean_absolute_error: 0.0146
# Epoch 21/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.3525e-05 - mean_absolute_error: 0.0070 - val_loss: 4.2928e-04 - val_mean_absolute_error: 0.0155
# Epoch 22/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7778e-05 - mean_absolute_error: 0.0063 - val_loss: 3.9242e-04 - val_mean_absolute_error: 0.0143
# Epoch 23/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1912e-05 - mean_absolute_error: 0.0061 - val_loss: 3.4116e-04 - val_mean_absolute_error: 0.0128
# Epoch 24/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.0737e-05 - mean_absolute_error: 0.0066 - val_loss: 3.9466e-04 - val_mean_absolute_error: 0.0145
# Epoch 25/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5090e-05 - mean_absolute_error: 0.0062 - val_loss: 3.3906e-04 - val_mean_absolute_error: 0.0127
# Epoch 26/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2443e-05 - mean_absolute_error: 0.0067 - val_loss: 4.4568e-04 - val_mean_absolute_error: 0.0165
# Epoch 27/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1214e-04 - mean_absolute_error: 0.0079 - val_loss: 3.3192e-04 - val_mean_absolute_error: 0.0126
# Epoch 28/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8552e-05 - mean_absolute_error: 0.0062 - val_loss: 4.0388e-04 - val_mean_absolute_error: 0.0149
# Epoch 29/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6517e-05 - mean_absolute_error: 0.0061 - val_loss: 3.2476e-04 - val_mean_absolute_error: 0.0123
# Epoch 30/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6048e-05 - mean_absolute_error: 0.0063 - val_loss: 3.2391e-04 - val_mean_absolute_error: 0.0124
# Epoch 31/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6848e-05 - mean_absolute_error: 0.0060 - val_loss: 3.9128e-04 - val_mean_absolute_error: 0.0150
# Epoch 32/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1439e-05 - mean_absolute_error: 0.0064 - val_loss: 3.3131e-04 - val_mean_absolute_error: 0.0126
# Epoch 33/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0113e-05 - mean_absolute_error: 0.0057 - val_loss: 3.2391e-04 - val_mean_absolute_error: 0.0123
# Epoch 34/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1044e-05 - mean_absolute_error: 0.0061 - val_loss: 3.1036e-04 - val_mean_absolute_error: 0.0119
# Epoch 35/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1865e-05 - mean_absolute_error: 0.0065 - val_loss: 3.5252e-04 - val_mean_absolute_error: 0.0138
# Epoch 36/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1539e-05 - mean_absolute_error: 0.0060 - val_loss: 3.0750e-04 - val_mean_absolute_error: 0.0118
# Epoch 37/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9023e-05 - mean_absolute_error: 0.0058 - val_loss: 3.1529e-04 - val_mean_absolute_error: 0.0121
# Epoch 38/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2309e-05 - mean_absolute_error: 0.0062 - val_loss: 3.0386e-04 - val_mean_absolute_error: 0.0117
# Epoch 39/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2517e-05 - mean_absolute_error: 0.0059 - val_loss: 3.0120e-04 - val_mean_absolute_error: 0.0117
# Epoch 40/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.9964e-05 - mean_absolute_error: 0.0058 - val_loss: 3.0100e-04 - val_mean_absolute_error: 0.0118
# Epoch 41/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0084e-05 - mean_absolute_error: 0.0054 - val_loss: 3.8828e-04 - val_mean_absolute_error: 0.0152
# Epoch 42/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3323e-04 - mean_absolute_error: 0.0089 - val_loss: 2.9987e-04 - val_mean_absolute_error: 0.0118
# Epoch 43/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6673e-05 - mean_absolute_error: 0.0062 - val_loss: 5.7297e-04 - val_mean_absolute_error: 0.0202
# Epoch 44/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0854e-04 - mean_absolute_error: 0.0079 - val_loss: 3.4541e-04 - val_mean_absolute_error: 0.0138
# Epoch 45/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.9002e-05 - mean_absolute_error: 0.0067 - val_loss: 3.0187e-04 - val_mean_absolute_error: 0.0120
# Epoch 46/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1022e-05 - mean_absolute_error: 0.0062 - val_loss: 3.2137e-04 - val_mean_absolute_error: 0.0129
# Epoch 47/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5306e-05 - mean_absolute_error: 0.0067 - val_loss: 3.6469e-04 - val_mean_absolute_error: 0.0146
# Epoch 48/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.2161e-05 - mean_absolute_error: 0.0070 - val_loss: 2.9961e-04 - val_mean_absolute_error: 0.0120
# Epoch 49/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9682e-05 - mean_absolute_error: 0.0063 - val_loss: 3.1368e-04 - val_mean_absolute_error: 0.0124
# Epoch 50/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1326e-05 - mean_absolute_error: 0.0058 - val_loss: 3.4875e-04 - val_mean_absolute_error: 0.0136
# Epoch 51/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1987e-05 - mean_absolute_error: 0.0060 - val_loss: 2.8674e-04 - val_mean_absolute_error: 0.0114
# Epoch 52/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9266e-05 - mean_absolute_error: 0.0056 - val_loss: 3.0633e-04 - val_mean_absolute_error: 0.0124
# Epoch 53/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3285e-05 - mean_absolute_error: 0.0062 - val_loss: 3.5466e-04 - val_mean_absolute_error: 0.0143
# Epoch 54/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9152e-05 - mean_absolute_error: 0.0063 - val_loss: 3.1287e-04 - val_mean_absolute_error: 0.0127
# Epoch 55/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6714e-05 - mean_absolute_error: 0.0055 - val_loss: 2.8920e-04 - val_mean_absolute_error: 0.0116
# Epoch 56/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4140e-05 - mean_absolute_error: 0.0057 - val_loss: 2.8475e-04 - val_mean_absolute_error: 0.0114
# Epoch 57/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5279e-05 - mean_absolute_error: 0.0054 - val_loss: 2.8189e-04 - val_mean_absolute_error: 0.0112
# Epoch 58/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.7929e-05 - mean_absolute_error: 0.0066 - val_loss: 2.9496e-04 - val_mean_absolute_error: 0.0118
# Epoch 59/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.2326e-05 - mean_absolute_error: 0.0061 - val_loss: 2.9593e-04 - val_mean_absolute_error: 0.0121
# Epoch 60/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9014e-05 - mean_absolute_error: 0.0059 - val_loss: 3.7553e-04 - val_mean_absolute_error: 0.0146
# Epoch 61/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4497e-05 - mean_absolute_error: 0.0073 - val_loss: 3.6168e-04 - val_mean_absolute_error: 0.0142
# Epoch 62/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7380e-05 - mean_absolute_error: 0.0058 - val_loss: 4.7124e-04 - val_mean_absolute_error: 0.0173
# Epoch 63/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2644e-04 - mean_absolute_error: 0.0087 - val_loss: 2.9882e-04 - val_mean_absolute_error: 0.0120
# Epoch 64/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0569e-05 - mean_absolute_error: 0.0059 - val_loss: 3.2263e-04 - val_mean_absolute_error: 0.0133
# Epoch 65/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6968e-05 - mean_absolute_error: 0.0062 - val_loss: 2.8337e-04 - val_mean_absolute_error: 0.0115
# Epoch 66/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7243e-05 - mean_absolute_error: 0.0059 - val_loss: 3.1943e-04 - val_mean_absolute_error: 0.0128
# Epoch 67/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5724e-05 - mean_absolute_error: 0.0061 - val_loss: 3.2010e-04 - val_mean_absolute_error: 0.0128
# Epoch 68/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4825e-05 - mean_absolute_error: 0.0072 - val_loss: 2.9294e-04 - val_mean_absolute_error: 0.0117
# Epoch 69/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4707e-05 - mean_absolute_error: 0.0066 - val_loss: 3.0848e-04 - val_mean_absolute_error: 0.0124
# Epoch 70/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5015e-05 - mean_absolute_error: 0.0065 - val_loss: 2.7395e-04 - val_mean_absolute_error: 0.0110
# Epoch 71/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0771e-05 - mean_absolute_error: 0.0062 - val_loss: 2.7365e-04 - val_mean_absolute_error: 0.0110
# Epoch 72/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5135e-05 - mean_absolute_error: 0.0055 - val_loss: 2.7308e-04 - val_mean_absolute_error: 0.0110
# Epoch 73/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4484e-05 - mean_absolute_error: 0.0050 - val_loss: 2.8825e-04 - val_mean_absolute_error: 0.0117
# Epoch 74/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4262e-05 - mean_absolute_error: 0.0057 - val_loss: 3.5825e-04 - val_mean_absolute_error: 0.0142
# Epoch 75/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1351e-05 - mean_absolute_error: 0.0061 - val_loss: 2.7937e-04 - val_mean_absolute_error: 0.0114
# Epoch 76/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7051e-05 - mean_absolute_error: 0.0057 - val_loss: 3.4439e-04 - val_mean_absolute_error: 0.0143
# Epoch 77/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3468e-05 - mean_absolute_error: 0.0062 - val_loss: 4.2999e-04 - val_mean_absolute_error: 0.0165
# Epoch 78/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.8306e-05 - mean_absolute_error: 0.0068 - val_loss: 2.7384e-04 - val_mean_absolute_error: 0.0112
# Epoch 79/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1760e-05 - mean_absolute_error: 0.0061 - val_loss: 2.9750e-04 - val_mean_absolute_error: 0.0121
# Epoch 80/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1826e-05 - mean_absolute_error: 0.0061 - val_loss: 2.8877e-04 - val_mean_absolute_error: 0.0117
# Epoch 81/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8640e-05 - mean_absolute_error: 0.0064 - val_loss: 2.6879e-04 - val_mean_absolute_error: 0.0110
# Epoch 82/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.8926e-05 - mean_absolute_error: 0.0059 - val_loss: 3.5612e-04 - val_mean_absolute_error: 0.0146
# Epoch 83/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.0213e-05 - mean_absolute_error: 0.0067 - val_loss: 3.0778e-04 - val_mean_absolute_error: 0.0129
# Epoch 84/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2596e-05 - mean_absolute_error: 0.0053 - val_loss: 3.4134e-04 - val_mean_absolute_error: 0.0142
# Epoch 85/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6143e-05 - mean_absolute_error: 0.0058 - val_loss: 3.5372e-04 - val_mean_absolute_error: 0.0146
# Epoch 86/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.5043e-05 - mean_absolute_error: 0.0061 - val_loss: 3.9103e-04 - val_mean_absolute_error: 0.0158
# Epoch 87/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9072e-05 - mean_absolute_error: 0.0054 - val_loss: 2.6606e-04 - val_mean_absolute_error: 0.0110
# Epoch 88/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6024e-05 - mean_absolute_error: 0.0057 - val_loss: 3.0594e-04 - val_mean_absolute_error: 0.0125
# Epoch 89/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4253e-05 - mean_absolute_error: 0.0061 - val_loss: 2.6521e-04 - val_mean_absolute_error: 0.0108
# Epoch 90/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1861e-05 - mean_absolute_error: 0.0055 - val_loss: 4.0174e-04 - val_mean_absolute_error: 0.0162
# Epoch 91/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7823e-05 - mean_absolute_error: 0.0063 - val_loss: 4.1548e-04 - val_mean_absolute_error: 0.0163
# Epoch 92/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3854e-05 - mean_absolute_error: 0.0061 - val_loss: 4.2263e-04 - val_mean_absolute_error: 0.0168
# Epoch 93/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6101e-05 - mean_absolute_error: 0.0065 - val_loss: 7.6363e-04 - val_mean_absolute_error: 0.0245
# Epoch 94/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6108e-04 - mean_absolute_error: 0.0100 - val_loss: 5.0478e-04 - val_mean_absolute_error: 0.0186
# Epoch 95/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4071e-05 - mean_absolute_error: 0.0058 - val_loss: 5.6842e-04 - val_mean_absolute_error: 0.0204
# Epoch 96/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2667e-04 - mean_absolute_error: 0.0087 - val_loss: 3.5911e-04 - val_mean_absolute_error: 0.0149
# Epoch 97/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3640e-05 - mean_absolute_error: 0.0058 - val_loss: 2.6965e-04 - val_mean_absolute_error: 0.0114
# Epoch 98/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1029e-05 - mean_absolute_error: 0.0054 - val_loss: 2.8046e-04 - val_mean_absolute_error: 0.0115
# Epoch 99/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2250e-05 - mean_absolute_error: 0.0056 - val_loss: 2.5957e-04 - val_mean_absolute_error: 0.0107
# Epoch 100/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1242e-05 - mean_absolute_error: 0.0052 - val_loss: 2.5827e-04 - val_mean_absolute_error: 0.0107
# Epoch 101/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3763e-05 - mean_absolute_error: 0.0054 - val_loss: 3.2738e-04 - val_mean_absolute_error: 0.0139
# Epoch 102/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9268e-05 - mean_absolute_error: 0.0053 - val_loss: 3.6905e-04 - val_mean_absolute_error: 0.0153
# Epoch 103/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.5971e-05 - mean_absolute_error: 0.0062 - val_loss: 2.7498e-04 - val_mean_absolute_error: 0.0113
# Epoch 104/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.2414e-05 - mean_absolute_error: 0.0069 - val_loss: 2.9550e-04 - val_mean_absolute_error: 0.0122
# Epoch 105/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0807e-05 - mean_absolute_error: 0.0060 - val_loss: 2.5769e-04 - val_mean_absolute_error: 0.0106
# Epoch 106/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3144e-05 - mean_absolute_error: 0.0055 - val_loss: 2.5723e-04 - val_mean_absolute_error: 0.0107
# Epoch 107/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0097e-05 - mean_absolute_error: 0.0052 - val_loss: 2.5813e-04 - val_mean_absolute_error: 0.0108
# Epoch 108/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3409e-05 - mean_absolute_error: 0.0055 - val_loss: 2.5840e-04 - val_mean_absolute_error: 0.0107
# Epoch 109/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9885e-05 - mean_absolute_error: 0.0053 - val_loss: 3.0877e-04 - val_mean_absolute_error: 0.0132
# Epoch 110/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5876e-05 - mean_absolute_error: 0.0055 - val_loss: 3.3374e-04 - val_mean_absolute_error: 0.0141
# Epoch 111/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.2983e-05 - mean_absolute_error: 0.0060 - val_loss: 4.3132e-04 - val_mean_absolute_error: 0.0172
# Epoch 112/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7353e-05 - mean_absolute_error: 0.0060 - val_loss: 2.5793e-04 - val_mean_absolute_error: 0.0108
# Epoch 113/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3484e-05 - mean_absolute_error: 0.0051 - val_loss: 2.6227e-04 - val_mean_absolute_error: 0.0108
# Epoch 114/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1262e-05 - mean_absolute_error: 0.0067 - val_loss: 2.7151e-04 - val_mean_absolute_error: 0.0114
# Epoch 115/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0556e-05 - mean_absolute_error: 0.0054 - val_loss: 3.7253e-04 - val_mean_absolute_error: 0.0153
# Epoch 116/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6206e-05 - mean_absolute_error: 0.0057 - val_loss: 2.6517e-04 - val_mean_absolute_error: 0.0109
# Epoch 117/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5473e-05 - mean_absolute_error: 0.0058 - val_loss: 2.6269e-04 - val_mean_absolute_error: 0.0112
# Epoch 118/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6403e-05 - mean_absolute_error: 0.0054 - val_loss: 3.2483e-04 - val_mean_absolute_error: 0.0138
# Epoch 119/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3997e-05 - mean_absolute_error: 0.0051 - val_loss: 2.9260e-04 - val_mean_absolute_error: 0.0122
# Epoch 120/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6341e-05 - mean_absolute_error: 0.0057 - val_loss: 2.5904e-04 - val_mean_absolute_error: 0.0107
# Epoch 121/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6930e-05 - mean_absolute_error: 0.0052 - val_loss: 4.6735e-04 - val_mean_absolute_error: 0.0176
# Epoch 122/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.7207e-05 - mean_absolute_error: 0.0073 - val_loss: 5.6161e-04 - val_mean_absolute_error: 0.0203
# Epoch 123/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1001e-04 - mean_absolute_error: 0.0079 - val_loss: 2.5719e-04 - val_mean_absolute_error: 0.0106
# Epoch 124/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0010e-05 - mean_absolute_error: 0.0060 - val_loss: 2.6022e-04 - val_mean_absolute_error: 0.0107
# Epoch 125/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9603e-05 - mean_absolute_error: 0.0057 - val_loss: 2.8979e-04 - val_mean_absolute_error: 0.0126
# Epoch 126/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3657e-05 - mean_absolute_error: 0.0058 - val_loss: 2.6651e-04 - val_mean_absolute_error: 0.0115
# Epoch 127/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1397e-05 - mean_absolute_error: 0.0055 - val_loss: 2.6123e-04 - val_mean_absolute_error: 0.0108
# Epoch 128/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5235e-05 - mean_absolute_error: 0.0068 - val_loss: 2.5838e-04 - val_mean_absolute_error: 0.0109
# Epoch 129/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5981e-05 - mean_absolute_error: 0.0052 - val_loss: 8.6865e-04 - val_mean_absolute_error: 0.0265
# Epoch 130/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4153e-04 - mean_absolute_error: 0.0092 - val_loss: 3.1198e-04 - val_mean_absolute_error: 0.0133
# Epoch 131/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5729e-05 - mean_absolute_error: 0.0053 - val_loss: 3.2289e-04 - val_mean_absolute_error: 0.0138
# Epoch 132/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6291e-05 - mean_absolute_error: 0.0059 - val_loss: 3.2187e-04 - val_mean_absolute_error: 0.0138
# Epoch 133/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1365e-05 - mean_absolute_error: 0.0055 - val_loss: 2.5565e-04 - val_mean_absolute_error: 0.0106
# Epoch 134/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.8293e-05 - mean_absolute_error: 0.0057 - val_loss: 2.5546e-04 - val_mean_absolute_error: 0.0109
# Epoch 135/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8349e-05 - mean_absolute_error: 0.0056 - val_loss: 3.0588e-04 - val_mean_absolute_error: 0.0132
# Epoch 136/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3398e-05 - mean_absolute_error: 0.0051 - val_loss: 2.6493e-04 - val_mean_absolute_error: 0.0110
# Epoch 137/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4837e-05 - mean_absolute_error: 0.0057 - val_loss: 2.5655e-04 - val_mean_absolute_error: 0.0106
# Epoch 138/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4797e-05 - mean_absolute_error: 0.0057 - val_loss: 2.5421e-04 - val_mean_absolute_error: 0.0106
# Epoch 139/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.8107e-05 - mean_absolute_error: 0.0061 - val_loss: 2.7697e-04 - val_mean_absolute_error: 0.0120
# Epoch 140/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5860e-05 - mean_absolute_error: 0.0054 - val_loss: 2.5161e-04 - val_mean_absolute_error: 0.0106
# Epoch 141/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0093e-05 - mean_absolute_error: 0.0055 - val_loss: 2.4944e-04 - val_mean_absolute_error: 0.0105
# Epoch 142/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.5480e-05 - mean_absolute_error: 0.0061 - val_loss: 5.4308e-04 - val_mean_absolute_error: 0.0200
# Epoch 143/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1857e-05 - mean_absolute_error: 0.0072 - val_loss: 2.5118e-04 - val_mean_absolute_error: 0.0106
# Epoch 144/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2288e-05 - mean_absolute_error: 0.0056 - val_loss: 4.7505e-04 - val_mean_absolute_error: 0.0178
# Epoch 145/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4556e-04 - mean_absolute_error: 0.0097 - val_loss: 2.6338e-04 - val_mean_absolute_error: 0.0109
# Epoch 146/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5231e-05 - mean_absolute_error: 0.0066 - val_loss: 2.5043e-04 - val_mean_absolute_error: 0.0105
# Epoch 147/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1953e-05 - mean_absolute_error: 0.0056 - val_loss: 2.6052e-04 - val_mean_absolute_error: 0.0113
# Epoch 148/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9174e-05 - mean_absolute_error: 0.0052 - val_loss: 3.4702e-04 - val_mean_absolute_error: 0.0147
# Epoch 149/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7250e-05 - mean_absolute_error: 0.0065 - val_loss: 2.4980e-04 - val_mean_absolute_error: 0.0104
# Epoch 150/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1941e-05 - mean_absolute_error: 0.0055 - val_loss: 3.2347e-04 - val_mean_absolute_error: 0.0140
# Epoch 151/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0426e-05 - mean_absolute_error: 0.0056 - val_loss: 3.7519e-04 - val_mean_absolute_error: 0.0156
# Epoch 152/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.4998e-05 - mean_absolute_error: 0.0057 - val_loss: 2.5495e-04 - val_mean_absolute_error: 0.0107
# Epoch 153/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8080e-05 - mean_absolute_error: 0.0060 - val_loss: 2.7592e-04 - val_mean_absolute_error: 0.0120
# Epoch 154/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0424e-05 - mean_absolute_error: 0.0055 - val_loss: 3.9237e-04 - val_mean_absolute_error: 0.0156
# Epoch 155/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.3925e-05 - mean_absolute_error: 0.0068 - val_loss: 3.0215e-04 - val_mean_absolute_error: 0.0132
# Epoch 156/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6624e-05 - mean_absolute_error: 0.0057 - val_loss: 3.2678e-04 - val_mean_absolute_error: 0.0141
# Epoch 157/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5638e-05 - mean_absolute_error: 0.0058 - val_loss: 2.6200e-04 - val_mean_absolute_error: 0.0109
# Epoch 158/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6569e-05 - mean_absolute_error: 0.0057 - val_loss: 2.5557e-04 - val_mean_absolute_error: 0.0111
# Epoch 159/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.8885e-05 - mean_absolute_error: 0.0055 - val_loss: 2.5020e-04 - val_mean_absolute_error: 0.0104
# Epoch 160/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4059e-05 - mean_absolute_error: 0.0051 - val_loss: 3.2944e-04 - val_mean_absolute_error: 0.0137
# Epoch 161/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.0781e-05 - mean_absolute_error: 0.0067 - val_loss: 3.5538e-04 - val_mean_absolute_error: 0.0145
# Epoch 162/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2146e-05 - mean_absolute_error: 0.0068 - val_loss: 2.5827e-04 - val_mean_absolute_error: 0.0112
# Epoch 163/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9026e-05 - mean_absolute_error: 0.0052 - val_loss: 3.8315e-04 - val_mean_absolute_error: 0.0159
# Epoch 164/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0909e-04 - mean_absolute_error: 0.0078 - val_loss: 3.0791e-04 - val_mean_absolute_error: 0.0134
# Epoch 165/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5251e-05 - mean_absolute_error: 0.0058 - val_loss: 2.5015e-04 - val_mean_absolute_error: 0.0107
# Epoch 166/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7072e-05 - mean_absolute_error: 0.0057 - val_loss: 2.9149e-04 - val_mean_absolute_error: 0.0123
# Epoch 167/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8258e-05 - mean_absolute_error: 0.0065 - val_loss: 2.4958e-04 - val_mean_absolute_error: 0.0105
# Epoch 168/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7788e-05 - mean_absolute_error: 0.0052 - val_loss: 2.8022e-04 - val_mean_absolute_error: 0.0123
# Epoch 169/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1613e-05 - mean_absolute_error: 0.0054 - val_loss: 2.9585e-04 - val_mean_absolute_error: 0.0124
# Epoch 170/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.7148e-05 - mean_absolute_error: 0.0069 - val_loss: 2.5863e-04 - val_mean_absolute_error: 0.0113
# Epoch 171/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.8274e-05 - mean_absolute_error: 0.0060 - val_loss: 2.4848e-04 - val_mean_absolute_error: 0.0106
# Epoch 172/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7672e-05 - mean_absolute_error: 0.0051 - val_loss: 4.4908e-04 - val_mean_absolute_error: 0.0172
# Epoch 173/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0471e-04 - mean_absolute_error: 0.0079 - val_loss: 2.4684e-04 - val_mean_absolute_error: 0.0104
# Epoch 174/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3160e-05 - mean_absolute_error: 0.0061 - val_loss: 3.2963e-04 - val_mean_absolute_error: 0.0141
# Epoch 175/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0878e-04 - mean_absolute_error: 0.0080 - val_loss: 3.6627e-04 - val_mean_absolute_error: 0.0154
# Epoch 176/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.2340e-05 - mean_absolute_error: 0.0058 - val_loss: 2.5045e-04 - val_mean_absolute_error: 0.0105
# Epoch 177/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2222e-05 - mean_absolute_error: 0.0055 - val_loss: 2.7332e-04 - val_mean_absolute_error: 0.0120
# Epoch 178/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2618e-05 - mean_absolute_error: 0.0051 - val_loss: 2.6795e-04 - val_mean_absolute_error: 0.0113
# Epoch 179/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3082e-05 - mean_absolute_error: 0.0057 - val_loss: 2.4674e-04 - val_mean_absolute_error: 0.0105
# Epoch 180/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5847e-05 - mean_absolute_error: 0.0057 - val_loss: 2.8704e-04 - val_mean_absolute_error: 0.0120
# Epoch 181/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2363e-05 - mean_absolute_error: 0.0065 - val_loss: 2.7715e-04 - val_mean_absolute_error: 0.0122
# Epoch 182/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8125e-05 - mean_absolute_error: 0.0053 - val_loss: 3.0848e-04 - val_mean_absolute_error: 0.0129
# Epoch 183/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6126e-05 - mean_absolute_error: 0.0058 - val_loss: 2.4709e-04 - val_mean_absolute_error: 0.0104
# Epoch 184/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9685e-05 - mean_absolute_error: 0.0061 - val_loss: 2.4584e-04 - val_mean_absolute_error: 0.0104
# Epoch 185/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4765e-05 - mean_absolute_error: 0.0062 - val_loss: 2.4688e-04 - val_mean_absolute_error: 0.0104
# Epoch 186/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6858e-05 - mean_absolute_error: 0.0051 - val_loss: 2.4903e-04 - val_mean_absolute_error: 0.0107
# Epoch 187/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1529e-05 - mean_absolute_error: 0.0054 - val_loss: 2.6915e-04 - val_mean_absolute_error: 0.0118
# Epoch 188/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1583e-05 - mean_absolute_error: 0.0056 - val_loss: 2.5999e-04 - val_mean_absolute_error: 0.0109
# Epoch 189/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7996e-05 - mean_absolute_error: 0.0057 - val_loss: 2.5781e-04 - val_mean_absolute_error: 0.0112
# Epoch 190/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8281e-05 - mean_absolute_error: 0.0047 - val_loss: 3.2169e-04 - val_mean_absolute_error: 0.0139
# Epoch 191/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1747e-05 - mean_absolute_error: 0.0055 - val_loss: 2.5847e-04 - val_mean_absolute_error: 0.0109
# Epoch 192/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1190e-05 - mean_absolute_error: 0.0057 - val_loss: 4.5468e-04 - val_mean_absolute_error: 0.0174
# Epoch 193/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0276e-04 - mean_absolute_error: 0.0077 - val_loss: 2.6684e-04 - val_mean_absolute_error: 0.0113
# Epoch 194/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9494e-05 - mean_absolute_error: 0.0060 - val_loss: 2.7739e-04 - val_mean_absolute_error: 0.0117
# Epoch 195/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4175e-05 - mean_absolute_error: 0.0055 - val_loss: 2.4731e-04 - val_mean_absolute_error: 0.0104
# Epoch 196/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6927e-05 - mean_absolute_error: 0.0051 - val_loss: 2.9829e-04 - val_mean_absolute_error: 0.0125
# Epoch 197/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0622e-05 - mean_absolute_error: 0.0060 - val_loss: 2.9992e-04 - val_mean_absolute_error: 0.0126
# Epoch 198/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3514e-05 - mean_absolute_error: 0.0063 - val_loss: 2.4700e-04 - val_mean_absolute_error: 0.0104
# Epoch 199/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6336e-05 - mean_absolute_error: 0.0056 - val_loss: 3.0340e-04 - val_mean_absolute_error: 0.0127
# Epoch 200/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8025e-05 - mean_absolute_error: 0.0065 - val_loss: 2.6082e-04 - val_mean_absolute_error: 0.0114

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6183e-04 - mean_absolute_error: 0.0137
# Test Loss: [0.00026082448312081397, 0.011427097022533417]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 239
# 250

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 4367766.535157399
# RMSE: 2089.9202221992587
# MAE: 1482.8030857740587
# MAPE: 2.1321295756669523 %
#
# Model evalution on validate set
# MSE: 4671834.562885539
# RMSE: 2161.442704048742
# MAE: 1607.2136067708334
# MAPE: 1.8001818286565152 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
y_pred_30_days
# Out:
# array([[107986.266],
#        [108022.664],
#        [107977.07 ],
#        [107964.37 ],
#        [107950.234],
#        [107948.72 ],
#        [107947.04 ],
#        [107946.49 ],
#        [107946.19 ],
#        [107946.08 ],
#        [107946.03 ],
#        [107946.01 ],
#        [107945.984],
#        [107945.984],
#        [107945.984],
#        [107945.984],
#        [107945.984],
#        [107945.984],
#        [107945.984],
#        [107945.984],
#        [107945.984],
#        [107945.984],
#        [107945.984],
#        [107945.984],
#        [107945.984],
#        [107945.984],
#        [107945.984],
#        [107945.984],
#        [107945.984],
#        [107945.984],
#        [107945.984]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
