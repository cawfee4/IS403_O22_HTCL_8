# %% [markdown]
# # Model: GRU (Gated Recurrent Unit)  - Stock Token: CMG - Test/Train/Vaildation: 60/20/20
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1417.23
# - MAE: 1080.23
# - MAPE: 3.23 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 1  # 6 2 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830
# ...           ...
# 2024-05-27  59000
# 2024-05-28  62100
# 2024-05-29  60000
# 2024-05-30  59200
# 2024-05-31  60900
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((776, 10), (776,), (251, 10), (251,), (253, 10), (253,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(100),
        Dense(32, activation="relu"),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 100)            │        30,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,165 (133.46 KB)
#  Trainable params: 34,165 (133.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 59ms/step - loss: 0.0190 - mean_absolute_error: 0.0972 - val_loss: 4.7610e-04 - val_mean_absolute_error: 0.0155
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.7067e-04 - mean_absolute_error: 0.0218 - val_loss: 4.7123e-04 - val_mean_absolute_error: 0.0155
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1137e-04 - mean_absolute_error: 0.0107 - val_loss: 5.3756e-04 - val_mean_absolute_error: 0.0172
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.0190e-04 - mean_absolute_error: 0.0102 - val_loss: 4.3657e-04 - val_mean_absolute_error: 0.0149
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.6693e-04 - mean_absolute_error: 0.0091 - val_loss: 4.3567e-04 - val_mean_absolute_error: 0.0149
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.9707e-04 - mean_absolute_error: 0.0098 - val_loss: 4.2308e-04 - val_mean_absolute_error: 0.0146
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8512e-04 - mean_absolute_error: 0.0094 - val_loss: 4.7554e-04 - val_mean_absolute_error: 0.0160
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.6304e-04 - mean_absolute_error: 0.0088 - val_loss: 4.5614e-04 - val_mean_absolute_error: 0.0156
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5634e-04 - mean_absolute_error: 0.0085 - val_loss: 3.9674e-04 - val_mean_absolute_error: 0.0142
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4570e-04 - mean_absolute_error: 0.0082 - val_loss: 3.8469e-04 - val_mean_absolute_error: 0.0139
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6183e-04 - mean_absolute_error: 0.0090 - val_loss: 3.8021e-04 - val_mean_absolute_error: 0.0139
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7734e-04 - mean_absolute_error: 0.0093 - val_loss: 3.7844e-04 - val_mean_absolute_error: 0.0139
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.5451e-04 - mean_absolute_error: 0.0086 - val_loss: 3.5586e-04 - val_mean_absolute_error: 0.0134
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.5422e-04 - mean_absolute_error: 0.0088 - val_loss: 3.8294e-04 - val_mean_absolute_error: 0.0142
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.7194e-04 - mean_absolute_error: 0.0093 - val_loss: 3.4623e-04 - val_mean_absolute_error: 0.0133
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3166e-04 - mean_absolute_error: 0.0080 - val_loss: 3.7026e-04 - val_mean_absolute_error: 0.0140
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.5767e-04 - mean_absolute_error: 0.0088 - val_loss: 3.3134e-04 - val_mean_absolute_error: 0.0130
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2814e-04 - mean_absolute_error: 0.0078 - val_loss: 3.4794e-04 - val_mean_absolute_error: 0.0134
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3757e-04 - mean_absolute_error: 0.0081 - val_loss: 3.4445e-04 - val_mean_absolute_error: 0.0139
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.9304e-04 - mean_absolute_error: 0.0100 - val_loss: 4.3466e-04 - val_mean_absolute_error: 0.0160
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5085e-04 - mean_absolute_error: 0.0088 - val_loss: 3.2518e-04 - val_mean_absolute_error: 0.0133
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3919e-04 - mean_absolute_error: 0.0082 - val_loss: 3.3363e-04 - val_mean_absolute_error: 0.0137
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.4159e-04 - mean_absolute_error: 0.0085 - val_loss: 3.6746e-04 - val_mean_absolute_error: 0.0142
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.1907e-04 - mean_absolute_error: 0.0075 - val_loss: 3.0753e-04 - val_mean_absolute_error: 0.0125
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.2269e-04 - mean_absolute_error: 0.0075 - val_loss: 3.0401e-04 - val_mean_absolute_error: 0.0125
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.3070e-04 - mean_absolute_error: 0.0080 - val_loss: 3.7008e-04 - val_mean_absolute_error: 0.0144
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.2210e-04 - mean_absolute_error: 0.0078 - val_loss: 3.0872e-04 - val_mean_absolute_error: 0.0131
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2852e-04 - mean_absolute_error: 0.0082 - val_loss: 3.0261e-04 - val_mean_absolute_error: 0.0125
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2252e-04 - mean_absolute_error: 0.0075 - val_loss: 2.9880e-04 - val_mean_absolute_error: 0.0124
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.2545e-04 - mean_absolute_error: 0.0076 - val_loss: 3.7637e-04 - val_mean_absolute_error: 0.0148
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.5078e-04 - mean_absolute_error: 0.0092 - val_loss: 2.8884e-04 - val_mean_absolute_error: 0.0122
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.1781e-04 - mean_absolute_error: 0.0073 - val_loss: 2.8544e-04 - val_mean_absolute_error: 0.0121
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2071e-04 - mean_absolute_error: 0.0075 - val_loss: 3.4609e-04 - val_mean_absolute_error: 0.0146
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.4136e-04 - mean_absolute_error: 0.0084 - val_loss: 5.3702e-04 - val_mean_absolute_error: 0.0196
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.6795e-04 - mean_absolute_error: 0.0098 - val_loss: 2.8739e-04 - val_mean_absolute_error: 0.0122
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.1072e-04 - mean_absolute_error: 0.0073 - val_loss: 3.0261e-04 - val_mean_absolute_error: 0.0133
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3882e-04 - mean_absolute_error: 0.0081 - val_loss: 2.8060e-04 - val_mean_absolute_error: 0.0121
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0284e-04 - mean_absolute_error: 0.0068 - val_loss: 2.8942e-04 - val_mean_absolute_error: 0.0123
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.1415e-04 - mean_absolute_error: 0.0073 - val_loss: 2.8940e-04 - val_mean_absolute_error: 0.0124
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.1610e-04 - mean_absolute_error: 0.0078 - val_loss: 4.2222e-04 - val_mean_absolute_error: 0.0164
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.1372e-04 - mean_absolute_error: 0.0078 - val_loss: 2.7761e-04 - val_mean_absolute_error: 0.0122
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.1553e-04 - mean_absolute_error: 0.0075 - val_loss: 2.8878e-04 - val_mean_absolute_error: 0.0124
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.2943e-04 - mean_absolute_error: 0.0077 - val_loss: 2.8103e-04 - val_mean_absolute_error: 0.0124
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.2132e-04 - mean_absolute_error: 0.0073 - val_loss: 2.7820e-04 - val_mean_absolute_error: 0.0123
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0279e-04 - mean_absolute_error: 0.0069 - val_loss: 4.0600e-04 - val_mean_absolute_error: 0.0160
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5689e-04 - mean_absolute_error: 0.0090 - val_loss: 3.9854e-04 - val_mean_absolute_error: 0.0158
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.0011e-04 - mean_absolute_error: 0.0070 - val_loss: 2.8012e-04 - val_mean_absolute_error: 0.0122
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.1130e-04 - mean_absolute_error: 0.0073 - val_loss: 3.9221e-04 - val_mean_absolute_error: 0.0157
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.4364e-04 - mean_absolute_error: 0.0088 - val_loss: 4.2477e-04 - val_mean_absolute_error: 0.0165
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5365e-04 - mean_absolute_error: 0.0092 - val_loss: 2.9325e-04 - val_mean_absolute_error: 0.0128
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0515e-04 - mean_absolute_error: 0.0074 - val_loss: 2.8665e-04 - val_mean_absolute_error: 0.0127
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0982e-04 - mean_absolute_error: 0.0071 - val_loss: 2.8526e-04 - val_mean_absolute_error: 0.0125
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2251e-04 - mean_absolute_error: 0.0075 - val_loss: 2.9391e-04 - val_mean_absolute_error: 0.0128
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0824e-04 - mean_absolute_error: 0.0072 - val_loss: 2.8339e-04 - val_mean_absolute_error: 0.0127
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.1981e-04 - mean_absolute_error: 0.0073 - val_loss: 3.2309e-04 - val_mean_absolute_error: 0.0138
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0781e-04 - mean_absolute_error: 0.0071 - val_loss: 4.1411e-04 - val_mean_absolute_error: 0.0163
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.4117e-04 - mean_absolute_error: 0.0090 - val_loss: 3.7910e-04 - val_mean_absolute_error: 0.0154
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4272e-04 - mean_absolute_error: 0.0085 - val_loss: 3.2534e-04 - val_mean_absolute_error: 0.0139
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.0281e-04 - mean_absolute_error: 0.0071 - val_loss: 2.7138e-04 - val_mean_absolute_error: 0.0122
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0586e-04 - mean_absolute_error: 0.0071 - val_loss: 4.8437e-04 - val_mean_absolute_error: 0.0185
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7209e-04 - mean_absolute_error: 0.0098 - val_loss: 2.8240e-04 - val_mean_absolute_error: 0.0126
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.0111e-04 - mean_absolute_error: 0.0070 - val_loss: 2.7518e-04 - val_mean_absolute_error: 0.0122
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.1201e-04 - mean_absolute_error: 0.0075 - val_loss: 3.0838e-04 - val_mean_absolute_error: 0.0135
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2536e-04 - mean_absolute_error: 0.0080 - val_loss: 3.3739e-04 - val_mean_absolute_error: 0.0144
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.0825e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9467e-04 - val_mean_absolute_error: 0.0130
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0827e-04 - mean_absolute_error: 0.0069 - val_loss: 3.4917e-04 - val_mean_absolute_error: 0.0147
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.1760e-04 - mean_absolute_error: 0.0078 - val_loss: 3.0769e-04 - val_mean_absolute_error: 0.0135
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.1185e-04 - mean_absolute_error: 0.0074 - val_loss: 2.9270e-04 - val_mean_absolute_error: 0.0130
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.1638e-04 - mean_absolute_error: 0.0074 - val_loss: 2.8272e-04 - val_mean_absolute_error: 0.0126
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.3449e-05 - mean_absolute_error: 0.0067 - val_loss: 3.1436e-04 - val_mean_absolute_error: 0.0138
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0111e-04 - mean_absolute_error: 0.0071 - val_loss: 2.7767e-04 - val_mean_absolute_error: 0.0125
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.2837e-04 - mean_absolute_error: 0.0083 - val_loss: 2.7173e-04 - val_mean_absolute_error: 0.0123
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.9331e-05 - mean_absolute_error: 0.0071 - val_loss: 2.7960e-04 - val_mean_absolute_error: 0.0125
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.0681e-04 - mean_absolute_error: 0.0071 - val_loss: 2.7328e-04 - val_mean_absolute_error: 0.0123
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.1776e-04 - mean_absolute_error: 0.0075 - val_loss: 4.0668e-04 - val_mean_absolute_error: 0.0164
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.2635e-04 - mean_absolute_error: 0.0081 - val_loss: 3.3885e-04 - val_mean_absolute_error: 0.0145
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.2380e-04 - mean_absolute_error: 0.0084 - val_loss: 3.4479e-04 - val_mean_absolute_error: 0.0146
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2400e-04 - mean_absolute_error: 0.0075 - val_loss: 3.2026e-04 - val_mean_absolute_error: 0.0140
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3032e-04 - mean_absolute_error: 0.0083 - val_loss: 3.0608e-04 - val_mean_absolute_error: 0.0134
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.8534e-05 - mean_absolute_error: 0.0067 - val_loss: 2.8857e-04 - val_mean_absolute_error: 0.0128
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0835e-04 - mean_absolute_error: 0.0073 - val_loss: 3.5853e-04 - val_mean_absolute_error: 0.0150
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.2022e-04 - mean_absolute_error: 0.0076 - val_loss: 2.8846e-04 - val_mean_absolute_error: 0.0128
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.9358e-05 - mean_absolute_error: 0.0071 - val_loss: 2.7094e-04 - val_mean_absolute_error: 0.0123
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.8863e-05 - mean_absolute_error: 0.0070 - val_loss: 2.7745e-04 - val_mean_absolute_error: 0.0124
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.1149e-04 - mean_absolute_error: 0.0073 - val_loss: 3.0213e-04 - val_mean_absolute_error: 0.0132
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0792e-04 - mean_absolute_error: 0.0075 - val_loss: 2.9284e-04 - val_mean_absolute_error: 0.0131
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.0528e-04 - mean_absolute_error: 0.0073 - val_loss: 2.9886e-04 - val_mean_absolute_error: 0.0131
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3098e-04 - mean_absolute_error: 0.0081 - val_loss: 2.8148e-04 - val_mean_absolute_error: 0.0127
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.3944e-05 - mean_absolute_error: 0.0071 - val_loss: 4.0838e-04 - val_mean_absolute_error: 0.0163
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.1553e-04 - mean_absolute_error: 0.0077 - val_loss: 2.9504e-04 - val_mean_absolute_error: 0.0130
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2471e-04 - mean_absolute_error: 0.0081 - val_loss: 2.7618e-04 - val_mean_absolute_error: 0.0124
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.0045e-04 - mean_absolute_error: 0.0071 - val_loss: 2.7630e-04 - val_mean_absolute_error: 0.0125
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0202e-04 - mean_absolute_error: 0.0068 - val_loss: 2.7980e-04 - val_mean_absolute_error: 0.0127
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.0994e-04 - mean_absolute_error: 0.0082 - val_loss: 2.8371e-04 - val_mean_absolute_error: 0.0128
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.0699e-04 - mean_absolute_error: 0.0071 - val_loss: 3.0363e-04 - val_mean_absolute_error: 0.0135
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0935e-04 - mean_absolute_error: 0.0075 - val_loss: 3.1861e-04 - val_mean_absolute_error: 0.0138
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0442e-04 - mean_absolute_error: 0.0068 - val_loss: 3.3325e-04 - val_mean_absolute_error: 0.0143
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 1.1033e-04 - mean_absolute_error: 0.0073 - val_loss: 2.9363e-04 - val_mean_absolute_error: 0.0132
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.4237e-05 - mean_absolute_error: 0.0068 - val_loss: 3.3976e-04 - val_mean_absolute_error: 0.0145
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0133e-04 - mean_absolute_error: 0.0074 - val_loss: 2.7641e-04 - val_mean_absolute_error: 0.0125
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0250e-04 - mean_absolute_error: 0.0068 - val_loss: 3.7400e-04 - val_mean_absolute_error: 0.0154
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.1555e-04 - mean_absolute_error: 0.0077 - val_loss: 2.8389e-04 - val_mean_absolute_error: 0.0128
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.1106e-04 - mean_absolute_error: 0.0069 - val_loss: 2.9263e-04 - val_mean_absolute_error: 0.0129
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.0236e-04 - mean_absolute_error: 0.0065 - val_loss: 2.7951e-04 - val_mean_absolute_error: 0.0125
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0034e-04 - mean_absolute_error: 0.0068 - val_loss: 2.7385e-04 - val_mean_absolute_error: 0.0124
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.6746e-05 - mean_absolute_error: 0.0068 - val_loss: 2.8744e-04 - val_mean_absolute_error: 0.0129
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.1672e-04 - mean_absolute_error: 0.0081 - val_loss: 2.9488e-04 - val_mean_absolute_error: 0.0131
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0467e-04 - mean_absolute_error: 0.0075 - val_loss: 3.1723e-04 - val_mean_absolute_error: 0.0137
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3825e-04 - mean_absolute_error: 0.0086 - val_loss: 2.9026e-04 - val_mean_absolute_error: 0.0130
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.6022e-05 - mean_absolute_error: 0.0071 - val_loss: 2.8440e-04 - val_mean_absolute_error: 0.0126
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.2883e-04 - mean_absolute_error: 0.0081 - val_loss: 3.5090e-04 - val_mean_absolute_error: 0.0147
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.1153e-04 - mean_absolute_error: 0.0077 - val_loss: 3.7721e-04 - val_mean_absolute_error: 0.0155
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.8880e-05 - mean_absolute_error: 0.0070 - val_loss: 2.8340e-04 - val_mean_absolute_error: 0.0126
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.9683e-05 - mean_absolute_error: 0.0061 - val_loss: 2.9658e-04 - val_mean_absolute_error: 0.0132
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.0058e-05 - mean_absolute_error: 0.0065 - val_loss: 2.8542e-04 - val_mean_absolute_error: 0.0127
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.9234e-05 - mean_absolute_error: 0.0070 - val_loss: 4.4802e-04 - val_mean_absolute_error: 0.0171
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.0948e-04 - mean_absolute_error: 0.0073 - val_loss: 4.8204e-04 - val_mean_absolute_error: 0.0180
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5488e-04 - mean_absolute_error: 0.0094 - val_loss: 2.8590e-04 - val_mean_absolute_error: 0.0127
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.3652e-05 - mean_absolute_error: 0.0067 - val_loss: 2.8815e-04 - val_mean_absolute_error: 0.0127
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2155e-04 - mean_absolute_error: 0.0079 - val_loss: 3.3093e-04 - val_mean_absolute_error: 0.0143
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 9.1036e-05 - mean_absolute_error: 0.0065 - val_loss: 2.9158e-04 - val_mean_absolute_error: 0.0130
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0094e-04 - mean_absolute_error: 0.0068 - val_loss: 2.8356e-04 - val_mean_absolute_error: 0.0126
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0142e-04 - mean_absolute_error: 0.0069 - val_loss: 2.8309e-04 - val_mean_absolute_error: 0.0126
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.0756e-04 - mean_absolute_error: 0.0073 - val_loss: 3.1399e-04 - val_mean_absolute_error: 0.0138
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.9541e-05 - mean_absolute_error: 0.0070 - val_loss: 2.9210e-04 - val_mean_absolute_error: 0.0128
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0155e-04 - mean_absolute_error: 0.0071 - val_loss: 3.1647e-04 - val_mean_absolute_error: 0.0139
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.1422e-04 - mean_absolute_error: 0.0078 - val_loss: 3.4378e-04 - val_mean_absolute_error: 0.0146
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.1748e-04 - mean_absolute_error: 0.0075 - val_loss: 3.0857e-04 - val_mean_absolute_error: 0.0136
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0613e-04 - mean_absolute_error: 0.0070 - val_loss: 3.5036e-04 - val_mean_absolute_error: 0.0148
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0666e-04 - mean_absolute_error: 0.0076 - val_loss: 4.0508e-04 - val_mean_absolute_error: 0.0161
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.2062e-04 - mean_absolute_error: 0.0080 - val_loss: 3.3235e-04 - val_mean_absolute_error: 0.0142
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.0487e-04 - mean_absolute_error: 0.0073 - val_loss: 2.8560e-04 - val_mean_absolute_error: 0.0127
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.2703e-04 - mean_absolute_error: 0.0078 - val_loss: 2.9107e-04 - val_mean_absolute_error: 0.0128
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0635e-04 - mean_absolute_error: 0.0073 - val_loss: 2.8391e-04 - val_mean_absolute_error: 0.0127
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.8751e-05 - mean_absolute_error: 0.0070 - val_loss: 2.8290e-04 - val_mean_absolute_error: 0.0127
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.3718e-05 - mean_absolute_error: 0.0068 - val_loss: 3.8326e-04 - val_mean_absolute_error: 0.0156
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.4794e-04 - mean_absolute_error: 0.0094 - val_loss: 3.5929e-04 - val_mean_absolute_error: 0.0150
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.1752e-04 - mean_absolute_error: 0.0080 - val_loss: 4.5980e-04 - val_mean_absolute_error: 0.0176
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.1295e-04 - mean_absolute_error: 0.0079 - val_loss: 2.9381e-04 - val_mean_absolute_error: 0.0129
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.1715e-04 - mean_absolute_error: 0.0082 - val_loss: 3.0315e-04 - val_mean_absolute_error: 0.0132
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6592e-04 - mean_absolute_error: 0.0096 - val_loss: 3.0958e-04 - val_mean_absolute_error: 0.0137
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0836e-04 - mean_absolute_error: 0.0076 - val_loss: 5.1606e-04 - val_mean_absolute_error: 0.0187
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.4126e-04 - mean_absolute_error: 0.0091 - val_loss: 4.2399e-04 - val_mean_absolute_error: 0.0167
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.1248e-04 - mean_absolute_error: 0.0078 - val_loss: 2.7546e-04 - val_mean_absolute_error: 0.0125
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.1407e-04 - mean_absolute_error: 0.0074 - val_loss: 2.8164e-04 - val_mean_absolute_error: 0.0126
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.7319e-05 - mean_absolute_error: 0.0069 - val_loss: 4.7422e-04 - val_mean_absolute_error: 0.0178
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.2366e-04 - mean_absolute_error: 0.0085 - val_loss: 3.0841e-04 - val_mean_absolute_error: 0.0136
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.1869e-04 - mean_absolute_error: 0.0081 - val_loss: 3.0336e-04 - val_mean_absolute_error: 0.0135
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.4178e-05 - mean_absolute_error: 0.0064 - val_loss: 2.8778e-04 - val_mean_absolute_error: 0.0127
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.0022e-05 - mean_absolute_error: 0.0065 - val_loss: 2.8385e-04 - val_mean_absolute_error: 0.0126
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.0502e-04 - mean_absolute_error: 0.0072 - val_loss: 2.8612e-04 - val_mean_absolute_error: 0.0129
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.0130e-04 - mean_absolute_error: 0.0070 - val_loss: 3.5524e-04 - val_mean_absolute_error: 0.0149
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0463e-04 - mean_absolute_error: 0.0072 - val_loss: 3.6735e-04 - val_mean_absolute_error: 0.0151
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.0906e-04 - mean_absolute_error: 0.0074 - val_loss: 2.8406e-04 - val_mean_absolute_error: 0.0126
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0806e-04 - mean_absolute_error: 0.0070 - val_loss: 2.8906e-04 - val_mean_absolute_error: 0.0129
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.2433e-04 - mean_absolute_error: 0.0077 - val_loss: 2.8845e-04 - val_mean_absolute_error: 0.0127
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 9.5787e-05 - mean_absolute_error: 0.0070 - val_loss: 3.0433e-04 - val_mean_absolute_error: 0.0135
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.2809e-05 - mean_absolute_error: 0.0067 - val_loss: 2.9713e-04 - val_mean_absolute_error: 0.0131
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.0351e-04 - mean_absolute_error: 0.0070 - val_loss: 2.9249e-04 - val_mean_absolute_error: 0.0128
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.6216e-05 - mean_absolute_error: 0.0069 - val_loss: 3.0723e-04 - val_mean_absolute_error: 0.0134
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 9.6910e-05 - mean_absolute_error: 0.0068 - val_loss: 4.0973e-04 - val_mean_absolute_error: 0.0162
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.2416e-04 - mean_absolute_error: 0.0072 - val_loss: 2.8871e-04 - val_mean_absolute_error: 0.0127
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0147e-04 - mean_absolute_error: 0.0069 - val_loss: 2.9087e-04 - val_mean_absolute_error: 0.0128
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6045e-04 - mean_absolute_error: 0.0092 - val_loss: 3.4997e-04 - val_mean_absolute_error: 0.0146
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2223e-04 - mean_absolute_error: 0.0075 - val_loss: 3.1094e-04 - val_mean_absolute_error: 0.0135
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.3697e-05 - mean_absolute_error: 0.0067 - val_loss: 2.8086e-04 - val_mean_absolute_error: 0.0127
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.1655e-04 - mean_absolute_error: 0.0081 - val_loss: 2.8205e-04 - val_mean_absolute_error: 0.0127
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0130e-04 - mean_absolute_error: 0.0071 - val_loss: 2.8938e-04 - val_mean_absolute_error: 0.0128
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.5114e-05 - mean_absolute_error: 0.0064 - val_loss: 2.9033e-04 - val_mean_absolute_error: 0.0128
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.0307e-04 - mean_absolute_error: 0.0068 - val_loss: 3.1205e-04 - val_mean_absolute_error: 0.0136
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.2634e-04 - mean_absolute_error: 0.0075 - val_loss: 3.2258e-04 - val_mean_absolute_error: 0.0140
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.1060e-04 - mean_absolute_error: 0.0074 - val_loss: 4.8983e-04 - val_mean_absolute_error: 0.0181
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.4355e-04 - mean_absolute_error: 0.0091 - val_loss: 4.5171e-04 - val_mean_absolute_error: 0.0173
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.5586e-04 - mean_absolute_error: 0.0092 - val_loss: 3.0500e-04 - val_mean_absolute_error: 0.0134
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.1088e-04 - mean_absolute_error: 0.0070 - val_loss: 3.3241e-04 - val_mean_absolute_error: 0.0143
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3746e-04 - mean_absolute_error: 0.0087 - val_loss: 2.9920e-04 - val_mean_absolute_error: 0.0130
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.0017e-04 - mean_absolute_error: 0.0070 - val_loss: 2.9294e-04 - val_mean_absolute_error: 0.0129
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.0726e-04 - mean_absolute_error: 0.0070 - val_loss: 2.8177e-04 - val_mean_absolute_error: 0.0126
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.5384e-05 - mean_absolute_error: 0.0069 - val_loss: 3.0066e-04 - val_mean_absolute_error: 0.0130
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.2899e-04 - mean_absolute_error: 0.0081 - val_loss: 3.4596e-04 - val_mean_absolute_error: 0.0145
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 9.4093e-05 - mean_absolute_error: 0.0067 - val_loss: 3.0840e-04 - val_mean_absolute_error: 0.0135
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0688e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9906e-04 - val_mean_absolute_error: 0.0130
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.1563e-04 - mean_absolute_error: 0.0076 - val_loss: 2.9241e-04 - val_mean_absolute_error: 0.0129
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.9880e-05 - mean_absolute_error: 0.0067 - val_loss: 2.9006e-04 - val_mean_absolute_error: 0.0129
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.7436e-05 - mean_absolute_error: 0.0067 - val_loss: 2.8355e-04 - val_mean_absolute_error: 0.0126
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.1428e-04 - mean_absolute_error: 0.0072 - val_loss: 2.8971e-04 - val_mean_absolute_error: 0.0128
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.8437e-05 - mean_absolute_error: 0.0061 - val_loss: 3.4604e-04 - val_mean_absolute_error: 0.0146
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.1611e-04 - mean_absolute_error: 0.0078 - val_loss: 4.6726e-04 - val_mean_absolute_error: 0.0176
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.1091e-04 - mean_absolute_error: 0.0081 - val_loss: 3.4831e-04 - val_mean_absolute_error: 0.0146
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.0579e-04 - mean_absolute_error: 0.0071 - val_loss: 4.4043e-04 - val_mean_absolute_error: 0.0169
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.7954e-05 - mean_absolute_error: 0.0072 - val_loss: 3.5941e-04 - val_mean_absolute_error: 0.0149
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6071e-04 - mean_absolute_error: 0.0098 - val_loss: 3.0253e-04 - val_mean_absolute_error: 0.0131
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0726e-04 - mean_absolute_error: 0.0072 - val_loss: 3.0891e-04 - val_mean_absolute_error: 0.0136
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.5164e-05 - mean_absolute_error: 0.0069 - val_loss: 2.9665e-04 - val_mean_absolute_error: 0.0130
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.1080e-04 - mean_absolute_error: 0.0070 - val_loss: 3.2526e-04 - val_mean_absolute_error: 0.0140
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.7175e-05 - mean_absolute_error: 0.0065 - val_loss: 3.3067e-04 - val_mean_absolute_error: 0.0142
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.0945e-04 - mean_absolute_error: 0.0074 - val_loss: 3.1867e-04 - val_mean_absolute_error: 0.0138
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0212e-04 - mean_absolute_error: 0.0070 - val_loss: 2.9919e-04 - val_mean_absolute_error: 0.0130
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2948e-04 - mean_absolute_error: 0.0077 - val_loss: 2.9191e-04 - val_mean_absolute_error: 0.0128
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 9.1312e-05 - mean_absolute_error: 0.0066 - val_loss: 2.9068e-04 - val_mean_absolute_error: 0.0128

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 204ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3848e-04 - mean_absolute_error: 0.0143
# Test Loss: [0.0002906807349063456, 0.012815012596547604]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 1459858.601798677
# RMSE: 1208.2460849506929
# MAE: 885.5443382719124
# MAPE: 2.7111106508565084 %
#
# Model evalution on validate set
# MSE: 2143311.47849916
# RMSE: 1464.0052863631197
# MAE: 888.6149487401186
# MAPE: 2.042872597193968 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step

# %%
y_pred_30_days
# Out:
# array([[60838.098],
#        [60324.527],
#        [60733.594],
#        [60576.87 ],
#        [60659.48 ],
#        [60623.34 ],
#        [60639.53 ],
#        [60632.215],
#        [60635.402],
#        [60633.99 ],
#        [60634.605],
#        [60634.332],
#        [60634.453],
#        [60634.402],
#        [60634.42 ],
#        [60634.42 ],
#        [60634.414],
#        [60634.42 ],
#        [60634.414],
#        [60634.42 ],
#        [60634.414],
#        [60634.42 ],
#        [60634.414],
#        [60634.42 ],
#        [60634.414],
#        [60634.42 ],
#        [60634.414],
#        [60634.42 ],
#        [60634.414],
#        [60634.42 ],
#        [60634.414]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
