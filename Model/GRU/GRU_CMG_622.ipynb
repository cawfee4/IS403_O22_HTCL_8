# %% [markdown]
# # Model: GRU (Gated Recurrent Unit)  - Stock Token: CMG - Test/Train/Vaildation: 60/20/20
# - Dataset: 1313 rows x 7 columns (01/03/2019 - 31/05/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1290.69
# - MAE: 986.65
# - MAPE: 3.03 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

plt.style.use("default")

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 1  # 6 2 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830
# ...           ...
# 2024-05-27  59000
# 2024-05-28  62100
# 2024-05-29  60000
# 2024-05-30  59200
# 2024-05-31  60900
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((776, 10), (776,), (251, 10), (251,), (253, 10), (253,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(100),
        Dense(32, activation="relu"),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 100)            │        30,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,165 (133.46 KB)
#  Trainable params: 34,165 (133.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0238 - mean_absolute_error: 0.1053 - val_loss: 0.0043 - val_mean_absolute_error: 0.0623
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3493e-04 - mean_absolute_error: 0.0169 - val_loss: 5.4649e-04 - val_mean_absolute_error: 0.0172
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2816e-04 - mean_absolute_error: 0.0112 - val_loss: 4.4130e-04 - val_mean_absolute_error: 0.0149
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8440e-04 - mean_absolute_error: 0.0092 - val_loss: 4.5991e-04 - val_mean_absolute_error: 0.0159
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9721e-04 - mean_absolute_error: 0.0102 - val_loss: 4.3918e-04 - val_mean_absolute_error: 0.0150
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8589e-04 - mean_absolute_error: 0.0095 - val_loss: 4.1793e-04 - val_mean_absolute_error: 0.0148
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5553e-04 - mean_absolute_error: 0.0085 - val_loss: 4.3202e-04 - val_mean_absolute_error: 0.0150
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7243e-04 - mean_absolute_error: 0.0089 - val_loss: 4.2386e-04 - val_mean_absolute_error: 0.0149
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8493e-04 - mean_absolute_error: 0.0092 - val_loss: 3.8350e-04 - val_mean_absolute_error: 0.0141
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6157e-04 - mean_absolute_error: 0.0089 - val_loss: 4.8538e-04 - val_mean_absolute_error: 0.0166
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6669e-04 - mean_absolute_error: 0.0089 - val_loss: 4.3149e-04 - val_mean_absolute_error: 0.0161
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8342e-04 - mean_absolute_error: 0.0095 - val_loss: 4.0181e-04 - val_mean_absolute_error: 0.0147
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5493e-04 - mean_absolute_error: 0.0090 - val_loss: 4.9734e-04 - val_mean_absolute_error: 0.0171
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5011e-04 - mean_absolute_error: 0.0087 - val_loss: 3.4423e-04 - val_mean_absolute_error: 0.0132
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5115e-04 - mean_absolute_error: 0.0083 - val_loss: 3.3956e-04 - val_mean_absolute_error: 0.0132
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5345e-04 - mean_absolute_error: 0.0088 - val_loss: 3.3452e-04 - val_mean_absolute_error: 0.0131
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7522e-04 - mean_absolute_error: 0.0097 - val_loss: 5.6034e-04 - val_mean_absolute_error: 0.0189
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6596e-04 - mean_absolute_error: 0.0097 - val_loss: 3.2637e-04 - val_mean_absolute_error: 0.0131
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3829e-04 - mean_absolute_error: 0.0085 - val_loss: 3.2970e-04 - val_mean_absolute_error: 0.0130
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3776e-04 - mean_absolute_error: 0.0080 - val_loss: 4.7442e-04 - val_mean_absolute_error: 0.0170
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5383e-04 - mean_absolute_error: 0.0094 - val_loss: 3.1819e-04 - val_mean_absolute_error: 0.0129
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5260e-04 - mean_absolute_error: 0.0086 - val_loss: 3.3038e-04 - val_mean_absolute_error: 0.0131
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3018e-04 - mean_absolute_error: 0.0081 - val_loss: 3.8325e-04 - val_mean_absolute_error: 0.0147
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5341e-04 - mean_absolute_error: 0.0090 - val_loss: 3.0733e-04 - val_mean_absolute_error: 0.0126
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2512e-04 - mean_absolute_error: 0.0078 - val_loss: 3.1173e-04 - val_mean_absolute_error: 0.0127
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5635e-04 - mean_absolute_error: 0.0090 - val_loss: 2.9974e-04 - val_mean_absolute_error: 0.0126
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5346e-04 - mean_absolute_error: 0.0089 - val_loss: 3.5947e-04 - val_mean_absolute_error: 0.0147
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4227e-04 - mean_absolute_error: 0.0084 - val_loss: 3.1237e-04 - val_mean_absolute_error: 0.0127
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2189e-04 - mean_absolute_error: 0.0078 - val_loss: 3.0965e-04 - val_mean_absolute_error: 0.0127
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2104e-04 - mean_absolute_error: 0.0075 - val_loss: 3.0370e-04 - val_mean_absolute_error: 0.0126
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4685e-04 - mean_absolute_error: 0.0086 - val_loss: 3.2638e-04 - val_mean_absolute_error: 0.0133
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3921e-04 - mean_absolute_error: 0.0081 - val_loss: 3.2351e-04 - val_mean_absolute_error: 0.0133
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2257e-04 - mean_absolute_error: 0.0077 - val_loss: 2.9902e-04 - val_mean_absolute_error: 0.0125
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2465e-04 - mean_absolute_error: 0.0076 - val_loss: 3.7900e-04 - val_mean_absolute_error: 0.0157
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4506e-04 - mean_absolute_error: 0.0086 - val_loss: 3.1972e-04 - val_mean_absolute_error: 0.0132
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2119e-04 - mean_absolute_error: 0.0077 - val_loss: 3.1480e-04 - val_mean_absolute_error: 0.0131
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2498e-04 - mean_absolute_error: 0.0078 - val_loss: 3.0452e-04 - val_mean_absolute_error: 0.0133
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1545e-04 - mean_absolute_error: 0.0073 - val_loss: 2.9670e-04 - val_mean_absolute_error: 0.0129
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1845e-04 - mean_absolute_error: 0.0073 - val_loss: 2.8018e-04 - val_mean_absolute_error: 0.0121
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0992e-04 - mean_absolute_error: 0.0074 - val_loss: 2.8064e-04 - val_mean_absolute_error: 0.0122
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2378e-04 - mean_absolute_error: 0.0076 - val_loss: 2.8927e-04 - val_mean_absolute_error: 0.0124
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4086e-05 - mean_absolute_error: 0.0068 - val_loss: 3.3952e-04 - val_mean_absolute_error: 0.0140
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2940e-04 - mean_absolute_error: 0.0080 - val_loss: 2.8073e-04 - val_mean_absolute_error: 0.0123
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0049e-04 - mean_absolute_error: 0.0071 - val_loss: 2.8739e-04 - val_mean_absolute_error: 0.0124
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1800e-04 - mean_absolute_error: 0.0077 - val_loss: 3.2623e-04 - val_mean_absolute_error: 0.0137
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1906e-04 - mean_absolute_error: 0.0078 - val_loss: 2.8109e-04 - val_mean_absolute_error: 0.0122
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3559e-04 - mean_absolute_error: 0.0082 - val_loss: 2.9748e-04 - val_mean_absolute_error: 0.0130
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2510e-04 - mean_absolute_error: 0.0079 - val_loss: 2.8165e-04 - val_mean_absolute_error: 0.0125
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1549e-04 - mean_absolute_error: 0.0072 - val_loss: 2.7417e-04 - val_mean_absolute_error: 0.0122
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0459e-04 - mean_absolute_error: 0.0072 - val_loss: 2.7405e-04 - val_mean_absolute_error: 0.0122
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0156e-04 - mean_absolute_error: 0.0070 - val_loss: 2.7940e-04 - val_mean_absolute_error: 0.0125
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1260e-04 - mean_absolute_error: 0.0076 - val_loss: 2.7953e-04 - val_mean_absolute_error: 0.0124
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0892e-04 - mean_absolute_error: 0.0073 - val_loss: 2.7459e-04 - val_mean_absolute_error: 0.0123
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0869e-04 - mean_absolute_error: 0.0071 - val_loss: 2.7233e-04 - val_mean_absolute_error: 0.0122
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0435e-04 - mean_absolute_error: 0.0067 - val_loss: 3.1232e-04 - val_mean_absolute_error: 0.0134
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2394e-04 - mean_absolute_error: 0.0079 - val_loss: 2.9256e-04 - val_mean_absolute_error: 0.0129
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7969e-05 - mean_absolute_error: 0.0068 - val_loss: 2.8530e-04 - val_mean_absolute_error: 0.0126
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0158e-04 - mean_absolute_error: 0.0070 - val_loss: 3.1592e-04 - val_mean_absolute_error: 0.0137
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4146e-04 - mean_absolute_error: 0.0089 - val_loss: 3.6365e-04 - val_mean_absolute_error: 0.0150
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0656e-04 - mean_absolute_error: 0.0073 - val_loss: 2.8202e-04 - val_mean_absolute_error: 0.0125
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4835e-05 - mean_absolute_error: 0.0066 - val_loss: 2.7798e-04 - val_mean_absolute_error: 0.0124
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0912e-04 - mean_absolute_error: 0.0070 - val_loss: 3.0198e-04 - val_mean_absolute_error: 0.0133
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1683e-04 - mean_absolute_error: 0.0074 - val_loss: 2.7965e-04 - val_mean_absolute_error: 0.0125
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0007e-04 - mean_absolute_error: 0.0070 - val_loss: 2.7213e-04 - val_mean_absolute_error: 0.0123
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0665e-04 - mean_absolute_error: 0.0067 - val_loss: 2.8568e-04 - val_mean_absolute_error: 0.0128
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0927e-04 - mean_absolute_error: 0.0072 - val_loss: 4.4229e-04 - val_mean_absolute_error: 0.0174
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4669e-04 - mean_absolute_error: 0.0095 - val_loss: 3.2245e-04 - val_mean_absolute_error: 0.0139
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0272e-04 - mean_absolute_error: 0.0072 - val_loss: 3.2859e-04 - val_mean_absolute_error: 0.0141
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1022e-04 - mean_absolute_error: 0.0074 - val_loss: 3.6821e-04 - val_mean_absolute_error: 0.0153
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5091e-04 - mean_absolute_error: 0.0091 - val_loss: 2.9011e-04 - val_mean_absolute_error: 0.0128
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0318e-04 - mean_absolute_error: 0.0069 - val_loss: 2.7996e-04 - val_mean_absolute_error: 0.0125
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1555e-04 - mean_absolute_error: 0.0072 - val_loss: 2.7507e-04 - val_mean_absolute_error: 0.0124
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0488e-04 - mean_absolute_error: 0.0070 - val_loss: 3.2457e-04 - val_mean_absolute_error: 0.0140
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1232e-04 - mean_absolute_error: 0.0079 - val_loss: 2.7888e-04 - val_mean_absolute_error: 0.0125
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4581e-05 - mean_absolute_error: 0.0068 - val_loss: 2.8322e-04 - val_mean_absolute_error: 0.0127
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1604e-04 - mean_absolute_error: 0.0075 - val_loss: 2.7568e-04 - val_mean_absolute_error: 0.0124
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0297e-04 - mean_absolute_error: 0.0071 - val_loss: 2.7560e-04 - val_mean_absolute_error: 0.0124
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1172e-04 - mean_absolute_error: 0.0075 - val_loss: 2.9600e-04 - val_mean_absolute_error: 0.0132
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.9413e-05 - mean_absolute_error: 0.0069 - val_loss: 2.7717e-04 - val_mean_absolute_error: 0.0125
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3755e-04 - mean_absolute_error: 0.0089 - val_loss: 2.7632e-04 - val_mean_absolute_error: 0.0124
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0006e-04 - mean_absolute_error: 0.0070 - val_loss: 2.9122e-04 - val_mean_absolute_error: 0.0130
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2822e-04 - mean_absolute_error: 0.0076 - val_loss: 3.3706e-04 - val_mean_absolute_error: 0.0144
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1653e-04 - mean_absolute_error: 0.0075 - val_loss: 2.8240e-04 - val_mean_absolute_error: 0.0127
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.9156e-05 - mean_absolute_error: 0.0067 - val_loss: 3.1598e-04 - val_mean_absolute_error: 0.0138
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0051e-04 - mean_absolute_error: 0.0070 - val_loss: 4.9150e-04 - val_mean_absolute_error: 0.0181
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2792e-04 - mean_absolute_error: 0.0084 - val_loss: 5.3929e-04 - val_mean_absolute_error: 0.0192
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4298e-04 - mean_absolute_error: 0.0086 - val_loss: 2.7860e-04 - val_mean_absolute_error: 0.0125
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1206e-04 - mean_absolute_error: 0.0073 - val_loss: 2.8600e-04 - val_mean_absolute_error: 0.0128
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0760e-04 - mean_absolute_error: 0.0071 - val_loss: 2.8824e-04 - val_mean_absolute_error: 0.0128
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1167e-04 - mean_absolute_error: 0.0075 - val_loss: 2.9043e-04 - val_mean_absolute_error: 0.0128
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0371e-04 - mean_absolute_error: 0.0073 - val_loss: 2.7936e-04 - val_mean_absolute_error: 0.0127
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0435e-04 - mean_absolute_error: 0.0071 - val_loss: 2.8605e-04 - val_mean_absolute_error: 0.0129
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0717e-04 - mean_absolute_error: 0.0071 - val_loss: 2.7397e-04 - val_mean_absolute_error: 0.0124
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0214e-04 - mean_absolute_error: 0.0066 - val_loss: 2.7991e-04 - val_mean_absolute_error: 0.0127
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0974e-04 - mean_absolute_error: 0.0073 - val_loss: 3.5114e-04 - val_mean_absolute_error: 0.0148
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4150e-04 - mean_absolute_error: 0.0087 - val_loss: 2.7586e-04 - val_mean_absolute_error: 0.0124
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.9436e-05 - mean_absolute_error: 0.0068 - val_loss: 2.9375e-04 - val_mean_absolute_error: 0.0131
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0359e-04 - mean_absolute_error: 0.0070 - val_loss: 3.0503e-04 - val_mean_absolute_error: 0.0135
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1669e-04 - mean_absolute_error: 0.0077 - val_loss: 9.3012e-04 - val_mean_absolute_error: 0.0266
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1893e-04 - mean_absolute_error: 0.0121 - val_loss: 2.7847e-04 - val_mean_absolute_error: 0.0124
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0308e-04 - mean_absolute_error: 0.0072 - val_loss: 2.7582e-04 - val_mean_absolute_error: 0.0124
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7041e-05 - mean_absolute_error: 0.0070 - val_loss: 2.8662e-04 - val_mean_absolute_error: 0.0128
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4147e-05 - mean_absolute_error: 0.0069 - val_loss: 2.8995e-04 - val_mean_absolute_error: 0.0130
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4583e-05 - mean_absolute_error: 0.0069 - val_loss: 2.7654e-04 - val_mean_absolute_error: 0.0125
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1424e-05 - mean_absolute_error: 0.0066 - val_loss: 2.7912e-04 - val_mean_absolute_error: 0.0126
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5624e-05 - mean_absolute_error: 0.0069 - val_loss: 3.7949e-04 - val_mean_absolute_error: 0.0155
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1640e-04 - mean_absolute_error: 0.0077 - val_loss: 3.4468e-04 - val_mean_absolute_error: 0.0145
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4565e-04 - mean_absolute_error: 0.0088 - val_loss: 2.9471e-04 - val_mean_absolute_error: 0.0129
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0009e-04 - mean_absolute_error: 0.0069 - val_loss: 2.9607e-04 - val_mean_absolute_error: 0.0132
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1536e-04 - mean_absolute_error: 0.0071 - val_loss: 3.0399e-04 - val_mean_absolute_error: 0.0133
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1962e-04 - mean_absolute_error: 0.0082 - val_loss: 3.3929e-04 - val_mean_absolute_error: 0.0144
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5787e-04 - mean_absolute_error: 0.0092 - val_loss: 2.7465e-04 - val_mean_absolute_error: 0.0124
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3595e-05 - mean_absolute_error: 0.0066 - val_loss: 2.7830e-04 - val_mean_absolute_error: 0.0126
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0500e-04 - mean_absolute_error: 0.0070 - val_loss: 2.8378e-04 - val_mean_absolute_error: 0.0127
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2195e-04 - mean_absolute_error: 0.0081 - val_loss: 2.7958e-04 - val_mean_absolute_error: 0.0126
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3115e-05 - mean_absolute_error: 0.0067 - val_loss: 3.1086e-04 - val_mean_absolute_error: 0.0135
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0444e-04 - mean_absolute_error: 0.0068 - val_loss: 3.1901e-04 - val_mean_absolute_error: 0.0137
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1076e-04 - mean_absolute_error: 0.0070 - val_loss: 2.8602e-04 - val_mean_absolute_error: 0.0129
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0086e-04 - mean_absolute_error: 0.0071 - val_loss: 2.8099e-04 - val_mean_absolute_error: 0.0126
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6839e-05 - mean_absolute_error: 0.0066 - val_loss: 3.9908e-04 - val_mean_absolute_error: 0.0160
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.4260e-05 - mean_absolute_error: 0.0068 - val_loss: 3.0717e-04 - val_mean_absolute_error: 0.0136
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.8816e-05 - mean_absolute_error: 0.0065 - val_loss: 2.8288e-04 - val_mean_absolute_error: 0.0127
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0461e-04 - mean_absolute_error: 0.0070 - val_loss: 2.9842e-04 - val_mean_absolute_error: 0.0132
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1256e-04 - mean_absolute_error: 0.0074 - val_loss: 2.8220e-04 - val_mean_absolute_error: 0.0127
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8511e-05 - mean_absolute_error: 0.0069 - val_loss: 2.8356e-04 - val_mean_absolute_error: 0.0126
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6902e-05 - mean_absolute_error: 0.0067 - val_loss: 3.3803e-04 - val_mean_absolute_error: 0.0145
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5254e-05 - mean_absolute_error: 0.0068 - val_loss: 3.7075e-04 - val_mean_absolute_error: 0.0153
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.8868e-05 - mean_absolute_error: 0.0065 - val_loss: 2.8125e-04 - val_mean_absolute_error: 0.0126
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.7378e-05 - mean_absolute_error: 0.0069 - val_loss: 2.8795e-04 - val_mean_absolute_error: 0.0129
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.0990e-05 - mean_absolute_error: 0.0067 - val_loss: 3.0052e-04 - val_mean_absolute_error: 0.0133
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0234e-04 - mean_absolute_error: 0.0071 - val_loss: 3.1740e-04 - val_mean_absolute_error: 0.0137
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1806e-04 - mean_absolute_error: 0.0080 - val_loss: 2.8630e-04 - val_mean_absolute_error: 0.0127
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8952e-05 - mean_absolute_error: 0.0068 - val_loss: 2.8890e-04 - val_mean_absolute_error: 0.0128
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6787e-05 - mean_absolute_error: 0.0069 - val_loss: 4.1628e-04 - val_mean_absolute_error: 0.0164
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1254e-04 - mean_absolute_error: 0.0072 - val_loss: 3.1204e-04 - val_mean_absolute_error: 0.0136
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0085e-04 - mean_absolute_error: 0.0074 - val_loss: 2.9549e-04 - val_mean_absolute_error: 0.0129
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2531e-04 - mean_absolute_error: 0.0077 - val_loss: 2.8186e-04 - val_mean_absolute_error: 0.0127
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0790e-04 - mean_absolute_error: 0.0073 - val_loss: 3.0147e-04 - val_mean_absolute_error: 0.0131
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0522e-04 - mean_absolute_error: 0.0073 - val_loss: 2.8479e-04 - val_mean_absolute_error: 0.0127
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.6640e-05 - mean_absolute_error: 0.0063 - val_loss: 3.0918e-04 - val_mean_absolute_error: 0.0136
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0934e-04 - mean_absolute_error: 0.0073 - val_loss: 2.8409e-04 - val_mean_absolute_error: 0.0128
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8923e-05 - mean_absolute_error: 0.0068 - val_loss: 3.7339e-04 - val_mean_absolute_error: 0.0153
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2790e-04 - mean_absolute_error: 0.0082 - val_loss: 2.7981e-04 - val_mean_absolute_error: 0.0126
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0236e-04 - mean_absolute_error: 0.0069 - val_loss: 2.8955e-04 - val_mean_absolute_error: 0.0128
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2832e-04 - mean_absolute_error: 0.0082 - val_loss: 3.4174e-04 - val_mean_absolute_error: 0.0144
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3985e-04 - mean_absolute_error: 0.0091 - val_loss: 3.2350e-04 - val_mean_absolute_error: 0.0140
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1765e-04 - mean_absolute_error: 0.0082 - val_loss: 2.8953e-04 - val_mean_absolute_error: 0.0131
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2362e-04 - mean_absolute_error: 0.0080 - val_loss: 3.0253e-04 - val_mean_absolute_error: 0.0132
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.4456e-05 - mean_absolute_error: 0.0067 - val_loss: 2.8524e-04 - val_mean_absolute_error: 0.0127
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.8598e-05 - mean_absolute_error: 0.0065 - val_loss: 4.4144e-04 - val_mean_absolute_error: 0.0170
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1745e-04 - mean_absolute_error: 0.0076 - val_loss: 4.8481e-04 - val_mean_absolute_error: 0.0180
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2850e-04 - mean_absolute_error: 0.0085 - val_loss: 3.0558e-04 - val_mean_absolute_error: 0.0133
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6445e-05 - mean_absolute_error: 0.0070 - val_loss: 2.7794e-04 - val_mean_absolute_error: 0.0126
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.9728e-05 - mean_absolute_error: 0.0069 - val_loss: 2.9127e-04 - val_mean_absolute_error: 0.0130
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.3160e-05 - mean_absolute_error: 0.0064 - val_loss: 3.6507e-04 - val_mean_absolute_error: 0.0151
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1488e-04 - mean_absolute_error: 0.0073 - val_loss: 2.9983e-04 - val_mean_absolute_error: 0.0132
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2678e-04 - mean_absolute_error: 0.0084 - val_loss: 3.8862e-04 - val_mean_absolute_error: 0.0157
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4060e-04 - mean_absolute_error: 0.0089 - val_loss: 2.9700e-04 - val_mean_absolute_error: 0.0129
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0611e-04 - mean_absolute_error: 0.0077 - val_loss: 2.9917e-04 - val_mean_absolute_error: 0.0132
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1816e-04 - mean_absolute_error: 0.0078 - val_loss: 2.8566e-04 - val_mean_absolute_error: 0.0127
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4782e-05 - mean_absolute_error: 0.0068 - val_loss: 2.8822e-04 - val_mean_absolute_error: 0.0129
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0153e-04 - mean_absolute_error: 0.0071 - val_loss: 2.8724e-04 - val_mean_absolute_error: 0.0129
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7520e-05 - mean_absolute_error: 0.0068 - val_loss: 3.9434e-04 - val_mean_absolute_error: 0.0159
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3465e-04 - mean_absolute_error: 0.0083 - val_loss: 3.2023e-04 - val_mean_absolute_error: 0.0139
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2571e-04 - mean_absolute_error: 0.0079 - val_loss: 2.7984e-04 - val_mean_absolute_error: 0.0126
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1553e-04 - mean_absolute_error: 0.0076 - val_loss: 3.2969e-04 - val_mean_absolute_error: 0.0142
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0323e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9152e-04 - val_mean_absolute_error: 0.0131
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1351e-04 - mean_absolute_error: 0.0076 - val_loss: 2.8956e-04 - val_mean_absolute_error: 0.0128
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.2739e-05 - mean_absolute_error: 0.0066 - val_loss: 3.3240e-04 - val_mean_absolute_error: 0.0143
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1647e-05 - mean_absolute_error: 0.0068 - val_loss: 3.2650e-04 - val_mean_absolute_error: 0.0140
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1886e-04 - mean_absolute_error: 0.0080 - val_loss: 2.9059e-04 - val_mean_absolute_error: 0.0129
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3716e-05 - mean_absolute_error: 0.0066 - val_loss: 3.5111e-04 - val_mean_absolute_error: 0.0147
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1296e-04 - mean_absolute_error: 0.0073 - val_loss: 3.0835e-04 - val_mean_absolute_error: 0.0135
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1365e-04 - mean_absolute_error: 0.0076 - val_loss: 2.8356e-04 - val_mean_absolute_error: 0.0126
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.6221e-05 - mean_absolute_error: 0.0062 - val_loss: 3.6597e-04 - val_mean_absolute_error: 0.0151
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0903e-04 - mean_absolute_error: 0.0076 - val_loss: 2.8861e-04 - val_mean_absolute_error: 0.0128
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7946e-05 - mean_absolute_error: 0.0068 - val_loss: 2.9750e-04 - val_mean_absolute_error: 0.0133
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1199e-04 - mean_absolute_error: 0.0078 - val_loss: 3.5604e-04 - val_mean_absolute_error: 0.0148
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2764e-04 - mean_absolute_error: 0.0081 - val_loss: 3.0186e-04 - val_mean_absolute_error: 0.0131
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0221e-04 - mean_absolute_error: 0.0072 - val_loss: 2.8923e-04 - val_mean_absolute_error: 0.0128
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0335e-04 - mean_absolute_error: 0.0070 - val_loss: 2.9437e-04 - val_mean_absolute_error: 0.0131
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7696e-05 - mean_absolute_error: 0.0069 - val_loss: 2.9929e-04 - val_mean_absolute_error: 0.0133
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.9782e-05 - mean_absolute_error: 0.0066 - val_loss: 2.9432e-04 - val_mean_absolute_error: 0.0131
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3650e-04 - mean_absolute_error: 0.0086 - val_loss: 2.9909e-04 - val_mean_absolute_error: 0.0133
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0620e-04 - mean_absolute_error: 0.0073 - val_loss: 3.2608e-04 - val_mean_absolute_error: 0.0139
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0609e-04 - mean_absolute_error: 0.0076 - val_loss: 3.3390e-04 - val_mean_absolute_error: 0.0143
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0133e-04 - mean_absolute_error: 0.0070 - val_loss: 3.3115e-04 - val_mean_absolute_error: 0.0141
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2732e-04 - mean_absolute_error: 0.0079 - val_loss: 3.0193e-04 - val_mean_absolute_error: 0.0134
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6137e-05 - mean_absolute_error: 0.0068 - val_loss: 3.0757e-04 - val_mean_absolute_error: 0.0134
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0447e-04 - mean_absolute_error: 0.0072 - val_loss: 3.2514e-04 - val_mean_absolute_error: 0.0141
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2790e-04 - mean_absolute_error: 0.0082 - val_loss: 3.5368e-04 - val_mean_absolute_error: 0.0147
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6704e-05 - mean_absolute_error: 0.0070 - val_loss: 2.8456e-04 - val_mean_absolute_error: 0.0127
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0772e-04 - mean_absolute_error: 0.0070 - val_loss: 2.9018e-04 - val_mean_absolute_error: 0.0130
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4395e-05 - mean_absolute_error: 0.0068 - val_loss: 3.3689e-04 - val_mean_absolute_error: 0.0144
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5629e-05 - mean_absolute_error: 0.0068 - val_loss: 3.0694e-04 - val_mean_absolute_error: 0.0135
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0703e-04 - mean_absolute_error: 0.0071 - val_loss: 2.9094e-04 - val_mean_absolute_error: 0.0130
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1592e-04 - mean_absolute_error: 0.0072 - val_loss: 3.7198e-04 - val_mean_absolute_error: 0.0153
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5339e-04 - mean_absolute_error: 0.0096 - val_loss: 3.2727e-04 - val_mean_absolute_error: 0.0142
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2032e-04 - mean_absolute_error: 0.0079 - val_loss: 3.6645e-04 - val_mean_absolute_error: 0.0152
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4649e-04 - mean_absolute_error: 0.0092 - val_loss: 3.6049e-04 - val_mean_absolute_error: 0.0150

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1273e-04 - mean_absolute_error: 0.0164
# Test Loss: [0.0003604887460824102, 0.015009907074272633]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 1665885.3655887924
# RMSE: 1290.6918166583348
# MAE: 986.6581019671315
# MAPE: 3.0354864213257677 %
#
# Model evalution on validate set
# MSE: 2112633.637095214
# RMSE: 1453.490157206169
# MAE: 962.5257225790514
# MAPE: 2.2484775200795073 %

# %% [markdown]
# ## 4. Forecast the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
y_pred_30_days
# Out:
# array([[61491.336],
#        [60927.07 ],
#        [61478.68 ],
#        [61152.332],
#        [61397.355],
#        [61241.523],
#        [61349.277],
#        [61277.45 ],
#        [61326.21 ],
#        [61293.438],
#        [61315.58 ],
#        [61300.664],
#        [61310.727],
#        [61303.945],
#        [61308.516],
#        [61305.43 ],
#        [61307.508],
#        [61306.105],
#        [61307.055],
#        [61306.414],
#        [61306.848],
#        [61306.555],
#        [61306.754],
#        [61306.61 ],
#        [61306.703],
#        [61306.65 ],
#        [61306.684],
#        [61306.66 ],
#        [61306.68 ],
#        [61306.66 ],
#        [61306.67 ]], dtype=float32)

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(16, 9))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
