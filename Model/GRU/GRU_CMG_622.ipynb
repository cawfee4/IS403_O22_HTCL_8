# %% [markdown]
# # Model: GRU (Gated Recurrent Unit)  - Stock Token: CMG - Test/Train/Vaildation: 60/20/20
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1417.23
# - MAE: 1080.23
# - MAPE: 3.23 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 1  # 6 2 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830
# ...           ...
# 2024-02-26  40000
# 2024-02-27  40200
# 2024-02-28  40000
# 2024-02-29  39950
# 2024-03-01  41200
#
# [1252 rows x 1 columns]

# %%
df.shape
# Out:
# (1252, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1247    40000
# 1248    40200
# 1249    40000
# 1250    39950
# 1251    41200
# Name: close, Length: 1252, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((740, 10), (740,), (239, 10), (239,), (240, 10), (240,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(100),
        Dense(32, activation="relu"),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 100)            │        30,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,165 (133.46 KB)
#  Trainable params: 34,165 (133.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0337 - mean_absolute_error: 0.1332 - val_loss: 0.0093 - val_mean_absolute_error: 0.0891
# Epoch 2/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8092e-04 - mean_absolute_error: 0.0200 - val_loss: 0.0014 - val_mean_absolute_error: 0.0285
# Epoch 3/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5956e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0013 - val_mean_absolute_error: 0.0274
# Epoch 4/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0376e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0013 - val_mean_absolute_error: 0.0272
# Epoch 5/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7979e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0012 - val_mean_absolute_error: 0.0264
# Epoch 6/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8996e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0015 - val_mean_absolute_error: 0.0294
# Epoch 7/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6578e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0013 - val_mean_absolute_error: 0.0285
# Epoch 8/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9785e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0013 - val_mean_absolute_error: 0.0286
# Epoch 9/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7088e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0014 - val_mean_absolute_error: 0.0296
# Epoch 10/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5001e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0010 - val_mean_absolute_error: 0.0240
# Epoch 11/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1809e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0010 - val_mean_absolute_error: 0.0241
# Epoch 12/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2255e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0012 - val_mean_absolute_error: 0.0280
# Epoch 13/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2127e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0011 - val_mean_absolute_error: 0.0245
# Epoch 14/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0708e-04 - mean_absolute_error: 0.0123 - val_loss: 9.5127e-04 - val_mean_absolute_error: 0.0229
# Epoch 15/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8200e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0011 - val_mean_absolute_error: 0.0254
# Epoch 16/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6112e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0014 - val_mean_absolute_error: 0.0302
# Epoch 17/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8926e-04 - mean_absolute_error: 0.0144 - val_loss: 9.4872e-04 - val_mean_absolute_error: 0.0232
# Epoch 18/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6086e-04 - mean_absolute_error: 0.0114 - val_loss: 9.1929e-04 - val_mean_absolute_error: 0.0226
# Epoch 19/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6671e-04 - mean_absolute_error: 0.0114 - val_loss: 9.4939e-04 - val_mean_absolute_error: 0.0235
# Epoch 20/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6311e-04 - mean_absolute_error: 0.0113 - val_loss: 9.0303e-04 - val_mean_absolute_error: 0.0223
# Epoch 21/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9248e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0019 - val_mean_absolute_error: 0.0365
# Epoch 22/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8949e-04 - mean_absolute_error: 0.0156 - val_loss: 9.2035e-04 - val_mean_absolute_error: 0.0230
# Epoch 23/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6169e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0011 - val_mean_absolute_error: 0.0260
# Epoch 24/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5867e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0010 - val_mean_absolute_error: 0.0252
# Epoch 25/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8366e-04 - mean_absolute_error: 0.0120 - val_loss: 8.9805e-04 - val_mean_absolute_error: 0.0223
# Epoch 26/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7819e-04 - mean_absolute_error: 0.0117 - val_loss: 8.6931e-04 - val_mean_absolute_error: 0.0220
# Epoch 27/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4951e-04 - mean_absolute_error: 0.0110 - val_loss: 9.1917e-04 - val_mean_absolute_error: 0.0234
# Epoch 28/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2956e-04 - mean_absolute_error: 0.0102 - val_loss: 9.1032e-04 - val_mean_absolute_error: 0.0232
# Epoch 29/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6077e-04 - mean_absolute_error: 0.0112 - val_loss: 8.8614e-04 - val_mean_absolute_error: 0.0228
# Epoch 30/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6177e-04 - mean_absolute_error: 0.0114 - val_loss: 8.6144e-04 - val_mean_absolute_error: 0.0221
# Epoch 31/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2283e-04 - mean_absolute_error: 0.0107 - val_loss: 8.5989e-04 - val_mean_absolute_error: 0.0221
# Epoch 32/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5255e-04 - mean_absolute_error: 0.0111 - val_loss: 8.5687e-04 - val_mean_absolute_error: 0.0221
# Epoch 33/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2247e-04 - mean_absolute_error: 0.0128 - val_loss: 8.5764e-04 - val_mean_absolute_error: 0.0222
# Epoch 34/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6389e-04 - mean_absolute_error: 0.0112 - val_loss: 9.1828e-04 - val_mean_absolute_error: 0.0229
# Epoch 35/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5577e-04 - mean_absolute_error: 0.0114 - val_loss: 9.4002e-04 - val_mean_absolute_error: 0.0238
# Epoch 36/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6049e-04 - mean_absolute_error: 0.0116 - val_loss: 8.7073e-04 - val_mean_absolute_error: 0.0224
# Epoch 37/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4933e-04 - mean_absolute_error: 0.0108 - val_loss: 8.7300e-04 - val_mean_absolute_error: 0.0226
# Epoch 38/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7381e-04 - mean_absolute_error: 0.0118 - val_loss: 8.6058e-04 - val_mean_absolute_error: 0.0223
# Epoch 39/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0851e-04 - mean_absolute_error: 0.0102 - val_loss: 9.5709e-04 - val_mean_absolute_error: 0.0241
# Epoch 40/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7306e-04 - mean_absolute_error: 0.0119 - val_loss: 8.5176e-04 - val_mean_absolute_error: 0.0223
# Epoch 41/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1571e-04 - mean_absolute_error: 0.0104 - val_loss: 9.3555e-04 - val_mean_absolute_error: 0.0238
# Epoch 42/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3778e-04 - mean_absolute_error: 0.0108 - val_loss: 8.6047e-04 - val_mean_absolute_error: 0.0224
# Epoch 43/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4494e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0012 - val_mean_absolute_error: 0.0273
# Epoch 44/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6203e-04 - mean_absolute_error: 0.0141 - val_loss: 9.0370e-04 - val_mean_absolute_error: 0.0229
# Epoch 45/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3520e-04 - mean_absolute_error: 0.0109 - val_loss: 8.7316e-04 - val_mean_absolute_error: 0.0226
# Epoch 46/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2774e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0010 - val_mean_absolute_error: 0.0253
# Epoch 47/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4612e-04 - mean_absolute_error: 0.0110 - val_loss: 8.7152e-04 - val_mean_absolute_error: 0.0225
# Epoch 48/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2229e-04 - mean_absolute_error: 0.0107 - val_loss: 8.9990e-04 - val_mean_absolute_error: 0.0230
# Epoch 49/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6739e-04 - mean_absolute_error: 0.0117 - val_loss: 9.9160e-04 - val_mean_absolute_error: 0.0246
# Epoch 50/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9366e-04 - mean_absolute_error: 0.0125 - val_loss: 8.8504e-04 - val_mean_absolute_error: 0.0229
# Epoch 51/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1032e-04 - mean_absolute_error: 0.0101 - val_loss: 8.5377e-04 - val_mean_absolute_error: 0.0223
# Epoch 52/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9255e-04 - mean_absolute_error: 0.0095 - val_loss: 8.5707e-04 - val_mean_absolute_error: 0.0224
# Epoch 53/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9551e-04 - mean_absolute_error: 0.0099 - val_loss: 8.6206e-04 - val_mean_absolute_error: 0.0226
# Epoch 54/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3773e-04 - mean_absolute_error: 0.0112 - val_loss: 8.8236e-04 - val_mean_absolute_error: 0.0229
# Epoch 55/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3531e-04 - mean_absolute_error: 0.0108 - val_loss: 8.6332e-04 - val_mean_absolute_error: 0.0225
# Epoch 56/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0474e-04 - mean_absolute_error: 0.0100 - val_loss: 8.6807e-04 - val_mean_absolute_error: 0.0226
# Epoch 57/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1338e-04 - mean_absolute_error: 0.0104 - val_loss: 9.0665e-04 - val_mean_absolute_error: 0.0233
# Epoch 58/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0892e-04 - mean_absolute_error: 0.0101 - val_loss: 8.7544e-04 - val_mean_absolute_error: 0.0227
# Epoch 59/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6605e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0013 - val_mean_absolute_error: 0.0284
# Epoch 60/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9559e-04 - mean_absolute_error: 0.0132 - val_loss: 8.9772e-04 - val_mean_absolute_error: 0.0231
# Epoch 61/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0119e-04 - mean_absolute_error: 0.0131 - val_loss: 8.9188e-04 - val_mean_absolute_error: 0.0228
# Epoch 62/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9729e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0010 - val_mean_absolute_error: 0.0249
# Epoch 63/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6190e-04 - mean_absolute_error: 0.0120 - val_loss: 9.3274e-04 - val_mean_absolute_error: 0.0236
# Epoch 64/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9506e-04 - mean_absolute_error: 0.0099 - val_loss: 9.6088e-04 - val_mean_absolute_error: 0.0242
# Epoch 65/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3948e-04 - mean_absolute_error: 0.0114 - val_loss: 8.8189e-04 - val_mean_absolute_error: 0.0227
# Epoch 66/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0704e-04 - mean_absolute_error: 0.0102 - val_loss: 9.1151e-04 - val_mean_absolute_error: 0.0232
# Epoch 67/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3233e-04 - mean_absolute_error: 0.0107 - val_loss: 8.6400e-04 - val_mean_absolute_error: 0.0226
# Epoch 68/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1581e-04 - mean_absolute_error: 0.0105 - val_loss: 8.6674e-04 - val_mean_absolute_error: 0.0228
# Epoch 69/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1206e-04 - mean_absolute_error: 0.0105 - val_loss: 9.6330e-04 - val_mean_absolute_error: 0.0240
# Epoch 70/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0888e-04 - mean_absolute_error: 0.0103 - val_loss: 9.3756e-04 - val_mean_absolute_error: 0.0235
# Epoch 71/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2895e-04 - mean_absolute_error: 0.0108 - val_loss: 9.4065e-04 - val_mean_absolute_error: 0.0236
# Epoch 72/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2829e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0011 - val_mean_absolute_error: 0.0258
# Epoch 73/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6535e-04 - mean_absolute_error: 0.0113 - val_loss: 9.0539e-04 - val_mean_absolute_error: 0.0231
# Epoch 74/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5084e-04 - mean_absolute_error: 0.0119 - val_loss: 8.7248e-04 - val_mean_absolute_error: 0.0228
# Epoch 75/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3475e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0012 - val_mean_absolute_error: 0.0280
# Epoch 76/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5656e-04 - mean_absolute_error: 0.0121 - val_loss: 8.7577e-04 - val_mean_absolute_error: 0.0228
# Epoch 77/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3283e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0011 - val_mean_absolute_error: 0.0263
# Epoch 78/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1951e-04 - mean_absolute_error: 0.0104 - val_loss: 8.8847e-04 - val_mean_absolute_error: 0.0228
# Epoch 79/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1595e-04 - mean_absolute_error: 0.0102 - val_loss: 8.8485e-04 - val_mean_absolute_error: 0.0228
# Epoch 80/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2093e-04 - mean_absolute_error: 0.0105 - val_loss: 8.8018e-04 - val_mean_absolute_error: 0.0229
# Epoch 81/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2195e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0010 - val_mean_absolute_error: 0.0247
# Epoch 82/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1279e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0010 - val_mean_absolute_error: 0.0246
# Epoch 83/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2294e-04 - mean_absolute_error: 0.0103 - val_loss: 8.8392e-04 - val_mean_absolute_error: 0.0231
# Epoch 84/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0124e-04 - mean_absolute_error: 0.0102 - val_loss: 9.7028e-04 - val_mean_absolute_error: 0.0239
# Epoch 85/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3838e-04 - mean_absolute_error: 0.0109 - val_loss: 8.9276e-04 - val_mean_absolute_error: 0.0228
# Epoch 86/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0497e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0010 - val_mean_absolute_error: 0.0251
# Epoch 87/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5504e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0013 - val_mean_absolute_error: 0.0293
# Epoch 88/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8171e-04 - mean_absolute_error: 0.0123 - val_loss: 9.8490e-04 - val_mean_absolute_error: 0.0242
# Epoch 89/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2813e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0010 - val_mean_absolute_error: 0.0252
# Epoch 90/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2141e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0013 - val_mean_absolute_error: 0.0280
# Epoch 91/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5763e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0010 - val_mean_absolute_error: 0.0254
# Epoch 92/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0366e-04 - mean_absolute_error: 0.0104 - val_loss: 9.0966e-04 - val_mean_absolute_error: 0.0230
# Epoch 93/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1204e-04 - mean_absolute_error: 0.0103 - val_loss: 9.7843e-04 - val_mean_absolute_error: 0.0241
# Epoch 94/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1575e-04 - mean_absolute_error: 0.0104 - val_loss: 9.2343e-04 - val_mean_absolute_error: 0.0235
# Epoch 95/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3593e-04 - mean_absolute_error: 0.0112 - val_loss: 9.0555e-04 - val_mean_absolute_error: 0.0233
# Epoch 96/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5340e-04 - mean_absolute_error: 0.0124 - val_loss: 9.3838e-04 - val_mean_absolute_error: 0.0233
# Epoch 97/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0694e-04 - mean_absolute_error: 0.0104 - val_loss: 9.4358e-04 - val_mean_absolute_error: 0.0239
# Epoch 98/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7754e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0016 - val_mean_absolute_error: 0.0326
# Epoch 99/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7447e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0013 - val_mean_absolute_error: 0.0294
# Epoch 100/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4407e-04 - mean_absolute_error: 0.0109 - val_loss: 9.4297e-04 - val_mean_absolute_error: 0.0238
# Epoch 101/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3492e-04 - mean_absolute_error: 0.0114 - val_loss: 9.7138e-04 - val_mean_absolute_error: 0.0239
# Epoch 102/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0961e-04 - mean_absolute_error: 0.0104 - val_loss: 9.8716e-04 - val_mean_absolute_error: 0.0241
# Epoch 103/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1258e-04 - mean_absolute_error: 0.0104 - val_loss: 9.7817e-04 - val_mean_absolute_error: 0.0242
# Epoch 104/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9349e-04 - mean_absolute_error: 0.0099 - val_loss: 9.5208e-04 - val_mean_absolute_error: 0.0236
# Epoch 105/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9304e-04 - mean_absolute_error: 0.0101 - val_loss: 9.3619e-04 - val_mean_absolute_error: 0.0233
# Epoch 106/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9028e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0010 - val_mean_absolute_error: 0.0248
# Epoch 107/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2784e-04 - mean_absolute_error: 0.0110 - val_loss: 9.2289e-04 - val_mean_absolute_error: 0.0232
# Epoch 108/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3062e-04 - mean_absolute_error: 0.0106 - val_loss: 9.1061e-04 - val_mean_absolute_error: 0.0230
# Epoch 109/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8559e-04 - mean_absolute_error: 0.0095 - val_loss: 9.3461e-04 - val_mean_absolute_error: 0.0237
# Epoch 110/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9735e-04 - mean_absolute_error: 0.0099 - val_loss: 9.4561e-04 - val_mean_absolute_error: 0.0235
# Epoch 111/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3266e-04 - mean_absolute_error: 0.0107 - val_loss: 9.3095e-04 - val_mean_absolute_error: 0.0233
# Epoch 112/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8640e-04 - mean_absolute_error: 0.0098 - val_loss: 9.2994e-04 - val_mean_absolute_error: 0.0233
# Epoch 113/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9291e-04 - mean_absolute_error: 0.0097 - val_loss: 9.2704e-04 - val_mean_absolute_error: 0.0232
# Epoch 114/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0172e-04 - mean_absolute_error: 0.0101 - val_loss: 9.3257e-04 - val_mean_absolute_error: 0.0232
# Epoch 115/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7985e-04 - mean_absolute_error: 0.0096 - val_loss: 9.2895e-04 - val_mean_absolute_error: 0.0233
# Epoch 116/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8400e-04 - mean_absolute_error: 0.0095 - val_loss: 9.4707e-04 - val_mean_absolute_error: 0.0236
# Epoch 117/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1351e-04 - mean_absolute_error: 0.0099 - val_loss: 9.5423e-04 - val_mean_absolute_error: 0.0239
# Epoch 118/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9343e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0011 - val_mean_absolute_error: 0.0258
# Epoch 119/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0613e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0010 - val_mean_absolute_error: 0.0249
# Epoch 120/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5044e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0011 - val_mean_absolute_error: 0.0256
# Epoch 121/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2220e-04 - mean_absolute_error: 0.0106 - val_loss: 9.2636e-04 - val_mean_absolute_error: 0.0235
# Epoch 122/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9115e-04 - mean_absolute_error: 0.0095 - val_loss: 9.7501e-04 - val_mean_absolute_error: 0.0239
# Epoch 123/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0240e-04 - mean_absolute_error: 0.0101 - val_loss: 9.2022e-04 - val_mean_absolute_error: 0.0231
# Epoch 124/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9701e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0010 - val_mean_absolute_error: 0.0250
# Epoch 125/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5077e-04 - mean_absolute_error: 0.0111 - val_loss: 9.7196e-04 - val_mean_absolute_error: 0.0243
# Epoch 126/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0004e-04 - mean_absolute_error: 0.0101 - val_loss: 9.8243e-04 - val_mean_absolute_error: 0.0243
# Epoch 127/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0726e-04 - mean_absolute_error: 0.0103 - val_loss: 9.4267e-04 - val_mean_absolute_error: 0.0236
# Epoch 128/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0861e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0011 - val_mean_absolute_error: 0.0251
# Epoch 129/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0217e-04 - mean_absolute_error: 0.0103 - val_loss: 9.5834e-04 - val_mean_absolute_error: 0.0238
# Epoch 130/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9408e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0011 - val_mean_absolute_error: 0.0265
# Epoch 131/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9040e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0012 - val_mean_absolute_error: 0.0276
# Epoch 132/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9839e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0010 - val_mean_absolute_error: 0.0247
# Epoch 133/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9724e-04 - mean_absolute_error: 0.0097 - val_loss: 9.7605e-04 - val_mean_absolute_error: 0.0243
# Epoch 134/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8339e-04 - mean_absolute_error: 0.0124 - val_loss: 9.1179e-04 - val_mean_absolute_error: 0.0232
# Epoch 135/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1939e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0015 - val_mean_absolute_error: 0.0311
# Epoch 136/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4027e-04 - mean_absolute_error: 0.0138 - val_loss: 9.6762e-04 - val_mean_absolute_error: 0.0238
# Epoch 137/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0678e-04 - mean_absolute_error: 0.0102 - val_loss: 9.4474e-04 - val_mean_absolute_error: 0.0235
# Epoch 138/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3875e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0012 - val_mean_absolute_error: 0.0270
# Epoch 139/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7737e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0014 - val_mean_absolute_error: 0.0295
# Epoch 140/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9051e-04 - mean_absolute_error: 0.0122 - val_loss: 9.9765e-04 - val_mean_absolute_error: 0.0243
# Epoch 141/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4706e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0011 - val_mean_absolute_error: 0.0256
# Epoch 142/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3215e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0010 - val_mean_absolute_error: 0.0242
# Epoch 143/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0320e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0010 - val_mean_absolute_error: 0.0250
# Epoch 144/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5829e-04 - mean_absolute_error: 0.0122 - val_loss: 9.2795e-04 - val_mean_absolute_error: 0.0233
# Epoch 145/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1857e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0011 - val_mean_absolute_error: 0.0256
# Epoch 146/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5678e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0010 - val_mean_absolute_error: 0.0242
# Epoch 147/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2764e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0011 - val_mean_absolute_error: 0.0260
# Epoch 148/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7085e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0011 - val_mean_absolute_error: 0.0264
# Epoch 149/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2639e-04 - mean_absolute_error: 0.0110 - val_loss: 9.4941e-04 - val_mean_absolute_error: 0.0236
# Epoch 150/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2741e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0010 - val_mean_absolute_error: 0.0246
# Epoch 151/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2938e-04 - mean_absolute_error: 0.0106 - val_loss: 9.6597e-04 - val_mean_absolute_error: 0.0239
# Epoch 152/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8649e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0010 - val_mean_absolute_error: 0.0250
# Epoch 153/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8123e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0010 - val_mean_absolute_error: 0.0247
# Epoch 154/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3132e-04 - mean_absolute_error: 0.0110 - val_loss: 9.2365e-04 - val_mean_absolute_error: 0.0233
# Epoch 155/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2216e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0010 - val_mean_absolute_error: 0.0250
# Epoch 156/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5324e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0010 - val_mean_absolute_error: 0.0247
# Epoch 157/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3841e-04 - mean_absolute_error: 0.0118 - val_loss: 9.4389e-04 - val_mean_absolute_error: 0.0235
# Epoch 158/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1408e-04 - mean_absolute_error: 0.0106 - val_loss: 9.6740e-04 - val_mean_absolute_error: 0.0237
# Epoch 159/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8566e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0010 - val_mean_absolute_error: 0.0246
# Epoch 160/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1213e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0010 - val_mean_absolute_error: 0.0244
# Epoch 161/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9086e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0011 - val_mean_absolute_error: 0.0253
# Epoch 162/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2209e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0010 - val_mean_absolute_error: 0.0249
# Epoch 163/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3110e-04 - mean_absolute_error: 0.0111 - val_loss: 9.7189e-04 - val_mean_absolute_error: 0.0238
# Epoch 164/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8069e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0010 - val_mean_absolute_error: 0.0248
# Epoch 165/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0518e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0011 - val_mean_absolute_error: 0.0257
# Epoch 166/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3023e-04 - mean_absolute_error: 0.0107 - val_loss: 9.9835e-04 - val_mean_absolute_error: 0.0241
# Epoch 167/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1177e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0012 - val_mean_absolute_error: 0.0270
# Epoch 168/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4562e-04 - mean_absolute_error: 0.0113 - val_loss: 9.7654e-04 - val_mean_absolute_error: 0.0241
# Epoch 169/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9958e-04 - mean_absolute_error: 0.0107 - val_loss: 9.9873e-04 - val_mean_absolute_error: 0.0242
# Epoch 170/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0728e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0012 - val_mean_absolute_error: 0.0269
# Epoch 171/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1813e-04 - mean_absolute_error: 0.0111 - val_loss: 9.9319e-04 - val_mean_absolute_error: 0.0245
# Epoch 172/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0791e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0010 - val_mean_absolute_error: 0.0247
# Epoch 173/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1461e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0014 - val_mean_absolute_error: 0.0302
# Epoch 174/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5182e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0010 - val_mean_absolute_error: 0.0249
# Epoch 175/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0725e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0011 - val_mean_absolute_error: 0.0253
# Epoch 176/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3107e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0010 - val_mean_absolute_error: 0.0244
# Epoch 177/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3468e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0010 - val_mean_absolute_error: 0.0247
# Epoch 178/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4612e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0017 - val_mean_absolute_error: 0.0336
# Epoch 179/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6138e-04 - mean_absolute_error: 0.0124 - val_loss: 9.7883e-04 - val_mean_absolute_error: 0.0243
# Epoch 180/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3192e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0010 - val_mean_absolute_error: 0.0245
# Epoch 181/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0355e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0011 - val_mean_absolute_error: 0.0252
# Epoch 182/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4369e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0010 - val_mean_absolute_error: 0.0244
# Epoch 183/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0386e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0010 - val_mean_absolute_error: 0.0248
# Epoch 184/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9326e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0016 - val_mean_absolute_error: 0.0316
# Epoch 185/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9601e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0010 - val_mean_absolute_error: 0.0250
# Epoch 186/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6254e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0011 - val_mean_absolute_error: 0.0259
# Epoch 187/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4230e-04 - mean_absolute_error: 0.0119 - val_loss: 9.9229e-04 - val_mean_absolute_error: 0.0242
# Epoch 188/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7952e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0011 - val_mean_absolute_error: 0.0254
# Epoch 189/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2037e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0010 - val_mean_absolute_error: 0.0248
# Epoch 190/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9849e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0010 - val_mean_absolute_error: 0.0246
# Epoch 191/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1531e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0010 - val_mean_absolute_error: 0.0246
# Epoch 192/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1674e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0011 - val_mean_absolute_error: 0.0250
# Epoch 193/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1800e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0010 - val_mean_absolute_error: 0.0247
# Epoch 194/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1108e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0011 - val_mean_absolute_error: 0.0254
# Epoch 195/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1499e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0011 - val_mean_absolute_error: 0.0255
# Epoch 196/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0749e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0010 - val_mean_absolute_error: 0.0246
# Epoch 197/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0938e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0011 - val_mean_absolute_error: 0.0251
# Epoch 198/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2457e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0010 - val_mean_absolute_error: 0.0245
# Epoch 199/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8239e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0010 - val_mean_absolute_error: 0.0249
# Epoch 200/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2927e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012 - mean_absolute_error: 0.0262
# Test Loss: [0.0010528492275625467, 0.024845952168107033]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 239
# 250

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 2008547.837138938
# RMSE: 1417.2324569875395
# MAE: 1080.2301010067993
# MAPE: 3.234931476490075 %
#
# Model evalution on validate set
# MSE: 778489.3485010624
# RMSE: 882.3204341400365
# MAE: 660.7322509765625
# MAPE: 1.7675125468020636 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
y_pred_30_days
# Out:
# array([[39775.406],
#        [39793.2  ],
#        [39790.016],
#        [39780.07 ],
#        [39827.027],
#        [39793.562],
#        [39820.41 ],
#        [39808.24 ],
#        [39804.477],
#        [39816.047],
#        [39800.836],
#        [39813.855],
#        [39806.207],
#        [39808.06 ],
#        [39811.004],
#        [39805.55 ],
#        [39811.223],
#        [39807.01 ],
#        [39808.96 ],
#        [39809.168],
#        [39807.484],
#        [39809.73 ],
#        [39807.734],
#        [39808.984],
#        [39808.625],
#        [39808.25 ],
#        [39809.03 ],
#        [39808.184],
#        [39808.844],
#        [39808.504],
#        [39808.52 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
