# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

plt.style.use("default")

# %% [markdown]
# ## 1. Data preprocessing

# %%
split_type = [0.8,0.7,0.9]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 0

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#              close
# time
# 2019-03-01   19270
# 2019-03-04   19440
# 2019-03-05   19390
# 2019-03-06   19270
# 2019-03-07   19330
# ...            ...
# 2024-05-27  132800
# 2024-05-28  137000
# 2024-05-29  135700
# 2024-05-30  135000
# 2024-05-31  134600
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split] * len(df_scaled))
test_size = len(df_scaled) - train_size

# %%
# Splitting data into train, test set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size:]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1039, 10), (1039,), (252, 10), (252,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Input

UNITS = 64

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(UNITS),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 64)             │        12,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,929 (50.50 KB)
#  Trainable params: 12,929 (50.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0497 - mean_absolute_error: 0.1647
# Epoch 2/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - mean_absolute_error: 0.0517
# Epoch 3/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9569e-04 - mean_absolute_error: 0.0097
# Epoch 4/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3246e-04 - mean_absolute_error: 0.0078
# Epoch 5/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4454e-04 - mean_absolute_error: 0.0078
# Epoch 6/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3721e-04 - mean_absolute_error: 0.0079
# Epoch 7/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4496e-04 - mean_absolute_error: 0.0082
# Epoch 8/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3055e-04 - mean_absolute_error: 0.0077
# Epoch 9/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2323e-04 - mean_absolute_error: 0.0076
# Epoch 10/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2337e-04 - mean_absolute_error: 0.0074
# Epoch 11/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5107e-04 - mean_absolute_error: 0.0080
# Epoch 12/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3005e-04 - mean_absolute_error: 0.0073
# Epoch 13/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2034e-04 - mean_absolute_error: 0.0075
# Epoch 14/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1940e-04 - mean_absolute_error: 0.0074
# Epoch 15/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1974e-04 - mean_absolute_error: 0.0073
# Epoch 16/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3541e-04 - mean_absolute_error: 0.0077
# Epoch 17/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1294e-04 - mean_absolute_error: 0.0069
# Epoch 18/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1516e-04 - mean_absolute_error: 0.0071
# Epoch 19/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2548e-04 - mean_absolute_error: 0.0072
# Epoch 20/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0524e-04 - mean_absolute_error: 0.0068
# Epoch 21/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1134e-04 - mean_absolute_error: 0.0067
# Epoch 22/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1292e-04 - mean_absolute_error: 0.0070
# Epoch 23/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2771e-04 - mean_absolute_error: 0.0072
# Epoch 24/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2305e-04 - mean_absolute_error: 0.0076
# Epoch 25/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0669e-04 - mean_absolute_error: 0.0067
# Epoch 26/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.0221e-05 - mean_absolute_error: 0.0063
# Epoch 27/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8612e-05 - mean_absolute_error: 0.0068
# Epoch 28/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8878e-05 - mean_absolute_error: 0.0066
# Epoch 29/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0628e-04 - mean_absolute_error: 0.0067
# Epoch 30/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1798e-05 - mean_absolute_error: 0.0064
# Epoch 31/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7024e-05 - mean_absolute_error: 0.0066
# Epoch 32/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4648e-05 - mean_absolute_error: 0.0064
# Epoch 33/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5749e-05 - mean_absolute_error: 0.0061
# Epoch 34/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7398e-05 - mean_absolute_error: 0.0064
# Epoch 35/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.8685e-05 - mean_absolute_error: 0.0063
# Epoch 36/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0048e-04 - mean_absolute_error: 0.0067
# Epoch 37/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.7831e-05 - mean_absolute_error: 0.0059
# Epoch 38/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.8405e-05 - mean_absolute_error: 0.0062
# Epoch 39/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6660e-05 - mean_absolute_error: 0.0061
# Epoch 40/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0101e-04 - mean_absolute_error: 0.0064
# Epoch 41/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1230e-04 - mean_absolute_error: 0.0075
# Epoch 42/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8945e-05 - mean_absolute_error: 0.0066
# Epoch 43/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3965e-05 - mean_absolute_error: 0.0062
# Epoch 44/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4032e-05 - mean_absolute_error: 0.0064
# Epoch 45/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1883e-05 - mean_absolute_error: 0.0062
# Epoch 46/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.0103e-05 - mean_absolute_error: 0.0064
# Epoch 47/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.8965e-05 - mean_absolute_error: 0.0062
# Epoch 48/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4639e-05 - mean_absolute_error: 0.0060
# Epoch 49/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6249e-05 - mean_absolute_error: 0.0060
# Epoch 50/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4946e-05 - mean_absolute_error: 0.0059
# Epoch 51/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7256e-05 - mean_absolute_error: 0.0063
# Epoch 52/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6890e-05 - mean_absolute_error: 0.0059
# Epoch 53/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1677e-04 - mean_absolute_error: 0.0075
# Epoch 54/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8837e-05 - mean_absolute_error: 0.0059
# Epoch 55/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4141e-05 - mean_absolute_error: 0.0065
# Epoch 56/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4140e-05 - mean_absolute_error: 0.0065
# Epoch 57/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.2818e-05 - mean_absolute_error: 0.0061
# Epoch 58/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8513e-05 - mean_absolute_error: 0.0058
# Epoch 59/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4422e-05 - mean_absolute_error: 0.0061
# Epoch 60/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.3436e-05 - mean_absolute_error: 0.0067
# Epoch 61/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3190e-05 - mean_absolute_error: 0.0057
# Epoch 62/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1352e-05 - mean_absolute_error: 0.0064
# Epoch 63/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0914e-05 - mean_absolute_error: 0.0060
# Epoch 64/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3610e-05 - mean_absolute_error: 0.0061
# Epoch 65/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.0956e-05 - mean_absolute_error: 0.0067
# Epoch 66/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8013e-05 - mean_absolute_error: 0.0057
# Epoch 67/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6914e-05 - mean_absolute_error: 0.0061
# Epoch 68/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1125e-05 - mean_absolute_error: 0.0058
# Epoch 69/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4834e-05 - mean_absolute_error: 0.0059
# Epoch 70/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3530e-05 - mean_absolute_error: 0.0057
# Epoch 71/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.5756e-05 - mean_absolute_error: 0.0060
# Epoch 72/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1873e-05 - mean_absolute_error: 0.0057
# Epoch 73/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6373e-05 - mean_absolute_error: 0.0061
# Epoch 74/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8317e-05 - mean_absolute_error: 0.0053
# Epoch 75/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0917e-05 - mean_absolute_error: 0.0063
# Epoch 76/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6376e-05 - mean_absolute_error: 0.0061
# Epoch 77/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1065e-05 - mean_absolute_error: 0.0053
# Epoch 78/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7086e-05 - mean_absolute_error: 0.0055
# Epoch 79/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3775e-05 - mean_absolute_error: 0.0054
# Epoch 80/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1078e-05 - mean_absolute_error: 0.0064
# Epoch 81/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.2261e-05 - mean_absolute_error: 0.0059
# Epoch 82/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.9727e-05 - mean_absolute_error: 0.0062
# Epoch 83/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8665e-05 - mean_absolute_error: 0.0059
# Epoch 84/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3502e-05 - mean_absolute_error: 0.0062
# Epoch 85/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4717e-05 - mean_absolute_error: 0.0053
# Epoch 86/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3621e-05 - mean_absolute_error: 0.0059
# Epoch 87/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.9440e-05 - mean_absolute_error: 0.0062
# Epoch 88/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8644e-05 - mean_absolute_error: 0.0058
# Epoch 89/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2773e-05 - mean_absolute_error: 0.0055
# Epoch 90/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7711e-05 - mean_absolute_error: 0.0064
# Epoch 91/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9378e-05 - mean_absolute_error: 0.0060
# Epoch 92/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4250e-05 - mean_absolute_error: 0.0066
# Epoch 93/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6739e-05 - mean_absolute_error: 0.0059
# Epoch 94/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4969e-05 - mean_absolute_error: 0.0055
# Epoch 95/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0045e-05 - mean_absolute_error: 0.0057
# Epoch 96/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6065e-05 - mean_absolute_error: 0.0058
# Epoch 97/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4832e-05 - mean_absolute_error: 0.0054
# Epoch 98/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1296e-05 - mean_absolute_error: 0.0058
# Epoch 99/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7372e-05 - mean_absolute_error: 0.0053
# Epoch 100/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9382e-05 - mean_absolute_error: 0.0053
# Epoch 101/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6805e-05 - mean_absolute_error: 0.0052
# Epoch 102/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8525e-05 - mean_absolute_error: 0.0060
# Epoch 103/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6493e-05 - mean_absolute_error: 0.0058
# Epoch 104/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2480e-05 - mean_absolute_error: 0.0058
# Epoch 105/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1079e-05 - mean_absolute_error: 0.0061
# Epoch 106/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3324e-05 - mean_absolute_error: 0.0051
# Epoch 107/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9396e-05 - mean_absolute_error: 0.0056
# Epoch 108/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.5900e-05 - mean_absolute_error: 0.0058
# Epoch 109/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0332e-05 - mean_absolute_error: 0.0055
# Epoch 110/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8373e-05 - mean_absolute_error: 0.0059
# Epoch 111/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2236e-05 - mean_absolute_error: 0.0052
# Epoch 112/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0888e-05 - mean_absolute_error: 0.0062
# Epoch 113/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7591e-05 - mean_absolute_error: 0.0052
# Epoch 114/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0923e-05 - mean_absolute_error: 0.0060
# Epoch 115/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0361e-05 - mean_absolute_error: 0.0061
# Epoch 116/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4397e-05 - mean_absolute_error: 0.0058
# Epoch 117/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.8267e-05 - mean_absolute_error: 0.0060
# Epoch 118/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.5921e-05 - mean_absolute_error: 0.0052
# Epoch 119/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7209e-05 - mean_absolute_error: 0.0052
# Epoch 120/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4510e-05 - mean_absolute_error: 0.0050
# Epoch 121/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3096e-05 - mean_absolute_error: 0.0057
# Epoch 122/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2778e-05 - mean_absolute_error: 0.0060
# Epoch 123/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1564e-05 - mean_absolute_error: 0.0054
# Epoch 124/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8718e-05 - mean_absolute_error: 0.0052
# Epoch 125/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9199e-05 - mean_absolute_error: 0.0054
# Epoch 126/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.5239e-05 - mean_absolute_error: 0.0050
# Epoch 127/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0229e-05 - mean_absolute_error: 0.0054
# Epoch 128/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1264e-05 - mean_absolute_error: 0.0059
# Epoch 129/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3034e-05 - mean_absolute_error: 0.0054
# Epoch 130/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2340e-05 - mean_absolute_error: 0.0052
# Epoch 131/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.5295e-05 - mean_absolute_error: 0.0051
# Epoch 132/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7459e-05 - mean_absolute_error: 0.0055
# Epoch 133/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6886e-05 - mean_absolute_error: 0.0060
# Epoch 134/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.5140e-05 - mean_absolute_error: 0.0053
# Epoch 135/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6749e-05 - mean_absolute_error: 0.0054
# Epoch 136/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3297e-05 - mean_absolute_error: 0.0054
# Epoch 137/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0515e-05 - mean_absolute_error: 0.0055
# Epoch 138/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9208e-05 - mean_absolute_error: 0.0051
# Epoch 139/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3693e-05 - mean_absolute_error: 0.0053
# Epoch 140/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1863e-05 - mean_absolute_error: 0.0055
# Epoch 141/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2547e-05 - mean_absolute_error: 0.0051
# Epoch 142/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6489e-05 - mean_absolute_error: 0.0055
# Epoch 143/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6096e-05 - mean_absolute_error: 0.0053
# Epoch 144/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0041e-05 - mean_absolute_error: 0.0053
# Epoch 145/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4487e-05 - mean_absolute_error: 0.0056
# Epoch 146/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5685e-05 - mean_absolute_error: 0.0049
# Epoch 147/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1762e-05 - mean_absolute_error: 0.0052
# Epoch 148/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8472e-05 - mean_absolute_error: 0.0053
# Epoch 149/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3586e-05 - mean_absolute_error: 0.0052
# Epoch 150/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8608e-05 - mean_absolute_error: 0.0053
# Epoch 151/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6256e-05 - mean_absolute_error: 0.0065
# Epoch 152/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8093e-05 - mean_absolute_error: 0.0060
# Epoch 153/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7841e-05 - mean_absolute_error: 0.0055
# Epoch 154/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4443e-05 - mean_absolute_error: 0.0059
# Epoch 155/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2407e-05 - mean_absolute_error: 0.0055
# Epoch 156/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8684e-05 - mean_absolute_error: 0.0056
# Epoch 157/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2832e-05 - mean_absolute_error: 0.0056
# Epoch 158/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4622e-05 - mean_absolute_error: 0.0053
# Epoch 159/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.5346e-05 - mean_absolute_error: 0.0056
# Epoch 160/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8493e-05 - mean_absolute_error: 0.0053
# Epoch 161/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7430e-05 - mean_absolute_error: 0.0065
# Epoch 162/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.5446e-05 - mean_absolute_error: 0.0056
# Epoch 163/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7249e-05 - mean_absolute_error: 0.0056
# Epoch 164/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9951e-05 - mean_absolute_error: 0.0050
# Epoch 165/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7080e-05 - mean_absolute_error: 0.0049
# Epoch 166/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1743e-05 - mean_absolute_error: 0.0051
# Epoch 167/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2303e-05 - mean_absolute_error: 0.0055
# Epoch 168/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7735e-05 - mean_absolute_error: 0.0049
# Epoch 169/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2408e-05 - mean_absolute_error: 0.0051
# Epoch 170/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6111e-05 - mean_absolute_error: 0.0053
# Epoch 171/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4432e-05 - mean_absolute_error: 0.0054
# Epoch 172/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0529e-05 - mean_absolute_error: 0.0054
# Epoch 173/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.2037e-05 - mean_absolute_error: 0.0059
# Epoch 174/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2031e-05 - mean_absolute_error: 0.0051
# Epoch 175/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8450e-05 - mean_absolute_error: 0.0051
# Epoch 176/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2136e-05 - mean_absolute_error: 0.0056
# Epoch 177/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9988e-05 - mean_absolute_error: 0.0057
# Epoch 178/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9668e-05 - mean_absolute_error: 0.0053
# Epoch 179/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9625e-05 - mean_absolute_error: 0.0054
# Epoch 180/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3369e-05 - mean_absolute_error: 0.0052
# Epoch 181/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6439e-05 - mean_absolute_error: 0.0060
# Epoch 182/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9360e-05 - mean_absolute_error: 0.0049
# Epoch 183/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8698e-05 - mean_absolute_error: 0.0057
# Epoch 184/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8076e-05 - mean_absolute_error: 0.0054
# Epoch 185/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1519e-05 - mean_absolute_error: 0.0051
# Epoch 186/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8951e-05 - mean_absolute_error: 0.0049
# Epoch 187/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4068e-05 - mean_absolute_error: 0.0048
# Epoch 188/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3253e-05 - mean_absolute_error: 0.0051
# Epoch 189/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4045e-05 - mean_absolute_error: 0.0064
# Epoch 190/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1116e-05 - mean_absolute_error: 0.0053
# Epoch 191/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2089e-05 - mean_absolute_error: 0.0050
# Epoch 192/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1005e-05 - mean_absolute_error: 0.0059
# Epoch 193/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1635e-05 - mean_absolute_error: 0.0051
# Epoch 194/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2095e-05 - mean_absolute_error: 0.0054
# Epoch 195/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1384e-05 - mean_absolute_error: 0.0055
# Epoch 196/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7425e-05 - mean_absolute_error: 0.0050
# Epoch 197/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6613e-05 - mean_absolute_error: 0.0053
# Epoch 198/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9791e-05 - mean_absolute_error: 0.0050
# Epoch 199/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.9324e-05 - mean_absolute_error: 0.0051
# Epoch 200/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6024e-05 - mean_absolute_error: 0.0052

# %% [markdown]
# ### Predicting with test set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7206e-04 - mean_absolute_error: 0.0091
# Test Loss: [0.0003187905822414905, 0.012905793264508247]

# %%
# Splitting data into train, test set again to evaluate, because i shaped the data between 0 to 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 252
# 263

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)
# Out:
# Model evalution on test set
# MSE: 7893716.913082062
# RMSE: 2809.5759311828647
# MAE: 2001.8632192460318
# MAPE: 1.9555721739288774 %

# %% [markdown]
# ## 4. Forecast the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(test_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
y_pred_30_days
# Out:
# array([[131677.9 ],
#        [132209.39],
#        [131803.97],
#        [131967.22],
#        [131873.19],
#        [131913.52],
#        [131892.98],
#        [131902.6 ],
#        [131897.88],
#        [131900.12],
#        [131899.05],
#        [131899.55],
#        [131899.31],
#        [131899.4 ],
#        [131899.36],
#        [131899.39],
#        [131899.38],
#        [131899.38],
#        [131899.38],
#        [131899.38],
#        [131899.38],
#        [131899.38],
#        [131899.39],
#        [131899.39],
#        [131899.38],
#        [131899.38],
#        [131899.38],
#        [131899.38],
#        [131899.38],
#        [131899.39],
#        [131899.39]], dtype=float32)

# %% [markdown]
# ### Continue forecast the next 60/90 days

# %%
y_pred_60_days = forecast(test_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
y_pred_90_days = forecast(test_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")

    # Predict test set
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        test_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Next {days} Days",
        linestyle="--",
    )

    plt.title(f"Forecast {stock_name[stock]} Stock Closing Price Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
