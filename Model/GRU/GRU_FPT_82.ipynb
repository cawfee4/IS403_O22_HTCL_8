# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

plt.style.use("default")

# %% [markdown]
# ## 1. Data preprocessing

# %%
split_type = [0.8,0.7,0.9]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#              close
# time
# 2019-03-01   19270
# 2019-03-04   19440
# 2019-03-05   19390
# 2019-03-06   19270
# 2019-03-07   19330
# ...            ...
# 2024-05-27  132800
# 2024-05-28  137000
# 2024-05-29  135700
# 2024-05-30  135000
# 2024-05-31  134600
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split] * len(df_scaled))
test_size = len(df_scaled) - train_size

# %%
# Splitting data into train, test set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size:]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test 
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1170, 10), (1170,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Input

UNITS = 64

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(UNITS),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 64)             │        12,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,929 (50.50 KB)
#  Trainable params: 12,929 (50.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0884 - mean_absolute_error: 0.2214
# Epoch 2/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0069 - mean_absolute_error: 0.0732
# Epoch 3/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9175e-04 - mean_absolute_error: 0.0117
# Epoch 4/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7858e-04 - mean_absolute_error: 0.0092
# Epoch 5/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7990e-04 - mean_absolute_error: 0.0092
# Epoch 6/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8711e-04 - mean_absolute_error: 0.0093
# Epoch 7/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8654e-04 - mean_absolute_error: 0.0094
# Epoch 8/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7638e-04 - mean_absolute_error: 0.0091
# Epoch 9/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5074e-04 - mean_absolute_error: 0.0084
# Epoch 10/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7197e-04 - mean_absolute_error: 0.0088
# Epoch 11/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6258e-04 - mean_absolute_error: 0.0087
# Epoch 12/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5050e-04 - mean_absolute_error: 0.0085
# Epoch 13/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5219e-04 - mean_absolute_error: 0.0084
# Epoch 14/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5616e-04 - mean_absolute_error: 0.0085
# Epoch 15/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4964e-04 - mean_absolute_error: 0.0083
# Epoch 16/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4781e-04 - mean_absolute_error: 0.0080
# Epoch 17/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6348e-04 - mean_absolute_error: 0.0086
# Epoch 18/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6164e-04 - mean_absolute_error: 0.0083
# Epoch 19/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3356e-04 - mean_absolute_error: 0.0078
# Epoch 20/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1941e-04 - mean_absolute_error: 0.0074
# Epoch 21/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4067e-04 - mean_absolute_error: 0.0079
# Epoch 22/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4281e-04 - mean_absolute_error: 0.0082
# Epoch 23/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5552e-04 - mean_absolute_error: 0.0085
# Epoch 24/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2082e-04 - mean_absolute_error: 0.0073
# Epoch 25/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4528e-04 - mean_absolute_error: 0.0079
# Epoch 26/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4609e-04 - mean_absolute_error: 0.0082
# Epoch 27/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1730e-04 - mean_absolute_error: 0.0073
# Epoch 28/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3914e-04 - mean_absolute_error: 0.0081
# Epoch 29/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4564e-04 - mean_absolute_error: 0.0081
# Epoch 30/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2891e-04 - mean_absolute_error: 0.0077
# Epoch 31/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2370e-04 - mean_absolute_error: 0.0074
# Epoch 32/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2424e-04 - mean_absolute_error: 0.0075
# Epoch 33/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2126e-04 - mean_absolute_error: 0.0074
# Epoch 34/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2658e-04 - mean_absolute_error: 0.0074
# Epoch 35/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1762e-04 - mean_absolute_error: 0.0071
# Epoch 36/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1259e-04 - mean_absolute_error: 0.0069
# Epoch 37/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2651e-04 - mean_absolute_error: 0.0079
# Epoch 38/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1682e-04 - mean_absolute_error: 0.0072
# Epoch 39/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0965e-04 - mean_absolute_error: 0.0069
# Epoch 40/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1066e-04 - mean_absolute_error: 0.0070
# Epoch 41/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0807e-04 - mean_absolute_error: 0.0070
# Epoch 42/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0518e-04 - mean_absolute_error: 0.0068
# Epoch 43/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1190e-04 - mean_absolute_error: 0.0071
# Epoch 44/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0219e-04 - mean_absolute_error: 0.0069
# Epoch 45/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2225e-04 - mean_absolute_error: 0.0075
# Epoch 46/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.3420e-05 - mean_absolute_error: 0.0064
# Epoch 47/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0897e-04 - mean_absolute_error: 0.0071
# Epoch 48/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0543e-04 - mean_absolute_error: 0.0068
# Epoch 49/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0442e-04 - mean_absolute_error: 0.0071
# Epoch 50/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1317e-04 - mean_absolute_error: 0.0071
# Epoch 51/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1082e-04 - mean_absolute_error: 0.0072
# Epoch 52/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1317e-04 - mean_absolute_error: 0.0069
# Epoch 53/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1690e-04 - mean_absolute_error: 0.0074
# Epoch 54/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0796e-04 - mean_absolute_error: 0.0069
# Epoch 55/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2376e-04 - mean_absolute_error: 0.0078
# Epoch 56/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0839e-04 - mean_absolute_error: 0.0070
# Epoch 57/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.2377e-05 - mean_absolute_error: 0.0066
# Epoch 58/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.9563e-05 - mean_absolute_error: 0.0067
# Epoch 59/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0901e-04 - mean_absolute_error: 0.0068
# Epoch 60/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6504e-05 - mean_absolute_error: 0.0066
# Epoch 61/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0564e-04 - mean_absolute_error: 0.0067
# Epoch 62/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0615e-04 - mean_absolute_error: 0.0070
# Epoch 63/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.7713e-05 - mean_absolute_error: 0.0066
# Epoch 64/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1616e-04 - mean_absolute_error: 0.0071
# Epoch 65/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.2627e-05 - mean_absolute_error: 0.0067
# Epoch 66/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0657e-04 - mean_absolute_error: 0.0069
# Epoch 67/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.2002e-05 - mean_absolute_error: 0.0065
# Epoch 68/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0269e-04 - mean_absolute_error: 0.0070
# Epoch 69/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8781e-05 - mean_absolute_error: 0.0065
# Epoch 70/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.0317e-05 - mean_absolute_error: 0.0064
# Epoch 71/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0287e-04 - mean_absolute_error: 0.0068
# Epoch 72/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1338e-04 - mean_absolute_error: 0.0071
# Epoch 73/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.9378e-05 - mean_absolute_error: 0.0068
# Epoch 74/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3269e-04 - mean_absolute_error: 0.0080
# Epoch 75/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0926e-04 - mean_absolute_error: 0.0070
# Epoch 76/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.5713e-05 - mean_absolute_error: 0.0066
# Epoch 77/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.4738e-05 - mean_absolute_error: 0.0068
# Epoch 78/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0328e-04 - mean_absolute_error: 0.0067
# Epoch 79/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.9659e-05 - mean_absolute_error: 0.0062
# Epoch 80/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0066e-04 - mean_absolute_error: 0.0068
# Epoch 81/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.5032e-05 - mean_absolute_error: 0.0063
# Epoch 82/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6771e-05 - mean_absolute_error: 0.0068
# Epoch 83/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7405e-05 - mean_absolute_error: 0.0064
# Epoch 84/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7394e-05 - mean_absolute_error: 0.0057
# Epoch 85/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.8287e-05 - mean_absolute_error: 0.0069
# Epoch 86/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.9927e-05 - mean_absolute_error: 0.0062
# Epoch 87/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.3617e-05 - mean_absolute_error: 0.0064
# Epoch 88/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.3762e-05 - mean_absolute_error: 0.0064
# Epoch 89/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7138e-05 - mean_absolute_error: 0.0058
# Epoch 90/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0006e-04 - mean_absolute_error: 0.0069
# Epoch 91/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.9167e-05 - mean_absolute_error: 0.0062
# Epoch 92/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0788e-05 - mean_absolute_error: 0.0060
# Epoch 93/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.8107e-05 - mean_absolute_error: 0.0062
# Epoch 94/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0445e-05 - mean_absolute_error: 0.0058
# Epoch 95/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7282e-05 - mean_absolute_error: 0.0063
# Epoch 96/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.0343e-05 - mean_absolute_error: 0.0066
# Epoch 97/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9715e-05 - mean_absolute_error: 0.0061
# Epoch 98/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9583e-05 - mean_absolute_error: 0.0057
# Epoch 99/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4404e-05 - mean_absolute_error: 0.0056
# Epoch 100/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.4448e-05 - mean_absolute_error: 0.0067
# Epoch 101/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.0189e-05 - mean_absolute_error: 0.0063
# Epoch 102/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9879e-05 - mean_absolute_error: 0.0060
# Epoch 103/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2015e-05 - mean_absolute_error: 0.0055
# Epoch 104/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6342e-05 - mean_absolute_error: 0.0056
# Epoch 105/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9452e-05 - mean_absolute_error: 0.0061
# Epoch 106/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2348e-05 - mean_absolute_error: 0.0058
# Epoch 107/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4474e-05 - mean_absolute_error: 0.0064
# Epoch 108/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.9101e-05 - mean_absolute_error: 0.0069
# Epoch 109/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3960e-05 - mean_absolute_error: 0.0062
# Epoch 110/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2872e-05 - mean_absolute_error: 0.0059
# Epoch 111/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7997e-05 - mean_absolute_error: 0.0063
# Epoch 112/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.3595e-05 - mean_absolute_error: 0.0066
# Epoch 113/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0927e-04 - mean_absolute_error: 0.0070
# Epoch 114/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9679e-05 - mean_absolute_error: 0.0060
# Epoch 115/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1938e-05 - mean_absolute_error: 0.0056
# Epoch 116/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3474e-05 - mean_absolute_error: 0.0065
# Epoch 117/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9709e-05 - mean_absolute_error: 0.0059
# Epoch 118/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7507e-05 - mean_absolute_error: 0.0059
# Epoch 119/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.0876e-05 - mean_absolute_error: 0.0064
# Epoch 120/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7475e-05 - mean_absolute_error: 0.0060
# Epoch 121/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.2026e-05 - mean_absolute_error: 0.0062
# Epoch 122/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2322e-05 - mean_absolute_error: 0.0059
# Epoch 123/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6264e-05 - mean_absolute_error: 0.0058
# Epoch 124/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3824e-05 - mean_absolute_error: 0.0060
# Epoch 125/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4268e-05 - mean_absolute_error: 0.0057
# Epoch 126/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3092e-05 - mean_absolute_error: 0.0057
# Epoch 127/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2192e-05 - mean_absolute_error: 0.0058
# Epoch 128/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4802e-05 - mean_absolute_error: 0.0061
# Epoch 129/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1191e-05 - mean_absolute_error: 0.0057
# Epoch 130/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6702e-05 - mean_absolute_error: 0.0063
# Epoch 131/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6752e-05 - mean_absolute_error: 0.0058
# Epoch 132/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9203e-05 - mean_absolute_error: 0.0058
# Epoch 133/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.2852e-05 - mean_absolute_error: 0.0065
# Epoch 134/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.7202e-05 - mean_absolute_error: 0.0068
# Epoch 135/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1247e-05 - mean_absolute_error: 0.0054
# Epoch 136/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3197e-05 - mean_absolute_error: 0.0056
# Epoch 137/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3640e-05 - mean_absolute_error: 0.0056
# Epoch 138/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0402e-05 - mean_absolute_error: 0.0056
# Epoch 139/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4856e-05 - mean_absolute_error: 0.0060
# Epoch 140/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9978e-05 - mean_absolute_error: 0.0056
# Epoch 141/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.1698e-05 - mean_absolute_error: 0.0064
# Epoch 142/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0946e-05 - mean_absolute_error: 0.0063
# Epoch 143/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0800e-05 - mean_absolute_error: 0.0061
# Epoch 144/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6116e-05 - mean_absolute_error: 0.0060
# Epoch 145/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2784e-05 - mean_absolute_error: 0.0058
# Epoch 146/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6984e-05 - mean_absolute_error: 0.0056
# Epoch 147/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8793e-05 - mean_absolute_error: 0.0059
# Epoch 148/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8147e-05 - mean_absolute_error: 0.0054
# Epoch 149/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4564e-05 - mean_absolute_error: 0.0061
# Epoch 150/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0365e-05 - mean_absolute_error: 0.0060
# Epoch 151/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.7488e-05 - mean_absolute_error: 0.0070
# Epoch 152/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6134e-05 - mean_absolute_error: 0.0058
# Epoch 153/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7841e-05 - mean_absolute_error: 0.0053
# Epoch 154/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7268e-05 - mean_absolute_error: 0.0053
# Epoch 155/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8641e-05 - mean_absolute_error: 0.0058
# Epoch 156/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2310e-05 - mean_absolute_error: 0.0059
# Epoch 157/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3548e-05 - mean_absolute_error: 0.0052
# Epoch 158/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8404e-05 - mean_absolute_error: 0.0059
# Epoch 159/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.9027e-05 - mean_absolute_error: 0.0066
# Epoch 160/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6928e-05 - mean_absolute_error: 0.0058
# Epoch 161/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2163e-05 - mean_absolute_error: 0.0056
# Epoch 162/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4499e-05 - mean_absolute_error: 0.0057
# Epoch 163/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.3271e-05 - mean_absolute_error: 0.0056
# Epoch 164/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3726e-05 - mean_absolute_error: 0.0057
# Epoch 165/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0856e-05 - mean_absolute_error: 0.0061
# Epoch 166/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4576e-05 - mean_absolute_error: 0.0053
# Epoch 167/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8470e-05 - mean_absolute_error: 0.0056
# Epoch 168/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6761e-05 - mean_absolute_error: 0.0058
# Epoch 169/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2118e-05 - mean_absolute_error: 0.0056
# Epoch 170/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0612e-05 - mean_absolute_error: 0.0062
# Epoch 171/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3010e-05 - mean_absolute_error: 0.0053
# Epoch 172/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8527e-05 - mean_absolute_error: 0.0060
# Epoch 173/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7990e-05 - mean_absolute_error: 0.0057
# Epoch 174/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7429e-05 - mean_absolute_error: 0.0054
# Epoch 175/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0253e-05 - mean_absolute_error: 0.0059
# Epoch 176/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9429e-05 - mean_absolute_error: 0.0059
# Epoch 177/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2216e-05 - mean_absolute_error: 0.0060
# Epoch 178/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3123e-05 - mean_absolute_error: 0.0053
# Epoch 179/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7201e-05 - mean_absolute_error: 0.0058
# Epoch 180/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9223e-05 - mean_absolute_error: 0.0058
# Epoch 181/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9287e-05 - mean_absolute_error: 0.0054
# Epoch 182/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0031e-05 - mean_absolute_error: 0.0054
# Epoch 183/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2153e-05 - mean_absolute_error: 0.0054
# Epoch 184/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7715e-05 - mean_absolute_error: 0.0052
# Epoch 185/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3703e-05 - mean_absolute_error: 0.0055
# Epoch 186/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7137e-05 - mean_absolute_error: 0.0060
# Epoch 187/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7175e-05 - mean_absolute_error: 0.0054
# Epoch 188/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3547e-05 - mean_absolute_error: 0.0057
# Epoch 189/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2248e-05 - mean_absolute_error: 0.0057
# Epoch 190/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3454e-05 - mean_absolute_error: 0.0056
# Epoch 191/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.6858e-05 - mean_absolute_error: 0.0070
# Epoch 192/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3509e-05 - mean_absolute_error: 0.0052
# Epoch 193/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8722e-05 - mean_absolute_error: 0.0050
# Epoch 194/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7903e-05 - mean_absolute_error: 0.0057
# Epoch 195/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4318e-05 - mean_absolute_error: 0.0057
# Epoch 196/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9116e-05 - mean_absolute_error: 0.0063
# Epoch 197/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9059e-05 - mean_absolute_error: 0.0055
# Epoch 198/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.5346e-05 - mean_absolute_error: 0.0054
# Epoch 199/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9088e-05 - mean_absolute_error: 0.0057
# Epoch 200/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5017e-05 - mean_absolute_error: 0.0051

# %% [markdown]
# ### Predicting with test set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4576e-04 - mean_absolute_error: 0.0086
# Test Loss: [0.00021424501028377563, 0.010444051586091518]

# %%
# Splitting data into train, test set again to evaluate, because i shaped the data between 0 to 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 121
# 132

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)
# Out:
# Model evalution on test set
# MSE: 6802414.137446632
# RMSE: 2608.1438107295066
# MAE: 1843.5960098140497
# MAPE: 1.6243785983313843 %

# %% [markdown]
# ## 4. Forecast the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(test_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
y_pred_30_days
# Out:
# array([[135168.36],
#        [135137.8 ],
#        [135140.66],
#        [135140.97],
#        [135140.81],
#        [135140.84],
#        [135140.86],
#        [135140.86],
#        [135140.86],
#        [135140.86],
#        [135140.86],
#        [135140.86],
#        [135140.86],
#        [135140.86],
#        [135140.86],
#        [135140.86],
#        [135140.86],
#        [135140.86],
#        [135140.86],
#        [135140.86],
#        [135140.86],
#        [135140.86],
#        [135140.86],
#        [135140.86],
#        [135140.86],
#        [135140.86],
#        [135140.86],
#        [135140.86],
#        [135140.86],
#        [135140.86],
#        [135140.86]], dtype=float32)

# %% [markdown]
# ### Continue forecast the next 60/90 days

# %%
y_pred_60_days = forecast(test_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
y_pred_90_days = forecast(test_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")

    # Predict test set
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        test_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Next {days} Days",
        linestyle="--",
    )

    plt.title(f"Forecast {stock_name[stock]} Stock Closing Price Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
