# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

plt.style.use("default")

# %% [markdown]
# ## 1. Data preprocessing

# %%
split_type = [0.8,0.7,0.9]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 1  # 70% train, 30% test

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#              close
# time
# 2019-03-01   19270
# 2019-03-04   19440
# 2019-03-05   19390
# 2019-03-06   19270
# 2019-03-07   19330
# ...            ...
# 2024-05-27  132800
# 2024-05-28  137000
# 2024-05-29  135700
# 2024-05-30  135000
# 2024-05-31  134600
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split] * len(df_scaled))
test_size = len(df_scaled) - train_size

# %%
# Splitting data into train, test set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size:]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test set
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((908, 10), (908,), (383, 10), (383,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Input

UNITS = 64

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(UNITS),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 64)             │        12,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,929 (50.50 KB)
#  Trainable params: 12,929 (50.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.0201 - mean_absolute_error: 0.1030
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7595e-04 - mean_absolute_error: 0.0173
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9271e-04 - mean_absolute_error: 0.0091
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0865e-04 - mean_absolute_error: 0.0068
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2783e-04 - mean_absolute_error: 0.0075
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2491e-04 - mean_absolute_error: 0.0074
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1531e-04 - mean_absolute_error: 0.0072
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0611e-04 - mean_absolute_error: 0.0067
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0373e-04 - mean_absolute_error: 0.0064
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0344e-04 - mean_absolute_error: 0.0065
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.8606e-05 - mean_absolute_error: 0.0064
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.5924e-05 - mean_absolute_error: 0.0064
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2717e-04 - mean_absolute_error: 0.0079
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0578e-04 - mean_absolute_error: 0.0066
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0278e-04 - mean_absolute_error: 0.0065
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6379e-05 - mean_absolute_error: 0.0062
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.2608e-05 - mean_absolute_error: 0.0061
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9070e-05 - mean_absolute_error: 0.0059
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.7184e-05 - mean_absolute_error: 0.0065
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.5040e-05 - mean_absolute_error: 0.0066
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3794e-05 - mean_absolute_error: 0.0060
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5418e-05 - mean_absolute_error: 0.0062
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0190e-04 - mean_absolute_error: 0.0062
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2141e-05 - mean_absolute_error: 0.0059
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.8850e-05 - mean_absolute_error: 0.0061
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.8500e-05 - mean_absolute_error: 0.0061
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2070e-05 - mean_absolute_error: 0.0061
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1868e-05 - mean_absolute_error: 0.0059
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2422e-05 - mean_absolute_error: 0.0054
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3473e-05 - mean_absolute_error: 0.0058
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6799e-05 - mean_absolute_error: 0.0055
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.3098e-05 - mean_absolute_error: 0.0061
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5738e-05 - mean_absolute_error: 0.0059
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3112e-05 - mean_absolute_error: 0.0054
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6046e-05 - mean_absolute_error: 0.0056
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0555e-05 - mean_absolute_error: 0.0058
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2634e-05 - mean_absolute_error: 0.0056
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0708e-04 - mean_absolute_error: 0.0066
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.3978e-05 - mean_absolute_error: 0.0063
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1996e-05 - mean_absolute_error: 0.0055
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4956e-05 - mean_absolute_error: 0.0056
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2766e-05 - mean_absolute_error: 0.0054
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0093e-05 - mean_absolute_error: 0.0057
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3382e-05 - mean_absolute_error: 0.0053
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4215e-05 - mean_absolute_error: 0.0055
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.5936e-05 - mean_absolute_error: 0.0063
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0679e-05 - mean_absolute_error: 0.0057
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1872e-05 - mean_absolute_error: 0.0060
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4942e-05 - mean_absolute_error: 0.0053
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6673e-05 - mean_absolute_error: 0.0055
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.0434e-05 - mean_absolute_error: 0.0062
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6482e-05 - mean_absolute_error: 0.0055
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0382e-04 - mean_absolute_error: 0.0069
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6616e-05 - mean_absolute_error: 0.0059
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8362e-05 - mean_absolute_error: 0.0052
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2812e-05 - mean_absolute_error: 0.0058
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1845e-05 - mean_absolute_error: 0.0056
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2106e-05 - mean_absolute_error: 0.0056
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5543e-05 - mean_absolute_error: 0.0054
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.2501e-05 - mean_absolute_error: 0.0064
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3396e-05 - mean_absolute_error: 0.0061
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8127e-05 - mean_absolute_error: 0.0062
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9957e-05 - mean_absolute_error: 0.0058
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8993e-05 - mean_absolute_error: 0.0058
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3287e-05 - mean_absolute_error: 0.0054
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0243e-05 - mean_absolute_error: 0.0062
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1301e-05 - mean_absolute_error: 0.0055
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7969e-05 - mean_absolute_error: 0.0059
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1817e-05 - mean_absolute_error: 0.0060
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7211e-05 - mean_absolute_error: 0.0056
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0846e-05 - mean_absolute_error: 0.0057
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6375e-05 - mean_absolute_error: 0.0051
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0575e-05 - mean_absolute_error: 0.0054
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0577e-05 - mean_absolute_error: 0.0052
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9783e-05 - mean_absolute_error: 0.0051
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0812e-05 - mean_absolute_error: 0.0054
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8456e-05 - mean_absolute_error: 0.0053
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2210e-05 - mean_absolute_error: 0.0055
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8690e-05 - mean_absolute_error: 0.0054
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6090e-05 - mean_absolute_error: 0.0061
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0093e-05 - mean_absolute_error: 0.0061
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4867e-05 - mean_absolute_error: 0.0058
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4064e-05 - mean_absolute_error: 0.0053
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6333e-05 - mean_absolute_error: 0.0052
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7258e-05 - mean_absolute_error: 0.0061
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0916e-05 - mean_absolute_error: 0.0062
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9006e-05 - mean_absolute_error: 0.0058
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7563e-05 - mean_absolute_error: 0.0053
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1688e-05 - mean_absolute_error: 0.0057
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3181e-05 - mean_absolute_error: 0.0058
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0163e-05 - mean_absolute_error: 0.0057
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0949e-05 - mean_absolute_error: 0.0061
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2646e-05 - mean_absolute_error: 0.0054
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7180e-05 - mean_absolute_error: 0.0050
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5836e-05 - mean_absolute_error: 0.0050
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.0200e-05 - mean_absolute_error: 0.0070
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.7738e-05 - mean_absolute_error: 0.0056
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4384e-05 - mean_absolute_error: 0.0051
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1370e-05 - mean_absolute_error: 0.0054
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2484e-05 - mean_absolute_error: 0.0051
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3967e-05 - mean_absolute_error: 0.0061
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6695e-05 - mean_absolute_error: 0.0052
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.1470e-05 - mean_absolute_error: 0.0071
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1027e-05 - mean_absolute_error: 0.0054
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0538e-05 - mean_absolute_error: 0.0052
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3579e-05 - mean_absolute_error: 0.0052
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4075e-05 - mean_absolute_error: 0.0051
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3887e-05 - mean_absolute_error: 0.0061
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4174e-05 - mean_absolute_error: 0.0056
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4704e-05 - mean_absolute_error: 0.0048
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1082e-05 - mean_absolute_error: 0.0054
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5914e-05 - mean_absolute_error: 0.0062
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8845e-05 - mean_absolute_error: 0.0055
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6765e-05 - mean_absolute_error: 0.0060
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5356e-05 - mean_absolute_error: 0.0054
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3038e-05 - mean_absolute_error: 0.0052
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5752e-05 - mean_absolute_error: 0.0050
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2146e-05 - mean_absolute_error: 0.0054
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.9346e-05 - mean_absolute_error: 0.0058
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7336e-05 - mean_absolute_error: 0.0053
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3707e-05 - mean_absolute_error: 0.0051
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5108e-05 - mean_absolute_error: 0.0058
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1532e-05 - mean_absolute_error: 0.0061
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6080e-05 - mean_absolute_error: 0.0049
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5536e-05 - mean_absolute_error: 0.0055
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2041e-05 - mean_absolute_error: 0.0052
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6981e-05 - mean_absolute_error: 0.0054
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3379e-05 - mean_absolute_error: 0.0053
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.4624e-05 - mean_absolute_error: 0.0058
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5492e-05 - mean_absolute_error: 0.0055
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9522e-05 - mean_absolute_error: 0.0054
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8947e-05 - mean_absolute_error: 0.0055
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4137e-05 - mean_absolute_error: 0.0049
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5028e-05 - mean_absolute_error: 0.0051
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6719e-05 - mean_absolute_error: 0.0058
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9851e-05 - mean_absolute_error: 0.0056
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3303e-05 - mean_absolute_error: 0.0051
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8902e-05 - mean_absolute_error: 0.0055
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5408e-05 - mean_absolute_error: 0.0058
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1249e-05 - mean_absolute_error: 0.0053
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0440e-05 - mean_absolute_error: 0.0050
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8030e-05 - mean_absolute_error: 0.0052
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9116e-05 - mean_absolute_error: 0.0057
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2514e-05 - mean_absolute_error: 0.0050
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9017e-05 - mean_absolute_error: 0.0050
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1349e-05 - mean_absolute_error: 0.0051
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3420e-05 - mean_absolute_error: 0.0052
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1332e-05 - mean_absolute_error: 0.0047
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9469e-05 - mean_absolute_error: 0.0053
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5847e-05 - mean_absolute_error: 0.0051
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9543e-05 - mean_absolute_error: 0.0049
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5629e-05 - mean_absolute_error: 0.0053
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.1468e-05 - mean_absolute_error: 0.0059
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6991e-05 - mean_absolute_error: 0.0051
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0986e-05 - mean_absolute_error: 0.0055
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4437e-05 - mean_absolute_error: 0.0051
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7264e-05 - mean_absolute_error: 0.0053
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8240e-05 - mean_absolute_error: 0.0060
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3550e-05 - mean_absolute_error: 0.0053
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6099e-05 - mean_absolute_error: 0.0049
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4113e-05 - mean_absolute_error: 0.0058
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4665e-05 - mean_absolute_error: 0.0051
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3456e-05 - mean_absolute_error: 0.0053
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4033e-05 - mean_absolute_error: 0.0052
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9745e-05 - mean_absolute_error: 0.0059
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3816e-05 - mean_absolute_error: 0.0051
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5058e-05 - mean_absolute_error: 0.0052
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0395e-05 - mean_absolute_error: 0.0052
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5405e-05 - mean_absolute_error: 0.0055
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6782e-05 - mean_absolute_error: 0.0055
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6573e-05 - mean_absolute_error: 0.0059
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.3002e-05 - mean_absolute_error: 0.0055
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7123e-05 - mean_absolute_error: 0.0056
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3007e-05 - mean_absolute_error: 0.0060
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8019e-05 - mean_absolute_error: 0.0053
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8444e-05 - mean_absolute_error: 0.0052
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.4007e-05 - mean_absolute_error: 0.0052
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4394e-05 - mean_absolute_error: 0.0056
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.3761e-05 - mean_absolute_error: 0.0054
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1766e-05 - mean_absolute_error: 0.0049
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4665e-05 - mean_absolute_error: 0.0052
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6820e-05 - mean_absolute_error: 0.0061
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4023e-05 - mean_absolute_error: 0.0052
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.2335e-05 - mean_absolute_error: 0.0053
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5104e-05 - mean_absolute_error: 0.0051
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.7999e-05 - mean_absolute_error: 0.0056
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5082e-05 - mean_absolute_error: 0.0060
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2860e-05 - mean_absolute_error: 0.0057
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0142e-05 - mean_absolute_error: 0.0056
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3538e-05 - mean_absolute_error: 0.0049
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.5771e-05 - mean_absolute_error: 0.0062
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0231e-05 - mean_absolute_error: 0.0051
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0849e-05 - mean_absolute_error: 0.0055
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0326e-05 - mean_absolute_error: 0.0051
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4198e-05 - mean_absolute_error: 0.0055
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8205e-05 - mean_absolute_error: 0.0049
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1986e-05 - mean_absolute_error: 0.0050
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7460e-05 - mean_absolute_error: 0.0051
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7077e-05 - mean_absolute_error: 0.0059
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5808e-05 - mean_absolute_error: 0.0056

# %% [markdown]
# ### Predicting with test set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)
# Out:
#  1/12 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.1010e-05 - mean_absolute_error: 0.0064
# Test Loss: [0.00016202146071009338, 0.008432166650891304]

# %%
# Splitting data into train, test set again to evaluate, because i shaped the data between 0 to 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 383
# 394

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)
# Out:
# Model evalution on test set
# MSE: 4537884.178759144
# RMSE: 2130.231015350012
# MAE: 1433.6971891318537
# MAPE: 1.5639936672725303 %

# %% [markdown]
# ## 4. Forecast the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(test_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
y_pred_30_days
# Out:
# array([[132785.48],
#        [133116.88],
#        [132917.86],
#        [132985.23],
#        [132950.83],
#        [132963.42],
#        [132957.95],
#        [132960.14],
#        [132959.22],
#        [132959.6 ],
#        [132959.45],
#        [132959.5 ],
#        [132959.48],
#        [132959.48],
#        [132959.48],
#        [132959.5 ],
#        [132959.48],
#        [132959.48],
#        [132959.5 ],
#        [132959.48],
#        [132959.48],
#        [132959.5 ],
#        [132959.48],
#        [132959.48],
#        [132959.5 ],
#        [132959.48],
#        [132959.48],
#        [132959.5 ],
#        [132959.48],
#        [132959.48],
#        [132959.5 ]], dtype=float32)

# %% [markdown]
# ### Continue forecast the next 60/90 days

# %%
y_pred_60_days = forecast(test_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
y_pred_90_days = forecast(test_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")

    # Predict test set
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        test_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Next {days} Days",
        linestyle="--",
    )

    plt.title(f"Forecast {stock_name[stock]} Stock Closing Price Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
