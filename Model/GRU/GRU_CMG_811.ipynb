# %% [markdown]
# # Model: GRU (Gated Recurrent Unit)  - Stock Token: CMG - Test/Train/Vaildation: 80/10/10
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 701.19
# - MAE: 475.63
# - MAPE: 1.35 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 2  # 8 1 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830
# ...           ...
# 2024-02-26  40000
# 2024-02-27  40200
# 2024-02-28  40000
# 2024-02-29  39950
# 2024-03-01  41200
#
# [1252 rows x 1 columns]

# %%
df.shape
# Out:
# (1252, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1247    40000
# 1248    40200
# 1249    40000
# 1250    39950
# 1251    41200
# Name: close, Length: 1252, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((990, 10), (990,), (114, 10), (114,), (115, 10), (115,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(100),
        Dense(32, activation="relu"),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 100)            │        30,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,165 (133.46 KB)
#  Trainable params: 34,165 (133.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0866 - mean_absolute_error: 0.2123 - val_loss: 0.0166 - val_mean_absolute_error: 0.1258
# Epoch 2/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mean_absolute_error: 0.0445 - val_loss: 3.0843e-04 - val_mean_absolute_error: 0.0117
# Epoch 3/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8572e-04 - mean_absolute_error: 0.0193 - val_loss: 3.0800e-04 - val_mean_absolute_error: 0.0114
# Epoch 4/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9686e-04 - mean_absolute_error: 0.0182 - val_loss: 2.9651e-04 - val_mean_absolute_error: 0.0112
# Epoch 5/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4261e-04 - mean_absolute_error: 0.0179 - val_loss: 6.5784e-04 - val_mean_absolute_error: 0.0198
# Epoch 6/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4147e-04 - mean_absolute_error: 0.0175 - val_loss: 4.1306e-04 - val_mean_absolute_error: 0.0137
# Epoch 7/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5503e-04 - mean_absolute_error: 0.0164 - val_loss: 4.8746e-04 - val_mean_absolute_error: 0.0158
# Epoch 8/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1636e-04 - mean_absolute_error: 0.0174 - val_loss: 2.8379e-04 - val_mean_absolute_error: 0.0121
# Epoch 9/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3483e-04 - mean_absolute_error: 0.0161 - val_loss: 3.0386e-04 - val_mean_absolute_error: 0.0112
# Epoch 10/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2571e-04 - mean_absolute_error: 0.0154 - val_loss: 2.5970e-04 - val_mean_absolute_error: 0.0107
# Epoch 11/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5886e-04 - mean_absolute_error: 0.0164 - val_loss: 2.8828e-04 - val_mean_absolute_error: 0.0127
# Epoch 12/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2105e-04 - mean_absolute_error: 0.0157 - val_loss: 2.7074e-04 - val_mean_absolute_error: 0.0107
# Epoch 13/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2415e-04 - mean_absolute_error: 0.0157 - val_loss: 4.1710e-04 - val_mean_absolute_error: 0.0144
# Epoch 14/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2929e-04 - mean_absolute_error: 0.0158 - val_loss: 2.4723e-04 - val_mean_absolute_error: 0.0106
# Epoch 15/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7436e-04 - mean_absolute_error: 0.0161 - val_loss: 2.4512e-04 - val_mean_absolute_error: 0.0104
# Epoch 16/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1574e-04 - mean_absolute_error: 0.0159 - val_loss: 5.5056e-04 - val_mean_absolute_error: 0.0209
# Epoch 17/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3569e-04 - mean_absolute_error: 0.0165 - val_loss: 2.4618e-04 - val_mean_absolute_error: 0.0103
# Epoch 18/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0120e-04 - mean_absolute_error: 0.0152 - val_loss: 2.3832e-04 - val_mean_absolute_error: 0.0104
# Epoch 19/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5054e-04 - mean_absolute_error: 0.0146 - val_loss: 2.4259e-04 - val_mean_absolute_error: 0.0109
# Epoch 20/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7197e-04 - mean_absolute_error: 0.0154 - val_loss: 2.7555e-04 - val_mean_absolute_error: 0.0111
# Epoch 21/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4218e-04 - mean_absolute_error: 0.0145 - val_loss: 4.8124e-04 - val_mean_absolute_error: 0.0166
# Epoch 22/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8267e-04 - mean_absolute_error: 0.0152 - val_loss: 3.2287e-04 - val_mean_absolute_error: 0.0143
# Epoch 23/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1634e-04 - mean_absolute_error: 0.0164 - val_loss: 2.7321e-04 - val_mean_absolute_error: 0.0111
# Epoch 24/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7312e-04 - mean_absolute_error: 0.0147 - val_loss: 2.3049e-04 - val_mean_absolute_error: 0.0102
# Epoch 25/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5438e-04 - mean_absolute_error: 0.0146 - val_loss: 3.4712e-04 - val_mean_absolute_error: 0.0151
# Epoch 26/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4239e-04 - mean_absolute_error: 0.0148 - val_loss: 3.3733e-04 - val_mean_absolute_error: 0.0129
# Epoch 27/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2525e-04 - mean_absolute_error: 0.0146 - val_loss: 7.7825e-04 - val_mean_absolute_error: 0.0235
# Epoch 28/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5914e-04 - mean_absolute_error: 0.0154 - val_loss: 2.4053e-04 - val_mean_absolute_error: 0.0102
# Epoch 29/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7042e-04 - mean_absolute_error: 0.0145 - val_loss: 4.0178e-04 - val_mean_absolute_error: 0.0148
# Epoch 30/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0093e-04 - mean_absolute_error: 0.0140 - val_loss: 3.0993e-04 - val_mean_absolute_error: 0.0122
# Epoch 31/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2434e-04 - mean_absolute_error: 0.0144 - val_loss: 2.9576e-04 - val_mean_absolute_error: 0.0118
# Epoch 32/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3224e-04 - mean_absolute_error: 0.0145 - val_loss: 2.2527e-04 - val_mean_absolute_error: 0.0103
# Epoch 33/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1748e-04 - mean_absolute_error: 0.0164 - val_loss: 2.4433e-04 - val_mean_absolute_error: 0.0103
# Epoch 34/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0618e-04 - mean_absolute_error: 0.0137 - val_loss: 3.0752e-04 - val_mean_absolute_error: 0.0138
# Epoch 35/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3146e-04 - mean_absolute_error: 0.0165 - val_loss: 2.2614e-04 - val_mean_absolute_error: 0.0099
# Epoch 36/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2998e-04 - mean_absolute_error: 0.0145 - val_loss: 2.2091e-04 - val_mean_absolute_error: 0.0099
# Epoch 37/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2588e-04 - mean_absolute_error: 0.0142 - val_loss: 2.2137e-04 - val_mean_absolute_error: 0.0099
# Epoch 38/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3693e-04 - mean_absolute_error: 0.0145 - val_loss: 2.4216e-04 - val_mean_absolute_error: 0.0115
# Epoch 39/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0587e-04 - mean_absolute_error: 0.0138 - val_loss: 2.8329e-04 - val_mean_absolute_error: 0.0131
# Epoch 40/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0484e-04 - mean_absolute_error: 0.0143 - val_loss: 2.9282e-04 - val_mean_absolute_error: 0.0118
# Epoch 41/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1918e-04 - mean_absolute_error: 0.0142 - val_loss: 2.2327e-04 - val_mean_absolute_error: 0.0098
# Epoch 42/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8040e-04 - mean_absolute_error: 0.0133 - val_loss: 2.9963e-04 - val_mean_absolute_error: 0.0120
# Epoch 43/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4159e-04 - mean_absolute_error: 0.0128 - val_loss: 2.1917e-04 - val_mean_absolute_error: 0.0103
# Epoch 44/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1977e-04 - mean_absolute_error: 0.0141 - val_loss: 3.7473e-04 - val_mean_absolute_error: 0.0143
# Epoch 45/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5298e-04 - mean_absolute_error: 0.0151 - val_loss: 2.6768e-04 - val_mean_absolute_error: 0.0110
# Epoch 46/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2537e-04 - mean_absolute_error: 0.0144 - val_loss: 2.9004e-04 - val_mean_absolute_error: 0.0117
# Epoch 47/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4637e-04 - mean_absolute_error: 0.0149 - val_loss: 3.4576e-04 - val_mean_absolute_error: 0.0134
# Epoch 48/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1658e-04 - mean_absolute_error: 0.0145 - val_loss: 2.3307e-04 - val_mean_absolute_error: 0.0100
# Epoch 49/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4959e-04 - mean_absolute_error: 0.0129 - val_loss: 4.2426e-04 - val_mean_absolute_error: 0.0157
# Epoch 50/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2815e-04 - mean_absolute_error: 0.0145 - val_loss: 2.1967e-04 - val_mean_absolute_error: 0.0106
# Epoch 51/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4461e-04 - mean_absolute_error: 0.0147 - val_loss: 2.2038e-04 - val_mean_absolute_error: 0.0107
# Epoch 52/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9648e-04 - mean_absolute_error: 0.0142 - val_loss: 2.2054e-04 - val_mean_absolute_error: 0.0097
# Epoch 53/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8714e-04 - mean_absolute_error: 0.0132 - val_loss: 2.1651e-04 - val_mean_absolute_error: 0.0101
# Epoch 54/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1085e-04 - mean_absolute_error: 0.0148 - val_loss: 2.2014e-04 - val_mean_absolute_error: 0.0101
# Epoch 55/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5654e-04 - mean_absolute_error: 0.0150 - val_loss: 2.3390e-04 - val_mean_absolute_error: 0.0114
# Epoch 56/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4869e-04 - mean_absolute_error: 0.0129 - val_loss: 3.7044e-04 - val_mean_absolute_error: 0.0160
# Epoch 57/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6845e-04 - mean_absolute_error: 0.0155 - val_loss: 3.2372e-04 - val_mean_absolute_error: 0.0145
# Epoch 58/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8939e-04 - mean_absolute_error: 0.0140 - val_loss: 2.1874e-04 - val_mean_absolute_error: 0.0107
# Epoch 59/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4462e-04 - mean_absolute_error: 0.0131 - val_loss: 2.1360e-04 - val_mean_absolute_error: 0.0100
# Epoch 60/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5588e-04 - mean_absolute_error: 0.0134 - val_loss: 2.6985e-04 - val_mean_absolute_error: 0.0111
# Epoch 61/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0172e-04 - mean_absolute_error: 0.0137 - val_loss: 5.5790e-04 - val_mean_absolute_error: 0.0192
# Epoch 62/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0717e-04 - mean_absolute_error: 0.0160 - val_loss: 2.5552e-04 - val_mean_absolute_error: 0.0107
# Epoch 63/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3759e-04 - mean_absolute_error: 0.0150 - val_loss: 5.9268e-04 - val_mean_absolute_error: 0.0198
# Epoch 64/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7771e-04 - mean_absolute_error: 0.0138 - val_loss: 2.6035e-04 - val_mean_absolute_error: 0.0125
# Epoch 65/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2307e-04 - mean_absolute_error: 0.0148 - val_loss: 2.8295e-04 - val_mean_absolute_error: 0.0115
# Epoch 66/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0071e-04 - mean_absolute_error: 0.0133 - val_loss: 2.2112e-04 - val_mean_absolute_error: 0.0099
# Epoch 67/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6840e-04 - mean_absolute_error: 0.0130 - val_loss: 2.1208e-04 - val_mean_absolute_error: 0.0099
# Epoch 68/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1829e-04 - mean_absolute_error: 0.0143 - val_loss: 2.6991e-04 - val_mean_absolute_error: 0.0129
# Epoch 69/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2653e-04 - mean_absolute_error: 0.0139 - val_loss: 2.0688e-04 - val_mean_absolute_error: 0.0099
# Epoch 70/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9884e-04 - mean_absolute_error: 0.0138 - val_loss: 2.5367e-04 - val_mean_absolute_error: 0.0107
# Epoch 71/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6752e-04 - mean_absolute_error: 0.0129 - val_loss: 3.2295e-04 - val_mean_absolute_error: 0.0128
# Epoch 72/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6093e-04 - mean_absolute_error: 0.0130 - val_loss: 2.2569e-04 - val_mean_absolute_error: 0.0101
# Epoch 73/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0781e-04 - mean_absolute_error: 0.0139 - val_loss: 4.2960e-04 - val_mean_absolute_error: 0.0159
# Epoch 74/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4078e-04 - mean_absolute_error: 0.0155 - val_loss: 3.0077e-04 - val_mean_absolute_error: 0.0121
# Epoch 75/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8054e-04 - mean_absolute_error: 0.0134 - val_loss: 2.3260e-04 - val_mean_absolute_error: 0.0102
# Epoch 76/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9659e-04 - mean_absolute_error: 0.0142 - val_loss: 2.1825e-04 - val_mean_absolute_error: 0.0100
# Epoch 77/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2804e-04 - mean_absolute_error: 0.0141 - val_loss: 2.2306e-04 - val_mean_absolute_error: 0.0100
# Epoch 78/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6513e-04 - mean_absolute_error: 0.0132 - val_loss: 2.1060e-04 - val_mean_absolute_error: 0.0101
# Epoch 79/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8592e-04 - mean_absolute_error: 0.0136 - val_loss: 5.5944e-04 - val_mean_absolute_error: 0.0193
# Epoch 80/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4589e-04 - mean_absolute_error: 0.0149 - val_loss: 3.3665e-04 - val_mean_absolute_error: 0.0132
# Epoch 81/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7622e-04 - mean_absolute_error: 0.0130 - val_loss: 3.9910e-04 - val_mean_absolute_error: 0.0152
# Epoch 82/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9346e-04 - mean_absolute_error: 0.0136 - val_loss: 3.2298e-04 - val_mean_absolute_error: 0.0146
# Epoch 83/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9707e-04 - mean_absolute_error: 0.0142 - val_loss: 2.1977e-04 - val_mean_absolute_error: 0.0110
# Epoch 84/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0097e-04 - mean_absolute_error: 0.0140 - val_loss: 4.6843e-04 - val_mean_absolute_error: 0.0171
# Epoch 85/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2409e-04 - mean_absolute_error: 0.0141 - val_loss: 2.0963e-04 - val_mean_absolute_error: 0.0103
# Epoch 86/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2156e-04 - mean_absolute_error: 0.0147 - val_loss: 2.4736e-04 - val_mean_absolute_error: 0.0121
# Epoch 87/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6799e-04 - mean_absolute_error: 0.0132 - val_loss: 2.4503e-04 - val_mean_absolute_error: 0.0120
# Epoch 88/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0578e-04 - mean_absolute_error: 0.0141 - val_loss: 2.1832e-04 - val_mean_absolute_error: 0.0100
# Epoch 89/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8505e-04 - mean_absolute_error: 0.0135 - val_loss: 2.5997e-04 - val_mean_absolute_error: 0.0109
# Epoch 90/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7045e-04 - mean_absolute_error: 0.0132 - val_loss: 4.4429e-04 - val_mean_absolute_error: 0.0165
# Epoch 91/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8403e-04 - mean_absolute_error: 0.0140 - val_loss: 4.8984e-04 - val_mean_absolute_error: 0.0177
# Epoch 92/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4506e-04 - mean_absolute_error: 0.0131 - val_loss: 2.1934e-04 - val_mean_absolute_error: 0.0109
# Epoch 93/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5682e-04 - mean_absolute_error: 0.0136 - val_loss: 2.5006e-04 - val_mean_absolute_error: 0.0122
# Epoch 94/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5288e-04 - mean_absolute_error: 0.0128 - val_loss: 2.1861e-04 - val_mean_absolute_error: 0.0109
# Epoch 95/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2366e-04 - mean_absolute_error: 0.0146 - val_loss: 6.4270e-04 - val_mean_absolute_error: 0.0230
# Epoch 96/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2986e-04 - mean_absolute_error: 0.0147 - val_loss: 3.6872e-04 - val_mean_absolute_error: 0.0143
# Epoch 97/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6619e-04 - mean_absolute_error: 0.0137 - val_loss: 5.6661e-04 - val_mean_absolute_error: 0.0195
# Epoch 98/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6267e-04 - mean_absolute_error: 0.0134 - val_loss: 2.1070e-04 - val_mean_absolute_error: 0.0100
# Epoch 99/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0336e-04 - mean_absolute_error: 0.0141 - val_loss: 3.3826e-04 - val_mean_absolute_error: 0.0151
# Epoch 100/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3030e-04 - mean_absolute_error: 0.0151 - val_loss: 3.8045e-04 - val_mean_absolute_error: 0.0147
# Epoch 101/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1975e-04 - mean_absolute_error: 0.0140 - val_loss: 2.1086e-04 - val_mean_absolute_error: 0.0103
# Epoch 102/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0499e-04 - mean_absolute_error: 0.0142 - val_loss: 4.5873e-04 - val_mean_absolute_error: 0.0186
# Epoch 103/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0023e-04 - mean_absolute_error: 0.0142 - val_loss: 2.4226e-04 - val_mean_absolute_error: 0.0109
# Epoch 104/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8790e-04 - mean_absolute_error: 0.0139 - val_loss: 2.6627e-04 - val_mean_absolute_error: 0.0128
# Epoch 105/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9411e-04 - mean_absolute_error: 0.0140 - val_loss: 4.3993e-04 - val_mean_absolute_error: 0.0158
# Epoch 106/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8554e-04 - mean_absolute_error: 0.0135 - val_loss: 7.1741e-04 - val_mean_absolute_error: 0.0225
# Epoch 107/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3105e-04 - mean_absolute_error: 0.0155 - val_loss: 2.3828e-04 - val_mean_absolute_error: 0.0117
# Epoch 108/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9039e-04 - mean_absolute_error: 0.0159 - val_loss: 2.2016e-04 - val_mean_absolute_error: 0.0105
# Epoch 109/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3670e-04 - mean_absolute_error: 0.0123 - val_loss: 2.1621e-04 - val_mean_absolute_error: 0.0105
# Epoch 110/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9422e-04 - mean_absolute_error: 0.0137 - val_loss: 2.3208e-04 - val_mean_absolute_error: 0.0103
# Epoch 111/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4281e-04 - mean_absolute_error: 0.0127 - val_loss: 2.1781e-04 - val_mean_absolute_error: 0.0107
# Epoch 112/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3474e-04 - mean_absolute_error: 0.0128 - val_loss: 2.1556e-04 - val_mean_absolute_error: 0.0101
# Epoch 113/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4905e-04 - mean_absolute_error: 0.0132 - val_loss: 2.2018e-04 - val_mean_absolute_error: 0.0109
# Epoch 114/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0271e-04 - mean_absolute_error: 0.0138 - val_loss: 2.3097e-04 - val_mean_absolute_error: 0.0104
# Epoch 115/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9057e-04 - mean_absolute_error: 0.0140 - val_loss: 4.8513e-04 - val_mean_absolute_error: 0.0175
# Epoch 116/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1496e-04 - mean_absolute_error: 0.0146 - val_loss: 2.4277e-04 - val_mean_absolute_error: 0.0105
# Epoch 117/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8464e-04 - mean_absolute_error: 0.0134 - val_loss: 3.3246e-04 - val_mean_absolute_error: 0.0131
# Epoch 118/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3658e-04 - mean_absolute_error: 0.0143 - val_loss: 2.4731e-04 - val_mean_absolute_error: 0.0108
# Epoch 119/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8426e-04 - mean_absolute_error: 0.0136 - val_loss: 2.1319e-04 - val_mean_absolute_error: 0.0104
# Epoch 120/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9519e-04 - mean_absolute_error: 0.0134 - val_loss: 2.4341e-04 - val_mean_absolute_error: 0.0106
# Epoch 121/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8724e-04 - mean_absolute_error: 0.0137 - val_loss: 7.9471e-04 - val_mean_absolute_error: 0.0242
# Epoch 122/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0969e-04 - mean_absolute_error: 0.0140 - val_loss: 9.4853e-04 - val_mean_absolute_error: 0.0270
# Epoch 123/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7107e-04 - mean_absolute_error: 0.0158 - val_loss: 3.8209e-04 - val_mean_absolute_error: 0.0146
# Epoch 124/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7917e-04 - mean_absolute_error: 0.0138 - val_loss: 5.4593e-04 - val_mean_absolute_error: 0.0190
# Epoch 125/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2368e-04 - mean_absolute_error: 0.0142 - val_loss: 8.6832e-04 - val_mean_absolute_error: 0.0256
# Epoch 126/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7075e-04 - mean_absolute_error: 0.0137 - val_loss: 3.8691e-04 - val_mean_absolute_error: 0.0148
# Epoch 127/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7210e-04 - mean_absolute_error: 0.0132 - val_loss: 3.1604e-04 - val_mean_absolute_error: 0.0126
# Epoch 128/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7679e-04 - mean_absolute_error: 0.0136 - val_loss: 2.1623e-04 - val_mean_absolute_error: 0.0101
# Epoch 129/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5108e-04 - mean_absolute_error: 0.0131 - val_loss: 2.4271e-04 - val_mean_absolute_error: 0.0106
# Epoch 130/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0447e-04 - mean_absolute_error: 0.0140 - val_loss: 2.5104e-04 - val_mean_absolute_error: 0.0108
# Epoch 131/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5695e-04 - mean_absolute_error: 0.0136 - val_loss: 3.5262e-04 - val_mean_absolute_error: 0.0138
# Epoch 132/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9134e-04 - mean_absolute_error: 0.0135 - val_loss: 3.4656e-04 - val_mean_absolute_error: 0.0136
# Epoch 133/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0440e-04 - mean_absolute_error: 0.0141 - val_loss: 2.1188e-04 - val_mean_absolute_error: 0.0102
# Epoch 134/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5248e-04 - mean_absolute_error: 0.0134 - val_loss: 3.3425e-04 - val_mean_absolute_error: 0.0132
# Epoch 135/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1795e-04 - mean_absolute_error: 0.0143 - val_loss: 2.3442e-04 - val_mean_absolute_error: 0.0104
# Epoch 136/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3756e-04 - mean_absolute_error: 0.0127 - val_loss: 3.1654e-04 - val_mean_absolute_error: 0.0127
# Epoch 137/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5233e-04 - mean_absolute_error: 0.0125 - val_loss: 2.1948e-04 - val_mean_absolute_error: 0.0109
# Epoch 138/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3354e-04 - mean_absolute_error: 0.0147 - val_loss: 2.4927e-04 - val_mean_absolute_error: 0.0106
# Epoch 139/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7094e-04 - mean_absolute_error: 0.0136 - val_loss: 2.9167e-04 - val_mean_absolute_error: 0.0119
# Epoch 140/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1282e-04 - mean_absolute_error: 0.0140 - val_loss: 2.2690e-04 - val_mean_absolute_error: 0.0112
# Epoch 141/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7497e-04 - mean_absolute_error: 0.0132 - val_loss: 5.5844e-04 - val_mean_absolute_error: 0.0210
# Epoch 142/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8657e-04 - mean_absolute_error: 0.0158 - val_loss: 2.3176e-04 - val_mean_absolute_error: 0.0115
# Epoch 143/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4404e-04 - mean_absolute_error: 0.0128 - val_loss: 3.0197e-04 - val_mean_absolute_error: 0.0122
# Epoch 144/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9556e-04 - mean_absolute_error: 0.0141 - val_loss: 2.3421e-04 - val_mean_absolute_error: 0.0104
# Epoch 145/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6733e-04 - mean_absolute_error: 0.0129 - val_loss: 2.4320e-04 - val_mean_absolute_error: 0.0119
# Epoch 146/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9830e-04 - mean_absolute_error: 0.0137 - val_loss: 2.9207e-04 - val_mean_absolute_error: 0.0120
# Epoch 147/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2787e-04 - mean_absolute_error: 0.0142 - val_loss: 2.2197e-04 - val_mean_absolute_error: 0.0102
# Epoch 148/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7775e-04 - mean_absolute_error: 0.0137 - val_loss: 2.3007e-04 - val_mean_absolute_error: 0.0114
# Epoch 149/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4408e-04 - mean_absolute_error: 0.0130 - val_loss: 2.3629e-04 - val_mean_absolute_error: 0.0105
# Epoch 150/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6740e-04 - mean_absolute_error: 0.0132 - val_loss: 3.5177e-04 - val_mean_absolute_error: 0.0138
# Epoch 151/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4527e-04 - mean_absolute_error: 0.0128 - val_loss: 3.7393e-04 - val_mean_absolute_error: 0.0145
# Epoch 152/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9729e-04 - mean_absolute_error: 0.0140 - val_loss: 3.0918e-04 - val_mean_absolute_error: 0.0124
# Epoch 153/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5195e-04 - mean_absolute_error: 0.0125 - val_loss: 2.7308e-04 - val_mean_absolute_error: 0.0114
# Epoch 154/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9042e-04 - mean_absolute_error: 0.0131 - val_loss: 2.2831e-04 - val_mean_absolute_error: 0.0104
# Epoch 155/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9350e-04 - mean_absolute_error: 0.0136 - val_loss: 2.3756e-04 - val_mean_absolute_error: 0.0105
# Epoch 156/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3701e-04 - mean_absolute_error: 0.0152 - val_loss: 3.1605e-04 - val_mean_absolute_error: 0.0143
# Epoch 157/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3398e-04 - mean_absolute_error: 0.0144 - val_loss: 2.3546e-04 - val_mean_absolute_error: 0.0104
# Epoch 158/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6901e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0011 - val_mean_absolute_error: 0.0295
# Epoch 159/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8152e-04 - mean_absolute_error: 0.0156 - val_loss: 5.8747e-04 - val_mean_absolute_error: 0.0199
# Epoch 160/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9811e-04 - mean_absolute_error: 0.0136 - val_loss: 2.1711e-04 - val_mean_absolute_error: 0.0107
# Epoch 161/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5738e-04 - mean_absolute_error: 0.0131 - val_loss: 5.8404e-04 - val_mean_absolute_error: 0.0198
# Epoch 162/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7386e-04 - mean_absolute_error: 0.0139 - val_loss: 2.1167e-04 - val_mean_absolute_error: 0.0102
# Epoch 163/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8286e-04 - mean_absolute_error: 0.0132 - val_loss: 3.3550e-04 - val_mean_absolute_error: 0.0150
# Epoch 164/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4447e-04 - mean_absolute_error: 0.0129 - val_loss: 2.7017e-04 - val_mean_absolute_error: 0.0113
# Epoch 165/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9979e-04 - mean_absolute_error: 0.0137 - val_loss: 2.3506e-04 - val_mean_absolute_error: 0.0103
# Epoch 166/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5585e-04 - mean_absolute_error: 0.0129 - val_loss: 4.4385e-04 - val_mean_absolute_error: 0.0165
# Epoch 167/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0156e-04 - mean_absolute_error: 0.0138 - val_loss: 3.0147e-04 - val_mean_absolute_error: 0.0139
# Epoch 168/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4210e-04 - mean_absolute_error: 0.0150 - val_loss: 2.6917e-04 - val_mean_absolute_error: 0.0128
# Epoch 169/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0605e-04 - mean_absolute_error: 0.0146 - val_loss: 2.4184e-04 - val_mean_absolute_error: 0.0106
# Epoch 170/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0153e-04 - mean_absolute_error: 0.0141 - val_loss: 2.5840e-04 - val_mean_absolute_error: 0.0110
# Epoch 171/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6350e-04 - mean_absolute_error: 0.0132 - val_loss: 2.1485e-04 - val_mean_absolute_error: 0.0106
# Epoch 172/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2348e-04 - mean_absolute_error: 0.0127 - val_loss: 2.4946e-04 - val_mean_absolute_error: 0.0109
# Epoch 173/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3950e-04 - mean_absolute_error: 0.0151 - val_loss: 2.3837e-04 - val_mean_absolute_error: 0.0117
# Epoch 174/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8155e-04 - mean_absolute_error: 0.0137 - val_loss: 2.6905e-04 - val_mean_absolute_error: 0.0113
# Epoch 175/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5474e-04 - mean_absolute_error: 0.0130 - val_loss: 2.5316e-04 - val_mean_absolute_error: 0.0108
# Epoch 176/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6481e-04 - mean_absolute_error: 0.0131 - val_loss: 2.3885e-04 - val_mean_absolute_error: 0.0105
# Epoch 177/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6041e-04 - mean_absolute_error: 0.0134 - val_loss: 2.4383e-04 - val_mean_absolute_error: 0.0106
# Epoch 178/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7792e-04 - mean_absolute_error: 0.0135 - val_loss: 2.4990e-04 - val_mean_absolute_error: 0.0108
# Epoch 179/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7907e-04 - mean_absolute_error: 0.0135 - val_loss: 2.1267e-04 - val_mean_absolute_error: 0.0103
# Epoch 180/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7881e-04 - mean_absolute_error: 0.0139 - val_loss: 2.1425e-04 - val_mean_absolute_error: 0.0102
# Epoch 181/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1304e-04 - mean_absolute_error: 0.0142 - val_loss: 3.9437e-04 - val_mean_absolute_error: 0.0151
# Epoch 182/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1301e-04 - mean_absolute_error: 0.0140 - val_loss: 4.8809e-04 - val_mean_absolute_error: 0.0175
# Epoch 183/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5472e-04 - mean_absolute_error: 0.0129 - val_loss: 2.8343e-04 - val_mean_absolute_error: 0.0117
# Epoch 184/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7672e-04 - mean_absolute_error: 0.0136 - val_loss: 4.3250e-04 - val_mean_absolute_error: 0.0161
# Epoch 185/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6754e-04 - mean_absolute_error: 0.0129 - val_loss: 5.0575e-04 - val_mean_absolute_error: 0.0180
# Epoch 186/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6513e-04 - mean_absolute_error: 0.0132 - val_loss: 2.2640e-04 - val_mean_absolute_error: 0.0112
# Epoch 187/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7122e-04 - mean_absolute_error: 0.0135 - val_loss: 4.2387e-04 - val_mean_absolute_error: 0.0175
# Epoch 188/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6481e-04 - mean_absolute_error: 0.0155 - val_loss: 4.2195e-04 - val_mean_absolute_error: 0.0158
# Epoch 189/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7426e-04 - mean_absolute_error: 0.0132 - val_loss: 2.1845e-04 - val_mean_absolute_error: 0.0108
# Epoch 190/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8171e-04 - mean_absolute_error: 0.0135 - val_loss: 2.3940e-04 - val_mean_absolute_error: 0.0105
# Epoch 191/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7341e-04 - mean_absolute_error: 0.0136 - val_loss: 2.8595e-04 - val_mean_absolute_error: 0.0134
# Epoch 192/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6614e-04 - mean_absolute_error: 0.0130 - val_loss: 2.3698e-04 - val_mean_absolute_error: 0.0117
# Epoch 193/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7467e-04 - mean_absolute_error: 0.0132 - val_loss: 5.7348e-04 - val_mean_absolute_error: 0.0196
# Epoch 194/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2221e-04 - mean_absolute_error: 0.0147 - val_loss: 3.8555e-04 - val_mean_absolute_error: 0.0148
# Epoch 195/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8011e-04 - mean_absolute_error: 0.0134 - val_loss: 2.5890e-04 - val_mean_absolute_error: 0.0125
# Epoch 196/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9280e-04 - mean_absolute_error: 0.0142 - val_loss: 2.6877e-04 - val_mean_absolute_error: 0.0129
# Epoch 197/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8331e-04 - mean_absolute_error: 0.0134 - val_loss: 2.1465e-04 - val_mean_absolute_error: 0.0103
# Epoch 198/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7657e-04 - mean_absolute_error: 0.0141 - val_loss: 2.4703e-04 - val_mean_absolute_error: 0.0106
# Epoch 199/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6562e-04 - mean_absolute_error: 0.0135 - val_loss: 4.0900e-04 - val_mean_absolute_error: 0.0155
# Epoch 200/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6532e-04 - mean_absolute_error: 0.0132 - val_loss: 2.3745e-04 - val_mean_absolute_error: 0.0105

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2136e-04 - mean_absolute_error: 0.0102
# Test Loss: [0.0002374463656451553, 0.010469028726220131]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 114
# 125

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 491662.16536501836
# RMSE: 701.1862558300885
# MAE: 475.632110060307
# MAPE: 1.3510135035758393 %
#
# Model evalution on validate set
# MSE: 781979.7556534477
# RMSE: 884.296192264474
# MAE: 661.721535326087
# MAPE: 1.692658386019441 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
y_pred_30_days
# Out:
# array([[41418.016],
#        [41241.17 ],
#        [41476.543],
#        [41344.152],
#        [41412.246],
#        [41370.996],
#        [41394.41 ],
#        [41381.12 ],
#        [41388.758],
#        [41384.395],
#        [41386.9  ],
#        [41385.47 ],
#        [41386.285],
#        [41385.816],
#        [41386.082],
#        [41385.93 ],
#        [41386.02 ],
#        [41385.973],
#        [41385.996],
#        [41385.98 ],
#        [41385.992],
#        [41385.984],
#        [41385.99 ],
#        [41385.99 ],
#        [41385.99 ],
#        [41385.99 ],
#        [41385.99 ],
#        [41385.99 ],
#        [41385.99 ],
#        [41385.99 ],
#        [41385.99 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
