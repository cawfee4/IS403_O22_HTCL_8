# %% [markdown]
# # Model: GRU (Gated Recurrent Unit)  - Stock Token: CMG - Test/Train/Vaildation: 80/10/10
# - Dataset: 1313 rows x 7 columns (01/03/2019 - 31/05/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 726.36
# - MAE: 532.04
# - MAPE: 1.45 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

plt.style.use("default")

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 2  # 8 1 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830
# ...           ...
# 2024-05-27  59000
# 2024-05-28  62100
# 2024-05-29  60000
# 2024-05-30  59200
# 2024-05-31  60900
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((1039, 10), (1039,), (120, 10), (120,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(100),
        Dense(32, activation="relu"),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 100)            │        30,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,165 (133.46 KB)
#  Trainable params: 34,165 (133.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0202 - mean_absolute_error: 0.1051 - val_loss: 2.1951e-04 - val_mean_absolute_error: 0.0116
# Epoch 2/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7293e-04 - mean_absolute_error: 0.0193 - val_loss: 2.1105e-04 - val_mean_absolute_error: 0.0106
# Epoch 3/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9426e-04 - mean_absolute_error: 0.0116 - val_loss: 2.3258e-04 - val_mean_absolute_error: 0.0112
# Epoch 4/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5619e-04 - mean_absolute_error: 0.0110 - val_loss: 2.0887e-04 - val_mean_absolute_error: 0.0108
# Epoch 5/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5897e-04 - mean_absolute_error: 0.0113 - val_loss: 2.1009e-04 - val_mean_absolute_error: 0.0105
# Epoch 6/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8307e-04 - mean_absolute_error: 0.0116 - val_loss: 1.9549e-04 - val_mean_absolute_error: 0.0101
# Epoch 7/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6881e-04 - mean_absolute_error: 0.0113 - val_loss: 1.7751e-04 - val_mean_absolute_error: 0.0098
# Epoch 8/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3462e-04 - mean_absolute_error: 0.0111 - val_loss: 1.7373e-04 - val_mean_absolute_error: 0.0094
# Epoch 9/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9020e-04 - mean_absolute_error: 0.0121 - val_loss: 1.6148e-04 - val_mean_absolute_error: 0.0091
# Epoch 10/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5048e-04 - mean_absolute_error: 0.0109 - val_loss: 1.5542e-04 - val_mean_absolute_error: 0.0089
# Epoch 11/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1433e-04 - mean_absolute_error: 0.0101 - val_loss: 1.5395e-04 - val_mean_absolute_error: 0.0088
# Epoch 12/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3389e-04 - mean_absolute_error: 0.0105 - val_loss: 1.5682e-04 - val_mean_absolute_error: 0.0092
# Epoch 13/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9657e-04 - mean_absolute_error: 0.0104 - val_loss: 3.9638e-04 - val_mean_absolute_error: 0.0167
# Epoch 14/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6727e-04 - mean_absolute_error: 0.0117 - val_loss: 2.3931e-04 - val_mean_absolute_error: 0.0118
# Epoch 15/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2912e-04 - mean_absolute_error: 0.0108 - val_loss: 1.5744e-04 - val_mean_absolute_error: 0.0094
# Epoch 16/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5775e-04 - mean_absolute_error: 0.0114 - val_loss: 1.8665e-04 - val_mean_absolute_error: 0.0107
# Epoch 17/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0903e-04 - mean_absolute_error: 0.0101 - val_loss: 1.3423e-04 - val_mean_absolute_error: 0.0082
# Epoch 18/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0994e-04 - mean_absolute_error: 0.0102 - val_loss: 1.3072e-04 - val_mean_absolute_error: 0.0080
# Epoch 19/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8625e-04 - mean_absolute_error: 0.0091 - val_loss: 1.8027e-04 - val_mean_absolute_error: 0.0098
# Epoch 20/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6447e-04 - mean_absolute_error: 0.0089 - val_loss: 1.3189e-04 - val_mean_absolute_error: 0.0081
# Epoch 21/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1564e-04 - mean_absolute_error: 0.0104 - val_loss: 2.0406e-04 - val_mean_absolute_error: 0.0115
# Epoch 22/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8128e-04 - mean_absolute_error: 0.0093 - val_loss: 1.3855e-04 - val_mean_absolute_error: 0.0083
# Epoch 23/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5433e-04 - mean_absolute_error: 0.0087 - val_loss: 1.5962e-04 - val_mean_absolute_error: 0.0092
# Epoch 24/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8451e-04 - mean_absolute_error: 0.0090 - val_loss: 1.4870e-04 - val_mean_absolute_error: 0.0092
# Epoch 25/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9024e-04 - mean_absolute_error: 0.0097 - val_loss: 1.4750e-04 - val_mean_absolute_error: 0.0092
# Epoch 26/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0428e-04 - mean_absolute_error: 0.0096 - val_loss: 1.1440e-04 - val_mean_absolute_error: 0.0074
# Epoch 27/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9184e-04 - mean_absolute_error: 0.0096 - val_loss: 1.3282e-04 - val_mean_absolute_error: 0.0085
# Epoch 28/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0913e-04 - mean_absolute_error: 0.0099 - val_loss: 1.9256e-04 - val_mean_absolute_error: 0.0106
# Epoch 29/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7280e-04 - mean_absolute_error: 0.0091 - val_loss: 1.1553e-04 - val_mean_absolute_error: 0.0074
# Epoch 30/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7092e-04 - mean_absolute_error: 0.0089 - val_loss: 1.6737e-04 - val_mean_absolute_error: 0.0097
# Epoch 31/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7086e-04 - mean_absolute_error: 0.0089 - val_loss: 1.5913e-04 - val_mean_absolute_error: 0.0093
# Epoch 32/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8085e-04 - mean_absolute_error: 0.0095 - val_loss: 2.4981e-04 - val_mean_absolute_error: 0.0130
# Epoch 33/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7337e-04 - mean_absolute_error: 0.0092 - val_loss: 1.1762e-04 - val_mean_absolute_error: 0.0077
# Epoch 34/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6065e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2413e-04 - val_mean_absolute_error: 0.0080
# Epoch 35/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7602e-04 - mean_absolute_error: 0.0089 - val_loss: 1.5632e-04 - val_mean_absolute_error: 0.0093
# Epoch 36/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6245e-04 - mean_absolute_error: 0.0088 - val_loss: 1.0538e-04 - val_mean_absolute_error: 0.0071
# Epoch 37/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8991e-04 - mean_absolute_error: 0.0094 - val_loss: 1.4045e-04 - val_mean_absolute_error: 0.0089
# Epoch 38/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6464e-04 - mean_absolute_error: 0.0089 - val_loss: 1.6975e-04 - val_mean_absolute_error: 0.0099
# Epoch 39/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5163e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0566e-04 - val_mean_absolute_error: 0.0071
# Epoch 40/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6764e-04 - mean_absolute_error: 0.0093 - val_loss: 2.1354e-04 - val_mean_absolute_error: 0.0117
# Epoch 41/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6360e-04 - mean_absolute_error: 0.0088 - val_loss: 2.3791e-04 - val_mean_absolute_error: 0.0127
# Epoch 42/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8819e-04 - mean_absolute_error: 0.0100 - val_loss: 1.3984e-04 - val_mean_absolute_error: 0.0086
# Epoch 43/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6055e-04 - mean_absolute_error: 0.0087 - val_loss: 1.0685e-04 - val_mean_absolute_error: 0.0072
# Epoch 44/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7585e-04 - mean_absolute_error: 0.0097 - val_loss: 1.0956e-04 - val_mean_absolute_error: 0.0072
# Epoch 45/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5996e-04 - mean_absolute_error: 0.0087 - val_loss: 1.0429e-04 - val_mean_absolute_error: 0.0071
# Epoch 46/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4132e-04 - mean_absolute_error: 0.0082 - val_loss: 1.9657e-04 - val_mean_absolute_error: 0.0115
# Epoch 47/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8714e-04 - mean_absolute_error: 0.0099 - val_loss: 1.0910e-04 - val_mean_absolute_error: 0.0073
# Epoch 48/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5362e-04 - mean_absolute_error: 0.0085 - val_loss: 1.3487e-04 - val_mean_absolute_error: 0.0087
# Epoch 49/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5945e-04 - mean_absolute_error: 0.0089 - val_loss: 1.1100e-04 - val_mean_absolute_error: 0.0072
# Epoch 50/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7676e-04 - mean_absolute_error: 0.0092 - val_loss: 1.1306e-04 - val_mean_absolute_error: 0.0074
# Epoch 51/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6595e-04 - mean_absolute_error: 0.0088 - val_loss: 1.3344e-04 - val_mean_absolute_error: 0.0086
# Epoch 52/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5318e-04 - mean_absolute_error: 0.0088 - val_loss: 1.1121e-04 - val_mean_absolute_error: 0.0073
# Epoch 53/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4950e-04 - mean_absolute_error: 0.0085 - val_loss: 2.1800e-04 - val_mean_absolute_error: 0.0120
# Epoch 54/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5172e-04 - mean_absolute_error: 0.0086 - val_loss: 1.4017e-04 - val_mean_absolute_error: 0.0087
# Epoch 55/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5372e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0631e-04 - val_mean_absolute_error: 0.0071
# Epoch 56/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6060e-04 - mean_absolute_error: 0.0088 - val_loss: 1.1007e-04 - val_mean_absolute_error: 0.0072
# Epoch 57/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3917e-04 - mean_absolute_error: 0.0081 - val_loss: 1.4876e-04 - val_mean_absolute_error: 0.0091
# Epoch 58/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5395e-04 - mean_absolute_error: 0.0085 - val_loss: 1.5654e-04 - val_mean_absolute_error: 0.0094
# Epoch 59/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4458e-04 - mean_absolute_error: 0.0083 - val_loss: 1.0065e-04 - val_mean_absolute_error: 0.0071
# Epoch 60/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5203e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0071e-04 - val_mean_absolute_error: 0.0070
# Epoch 61/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6031e-04 - mean_absolute_error: 0.0088 - val_loss: 1.6869e-04 - val_mean_absolute_error: 0.0099
# Epoch 62/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3710e-04 - mean_absolute_error: 0.0082 - val_loss: 1.0279e-04 - val_mean_absolute_error: 0.0071
# Epoch 63/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9265e-04 - mean_absolute_error: 0.0104 - val_loss: 7.3495e-04 - val_mean_absolute_error: 0.0255
# Epoch 64/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3223e-04 - mean_absolute_error: 0.0112 - val_loss: 1.0368e-04 - val_mean_absolute_error: 0.0072
# Epoch 65/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8954e-04 - mean_absolute_error: 0.0100 - val_loss: 1.0182e-04 - val_mean_absolute_error: 0.0070
# Epoch 66/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7239e-04 - mean_absolute_error: 0.0095 - val_loss: 1.6556e-04 - val_mean_absolute_error: 0.0102
# Epoch 67/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5775e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2967e-04 - val_mean_absolute_error: 0.0082
# Epoch 68/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4553e-04 - mean_absolute_error: 0.0083 - val_loss: 1.8663e-04 - val_mean_absolute_error: 0.0108
# Epoch 69/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4842e-04 - mean_absolute_error: 0.0081 - val_loss: 1.0454e-04 - val_mean_absolute_error: 0.0073
# Epoch 70/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7814e-04 - mean_absolute_error: 0.0093 - val_loss: 1.3006e-04 - val_mean_absolute_error: 0.0082
# Epoch 71/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3905e-04 - mean_absolute_error: 0.0080 - val_loss: 1.0775e-04 - val_mean_absolute_error: 0.0072
# Epoch 72/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4215e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3769e-04 - val_mean_absolute_error: 0.0086
# Epoch 73/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5122e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2241e-04 - val_mean_absolute_error: 0.0079
# Epoch 74/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4736e-04 - mean_absolute_error: 0.0082 - val_loss: 1.8058e-04 - val_mean_absolute_error: 0.0109
# Epoch 75/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5942e-04 - mean_absolute_error: 0.0090 - val_loss: 9.8274e-05 - val_mean_absolute_error: 0.0070
# Epoch 76/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5646e-04 - mean_absolute_error: 0.0088 - val_loss: 1.0638e-04 - val_mean_absolute_error: 0.0072
# Epoch 77/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4343e-04 - mean_absolute_error: 0.0081 - val_loss: 1.6047e-04 - val_mean_absolute_error: 0.0097
# Epoch 78/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4524e-04 - mean_absolute_error: 0.0084 - val_loss: 2.3115e-04 - val_mean_absolute_error: 0.0125
# Epoch 79/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7596e-04 - mean_absolute_error: 0.0095 - val_loss: 1.3377e-04 - val_mean_absolute_error: 0.0084
# Epoch 80/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5797e-04 - mean_absolute_error: 0.0087 - val_loss: 1.0086e-04 - val_mean_absolute_error: 0.0072
# Epoch 81/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6853e-04 - mean_absolute_error: 0.0093 - val_loss: 4.1672e-04 - val_mean_absolute_error: 0.0183
# Epoch 82/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7024e-04 - mean_absolute_error: 0.0092 - val_loss: 2.5327e-04 - val_mean_absolute_error: 0.0134
# Epoch 83/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4271e-04 - mean_absolute_error: 0.0083 - val_loss: 1.0116e-04 - val_mean_absolute_error: 0.0070
# Epoch 84/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6240e-04 - mean_absolute_error: 0.0092 - val_loss: 1.1269e-04 - val_mean_absolute_error: 0.0078
# Epoch 85/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6147e-04 - mean_absolute_error: 0.0088 - val_loss: 1.7478e-04 - val_mean_absolute_error: 0.0103
# Epoch 86/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1666e-04 - mean_absolute_error: 0.0075 - val_loss: 9.8371e-05 - val_mean_absolute_error: 0.0070
# Epoch 87/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7653e-04 - mean_absolute_error: 0.0092 - val_loss: 2.2570e-04 - val_mean_absolute_error: 0.0123
# Epoch 88/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7900e-04 - mean_absolute_error: 0.0091 - val_loss: 1.0980e-04 - val_mean_absolute_error: 0.0074
# Epoch 89/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3791e-04 - mean_absolute_error: 0.0080 - val_loss: 1.4232e-04 - val_mean_absolute_error: 0.0088
# Epoch 90/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5264e-04 - mean_absolute_error: 0.0085 - val_loss: 9.9135e-05 - val_mean_absolute_error: 0.0071
# Epoch 91/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5138e-04 - mean_absolute_error: 0.0085 - val_loss: 1.3266e-04 - val_mean_absolute_error: 0.0084
# Epoch 92/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3629e-04 - mean_absolute_error: 0.0082 - val_loss: 1.0817e-04 - val_mean_absolute_error: 0.0073
# Epoch 93/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5351e-04 - mean_absolute_error: 0.0087 - val_loss: 2.7157e-04 - val_mean_absolute_error: 0.0140
# Epoch 94/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4264e-04 - mean_absolute_error: 0.0086 - val_loss: 1.1875e-04 - val_mean_absolute_error: 0.0078
# Epoch 95/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6608e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0382e-04 - val_mean_absolute_error: 0.0071
# Epoch 96/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6354e-04 - mean_absolute_error: 0.0089 - val_loss: 1.6198e-04 - val_mean_absolute_error: 0.0098
# Epoch 97/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5047e-04 - mean_absolute_error: 0.0089 - val_loss: 1.9753e-04 - val_mean_absolute_error: 0.0113
# Epoch 98/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3381e-04 - mean_absolute_error: 0.0080 - val_loss: 1.8696e-04 - val_mean_absolute_error: 0.0112
# Epoch 99/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7459e-04 - mean_absolute_error: 0.0095 - val_loss: 1.7745e-04 - val_mean_absolute_error: 0.0105
# Epoch 100/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6367e-04 - mean_absolute_error: 0.0091 - val_loss: 1.0709e-04 - val_mean_absolute_error: 0.0075
# Epoch 101/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5431e-04 - mean_absolute_error: 0.0088 - val_loss: 9.7366e-05 - val_mean_absolute_error: 0.0070
# Epoch 102/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8094e-04 - mean_absolute_error: 0.0097 - val_loss: 1.0817e-04 - val_mean_absolute_error: 0.0073
# Epoch 103/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5800e-04 - mean_absolute_error: 0.0085 - val_loss: 1.1104e-04 - val_mean_absolute_error: 0.0075
# Epoch 104/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3820e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2433e-04 - val_mean_absolute_error: 0.0080
# Epoch 105/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5418e-04 - mean_absolute_error: 0.0086 - val_loss: 1.1579e-04 - val_mean_absolute_error: 0.0077
# Epoch 106/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5841e-04 - mean_absolute_error: 0.0087 - val_loss: 1.6692e-04 - val_mean_absolute_error: 0.0100
# Epoch 107/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4302e-04 - mean_absolute_error: 0.0085 - val_loss: 1.6653e-04 - val_mean_absolute_error: 0.0100
# Epoch 108/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4629e-04 - mean_absolute_error: 0.0087 - val_loss: 1.0369e-04 - val_mean_absolute_error: 0.0073
# Epoch 109/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7599e-04 - mean_absolute_error: 0.0095 - val_loss: 1.0143e-04 - val_mean_absolute_error: 0.0072
# Epoch 110/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5184e-04 - mean_absolute_error: 0.0089 - val_loss: 1.1512e-04 - val_mean_absolute_error: 0.0076
# Epoch 111/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5996e-04 - mean_absolute_error: 0.0087 - val_loss: 2.8868e-04 - val_mean_absolute_error: 0.0146
# Epoch 112/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7118e-04 - mean_absolute_error: 0.0089 - val_loss: 1.1454e-04 - val_mean_absolute_error: 0.0076
# Epoch 113/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4380e-04 - mean_absolute_error: 0.0083 - val_loss: 1.4129e-04 - val_mean_absolute_error: 0.0088
# Epoch 114/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3754e-04 - mean_absolute_error: 0.0080 - val_loss: 1.0387e-04 - val_mean_absolute_error: 0.0071
# Epoch 115/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3714e-04 - mean_absolute_error: 0.0082 - val_loss: 1.0478e-04 - val_mean_absolute_error: 0.0074
# Epoch 116/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6128e-04 - mean_absolute_error: 0.0090 - val_loss: 9.8892e-05 - val_mean_absolute_error: 0.0070
# Epoch 117/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4877e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0714e-04 - val_mean_absolute_error: 0.0073
# Epoch 118/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3515e-04 - mean_absolute_error: 0.0081 - val_loss: 1.0468e-04 - val_mean_absolute_error: 0.0072
# Epoch 119/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7029e-04 - mean_absolute_error: 0.0092 - val_loss: 9.9665e-05 - val_mean_absolute_error: 0.0071
# Epoch 120/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5473e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0756e-04 - val_mean_absolute_error: 0.0075
# Epoch 121/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6130e-04 - mean_absolute_error: 0.0087 - val_loss: 3.2414e-04 - val_mean_absolute_error: 0.0157
# Epoch 122/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6479e-04 - mean_absolute_error: 0.0091 - val_loss: 1.0330e-04 - val_mean_absolute_error: 0.0073
# Epoch 123/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5706e-04 - mean_absolute_error: 0.0095 - val_loss: 3.0407e-04 - val_mean_absolute_error: 0.0151
# Epoch 124/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5118e-04 - mean_absolute_error: 0.0089 - val_loss: 9.8820e-05 - val_mean_absolute_error: 0.0070
# Epoch 125/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6803e-04 - mean_absolute_error: 0.0094 - val_loss: 2.2030e-04 - val_mean_absolute_error: 0.0122
# Epoch 126/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4425e-04 - mean_absolute_error: 0.0083 - val_loss: 1.1053e-04 - val_mean_absolute_error: 0.0074
# Epoch 127/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5143e-04 - mean_absolute_error: 0.0084 - val_loss: 2.4827e-04 - val_mean_absolute_error: 0.0132
# Epoch 128/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5441e-04 - mean_absolute_error: 0.0086 - val_loss: 2.5089e-04 - val_mean_absolute_error: 0.0133
# Epoch 129/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4184e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0116e-04 - val_mean_absolute_error: 0.0072
# Epoch 130/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3298e-04 - mean_absolute_error: 0.0081 - val_loss: 1.7058e-04 - val_mean_absolute_error: 0.0101
# Epoch 131/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5576e-04 - mean_absolute_error: 0.0086 - val_loss: 1.3764e-04 - val_mean_absolute_error: 0.0086
# Epoch 132/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7601e-04 - mean_absolute_error: 0.0094 - val_loss: 1.0076e-04 - val_mean_absolute_error: 0.0072
# Epoch 133/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5485e-04 - mean_absolute_error: 0.0089 - val_loss: 1.5526e-04 - val_mean_absolute_error: 0.0098
# Epoch 134/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4770e-04 - mean_absolute_error: 0.0090 - val_loss: 1.9330e-04 - val_mean_absolute_error: 0.0111
# Epoch 135/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3778e-04 - mean_absolute_error: 0.0081 - val_loss: 1.4169e-04 - val_mean_absolute_error: 0.0088
# Epoch 136/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7080e-04 - mean_absolute_error: 0.0099 - val_loss: 1.0577e-04 - val_mean_absolute_error: 0.0074
# Epoch 137/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7318e-04 - mean_absolute_error: 0.0094 - val_loss: 1.2027e-04 - val_mean_absolute_error: 0.0078
# Epoch 138/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5717e-04 - mean_absolute_error: 0.0090 - val_loss: 3.0185e-04 - val_mean_absolute_error: 0.0150
# Epoch 139/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5368e-04 - mean_absolute_error: 0.0088 - val_loss: 1.0208e-04 - val_mean_absolute_error: 0.0072
# Epoch 140/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3265e-04 - mean_absolute_error: 0.0081 - val_loss: 9.8358e-05 - val_mean_absolute_error: 0.0070
# Epoch 141/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5851e-04 - mean_absolute_error: 0.0091 - val_loss: 1.0650e-04 - val_mean_absolute_error: 0.0073
# Epoch 142/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4977e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2336e-04 - val_mean_absolute_error: 0.0080
# Epoch 143/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3926e-04 - mean_absolute_error: 0.0081 - val_loss: 1.0684e-04 - val_mean_absolute_error: 0.0075
# Epoch 144/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5724e-04 - mean_absolute_error: 0.0087 - val_loss: 1.3313e-04 - val_mean_absolute_error: 0.0084
# Epoch 145/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3292e-04 - mean_absolute_error: 0.0077 - val_loss: 1.2743e-04 - val_mean_absolute_error: 0.0085
# Epoch 146/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6599e-04 - mean_absolute_error: 0.0095 - val_loss: 1.0286e-04 - val_mean_absolute_error: 0.0073
# Epoch 147/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5390e-04 - mean_absolute_error: 0.0091 - val_loss: 1.8496e-04 - val_mean_absolute_error: 0.0107
# Epoch 148/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3817e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2499e-04 - val_mean_absolute_error: 0.0080
# Epoch 149/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4586e-04 - mean_absolute_error: 0.0086 - val_loss: 9.8980e-05 - val_mean_absolute_error: 0.0071
# Epoch 150/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7110e-04 - mean_absolute_error: 0.0093 - val_loss: 1.7139e-04 - val_mean_absolute_error: 0.0105
# Epoch 151/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0640e-04 - mean_absolute_error: 0.0109 - val_loss: 1.4860e-04 - val_mean_absolute_error: 0.0091
# Epoch 152/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5383e-04 - mean_absolute_error: 0.0087 - val_loss: 1.5652e-04 - val_mean_absolute_error: 0.0095
# Epoch 153/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6053e-04 - mean_absolute_error: 0.0091 - val_loss: 9.8453e-05 - val_mean_absolute_error: 0.0070
# Epoch 154/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3609e-04 - mean_absolute_error: 0.0081 - val_loss: 1.0739e-04 - val_mean_absolute_error: 0.0075
# Epoch 155/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6088e-04 - mean_absolute_error: 0.0089 - val_loss: 1.7772e-04 - val_mean_absolute_error: 0.0105
# Epoch 156/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4972e-04 - mean_absolute_error: 0.0087 - val_loss: 1.0903e-04 - val_mean_absolute_error: 0.0073
# Epoch 157/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5421e-04 - mean_absolute_error: 0.0086 - val_loss: 4.4937e-04 - val_mean_absolute_error: 0.0191
# Epoch 158/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6005e-04 - mean_absolute_error: 0.0094 - val_loss: 9.7676e-05 - val_mean_absolute_error: 0.0070
# Epoch 159/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3757e-04 - mean_absolute_error: 0.0081 - val_loss: 1.0218e-04 - val_mean_absolute_error: 0.0071
# Epoch 160/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5053e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0493e-04 - val_mean_absolute_error: 0.0074
# Epoch 161/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2946e-04 - mean_absolute_error: 0.0082 - val_loss: 9.8164e-05 - val_mean_absolute_error: 0.0070
# Epoch 162/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5016e-04 - mean_absolute_error: 0.0085 - val_loss: 2.2589e-04 - val_mean_absolute_error: 0.0124
# Epoch 163/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4451e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0556e-04 - val_mean_absolute_error: 0.0072
# Epoch 164/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5760e-04 - mean_absolute_error: 0.0089 - val_loss: 2.5735e-04 - val_mean_absolute_error: 0.0135
# Epoch 165/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4564e-04 - mean_absolute_error: 0.0083 - val_loss: 2.0305e-04 - val_mean_absolute_error: 0.0115
# Epoch 166/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5475e-04 - mean_absolute_error: 0.0087 - val_loss: 1.0149e-04 - val_mean_absolute_error: 0.0071
# Epoch 167/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4645e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2144e-04 - val_mean_absolute_error: 0.0079
# Epoch 168/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3254e-04 - mean_absolute_error: 0.0079 - val_loss: 1.1430e-04 - val_mean_absolute_error: 0.0076
# Epoch 169/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4261e-04 - mean_absolute_error: 0.0083 - val_loss: 1.0761e-04 - val_mean_absolute_error: 0.0075
# Epoch 170/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3035e-04 - mean_absolute_error: 0.0081 - val_loss: 1.3962e-04 - val_mean_absolute_error: 0.0091
# Epoch 171/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8126e-04 - mean_absolute_error: 0.0095 - val_loss: 9.7953e-05 - val_mean_absolute_error: 0.0070
# Epoch 172/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3957e-04 - mean_absolute_error: 0.0082 - val_loss: 9.8243e-05 - val_mean_absolute_error: 0.0070
# Epoch 173/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4338e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0065e-04 - val_mean_absolute_error: 0.0072
# Epoch 174/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5965e-04 - mean_absolute_error: 0.0093 - val_loss: 3.3427e-04 - val_mean_absolute_error: 0.0160
# Epoch 175/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7250e-04 - mean_absolute_error: 0.0098 - val_loss: 2.1642e-04 - val_mean_absolute_error: 0.0124
# Epoch 176/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5117e-04 - mean_absolute_error: 0.0121 - val_loss: 1.2475e-04 - val_mean_absolute_error: 0.0080
# Epoch 177/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8793e-04 - mean_absolute_error: 0.0103 - val_loss: 1.1186e-04 - val_mean_absolute_error: 0.0075
# Epoch 178/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5265e-04 - mean_absolute_error: 0.0084 - val_loss: 3.2381e-04 - val_mean_absolute_error: 0.0157
# Epoch 179/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4609e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0530e-04 - val_mean_absolute_error: 0.0072
# Epoch 180/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6029e-04 - mean_absolute_error: 0.0092 - val_loss: 1.3391e-04 - val_mean_absolute_error: 0.0085
# Epoch 181/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6424e-04 - mean_absolute_error: 0.0089 - val_loss: 1.4901e-04 - val_mean_absolute_error: 0.0092
# Epoch 182/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4952e-04 - mean_absolute_error: 0.0083 - val_loss: 1.1568e-04 - val_mean_absolute_error: 0.0080
# Epoch 183/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0904e-04 - mean_absolute_error: 0.0104 - val_loss: 2.9011e-04 - val_mean_absolute_error: 0.0146
# Epoch 184/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7085e-04 - mean_absolute_error: 0.0090 - val_loss: 1.0025e-04 - val_mean_absolute_error: 0.0071
# Epoch 185/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3868e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3510e-04 - val_mean_absolute_error: 0.0085
# Epoch 186/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2843e-04 - mean_absolute_error: 0.0078 - val_loss: 9.7533e-05 - val_mean_absolute_error: 0.0070
# Epoch 187/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7957e-04 - mean_absolute_error: 0.0098 - val_loss: 2.0690e-04 - val_mean_absolute_error: 0.0116
# Epoch 188/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2188e-04 - mean_absolute_error: 0.0076 - val_loss: 1.0491e-04 - val_mean_absolute_error: 0.0074
# Epoch 189/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5483e-04 - mean_absolute_error: 0.0087 - val_loss: 1.1855e-04 - val_mean_absolute_error: 0.0078
# Epoch 190/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4177e-04 - mean_absolute_error: 0.0082 - val_loss: 1.1338e-04 - val_mean_absolute_error: 0.0076
# Epoch 191/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4668e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0489e-04 - val_mean_absolute_error: 0.0072
# Epoch 192/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3807e-04 - mean_absolute_error: 0.0081 - val_loss: 3.6745e-04 - val_mean_absolute_error: 0.0170
# Epoch 193/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6517e-04 - mean_absolute_error: 0.0089 - val_loss: 2.3614e-04 - val_mean_absolute_error: 0.0127
# Epoch 194/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6558e-04 - mean_absolute_error: 0.0092 - val_loss: 1.1901e-04 - val_mean_absolute_error: 0.0078
# Epoch 195/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3582e-04 - mean_absolute_error: 0.0081 - val_loss: 1.0158e-04 - val_mean_absolute_error: 0.0071
# Epoch 196/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4834e-04 - mean_absolute_error: 0.0085 - val_loss: 1.3110e-04 - val_mean_absolute_error: 0.0083
# Epoch 197/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4457e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0442e-04 - val_mean_absolute_error: 0.0072
# Epoch 198/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3518e-04 - mean_absolute_error: 0.0078 - val_loss: 1.1030e-04 - val_mean_absolute_error: 0.0074
# Epoch 199/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5851e-04 - mean_absolute_error: 0.0087 - val_loss: 1.9100e-04 - val_mean_absolute_error: 0.0110
# Epoch 200/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5433e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0415e-04 - val_mean_absolute_error: 0.0073

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1004e-04 - mean_absolute_error: 0.0075
# Test Loss: [0.00010414584539830685, 0.007347611710429192]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 120
# 131

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 527602.1847205798
# RMSE: 726.3622957729701
# MAE: 532.0423014322917
# MAPE: 1.4498169906237206 %
#
# Model evalution on validate set
# MSE: 3826369.9314538627
# RMSE: 1956.1109200282744
# MAE: 1243.9015689566115
# MAPE: 2.603051461726956 %

# %% [markdown]
# ## 4. Forecast the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
y_pred_30_days
# Out:
# array([[61253.02 ],
#        [60925.996],
#        [61399.145],
#        [61123.164],
#        [61272.34 ],
#        [61166.38 ],
#        [61228.855],
#        [61189.79 ],
#        [61214.48 ],
#        [61199.277],
#        [61208.8  ],
#        [61202.875],
#        [61206.56 ],
#        [61204.258],
#        [61205.69 ],
#        [61204.797],
#        [61205.355],
#        [61205.004],
#        [61205.22 ],
#        [61205.086],
#        [61205.168],
#        [61205.117],
#        [61205.15 ],
#        [61205.137],
#        [61205.137],
#        [61205.137],
#        [61205.137],
#        [61205.137],
#        [61205.137],
#        [61205.137],
#        [61205.137]], dtype=float32)

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(16, 9))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
