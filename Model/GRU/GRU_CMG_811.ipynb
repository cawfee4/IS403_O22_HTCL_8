# %% [markdown]
# # Model: GRU (Gated Recurrent Unit)  - Stock Token: CMG - Test/Train/Vaildation: 80/10/10
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 701.19
# - MAE: 475.63
# - MAPE: 1.35 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 2  # 8 1 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830
# ...           ...
# 2024-05-27  59000
# 2024-05-28  62100
# 2024-05-29  60000
# 2024-05-30  59200
# 2024-05-31  60900
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((1039, 10), (1039,), (120, 10), (120,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(100),
        Dense(32, activation="relu"),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 100)            │        30,900 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 32)             │         3,232 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34,165 (133.46 KB)
#  Trainable params: 34,165 (133.46 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 0.0229 - mean_absolute_error: 0.1006 - val_loss: 3.1376e-04 - val_mean_absolute_error: 0.0143
# Epoch 2/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.2519e-04 - mean_absolute_error: 0.0128 - val_loss: 2.6300e-04 - val_mean_absolute_error: 0.0123
# Epoch 3/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.3454e-04 - mean_absolute_error: 0.0105 - val_loss: 2.7214e-04 - val_mean_absolute_error: 0.0126
# Epoch 4/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.4397e-04 - mean_absolute_error: 0.0107 - val_loss: 1.9700e-04 - val_mean_absolute_error: 0.0108
# Epoch 5/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.4101e-04 - mean_absolute_error: 0.0108 - val_loss: 1.5839e-04 - val_mean_absolute_error: 0.0089
# Epoch 6/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.2903e-04 - mean_absolute_error: 0.0107 - val_loss: 1.4751e-04 - val_mean_absolute_error: 0.0088
# Epoch 7/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.0661e-04 - mean_absolute_error: 0.0101 - val_loss: 1.7297e-04 - val_mean_absolute_error: 0.0094
# Epoch 8/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.0118e-04 - mean_absolute_error: 0.0098 - val_loss: 1.3438e-04 - val_mean_absolute_error: 0.0082
# Epoch 9/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.3035e-04 - mean_absolute_error: 0.0109 - val_loss: 3.9911e-04 - val_mean_absolute_error: 0.0178
# Epoch 10/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.4513e-04 - mean_absolute_error: 0.0137 - val_loss: 1.3429e-04 - val_mean_absolute_error: 0.0083
# Epoch 11/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.8898e-04 - mean_absolute_error: 0.0093 - val_loss: 1.2912e-04 - val_mean_absolute_error: 0.0080
# Epoch 12/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.8928e-04 - mean_absolute_error: 0.0094 - val_loss: 1.2214e-04 - val_mean_absolute_error: 0.0077
# Epoch 13/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.0460e-04 - mean_absolute_error: 0.0100 - val_loss: 1.3009e-04 - val_mean_absolute_error: 0.0080
# Epoch 14/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.0396e-04 - mean_absolute_error: 0.0100 - val_loss: 1.2378e-04 - val_mean_absolute_error: 0.0078
# Epoch 15/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.8906e-04 - mean_absolute_error: 0.0094 - val_loss: 1.6036e-04 - val_mean_absolute_error: 0.0093
# Epoch 16/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7870e-04 - mean_absolute_error: 0.0091 - val_loss: 1.8158e-04 - val_mean_absolute_error: 0.0101
# Epoch 17/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7620e-04 - mean_absolute_error: 0.0094 - val_loss: 1.9334e-04 - val_mean_absolute_error: 0.0107
# Epoch 18/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.0254e-04 - mean_absolute_error: 0.0100 - val_loss: 1.2295e-04 - val_mean_absolute_error: 0.0080
# Epoch 19/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.9651e-04 - mean_absolute_error: 0.0099 - val_loss: 2.5125e-04 - val_mean_absolute_error: 0.0129
# Epoch 20/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.8981e-04 - mean_absolute_error: 0.0097 - val_loss: 1.2539e-04 - val_mean_absolute_error: 0.0081
# Epoch 21/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.8025e-04 - mean_absolute_error: 0.0091 - val_loss: 1.2834e-04 - val_mean_absolute_error: 0.0083
# Epoch 22/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.7731e-04 - mean_absolute_error: 0.0093 - val_loss: 1.0860e-04 - val_mean_absolute_error: 0.0072
# Epoch 23/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.7471e-04 - mean_absolute_error: 0.0092 - val_loss: 1.0875e-04 - val_mean_absolute_error: 0.0071
# Epoch 24/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.9707e-04 - mean_absolute_error: 0.0100 - val_loss: 1.3621e-04 - val_mean_absolute_error: 0.0084
# Epoch 25/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4801e-04 - mean_absolute_error: 0.0084 - val_loss: 1.6426e-04 - val_mean_absolute_error: 0.0096
# Epoch 26/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.0265e-04 - mean_absolute_error: 0.0102 - val_loss: 1.0553e-04 - val_mean_absolute_error: 0.0071
# Epoch 27/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.9040e-04 - mean_absolute_error: 0.0096 - val_loss: 1.9568e-04 - val_mean_absolute_error: 0.0115
# Epoch 28/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.9872e-04 - mean_absolute_error: 0.0105 - val_loss: 1.8556e-04 - val_mean_absolute_error: 0.0106
# Epoch 29/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.3536e-04 - mean_absolute_error: 0.0113 - val_loss: 2.3651e-04 - val_mean_absolute_error: 0.0125
# Epoch 30/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.7346e-04 - mean_absolute_error: 0.0095 - val_loss: 1.1237e-04 - val_mean_absolute_error: 0.0074
# Epoch 31/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.6152e-04 - mean_absolute_error: 0.0088 - val_loss: 2.0095e-04 - val_mean_absolute_error: 0.0112
# Epoch 32/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7469e-04 - mean_absolute_error: 0.0092 - val_loss: 1.4529e-04 - val_mean_absolute_error: 0.0088
# Epoch 33/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.6342e-04 - mean_absolute_error: 0.0089 - val_loss: 1.2029e-04 - val_mean_absolute_error: 0.0079
# Epoch 34/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.8153e-04 - mean_absolute_error: 0.0096 - val_loss: 1.1449e-04 - val_mean_absolute_error: 0.0076
# Epoch 35/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4181e-04 - mean_absolute_error: 0.0082 - val_loss: 1.1755e-04 - val_mean_absolute_error: 0.0078
# Epoch 36/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6221e-04 - mean_absolute_error: 0.0091 - val_loss: 1.4278e-04 - val_mean_absolute_error: 0.0091
# Epoch 37/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5134e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0407e-04 - val_mean_absolute_error: 0.0070
# Epoch 38/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.7394e-04 - mean_absolute_error: 0.0092 - val_loss: 1.0403e-04 - val_mean_absolute_error: 0.0070
# Epoch 39/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6075e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0974e-04 - val_mean_absolute_error: 0.0072
# Epoch 40/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5520e-04 - mean_absolute_error: 0.0085 - val_loss: 1.1349e-04 - val_mean_absolute_error: 0.0073
# Epoch 41/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.7430e-04 - mean_absolute_error: 0.0094 - val_loss: 1.9174e-04 - val_mean_absolute_error: 0.0109
# Epoch 42/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.8136e-04 - mean_absolute_error: 0.0092 - val_loss: 1.0463e-04 - val_mean_absolute_error: 0.0070
# Epoch 43/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.7265e-04 - mean_absolute_error: 0.0095 - val_loss: 1.4473e-04 - val_mean_absolute_error: 0.0089
# Epoch 44/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.7660e-04 - mean_absolute_error: 0.0097 - val_loss: 1.0091e-04 - val_mean_absolute_error: 0.0070
# Epoch 45/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5353e-04 - mean_absolute_error: 0.0086 - val_loss: 1.4064e-04 - val_mean_absolute_error: 0.0087
# Epoch 46/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8629e-04 - mean_absolute_error: 0.0099 - val_loss: 1.0013e-04 - val_mean_absolute_error: 0.0070
# Epoch 47/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6540e-04 - mean_absolute_error: 0.0090 - val_loss: 1.0141e-04 - val_mean_absolute_error: 0.0070
# Epoch 48/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6685e-04 - mean_absolute_error: 0.0092 - val_loss: 1.0070e-04 - val_mean_absolute_error: 0.0070
# Epoch 49/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.4392e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2057e-04 - val_mean_absolute_error: 0.0077
# Epoch 50/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.6443e-04 - mean_absolute_error: 0.0091 - val_loss: 1.0201e-04 - val_mean_absolute_error: 0.0071
# Epoch 51/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.6427e-04 - mean_absolute_error: 0.0090 - val_loss: 3.1552e-04 - val_mean_absolute_error: 0.0155
# Epoch 52/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.5561e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0698e-04 - val_mean_absolute_error: 0.0072
# Epoch 53/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5844e-04 - mean_absolute_error: 0.0085 - val_loss: 1.5980e-04 - val_mean_absolute_error: 0.0096
# Epoch 54/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6262e-04 - mean_absolute_error: 0.0091 - val_loss: 1.8713e-04 - val_mean_absolute_error: 0.0108
# Epoch 55/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.4827e-04 - mean_absolute_error: 0.0084 - val_loss: 9.9007e-05 - val_mean_absolute_error: 0.0071
# Epoch 56/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5930e-04 - mean_absolute_error: 0.0090 - val_loss: 1.0214e-04 - val_mean_absolute_error: 0.0070
# Epoch 57/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.6750e-04 - mean_absolute_error: 0.0093 - val_loss: 1.1581e-04 - val_mean_absolute_error: 0.0079
# Epoch 58/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5187e-04 - mean_absolute_error: 0.0086 - val_loss: 2.1564e-04 - val_mean_absolute_error: 0.0119
# Epoch 59/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.6888e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0612e-04 - val_mean_absolute_error: 0.0074
# Epoch 60/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.7843e-04 - mean_absolute_error: 0.0098 - val_loss: 1.0315e-04 - val_mean_absolute_error: 0.0071
# Epoch 61/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.4441e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2086e-04 - val_mean_absolute_error: 0.0078
# Epoch 62/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3250e-04 - mean_absolute_error: 0.0078 - val_loss: 1.6034e-04 - val_mean_absolute_error: 0.0096
# Epoch 63/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.5833e-04 - mean_absolute_error: 0.0085 - val_loss: 2.7849e-04 - val_mean_absolute_error: 0.0143
# Epoch 64/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.9461e-04 - mean_absolute_error: 0.0103 - val_loss: 9.7047e-05 - val_mean_absolute_error: 0.0070
# Epoch 65/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4916e-04 - mean_absolute_error: 0.0089 - val_loss: 1.6892e-04 - val_mean_absolute_error: 0.0100
# Epoch 66/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.6498e-04 - mean_absolute_error: 0.0087 - val_loss: 1.7985e-04 - val_mean_absolute_error: 0.0105
# Epoch 67/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4953e-04 - mean_absolute_error: 0.0083 - val_loss: 1.1552e-04 - val_mean_absolute_error: 0.0078
# Epoch 68/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.7073e-04 - mean_absolute_error: 0.0091 - val_loss: 2.0570e-04 - val_mean_absolute_error: 0.0116
# Epoch 69/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5794e-04 - mean_absolute_error: 0.0088 - val_loss: 9.7826e-05 - val_mean_absolute_error: 0.0070
# Epoch 70/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7254e-04 - mean_absolute_error: 0.0094 - val_loss: 1.8039e-04 - val_mean_absolute_error: 0.0105
# Epoch 71/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5855e-04 - mean_absolute_error: 0.0087 - val_loss: 9.9196e-05 - val_mean_absolute_error: 0.0070
# Epoch 72/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7027e-04 - mean_absolute_error: 0.0094 - val_loss: 9.9193e-05 - val_mean_absolute_error: 0.0070
# Epoch 73/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.5425e-04 - mean_absolute_error: 0.0088 - val_loss: 1.0672e-04 - val_mean_absolute_error: 0.0072
# Epoch 74/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.5682e-04 - mean_absolute_error: 0.0088 - val_loss: 1.0664e-04 - val_mean_absolute_error: 0.0074
# Epoch 75/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.4605e-04 - mean_absolute_error: 0.0087 - val_loss: 1.0306e-04 - val_mean_absolute_error: 0.0071
# Epoch 76/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5132e-04 - mean_absolute_error: 0.0093 - val_loss: 1.1786e-04 - val_mean_absolute_error: 0.0077
# Epoch 77/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.3691e-04 - mean_absolute_error: 0.0080 - val_loss: 1.1241e-04 - val_mean_absolute_error: 0.0074
# Epoch 78/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.7602e-04 - mean_absolute_error: 0.0096 - val_loss: 1.0337e-04 - val_mean_absolute_error: 0.0071
# Epoch 79/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.4434e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0619e-04 - val_mean_absolute_error: 0.0072
# Epoch 80/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6499e-04 - mean_absolute_error: 0.0095 - val_loss: 3.6088e-04 - val_mean_absolute_error: 0.0172
# Epoch 81/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1860e-04 - mean_absolute_error: 0.0109 - val_loss: 1.0261e-04 - val_mean_absolute_error: 0.0070
# Epoch 82/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5165e-04 - mean_absolute_error: 0.0083 - val_loss: 1.8971e-04 - val_mean_absolute_error: 0.0109
# Epoch 83/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.8280e-04 - mean_absolute_error: 0.0100 - val_loss: 2.8941e-04 - val_mean_absolute_error: 0.0146
# Epoch 84/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.9682e-04 - mean_absolute_error: 0.0098 - val_loss: 9.8255e-05 - val_mean_absolute_error: 0.0070
# Epoch 85/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.6446e-04 - mean_absolute_error: 0.0090 - val_loss: 9.8344e-05 - val_mean_absolute_error: 0.0071
# Epoch 86/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.6187e-04 - mean_absolute_error: 0.0088 - val_loss: 1.3840e-04 - val_mean_absolute_error: 0.0086
# Epoch 87/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6403e-04 - mean_absolute_error: 0.0093 - val_loss: 1.0568e-04 - val_mean_absolute_error: 0.0071
# Epoch 88/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6620e-04 - mean_absolute_error: 0.0090 - val_loss: 1.0966e-04 - val_mean_absolute_error: 0.0073
# Epoch 89/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6397e-04 - mean_absolute_error: 0.0094 - val_loss: 1.7398e-04 - val_mean_absolute_error: 0.0106
# Epoch 90/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.6717e-04 - mean_absolute_error: 0.0092 - val_loss: 1.1004e-04 - val_mean_absolute_error: 0.0073
# Epoch 91/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5272e-04 - mean_absolute_error: 0.0085 - val_loss: 1.3431e-04 - val_mean_absolute_error: 0.0085
# Epoch 92/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.4170e-04 - mean_absolute_error: 0.0083 - val_loss: 1.0019e-04 - val_mean_absolute_error: 0.0070
# Epoch 93/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5020e-04 - mean_absolute_error: 0.0085 - val_loss: 1.4050e-04 - val_mean_absolute_error: 0.0087
# Epoch 94/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3586e-04 - mean_absolute_error: 0.0080 - val_loss: 1.6383e-04 - val_mean_absolute_error: 0.0098
# Epoch 95/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.6904e-04 - mean_absolute_error: 0.0093 - val_loss: 1.0030e-04 - val_mean_absolute_error: 0.0071
# Epoch 96/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6171e-04 - mean_absolute_error: 0.0088 - val_loss: 1.9393e-04 - val_mean_absolute_error: 0.0111
# Epoch 97/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5236e-04 - mean_absolute_error: 0.0086 - val_loss: 1.1320e-04 - val_mean_absolute_error: 0.0078
# Epoch 98/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6476e-04 - mean_absolute_error: 0.0092 - val_loss: 9.7313e-05 - val_mean_absolute_error: 0.0070
# Epoch 99/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7019e-04 - mean_absolute_error: 0.0090 - val_loss: 9.9040e-05 - val_mean_absolute_error: 0.0070
# Epoch 100/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.4683e-04 - mean_absolute_error: 0.0085 - val_loss: 3.2109e-04 - val_mean_absolute_error: 0.0156
# Epoch 101/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6484e-04 - mean_absolute_error: 0.0093 - val_loss: 1.7236e-04 - val_mean_absolute_error: 0.0102
# Epoch 102/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4683e-04 - mean_absolute_error: 0.0084 - val_loss: 1.1521e-04 - val_mean_absolute_error: 0.0077
# Epoch 103/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6222e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0162e-04 - val_mean_absolute_error: 0.0071
# Epoch 104/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.4940e-04 - mean_absolute_error: 0.0087 - val_loss: 1.0994e-04 - val_mean_absolute_error: 0.0073
# Epoch 105/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7774e-04 - mean_absolute_error: 0.0098 - val_loss: 3.5729e-04 - val_mean_absolute_error: 0.0167
# Epoch 106/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7734e-04 - mean_absolute_error: 0.0096 - val_loss: 1.0016e-04 - val_mean_absolute_error: 0.0070
# Epoch 107/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5918e-04 - mean_absolute_error: 0.0087 - val_loss: 3.2895e-04 - val_mean_absolute_error: 0.0158
# Epoch 108/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5651e-04 - mean_absolute_error: 0.0087 - val_loss: 1.8546e-04 - val_mean_absolute_error: 0.0111
# Epoch 109/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.8232e-04 - mean_absolute_error: 0.0103 - val_loss: 1.3731e-04 - val_mean_absolute_error: 0.0090
# Epoch 110/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.8665e-04 - mean_absolute_error: 0.0101 - val_loss: 2.5652e-04 - val_mean_absolute_error: 0.0135
# Epoch 111/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.4642e-04 - mean_absolute_error: 0.0086 - val_loss: 1.3582e-04 - val_mean_absolute_error: 0.0086
# Epoch 112/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5131e-04 - mean_absolute_error: 0.0084 - val_loss: 1.1434e-04 - val_mean_absolute_error: 0.0079
# Epoch 113/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.6823e-04 - mean_absolute_error: 0.0093 - val_loss: 1.1463e-04 - val_mean_absolute_error: 0.0079
# Epoch 114/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.6268e-04 - mean_absolute_error: 0.0091 - val_loss: 9.8346e-05 - val_mean_absolute_error: 0.0070
# Epoch 115/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5784e-04 - mean_absolute_error: 0.0087 - val_loss: 9.7730e-05 - val_mean_absolute_error: 0.0070
# Epoch 116/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6192e-04 - mean_absolute_error: 0.0092 - val_loss: 1.0622e-04 - val_mean_absolute_error: 0.0074
# Epoch 117/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7374e-04 - mean_absolute_error: 0.0096 - val_loss: 2.6681e-04 - val_mean_absolute_error: 0.0138
# Epoch 118/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5961e-04 - mean_absolute_error: 0.0091 - val_loss: 3.4993e-04 - val_mean_absolute_error: 0.0165
# Epoch 119/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6586e-04 - mean_absolute_error: 0.0092 - val_loss: 1.2830e-04 - val_mean_absolute_error: 0.0082
# Epoch 120/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4627e-04 - mean_absolute_error: 0.0087 - val_loss: 1.0540e-04 - val_mean_absolute_error: 0.0072
# Epoch 121/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.8005e-04 - mean_absolute_error: 0.0094 - val_loss: 1.2480e-04 - val_mean_absolute_error: 0.0080
# Epoch 122/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5898e-04 - mean_absolute_error: 0.0090 - val_loss: 1.0571e-04 - val_mean_absolute_error: 0.0072
# Epoch 123/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.4891e-04 - mean_absolute_error: 0.0085 - val_loss: 9.9363e-05 - val_mean_absolute_error: 0.0071
# Epoch 124/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.8137e-04 - mean_absolute_error: 0.0097 - val_loss: 1.5259e-04 - val_mean_absolute_error: 0.0093
# Epoch 125/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.4758e-04 - mean_absolute_error: 0.0084 - val_loss: 9.8668e-05 - val_mean_absolute_error: 0.0070
# Epoch 126/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7610e-04 - mean_absolute_error: 0.0098 - val_loss: 1.1291e-04 - val_mean_absolute_error: 0.0078
# Epoch 127/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.0508e-04 - mean_absolute_error: 0.0107 - val_loss: 9.8417e-05 - val_mean_absolute_error: 0.0070
# Epoch 128/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8158e-04 - mean_absolute_error: 0.0095 - val_loss: 1.1422e-04 - val_mean_absolute_error: 0.0076
# Epoch 129/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5821e-04 - mean_absolute_error: 0.0092 - val_loss: 3.3417e-04 - val_mean_absolute_error: 0.0160
# Epoch 130/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8102e-04 - mean_absolute_error: 0.0099 - val_loss: 9.7129e-05 - val_mean_absolute_error: 0.0070
# Epoch 131/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.2695e-04 - mean_absolute_error: 0.0079 - val_loss: 9.7002e-05 - val_mean_absolute_error: 0.0070
# Epoch 132/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3657e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0038e-04 - val_mean_absolute_error: 0.0071
# Epoch 133/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.4414e-04 - mean_absolute_error: 0.0085 - val_loss: 4.0223e-04 - val_mean_absolute_error: 0.0179
# Epoch 134/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5990e-04 - mean_absolute_error: 0.0091 - val_loss: 1.0887e-04 - val_mean_absolute_error: 0.0073
# Epoch 135/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5220e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2064e-04 - val_mean_absolute_error: 0.0078
# Epoch 136/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.0462e-04 - mean_absolute_error: 0.0103 - val_loss: 1.0413e-04 - val_mean_absolute_error: 0.0072
# Epoch 137/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4734e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0485e-04 - val_mean_absolute_error: 0.0073
# Epoch 138/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.9962e-04 - mean_absolute_error: 0.0108 - val_loss: 1.1083e-04 - val_mean_absolute_error: 0.0074
# Epoch 139/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6275e-04 - mean_absolute_error: 0.0092 - val_loss: 1.5443e-04 - val_mean_absolute_error: 0.0094
# Epoch 140/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3921e-04 - mean_absolute_error: 0.0081 - val_loss: 1.1669e-04 - val_mean_absolute_error: 0.0077
# Epoch 141/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4068e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0182e-04 - val_mean_absolute_error: 0.0071
# Epoch 142/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.4513e-04 - mean_absolute_error: 0.0084 - val_loss: 2.4034e-04 - val_mean_absolute_error: 0.0129
# Epoch 143/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4094e-04 - mean_absolute_error: 0.0083 - val_loss: 1.6975e-04 - val_mean_absolute_error: 0.0101
# Epoch 144/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5034e-04 - mean_absolute_error: 0.0087 - val_loss: 2.8864e-04 - val_mean_absolute_error: 0.0146
# Epoch 145/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6474e-04 - mean_absolute_error: 0.0092 - val_loss: 1.4856e-04 - val_mean_absolute_error: 0.0091
# Epoch 146/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5226e-04 - mean_absolute_error: 0.0088 - val_loss: 9.7140e-05 - val_mean_absolute_error: 0.0070
# Epoch 147/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6951e-04 - mean_absolute_error: 0.0094 - val_loss: 2.8212e-04 - val_mean_absolute_error: 0.0144
# Epoch 148/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4779e-04 - mean_absolute_error: 0.0090 - val_loss: 1.1777e-04 - val_mean_absolute_error: 0.0077
# Epoch 149/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3085e-04 - mean_absolute_error: 0.0078 - val_loss: 1.9016e-04 - val_mean_absolute_error: 0.0110
# Epoch 150/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.6017e-04 - mean_absolute_error: 0.0093 - val_loss: 1.4289e-04 - val_mean_absolute_error: 0.0089
# Epoch 151/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3563e-04 - mean_absolute_error: 0.0080 - val_loss: 9.6878e-05 - val_mean_absolute_error: 0.0070
# Epoch 152/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5320e-04 - mean_absolute_error: 0.0092 - val_loss: 1.0923e-04 - val_mean_absolute_error: 0.0074
# Epoch 153/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6640e-04 - mean_absolute_error: 0.0092 - val_loss: 1.4184e-04 - val_mean_absolute_error: 0.0089
# Epoch 154/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5546e-04 - mean_absolute_error: 0.0086 - val_loss: 1.1786e-04 - val_mean_absolute_error: 0.0077
# Epoch 155/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5101e-04 - mean_absolute_error: 0.0088 - val_loss: 9.8375e-05 - val_mean_absolute_error: 0.0070
# Epoch 156/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5327e-04 - mean_absolute_error: 0.0087 - val_loss: 2.3952e-04 - val_mean_absolute_error: 0.0129
# Epoch 157/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3904e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0234e-04 - val_mean_absolute_error: 0.0071
# Epoch 158/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.4426e-04 - mean_absolute_error: 0.0084 - val_loss: 1.6847e-04 - val_mean_absolute_error: 0.0101
# Epoch 159/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4839e-04 - mean_absolute_error: 0.0086 - val_loss: 1.4342e-04 - val_mean_absolute_error: 0.0093
# Epoch 160/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.9421e-04 - mean_absolute_error: 0.0104 - val_loss: 1.3219e-04 - val_mean_absolute_error: 0.0084
# Epoch 161/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.4789e-04 - mean_absolute_error: 0.0086 - val_loss: 1.8196e-04 - val_mean_absolute_error: 0.0106
# Epoch 162/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6047e-04 - mean_absolute_error: 0.0088 - val_loss: 9.7792e-05 - val_mean_absolute_error: 0.0070
# Epoch 163/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6392e-04 - mean_absolute_error: 0.0090 - val_loss: 2.4308e-04 - val_mean_absolute_error: 0.0130
# Epoch 164/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3954e-04 - mean_absolute_error: 0.0081 - val_loss: 2.6684e-04 - val_mean_absolute_error: 0.0138
# Epoch 165/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.4197e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0081e-04 - val_mean_absolute_error: 0.0072
# Epoch 166/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.4013e-04 - mean_absolute_error: 0.0086 - val_loss: 9.6972e-05 - val_mean_absolute_error: 0.0070
# Epoch 167/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4071e-04 - mean_absolute_error: 0.0082 - val_loss: 1.0051e-04 - val_mean_absolute_error: 0.0071
# Epoch 168/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3942e-04 - mean_absolute_error: 0.0080 - val_loss: 9.7510e-05 - val_mean_absolute_error: 0.0070
# Epoch 169/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.4654e-04 - mean_absolute_error: 0.0083 - val_loss: 1.1421e-04 - val_mean_absolute_error: 0.0075
# Epoch 170/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.5099e-04 - mean_absolute_error: 0.0087 - val_loss: 3.8803e-04 - val_mean_absolute_error: 0.0176
# Epoch 171/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6814e-04 - mean_absolute_error: 0.0089 - val_loss: 1.2991e-04 - val_mean_absolute_error: 0.0082
# Epoch 172/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.4914e-04 - mean_absolute_error: 0.0087 - val_loss: 1.8129e-04 - val_mean_absolute_error: 0.0106
# Epoch 173/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6680e-04 - mean_absolute_error: 0.0093 - val_loss: 1.8136e-04 - val_mean_absolute_error: 0.0106
# Epoch 174/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6861e-04 - mean_absolute_error: 0.0092 - val_loss: 9.8072e-05 - val_mean_absolute_error: 0.0070
# Epoch 175/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3554e-04 - mean_absolute_error: 0.0082 - val_loss: 1.0068e-04 - val_mean_absolute_error: 0.0072
# Epoch 176/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3829e-04 - mean_absolute_error: 0.0081 - val_loss: 1.0166e-04 - val_mean_absolute_error: 0.0072
# Epoch 177/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6110e-04 - mean_absolute_error: 0.0090 - val_loss: 1.2646e-04 - val_mean_absolute_error: 0.0081
# Epoch 178/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.4164e-04 - mean_absolute_error: 0.0082 - val_loss: 1.1387e-04 - val_mean_absolute_error: 0.0076
# Epoch 179/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3696e-04 - mean_absolute_error: 0.0081 - val_loss: 1.4472e-04 - val_mean_absolute_error: 0.0093
# Epoch 180/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8458e-04 - mean_absolute_error: 0.0096 - val_loss: 1.7353e-04 - val_mean_absolute_error: 0.0103
# Epoch 181/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4859e-04 - mean_absolute_error: 0.0086 - val_loss: 1.5768e-04 - val_mean_absolute_error: 0.0096
# Epoch 182/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.4738e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0028e-04 - val_mean_absolute_error: 0.0072
# Epoch 183/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5444e-04 - mean_absolute_error: 0.0091 - val_loss: 2.1957e-04 - val_mean_absolute_error: 0.0121
# Epoch 184/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7639e-04 - mean_absolute_error: 0.0092 - val_loss: 3.7114e-04 - val_mean_absolute_error: 0.0171
# Epoch 185/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.9220e-04 - mean_absolute_error: 0.0101 - val_loss: 1.0635e-04 - val_mean_absolute_error: 0.0073
# Epoch 186/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.4564e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0461e-04 - val_mean_absolute_error: 0.0073
# Epoch 187/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.4398e-04 - mean_absolute_error: 0.0084 - val_loss: 9.8112e-05 - val_mean_absolute_error: 0.0071
# Epoch 188/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5136e-04 - mean_absolute_error: 0.0087 - val_loss: 2.3041e-04 - val_mean_absolute_error: 0.0125
# Epoch 189/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.6546e-04 - mean_absolute_error: 0.0090 - val_loss: 1.7343e-04 - val_mean_absolute_error: 0.0103
# Epoch 190/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.4521e-04 - mean_absolute_error: 0.0084 - val_loss: 2.1211e-04 - val_mean_absolute_error: 0.0118
# Epoch 191/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7304e-04 - mean_absolute_error: 0.0098 - val_loss: 1.1522e-04 - val_mean_absolute_error: 0.0076
# Epoch 192/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.3746e-04 - mean_absolute_error: 0.0081 - val_loss: 2.5063e-04 - val_mean_absolute_error: 0.0132
# Epoch 193/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.8423e-04 - mean_absolute_error: 0.0099 - val_loss: 9.7606e-05 - val_mean_absolute_error: 0.0070
# Epoch 194/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4543e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0863e-04 - val_mean_absolute_error: 0.0076
# Epoch 195/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.5800e-04 - mean_absolute_error: 0.0092 - val_loss: 1.3436e-04 - val_mean_absolute_error: 0.0085
# Epoch 196/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.5058e-04 - mean_absolute_error: 0.0086 - val_loss: 1.4668e-04 - val_mean_absolute_error: 0.0091
# Epoch 197/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4894e-04 - mean_absolute_error: 0.0085 - val_loss: 1.5851e-04 - val_mean_absolute_error: 0.0096
# Epoch 198/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7995e-04 - mean_absolute_error: 0.0096 - val_loss: 1.3514e-04 - val_mean_absolute_error: 0.0085
# Epoch 199/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.4679e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3911e-04 - val_mean_absolute_error: 0.0087
# Epoch 200/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5386e-04 - mean_absolute_error: 0.0088 - val_loss: 2.9570e-04 - val_mean_absolute_error: 0.0148

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 191ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.1014e-04 - mean_absolute_error: 0.0147
# Test Loss: [0.0002957042306661606, 0.014807255938649178]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 120
# 131

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 1119948.0021206855
# RMSE: 1058.2759574518764
# MAE: 864.5294759114583
# MAPE: 2.3241587598901825 %
#
# Model evalution on validate set
# MSE: 5907740.563219433
# RMSE: 2430.5844077545285
# MAE: 1711.4855049070247
# MAPE: 3.6522002004759213 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 695ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step

# %%
y_pred_30_days
# Out:
# array([[59498.863],
#        [59528.375],
#        [59595.477],
#        [59557.152],
#        [59575.594],
#        [59562.61 ],
#        [59571.105],
#        [59565.953],
#        [59569.23 ],
#        [59567.145],
#        [59568.465],
#        [59567.637],
#        [59568.156],
#        [59567.824],
#        [59568.04 ],
#        [59567.9  ],
#        [59567.99 ],
#        [59567.93 ],
#        [59567.97 ],
#        [59567.945],
#        [59567.96 ],
#        [59567.95 ],
#        [59567.957],
#        [59567.95 ],
#        [59567.957],
#        [59567.95 ],
#        [59567.957],
#        [59567.957],
#        [59567.957],
#        [59567.95 ],
#        [59567.957]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
