# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

plt.style.use("default")

# %% [markdown]
# ## 1. Data preprocessing

# %%
split_type = [0.8,0.7,0.9]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830
# ...           ...
# 2024-05-27  59000
# 2024-05-28  62100
# 2024-05-29  60000
# 2024-05-30  59200
# 2024-05-31  60900
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split] * len(df_scaled))
test_size = len(df_scaled) - train_size

# %%
# Splitting data into train, test set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size:]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test set
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1170, 10), (1170,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, GRU, Input

UNITS = 64

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        GRU(UNITS),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru (GRU)                       │ (None, 64)             │        12,864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,929 (50.50 KB)
#  Trainable params: 12,929 (50.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0312 - mean_absolute_error: 0.1344
# Epoch 2/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - mean_absolute_error: 0.0366
# Epoch 3/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8643e-04 - mean_absolute_error: 0.0115
# Epoch 4/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.7375e-04 - mean_absolute_error: 0.0115
# Epoch 5/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4420e-04 - mean_absolute_error: 0.0107
# Epoch 6/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7445e-04 - mean_absolute_error: 0.0114
# Epoch 7/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6051e-04 - mean_absolute_error: 0.0112
# Epoch 8/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4733e-04 - mean_absolute_error: 0.0107
# Epoch 9/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5340e-04 - mean_absolute_error: 0.0108
# Epoch 10/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3320e-04 - mean_absolute_error: 0.0103
# Epoch 11/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5715e-04 - mean_absolute_error: 0.0110
# Epoch 12/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9770e-04 - mean_absolute_error: 0.0098
# Epoch 13/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2121e-04 - mean_absolute_error: 0.0104
# Epoch 14/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4514e-04 - mean_absolute_error: 0.0109
# Epoch 15/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2561e-04 - mean_absolute_error: 0.0103
# Epoch 16/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1310e-04 - mean_absolute_error: 0.0102
# Epoch 17/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2054e-04 - mean_absolute_error: 0.0102
# Epoch 18/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1477e-04 - mean_absolute_error: 0.0100
# Epoch 19/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7796e-04 - mean_absolute_error: 0.0092
# Epoch 20/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8066e-04 - mean_absolute_error: 0.0091
# Epoch 21/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8705e-04 - mean_absolute_error: 0.0094
# Epoch 22/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1025e-04 - mean_absolute_error: 0.0100
# Epoch 23/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8156e-04 - mean_absolute_error: 0.0091
# Epoch 24/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9730e-04 - mean_absolute_error: 0.0100
# Epoch 25/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8507e-04 - mean_absolute_error: 0.0093
# Epoch 26/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0249e-04 - mean_absolute_error: 0.0099
# Epoch 27/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8044e-04 - mean_absolute_error: 0.0093
# Epoch 28/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1230e-04 - mean_absolute_error: 0.0101
# Epoch 29/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8935e-04 - mean_absolute_error: 0.0095
# Epoch 30/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7964e-04 - mean_absolute_error: 0.0091
# Epoch 31/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4942e-04 - mean_absolute_error: 0.0083
# Epoch 32/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8111e-04 - mean_absolute_error: 0.0091
# Epoch 33/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8984e-04 - mean_absolute_error: 0.0094
# Epoch 34/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7960e-04 - mean_absolute_error: 0.0094
# Epoch 35/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9378e-04 - mean_absolute_error: 0.0095
# Epoch 36/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7854e-04 - mean_absolute_error: 0.0092
# Epoch 37/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8350e-04 - mean_absolute_error: 0.0094
# Epoch 38/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7402e-04 - mean_absolute_error: 0.0091
# Epoch 39/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7451e-04 - mean_absolute_error: 0.0091
# Epoch 40/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5638e-04 - mean_absolute_error: 0.0085
# Epoch 41/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0569e-04 - mean_absolute_error: 0.0100
# Epoch 42/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7489e-04 - mean_absolute_error: 0.0092
# Epoch 43/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7681e-04 - mean_absolute_error: 0.0088
# Epoch 44/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7588e-04 - mean_absolute_error: 0.0093
# Epoch 45/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6443e-04 - mean_absolute_error: 0.0091
# Epoch 46/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4680e-04 - mean_absolute_error: 0.0083
# Epoch 47/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6654e-04 - mean_absolute_error: 0.0090
# Epoch 48/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5216e-04 - mean_absolute_error: 0.0087
# Epoch 49/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6212e-04 - mean_absolute_error: 0.0086
# Epoch 50/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7662e-04 - mean_absolute_error: 0.0096
# Epoch 51/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5264e-04 - mean_absolute_error: 0.0084
# Epoch 52/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5822e-04 - mean_absolute_error: 0.0087
# Epoch 53/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5629e-04 - mean_absolute_error: 0.0086
# Epoch 54/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5990e-04 - mean_absolute_error: 0.0085
# Epoch 55/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5160e-04 - mean_absolute_error: 0.0086
# Epoch 56/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6985e-04 - mean_absolute_error: 0.0091
# Epoch 57/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8145e-04 - mean_absolute_error: 0.0096
# Epoch 58/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6838e-04 - mean_absolute_error: 0.0088
# Epoch 59/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3976e-04 - mean_absolute_error: 0.0081
# Epoch 60/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8103e-04 - mean_absolute_error: 0.0091
# Epoch 61/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5263e-04 - mean_absolute_error: 0.0086
# Epoch 62/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4900e-04 - mean_absolute_error: 0.0083
# Epoch 63/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6969e-04 - mean_absolute_error: 0.0089
# Epoch 64/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5365e-04 - mean_absolute_error: 0.0085
# Epoch 65/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5318e-04 - mean_absolute_error: 0.0087
# Epoch 66/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7165e-04 - mean_absolute_error: 0.0093
# Epoch 67/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4274e-04 - mean_absolute_error: 0.0082
# Epoch 68/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8646e-04 - mean_absolute_error: 0.0100
# Epoch 69/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0430e-04 - mean_absolute_error: 0.0103
# Epoch 70/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7249e-04 - mean_absolute_error: 0.0091
# Epoch 71/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5662e-04 - mean_absolute_error: 0.0086
# Epoch 72/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4309e-04 - mean_absolute_error: 0.0082
# Epoch 73/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8082e-04 - mean_absolute_error: 0.0099
# Epoch 74/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6918e-04 - mean_absolute_error: 0.0088
# Epoch 75/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5162e-04 - mean_absolute_error: 0.0086
# Epoch 76/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5751e-04 - mean_absolute_error: 0.0086
# Epoch 77/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3268e-04 - mean_absolute_error: 0.0081
# Epoch 78/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7829e-04 - mean_absolute_error: 0.0093
# Epoch 79/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7059e-04 - mean_absolute_error: 0.0090
# Epoch 80/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4422e-04 - mean_absolute_error: 0.0085
# Epoch 81/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6879e-04 - mean_absolute_error: 0.0090
# Epoch 82/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4583e-04 - mean_absolute_error: 0.0084
# Epoch 83/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4969e-04 - mean_absolute_error: 0.0084
# Epoch 84/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4020e-04 - mean_absolute_error: 0.0080
# Epoch 85/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5649e-04 - mean_absolute_error: 0.0084
# Epoch 86/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5390e-04 - mean_absolute_error: 0.0086
# Epoch 87/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4723e-04 - mean_absolute_error: 0.0085
# Epoch 88/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4798e-04 - mean_absolute_error: 0.0087
# Epoch 89/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4441e-04 - mean_absolute_error: 0.0085
# Epoch 90/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5078e-04 - mean_absolute_error: 0.0086
# Epoch 91/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4132e-04 - mean_absolute_error: 0.0082
# Epoch 92/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6269e-04 - mean_absolute_error: 0.0091
# Epoch 93/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3411e-04 - mean_absolute_error: 0.0080
# Epoch 94/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4480e-04 - mean_absolute_error: 0.0083
# Epoch 95/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4242e-04 - mean_absolute_error: 0.0083
# Epoch 96/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6106e-04 - mean_absolute_error: 0.0091
# Epoch 97/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5968e-04 - mean_absolute_error: 0.0089
# Epoch 98/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5318e-04 - mean_absolute_error: 0.0086
# Epoch 99/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4718e-04 - mean_absolute_error: 0.0085
# Epoch 100/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4085e-04 - mean_absolute_error: 0.0080
# Epoch 101/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5150e-04 - mean_absolute_error: 0.0086
# Epoch 102/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3339e-04 - mean_absolute_error: 0.0080
# Epoch 103/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9332e-04 - mean_absolute_error: 0.0105
# Epoch 104/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5929e-04 - mean_absolute_error: 0.0086
# Epoch 105/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4380e-04 - mean_absolute_error: 0.0084
# Epoch 106/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6478e-04 - mean_absolute_error: 0.0093
# Epoch 107/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4866e-04 - mean_absolute_error: 0.0083
# Epoch 108/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4449e-04 - mean_absolute_error: 0.0081
# Epoch 109/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6799e-04 - mean_absolute_error: 0.0092
# Epoch 110/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4453e-04 - mean_absolute_error: 0.0080
# Epoch 111/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4419e-04 - mean_absolute_error: 0.0084
# Epoch 112/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3577e-04 - mean_absolute_error: 0.0082
# Epoch 113/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4023e-04 - mean_absolute_error: 0.0084
# Epoch 114/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5428e-04 - mean_absolute_error: 0.0087
# Epoch 115/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5165e-04 - mean_absolute_error: 0.0086
# Epoch 116/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5589e-04 - mean_absolute_error: 0.0086
# Epoch 117/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5136e-04 - mean_absolute_error: 0.0087
# Epoch 118/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4251e-04 - mean_absolute_error: 0.0086
# Epoch 119/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3254e-04 - mean_absolute_error: 0.0080
# Epoch 120/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4873e-04 - mean_absolute_error: 0.0083
# Epoch 121/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3219e-04 - mean_absolute_error: 0.0083
# Epoch 122/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5588e-04 - mean_absolute_error: 0.0086
# Epoch 123/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4964e-04 - mean_absolute_error: 0.0085
# Epoch 124/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4006e-04 - mean_absolute_error: 0.0085
# Epoch 125/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5218e-04 - mean_absolute_error: 0.0087
# Epoch 126/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3916e-04 - mean_absolute_error: 0.0081
# Epoch 127/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3055e-04 - mean_absolute_error: 0.0078
# Epoch 128/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3370e-04 - mean_absolute_error: 0.0079
# Epoch 129/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4256e-04 - mean_absolute_error: 0.0082
# Epoch 130/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4185e-04 - mean_absolute_error: 0.0082
# Epoch 131/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2396e-04 - mean_absolute_error: 0.0076
# Epoch 132/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4924e-04 - mean_absolute_error: 0.0086
# Epoch 133/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4921e-04 - mean_absolute_error: 0.0085
# Epoch 134/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5277e-04 - mean_absolute_error: 0.0083
# Epoch 135/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5088e-04 - mean_absolute_error: 0.0086
# Epoch 136/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3296e-04 - mean_absolute_error: 0.0079
# Epoch 137/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3689e-04 - mean_absolute_error: 0.0081
# Epoch 138/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4946e-04 - mean_absolute_error: 0.0085
# Epoch 139/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3509e-04 - mean_absolute_error: 0.0078
# Epoch 140/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3677e-04 - mean_absolute_error: 0.0083
# Epoch 141/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4593e-04 - mean_absolute_error: 0.0082
# Epoch 142/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4060e-04 - mean_absolute_error: 0.0079
# Epoch 143/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6228e-04 - mean_absolute_error: 0.0087
# Epoch 144/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3406e-04 - mean_absolute_error: 0.0081
# Epoch 145/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3684e-04 - mean_absolute_error: 0.0080
# Epoch 146/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4673e-04 - mean_absolute_error: 0.0083
# Epoch 147/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6303e-04 - mean_absolute_error: 0.0088
# Epoch 148/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4333e-04 - mean_absolute_error: 0.0083
# Epoch 149/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7081e-04 - mean_absolute_error: 0.0096
# Epoch 150/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2755e-04 - mean_absolute_error: 0.0077
# Epoch 151/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3799e-04 - mean_absolute_error: 0.0081
# Epoch 152/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3885e-04 - mean_absolute_error: 0.0082
# Epoch 153/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3715e-04 - mean_absolute_error: 0.0080
# Epoch 154/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3523e-04 - mean_absolute_error: 0.0079
# Epoch 155/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3464e-04 - mean_absolute_error: 0.0080
# Epoch 156/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5727e-04 - mean_absolute_error: 0.0088
# Epoch 157/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3218e-04 - mean_absolute_error: 0.0081
# Epoch 158/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7610e-04 - mean_absolute_error: 0.0093
# Epoch 159/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8208e-04 - mean_absolute_error: 0.0096
# Epoch 160/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4628e-04 - mean_absolute_error: 0.0082
# Epoch 161/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4620e-04 - mean_absolute_error: 0.0084
# Epoch 162/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5186e-04 - mean_absolute_error: 0.0085
# Epoch 163/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5807e-04 - mean_absolute_error: 0.0087
# Epoch 164/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3755e-04 - mean_absolute_error: 0.0082
# Epoch 165/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5554e-04 - mean_absolute_error: 0.0088
# Epoch 166/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4826e-04 - mean_absolute_error: 0.0083
# Epoch 167/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4193e-04 - mean_absolute_error: 0.0082
# Epoch 168/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6912e-04 - mean_absolute_error: 0.0094
# Epoch 169/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2603e-04 - mean_absolute_error: 0.0077
# Epoch 170/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3539e-04 - mean_absolute_error: 0.0078
# Epoch 171/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3557e-04 - mean_absolute_error: 0.0081
# Epoch 172/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3728e-04 - mean_absolute_error: 0.0082
# Epoch 173/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2217e-04 - mean_absolute_error: 0.0076
# Epoch 174/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4718e-04 - mean_absolute_error: 0.0086
# Epoch 175/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3263e-04 - mean_absolute_error: 0.0080
# Epoch 176/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5250e-04 - mean_absolute_error: 0.0083
# Epoch 177/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4035e-04 - mean_absolute_error: 0.0082
# Epoch 178/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5302e-04 - mean_absolute_error: 0.0084
# Epoch 179/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4773e-04 - mean_absolute_error: 0.0082
# Epoch 180/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4666e-04 - mean_absolute_error: 0.0084
# Epoch 181/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3080e-04 - mean_absolute_error: 0.0080
# Epoch 182/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4906e-04 - mean_absolute_error: 0.0084
# Epoch 183/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8619e-04 - mean_absolute_error: 0.0098
# Epoch 184/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3817e-04 - mean_absolute_error: 0.0083
# Epoch 185/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4013e-04 - mean_absolute_error: 0.0083
# Epoch 186/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5152e-04 - mean_absolute_error: 0.0085
# Epoch 187/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3719e-04 - mean_absolute_error: 0.0081
# Epoch 188/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5560e-04 - mean_absolute_error: 0.0087
# Epoch 189/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7072e-04 - mean_absolute_error: 0.0096
# Epoch 190/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4654e-04 - mean_absolute_error: 0.0082
# Epoch 191/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4057e-04 - mean_absolute_error: 0.0083
# Epoch 192/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5520e-04 - mean_absolute_error: 0.0089
# Epoch 193/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4228e-04 - mean_absolute_error: 0.0083
# Epoch 194/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4735e-04 - mean_absolute_error: 0.0086
# Epoch 195/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1742e-04 - mean_absolute_error: 0.0074
# Epoch 196/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4067e-04 - mean_absolute_error: 0.0084
# Epoch 197/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5674e-04 - mean_absolute_error: 0.0090
# Epoch 198/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3866e-04 - mean_absolute_error: 0.0081
# Epoch 199/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3181e-04 - mean_absolute_error: 0.0080
# Epoch 200/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7561e-04 - mean_absolute_error: 0.0096

# %% [markdown]
# ### Predicting with test set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6872e-04 - mean_absolute_error: 0.0126
# Test Loss: [0.0006338636158034205, 0.01699967496097088]

# %%
# Splitting data into train, test set again to evaluate, because i shaped the data between 0 to 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 121
# 132

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)
# Out:
# Model evalution on test set
# MSE: 3614783.7431112244
# RMSE: 1901.258462995293
# MAE: 1256.6912771177685
# MAPE: 2.6548053537606564 %

# %% [markdown]
# ## 4. Forecast the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(test_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %%
y_pred_30_days
# Out:
# array([[61055.09 ],
#        [60794.926],
#        [61128.074],
#        [60897.13 ],
#        [61030.043],
#        [60947.375],
#        [61001.336],
#        [60967.695],
#        [60988.844],
#        [60975.47 ],
#        [60983.89 ],
#        [60978.59 ],
#        [60981.934],
#        [60979.83 ],
#        [60981.16 ],
#        [60980.32 ],
#        [60980.855],
#        [60980.508],
#        [60980.727],
#        [60980.582],
#        [60980.67 ],
#        [60980.613],
#        [60980.652],
#        [60980.633],
#        [60980.65 ],
#        [60980.65 ],
#        [60980.65 ],
#        [60980.65 ],
#        [60980.65 ],
#        [60980.65 ],
#        [60980.65 ]], dtype=float32)

# %% [markdown]
# ### Continue forecast the next 60/90 days

# %%
y_pred_60_days = forecast(test_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
y_pred_90_days = forecast(test_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")

    # Predict test set
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        test_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Next {days} Days",
        linestyle="--",
    )

    plt.title(f"Forecast {stock_name[stock]} Stock Closing Price Using GRU")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
