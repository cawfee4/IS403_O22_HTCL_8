# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: FPT - Test/Train/Vaildation: 70/20/10
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1778.98
# - MAE: 1346.53
# - MAPE: 1.90 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 0

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#              close
# time
# 2019-03-01   19270
# 2019-03-04   19440
# 2019-03-05   19390
# 2019-03-06   19270
# 2019-03-07   19330
# ...            ...
# 2024-05-27  132800
# 2024-05-28  137000
# 2024-05-29  135700
# 2024-05-30  135000
# 2024-05-31  134600
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((908, 10), (908,), (251, 10), (251,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 112ms/step - loss: 0.0323 - mean_absolute_error: 0.1295 - val_loss: 0.0049 - val_mean_absolute_error: 0.0654
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.0505e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0013 - val_mean_absolute_error: 0.0284
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.1984e-04 - mean_absolute_error: 0.0125 - val_loss: 4.9510e-04 - val_mean_absolute_error: 0.0161
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.5706e-04 - mean_absolute_error: 0.0110 - val_loss: 4.9754e-04 - val_mean_absolute_error: 0.0161
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.0092e-04 - mean_absolute_error: 0.0124 - val_loss: 6.4246e-04 - val_mean_absolute_error: 0.0193
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.4851e-04 - mean_absolute_error: 0.0108 - val_loss: 5.8389e-04 - val_mean_absolute_error: 0.0179
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.5129e-04 - mean_absolute_error: 0.0106 - val_loss: 4.3807e-04 - val_mean_absolute_error: 0.0149
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.3814e-04 - mean_absolute_error: 0.0107 - val_loss: 5.0810e-04 - val_mean_absolute_error: 0.0160
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.3731e-04 - mean_absolute_error: 0.0104 - val_loss: 6.3994e-04 - val_mean_absolute_error: 0.0184
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.8575e-04 - mean_absolute_error: 0.0106 - val_loss: 6.2372e-04 - val_mean_absolute_error: 0.0179
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 2.6799e-04 - mean_absolute_error: 0.0104 - val_loss: 4.7474e-04 - val_mean_absolute_error: 0.0152
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 2.4182e-04 - mean_absolute_error: 0.0106 - val_loss: 6.4650e-04 - val_mean_absolute_error: 0.0180
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 2.2536e-04 - mean_absolute_error: 0.0100 - val_loss: 5.6218e-04 - val_mean_absolute_error: 0.0164
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.6166e-04 - mean_absolute_error: 0.0107 - val_loss: 4.9608e-04 - val_mean_absolute_error: 0.0154
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.6348e-04 - mean_absolute_error: 0.0111 - val_loss: 4.6382e-04 - val_mean_absolute_error: 0.0150
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 1.9525e-04 - mean_absolute_error: 0.0095 - val_loss: 4.3874e-04 - val_mean_absolute_error: 0.0150
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.4316e-04 - mean_absolute_error: 0.0104 - val_loss: 6.4649e-04 - val_mean_absolute_error: 0.0176
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 2.1192e-04 - mean_absolute_error: 0.0095 - val_loss: 5.5103e-04 - val_mean_absolute_error: 0.0160
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.0360e-04 - mean_absolute_error: 0.0095 - val_loss: 5.8362e-04 - val_mean_absolute_error: 0.0165
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.4409e-04 - mean_absolute_error: 0.0105 - val_loss: 5.6142e-04 - val_mean_absolute_error: 0.0161
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.1293e-04 - mean_absolute_error: 0.0096 - val_loss: 5.6173e-04 - val_mean_absolute_error: 0.0161
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.9892e-04 - mean_absolute_error: 0.0128 - val_loss: 4.8499e-04 - val_mean_absolute_error: 0.0154
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.3430e-04 - mean_absolute_error: 0.0105 - val_loss: 9.0496e-04 - val_mean_absolute_error: 0.0222
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.5120e-04 - mean_absolute_error: 0.0106 - val_loss: 6.3788e-04 - val_mean_absolute_error: 0.0174
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.1412e-04 - mean_absolute_error: 0.0096 - val_loss: 5.5524e-04 - val_mean_absolute_error: 0.0161
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.0042e-04 - mean_absolute_error: 0.0095 - val_loss: 8.2893e-04 - val_mean_absolute_error: 0.0207
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.0956e-04 - mean_absolute_error: 0.0093 - val_loss: 6.6159e-04 - val_mean_absolute_error: 0.0178
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.9013e-04 - mean_absolute_error: 0.0093 - val_loss: 5.2165e-04 - val_mean_absolute_error: 0.0155
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.3788e-04 - mean_absolute_error: 0.0102 - val_loss: 6.1938e-04 - val_mean_absolute_error: 0.0172
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.1389e-04 - mean_absolute_error: 0.0099 - val_loss: 4.7812e-04 - val_mean_absolute_error: 0.0150
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.0653e-04 - mean_absolute_error: 0.0096 - val_loss: 8.6332e-04 - val_mean_absolute_error: 0.0217
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.9757e-04 - mean_absolute_error: 0.0096 - val_loss: 6.4014e-04 - val_mean_absolute_error: 0.0175
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.9298e-04 - mean_absolute_error: 0.0091 - val_loss: 7.1301e-04 - val_mean_absolute_error: 0.0188
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.1034e-04 - mean_absolute_error: 0.0097 - val_loss: 6.0004e-04 - val_mean_absolute_error: 0.0169
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.2590e-04 - mean_absolute_error: 0.0101 - val_loss: 4.2581e-04 - val_mean_absolute_error: 0.0146
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.0025e-04 - mean_absolute_error: 0.0098 - val_loss: 4.0993e-04 - val_mean_absolute_error: 0.0148
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.1605e-04 - mean_absolute_error: 0.0105 - val_loss: 5.6062e-04 - val_mean_absolute_error: 0.0163
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.1843e-04 - mean_absolute_error: 0.0100 - val_loss: 6.1939e-04 - val_mean_absolute_error: 0.0173
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.0524e-04 - mean_absolute_error: 0.0093 - val_loss: 5.3793e-04 - val_mean_absolute_error: 0.0159
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.0353e-04 - mean_absolute_error: 0.0096 - val_loss: 7.6133e-04 - val_mean_absolute_error: 0.0199
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.0351e-04 - mean_absolute_error: 0.0099 - val_loss: 8.7917e-04 - val_mean_absolute_error: 0.0224
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.9622e-04 - mean_absolute_error: 0.0096 - val_loss: 5.2402e-04 - val_mean_absolute_error: 0.0157
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4784e-04 - mean_absolute_error: 0.0084 - val_loss: 4.5422e-04 - val_mean_absolute_error: 0.0145
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6848e-04 - mean_absolute_error: 0.0090 - val_loss: 5.1499e-04 - val_mean_absolute_error: 0.0156
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6827e-04 - mean_absolute_error: 0.0088 - val_loss: 3.8189e-04 - val_mean_absolute_error: 0.0141
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.0139e-04 - mean_absolute_error: 0.0099 - val_loss: 4.2533e-04 - val_mean_absolute_error: 0.0142
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6737e-04 - mean_absolute_error: 0.0092 - val_loss: 6.1863e-04 - val_mean_absolute_error: 0.0173
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.0659e-04 - mean_absolute_error: 0.0095 - val_loss: 6.6127e-04 - val_mean_absolute_error: 0.0182
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.9880e-04 - mean_absolute_error: 0.0093 - val_loss: 4.6584e-04 - val_mean_absolute_error: 0.0148
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.9263e-04 - mean_absolute_error: 0.0091 - val_loss: 5.9772e-04 - val_mean_absolute_error: 0.0171
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6830e-04 - mean_absolute_error: 0.0088 - val_loss: 3.4392e-04 - val_mean_absolute_error: 0.0139
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6789e-04 - mean_absolute_error: 0.0092 - val_loss: 3.9627e-04 - val_mean_absolute_error: 0.0137
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6540e-04 - mean_absolute_error: 0.0086 - val_loss: 4.7646e-04 - val_mean_absolute_error: 0.0150
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.6599e-04 - mean_absolute_error: 0.0087 - val_loss: 3.3513e-04 - val_mean_absolute_error: 0.0142
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.9468e-04 - mean_absolute_error: 0.0097 - val_loss: 4.4250e-04 - val_mean_absolute_error: 0.0144
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.8490e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0013 - val_mean_absolute_error: 0.0300
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1057e-04 - mean_absolute_error: 0.0100 - val_loss: 4.1654e-04 - val_mean_absolute_error: 0.0140
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.4383e-04 - mean_absolute_error: 0.0083 - val_loss: 6.9640e-04 - val_mean_absolute_error: 0.0197
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 1.9845e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0014 - val_mean_absolute_error: 0.0316
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.9713e-04 - mean_absolute_error: 0.0099 - val_loss: 6.7352e-04 - val_mean_absolute_error: 0.0191
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.6117e-04 - mean_absolute_error: 0.0087 - val_loss: 2.9897e-04 - val_mean_absolute_error: 0.0125
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.7096e-04 - mean_absolute_error: 0.0091 - val_loss: 4.8323e-04 - val_mean_absolute_error: 0.0153
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.5423e-04 - mean_absolute_error: 0.0085 - val_loss: 5.0660e-04 - val_mean_absolute_error: 0.0157
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.4209e-04 - mean_absolute_error: 0.0082 - val_loss: 2.8613e-04 - val_mean_absolute_error: 0.0131
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4862e-04 - mean_absolute_error: 0.0085 - val_loss: 3.7717e-04 - val_mean_absolute_error: 0.0133
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.4027e-04 - mean_absolute_error: 0.0079 - val_loss: 4.9788e-04 - val_mean_absolute_error: 0.0157
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6526e-04 - mean_absolute_error: 0.0091 - val_loss: 2.7935e-04 - val_mean_absolute_error: 0.0125
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4576e-04 - mean_absolute_error: 0.0085 - val_loss: 3.3029e-04 - val_mean_absolute_error: 0.0125
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.4162e-04 - mean_absolute_error: 0.0080 - val_loss: 5.3512e-04 - val_mean_absolute_error: 0.0164
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3895e-04 - mean_absolute_error: 0.0083 - val_loss: 2.7865e-04 - val_mean_absolute_error: 0.0122
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.4792e-04 - mean_absolute_error: 0.0085 - val_loss: 7.3625e-04 - val_mean_absolute_error: 0.0206
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.7683e-04 - mean_absolute_error: 0.0094 - val_loss: 8.3994e-04 - val_mean_absolute_error: 0.0230
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5921e-04 - mean_absolute_error: 0.0084 - val_loss: 3.5636e-04 - val_mean_absolute_error: 0.0129
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.3752e-04 - mean_absolute_error: 0.0081 - val_loss: 7.9837e-04 - val_mean_absolute_error: 0.0219
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.4332e-04 - mean_absolute_error: 0.0083 - val_loss: 2.6043e-04 - val_mean_absolute_error: 0.0120
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3503e-04 - mean_absolute_error: 0.0083 - val_loss: 4.0285e-04 - val_mean_absolute_error: 0.0138
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.2520e-04 - mean_absolute_error: 0.0076 - val_loss: 3.4509e-04 - val_mean_absolute_error: 0.0128
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2256e-04 - mean_absolute_error: 0.0076 - val_loss: 2.7366e-04 - val_mean_absolute_error: 0.0127
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4849e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0017 - val_mean_absolute_error: 0.0361
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.4697e-04 - mean_absolute_error: 0.0115 - val_loss: 2.6454e-04 - val_mean_absolute_error: 0.0115
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4572e-04 - mean_absolute_error: 0.0079 - val_loss: 5.0312e-04 - val_mean_absolute_error: 0.0163
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3205e-04 - mean_absolute_error: 0.0078 - val_loss: 4.3862e-04 - val_mean_absolute_error: 0.0145
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.7280e-04 - mean_absolute_error: 0.0090 - val_loss: 7.5422e-04 - val_mean_absolute_error: 0.0215
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3565e-04 - mean_absolute_error: 0.0081 - val_loss: 2.5958e-04 - val_mean_absolute_error: 0.0124
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.6326e-04 - mean_absolute_error: 0.0090 - val_loss: 2.6407e-04 - val_mean_absolute_error: 0.0115
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.2871e-04 - mean_absolute_error: 0.0075 - val_loss: 3.0625e-04 - val_mean_absolute_error: 0.0120
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3942e-04 - mean_absolute_error: 0.0082 - val_loss: 3.7249e-04 - val_mean_absolute_error: 0.0132
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.0866e-04 - mean_absolute_error: 0.0072 - val_loss: 2.5955e-04 - val_mean_absolute_error: 0.0114
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3700e-04 - mean_absolute_error: 0.0078 - val_loss: 5.1750e-04 - val_mean_absolute_error: 0.0164
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.3174e-04 - mean_absolute_error: 0.0076 - val_loss: 2.7127e-04 - val_mean_absolute_error: 0.0115
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.1466e-04 - mean_absolute_error: 0.0071 - val_loss: 5.7958e-04 - val_mean_absolute_error: 0.0178
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.1781e-04 - mean_absolute_error: 0.0076 - val_loss: 2.5494e-04 - val_mean_absolute_error: 0.0116
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.3392e-04 - mean_absolute_error: 0.0079 - val_loss: 3.2198e-04 - val_mean_absolute_error: 0.0122
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.1596e-04 - mean_absolute_error: 0.0073 - val_loss: 5.8584e-04 - val_mean_absolute_error: 0.0178
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.2321e-04 - mean_absolute_error: 0.0075 - val_loss: 2.2909e-04 - val_mean_absolute_error: 0.0118
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3322e-04 - mean_absolute_error: 0.0077 - val_loss: 5.2256e-04 - val_mean_absolute_error: 0.0168
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.1863e-04 - mean_absolute_error: 0.0074 - val_loss: 3.7501e-04 - val_mean_absolute_error: 0.0134
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.2178e-04 - mean_absolute_error: 0.0074 - val_loss: 2.2620e-04 - val_mean_absolute_error: 0.0117
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.2942e-04 - mean_absolute_error: 0.0081 - val_loss: 2.3549e-04 - val_mean_absolute_error: 0.0112
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.2348e-04 - mean_absolute_error: 0.0074 - val_loss: 2.6406e-04 - val_mean_absolute_error: 0.0112
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0518e-04 - mean_absolute_error: 0.0070 - val_loss: 5.5048e-04 - val_mean_absolute_error: 0.0175
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.4106e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0012 - val_mean_absolute_error: 0.0295
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.1506e-04 - mean_absolute_error: 0.0105 - val_loss: 2.6190e-04 - val_mean_absolute_error: 0.0112
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.1393e-04 - mean_absolute_error: 0.0071 - val_loss: 3.5027e-04 - val_mean_absolute_error: 0.0129
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.7424e-05 - mean_absolute_error: 0.0067 - val_loss: 3.5238e-04 - val_mean_absolute_error: 0.0129
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.1392e-04 - mean_absolute_error: 0.0071 - val_loss: 2.2543e-04 - val_mean_absolute_error: 0.0111
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.1752e-04 - mean_absolute_error: 0.0076 - val_loss: 2.5240e-04 - val_mean_absolute_error: 0.0110
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.1182e-04 - mean_absolute_error: 0.0072 - val_loss: 2.5914e-04 - val_mean_absolute_error: 0.0110
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.4310e-04 - mean_absolute_error: 0.0083 - val_loss: 8.3269e-04 - val_mean_absolute_error: 0.0237
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.0886e-04 - mean_absolute_error: 0.0074 - val_loss: 2.0734e-04 - val_mean_absolute_error: 0.0105
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.0609e-04 - mean_absolute_error: 0.0073 - val_loss: 3.5280e-04 - val_mean_absolute_error: 0.0132
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0619e-04 - mean_absolute_error: 0.0071 - val_loss: 3.2487e-04 - val_mean_absolute_error: 0.0124
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.1817e-04 - mean_absolute_error: 0.0074 - val_loss: 2.2584e-04 - val_mean_absolute_error: 0.0124
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 1.0681e-04 - mean_absolute_error: 0.0071 - val_loss: 2.0798e-04 - val_mean_absolute_error: 0.0106
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.0901e-04 - mean_absolute_error: 0.0070 - val_loss: 5.4747e-04 - val_mean_absolute_error: 0.0182
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3331e-04 - mean_absolute_error: 0.0079 - val_loss: 4.6973e-04 - val_mean_absolute_error: 0.0160
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 9.7983e-05 - mean_absolute_error: 0.0067 - val_loss: 3.9680e-04 - val_mean_absolute_error: 0.0142
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.1165e-04 - mean_absolute_error: 0.0071 - val_loss: 2.3487e-04 - val_mean_absolute_error: 0.0106
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.3477e-04 - mean_absolute_error: 0.0079 - val_loss: 5.2703e-04 - val_mean_absolute_error: 0.0170
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2553e-04 - mean_absolute_error: 0.0075 - val_loss: 2.5151e-04 - val_mean_absolute_error: 0.0109
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.0123e-04 - mean_absolute_error: 0.0069 - val_loss: 4.6866e-04 - val_mean_absolute_error: 0.0157
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.0505e-04 - mean_absolute_error: 0.0069 - val_loss: 2.8002e-04 - val_mean_absolute_error: 0.0114
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.9652e-05 - mean_absolute_error: 0.0064 - val_loss: 5.2743e-04 - val_mean_absolute_error: 0.0172
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3565e-04 - mean_absolute_error: 0.0077 - val_loss: 3.2617e-04 - val_mean_absolute_error: 0.0127
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0699e-04 - mean_absolute_error: 0.0069 - val_loss: 2.2826e-04 - val_mean_absolute_error: 0.0105
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.1170e-04 - mean_absolute_error: 0.0071 - val_loss: 5.2658e-04 - val_mean_absolute_error: 0.0178
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.2595e-04 - mean_absolute_error: 0.0079 - val_loss: 1.7558e-04 - val_mean_absolute_error: 0.0105
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2951e-04 - mean_absolute_error: 0.0077 - val_loss: 2.1057e-04 - val_mean_absolute_error: 0.0119
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3926e-04 - mean_absolute_error: 0.0087 - val_loss: 2.6241e-04 - val_mean_absolute_error: 0.0138
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.2791e-04 - mean_absolute_error: 0.0079 - val_loss: 4.2180e-04 - val_mean_absolute_error: 0.0152
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.4752e-05 - mean_absolute_error: 0.0068 - val_loss: 2.0757e-04 - val_mean_absolute_error: 0.0101
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 9.7534e-05 - mean_absolute_error: 0.0069 - val_loss: 2.4613e-04 - val_mean_absolute_error: 0.0107
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.9648e-05 - mean_absolute_error: 0.0064 - val_loss: 2.5929e-04 - val_mean_absolute_error: 0.0110
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.0086e-04 - mean_absolute_error: 0.0066 - val_loss: 5.9607e-04 - val_mean_absolute_error: 0.0192
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.3950e-05 - mean_absolute_error: 0.0069 - val_loss: 2.9758e-04 - val_mean_absolute_error: 0.0120
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 7.8490e-05 - mean_absolute_error: 0.0061 - val_loss: 3.5692e-04 - val_mean_absolute_error: 0.0137
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.0217e-04 - mean_absolute_error: 0.0068 - val_loss: 1.7520e-04 - val_mean_absolute_error: 0.0099
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.9419e-05 - mean_absolute_error: 0.0069 - val_loss: 1.9853e-04 - val_mean_absolute_error: 0.0116
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.1996e-04 - mean_absolute_error: 0.0074 - val_loss: 2.0817e-04 - val_mean_absolute_error: 0.0099
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.0225e-04 - mean_absolute_error: 0.0066 - val_loss: 5.4677e-04 - val_mean_absolute_error: 0.0188
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.1494e-04 - mean_absolute_error: 0.0077 - val_loss: 2.8210e-04 - val_mean_absolute_error: 0.0119
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.1807e-04 - mean_absolute_error: 0.0076 - val_loss: 5.1600e-04 - val_mean_absolute_error: 0.0178
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.1401e-04 - mean_absolute_error: 0.0072 - val_loss: 2.5849e-04 - val_mean_absolute_error: 0.0110
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.8846e-05 - mean_absolute_error: 0.0062 - val_loss: 1.7979e-04 - val_mean_absolute_error: 0.0097
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.9148e-05 - mean_absolute_error: 0.0064 - val_loss: 2.3176e-04 - val_mean_absolute_error: 0.0105
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0586e-04 - mean_absolute_error: 0.0069 - val_loss: 2.7447e-04 - val_mean_absolute_error: 0.0118
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.1002e-04 - mean_absolute_error: 0.0069 - val_loss: 3.0998e-04 - val_mean_absolute_error: 0.0125
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.5887e-05 - mean_absolute_error: 0.0063 - val_loss: 3.2394e-04 - val_mean_absolute_error: 0.0130
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.4999e-05 - mean_absolute_error: 0.0068 - val_loss: 4.3108e-04 - val_mean_absolute_error: 0.0159
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 9.9481e-05 - mean_absolute_error: 0.0067 - val_loss: 2.7119e-04 - val_mean_absolute_error: 0.0114
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.4389e-05 - mean_absolute_error: 0.0064 - val_loss: 2.6997e-04 - val_mean_absolute_error: 0.0115
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.2859e-05 - mean_absolute_error: 0.0062 - val_loss: 3.0867e-04 - val_mean_absolute_error: 0.0126
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0335e-04 - mean_absolute_error: 0.0065 - val_loss: 1.7783e-04 - val_mean_absolute_error: 0.0093
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.3394e-05 - mean_absolute_error: 0.0065 - val_loss: 2.4238e-04 - val_mean_absolute_error: 0.0107
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.0383e-05 - mean_absolute_error: 0.0062 - val_loss: 1.9849e-04 - val_mean_absolute_error: 0.0097
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.2288e-05 - mean_absolute_error: 0.0063 - val_loss: 2.5451e-04 - val_mean_absolute_error: 0.0112
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2187e-04 - mean_absolute_error: 0.0078 - val_loss: 3.2954e-04 - val_mean_absolute_error: 0.0135
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.9130e-05 - mean_absolute_error: 0.0070 - val_loss: 4.0106e-04 - val_mean_absolute_error: 0.0153
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.1108e-05 - mean_absolute_error: 0.0064 - val_loss: 2.7059e-04 - val_mean_absolute_error: 0.0116
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.5884e-05 - mean_absolute_error: 0.0064 - val_loss: 2.4983e-04 - val_mean_absolute_error: 0.0113
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.0201e-05 - mean_absolute_error: 0.0060 - val_loss: 3.5100e-04 - val_mean_absolute_error: 0.0144
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0999e-04 - mean_absolute_error: 0.0070 - val_loss: 2.3488e-04 - val_mean_absolute_error: 0.0106
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0042e-04 - mean_absolute_error: 0.0068 - val_loss: 1.3641e-04 - val_mean_absolute_error: 0.0086
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.0382e-05 - mean_absolute_error: 0.0060 - val_loss: 1.9311e-04 - val_mean_absolute_error: 0.0095
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.5125e-05 - mean_absolute_error: 0.0066 - val_loss: 2.0023e-04 - val_mean_absolute_error: 0.0097
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 7.6178e-05 - mean_absolute_error: 0.0060 - val_loss: 2.4138e-04 - val_mean_absolute_error: 0.0110
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.3641e-05 - mean_absolute_error: 0.0062 - val_loss: 1.5550e-04 - val_mean_absolute_error: 0.0087
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.0523e-05 - mean_absolute_error: 0.0058 - val_loss: 1.5440e-04 - val_mean_absolute_error: 0.0099
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.8528e-05 - mean_absolute_error: 0.0063 - val_loss: 3.6446e-04 - val_mean_absolute_error: 0.0148
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.7307e-05 - mean_absolute_error: 0.0062 - val_loss: 5.4959e-04 - val_mean_absolute_error: 0.0190
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 8.9714e-05 - mean_absolute_error: 0.0065 - val_loss: 3.8392e-04 - val_mean_absolute_error: 0.0156
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.9399e-05 - mean_absolute_error: 0.0071 - val_loss: 4.3851e-04 - val_mean_absolute_error: 0.0166
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 9.1692e-05 - mean_absolute_error: 0.0065 - val_loss: 1.9997e-04 - val_mean_absolute_error: 0.0098
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 8.1470e-05 - mean_absolute_error: 0.0060 - val_loss: 4.3509e-04 - val_mean_absolute_error: 0.0169
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.2113e-04 - mean_absolute_error: 0.0075 - val_loss: 1.2566e-04 - val_mean_absolute_error: 0.0082
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.2744e-05 - mean_absolute_error: 0.0066 - val_loss: 1.3342e-04 - val_mean_absolute_error: 0.0090
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.0478e-05 - mean_absolute_error: 0.0062 - val_loss: 1.8244e-04 - val_mean_absolute_error: 0.0093
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.3115e-05 - mean_absolute_error: 0.0059 - val_loss: 3.9079e-04 - val_mean_absolute_error: 0.0158
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.6984e-05 - mean_absolute_error: 0.0066 - val_loss: 1.4537e-04 - val_mean_absolute_error: 0.0083
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.0035e-05 - mean_absolute_error: 0.0063 - val_loss: 2.4344e-04 - val_mean_absolute_error: 0.0112
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.0888e-05 - mean_absolute_error: 0.0059 - val_loss: 1.9759e-04 - val_mean_absolute_error: 0.0097
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.7459e-05 - mean_absolute_error: 0.0058 - val_loss: 2.5254e-04 - val_mean_absolute_error: 0.0118
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.5302e-05 - mean_absolute_error: 0.0065 - val_loss: 2.4305e-04 - val_mean_absolute_error: 0.0116
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0112e-04 - mean_absolute_error: 0.0068 - val_loss: 3.1935e-04 - val_mean_absolute_error: 0.0137
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.7578e-05 - mean_absolute_error: 0.0069 - val_loss: 3.5403e-04 - val_mean_absolute_error: 0.0148
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.5357e-05 - mean_absolute_error: 0.0063 - val_loss: 1.2384e-04 - val_mean_absolute_error: 0.0083
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 7.8995e-05 - mean_absolute_error: 0.0062 - val_loss: 1.2807e-04 - val_mean_absolute_error: 0.0089
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.0994e-05 - mean_absolute_error: 0.0065 - val_loss: 2.0005e-04 - val_mean_absolute_error: 0.0100
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.1368e-05 - mean_absolute_error: 0.0069 - val_loss: 2.9856e-04 - val_mean_absolute_error: 0.0132
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 6.8418e-05 - mean_absolute_error: 0.0055 - val_loss: 2.4450e-04 - val_mean_absolute_error: 0.0113
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.8494e-05 - mean_absolute_error: 0.0059 - val_loss: 1.2372e-04 - val_mean_absolute_error: 0.0086
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.7883e-05 - mean_absolute_error: 0.0057 - val_loss: 1.1748e-04 - val_mean_absolute_error: 0.0079
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.7435e-05 - mean_absolute_error: 0.0058 - val_loss: 1.1872e-04 - val_mean_absolute_error: 0.0080
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.1966e-05 - mean_absolute_error: 0.0057 - val_loss: 1.2261e-04 - val_mean_absolute_error: 0.0082
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.2338e-05 - mean_absolute_error: 0.0056 - val_loss: 2.7033e-04 - val_mean_absolute_error: 0.0121
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 7.9361e-05 - mean_absolute_error: 0.0058 - val_loss: 1.6569e-04 - val_mean_absolute_error: 0.0088
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.8304e-05 - mean_absolute_error: 0.0057 - val_loss: 1.6674e-04 - val_mean_absolute_error: 0.0089
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.9179e-05 - mean_absolute_error: 0.0062 - val_loss: 2.1621e-04 - val_mean_absolute_error: 0.0106
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.2343e-05 - mean_absolute_error: 0.0055 - val_loss: 2.7135e-04 - val_mean_absolute_error: 0.0126
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.2526e-05 - mean_absolute_error: 0.0061 - val_loss: 1.3350e-04 - val_mean_absolute_error: 0.0081

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5511e-05 - mean_absolute_error: 0.0069
# Test Loss: [0.00013349813525564969, 0.008112970739603043]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 3025025.9761506342
# RMSE: 1739.2601806948362
# MAE: 1237.9681741782867
# MAPE: 1.5799882492660227 %
#
# Model evalution on validate set
# MSE: 23711231.61599555
# RMSE: 4869.417995612571
# MAE: 3883.617445764463
# MAPE: 3.393885148636006 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step

# %%
y_pred_30_days
# Out:
# array([[129822.   ],
#        [129935.45 ],
#        [130295.32 ],
#        [130455.28 ],
#        [130533.96 ],
#        [130509.87 ],
#        [130492.63 ],
#        [130488.45 ],
#        [130488.664],
#        [130489.95 ],
#        [130490.44 ],
#        [130490.42 ],
#        [130490.38 ],
#        [130490.32 ],
#        [130490.31 ],
#        [130490.32 ],
#        [130490.31 ],
#        [130490.31 ],
#        [130490.31 ],
#        [130490.31 ],
#        [130490.31 ],
#        [130490.31 ],
#        [130490.31 ],
#        [130490.31 ],
#        [130490.31 ],
#        [130490.31 ],
#        [130490.31 ],
#        [130490.31 ],
#        [130490.31 ],
#        [130490.31 ],
#        [130490.31 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
