# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: FPT - Test/Train/Vaildation: 70/20/10
# - Dataset: 1313 rows x 7 columns (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1584.2796032950623
# - MAE: 1156.8106947211156
# - MAPE: 1.5085737180837921 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 0

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#              close
# time
# 2019-03-01   19270
# 2019-03-04   19440
# 2019-03-05   19390
# 2019-03-06   19270
# 2019-03-07   19330
# ...            ...
# 2024-05-27  132800
# 2024-05-28  137000
# 2024-05-29  135700
# 2024-05-30  135000
# 2024-05-31  134600
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((908, 10), (908,), (251, 10), (251,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 97ms/step - loss: 0.0410 - mean_absolute_error: 0.1467 - val_loss: 0.0095 - val_mean_absolute_error: 0.0924
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0014 - mean_absolute_error: 0.0291 - val_loss: 0.0011 - val_mean_absolute_error: 0.0250
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.2408e-04 - mean_absolute_error: 0.0123 - val_loss: 5.1092e-04 - val_mean_absolute_error: 0.0165
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.4253e-04 - mean_absolute_error: 0.0103 - val_loss: 4.9547e-04 - val_mean_absolute_error: 0.0159
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.6655e-04 - mean_absolute_error: 0.0109 - val_loss: 4.6943e-04 - val_mean_absolute_error: 0.0155
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.5107e-04 - mean_absolute_error: 0.0107 - val_loss: 4.7066e-04 - val_mean_absolute_error: 0.0155
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.2110e-04 - mean_absolute_error: 0.0101 - val_loss: 5.1503e-04 - val_mean_absolute_error: 0.0163
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.4060e-04 - mean_absolute_error: 0.0105 - val_loss: 4.2658e-04 - val_mean_absolute_error: 0.0151
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.3570e-04 - mean_absolute_error: 0.0106 - val_loss: 6.9451e-04 - val_mean_absolute_error: 0.0192
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.5068e-04 - mean_absolute_error: 0.0103 - val_loss: 5.2017e-04 - val_mean_absolute_error: 0.0159
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.6739e-04 - mean_absolute_error: 0.0109 - val_loss: 6.3061e-04 - val_mean_absolute_error: 0.0176
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 2.3705e-04 - mean_absolute_error: 0.0101 - val_loss: 4.3336e-04 - val_mean_absolute_error: 0.0152
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.8006e-04 - mean_absolute_error: 0.0111 - val_loss: 6.1504e-04 - val_mean_absolute_error: 0.0171
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.2139e-04 - mean_absolute_error: 0.0097 - val_loss: 4.4233e-04 - val_mean_absolute_error: 0.0152
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.4043e-04 - mean_absolute_error: 0.0102 - val_loss: 5.0172e-04 - val_mean_absolute_error: 0.0153
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.5441e-04 - mean_absolute_error: 0.0107 - val_loss: 6.7117e-04 - val_mean_absolute_error: 0.0179
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.5134e-04 - mean_absolute_error: 0.0102 - val_loss: 8.2572e-04 - val_mean_absolute_error: 0.0206
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.4925e-04 - mean_absolute_error: 0.0104 - val_loss: 7.2504e-04 - val_mean_absolute_error: 0.0189
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.9931e-04 - mean_absolute_error: 0.0093 - val_loss: 6.8666e-04 - val_mean_absolute_error: 0.0182
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.0266e-04 - mean_absolute_error: 0.0095 - val_loss: 5.7775e-04 - val_mean_absolute_error: 0.0164
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 2.1003e-04 - mean_absolute_error: 0.0099 - val_loss: 4.6787e-04 - val_mean_absolute_error: 0.0152
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.2920e-04 - mean_absolute_error: 0.0105 - val_loss: 6.5462e-04 - val_mean_absolute_error: 0.0177
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1194e-04 - mean_absolute_error: 0.0097 - val_loss: 6.7083e-04 - val_mean_absolute_error: 0.0180
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.4878e-04 - mean_absolute_error: 0.0103 - val_loss: 4.3612e-04 - val_mean_absolute_error: 0.0153
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.6552e-04 - mean_absolute_error: 0.0110 - val_loss: 7.0137e-04 - val_mean_absolute_error: 0.0186
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8545e-04 - mean_absolute_error: 0.0092 - val_loss: 4.4685e-04 - val_mean_absolute_error: 0.0150
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.1429e-04 - mean_absolute_error: 0.0100 - val_loss: 8.5520e-04 - val_mean_absolute_error: 0.0212
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.3419e-04 - mean_absolute_error: 0.0105 - val_loss: 7.2454e-04 - val_mean_absolute_error: 0.0189
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.7256e-04 - mean_absolute_error: 0.0088 - val_loss: 6.5066e-04 - val_mean_absolute_error: 0.0176
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.8980e-04 - mean_absolute_error: 0.0093 - val_loss: 5.3635e-04 - val_mean_absolute_error: 0.0158
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.8629e-04 - mean_absolute_error: 0.0092 - val_loss: 7.5048e-04 - val_mean_absolute_error: 0.0194
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.1348e-04 - mean_absolute_error: 0.0098 - val_loss: 6.3596e-04 - val_mean_absolute_error: 0.0175
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.7696e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0013 - val_mean_absolute_error: 0.0292
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.5628e-04 - mean_absolute_error: 0.0114 - val_loss: 7.8451e-04 - val_mean_absolute_error: 0.0203
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.8032e-04 - mean_absolute_error: 0.0092 - val_loss: 9.2722e-04 - val_mean_absolute_error: 0.0230
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.8879e-04 - mean_absolute_error: 0.0094 - val_loss: 5.3739e-04 - val_mean_absolute_error: 0.0159
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 1.8346e-04 - mean_absolute_error: 0.0092 - val_loss: 4.5113e-04 - val_mean_absolute_error: 0.0147
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.8576e-04 - mean_absolute_error: 0.0096 - val_loss: 3.8743e-04 - val_mean_absolute_error: 0.0141
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.8790e-04 - mean_absolute_error: 0.0094 - val_loss: 5.9925e-04 - val_mean_absolute_error: 0.0171
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.7779e-04 - mean_absolute_error: 0.0089 - val_loss: 5.6588e-04 - val_mean_absolute_error: 0.0165
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.6123e-04 - mean_absolute_error: 0.0084 - val_loss: 3.6342e-04 - val_mean_absolute_error: 0.0139
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1802e-04 - mean_absolute_error: 0.0103 - val_loss: 3.9709e-04 - val_mean_absolute_error: 0.0137
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.9357e-04 - mean_absolute_error: 0.0091 - val_loss: 4.6912e-04 - val_mean_absolute_error: 0.0148
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.6598e-04 - mean_absolute_error: 0.0085 - val_loss: 5.2532e-04 - val_mean_absolute_error: 0.0159
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7618e-04 - mean_absolute_error: 0.0092 - val_loss: 8.6757e-04 - val_mean_absolute_error: 0.0227
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7478e-04 - mean_absolute_error: 0.0095 - val_loss: 3.6006e-04 - val_mean_absolute_error: 0.0131
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.7782e-04 - mean_absolute_error: 0.0089 - val_loss: 9.8171e-04 - val_mean_absolute_error: 0.0249
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.9595e-04 - mean_absolute_error: 0.0097 - val_loss: 3.3636e-04 - val_mean_absolute_error: 0.0139
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.0169e-04 - mean_absolute_error: 0.0101 - val_loss: 8.2567e-04 - val_mean_absolute_error: 0.0223
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.8868e-04 - mean_absolute_error: 0.0097 - val_loss: 4.3182e-04 - val_mean_absolute_error: 0.0142
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.7147e-04 - mean_absolute_error: 0.0092 - val_loss: 3.5439e-04 - val_mean_absolute_error: 0.0129
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.8969e-04 - mean_absolute_error: 0.0098 - val_loss: 5.3026e-04 - val_mean_absolute_error: 0.0163
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.8912e-04 - mean_absolute_error: 0.0099 - val_loss: 6.9961e-04 - val_mean_absolute_error: 0.0196
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.7316e-04 - mean_absolute_error: 0.0087 - val_loss: 5.4775e-04 - val_mean_absolute_error: 0.0167
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.5326e-04 - mean_absolute_error: 0.0082 - val_loss: 3.0181e-04 - val_mean_absolute_error: 0.0138
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.6343e-04 - mean_absolute_error: 0.0089 - val_loss: 5.6207e-04 - val_mean_absolute_error: 0.0169
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.4063e-04 - mean_absolute_error: 0.0081 - val_loss: 2.8398e-04 - val_mean_absolute_error: 0.0122
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5463e-04 - mean_absolute_error: 0.0085 - val_loss: 5.9895e-04 - val_mean_absolute_error: 0.0178
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3036e-04 - mean_absolute_error: 0.0077 - val_loss: 3.2284e-04 - val_mean_absolute_error: 0.0125
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.4384e-04 - mean_absolute_error: 0.0081 - val_loss: 2.7856e-04 - val_mean_absolute_error: 0.0119
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.4379e-04 - mean_absolute_error: 0.0082 - val_loss: 3.3198e-04 - val_mean_absolute_error: 0.0125
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3239e-04 - mean_absolute_error: 0.0078 - val_loss: 5.2832e-04 - val_mean_absolute_error: 0.0168
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3535e-04 - mean_absolute_error: 0.0082 - val_loss: 3.9872e-04 - val_mean_absolute_error: 0.0138
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3180e-04 - mean_absolute_error: 0.0079 - val_loss: 5.1036e-04 - val_mean_absolute_error: 0.0161
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.8511e-04 - mean_absolute_error: 0.0089 - val_loss: 3.7103e-04 - val_mean_absolute_error: 0.0133
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2931e-04 - mean_absolute_error: 0.0077 - val_loss: 6.4928e-04 - val_mean_absolute_error: 0.0193
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4059e-04 - mean_absolute_error: 0.0079 - val_loss: 6.0001e-04 - val_mean_absolute_error: 0.0184
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3252e-04 - mean_absolute_error: 0.0079 - val_loss: 3.5565e-04 - val_mean_absolute_error: 0.0162
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.0764e-04 - mean_absolute_error: 0.0107 - val_loss: 5.9442e-04 - val_mean_absolute_error: 0.0187
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.4323e-04 - mean_absolute_error: 0.0083 - val_loss: 3.2204e-04 - val_mean_absolute_error: 0.0124
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.4951e-04 - mean_absolute_error: 0.0085 - val_loss: 4.7131e-04 - val_mean_absolute_error: 0.0160
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2617e-04 - mean_absolute_error: 0.0076 - val_loss: 3.0181e-04 - val_mean_absolute_error: 0.0120
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.2711e-04 - mean_absolute_error: 0.0076 - val_loss: 2.1996e-04 - val_mean_absolute_error: 0.0110
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 1.3674e-04 - mean_absolute_error: 0.0079 - val_loss: 3.1315e-04 - val_mean_absolute_error: 0.0122
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.5576e-04 - mean_absolute_error: 0.0084 - val_loss: 2.4276e-04 - val_mean_absolute_error: 0.0109
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.1831e-04 - mean_absolute_error: 0.0076 - val_loss: 3.9033e-04 - val_mean_absolute_error: 0.0141
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.2808e-04 - mean_absolute_error: 0.0077 - val_loss: 4.4825e-04 - val_mean_absolute_error: 0.0156
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.3187e-04 - mean_absolute_error: 0.0078 - val_loss: 3.8198e-04 - val_mean_absolute_error: 0.0139
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2052e-04 - mean_absolute_error: 0.0072 - val_loss: 2.7068e-04 - val_mean_absolute_error: 0.0113
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.0864e-04 - mean_absolute_error: 0.0074 - val_loss: 5.5954e-04 - val_mean_absolute_error: 0.0180
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.2973e-04 - mean_absolute_error: 0.0081 - val_loss: 2.5722e-04 - val_mean_absolute_error: 0.0111
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2453e-04 - mean_absolute_error: 0.0077 - val_loss: 2.8212e-04 - val_mean_absolute_error: 0.0115
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2030e-04 - mean_absolute_error: 0.0072 - val_loss: 2.3228e-04 - val_mean_absolute_error: 0.0107
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.1679e-04 - mean_absolute_error: 0.0073 - val_loss: 4.2754e-04 - val_mean_absolute_error: 0.0151
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4293e-04 - mean_absolute_error: 0.0081 - val_loss: 3.6507e-04 - val_mean_absolute_error: 0.0136
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0987e-04 - mean_absolute_error: 0.0071 - val_loss: 3.7316e-04 - val_mean_absolute_error: 0.0136
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3055e-04 - mean_absolute_error: 0.0077 - val_loss: 7.9623e-04 - val_mean_absolute_error: 0.0235
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2764e-04 - mean_absolute_error: 0.0077 - val_loss: 2.1012e-04 - val_mean_absolute_error: 0.0102
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.1366e-04 - mean_absolute_error: 0.0071 - val_loss: 2.5212e-04 - val_mean_absolute_error: 0.0109
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0656e-04 - mean_absolute_error: 0.0072 - val_loss: 1.9531e-04 - val_mean_absolute_error: 0.0101
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4259e-04 - mean_absolute_error: 0.0081 - val_loss: 5.5723e-04 - val_mean_absolute_error: 0.0183
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4092e-04 - mean_absolute_error: 0.0083 - val_loss: 3.1597e-04 - val_mean_absolute_error: 0.0124
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.1080e-04 - mean_absolute_error: 0.0071 - val_loss: 2.4172e-04 - val_mean_absolute_error: 0.0107
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.1274e-04 - mean_absolute_error: 0.0072 - val_loss: 1.8686e-04 - val_mean_absolute_error: 0.0103
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.1988e-04 - mean_absolute_error: 0.0076 - val_loss: 2.3559e-04 - val_mean_absolute_error: 0.0106
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.1562e-04 - mean_absolute_error: 0.0071 - val_loss: 2.9101e-04 - val_mean_absolute_error: 0.0118
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.2076e-04 - mean_absolute_error: 0.0077 - val_loss: 3.0478e-04 - val_mean_absolute_error: 0.0124
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.1658e-04 - mean_absolute_error: 0.0071 - val_loss: 6.1760e-04 - val_mean_absolute_error: 0.0200
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.4147e-04 - mean_absolute_error: 0.0077 - val_loss: 1.7542e-04 - val_mean_absolute_error: 0.0097
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.1069e-04 - mean_absolute_error: 0.0070 - val_loss: 3.4881e-04 - val_mean_absolute_error: 0.0164
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 1.6509e-04 - mean_absolute_error: 0.0090 - val_loss: 2.3070e-04 - val_mean_absolute_error: 0.0104
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.0310e-04 - mean_absolute_error: 0.0067 - val_loss: 4.4081e-04 - val_mean_absolute_error: 0.0161
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3758e-04 - mean_absolute_error: 0.0080 - val_loss: 1.7200e-04 - val_mean_absolute_error: 0.0101
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.3780e-04 - mean_absolute_error: 0.0084 - val_loss: 1.8906e-04 - val_mean_absolute_error: 0.0112
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3806e-04 - mean_absolute_error: 0.0080 - val_loss: 2.6379e-04 - val_mean_absolute_error: 0.0114
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0617e-04 - mean_absolute_error: 0.0069 - val_loss: 2.3084e-04 - val_mean_absolute_error: 0.0104
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0779e-04 - mean_absolute_error: 0.0070 - val_loss: 3.2567e-04 - val_mean_absolute_error: 0.0129
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.1162e-04 - mean_absolute_error: 0.0073 - val_loss: 1.6540e-04 - val_mean_absolute_error: 0.0096
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.1209e-04 - mean_absolute_error: 0.0071 - val_loss: 2.0940e-04 - val_mean_absolute_error: 0.0099
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2722e-04 - mean_absolute_error: 0.0079 - val_loss: 2.0378e-04 - val_mean_absolute_error: 0.0098
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.4132e-05 - mean_absolute_error: 0.0065 - val_loss: 2.5123e-04 - val_mean_absolute_error: 0.0113
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.0537e-04 - mean_absolute_error: 0.0069 - val_loss: 2.2783e-04 - val_mean_absolute_error: 0.0104
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.7740e-05 - mean_absolute_error: 0.0066 - val_loss: 1.9319e-04 - val_mean_absolute_error: 0.0095
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.2744e-04 - mean_absolute_error: 0.0079 - val_loss: 1.5165e-04 - val_mean_absolute_error: 0.0090
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2348e-04 - mean_absolute_error: 0.0076 - val_loss: 2.3943e-04 - val_mean_absolute_error: 0.0109
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.0424e-04 - mean_absolute_error: 0.0066 - val_loss: 1.4687e-04 - val_mean_absolute_error: 0.0088
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.0467e-04 - mean_absolute_error: 0.0071 - val_loss: 1.7929e-04 - val_mean_absolute_error: 0.0110
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.0557e-04 - mean_absolute_error: 0.0075 - val_loss: 1.5458e-04 - val_mean_absolute_error: 0.0097
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0183e-04 - mean_absolute_error: 0.0069 - val_loss: 1.4573e-04 - val_mean_absolute_error: 0.0089
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.0705e-04 - mean_absolute_error: 0.0070 - val_loss: 2.2303e-04 - val_mean_absolute_error: 0.0106
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.1197e-04 - mean_absolute_error: 0.0068 - val_loss: 1.5994e-04 - val_mean_absolute_error: 0.0100
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.2260e-04 - mean_absolute_error: 0.0074 - val_loss: 2.5472e-04 - val_mean_absolute_error: 0.0115
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.0927e-04 - mean_absolute_error: 0.0071 - val_loss: 1.5919e-04 - val_mean_absolute_error: 0.0088
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.5726e-05 - mean_absolute_error: 0.0066 - val_loss: 2.8292e-04 - val_mean_absolute_error: 0.0123
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.4958e-05 - mean_absolute_error: 0.0059 - val_loss: 3.7260e-04 - val_mean_absolute_error: 0.0147
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.1184e-04 - mean_absolute_error: 0.0073 - val_loss: 3.3900e-04 - val_mean_absolute_error: 0.0141
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0889e-04 - mean_absolute_error: 0.0070 - val_loss: 1.9937e-04 - val_mean_absolute_error: 0.0098
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 7.3725e-05 - mean_absolute_error: 0.0056 - val_loss: 1.4270e-04 - val_mean_absolute_error: 0.0085
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.5411e-05 - mean_absolute_error: 0.0065 - val_loss: 1.6624e-04 - val_mean_absolute_error: 0.0089
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.6950e-05 - mean_absolute_error: 0.0065 - val_loss: 1.8140e-04 - val_mean_absolute_error: 0.0093
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.7283e-05 - mean_absolute_error: 0.0064 - val_loss: 2.2898e-04 - val_mean_absolute_error: 0.0107
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.0448e-04 - mean_absolute_error: 0.0066 - val_loss: 1.5177e-04 - val_mean_absolute_error: 0.0085
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.1991e-05 - mean_absolute_error: 0.0067 - val_loss: 2.2600e-04 - val_mean_absolute_error: 0.0107
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.3221e-05 - mean_absolute_error: 0.0062 - val_loss: 3.6545e-04 - val_mean_absolute_error: 0.0147
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.0154e-04 - mean_absolute_error: 0.0069 - val_loss: 1.2283e-04 - val_mean_absolute_error: 0.0084
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.3453e-05 - mean_absolute_error: 0.0066 - val_loss: 1.4263e-04 - val_mean_absolute_error: 0.0083
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0392e-04 - mean_absolute_error: 0.0068 - val_loss: 2.4386e-04 - val_mean_absolute_error: 0.0115
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.4387e-05 - mean_absolute_error: 0.0062 - val_loss: 3.2155e-04 - val_mean_absolute_error: 0.0140
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.6118e-05 - mean_absolute_error: 0.0063 - val_loss: 1.6791e-04 - val_mean_absolute_error: 0.0089
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.2398e-05 - mean_absolute_error: 0.0059 - val_loss: 1.4033e-04 - val_mean_absolute_error: 0.0082
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.1416e-04 - mean_absolute_error: 0.0071 - val_loss: 1.9611e-04 - val_mean_absolute_error: 0.0099
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.9101e-05 - mean_absolute_error: 0.0069 - val_loss: 1.3078e-04 - val_mean_absolute_error: 0.0090
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.1139e-05 - mean_absolute_error: 0.0064 - val_loss: 1.9581e-04 - val_mean_absolute_error: 0.0099
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.0551e-04 - mean_absolute_error: 0.0068 - val_loss: 1.2657e-04 - val_mean_absolute_error: 0.0079
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.6233e-05 - mean_absolute_error: 0.0067 - val_loss: 1.4132e-04 - val_mean_absolute_error: 0.0081
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.4907e-05 - mean_absolute_error: 0.0061 - val_loss: 1.3466e-04 - val_mean_absolute_error: 0.0080
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.4805e-05 - mean_absolute_error: 0.0063 - val_loss: 1.5918e-04 - val_mean_absolute_error: 0.0105
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0107e-04 - mean_absolute_error: 0.0072 - val_loss: 3.7588e-04 - val_mean_absolute_error: 0.0158
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.3450e-05 - mean_absolute_error: 0.0069 - val_loss: 1.4142e-04 - val_mean_absolute_error: 0.0081
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.1530e-05 - mean_absolute_error: 0.0058 - val_loss: 2.9534e-04 - val_mean_absolute_error: 0.0132
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 9.7935e-05 - mean_absolute_error: 0.0066 - val_loss: 1.1673e-04 - val_mean_absolute_error: 0.0078
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.1172e-04 - mean_absolute_error: 0.0075 - val_loss: 1.1951e-04 - val_mean_absolute_error: 0.0082
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.8880e-05 - mean_absolute_error: 0.0069 - val_loss: 1.9249e-04 - val_mean_absolute_error: 0.0099
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.6547e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3869e-04 - val_mean_absolute_error: 0.0112
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.2317e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4677e-04 - val_mean_absolute_error: 0.0083
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.8118e-05 - mean_absolute_error: 0.0058 - val_loss: 1.8063e-04 - val_mean_absolute_error: 0.0093
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.5332e-05 - mean_absolute_error: 0.0062 - val_loss: 1.7127e-04 - val_mean_absolute_error: 0.0092
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.1911e-05 - mean_absolute_error: 0.0057 - val_loss: 1.2748e-04 - val_mean_absolute_error: 0.0090
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0041e-04 - mean_absolute_error: 0.0068 - val_loss: 2.5699e-04 - val_mean_absolute_error: 0.0124
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.5861e-05 - mean_absolute_error: 0.0065 - val_loss: 2.0352e-04 - val_mean_absolute_error: 0.0105
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.5697e-05 - mean_absolute_error: 0.0058 - val_loss: 2.0200e-04 - val_mean_absolute_error: 0.0103
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.8307e-05 - mean_absolute_error: 0.0055 - val_loss: 2.6784e-04 - val_mean_absolute_error: 0.0125
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.2961e-05 - mean_absolute_error: 0.0061 - val_loss: 3.2796e-04 - val_mean_absolute_error: 0.0144
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0319e-04 - mean_absolute_error: 0.0073 - val_loss: 2.0437e-04 - val_mean_absolute_error: 0.0103
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.2569e-05 - mean_absolute_error: 0.0063 - val_loss: 1.0128e-04 - val_mean_absolute_error: 0.0072
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.2894e-05 - mean_absolute_error: 0.0060 - val_loss: 2.3425e-04 - val_mean_absolute_error: 0.0112
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.7765e-05 - mean_absolute_error: 0.0066 - val_loss: 1.1140e-04 - val_mean_absolute_error: 0.0079
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.5869e-05 - mean_absolute_error: 0.0059 - val_loss: 1.6598e-04 - val_mean_absolute_error: 0.0090
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.2172e-05 - mean_absolute_error: 0.0059 - val_loss: 1.8100e-04 - val_mean_absolute_error: 0.0093
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.6893e-05 - mean_absolute_error: 0.0061 - val_loss: 1.2952e-04 - val_mean_absolute_error: 0.0092
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.5042e-05 - mean_absolute_error: 0.0061 - val_loss: 2.5542e-04 - val_mean_absolute_error: 0.0122
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.9709e-05 - mean_absolute_error: 0.0070 - val_loss: 1.1545e-04 - val_mean_absolute_error: 0.0074
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.8397e-05 - mean_absolute_error: 0.0054 - val_loss: 1.5162e-04 - val_mean_absolute_error: 0.0084
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.1143e-05 - mean_absolute_error: 0.0055 - val_loss: 1.7902e-04 - val_mean_absolute_error: 0.0095
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.1638e-05 - mean_absolute_error: 0.0054 - val_loss: 1.7520e-04 - val_mean_absolute_error: 0.0093
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.6744e-05 - mean_absolute_error: 0.0053 - val_loss: 1.3845e-04 - val_mean_absolute_error: 0.0080
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.2421e-05 - mean_absolute_error: 0.0063 - val_loss: 1.7279e-04 - val_mean_absolute_error: 0.0090
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.1038e-05 - mean_absolute_error: 0.0057 - val_loss: 1.3846e-04 - val_mean_absolute_error: 0.0080
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 8.0165e-05 - mean_absolute_error: 0.0060 - val_loss: 1.8607e-04 - val_mean_absolute_error: 0.0117
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.8971e-05 - mean_absolute_error: 0.0068 - val_loss: 1.0139e-04 - val_mean_absolute_error: 0.0072
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.9459e-05 - mean_absolute_error: 0.0061 - val_loss: 1.1171e-04 - val_mean_absolute_error: 0.0076
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.6878e-05 - mean_absolute_error: 0.0059 - val_loss: 1.2822e-04 - val_mean_absolute_error: 0.0076
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.6301e-05 - mean_absolute_error: 0.0050 - val_loss: 2.1112e-04 - val_mean_absolute_error: 0.0107
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.1218e-05 - mean_absolute_error: 0.0055 - val_loss: 1.2933e-04 - val_mean_absolute_error: 0.0092
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.6794e-05 - mean_absolute_error: 0.0061 - val_loss: 2.0974e-04 - val_mean_absolute_error: 0.0107
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.8418e-05 - mean_absolute_error: 0.0065 - val_loss: 1.0946e-04 - val_mean_absolute_error: 0.0079
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.2169e-05 - mean_absolute_error: 0.0063 - val_loss: 1.2581e-04 - val_mean_absolute_error: 0.0075
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.6845e-05 - mean_absolute_error: 0.0057 - val_loss: 1.3581e-04 - val_mean_absolute_error: 0.0096
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.1742e-05 - mean_absolute_error: 0.0056 - val_loss: 2.1357e-04 - val_mean_absolute_error: 0.0105
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.5527e-05 - mean_absolute_error: 0.0064 - val_loss: 1.6755e-04 - val_mean_absolute_error: 0.0094
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.6516e-05 - mean_absolute_error: 0.0056 - val_loss: 1.0910e-04 - val_mean_absolute_error: 0.0076
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.3238e-05 - mean_absolute_error: 0.0057 - val_loss: 1.8166e-04 - val_mean_absolute_error: 0.0093
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.0724e-05 - mean_absolute_error: 0.0055 - val_loss: 1.9628e-04 - val_mean_absolute_error: 0.0099
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.4286e-05 - mean_absolute_error: 0.0054 - val_loss: 1.8790e-04 - val_mean_absolute_error: 0.0098
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 6.8614e-05 - mean_absolute_error: 0.0056 - val_loss: 1.3315e-04 - val_mean_absolute_error: 0.0077
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0189e-04 - mean_absolute_error: 0.0067 - val_loss: 1.0739e-04 - val_mean_absolute_error: 0.0072
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.1774e-05 - mean_absolute_error: 0.0053 - val_loss: 2.0141e-04 - val_mean_absolute_error: 0.0102
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.7904e-05 - mean_absolute_error: 0.0056 - val_loss: 1.3618e-04 - val_mean_absolute_error: 0.0077
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.4460e-05 - mean_absolute_error: 0.0054 - val_loss: 1.1484e-04 - val_mean_absolute_error: 0.0071
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.0534e-05 - mean_absolute_error: 0.0057 - val_loss: 1.0381e-04 - val_mean_absolute_error: 0.0075

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.8665e-05 - mean_absolute_error: 0.0069
# Test Loss: [0.0001038077607518062, 0.007485044654458761]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 2509941.86141676
# RMSE: 1584.2796032950623
# MAE: 1156.8106947211156
# MAPE: 1.5085737180837921 %
#
# Model evalution on validate set
# MSE: 19240931.72501947
# RMSE: 4386.44864611675
# MAE: 3172.4719137396696
# MAPE: 2.723709894503033 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 779ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step

# %%
y_pred_30_days
# Out:
# array([[131274.95],
#        [133337.77],
#        [131801.4 ],
#        [132891.97],
#        [132133.1 ],
#        [132663.06],
#        [132293.  ],
#        [132551.17],
#        [132370.9 ],
#        [132496.69],
#        [132408.9 ],
#        [132470.17],
#        [132427.4 ],
#        [132457.25],
#        [132436.44],
#        [132450.95],
#        [132440.81],
#        [132447.89],
#        [132442.94],
#        [132446.39],
#        [132444.  ],
#        [132445.67],
#        [132444.48],
#        [132445.33],
#        [132444.73],
#        [132445.17],
#        [132444.84],
#        [132445.08],
#        [132444.89],
#        [132445.05],
#        [132444.9 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Forecast Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
