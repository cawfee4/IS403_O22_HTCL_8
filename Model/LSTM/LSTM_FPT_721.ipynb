# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: FPT - Test/Train/Vaildation: 70/20/10
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1778.98
# - MAE: 1346.53
# - MAPE: 1.90 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 0

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#              close
# time
# 2019-03-01   19270
# 2019-03-04   19440
# 2019-03-05   19390
# 2019-03-06   19270
# 2019-03-07   19330
# ...            ...
# 2024-02-26  108000
# 2024-02-27  107900
# 2024-02-28  108500
# 2024-02-29  109000
# 2024-03-01  110800
#
# [1252 rows x 1 columns]

# %%
df.shape
# Out:
# (1252, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1247    108000
# 1248    107900
# 1249    108500
# 1250    109000
# 1251    110800
# Name: close, Length: 1252, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((865, 10), (865,), (239, 10), (239,), (115, 10), (115,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0370 - mean_absolute_error: 0.1350 - val_loss: 0.0074 - val_mean_absolute_error: 0.0818
# Epoch 2/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0283 - val_loss: 8.6387e-04 - val_mean_absolute_error: 0.0246
# Epoch 3/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0431e-04 - mean_absolute_error: 0.0136 - val_loss: 4.5541e-04 - val_mean_absolute_error: 0.0164
# Epoch 4/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8473e-04 - mean_absolute_error: 0.0133 - val_loss: 5.3201e-04 - val_mean_absolute_error: 0.0173
# Epoch 5/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6218e-04 - mean_absolute_error: 0.0130 - val_loss: 6.3128e-04 - val_mean_absolute_error: 0.0204
# Epoch 6/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8927e-04 - mean_absolute_error: 0.0133 - val_loss: 4.4940e-04 - val_mean_absolute_error: 0.0160
# Epoch 7/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3106e-04 - mean_absolute_error: 0.0137 - val_loss: 4.6105e-04 - val_mean_absolute_error: 0.0161
# Epoch 8/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2289e-04 - mean_absolute_error: 0.0119 - val_loss: 6.4179e-04 - val_mean_absolute_error: 0.0191
# Epoch 9/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8934e-04 - mean_absolute_error: 0.0131 - val_loss: 4.7968e-04 - val_mean_absolute_error: 0.0163
# Epoch 10/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0388e-04 - mean_absolute_error: 0.0135 - val_loss: 5.5080e-04 - val_mean_absolute_error: 0.0185
# Epoch 11/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7091e-04 - mean_absolute_error: 0.0128 - val_loss: 5.1515e-04 - val_mean_absolute_error: 0.0168
# Epoch 12/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8535e-04 - mean_absolute_error: 0.0132 - val_loss: 4.8059e-04 - val_mean_absolute_error: 0.0164
# Epoch 13/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2462e-04 - mean_absolute_error: 0.0136 - val_loss: 4.7740e-04 - val_mean_absolute_error: 0.0164
# Epoch 14/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5834e-04 - mean_absolute_error: 0.0122 - val_loss: 7.3697e-04 - val_mean_absolute_error: 0.0206
# Epoch 15/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1518e-04 - mean_absolute_error: 0.0172 - val_loss: 9.2955e-04 - val_mean_absolute_error: 0.0241
# Epoch 16/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5124e-04 - mean_absolute_error: 0.0139 - val_loss: 6.5371e-04 - val_mean_absolute_error: 0.0189
# Epoch 17/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7287e-04 - mean_absolute_error: 0.0127 - val_loss: 4.8591e-04 - val_mean_absolute_error: 0.0166
# Epoch 18/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4301e-04 - mean_absolute_error: 0.0121 - val_loss: 4.9084e-04 - val_mean_absolute_error: 0.0165
# Epoch 19/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6725e-04 - mean_absolute_error: 0.0124 - val_loss: 5.1300e-04 - val_mean_absolute_error: 0.0175
# Epoch 20/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6114e-04 - mean_absolute_error: 0.0128 - val_loss: 4.8626e-04 - val_mean_absolute_error: 0.0165
# Epoch 21/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4952e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0016 - val_mean_absolute_error: 0.0351
# Epoch 22/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.9207e-04 - mean_absolute_error: 0.0210 - val_loss: 6.8641e-04 - val_mean_absolute_error: 0.0213
# Epoch 23/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8412e-04 - mean_absolute_error: 0.0142 - val_loss: 6.3934e-04 - val_mean_absolute_error: 0.0204
# Epoch 24/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6809e-04 - mean_absolute_error: 0.0131 - val_loss: 5.7405e-04 - val_mean_absolute_error: 0.0175
# Epoch 25/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6983e-04 - mean_absolute_error: 0.0129 - val_loss: 4.7592e-04 - val_mean_absolute_error: 0.0161
# Epoch 26/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4085e-04 - mean_absolute_error: 0.0121 - val_loss: 4.6029e-04 - val_mean_absolute_error: 0.0161
# Epoch 27/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6308e-04 - mean_absolute_error: 0.0126 - val_loss: 6.9802e-04 - val_mean_absolute_error: 0.0200
# Epoch 28/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.0881e-04 - mean_absolute_error: 0.0167 - val_loss: 5.2979e-04 - val_mean_absolute_error: 0.0168
# Epoch 29/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9273e-04 - mean_absolute_error: 0.0116 - val_loss: 4.3815e-04 - val_mean_absolute_error: 0.0156
# Epoch 30/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4946e-04 - mean_absolute_error: 0.0128 - val_loss: 4.5372e-04 - val_mean_absolute_error: 0.0157
# Epoch 31/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5718e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0021 - val_mean_absolute_error: 0.0406
# Epoch 32/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.3488e-04 - mean_absolute_error: 0.0198 - val_loss: 6.2027e-04 - val_mean_absolute_error: 0.0182
# Epoch 33/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2867e-04 - mean_absolute_error: 0.0122 - val_loss: 5.5613e-04 - val_mean_absolute_error: 0.0187
# Epoch 34/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9599e-04 - mean_absolute_error: 0.0134 - val_loss: 4.7880e-04 - val_mean_absolute_error: 0.0160
# Epoch 35/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5866e-04 - mean_absolute_error: 0.0128 - val_loss: 4.5188e-04 - val_mean_absolute_error: 0.0161
# Epoch 36/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3049e-04 - mean_absolute_error: 0.0118 - val_loss: 4.5931e-04 - val_mean_absolute_error: 0.0157
# Epoch 37/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7109e-04 - mean_absolute_error: 0.0134 - val_loss: 4.5120e-04 - val_mean_absolute_error: 0.0161
# Epoch 38/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7200e-04 - mean_absolute_error: 0.0132 - val_loss: 8.4969e-04 - val_mean_absolute_error: 0.0231
# Epoch 39/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7902e-04 - mean_absolute_error: 0.0134 - val_loss: 5.2423e-04 - val_mean_absolute_error: 0.0181
# Epoch 40/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3102e-04 - mean_absolute_error: 0.0125 - val_loss: 5.3738e-04 - val_mean_absolute_error: 0.0168
# Epoch 41/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4541e-04 - mean_absolute_error: 0.0123 - val_loss: 4.3298e-04 - val_mean_absolute_error: 0.0158
# Epoch 42/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1438e-04 - mean_absolute_error: 0.0119 - val_loss: 5.6371e-04 - val_mean_absolute_error: 0.0192
# Epoch 43/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4784e-04 - mean_absolute_error: 0.0128 - val_loss: 6.7866e-04 - val_mean_absolute_error: 0.0200
# Epoch 44/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3704e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0014 - val_mean_absolute_error: 0.0337
# Epoch 45/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7095e-04 - mean_absolute_error: 0.0186 - val_loss: 5.6017e-04 - val_mean_absolute_error: 0.0172
# Epoch 46/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3443e-04 - mean_absolute_error: 0.0120 - val_loss: 5.1250e-04 - val_mean_absolute_error: 0.0164
# Epoch 47/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8723e-04 - mean_absolute_error: 0.0116 - val_loss: 5.3686e-04 - val_mean_absolute_error: 0.0169
# Epoch 48/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1207e-04 - mean_absolute_error: 0.0115 - val_loss: 5.4839e-04 - val_mean_absolute_error: 0.0171
# Epoch 49/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0981e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0010 - val_mean_absolute_error: 0.0268
# Epoch 50/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5806e-04 - mean_absolute_error: 0.0162 - val_loss: 4.1742e-04 - val_mean_absolute_error: 0.0148
# Epoch 51/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2146e-04 - mean_absolute_error: 0.0118 - val_loss: 4.1658e-04 - val_mean_absolute_error: 0.0148
# Epoch 52/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1414e-04 - mean_absolute_error: 0.0117 - val_loss: 3.7747e-04 - val_mean_absolute_error: 0.0143
# Epoch 53/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6346e-04 - mean_absolute_error: 0.0113 - val_loss: 3.8339e-04 - val_mean_absolute_error: 0.0142
# Epoch 54/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9185e-04 - mean_absolute_error: 0.0117 - val_loss: 4.6581e-04 - val_mean_absolute_error: 0.0171
# Epoch 55/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0055e-04 - mean_absolute_error: 0.0121 - val_loss: 3.8939e-04 - val_mean_absolute_error: 0.0142
# Epoch 56/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9611e-04 - mean_absolute_error: 0.0117 - val_loss: 4.2233e-04 - val_mean_absolute_error: 0.0147
# Epoch 57/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6885e-04 - mean_absolute_error: 0.0116 - val_loss: 3.7374e-04 - val_mean_absolute_error: 0.0146
# Epoch 58/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5479e-04 - mean_absolute_error: 0.0111 - val_loss: 6.0681e-04 - val_mean_absolute_error: 0.0207
# Epoch 59/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7410e-04 - mean_absolute_error: 0.0113 - val_loss: 3.4368e-04 - val_mean_absolute_error: 0.0138
# Epoch 60/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5133e-04 - mean_absolute_error: 0.0110 - val_loss: 3.8981e-04 - val_mean_absolute_error: 0.0141
# Epoch 61/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8747e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0025 - val_mean_absolute_error: 0.0475
# Epoch 62/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0250 - val_loss: 6.2361e-04 - val_mean_absolute_error: 0.0198
# Epoch 63/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9632e-04 - mean_absolute_error: 0.0122 - val_loss: 4.5373e-04 - val_mean_absolute_error: 0.0156
# Epoch 64/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8141e-04 - mean_absolute_error: 0.0112 - val_loss: 6.5541e-04 - val_mean_absolute_error: 0.0204
# Epoch 65/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1289e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0019 - val_mean_absolute_error: 0.0402
# Epoch 66/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1350e-04 - mean_absolute_error: 0.0211 - val_loss: 3.2708e-04 - val_mean_absolute_error: 0.0130
# Epoch 67/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6082e-04 - mean_absolute_error: 0.0111 - val_loss: 3.6448e-04 - val_mean_absolute_error: 0.0147
# Epoch 68/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6870e-04 - mean_absolute_error: 0.0113 - val_loss: 3.1840e-04 - val_mean_absolute_error: 0.0130
# Epoch 69/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2907e-04 - mean_absolute_error: 0.0104 - val_loss: 3.0746e-04 - val_mean_absolute_error: 0.0127
# Epoch 70/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5876e-04 - mean_absolute_error: 0.0128 - val_loss: 4.7257e-04 - val_mean_absolute_error: 0.0163
# Epoch 71/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7894e-04 - mean_absolute_error: 0.0118 - val_loss: 3.0598e-04 - val_mean_absolute_error: 0.0129
# Epoch 72/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1641e-04 - mean_absolute_error: 0.0102 - val_loss: 3.0897e-04 - val_mean_absolute_error: 0.0125
# Epoch 73/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3060e-04 - mean_absolute_error: 0.0103 - val_loss: 2.8936e-04 - val_mean_absolute_error: 0.0123
# Epoch 74/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3892e-04 - mean_absolute_error: 0.0106 - val_loss: 3.1196e-04 - val_mean_absolute_error: 0.0125
# Epoch 75/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3774e-04 - mean_absolute_error: 0.0102 - val_loss: 2.7841e-04 - val_mean_absolute_error: 0.0120
# Epoch 76/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6417e-04 - mean_absolute_error: 0.0109 - val_loss: 3.2899e-04 - val_mean_absolute_error: 0.0130
# Epoch 77/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2698e-04 - mean_absolute_error: 0.0103 - val_loss: 3.3938e-04 - val_mean_absolute_error: 0.0134
# Epoch 78/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6077e-04 - mean_absolute_error: 0.0110 - val_loss: 3.1832e-04 - val_mean_absolute_error: 0.0127
# Epoch 79/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4414e-04 - mean_absolute_error: 0.0109 - val_loss: 2.6464e-04 - val_mean_absolute_error: 0.0116
# Epoch 80/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8662e-04 - mean_absolute_error: 0.0096 - val_loss: 3.6598e-04 - val_mean_absolute_error: 0.0142
# Epoch 81/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9744e-04 - mean_absolute_error: 0.0097 - val_loss: 2.6238e-04 - val_mean_absolute_error: 0.0114
# Epoch 82/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7199e-04 - mean_absolute_error: 0.0090 - val_loss: 2.8045e-04 - val_mean_absolute_error: 0.0125
# Epoch 83/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6886e-04 - mean_absolute_error: 0.0118 - val_loss: 8.4194e-04 - val_mean_absolute_error: 0.0249
# Epoch 84/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3693e-04 - mean_absolute_error: 0.0127 - val_loss: 3.9158e-04 - val_mean_absolute_error: 0.0151
# Epoch 85/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5998e-04 - mean_absolute_error: 0.0111 - val_loss: 7.6855e-04 - val_mean_absolute_error: 0.0237
# Epoch 86/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9324e-04 - mean_absolute_error: 0.0160 - val_loss: 5.2506e-04 - val_mean_absolute_error: 0.0195
# Epoch 87/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8035e-04 - mean_absolute_error: 0.0114 - val_loss: 3.8161e-04 - val_mean_absolute_error: 0.0150
# Epoch 88/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5718e-04 - mean_absolute_error: 0.0107 - val_loss: 2.6692e-04 - val_mean_absolute_error: 0.0116
# Epoch 89/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9807e-04 - mean_absolute_error: 0.0093 - val_loss: 2.3605e-04 - val_mean_absolute_error: 0.0111
# Epoch 90/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2959e-04 - mean_absolute_error: 0.0104 - val_loss: 2.3690e-04 - val_mean_absolute_error: 0.0109
# Epoch 91/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9368e-04 - mean_absolute_error: 0.0095 - val_loss: 3.1790e-04 - val_mean_absolute_error: 0.0132
# Epoch 92/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8289e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0015 - val_mean_absolute_error: 0.0345
# Epoch 93/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010 - mean_absolute_error: 0.0230 - val_loss: 2.7539e-04 - val_mean_absolute_error: 0.0117
# Epoch 94/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2763e-04 - mean_absolute_error: 0.0109 - val_loss: 2.4146e-04 - val_mean_absolute_error: 0.0111
# Epoch 95/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8445e-04 - mean_absolute_error: 0.0091 - val_loss: 3.0216e-04 - val_mean_absolute_error: 0.0126
# Epoch 96/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9737e-04 - mean_absolute_error: 0.0091 - val_loss: 2.3321e-04 - val_mean_absolute_error: 0.0108
# Epoch 97/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7362e-04 - mean_absolute_error: 0.0090 - val_loss: 2.4664e-04 - val_mean_absolute_error: 0.0116
# Epoch 98/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0489e-04 - mean_absolute_error: 0.0099 - val_loss: 3.9473e-04 - val_mean_absolute_error: 0.0163
# Epoch 99/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5601e-04 - mean_absolute_error: 0.0117 - val_loss: 4.4760e-04 - val_mean_absolute_error: 0.0167
# Epoch 100/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1372e-04 - mean_absolute_error: 0.0101 - val_loss: 2.5175e-04 - val_mean_absolute_error: 0.0112
# Epoch 101/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9715e-04 - mean_absolute_error: 0.0098 - val_loss: 2.3001e-04 - val_mean_absolute_error: 0.0108
# Epoch 102/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2161e-04 - mean_absolute_error: 0.0098 - val_loss: 2.1945e-04 - val_mean_absolute_error: 0.0105
# Epoch 103/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5423e-04 - mean_absolute_error: 0.0083 - val_loss: 2.4896e-04 - val_mean_absolute_error: 0.0112
# Epoch 104/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0894e-04 - mean_absolute_error: 0.0100 - val_loss: 4.8092e-04 - val_mean_absolute_error: 0.0178
# Epoch 105/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7318e-04 - mean_absolute_error: 0.0089 - val_loss: 2.6223e-04 - val_mean_absolute_error: 0.0118
# Epoch 106/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8849e-04 - mean_absolute_error: 0.0093 - val_loss: 2.9696e-04 - val_mean_absolute_error: 0.0129
# Epoch 107/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5895e-04 - mean_absolute_error: 0.0085 - val_loss: 2.1950e-04 - val_mean_absolute_error: 0.0104
# Epoch 108/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5229e-04 - mean_absolute_error: 0.0084 - val_loss: 2.3494e-04 - val_mean_absolute_error: 0.0109
# Epoch 109/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5859e-04 - mean_absolute_error: 0.0083 - val_loss: 2.0596e-04 - val_mean_absolute_error: 0.0103
# Epoch 110/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5189e-04 - mean_absolute_error: 0.0084 - val_loss: 1.9451e-04 - val_mean_absolute_error: 0.0099
# Epoch 111/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8047e-04 - mean_absolute_error: 0.0092 - val_loss: 2.1679e-04 - val_mean_absolute_error: 0.0105
# Epoch 112/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8011e-04 - mean_absolute_error: 0.0086 - val_loss: 2.7008e-04 - val_mean_absolute_error: 0.0122
# Epoch 113/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6485e-04 - mean_absolute_error: 0.0085 - val_loss: 1.9784e-04 - val_mean_absolute_error: 0.0098
# Epoch 114/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6146e-04 - mean_absolute_error: 0.0082 - val_loss: 1.9269e-04 - val_mean_absolute_error: 0.0097
# Epoch 115/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6593e-04 - mean_absolute_error: 0.0089 - val_loss: 2.1598e-04 - val_mean_absolute_error: 0.0105
# Epoch 116/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4454e-04 - mean_absolute_error: 0.0081 - val_loss: 8.9188e-04 - val_mean_absolute_error: 0.0273
# Epoch 117/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5122e-04 - mean_absolute_error: 0.0135 - val_loss: 2.0061e-04 - val_mean_absolute_error: 0.0104
# Epoch 118/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0982e-04 - mean_absolute_error: 0.0105 - val_loss: 3.0532e-04 - val_mean_absolute_error: 0.0136
# Epoch 119/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3274e-04 - mean_absolute_error: 0.0102 - val_loss: 8.2204e-04 - val_mean_absolute_error: 0.0260
# Epoch 120/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9050e-04 - mean_absolute_error: 0.0141 - val_loss: 3.0190e-04 - val_mean_absolute_error: 0.0135
# Epoch 121/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5064e-04 - mean_absolute_error: 0.0087 - val_loss: 2.1725e-04 - val_mean_absolute_error: 0.0106
# Epoch 122/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0765e-04 - mean_absolute_error: 0.0096 - val_loss: 2.4144e-04 - val_mean_absolute_error: 0.0121
# Epoch 123/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6533e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7872e-04 - val_mean_absolute_error: 0.0128
# Epoch 124/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7277e-04 - mean_absolute_error: 0.0095 - val_loss: 1.9529e-04 - val_mean_absolute_error: 0.0098
# Epoch 125/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7122e-04 - mean_absolute_error: 0.0083 - val_loss: 2.3577e-04 - val_mean_absolute_error: 0.0119
# Epoch 126/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6538e-04 - mean_absolute_error: 0.0087 - val_loss: 1.8427e-04 - val_mean_absolute_error: 0.0094
# Epoch 127/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7725e-04 - mean_absolute_error: 0.0087 - val_loss: 2.3198e-04 - val_mean_absolute_error: 0.0112
# Epoch 128/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6386e-04 - mean_absolute_error: 0.0084 - val_loss: 1.7783e-04 - val_mean_absolute_error: 0.0097
# Epoch 129/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3385e-04 - mean_absolute_error: 0.0075 - val_loss: 1.7720e-04 - val_mean_absolute_error: 0.0093
# Epoch 130/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4458e-04 - mean_absolute_error: 0.0083 - val_loss: 2.1054e-04 - val_mean_absolute_error: 0.0110
# Epoch 131/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7181e-04 - mean_absolute_error: 0.0089 - val_loss: 2.2869e-04 - val_mean_absolute_error: 0.0111
# Epoch 132/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5957e-04 - mean_absolute_error: 0.0085 - val_loss: 3.2010e-04 - val_mean_absolute_error: 0.0143
# Epoch 133/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6776e-04 - mean_absolute_error: 0.0083 - val_loss: 2.8808e-04 - val_mean_absolute_error: 0.0133
# Epoch 134/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6285e-04 - mean_absolute_error: 0.0083 - val_loss: 2.9762e-04 - val_mean_absolute_error: 0.0142
# Epoch 135/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0519e-04 - mean_absolute_error: 0.0096 - val_loss: 1.7938e-04 - val_mean_absolute_error: 0.0094
# Epoch 136/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4104e-04 - mean_absolute_error: 0.0076 - val_loss: 1.7577e-04 - val_mean_absolute_error: 0.0092
# Epoch 137/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5942e-04 - mean_absolute_error: 0.0080 - val_loss: 1.6553e-04 - val_mean_absolute_error: 0.0089
# Epoch 138/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4998e-04 - mean_absolute_error: 0.0083 - val_loss: 3.0968e-04 - val_mean_absolute_error: 0.0147
# Epoch 139/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5364e-04 - mean_absolute_error: 0.0078 - val_loss: 3.5557e-04 - val_mean_absolute_error: 0.0160
# Epoch 140/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9240e-04 - mean_absolute_error: 0.0097 - val_loss: 1.8734e-04 - val_mean_absolute_error: 0.0103
# Epoch 141/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2748e-04 - mean_absolute_error: 0.0077 - val_loss: 1.6987e-04 - val_mean_absolute_error: 0.0091
# Epoch 142/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4550e-04 - mean_absolute_error: 0.0078 - val_loss: 1.7678e-04 - val_mean_absolute_error: 0.0099
# Epoch 143/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6480e-04 - mean_absolute_error: 0.0083 - val_loss: 2.3684e-04 - val_mean_absolute_error: 0.0124
# Epoch 144/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6993e-04 - mean_absolute_error: 0.0091 - val_loss: 3.5715e-04 - val_mean_absolute_error: 0.0156
# Epoch 145/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8441e-04 - mean_absolute_error: 0.0097 - val_loss: 1.7825e-04 - val_mean_absolute_error: 0.0100
# Epoch 146/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3181e-04 - mean_absolute_error: 0.0076 - val_loss: 1.5834e-04 - val_mean_absolute_error: 0.0087
# Epoch 147/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4673e-04 - mean_absolute_error: 0.0085 - val_loss: 3.0047e-04 - val_mean_absolute_error: 0.0139
# Epoch 148/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6508e-04 - mean_absolute_error: 0.0082 - val_loss: 2.8925e-04 - val_mean_absolute_error: 0.0141
# Epoch 149/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5459e-04 - mean_absolute_error: 0.0088 - val_loss: 3.9806e-04 - val_mean_absolute_error: 0.0168
# Epoch 150/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5775e-04 - mean_absolute_error: 0.0084 - val_loss: 2.5783e-04 - val_mean_absolute_error: 0.0131
# Epoch 151/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5417e-04 - mean_absolute_error: 0.0086 - val_loss: 2.4112e-04 - val_mean_absolute_error: 0.0126
# Epoch 152/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7787e-04 - mean_absolute_error: 0.0090 - val_loss: 3.2470e-04 - val_mean_absolute_error: 0.0147
# Epoch 153/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3162e-04 - mean_absolute_error: 0.0079 - val_loss: 1.6208e-04 - val_mean_absolute_error: 0.0089
# Epoch 154/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4150e-04 - mean_absolute_error: 0.0076 - val_loss: 3.3631e-04 - val_mean_absolute_error: 0.0156
# Epoch 155/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5526e-04 - mean_absolute_error: 0.0116 - val_loss: 1.8557e-04 - val_mean_absolute_error: 0.0105
# Epoch 156/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5879e-04 - mean_absolute_error: 0.0085 - val_loss: 1.6494e-04 - val_mean_absolute_error: 0.0095
# Epoch 157/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2388e-04 - mean_absolute_error: 0.0079 - val_loss: 1.6212e-04 - val_mean_absolute_error: 0.0094
# Epoch 158/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3144e-04 - mean_absolute_error: 0.0081 - val_loss: 1.9054e-04 - val_mean_absolute_error: 0.0107
# Epoch 159/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3552e-04 - mean_absolute_error: 0.0079 - val_loss: 1.4348e-04 - val_mean_absolute_error: 0.0083
# Epoch 160/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0969e-04 - mean_absolute_error: 0.0069 - val_loss: 1.3793e-04 - val_mean_absolute_error: 0.0082
# Epoch 161/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1975e-04 - mean_absolute_error: 0.0073 - val_loss: 4.0039e-04 - val_mean_absolute_error: 0.0172
# Epoch 162/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0070e-04 - mean_absolute_error: 0.0103 - val_loss: 1.5395e-04 - val_mean_absolute_error: 0.0088
# Epoch 163/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4067e-04 - mean_absolute_error: 0.0079 - val_loss: 1.4650e-04 - val_mean_absolute_error: 0.0087
# Epoch 164/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4720e-04 - mean_absolute_error: 0.0078 - val_loss: 1.6632e-04 - val_mean_absolute_error: 0.0097
# Epoch 165/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5541e-04 - mean_absolute_error: 0.0083 - val_loss: 3.4750e-04 - val_mean_absolute_error: 0.0156
# Epoch 166/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3894e-04 - mean_absolute_error: 0.0078 - val_loss: 1.5007e-04 - val_mean_absolute_error: 0.0090
# Epoch 167/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4135e-04 - mean_absolute_error: 0.0083 - val_loss: 1.5541e-04 - val_mean_absolute_error: 0.0092
# Epoch 168/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1470e-04 - mean_absolute_error: 0.0071 - val_loss: 2.1222e-04 - val_mean_absolute_error: 0.0113
# Epoch 169/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2735e-04 - mean_absolute_error: 0.0073 - val_loss: 1.8825e-04 - val_mean_absolute_error: 0.0108
# Epoch 170/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3528e-04 - mean_absolute_error: 0.0074 - val_loss: 6.6031e-04 - val_mean_absolute_error: 0.0233
# Epoch 171/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7234e-04 - mean_absolute_error: 0.0092 - val_loss: 1.6756e-04 - val_mean_absolute_error: 0.0094
# Epoch 172/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2327e-04 - mean_absolute_error: 0.0070 - val_loss: 2.1290e-04 - val_mean_absolute_error: 0.0114
# Epoch 173/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1912e-04 - mean_absolute_error: 0.0077 - val_loss: 1.4502e-04 - val_mean_absolute_error: 0.0083
# Epoch 174/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1686e-04 - mean_absolute_error: 0.0071 - val_loss: 2.2704e-04 - val_mean_absolute_error: 0.0120
# Epoch 175/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0119e-04 - mean_absolute_error: 0.0066 - val_loss: 1.3004e-04 - val_mean_absolute_error: 0.0079
# Epoch 176/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0958e-04 - mean_absolute_error: 0.0066 - val_loss: 1.3096e-04 - val_mean_absolute_error: 0.0078
# Epoch 177/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1077e-04 - mean_absolute_error: 0.0066 - val_loss: 1.4127e-04 - val_mean_absolute_error: 0.0086
# Epoch 178/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0482e-04 - mean_absolute_error: 0.0066 - val_loss: 1.6435e-04 - val_mean_absolute_error: 0.0097
# Epoch 179/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1421e-04 - mean_absolute_error: 0.0070 - val_loss: 2.1005e-04 - val_mean_absolute_error: 0.0116
# Epoch 180/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2959e-04 - mean_absolute_error: 0.0076 - val_loss: 1.7856e-04 - val_mean_absolute_error: 0.0104
# Epoch 181/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1653e-04 - mean_absolute_error: 0.0072 - val_loss: 1.9368e-04 - val_mean_absolute_error: 0.0110
# Epoch 182/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3768e-04 - mean_absolute_error: 0.0083 - val_loss: 1.4781e-04 - val_mean_absolute_error: 0.0086
# Epoch 183/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1177e-04 - mean_absolute_error: 0.0069 - val_loss: 2.0528e-04 - val_mean_absolute_error: 0.0113
# Epoch 184/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6237e-04 - mean_absolute_error: 0.0092 - val_loss: 1.5735e-04 - val_mean_absolute_error: 0.0090
# Epoch 185/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2246e-04 - mean_absolute_error: 0.0074 - val_loss: 3.1895e-04 - val_mean_absolute_error: 0.0153
# Epoch 186/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9094e-04 - mean_absolute_error: 0.0096 - val_loss: 1.7913e-04 - val_mean_absolute_error: 0.0103
# Epoch 187/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0868e-04 - mean_absolute_error: 0.0068 - val_loss: 1.6358e-04 - val_mean_absolute_error: 0.0095
# Epoch 188/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1242e-04 - mean_absolute_error: 0.0075 - val_loss: 3.7311e-04 - val_mean_absolute_error: 0.0169
# Epoch 189/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8330e-04 - mean_absolute_error: 0.0099 - val_loss: 1.4397e-04 - val_mean_absolute_error: 0.0088
# Epoch 190/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2726e-04 - mean_absolute_error: 0.0075 - val_loss: 1.3520e-04 - val_mean_absolute_error: 0.0084
# Epoch 191/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1596e-04 - mean_absolute_error: 0.0074 - val_loss: 3.2757e-04 - val_mean_absolute_error: 0.0156
# Epoch 192/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5992e-04 - mean_absolute_error: 0.0086 - val_loss: 1.3420e-04 - val_mean_absolute_error: 0.0082
# Epoch 193/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1440e-04 - mean_absolute_error: 0.0072 - val_loss: 1.3404e-04 - val_mean_absolute_error: 0.0082
# Epoch 194/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1182e-04 - mean_absolute_error: 0.0075 - val_loss: 1.3841e-04 - val_mean_absolute_error: 0.0082
# Epoch 195/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1813e-04 - mean_absolute_error: 0.0072 - val_loss: 1.3869e-04 - val_mean_absolute_error: 0.0082
# Epoch 196/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0363e-04 - mean_absolute_error: 0.0067 - val_loss: 1.7874e-04 - val_mean_absolute_error: 0.0103
# Epoch 197/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5964e-04 - mean_absolute_error: 0.0093 - val_loss: 1.4626e-04 - val_mean_absolute_error: 0.0088
# Epoch 198/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1553e-04 - mean_absolute_error: 0.0079 - val_loss: 2.9773e-04 - val_mean_absolute_error: 0.0147
# Epoch 199/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2098e-04 - mean_absolute_error: 0.0108 - val_loss: 2.4082e-04 - val_mean_absolute_error: 0.0125
# Epoch 200/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8622e-05 - mean_absolute_error: 0.0066 - val_loss: 2.2388e-04 - val_mean_absolute_error: 0.0119

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0167e-04 - mean_absolute_error: 0.0114
# Test Loss: [0.00022387907665688545, 0.01192532479763031]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 239
# 250

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 3164779.8206511303
# RMSE: 1778.9828050465048
# MAE: 1346.534911087866
# MAPE: 1.9016903718177425 %
#
# Model evalution on validate set
# MSE: 16282641.949374257
# RMSE: 4035.1755785063747
# MAE: 3582.838519021739
# MAPE: 3.7119826157717646 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
y_pred_30_days
# Out:
# array([[108772.49 ],
#        [108938.77 ],
#        [108836.63 ],
#        [108905.4  ],
#        [108860.625],
#        [108890.11 ],
#        [108870.79 ],
#        [108883.48 ],
#        [108875.15 ],
#        [108880.62 ],
#        [108877.02 ],
#        [108879.38 ],
#        [108877.836],
#        [108878.85 ],
#        [108878.18 ],
#        [108878.63 ],
#        [108878.29 ],
#        [108878.55 ],
#        [108878.39 ],
#        [108878.49 ],
#        [108878.414],
#        [108878.48 ],
#        [108878.44 ],
#        [108878.48 ],
#        [108878.445],
#        [108878.45 ],
#        [108878.45 ],
#        [108878.45 ],
#        [108878.45 ],
#        [108878.45 ],
#        [108878.47 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
