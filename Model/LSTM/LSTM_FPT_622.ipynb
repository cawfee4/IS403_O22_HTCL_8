# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: FPT - Test/Train/Vaildation: 60/20/20
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 2129.89
# - MAE: 1501.56
# - MAPE: 2.15 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#              close
# time
# 2019-03-01   19270
# 2019-03-04   19440
# 2019-03-05   19390
# 2019-03-06   19270
# 2019-03-07   19330
# ...            ...
# 2024-05-27  132800
# 2024-05-28  137000
# 2024-05-29  135700
# 2024-05-30  135000
# 2024-05-31  134600
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((776, 10), (776,), (251, 10), (251,), (253, 10), (253,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - loss: 0.0142 - mean_absolute_error: 0.0851 - val_loss: 0.0031 - val_mean_absolute_error: 0.0522
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.5259e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0014 - val_mean_absolute_error: 0.0330
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.5354e-04 - mean_absolute_error: 0.0114 - val_loss: 5.2880e-04 - val_mean_absolute_error: 0.0182
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6055e-04 - mean_absolute_error: 0.0087 - val_loss: 3.9699e-04 - val_mean_absolute_error: 0.0147
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4866e-04 - mean_absolute_error: 0.0085 - val_loss: 4.4756e-04 - val_mean_absolute_error: 0.0162
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.0007e-04 - mean_absolute_error: 0.0100 - val_loss: 3.6704e-04 - val_mean_absolute_error: 0.0138
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5068e-04 - mean_absolute_error: 0.0085 - val_loss: 4.3531e-04 - val_mean_absolute_error: 0.0159
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.7338e-04 - mean_absolute_error: 0.0092 - val_loss: 4.3145e-04 - val_mean_absolute_error: 0.0159
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3868e-04 - mean_absolute_error: 0.0085 - val_loss: 4.8631e-04 - val_mean_absolute_error: 0.0174
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.5455e-04 - mean_absolute_error: 0.0086 - val_loss: 3.9156e-04 - val_mean_absolute_error: 0.0148
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.5136e-04 - mean_absolute_error: 0.0085 - val_loss: 5.7760e-04 - val_mean_absolute_error: 0.0197
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7288e-04 - mean_absolute_error: 0.0092 - val_loss: 4.8914e-04 - val_mean_absolute_error: 0.0176
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.5696e-04 - mean_absolute_error: 0.0089 - val_loss: 3.9034e-04 - val_mean_absolute_error: 0.0149
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5917e-04 - mean_absolute_error: 0.0089 - val_loss: 3.3233e-04 - val_mean_absolute_error: 0.0127
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.6333e-04 - mean_absolute_error: 0.0089 - val_loss: 3.2897e-04 - val_mean_absolute_error: 0.0126
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.4338e-04 - mean_absolute_error: 0.0081 - val_loss: 3.2999e-04 - val_mean_absolute_error: 0.0126
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.4905e-04 - mean_absolute_error: 0.0088 - val_loss: 3.4478e-04 - val_mean_absolute_error: 0.0136
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5299e-04 - mean_absolute_error: 0.0086 - val_loss: 3.8926e-04 - val_mean_absolute_error: 0.0143
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.8255e-04 - mean_absolute_error: 0.0095 - val_loss: 3.4083e-04 - val_mean_absolute_error: 0.0135
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5362e-04 - mean_absolute_error: 0.0086 - val_loss: 4.8518e-04 - val_mean_absolute_error: 0.0177
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5993e-04 - mean_absolute_error: 0.0093 - val_loss: 3.1850e-04 - val_mean_absolute_error: 0.0127
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.5066e-04 - mean_absolute_error: 0.0084 - val_loss: 3.1140e-04 - val_mean_absolute_error: 0.0124
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4001e-04 - mean_absolute_error: 0.0082 - val_loss: 3.5460e-04 - val_mean_absolute_error: 0.0141
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.4076e-04 - mean_absolute_error: 0.0083 - val_loss: 3.6823e-04 - val_mean_absolute_error: 0.0145
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.4713e-04 - mean_absolute_error: 0.0086 - val_loss: 3.4827e-04 - val_mean_absolute_error: 0.0139
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5369e-04 - mean_absolute_error: 0.0084 - val_loss: 4.6934e-04 - val_mean_absolute_error: 0.0174
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5534e-04 - mean_absolute_error: 0.0088 - val_loss: 3.6047e-04 - val_mean_absolute_error: 0.0144
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3509e-04 - mean_absolute_error: 0.0082 - val_loss: 3.5477e-04 - val_mean_absolute_error: 0.0142
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.1771e-04 - mean_absolute_error: 0.0076 - val_loss: 5.1489e-04 - val_mean_absolute_error: 0.0186
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.4880e-04 - mean_absolute_error: 0.0086 - val_loss: 3.3745e-04 - val_mean_absolute_error: 0.0137
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.4021e-04 - mean_absolute_error: 0.0080 - val_loss: 4.7388e-04 - val_mean_absolute_error: 0.0176
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.3930e-04 - mean_absolute_error: 0.0083 - val_loss: 9.6092e-04 - val_mean_absolute_error: 0.0276
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 2.2186e-04 - mean_absolute_error: 0.0107 - val_loss: 3.5095e-04 - val_mean_absolute_error: 0.0142
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.2791e-04 - mean_absolute_error: 0.0079 - val_loss: 5.3693e-04 - val_mean_absolute_error: 0.0193
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 1.3690e-04 - mean_absolute_error: 0.0081 - val_loss: 4.9030e-04 - val_mean_absolute_error: 0.0181
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.3960e-04 - mean_absolute_error: 0.0086 - val_loss: 2.7736e-04 - val_mean_absolute_error: 0.0116
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.1620e-04 - mean_absolute_error: 0.0077 - val_loss: 3.6128e-04 - val_mean_absolute_error: 0.0147
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.2390e-04 - mean_absolute_error: 0.0079 - val_loss: 5.1195e-04 - val_mean_absolute_error: 0.0187
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 1.1586e-04 - mean_absolute_error: 0.0077 - val_loss: 3.1867e-04 - val_mean_absolute_error: 0.0130
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3578e-04 - mean_absolute_error: 0.0086 - val_loss: 3.0461e-04 - val_mean_absolute_error: 0.0130
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.2894e-04 - mean_absolute_error: 0.0079 - val_loss: 3.7883e-04 - val_mean_absolute_error: 0.0153
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.2735e-04 - mean_absolute_error: 0.0078 - val_loss: 3.5495e-04 - val_mean_absolute_error: 0.0146
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.1705e-04 - mean_absolute_error: 0.0075 - val_loss: 3.2607e-04 - val_mean_absolute_error: 0.0137
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.1522e-04 - mean_absolute_error: 0.0076 - val_loss: 3.3713e-04 - val_mean_absolute_error: 0.0139
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3668e-04 - mean_absolute_error: 0.0083 - val_loss: 5.2644e-04 - val_mean_absolute_error: 0.0192
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.1696e-04 - mean_absolute_error: 0.0076 - val_loss: 3.5365e-04 - val_mean_absolute_error: 0.0147
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2435e-04 - mean_absolute_error: 0.0079 - val_loss: 3.1985e-04 - val_mean_absolute_error: 0.0137
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.2391e-04 - mean_absolute_error: 0.0077 - val_loss: 2.5761e-04 - val_mean_absolute_error: 0.0116
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.8008e-05 - mean_absolute_error: 0.0069 - val_loss: 2.5778e-04 - val_mean_absolute_error: 0.0114
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.9466e-05 - mean_absolute_error: 0.0069 - val_loss: 2.3332e-04 - val_mean_absolute_error: 0.0107
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.0964e-04 - mean_absolute_error: 0.0074 - val_loss: 4.5208e-04 - val_mean_absolute_error: 0.0176
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.4464e-04 - mean_absolute_error: 0.0087 - val_loss: 3.4198e-04 - val_mean_absolute_error: 0.0145
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.1789e-04 - mean_absolute_error: 0.0077 - val_loss: 3.6976e-04 - val_mean_absolute_error: 0.0153
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.2963e-04 - mean_absolute_error: 0.0081 - val_loss: 2.3980e-04 - val_mean_absolute_error: 0.0112
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2451e-04 - mean_absolute_error: 0.0080 - val_loss: 2.4337e-04 - val_mean_absolute_error: 0.0113
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0028e-04 - mean_absolute_error: 0.0068 - val_loss: 2.8843e-04 - val_mean_absolute_error: 0.0130
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.0989e-05 - mean_absolute_error: 0.0066 - val_loss: 3.1098e-04 - val_mean_absolute_error: 0.0137
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.1116e-04 - mean_absolute_error: 0.0077 - val_loss: 3.6768e-04 - val_mean_absolute_error: 0.0154
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3245e-04 - mean_absolute_error: 0.0082 - val_loss: 2.0997e-04 - val_mean_absolute_error: 0.0101
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.8784e-05 - mean_absolute_error: 0.0069 - val_loss: 2.1387e-04 - val_mean_absolute_error: 0.0103
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.0640e-04 - mean_absolute_error: 0.0072 - val_loss: 2.4057e-04 - val_mean_absolute_error: 0.0113
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.0948e-04 - mean_absolute_error: 0.0076 - val_loss: 2.1329e-04 - val_mean_absolute_error: 0.0103
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.8382e-05 - mean_absolute_error: 0.0066 - val_loss: 2.7805e-04 - val_mean_absolute_error: 0.0128
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0005e-04 - mean_absolute_error: 0.0072 - val_loss: 4.9139e-04 - val_mean_absolute_error: 0.0188
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.1262e-04 - mean_absolute_error: 0.0077 - val_loss: 2.1755e-04 - val_mean_absolute_error: 0.0107
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.0511e-05 - mean_absolute_error: 0.0068 - val_loss: 2.6082e-04 - val_mean_absolute_error: 0.0124
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.0848e-04 - mean_absolute_error: 0.0075 - val_loss: 1.9285e-04 - val_mean_absolute_error: 0.0096
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0572e-04 - mean_absolute_error: 0.0072 - val_loss: 1.9035e-04 - val_mean_absolute_error: 0.0095
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0493e-04 - mean_absolute_error: 0.0071 - val_loss: 3.2642e-04 - val_mean_absolute_error: 0.0147
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3688e-04 - mean_absolute_error: 0.0086 - val_loss: 2.0970e-04 - val_mean_absolute_error: 0.0105
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.5567e-05 - mean_absolute_error: 0.0065 - val_loss: 1.8514e-04 - val_mean_absolute_error: 0.0094
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.1604e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3088e-04 - val_mean_absolute_error: 0.0114
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0051e-04 - mean_absolute_error: 0.0071 - val_loss: 1.9144e-04 - val_mean_absolute_error: 0.0097
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.5121e-05 - mean_absolute_error: 0.0064 - val_loss: 1.9216e-04 - val_mean_absolute_error: 0.0098
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 7.5942e-05 - mean_absolute_error: 0.0061 - val_loss: 1.9355e-04 - val_mean_absolute_error: 0.0099
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.4129e-05 - mean_absolute_error: 0.0063 - val_loss: 2.0279e-04 - val_mean_absolute_error: 0.0103
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.5480e-05 - mean_absolute_error: 0.0063 - val_loss: 2.2297e-04 - val_mean_absolute_error: 0.0113
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.1200e-04 - mean_absolute_error: 0.0072 - val_loss: 3.6809e-04 - val_mean_absolute_error: 0.0161
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0582e-04 - mean_absolute_error: 0.0076 - val_loss: 1.7465e-04 - val_mean_absolute_error: 0.0091
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.4797e-05 - mean_absolute_error: 0.0061 - val_loss: 1.8355e-04 - val_mean_absolute_error: 0.0096
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.7573e-05 - mean_absolute_error: 0.0067 - val_loss: 2.2342e-04 - val_mean_absolute_error: 0.0112
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 7.7588e-05 - mean_absolute_error: 0.0061 - val_loss: 1.7855e-04 - val_mean_absolute_error: 0.0093
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.9378e-05 - mean_absolute_error: 0.0066 - val_loss: 2.2110e-04 - val_mean_absolute_error: 0.0113
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0053e-04 - mean_absolute_error: 0.0072 - val_loss: 1.8805e-04 - val_mean_absolute_error: 0.0099
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.2143e-04 - mean_absolute_error: 0.0079 - val_loss: 1.7174e-04 - val_mean_absolute_error: 0.0091
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.0193e-05 - mean_absolute_error: 0.0068 - val_loss: 1.6711e-04 - val_mean_absolute_error: 0.0089
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.6535e-05 - mean_absolute_error: 0.0060 - val_loss: 1.6947e-04 - val_mean_absolute_error: 0.0090
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 7.8516e-05 - mean_absolute_error: 0.0061 - val_loss: 2.3872e-04 - val_mean_absolute_error: 0.0119
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.1278e-05 - mean_absolute_error: 0.0068 - val_loss: 2.9689e-04 - val_mean_absolute_error: 0.0139
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.8217e-05 - mean_absolute_error: 0.0072 - val_loss: 1.7454e-04 - val_mean_absolute_error: 0.0093
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.3471e-05 - mean_absolute_error: 0.0058 - val_loss: 1.6548e-04 - val_mean_absolute_error: 0.0088
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.0098e-05 - mean_absolute_error: 0.0059 - val_loss: 1.6822e-04 - val_mean_absolute_error: 0.0090
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.5342e-05 - mean_absolute_error: 0.0068 - val_loss: 1.6254e-04 - val_mean_absolute_error: 0.0087
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.0138e-04 - mean_absolute_error: 0.0072 - val_loss: 3.0409e-04 - val_mean_absolute_error: 0.0142
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.7882e-05 - mean_absolute_error: 0.0061 - val_loss: 2.2198e-04 - val_mean_absolute_error: 0.0114
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0217e-04 - mean_absolute_error: 0.0072 - val_loss: 1.6607e-04 - val_mean_absolute_error: 0.0089
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.7007e-05 - mean_absolute_error: 0.0064 - val_loss: 1.6574e-04 - val_mean_absolute_error: 0.0089
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.0667e-05 - mean_absolute_error: 0.0063 - val_loss: 2.4106e-04 - val_mean_absolute_error: 0.0121
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 6.4664e-05 - mean_absolute_error: 0.0056 - val_loss: 2.0900e-04 - val_mean_absolute_error: 0.0110
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.5380e-05 - mean_absolute_error: 0.0067 - val_loss: 1.6615e-04 - val_mean_absolute_error: 0.0090
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.1564e-05 - mean_absolute_error: 0.0065 - val_loss: 1.5800e-04 - val_mean_absolute_error: 0.0086
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.8772e-05 - mean_absolute_error: 0.0058 - val_loss: 2.0466e-04 - val_mean_absolute_error: 0.0108
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.4588e-05 - mean_absolute_error: 0.0069 - val_loss: 1.5640e-04 - val_mean_absolute_error: 0.0085
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.4757e-05 - mean_absolute_error: 0.0060 - val_loss: 1.5578e-04 - val_mean_absolute_error: 0.0085
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.9546e-05 - mean_absolute_error: 0.0069 - val_loss: 2.0527e-04 - val_mean_absolute_error: 0.0108
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.2523e-05 - mean_absolute_error: 0.0068 - val_loss: 1.5981e-04 - val_mean_absolute_error: 0.0087
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 7.9295e-05 - mean_absolute_error: 0.0060 - val_loss: 2.4272e-04 - val_mean_absolute_error: 0.0123
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.0578e-05 - mean_absolute_error: 0.0063 - val_loss: 2.0561e-04 - val_mean_absolute_error: 0.0109
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.9546e-05 - mean_absolute_error: 0.0056 - val_loss: 1.9813e-04 - val_mean_absolute_error: 0.0106
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.2472e-05 - mean_absolute_error: 0.0062 - val_loss: 1.7144e-04 - val_mean_absolute_error: 0.0094
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.0428e-05 - mean_absolute_error: 0.0063 - val_loss: 1.5609e-04 - val_mean_absolute_error: 0.0085
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 6.7824e-05 - mean_absolute_error: 0.0058 - val_loss: 1.6112e-04 - val_mean_absolute_error: 0.0089
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 7.1240e-05 - mean_absolute_error: 0.0061 - val_loss: 1.5566e-04 - val_mean_absolute_error: 0.0086
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 6.5700e-05 - mean_absolute_error: 0.0056 - val_loss: 2.1142e-04 - val_mean_absolute_error: 0.0113
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.2504e-05 - mean_absolute_error: 0.0065 - val_loss: 1.5860e-04 - val_mean_absolute_error: 0.0088
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.9051e-05 - mean_absolute_error: 0.0066 - val_loss: 1.5080e-04 - val_mean_absolute_error: 0.0083
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 6.6851e-05 - mean_absolute_error: 0.0056 - val_loss: 1.4949e-04 - val_mean_absolute_error: 0.0082
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 6.4170e-05 - mean_absolute_error: 0.0055 - val_loss: 1.6604e-04 - val_mean_absolute_error: 0.0092
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.3191e-05 - mean_absolute_error: 0.0055 - val_loss: 1.5278e-04 - val_mean_absolute_error: 0.0084
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.3197e-05 - mean_absolute_error: 0.0055 - val_loss: 2.1087e-04 - val_mean_absolute_error: 0.0113
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 6.5034e-05 - mean_absolute_error: 0.0057 - val_loss: 2.9630e-04 - val_mean_absolute_error: 0.0143
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 8.3290e-05 - mean_absolute_error: 0.0066 - val_loss: 1.5698e-04 - val_mean_absolute_error: 0.0089
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.3448e-05 - mean_absolute_error: 0.0062 - val_loss: 1.8846e-04 - val_mean_absolute_error: 0.0104
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 6.6058e-05 - mean_absolute_error: 0.0057 - val_loss: 1.4984e-04 - val_mean_absolute_error: 0.0083
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 6.6203e-05 - mean_absolute_error: 0.0055 - val_loss: 1.8222e-04 - val_mean_absolute_error: 0.0101
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 8.2332e-05 - mean_absolute_error: 0.0064 - val_loss: 1.7644e-04 - val_mean_absolute_error: 0.0098
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 6.6540e-05 - mean_absolute_error: 0.0055 - val_loss: 2.6231e-04 - val_mean_absolute_error: 0.0132
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.1741e-04 - mean_absolute_error: 0.0079 - val_loss: 1.5043e-04 - val_mean_absolute_error: 0.0085
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.1819e-05 - mean_absolute_error: 0.0055 - val_loss: 1.5092e-04 - val_mean_absolute_error: 0.0086
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 7.9606e-05 - mean_absolute_error: 0.0062 - val_loss: 1.4231e-04 - val_mean_absolute_error: 0.0080
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.4921e-05 - mean_absolute_error: 0.0055 - val_loss: 1.3978e-04 - val_mean_absolute_error: 0.0078
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 6.8426e-05 - mean_absolute_error: 0.0058 - val_loss: 2.1203e-04 - val_mean_absolute_error: 0.0114
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.3638e-05 - mean_absolute_error: 0.0057 - val_loss: 1.8765e-04 - val_mean_absolute_error: 0.0105
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.3961e-05 - mean_absolute_error: 0.0060 - val_loss: 1.6240e-04 - val_mean_absolute_error: 0.0093
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 8.2353e-05 - mean_absolute_error: 0.0066 - val_loss: 2.0936e-04 - val_mean_absolute_error: 0.0113
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 6.4360e-05 - mean_absolute_error: 0.0054 - val_loss: 1.5477e-04 - val_mean_absolute_error: 0.0089
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.8831e-05 - mean_absolute_error: 0.0058 - val_loss: 1.4039e-04 - val_mean_absolute_error: 0.0079
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 5.9595e-05 - mean_absolute_error: 0.0053 - val_loss: 1.5806e-04 - val_mean_absolute_error: 0.0091
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 6.8509e-05 - mean_absolute_error: 0.0057 - val_loss: 1.5832e-04 - val_mean_absolute_error: 0.0091
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 6.5459e-05 - mean_absolute_error: 0.0056 - val_loss: 1.3583e-04 - val_mean_absolute_error: 0.0077
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.5766e-05 - mean_absolute_error: 0.0067 - val_loss: 1.3865e-04 - val_mean_absolute_error: 0.0080
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 5.1993e-05 - mean_absolute_error: 0.0049 - val_loss: 1.3793e-04 - val_mean_absolute_error: 0.0079
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 6.0914e-05 - mean_absolute_error: 0.0053 - val_loss: 1.5342e-04 - val_mean_absolute_error: 0.0089
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.1421e-05 - mean_absolute_error: 0.0066 - val_loss: 1.7434e-04 - val_mean_absolute_error: 0.0100
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.5113e-05 - mean_absolute_error: 0.0051 - val_loss: 1.5444e-04 - val_mean_absolute_error: 0.0090
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.4308e-05 - mean_absolute_error: 0.0050 - val_loss: 1.3210e-04 - val_mean_absolute_error: 0.0076
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.1637e-05 - mean_absolute_error: 0.0054 - val_loss: 1.3775e-04 - val_mean_absolute_error: 0.0080
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.6881e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3711e-04 - val_mean_absolute_error: 0.0080
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.9067e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3237e-04 - val_mean_absolute_error: 0.0077
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.7214e-05 - mean_absolute_error: 0.0048 - val_loss: 1.3536e-04 - val_mean_absolute_error: 0.0079
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.9652e-05 - mean_absolute_error: 0.0047 - val_loss: 1.5876e-04 - val_mean_absolute_error: 0.0093
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.6089e-05 - mean_absolute_error: 0.0052 - val_loss: 1.5810e-04 - val_mean_absolute_error: 0.0092
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.6279e-05 - mean_absolute_error: 0.0056 - val_loss: 1.2922e-04 - val_mean_absolute_error: 0.0075
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.1017e-05 - mean_absolute_error: 0.0052 - val_loss: 1.7925e-04 - val_mean_absolute_error: 0.0103
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 5.9243e-05 - mean_absolute_error: 0.0052 - val_loss: 1.4053e-04 - val_mean_absolute_error: 0.0083
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.4318e-05 - mean_absolute_error: 0.0050 - val_loss: 1.9465e-04 - val_mean_absolute_error: 0.0109
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 6.5013e-05 - mean_absolute_error: 0.0057 - val_loss: 1.5665e-04 - val_mean_absolute_error: 0.0092
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.8180e-05 - mean_absolute_error: 0.0056 - val_loss: 1.4925e-04 - val_mean_absolute_error: 0.0089
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.8947e-05 - mean_absolute_error: 0.0052 - val_loss: 1.5970e-04 - val_mean_absolute_error: 0.0094
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.7434e-05 - mean_absolute_error: 0.0056 - val_loss: 1.6450e-04 - val_mean_absolute_error: 0.0097
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.3448e-05 - mean_absolute_error: 0.0050 - val_loss: 1.3815e-04 - val_mean_absolute_error: 0.0082
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.9433e-05 - mean_absolute_error: 0.0050 - val_loss: 1.4529e-04 - val_mean_absolute_error: 0.0087
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 6.1478e-05 - mean_absolute_error: 0.0055 - val_loss: 1.2540e-04 - val_mean_absolute_error: 0.0074
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.2783e-05 - mean_absolute_error: 0.0051 - val_loss: 1.4633e-04 - val_mean_absolute_error: 0.0088
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.9676e-05 - mean_absolute_error: 0.0048 - val_loss: 1.2392e-04 - val_mean_absolute_error: 0.0074
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.8866e-05 - mean_absolute_error: 0.0046 - val_loss: 1.4025e-04 - val_mean_absolute_error: 0.0085
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.0383e-05 - mean_absolute_error: 0.0057 - val_loss: 1.3871e-04 - val_mean_absolute_error: 0.0084
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.5310e-05 - mean_absolute_error: 0.0057 - val_loss: 1.4871e-04 - val_mean_absolute_error: 0.0090
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.0524e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2844e-04 - val_mean_absolute_error: 0.0077
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.6303e-05 - mean_absolute_error: 0.0051 - val_loss: 1.6536e-04 - val_mean_absolute_error: 0.0098
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.6407e-05 - mean_absolute_error: 0.0048 - val_loss: 1.6769e-04 - val_mean_absolute_error: 0.0099
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 5.5272e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2330e-04 - val_mean_absolute_error: 0.0074
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.8584e-05 - mean_absolute_error: 0.0046 - val_loss: 1.2577e-04 - val_mean_absolute_error: 0.0077
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.3080e-05 - mean_absolute_error: 0.0048 - val_loss: 1.3548e-04 - val_mean_absolute_error: 0.0083
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.3620e-05 - mean_absolute_error: 0.0055 - val_loss: 1.2513e-04 - val_mean_absolute_error: 0.0076
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.0635e-05 - mean_absolute_error: 0.0049 - val_loss: 1.1791e-04 - val_mean_absolute_error: 0.0072
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.7322e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3521e-04 - val_mean_absolute_error: 0.0082
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.3184e-05 - mean_absolute_error: 0.0049 - val_loss: 1.5716e-04 - val_mean_absolute_error: 0.0096
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.8181e-05 - mean_absolute_error: 0.0054 - val_loss: 1.7423e-04 - val_mean_absolute_error: 0.0103
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.0741e-05 - mean_absolute_error: 0.0058 - val_loss: 1.2260e-04 - val_mean_absolute_error: 0.0075
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.1890e-05 - mean_absolute_error: 0.0054 - val_loss: 1.3713e-04 - val_mean_absolute_error: 0.0084
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.1540e-05 - mean_absolute_error: 0.0055 - val_loss: 1.8061e-04 - val_mean_absolute_error: 0.0106
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.1088e-05 - mean_absolute_error: 0.0050 - val_loss: 1.7674e-04 - val_mean_absolute_error: 0.0104
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.8614e-05 - mean_absolute_error: 0.0049 - val_loss: 1.2668e-04 - val_mean_absolute_error: 0.0079
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5426e-05 - mean_absolute_error: 0.0046 - val_loss: 1.8273e-04 - val_mean_absolute_error: 0.0107
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 6.4754e-05 - mean_absolute_error: 0.0055 - val_loss: 1.2061e-04 - val_mean_absolute_error: 0.0075
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.0525e-05 - mean_absolute_error: 0.0049 - val_loss: 1.1611e-04 - val_mean_absolute_error: 0.0072
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.3358e-05 - mean_absolute_error: 0.0044 - val_loss: 1.2168e-04 - val_mean_absolute_error: 0.0075
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.7127e-05 - mean_absolute_error: 0.0044 - val_loss: 2.9348e-04 - val_mean_absolute_error: 0.0147
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.4629e-05 - mean_absolute_error: 0.0057 - val_loss: 1.1277e-04 - val_mean_absolute_error: 0.0070
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.6076e-05 - mean_absolute_error: 0.0045 - val_loss: 1.5159e-04 - val_mean_absolute_error: 0.0094
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 7.0259e-05 - mean_absolute_error: 0.0059 - val_loss: 1.1188e-04 - val_mean_absolute_error: 0.0070
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.4397e-05 - mean_absolute_error: 0.0049 - val_loss: 1.2170e-04 - val_mean_absolute_error: 0.0076
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.6113e-05 - mean_absolute_error: 0.0051 - val_loss: 1.1133e-04 - val_mean_absolute_error: 0.0069
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.0687e-05 - mean_absolute_error: 0.0051 - val_loss: 1.2085e-04 - val_mean_absolute_error: 0.0076
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.2266e-05 - mean_absolute_error: 0.0044 - val_loss: 1.3061e-04 - val_mean_absolute_error: 0.0082
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.4835e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1155e-04 - val_mean_absolute_error: 0.0070
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.3556e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1077e-04 - val_mean_absolute_error: 0.0069
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.0499e-05 - mean_absolute_error: 0.0048 - val_loss: 1.2286e-04 - val_mean_absolute_error: 0.0077
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.4809e-05 - mean_absolute_error: 0.0047 - val_loss: 1.6833e-04 - val_mean_absolute_error: 0.0103

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 327ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4687e-04 - mean_absolute_error: 0.0123
# Test Loss: [0.00016832987603265792, 0.01031316164880991]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 3782598.1627794243
# RMSE: 1944.8902701127959
# MAE: 1448.7579681274901
# MAPE: 2.1054801541069184 %
#
# Model evalution on validate set
# MSE: 16072094.435695723
# RMSE: 4009.0016756913087
# MAE: 3134.184751729249
# MAPE: 3.0739635149053965 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step

# %%
y_pred_30_days
# Out:
# array([[125944.31 ],
#        [126787.5  ],
#        [127901.664],
#        [127966.22 ],
#        [127760.52 ],
#        [127733.02 ],
#        [127762.14 ],
#        [127770.17 ],
#        [127766.19 ],
#        [127764.44 ],
#        [127764.91 ],
#        [127765.23 ],
#        [127765.2  ],
#        [127765.14 ],
#        [127765.14 ],
#        [127765.16 ],
#        [127765.16 ],
#        [127765.14 ],
#        [127765.16 ],
#        [127765.16 ],
#        [127765.14 ],
#        [127765.14 ],
#        [127765.14 ],
#        [127765.14 ],
#        [127765.14 ],
#        [127765.14 ],
#        [127765.14 ],
#        [127765.14 ],
#        [127765.14 ],
#        [127765.14 ],
#        [127765.14 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
