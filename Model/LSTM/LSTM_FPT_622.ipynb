# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: FPT - Test/Train/Vaildation: 60/20/20
# - Dataset: 1313 rows x 7 columns (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1729.6271698815349
# - MAE: 1159.1538688994024
# - MAPE: 1.698084285092822 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#              close
# time
# 2019-03-01   19270
# 2019-03-04   19440
# 2019-03-05   19390
# 2019-03-06   19270
# 2019-03-07   19330
# ...            ...
# 2024-05-27  132800
# 2024-05-28  137000
# 2024-05-29  135700
# 2024-05-30  135000
# 2024-05-31  134600
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((776, 10), (776,), (251, 10), (251,), (253, 10), (253,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 24s 159ms/step - loss: 0.0192 - mean_absolute_error: 0.1006 - val_loss: 0.0051 - val_mean_absolute_error: 0.0689
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.4893e-04 - mean_absolute_error: 0.0169 - val_loss: 4.2438e-04 - val_mean_absolute_error: 0.0155
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.2979e-04 - mean_absolute_error: 0.0106 - val_loss: 5.8518e-04 - val_mean_absolute_error: 0.0197
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.6412e-04 - mean_absolute_error: 0.0090 - val_loss: 3.5416e-04 - val_mean_absolute_error: 0.0133
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6587e-04 - mean_absolute_error: 0.0088 - val_loss: 4.3246e-04 - val_mean_absolute_error: 0.0159
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5476e-04 - mean_absolute_error: 0.0086 - val_loss: 6.5288e-04 - val_mean_absolute_error: 0.0213
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.8492e-04 - mean_absolute_error: 0.0096 - val_loss: 3.6186e-04 - val_mean_absolute_error: 0.0138
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.6762e-04 - mean_absolute_error: 0.0088 - val_loss: 4.5252e-04 - val_mean_absolute_error: 0.0165
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.7533e-04 - mean_absolute_error: 0.0091 - val_loss: 3.5302e-04 - val_mean_absolute_error: 0.0130
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.6761e-04 - mean_absolute_error: 0.0089 - val_loss: 3.8523e-04 - val_mean_absolute_error: 0.0146
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.5179e-04 - mean_absolute_error: 0.0086 - val_loss: 4.4004e-04 - val_mean_absolute_error: 0.0163
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.5254e-04 - mean_absolute_error: 0.0084 - val_loss: 5.3697e-04 - val_mean_absolute_error: 0.0188
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.0293e-04 - mean_absolute_error: 0.0103 - val_loss: 3.4182e-04 - val_mean_absolute_error: 0.0133
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.4947e-04 - mean_absolute_error: 0.0081 - val_loss: 4.0643e-04 - val_mean_absolute_error: 0.0154
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.3942e-04 - mean_absolute_error: 0.0083 - val_loss: 4.7242e-04 - val_mean_absolute_error: 0.0172
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7586e-04 - mean_absolute_error: 0.0097 - val_loss: 3.6749e-04 - val_mean_absolute_error: 0.0142
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8536e-04 - mean_absolute_error: 0.0096 - val_loss: 3.4077e-04 - val_mean_absolute_error: 0.0128
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3821e-04 - mean_absolute_error: 0.0083 - val_loss: 3.2898e-04 - val_mean_absolute_error: 0.0126
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.5071e-04 - mean_absolute_error: 0.0084 - val_loss: 3.3014e-04 - val_mean_absolute_error: 0.0129
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6617e-04 - mean_absolute_error: 0.0086 - val_loss: 4.5934e-04 - val_mean_absolute_error: 0.0170
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6219e-04 - mean_absolute_error: 0.0088 - val_loss: 4.3543e-04 - val_mean_absolute_error: 0.0163
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.5412e-04 - mean_absolute_error: 0.0088 - val_loss: 3.9878e-04 - val_mean_absolute_error: 0.0153
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5381e-04 - mean_absolute_error: 0.0085 - val_loss: 3.5640e-04 - val_mean_absolute_error: 0.0140
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.2761e-04 - mean_absolute_error: 0.0078 - val_loss: 3.1885e-04 - val_mean_absolute_error: 0.0126
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.4875e-04 - mean_absolute_error: 0.0085 - val_loss: 3.2028e-04 - val_mean_absolute_error: 0.0128
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.4235e-04 - mean_absolute_error: 0.0082 - val_loss: 3.1351e-04 - val_mean_absolute_error: 0.0124
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 1.3752e-04 - mean_absolute_error: 0.0082 - val_loss: 4.1432e-04 - val_mean_absolute_error: 0.0158
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.5281e-04 - mean_absolute_error: 0.0084 - val_loss: 3.1845e-04 - val_mean_absolute_error: 0.0124
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5807e-04 - mean_absolute_error: 0.0085 - val_loss: 3.7098e-04 - val_mean_absolute_error: 0.0146
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.5773e-04 - mean_absolute_error: 0.0087 - val_loss: 3.0754e-04 - val_mean_absolute_error: 0.0122
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.4837e-04 - mean_absolute_error: 0.0084 - val_loss: 3.2260e-04 - val_mean_absolute_error: 0.0131
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 1.2698e-04 - mean_absolute_error: 0.0078 - val_loss: 6.1949e-04 - val_mean_absolute_error: 0.0210
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4116e-04 - mean_absolute_error: 0.0084 - val_loss: 3.0145e-04 - val_mean_absolute_error: 0.0122
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3378e-04 - mean_absolute_error: 0.0078 - val_loss: 2.9976e-04 - val_mean_absolute_error: 0.0121
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4064e-04 - mean_absolute_error: 0.0083 - val_loss: 3.0609e-04 - val_mean_absolute_error: 0.0126
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.2376e-04 - mean_absolute_error: 0.0077 - val_loss: 2.9447e-04 - val_mean_absolute_error: 0.0121
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4074e-04 - mean_absolute_error: 0.0084 - val_loss: 3.1642e-04 - val_mean_absolute_error: 0.0130
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.4810e-04 - mean_absolute_error: 0.0084 - val_loss: 3.1273e-04 - val_mean_absolute_error: 0.0129
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.2896e-04 - mean_absolute_error: 0.0079 - val_loss: 3.4827e-04 - val_mean_absolute_error: 0.0141
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.2739e-04 - mean_absolute_error: 0.0076 - val_loss: 3.6922e-04 - val_mean_absolute_error: 0.0147
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2491e-04 - mean_absolute_error: 0.0080 - val_loss: 3.9910e-04 - val_mean_absolute_error: 0.0156
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.4859e-04 - mean_absolute_error: 0.0087 - val_loss: 3.7052e-04 - val_mean_absolute_error: 0.0148
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3682e-04 - mean_absolute_error: 0.0080 - val_loss: 3.1694e-04 - val_mean_absolute_error: 0.0132
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4158e-04 - mean_absolute_error: 0.0085 - val_loss: 3.2030e-04 - val_mean_absolute_error: 0.0134
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 1.5838e-04 - mean_absolute_error: 0.0087 - val_loss: 2.9844e-04 - val_mean_absolute_error: 0.0121
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.4426e-04 - mean_absolute_error: 0.0083 - val_loss: 4.4672e-04 - val_mean_absolute_error: 0.0170
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 1.4815e-04 - mean_absolute_error: 0.0085 - val_loss: 3.9208e-04 - val_mean_absolute_error: 0.0153
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.0395e-04 - mean_absolute_error: 0.0097 - val_loss: 2.9260e-04 - val_mean_absolute_error: 0.0125
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3080e-04 - mean_absolute_error: 0.0078 - val_loss: 2.9856e-04 - val_mean_absolute_error: 0.0127
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.1949e-04 - mean_absolute_error: 0.0075 - val_loss: 8.0845e-04 - val_mean_absolute_error: 0.0250
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.8398e-04 - mean_absolute_error: 0.0101 - val_loss: 3.5189e-04 - val_mean_absolute_error: 0.0145
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.7511e-04 - mean_absolute_error: 0.0096 - val_loss: 2.9400e-04 - val_mean_absolute_error: 0.0122
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5688e-04 - mean_absolute_error: 0.0085 - val_loss: 3.7628e-04 - val_mean_absolute_error: 0.0152
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.4536e-04 - mean_absolute_error: 0.0090 - val_loss: 2.7433e-04 - val_mean_absolute_error: 0.0116
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3115e-04 - mean_absolute_error: 0.0080 - val_loss: 2.9730e-04 - val_mean_absolute_error: 0.0128
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.2501e-04 - mean_absolute_error: 0.0076 - val_loss: 3.0554e-04 - val_mean_absolute_error: 0.0131
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0779e-04 - mean_absolute_error: 0.0072 - val_loss: 2.6310e-04 - val_mean_absolute_error: 0.0117
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3750e-04 - mean_absolute_error: 0.0082 - val_loss: 4.3509e-04 - val_mean_absolute_error: 0.0169
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3879e-04 - mean_absolute_error: 0.0085 - val_loss: 2.5898e-04 - val_mean_absolute_error: 0.0115
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.1476e-04 - mean_absolute_error: 0.0074 - val_loss: 2.7706e-04 - val_mean_absolute_error: 0.0119
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1399e-04 - mean_absolute_error: 0.0103 - val_loss: 2.8066e-04 - val_mean_absolute_error: 0.0124
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.5711e-04 - mean_absolute_error: 0.0088 - val_loss: 4.0662e-04 - val_mean_absolute_error: 0.0163
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.7595e-04 - mean_absolute_error: 0.0102 - val_loss: 3.2114e-04 - val_mean_absolute_error: 0.0136
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.6520e-04 - mean_absolute_error: 0.0093 - val_loss: 5.3827e-04 - val_mean_absolute_error: 0.0196
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.2471e-04 - mean_absolute_error: 0.0079 - val_loss: 2.4117e-04 - val_mean_absolute_error: 0.0108
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.0335e-04 - mean_absolute_error: 0.0070 - val_loss: 2.3657e-04 - val_mean_absolute_error: 0.0108
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3146e-04 - mean_absolute_error: 0.0082 - val_loss: 3.9971e-04 - val_mean_absolute_error: 0.0162
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2235e-04 - mean_absolute_error: 0.0080 - val_loss: 2.3151e-04 - val_mean_absolute_error: 0.0106
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0492e-04 - mean_absolute_error: 0.0071 - val_loss: 3.3319e-04 - val_mean_absolute_error: 0.0142
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.2632e-04 - mean_absolute_error: 0.0078 - val_loss: 3.3415e-04 - val_mean_absolute_error: 0.0143
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.0420e-04 - mean_absolute_error: 0.0072 - val_loss: 2.2444e-04 - val_mean_absolute_error: 0.0105
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 1.2365e-04 - mean_absolute_error: 0.0078 - val_loss: 3.2205e-04 - val_mean_absolute_error: 0.0139
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3993e-04 - mean_absolute_error: 0.0084 - val_loss: 3.8744e-04 - val_mean_absolute_error: 0.0160
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.3556e-04 - mean_absolute_error: 0.0088 - val_loss: 2.2090e-04 - val_mean_absolute_error: 0.0104
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 1.0284e-04 - mean_absolute_error: 0.0070 - val_loss: 2.1812e-04 - val_mean_absolute_error: 0.0103
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 9.8207e-05 - mean_absolute_error: 0.0069 - val_loss: 2.3165e-04 - val_mean_absolute_error: 0.0108
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.1592e-04 - mean_absolute_error: 0.0074 - val_loss: 2.1540e-04 - val_mean_absolute_error: 0.0102
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.1352e-04 - mean_absolute_error: 0.0073 - val_loss: 2.1603e-04 - val_mean_absolute_error: 0.0103
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.1427e-04 - mean_absolute_error: 0.0075 - val_loss: 4.6030e-04 - val_mean_absolute_error: 0.0179
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.0882e-04 - mean_absolute_error: 0.0075 - val_loss: 2.6317e-04 - val_mean_absolute_error: 0.0122
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3155e-04 - mean_absolute_error: 0.0075 - val_loss: 2.7689e-04 - val_mean_absolute_error: 0.0127
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.9808e-05 - mean_absolute_error: 0.0068 - val_loss: 2.5252e-04 - val_mean_absolute_error: 0.0118
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.2175e-05 - mean_absolute_error: 0.0064 - val_loss: 2.2578e-04 - val_mean_absolute_error: 0.0109
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.1708e-04 - mean_absolute_error: 0.0074 - val_loss: 2.7817e-04 - val_mean_absolute_error: 0.0128
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.1222e-05 - mean_absolute_error: 0.0065 - val_loss: 2.3322e-04 - val_mean_absolute_error: 0.0112
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0337e-04 - mean_absolute_error: 0.0071 - val_loss: 2.6152e-04 - val_mean_absolute_error: 0.0123
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 9.2210e-05 - mean_absolute_error: 0.0070 - val_loss: 1.9335e-04 - val_mean_absolute_error: 0.0096
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.0931e-05 - mean_absolute_error: 0.0069 - val_loss: 2.6376e-04 - val_mean_absolute_error: 0.0124
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.0604e-04 - mean_absolute_error: 0.0071 - val_loss: 2.5393e-04 - val_mean_absolute_error: 0.0121
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.0637e-05 - mean_absolute_error: 0.0066 - val_loss: 2.6652e-04 - val_mean_absolute_error: 0.0125
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 8.5237e-05 - mean_absolute_error: 0.0063 - val_loss: 2.1290e-04 - val_mean_absolute_error: 0.0106
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0292e-04 - mean_absolute_error: 0.0070 - val_loss: 2.0269e-04 - val_mean_absolute_error: 0.0102
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.6228e-05 - mean_absolute_error: 0.0060 - val_loss: 3.6818e-04 - val_mean_absolute_error: 0.0160
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.1616e-04 - mean_absolute_error: 0.0078 - val_loss: 1.9332e-04 - val_mean_absolute_error: 0.0099
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 8.3229e-05 - mean_absolute_error: 0.0063 - val_loss: 1.8448e-04 - val_mean_absolute_error: 0.0095
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.2819e-05 - mean_absolute_error: 0.0064 - val_loss: 1.8995e-04 - val_mean_absolute_error: 0.0097
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.6211e-05 - mean_absolute_error: 0.0061 - val_loss: 2.3284e-04 - val_mean_absolute_error: 0.0116
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.6922e-05 - mean_absolute_error: 0.0069 - val_loss: 2.4214e-04 - val_mean_absolute_error: 0.0118
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.3839e-05 - mean_absolute_error: 0.0062 - val_loss: 2.5086e-04 - val_mean_absolute_error: 0.0122
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.7111e-05 - mean_absolute_error: 0.0067 - val_loss: 1.7919e-04 - val_mean_absolute_error: 0.0092
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.4333e-05 - mean_absolute_error: 0.0064 - val_loss: 1.7546e-04 - val_mean_absolute_error: 0.0092
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 7.7093e-05 - mean_absolute_error: 0.0060 - val_loss: 2.0814e-04 - val_mean_absolute_error: 0.0107
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.7035e-05 - mean_absolute_error: 0.0067 - val_loss: 2.2457e-04 - val_mean_absolute_error: 0.0112
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.3067e-05 - mean_absolute_error: 0.0062 - val_loss: 1.8096e-04 - val_mean_absolute_error: 0.0094
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 7.8635e-05 - mean_absolute_error: 0.0062 - val_loss: 1.8137e-04 - val_mean_absolute_error: 0.0094
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.1887e-05 - mean_absolute_error: 0.0064 - val_loss: 4.4258e-04 - val_mean_absolute_error: 0.0179
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.3204e-04 - mean_absolute_error: 0.0084 - val_loss: 1.7527e-04 - val_mean_absolute_error: 0.0093
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.5488e-05 - mean_absolute_error: 0.0059 - val_loss: 1.7130e-04 - val_mean_absolute_error: 0.0090
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.3496e-05 - mean_absolute_error: 0.0065 - val_loss: 1.6779e-04 - val_mean_absolute_error: 0.0089
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.6829e-05 - mean_absolute_error: 0.0058 - val_loss: 2.0008e-04 - val_mean_absolute_error: 0.0104
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.3274e-05 - mean_absolute_error: 0.0059 - val_loss: 2.2899e-04 - val_mean_absolute_error: 0.0115
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 6.9929e-05 - mean_absolute_error: 0.0057 - val_loss: 2.5164e-04 - val_mean_absolute_error: 0.0124
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0903e-04 - mean_absolute_error: 0.0076 - val_loss: 2.1999e-04 - val_mean_absolute_error: 0.0113
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.9510e-05 - mean_absolute_error: 0.0074 - val_loss: 1.8150e-04 - val_mean_absolute_error: 0.0097
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.6208e-05 - mean_absolute_error: 0.0060 - val_loss: 1.7971e-04 - val_mean_absolute_error: 0.0096
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 1.0920e-04 - mean_absolute_error: 0.0076 - val_loss: 2.3669e-04 - val_mean_absolute_error: 0.0119
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.4053e-04 - mean_absolute_error: 0.0086 - val_loss: 1.7325e-04 - val_mean_absolute_error: 0.0092
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.1629e-05 - mean_absolute_error: 0.0068 - val_loss: 1.9349e-04 - val_mean_absolute_error: 0.0102
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.0606e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3277e-04 - val_mean_absolute_error: 0.0118
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.4833e-05 - mean_absolute_error: 0.0061 - val_loss: 3.3281e-04 - val_mean_absolute_error: 0.0152
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.0255e-04 - mean_absolute_error: 0.0072 - val_loss: 2.2098e-04 - val_mean_absolute_error: 0.0114
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.8243e-05 - mean_absolute_error: 0.0063 - val_loss: 1.5904e-04 - val_mean_absolute_error: 0.0086
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.5816e-05 - mean_absolute_error: 0.0060 - val_loss: 1.6399e-04 - val_mean_absolute_error: 0.0089
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.6552e-05 - mean_absolute_error: 0.0056 - val_loss: 3.2255e-04 - val_mean_absolute_error: 0.0149
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.1752e-05 - mean_absolute_error: 0.0067 - val_loss: 1.5580e-04 - val_mean_absolute_error: 0.0085
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.8805e-05 - mean_absolute_error: 0.0058 - val_loss: 2.2738e-04 - val_mean_absolute_error: 0.0117
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 7.6598e-05 - mean_absolute_error: 0.0062 - val_loss: 2.2975e-04 - val_mean_absolute_error: 0.0118
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.9850e-05 - mean_absolute_error: 0.0068 - val_loss: 1.6267e-04 - val_mean_absolute_error: 0.0088
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.7563e-05 - mean_absolute_error: 0.0056 - val_loss: 1.7303e-04 - val_mean_absolute_error: 0.0095
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.9466e-05 - mean_absolute_error: 0.0058 - val_loss: 1.6729e-04 - val_mean_absolute_error: 0.0091
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 6.9778e-05 - mean_absolute_error: 0.0058 - val_loss: 2.1208e-04 - val_mean_absolute_error: 0.0112
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.2443e-05 - mean_absolute_error: 0.0059 - val_loss: 1.5880e-04 - val_mean_absolute_error: 0.0087
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 7.1156e-05 - mean_absolute_error: 0.0057 - val_loss: 1.8093e-04 - val_mean_absolute_error: 0.0099
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.9455e-05 - mean_absolute_error: 0.0053 - val_loss: 1.5311e-04 - val_mean_absolute_error: 0.0084
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.4901e-05 - mean_absolute_error: 0.0059 - val_loss: 1.5521e-04 - val_mean_absolute_error: 0.0085
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.0023e-05 - mean_absolute_error: 0.0057 - val_loss: 1.5192e-04 - val_mean_absolute_error: 0.0083
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.1262e-05 - mean_absolute_error: 0.0057 - val_loss: 1.7549e-04 - val_mean_absolute_error: 0.0097
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.0237e-05 - mean_absolute_error: 0.0057 - val_loss: 1.4871e-04 - val_mean_absolute_error: 0.0082
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 6.5687e-05 - mean_absolute_error: 0.0056 - val_loss: 1.4836e-04 - val_mean_absolute_error: 0.0082
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.4864e-05 - mean_absolute_error: 0.0054 - val_loss: 1.5882e-04 - val_mean_absolute_error: 0.0088
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.8330e-05 - mean_absolute_error: 0.0057 - val_loss: 2.0636e-04 - val_mean_absolute_error: 0.0111
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0551e-04 - mean_absolute_error: 0.0073 - val_loss: 1.6237e-04 - val_mean_absolute_error: 0.0090
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.2385e-05 - mean_absolute_error: 0.0055 - val_loss: 1.4683e-04 - val_mean_absolute_error: 0.0081
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.2345e-05 - mean_absolute_error: 0.0059 - val_loss: 1.5341e-04 - val_mean_absolute_error: 0.0085
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.9475e-05 - mean_absolute_error: 0.0054 - val_loss: 1.4411e-04 - val_mean_absolute_error: 0.0080
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.8240e-05 - mean_absolute_error: 0.0055 - val_loss: 1.6652e-04 - val_mean_absolute_error: 0.0094
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.3396e-05 - mean_absolute_error: 0.0055 - val_loss: 1.4704e-04 - val_mean_absolute_error: 0.0082
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.2673e-05 - mean_absolute_error: 0.0057 - val_loss: 2.2745e-04 - val_mean_absolute_error: 0.0120
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.9830e-05 - mean_absolute_error: 0.0073 - val_loss: 1.6262e-04 - val_mean_absolute_error: 0.0091
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.1258e-05 - mean_absolute_error: 0.0058 - val_loss: 2.7637e-04 - val_mean_absolute_error: 0.0138
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.7841e-05 - mean_absolute_error: 0.0062 - val_loss: 1.6291e-04 - val_mean_absolute_error: 0.0092
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.1241e-05 - mean_absolute_error: 0.0053 - val_loss: 1.6553e-04 - val_mean_absolute_error: 0.0094
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.2667e-05 - mean_absolute_error: 0.0056 - val_loss: 1.4439e-04 - val_mean_absolute_error: 0.0081
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.7090e-05 - mean_absolute_error: 0.0057 - val_loss: 1.4839e-04 - val_mean_absolute_error: 0.0084
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.7201e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3867e-04 - val_mean_absolute_error: 0.0078
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.4049e-05 - mean_absolute_error: 0.0058 - val_loss: 1.5667e-04 - val_mean_absolute_error: 0.0090
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 5.8760e-05 - mean_absolute_error: 0.0053 - val_loss: 1.8087e-04 - val_mean_absolute_error: 0.0102
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.0803e-05 - mean_absolute_error: 0.0054 - val_loss: 1.4679e-04 - val_mean_absolute_error: 0.0084
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.1413e-05 - mean_absolute_error: 0.0054 - val_loss: 1.7919e-04 - val_mean_absolute_error: 0.0101
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.4224e-05 - mean_absolute_error: 0.0057 - val_loss: 1.4389e-04 - val_mean_absolute_error: 0.0082
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.4811e-05 - mean_absolute_error: 0.0057 - val_loss: 1.3755e-04 - val_mean_absolute_error: 0.0077
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.3149e-05 - mean_absolute_error: 0.0075 - val_loss: 1.4690e-04 - val_mean_absolute_error: 0.0084
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.7660e-05 - mean_absolute_error: 0.0061 - val_loss: 1.5408e-04 - val_mean_absolute_error: 0.0089
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.5552e-05 - mean_absolute_error: 0.0057 - val_loss: 1.9876e-04 - val_mean_absolute_error: 0.0110
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.4405e-05 - mean_absolute_error: 0.0058 - val_loss: 1.3361e-04 - val_mean_absolute_error: 0.0076
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.8647e-05 - mean_absolute_error: 0.0048 - val_loss: 1.3231e-04 - val_mean_absolute_error: 0.0076
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.0948e-05 - mean_absolute_error: 0.0053 - val_loss: 1.3410e-04 - val_mean_absolute_error: 0.0077
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.6822e-05 - mean_absolute_error: 0.0048 - val_loss: 1.4263e-04 - val_mean_absolute_error: 0.0083
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.4242e-05 - mean_absolute_error: 0.0055 - val_loss: 1.3263e-04 - val_mean_absolute_error: 0.0077
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.9952e-05 - mean_absolute_error: 0.0048 - val_loss: 1.3083e-04 - val_mean_absolute_error: 0.0076
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.2821e-05 - mean_absolute_error: 0.0051 - val_loss: 1.4264e-04 - val_mean_absolute_error: 0.0084
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.4564e-05 - mean_absolute_error: 0.0056 - val_loss: 1.4609e-04 - val_mean_absolute_error: 0.0085
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.3001e-05 - mean_absolute_error: 0.0053 - val_loss: 1.6162e-04 - val_mean_absolute_error: 0.0095
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.6742e-05 - mean_absolute_error: 0.0059 - val_loss: 1.4027e-04 - val_mean_absolute_error: 0.0083
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.6095e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2841e-04 - val_mean_absolute_error: 0.0075
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.3708e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2709e-04 - val_mean_absolute_error: 0.0074
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.9488e-05 - mean_absolute_error: 0.0051 - val_loss: 1.3345e-04 - val_mean_absolute_error: 0.0078
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.1577e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2686e-04 - val_mean_absolute_error: 0.0074
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.9847e-05 - mean_absolute_error: 0.0051 - val_loss: 1.3560e-04 - val_mean_absolute_error: 0.0080
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.5261e-05 - mean_absolute_error: 0.0049 - val_loss: 1.3013e-04 - val_mean_absolute_error: 0.0078
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.2783e-05 - mean_absolute_error: 0.0051 - val_loss: 1.2415e-04 - val_mean_absolute_error: 0.0074
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.0496e-05 - mean_absolute_error: 0.0048 - val_loss: 1.2692e-04 - val_mean_absolute_error: 0.0075
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.1037e-05 - mean_absolute_error: 0.0048 - val_loss: 1.3490e-04 - val_mean_absolute_error: 0.0080
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.8618e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2784e-04 - val_mean_absolute_error: 0.0076
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.5885e-05 - mean_absolute_error: 0.0051 - val_loss: 2.2149e-04 - val_mean_absolute_error: 0.0120
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.3481e-05 - mean_absolute_error: 0.0062 - val_loss: 1.4991e-04 - val_mean_absolute_error: 0.0089
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.1964e-05 - mean_absolute_error: 0.0051 - val_loss: 1.9352e-04 - val_mean_absolute_error: 0.0110
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.8100e-05 - mean_absolute_error: 0.0051 - val_loss: 1.6124e-04 - val_mean_absolute_error: 0.0096
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.4644e-05 - mean_absolute_error: 0.0055 - val_loss: 1.5733e-04 - val_mean_absolute_error: 0.0094
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.4401e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1948e-04 - val_mean_absolute_error: 0.0073
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.3660e-05 - mean_absolute_error: 0.0051 - val_loss: 1.2998e-04 - val_mean_absolute_error: 0.0079
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.2851e-05 - mean_absolute_error: 0.0044 - val_loss: 1.3461e-04 - val_mean_absolute_error: 0.0082
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.9091e-05 - mean_absolute_error: 0.0053 - val_loss: 1.1908e-04 - val_mean_absolute_error: 0.0072
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.3577e-05 - mean_absolute_error: 0.0049 - val_loss: 1.5787e-04 - val_mean_absolute_error: 0.0095
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.7174e-05 - mean_absolute_error: 0.0054 - val_loss: 1.3236e-04 - val_mean_absolute_error: 0.0081
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.7060e-05 - mean_absolute_error: 0.0051 - val_loss: 1.2443e-04 - val_mean_absolute_error: 0.0076
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.3612e-05 - mean_absolute_error: 0.0051 - val_loss: 1.8065e-04 - val_mean_absolute_error: 0.0106
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.0915e-05 - mean_absolute_error: 0.0061 - val_loss: 1.3999e-04 - val_mean_absolute_error: 0.0086
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 7.6364e-05 - mean_absolute_error: 0.0062 - val_loss: 1.1798e-04 - val_mean_absolute_error: 0.0073
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.2839e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1434e-04 - val_mean_absolute_error: 0.0070

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 150ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8383e-04 - mean_absolute_error: 0.0091
# Test Loss: [0.00011434441694291309, 0.007013894617557526]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 2991610.146792408
# RMSE: 1729.6271698815349
# MAE: 1159.1538688994024
# MAPE: 1.698084285092822 %
#
# Model evalution on validate set
# MSE: 7705129.234695374
# RMSE: 2775.811455177634
# MAE: 1946.1908349802372
# MAPE: 1.8972325759911022 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 751ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step

# %%
y_pred_30_days
# Out:
# array([[130681.67 ],
#        [130187.92 ],
#        [130576.91 ],
#        [130938.42 ],
#        [131084.1  ],
#        [131061.695],
#        [131015.21 ],
#        [130993.48 ],
#        [130992.4  ],
#        [130997.414],
#        [131000.586],
#        [131001.18 ],
#        [131000.71 ],
#        [131000.29 ],
#        [131000.14 ],
#        [131000.17 ],
#        [131000.23 ],
#        [131000.24 ],
#        [131000.24 ],
#        [131000.24 ],
#        [131000.24 ],
#        [131000.24 ],
#        [131000.24 ],
#        [131000.24 ],
#        [131000.24 ],
#        [131000.24 ],
#        [131000.24 ],
#        [131000.24 ],
#        [131000.24 ],
#        [131000.24 ],
#        [131000.24 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Forecast Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
