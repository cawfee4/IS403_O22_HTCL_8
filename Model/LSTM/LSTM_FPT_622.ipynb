# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: FPT - Test/Train/Vaildation: 60/20/20
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 2129.89
# - MAE: 1501.56
# - MAPE: 2.15 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#              close
# time
# 2019-03-01   19270
# 2019-03-04   19440
# 2019-03-05   19390
# 2019-03-06   19270
# 2019-03-07   19330
# ...            ...
# 2024-02-26  108000
# 2024-02-27  107900
# 2024-02-28  108500
# 2024-02-29  109000
# 2024-03-01  110800
#
# [1252 rows x 1 columns]

# %%
df.shape
# Out:
# (1252, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1247    108000
# 1248    107900
# 1249    108500
# 1250    109000
# 1251    110800
# Name: close, Length: 1252, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((740, 10), (740,), (239, 10), (239,), (240, 10), (240,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0361 - mean_absolute_error: 0.1329 - val_loss: 0.0199 - val_mean_absolute_error: 0.1374
# Epoch 2/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0028 - mean_absolute_error: 0.0372 - val_loss: 0.0015 - val_mean_absolute_error: 0.0308
# Epoch 3/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0894e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0013 - val_mean_absolute_error: 0.0276
# Epoch 4/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3947e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0013 - val_mean_absolute_error: 0.0287
# Epoch 5/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5424e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0011 - val_mean_absolute_error: 0.0246
# Epoch 6/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2539e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0011 - val_mean_absolute_error: 0.0254
# Epoch 7/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4855e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0011 - val_mean_absolute_error: 0.0249
# Epoch 8/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2014e-04 - mean_absolute_error: 0.0107 - val_loss: 9.8272e-04 - val_mean_absolute_error: 0.0234
# Epoch 9/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0269e-04 - mean_absolute_error: 0.0100 - val_loss: 9.7205e-04 - val_mean_absolute_error: 0.0224
# Epoch 10/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2194e-04 - mean_absolute_error: 0.0105 - val_loss: 9.5800e-04 - val_mean_absolute_error: 0.0230
# Epoch 11/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1864e-04 - mean_absolute_error: 0.0105 - val_loss: 9.4852e-04 - val_mean_absolute_error: 0.0228
# Epoch 12/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0613e-04 - mean_absolute_error: 0.0103 - val_loss: 9.4115e-04 - val_mean_absolute_error: 0.0222
# Epoch 13/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2166e-04 - mean_absolute_error: 0.0102 - val_loss: 9.5903e-04 - val_mean_absolute_error: 0.0223
# Epoch 14/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0687e-04 - mean_absolute_error: 0.0101 - val_loss: 9.2625e-04 - val_mean_absolute_error: 0.0220
# Epoch 15/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9005e-04 - mean_absolute_error: 0.0099 - val_loss: 9.2481e-04 - val_mean_absolute_error: 0.0220
# Epoch 16/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9290e-04 - mean_absolute_error: 0.0099 - val_loss: 9.0997e-04 - val_mean_absolute_error: 0.0220
# Epoch 17/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0049e-04 - mean_absolute_error: 0.0098 - val_loss: 9.2943e-04 - val_mean_absolute_error: 0.0228
# Epoch 18/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9509e-04 - mean_absolute_error: 0.0097 - val_loss: 9.0790e-04 - val_mean_absolute_error: 0.0219
# Epoch 19/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7251e-04 - mean_absolute_error: 0.0094 - val_loss: 8.9938e-04 - val_mean_absolute_error: 0.0221
# Epoch 20/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9656e-04 - mean_absolute_error: 0.0100 - val_loss: 8.9028e-04 - val_mean_absolute_error: 0.0218
# Epoch 21/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8558e-04 - mean_absolute_error: 0.0099 - val_loss: 8.9353e-04 - val_mean_absolute_error: 0.0221
# Epoch 22/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8062e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0010 - val_mean_absolute_error: 0.0229
# Epoch 23/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0173e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0010 - val_mean_absolute_error: 0.0232
# Epoch 24/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1327e-04 - mean_absolute_error: 0.0104 - val_loss: 9.1926e-04 - val_mean_absolute_error: 0.0229
# Epoch 25/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0201e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0010 - val_mean_absolute_error: 0.0231
# Epoch 26/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1526e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0011 - val_mean_absolute_error: 0.0251
# Epoch 27/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2270e-04 - mean_absolute_error: 0.0108 - val_loss: 9.2445e-04 - val_mean_absolute_error: 0.0219
# Epoch 28/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8503e-04 - mean_absolute_error: 0.0097 - val_loss: 8.6391e-04 - val_mean_absolute_error: 0.0214
# Epoch 29/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8568e-04 - mean_absolute_error: 0.0097 - val_loss: 8.8013e-04 - val_mean_absolute_error: 0.0214
# Epoch 30/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7331e-04 - mean_absolute_error: 0.0095 - val_loss: 8.5421e-04 - val_mean_absolute_error: 0.0213
# Epoch 31/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6299e-04 - mean_absolute_error: 0.0092 - val_loss: 8.4565e-04 - val_mean_absolute_error: 0.0213
# Epoch 32/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2594e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0010 - val_mean_absolute_error: 0.0251
# Epoch 33/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8316e-04 - mean_absolute_error: 0.0102 - val_loss: 9.5151e-04 - val_mean_absolute_error: 0.0223
# Epoch 34/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0739e-04 - mean_absolute_error: 0.0102 - val_loss: 9.6232e-04 - val_mean_absolute_error: 0.0224
# Epoch 35/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8083e-04 - mean_absolute_error: 0.0097 - val_loss: 8.8869e-04 - val_mean_absolute_error: 0.0214
# Epoch 36/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5132e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0012 - val_mean_absolute_error: 0.0260
# Epoch 37/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0009e-04 - mean_absolute_error: 0.0104 - val_loss: 8.2289e-04 - val_mean_absolute_error: 0.0208
# Epoch 38/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8546e-04 - mean_absolute_error: 0.0099 - val_loss: 8.3113e-04 - val_mean_absolute_error: 0.0215
# Epoch 39/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8041e-04 - mean_absolute_error: 0.0095 - val_loss: 9.5291e-04 - val_mean_absolute_error: 0.0224
# Epoch 40/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4427e-04 - mean_absolute_error: 0.0110 - val_loss: 8.0170e-04 - val_mean_absolute_error: 0.0207
# Epoch 41/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0418e-04 - mean_absolute_error: 0.0105 - val_loss: 7.9504e-04 - val_mean_absolute_error: 0.0206
# Epoch 42/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9552e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0011 - val_mean_absolute_error: 0.0258
# Epoch 43/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7734e-04 - mean_absolute_error: 0.0097 - val_loss: 9.7403e-04 - val_mean_absolute_error: 0.0229
# Epoch 44/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8016e-04 - mean_absolute_error: 0.0095 - val_loss: 9.1947e-04 - val_mean_absolute_error: 0.0220
# Epoch 45/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2218e-04 - mean_absolute_error: 0.0108 - val_loss: 8.4598e-04 - val_mean_absolute_error: 0.0221
# Epoch 46/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3367e-04 - mean_absolute_error: 0.0114 - val_loss: 7.8141e-04 - val_mean_absolute_error: 0.0202
# Epoch 47/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8254e-04 - mean_absolute_error: 0.0099 - val_loss: 8.5780e-04 - val_mean_absolute_error: 0.0211
# Epoch 48/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7276e-04 - mean_absolute_error: 0.0094 - val_loss: 7.6425e-04 - val_mean_absolute_error: 0.0200
# Epoch 49/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5835e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0010 - val_mean_absolute_error: 0.0238
# Epoch 50/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0092e-04 - mean_absolute_error: 0.0105 - val_loss: 7.4841e-04 - val_mean_absolute_error: 0.0199
# Epoch 51/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7505e-04 - mean_absolute_error: 0.0093 - val_loss: 7.7535e-04 - val_mean_absolute_error: 0.0208
# Epoch 52/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8166e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248
# Epoch 53/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2564e-04 - mean_absolute_error: 0.0105 - val_loss: 7.3696e-04 - val_mean_absolute_error: 0.0200
# Epoch 54/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8031e-04 - mean_absolute_error: 0.0096 - val_loss: 8.1735e-04 - val_mean_absolute_error: 0.0206
# Epoch 55/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8161e-04 - mean_absolute_error: 0.0097 - val_loss: 7.3295e-04 - val_mean_absolute_error: 0.0200
# Epoch 56/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7050e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0012 - val_mean_absolute_error: 0.0274
# Epoch 57/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3494e-04 - mean_absolute_error: 0.0111 - val_loss: 8.1563e-04 - val_mean_absolute_error: 0.0219
# Epoch 58/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0467e-04 - mean_absolute_error: 0.0106 - val_loss: 7.5783e-04 - val_mean_absolute_error: 0.0197
# Epoch 59/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7028e-04 - mean_absolute_error: 0.0092 - val_loss: 7.0018e-04 - val_mean_absolute_error: 0.0191
# Epoch 60/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6352e-04 - mean_absolute_error: 0.0094 - val_loss: 6.9839e-04 - val_mean_absolute_error: 0.0190
# Epoch 61/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6540e-04 - mean_absolute_error: 0.0095 - val_loss: 7.5541e-04 - val_mean_absolute_error: 0.0198
# Epoch 62/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7096e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0010 - val_mean_absolute_error: 0.0253
# Epoch 63/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0661e-04 - mean_absolute_error: 0.0102 - val_loss: 7.4379e-04 - val_mean_absolute_error: 0.0207
# Epoch 64/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6590e-04 - mean_absolute_error: 0.0093 - val_loss: 6.8024e-04 - val_mean_absolute_error: 0.0187
# Epoch 65/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4766e-04 - mean_absolute_error: 0.0089 - val_loss: 6.6573e-04 - val_mean_absolute_error: 0.0186
# Epoch 66/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4259e-04 - mean_absolute_error: 0.0086 - val_loss: 8.2583e-04 - val_mean_absolute_error: 0.0213
# Epoch 67/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3457e-04 - mean_absolute_error: 0.0083 - val_loss: 9.1152e-04 - val_mean_absolute_error: 0.0231
# Epoch 68/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3749e-04 - mean_absolute_error: 0.0085 - val_loss: 6.5179e-04 - val_mean_absolute_error: 0.0182
# Epoch 69/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6473e-04 - mean_absolute_error: 0.0092 - val_loss: 7.0601e-04 - val_mean_absolute_error: 0.0191
# Epoch 70/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4549e-04 - mean_absolute_error: 0.0085 - val_loss: 6.3559e-04 - val_mean_absolute_error: 0.0180
# Epoch 71/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7057e-04 - mean_absolute_error: 0.0094 - val_loss: 6.2449e-04 - val_mean_absolute_error: 0.0179
# Epoch 72/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4241e-04 - mean_absolute_error: 0.0085 - val_loss: 6.1737e-04 - val_mean_absolute_error: 0.0181
# Epoch 73/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5286e-04 - mean_absolute_error: 0.0088 - val_loss: 6.0812e-04 - val_mean_absolute_error: 0.0178
# Epoch 74/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5885e-04 - mean_absolute_error: 0.0092 - val_loss: 6.3853e-04 - val_mean_absolute_error: 0.0189
# Epoch 75/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5324e-04 - mean_absolute_error: 0.0090 - val_loss: 6.3349e-04 - val_mean_absolute_error: 0.0179
# Epoch 76/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3064e-04 - mean_absolute_error: 0.0082 - val_loss: 5.8796e-04 - val_mean_absolute_error: 0.0176
# Epoch 77/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5805e-04 - mean_absolute_error: 0.0091 - val_loss: 9.2197e-04 - val_mean_absolute_error: 0.0240
# Epoch 78/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7946e-04 - mean_absolute_error: 0.0095 - val_loss: 5.7706e-04 - val_mean_absolute_error: 0.0173
# Epoch 79/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6405e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0012 - val_mean_absolute_error: 0.0287
# Epoch 80/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5586e-04 - mean_absolute_error: 0.0092 - val_loss: 5.7155e-04 - val_mean_absolute_error: 0.0174
# Epoch 81/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4494e-04 - mean_absolute_error: 0.0088 - val_loss: 5.7451e-04 - val_mean_absolute_error: 0.0170
# Epoch 82/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2713e-04 - mean_absolute_error: 0.0079 - val_loss: 8.8625e-04 - val_mean_absolute_error: 0.0241
# Epoch 83/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0859e-04 - mean_absolute_error: 0.0106 - val_loss: 5.6956e-04 - val_mean_absolute_error: 0.0170
# Epoch 84/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5848e-04 - mean_absolute_error: 0.0089 - val_loss: 5.8042e-04 - val_mean_absolute_error: 0.0172
# Epoch 85/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4144e-04 - mean_absolute_error: 0.0084 - val_loss: 5.5493e-04 - val_mean_absolute_error: 0.0172
# Epoch 86/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3288e-04 - mean_absolute_error: 0.0084 - val_loss: 5.8132e-04 - val_mean_absolute_error: 0.0173
# Epoch 87/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4834e-04 - mean_absolute_error: 0.0088 - val_loss: 6.9101e-04 - val_mean_absolute_error: 0.0205
# Epoch 88/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5927e-04 - mean_absolute_error: 0.0088 - val_loss: 5.5369e-04 - val_mean_absolute_error: 0.0169
# Epoch 89/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1735e-04 - mean_absolute_error: 0.0078 - val_loss: 5.1312e-04 - val_mean_absolute_error: 0.0162
# Epoch 90/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4907e-04 - mean_absolute_error: 0.0087 - val_loss: 7.4580e-04 - val_mean_absolute_error: 0.0217
# Epoch 91/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4911e-04 - mean_absolute_error: 0.0090 - val_loss: 5.7924e-04 - val_mean_absolute_error: 0.0177
# Epoch 92/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4258e-04 - mean_absolute_error: 0.0084 - val_loss: 5.9894e-04 - val_mean_absolute_error: 0.0182
# Epoch 93/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3128e-04 - mean_absolute_error: 0.0085 - val_loss: 6.3421e-04 - val_mean_absolute_error: 0.0191
# Epoch 94/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3434e-04 - mean_absolute_error: 0.0083 - val_loss: 4.9291e-04 - val_mean_absolute_error: 0.0158
# Epoch 95/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2566e-04 - mean_absolute_error: 0.0078 - val_loss: 8.4553e-04 - val_mean_absolute_error: 0.0236
# Epoch 96/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2930e-04 - mean_absolute_error: 0.0110 - val_loss: 4.9327e-04 - val_mean_absolute_error: 0.0158
# Epoch 97/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3146e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0010 - val_mean_absolute_error: 0.0272
# Epoch 98/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7046e-04 - mean_absolute_error: 0.0125 - val_loss: 6.2179e-04 - val_mean_absolute_error: 0.0192
# Epoch 99/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4941e-04 - mean_absolute_error: 0.0088 - val_loss: 6.4570e-04 - val_mean_absolute_error: 0.0194
# Epoch 100/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2757e-04 - mean_absolute_error: 0.0081 - val_loss: 5.1517e-04 - val_mean_absolute_error: 0.0164
# Epoch 101/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5337e-04 - mean_absolute_error: 0.0093 - val_loss: 4.8130e-04 - val_mean_absolute_error: 0.0156
# Epoch 102/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3753e-04 - mean_absolute_error: 0.0084 - val_loss: 4.6748e-04 - val_mean_absolute_error: 0.0154
# Epoch 103/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1633e-04 - mean_absolute_error: 0.0077 - val_loss: 4.6192e-04 - val_mean_absolute_error: 0.0153
# Epoch 104/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1135e-04 - mean_absolute_error: 0.0074 - val_loss: 4.8899e-04 - val_mean_absolute_error: 0.0161
# Epoch 105/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0970e-04 - mean_absolute_error: 0.0074 - val_loss: 4.6029e-04 - val_mean_absolute_error: 0.0154
# Epoch 106/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2215e-04 - mean_absolute_error: 0.0079 - val_loss: 4.8098e-04 - val_mean_absolute_error: 0.0160
# Epoch 107/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2174e-04 - mean_absolute_error: 0.0075 - val_loss: 5.7082e-04 - val_mean_absolute_error: 0.0183
# Epoch 108/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3890e-04 - mean_absolute_error: 0.0083 - val_loss: 4.8936e-04 - val_mean_absolute_error: 0.0163
# Epoch 109/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0751e-04 - mean_absolute_error: 0.0073 - val_loss: 4.3560e-04 - val_mean_absolute_error: 0.0149
# Epoch 110/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1442e-04 - mean_absolute_error: 0.0076 - val_loss: 6.8035e-04 - val_mean_absolute_error: 0.0208
# Epoch 111/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2385e-04 - mean_absolute_error: 0.0080 - val_loss: 4.8779e-04 - val_mean_absolute_error: 0.0163
# Epoch 112/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2203e-04 - mean_absolute_error: 0.0080 - val_loss: 4.5669e-04 - val_mean_absolute_error: 0.0156
# Epoch 113/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0862e-04 - mean_absolute_error: 0.0072 - val_loss: 5.3981e-04 - val_mean_absolute_error: 0.0177
# Epoch 114/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3416e-04 - mean_absolute_error: 0.0085 - val_loss: 4.4726e-04 - val_mean_absolute_error: 0.0154
# Epoch 115/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2914e-04 - mean_absolute_error: 0.0080 - val_loss: 9.7552e-04 - val_mean_absolute_error: 0.0265
# Epoch 116/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2631e-04 - mean_absolute_error: 0.0111 - val_loss: 5.0815e-04 - val_mean_absolute_error: 0.0170
# Epoch 117/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1706e-04 - mean_absolute_error: 0.0077 - val_loss: 4.2801e-04 - val_mean_absolute_error: 0.0147
# Epoch 118/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1301e-04 - mean_absolute_error: 0.0076 - val_loss: 4.5477e-04 - val_mean_absolute_error: 0.0156
# Epoch 119/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1881e-04 - mean_absolute_error: 0.0077 - val_loss: 4.1915e-04 - val_mean_absolute_error: 0.0145
# Epoch 120/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.2769e-05 - mean_absolute_error: 0.0069 - val_loss: 8.3707e-04 - val_mean_absolute_error: 0.0241
# Epoch 121/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2361e-04 - mean_absolute_error: 0.0081 - val_loss: 4.5437e-04 - val_mean_absolute_error: 0.0156
# Epoch 122/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4382e-04 - mean_absolute_error: 0.0087 - val_loss: 4.2246e-04 - val_mean_absolute_error: 0.0149
# Epoch 123/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6037e-05 - mean_absolute_error: 0.0069 - val_loss: 4.2658e-04 - val_mean_absolute_error: 0.0150
# Epoch 124/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0876e-04 - mean_absolute_error: 0.0075 - val_loss: 4.5291e-04 - val_mean_absolute_error: 0.0157
# Epoch 125/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2595e-04 - mean_absolute_error: 0.0080 - val_loss: 4.1331e-04 - val_mean_absolute_error: 0.0147
# Epoch 126/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1436e-04 - mean_absolute_error: 0.0078 - val_loss: 4.9465e-04 - val_mean_absolute_error: 0.0168
# Epoch 127/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2212e-04 - mean_absolute_error: 0.0078 - val_loss: 4.2520e-04 - val_mean_absolute_error: 0.0151
# Epoch 128/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0143e-04 - mean_absolute_error: 0.0070 - val_loss: 3.8882e-04 - val_mean_absolute_error: 0.0140
# Epoch 129/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6057e-05 - mean_absolute_error: 0.0068 - val_loss: 3.8247e-04 - val_mean_absolute_error: 0.0139
# Epoch 130/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6179e-05 - mean_absolute_error: 0.0068 - val_loss: 3.8005e-04 - val_mean_absolute_error: 0.0138
# Epoch 131/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0029e-04 - mean_absolute_error: 0.0070 - val_loss: 4.5994e-04 - val_mean_absolute_error: 0.0161
# Epoch 132/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1756e-04 - mean_absolute_error: 0.0079 - val_loss: 3.7686e-04 - val_mean_absolute_error: 0.0137
# Epoch 133/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0085e-04 - mean_absolute_error: 0.0070 - val_loss: 3.7896e-04 - val_mean_absolute_error: 0.0137
# Epoch 134/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0058e-04 - mean_absolute_error: 0.0068 - val_loss: 3.7977e-04 - val_mean_absolute_error: 0.0137
# Epoch 135/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4875e-05 - mean_absolute_error: 0.0068 - val_loss: 3.8507e-04 - val_mean_absolute_error: 0.0140
# Epoch 136/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5946e-05 - mean_absolute_error: 0.0068 - val_loss: 5.1248e-04 - val_mean_absolute_error: 0.0175
# Epoch 137/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2506e-04 - mean_absolute_error: 0.0079 - val_loss: 4.0306e-04 - val_mean_absolute_error: 0.0146
# Epoch 138/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3470e-05 - mean_absolute_error: 0.0066 - val_loss: 3.8094e-04 - val_mean_absolute_error: 0.0139
# Epoch 139/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0751e-04 - mean_absolute_error: 0.0071 - val_loss: 4.8897e-04 - val_mean_absolute_error: 0.0170
# Epoch 140/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0359e-04 - mean_absolute_error: 0.0072 - val_loss: 5.4414e-04 - val_mean_absolute_error: 0.0184
# Epoch 141/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1036e-04 - mean_absolute_error: 0.0077 - val_loss: 5.0316e-04 - val_mean_absolute_error: 0.0173
# Epoch 142/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1179e-04 - mean_absolute_error: 0.0077 - val_loss: 5.4445e-04 - val_mean_absolute_error: 0.0183
# Epoch 143/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9124e-04 - mean_absolute_error: 0.0101 - val_loss: 4.9538e-04 - val_mean_absolute_error: 0.0172
# Epoch 144/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2351e-04 - mean_absolute_error: 0.0079 - val_loss: 3.8008e-04 - val_mean_absolute_error: 0.0138
# Epoch 145/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1497e-05 - mean_absolute_error: 0.0069 - val_loss: 3.7363e-04 - val_mean_absolute_error: 0.0137
# Epoch 146/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3916e-05 - mean_absolute_error: 0.0066 - val_loss: 3.5914e-04 - val_mean_absolute_error: 0.0132
# Epoch 147/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3287e-04 - mean_absolute_error: 0.0085 - val_loss: 3.9832e-04 - val_mean_absolute_error: 0.0145
# Epoch 148/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1312e-05 - mean_absolute_error: 0.0064 - val_loss: 4.9493e-04 - val_mean_absolute_error: 0.0173
# Epoch 149/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0649e-04 - mean_absolute_error: 0.0073 - val_loss: 3.8780e-04 - val_mean_absolute_error: 0.0142
# Epoch 150/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3634e-05 - mean_absolute_error: 0.0068 - val_loss: 3.7284e-04 - val_mean_absolute_error: 0.0138
# Epoch 151/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.9916e-05 - mean_absolute_error: 0.0070 - val_loss: 6.4687e-04 - val_mean_absolute_error: 0.0210
# Epoch 152/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1018e-04 - mean_absolute_error: 0.0075 - val_loss: 4.5165e-04 - val_mean_absolute_error: 0.0162
# Epoch 153/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3145e-04 - mean_absolute_error: 0.0081 - val_loss: 3.8461e-04 - val_mean_absolute_error: 0.0142
# Epoch 154/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2159e-04 - mean_absolute_error: 0.0077 - val_loss: 4.0821e-04 - val_mean_absolute_error: 0.0150
# Epoch 155/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1118e-05 - mean_absolute_error: 0.0066 - val_loss: 3.6868e-04 - val_mean_absolute_error: 0.0137
# Epoch 156/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7306e-05 - mean_absolute_error: 0.0067 - val_loss: 3.9723e-04 - val_mean_absolute_error: 0.0147
# Epoch 157/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0243e-04 - mean_absolute_error: 0.0071 - val_loss: 3.8811e-04 - val_mean_absolute_error: 0.0144
# Epoch 158/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.2332e-05 - mean_absolute_error: 0.0064 - val_loss: 3.4030e-04 - val_mean_absolute_error: 0.0128
# Epoch 159/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.1435e-05 - mean_absolute_error: 0.0068 - val_loss: 3.6906e-04 - val_mean_absolute_error: 0.0138
# Epoch 160/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7590e-05 - mean_absolute_error: 0.0063 - val_loss: 3.6128e-04 - val_mean_absolute_error: 0.0135
# Epoch 161/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.7331e-05 - mean_absolute_error: 0.0066 - val_loss: 3.4417e-04 - val_mean_absolute_error: 0.0130
# Epoch 162/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0414e-04 - mean_absolute_error: 0.0073 - val_loss: 3.3485e-04 - val_mean_absolute_error: 0.0126
# Epoch 163/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.6448e-05 - mean_absolute_error: 0.0063 - val_loss: 3.4321e-04 - val_mean_absolute_error: 0.0129
# Epoch 164/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.5548e-05 - mean_absolute_error: 0.0069 - val_loss: 3.2907e-04 - val_mean_absolute_error: 0.0124
# Epoch 165/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.9762e-05 - mean_absolute_error: 0.0066 - val_loss: 3.3135e-04 - val_mean_absolute_error: 0.0125
# Epoch 166/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.2378e-05 - mean_absolute_error: 0.0066 - val_loss: 3.5731e-04 - val_mean_absolute_error: 0.0136
# Epoch 167/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.3882e-05 - mean_absolute_error: 0.0064 - val_loss: 6.3767e-04 - val_mean_absolute_error: 0.0211
# Epoch 168/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1242e-04 - mean_absolute_error: 0.0075 - val_loss: 3.6945e-04 - val_mean_absolute_error: 0.0140
# Epoch 169/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8494e-05 - mean_absolute_error: 0.0072 - val_loss: 3.5779e-04 - val_mean_absolute_error: 0.0136
# Epoch 170/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0079e-04 - mean_absolute_error: 0.0074 - val_loss: 4.1574e-04 - val_mean_absolute_error: 0.0156
# Epoch 171/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.8435e-05 - mean_absolute_error: 0.0066 - val_loss: 3.1984e-04 - val_mean_absolute_error: 0.0122
# Epoch 172/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.3881e-05 - mean_absolute_error: 0.0062 - val_loss: 3.3484e-04 - val_mean_absolute_error: 0.0128
# Epoch 173/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1974e-05 - mean_absolute_error: 0.0067 - val_loss: 3.6631e-04 - val_mean_absolute_error: 0.0140
# Epoch 174/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.3884e-05 - mean_absolute_error: 0.0062 - val_loss: 3.4316e-04 - val_mean_absolute_error: 0.0133
# Epoch 175/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7170e-05 - mean_absolute_error: 0.0060 - val_loss: 4.0857e-04 - val_mean_absolute_error: 0.0154
# Epoch 176/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4228e-05 - mean_absolute_error: 0.0062 - val_loss: 3.1879e-04 - val_mean_absolute_error: 0.0123
# Epoch 177/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2221e-05 - mean_absolute_error: 0.0063 - val_loss: 3.4235e-04 - val_mean_absolute_error: 0.0132
# Epoch 178/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0879e-05 - mean_absolute_error: 0.0059 - val_loss: 3.3770e-04 - val_mean_absolute_error: 0.0130
# Epoch 179/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.9394e-05 - mean_absolute_error: 0.0068 - val_loss: 3.0714e-04 - val_mean_absolute_error: 0.0119
# Epoch 180/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.8250e-05 - mean_absolute_error: 0.0059 - val_loss: 3.0757e-04 - val_mean_absolute_error: 0.0119
# Epoch 181/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.8601e-05 - mean_absolute_error: 0.0067 - val_loss: 3.5078e-04 - val_mean_absolute_error: 0.0135
# Epoch 182/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.3159e-05 - mean_absolute_error: 0.0066 - val_loss: 3.0581e-04 - val_mean_absolute_error: 0.0118
# Epoch 183/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.3499e-05 - mean_absolute_error: 0.0065 - val_loss: 3.7869e-04 - val_mean_absolute_error: 0.0145
# Epoch 184/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0284e-04 - mean_absolute_error: 0.0070 - val_loss: 3.1280e-04 - val_mean_absolute_error: 0.0121
# Epoch 185/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2562e-05 - mean_absolute_error: 0.0061 - val_loss: 3.1144e-04 - val_mean_absolute_error: 0.0122
# Epoch 186/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.5702e-05 - mean_absolute_error: 0.0058 - val_loss: 3.2909e-04 - val_mean_absolute_error: 0.0128
# Epoch 187/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9223e-05 - mean_absolute_error: 0.0071 - val_loss: 3.4976e-04 - val_mean_absolute_error: 0.0136
# Epoch 188/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.8781e-05 - mean_absolute_error: 0.0063 - val_loss: 3.2968e-04 - val_mean_absolute_error: 0.0131
# Epoch 189/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.6296e-05 - mean_absolute_error: 0.0060 - val_loss: 3.4499e-04 - val_mean_absolute_error: 0.0137
# Epoch 190/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.2038e-05 - mean_absolute_error: 0.0057 - val_loss: 2.9754e-04 - val_mean_absolute_error: 0.0118
# Epoch 191/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.5073e-05 - mean_absolute_error: 0.0065 - val_loss: 2.9258e-04 - val_mean_absolute_error: 0.0115
# Epoch 192/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.3188e-05 - mean_absolute_error: 0.0059 - val_loss: 2.9070e-04 - val_mean_absolute_error: 0.0115
# Epoch 193/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5727e-05 - mean_absolute_error: 0.0057 - val_loss: 3.0789e-04 - val_mean_absolute_error: 0.0121
# Epoch 194/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.2952e-05 - mean_absolute_error: 0.0059 - val_loss: 2.8892e-04 - val_mean_absolute_error: 0.0114
# Epoch 195/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1741e-05 - mean_absolute_error: 0.0058 - val_loss: 2.8719e-04 - val_mean_absolute_error: 0.0114
# Epoch 196/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.9926e-05 - mean_absolute_error: 0.0069 - val_loss: 4.8599e-04 - val_mean_absolute_error: 0.0177
# Epoch 197/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.4092e-05 - mean_absolute_error: 0.0066 - val_loss: 2.9468e-04 - val_mean_absolute_error: 0.0119
# Epoch 198/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.7996e-05 - mean_absolute_error: 0.0053 - val_loss: 2.8417e-04 - val_mean_absolute_error: 0.0113
# Epoch 199/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.2209e-05 - mean_absolute_error: 0.0053 - val_loss: 3.6583e-04 - val_mean_absolute_error: 0.0146
# Epoch 200/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3069e-05 - mean_absolute_error: 0.0071 - val_loss: 2.9676e-04 - val_mean_absolute_error: 0.0120

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1740e-04 - mean_absolute_error: 0.0145
# Test Loss: [0.00029676288249902427, 0.012037406675517559]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 239
# 250

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 4536380.9724294115
# RMSE: 2129.878159057323
# MAE: 1501.5609473064853
# MAPE: 2.1554497678632614 %
#
# Model evalution on validate set
# MSE: 6128307.183318075
# RMSE: 2475.541795914194
# MAE: 1881.8167317708333
# MAPE: 2.0863165971244735 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
y_pred_30_days
# Out:
# array([[103717.88 ],
#        [102598.14 ],
#        [102565.516],
#        [102929.41 ],
#        [103267.87 ],
#        [103368.69 ],
#        [103354.22 ],
#        [103311.91 ],
#        [103284.66 ],
#        [103277.87 ],
#        [103280.78 ],
#        [103284.96 ],
#        [103287.164],
#        [103287.53 ],
#        [103287.15 ],
#        [103286.74 ],
#        [103286.58 ],
#        [103286.57 ],
#        [103286.61 ],
#        [103286.66 ],
#        [103286.68 ],
#        [103286.664],
#        [103286.664],
#        [103286.664],
#        [103286.66 ],
#        [103286.664],
#        [103286.664],
#        [103286.664],
#        [103286.664],
#        [103286.664],
#        [103286.664]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
