# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: CMG - Test/Train/Vaildation: 80/10/10
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 740.67
# - MAE: 513.57
# - MAPE: 1.45 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830
# ...           ...
# 2024-02-26  40000
# 2024-02-27  40200
# 2024-02-28  40000
# 2024-02-29  39950
# 2024-03-01  41200
#
# [1252 rows x 1 columns]

# %%
df.shape
# Out:
# (1252, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1247    40000
# 1248    40200
# 1249    40000
# 1250    39950
# 1251    41200
# Name: close, Length: 1252, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((990, 10), (990,), (114, 10), (114,), (115, 10), (115,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0763 - mean_absolute_error: 0.2033 - val_loss: 0.0146 - val_mean_absolute_error: 0.1165
# Epoch 2/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - mean_absolute_error: 0.0449 - val_loss: 6.2561e-04 - val_mean_absolute_error: 0.0191
# Epoch 3/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mean_absolute_error: 0.0289 - val_loss: 5.6795e-04 - val_mean_absolute_error: 0.0171
# Epoch 4/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mean_absolute_error: 0.0272 - val_loss: 8.5525e-04 - val_mean_absolute_error: 0.0201
# Epoch 5/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mean_absolute_error: 0.0270 - val_loss: 0.0013 - val_mean_absolute_error: 0.0273
# Epoch 6/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mean_absolute_error: 0.0285 - val_loss: 0.0018 - val_mean_absolute_error: 0.0353
# Epoch 7/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0266 - val_loss: 6.3015e-04 - val_mean_absolute_error: 0.0202
# Epoch 8/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mean_absolute_error: 0.0288 - val_loss: 5.8653e-04 - val_mean_absolute_error: 0.0191
# Epoch 9/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - mean_absolute_error: 0.0267 - val_loss: 5.9488e-04 - val_mean_absolute_error: 0.0168
# Epoch 10/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mean_absolute_error: 0.0279 - val_loss: 0.0011 - val_mean_absolute_error: 0.0244
# Epoch 11/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0264 - val_loss: 6.2271e-04 - val_mean_absolute_error: 0.0172
# Epoch 12/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0267 - val_loss: 5.3433e-04 - val_mean_absolute_error: 0.0174
# Epoch 13/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mean_absolute_error: 0.0277 - val_loss: 5.3871e-04 - val_mean_absolute_error: 0.0179
# Epoch 14/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mean_absolute_error: 0.0278 - val_loss: 0.0011 - val_mean_absolute_error: 0.0252
# Epoch 15/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0259 - val_loss: 5.5389e-04 - val_mean_absolute_error: 0.0165
# Epoch 16/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014 - mean_absolute_error: 0.0256 - val_loss: 5.9851e-04 - val_mean_absolute_error: 0.0177
# Epoch 17/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0255 - val_loss: 4.9984e-04 - val_mean_absolute_error: 0.0168
# Epoch 18/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0253 - val_loss: 5.2007e-04 - val_mean_absolute_error: 0.0181
# Epoch 19/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mean_absolute_error: 0.0276 - val_loss: 4.9357e-04 - val_mean_absolute_error: 0.0158
# Epoch 20/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0240 - val_loss: 4.7001e-04 - val_mean_absolute_error: 0.0163
# Epoch 21/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0239 - val_loss: 8.5879e-04 - val_mean_absolute_error: 0.0216
# Epoch 22/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0245 - val_loss: 0.0011 - val_mean_absolute_error: 0.0253
# Epoch 23/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0235 - val_loss: 0.0015 - val_mean_absolute_error: 0.0309
# Epoch 24/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0239 - val_loss: 0.0016 - val_mean_absolute_error: 0.0331
# Epoch 25/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0010 - mean_absolute_error: 0.0235 - val_loss: 7.7872e-04 - val_mean_absolute_error: 0.0204
# Epoch 26/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.4283e-04 - mean_absolute_error: 0.0210 - val_loss: 4.8906e-04 - val_mean_absolute_error: 0.0178
# Epoch 27/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8254e-04 - mean_absolute_error: 0.0225 - val_loss: 8.8285e-04 - val_mean_absolute_error: 0.0222
# Epoch 28/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - mean_absolute_error: 0.0245 - val_loss: 8.9158e-04 - val_mean_absolute_error: 0.0266
# Epoch 29/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.7218e-04 - mean_absolute_error: 0.0215 - val_loss: 4.7831e-04 - val_mean_absolute_error: 0.0177
# Epoch 30/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.4503e-04 - mean_absolute_error: 0.0212 - val_loss: 4.1474e-04 - val_mean_absolute_error: 0.0150
# Epoch 31/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7045e-04 - mean_absolute_error: 0.0209 - val_loss: 8.8549e-04 - val_mean_absolute_error: 0.0224
# Epoch 32/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0722e-04 - mean_absolute_error: 0.0201 - val_loss: 5.3107e-04 - val_mean_absolute_error: 0.0165
# Epoch 33/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.0105e-04 - mean_absolute_error: 0.0215 - val_loss: 9.3380e-04 - val_mean_absolute_error: 0.0233
# Epoch 34/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2823e-04 - mean_absolute_error: 0.0207 - val_loss: 0.0011 - val_mean_absolute_error: 0.0262
# Epoch 35/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6567e-04 - mean_absolute_error: 0.0208 - val_loss: 4.2828e-04 - val_mean_absolute_error: 0.0151
# Epoch 36/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2293e-04 - mean_absolute_error: 0.0210 - val_loss: 7.2184e-04 - val_mean_absolute_error: 0.0197
# Epoch 37/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0256e-04 - mean_absolute_error: 0.0189 - val_loss: 6.4631e-04 - val_mean_absolute_error: 0.0184
# Epoch 38/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7305e-04 - mean_absolute_error: 0.0198 - val_loss: 4.3711e-04 - val_mean_absolute_error: 0.0166
# Epoch 39/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.0925e-04 - mean_absolute_error: 0.0198 - val_loss: 4.0629e-04 - val_mean_absolute_error: 0.0157
# Epoch 40/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6247e-04 - mean_absolute_error: 0.0200 - val_loss: 0.0018 - val_mean_absolute_error: 0.0367
# Epoch 41/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7381e-04 - mean_absolute_error: 0.0204 - val_loss: 4.3983e-04 - val_mean_absolute_error: 0.0145
# Epoch 42/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8364e-04 - mean_absolute_error: 0.0201 - val_loss: 4.1704e-04 - val_mean_absolute_error: 0.0143
# Epoch 43/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4282e-04 - mean_absolute_error: 0.0191 - val_loss: 5.0157e-04 - val_mean_absolute_error: 0.0157
# Epoch 44/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.0541e-04 - mean_absolute_error: 0.0201 - val_loss: 4.8151e-04 - val_mean_absolute_error: 0.0152
# Epoch 45/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0998e-04 - mean_absolute_error: 0.0193 - val_loss: 0.0016 - val_mean_absolute_error: 0.0347
# Epoch 46/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.4631e-04 - mean_absolute_error: 0.0226 - val_loss: 0.0017 - val_mean_absolute_error: 0.0368
# Epoch 47/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.1370e-04 - mean_absolute_error: 0.0204 - val_loss: 3.4696e-04 - val_mean_absolute_error: 0.0139
# Epoch 48/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0681e-04 - mean_absolute_error: 0.0186 - val_loss: 6.4829e-04 - val_mean_absolute_error: 0.0187
# Epoch 49/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3871e-04 - mean_absolute_error: 0.0182 - val_loss: 5.4238e-04 - val_mean_absolute_error: 0.0201
# Epoch 50/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1845e-04 - mean_absolute_error: 0.0193 - val_loss: 3.3920e-04 - val_mean_absolute_error: 0.0134
# Epoch 51/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2705e-04 - mean_absolute_error: 0.0184 - val_loss: 5.5883e-04 - val_mean_absolute_error: 0.0204
# Epoch 52/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3701e-04 - mean_absolute_error: 0.0181 - val_loss: 5.6114e-04 - val_mean_absolute_error: 0.0170
# Epoch 53/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2335e-04 - mean_absolute_error: 0.0180 - val_loss: 7.5245e-04 - val_mean_absolute_error: 0.0245
# Epoch 54/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7513e-04 - mean_absolute_error: 0.0200 - val_loss: 3.4190e-04 - val_mean_absolute_error: 0.0141
# Epoch 55/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6758e-04 - mean_absolute_error: 0.0181 - val_loss: 5.9417e-04 - val_mean_absolute_error: 0.0179
# Epoch 56/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3893e-04 - mean_absolute_error: 0.0177 - val_loss: 3.5083e-04 - val_mean_absolute_error: 0.0131
# Epoch 57/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0618e-04 - mean_absolute_error: 0.0175 - val_loss: 3.4621e-04 - val_mean_absolute_error: 0.0144
# Epoch 58/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0954e-04 - mean_absolute_error: 0.0160 - val_loss: 3.3232e-04 - val_mean_absolute_error: 0.0139
# Epoch 59/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0498e-04 - mean_absolute_error: 0.0186 - val_loss: 3.4732e-04 - val_mean_absolute_error: 0.0125
# Epoch 60/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5625e-04 - mean_absolute_error: 0.0182 - val_loss: 5.8955e-04 - val_mean_absolute_error: 0.0181
# Epoch 61/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0699e-04 - mean_absolute_error: 0.0174 - val_loss: 7.3370e-04 - val_mean_absolute_error: 0.0211
# Epoch 62/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.2881e-04 - mean_absolute_error: 0.0191 - val_loss: 3.1066e-04 - val_mean_absolute_error: 0.0126
# Epoch 63/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6425e-04 - mean_absolute_error: 0.0182 - val_loss: 3.3958e-04 - val_mean_absolute_error: 0.0126
# Epoch 64/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1030e-04 - mean_absolute_error: 0.0175 - val_loss: 3.0219e-04 - val_mean_absolute_error: 0.0129
# Epoch 65/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6108e-04 - mean_absolute_error: 0.0168 - val_loss: 4.4800e-04 - val_mean_absolute_error: 0.0150
# Epoch 66/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7052e-04 - mean_absolute_error: 0.0168 - val_loss: 4.6078e-04 - val_mean_absolute_error: 0.0154
# Epoch 67/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4516e-04 - mean_absolute_error: 0.0165 - val_loss: 3.0720e-04 - val_mean_absolute_error: 0.0123
# Epoch 68/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6493e-04 - mean_absolute_error: 0.0170 - val_loss: 3.0002e-04 - val_mean_absolute_error: 0.0122
# Epoch 69/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4927e-04 - mean_absolute_error: 0.0152 - val_loss: 3.0257e-04 - val_mean_absolute_error: 0.0127
# Epoch 70/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7140e-04 - mean_absolute_error: 0.0175 - val_loss: 6.9189e-04 - val_mean_absolute_error: 0.0204
# Epoch 71/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6418e-04 - mean_absolute_error: 0.0168 - val_loss: 3.5373e-04 - val_mean_absolute_error: 0.0150
# Epoch 72/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1908e-04 - mean_absolute_error: 0.0165 - val_loss: 5.0816e-04 - val_mean_absolute_error: 0.0167
# Epoch 73/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1513e-04 - mean_absolute_error: 0.0179 - val_loss: 3.9874e-04 - val_mean_absolute_error: 0.0142
# Epoch 74/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9792e-04 - mean_absolute_error: 0.0156 - val_loss: 3.1075e-04 - val_mean_absolute_error: 0.0121
# Epoch 75/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5000e-04 - mean_absolute_error: 0.0162 - val_loss: 3.9129e-04 - val_mean_absolute_error: 0.0140
# Epoch 76/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8352e-04 - mean_absolute_error: 0.0152 - val_loss: 5.1589e-04 - val_mean_absolute_error: 0.0170
# Epoch 77/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3803e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0015 - val_mean_absolute_error: 0.0348
# Epoch 78/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9537e-04 - mean_absolute_error: 0.0200 - val_loss: 0.0017 - val_mean_absolute_error: 0.0370
# Epoch 79/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0941e-04 - mean_absolute_error: 0.0175 - val_loss: 5.3393e-04 - val_mean_absolute_error: 0.0176
# Epoch 80/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1188e-04 - mean_absolute_error: 0.0158 - val_loss: 2.6385e-04 - val_mean_absolute_error: 0.0115
# Epoch 81/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6384e-04 - mean_absolute_error: 0.0168 - val_loss: 5.2937e-04 - val_mean_absolute_error: 0.0200
# Epoch 82/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2457e-04 - mean_absolute_error: 0.0163 - val_loss: 2.6122e-04 - val_mean_absolute_error: 0.0113
# Epoch 83/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9419e-04 - mean_absolute_error: 0.0153 - val_loss: 2.7147e-04 - val_mean_absolute_error: 0.0120
# Epoch 84/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0240e-04 - mean_absolute_error: 0.0160 - val_loss: 2.6716e-04 - val_mean_absolute_error: 0.0113
# Epoch 85/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9719e-04 - mean_absolute_error: 0.0177 - val_loss: 2.6134e-04 - val_mean_absolute_error: 0.0110
# Epoch 86/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6922e-04 - mean_absolute_error: 0.0151 - val_loss: 6.1958e-04 - val_mean_absolute_error: 0.0197
# Epoch 87/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9430e-04 - mean_absolute_error: 0.0158 - val_loss: 3.0084e-04 - val_mean_absolute_error: 0.0131
# Epoch 88/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8048e-04 - mean_absolute_error: 0.0152 - val_loss: 2.8443e-04 - val_mean_absolute_error: 0.0125
# Epoch 89/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7372e-04 - mean_absolute_error: 0.0155 - val_loss: 3.3561e-04 - val_mean_absolute_error: 0.0129
# Epoch 90/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9554e-04 - mean_absolute_error: 0.0158 - val_loss: 4.6056e-04 - val_mean_absolute_error: 0.0161
# Epoch 91/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9520e-04 - mean_absolute_error: 0.0153 - val_loss: 2.4914e-04 - val_mean_absolute_error: 0.0106
# Epoch 92/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2269e-04 - mean_absolute_error: 0.0162 - val_loss: 3.3698e-04 - val_mean_absolute_error: 0.0130
# Epoch 93/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8629e-04 - mean_absolute_error: 0.0155 - val_loss: 8.2644e-04 - val_mean_absolute_error: 0.0241
# Epoch 94/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5299e-04 - mean_absolute_error: 0.0146 - val_loss: 2.6354e-04 - val_mean_absolute_error: 0.0114
# Epoch 95/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6714e-04 - mean_absolute_error: 0.0154 - val_loss: 3.6776e-04 - val_mean_absolute_error: 0.0138
# Epoch 96/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1003e-04 - mean_absolute_error: 0.0159 - val_loss: 3.0440e-04 - val_mean_absolute_error: 0.0123
# Epoch 97/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4243e-04 - mean_absolute_error: 0.0153 - val_loss: 2.4821e-04 - val_mean_absolute_error: 0.0108
# Epoch 98/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4006e-04 - mean_absolute_error: 0.0144 - val_loss: 2.5108e-04 - val_mean_absolute_error: 0.0112
# Epoch 99/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5423e-04 - mean_absolute_error: 0.0153 - val_loss: 2.5439e-04 - val_mean_absolute_error: 0.0108
# Epoch 100/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1608e-04 - mean_absolute_error: 0.0144 - val_loss: 2.6854e-04 - val_mean_absolute_error: 0.0119
# Epoch 101/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8156e-04 - mean_absolute_error: 0.0172 - val_loss: 2.5286e-04 - val_mean_absolute_error: 0.0108
# Epoch 102/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4596e-04 - mean_absolute_error: 0.0146 - val_loss: 3.2534e-04 - val_mean_absolute_error: 0.0141
# Epoch 103/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9580e-04 - mean_absolute_error: 0.0155 - val_loss: 2.4049e-04 - val_mean_absolute_error: 0.0107
# Epoch 104/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5675e-04 - mean_absolute_error: 0.0168 - val_loss: 3.0901e-04 - val_mean_absolute_error: 0.0123
# Epoch 105/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1333e-04 - mean_absolute_error: 0.0138 - val_loss: 2.9564e-04 - val_mean_absolute_error: 0.0119
# Epoch 106/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6957e-04 - mean_absolute_error: 0.0150 - val_loss: 2.4350e-04 - val_mean_absolute_error: 0.0110
# Epoch 107/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6829e-04 - mean_absolute_error: 0.0158 - val_loss: 2.3211e-04 - val_mean_absolute_error: 0.0105
# Epoch 108/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8120e-04 - mean_absolute_error: 0.0152 - val_loss: 2.3942e-04 - val_mean_absolute_error: 0.0107
# Epoch 109/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7473e-04 - mean_absolute_error: 0.0150 - val_loss: 3.2235e-04 - val_mean_absolute_error: 0.0127
# Epoch 110/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2518e-04 - mean_absolute_error: 0.0145 - val_loss: 4.4277e-04 - val_mean_absolute_error: 0.0160
# Epoch 111/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9864e-04 - mean_absolute_error: 0.0143 - val_loss: 2.5224e-04 - val_mean_absolute_error: 0.0109
# Epoch 112/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2737e-04 - mean_absolute_error: 0.0146 - val_loss: 4.2570e-04 - val_mean_absolute_error: 0.0155
# Epoch 113/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3389e-04 - mean_absolute_error: 0.0146 - val_loss: 2.4087e-04 - val_mean_absolute_error: 0.0105
# Epoch 114/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4127e-04 - mean_absolute_error: 0.0142 - val_loss: 2.4959e-04 - val_mean_absolute_error: 0.0105
# Epoch 115/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3613e-04 - mean_absolute_error: 0.0147 - val_loss: 2.9307e-04 - val_mean_absolute_error: 0.0119
# Epoch 116/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6915e-04 - mean_absolute_error: 0.0151 - val_loss: 8.6046e-04 - val_mean_absolute_error: 0.0251
# Epoch 117/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7378e-04 - mean_absolute_error: 0.0157 - val_loss: 2.4967e-04 - val_mean_absolute_error: 0.0117
# Epoch 118/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3283e-04 - mean_absolute_error: 0.0146 - val_loss: 3.5467e-04 - val_mean_absolute_error: 0.0137
# Epoch 119/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1154e-04 - mean_absolute_error: 0.0139 - val_loss: 2.3335e-04 - val_mean_absolute_error: 0.0110
# Epoch 120/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6463e-04 - mean_absolute_error: 0.0147 - val_loss: 2.3168e-04 - val_mean_absolute_error: 0.0110
# Epoch 121/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6597e-04 - mean_absolute_error: 0.0155 - val_loss: 4.5759e-04 - val_mean_absolute_error: 0.0164
# Epoch 122/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1605e-04 - mean_absolute_error: 0.0148 - val_loss: 4.0883e-04 - val_mean_absolute_error: 0.0152
# Epoch 123/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7958e-04 - mean_absolute_error: 0.0136 - val_loss: 3.4560e-04 - val_mean_absolute_error: 0.0134
# Epoch 124/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2323e-04 - mean_absolute_error: 0.0143 - val_loss: 2.3135e-04 - val_mean_absolute_error: 0.0102
# Epoch 125/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6928e-04 - mean_absolute_error: 0.0152 - val_loss: 5.2791e-04 - val_mean_absolute_error: 0.0182
# Epoch 126/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7643e-04 - mean_absolute_error: 0.0154 - val_loss: 3.1265e-04 - val_mean_absolute_error: 0.0124
# Epoch 127/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7915e-04 - mean_absolute_error: 0.0154 - val_loss: 2.2302e-04 - val_mean_absolute_error: 0.0106
# Epoch 128/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3854e-04 - mean_absolute_error: 0.0144 - val_loss: 4.6342e-04 - val_mean_absolute_error: 0.0165
# Epoch 129/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2611e-04 - mean_absolute_error: 0.0142 - val_loss: 3.3383e-04 - val_mean_absolute_error: 0.0131
# Epoch 130/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2397e-04 - mean_absolute_error: 0.0142 - val_loss: 2.4388e-04 - val_mean_absolute_error: 0.0105
# Epoch 131/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4363e-04 - mean_absolute_error: 0.0145 - val_loss: 5.4272e-04 - val_mean_absolute_error: 0.0206
# Epoch 132/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7847e-04 - mean_absolute_error: 0.0177 - val_loss: 2.6736e-04 - val_mean_absolute_error: 0.0126
# Epoch 133/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5935e-04 - mean_absolute_error: 0.0153 - val_loss: 2.7466e-04 - val_mean_absolute_error: 0.0113
# Epoch 134/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8803e-04 - mean_absolute_error: 0.0136 - val_loss: 2.3881e-04 - val_mean_absolute_error: 0.0103
# Epoch 135/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9908e-04 - mean_absolute_error: 0.0137 - val_loss: 2.9167e-04 - val_mean_absolute_error: 0.0135
# Epoch 136/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0113e-04 - mean_absolute_error: 0.0137 - val_loss: 2.4160e-04 - val_mean_absolute_error: 0.0106
# Epoch 137/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9070e-04 - mean_absolute_error: 0.0134 - val_loss: 2.1605e-04 - val_mean_absolute_error: 0.0102
# Epoch 138/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2818e-04 - mean_absolute_error: 0.0142 - val_loss: 2.8466e-04 - val_mean_absolute_error: 0.0133
# Epoch 139/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0670e-04 - mean_absolute_error: 0.0138 - val_loss: 3.9140e-04 - val_mean_absolute_error: 0.0147
# Epoch 140/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1514e-04 - mean_absolute_error: 0.0142 - val_loss: 4.0164e-04 - val_mean_absolute_error: 0.0150
# Epoch 141/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3843e-04 - mean_absolute_error: 0.0139 - val_loss: 2.9905e-04 - val_mean_absolute_error: 0.0138
# Epoch 142/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1492e-04 - mean_absolute_error: 0.0142 - val_loss: 3.2047e-04 - val_mean_absolute_error: 0.0127
# Epoch 143/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5965e-04 - mean_absolute_error: 0.0150 - val_loss: 2.3271e-04 - val_mean_absolute_error: 0.0105
# Epoch 144/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0118e-04 - mean_absolute_error: 0.0138 - val_loss: 2.1574e-04 - val_mean_absolute_error: 0.0107
# Epoch 145/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6997e-04 - mean_absolute_error: 0.0134 - val_loss: 2.1981e-04 - val_mean_absolute_error: 0.0106
# Epoch 146/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8840e-04 - mean_absolute_error: 0.0137 - val_loss: 2.2693e-04 - val_mean_absolute_error: 0.0112
# Epoch 147/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0809e-04 - mean_absolute_error: 0.0141 - val_loss: 5.7568e-04 - val_mean_absolute_error: 0.0196
# Epoch 148/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2762e-04 - mean_absolute_error: 0.0145 - val_loss: 3.1746e-04 - val_mean_absolute_error: 0.0127
# Epoch 149/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1638e-04 - mean_absolute_error: 0.0143 - val_loss: 4.9137e-04 - val_mean_absolute_error: 0.0176
# Epoch 150/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7575e-04 - mean_absolute_error: 0.0157 - val_loss: 8.5387e-04 - val_mean_absolute_error: 0.0254
# Epoch 151/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6297e-04 - mean_absolute_error: 0.0155 - val_loss: 2.0715e-04 - val_mean_absolute_error: 0.0099
# Epoch 152/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6163e-04 - mean_absolute_error: 0.0129 - val_loss: 3.0592e-04 - val_mean_absolute_error: 0.0123
# Epoch 153/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1645e-04 - mean_absolute_error: 0.0140 - val_loss: 4.0827e-04 - val_mean_absolute_error: 0.0170
# Epoch 154/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6179e-04 - mean_absolute_error: 0.0153 - val_loss: 3.9622e-04 - val_mean_absolute_error: 0.0151
# Epoch 155/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7061e-04 - mean_absolute_error: 0.0132 - val_loss: 2.1013e-04 - val_mean_absolute_error: 0.0103
# Epoch 156/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7115e-04 - mean_absolute_error: 0.0133 - val_loss: 3.0488e-04 - val_mean_absolute_error: 0.0140
# Epoch 157/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5927e-04 - mean_absolute_error: 0.0155 - val_loss: 2.1743e-04 - val_mean_absolute_error: 0.0103
# Epoch 158/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4308e-04 - mean_absolute_error: 0.0148 - val_loss: 3.3310e-04 - val_mean_absolute_error: 0.0149
# Epoch 159/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1201e-04 - mean_absolute_error: 0.0141 - val_loss: 2.6575e-04 - val_mean_absolute_error: 0.0127
# Epoch 160/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0593e-04 - mean_absolute_error: 0.0139 - val_loss: 2.2709e-04 - val_mean_absolute_error: 0.0106
# Epoch 161/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0223e-04 - mean_absolute_error: 0.0139 - val_loss: 6.2038e-04 - val_mean_absolute_error: 0.0206
# Epoch 162/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4405e-04 - mean_absolute_error: 0.0148 - val_loss: 2.8002e-04 - val_mean_absolute_error: 0.0118
# Epoch 163/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3711e-04 - mean_absolute_error: 0.0148 - val_loss: 5.6077e-04 - val_mean_absolute_error: 0.0193
# Epoch 164/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8579e-04 - mean_absolute_error: 0.0137 - val_loss: 3.1728e-04 - val_mean_absolute_error: 0.0127
# Epoch 165/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1453e-04 - mean_absolute_error: 0.0142 - val_loss: 2.9607e-04 - val_mean_absolute_error: 0.0120
# Epoch 166/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7456e-04 - mean_absolute_error: 0.0140 - val_loss: 3.0873e-04 - val_mean_absolute_error: 0.0142
# Epoch 167/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3584e-04 - mean_absolute_error: 0.0142 - val_loss: 2.2202e-04 - val_mean_absolute_error: 0.0109
# Epoch 168/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5156e-04 - mean_absolute_error: 0.0134 - val_loss: 2.9518e-04 - val_mean_absolute_error: 0.0121
# Epoch 169/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5794e-04 - mean_absolute_error: 0.0147 - val_loss: 2.4454e-04 - val_mean_absolute_error: 0.0120
# Epoch 170/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2949e-04 - mean_absolute_error: 0.0148 - val_loss: 4.8121e-04 - val_mean_absolute_error: 0.0191
# Epoch 171/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5964e-04 - mean_absolute_error: 0.0154 - val_loss: 2.6425e-04 - val_mean_absolute_error: 0.0112
# Epoch 172/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6932e-04 - mean_absolute_error: 0.0139 - val_loss: 2.3242e-04 - val_mean_absolute_error: 0.0104
# Epoch 173/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7450e-04 - mean_absolute_error: 0.0129 - val_loss: 2.5326e-04 - val_mean_absolute_error: 0.0108
# Epoch 174/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8898e-04 - mean_absolute_error: 0.0134 - val_loss: 3.3130e-04 - val_mean_absolute_error: 0.0148
# Epoch 175/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3934e-04 - mean_absolute_error: 0.0147 - val_loss: 2.2983e-04 - val_mean_absolute_error: 0.0114
# Epoch 176/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0362e-04 - mean_absolute_error: 0.0137 - val_loss: 2.2066e-04 - val_mean_absolute_error: 0.0103
# Epoch 177/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9356e-04 - mean_absolute_error: 0.0137 - val_loss: 2.5594e-04 - val_mean_absolute_error: 0.0109
# Epoch 178/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9956e-04 - mean_absolute_error: 0.0141 - val_loss: 4.4520e-04 - val_mean_absolute_error: 0.0164
# Epoch 179/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8971e-04 - mean_absolute_error: 0.0136 - val_loss: 2.1659e-04 - val_mean_absolute_error: 0.0106
# Epoch 180/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1351e-04 - mean_absolute_error: 0.0147 - val_loss: 2.4288e-04 - val_mean_absolute_error: 0.0106
# Epoch 181/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7631e-04 - mean_absolute_error: 0.0135 - val_loss: 6.5198e-04 - val_mean_absolute_error: 0.0213
# Epoch 182/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4847e-04 - mean_absolute_error: 0.0146 - val_loss: 3.8452e-04 - val_mean_absolute_error: 0.0147
# Epoch 183/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3870e-04 - mean_absolute_error: 0.0149 - val_loss: 2.1793e-04 - val_mean_absolute_error: 0.0109
# Epoch 184/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5424e-04 - mean_absolute_error: 0.0127 - val_loss: 2.7199e-04 - val_mean_absolute_error: 0.0130
# Epoch 185/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0195e-04 - mean_absolute_error: 0.0136 - val_loss: 2.6135e-04 - val_mean_absolute_error: 0.0126
# Epoch 186/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2590e-04 - mean_absolute_error: 0.0147 - val_loss: 4.6426e-04 - val_mean_absolute_error: 0.0170
# Epoch 187/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9288e-04 - mean_absolute_error: 0.0138 - val_loss: 2.7578e-04 - val_mean_absolute_error: 0.0130
# Epoch 188/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9902e-04 - mean_absolute_error: 0.0144 - val_loss: 3.0417e-04 - val_mean_absolute_error: 0.0125
# Epoch 189/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5066e-04 - mean_absolute_error: 0.0130 - val_loss: 2.0941e-04 - val_mean_absolute_error: 0.0102
# Epoch 190/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8550e-04 - mean_absolute_error: 0.0134 - val_loss: 2.1007e-04 - val_mean_absolute_error: 0.0100
# Epoch 191/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1198e-04 - mean_absolute_error: 0.0140 - val_loss: 2.2711e-04 - val_mean_absolute_error: 0.0105
# Epoch 192/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0727e-04 - mean_absolute_error: 0.0140 - val_loss: 3.5643e-04 - val_mean_absolute_error: 0.0139
# Epoch 193/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0859e-04 - mean_absolute_error: 0.0138 - val_loss: 7.0081e-04 - val_mean_absolute_error: 0.0223
# Epoch 194/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0673e-04 - mean_absolute_error: 0.0139 - val_loss: 2.3073e-04 - val_mean_absolute_error: 0.0105
# Epoch 195/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8068e-04 - mean_absolute_error: 0.0135 - val_loss: 2.9018e-04 - val_mean_absolute_error: 0.0135
# Epoch 196/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6152e-04 - mean_absolute_error: 0.0157 - val_loss: 2.4304e-04 - val_mean_absolute_error: 0.0106
# Epoch 197/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8195e-04 - mean_absolute_error: 0.0136 - val_loss: 4.2169e-04 - val_mean_absolute_error: 0.0157
# Epoch 198/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3769e-04 - mean_absolute_error: 0.0129 - val_loss: 2.4572e-04 - val_mean_absolute_error: 0.0108
# Epoch 199/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1163e-04 - mean_absolute_error: 0.0137 - val_loss: 2.4638e-04 - val_mean_absolute_error: 0.0108
# Epoch 200/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5502e-04 - mean_absolute_error: 0.0130 - val_loss: 2.7644e-04 - val_mean_absolute_error: 0.0115

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4430e-04 - mean_absolute_error: 0.0107
# Test Loss: [0.000276441453024745, 0.011529947631061077]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 114
# 125

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 548595.8255149774
# RMSE: 740.6725494541953
# MAE: 513.575743558114
# MAPE: 1.4507211533014894 %
#
# Model evalution on validate set
# MSE: 941354.4054388958
# RMSE: 970.2342013343458
# MAE: 754.0510529891304
# MAPE: 1.9233332276884247 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
y_pred_30_days
# Out:
# array([[41142.293],
#        [40947.97 ],
#        [41106.164],
#        [41030.88 ],
#        [41058.27 ],
#        [41042.855],
#        [41049.344],
#        [41046.36 ],
#        [41047.777],
#        [41047.15 ],
#        [41047.44 ],
#        [41047.3  ],
#        [41047.367],
#        [41047.34 ],
#        [41047.35 ],
#        [41047.344],
#        [41047.348],
#        [41047.348],
#        [41047.348],
#        [41047.348],
#        [41047.348],
#        [41047.344],
#        [41047.344],
#        [41047.348],
#        [41047.348],
#        [41047.348],
#        [41047.344],
#        [41047.348],
#        [41047.348],
#        [41047.344],
#        [41047.348]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
