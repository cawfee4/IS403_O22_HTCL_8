# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: CMG - Test/Train/Vaildation: 80/10/10
# - Dataset: 1313 rows x 7 columns (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 767.4216833632966
# - MAE: 568.27685546875
# - MAPE: 1.5403484166514707 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830
# ...           ...
# 2024-05-27  59000
# 2024-05-28  62100
# 2024-05-29  60000
# 2024-05-30  59200
# 2024-05-31  60900
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((1039, 10), (1039,), (120, 10), (120,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 23s 107ms/step - loss: 0.0333 - mean_absolute_error: 0.1344 - val_loss: 0.0028 - val_mean_absolute_error: 0.0499
# Epoch 2/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0299 - val_loss: 5.9317e-04 - val_mean_absolute_error: 0.0190
# Epoch 3/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.8224e-04 - mean_absolute_error: 0.0182 - val_loss: 4.7497e-04 - val_mean_absolute_error: 0.0165
# Epoch 4/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.6425e-04 - mean_absolute_error: 0.0176 - val_loss: 6.6634e-04 - val_mean_absolute_error: 0.0201
# Epoch 5/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.8923e-04 - mean_absolute_error: 0.0172 - val_loss: 4.7025e-04 - val_mean_absolute_error: 0.0164
# Epoch 6/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.1890e-04 - mean_absolute_error: 0.0178 - val_loss: 4.3149e-04 - val_mean_absolute_error: 0.0155
# Epoch 7/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.7379e-04 - mean_absolute_error: 0.0170 - val_loss: 4.1606e-04 - val_mean_absolute_error: 0.0152
# Epoch 8/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.4790e-04 - mean_absolute_error: 0.0168 - val_loss: 4.6429e-04 - val_mean_absolute_error: 0.0164
# Epoch 9/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.8719e-04 - mean_absolute_error: 0.0169 - val_loss: 4.4730e-04 - val_mean_absolute_error: 0.0161
# Epoch 10/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.5129e-04 - mean_absolute_error: 0.0168 - val_loss: 3.8567e-04 - val_mean_absolute_error: 0.0147
# Epoch 11/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.2204e-04 - mean_absolute_error: 0.0175 - val_loss: 6.6286e-04 - val_mean_absolute_error: 0.0210
# Epoch 12/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.1527e-04 - mean_absolute_error: 0.0162 - val_loss: 3.5818e-04 - val_mean_absolute_error: 0.0139
# Epoch 13/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.0904e-04 - mean_absolute_error: 0.0161 - val_loss: 3.5548e-04 - val_mean_absolute_error: 0.0139
# Epoch 14/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.9288e-04 - mean_absolute_error: 0.0157 - val_loss: 3.3988e-04 - val_mean_absolute_error: 0.0135
# Epoch 15/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.0909e-04 - mean_absolute_error: 0.0168 - val_loss: 0.0013 - val_mean_absolute_error: 0.0322
# Epoch 16/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.3266e-04 - mean_absolute_error: 0.0167 - val_loss: 4.5784e-04 - val_mean_absolute_error: 0.0167
# Epoch 17/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.4480e-04 - mean_absolute_error: 0.0154 - val_loss: 4.4722e-04 - val_mean_absolute_error: 0.0165
# Epoch 18/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.4357e-04 - mean_absolute_error: 0.0153 - val_loss: 3.9743e-04 - val_mean_absolute_error: 0.0153
# Epoch 19/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.1138e-04 - mean_absolute_error: 0.0142 - val_loss: 3.6712e-04 - val_mean_absolute_error: 0.0145
# Epoch 20/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.8398e-04 - mean_absolute_error: 0.0154 - val_loss: 2.6923e-04 - val_mean_absolute_error: 0.0121
# Epoch 21/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.3580e-04 - mean_absolute_error: 0.0150 - val_loss: 4.6377e-04 - val_mean_absolute_error: 0.0174
# Epoch 22/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.3203e-04 - mean_absolute_error: 0.0148 - val_loss: 5.0774e-04 - val_mean_absolute_error: 0.0187
# Epoch 23/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.6832e-04 - mean_absolute_error: 0.0138 - val_loss: 2.9717e-04 - val_mean_absolute_error: 0.0128
# Epoch 24/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.6992e-04 - mean_absolute_error: 0.0137 - val_loss: 2.2946e-04 - val_mean_absolute_error: 0.0117
# Epoch 25/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.3800e-04 - mean_absolute_error: 0.0152 - val_loss: 3.0766e-04 - val_mean_absolute_error: 0.0134
# Epoch 26/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.4033e-04 - mean_absolute_error: 0.0132 - val_loss: 3.8449e-04 - val_mean_absolute_error: 0.0157
# Epoch 27/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.3297e-04 - mean_absolute_error: 0.0128 - val_loss: 2.0853e-04 - val_mean_absolute_error: 0.0107
# Epoch 28/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.3595e-04 - mean_absolute_error: 0.0132 - val_loss: 1.8779e-04 - val_mean_absolute_error: 0.0105
# Epoch 29/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.5168e-04 - mean_absolute_error: 0.0135 - val_loss: 2.6652e-04 - val_mean_absolute_error: 0.0135
# Epoch 30/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.6180e-04 - mean_absolute_error: 0.0136 - val_loss: 1.8282e-04 - val_mean_absolute_error: 0.0100
# Epoch 31/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.8846e-04 - mean_absolute_error: 0.0123 - val_loss: 2.6950e-04 - val_mean_absolute_error: 0.0127
# Epoch 32/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.0311e-04 - mean_absolute_error: 0.0127 - val_loss: 4.8964e-04 - val_mean_absolute_error: 0.0187
# Epoch 33/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 2.9658e-04 - mean_absolute_error: 0.0118 - val_loss: 5.6066e-04 - val_mean_absolute_error: 0.0204
# Epoch 34/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.8581e-04 - mean_absolute_error: 0.0119 - val_loss: 6.2526e-04 - val_mean_absolute_error: 0.0218
# Epoch 35/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.9771e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0012 - val_mean_absolute_error: 0.0322
# Epoch 36/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.5354e-04 - mean_absolute_error: 0.0142 - val_loss: 1.6636e-04 - val_mean_absolute_error: 0.0094
# Epoch 37/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.8788e-04 - mean_absolute_error: 0.0121 - val_loss: 3.4064e-04 - val_mean_absolute_error: 0.0149
# Epoch 38/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.7636e-04 - mean_absolute_error: 0.0140 - val_loss: 2.0858e-04 - val_mean_absolute_error: 0.0107
# Epoch 39/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.9257e-04 - mean_absolute_error: 0.0119 - val_loss: 2.6772e-04 - val_mean_absolute_error: 0.0126
# Epoch 40/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.6885e-04 - mean_absolute_error: 0.0117 - val_loss: 1.8159e-04 - val_mean_absolute_error: 0.0099
# Epoch 41/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.7071e-04 - mean_absolute_error: 0.0116 - val_loss: 3.6085e-04 - val_mean_absolute_error: 0.0157
# Epoch 42/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 2.5801e-04 - mean_absolute_error: 0.0113 - val_loss: 1.7464e-04 - val_mean_absolute_error: 0.0103
# Epoch 43/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.2449e-04 - mean_absolute_error: 0.0133 - val_loss: 2.0135e-04 - val_mean_absolute_error: 0.0105
# Epoch 44/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.3417e-04 - mean_absolute_error: 0.0110 - val_loss: 2.2082e-04 - val_mean_absolute_error: 0.0122
# Epoch 45/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.5881e-04 - mean_absolute_error: 0.0116 - val_loss: 9.5967e-04 - val_mean_absolute_error: 0.0287
# Epoch 46/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.8160e-04 - mean_absolute_error: 0.0117 - val_loss: 4.4306e-04 - val_mean_absolute_error: 0.0180
# Epoch 47/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.4566e-04 - mean_absolute_error: 0.0110 - val_loss: 1.8791e-04 - val_mean_absolute_error: 0.0102
# Epoch 48/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.5516e-04 - mean_absolute_error: 0.0113 - val_loss: 8.7207e-04 - val_mean_absolute_error: 0.0272
# Epoch 49/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.0278e-04 - mean_absolute_error: 0.0123 - val_loss: 2.7377e-04 - val_mean_absolute_error: 0.0132
# Epoch 50/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.5701e-04 - mean_absolute_error: 0.0114 - val_loss: 1.7935e-04 - val_mean_absolute_error: 0.0097
# Epoch 51/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.7872e-04 - mean_absolute_error: 0.0118 - val_loss: 1.9163e-04 - val_mean_absolute_error: 0.0103
# Epoch 52/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.9073e-04 - mean_absolute_error: 0.0124 - val_loss: 3.2955e-04 - val_mean_absolute_error: 0.0150
# Epoch 53/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.3107e-04 - mean_absolute_error: 0.0108 - val_loss: 1.7470e-04 - val_mean_absolute_error: 0.0096
# Epoch 54/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.5295e-04 - mean_absolute_error: 0.0110 - val_loss: 1.4387e-04 - val_mean_absolute_error: 0.0090
# Epoch 55/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.2487e-04 - mean_absolute_error: 0.0104 - val_loss: 1.3983e-04 - val_mean_absolute_error: 0.0088
# Epoch 56/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.4430e-04 - mean_absolute_error: 0.0111 - val_loss: 1.9720e-04 - val_mean_absolute_error: 0.0105
# Epoch 57/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.3274e-04 - mean_absolute_error: 0.0111 - val_loss: 3.4726e-04 - val_mean_absolute_error: 0.0164
# Epoch 58/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.9694e-04 - mean_absolute_error: 0.0126 - val_loss: 3.8898e-04 - val_mean_absolute_error: 0.0168
# Epoch 59/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.7311e-04 - mean_absolute_error: 0.0125 - val_loss: 1.2937e-04 - val_mean_absolute_error: 0.0080
# Epoch 60/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.2428e-04 - mean_absolute_error: 0.0109 - val_loss: 1.3753e-04 - val_mean_absolute_error: 0.0085
# Epoch 61/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.2855e-04 - mean_absolute_error: 0.0110 - val_loss: 1.3234e-04 - val_mean_absolute_error: 0.0085
# Epoch 62/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.3693e-04 - mean_absolute_error: 0.0109 - val_loss: 2.5547e-04 - val_mean_absolute_error: 0.0129
# Epoch 63/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1336e-04 - mean_absolute_error: 0.0104 - val_loss: 7.3847e-04 - val_mean_absolute_error: 0.0251
# Epoch 64/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.1578e-04 - mean_absolute_error: 0.0107 - val_loss: 1.3056e-04 - val_mean_absolute_error: 0.0081
# Epoch 65/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.3794e-04 - mean_absolute_error: 0.0113 - val_loss: 1.2883e-04 - val_mean_absolute_error: 0.0083
# Epoch 66/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.3116e-04 - mean_absolute_error: 0.0107 - val_loss: 3.1986e-04 - val_mean_absolute_error: 0.0152
# Epoch 67/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.4393e-04 - mean_absolute_error: 0.0115 - val_loss: 1.2002e-04 - val_mean_absolute_error: 0.0079
# Epoch 68/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 2.1289e-04 - mean_absolute_error: 0.0104 - val_loss: 1.1861e-04 - val_mean_absolute_error: 0.0077
# Epoch 69/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.0234e-04 - mean_absolute_error: 0.0103 - val_loss: 1.1596e-04 - val_mean_absolute_error: 0.0075
# Epoch 70/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.0266e-04 - mean_absolute_error: 0.0101 - val_loss: 1.1365e-04 - val_mean_absolute_error: 0.0074
# Epoch 71/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.8241e-04 - mean_absolute_error: 0.0096 - val_loss: 2.4255e-04 - val_mean_absolute_error: 0.0131
# Epoch 72/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.3810e-04 - mean_absolute_error: 0.0110 - val_loss: 1.2913e-04 - val_mean_absolute_error: 0.0082
# Epoch 73/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.0881e-04 - mean_absolute_error: 0.0103 - val_loss: 1.3684e-04 - val_mean_absolute_error: 0.0085
# Epoch 74/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.0462e-04 - mean_absolute_error: 0.0102 - val_loss: 2.4643e-04 - val_mean_absolute_error: 0.0129
# Epoch 75/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.0303e-04 - mean_absolute_error: 0.0100 - val_loss: 1.5203e-04 - val_mean_absolute_error: 0.0092
# Epoch 76/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8616e-04 - mean_absolute_error: 0.0098 - val_loss: 3.0547e-04 - val_mean_absolute_error: 0.0150
# Epoch 77/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.8325e-04 - mean_absolute_error: 0.0098 - val_loss: 3.0803e-04 - val_mean_absolute_error: 0.0151
# Epoch 78/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.8713e-04 - mean_absolute_error: 0.0099 - val_loss: 2.6290e-04 - val_mean_absolute_error: 0.0137
# Epoch 79/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.9969e-04 - mean_absolute_error: 0.0098 - val_loss: 1.9374e-04 - val_mean_absolute_error: 0.0109
# Epoch 80/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.9828e-04 - mean_absolute_error: 0.0099 - val_loss: 1.0831e-04 - val_mean_absolute_error: 0.0070
# Epoch 81/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.7978e-04 - mean_absolute_error: 0.0093 - val_loss: 2.0750e-04 - val_mean_absolute_error: 0.0116
# Epoch 82/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.8216e-04 - mean_absolute_error: 0.0096 - val_loss: 1.0764e-04 - val_mean_absolute_error: 0.0071
# Epoch 83/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.8599e-04 - mean_absolute_error: 0.0097 - val_loss: 5.5838e-04 - val_mean_absolute_error: 0.0222
# Epoch 84/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.2201e-04 - mean_absolute_error: 0.0110 - val_loss: 3.4215e-04 - val_mean_absolute_error: 0.0162
# Epoch 85/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.0106e-04 - mean_absolute_error: 0.0100 - val_loss: 1.0586e-04 - val_mean_absolute_error: 0.0070
# Epoch 86/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.9204e-04 - mean_absolute_error: 0.0100 - val_loss: 1.6461e-04 - val_mean_absolute_error: 0.0100
# Epoch 87/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.9404e-04 - mean_absolute_error: 0.0101 - val_loss: 1.2383e-04 - val_mean_absolute_error: 0.0079
# Epoch 88/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.0269e-04 - mean_absolute_error: 0.0100 - val_loss: 1.6435e-04 - val_mean_absolute_error: 0.0097
# Epoch 89/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.8944e-04 - mean_absolute_error: 0.0097 - val_loss: 2.2738e-04 - val_mean_absolute_error: 0.0125
# Epoch 90/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.7990e-04 - mean_absolute_error: 0.0095 - val_loss: 2.7335e-04 - val_mean_absolute_error: 0.0141
# Epoch 91/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7783e-04 - mean_absolute_error: 0.0095 - val_loss: 3.3456e-04 - val_mean_absolute_error: 0.0161
# Epoch 92/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.3591e-04 - mean_absolute_error: 0.0115 - val_loss: 2.2287e-04 - val_mean_absolute_error: 0.0126
# Epoch 93/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1065e-04 - mean_absolute_error: 0.0106 - val_loss: 1.3709e-04 - val_mean_absolute_error: 0.0085
# Epoch 94/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.9035e-04 - mean_absolute_error: 0.0097 - val_loss: 3.8352e-04 - val_mean_absolute_error: 0.0175
# Epoch 95/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.9717e-04 - mean_absolute_error: 0.0100 - val_loss: 1.2486e-04 - val_mean_absolute_error: 0.0081
# Epoch 96/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.9694e-04 - mean_absolute_error: 0.0104 - val_loss: 2.5806e-04 - val_mean_absolute_error: 0.0136
# Epoch 97/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8484e-04 - mean_absolute_error: 0.0097 - val_loss: 1.1020e-04 - val_mean_absolute_error: 0.0074
# Epoch 98/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.7988e-04 - mean_absolute_error: 0.0093 - val_loss: 1.0808e-04 - val_mean_absolute_error: 0.0072
# Epoch 99/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.6984e-04 - mean_absolute_error: 0.0091 - val_loss: 1.1230e-04 - val_mean_absolute_error: 0.0074
# Epoch 100/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3912e-04 - mean_absolute_error: 0.0081 - val_loss: 1.6169e-04 - val_mean_absolute_error: 0.0099
# Epoch 101/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.7180e-04 - mean_absolute_error: 0.0095 - val_loss: 1.0129e-04 - val_mean_absolute_error: 0.0070
# Epoch 102/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5523e-04 - mean_absolute_error: 0.0087 - val_loss: 1.4432e-04 - val_mean_absolute_error: 0.0091
# Epoch 103/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9746e-04 - mean_absolute_error: 0.0101 - val_loss: 1.4675e-04 - val_mean_absolute_error: 0.0090
# Epoch 104/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7861e-04 - mean_absolute_error: 0.0094 - val_loss: 1.2263e-04 - val_mean_absolute_error: 0.0079
# Epoch 105/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6750e-04 - mean_absolute_error: 0.0092 - val_loss: 1.2087e-04 - val_mean_absolute_error: 0.0079
# Epoch 106/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5332e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0057e-04 - val_mean_absolute_error: 0.0070
# Epoch 107/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.8894e-04 - mean_absolute_error: 0.0100 - val_loss: 1.6374e-04 - val_mean_absolute_error: 0.0098
# Epoch 108/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7845e-04 - mean_absolute_error: 0.0093 - val_loss: 1.3130e-04 - val_mean_absolute_error: 0.0083
# Epoch 109/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.6060e-04 - mean_absolute_error: 0.0087 - val_loss: 2.8978e-04 - val_mean_absolute_error: 0.0147
# Epoch 110/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8009e-04 - mean_absolute_error: 0.0095 - val_loss: 1.1332e-04 - val_mean_absolute_error: 0.0077
# Epoch 111/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.6553e-04 - mean_absolute_error: 0.0092 - val_loss: 1.0103e-04 - val_mean_absolute_error: 0.0070
# Epoch 112/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.6360e-04 - mean_absolute_error: 0.0090 - val_loss: 2.6989e-04 - val_mean_absolute_error: 0.0140
# Epoch 113/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.5795e-04 - mean_absolute_error: 0.0090 - val_loss: 2.1682e-04 - val_mean_absolute_error: 0.0120
# Epoch 114/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6770e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0172e-04 - val_mean_absolute_error: 0.0072
# Epoch 115/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.6877e-04 - mean_absolute_error: 0.0092 - val_loss: 1.2180e-04 - val_mean_absolute_error: 0.0081
# Epoch 116/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.8583e-04 - mean_absolute_error: 0.0101 - val_loss: 1.3880e-04 - val_mean_absolute_error: 0.0086
# Epoch 117/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5060e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0155e-04 - val_mean_absolute_error: 0.0070
# Epoch 118/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5832e-04 - mean_absolute_error: 0.0088 - val_loss: 1.7789e-04 - val_mean_absolute_error: 0.0104
# Epoch 119/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.6241e-04 - mean_absolute_error: 0.0087 - val_loss: 2.2559e-04 - val_mean_absolute_error: 0.0126
# Epoch 120/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.7614e-04 - mean_absolute_error: 0.0094 - val_loss: 1.4466e-04 - val_mean_absolute_error: 0.0093
# Epoch 121/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6943e-04 - mean_absolute_error: 0.0095 - val_loss: 1.0818e-04 - val_mean_absolute_error: 0.0074
# Epoch 122/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5075e-04 - mean_absolute_error: 0.0087 - val_loss: 1.3502e-04 - val_mean_absolute_error: 0.0085
# Epoch 123/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7303e-04 - mean_absolute_error: 0.0093 - val_loss: 1.0163e-04 - val_mean_absolute_error: 0.0071
# Epoch 124/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.7312e-04 - mean_absolute_error: 0.0095 - val_loss: 1.2495e-04 - val_mean_absolute_error: 0.0081
# Epoch 125/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.7547e-04 - mean_absolute_error: 0.0089 - val_loss: 1.1350e-04 - val_mean_absolute_error: 0.0078
# Epoch 126/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.8440e-04 - mean_absolute_error: 0.0097 - val_loss: 2.3544e-04 - val_mean_absolute_error: 0.0127
# Epoch 127/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.6995e-04 - mean_absolute_error: 0.0093 - val_loss: 1.0063e-04 - val_mean_absolute_error: 0.0071
# Epoch 128/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.6640e-04 - mean_absolute_error: 0.0090 - val_loss: 1.0049e-04 - val_mean_absolute_error: 0.0070
# Epoch 129/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.5325e-04 - mean_absolute_error: 0.0087 - val_loss: 1.6908e-04 - val_mean_absolute_error: 0.0100
# Epoch 130/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.7112e-04 - mean_absolute_error: 0.0092 - val_loss: 8.1694e-04 - val_mean_absolute_error: 0.0270
# Epoch 131/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.4887e-04 - mean_absolute_error: 0.0113 - val_loss: 1.5601e-04 - val_mean_absolute_error: 0.0094
# Epoch 132/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5667e-04 - mean_absolute_error: 0.0087 - val_loss: 1.3699e-04 - val_mean_absolute_error: 0.0086
# Epoch 133/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.5034e-04 - mean_absolute_error: 0.0085 - val_loss: 1.4002e-04 - val_mean_absolute_error: 0.0091
# Epoch 134/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5751e-04 - mean_absolute_error: 0.0089 - val_loss: 1.1457e-04 - val_mean_absolute_error: 0.0076
# Epoch 135/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.5864e-04 - mean_absolute_error: 0.0091 - val_loss: 1.1274e-04 - val_mean_absolute_error: 0.0075
# Epoch 136/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4988e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2376e-04 - val_mean_absolute_error: 0.0080
# Epoch 137/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.8914e-04 - mean_absolute_error: 0.0095 - val_loss: 1.2526e-04 - val_mean_absolute_error: 0.0081
# Epoch 138/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5776e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0490e-04 - val_mean_absolute_error: 0.0072
# Epoch 139/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.6383e-04 - mean_absolute_error: 0.0088 - val_loss: 1.1002e-04 - val_mean_absolute_error: 0.0076
# Epoch 140/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.5133e-04 - mean_absolute_error: 0.0084 - val_loss: 1.8347e-04 - val_mean_absolute_error: 0.0107
# Epoch 141/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.7967e-04 - mean_absolute_error: 0.0095 - val_loss: 1.5277e-04 - val_mean_absolute_error: 0.0093
# Epoch 142/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6580e-04 - mean_absolute_error: 0.0088 - val_loss: 2.3879e-04 - val_mean_absolute_error: 0.0128
# Epoch 143/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5080e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2691e-04 - val_mean_absolute_error: 0.0085
# Epoch 144/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6278e-04 - mean_absolute_error: 0.0092 - val_loss: 2.1518e-04 - val_mean_absolute_error: 0.0119
# Epoch 145/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7869e-04 - mean_absolute_error: 0.0093 - val_loss: 1.6046e-04 - val_mean_absolute_error: 0.0096
# Epoch 146/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4308e-04 - mean_absolute_error: 0.0083 - val_loss: 1.3100e-04 - val_mean_absolute_error: 0.0083
# Epoch 147/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3660e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2840e-04 - val_mean_absolute_error: 0.0082
# Epoch 148/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.6039e-04 - mean_absolute_error: 0.0088 - val_loss: 2.3709e-04 - val_mean_absolute_error: 0.0131
# Epoch 149/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7877e-04 - mean_absolute_error: 0.0097 - val_loss: 2.5670e-04 - val_mean_absolute_error: 0.0134
# Epoch 150/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.8912e-04 - mean_absolute_error: 0.0096 - val_loss: 1.0175e-04 - val_mean_absolute_error: 0.0071
# Epoch 151/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5064e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0347e-04 - val_mean_absolute_error: 0.0071
# Epoch 152/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4286e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0544e-04 - val_mean_absolute_error: 0.0073
# Epoch 153/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6261e-04 - mean_absolute_error: 0.0088 - val_loss: 3.6279e-04 - val_mean_absolute_error: 0.0168
# Epoch 154/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.6786e-04 - mean_absolute_error: 0.0092 - val_loss: 1.2435e-04 - val_mean_absolute_error: 0.0080
# Epoch 155/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.3786e-04 - mean_absolute_error: 0.0082 - val_loss: 1.1761e-04 - val_mean_absolute_error: 0.0080
# Epoch 156/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.6766e-04 - mean_absolute_error: 0.0090 - val_loss: 1.1298e-04 - val_mean_absolute_error: 0.0076
# Epoch 157/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6215e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0667e-04 - val_mean_absolute_error: 0.0074
# Epoch 158/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6737e-04 - mean_absolute_error: 0.0091 - val_loss: 1.0252e-04 - val_mean_absolute_error: 0.0072
# Epoch 159/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4520e-04 - mean_absolute_error: 0.0084 - val_loss: 1.4954e-04 - val_mean_absolute_error: 0.0091
# Epoch 160/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5011e-04 - mean_absolute_error: 0.0084 - val_loss: 2.7776e-04 - val_mean_absolute_error: 0.0141
# Epoch 161/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9098e-04 - mean_absolute_error: 0.0100 - val_loss: 1.0027e-04 - val_mean_absolute_error: 0.0071
# Epoch 162/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4547e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0284e-04 - val_mean_absolute_error: 0.0071
# Epoch 163/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3849e-04 - mean_absolute_error: 0.0082 - val_loss: 1.0083e-04 - val_mean_absolute_error: 0.0072
# Epoch 164/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6381e-04 - mean_absolute_error: 0.0089 - val_loss: 1.1237e-04 - val_mean_absolute_error: 0.0075
# Epoch 165/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6441e-04 - mean_absolute_error: 0.0091 - val_loss: 1.5687e-04 - val_mean_absolute_error: 0.0095
# Epoch 166/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.6293e-04 - mean_absolute_error: 0.0087 - val_loss: 3.0189e-04 - val_mean_absolute_error: 0.0153
# Epoch 167/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.9240e-04 - mean_absolute_error: 0.0102 - val_loss: 2.0694e-04 - val_mean_absolute_error: 0.0116
# Epoch 168/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3650e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2047e-04 - val_mean_absolute_error: 0.0078
# Epoch 169/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.6133e-04 - mean_absolute_error: 0.0088 - val_loss: 1.8751e-04 - val_mean_absolute_error: 0.0108
# Epoch 170/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.6865e-04 - mean_absolute_error: 0.0091 - val_loss: 1.2082e-04 - val_mean_absolute_error: 0.0082
# Epoch 171/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5907e-04 - mean_absolute_error: 0.0092 - val_loss: 4.6186e-04 - val_mean_absolute_error: 0.0194
# Epoch 172/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.8694e-04 - mean_absolute_error: 0.0101 - val_loss: 1.0181e-04 - val_mean_absolute_error: 0.0071
# Epoch 173/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6140e-04 - mean_absolute_error: 0.0092 - val_loss: 1.1610e-04 - val_mean_absolute_error: 0.0079
# Epoch 174/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.4887e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2419e-04 - val_mean_absolute_error: 0.0084
# Epoch 175/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5261e-04 - mean_absolute_error: 0.0087 - val_loss: 1.0106e-04 - val_mean_absolute_error: 0.0071
# Epoch 176/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5520e-04 - mean_absolute_error: 0.0087 - val_loss: 1.0142e-04 - val_mean_absolute_error: 0.0071
# Epoch 177/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6304e-04 - mean_absolute_error: 0.0088 - val_loss: 2.6178e-04 - val_mean_absolute_error: 0.0136
# Epoch 178/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5236e-04 - mean_absolute_error: 0.0083 - val_loss: 2.2921e-04 - val_mean_absolute_error: 0.0125
# Epoch 179/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.6785e-04 - mean_absolute_error: 0.0093 - val_loss: 1.4164e-04 - val_mean_absolute_error: 0.0092
# Epoch 180/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7745e-04 - mean_absolute_error: 0.0096 - val_loss: 1.2573e-04 - val_mean_absolute_error: 0.0081
# Epoch 181/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.4195e-04 - mean_absolute_error: 0.0082 - val_loss: 1.0473e-04 - val_mean_absolute_error: 0.0072
# Epoch 182/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4900e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0514e-04 - val_mean_absolute_error: 0.0072
# Epoch 183/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.5341e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0051e-04 - val_mean_absolute_error: 0.0071
# Epoch 184/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.5688e-04 - mean_absolute_error: 0.0087 - val_loss: 1.5345e-04 - val_mean_absolute_error: 0.0093
# Epoch 185/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6904e-04 - mean_absolute_error: 0.0091 - val_loss: 1.7090e-04 - val_mean_absolute_error: 0.0105
# Epoch 186/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.8315e-04 - mean_absolute_error: 0.0097 - val_loss: 1.1148e-04 - val_mean_absolute_error: 0.0075
# Epoch 187/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.5876e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0485e-04 - val_mean_absolute_error: 0.0073
# Epoch 188/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5615e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0259e-04 - val_mean_absolute_error: 0.0071
# Epoch 189/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6144e-04 - mean_absolute_error: 0.0088 - val_loss: 1.0957e-04 - val_mean_absolute_error: 0.0074
# Epoch 190/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5853e-04 - mean_absolute_error: 0.0089 - val_loss: 2.3005e-04 - val_mean_absolute_error: 0.0125
# Epoch 191/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5839e-04 - mean_absolute_error: 0.0090 - val_loss: 1.0014e-04 - val_mean_absolute_error: 0.0071
# Epoch 192/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3829e-04 - mean_absolute_error: 0.0082 - val_loss: 1.6563e-04 - val_mean_absolute_error: 0.0099
# Epoch 193/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4253e-04 - mean_absolute_error: 0.0084 - val_loss: 1.4270e-04 - val_mean_absolute_error: 0.0092
# Epoch 194/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8132e-04 - mean_absolute_error: 0.0097 - val_loss: 1.0914e-04 - val_mean_absolute_error: 0.0074
# Epoch 195/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.5182e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0506e-04 - val_mean_absolute_error: 0.0073
# Epoch 196/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3755e-04 - mean_absolute_error: 0.0083 - val_loss: 1.0337e-04 - val_mean_absolute_error: 0.0072
# Epoch 197/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4789e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0633e-04 - val_mean_absolute_error: 0.0073
# Epoch 198/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4622e-04 - mean_absolute_error: 0.0082 - val_loss: 3.6340e-04 - val_mean_absolute_error: 0.0168
# Epoch 199/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4029e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0013e-04 - val_mean_absolute_error: 0.0071
# Epoch 200/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5390e-04 - mean_absolute_error: 0.0088 - val_loss: 1.1566e-04 - val_mean_absolute_error: 0.0077

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2638e-04 - mean_absolute_error: 0.0075
# Test Loss: [0.00011565838940441608, 0.007674986030906439]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 120
# 131

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 588936.0400961558
# RMSE: 767.4216833632966
# MAE: 568.27685546875
# MAPE: 1.5403484166514707 %
#
# Model evalution on validate set
# MSE: 5165335.291398356
# RMSE: 2272.737400448709
# MAE: 1439.9975142045455
# MAPE: 2.96844789710851 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 820ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step

# %%
y_pred_30_days
# Out:
# array([[60681.863],
#        [60063.81 ],
#        [60886.953],
#        [60114.72 ],
#        [60829.97 ],
#        [60138.62 ],
#        [60797.14 ],
#        [60169.7  ],
#        [60768.574],
#        [60197.516],
#        [60742.28 ],
#        [60222.734],
#        [60718.355],
#        [60245.7  ],
#        [60696.582],
#        [60266.566],
#        [60676.773],
#        [60285.56 ],
#        [60658.75 ],
#        [60302.82 ],
#        [60642.34 ],
#        [60318.53 ],
#        [60627.42 ],
#        [60332.824],
#        [60613.832],
#        [60345.816],
#        [60601.484],
#        [60357.637],
#        [60590.246],
#        [60368.383],
#        [60580.016]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Forecast Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
