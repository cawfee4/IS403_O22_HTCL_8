# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: CMG - Test/Train/Vaildation: 80/10/10
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 740.67
# - MAE: 513.57
# - MAPE: 1.45 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830
# ...           ...
# 2024-05-27  59000
# 2024-05-28  62100
# 2024-05-29  60000
# 2024-05-30  59200
# 2024-05-31  60900
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((1039, 10), (1039,), (120, 10), (120,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 9s 59ms/step - loss: 0.0368 - mean_absolute_error: 0.1421 - val_loss: 0.0048 - val_mean_absolute_error: 0.0665
# Epoch 2/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - mean_absolute_error: 0.0290 - val_loss: 6.6773e-04 - val_mean_absolute_error: 0.0196
# Epoch 3/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.4429e-04 - mean_absolute_error: 0.0174 - val_loss: 5.1573e-04 - val_mean_absolute_error: 0.0172
# Epoch 4/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.1246e-04 - mean_absolute_error: 0.0172 - val_loss: 5.2115e-04 - val_mean_absolute_error: 0.0176
# Epoch 5/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.4193e-04 - mean_absolute_error: 0.0190 - val_loss: 5.1115e-04 - val_mean_absolute_error: 0.0174
# Epoch 6/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.3190e-04 - mean_absolute_error: 0.0174 - val_loss: 4.4322e-04 - val_mean_absolute_error: 0.0157
# Epoch 7/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.2061e-04 - mean_absolute_error: 0.0180 - val_loss: 4.4779e-04 - val_mean_absolute_error: 0.0159
# Epoch 8/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.2791e-04 - mean_absolute_error: 0.0177 - val_loss: 4.2914e-04 - val_mean_absolute_error: 0.0154
# Epoch 9/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.3488e-04 - mean_absolute_error: 0.0162 - val_loss: 4.5947e-04 - val_mean_absolute_error: 0.0163
# Epoch 10/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.9542e-04 - mean_absolute_error: 0.0175 - val_loss: 4.8937e-04 - val_mean_absolute_error: 0.0171
# Epoch 11/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.5127e-04 - mean_absolute_error: 0.0178 - val_loss: 4.3850e-04 - val_mean_absolute_error: 0.0159
# Epoch 12/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.2302e-04 - mean_absolute_error: 0.0163 - val_loss: 3.9850e-04 - val_mean_absolute_error: 0.0148
# Epoch 13/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.3850e-04 - mean_absolute_error: 0.0172 - val_loss: 4.8997e-04 - val_mean_absolute_error: 0.0172
# Epoch 14/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.5204e-04 - mean_absolute_error: 0.0167 - val_loss: 4.3143e-04 - val_mean_absolute_error: 0.0158
# Epoch 15/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.9008e-04 - mean_absolute_error: 0.0182 - val_loss: 3.6920e-04 - val_mean_absolute_error: 0.0142
# Epoch 16/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.5895e-04 - mean_absolute_error: 0.0168 - val_loss: 3.9033e-04 - val_mean_absolute_error: 0.0148
# Epoch 17/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.1212e-04 - mean_absolute_error: 0.0163 - val_loss: 3.8625e-04 - val_mean_absolute_error: 0.0147
# Epoch 18/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.5848e-04 - mean_absolute_error: 0.0166 - val_loss: 5.3382e-04 - val_mean_absolute_error: 0.0184
# Epoch 19/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.2084e-04 - mean_absolute_error: 0.0177 - val_loss: 3.8644e-04 - val_mean_absolute_error: 0.0148
# Epoch 20/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.0915e-04 - mean_absolute_error: 0.0158 - val_loss: 6.9517e-04 - val_mean_absolute_error: 0.0223
# Epoch 21/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.3051e-04 - mean_absolute_error: 0.0163 - val_loss: 3.0652e-04 - val_mean_absolute_error: 0.0131
# Epoch 22/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.8817e-04 - mean_absolute_error: 0.0162 - val_loss: 3.0569e-04 - val_mean_absolute_error: 0.0127
# Epoch 23/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.7190e-04 - mean_absolute_error: 0.0154 - val_loss: 2.8701e-04 - val_mean_absolute_error: 0.0127
# Epoch 24/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.7257e-04 - mean_absolute_error: 0.0158 - val_loss: 4.4050e-04 - val_mean_absolute_error: 0.0165
# Epoch 25/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.0840e-04 - mean_absolute_error: 0.0162 - val_loss: 2.7068e-04 - val_mean_absolute_error: 0.0122
# Epoch 26/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 3.9381e-04 - mean_absolute_error: 0.0143 - val_loss: 4.4092e-04 - val_mean_absolute_error: 0.0167
# Epoch 27/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.0001e-04 - mean_absolute_error: 0.0144 - val_loss: 2.8221e-04 - val_mean_absolute_error: 0.0131
# Epoch 28/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.9399e-04 - mean_absolute_error: 0.0145 - val_loss: 2.6131e-04 - val_mean_absolute_error: 0.0117
# Epoch 29/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.1454e-04 - mean_absolute_error: 0.0145 - val_loss: 3.6336e-04 - val_mean_absolute_error: 0.0149
# Epoch 30/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.2221e-04 - mean_absolute_error: 0.0152 - val_loss: 2.3542e-04 - val_mean_absolute_error: 0.0111
# Epoch 31/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.5966e-04 - mean_absolute_error: 0.0132 - val_loss: 3.8689e-04 - val_mean_absolute_error: 0.0156
# Epoch 32/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 4.0985e-04 - mean_absolute_error: 0.0151 - val_loss: 2.1266e-04 - val_mean_absolute_error: 0.0112
# Epoch 33/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.2117e-04 - mean_absolute_error: 0.0130 - val_loss: 7.6532e-04 - val_mean_absolute_error: 0.0245
# Epoch 34/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.4636e-04 - mean_absolute_error: 0.0133 - val_loss: 5.3492e-04 - val_mean_absolute_error: 0.0196
# Epoch 35/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.4311e-04 - mean_absolute_error: 0.0133 - val_loss: 5.3377e-04 - val_mean_absolute_error: 0.0196
# Epoch 36/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.4270e-04 - mean_absolute_error: 0.0134 - val_loss: 2.5455e-04 - val_mean_absolute_error: 0.0119
# Epoch 37/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.1058e-04 - mean_absolute_error: 0.0125 - val_loss: 3.0680e-04 - val_mean_absolute_error: 0.0137
# Epoch 38/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.8356e-04 - mean_absolute_error: 0.0120 - val_loss: 1.7892e-04 - val_mean_absolute_error: 0.0101
# Epoch 39/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.4721e-04 - mean_absolute_error: 0.0133 - val_loss: 1.7371e-04 - val_mean_absolute_error: 0.0097
# Epoch 40/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.9295e-04 - mean_absolute_error: 0.0125 - val_loss: 2.4151e-04 - val_mean_absolute_error: 0.0117
# Epoch 41/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.8078e-04 - mean_absolute_error: 0.0117 - val_loss: 2.9752e-04 - val_mean_absolute_error: 0.0135
# Epoch 42/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.7713e-04 - mean_absolute_error: 0.0116 - val_loss: 4.9528e-04 - val_mean_absolute_error: 0.0189
# Epoch 43/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.0674e-04 - mean_absolute_error: 0.0127 - val_loss: 1.6637e-04 - val_mean_absolute_error: 0.0094
# Epoch 44/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.1629e-04 - mean_absolute_error: 0.0125 - val_loss: 3.3486e-04 - val_mean_absolute_error: 0.0146
# Epoch 45/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.4411e-04 - mean_absolute_error: 0.0112 - val_loss: 2.0321e-04 - val_mean_absolute_error: 0.0106
# Epoch 46/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.8162e-04 - mean_absolute_error: 0.0120 - val_loss: 1.6945e-04 - val_mean_absolute_error: 0.0094
# Epoch 47/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.7058e-04 - mean_absolute_error: 0.0114 - val_loss: 2.6649e-04 - val_mean_absolute_error: 0.0126
# Epoch 48/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.7634e-04 - mean_absolute_error: 0.0118 - val_loss: 2.6776e-04 - val_mean_absolute_error: 0.0137
# Epoch 49/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.6022e-04 - mean_absolute_error: 0.0118 - val_loss: 2.4687e-04 - val_mean_absolute_error: 0.0131
# Epoch 50/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.3018e-04 - mean_absolute_error: 0.0126 - val_loss: 4.1672e-04 - val_mean_absolute_error: 0.0172
# Epoch 51/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.4981e-04 - mean_absolute_error: 0.0112 - val_loss: 1.9962e-04 - val_mean_absolute_error: 0.0105
# Epoch 52/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.5399e-04 - mean_absolute_error: 0.0111 - val_loss: 1.6607e-04 - val_mean_absolute_error: 0.0094
# Epoch 53/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.6309e-04 - mean_absolute_error: 0.0115 - val_loss: 3.1757e-04 - val_mean_absolute_error: 0.0145
# Epoch 54/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.6605e-04 - mean_absolute_error: 0.0113 - val_loss: 2.1923e-04 - val_mean_absolute_error: 0.0112
# Epoch 55/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.2495e-04 - mean_absolute_error: 0.0107 - val_loss: 1.5392e-04 - val_mean_absolute_error: 0.0094
# Epoch 56/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.4346e-04 - mean_absolute_error: 0.0110 - val_loss: 1.5594e-04 - val_mean_absolute_error: 0.0090
# Epoch 57/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.4286e-04 - mean_absolute_error: 0.0109 - val_loss: 1.4832e-04 - val_mean_absolute_error: 0.0088
# Epoch 58/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.3570e-04 - mean_absolute_error: 0.0108 - val_loss: 6.2440e-04 - val_mean_absolute_error: 0.0224
# Epoch 59/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.9234e-04 - mean_absolute_error: 0.0120 - val_loss: 2.2838e-04 - val_mean_absolute_error: 0.0116
# Epoch 60/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.2124e-04 - mean_absolute_error: 0.0107 - val_loss: 1.5131e-04 - val_mean_absolute_error: 0.0094
# Epoch 61/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.4421e-04 - mean_absolute_error: 0.0114 - val_loss: 2.5226e-04 - val_mean_absolute_error: 0.0126
# Epoch 62/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.1753e-04 - mean_absolute_error: 0.0105 - val_loss: 2.3070e-04 - val_mean_absolute_error: 0.0119
# Epoch 63/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.0400e-04 - mean_absolute_error: 0.0101 - val_loss: 1.9982e-04 - val_mean_absolute_error: 0.0108
# Epoch 64/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.2850e-04 - mean_absolute_error: 0.0110 - val_loss: 1.6571e-04 - val_mean_absolute_error: 0.0094
# Epoch 65/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.1396e-04 - mean_absolute_error: 0.0099 - val_loss: 3.5569e-04 - val_mean_absolute_error: 0.0161
# Epoch 66/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.5140e-04 - mean_absolute_error: 0.0116 - val_loss: 1.3369e-04 - val_mean_absolute_error: 0.0085
# Epoch 67/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.1611e-04 - mean_absolute_error: 0.0103 - val_loss: 2.7398e-04 - val_mean_absolute_error: 0.0135
# Epoch 68/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.0908e-04 - mean_absolute_error: 0.0103 - val_loss: 3.1672e-04 - val_mean_absolute_error: 0.0150
# Epoch 69/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.1566e-04 - mean_absolute_error: 0.0106 - val_loss: 3.0067e-04 - val_mean_absolute_error: 0.0145
# Epoch 70/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.1658e-04 - mean_absolute_error: 0.0103 - val_loss: 1.3104e-04 - val_mean_absolute_error: 0.0082
# Epoch 71/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.3865e-04 - mean_absolute_error: 0.0112 - val_loss: 1.4553e-04 - val_mean_absolute_error: 0.0088
# Epoch 72/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.3724e-04 - mean_absolute_error: 0.0111 - val_loss: 1.3328e-04 - val_mean_absolute_error: 0.0081
# Epoch 73/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.9214e-04 - mean_absolute_error: 0.0096 - val_loss: 2.1299e-04 - val_mean_absolute_error: 0.0120
# Epoch 74/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.6029e-04 - mean_absolute_error: 0.0116 - val_loss: 3.7754e-04 - val_mean_absolute_error: 0.0169
# Epoch 75/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.9880e-04 - mean_absolute_error: 0.0098 - val_loss: 1.2323e-04 - val_mean_absolute_error: 0.0079
# Epoch 76/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.1687e-04 - mean_absolute_error: 0.0107 - val_loss: 5.3008e-04 - val_mean_absolute_error: 0.0209
# Epoch 77/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.6960e-04 - mean_absolute_error: 0.0118 - val_loss: 1.2375e-04 - val_mean_absolute_error: 0.0079
# Epoch 78/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.9125e-04 - mean_absolute_error: 0.0097 - val_loss: 1.1789e-04 - val_mean_absolute_error: 0.0076
# Epoch 79/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8062e-04 - mean_absolute_error: 0.0095 - val_loss: 1.5121e-04 - val_mean_absolute_error: 0.0091
# Epoch 80/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.0161e-04 - mean_absolute_error: 0.0099 - val_loss: 2.3145e-04 - val_mean_absolute_error: 0.0124
# Epoch 81/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7741e-04 - mean_absolute_error: 0.0092 - val_loss: 1.1215e-04 - val_mean_absolute_error: 0.0073
# Epoch 82/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.3187e-04 - mean_absolute_error: 0.0109 - val_loss: 1.2620e-04 - val_mean_absolute_error: 0.0081
# Epoch 83/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.8019e-04 - mean_absolute_error: 0.0094 - val_loss: 1.0904e-04 - val_mean_absolute_error: 0.0071
# Epoch 84/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8565e-04 - mean_absolute_error: 0.0096 - val_loss: 1.5212e-04 - val_mean_absolute_error: 0.0094
# Epoch 85/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.0110e-04 - mean_absolute_error: 0.0100 - val_loss: 1.1210e-04 - val_mean_absolute_error: 0.0073
# Epoch 86/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6892e-04 - mean_absolute_error: 0.0089 - val_loss: 1.4237e-04 - val_mean_absolute_error: 0.0088
# Epoch 87/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.9647e-04 - mean_absolute_error: 0.0101 - val_loss: 2.1788e-04 - val_mean_absolute_error: 0.0120
# Epoch 88/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.8831e-04 - mean_absolute_error: 0.0097 - val_loss: 2.5362e-04 - val_mean_absolute_error: 0.0134
# Epoch 89/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6478e-04 - mean_absolute_error: 0.0090 - val_loss: 2.1116e-04 - val_mean_absolute_error: 0.0118
# Epoch 90/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.8059e-04 - mean_absolute_error: 0.0096 - val_loss: 1.0626e-04 - val_mean_absolute_error: 0.0070
# Epoch 91/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.8650e-04 - mean_absolute_error: 0.0095 - val_loss: 2.6938e-04 - val_mean_absolute_error: 0.0140
# Epoch 92/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.9436e-04 - mean_absolute_error: 0.0101 - val_loss: 3.2967e-04 - val_mean_absolute_error: 0.0159
# Epoch 93/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.7689e-04 - mean_absolute_error: 0.0093 - val_loss: 1.2858e-04 - val_mean_absolute_error: 0.0082
# Epoch 94/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.7501e-04 - mean_absolute_error: 0.0092 - val_loss: 1.1262e-04 - val_mean_absolute_error: 0.0074
# Epoch 95/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6626e-04 - mean_absolute_error: 0.0090 - val_loss: 1.9796e-04 - val_mean_absolute_error: 0.0116
# Epoch 96/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6476e-04 - mean_absolute_error: 0.0091 - val_loss: 1.8242e-04 - val_mean_absolute_error: 0.0106
# Epoch 97/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.7838e-04 - mean_absolute_error: 0.0094 - val_loss: 2.3153e-04 - val_mean_absolute_error: 0.0126
# Epoch 98/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.8286e-04 - mean_absolute_error: 0.0092 - val_loss: 1.0122e-04 - val_mean_absolute_error: 0.0070
# Epoch 99/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.9936e-04 - mean_absolute_error: 0.0101 - val_loss: 1.4635e-04 - val_mean_absolute_error: 0.0090
# Epoch 100/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.9089e-04 - mean_absolute_error: 0.0097 - val_loss: 1.8290e-04 - val_mean_absolute_error: 0.0106
# Epoch 101/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.9172e-04 - mean_absolute_error: 0.0102 - val_loss: 1.5293e-04 - val_mean_absolute_error: 0.0093
# Epoch 102/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6623e-04 - mean_absolute_error: 0.0089 - val_loss: 1.2773e-04 - val_mean_absolute_error: 0.0081
# Epoch 103/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.7285e-04 - mean_absolute_error: 0.0094 - val_loss: 1.4615e-04 - val_mean_absolute_error: 0.0090
# Epoch 104/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.6931e-04 - mean_absolute_error: 0.0092 - val_loss: 1.4094e-04 - val_mean_absolute_error: 0.0087
# Epoch 105/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4779e-04 - mean_absolute_error: 0.0086 - val_loss: 1.1364e-04 - val_mean_absolute_error: 0.0076
# Epoch 106/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.6999e-04 - mean_absolute_error: 0.0090 - val_loss: 1.9710e-04 - val_mean_absolute_error: 0.0113
# Epoch 107/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7721e-04 - mean_absolute_error: 0.0093 - val_loss: 2.1886e-04 - val_mean_absolute_error: 0.0122
# Epoch 108/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.0104e-04 - mean_absolute_error: 0.0102 - val_loss: 1.0157e-04 - val_mean_absolute_error: 0.0070
# Epoch 109/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7269e-04 - mean_absolute_error: 0.0093 - val_loss: 1.7072e-04 - val_mean_absolute_error: 0.0101
# Epoch 110/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.6770e-04 - mean_absolute_error: 0.0090 - val_loss: 1.0003e-04 - val_mean_absolute_error: 0.0070
# Epoch 111/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 1.7646e-04 - mean_absolute_error: 0.0091 - val_loss: 1.7301e-04 - val_mean_absolute_error: 0.0102
# Epoch 112/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.5165e-04 - mean_absolute_error: 0.0083 - val_loss: 1.0211e-04 - val_mean_absolute_error: 0.0071
# Epoch 113/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.7253e-04 - mean_absolute_error: 0.0094 - val_loss: 3.1948e-04 - val_mean_absolute_error: 0.0156
# Epoch 114/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.9549e-04 - mean_absolute_error: 0.0103 - val_loss: 1.0033e-04 - val_mean_absolute_error: 0.0070
# Epoch 115/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.9291e-04 - mean_absolute_error: 0.0097 - val_loss: 1.9061e-04 - val_mean_absolute_error: 0.0110
# Epoch 116/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.6165e-04 - mean_absolute_error: 0.0087 - val_loss: 1.0874e-04 - val_mean_absolute_error: 0.0073
# Epoch 117/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.7570e-04 - mean_absolute_error: 0.0092 - val_loss: 1.0719e-04 - val_mean_absolute_error: 0.0074
# Epoch 118/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.7589e-04 - mean_absolute_error: 0.0093 - val_loss: 1.0326e-04 - val_mean_absolute_error: 0.0072
# Epoch 119/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7399e-04 - mean_absolute_error: 0.0090 - val_loss: 1.0015e-04 - val_mean_absolute_error: 0.0071
# Epoch 120/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8372e-04 - mean_absolute_error: 0.0098 - val_loss: 1.0918e-04 - val_mean_absolute_error: 0.0075
# Epoch 121/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5327e-04 - mean_absolute_error: 0.0087 - val_loss: 1.1773e-04 - val_mean_absolute_error: 0.0077
# Epoch 122/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.5812e-04 - mean_absolute_error: 0.0089 - val_loss: 1.4212e-04 - val_mean_absolute_error: 0.0092
# Epoch 123/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.7826e-04 - mean_absolute_error: 0.0096 - val_loss: 1.3240e-04 - val_mean_absolute_error: 0.0083
# Epoch 124/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.7230e-04 - mean_absolute_error: 0.0091 - val_loss: 2.2283e-04 - val_mean_absolute_error: 0.0126
# Epoch 125/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.9719e-04 - mean_absolute_error: 0.0099 - val_loss: 1.2754e-04 - val_mean_absolute_error: 0.0081
# Epoch 126/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5442e-04 - mean_absolute_error: 0.0086 - val_loss: 3.0887e-04 - val_mean_absolute_error: 0.0153
# Epoch 127/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.8455e-04 - mean_absolute_error: 0.0098 - val_loss: 2.2288e-04 - val_mean_absolute_error: 0.0123
# Epoch 128/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7633e-04 - mean_absolute_error: 0.0095 - val_loss: 2.3638e-04 - val_mean_absolute_error: 0.0127
# Epoch 129/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8178e-04 - mean_absolute_error: 0.0096 - val_loss: 1.1326e-04 - val_mean_absolute_error: 0.0075
# Epoch 130/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.8832e-04 - mean_absolute_error: 0.0100 - val_loss: 2.4024e-04 - val_mean_absolute_error: 0.0129
# Epoch 131/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.0532e-04 - mean_absolute_error: 0.0104 - val_loss: 3.1980e-04 - val_mean_absolute_error: 0.0156
# Epoch 132/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.8771e-04 - mean_absolute_error: 0.0099 - val_loss: 1.8131e-04 - val_mean_absolute_error: 0.0106
# Epoch 133/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.5209e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2531e-04 - val_mean_absolute_error: 0.0080
# Epoch 134/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 3s 62ms/step - loss: 1.8130e-04 - mean_absolute_error: 0.0093 - val_loss: 1.5286e-04 - val_mean_absolute_error: 0.0093
# Epoch 135/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.4442e-04 - mean_absolute_error: 0.0084 - val_loss: 9.9799e-05 - val_mean_absolute_error: 0.0070
# Epoch 136/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.6886e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0595e-04 - val_mean_absolute_error: 0.0073
# Epoch 137/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.4885e-04 - mean_absolute_error: 0.0083 - val_loss: 1.0334e-04 - val_mean_absolute_error: 0.0071
# Epoch 138/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7885e-04 - mean_absolute_error: 0.0092 - val_loss: 1.8526e-04 - val_mean_absolute_error: 0.0108
# Epoch 139/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.5037e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0468e-04 - val_mean_absolute_error: 0.0072
# Epoch 140/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7425e-04 - mean_absolute_error: 0.0089 - val_loss: 2.2405e-04 - val_mean_absolute_error: 0.0123
# Epoch 141/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.4592e-04 - mean_absolute_error: 0.0084 - val_loss: 2.0503e-04 - val_mean_absolute_error: 0.0115
# Epoch 142/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.7441e-04 - mean_absolute_error: 0.0091 - val_loss: 1.0340e-04 - val_mean_absolute_error: 0.0072
# Epoch 143/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5824e-04 - mean_absolute_error: 0.0090 - val_loss: 1.3801e-04 - val_mean_absolute_error: 0.0090
# Epoch 144/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5989e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0181e-04 - val_mean_absolute_error: 0.0072
# Epoch 145/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4598e-04 - mean_absolute_error: 0.0088 - val_loss: 1.1779e-04 - val_mean_absolute_error: 0.0080
# Epoch 146/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5428e-04 - mean_absolute_error: 0.0090 - val_loss: 1.1750e-04 - val_mean_absolute_error: 0.0077
# Epoch 147/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.6478e-04 - mean_absolute_error: 0.0088 - val_loss: 1.5287e-04 - val_mean_absolute_error: 0.0093
# Epoch 148/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.5978e-04 - mean_absolute_error: 0.0088 - val_loss: 1.4007e-04 - val_mean_absolute_error: 0.0087
# Epoch 149/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3847e-04 - mean_absolute_error: 0.0082 - val_loss: 1.3211e-04 - val_mean_absolute_error: 0.0084
# Epoch 150/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.5204e-04 - mean_absolute_error: 0.0090 - val_loss: 1.0306e-04 - val_mean_absolute_error: 0.0071
# Epoch 151/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5881e-04 - mean_absolute_error: 0.0088 - val_loss: 1.0378e-04 - val_mean_absolute_error: 0.0072
# Epoch 152/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.6586e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0073e-04 - val_mean_absolute_error: 0.0071
# Epoch 153/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.7476e-04 - mean_absolute_error: 0.0095 - val_loss: 2.0831e-04 - val_mean_absolute_error: 0.0120
# Epoch 154/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.7845e-04 - mean_absolute_error: 0.0095 - val_loss: 1.0279e-04 - val_mean_absolute_error: 0.0072
# Epoch 155/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8113e-04 - mean_absolute_error: 0.0097 - val_loss: 1.4887e-04 - val_mean_absolute_error: 0.0091
# Epoch 156/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.7056e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0031e-04 - val_mean_absolute_error: 0.0071
# Epoch 157/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5588e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0429e-04 - val_mean_absolute_error: 0.0073
# Epoch 158/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5048e-04 - mean_absolute_error: 0.0085 - val_loss: 1.6876e-04 - val_mean_absolute_error: 0.0100
# Epoch 159/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7027e-04 - mean_absolute_error: 0.0090 - val_loss: 1.1323e-04 - val_mean_absolute_error: 0.0076
# Epoch 160/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4219e-04 - mean_absolute_error: 0.0083 - val_loss: 2.2956e-04 - val_mean_absolute_error: 0.0125
# Epoch 161/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.7604e-04 - mean_absolute_error: 0.0093 - val_loss: 1.1659e-04 - val_mean_absolute_error: 0.0077
# Epoch 162/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6923e-04 - mean_absolute_error: 0.0090 - val_loss: 1.0310e-04 - val_mean_absolute_error: 0.0071
# Epoch 163/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.4767e-04 - mean_absolute_error: 0.0084 - val_loss: 1.8386e-04 - val_mean_absolute_error: 0.0107
# Epoch 164/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.4105e-04 - mean_absolute_error: 0.0083 - val_loss: 1.7903e-04 - val_mean_absolute_error: 0.0105
# Epoch 165/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.5891e-04 - mean_absolute_error: 0.0089 - val_loss: 1.1293e-04 - val_mean_absolute_error: 0.0076
# Epoch 166/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.5507e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2343e-04 - val_mean_absolute_error: 0.0079
# Epoch 167/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.7327e-04 - mean_absolute_error: 0.0093 - val_loss: 1.9575e-04 - val_mean_absolute_error: 0.0112
# Epoch 168/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6978e-04 - mean_absolute_error: 0.0094 - val_loss: 2.4924e-04 - val_mean_absolute_error: 0.0132
# Epoch 169/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.8868e-04 - mean_absolute_error: 0.0097 - val_loss: 1.4211e-04 - val_mean_absolute_error: 0.0088
# Epoch 170/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4768e-04 - mean_absolute_error: 0.0087 - val_loss: 2.2195e-04 - val_mean_absolute_error: 0.0122
# Epoch 171/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.6390e-04 - mean_absolute_error: 0.0091 - val_loss: 1.3226e-04 - val_mean_absolute_error: 0.0083
# Epoch 172/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6192e-04 - mean_absolute_error: 0.0090 - val_loss: 9.9426e-05 - val_mean_absolute_error: 0.0071
# Epoch 173/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4288e-04 - mean_absolute_error: 0.0084 - val_loss: 1.5050e-04 - val_mean_absolute_error: 0.0092
# Epoch 174/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.4755e-04 - mean_absolute_error: 0.0084 - val_loss: 3.9052e-04 - val_mean_absolute_error: 0.0176
# Epoch 175/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.4243e-04 - mean_absolute_error: 0.0085 - val_loss: 2.6393e-04 - val_mean_absolute_error: 0.0137
# Epoch 176/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6114e-04 - mean_absolute_error: 0.0089 - val_loss: 1.5064e-04 - val_mean_absolute_error: 0.0096
# Epoch 177/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7644e-04 - mean_absolute_error: 0.0095 - val_loss: 1.2343e-04 - val_mean_absolute_error: 0.0080
# Epoch 178/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.5702e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2403e-04 - val_mean_absolute_error: 0.0080
# Epoch 179/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5745e-04 - mean_absolute_error: 0.0086 - val_loss: 1.7576e-04 - val_mean_absolute_error: 0.0104
# Epoch 180/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.7240e-04 - mean_absolute_error: 0.0090 - val_loss: 1.1759e-04 - val_mean_absolute_error: 0.0078
# Epoch 181/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5716e-04 - mean_absolute_error: 0.0087 - val_loss: 1.3615e-04 - val_mean_absolute_error: 0.0085
# Epoch 182/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5091e-04 - mean_absolute_error: 0.0085 - val_loss: 1.8528e-04 - val_mean_absolute_error: 0.0108
# Epoch 183/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.4338e-04 - mean_absolute_error: 0.0085 - val_loss: 2.1509e-04 - val_mean_absolute_error: 0.0119
# Epoch 184/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6982e-04 - mean_absolute_error: 0.0093 - val_loss: 1.1393e-04 - val_mean_absolute_error: 0.0076
# Epoch 185/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.5243e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0017e-04 - val_mean_absolute_error: 0.0071
# Epoch 186/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4656e-04 - mean_absolute_error: 0.0084 - val_loss: 2.5583e-04 - val_mean_absolute_error: 0.0135
# Epoch 187/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5822e-04 - mean_absolute_error: 0.0088 - val_loss: 1.8972e-04 - val_mean_absolute_error: 0.0109
# Epoch 188/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.6791e-04 - mean_absolute_error: 0.0093 - val_loss: 2.0952e-04 - val_mean_absolute_error: 0.0117
# Epoch 189/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.6995e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0028e-04 - val_mean_absolute_error: 0.0071
# Epoch 190/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.5799e-04 - mean_absolute_error: 0.0089 - val_loss: 1.1579e-04 - val_mean_absolute_error: 0.0079
# Epoch 191/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.8304e-04 - mean_absolute_error: 0.0095 - val_loss: 1.0209e-04 - val_mean_absolute_error: 0.0073
# Epoch 192/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.7535e-04 - mean_absolute_error: 0.0095 - val_loss: 1.3634e-04 - val_mean_absolute_error: 0.0086
# Epoch 193/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7338e-04 - mean_absolute_error: 0.0095 - val_loss: 1.3498e-04 - val_mean_absolute_error: 0.0085
# Epoch 194/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5797e-04 - mean_absolute_error: 0.0088 - val_loss: 1.0369e-04 - val_mean_absolute_error: 0.0072
# Epoch 195/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7618e-04 - mean_absolute_error: 0.0091 - val_loss: 1.8937e-04 - val_mean_absolute_error: 0.0109
# Epoch 196/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.7417e-04 - mean_absolute_error: 0.0092 - val_loss: 1.6943e-04 - val_mean_absolute_error: 0.0101
# Epoch 197/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.5385e-04 - mean_absolute_error: 0.0084 - val_loss: 1.5205e-04 - val_mean_absolute_error: 0.0093
# Epoch 198/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3799e-04 - mean_absolute_error: 0.0082 - val_loss: 1.0405e-04 - val_mean_absolute_error: 0.0074
# Epoch 199/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6490e-04 - mean_absolute_error: 0.0093 - val_loss: 1.5320e-04 - val_mean_absolute_error: 0.0093
# Epoch 200/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4200e-04 - mean_absolute_error: 0.0084 - val_loss: 1.1185e-04 - val_mean_absolute_error: 0.0075

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 4s 658ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2233e-04 - mean_absolute_error: 0.0073
# Test Loss: [0.00011185173207195476, 0.007477027364075184]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 120
# 131

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 577914.0735977809
# RMSE: 760.2065992858658
# MAE: 557.7289388020833
# MAPE: 1.5130992734218887 %
#
# Model evalution on validate set
# MSE: 5340987.692767182
# RMSE: 2311.057700008198
# MAE: 1446.3375516528927
# MAPE: 2.964493885605347 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 926ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step

# %%
y_pred_30_days
# Out:
# array([[59638.95 ],
#        [59516.78 ],
#        [59674.03 ],
#        [59548.098],
#        [59640.47 ],
#        [59568.246],
#        [59624.6  ],
#        [59580.996],
#        [59614.82 ],
#        [59588.582],
#        [59608.926],
#        [59593.152],
#        [59605.375],
#        [59595.9  ],
#        [59603.258],
#        [59597.543],
#        [59601.977],
#        [59598.53 ],
#        [59601.215],
#        [59599.13 ],
#        [59600.74 ],
#        [59599.492],
#        [59600.46 ],
#        [59599.707],
#        [59600.29 ],
#        [59599.844],
#        [59600.195],
#        [59599.926],
#        [59600.12 ],
#        [59599.97 ],
#        [59600.09 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
