# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: CMG - Test/Train/Vaildation: 60/20/20
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1484.03
# - MAE: 1132.39
# - MAPE: 3.38 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830
# ...           ...
# 2024-05-27  59000
# 2024-05-28  62100
# 2024-05-29  60000
# 2024-05-30  59200
# 2024-05-31  60900
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((776, 10), (776,), (251, 10), (251,), (253, 10), (253,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - loss: 0.0164 - mean_absolute_error: 0.0922 - val_loss: 0.0037 - val_mean_absolute_error: 0.0544
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.0642e-04 - mean_absolute_error: 0.0226 - val_loss: 0.0024 - val_mean_absolute_error: 0.0387
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.8022e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0012 - val_mean_absolute_error: 0.0252
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.1013e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0012 - val_mean_absolute_error: 0.0248
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.9934e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0012 - val_mean_absolute_error: 0.0252
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.9483e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0011 - val_mean_absolute_error: 0.0242
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.0033e-04 - mean_absolute_error: 0.0139 - val_loss: 9.9654e-04 - val_mean_absolute_error: 0.0225
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.9125e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0010 - val_mean_absolute_error: 0.0226
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.2140e-04 - mean_absolute_error: 0.0143 - val_loss: 9.5222e-04 - val_mean_absolute_error: 0.0219
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.2877e-04 - mean_absolute_error: 0.0145 - val_loss: 9.7831e-04 - val_mean_absolute_error: 0.0224
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.1032e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0012 - val_mean_absolute_error: 0.0261
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.1390e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0010 - val_mean_absolute_error: 0.0229
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.8574e-04 - mean_absolute_error: 0.0137 - val_loss: 9.0055e-04 - val_mean_absolute_error: 0.0215
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.1916e-04 - mean_absolute_error: 0.0131 - val_loss: 9.8679e-04 - val_mean_absolute_error: 0.0244
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.9271e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0010 - val_mean_absolute_error: 0.0233
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.3888e-04 - mean_absolute_error: 0.0130 - val_loss: 8.6044e-04 - val_mean_absolute_error: 0.0212
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.3806e-04 - mean_absolute_error: 0.0130 - val_loss: 7.7611e-04 - val_mean_absolute_error: 0.0198
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.2049e-04 - mean_absolute_error: 0.0124 - val_loss: 8.8052e-04 - val_mean_absolute_error: 0.0218
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.1085e-04 - mean_absolute_error: 0.0127 - val_loss: 7.2343e-04 - val_mean_absolute_error: 0.0191
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.0712e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0012 - val_mean_absolute_error: 0.0275
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.4564e-04 - mean_absolute_error: 0.0132 - val_loss: 8.2117e-04 - val_mean_absolute_error: 0.0210
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.5505e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0011 - val_mean_absolute_error: 0.0263
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.5787e-04 - mean_absolute_error: 0.0117 - val_loss: 6.2294e-04 - val_mean_absolute_error: 0.0177
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9501e-04 - mean_absolute_error: 0.0122 - val_loss: 8.4084e-04 - val_mean_absolute_error: 0.0221
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.5796e-04 - mean_absolute_error: 0.0112 - val_loss: 7.3804e-04 - val_mean_absolute_error: 0.0204
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 2.8530e-04 - mean_absolute_error: 0.0119 - val_loss: 5.6063e-04 - val_mean_absolute_error: 0.0170
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.8964e-04 - mean_absolute_error: 0.0122 - val_loss: 6.6244e-04 - val_mean_absolute_error: 0.0194
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.4589e-04 - mean_absolute_error: 0.0114 - val_loss: 5.6679e-04 - val_mean_absolute_error: 0.0174
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.5521e-04 - mean_absolute_error: 0.0110 - val_loss: 5.6685e-04 - val_mean_absolute_error: 0.0179
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.7660e-04 - mean_absolute_error: 0.0120 - val_loss: 4.9737e-04 - val_mean_absolute_error: 0.0160
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.3893e-04 - mean_absolute_error: 0.0109 - val_loss: 5.5017e-04 - val_mean_absolute_error: 0.0175
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 2.4981e-04 - mean_absolute_error: 0.0112 - val_loss: 6.0572e-04 - val_mean_absolute_error: 0.0188
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.1525e-04 - mean_absolute_error: 0.0104 - val_loss: 5.6622e-04 - val_mean_absolute_error: 0.0181
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 2.4706e-04 - mean_absolute_error: 0.0113 - val_loss: 4.5681e-04 - val_mean_absolute_error: 0.0154
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.2278e-04 - mean_absolute_error: 0.0104 - val_loss: 5.2245e-04 - val_mean_absolute_error: 0.0172
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.1996e-04 - mean_absolute_error: 0.0105 - val_loss: 4.7096e-04 - val_mean_absolute_error: 0.0162
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.3659e-04 - mean_absolute_error: 0.0110 - val_loss: 5.7503e-04 - val_mean_absolute_error: 0.0184
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 2.0291e-04 - mean_absolute_error: 0.0103 - val_loss: 4.4046e-04 - val_mean_absolute_error: 0.0153
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.3305e-04 - mean_absolute_error: 0.0106 - val_loss: 8.2368e-04 - val_mean_absolute_error: 0.0233
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 2.2567e-04 - mean_absolute_error: 0.0110 - val_loss: 5.1084e-04 - val_mean_absolute_error: 0.0170
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.3940e-04 - mean_absolute_error: 0.0112 - val_loss: 6.9743e-04 - val_mean_absolute_error: 0.0218
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.3783e-04 - mean_absolute_error: 0.0109 - val_loss: 5.5554e-04 - val_mean_absolute_error: 0.0181
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.8874e-04 - mean_absolute_error: 0.0096 - val_loss: 4.5376e-04 - val_mean_absolute_error: 0.0156
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.9365e-04 - mean_absolute_error: 0.0097 - val_loss: 4.6968e-04 - val_mean_absolute_error: 0.0162
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.2910e-04 - mean_absolute_error: 0.0106 - val_loss: 4.2491e-04 - val_mean_absolute_error: 0.0154
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.1151e-04 - mean_absolute_error: 0.0103 - val_loss: 4.1530e-04 - val_mean_absolute_error: 0.0150
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.2222e-04 - mean_absolute_error: 0.0107 - val_loss: 5.7010e-04 - val_mean_absolute_error: 0.0186
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1424e-04 - mean_absolute_error: 0.0104 - val_loss: 5.6504e-04 - val_mean_absolute_error: 0.0184
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.9481e-04 - mean_absolute_error: 0.0097 - val_loss: 5.2813e-04 - val_mean_absolute_error: 0.0184
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.3884e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0016 - val_mean_absolute_error: 0.0347
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.7397e-04 - mean_absolute_error: 0.0121 - val_loss: 4.3268e-04 - val_mean_absolute_error: 0.0159
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.9939e-04 - mean_absolute_error: 0.0102 - val_loss: 5.1431e-04 - val_mean_absolute_error: 0.0182
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 2.0663e-04 - mean_absolute_error: 0.0102 - val_loss: 5.5846e-04 - val_mean_absolute_error: 0.0183
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.1857e-04 - mean_absolute_error: 0.0105 - val_loss: 4.8161e-04 - val_mean_absolute_error: 0.0174
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.8777e-04 - mean_absolute_error: 0.0098 - val_loss: 4.2700e-04 - val_mean_absolute_error: 0.0159
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.9221e-04 - mean_absolute_error: 0.0096 - val_loss: 3.9070e-04 - val_mean_absolute_error: 0.0148
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8144e-04 - mean_absolute_error: 0.0092 - val_loss: 3.7373e-04 - val_mean_absolute_error: 0.0141
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8077e-04 - mean_absolute_error: 0.0092 - val_loss: 3.9415e-04 - val_mean_absolute_error: 0.0150
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 2.0789e-04 - mean_absolute_error: 0.0104 - val_loss: 6.0344e-04 - val_mean_absolute_error: 0.0194
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6734e-04 - mean_absolute_error: 0.0092 - val_loss: 4.4844e-04 - val_mean_absolute_error: 0.0160
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.8564e-04 - mean_absolute_error: 0.0100 - val_loss: 4.1670e-04 - val_mean_absolute_error: 0.0159
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.8740e-04 - mean_absolute_error: 0.0097 - val_loss: 3.6133e-04 - val_mean_absolute_error: 0.0139
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.7978e-04 - mean_absolute_error: 0.0091 - val_loss: 3.8143e-04 - val_mean_absolute_error: 0.0148
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8601e-04 - mean_absolute_error: 0.0097 - val_loss: 7.2917e-04 - val_mean_absolute_error: 0.0221
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.8372e-04 - mean_absolute_error: 0.0098 - val_loss: 3.7110e-04 - val_mean_absolute_error: 0.0141
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.8050e-04 - mean_absolute_error: 0.0093 - val_loss: 4.8559e-04 - val_mean_absolute_error: 0.0179
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.1887e-04 - mean_absolute_error: 0.0103 - val_loss: 3.7589e-04 - val_mean_absolute_error: 0.0142
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.7148e-04 - mean_absolute_error: 0.0094 - val_loss: 3.8775e-04 - val_mean_absolute_error: 0.0145
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4245e-04 - mean_absolute_error: 0.0084 - val_loss: 3.4459e-04 - val_mean_absolute_error: 0.0135
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.6988e-04 - mean_absolute_error: 0.0092 - val_loss: 3.4276e-04 - val_mean_absolute_error: 0.0136
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.6142e-04 - mean_absolute_error: 0.0088 - val_loss: 4.7848e-04 - val_mean_absolute_error: 0.0169
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.8874e-04 - mean_absolute_error: 0.0096 - val_loss: 3.3541e-04 - val_mean_absolute_error: 0.0134
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7093e-04 - mean_absolute_error: 0.0091 - val_loss: 4.2221e-04 - val_mean_absolute_error: 0.0164
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.6300e-04 - mean_absolute_error: 0.0089 - val_loss: 3.9439e-04 - val_mean_absolute_error: 0.0156
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.5268e-04 - mean_absolute_error: 0.0117 - val_loss: 4.3389e-04 - val_mean_absolute_error: 0.0159
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7278e-04 - mean_absolute_error: 0.0091 - val_loss: 3.2889e-04 - val_mean_absolute_error: 0.0132
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.5656e-04 - mean_absolute_error: 0.0086 - val_loss: 3.4148e-04 - val_mean_absolute_error: 0.0134
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.6759e-04 - mean_absolute_error: 0.0093 - val_loss: 3.8027e-04 - val_mean_absolute_error: 0.0152
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.4960e-04 - mean_absolute_error: 0.0084 - val_loss: 3.2866e-04 - val_mean_absolute_error: 0.0135
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7169e-04 - mean_absolute_error: 0.0091 - val_loss: 3.3023e-04 - val_mean_absolute_error: 0.0136
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6034e-04 - mean_absolute_error: 0.0087 - val_loss: 3.1668e-04 - val_mean_absolute_error: 0.0129
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.4936e-04 - mean_absolute_error: 0.0087 - val_loss: 3.7715e-04 - val_mean_absolute_error: 0.0145
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3867e-04 - mean_absolute_error: 0.0079 - val_loss: 3.1364e-04 - val_mean_absolute_error: 0.0130
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3976e-04 - mean_absolute_error: 0.0081 - val_loss: 3.5361e-04 - val_mean_absolute_error: 0.0139
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4254e-04 - mean_absolute_error: 0.0084 - val_loss: 3.1190e-04 - val_mean_absolute_error: 0.0128
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.4713e-04 - mean_absolute_error: 0.0082 - val_loss: 3.0245e-04 - val_mean_absolute_error: 0.0126
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6387e-04 - mean_absolute_error: 0.0089 - val_loss: 4.0501e-04 - val_mean_absolute_error: 0.0155
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.5207e-04 - mean_absolute_error: 0.0088 - val_loss: 3.0338e-04 - val_mean_absolute_error: 0.0126
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.5556e-04 - mean_absolute_error: 0.0089 - val_loss: 3.0061e-04 - val_mean_absolute_error: 0.0125
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.4101e-04 - mean_absolute_error: 0.0080 - val_loss: 3.0570e-04 - val_mean_absolute_error: 0.0127
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3647e-04 - mean_absolute_error: 0.0082 - val_loss: 3.4404e-04 - val_mean_absolute_error: 0.0144
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.6386e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8902e-04 - val_mean_absolute_error: 0.0122
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3957e-04 - mean_absolute_error: 0.0082 - val_loss: 3.5174e-04 - val_mean_absolute_error: 0.0147
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.5831e-04 - mean_absolute_error: 0.0090 - val_loss: 3.3292e-04 - val_mean_absolute_error: 0.0135
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3039e-04 - mean_absolute_error: 0.0081 - val_loss: 2.9544e-04 - val_mean_absolute_error: 0.0124
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5338e-04 - mean_absolute_error: 0.0088 - val_loss: 3.8457e-04 - val_mean_absolute_error: 0.0151
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3925e-04 - mean_absolute_error: 0.0081 - val_loss: 2.8944e-04 - val_mean_absolute_error: 0.0123
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.1333e-04 - mean_absolute_error: 0.0075 - val_loss: 4.0784e-04 - val_mean_absolute_error: 0.0158
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.4064e-04 - mean_absolute_error: 0.0083 - val_loss: 6.1046e-04 - val_mean_absolute_error: 0.0206
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.8728e-04 - mean_absolute_error: 0.0098 - val_loss: 3.5546e-04 - val_mean_absolute_error: 0.0143
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2333e-04 - mean_absolute_error: 0.0077 - val_loss: 3.7104e-04 - val_mean_absolute_error: 0.0154
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.3719e-04 - mean_absolute_error: 0.0082 - val_loss: 2.8853e-04 - val_mean_absolute_error: 0.0122
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.1604e-04 - mean_absolute_error: 0.0074 - val_loss: 2.8064e-04 - val_mean_absolute_error: 0.0121
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.4759e-04 - mean_absolute_error: 0.0084 - val_loss: 3.8973e-04 - val_mean_absolute_error: 0.0154
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.2153e-04 - mean_absolute_error: 0.0076 - val_loss: 2.8299e-04 - val_mean_absolute_error: 0.0122
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2884e-04 - mean_absolute_error: 0.0076 - val_loss: 3.3262e-04 - val_mean_absolute_error: 0.0138
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.2860e-04 - mean_absolute_error: 0.0081 - val_loss: 3.1855e-04 - val_mean_absolute_error: 0.0138
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.5197e-04 - mean_absolute_error: 0.0087 - val_loss: 2.7658e-04 - val_mean_absolute_error: 0.0121
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.1533e-04 - mean_absolute_error: 0.0072 - val_loss: 5.1111e-04 - val_mean_absolute_error: 0.0186
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.1572e-04 - mean_absolute_error: 0.0114 - val_loss: 3.1413e-04 - val_mean_absolute_error: 0.0137
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4941e-04 - mean_absolute_error: 0.0090 - val_loss: 3.0945e-04 - val_mean_absolute_error: 0.0131
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.2343e-04 - mean_absolute_error: 0.0078 - val_loss: 2.7635e-04 - val_mean_absolute_error: 0.0122
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.1741e-04 - mean_absolute_error: 0.0074 - val_loss: 2.9372e-04 - val_mean_absolute_error: 0.0126
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.1878e-04 - mean_absolute_error: 0.0075 - val_loss: 2.8357e-04 - val_mean_absolute_error: 0.0126
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.1989e-04 - mean_absolute_error: 0.0076 - val_loss: 4.1242e-04 - val_mean_absolute_error: 0.0162
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3230e-04 - mean_absolute_error: 0.0085 - val_loss: 3.4202e-04 - val_mean_absolute_error: 0.0146
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 1.4294e-04 - mean_absolute_error: 0.0086 - val_loss: 3.6106e-04 - val_mean_absolute_error: 0.0148
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 1.1632e-04 - mean_absolute_error: 0.0074 - val_loss: 4.0890e-04 - val_mean_absolute_error: 0.0165
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 1.1262e-04 - mean_absolute_error: 0.0075 - val_loss: 2.7213e-04 - val_mean_absolute_error: 0.0121
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 1.2561e-04 - mean_absolute_error: 0.0075 - val_loss: 3.0559e-04 - val_mean_absolute_error: 0.0132
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.2598e-04 - mean_absolute_error: 0.0079 - val_loss: 2.7122e-04 - val_mean_absolute_error: 0.0122
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.2315e-04 - mean_absolute_error: 0.0080 - val_loss: 2.9605e-04 - val_mean_absolute_error: 0.0129
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.3041e-04 - mean_absolute_error: 0.0078 - val_loss: 2.7912e-04 - val_mean_absolute_error: 0.0125
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.4636e-04 - mean_absolute_error: 0.0084 - val_loss: 2.8632e-04 - val_mean_absolute_error: 0.0127
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 1.0253e-04 - mean_absolute_error: 0.0068 - val_loss: 2.7233e-04 - val_mean_absolute_error: 0.0122
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.1895e-04 - mean_absolute_error: 0.0076 - val_loss: 2.7103e-04 - val_mean_absolute_error: 0.0121
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.2003e-04 - mean_absolute_error: 0.0078 - val_loss: 2.7193e-04 - val_mean_absolute_error: 0.0122
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.2105e-04 - mean_absolute_error: 0.0074 - val_loss: 4.1954e-04 - val_mean_absolute_error: 0.0168
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6658e-04 - mean_absolute_error: 0.0095 - val_loss: 9.9521e-04 - val_mean_absolute_error: 0.0275
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.7042e-04 - mean_absolute_error: 0.0094 - val_loss: 3.1895e-04 - val_mean_absolute_error: 0.0136
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.1167e-04 - mean_absolute_error: 0.0075 - val_loss: 2.7468e-04 - val_mean_absolute_error: 0.0122
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.2104e-04 - mean_absolute_error: 0.0075 - val_loss: 2.7572e-04 - val_mean_absolute_error: 0.0123
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.1424e-04 - mean_absolute_error: 0.0075 - val_loss: 2.7655e-04 - val_mean_absolute_error: 0.0124
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.0235e-04 - mean_absolute_error: 0.0071 - val_loss: 4.0488e-04 - val_mean_absolute_error: 0.0163
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.1300e-04 - mean_absolute_error: 0.0076 - val_loss: 4.1007e-04 - val_mean_absolute_error: 0.0162
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.0835e-04 - mean_absolute_error: 0.0073 - val_loss: 2.7630e-04 - val_mean_absolute_error: 0.0123
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.2588e-04 - mean_absolute_error: 0.0082 - val_loss: 2.9298e-04 - val_mean_absolute_error: 0.0130
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0322e-04 - mean_absolute_error: 0.0072 - val_loss: 2.7935e-04 - val_mean_absolute_error: 0.0125
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.2728e-04 - mean_absolute_error: 0.0076 - val_loss: 2.8189e-04 - val_mean_absolute_error: 0.0126
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.1157e-04 - mean_absolute_error: 0.0074 - val_loss: 5.0520e-04 - val_mean_absolute_error: 0.0183
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3648e-04 - mean_absolute_error: 0.0081 - val_loss: 3.2032e-04 - val_mean_absolute_error: 0.0139
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.1079e-04 - mean_absolute_error: 0.0074 - val_loss: 2.7941e-04 - val_mean_absolute_error: 0.0125
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0855e-04 - mean_absolute_error: 0.0069 - val_loss: 2.8445e-04 - val_mean_absolute_error: 0.0126
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.2647e-05 - mean_absolute_error: 0.0066 - val_loss: 3.3460e-04 - val_mean_absolute_error: 0.0142
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.1371e-04 - mean_absolute_error: 0.0072 - val_loss: 2.8248e-04 - val_mean_absolute_error: 0.0126
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.7687e-05 - mean_absolute_error: 0.0069 - val_loss: 3.7301e-04 - val_mean_absolute_error: 0.0153
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.1085e-04 - mean_absolute_error: 0.0073 - val_loss: 2.9163e-04 - val_mean_absolute_error: 0.0130
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.0545e-04 - mean_absolute_error: 0.0069 - val_loss: 2.8198e-04 - val_mean_absolute_error: 0.0125
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0744e-04 - mean_absolute_error: 0.0070 - val_loss: 3.5562e-04 - val_mean_absolute_error: 0.0148
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.1121e-04 - mean_absolute_error: 0.0072 - val_loss: 3.7717e-04 - val_mean_absolute_error: 0.0153
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.8928e-05 - mean_absolute_error: 0.0067 - val_loss: 3.8482e-04 - val_mean_absolute_error: 0.0156
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.0459e-04 - mean_absolute_error: 0.0070 - val_loss: 3.2390e-04 - val_mean_absolute_error: 0.0139
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.1354e-04 - mean_absolute_error: 0.0074 - val_loss: 3.0989e-04 - val_mean_absolute_error: 0.0134
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.0476e-04 - mean_absolute_error: 0.0067 - val_loss: 2.9510e-04 - val_mean_absolute_error: 0.0131
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.0862e-04 - mean_absolute_error: 0.0069 - val_loss: 2.8556e-04 - val_mean_absolute_error: 0.0126
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 1.0498e-04 - mean_absolute_error: 0.0068 - val_loss: 3.3001e-04 - val_mean_absolute_error: 0.0140
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.0512e-04 - mean_absolute_error: 0.0072 - val_loss: 3.2582e-04 - val_mean_absolute_error: 0.0139
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 1.6709e-04 - mean_absolute_error: 0.0096 - val_loss: 3.1725e-04 - val_mean_absolute_error: 0.0137
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.0593e-04 - mean_absolute_error: 0.0070 - val_loss: 2.8781e-04 - val_mean_absolute_error: 0.0127
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.2171e-04 - mean_absolute_error: 0.0077 - val_loss: 3.6873e-04 - val_mean_absolute_error: 0.0152
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.2059e-04 - mean_absolute_error: 0.0078 - val_loss: 2.9201e-04 - val_mean_absolute_error: 0.0130
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.3760e-05 - mean_absolute_error: 0.0063 - val_loss: 3.0904e-04 - val_mean_absolute_error: 0.0135
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0992e-04 - mean_absolute_error: 0.0070 - val_loss: 2.8962e-04 - val_mean_absolute_error: 0.0128
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.1323e-04 - mean_absolute_error: 0.0070 - val_loss: 3.0145e-04 - val_mean_absolute_error: 0.0131
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.0031e-04 - mean_absolute_error: 0.0066 - val_loss: 3.3554e-04 - val_mean_absolute_error: 0.0142
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.0573e-04 - mean_absolute_error: 0.0072 - val_loss: 3.6399e-04 - val_mean_absolute_error: 0.0150
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 8.6842e-05 - mean_absolute_error: 0.0067 - val_loss: 3.9534e-04 - val_mean_absolute_error: 0.0158
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3446e-04 - mean_absolute_error: 0.0087 - val_loss: 3.2087e-04 - val_mean_absolute_error: 0.0138
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0829e-04 - mean_absolute_error: 0.0071 - val_loss: 2.9611e-04 - val_mean_absolute_error: 0.0131
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0874e-04 - mean_absolute_error: 0.0071 - val_loss: 4.8623e-04 - val_mean_absolute_error: 0.0180
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3507e-04 - mean_absolute_error: 0.0082 - val_loss: 2.9348e-04 - val_mean_absolute_error: 0.0129
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0805e-04 - mean_absolute_error: 0.0071 - val_loss: 2.9255e-04 - val_mean_absolute_error: 0.0128
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.0998e-04 - mean_absolute_error: 0.0074 - val_loss: 2.9149e-04 - val_mean_absolute_error: 0.0129
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.0484e-05 - mean_absolute_error: 0.0067 - val_loss: 3.1120e-04 - val_mean_absolute_error: 0.0135
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 9.7896e-05 - mean_absolute_error: 0.0066 - val_loss: 2.9960e-04 - val_mean_absolute_error: 0.0132
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0619e-04 - mean_absolute_error: 0.0068 - val_loss: 3.1643e-04 - val_mean_absolute_error: 0.0135
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.0128e-04 - mean_absolute_error: 0.0069 - val_loss: 3.4990e-04 - val_mean_absolute_error: 0.0147
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.0454e-04 - mean_absolute_error: 0.0067 - val_loss: 3.0015e-04 - val_mean_absolute_error: 0.0130
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.5930e-05 - mean_absolute_error: 0.0066 - val_loss: 4.1083e-04 - val_mean_absolute_error: 0.0162
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2766e-04 - mean_absolute_error: 0.0081 - val_loss: 2.9457e-04 - val_mean_absolute_error: 0.0129
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.7072e-05 - mean_absolute_error: 0.0066 - val_loss: 2.9614e-04 - val_mean_absolute_error: 0.0130
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.7502e-05 - mean_absolute_error: 0.0066 - val_loss: 3.0015e-04 - val_mean_absolute_error: 0.0130
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.9072e-05 - mean_absolute_error: 0.0067 - val_loss: 4.1936e-04 - val_mean_absolute_error: 0.0164
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2532e-04 - mean_absolute_error: 0.0079 - val_loss: 2.9924e-04 - val_mean_absolute_error: 0.0132
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.9144e-05 - mean_absolute_error: 0.0069 - val_loss: 3.9064e-04 - val_mean_absolute_error: 0.0157
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2154e-04 - mean_absolute_error: 0.0081 - val_loss: 3.0372e-04 - val_mean_absolute_error: 0.0132
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3232e-04 - mean_absolute_error: 0.0082 - val_loss: 2.9905e-04 - val_mean_absolute_error: 0.0132
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0955e-04 - mean_absolute_error: 0.0072 - val_loss: 3.2295e-04 - val_mean_absolute_error: 0.0139
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.0235e-04 - mean_absolute_error: 0.0070 - val_loss: 3.8216e-04 - val_mean_absolute_error: 0.0155
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2609e-04 - mean_absolute_error: 0.0084 - val_loss: 2.9434e-04 - val_mean_absolute_error: 0.0129
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0582e-04 - mean_absolute_error: 0.0070 - val_loss: 3.2115e-04 - val_mean_absolute_error: 0.0138
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.0681e-04 - mean_absolute_error: 0.0071 - val_loss: 3.1061e-04 - val_mean_absolute_error: 0.0136
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.1967e-04 - mean_absolute_error: 0.0077 - val_loss: 2.9558e-04 - val_mean_absolute_error: 0.0129
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.0508e-04 - mean_absolute_error: 0.0070 - val_loss: 2.9644e-04 - val_mean_absolute_error: 0.0131
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.0936e-04 - mean_absolute_error: 0.0073 - val_loss: 3.1557e-04 - val_mean_absolute_error: 0.0135
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.6287e-05 - mean_absolute_error: 0.0068 - val_loss: 2.9112e-04 - val_mean_absolute_error: 0.0129
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0907e-04 - mean_absolute_error: 0.0071 - val_loss: 3.6654e-04 - val_mean_absolute_error: 0.0150
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.4130e-05 - mean_absolute_error: 0.0069 - val_loss: 3.1145e-04 - val_mean_absolute_error: 0.0133
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.6435e-05 - mean_absolute_error: 0.0067 - val_loss: 3.3972e-04 - val_mean_absolute_error: 0.0144
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.0278e-05 - mean_absolute_error: 0.0069 - val_loss: 2.9361e-04 - val_mean_absolute_error: 0.0129

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 319ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4306e-04 - mean_absolute_error: 0.0144
# Test Loss: [0.0002936087839771062, 0.012935290113091469]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 1480797.454307632
# RMSE: 1216.8802136231948
# MAE: 894.3401939118526
# MAPE: 2.739317039821704 %
#
# Model evalution on validate set
# MSE: 2658439.961722559
# RMSE: 1630.472312467329
# MAE: 957.5011502593874
# MAPE: 2.167747701328273 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step

# %%
y_pred_30_days
# Out:
# array([[60539.668],
#        [60137.664],
#        [60849.05 ],
#        [59871.227],
#        [61051.406],
#        [59685.12 ],
#        [61345.574],
#        [59337.992],
#        [61748.28 ],
#        [58838.406],
#        [62327.242],
#        [58107.02 ],
#        [63151.043],
#        [57043.027],
#        [64310.242],
#        [55503.73 ],
#        [65902.5  ],
#        [53310.777],
#        [67991.72 ],
#        [50297.582],
#        [70499.12 ],
#        [46470.344],
#        [73026.07 ],
#        [42323.9  ],
#        [74866.05 ],
#        [38965.324],
#        [75674.23 ],
#        [37215.258],
#        [75876.41 ],
#        [36675.055],
#        [75913.08 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 546ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 640ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
