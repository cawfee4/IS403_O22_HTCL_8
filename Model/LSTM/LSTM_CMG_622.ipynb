# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: CMG - Test/Train/Vaildation: 60/20/20
# - Dataset: 1313 rows x 7 columns (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1262.2479486195132
# - MAE: 936.0949638944223
# - MAPE: 2.8553305132545526 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830
# ...           ...
# 2024-05-27  59000
# 2024-05-28  62100
# 2024-05-29  60000
# 2024-05-30  59200
# 2024-05-31  60900
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((776, 10), (776,), (251, 10), (251,), (253, 10), (253,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 39s 177ms/step - loss: 0.0106 - mean_absolute_error: 0.0756 - val_loss: 0.0013 - val_mean_absolute_error: 0.0282
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 6.7659e-04 - mean_absolute_error: 0.0211 - val_loss: 0.0014 - val_mean_absolute_error: 0.0268
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.7766e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0013 - val_mean_absolute_error: 0.0265
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.0766e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0011 - val_mean_absolute_error: 0.0238
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.0248e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0017 - val_mean_absolute_error: 0.0321
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.5584e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0019 - val_mean_absolute_error: 0.0338
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.3800e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0013 - val_mean_absolute_error: 0.0272
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.9723e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0015 - val_mean_absolute_error: 0.0300
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.4719e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0015 - val_mean_absolute_error: 0.0298
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.7367e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0012 - val_mean_absolute_error: 0.0259
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.7799e-04 - mean_absolute_error: 0.0144 - val_loss: 9.9999e-04 - val_mean_absolute_error: 0.0226
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.0969e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.2099e-04 - mean_absolute_error: 0.0164 - val_loss: 0.0013 - val_mean_absolute_error: 0.0270
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.6699e-04 - mean_absolute_error: 0.0162 - val_loss: 9.4618e-04 - val_mean_absolute_error: 0.0220
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.4037e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0012 - val_mean_absolute_error: 0.0259
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8579e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0010 - val_mean_absolute_error: 0.0234
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.7495e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0016 - val_mean_absolute_error: 0.0321
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.8392e-04 - mean_absolute_error: 0.0142 - val_loss: 8.3524e-04 - val_mean_absolute_error: 0.0206
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.4893e-04 - mean_absolute_error: 0.0134 - val_loss: 8.1688e-04 - val_mean_absolute_error: 0.0204
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.2316e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0012 - val_mean_absolute_error: 0.0266
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.7261e-04 - mean_absolute_error: 0.0142 - val_loss: 7.9121e-04 - val_mean_absolute_error: 0.0200
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.6657e-04 - mean_absolute_error: 0.0136 - val_loss: 8.3209e-04 - val_mean_absolute_error: 0.0208
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.1653e-04 - mean_absolute_error: 0.0131 - val_loss: 7.4979e-04 - val_mean_absolute_error: 0.0194
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 3.0025e-04 - mean_absolute_error: 0.0125 - val_loss: 7.5874e-04 - val_mean_absolute_error: 0.0199
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.4053e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0013 - val_mean_absolute_error: 0.0287
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.9317e-04 - mean_absolute_error: 0.0122 - val_loss: 6.8725e-04 - val_mean_absolute_error: 0.0186
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.7907e-04 - mean_absolute_error: 0.0115 - val_loss: 6.9792e-04 - val_mean_absolute_error: 0.0194
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.1299e-04 - mean_absolute_error: 0.0122 - val_loss: 7.1809e-04 - val_mean_absolute_error: 0.0198
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.7713e-04 - mean_absolute_error: 0.0118 - val_loss: 6.7009e-04 - val_mean_absolute_error: 0.0189
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.1178e-04 - mean_absolute_error: 0.0132 - val_loss: 7.1998e-04 - val_mean_absolute_error: 0.0200
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.9595e-04 - mean_absolute_error: 0.0122 - val_loss: 8.5304e-04 - val_mean_absolute_error: 0.0236
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.5094e-04 - mean_absolute_error: 0.0131 - val_loss: 5.7324e-04 - val_mean_absolute_error: 0.0175
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.4508e-04 - mean_absolute_error: 0.0113 - val_loss: 5.5928e-04 - val_mean_absolute_error: 0.0172
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.5993e-04 - mean_absolute_error: 0.0116 - val_loss: 6.3509e-04 - val_mean_absolute_error: 0.0190
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.9346e-04 - mean_absolute_error: 0.0122 - val_loss: 5.6779e-04 - val_mean_absolute_error: 0.0180
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.5524e-04 - mean_absolute_error: 0.0112 - val_loss: 7.1903e-04 - val_mean_absolute_error: 0.0210
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.2327e-04 - mean_absolute_error: 0.0105 - val_loss: 4.9157e-04 - val_mean_absolute_error: 0.0161
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.4701e-04 - mean_absolute_error: 0.0111 - val_loss: 4.6289e-04 - val_mean_absolute_error: 0.0154
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.6273e-04 - mean_absolute_error: 0.0120 - val_loss: 4.7405e-04 - val_mean_absolute_error: 0.0159
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.2134e-04 - mean_absolute_error: 0.0106 - val_loss: 5.0485e-04 - val_mean_absolute_error: 0.0170
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 2.3146e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0010 - val_mean_absolute_error: 0.0264
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.3556e-04 - mean_absolute_error: 0.0109 - val_loss: 4.8614e-04 - val_mean_absolute_error: 0.0167
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.4114e-04 - mean_absolute_error: 0.0111 - val_loss: 6.8183e-04 - val_mean_absolute_error: 0.0207
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.3249e-04 - mean_absolute_error: 0.0113 - val_loss: 4.4340e-04 - val_mean_absolute_error: 0.0153
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.1251e-04 - mean_absolute_error: 0.0103 - val_loss: 4.2348e-04 - val_mean_absolute_error: 0.0150
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.0676e-04 - mean_absolute_error: 0.0098 - val_loss: 4.2126e-04 - val_mean_absolute_error: 0.0149
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.1087e-04 - mean_absolute_error: 0.0106 - val_loss: 4.0949e-04 - val_mean_absolute_error: 0.0146
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.4174e-04 - mean_absolute_error: 0.0109 - val_loss: 4.0921e-04 - val_mean_absolute_error: 0.0147
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.9719e-04 - mean_absolute_error: 0.0096 - val_loss: 3.9259e-04 - val_mean_absolute_error: 0.0144
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.2026e-04 - mean_absolute_error: 0.0107 - val_loss: 4.2572e-04 - val_mean_absolute_error: 0.0155
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.9819e-04 - mean_absolute_error: 0.0130 - val_loss: 4.6345e-04 - val_mean_absolute_error: 0.0167
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1599e-04 - mean_absolute_error: 0.0106 - val_loss: 3.9073e-04 - val_mean_absolute_error: 0.0143
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.4162e-04 - mean_absolute_error: 0.0108 - val_loss: 4.9841e-04 - val_mean_absolute_error: 0.0169
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7017e-04 - mean_absolute_error: 0.0091 - val_loss: 3.7788e-04 - val_mean_absolute_error: 0.0142
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5735e-04 - mean_absolute_error: 0.0087 - val_loss: 4.3233e-04 - val_mean_absolute_error: 0.0161
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.2363e-04 - mean_absolute_error: 0.0103 - val_loss: 3.7210e-04 - val_mean_absolute_error: 0.0140
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.7344e-04 - mean_absolute_error: 0.0089 - val_loss: 5.5507e-04 - val_mean_absolute_error: 0.0184
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.7434e-04 - mean_absolute_error: 0.0093 - val_loss: 4.4291e-04 - val_mean_absolute_error: 0.0166
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6822e-04 - mean_absolute_error: 0.0091 - val_loss: 3.5536e-04 - val_mean_absolute_error: 0.0137
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6386e-04 - mean_absolute_error: 0.0088 - val_loss: 4.1889e-04 - val_mean_absolute_error: 0.0161
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6277e-04 - mean_absolute_error: 0.0088 - val_loss: 3.8416e-04 - val_mean_absolute_error: 0.0144
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.7660e-04 - mean_absolute_error: 0.0093 - val_loss: 3.7974e-04 - val_mean_absolute_error: 0.0143
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6426e-04 - mean_absolute_error: 0.0087 - val_loss: 3.4476e-04 - val_mean_absolute_error: 0.0135
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.6716e-04 - mean_absolute_error: 0.0088 - val_loss: 3.5309e-04 - val_mean_absolute_error: 0.0137
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.6747e-04 - mean_absolute_error: 0.0090 - val_loss: 3.3355e-04 - val_mean_absolute_error: 0.0133
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6646e-04 - mean_absolute_error: 0.0091 - val_loss: 5.0365e-04 - val_mean_absolute_error: 0.0185
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.2279e-04 - mean_absolute_error: 0.0105 - val_loss: 4.8433e-04 - val_mean_absolute_error: 0.0172
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.9573e-04 - mean_absolute_error: 0.0107 - val_loss: 3.2350e-04 - val_mean_absolute_error: 0.0131
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.7146e-04 - mean_absolute_error: 0.0092 - val_loss: 3.7211e-04 - val_mean_absolute_error: 0.0150
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.6554e-04 - mean_absolute_error: 0.0092 - val_loss: 3.8362e-04 - val_mean_absolute_error: 0.0146
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7802e-04 - mean_absolute_error: 0.0100 - val_loss: 3.2405e-04 - val_mean_absolute_error: 0.0133
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.9052e-04 - mean_absolute_error: 0.0097 - val_loss: 4.0969e-04 - val_mean_absolute_error: 0.0162
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.9057e-04 - mean_absolute_error: 0.0097 - val_loss: 3.6160e-04 - val_mean_absolute_error: 0.0141
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7406e-04 - mean_absolute_error: 0.0095 - val_loss: 3.1160e-04 - val_mean_absolute_error: 0.0129
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.5562e-04 - mean_absolute_error: 0.0087 - val_loss: 3.0882e-04 - val_mean_absolute_error: 0.0127
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5367e-04 - mean_absolute_error: 0.0089 - val_loss: 3.6265e-04 - val_mean_absolute_error: 0.0142
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2818e-04 - mean_absolute_error: 0.0078 - val_loss: 3.3100e-04 - val_mean_absolute_error: 0.0133
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5950e-04 - mean_absolute_error: 0.0087 - val_loss: 3.0011e-04 - val_mean_absolute_error: 0.0126
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3776e-04 - mean_absolute_error: 0.0080 - val_loss: 3.5179e-04 - val_mean_absolute_error: 0.0140
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.4718e-04 - mean_absolute_error: 0.0083 - val_loss: 2.9557e-04 - val_mean_absolute_error: 0.0125
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.3089e-04 - mean_absolute_error: 0.0081 - val_loss: 3.4853e-04 - val_mean_absolute_error: 0.0139
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3945e-04 - mean_absolute_error: 0.0084 - val_loss: 3.4172e-04 - val_mean_absolute_error: 0.0144
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6433e-04 - mean_absolute_error: 0.0090 - val_loss: 3.8835e-04 - val_mean_absolute_error: 0.0151
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.3545e-04 - mean_absolute_error: 0.0083 - val_loss: 2.9763e-04 - val_mean_absolute_error: 0.0124
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.1129e-04 - mean_absolute_error: 0.0070 - val_loss: 3.9605e-04 - val_mean_absolute_error: 0.0154
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.3803e-04 - mean_absolute_error: 0.0083 - val_loss: 2.8868e-04 - val_mean_absolute_error: 0.0124
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.2291e-04 - mean_absolute_error: 0.0075 - val_loss: 3.7367e-04 - val_mean_absolute_error: 0.0155
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5242e-04 - mean_absolute_error: 0.0083 - val_loss: 2.9729e-04 - val_mean_absolute_error: 0.0130
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.5220e-04 - mean_absolute_error: 0.0085 - val_loss: 4.3734e-04 - val_mean_absolute_error: 0.0166
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.3510e-04 - mean_absolute_error: 0.0082 - val_loss: 3.0018e-04 - val_mean_absolute_error: 0.0131
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.4996e-04 - mean_absolute_error: 0.0085 - val_loss: 3.9830e-04 - val_mean_absolute_error: 0.0156
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.4103e-04 - mean_absolute_error: 0.0084 - val_loss: 2.8795e-04 - val_mean_absolute_error: 0.0126
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4470e-04 - mean_absolute_error: 0.0082 - val_loss: 3.2376e-04 - val_mean_absolute_error: 0.0134
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3853e-04 - mean_absolute_error: 0.0083 - val_loss: 2.8475e-04 - val_mean_absolute_error: 0.0124
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3015e-04 - mean_absolute_error: 0.0080 - val_loss: 2.9639e-04 - val_mean_absolute_error: 0.0125
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.3385e-04 - mean_absolute_error: 0.0081 - val_loss: 2.8076e-04 - val_mean_absolute_error: 0.0123
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1912e-04 - mean_absolute_error: 0.0074 - val_loss: 3.4506e-04 - val_mean_absolute_error: 0.0141
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2609e-04 - mean_absolute_error: 0.0079 - val_loss: 2.7839e-04 - val_mean_absolute_error: 0.0123
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.2500e-04 - mean_absolute_error: 0.0076 - val_loss: 3.0252e-04 - val_mean_absolute_error: 0.0129
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.1940e-04 - mean_absolute_error: 0.0078 - val_loss: 2.7954e-04 - val_mean_absolute_error: 0.0123
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.2958e-04 - mean_absolute_error: 0.0078 - val_loss: 2.8805e-04 - val_mean_absolute_error: 0.0124
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.2295e-04 - mean_absolute_error: 0.0077 - val_loss: 2.8456e-04 - val_mean_absolute_error: 0.0126
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2241e-04 - mean_absolute_error: 0.0075 - val_loss: 3.6900e-04 - val_mean_absolute_error: 0.0154
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9393e-04 - mean_absolute_error: 0.0104 - val_loss: 3.0773e-04 - val_mean_absolute_error: 0.0131
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.2957e-04 - mean_absolute_error: 0.0081 - val_loss: 2.8489e-04 - val_mean_absolute_error: 0.0124
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1612e-04 - mean_absolute_error: 0.0073 - val_loss: 2.8368e-04 - val_mean_absolute_error: 0.0125
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.2712e-04 - mean_absolute_error: 0.0077 - val_loss: 2.7788e-04 - val_mean_absolute_error: 0.0123
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.2620e-04 - mean_absolute_error: 0.0078 - val_loss: 2.8117e-04 - val_mean_absolute_error: 0.0124
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1938e-04 - mean_absolute_error: 0.0073 - val_loss: 2.7815e-04 - val_mean_absolute_error: 0.0124
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7111e-04 - mean_absolute_error: 0.0095 - val_loss: 2.8956e-04 - val_mean_absolute_error: 0.0127
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1530e-04 - mean_absolute_error: 0.0076 - val_loss: 3.2550e-04 - val_mean_absolute_error: 0.0138
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.0882e-04 - mean_absolute_error: 0.0076 - val_loss: 3.3615e-04 - val_mean_absolute_error: 0.0141
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.1991e-04 - mean_absolute_error: 0.0076 - val_loss: 3.1265e-04 - val_mean_absolute_error: 0.0134
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2314e-04 - mean_absolute_error: 0.0075 - val_loss: 2.7557e-04 - val_mean_absolute_error: 0.0123
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.1393e-04 - mean_absolute_error: 0.0074 - val_loss: 3.1902e-04 - val_mean_absolute_error: 0.0138
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2397e-04 - mean_absolute_error: 0.0076 - val_loss: 2.9649e-04 - val_mean_absolute_error: 0.0130
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4887e-04 - mean_absolute_error: 0.0088 - val_loss: 3.1855e-04 - val_mean_absolute_error: 0.0137
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1577e-04 - mean_absolute_error: 0.0074 - val_loss: 2.9662e-04 - val_mean_absolute_error: 0.0130
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.0993e-04 - mean_absolute_error: 0.0072 - val_loss: 2.8442e-04 - val_mean_absolute_error: 0.0126
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.0259e-04 - mean_absolute_error: 0.0068 - val_loss: 2.8708e-04 - val_mean_absolute_error: 0.0127
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1003e-04 - mean_absolute_error: 0.0071 - val_loss: 2.7862e-04 - val_mean_absolute_error: 0.0124
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.1387e-04 - mean_absolute_error: 0.0075 - val_loss: 3.2899e-04 - val_mean_absolute_error: 0.0141
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.0195e-04 - mean_absolute_error: 0.0071 - val_loss: 2.8463e-04 - val_mean_absolute_error: 0.0125
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.0824e-04 - mean_absolute_error: 0.0071 - val_loss: 2.8243e-04 - val_mean_absolute_error: 0.0125
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.4630e-05 - mean_absolute_error: 0.0066 - val_loss: 4.0213e-04 - val_mean_absolute_error: 0.0161
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1601e-04 - mean_absolute_error: 0.0073 - val_loss: 3.2115e-04 - val_mean_absolute_error: 0.0139
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.6981e-05 - mean_absolute_error: 0.0066 - val_loss: 2.9390e-04 - val_mean_absolute_error: 0.0130
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.1872e-04 - mean_absolute_error: 0.0074 - val_loss: 3.1976e-04 - val_mean_absolute_error: 0.0138
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.2120e-04 - mean_absolute_error: 0.0079 - val_loss: 3.3763e-04 - val_mean_absolute_error: 0.0143
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1540e-04 - mean_absolute_error: 0.0076 - val_loss: 3.4709e-04 - val_mean_absolute_error: 0.0146
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.0836e-04 - mean_absolute_error: 0.0074 - val_loss: 2.9113e-04 - val_mean_absolute_error: 0.0127
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.1958e-04 - mean_absolute_error: 0.0079 - val_loss: 2.9051e-04 - val_mean_absolute_error: 0.0128
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.7904e-05 - mean_absolute_error: 0.0068 - val_loss: 2.9265e-04 - val_mean_absolute_error: 0.0127
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.0565e-04 - mean_absolute_error: 0.0068 - val_loss: 3.1328e-04 - val_mean_absolute_error: 0.0135
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0459e-04 - mean_absolute_error: 0.0073 - val_loss: 2.9737e-04 - val_mean_absolute_error: 0.0129
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0189e-04 - mean_absolute_error: 0.0069 - val_loss: 3.1274e-04 - val_mean_absolute_error: 0.0135
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.4499e-05 - mean_absolute_error: 0.0068 - val_loss: 3.8405e-04 - val_mean_absolute_error: 0.0155
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0543e-04 - mean_absolute_error: 0.0071 - val_loss: 3.5775e-04 - val_mean_absolute_error: 0.0148
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1125e-04 - mean_absolute_error: 0.0072 - val_loss: 3.4505e-04 - val_mean_absolute_error: 0.0145
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2063e-04 - mean_absolute_error: 0.0077 - val_loss: 2.9741e-04 - val_mean_absolute_error: 0.0129
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1339e-04 - mean_absolute_error: 0.0073 - val_loss: 2.9040e-04 - val_mean_absolute_error: 0.0128
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0974e-04 - mean_absolute_error: 0.0070 - val_loss: 3.9019e-04 - val_mean_absolute_error: 0.0157
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3606e-04 - mean_absolute_error: 0.0080 - val_loss: 3.1853e-04 - val_mean_absolute_error: 0.0137
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.0520e-04 - mean_absolute_error: 0.0070 - val_loss: 3.5659e-04 - val_mean_absolute_error: 0.0148
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.5608e-05 - mean_absolute_error: 0.0068 - val_loss: 3.0244e-04 - val_mean_absolute_error: 0.0132
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0703e-04 - mean_absolute_error: 0.0068 - val_loss: 2.9232e-04 - val_mean_absolute_error: 0.0129
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1740e-04 - mean_absolute_error: 0.0080 - val_loss: 3.3774e-04 - val_mean_absolute_error: 0.0142
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0675e-04 - mean_absolute_error: 0.0070 - val_loss: 3.2431e-04 - val_mean_absolute_error: 0.0139
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1080e-04 - mean_absolute_error: 0.0076 - val_loss: 2.9726e-04 - val_mean_absolute_error: 0.0129
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1868e-04 - mean_absolute_error: 0.0078 - val_loss: 2.9404e-04 - val_mean_absolute_error: 0.0129
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.9503e-05 - mean_absolute_error: 0.0067 - val_loss: 3.0637e-04 - val_mean_absolute_error: 0.0132
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2278e-04 - mean_absolute_error: 0.0080 - val_loss: 4.9697e-04 - val_mean_absolute_error: 0.0181
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3631e-04 - mean_absolute_error: 0.0082 - val_loss: 2.9707e-04 - val_mean_absolute_error: 0.0130
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.0365e-04 - mean_absolute_error: 0.0066 - val_loss: 3.4490e-04 - val_mean_absolute_error: 0.0144
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2731e-04 - mean_absolute_error: 0.0075 - val_loss: 3.0562e-04 - val_mean_absolute_error: 0.0132
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0669e-04 - mean_absolute_error: 0.0071 - val_loss: 3.5647e-04 - val_mean_absolute_error: 0.0147
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0079e-04 - mean_absolute_error: 0.0068 - val_loss: 3.4050e-04 - val_mean_absolute_error: 0.0143
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5493e-04 - mean_absolute_error: 0.0090 - val_loss: 2.9851e-04 - val_mean_absolute_error: 0.0130
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1681e-04 - mean_absolute_error: 0.0074 - val_loss: 3.9224e-04 - val_mean_absolute_error: 0.0157
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1416e-04 - mean_absolute_error: 0.0076 - val_loss: 3.0103e-04 - val_mean_absolute_error: 0.0130
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0092e-04 - mean_absolute_error: 0.0065 - val_loss: 2.9420e-04 - val_mean_absolute_error: 0.0129
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.0869e-05 - mean_absolute_error: 0.0062 - val_loss: 2.9973e-04 - val_mean_absolute_error: 0.0130
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1110e-04 - mean_absolute_error: 0.0069 - val_loss: 3.0929e-04 - val_mean_absolute_error: 0.0133
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0112e-04 - mean_absolute_error: 0.0071 - val_loss: 4.4974e-04 - val_mean_absolute_error: 0.0171
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2731e-04 - mean_absolute_error: 0.0086 - val_loss: 3.1957e-04 - val_mean_absolute_error: 0.0137
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.5152e-05 - mean_absolute_error: 0.0066 - val_loss: 3.0646e-04 - val_mean_absolute_error: 0.0133
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2161e-04 - mean_absolute_error: 0.0077 - val_loss: 3.1489e-04 - val_mean_absolute_error: 0.0136
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0032e-04 - mean_absolute_error: 0.0066 - val_loss: 3.9836e-04 - val_mean_absolute_error: 0.0158
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1404e-04 - mean_absolute_error: 0.0077 - val_loss: 3.0118e-04 - val_mean_absolute_error: 0.0130
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2215e-04 - mean_absolute_error: 0.0074 - val_loss: 2.9528e-04 - val_mean_absolute_error: 0.0129
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1101e-04 - mean_absolute_error: 0.0073 - val_loss: 3.3999e-04 - val_mean_absolute_error: 0.0142
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1078e-04 - mean_absolute_error: 0.0072 - val_loss: 3.5793e-04 - val_mean_absolute_error: 0.0148
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0760e-04 - mean_absolute_error: 0.0073 - val_loss: 3.2695e-04 - val_mean_absolute_error: 0.0140
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0564e-04 - mean_absolute_error: 0.0071 - val_loss: 2.9713e-04 - val_mean_absolute_error: 0.0130
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0338e-04 - mean_absolute_error: 0.0067 - val_loss: 3.1069e-04 - val_mean_absolute_error: 0.0135
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0101e-04 - mean_absolute_error: 0.0070 - val_loss: 4.9433e-04 - val_mean_absolute_error: 0.0181
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1827e-04 - mean_absolute_error: 0.0079 - val_loss: 3.1231e-04 - val_mean_absolute_error: 0.0134
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.2056e-04 - mean_absolute_error: 0.0071 - val_loss: 3.0023e-04 - val_mean_absolute_error: 0.0131
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.6735e-05 - mean_absolute_error: 0.0071 - val_loss: 4.0593e-04 - val_mean_absolute_error: 0.0160
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0787e-04 - mean_absolute_error: 0.0072 - val_loss: 3.0354e-04 - val_mean_absolute_error: 0.0131
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.8616e-05 - mean_absolute_error: 0.0065 - val_loss: 2.9735e-04 - val_mean_absolute_error: 0.0130
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.9351e-05 - mean_absolute_error: 0.0067 - val_loss: 3.0764e-04 - val_mean_absolute_error: 0.0134
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.5264e-05 - mean_absolute_error: 0.0069 - val_loss: 3.1842e-04 - val_mean_absolute_error: 0.0137
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0088e-04 - mean_absolute_error: 0.0066 - val_loss: 2.9356e-04 - val_mean_absolute_error: 0.0129
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0441e-04 - mean_absolute_error: 0.0068 - val_loss: 3.0922e-04 - val_mean_absolute_error: 0.0133
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0828e-04 - mean_absolute_error: 0.0074 - val_loss: 2.9848e-04 - val_mean_absolute_error: 0.0131
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.5681e-05 - mean_absolute_error: 0.0068 - val_loss: 3.4476e-04 - val_mean_absolute_error: 0.0145
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2199e-04 - mean_absolute_error: 0.0078 - val_loss: 4.8903e-04 - val_mean_absolute_error: 0.0179
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.9831e-05 - mean_absolute_error: 0.0072 - val_loss: 3.2275e-04 - val_mean_absolute_error: 0.0138
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0382e-04 - mean_absolute_error: 0.0070 - val_loss: 3.3390e-04 - val_mean_absolute_error: 0.0141
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.3881e-05 - mean_absolute_error: 0.0066 - val_loss: 2.9473e-04 - val_mean_absolute_error: 0.0130
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0156e-04 - mean_absolute_error: 0.0066 - val_loss: 2.9190e-04 - val_mean_absolute_error: 0.0129
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0149e-04 - mean_absolute_error: 0.0071 - val_loss: 3.4443e-04 - val_mean_absolute_error: 0.0145
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5672e-04 - mean_absolute_error: 0.0094 - val_loss: 4.0274e-04 - val_mean_absolute_error: 0.0159
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0879e-04 - mean_absolute_error: 0.0076 - val_loss: 3.1572e-04 - val_mean_absolute_error: 0.0135
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1567e-04 - mean_absolute_error: 0.0078 - val_loss: 3.1236e-04 - val_mean_absolute_error: 0.0135
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1397e-04 - mean_absolute_error: 0.0071 - val_loss: 3.3599e-04 - val_mean_absolute_error: 0.0142
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1006e-04 - mean_absolute_error: 0.0070 - val_loss: 3.1270e-04 - val_mean_absolute_error: 0.0134
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0713e-04 - mean_absolute_error: 0.0070 - val_loss: 3.8085e-04 - val_mean_absolute_error: 0.0154
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.0761e-04 - mean_absolute_error: 0.0075 - val_loss: 3.3442e-04 - val_mean_absolute_error: 0.0141

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8270e-04 - mean_absolute_error: 0.0154
# Test Loss: [0.00033442111453041434, 0.014104075729846954]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 1593269.883794169
# RMSE: 1262.2479486195132
# MAE: 936.0949638944223
# MAPE: 2.8553305132545526 %
#
# Model evalution on validate set
# MSE: 3016355.198097681
# RMSE: 1736.765729192536
# MAE: 1095.3978353507905
# MAPE: 2.5174508898111214 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 884ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step

# %%
y_pred_30_days
# Out:
# array([[61119.367],
#        [60227.73 ],
#        [61832.797],
#        [59412.785],
#        [62860.625],
#        [58088.566],
#        [64789.38 ],
#        [55219.676],
#        [68397.78 ],
#        [49463.316],
#        [74569.67 ],
#        [38622.9  ],
#        [81813.64 ],
#        [24160.484],
#        [84194.15 ],
#        [17127.414],
#        [83429.32 ],
#        [17266.582],
#        [83227.305],
#        [17665.934],
#        [83228.87 ],
#        [17688.703],
#        [83237.   ],
#        [17675.63 ],
#        [83236.23 ],
#        [17674.9  ],
#        [83236.05 ],
#        [17675.385],
#        [83236.01 ],
#        [17675.45 ],
#        [83236.04 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Forecast Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
