# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: CMG - Test/Train/Vaildation: 60/20/20
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1484.03
# - MAE: 1132.39
# - MAPE: 3.38 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830
# ...           ...
# 2024-02-26  40000
# 2024-02-27  40200
# 2024-02-28  40000
# 2024-02-29  39950
# 2024-03-01  41200
#
# [1252 rows x 1 columns]

# %%
df.shape
# Out:
# (1252, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1247    40000
# 1248    40200
# 1249    40000
# 1250    39950
# 1251    41200
# Name: close, Length: 1252, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((740, 10), (740,), (239, 10), (239,), (240, 10), (240,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0482 - mean_absolute_error: 0.1631 - val_loss: 0.0352 - val_mean_absolute_error: 0.1781
# Epoch 2/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0049 - mean_absolute_error: 0.0452 - val_loss: 0.0035 - val_mean_absolute_error: 0.0458
# Epoch 3/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0237 - val_loss: 0.0039 - val_mean_absolute_error: 0.0481
# Epoch 4/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0231 - val_loss: 0.0037 - val_mean_absolute_error: 0.0472
# Epoch 5/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010 - mean_absolute_error: 0.0228 - val_loss: 0.0033 - val_mean_absolute_error: 0.0448
# Epoch 6/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0244 - val_loss: 0.0033 - val_mean_absolute_error: 0.0445
# Epoch 7/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5808e-04 - mean_absolute_error: 0.0221 - val_loss: 0.0039 - val_mean_absolute_error: 0.0487
# Epoch 8/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010 - mean_absolute_error: 0.0232 - val_loss: 0.0036 - val_mean_absolute_error: 0.0465
# Epoch 9/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.9984e-04 - mean_absolute_error: 0.0225 - val_loss: 0.0031 - val_mean_absolute_error: 0.0433
# Epoch 10/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0230 - val_loss: 0.0031 - val_mean_absolute_error: 0.0430
# Epoch 11/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0236 - val_loss: 0.0033 - val_mean_absolute_error: 0.0453
# Epoch 12/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.9386e-04 - mean_absolute_error: 0.0225 - val_loss: 0.0035 - val_mean_absolute_error: 0.0460
# Epoch 13/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010 - mean_absolute_error: 0.0234 - val_loss: 0.0029 - val_mean_absolute_error: 0.0417
# Epoch 14/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010 - mean_absolute_error: 0.0231 - val_loss: 0.0031 - val_mean_absolute_error: 0.0432
# Epoch 15/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1185e-04 - mean_absolute_error: 0.0210 - val_loss: 0.0028 - val_mean_absolute_error: 0.0411
# Epoch 16/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7640e-04 - mean_absolute_error: 0.0226 - val_loss: 0.0030 - val_mean_absolute_error: 0.0417
# Epoch 17/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.8823e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0027 - val_mean_absolute_error: 0.0402
# Epoch 18/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.0708e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0029 - val_mean_absolute_error: 0.0425
# Epoch 19/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.8827e-04 - mean_absolute_error: 0.0217 - val_loss: 0.0029 - val_mean_absolute_error: 0.0429
# Epoch 20/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.0296e-04 - mean_absolute_error: 0.0223 - val_loss: 0.0025 - val_mean_absolute_error: 0.0386
# Epoch 21/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.8235e-04 - mean_absolute_error: 0.0218 - val_loss: 0.0023 - val_mean_absolute_error: 0.0370
# Epoch 22/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1073e-04 - mean_absolute_error: 0.0211 - val_loss: 0.0027 - val_mean_absolute_error: 0.0407
# Epoch 23/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.9292e-04 - mean_absolute_error: 0.0204 - val_loss: 0.0025 - val_mean_absolute_error: 0.0381
# Epoch 24/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.6532e-04 - mean_absolute_error: 0.0208 - val_loss: 0.0035 - val_mean_absolute_error: 0.0473
# Epoch 25/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.4225e-04 - mean_absolute_error: 0.0209 - val_loss: 0.0021 - val_mean_absolute_error: 0.0355
# Epoch 26/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1389e-04 - mean_absolute_error: 0.0213 - val_loss: 0.0020 - val_mean_absolute_error: 0.0339
# Epoch 27/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6540e-04 - mean_absolute_error: 0.0210 - val_loss: 0.0021 - val_mean_absolute_error: 0.0353
# Epoch 28/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1663e-04 - mean_absolute_error: 0.0211 - val_loss: 0.0019 - val_mean_absolute_error: 0.0329
# Epoch 29/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4730e-04 - mean_absolute_error: 0.0193 - val_loss: 0.0019 - val_mean_absolute_error: 0.0323
# Epoch 30/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3516e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0017 - val_mean_absolute_error: 0.0310
# Epoch 31/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7071e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0059 - val_mean_absolute_error: 0.0675
# Epoch 32/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.0674e-04 - mean_absolute_error: 0.0209 - val_loss: 0.0029 - val_mean_absolute_error: 0.0436
# Epoch 33/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.0200e-04 - mean_absolute_error: 0.0184 - val_loss: 0.0024 - val_mean_absolute_error: 0.0385
# Epoch 34/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2790e-04 - mean_absolute_error: 0.0164 - val_loss: 0.0018 - val_mean_absolute_error: 0.0336
# Epoch 35/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6377e-04 - mean_absolute_error: 0.0189 - val_loss: 0.0025 - val_mean_absolute_error: 0.0407
# Epoch 36/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.9464e-04 - mean_absolute_error: 0.0201 - val_loss: 0.0016 - val_mean_absolute_error: 0.0295
# Epoch 37/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5311e-04 - mean_absolute_error: 0.0170 - val_loss: 0.0021 - val_mean_absolute_error: 0.0356
# Epoch 38/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1209e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0014 - val_mean_absolute_error: 0.0279
# Epoch 39/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3765e-04 - mean_absolute_error: 0.0164 - val_loss: 0.0015 - val_mean_absolute_error: 0.0306
# Epoch 40/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9545e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0022 - val_mean_absolute_error: 0.0376
# Epoch 41/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8996e-04 - mean_absolute_error: 0.0177 - val_loss: 0.0019 - val_mean_absolute_error: 0.0345
# Epoch 42/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2384e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0016 - val_mean_absolute_error: 0.0312
# Epoch 43/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6670e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0015 - val_mean_absolute_error: 0.0298
# Epoch 44/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6899e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0018 - val_mean_absolute_error: 0.0332
# Epoch 45/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.5526e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0023 - val_mean_absolute_error: 0.0392
# Epoch 46/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2578e-04 - mean_absolute_error: 0.0177 - val_loss: 0.0016 - val_mean_absolute_error: 0.0311
# Epoch 47/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2482e-04 - mean_absolute_error: 0.0163 - val_loss: 0.0016 - val_mean_absolute_error: 0.0313
# Epoch 48/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5590e-04 - mean_absolute_error: 0.0176 - val_loss: 0.0020 - val_mean_absolute_error: 0.0363
# Epoch 49/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3874e-04 - mean_absolute_error: 0.0190 - val_loss: 0.0021 - val_mean_absolute_error: 0.0366
# Epoch 50/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6971e-04 - mean_absolute_error: 0.0186 - val_loss: 0.0013 - val_mean_absolute_error: 0.0267
# Epoch 51/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2574e-04 - mean_absolute_error: 0.0148 - val_loss: 0.0013 - val_mean_absolute_error: 0.0276
# Epoch 52/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9986e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0012 - val_mean_absolute_error: 0.0260
# Epoch 53/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1863e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0013 - val_mean_absolute_error: 0.0276
# Epoch 54/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5890e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0013 - val_mean_absolute_error: 0.0276
# Epoch 55/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1560e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0013 - val_mean_absolute_error: 0.0276
# Epoch 56/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6557e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0012 - val_mean_absolute_error: 0.0259
# Epoch 57/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1025e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0013 - val_mean_absolute_error: 0.0279
# Epoch 58/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7307e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0012 - val_mean_absolute_error: 0.0263
# Epoch 59/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3474e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0011 - val_mean_absolute_error: 0.0253
# Epoch 60/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6166e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0011 - val_mean_absolute_error: 0.0253
# Epoch 61/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9915e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0013 - val_mean_absolute_error: 0.0285
# Epoch 62/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0853e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0014 - val_mean_absolute_error: 0.0293
# Epoch 63/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7061e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0011 - val_mean_absolute_error: 0.0259
# Epoch 64/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4066e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0011 - val_mean_absolute_error: 0.0247
# Epoch 65/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7653e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0013 - val_mean_absolute_error: 0.0290
# Epoch 66/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4798e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248
# Epoch 67/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7191e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0010 - val_mean_absolute_error: 0.0245
# Epoch 68/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6985e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0010 - val_mean_absolute_error: 0.0243
# Epoch 69/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3649e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0010 - val_mean_absolute_error: 0.0244
# Epoch 70/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4018e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0010 - val_mean_absolute_error: 0.0243
# Epoch 71/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0832e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0010 - val_mean_absolute_error: 0.0240
# Epoch 72/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3666e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0012 - val_mean_absolute_error: 0.0266
# Epoch 73/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9243e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0013 - val_mean_absolute_error: 0.0295
# Epoch 74/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9456e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0011 - val_mean_absolute_error: 0.0256
# Epoch 75/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5219e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0013 - val_mean_absolute_error: 0.0284
# Epoch 76/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8254e-04 - mean_absolute_error: 0.0133 - val_loss: 9.9857e-04 - val_mean_absolute_error: 0.0242
# Epoch 77/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5884e-04 - mean_absolute_error: 0.0133 - val_loss: 9.9529e-04 - val_mean_absolute_error: 0.0242
# Epoch 78/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7367e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0010 - val_mean_absolute_error: 0.0247
# Epoch 79/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2643e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0011 - val_mean_absolute_error: 0.0263
# Epoch 80/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0618e-04 - mean_absolute_error: 0.0148 - val_loss: 9.6891e-04 - val_mean_absolute_error: 0.0235
# Epoch 81/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1533e-04 - mean_absolute_error: 0.0123 - val_loss: 9.8724e-04 - val_mean_absolute_error: 0.0243
# Epoch 82/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5863e-04 - mean_absolute_error: 0.0132 - val_loss: 9.9506e-04 - val_mean_absolute_error: 0.0239
# Epoch 83/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5190e-04 - mean_absolute_error: 0.0133 - val_loss: 9.7868e-04 - val_mean_absolute_error: 0.0236
# Epoch 84/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1983e-04 - mean_absolute_error: 0.0125 - val_loss: 9.2170e-04 - val_mean_absolute_error: 0.0228
# Epoch 85/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8293e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0011 - val_mean_absolute_error: 0.0259
# Epoch 86/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4048e-04 - mean_absolute_error: 0.0134 - val_loss: 8.9717e-04 - val_mean_absolute_error: 0.0227
# Epoch 87/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2323e-04 - mean_absolute_error: 0.0126 - val_loss: 9.0012e-04 - val_mean_absolute_error: 0.0227
# Epoch 88/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1584e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0012 - val_mean_absolute_error: 0.0276
# Epoch 89/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2888e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0025 - val_mean_absolute_error: 0.0421
# Epoch 90/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0646e-04 - mean_absolute_error: 0.0167 - val_loss: 0.0018 - val_mean_absolute_error: 0.0346
# Epoch 91/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7971e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0011 - val_mean_absolute_error: 0.0259
# Epoch 92/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0784e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0011 - val_mean_absolute_error: 0.0261
# Epoch 93/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1234e-04 - mean_absolute_error: 0.0121 - val_loss: 8.9187e-04 - val_mean_absolute_error: 0.0229
# Epoch 94/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8500e-04 - mean_absolute_error: 0.0120 - val_loss: 9.7228e-04 - val_mean_absolute_error: 0.0243
# Epoch 95/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9394e-04 - mean_absolute_error: 0.0119 - val_loss: 9.0355e-04 - val_mean_absolute_error: 0.0232
# Epoch 96/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6924e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0012 - val_mean_absolute_error: 0.0273
# Epoch 97/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2380e-04 - mean_absolute_error: 0.0128 - val_loss: 8.7479e-04 - val_mean_absolute_error: 0.0227
# Epoch 98/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5926e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0012 - val_mean_absolute_error: 0.0269
# Epoch 99/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6045e-04 - mean_absolute_error: 0.0115 - val_loss: 9.2558e-04 - val_mean_absolute_error: 0.0236
# Epoch 100/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4806e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0011 - val_mean_absolute_error: 0.0261
# Epoch 101/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0450e-04 - mean_absolute_error: 0.0121 - val_loss: 9.2496e-04 - val_mean_absolute_error: 0.0235
# Epoch 102/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1010e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0013 - val_mean_absolute_error: 0.0291
# Epoch 103/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2717e-04 - mean_absolute_error: 0.0129 - val_loss: 8.6889e-04 - val_mean_absolute_error: 0.0227
# Epoch 104/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8741e-04 - mean_absolute_error: 0.0117 - val_loss: 8.8098e-04 - val_mean_absolute_error: 0.0229
# Epoch 105/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5276e-04 - mean_absolute_error: 0.0108 - val_loss: 8.8452e-04 - val_mean_absolute_error: 0.0231
# Epoch 106/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7309e-04 - mean_absolute_error: 0.0113 - val_loss: 9.0375e-04 - val_mean_absolute_error: 0.0231
# Epoch 107/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1037e-04 - mean_absolute_error: 0.0103 - val_loss: 8.7647e-04 - val_mean_absolute_error: 0.0229
# Epoch 108/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5372e-04 - mean_absolute_error: 0.0111 - val_loss: 8.8869e-04 - val_mean_absolute_error: 0.0229
# Epoch 109/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6657e-04 - mean_absolute_error: 0.0112 - val_loss: 8.9039e-04 - val_mean_absolute_error: 0.0232
# Epoch 110/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9887e-04 - mean_absolute_error: 0.0121 - val_loss: 9.9732e-04 - val_mean_absolute_error: 0.0248
# Epoch 111/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3007e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0011 - val_mean_absolute_error: 0.0255
# Epoch 112/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8236e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0011 - val_mean_absolute_error: 0.0257
# Epoch 113/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4098e-04 - mean_absolute_error: 0.0112 - val_loss: 9.5458e-04 - val_mean_absolute_error: 0.0236
# Epoch 114/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4506e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0012 - val_mean_absolute_error: 0.0269
# Epoch 115/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5147e-04 - mean_absolute_error: 0.0112 - val_loss: 9.4716e-04 - val_mean_absolute_error: 0.0240
# Epoch 116/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4926e-04 - mean_absolute_error: 0.0108 - val_loss: 9.3675e-04 - val_mean_absolute_error: 0.0234
# Epoch 117/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2038e-04 - mean_absolute_error: 0.0100 - val_loss: 9.6584e-04 - val_mean_absolute_error: 0.0237
# Epoch 118/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1912e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0011 - val_mean_absolute_error: 0.0258
# Epoch 119/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1712e-04 - mean_absolute_error: 0.0102 - val_loss: 9.8749e-04 - val_mean_absolute_error: 0.0239
# Epoch 120/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3923e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0011 - val_mean_absolute_error: 0.0253
# Epoch 121/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3333e-04 - mean_absolute_error: 0.0105 - val_loss: 9.7233e-04 - val_mean_absolute_error: 0.0238
# Epoch 122/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0885e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0010 - val_mean_absolute_error: 0.0241
# Epoch 123/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3616e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0010 - val_mean_absolute_error: 0.0244
# Epoch 124/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3306e-04 - mean_absolute_error: 0.0104 - val_loss: 9.9885e-04 - val_mean_absolute_error: 0.0240
# Epoch 125/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3730e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0010 - val_mean_absolute_error: 0.0243
# Epoch 126/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6679e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0013 - val_mean_absolute_error: 0.0280
# Epoch 127/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3228e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0012 - val_mean_absolute_error: 0.0265
# Epoch 128/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1223e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0011 - val_mean_absolute_error: 0.0246
# Epoch 129/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3537e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0012 - val_mean_absolute_error: 0.0259
# Epoch 130/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8800e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0011 - val_mean_absolute_error: 0.0254
# Epoch 131/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0870e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0012 - val_mean_absolute_error: 0.0268
# Epoch 132/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0731e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0018 - val_mean_absolute_error: 0.0343
# Epoch 133/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2153e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0013 - val_mean_absolute_error: 0.0281
# Epoch 134/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5093e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248
# Epoch 135/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3669e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0011 - val_mean_absolute_error: 0.0251
# Epoch 136/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2445e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0011 - val_mean_absolute_error: 0.0250
# Epoch 137/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9735e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0012 - val_mean_absolute_error: 0.0271
# Epoch 138/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3265e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0011 - val_mean_absolute_error: 0.0254
# Epoch 139/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9556e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0013 - val_mean_absolute_error: 0.0273
# Epoch 140/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4128e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0014 - val_mean_absolute_error: 0.0299
# Epoch 141/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2181e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0011 - val_mean_absolute_error: 0.0255
# Epoch 142/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3968e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0012 - val_mean_absolute_error: 0.0273
# Epoch 143/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0257e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0012 - val_mean_absolute_error: 0.0260
# Epoch 144/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1469e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0012 - val_mean_absolute_error: 0.0262
# Epoch 145/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1257e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0012 - val_mean_absolute_error: 0.0260
# Epoch 146/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2245e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0012 - val_mean_absolute_error: 0.0262
# Epoch 147/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8230e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0012 - val_mean_absolute_error: 0.0267
# Epoch 148/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3055e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0012 - val_mean_absolute_error: 0.0270
# Epoch 149/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4004e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0012 - val_mean_absolute_error: 0.0270
# Epoch 150/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5832e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0011 - val_mean_absolute_error: 0.0257
# Epoch 151/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6633e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0012 - val_mean_absolute_error: 0.0267
# Epoch 152/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1368e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0012 - val_mean_absolute_error: 0.0270
# Epoch 153/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4185e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0013 - val_mean_absolute_error: 0.0276
# Epoch 154/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0384e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0013 - val_mean_absolute_error: 0.0287
# Epoch 155/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4517e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0012 - val_mean_absolute_error: 0.0266
# Epoch 156/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3599e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0011 - val_mean_absolute_error: 0.0256
# Epoch 157/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2285e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0011 - val_mean_absolute_error: 0.0256
# Epoch 158/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0462e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0011 - val_mean_absolute_error: 0.0257
# Epoch 159/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9480e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0013 - val_mean_absolute_error: 0.0283
# Epoch 160/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2235e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0012 - val_mean_absolute_error: 0.0261
# Epoch 161/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6140e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0013 - val_mean_absolute_error: 0.0276
# Epoch 162/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2188e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0012 - val_mean_absolute_error: 0.0262
# Epoch 163/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7917e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0013 - val_mean_absolute_error: 0.0274
# Epoch 164/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2497e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0011 - val_mean_absolute_error: 0.0256
# Epoch 165/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0203e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0014 - val_mean_absolute_error: 0.0294
# Epoch 166/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6090e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0011 - val_mean_absolute_error: 0.0257
# Epoch 167/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0246e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0012 - val_mean_absolute_error: 0.0267
# Epoch 168/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1745e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0016 - val_mean_absolute_error: 0.0314
# Epoch 169/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2017e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0011 - val_mean_absolute_error: 0.0255
# Epoch 170/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2605e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0012 - val_mean_absolute_error: 0.0266
# Epoch 171/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8983e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0014 - val_mean_absolute_error: 0.0295
# Epoch 172/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3120e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0011 - val_mean_absolute_error: 0.0256
# Epoch 173/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2050e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0012 - val_mean_absolute_error: 0.0258
# Epoch 174/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9849e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0012 - val_mean_absolute_error: 0.0264
# Epoch 175/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1938e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0011 - val_mean_absolute_error: 0.0254
# Epoch 176/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1403e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0011 - val_mean_absolute_error: 0.0256
# Epoch 177/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1281e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0013 - val_mean_absolute_error: 0.0285
# Epoch 178/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7676e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0011 - val_mean_absolute_error: 0.0252
# Epoch 179/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2038e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0015 - val_mean_absolute_error: 0.0301
# Epoch 180/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4302e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0011 - val_mean_absolute_error: 0.0254
# Epoch 181/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6210e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0011 - val_mean_absolute_error: 0.0261
# Epoch 182/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4741e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0011 - val_mean_absolute_error: 0.0258
# Epoch 183/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0251e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0012 - val_mean_absolute_error: 0.0259
# Epoch 184/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9209e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0011 - val_mean_absolute_error: 0.0260
# Epoch 185/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1563e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0011 - val_mean_absolute_error: 0.0252
# Epoch 186/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9378e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0013 - val_mean_absolute_error: 0.0279
# Epoch 187/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2138e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0014 - val_mean_absolute_error: 0.0297
# Epoch 188/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4616e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0014 - val_mean_absolute_error: 0.0288
# Epoch 189/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0615e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0011 - val_mean_absolute_error: 0.0255
# Epoch 190/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9932e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0019 - val_mean_absolute_error: 0.0353
# Epoch 191/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8534e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0011 - val_mean_absolute_error: 0.0252
# Epoch 192/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3377e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0011 - val_mean_absolute_error: 0.0254
# Epoch 193/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0832e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0011 - val_mean_absolute_error: 0.0251
# Epoch 194/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2028e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0011 - val_mean_absolute_error: 0.0250
# Epoch 195/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1316e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0011 - val_mean_absolute_error: 0.0249
# Epoch 196/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8995e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0013 - val_mean_absolute_error: 0.0279
# Epoch 197/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1007e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0011 - val_mean_absolute_error: 0.0251
# Epoch 198/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9567e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0012 - val_mean_absolute_error: 0.0272
# Epoch 199/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9928e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0011 - val_mean_absolute_error: 0.0254
# Epoch 200/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9356e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0012 - val_mean_absolute_error: 0.0266

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0290
# Test Loss: [0.0011967439204454422, 0.026568979024887085]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 239
# 250

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 2202359.2768063885
# RMSE: 1484.0347963597042
# MAE: 1132.3921695214435
# MAPE: 3.379458372729769 %
#
# Model evalution on validate set
# MSE: 963152.031860272
# RMSE: 981.4030934637775
# MAE: 764.6214762369792
# MAPE: 2.0477173978689294 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
y_pred_30_days
# Out:
# array([[41408.957],
#        [40324.473],
#        [41715.477],
#        [40064.906],
#        [42066.15 ],
#        [39660.516],
#        [42546.785],
#        [39063.977],
#        [43224.305],
#        [38209.383],
#        [44159.266],
#        [37014.207],
#        [45389.535],
#        [35422.41 ],
#        [46866.98 ],
#        [33498.14 ],
#        [48379.04 ],
#        [31542.92 ],
#        [49607.117],
#        [30009.807],
#        [50394.656],
#        [29100.064],
#        [50833.105],
#        [28640.832],
#        [51063.773],
#        [28412.652],
#        [51181.582],
#        [28297.912],
#        [51240.992],
#        [28240.445],
#        [51270.77 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
