# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: FPT - Test/Train/Vaildation: 80/10/10
# - Dataset: 1313 rows x 7 columns (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 2853.53349314711
# - MAE: 2295.1863932291667
# - MAPE: 2.615232192523851 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 2  # 8 1 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#              close
# time
# 2019-03-01   19270
# 2019-03-04   19440
# 2019-03-05   19390
# 2019-03-06   19270
# 2019-03-07   19330
# ...            ...
# 2024-05-27  132800
# 2024-05-28  137000
# 2024-05-29  135700
# 2024-05-30  135000
# 2024-05-31  134600
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((1039, 10), (1039,), (120, 10), (120,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 18s 85ms/step - loss: 0.0318 - mean_absolute_error: 0.1321 - val_loss: 0.0012 - val_mean_absolute_error: 0.0270
# Epoch 2/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.2408e-04 - mean_absolute_error: 0.0201 - val_loss: 9.6913e-04 - val_mean_absolute_error: 0.0251
# Epoch 3/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.5269e-04 - mean_absolute_error: 0.0109 - val_loss: 7.9564e-04 - val_mean_absolute_error: 0.0210
# Epoch 4/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.5025e-04 - mean_absolute_error: 0.0110 - val_loss: 8.1522e-04 - val_mean_absolute_error: 0.0218
# Epoch 5/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.2668e-04 - mean_absolute_error: 0.0104 - val_loss: 9.0956e-04 - val_mean_absolute_error: 0.0235
# Epoch 6/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.7798e-04 - mean_absolute_error: 0.0112 - val_loss: 7.9328e-04 - val_mean_absolute_error: 0.0212
# Epoch 7/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.4669e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0010 - val_mean_absolute_error: 0.0247
# Epoch 8/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.6907e-04 - mean_absolute_error: 0.0111 - val_loss: 7.3038e-04 - val_mean_absolute_error: 0.0197
# Epoch 9/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.6810e-04 - mean_absolute_error: 0.0111 - val_loss: 9.1347e-04 - val_mean_absolute_error: 0.0228
# Epoch 10/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.5542e-04 - mean_absolute_error: 0.0104 - val_loss: 7.0551e-04 - val_mean_absolute_error: 0.0193
# Epoch 11/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.2146e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0011 - val_mean_absolute_error: 0.0250
# Epoch 12/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.3233e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0010 - val_mean_absolute_error: 0.0241
# Epoch 13/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.3884e-04 - mean_absolute_error: 0.0105 - val_loss: 9.9483e-04 - val_mean_absolute_error: 0.0233
# Epoch 14/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.4814e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0010 - val_mean_absolute_error: 0.0234
# Epoch 15/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.0262e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0011 - val_mean_absolute_error: 0.0251
# Epoch 16/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.2672e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0015 - val_mean_absolute_error: 0.0317
# Epoch 17/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.2077e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0014 - val_mean_absolute_error: 0.0298
# Epoch 18/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.7740e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0018 - val_mean_absolute_error: 0.0352
# Epoch 19/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.6131e-04 - mean_absolute_error: 0.0107 - val_loss: 9.9522e-04 - val_mean_absolute_error: 0.0229
# Epoch 20/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.1305e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0010 - val_mean_absolute_error: 0.0231
# Epoch 21/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.3008e-04 - mean_absolute_error: 0.0100 - val_loss: 8.6118e-04 - val_mean_absolute_error: 0.0208
# Epoch 22/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.0669e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0011 - val_mean_absolute_error: 0.0246
# Epoch 23/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.9986e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0011 - val_mean_absolute_error: 0.0244
# Epoch 24/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.1920e-04 - mean_absolute_error: 0.0100 - val_loss: 7.5228e-04 - val_mean_absolute_error: 0.0194
# Epoch 25/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.4638e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0014 - val_mean_absolute_error: 0.0299
# Epoch 26/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.2807e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0016 - val_mean_absolute_error: 0.0328
# Epoch 27/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.3233e-04 - mean_absolute_error: 0.0104 - val_loss: 9.3284e-04 - val_mean_absolute_error: 0.0219
# Epoch 28/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.0551e-04 - mean_absolute_error: 0.0098 - val_loss: 9.0299e-04 - val_mean_absolute_error: 0.0216
# Epoch 29/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.0542e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0014 - val_mean_absolute_error: 0.0300
# Epoch 30/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1283e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0015 - val_mean_absolute_error: 0.0314
# Epoch 31/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.9310e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0010 - val_mean_absolute_error: 0.0236
# Epoch 32/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.7624e-04 - mean_absolute_error: 0.0122 - val_loss: 6.9756e-04 - val_mean_absolute_error: 0.0187
# Epoch 33/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.9247e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0015 - val_mean_absolute_error: 0.0316
# Epoch 34/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.9026e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0012 - val_mean_absolute_error: 0.0274
# Epoch 35/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8499e-04 - mean_absolute_error: 0.0096 - val_loss: 6.0811e-04 - val_mean_absolute_error: 0.0178
# Epoch 36/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.0252e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0013 - val_mean_absolute_error: 0.0295
# Epoch 37/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.8295e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0012 - val_mean_absolute_error: 0.0279
# Epoch 38/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 1.9459e-04 - mean_absolute_error: 0.0095 - val_loss: 8.4109e-04 - val_mean_absolute_error: 0.0212
# Epoch 39/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8589e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0012 - val_mean_absolute_error: 0.0269
# Epoch 40/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.9482e-04 - mean_absolute_error: 0.0095 - val_loss: 6.8797e-04 - val_mean_absolute_error: 0.0186
# Epoch 41/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.0921e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0015 - val_mean_absolute_error: 0.0330
# Epoch 42/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.1570e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0016 - val_mean_absolute_error: 0.0345
# Epoch 43/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.0042e-04 - mean_absolute_error: 0.0098 - val_loss: 9.7838e-04 - val_mean_absolute_error: 0.0242
# Epoch 44/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.5963e-04 - mean_absolute_error: 0.0085 - val_loss: 7.2316e-04 - val_mean_absolute_error: 0.0195
# Epoch 45/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.4837e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0012 - val_mean_absolute_error: 0.0289
# Epoch 46/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.7787e-04 - mean_absolute_error: 0.0091 - val_loss: 6.2286e-04 - val_mean_absolute_error: 0.0180
# Epoch 47/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6422e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0013 - val_mean_absolute_error: 0.0300
# Epoch 48/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.5696e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0028 - val_mean_absolute_error: 0.0483
# Epoch 49/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.0297e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0012 - val_mean_absolute_error: 0.0285
# Epoch 50/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.7083e-04 - mean_absolute_error: 0.0091 - val_loss: 9.0365e-04 - val_mean_absolute_error: 0.0238
# Epoch 51/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6661e-04 - mean_absolute_error: 0.0091 - val_loss: 3.6239e-04 - val_mean_absolute_error: 0.0152
# Epoch 52/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.3473e-04 - mean_absolute_error: 0.0111 - val_loss: 6.7841e-04 - val_mean_absolute_error: 0.0194
# Epoch 53/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.7380e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0013 - val_mean_absolute_error: 0.0303
# Epoch 54/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.5612e-04 - mean_absolute_error: 0.0086 - val_loss: 5.8190e-04 - val_mean_absolute_error: 0.0177
# Epoch 55/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.3503e-04 - mean_absolute_error: 0.0079 - val_loss: 3.9069e-04 - val_mean_absolute_error: 0.0148
# Epoch 56/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5565e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0012 - val_mean_absolute_error: 0.0291
# Epoch 57/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4334e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0017 - val_mean_absolute_error: 0.0365
# Epoch 58/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.9047e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0010 - val_mean_absolute_error: 0.0262
# Epoch 59/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4184e-04 - mean_absolute_error: 0.0083 - val_loss: 8.5248e-04 - val_mean_absolute_error: 0.0233
# Epoch 60/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.2468e-04 - mean_absolute_error: 0.0077 - val_loss: 8.9389e-04 - val_mean_absolute_error: 0.0241
# Epoch 61/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6358e-04 - mean_absolute_error: 0.0087 - val_loss: 3.1875e-04 - val_mean_absolute_error: 0.0138
# Epoch 62/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 1.8471e-04 - mean_absolute_error: 0.0096 - val_loss: 3.0525e-04 - val_mean_absolute_error: 0.0137
# Epoch 63/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.9095e-04 - mean_absolute_error: 0.0102 - val_loss: 3.0805e-04 - val_mean_absolute_error: 0.0134
# Epoch 64/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.8074e-04 - mean_absolute_error: 0.0096 - val_loss: 6.9221e-04 - val_mean_absolute_error: 0.0204
# Epoch 65/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.2794e-04 - mean_absolute_error: 0.0076 - val_loss: 5.4965e-04 - val_mean_absolute_error: 0.0176
# Epoch 66/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.3387e-04 - mean_absolute_error: 0.0082 - val_loss: 4.5272e-04 - val_mean_absolute_error: 0.0158
# Epoch 67/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.4338e-04 - mean_absolute_error: 0.0085 - val_loss: 3.3886e-04 - val_mean_absolute_error: 0.0138
# Epoch 68/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3231e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0011 - val_mean_absolute_error: 0.0279
# Epoch 69/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5921e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0012 - val_mean_absolute_error: 0.0300
# Epoch 70/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.1761e-04 - mean_absolute_error: 0.0074 - val_loss: 7.8308e-04 - val_mean_absolute_error: 0.0225
# Epoch 71/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.2061e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0012 - val_mean_absolute_error: 0.0297
# Epoch 72/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.2307e-04 - mean_absolute_error: 0.0074 - val_loss: 8.4427e-04 - val_mean_absolute_error: 0.0237
# Epoch 73/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3731e-04 - mean_absolute_error: 0.0081 - val_loss: 6.8099e-04 - val_mean_absolute_error: 0.0205
# Epoch 74/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.6820e-05 - mean_absolute_error: 0.0069 - val_loss: 5.5163e-04 - val_mean_absolute_error: 0.0178
# Epoch 75/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3511e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0011 - val_mean_absolute_error: 0.0274
# Epoch 76/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2045e-04 - mean_absolute_error: 0.0076 - val_loss: 4.6432e-04 - val_mean_absolute_error: 0.0161
# Epoch 77/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5032e-04 - mean_absolute_error: 0.0087 - val_loss: 2.7299e-04 - val_mean_absolute_error: 0.0126
# Epoch 78/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.1822e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0015 - val_mean_absolute_error: 0.0348
# Epoch 79/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.5747e-04 - mean_absolute_error: 0.0090 - val_loss: 6.7210e-04 - val_mean_absolute_error: 0.0205
# Epoch 80/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3472e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0010 - val_mean_absolute_error: 0.0268
# Epoch 81/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.1464e-04 - mean_absolute_error: 0.0073 - val_loss: 6.2872e-04 - val_mean_absolute_error: 0.0197
# Epoch 82/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0568e-04 - mean_absolute_error: 0.0072 - val_loss: 6.7636e-04 - val_mean_absolute_error: 0.0207
# Epoch 83/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.1537e-04 - mean_absolute_error: 0.0072 - val_loss: 6.2895e-04 - val_mean_absolute_error: 0.0196
# Epoch 84/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0727e-04 - mean_absolute_error: 0.0071 - val_loss: 9.0234e-04 - val_mean_absolute_error: 0.0252
# Epoch 85/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 1.1450e-04 - mean_absolute_error: 0.0075 - val_loss: 4.0865e-04 - val_mean_absolute_error: 0.0151
# Epoch 86/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.0585e-04 - mean_absolute_error: 0.0071 - val_loss: 8.1547e-04 - val_mean_absolute_error: 0.0235
# Epoch 87/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2192e-04 - mean_absolute_error: 0.0073 - val_loss: 5.9599e-04 - val_mean_absolute_error: 0.0190
# Epoch 88/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3397e-04 - mean_absolute_error: 0.0080 - val_loss: 8.0542e-04 - val_mean_absolute_error: 0.0236
# Epoch 89/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.2156e-04 - mean_absolute_error: 0.0077 - val_loss: 6.9448e-04 - val_mean_absolute_error: 0.0216
# Epoch 90/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.1922e-04 - mean_absolute_error: 0.0072 - val_loss: 7.2177e-04 - val_mean_absolute_error: 0.0217
# Epoch 91/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4378e-04 - mean_absolute_error: 0.0082 - val_loss: 5.6467e-04 - val_mean_absolute_error: 0.0187
# Epoch 92/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.1615e-04 - mean_absolute_error: 0.0075 - val_loss: 9.4634e-04 - val_mean_absolute_error: 0.0261
# Epoch 93/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.0852e-04 - mean_absolute_error: 0.0071 - val_loss: 3.8444e-04 - val_mean_absolute_error: 0.0146
# Epoch 94/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.8930e-05 - mean_absolute_error: 0.0067 - val_loss: 0.0014 - val_mean_absolute_error: 0.0332
# Epoch 95/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4003e-04 - mean_absolute_error: 0.0085 - val_loss: 3.5037e-04 - val_mean_absolute_error: 0.0139
# Epoch 96/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.1673e-04 - mean_absolute_error: 0.0074 - val_loss: 6.8451e-04 - val_mean_absolute_error: 0.0215
# Epoch 97/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.5600e-05 - mean_absolute_error: 0.0067 - val_loss: 3.9755e-04 - val_mean_absolute_error: 0.0150
# Epoch 98/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.2833e-05 - mean_absolute_error: 0.0069 - val_loss: 5.7666e-04 - val_mean_absolute_error: 0.0190
# Epoch 99/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.1477e-04 - mean_absolute_error: 0.0071 - val_loss: 3.0161e-04 - val_mean_absolute_error: 0.0129
# Epoch 100/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.1287e-04 - mean_absolute_error: 0.0074 - val_loss: 3.7471e-04 - val_mean_absolute_error: 0.0144
# Epoch 101/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.1949e-04 - mean_absolute_error: 0.0071 - val_loss: 6.6194e-04 - val_mean_absolute_error: 0.0209
# Epoch 102/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.0811e-04 - mean_absolute_error: 0.0072 - val_loss: 0.0016 - val_mean_absolute_error: 0.0364
# Epoch 103/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.6475e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0010 - val_mean_absolute_error: 0.0279
# Epoch 104/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0335e-04 - mean_absolute_error: 0.0070 - val_loss: 2.6087e-04 - val_mean_absolute_error: 0.0122
# Epoch 105/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.1958e-04 - mean_absolute_error: 0.0073 - val_loss: 6.6927e-04 - val_mean_absolute_error: 0.0213
# Epoch 106/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0221e-04 - mean_absolute_error: 0.0069 - val_loss: 6.6139e-04 - val_mean_absolute_error: 0.0213
# Epoch 107/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.1936e-04 - mean_absolute_error: 0.0076 - val_loss: 4.6494e-04 - val_mean_absolute_error: 0.0167
# Epoch 108/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3010e-04 - mean_absolute_error: 0.0083 - val_loss: 6.0872e-04 - val_mean_absolute_error: 0.0203
# Epoch 109/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.1799e-04 - mean_absolute_error: 0.0075 - val_loss: 5.9646e-04 - val_mean_absolute_error: 0.0200
# Epoch 110/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 9.8866e-05 - mean_absolute_error: 0.0067 - val_loss: 3.3674e-04 - val_mean_absolute_error: 0.0137
# Epoch 111/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.1103e-04 - mean_absolute_error: 0.0070 - val_loss: 1.9131e-04 - val_mean_absolute_error: 0.0108
# Epoch 112/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0315e-04 - mean_absolute_error: 0.0074 - val_loss: 9.8152e-04 - val_mean_absolute_error: 0.0276
# Epoch 113/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.1998e-04 - mean_absolute_error: 0.0075 - val_loss: 1.9074e-04 - val_mean_absolute_error: 0.0103
# Epoch 114/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.0793e-04 - mean_absolute_error: 0.0074 - val_loss: 5.7804e-04 - val_mean_absolute_error: 0.0196
# Epoch 115/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.6688e-05 - mean_absolute_error: 0.0067 - val_loss: 4.5439e-04 - val_mean_absolute_error: 0.0167
# Epoch 116/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0844e-04 - mean_absolute_error: 0.0068 - val_loss: 2.3086e-04 - val_mean_absolute_error: 0.0114
# Epoch 117/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.0759e-04 - mean_absolute_error: 0.0071 - val_loss: 3.8178e-04 - val_mean_absolute_error: 0.0149
# Epoch 118/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.9775e-05 - mean_absolute_error: 0.0064 - val_loss: 2.7219e-04 - val_mean_absolute_error: 0.0122
# Epoch 119/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.2887e-05 - mean_absolute_error: 0.0065 - val_loss: 7.0269e-04 - val_mean_absolute_error: 0.0224
# Epoch 120/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.3896e-05 - mean_absolute_error: 0.0067 - val_loss: 1.9787e-04 - val_mean_absolute_error: 0.0104
# Epoch 121/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.3394e-05 - mean_absolute_error: 0.0063 - val_loss: 7.3202e-04 - val_mean_absolute_error: 0.0230
# Epoch 122/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.0111e-04 - mean_absolute_error: 0.0068 - val_loss: 4.1363e-04 - val_mean_absolute_error: 0.0158
# Epoch 123/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.9104e-05 - mean_absolute_error: 0.0067 - val_loss: 2.0750e-04 - val_mean_absolute_error: 0.0107
# Epoch 124/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.1052e-04 - mean_absolute_error: 0.0072 - val_loss: 2.7189e-04 - val_mean_absolute_error: 0.0121
# Epoch 125/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.0622e-04 - mean_absolute_error: 0.0070 - val_loss: 1.8114e-04 - val_mean_absolute_error: 0.0099
# Epoch 126/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.0453e-04 - mean_absolute_error: 0.0070 - val_loss: 1.6545e-04 - val_mean_absolute_error: 0.0101
# Epoch 127/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3982e-04 - mean_absolute_error: 0.0087 - val_loss: 1.8164e-04 - val_mean_absolute_error: 0.0098
# Epoch 128/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.8040e-05 - mean_absolute_error: 0.0068 - val_loss: 4.2659e-04 - val_mean_absolute_error: 0.0164
# Epoch 129/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0945e-04 - mean_absolute_error: 0.0069 - val_loss: 3.4452e-04 - val_mean_absolute_error: 0.0144
# Epoch 130/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.0679e-05 - mean_absolute_error: 0.0065 - val_loss: 2.2332e-04 - val_mean_absolute_error: 0.0109
# Epoch 131/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.9736e-05 - mean_absolute_error: 0.0061 - val_loss: 2.4376e-04 - val_mean_absolute_error: 0.0115
# Epoch 132/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.8106e-05 - mean_absolute_error: 0.0068 - val_loss: 2.2781e-04 - val_mean_absolute_error: 0.0111
# Epoch 133/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0333e-04 - mean_absolute_error: 0.0071 - val_loss: 3.0831e-04 - val_mean_absolute_error: 0.0132
# Epoch 134/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.2437e-05 - mean_absolute_error: 0.0062 - val_loss: 3.0625e-04 - val_mean_absolute_error: 0.0131
# Epoch 135/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.3512e-05 - mean_absolute_error: 0.0067 - val_loss: 2.0868e-04 - val_mean_absolute_error: 0.0105
# Epoch 136/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 9.3047e-05 - mean_absolute_error: 0.0066 - val_loss: 3.1732e-04 - val_mean_absolute_error: 0.0136
# Epoch 137/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.4895e-05 - mean_absolute_error: 0.0063 - val_loss: 5.2332e-04 - val_mean_absolute_error: 0.0191
# Epoch 138/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.9331e-05 - mean_absolute_error: 0.0060 - val_loss: 5.1282e-04 - val_mean_absolute_error: 0.0188
# Epoch 139/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.1314e-04 - mean_absolute_error: 0.0076 - val_loss: 2.3359e-04 - val_mean_absolute_error: 0.0112
# Epoch 140/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.5046e-05 - mean_absolute_error: 0.0063 - val_loss: 4.3202e-04 - val_mean_absolute_error: 0.0169
# Epoch 141/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.2308e-04 - mean_absolute_error: 0.0079 - val_loss: 2.3004e-04 - val_mean_absolute_error: 0.0111
# Epoch 142/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.2790e-05 - mean_absolute_error: 0.0059 - val_loss: 4.7158e-04 - val_mean_absolute_error: 0.0178
# Epoch 143/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.1008e-04 - mean_absolute_error: 0.0073 - val_loss: 4.5794e-04 - val_mean_absolute_error: 0.0176
# Epoch 144/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.0942e-05 - mean_absolute_error: 0.0061 - val_loss: 6.0072e-04 - val_mean_absolute_error: 0.0209
# Epoch 145/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.5063e-05 - mean_absolute_error: 0.0068 - val_loss: 3.0239e-04 - val_mean_absolute_error: 0.0131
# Epoch 146/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.8356e-05 - mean_absolute_error: 0.0062 - val_loss: 7.5378e-04 - val_mean_absolute_error: 0.0241
# Epoch 147/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0442e-04 - mean_absolute_error: 0.0073 - val_loss: 6.5394e-04 - val_mean_absolute_error: 0.0221
# Epoch 148/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.3017e-05 - mean_absolute_error: 0.0068 - val_loss: 2.0026e-04 - val_mean_absolute_error: 0.0102
# Epoch 149/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.9000e-05 - mean_absolute_error: 0.0065 - val_loss: 1.4566e-04 - val_mean_absolute_error: 0.0095
# Epoch 150/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.9022e-05 - mean_absolute_error: 0.0069 - val_loss: 3.5395e-04 - val_mean_absolute_error: 0.0148
# Epoch 151/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.4095e-05 - mean_absolute_error: 0.0057 - val_loss: 2.9531e-04 - val_mean_absolute_error: 0.0131
# Epoch 152/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.6530e-05 - mean_absolute_error: 0.0059 - val_loss: 2.6176e-04 - val_mean_absolute_error: 0.0122
# Epoch 153/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.7897e-05 - mean_absolute_error: 0.0070 - val_loss: 1.7067e-04 - val_mean_absolute_error: 0.0093
# Epoch 154/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.6524e-05 - mean_absolute_error: 0.0070 - val_loss: 2.4691e-04 - val_mean_absolute_error: 0.0116
# Epoch 155/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.8093e-05 - mean_absolute_error: 0.0059 - val_loss: 1.7036e-04 - val_mean_absolute_error: 0.0094
# Epoch 156/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.0347e-04 - mean_absolute_error: 0.0071 - val_loss: 1.4103e-04 - val_mean_absolute_error: 0.0093
# Epoch 157/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 9.8112e-05 - mean_absolute_error: 0.0068 - val_loss: 3.0574e-04 - val_mean_absolute_error: 0.0135
# Epoch 158/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.6618e-05 - mean_absolute_error: 0.0060 - val_loss: 2.7709e-04 - val_mean_absolute_error: 0.0126
# Epoch 159/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.2041e-05 - mean_absolute_error: 0.0058 - val_loss: 1.7898e-04 - val_mean_absolute_error: 0.0096
# Epoch 160/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.2078e-05 - mean_absolute_error: 0.0056 - val_loss: 2.5052e-04 - val_mean_absolute_error: 0.0119
# Epoch 161/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.2153e-05 - mean_absolute_error: 0.0057 - val_loss: 1.9960e-04 - val_mean_absolute_error: 0.0102
# Epoch 162/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.6017e-05 - mean_absolute_error: 0.0062 - val_loss: 2.3792e-04 - val_mean_absolute_error: 0.0114
# Epoch 163/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.5383e-05 - mean_absolute_error: 0.0059 - val_loss: 2.9087e-04 - val_mean_absolute_error: 0.0130
# Epoch 164/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.1820e-05 - mean_absolute_error: 0.0063 - val_loss: 1.6851e-04 - val_mean_absolute_error: 0.0094
# Epoch 165/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.0009e-05 - mean_absolute_error: 0.0060 - val_loss: 3.0790e-04 - val_mean_absolute_error: 0.0134
# Epoch 166/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.5973e-05 - mean_absolute_error: 0.0063 - val_loss: 6.0882e-04 - val_mean_absolute_error: 0.0214
# Epoch 167/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.1128e-04 - mean_absolute_error: 0.0075 - val_loss: 2.6006e-04 - val_mean_absolute_error: 0.0121
# Epoch 168/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.5671e-05 - mean_absolute_error: 0.0062 - val_loss: 4.1583e-04 - val_mean_absolute_error: 0.0167
# Epoch 169/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.0569e-05 - mean_absolute_error: 0.0057 - val_loss: 2.6232e-04 - val_mean_absolute_error: 0.0122
# Epoch 170/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.6848e-05 - mean_absolute_error: 0.0057 - val_loss: 2.4675e-04 - val_mean_absolute_error: 0.0118
# Epoch 171/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.3618e-05 - mean_absolute_error: 0.0052 - val_loss: 3.8810e-04 - val_mean_absolute_error: 0.0160
# Epoch 172/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.7083e-05 - mean_absolute_error: 0.0073 - val_loss: 1.5644e-04 - val_mean_absolute_error: 0.0092
# Epoch 173/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.1436e-05 - mean_absolute_error: 0.0059 - val_loss: 1.4483e-04 - val_mean_absolute_error: 0.0089
# Epoch 174/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.4732e-05 - mean_absolute_error: 0.0069 - val_loss: 2.6053e-04 - val_mean_absolute_error: 0.0122
# Epoch 175/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.3596e-05 - mean_absolute_error: 0.0059 - val_loss: 2.2412e-04 - val_mean_absolute_error: 0.0111
# Epoch 176/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.1511e-05 - mean_absolute_error: 0.0060 - val_loss: 2.9365e-04 - val_mean_absolute_error: 0.0131
# Epoch 177/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.1405e-05 - mean_absolute_error: 0.0056 - val_loss: 5.5992e-04 - val_mean_absolute_error: 0.0203
# Epoch 178/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.2244e-05 - mean_absolute_error: 0.0065 - val_loss: 3.3069e-04 - val_mean_absolute_error: 0.0144
# Epoch 179/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.9205e-05 - mean_absolute_error: 0.0056 - val_loss: 2.2886e-04 - val_mean_absolute_error: 0.0113
# Epoch 180/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.1238e-05 - mean_absolute_error: 0.0053 - val_loss: 3.3691e-04 - val_mean_absolute_error: 0.0144
# Epoch 181/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.4767e-05 - mean_absolute_error: 0.0058 - val_loss: 2.8046e-04 - val_mean_absolute_error: 0.0127
# Epoch 182/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.7299e-05 - mean_absolute_error: 0.0056 - val_loss: 2.6390e-04 - val_mean_absolute_error: 0.0123
# Epoch 183/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.7018e-05 - mean_absolute_error: 0.0054 - val_loss: 2.0108e-04 - val_mean_absolute_error: 0.0103
# Epoch 184/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.3711e-05 - mean_absolute_error: 0.0051 - val_loss: 7.2031e-04 - val_mean_absolute_error: 0.0236
# Epoch 185/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.7968e-05 - mean_absolute_error: 0.0070 - val_loss: 5.7437e-04 - val_mean_absolute_error: 0.0207
# Epoch 186/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.9765e-05 - mean_absolute_error: 0.0061 - val_loss: 3.2957e-04 - val_mean_absolute_error: 0.0144
# Epoch 187/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.8347e-05 - mean_absolute_error: 0.0058 - val_loss: 2.5212e-04 - val_mean_absolute_error: 0.0119
# Epoch 188/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.1047e-05 - mean_absolute_error: 0.0063 - val_loss: 4.8084e-04 - val_mean_absolute_error: 0.0185
# Epoch 189/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.4414e-05 - mean_absolute_error: 0.0058 - val_loss: 1.4529e-04 - val_mean_absolute_error: 0.0087
# Epoch 190/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.5052e-05 - mean_absolute_error: 0.0060 - val_loss: 2.8488e-04 - val_mean_absolute_error: 0.0129
# Epoch 191/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.5022e-05 - mean_absolute_error: 0.0053 - val_loss: 1.9124e-04 - val_mean_absolute_error: 0.0099
# Epoch 192/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.4764e-05 - mean_absolute_error: 0.0052 - val_loss: 2.8575e-04 - val_mean_absolute_error: 0.0129
# Epoch 193/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.8953e-05 - mean_absolute_error: 0.0055 - val_loss: 2.3035e-04 - val_mean_absolute_error: 0.0111
# Epoch 194/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.8697e-05 - mean_absolute_error: 0.0062 - val_loss: 3.4852e-04 - val_mean_absolute_error: 0.0147
# Epoch 195/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.3502e-05 - mean_absolute_error: 0.0058 - val_loss: 1.5315e-04 - val_mean_absolute_error: 0.0091
# Epoch 196/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.6196e-05 - mean_absolute_error: 0.0062 - val_loss: 1.4275e-04 - val_mean_absolute_error: 0.0090
# Epoch 197/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.2784e-05 - mean_absolute_error: 0.0058 - val_loss: 1.8827e-04 - val_mean_absolute_error: 0.0097
# Epoch 198/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.7080e-05 - mean_absolute_error: 0.0059 - val_loss: 2.5190e-04 - val_mean_absolute_error: 0.0117
# Epoch 199/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.0744e-05 - mean_absolute_error: 0.0060 - val_loss: 3.6416e-04 - val_mean_absolute_error: 0.0153
# Epoch 200/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.3223e-05 - mean_absolute_error: 0.0052 - val_loss: 4.3071e-04 - val_mean_absolute_error: 0.0169

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0175e-04 - mean_absolute_error: 0.0137
# Test Loss: [0.0004307128838263452, 0.016890252009034157]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 120
# 131

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 8142653.396512349
# RMSE: 2853.53349314711
# MAE: 2295.1863932291667
# MAPE: 2.615232192523851 %
#
# Model evalution on validate set
# MSE: 38649951.077559546
# RMSE: 6216.908482321382
# MAE: 5297.384878615702
# MAPE: 4.655866559579199 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 761ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step

# %%
y_pred_30_days
# Out:
# array([[128772.875],
#        [132464.28 ],
#        [129339.15 ],
#        [131700.27 ],
#        [129855.9  ],
#        [131272.58 ],
#        [130178.82 ],
#        [131021.43 ],
#        [130371.664],
#        [130872.44 ],
#        [130486.36 ],
#        [130783.945],
#        [130554.52 ],
#        [130731.35 ],
#        [130595.05 ],
#        [130700.11 ],
#        [130619.125],
#        [130681.54 ],
#        [130633.445],
#        [130670.51 ],
#        [130641.94 ],
#        [130663.95 ],
#        [130646.984],
#        [130660.07 ],
#        [130649.97 ],
#        [130657.76 ],
#        [130651.77 ],
#        [130656.39 ],
#        [130652.805],
#        [130655.61 ],
#        [130653.43 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Forecast Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
