# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: FPT - Test/Train/Vaildation: 80/10/10
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1224.22
# - MAE: 918.34
# - MAPE: 1.22 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 2  # 8 1 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#              close
# time
# 2019-03-01   19270
# 2019-03-04   19440
# 2019-03-05   19390
# 2019-03-06   19270
# 2019-03-07   19330
# ...            ...
# 2024-05-27  132800
# 2024-05-28  137000
# 2024-05-29  135700
# 2024-05-30  135000
# 2024-05-31  134600
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((1039, 10), (1039,), (120, 10), (120,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 19s 89ms/step - loss: 0.0372 - mean_absolute_error: 0.1407 - val_loss: 0.0017 - val_mean_absolute_error: 0.0336
# Epoch 2/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.3372e-04 - mean_absolute_error: 0.0219 - val_loss: 9.4713e-04 - val_mean_absolute_error: 0.0230
# Epoch 3/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.8281e-04 - mean_absolute_error: 0.0117 - val_loss: 8.4167e-04 - val_mean_absolute_error: 0.0217
# Epoch 4/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.5521e-04 - mean_absolute_error: 0.0109 - val_loss: 8.1839e-04 - val_mean_absolute_error: 0.0220
# Epoch 5/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.8409e-04 - mean_absolute_error: 0.0115 - val_loss: 9.7690e-04 - val_mean_absolute_error: 0.0234
# Epoch 6/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.1529e-04 - mean_absolute_error: 0.0121 - val_loss: 7.4684e-04 - val_mean_absolute_error: 0.0203
# Epoch 7/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 2.7522e-04 - mean_absolute_error: 0.0114 - val_loss: 7.9094e-04 - val_mean_absolute_error: 0.0213
# Epoch 8/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.4064e-04 - mean_absolute_error: 0.0107 - val_loss: 8.1660e-04 - val_mean_absolute_error: 0.0216
# Epoch 9/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.6485e-04 - mean_absolute_error: 0.0107 - val_loss: 7.5916e-04 - val_mean_absolute_error: 0.0203
# Epoch 10/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.5495e-04 - mean_absolute_error: 0.0108 - val_loss: 6.7985e-04 - val_mean_absolute_error: 0.0192
# Epoch 11/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.1227e-04 - mean_absolute_error: 0.0100 - val_loss: 8.0791e-04 - val_mean_absolute_error: 0.0208
# Epoch 12/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.0294e-04 - mean_absolute_error: 0.0098 - val_loss: 8.0299e-04 - val_mean_absolute_error: 0.0206
# Epoch 13/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.4587e-04 - mean_absolute_error: 0.0104 - val_loss: 8.5439e-04 - val_mean_absolute_error: 0.0212
# Epoch 14/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.3215e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0013 - val_mean_absolute_error: 0.0284
# Epoch 15/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.2984e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0012 - val_mean_absolute_error: 0.0268
# Epoch 16/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.3850e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0013 - val_mean_absolute_error: 0.0281
# Epoch 17/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.8889e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0014 - val_mean_absolute_error: 0.0289
# Epoch 18/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.2744e-04 - mean_absolute_error: 0.0102 - val_loss: 7.2268e-04 - val_mean_absolute_error: 0.0193
# Epoch 19/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.5166e-04 - mean_absolute_error: 0.0107 - val_loss: 9.7785e-04 - val_mean_absolute_error: 0.0227
# Epoch 20/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.1415e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0017 - val_mean_absolute_error: 0.0341
# Epoch 21/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.4548e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0016 - val_mean_absolute_error: 0.0334
# Epoch 22/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.2710e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0013 - val_mean_absolute_error: 0.0285
# Epoch 23/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.2953e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0012 - val_mean_absolute_error: 0.0267
# Epoch 24/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.8805e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0020 - val_mean_absolute_error: 0.0378
# Epoch 25/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.4900e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0010 - val_mean_absolute_error: 0.0237
# Epoch 26/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.0957e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0013 - val_mean_absolute_error: 0.0285
# Epoch 27/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.0778e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0016 - val_mean_absolute_error: 0.0336
# Epoch 28/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.1570e-04 - mean_absolute_error: 0.0100 - val_loss: 9.5061e-04 - val_mean_absolute_error: 0.0224
# Epoch 29/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5387e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0011 - val_mean_absolute_error: 0.0258
# Epoch 30/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.2040e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0011 - val_mean_absolute_error: 0.0253
# Epoch 31/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.9620e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0013 - val_mean_absolute_error: 0.0279
# Epoch 32/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.1758e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0011 - val_mean_absolute_error: 0.0252
# Epoch 33/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.2510e-04 - mean_absolute_error: 0.0104 - val_loss: 8.4685e-04 - val_mean_absolute_error: 0.0209
# Epoch 34/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.0956e-04 - mean_absolute_error: 0.0099 - val_loss: 8.0021e-04 - val_mean_absolute_error: 0.0202
# Epoch 35/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.0930e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0016 - val_mean_absolute_error: 0.0333
# Epoch 36/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.9761e-04 - mean_absolute_error: 0.0095 - val_loss: 7.2869e-04 - val_mean_absolute_error: 0.0191
# Epoch 37/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.9850e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0014 - val_mean_absolute_error: 0.0302
# Epoch 38/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.8074e-04 - mean_absolute_error: 0.0093 - val_loss: 7.3436e-04 - val_mean_absolute_error: 0.0192
# Epoch 39/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.1869e-04 - mean_absolute_error: 0.0104 - val_loss: 9.7566e-04 - val_mean_absolute_error: 0.0236
# Epoch 40/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6887e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0020 - val_mean_absolute_error: 0.0386
# Epoch 41/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.5806e-04 - mean_absolute_error: 0.0114 - val_loss: 9.7247e-04 - val_mean_absolute_error: 0.0237
# Epoch 42/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.9504e-04 - mean_absolute_error: 0.0092 - val_loss: 7.4571e-04 - val_mean_absolute_error: 0.0196
# Epoch 43/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5758e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0011 - val_mean_absolute_error: 0.0260
# Epoch 44/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.1453e-04 - mean_absolute_error: 0.0103 - val_loss: 6.2110e-04 - val_mean_absolute_error: 0.0177
# Epoch 45/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.7614e-04 - mean_absolute_error: 0.0090 - val_loss: 8.9174e-04 - val_mean_absolute_error: 0.0226
# Epoch 46/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.7236e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0012 - val_mean_absolute_error: 0.0279
# Epoch 47/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5868e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0011 - val_mean_absolute_error: 0.0265
# Epoch 48/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.7050e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0014 - val_mean_absolute_error: 0.0314
# Epoch 49/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8805e-04 - mean_absolute_error: 0.0093 - val_loss: 5.1522e-04 - val_mean_absolute_error: 0.0163
# Epoch 50/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.7820e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0012 - val_mean_absolute_error: 0.0283
# Epoch 51/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.4563e-04 - mean_absolute_error: 0.0084 - val_loss: 5.1313e-04 - val_mean_absolute_error: 0.0162
# Epoch 52/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6919e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0011 - val_mean_absolute_error: 0.0264
# Epoch 53/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.5915e-04 - mean_absolute_error: 0.0087 - val_loss: 7.0697e-04 - val_mean_absolute_error: 0.0198
# Epoch 54/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.0221e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0012 - val_mean_absolute_error: 0.0292
# Epoch 55/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6383e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0012 - val_mean_absolute_error: 0.0287
# Epoch 56/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5614e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0014 - val_mean_absolute_error: 0.0323
# Epoch 57/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6718e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0012 - val_mean_absolute_error: 0.0286
# Epoch 58/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8595e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0016 - val_mean_absolute_error: 0.0350
# Epoch 59/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4068e-04 - mean_absolute_error: 0.0084 - val_loss: 4.4606e-04 - val_mean_absolute_error: 0.0156
# Epoch 60/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.5226e-04 - mean_absolute_error: 0.0083 - val_loss: 6.2640e-04 - val_mean_absolute_error: 0.0187
# Epoch 61/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6598e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0013 - val_mean_absolute_error: 0.0306
# Epoch 62/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6367e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0019 - val_mean_absolute_error: 0.0394
# Epoch 63/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.8419e-04 - mean_absolute_error: 0.0096 - val_loss: 9.4844e-04 - val_mean_absolute_error: 0.0253
# Epoch 64/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4587e-04 - mean_absolute_error: 0.0080 - val_loss: 3.9517e-04 - val_mean_absolute_error: 0.0148
# Epoch 65/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3458e-04 - mean_absolute_error: 0.0080 - val_loss: 5.6480e-04 - val_mean_absolute_error: 0.0178
# Epoch 66/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4458e-04 - mean_absolute_error: 0.0082 - val_loss: 6.0469e-04 - val_mean_absolute_error: 0.0186
# Epoch 67/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3087e-04 - mean_absolute_error: 0.0079 - val_loss: 6.2010e-04 - val_mean_absolute_error: 0.0190
# Epoch 68/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.1888e-04 - mean_absolute_error: 0.0075 - val_loss: 4.2152e-04 - val_mean_absolute_error: 0.0153
# Epoch 69/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2918e-04 - mean_absolute_error: 0.0079 - val_loss: 3.5590e-04 - val_mean_absolute_error: 0.0141
# Epoch 70/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.9584e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0020 - val_mean_absolute_error: 0.0406
# Epoch 71/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.8743e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0015 - val_mean_absolute_error: 0.0342
# Epoch 72/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.5371e-04 - mean_absolute_error: 0.0084 - val_loss: 8.9107e-04 - val_mean_absolute_error: 0.0247
# Epoch 73/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.1708e-04 - mean_absolute_error: 0.0074 - val_loss: 2.9279e-04 - val_mean_absolute_error: 0.0129
# Epoch 74/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.4588e-04 - mean_absolute_error: 0.0084 - val_loss: 6.9873e-04 - val_mean_absolute_error: 0.0211
# Epoch 75/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.1880e-04 - mean_absolute_error: 0.0074 - val_loss: 6.7044e-04 - val_mean_absolute_error: 0.0204
# Epoch 76/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.2469e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0014 - val_mean_absolute_error: 0.0337
# Epoch 77/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.4605e-04 - mean_absolute_error: 0.0084 - val_loss: 3.1023e-04 - val_mean_absolute_error: 0.0132
# Epoch 78/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.1991e-04 - mean_absolute_error: 0.0075 - val_loss: 5.9794e-04 - val_mean_absolute_error: 0.0190
# Epoch 79/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.0999e-04 - mean_absolute_error: 0.0073 - val_loss: 2.3742e-04 - val_mean_absolute_error: 0.0119
# Epoch 80/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.2434e-04 - mean_absolute_error: 0.0077 - val_loss: 8.6617e-04 - val_mean_absolute_error: 0.0247
# Epoch 81/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.5442e-04 - mean_absolute_error: 0.0088 - val_loss: 4.5093e-04 - val_mean_absolute_error: 0.0160
# Epoch 82/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.1390e-04 - mean_absolute_error: 0.0074 - val_loss: 3.5355e-04 - val_mean_absolute_error: 0.0140
# Epoch 83/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.2266e-04 - mean_absolute_error: 0.0077 - val_loss: 2.3679e-04 - val_mean_absolute_error: 0.0117
# Epoch 84/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.1459e-04 - mean_absolute_error: 0.0072 - val_loss: 3.8885e-04 - val_mean_absolute_error: 0.0147
# Epoch 85/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.2258e-04 - mean_absolute_error: 0.0076 - val_loss: 5.1058e-04 - val_mean_absolute_error: 0.0175
# Epoch 86/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.0810e-04 - mean_absolute_error: 0.0071 - val_loss: 4.4875e-04 - val_mean_absolute_error: 0.0160
# Epoch 87/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.2508e-04 - mean_absolute_error: 0.0077 - val_loss: 9.2592e-04 - val_mean_absolute_error: 0.0259
# Epoch 88/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.2877e-04 - mean_absolute_error: 0.0079 - val_loss: 0.0011 - val_mean_absolute_error: 0.0293
# Epoch 89/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.4157e-04 - mean_absolute_error: 0.0084 - val_loss: 8.9992e-04 - val_mean_absolute_error: 0.0253
# Epoch 90/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 9.7609e-05 - mean_absolute_error: 0.0068 - val_loss: 2.8632e-04 - val_mean_absolute_error: 0.0127
# Epoch 91/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.2717e-04 - mean_absolute_error: 0.0076 - val_loss: 3.8026e-04 - val_mean_absolute_error: 0.0146
# Epoch 92/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.0573e-04 - mean_absolute_error: 0.0072 - val_loss: 4.2787e-04 - val_mean_absolute_error: 0.0156
# Epoch 93/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.8386e-05 - mean_absolute_error: 0.0066 - val_loss: 3.4132e-04 - val_mean_absolute_error: 0.0137
# Epoch 94/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.1756e-04 - mean_absolute_error: 0.0077 - val_loss: 3.1455e-04 - val_mean_absolute_error: 0.0132
# Epoch 95/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.9052e-05 - mean_absolute_error: 0.0069 - val_loss: 6.1847e-04 - val_mean_absolute_error: 0.0199
# Epoch 96/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.6385e-05 - mean_absolute_error: 0.0068 - val_loss: 2.5161e-04 - val_mean_absolute_error: 0.0119
# Epoch 97/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.1099e-04 - mean_absolute_error: 0.0071 - val_loss: 3.1390e-04 - val_mean_absolute_error: 0.0131
# Epoch 98/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 9.4731e-05 - mean_absolute_error: 0.0068 - val_loss: 4.4461e-04 - val_mean_absolute_error: 0.0161
# Epoch 99/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0575e-04 - mean_absolute_error: 0.0066 - val_loss: 8.3400e-04 - val_mean_absolute_error: 0.0244
# Epoch 100/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0712e-04 - mean_absolute_error: 0.0074 - val_loss: 2.9029e-04 - val_mean_absolute_error: 0.0126
# Epoch 101/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.2322e-04 - mean_absolute_error: 0.0077 - val_loss: 3.2846e-04 - val_mean_absolute_error: 0.0135
# Epoch 102/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.2863e-05 - mean_absolute_error: 0.0064 - val_loss: 4.4765e-04 - val_mean_absolute_error: 0.0163
# Epoch 103/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 8.4376e-05 - mean_absolute_error: 0.0064 - val_loss: 2.6935e-04 - val_mean_absolute_error: 0.0121
# Epoch 104/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.1191e-04 - mean_absolute_error: 0.0076 - val_loss: 5.3555e-04 - val_mean_absolute_error: 0.0187
# Epoch 105/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 1.0885e-04 - mean_absolute_error: 0.0071 - val_loss: 2.8396e-04 - val_mean_absolute_error: 0.0124
# Epoch 106/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 1.0224e-04 - mean_absolute_error: 0.0070 - val_loss: 2.7159e-04 - val_mean_absolute_error: 0.0121
# Epoch 107/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 1.0693e-04 - mean_absolute_error: 0.0072 - val_loss: 2.2868e-04 - val_mean_absolute_error: 0.0126
# Epoch 108/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4932e-04 - mean_absolute_error: 0.0086 - val_loss: 3.7574e-04 - val_mean_absolute_error: 0.0147
# Epoch 109/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 8.4654e-05 - mean_absolute_error: 0.0062 - val_loss: 4.2416e-04 - val_mean_absolute_error: 0.0158
# Epoch 110/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.7235e-05 - mean_absolute_error: 0.0065 - val_loss: 6.7777e-04 - val_mean_absolute_error: 0.0220
# Epoch 111/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.1167e-04 - mean_absolute_error: 0.0073 - val_loss: 2.3416e-04 - val_mean_absolute_error: 0.0113
# Epoch 112/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.1734e-04 - mean_absolute_error: 0.0078 - val_loss: 4.2339e-04 - val_mean_absolute_error: 0.0160
# Epoch 113/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.0260e-05 - mean_absolute_error: 0.0065 - val_loss: 5.4121e-04 - val_mean_absolute_error: 0.0190
# Epoch 114/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.4238e-05 - mean_absolute_error: 0.0067 - val_loss: 7.6530e-04 - val_mean_absolute_error: 0.0238
# Epoch 115/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.1159e-04 - mean_absolute_error: 0.0073 - val_loss: 2.2709e-04 - val_mean_absolute_error: 0.0111
# Epoch 116/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0314e-04 - mean_absolute_error: 0.0069 - val_loss: 3.2585e-04 - val_mean_absolute_error: 0.0135
# Epoch 117/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.1044e-05 - mean_absolute_error: 0.0062 - val_loss: 1.8431e-04 - val_mean_absolute_error: 0.0099
# Epoch 118/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.1478e-04 - mean_absolute_error: 0.0074 - val_loss: 6.5945e-04 - val_mean_absolute_error: 0.0219
# Epoch 119/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0982e-04 - mean_absolute_error: 0.0072 - val_loss: 2.2943e-04 - val_mean_absolute_error: 0.0111
# Epoch 120/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0830e-04 - mean_absolute_error: 0.0070 - val_loss: 3.7439e-04 - val_mean_absolute_error: 0.0150
# Epoch 121/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.7873e-05 - mean_absolute_error: 0.0064 - val_loss: 2.6269e-04 - val_mean_absolute_error: 0.0119
# Epoch 122/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.9407e-05 - mean_absolute_error: 0.0066 - val_loss: 5.7568e-04 - val_mean_absolute_error: 0.0200
# Epoch 123/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.1372e-05 - mean_absolute_error: 0.0066 - val_loss: 4.6385e-04 - val_mean_absolute_error: 0.0174
# Epoch 124/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.8890e-05 - mean_absolute_error: 0.0064 - val_loss: 2.8824e-04 - val_mean_absolute_error: 0.0126
# Epoch 125/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0001e-04 - mean_absolute_error: 0.0071 - val_loss: 1.9503e-04 - val_mean_absolute_error: 0.0101
# Epoch 126/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0811e-04 - mean_absolute_error: 0.0071 - val_loss: 1.5756e-04 - val_mean_absolute_error: 0.0092
# Epoch 127/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.6403e-05 - mean_absolute_error: 0.0064 - val_loss: 6.7381e-04 - val_mean_absolute_error: 0.0224
# Epoch 128/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.8126e-05 - mean_absolute_error: 0.0064 - val_loss: 5.0697e-04 - val_mean_absolute_error: 0.0185
# Epoch 129/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.0365e-04 - mean_absolute_error: 0.0069 - val_loss: 1.6227e-04 - val_mean_absolute_error: 0.0096
# Epoch 130/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.9084e-05 - mean_absolute_error: 0.0070 - val_loss: 2.4344e-04 - val_mean_absolute_error: 0.0115
# Epoch 131/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.6333e-05 - mean_absolute_error: 0.0064 - val_loss: 4.2227e-04 - val_mean_absolute_error: 0.0164
# Epoch 132/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.6628e-05 - mean_absolute_error: 0.0062 - val_loss: 4.0175e-04 - val_mean_absolute_error: 0.0161
# Epoch 133/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.3467e-05 - mean_absolute_error: 0.0068 - val_loss: 3.4579e-04 - val_mean_absolute_error: 0.0144
# Epoch 134/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.0155e-04 - mean_absolute_error: 0.0068 - val_loss: 2.4054e-04 - val_mean_absolute_error: 0.0114
# Epoch 135/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.6888e-05 - mean_absolute_error: 0.0063 - val_loss: 1.9651e-04 - val_mean_absolute_error: 0.0102
# Epoch 136/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.4156e-05 - mean_absolute_error: 0.0064 - val_loss: 3.5379e-04 - val_mean_absolute_error: 0.0146
# Epoch 137/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.3210e-05 - mean_absolute_error: 0.0060 - val_loss: 5.5761e-04 - val_mean_absolute_error: 0.0198
# Epoch 138/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.0724e-05 - mean_absolute_error: 0.0060 - val_loss: 7.8788e-04 - val_mean_absolute_error: 0.0247
# Epoch 139/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0011e-04 - mean_absolute_error: 0.0067 - val_loss: 2.0615e-04 - val_mean_absolute_error: 0.0104
# Epoch 140/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.0416e-05 - mean_absolute_error: 0.0068 - val_loss: 1.4622e-04 - val_mean_absolute_error: 0.0095
# Epoch 141/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.0745e-04 - mean_absolute_error: 0.0074 - val_loss: 1.5203e-04 - val_mean_absolute_error: 0.0090
# Epoch 142/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.8358e-05 - mean_absolute_error: 0.0067 - val_loss: 4.0624e-04 - val_mean_absolute_error: 0.0161
# Epoch 143/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.2976e-05 - mean_absolute_error: 0.0062 - val_loss: 4.5532e-04 - val_mean_absolute_error: 0.0174
# Epoch 144/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.8893e-05 - mean_absolute_error: 0.0063 - val_loss: 2.2196e-04 - val_mean_absolute_error: 0.0109
# Epoch 145/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.3979e-05 - mean_absolute_error: 0.0066 - val_loss: 5.2889e-04 - val_mean_absolute_error: 0.0193
# Epoch 146/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.8884e-05 - mean_absolute_error: 0.0062 - val_loss: 4.3329e-04 - val_mean_absolute_error: 0.0167
# Epoch 147/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.5754e-05 - mean_absolute_error: 0.0057 - val_loss: 1.8299e-04 - val_mean_absolute_error: 0.0097
# Epoch 148/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.8141e-05 - mean_absolute_error: 0.0059 - val_loss: 1.6793e-04 - val_mean_absolute_error: 0.0094
# Epoch 149/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.5834e-05 - mean_absolute_error: 0.0063 - val_loss: 8.9647e-04 - val_mean_absolute_error: 0.0267
# Epoch 150/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.8009e-05 - mean_absolute_error: 0.0067 - val_loss: 2.2057e-04 - val_mean_absolute_error: 0.0109
# Epoch 151/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.9803e-05 - mean_absolute_error: 0.0061 - val_loss: 1.3517e-04 - val_mean_absolute_error: 0.0091
# Epoch 152/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 8.7929e-05 - mean_absolute_error: 0.0066 - val_loss: 2.7774e-04 - val_mean_absolute_error: 0.0126
# Epoch 153/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.8235e-05 - mean_absolute_error: 0.0059 - val_loss: 4.7144e-04 - val_mean_absolute_error: 0.0178
# Epoch 154/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.9222e-05 - mean_absolute_error: 0.0056 - val_loss: 5.2097e-04 - val_mean_absolute_error: 0.0192
# Epoch 155/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.3771e-05 - mean_absolute_error: 0.0062 - val_loss: 3.5979e-04 - val_mean_absolute_error: 0.0150
# Epoch 156/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.4364e-05 - mean_absolute_error: 0.0055 - val_loss: 3.4288e-04 - val_mean_absolute_error: 0.0145
# Epoch 157/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.1736e-05 - mean_absolute_error: 0.0059 - val_loss: 1.7169e-04 - val_mean_absolute_error: 0.0096
# Epoch 158/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.9335e-05 - mean_absolute_error: 0.0070 - val_loss: 2.8475e-04 - val_mean_absolute_error: 0.0128
# Epoch 159/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.8563e-05 - mean_absolute_error: 0.0058 - val_loss: 3.2238e-04 - val_mean_absolute_error: 0.0139
# Epoch 160/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.2862e-05 - mean_absolute_error: 0.0057 - val_loss: 2.6928e-04 - val_mean_absolute_error: 0.0124
# Epoch 161/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.8959e-05 - mean_absolute_error: 0.0062 - val_loss: 6.0078e-04 - val_mean_absolute_error: 0.0212
# Epoch 162/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.4327e-05 - mean_absolute_error: 0.0065 - val_loss: 3.8221e-04 - val_mean_absolute_error: 0.0157
# Epoch 163/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.5860e-05 - mean_absolute_error: 0.0062 - val_loss: 2.5037e-04 - val_mean_absolute_error: 0.0118
# Epoch 164/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.3529e-05 - mean_absolute_error: 0.0061 - val_loss: 1.3825e-04 - val_mean_absolute_error: 0.0094
# Epoch 165/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.5117e-05 - mean_absolute_error: 0.0065 - val_loss: 1.7694e-04 - val_mean_absolute_error: 0.0096
# Epoch 166/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.0459e-05 - mean_absolute_error: 0.0055 - val_loss: 2.0565e-04 - val_mean_absolute_error: 0.0104
# Epoch 167/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.3400e-05 - mean_absolute_error: 0.0063 - val_loss: 1.5139e-04 - val_mean_absolute_error: 0.0088
# Epoch 168/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.6694e-05 - mean_absolute_error: 0.0055 - val_loss: 3.0693e-04 - val_mean_absolute_error: 0.0134
# Epoch 169/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.0107e-05 - mean_absolute_error: 0.0056 - val_loss: 1.9420e-04 - val_mean_absolute_error: 0.0101
# Epoch 170/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.3963e-05 - mean_absolute_error: 0.0057 - val_loss: 2.8861e-04 - val_mean_absolute_error: 0.0128
# Epoch 171/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.1797e-05 - mean_absolute_error: 0.0055 - val_loss: 7.1947e-04 - val_mean_absolute_error: 0.0236
# Epoch 172/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.1080e-04 - mean_absolute_error: 0.0074 - val_loss: 2.6221e-04 - val_mean_absolute_error: 0.0123
# Epoch 173/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.3124e-05 - mean_absolute_error: 0.0059 - val_loss: 2.4735e-04 - val_mean_absolute_error: 0.0117
# Epoch 174/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 7.5110e-05 - mean_absolute_error: 0.0056 - val_loss: 1.6983e-04 - val_mean_absolute_error: 0.0094
# Epoch 175/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.7050e-05 - mean_absolute_error: 0.0060 - val_loss: 1.5210e-04 - val_mean_absolute_error: 0.0089
# Epoch 176/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.1562e-05 - mean_absolute_error: 0.0059 - val_loss: 4.2119e-04 - val_mean_absolute_error: 0.0168
# Epoch 177/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.4083e-05 - mean_absolute_error: 0.0053 - val_loss: 1.5008e-04 - val_mean_absolute_error: 0.0090
# Epoch 178/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.8574e-05 - mean_absolute_error: 0.0060 - val_loss: 1.7056e-04 - val_mean_absolute_error: 0.0094
# Epoch 179/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 8.4381e-05 - mean_absolute_error: 0.0063 - val_loss: 4.7965e-04 - val_mean_absolute_error: 0.0182
# Epoch 180/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.6614e-05 - mean_absolute_error: 0.0065 - val_loss: 6.2278e-04 - val_mean_absolute_error: 0.0217
# Epoch 181/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.8271e-05 - mean_absolute_error: 0.0060 - val_loss: 2.2271e-04 - val_mean_absolute_error: 0.0109
# Epoch 182/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.1903e-05 - mean_absolute_error: 0.0052 - val_loss: 2.8567e-04 - val_mean_absolute_error: 0.0127
# Epoch 183/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.8678e-05 - mean_absolute_error: 0.0062 - val_loss: 5.9100e-04 - val_mean_absolute_error: 0.0208
# Epoch 184/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.6595e-05 - mean_absolute_error: 0.0059 - val_loss: 2.9713e-04 - val_mean_absolute_error: 0.0129
# Epoch 185/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.2058e-05 - mean_absolute_error: 0.0054 - val_loss: 1.6562e-04 - val_mean_absolute_error: 0.0092
# Epoch 186/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.4631e-05 - mean_absolute_error: 0.0055 - val_loss: 1.9102e-04 - val_mean_absolute_error: 0.0098
# Epoch 187/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.3242e-05 - mean_absolute_error: 0.0053 - val_loss: 3.1187e-04 - val_mean_absolute_error: 0.0132
# Epoch 188/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.7109e-05 - mean_absolute_error: 0.0049 - val_loss: 2.9973e-04 - val_mean_absolute_error: 0.0129
# Epoch 189/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.0102e-05 - mean_absolute_error: 0.0055 - val_loss: 4.3365e-04 - val_mean_absolute_error: 0.0170
# Epoch 190/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.2104e-05 - mean_absolute_error: 0.0052 - val_loss: 3.5777e-04 - val_mean_absolute_error: 0.0151
# Epoch 191/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.2130e-05 - mean_absolute_error: 0.0053 - val_loss: 3.1615e-04 - val_mean_absolute_error: 0.0137
# Epoch 192/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.3886e-05 - mean_absolute_error: 0.0060 - val_loss: 1.4101e-04 - val_mean_absolute_error: 0.0089
# Epoch 193/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.6001e-05 - mean_absolute_error: 0.0070 - val_loss: 2.4377e-04 - val_mean_absolute_error: 0.0114
# Epoch 194/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.6638e-05 - mean_absolute_error: 0.0055 - val_loss: 3.8525e-04 - val_mean_absolute_error: 0.0159
# Epoch 195/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.1272e-05 - mean_absolute_error: 0.0051 - val_loss: 2.2583e-04 - val_mean_absolute_error: 0.0108
# Epoch 196/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7847e-05 - mean_absolute_error: 0.0054 - val_loss: 1.4730e-04 - val_mean_absolute_error: 0.0089
# Epoch 197/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.4171e-05 - mean_absolute_error: 0.0057 - val_loss: 2.9717e-04 - val_mean_absolute_error: 0.0131
# Epoch 198/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.0424e-05 - mean_absolute_error: 0.0053 - val_loss: 3.5621e-04 - val_mean_absolute_error: 0.0147
# Epoch 199/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.5209e-05 - mean_absolute_error: 0.0052 - val_loss: 2.0176e-04 - val_mean_absolute_error: 0.0099
# Epoch 200/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.5787e-05 - mean_absolute_error: 0.0062 - val_loss: 6.7170e-04 - val_mean_absolute_error: 0.0225

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 1s 646ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9860e-04 - mean_absolute_error: 0.0193
# Test Loss: [0.0006716957432217896, 0.022542109712958336]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 120
# 131

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 11734961.003394064
# RMSE: 3425.6329347135347
# MAE: 2921.815950520833
# MAPE: 3.3583909844050046 %
#
# Model evalution on validate set
# MSE: 53331614.06883706
# RMSE: 7302.849722460202
# MAE: 6409.627647210744
# MAPE: 5.648054386617376 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 987ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step

# %%
y_pred_30_days
# Out:
# array([[129507.805],
#        [133460.17 ],
#        [129146.08 ],
#        [133941.66 ],
#        [128757.23 ],
#        [134328.77 ],
#        [128296.984],
#        [134799.22 ],
#        [127766.7  ],
#        [135340.33 ],
#        [127150.36 ],
#        [135962.02 ],
#        [126437.086],
#        [136672.42 ],
#        [125615.305],
#        [137478.6  ],
#        [124674.37 ],
#        [138385.16 ],
#        [123606.016],
#        [139392.78 ],
#        [122406.56 ],
#        [140496.02 ],
#        [121079.75 ],
#        [141681.1  ],
#        [119639.984],
#        [142924.44 ],
#        [118114.91 ],
#        [144192.22 ],
#        [116546.62 ],
#        [145442.34 ],
#        [114989.375]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
