# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: FPT - Test/Train/Vaildation: 80/10/10
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1224.22
# - MAE: 918.34
# - MAPE: 1.22 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 2  # 8 1 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df
# Out:
#              close
# time
# 2019-03-01   19270
# 2019-03-04   19440
# 2019-03-05   19390
# 2019-03-06   19270
# 2019-03-07   19330
# ...            ...
# 2024-02-26  108000
# 2024-02-27  107900
# 2024-02-28  108500
# 2024-02-29  109000
# 2024-03-01  110800
#
# [1252 rows x 1 columns]

# %%
df.shape
# Out:
# (1252, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1247    108000
# 1248    107900
# 1249    108500
# 1250    109000
# 1251    110800
# Name: close, Length: 1252, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((990, 10), (990,), (114, 10), (114,), (115, 10), (115,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0403 - mean_absolute_error: 0.1454 - val_loss: 0.0036 - val_mean_absolute_error: 0.0553
# Epoch 2/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0287 - val_loss: 2.6338e-04 - val_mean_absolute_error: 0.0126
# Epoch 3/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1968e-04 - mean_absolute_error: 0.0144 - val_loss: 3.8058e-04 - val_mean_absolute_error: 0.0139
# Epoch 4/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1302e-04 - mean_absolute_error: 0.0134 - val_loss: 4.0409e-04 - val_mean_absolute_error: 0.0144
# Epoch 5/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3927e-04 - mean_absolute_error: 0.0139 - val_loss: 3.0382e-04 - val_mean_absolute_error: 0.0127
# Epoch 6/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8794e-04 - mean_absolute_error: 0.0135 - val_loss: 4.1925e-04 - val_mean_absolute_error: 0.0145
# Epoch 7/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2503e-04 - mean_absolute_error: 0.0135 - val_loss: 5.3164e-04 - val_mean_absolute_error: 0.0166
# Epoch 8/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1311e-04 - mean_absolute_error: 0.0137 - val_loss: 5.1798e-04 - val_mean_absolute_error: 0.0163
# Epoch 9/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0811e-04 - mean_absolute_error: 0.0135 - val_loss: 8.6934e-04 - val_mean_absolute_error: 0.0228
# Epoch 10/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5671e-04 - mean_absolute_error: 0.0128 - val_loss: 4.6692e-04 - val_mean_absolute_error: 0.0152
# Epoch 11/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9073e-04 - mean_absolute_error: 0.0128 - val_loss: 6.1869e-04 - val_mean_absolute_error: 0.0179
# Epoch 12/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3139e-04 - mean_absolute_error: 0.0123 - val_loss: 3.4978e-04 - val_mean_absolute_error: 0.0138
# Epoch 13/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5629e-04 - mean_absolute_error: 0.0134 - val_loss: 4.9418e-04 - val_mean_absolute_error: 0.0155
# Epoch 14/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6897e-04 - mean_absolute_error: 0.0127 - val_loss: 5.5526e-04 - val_mean_absolute_error: 0.0166
# Epoch 15/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2154e-04 - mean_absolute_error: 0.0138 - val_loss: 9.6198e-04 - val_mean_absolute_error: 0.0241
# Epoch 16/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9972e-04 - mean_absolute_error: 0.0130 - val_loss: 5.9118e-04 - val_mean_absolute_error: 0.0172
# Epoch 17/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6406e-04 - mean_absolute_error: 0.0124 - val_loss: 7.9632e-04 - val_mean_absolute_error: 0.0210
# Epoch 18/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6565e-04 - mean_absolute_error: 0.0129 - val_loss: 6.4960e-04 - val_mean_absolute_error: 0.0182
# Epoch 19/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1885e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0012 - val_mean_absolute_error: 0.0276
# Epoch 20/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5389e-04 - mean_absolute_error: 0.0131 - val_loss: 5.5852e-04 - val_mean_absolute_error: 0.0165
# Epoch 21/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4421e-04 - mean_absolute_error: 0.0124 - val_loss: 5.3159e-04 - val_mean_absolute_error: 0.0161
# Epoch 22/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1759e-04 - mean_absolute_error: 0.0123 - val_loss: 6.3801e-04 - val_mean_absolute_error: 0.0179
# Epoch 23/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0314e-04 - mean_absolute_error: 0.0141 - val_loss: 7.3955e-04 - val_mean_absolute_error: 0.0198
# Epoch 24/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3443e-04 - mean_absolute_error: 0.0129 - val_loss: 7.5847e-04 - val_mean_absolute_error: 0.0202
# Epoch 25/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8081e-04 - mean_absolute_error: 0.0133 - val_loss: 8.2138e-04 - val_mean_absolute_error: 0.0213
# Epoch 26/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3949e-04 - mean_absolute_error: 0.0123 - val_loss: 5.5208e-04 - val_mean_absolute_error: 0.0164
# Epoch 27/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5048e-04 - mean_absolute_error: 0.0127 - val_loss: 4.2323e-04 - val_mean_absolute_error: 0.0177
# Epoch 28/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0296e-04 - mean_absolute_error: 0.0142 - val_loss: 3.6602e-04 - val_mean_absolute_error: 0.0156
# Epoch 29/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7305e-04 - mean_absolute_error: 0.0138 - val_loss: 3.6354e-04 - val_mean_absolute_error: 0.0139
# Epoch 30/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7886e-04 - mean_absolute_error: 0.0132 - val_loss: 5.6269e-04 - val_mean_absolute_error: 0.0167
# Epoch 31/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0259e-04 - mean_absolute_error: 0.0118 - val_loss: 7.3548e-04 - val_mean_absolute_error: 0.0199
# Epoch 32/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1349e-04 - mean_absolute_error: 0.0120 - val_loss: 4.0786e-04 - val_mean_absolute_error: 0.0141
# Epoch 33/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1477e-04 - mean_absolute_error: 0.0121 - val_loss: 7.0149e-04 - val_mean_absolute_error: 0.0194
# Epoch 34/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5555e-04 - mean_absolute_error: 0.0126 - val_loss: 8.2323e-04 - val_mean_absolute_error: 0.0220
# Epoch 35/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8656e-04 - mean_absolute_error: 0.0117 - val_loss: 4.3022e-04 - val_mean_absolute_error: 0.0143
# Epoch 36/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6412e-04 - mean_absolute_error: 0.0132 - val_loss: 3.7894e-04 - val_mean_absolute_error: 0.0137
# Epoch 37/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0823e-04 - mean_absolute_error: 0.0121 - val_loss: 4.4736e-04 - val_mean_absolute_error: 0.0147
# Epoch 38/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1075e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0011 - val_mean_absolute_error: 0.0266
# Epoch 39/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1361e-04 - mean_absolute_error: 0.0123 - val_loss: 3.7982e-04 - val_mean_absolute_error: 0.0135
# Epoch 40/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9945e-04 - mean_absolute_error: 0.0118 - val_loss: 5.1934e-04 - val_mean_absolute_error: 0.0161
# Epoch 41/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9824e-04 - mean_absolute_error: 0.0116 - val_loss: 6.5453e-04 - val_mean_absolute_error: 0.0189
# Epoch 42/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2807e-04 - mean_absolute_error: 0.0127 - val_loss: 7.5118e-04 - val_mean_absolute_error: 0.0206
# Epoch 43/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6509e-04 - mean_absolute_error: 0.0112 - val_loss: 4.0152e-04 - val_mean_absolute_error: 0.0138
# Epoch 44/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6963e-04 - mean_absolute_error: 0.0115 - val_loss: 3.6055e-04 - val_mean_absolute_error: 0.0131
# Epoch 45/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9272e-04 - mean_absolute_error: 0.0116 - val_loss: 5.3646e-04 - val_mean_absolute_error: 0.0167
# Epoch 46/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9557e-04 - mean_absolute_error: 0.0142 - val_loss: 8.4871e-04 - val_mean_absolute_error: 0.0233
# Epoch 47/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9264e-04 - mean_absolute_error: 0.0121 - val_loss: 3.6515e-04 - val_mean_absolute_error: 0.0131
# Epoch 48/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7031e-04 - mean_absolute_error: 0.0108 - val_loss: 4.4460e-04 - val_mean_absolute_error: 0.0147
# Epoch 49/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2959e-04 - mean_absolute_error: 0.0102 - val_loss: 5.6413e-04 - val_mean_absolute_error: 0.0174
# Epoch 50/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2787e-04 - mean_absolute_error: 0.0103 - val_loss: 3.6853e-04 - val_mean_absolute_error: 0.0131
# Epoch 51/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5148e-04 - mean_absolute_error: 0.0107 - val_loss: 5.3254e-04 - val_mean_absolute_error: 0.0169
# Epoch 52/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4885e-04 - mean_absolute_error: 0.0107 - val_loss: 4.0682e-04 - val_mean_absolute_error: 0.0140
# Epoch 53/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7410e-04 - mean_absolute_error: 0.0112 - val_loss: 3.5779e-04 - val_mean_absolute_error: 0.0130
# Epoch 54/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4081e-04 - mean_absolute_error: 0.0128 - val_loss: 8.5499e-04 - val_mean_absolute_error: 0.0241
# Epoch 55/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5625e-04 - mean_absolute_error: 0.0113 - val_loss: 5.9946e-04 - val_mean_absolute_error: 0.0188
# Epoch 56/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3521e-04 - mean_absolute_error: 0.0104 - val_loss: 3.0061e-04 - val_mean_absolute_error: 0.0118
# Epoch 57/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2007e-04 - mean_absolute_error: 0.0099 - val_loss: 2.2169e-04 - val_mean_absolute_error: 0.0108
# Epoch 58/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1081e-04 - mean_absolute_error: 0.0102 - val_loss: 2.9018e-04 - val_mean_absolute_error: 0.0115
# Epoch 59/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2810e-04 - mean_absolute_error: 0.0099 - val_loss: 7.1420e-04 - val_mean_absolute_error: 0.0212
# Epoch 60/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1876e-04 - mean_absolute_error: 0.0101 - val_loss: 3.3333e-04 - val_mean_absolute_error: 0.0125
# Epoch 61/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2635e-04 - mean_absolute_error: 0.0105 - val_loss: 2.3995e-04 - val_mean_absolute_error: 0.0105
# Epoch 62/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0538e-04 - mean_absolute_error: 0.0098 - val_loss: 1.9105e-04 - val_mean_absolute_error: 0.0106
# Epoch 63/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9823e-04 - mean_absolute_error: 0.0098 - val_loss: 3.5914e-04 - val_mean_absolute_error: 0.0170
# Epoch 64/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9252e-04 - mean_absolute_error: 0.0125 - val_loss: 4.6726e-04 - val_mean_absolute_error: 0.0162
# Epoch 65/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1890e-04 - mean_absolute_error: 0.0099 - val_loss: 2.1362e-04 - val_mean_absolute_error: 0.0120
# Epoch 66/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6402e-04 - mean_absolute_error: 0.0114 - val_loss: 3.7181e-04 - val_mean_absolute_error: 0.0138
# Epoch 67/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9435e-04 - mean_absolute_error: 0.0095 - val_loss: 2.1562e-04 - val_mean_absolute_error: 0.0101
# Epoch 68/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2789e-04 - mean_absolute_error: 0.0104 - val_loss: 2.0640e-04 - val_mean_absolute_error: 0.0101
# Epoch 69/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2340e-04 - mean_absolute_error: 0.0102 - val_loss: 5.6827e-04 - val_mean_absolute_error: 0.0189
# Epoch 70/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5481e-04 - mean_absolute_error: 0.0113 - val_loss: 2.2201e-04 - val_mean_absolute_error: 0.0100
# Epoch 71/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4652e-04 - mean_absolute_error: 0.0105 - val_loss: 2.0882e-04 - val_mean_absolute_error: 0.0098
# Epoch 72/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4500e-04 - mean_absolute_error: 0.0109 - val_loss: 2.0655e-04 - val_mean_absolute_error: 0.0098
# Epoch 73/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0416e-04 - mean_absolute_error: 0.0099 - val_loss: 4.4832e-04 - val_mean_absolute_error: 0.0161
# Epoch 74/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9699e-04 - mean_absolute_error: 0.0099 - val_loss: 2.7280e-04 - val_mean_absolute_error: 0.0111
# Epoch 75/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1565e-04 - mean_absolute_error: 0.0099 - val_loss: 2.7897e-04 - val_mean_absolute_error: 0.0112
# Epoch 76/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8369e-04 - mean_absolute_error: 0.0093 - val_loss: 6.7802e-04 - val_mean_absolute_error: 0.0215
# Epoch 77/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1965e-04 - mean_absolute_error: 0.0106 - val_loss: 2.5044e-04 - val_mean_absolute_error: 0.0136
# Epoch 78/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2533e-04 - mean_absolute_error: 0.0107 - val_loss: 4.5902e-04 - val_mean_absolute_error: 0.0164
# Epoch 79/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1781e-04 - mean_absolute_error: 0.0101 - val_loss: 2.4551e-04 - val_mean_absolute_error: 0.0136
# Epoch 80/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6167e-04 - mean_absolute_error: 0.0114 - val_loss: 1.8246e-04 - val_mean_absolute_error: 0.0108
# Epoch 81/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4350e-04 - mean_absolute_error: 0.0108 - val_loss: 3.4445e-04 - val_mean_absolute_error: 0.0136
# Epoch 82/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2925e-04 - mean_absolute_error: 0.0099 - val_loss: 4.1881e-04 - val_mean_absolute_error: 0.0156
# Epoch 83/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2063e-04 - mean_absolute_error: 0.0101 - val_loss: 1.6504e-04 - val_mean_absolute_error: 0.0093
# Epoch 84/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7363e-04 - mean_absolute_error: 0.0089 - val_loss: 1.9095e-04 - val_mean_absolute_error: 0.0094
# Epoch 85/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8681e-04 - mean_absolute_error: 0.0093 - val_loss: 2.8098e-04 - val_mean_absolute_error: 0.0116
# Epoch 86/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9065e-04 - mean_absolute_error: 0.0092 - val_loss: 2.3159e-04 - val_mean_absolute_error: 0.0102
# Epoch 87/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9933e-04 - mean_absolute_error: 0.0099 - val_loss: 1.8657e-04 - val_mean_absolute_error: 0.0092
# Epoch 88/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7010e-04 - mean_absolute_error: 0.0090 - val_loss: 5.9012e-04 - val_mean_absolute_error: 0.0200
# Epoch 89/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8536e-04 - mean_absolute_error: 0.0097 - val_loss: 1.5916e-04 - val_mean_absolute_error: 0.0092
# Epoch 90/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8688e-04 - mean_absolute_error: 0.0095 - val_loss: 1.5833e-04 - val_mean_absolute_error: 0.0091
# Epoch 91/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8707e-04 - mean_absolute_error: 0.0095 - val_loss: 1.7685e-04 - val_mean_absolute_error: 0.0089
# Epoch 92/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7396e-04 - mean_absolute_error: 0.0091 - val_loss: 2.4987e-04 - val_mean_absolute_error: 0.0110
# Epoch 93/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6200e-04 - mean_absolute_error: 0.0085 - val_loss: 7.7557e-04 - val_mean_absolute_error: 0.0241
# Epoch 94/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2682e-04 - mean_absolute_error: 0.0107 - val_loss: 1.7754e-04 - val_mean_absolute_error: 0.0109
# Epoch 95/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0753e-04 - mean_absolute_error: 0.0102 - val_loss: 3.5399e-04 - val_mean_absolute_error: 0.0141
# Epoch 96/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7778e-04 - mean_absolute_error: 0.0091 - val_loss: 3.0699e-04 - val_mean_absolute_error: 0.0126
# Epoch 97/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6515e-04 - mean_absolute_error: 0.0087 - val_loss: 4.5790e-04 - val_mean_absolute_error: 0.0171
# Epoch 98/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0556e-04 - mean_absolute_error: 0.0097 - val_loss: 2.2666e-04 - val_mean_absolute_error: 0.0103
# Epoch 99/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8402e-04 - mean_absolute_error: 0.0090 - val_loss: 3.0742e-04 - val_mean_absolute_error: 0.0128
# Epoch 100/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8274e-04 - mean_absolute_error: 0.0089 - val_loss: 1.3992e-04 - val_mean_absolute_error: 0.0085
# Epoch 101/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9182e-04 - mean_absolute_error: 0.0093 - val_loss: 2.1603e-04 - val_mean_absolute_error: 0.0099
# Epoch 102/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5833e-04 - mean_absolute_error: 0.0085 - val_loss: 2.0254e-04 - val_mean_absolute_error: 0.0094
# Epoch 103/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5637e-04 - mean_absolute_error: 0.0087 - val_loss: 1.5142e-04 - val_mean_absolute_error: 0.0086
# Epoch 104/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9045e-04 - mean_absolute_error: 0.0094 - val_loss: 1.5717e-04 - val_mean_absolute_error: 0.0084
# Epoch 105/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6118e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2856e-04 - val_mean_absolute_error: 0.0084
# Epoch 106/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5619e-04 - mean_absolute_error: 0.0086 - val_loss: 3.3215e-04 - val_mean_absolute_error: 0.0139
# Epoch 107/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2277e-04 - mean_absolute_error: 0.0101 - val_loss: 1.3920e-04 - val_mean_absolute_error: 0.0087
# Epoch 108/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8975e-04 - mean_absolute_error: 0.0094 - val_loss: 1.9609e-04 - val_mean_absolute_error: 0.0095
# Epoch 109/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5902e-04 - mean_absolute_error: 0.0085 - val_loss: 1.6269e-04 - val_mean_absolute_error: 0.0105
# Epoch 110/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7302e-04 - mean_absolute_error: 0.0091 - val_loss: 3.1328e-04 - val_mean_absolute_error: 0.0132
# Epoch 111/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6500e-04 - mean_absolute_error: 0.0087 - val_loss: 2.1476e-04 - val_mean_absolute_error: 0.0101
# Epoch 112/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8134e-04 - mean_absolute_error: 0.0088 - val_loss: 1.5749e-04 - val_mean_absolute_error: 0.0102
# Epoch 113/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0692e-04 - mean_absolute_error: 0.0100 - val_loss: 3.1025e-04 - val_mean_absolute_error: 0.0134
# Epoch 114/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1099e-04 - mean_absolute_error: 0.0100 - val_loss: 2.4696e-04 - val_mean_absolute_error: 0.0113
# Epoch 115/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7299e-04 - mean_absolute_error: 0.0092 - val_loss: 1.4463e-04 - val_mean_absolute_error: 0.0096
# Epoch 116/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8882e-04 - mean_absolute_error: 0.0093 - val_loss: 2.5914e-04 - val_mean_absolute_error: 0.0117
# Epoch 117/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5014e-04 - mean_absolute_error: 0.0085 - val_loss: 1.4697e-04 - val_mean_absolute_error: 0.0081
# Epoch 118/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4381e-04 - mean_absolute_error: 0.0082 - val_loss: 4.3044e-04 - val_mean_absolute_error: 0.0170
# Epoch 119/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6036e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7036e-04 - val_mean_absolute_error: 0.0120
# Epoch 120/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4607e-04 - mean_absolute_error: 0.0084 - val_loss: 1.6179e-04 - val_mean_absolute_error: 0.0085
# Epoch 121/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8169e-04 - mean_absolute_error: 0.0093 - val_loss: 2.6218e-04 - val_mean_absolute_error: 0.0117
# Epoch 122/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5841e-04 - mean_absolute_error: 0.0084 - val_loss: 1.7166e-04 - val_mean_absolute_error: 0.0087
# Epoch 123/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4942e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2320e-04 - val_mean_absolute_error: 0.0079
# Epoch 124/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6052e-04 - mean_absolute_error: 0.0082 - val_loss: 1.7354e-04 - val_mean_absolute_error: 0.0088
# Epoch 125/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3920e-04 - mean_absolute_error: 0.0080 - val_loss: 1.7241e-04 - val_mean_absolute_error: 0.0088
# Epoch 126/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4949e-04 - mean_absolute_error: 0.0085 - val_loss: 3.3750e-04 - val_mean_absolute_error: 0.0144
# Epoch 127/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8411e-04 - mean_absolute_error: 0.0088 - val_loss: 1.4216e-04 - val_mean_absolute_error: 0.0079
# Epoch 128/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3529e-04 - mean_absolute_error: 0.0082 - val_loss: 2.4500e-04 - val_mean_absolute_error: 0.0112
# Epoch 129/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4497e-04 - mean_absolute_error: 0.0083 - val_loss: 1.1753e-04 - val_mean_absolute_error: 0.0079
# Epoch 130/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4681e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2434e-04 - val_mean_absolute_error: 0.0078
# Epoch 131/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5435e-04 - mean_absolute_error: 0.0083 - val_loss: 1.7110e-04 - val_mean_absolute_error: 0.0088
# Epoch 132/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3155e-04 - mean_absolute_error: 0.0077 - val_loss: 1.1694e-04 - val_mean_absolute_error: 0.0079
# Epoch 133/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3967e-04 - mean_absolute_error: 0.0079 - val_loss: 4.8538e-04 - val_mean_absolute_error: 0.0189
# Epoch 134/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9306e-04 - mean_absolute_error: 0.0095 - val_loss: 1.1519e-04 - val_mean_absolute_error: 0.0076
# Epoch 135/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3439e-04 - mean_absolute_error: 0.0081 - val_loss: 1.4886e-04 - val_mean_absolute_error: 0.0080
# Epoch 136/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3839e-04 - mean_absolute_error: 0.0077 - val_loss: 2.9466e-04 - val_mean_absolute_error: 0.0132
# Epoch 137/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6240e-04 - mean_absolute_error: 0.0081 - val_loss: 2.4052e-04 - val_mean_absolute_error: 0.0114
# Epoch 138/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4696e-04 - mean_absolute_error: 0.0084 - val_loss: 1.1493e-04 - val_mean_absolute_error: 0.0080
# Epoch 139/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6518e-04 - mean_absolute_error: 0.0092 - val_loss: 1.7174e-04 - val_mean_absolute_error: 0.0087
# Epoch 140/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4462e-04 - mean_absolute_error: 0.0085 - val_loss: 2.2089e-04 - val_mean_absolute_error: 0.0106
# Epoch 141/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6545e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2873e-04 - val_mean_absolute_error: 0.0092
# Epoch 142/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9685e-04 - mean_absolute_error: 0.0095 - val_loss: 3.1989e-04 - val_mean_absolute_error: 0.0143
# Epoch 143/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6184e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2664e-04 - val_mean_absolute_error: 0.0091
# Epoch 144/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8549e-04 - mean_absolute_error: 0.0097 - val_loss: 1.8821e-04 - val_mean_absolute_error: 0.0094
# Epoch 145/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4798e-04 - mean_absolute_error: 0.0083 - val_loss: 2.7295e-04 - val_mean_absolute_error: 0.0125
# Epoch 146/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1992e-04 - mean_absolute_error: 0.0076 - val_loss: 4.8471e-04 - val_mean_absolute_error: 0.0186
# Epoch 147/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3182e-04 - mean_absolute_error: 0.0081 - val_loss: 1.7259e-04 - val_mean_absolute_error: 0.0088
# Epoch 148/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2538e-04 - mean_absolute_error: 0.0074 - val_loss: 1.8777e-04 - val_mean_absolute_error: 0.0095
# Epoch 149/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3891e-04 - mean_absolute_error: 0.0082 - val_loss: 1.1877e-04 - val_mean_absolute_error: 0.0088
# Epoch 150/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3583e-04 - mean_absolute_error: 0.0081 - val_loss: 3.4572e-04 - val_mean_absolute_error: 0.0151
# Epoch 151/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2027e-04 - mean_absolute_error: 0.0076 - val_loss: 1.1729e-04 - val_mean_absolute_error: 0.0076
# Epoch 152/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5410e-04 - mean_absolute_error: 0.0081 - val_loss: 2.9220e-04 - val_mean_absolute_error: 0.0132
# Epoch 153/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2629e-04 - mean_absolute_error: 0.0071 - val_loss: 1.3160e-04 - val_mean_absolute_error: 0.0076
# Epoch 154/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2633e-04 - mean_absolute_error: 0.0072 - val_loss: 1.1071e-04 - val_mean_absolute_error: 0.0083
# Epoch 155/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3208e-04 - mean_absolute_error: 0.0076 - val_loss: 1.7012e-04 - val_mean_absolute_error: 0.0087
# Epoch 156/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2565e-04 - mean_absolute_error: 0.0074 - val_loss: 1.8607e-04 - val_mean_absolute_error: 0.0096
# Epoch 157/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0570e-04 - mean_absolute_error: 0.0068 - val_loss: 1.0310e-04 - val_mean_absolute_error: 0.0073
# Epoch 158/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2260e-04 - mean_absolute_error: 0.0076 - val_loss: 1.0217e-04 - val_mean_absolute_error: 0.0074
# Epoch 159/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8348e-04 - mean_absolute_error: 0.0091 - val_loss: 1.9566e-04 - val_mean_absolute_error: 0.0099
# Epoch 160/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1983e-04 - mean_absolute_error: 0.0073 - val_loss: 1.8769e-04 - val_mean_absolute_error: 0.0096
# Epoch 161/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3680e-04 - mean_absolute_error: 0.0079 - val_loss: 1.2767e-04 - val_mean_absolute_error: 0.0074
# Epoch 162/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4500e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2695e-04 - val_mean_absolute_error: 0.0075
# Epoch 163/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2496e-04 - mean_absolute_error: 0.0073 - val_loss: 2.0400e-04 - val_mean_absolute_error: 0.0102
# Epoch 164/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1487e-04 - mean_absolute_error: 0.0071 - val_loss: 1.0492e-04 - val_mean_absolute_error: 0.0080
# Epoch 165/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1663e-04 - mean_absolute_error: 0.0074 - val_loss: 1.3549e-04 - val_mean_absolute_error: 0.0076
# Epoch 166/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4035e-04 - mean_absolute_error: 0.0080 - val_loss: 1.1114e-04 - val_mean_absolute_error: 0.0072
# Epoch 167/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3310e-04 - mean_absolute_error: 0.0075 - val_loss: 1.0273e-04 - val_mean_absolute_error: 0.0079
# Epoch 168/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2232e-04 - mean_absolute_error: 0.0075 - val_loss: 3.1335e-04 - val_mean_absolute_error: 0.0143
# Epoch 169/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3056e-04 - mean_absolute_error: 0.0076 - val_loss: 1.7199e-04 - val_mean_absolute_error: 0.0089
# Epoch 170/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0131e-04 - mean_absolute_error: 0.0068 - val_loss: 1.1117e-04 - val_mean_absolute_error: 0.0084
# Epoch 171/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6746e-04 - mean_absolute_error: 0.0093 - val_loss: 2.3622e-04 - val_mean_absolute_error: 0.0118
# Epoch 172/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1366e-04 - mean_absolute_error: 0.0070 - val_loss: 2.3289e-04 - val_mean_absolute_error: 0.0116
# Epoch 173/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4094e-04 - mean_absolute_error: 0.0078 - val_loss: 3.3474e-04 - val_mean_absolute_error: 0.0148
# Epoch 174/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1780e-04 - mean_absolute_error: 0.0075 - val_loss: 1.1849e-04 - val_mean_absolute_error: 0.0072
# Epoch 175/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1151e-04 - mean_absolute_error: 0.0069 - val_loss: 1.1479e-04 - val_mean_absolute_error: 0.0089
# Epoch 176/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3928e-04 - mean_absolute_error: 0.0081 - val_loss: 9.2547e-05 - val_mean_absolute_error: 0.0075
# Epoch 177/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5259e-04 - mean_absolute_error: 0.0089 - val_loss: 2.8805e-04 - val_mean_absolute_error: 0.0136
# Epoch 178/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0928e-04 - mean_absolute_error: 0.0102 - val_loss: 9.4905e-05 - val_mean_absolute_error: 0.0072
# Epoch 179/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4266e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2103e-04 - val_mean_absolute_error: 0.0072
# Epoch 180/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7103e-04 - mean_absolute_error: 0.0091 - val_loss: 1.0346e-04 - val_mean_absolute_error: 0.0067
# Epoch 181/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3274e-04 - mean_absolute_error: 0.0076 - val_loss: 1.9085e-04 - val_mean_absolute_error: 0.0101
# Epoch 182/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3666e-04 - mean_absolute_error: 0.0077 - val_loss: 9.9514e-05 - val_mean_absolute_error: 0.0067
# Epoch 183/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3122e-04 - mean_absolute_error: 0.0073 - val_loss: 9.3224e-05 - val_mean_absolute_error: 0.0068
# Epoch 184/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4821e-04 - mean_absolute_error: 0.0086 - val_loss: 1.7947e-04 - val_mean_absolute_error: 0.0117
# Epoch 185/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7731e-04 - mean_absolute_error: 0.0091 - val_loss: 1.8998e-04 - val_mean_absolute_error: 0.0100
# Epoch 186/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3315e-04 - mean_absolute_error: 0.0074 - val_loss: 1.5348e-04 - val_mean_absolute_error: 0.0084
# Epoch 187/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3067e-04 - mean_absolute_error: 0.0075 - val_loss: 8.9865e-05 - val_mean_absolute_error: 0.0068
# Epoch 188/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1769e-04 - mean_absolute_error: 0.0072 - val_loss: 1.8340e-04 - val_mean_absolute_error: 0.0097
# Epoch 189/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.9351e-05 - mean_absolute_error: 0.0068 - val_loss: 9.9231e-05 - val_mean_absolute_error: 0.0066
# Epoch 190/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1254e-04 - mean_absolute_error: 0.0068 - val_loss: 1.1995e-04 - val_mean_absolute_error: 0.0071
# Epoch 191/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3706e-04 - mean_absolute_error: 0.0079 - val_loss: 2.1497e-04 - val_mean_absolute_error: 0.0112
# Epoch 192/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0911e-04 - mean_absolute_error: 0.0070 - val_loss: 2.2278e-04 - val_mean_absolute_error: 0.0114
# Epoch 193/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2188e-04 - mean_absolute_error: 0.0074 - val_loss: 1.8934e-04 - val_mean_absolute_error: 0.0100
# Epoch 194/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6554e-04 - mean_absolute_error: 0.0092 - val_loss: 1.6111e-04 - val_mean_absolute_error: 0.0088
# Epoch 195/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4092e-04 - mean_absolute_error: 0.0079 - val_loss: 9.7068e-05 - val_mean_absolute_error: 0.0065
# Epoch 196/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0833e-04 - mean_absolute_error: 0.0069 - val_loss: 9.8655e-05 - val_mean_absolute_error: 0.0065
# Epoch 197/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1361e-04 - mean_absolute_error: 0.0070 - val_loss: 1.4368e-04 - val_mean_absolute_error: 0.0081
# Epoch 198/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1395e-04 - mean_absolute_error: 0.0072 - val_loss: 8.9573e-05 - val_mean_absolute_error: 0.0064
# Epoch 199/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2253e-04 - mean_absolute_error: 0.0071 - val_loss: 1.8137e-04 - val_mean_absolute_error: 0.0118
# Epoch 200/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1469e-04 - mean_absolute_error: 0.0075 - val_loss: 1.1309e-04 - val_mean_absolute_error: 0.0068

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0657e-05 - mean_absolute_error: 0.0055
# Test Loss: [0.00011309165711281821, 0.006845812313258648]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 114
# 125

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 2126749.372543067
# RMSE: 1458.337880102916
# MAE: 992.5468064692982
# MAPE: 1.2807342256144554 %
#
# Model evalution on validate set
# MSE: 9459540.439299742
# RMSE: 3075.636590902726
# MAE: 2560.3124320652173
# MAPE: 2.646508384360189 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
y_pred_30_days
# Out:
# array([[107521.86 ],
#        [108186.2  ],
#        [107732.695],
#        [108005.24 ],
#        [107817.57 ],
#        [107936.125],
#        [107858.6  ],
#        [107908.34 ],
#        [107876.016],
#        [107896.89 ],
#        [107883.39 ],
#        [107892.1  ],
#        [107886.47 ],
#        [107890.12 ],
#        [107887.76 ],
#        [107889.266],
#        [107888.29 ],
#        [107888.93 ],
#        [107888.51 ],
#        [107888.805],
#        [107888.6  ],
#        [107888.74 ],
#        [107888.63 ],
#        [107888.71 ],
#        [107888.664],
#        [107888.69 ],
#        [107888.664],
#        [107888.69 ],
#        [107888.67 ],
#        [107888.69 ],
#        [107888.67 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
