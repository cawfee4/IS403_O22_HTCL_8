# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: ITD - Test/Train/Vaildation: 70/20/10
# - Dataset: 1313 rows x 7 columns (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 314.70944108378995
# - MAE: 222.1538766807769
# - MAPE: 2.0013702793154224 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 0

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170
# ...           ...
# 2024-05-27  11300
# 2024-05-28  12050
# 2024-05-29  12600
# 2024-05-30  12500
# 2024-05-31  12700
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        6900
# 1        7100
# 2        7100
# 3        7170
# 4        7170
#         ...
# 1308    11300
# 1309    12050
# 1310    12600
# 1311    12500
# 1312    12700
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((908, 10), (908,), (251, 10), (251,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 11s 70ms/step - loss: 0.0563 - mean_absolute_error: 0.1674 - val_loss: 0.0025 - val_mean_absolute_error: 0.0448
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0032 - mean_absolute_error: 0.0411 - val_loss: 5.3972e-04 - val_mean_absolute_error: 0.0167
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - mean_absolute_error: 0.0260 - val_loss: 6.6787e-04 - val_mean_absolute_error: 0.0216
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0020 - mean_absolute_error: 0.0288 - val_loss: 5.9435e-04 - val_mean_absolute_error: 0.0173
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0017 - mean_absolute_error: 0.0251 - val_loss: 5.0901e-04 - val_mean_absolute_error: 0.0165
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0015 - mean_absolute_error: 0.0243 - val_loss: 5.6963e-04 - val_mean_absolute_error: 0.0193
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0017 - mean_absolute_error: 0.0263 - val_loss: 5.7812e-04 - val_mean_absolute_error: 0.0170
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0015 - mean_absolute_error: 0.0244 - val_loss: 5.4700e-04 - val_mean_absolute_error: 0.0165
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0016 - mean_absolute_error: 0.0248 - val_loss: 4.9469e-04 - val_mean_absolute_error: 0.0171
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0015 - mean_absolute_error: 0.0243 - val_loss: 4.7438e-04 - val_mean_absolute_error: 0.0163
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0014 - mean_absolute_error: 0.0245 - val_loss: 5.1277e-04 - val_mean_absolute_error: 0.0179
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - mean_absolute_error: 0.0234 - val_loss: 5.4556e-04 - val_mean_absolute_error: 0.0188
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0013 - mean_absolute_error: 0.0226 - val_loss: 5.7338e-04 - val_mean_absolute_error: 0.0196
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0012 - mean_absolute_error: 0.0217 - val_loss: 0.0015 - val_mean_absolute_error: 0.0344
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0014 - mean_absolute_error: 0.0253 - val_loss: 4.4843e-04 - val_mean_absolute_error: 0.0151
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - mean_absolute_error: 0.0223 - val_loss: 4.7075e-04 - val_mean_absolute_error: 0.0153
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0013 - mean_absolute_error: 0.0219 - val_loss: 4.8267e-04 - val_mean_absolute_error: 0.0173
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0010 - mean_absolute_error: 0.0212 - val_loss: 4.9212e-04 - val_mean_absolute_error: 0.0176
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012 - mean_absolute_error: 0.0235 - val_loss: 4.8356e-04 - val_mean_absolute_error: 0.0174
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0010 - mean_absolute_error: 0.0211 - val_loss: 4.2697e-04 - val_mean_absolute_error: 0.0145
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.0663e-04 - mean_absolute_error: 0.0191 - val_loss: 4.0547e-04 - val_mean_absolute_error: 0.0142
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0010 - mean_absolute_error: 0.0203 - val_loss: 3.9860e-04 - val_mean_absolute_error: 0.0146
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0209 - val_loss: 4.2817e-04 - val_mean_absolute_error: 0.0158
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0010 - mean_absolute_error: 0.0202 - val_loss: 4.7560e-04 - val_mean_absolute_error: 0.0173
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0010 - mean_absolute_error: 0.0205 - val_loss: 5.3685e-04 - val_mean_absolute_error: 0.0174
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0010 - mean_absolute_error: 0.0212 - val_loss: 4.4523e-04 - val_mean_absolute_error: 0.0165
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 9.8761e-04 - mean_absolute_error: 0.0206 - val_loss: 4.1220e-04 - val_mean_absolute_error: 0.0143
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - loss: 0.0013 - mean_absolute_error: 0.0240 - val_loss: 3.6875e-04 - val_mean_absolute_error: 0.0137
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0012 - mean_absolute_error: 0.0224 - val_loss: 4.7883e-04 - val_mean_absolute_error: 0.0176
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.1152e-04 - mean_absolute_error: 0.0182 - val_loss: 3.6105e-04 - val_mean_absolute_error: 0.0135
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0010 - mean_absolute_error: 0.0196 - val_loss: 3.6073e-04 - val_mean_absolute_error: 0.0133
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.7930e-04 - mean_absolute_error: 0.0176 - val_loss: 7.2777e-04 - val_mean_absolute_error: 0.0234
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.7691e-04 - mean_absolute_error: 0.0212 - val_loss: 3.8385e-04 - val_mean_absolute_error: 0.0139
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.1431e-04 - mean_absolute_error: 0.0199 - val_loss: 4.7871e-04 - val_mean_absolute_error: 0.0163
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0010 - mean_absolute_error: 0.0207 - val_loss: 7.7076e-04 - val_mean_absolute_error: 0.0243
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.0706e-04 - mean_absolute_error: 0.0194 - val_loss: 5.3995e-04 - val_mean_absolute_error: 0.0194
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0011 - mean_absolute_error: 0.0213 - val_loss: 4.1842e-04 - val_mean_absolute_error: 0.0160
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 9.3020e-04 - mean_absolute_error: 0.0197 - val_loss: 3.7209e-04 - val_mean_absolute_error: 0.0144
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.0176e-04 - mean_absolute_error: 0.0175 - val_loss: 4.2943e-04 - val_mean_absolute_error: 0.0152
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.8019e-04 - mean_absolute_error: 0.0197 - val_loss: 3.6449e-04 - val_mean_absolute_error: 0.0135
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 7.3434e-04 - mean_absolute_error: 0.0172 - val_loss: 3.4782e-04 - val_mean_absolute_error: 0.0131
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.3406e-04 - mean_absolute_error: 0.0157 - val_loss: 3.2463e-04 - val_mean_absolute_error: 0.0128
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.6564e-04 - mean_absolute_error: 0.0157 - val_loss: 3.3125e-04 - val_mean_absolute_error: 0.0132
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.8301e-04 - mean_absolute_error: 0.0161 - val_loss: 3.2136e-04 - val_mean_absolute_error: 0.0126
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 7.2365e-04 - mean_absolute_error: 0.0171 - val_loss: 3.6541e-04 - val_mean_absolute_error: 0.0145
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.3548e-04 - mean_absolute_error: 0.0176 - val_loss: 3.3087e-04 - val_mean_absolute_error: 0.0135
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 6.4898e-04 - mean_absolute_error: 0.0164 - val_loss: 3.5530e-04 - val_mean_absolute_error: 0.0135
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 6.8241e-04 - mean_absolute_error: 0.0166 - val_loss: 3.1408e-04 - val_mean_absolute_error: 0.0129
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 6.7744e-04 - mean_absolute_error: 0.0164 - val_loss: 3.5962e-04 - val_mean_absolute_error: 0.0147
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.5835e-04 - mean_absolute_error: 0.0163 - val_loss: 3.0176e-04 - val_mean_absolute_error: 0.0121
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.3096e-04 - mean_absolute_error: 0.0161 - val_loss: 3.3771e-04 - val_mean_absolute_error: 0.0140
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.8411e-04 - mean_absolute_error: 0.0166 - val_loss: 3.0084e-04 - val_mean_absolute_error: 0.0126
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.9917e-04 - mean_absolute_error: 0.0159 - val_loss: 2.8786e-04 - val_mean_absolute_error: 0.0120
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 5.9251e-04 - mean_absolute_error: 0.0153 - val_loss: 2.8691e-04 - val_mean_absolute_error: 0.0119
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.5787e-04 - mean_absolute_error: 0.0151 - val_loss: 2.8550e-04 - val_mean_absolute_error: 0.0118
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 5.6804e-04 - mean_absolute_error: 0.0148 - val_loss: 2.8421e-04 - val_mean_absolute_error: 0.0118
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.5918e-04 - mean_absolute_error: 0.0148 - val_loss: 3.7855e-04 - val_mean_absolute_error: 0.0156
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.8253e-04 - mean_absolute_error: 0.0146 - val_loss: 3.0909e-04 - val_mean_absolute_error: 0.0133
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 5.6216e-04 - mean_absolute_error: 0.0151 - val_loss: 3.2438e-04 - val_mean_absolute_error: 0.0139
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.5431e-04 - mean_absolute_error: 0.0148 - val_loss: 2.7279e-04 - val_mean_absolute_error: 0.0119
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.4566e-04 - mean_absolute_error: 0.0147 - val_loss: 3.9810e-04 - val_mean_absolute_error: 0.0164
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.7842e-04 - mean_absolute_error: 0.0155 - val_loss: 2.6320e-04 - val_mean_absolute_error: 0.0114
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.9547e-04 - mean_absolute_error: 0.0138 - val_loss: 2.9020e-04 - val_mean_absolute_error: 0.0122
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 5.2851e-04 - mean_absolute_error: 0.0151 - val_loss: 2.7825e-04 - val_mean_absolute_error: 0.0123
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.8686e-04 - mean_absolute_error: 0.0142 - val_loss: 2.8455e-04 - val_mean_absolute_error: 0.0126
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.4141e-04 - mean_absolute_error: 0.0133 - val_loss: 3.4520e-04 - val_mean_absolute_error: 0.0139
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.2485e-04 - mean_absolute_error: 0.0163 - val_loss: 2.5631e-04 - val_mean_absolute_error: 0.0115
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.5873e-04 - mean_absolute_error: 0.0136 - val_loss: 2.6123e-04 - val_mean_absolute_error: 0.0118
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.6480e-04 - mean_absolute_error: 0.0142 - val_loss: 3.7914e-04 - val_mean_absolute_error: 0.0160
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.2849e-04 - mean_absolute_error: 0.0148 - val_loss: 3.7272e-04 - val_mean_absolute_error: 0.0158
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.4848e-04 - mean_absolute_error: 0.0158 - val_loss: 2.7207e-04 - val_mean_absolute_error: 0.0119
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.2261e-04 - mean_absolute_error: 0.0147 - val_loss: 3.0904e-04 - val_mean_absolute_error: 0.0131
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.0353e-04 - mean_absolute_error: 0.0147 - val_loss: 3.7304e-04 - val_mean_absolute_error: 0.0158
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.5366e-04 - mean_absolute_error: 0.0146 - val_loss: 2.4605e-04 - val_mean_absolute_error: 0.0111
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.1756e-04 - mean_absolute_error: 0.0136 - val_loss: 2.4223e-04 - val_mean_absolute_error: 0.0111
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.1559e-04 - mean_absolute_error: 0.0131 - val_loss: 2.7830e-04 - val_mean_absolute_error: 0.0121
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.0408e-04 - mean_absolute_error: 0.0144 - val_loss: 4.1921e-04 - val_mean_absolute_error: 0.0164
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.6024e-04 - mean_absolute_error: 0.0143 - val_loss: 4.3384e-04 - val_mean_absolute_error: 0.0169
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.2798e-04 - mean_absolute_error: 0.0153 - val_loss: 2.4151e-04 - val_mean_absolute_error: 0.0111
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.3493e-04 - mean_absolute_error: 0.0134 - val_loss: 3.2058e-04 - val_mean_absolute_error: 0.0143
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.9846e-04 - mean_absolute_error: 0.0130 - val_loss: 2.4889e-04 - val_mean_absolute_error: 0.0116
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.2432e-04 - mean_absolute_error: 0.0134 - val_loss: 3.0355e-04 - val_mean_absolute_error: 0.0132
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.4346e-04 - mean_absolute_error: 0.0138 - val_loss: 3.4995e-04 - val_mean_absolute_error: 0.0152
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.8046e-04 - mean_absolute_error: 0.0148 - val_loss: 2.3963e-04 - val_mean_absolute_error: 0.0112
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.8556e-04 - mean_absolute_error: 0.0140 - val_loss: 2.5646e-04 - val_mean_absolute_error: 0.0120
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.1573e-04 - mean_absolute_error: 0.0132 - val_loss: 4.5888e-04 - val_mean_absolute_error: 0.0182
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.4494e-04 - mean_absolute_error: 0.0137 - val_loss: 2.3438e-04 - val_mean_absolute_error: 0.0110
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.1866e-04 - mean_absolute_error: 0.0130 - val_loss: 2.7064e-04 - val_mean_absolute_error: 0.0122
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.6838e-04 - mean_absolute_error: 0.0143 - val_loss: 3.0350e-04 - val_mean_absolute_error: 0.0138
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.2394e-04 - mean_absolute_error: 0.0142 - val_loss: 2.6550e-04 - val_mean_absolute_error: 0.0121
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.4144e-04 - mean_absolute_error: 0.0142 - val_loss: 2.5665e-04 - val_mean_absolute_error: 0.0120
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.6438e-04 - mean_absolute_error: 0.0127 - val_loss: 2.5202e-04 - val_mean_absolute_error: 0.0116
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.0836e-04 - mean_absolute_error: 0.0130 - val_loss: 2.2858e-04 - val_mean_absolute_error: 0.0107
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.4118e-04 - mean_absolute_error: 0.0137 - val_loss: 3.5377e-04 - val_mean_absolute_error: 0.0149
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.2160e-04 - mean_absolute_error: 0.0137 - val_loss: 2.3256e-04 - val_mean_absolute_error: 0.0109
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.5982e-04 - mean_absolute_error: 0.0121 - val_loss: 3.3043e-04 - val_mean_absolute_error: 0.0142
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.9214e-04 - mean_absolute_error: 0.0135 - val_loss: 2.5527e-04 - val_mean_absolute_error: 0.0117
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.6346e-04 - mean_absolute_error: 0.0139 - val_loss: 3.1269e-04 - val_mean_absolute_error: 0.0141
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.6213e-04 - mean_absolute_error: 0.0145 - val_loss: 2.7301e-04 - val_mean_absolute_error: 0.0124
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.3772e-04 - mean_absolute_error: 0.0149 - val_loss: 2.4277e-04 - val_mean_absolute_error: 0.0114
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.6824e-04 - mean_absolute_error: 0.0124 - val_loss: 2.3153e-04 - val_mean_absolute_error: 0.0108
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.6039e-04 - mean_absolute_error: 0.0123 - val_loss: 3.0343e-04 - val_mean_absolute_error: 0.0138
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.8465e-04 - mean_absolute_error: 0.0134 - val_loss: 2.9897e-04 - val_mean_absolute_error: 0.0136
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.1109e-04 - mean_absolute_error: 0.0134 - val_loss: 2.3358e-04 - val_mean_absolute_error: 0.0110
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.8630e-04 - mean_absolute_error: 0.0127 - val_loss: 2.3020e-04 - val_mean_absolute_error: 0.0108
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.7538e-04 - mean_absolute_error: 0.0129 - val_loss: 3.2218e-04 - val_mean_absolute_error: 0.0143
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 3.6475e-04 - mean_absolute_error: 0.0123 - val_loss: 2.7131e-04 - val_mean_absolute_error: 0.0124
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.4338e-04 - mean_absolute_error: 0.0137 - val_loss: 3.1166e-04 - val_mean_absolute_error: 0.0140
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.2326e-04 - mean_absolute_error: 0.0136 - val_loss: 2.3859e-04 - val_mean_absolute_error: 0.0112
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.6440e-04 - mean_absolute_error: 0.0145 - val_loss: 2.3726e-04 - val_mean_absolute_error: 0.0111
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.7487e-04 - mean_absolute_error: 0.0142 - val_loss: 2.8078e-04 - val_mean_absolute_error: 0.0127
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.5451e-04 - mean_absolute_error: 0.0127 - val_loss: 2.4779e-04 - val_mean_absolute_error: 0.0116
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.5460e-04 - mean_absolute_error: 0.0137 - val_loss: 2.9791e-04 - val_mean_absolute_error: 0.0135
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.0299e-04 - mean_absolute_error: 0.0134 - val_loss: 3.4994e-04 - val_mean_absolute_error: 0.0148
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.6347e-04 - mean_absolute_error: 0.0126 - val_loss: 2.3095e-04 - val_mean_absolute_error: 0.0108
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8231e-04 - mean_absolute_error: 0.0132 - val_loss: 2.4268e-04 - val_mean_absolute_error: 0.0113
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.0124e-04 - mean_absolute_error: 0.0129 - val_loss: 7.4570e-04 - val_mean_absolute_error: 0.0241
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.8007e-04 - mean_absolute_error: 0.0151 - val_loss: 2.8219e-04 - val_mean_absolute_error: 0.0127
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.5050e-04 - mean_absolute_error: 0.0138 - val_loss: 2.3958e-04 - val_mean_absolute_error: 0.0112
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.1393e-04 - mean_absolute_error: 0.0128 - val_loss: 2.4899e-04 - val_mean_absolute_error: 0.0116
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.6047e-04 - mean_absolute_error: 0.0119 - val_loss: 2.4520e-04 - val_mean_absolute_error: 0.0114
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.5069e-04 - mean_absolute_error: 0.0120 - val_loss: 2.9866e-04 - val_mean_absolute_error: 0.0135
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.9897e-04 - mean_absolute_error: 0.0128 - val_loss: 2.8278e-04 - val_mean_absolute_error: 0.0128
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.5855e-04 - mean_absolute_error: 0.0139 - val_loss: 3.0063e-04 - val_mean_absolute_error: 0.0136
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.1983e-04 - mean_absolute_error: 0.0135 - val_loss: 2.3771e-04 - val_mean_absolute_error: 0.0111
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.5856e-04 - mean_absolute_error: 0.0124 - val_loss: 2.4552e-04 - val_mean_absolute_error: 0.0114
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.0290e-04 - mean_absolute_error: 0.0128 - val_loss: 2.3422e-04 - val_mean_absolute_error: 0.0110
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.6349e-04 - mean_absolute_error: 0.0123 - val_loss: 2.3564e-04 - val_mean_absolute_error: 0.0110
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.2035e-04 - mean_absolute_error: 0.0129 - val_loss: 2.3371e-04 - val_mean_absolute_error: 0.0109
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.9061e-04 - mean_absolute_error: 0.0129 - val_loss: 3.4133e-04 - val_mean_absolute_error: 0.0145
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.9010e-04 - mean_absolute_error: 0.0137 - val_loss: 2.9007e-04 - val_mean_absolute_error: 0.0132
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.8482e-04 - mean_absolute_error: 0.0130 - val_loss: 3.1210e-04 - val_mean_absolute_error: 0.0137
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.5026e-04 - mean_absolute_error: 0.0147 - val_loss: 2.4560e-04 - val_mean_absolute_error: 0.0115
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.7888e-04 - mean_absolute_error: 0.0129 - val_loss: 3.8718e-04 - val_mean_absolute_error: 0.0162
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.3645e-04 - mean_absolute_error: 0.0139 - val_loss: 2.4680e-04 - val_mean_absolute_error: 0.0115
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 4.5146e-04 - mean_absolute_error: 0.0146 - val_loss: 2.4675e-04 - val_mean_absolute_error: 0.0115
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.9825e-04 - mean_absolute_error: 0.0130 - val_loss: 2.4260e-04 - val_mean_absolute_error: 0.0113
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.3079e-04 - mean_absolute_error: 0.0117 - val_loss: 6.2194e-04 - val_mean_absolute_error: 0.0217
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.0823e-04 - mean_absolute_error: 0.0155 - val_loss: 2.3444e-04 - val_mean_absolute_error: 0.0109
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.3323e-04 - mean_absolute_error: 0.0133 - val_loss: 2.3335e-04 - val_mean_absolute_error: 0.0109
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.0998e-04 - mean_absolute_error: 0.0132 - val_loss: 2.4721e-04 - val_mean_absolute_error: 0.0115
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8478e-04 - mean_absolute_error: 0.0134 - val_loss: 2.5861e-04 - val_mean_absolute_error: 0.0120
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.2388e-04 - mean_absolute_error: 0.0137 - val_loss: 2.7698e-04 - val_mean_absolute_error: 0.0127
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.1894e-04 - mean_absolute_error: 0.0138 - val_loss: 3.9315e-04 - val_mean_absolute_error: 0.0160
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.2856e-04 - mean_absolute_error: 0.0140 - val_loss: 3.4395e-04 - val_mean_absolute_error: 0.0150
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.1179e-04 - mean_absolute_error: 0.0134 - val_loss: 2.3659e-04 - val_mean_absolute_error: 0.0111
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.6977e-04 - mean_absolute_error: 0.0126 - val_loss: 2.8005e-04 - val_mean_absolute_error: 0.0128
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.2105e-04 - mean_absolute_error: 0.0133 - val_loss: 2.4136e-04 - val_mean_absolute_error: 0.0113
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.7091e-04 - mean_absolute_error: 0.0127 - val_loss: 4.4071e-04 - val_mean_absolute_error: 0.0176
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.9217e-04 - mean_absolute_error: 0.0156 - val_loss: 2.3961e-04 - val_mean_absolute_error: 0.0112
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.3627e-04 - mean_absolute_error: 0.0135 - val_loss: 3.5750e-04 - val_mean_absolute_error: 0.0153
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.7239e-04 - mean_absolute_error: 0.0133 - val_loss: 2.4178e-04 - val_mean_absolute_error: 0.0113
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.7256e-04 - mean_absolute_error: 0.0128 - val_loss: 2.6167e-04 - val_mean_absolute_error: 0.0120
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.4863e-04 - mean_absolute_error: 0.0125 - val_loss: 4.0684e-04 - val_mean_absolute_error: 0.0167
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.4656e-04 - mean_absolute_error: 0.0151 - val_loss: 2.3327e-04 - val_mean_absolute_error: 0.0110
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.9572e-04 - mean_absolute_error: 0.0127 - val_loss: 2.9838e-04 - val_mean_absolute_error: 0.0135
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.9951e-04 - mean_absolute_error: 0.0130 - val_loss: 3.7562e-04 - val_mean_absolute_error: 0.0159
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.9567e-04 - mean_absolute_error: 0.0147 - val_loss: 2.3794e-04 - val_mean_absolute_error: 0.0111
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.2582e-04 - mean_absolute_error: 0.0137 - val_loss: 2.5115e-04 - val_mean_absolute_error: 0.0117
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.1538e-04 - mean_absolute_error: 0.0131 - val_loss: 3.5111e-04 - val_mean_absolute_error: 0.0151
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.1832e-04 - mean_absolute_error: 0.0131 - val_loss: 2.7645e-04 - val_mean_absolute_error: 0.0126
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.9120e-04 - mean_absolute_error: 0.0138 - val_loss: 4.0935e-04 - val_mean_absolute_error: 0.0168
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.0231e-04 - mean_absolute_error: 0.0141 - val_loss: 2.8467e-04 - val_mean_absolute_error: 0.0130
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.6010e-04 - mean_absolute_error: 0.0122 - val_loss: 2.4116e-04 - val_mean_absolute_error: 0.0112
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.7309e-04 - mean_absolute_error: 0.0133 - val_loss: 2.3349e-04 - val_mean_absolute_error: 0.0109
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.7863e-04 - mean_absolute_error: 0.0129 - val_loss: 2.3702e-04 - val_mean_absolute_error: 0.0111
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.1872e-04 - mean_absolute_error: 0.0137 - val_loss: 2.6387e-04 - val_mean_absolute_error: 0.0122
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.3687e-04 - mean_absolute_error: 0.0134 - val_loss: 2.4470e-04 - val_mean_absolute_error: 0.0114
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.5289e-04 - mean_absolute_error: 0.0128 - val_loss: 3.2846e-04 - val_mean_absolute_error: 0.0144
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.8333e-04 - mean_absolute_error: 0.0126 - val_loss: 2.4431e-04 - val_mean_absolute_error: 0.0114
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.9185e-04 - mean_absolute_error: 0.0128 - val_loss: 2.3722e-04 - val_mean_absolute_error: 0.0110
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.8540e-04 - mean_absolute_error: 0.0137 - val_loss: 2.6283e-04 - val_mean_absolute_error: 0.0121
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7969e-04 - mean_absolute_error: 0.0127 - val_loss: 2.7548e-04 - val_mean_absolute_error: 0.0126
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.3667e-04 - mean_absolute_error: 0.0135 - val_loss: 2.8487e-04 - val_mean_absolute_error: 0.0129
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.9946e-04 - mean_absolute_error: 0.0139 - val_loss: 2.5311e-04 - val_mean_absolute_error: 0.0117
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.2302e-04 - mean_absolute_error: 0.0131 - val_loss: 2.8340e-04 - val_mean_absolute_error: 0.0128
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.2862e-04 - mean_absolute_error: 0.0137 - val_loss: 2.7629e-04 - val_mean_absolute_error: 0.0125
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.8168e-04 - mean_absolute_error: 0.0132 - val_loss: 2.5101e-04 - val_mean_absolute_error: 0.0116
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.0941e-04 - mean_absolute_error: 0.0133 - val_loss: 4.2237e-04 - val_mean_absolute_error: 0.0168
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.0502e-04 - mean_absolute_error: 0.0154 - val_loss: 2.4686e-04 - val_mean_absolute_error: 0.0115
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.8980e-04 - mean_absolute_error: 0.0126 - val_loss: 2.3645e-04 - val_mean_absolute_error: 0.0110
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.5301e-04 - mean_absolute_error: 0.0124 - val_loss: 2.4384e-04 - val_mean_absolute_error: 0.0113
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.2538e-04 - mean_absolute_error: 0.0131 - val_loss: 2.8235e-04 - val_mean_absolute_error: 0.0128
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.8226e-04 - mean_absolute_error: 0.0130 - val_loss: 4.0876e-04 - val_mean_absolute_error: 0.0164
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.9991e-04 - mean_absolute_error: 0.0137 - val_loss: 2.3860e-04 - val_mean_absolute_error: 0.0111
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.4794e-04 - mean_absolute_error: 0.0122 - val_loss: 3.0758e-04 - val_mean_absolute_error: 0.0135
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.8192e-04 - mean_absolute_error: 0.0130 - val_loss: 2.3665e-04 - val_mean_absolute_error: 0.0110
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.4539e-04 - mean_absolute_error: 0.0123 - val_loss: 2.6877e-04 - val_mean_absolute_error: 0.0122
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.0688e-04 - mean_absolute_error: 0.0135 - val_loss: 4.1150e-04 - val_mean_absolute_error: 0.0168
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.3503e-04 - mean_absolute_error: 0.0140 - val_loss: 3.1422e-04 - val_mean_absolute_error: 0.0138
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.5080e-04 - mean_absolute_error: 0.0123 - val_loss: 3.9294e-04 - val_mean_absolute_error: 0.0162
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.5576e-04 - mean_absolute_error: 0.0138 - val_loss: 2.9583e-04 - val_mean_absolute_error: 0.0131
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.7590e-04 - mean_absolute_error: 0.0128 - val_loss: 3.6872e-04 - val_mean_absolute_error: 0.0156
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.5358e-04 - mean_absolute_error: 0.0136 - val_loss: 2.7697e-04 - val_mean_absolute_error: 0.0126
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9855e-04 - mean_absolute_error: 0.0132 - val_loss: 2.4162e-04 - val_mean_absolute_error: 0.0113
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6218e-04 - mean_absolute_error: 0.0132 - val_loss: 2.7211e-04 - val_mean_absolute_error: 0.0124
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.6453e-04 - mean_absolute_error: 0.0126 - val_loss: 2.4378e-04 - val_mean_absolute_error: 0.0113
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.7210e-04 - mean_absolute_error: 0.0125 - val_loss: 2.5628e-04 - val_mean_absolute_error: 0.0118
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.4561e-04 - mean_absolute_error: 0.0121 - val_loss: 2.5014e-04 - val_mean_absolute_error: 0.0116
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.0096e-04 - mean_absolute_error: 0.0136 - val_loss: 2.3811e-04 - val_mean_absolute_error: 0.0110

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 148ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0793e-04 - mean_absolute_error: 0.0126
# Test Loss: [0.00023810913262423128, 0.01104876771569252]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 99042.03230727147
# RMSE: 314.70944108378995
# MAE: 222.1538766807769
# MAPE: 2.0013702793154224 %
#
# Model evalution on validate set
# MSE: 78274.40595478656
# RMSE: 279.7756350270455
# MAE: 184.12441890495867
# MAPE: 1.7590845049801807 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 728ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step

# %%
y_pred_30_days
# Out:
# array([[12623.416],
#        [12618.016],
#        [12629.145],
#        [12628.439],
#        [12629.982],
#        [12629.878],
#        [12630.056],
#        [12630.044],
#        [12630.066],
#        [12630.065],
#        [12630.067],
#        [12630.067],
#        [12630.067],
#        [12630.066],
#        [12630.066],
#        [12630.066],
#        [12630.066],
#        [12630.066],
#        [12630.066],
#        [12630.066],
#        [12630.066],
#        [12630.066],
#        [12630.066],
#        [12630.066],
#        [12630.066],
#        [12630.066],
#        [12630.066],
#        [12630.066],
#        [12630.066],
#        [12630.066],
#        [12630.066]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Forecast Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
