# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: ITD - Test/Train/Vaildation: 70/20/10
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 329.63
# - MAE: 232.67
# - MAPE: 2.14 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 0

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170
# ...           ...
# 2024-02-26   9700
# 2024-02-27   9640
# 2024-02-28   9890
# 2024-02-29   9950
# 2024-03-01   9990
#
# [1252 rows x 1 columns]

# %%
df.shape
# Out:
# (1252, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       6900
# 1       7100
# 2       7100
# 3       7170
# 4       7170
#         ...
# 1247    9700
# 1248    9640
# 1249    9890
# 1250    9950
# 1251    9990
# Name: close, Length: 1252, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((865, 10), (865,), (239, 10), (239,), (115, 10), (115,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0629 - mean_absolute_error: 0.1789 - val_loss: 0.0042 - val_mean_absolute_error: 0.0592
# Epoch 2/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0046 - mean_absolute_error: 0.0439 - val_loss: 8.2646e-04 - val_mean_absolute_error: 0.0202
# Epoch 3/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - mean_absolute_error: 0.0301 - val_loss: 7.4112e-04 - val_mean_absolute_error: 0.0208
# Epoch 4/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mean_absolute_error: 0.0262 - val_loss: 7.2258e-04 - val_mean_absolute_error: 0.0198
# Epoch 5/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mean_absolute_error: 0.0250 - val_loss: 0.0013 - val_mean_absolute_error: 0.0291
# Epoch 6/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0032 - mean_absolute_error: 0.0392 - val_loss: 9.2095e-04 - val_mean_absolute_error: 0.0222
# Epoch 7/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mean_absolute_error: 0.0239 - val_loss: 7.1321e-04 - val_mean_absolute_error: 0.0190
# Epoch 8/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mean_absolute_error: 0.0238 - val_loss: 7.0574e-04 - val_mean_absolute_error: 0.0191
# Epoch 9/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mean_absolute_error: 0.0240 - val_loss: 7.0013e-04 - val_mean_absolute_error: 0.0201
# Epoch 10/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0229 - val_loss: 8.3817e-04 - val_mean_absolute_error: 0.0238
# Epoch 11/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mean_absolute_error: 0.0236 - val_loss: 7.2501e-04 - val_mean_absolute_error: 0.0212
# Epoch 12/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mean_absolute_error: 0.0251 - val_loss: 6.6796e-04 - val_mean_absolute_error: 0.0190
# Epoch 13/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0226 - val_loss: 0.0014 - val_mean_absolute_error: 0.0332
# Epoch 14/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0023 - mean_absolute_error: 0.0325 - val_loss: 7.4561e-04 - val_mean_absolute_error: 0.0194
# Epoch 15/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0225 - val_loss: 6.5423e-04 - val_mean_absolute_error: 0.0192
# Epoch 16/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0242 - val_loss: 6.3036e-04 - val_mean_absolute_error: 0.0186
# Epoch 17/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0215 - val_loss: 6.7991e-04 - val_mean_absolute_error: 0.0205
# Epoch 18/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0216 - val_loss: 9.4962e-04 - val_mean_absolute_error: 0.0262
# Epoch 19/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - mean_absolute_error: 0.0229 - val_loss: 5.8990e-04 - val_mean_absolute_error: 0.0173
# Epoch 20/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0227 - val_loss: 6.2458e-04 - val_mean_absolute_error: 0.0175
# Epoch 21/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0224 - val_loss: 6.0840e-04 - val_mean_absolute_error: 0.0173
# Epoch 22/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mean_absolute_error: 0.0245 - val_loss: 5.8099e-04 - val_mean_absolute_error: 0.0168
# Epoch 23/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0210 - val_loss: 5.5592e-04 - val_mean_absolute_error: 0.0166
# Epoch 24/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0210 - val_loss: 5.7197e-04 - val_mean_absolute_error: 0.0167
# Epoch 25/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0204 - val_loss: 5.3634e-04 - val_mean_absolute_error: 0.0164
# Epoch 26/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0207 - val_loss: 5.3090e-04 - val_mean_absolute_error: 0.0160
# Epoch 27/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0207 - val_loss: 7.5446e-04 - val_mean_absolute_error: 0.0228
# Epoch 28/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0210 - val_loss: 5.3587e-04 - val_mean_absolute_error: 0.0173
# Epoch 29/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0205 - val_loss: 5.7058e-04 - val_mean_absolute_error: 0.0185
# Epoch 30/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7543e-04 - mean_absolute_error: 0.0201 - val_loss: 5.2724e-04 - val_mean_absolute_error: 0.0162
# Epoch 31/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0233 - val_loss: 6.7305e-04 - val_mean_absolute_error: 0.0211
# Epoch 32/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0209 - val_loss: 6.1511e-04 - val_mean_absolute_error: 0.0199
# Epoch 33/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010 - mean_absolute_error: 0.0203 - val_loss: 5.0580e-04 - val_mean_absolute_error: 0.0157
# Epoch 34/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0213 - val_loss: 4.7111e-04 - val_mean_absolute_error: 0.0151
# Epoch 35/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0234 - val_loss: 4.9032e-04 - val_mean_absolute_error: 0.0163
# Epoch 36/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010 - mean_absolute_error: 0.0207 - val_loss: 8.2129e-04 - val_mean_absolute_error: 0.0229
# Epoch 37/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0229 - val_loss: 6.6793e-04 - val_mean_absolute_error: 0.0196
# Epoch 38/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4898e-04 - mean_absolute_error: 0.0208 - val_loss: 7.9750e-04 - val_mean_absolute_error: 0.0242
# Epoch 39/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0253 - val_loss: 5.0621e-04 - val_mean_absolute_error: 0.0172
# Epoch 40/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.9837e-04 - mean_absolute_error: 0.0190 - val_loss: 5.5852e-04 - val_mean_absolute_error: 0.0188
# Epoch 41/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.7937e-04 - mean_absolute_error: 0.0183 - val_loss: 4.3527e-04 - val_mean_absolute_error: 0.0148
# Epoch 42/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1820e-04 - mean_absolute_error: 0.0178 - val_loss: 4.2440e-04 - val_mean_absolute_error: 0.0142
# Epoch 43/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.8440e-04 - mean_absolute_error: 0.0191 - val_loss: 4.2118e-04 - val_mean_absolute_error: 0.0142
# Epoch 44/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7876e-04 - mean_absolute_error: 0.0177 - val_loss: 4.8466e-04 - val_mean_absolute_error: 0.0157
# Epoch 45/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.4612e-04 - mean_absolute_error: 0.0180 - val_loss: 4.1020e-04 - val_mean_absolute_error: 0.0140
# Epoch 46/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.4747e-04 - mean_absolute_error: 0.0180 - val_loss: 7.8871e-04 - val_mean_absolute_error: 0.0244
# Epoch 47/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0231 - val_loss: 4.0365e-04 - val_mean_absolute_error: 0.0140
# Epoch 48/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.7843e-04 - mean_absolute_error: 0.0185 - val_loss: 4.2191e-04 - val_mean_absolute_error: 0.0143
# Epoch 49/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6490e-04 - mean_absolute_error: 0.0170 - val_loss: 0.0010 - val_mean_absolute_error: 0.0288
# Epoch 50/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0235 - val_loss: 3.9856e-04 - val_mean_absolute_error: 0.0140
# Epoch 51/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7628e-04 - mean_absolute_error: 0.0162 - val_loss: 4.0161e-04 - val_mean_absolute_error: 0.0144
# Epoch 52/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8499e-04 - mean_absolute_error: 0.0177 - val_loss: 4.1111e-04 - val_mean_absolute_error: 0.0150
# Epoch 53/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0212e-04 - mean_absolute_error: 0.0158 - val_loss: 3.8211e-04 - val_mean_absolute_error: 0.0138
# Epoch 54/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6846e-04 - mean_absolute_error: 0.0181 - val_loss: 5.5399e-04 - val_mean_absolute_error: 0.0194
# Epoch 55/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2486e-04 - mean_absolute_error: 0.0174 - val_loss: 5.1218e-04 - val_mean_absolute_error: 0.0184
# Epoch 56/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3470e-04 - mean_absolute_error: 0.0165 - val_loss: 3.8723e-04 - val_mean_absolute_error: 0.0136
# Epoch 57/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6235e-04 - mean_absolute_error: 0.0176 - val_loss: 4.9375e-04 - val_mean_absolute_error: 0.0165
# Epoch 58/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.3674e-04 - mean_absolute_error: 0.0181 - val_loss: 3.6612e-04 - val_mean_absolute_error: 0.0135
# Epoch 59/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.2588e-04 - mean_absolute_error: 0.0165 - val_loss: 4.0402e-04 - val_mean_absolute_error: 0.0153
# Epoch 60/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5737e-04 - mean_absolute_error: 0.0163 - val_loss: 3.5910e-04 - val_mean_absolute_error: 0.0135
# Epoch 61/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6815e-04 - mean_absolute_error: 0.0170 - val_loss: 4.3115e-04 - val_mean_absolute_error: 0.0163
# Epoch 62/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9013e-04 - mean_absolute_error: 0.0167 - val_loss: 3.4951e-04 - val_mean_absolute_error: 0.0134
# Epoch 63/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4151e-04 - mean_absolute_error: 0.0160 - val_loss: 4.5914e-04 - val_mean_absolute_error: 0.0172
# Epoch 64/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.8385e-04 - mean_absolute_error: 0.0169 - val_loss: 3.6620e-04 - val_mean_absolute_error: 0.0143
# Epoch 65/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1295e-04 - mean_absolute_error: 0.0162 - val_loss: 3.4229e-04 - val_mean_absolute_error: 0.0128
# Epoch 66/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6285e-04 - mean_absolute_error: 0.0146 - val_loss: 3.3774e-04 - val_mean_absolute_error: 0.0127
# Epoch 67/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1939e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0029 - val_mean_absolute_error: 0.0502
# Epoch 68/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0025 - mean_absolute_error: 0.0359 - val_loss: 6.2513e-04 - val_mean_absolute_error: 0.0216
# Epoch 69/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4034e-04 - mean_absolute_error: 0.0193 - val_loss: 3.2782e-04 - val_mean_absolute_error: 0.0128
# Epoch 70/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4673e-04 - mean_absolute_error: 0.0152 - val_loss: 3.9546e-04 - val_mean_absolute_error: 0.0143
# Epoch 71/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3251e-04 - mean_absolute_error: 0.0162 - val_loss: 3.2330e-04 - val_mean_absolute_error: 0.0125
# Epoch 72/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8575e-04 - mean_absolute_error: 0.0150 - val_loss: 3.2304e-04 - val_mean_absolute_error: 0.0130
# Epoch 73/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2313e-04 - mean_absolute_error: 0.0142 - val_loss: 3.2700e-04 - val_mean_absolute_error: 0.0133
# Epoch 74/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2701e-04 - mean_absolute_error: 0.0147 - val_loss: 4.2117e-04 - val_mean_absolute_error: 0.0165
# Epoch 75/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5807e-04 - mean_absolute_error: 0.0153 - val_loss: 3.1645e-04 - val_mean_absolute_error: 0.0130
# Epoch 76/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3878e-04 - mean_absolute_error: 0.0144 - val_loss: 3.2359e-04 - val_mean_absolute_error: 0.0133
# Epoch 77/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5897e-04 - mean_absolute_error: 0.0149 - val_loss: 8.0121e-04 - val_mean_absolute_error: 0.0242
# Epoch 78/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mean_absolute_error: 0.0290 - val_loss: 3.0636e-04 - val_mean_absolute_error: 0.0123
# Epoch 79/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9178e-04 - mean_absolute_error: 0.0157 - val_loss: 3.7476e-04 - val_mean_absolute_error: 0.0153
# Epoch 80/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1035e-04 - mean_absolute_error: 0.0150 - val_loss: 2.9581e-04 - val_mean_absolute_error: 0.0121
# Epoch 81/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.2203e-04 - mean_absolute_error: 0.0142 - val_loss: 2.9797e-04 - val_mean_absolute_error: 0.0123
# Epoch 82/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8685e-04 - mean_absolute_error: 0.0138 - val_loss: 2.9640e-04 - val_mean_absolute_error: 0.0121
# Epoch 83/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4420e-04 - mean_absolute_error: 0.0152 - val_loss: 2.9391e-04 - val_mean_absolute_error: 0.0121
# Epoch 84/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2031e-04 - mean_absolute_error: 0.0145 - val_loss: 2.9043e-04 - val_mean_absolute_error: 0.0120
# Epoch 85/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0759e-04 - mean_absolute_error: 0.0145 - val_loss: 4.6126e-04 - val_mean_absolute_error: 0.0168
# Epoch 86/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0224 - val_loss: 3.2046e-04 - val_mean_absolute_error: 0.0136
# Epoch 87/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7425e-04 - mean_absolute_error: 0.0136 - val_loss: 2.9063e-04 - val_mean_absolute_error: 0.0120
# Epoch 88/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3959e-04 - mean_absolute_error: 0.0130 - val_loss: 3.2667e-04 - val_mean_absolute_error: 0.0140
# Epoch 89/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2361e-04 - mean_absolute_error: 0.0129 - val_loss: 3.2505e-04 - val_mean_absolute_error: 0.0140
# Epoch 90/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.9854e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0013 - val_mean_absolute_error: 0.0328
# Epoch 91/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mean_absolute_error: 0.0276 - val_loss: 2.9045e-04 - val_mean_absolute_error: 0.0127
# Epoch 92/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6893e-04 - mean_absolute_error: 0.0139 - val_loss: 2.7271e-04 - val_mean_absolute_error: 0.0118
# Epoch 93/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3455e-04 - mean_absolute_error: 0.0132 - val_loss: 2.7961e-04 - val_mean_absolute_error: 0.0117
# Epoch 94/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7796e-04 - mean_absolute_error: 0.0136 - val_loss: 3.2705e-04 - val_mean_absolute_error: 0.0141
# Epoch 95/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9071e-04 - mean_absolute_error: 0.0145 - val_loss: 3.6086e-04 - val_mean_absolute_error: 0.0152
# Epoch 96/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4357e-04 - mean_absolute_error: 0.0152 - val_loss: 4.1833e-04 - val_mean_absolute_error: 0.0158
# Epoch 97/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3230e-04 - mean_absolute_error: 0.0194 - val_loss: 3.0944e-04 - val_mean_absolute_error: 0.0134
# Epoch 98/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0647e-04 - mean_absolute_error: 0.0129 - val_loss: 3.5889e-04 - val_mean_absolute_error: 0.0152
# Epoch 99/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3397e-04 - mean_absolute_error: 0.0157 - val_loss: 2.6921e-04 - val_mean_absolute_error: 0.0118
# Epoch 100/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9178e-04 - mean_absolute_error: 0.0144 - val_loss: 2.6632e-04 - val_mean_absolute_error: 0.0116
# Epoch 101/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3740e-04 - mean_absolute_error: 0.0134 - val_loss: 2.8308e-04 - val_mean_absolute_error: 0.0126
# Epoch 102/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4114e-04 - mean_absolute_error: 0.0135 - val_loss: 3.2546e-04 - val_mean_absolute_error: 0.0141
# Epoch 103/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4976e-04 - mean_absolute_error: 0.0142 - val_loss: 2.6440e-04 - val_mean_absolute_error: 0.0116
# Epoch 104/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3350e-04 - mean_absolute_error: 0.0135 - val_loss: 2.8750e-04 - val_mean_absolute_error: 0.0120
# Epoch 105/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1654e-04 - mean_absolute_error: 0.0147 - val_loss: 2.6861e-04 - val_mean_absolute_error: 0.0115
# Epoch 106/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0177e-04 - mean_absolute_error: 0.0149 - val_loss: 3.8007e-04 - val_mean_absolute_error: 0.0159
# Epoch 107/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8626e-04 - mean_absolute_error: 0.0174 - val_loss: 2.6521e-04 - val_mean_absolute_error: 0.0115
# Epoch 108/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2456e-04 - mean_absolute_error: 0.0137 - val_loss: 3.0596e-04 - val_mean_absolute_error: 0.0128
# Epoch 109/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8156e-04 - mean_absolute_error: 0.0126 - val_loss: 2.6596e-04 - val_mean_absolute_error: 0.0115
# Epoch 110/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7799e-04 - mean_absolute_error: 0.0126 - val_loss: 2.6569e-04 - val_mean_absolute_error: 0.0119
# Epoch 111/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7258e-04 - mean_absolute_error: 0.0138 - val_loss: 2.5751e-04 - val_mean_absolute_error: 0.0114
# Epoch 112/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9244e-04 - mean_absolute_error: 0.0125 - val_loss: 2.5815e-04 - val_mean_absolute_error: 0.0115
# Epoch 113/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7845e-04 - mean_absolute_error: 0.0137 - val_loss: 2.5690e-04 - val_mean_absolute_error: 0.0113
# Epoch 114/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2037e-04 - mean_absolute_error: 0.0132 - val_loss: 2.7951e-04 - val_mean_absolute_error: 0.0121
# Epoch 115/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7307e-04 - mean_absolute_error: 0.0143 - val_loss: 2.6479e-04 - val_mean_absolute_error: 0.0116
# Epoch 116/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7931e-04 - mean_absolute_error: 0.0148 - val_loss: 2.7426e-04 - val_mean_absolute_error: 0.0123
# Epoch 117/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2915e-04 - mean_absolute_error: 0.0143 - val_loss: 6.1580e-04 - val_mean_absolute_error: 0.0214
# Epoch 118/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7816e-04 - mean_absolute_error: 0.0218 - val_loss: 3.8636e-04 - val_mean_absolute_error: 0.0161
# Epoch 119/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3744e-04 - mean_absolute_error: 0.0207 - val_loss: 2.8802e-04 - val_mean_absolute_error: 0.0128
# Epoch 120/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4609e-04 - mean_absolute_error: 0.0130 - val_loss: 2.8183e-04 - val_mean_absolute_error: 0.0122
# Epoch 121/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8237e-04 - mean_absolute_error: 0.0146 - val_loss: 4.4842e-04 - val_mean_absolute_error: 0.0177
# Epoch 122/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7378e-04 - mean_absolute_error: 0.0146 - val_loss: 2.5357e-04 - val_mean_absolute_error: 0.0112
# Epoch 123/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7395e-04 - mean_absolute_error: 0.0139 - val_loss: 2.5826e-04 - val_mean_absolute_error: 0.0116
# Epoch 124/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5905e-04 - mean_absolute_error: 0.0120 - val_loss: 2.5365e-04 - val_mean_absolute_error: 0.0112
# Epoch 125/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3425e-04 - mean_absolute_error: 0.0137 - val_loss: 2.5587e-04 - val_mean_absolute_error: 0.0113
# Epoch 126/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0658e-04 - mean_absolute_error: 0.0128 - val_loss: 2.5578e-04 - val_mean_absolute_error: 0.0114
# Epoch 127/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9164e-04 - mean_absolute_error: 0.0128 - val_loss: 3.1956e-04 - val_mean_absolute_error: 0.0139
# Epoch 128/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7919e-04 - mean_absolute_error: 0.0130 - val_loss: 3.2315e-04 - val_mean_absolute_error: 0.0140
# Epoch 129/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2928e-04 - mean_absolute_error: 0.0133 - val_loss: 2.5646e-04 - val_mean_absolute_error: 0.0115
# Epoch 130/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9718e-04 - mean_absolute_error: 0.0127 - val_loss: 2.6705e-04 - val_mean_absolute_error: 0.0119
# Epoch 131/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1782e-04 - mean_absolute_error: 0.0133 - val_loss: 2.6719e-04 - val_mean_absolute_error: 0.0119
# Epoch 132/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5311e-04 - mean_absolute_error: 0.0121 - val_loss: 2.5255e-04 - val_mean_absolute_error: 0.0112
# Epoch 133/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3345e-04 - mean_absolute_error: 0.0136 - val_loss: 2.7487e-04 - val_mean_absolute_error: 0.0123
# Epoch 134/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2090e-04 - mean_absolute_error: 0.0145 - val_loss: 2.5803e-04 - val_mean_absolute_error: 0.0114
# Epoch 135/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7960e-04 - mean_absolute_error: 0.0123 - val_loss: 2.6456e-04 - val_mean_absolute_error: 0.0116
# Epoch 136/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1985e-04 - mean_absolute_error: 0.0132 - val_loss: 3.7992e-04 - val_mean_absolute_error: 0.0158
# Epoch 137/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7396e-04 - mean_absolute_error: 0.0125 - val_loss: 3.6971e-04 - val_mean_absolute_error: 0.0155
# Epoch 138/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9743e-04 - mean_absolute_error: 0.0150 - val_loss: 2.5713e-04 - val_mean_absolute_error: 0.0115
# Epoch 139/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9707e-04 - mean_absolute_error: 0.0124 - val_loss: 3.7228e-04 - val_mean_absolute_error: 0.0151
# Epoch 140/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0762e-04 - mean_absolute_error: 0.0135 - val_loss: 2.7240e-04 - val_mean_absolute_error: 0.0119
# Epoch 141/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1282e-04 - mean_absolute_error: 0.0130 - val_loss: 2.8961e-04 - val_mean_absolute_error: 0.0129
# Epoch 142/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0088e-04 - mean_absolute_error: 0.0129 - val_loss: 2.8021e-04 - val_mean_absolute_error: 0.0124
# Epoch 143/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3122e-04 - mean_absolute_error: 0.0134 - val_loss: 3.4756e-04 - val_mean_absolute_error: 0.0148
# Epoch 144/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9699e-04 - mean_absolute_error: 0.0130 - val_loss: 9.0130e-04 - val_mean_absolute_error: 0.0268
# Epoch 145/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0029 - mean_absolute_error: 0.0384 - val_loss: 3.3241e-04 - val_mean_absolute_error: 0.0138
# Epoch 146/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4667e-04 - mean_absolute_error: 0.0140 - val_loss: 2.5547e-04 - val_mean_absolute_error: 0.0113
# Epoch 147/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7393e-04 - mean_absolute_error: 0.0126 - val_loss: 2.7122e-04 - val_mean_absolute_error: 0.0118
# Epoch 148/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0124e-04 - mean_absolute_error: 0.0134 - val_loss: 2.5771e-04 - val_mean_absolute_error: 0.0115
# Epoch 149/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9410e-04 - mean_absolute_error: 0.0128 - val_loss: 2.6957e-04 - val_mean_absolute_error: 0.0118
# Epoch 150/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1115e-04 - mean_absolute_error: 0.0131 - val_loss: 3.1316e-04 - val_mean_absolute_error: 0.0133
# Epoch 151/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6884e-04 - mean_absolute_error: 0.0144 - val_loss: 2.8131e-04 - val_mean_absolute_error: 0.0125
# Epoch 152/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8217e-04 - mean_absolute_error: 0.0127 - val_loss: 2.8258e-04 - val_mean_absolute_error: 0.0126
# Epoch 153/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8888e-04 - mean_absolute_error: 0.0133 - val_loss: 2.7881e-04 - val_mean_absolute_error: 0.0124
# Epoch 154/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6942e-04 - mean_absolute_error: 0.0124 - val_loss: 3.2949e-04 - val_mean_absolute_error: 0.0139
# Epoch 155/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6585e-04 - mean_absolute_error: 0.0139 - val_loss: 2.9917e-04 - val_mean_absolute_error: 0.0131
# Epoch 156/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2807e-04 - mean_absolute_error: 0.0137 - val_loss: 2.5643e-04 - val_mean_absolute_error: 0.0114
# Epoch 157/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8707e-04 - mean_absolute_error: 0.0129 - val_loss: 2.5652e-04 - val_mean_absolute_error: 0.0113
# Epoch 158/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8299e-04 - mean_absolute_error: 0.0127 - val_loss: 2.6533e-04 - val_mean_absolute_error: 0.0119
# Epoch 159/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7251e-04 - mean_absolute_error: 0.0152 - val_loss: 2.7732e-04 - val_mean_absolute_error: 0.0122
# Epoch 160/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0505e-04 - mean_absolute_error: 0.0129 - val_loss: 2.6967e-04 - val_mean_absolute_error: 0.0120
# Epoch 161/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6982e-04 - mean_absolute_error: 0.0123 - val_loss: 2.7526e-04 - val_mean_absolute_error: 0.0123
# Epoch 162/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5623e-04 - mean_absolute_error: 0.0124 - val_loss: 2.6163e-04 - val_mean_absolute_error: 0.0116
# Epoch 163/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5818e-04 - mean_absolute_error: 0.0121 - val_loss: 3.1653e-04 - val_mean_absolute_error: 0.0137
# Epoch 164/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2111e-04 - mean_absolute_error: 0.0156 - val_loss: 2.6453e-04 - val_mean_absolute_error: 0.0118
# Epoch 165/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1624e-04 - mean_absolute_error: 0.0135 - val_loss: 2.5601e-04 - val_mean_absolute_error: 0.0115
# Epoch 166/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6508e-04 - mean_absolute_error: 0.0125 - val_loss: 2.7132e-04 - val_mean_absolute_error: 0.0120
# Epoch 167/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8714e-04 - mean_absolute_error: 0.0134 - val_loss: 2.6286e-04 - val_mean_absolute_error: 0.0117
# Epoch 168/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5137e-04 - mean_absolute_error: 0.0120 - val_loss: 2.6503e-04 - val_mean_absolute_error: 0.0118
# Epoch 169/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6517e-04 - mean_absolute_error: 0.0149 - val_loss: 2.9169e-04 - val_mean_absolute_error: 0.0128
# Epoch 170/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3701e-04 - mean_absolute_error: 0.0144 - val_loss: 2.5655e-04 - val_mean_absolute_error: 0.0114
# Epoch 171/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2876e-04 - mean_absolute_error: 0.0118 - val_loss: 2.6214e-04 - val_mean_absolute_error: 0.0117
# Epoch 172/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5758e-04 - mean_absolute_error: 0.0122 - val_loss: 3.0239e-04 - val_mean_absolute_error: 0.0133
# Epoch 173/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0906e-04 - mean_absolute_error: 0.0134 - val_loss: 5.0663e-04 - val_mean_absolute_error: 0.0189
# Epoch 174/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3716e-04 - mean_absolute_error: 0.0167 - val_loss: 3.6531e-04 - val_mean_absolute_error: 0.0153
# Epoch 175/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2139e-04 - mean_absolute_error: 0.0141 - val_loss: 2.5799e-04 - val_mean_absolute_error: 0.0116
# Epoch 176/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6955e-04 - mean_absolute_error: 0.0127 - val_loss: 4.6286e-04 - val_mean_absolute_error: 0.0179
# Epoch 177/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0251 - val_loss: 2.6657e-04 - val_mean_absolute_error: 0.0117
# Epoch 178/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9201e-04 - mean_absolute_error: 0.0135 - val_loss: 2.5966e-04 - val_mean_absolute_error: 0.0115
# Epoch 179/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7127e-04 - mean_absolute_error: 0.0125 - val_loss: 2.6782e-04 - val_mean_absolute_error: 0.0120
# Epoch 180/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0855e-04 - mean_absolute_error: 0.0132 - val_loss: 2.7173e-04 - val_mean_absolute_error: 0.0120
# Epoch 181/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6242e-04 - mean_absolute_error: 0.0120 - val_loss: 3.0124e-04 - val_mean_absolute_error: 0.0132
# Epoch 182/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6692e-04 - mean_absolute_error: 0.0126 - val_loss: 2.7623e-04 - val_mean_absolute_error: 0.0123
# Epoch 183/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1670e-04 - mean_absolute_error: 0.0134 - val_loss: 2.6546e-04 - val_mean_absolute_error: 0.0118
# Epoch 184/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8120e-04 - mean_absolute_error: 0.0127 - val_loss: 4.2590e-04 - val_mean_absolute_error: 0.0170
# Epoch 185/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4763e-04 - mean_absolute_error: 0.0179 - val_loss: 2.8146e-04 - val_mean_absolute_error: 0.0124
# Epoch 186/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3023e-04 - mean_absolute_error: 0.0136 - val_loss: 3.2876e-04 - val_mean_absolute_error: 0.0139
# Epoch 187/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1337e-04 - mean_absolute_error: 0.0130 - val_loss: 2.5380e-04 - val_mean_absolute_error: 0.0114
# Epoch 188/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9585e-04 - mean_absolute_error: 0.0133 - val_loss: 2.5456e-04 - val_mean_absolute_error: 0.0114
# Epoch 189/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0948e-04 - mean_absolute_error: 0.0132 - val_loss: 2.6225e-04 - val_mean_absolute_error: 0.0118
# Epoch 190/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7616e-04 - mean_absolute_error: 0.0124 - val_loss: 3.2257e-04 - val_mean_absolute_error: 0.0139
# Epoch 191/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4910e-04 - mean_absolute_error: 0.0122 - val_loss: 2.8695e-04 - val_mean_absolute_error: 0.0126
# Epoch 192/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2291e-04 - mean_absolute_error: 0.0142 - val_loss: 2.5574e-04 - val_mean_absolute_error: 0.0115
# Epoch 193/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9838e-04 - mean_absolute_error: 0.0127 - val_loss: 2.6485e-04 - val_mean_absolute_error: 0.0118
# Epoch 194/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5521e-04 - mean_absolute_error: 0.0119 - val_loss: 2.5646e-04 - val_mean_absolute_error: 0.0115
# Epoch 195/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0096e-04 - mean_absolute_error: 0.0133 - val_loss: 2.5537e-04 - val_mean_absolute_error: 0.0115
# Epoch 196/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6091e-04 - mean_absolute_error: 0.0138 - val_loss: 2.7834e-04 - val_mean_absolute_error: 0.0123
# Epoch 197/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5050e-04 - mean_absolute_error: 0.0118 - val_loss: 2.8517e-04 - val_mean_absolute_error: 0.0126
# Epoch 198/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7574e-04 - mean_absolute_error: 0.0128 - val_loss: 2.9555e-04 - val_mean_absolute_error: 0.0129
# Epoch 199/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8720e-04 - mean_absolute_error: 0.0150 - val_loss: 2.5987e-04 - val_mean_absolute_error: 0.0115
# Epoch 200/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0436e-04 - mean_absolute_error: 0.0129 - val_loss: 2.5801e-04 - val_mean_absolute_error: 0.0115

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 3.1925e-04 - mean_absolute_error: 0.0130
# Test Loss: [0.00025801040465012193, 0.011526298709213734]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 239
# 250

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 108654.4307092483
# RMSE: 329.6277153232845
# MAE: 232.67109048117155
# MAPE: 2.144967798509298 %
#
# Model evalution on validate set
# MSE: 54163.17183436518
# RMSE: 232.729825837526
# MAE: 165.85368546195653
# MAPE: 1.667975097596461 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
y_pred_30_days
# Out:
# array([[9900.736],
#        [9903.344],
#        [9905.07 ],
#        [9904.902],
#        [9904.509],
#        [9904.521],
#        [9904.518],
#        [9904.507],
#        [9904.501],
#        [9904.5  ],
#        [9904.499],
#        [9904.498],
#        [9904.498],
#        [9904.498],
#        [9904.498],
#        [9904.498],
#        [9904.498],
#        [9904.498],
#        [9904.498],
#        [9904.498],
#        [9904.498],
#        [9904.498],
#        [9904.498],
#        [9904.498],
#        [9904.498],
#        [9904.498],
#        [9904.498],
#        [9904.498],
#        [9904.498],
#        [9904.498],
#        [9904.498]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
