# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: ITD - Test/Train/Vaildation: 70/20/10
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 329.63
# - MAE: 232.67
# - MAPE: 2.14 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 0

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170
# ...           ...
# 2024-05-27  11300
# 2024-05-28  12050
# 2024-05-29  12600
# 2024-05-30  12500
# 2024-05-31  12700
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        6900
# 1        7100
# 2        7100
# 3        7170
# 4        7170
#         ...
# 1308    11300
# 1309    12050
# 1310    12600
# 1311    12500
# 1312    12700
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((908, 10), (908,), (251, 10), (251,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 22ms/step - loss: 0.0613 - mean_absolute_error: 0.1679 - val_loss: 0.0037 - val_mean_absolute_error: 0.0560
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0034 - mean_absolute_error: 0.0388 - val_loss: 5.7856e-04 - val_mean_absolute_error: 0.0192
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0018 - mean_absolute_error: 0.0268 - val_loss: 6.6106e-04 - val_mean_absolute_error: 0.0184
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - mean_absolute_error: 0.0257 - val_loss: 8.3135e-04 - val_mean_absolute_error: 0.0247
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0019 - mean_absolute_error: 0.0283 - val_loss: 6.0205e-04 - val_mean_absolute_error: 0.0174
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - mean_absolute_error: 0.0253 - val_loss: 5.1532e-04 - val_mean_absolute_error: 0.0167
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014 - mean_absolute_error: 0.0240 - val_loss: 5.3392e-04 - val_mean_absolute_error: 0.0181
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0016 - mean_absolute_error: 0.0251 - val_loss: 5.3715e-04 - val_mean_absolute_error: 0.0183
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0019 - mean_absolute_error: 0.0273 - val_loss: 7.2445e-04 - val_mean_absolute_error: 0.0228
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0017 - mean_absolute_error: 0.0267 - val_loss: 7.5593e-04 - val_mean_absolute_error: 0.0234
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0016 - mean_absolute_error: 0.0239 - val_loss: 5.4047e-04 - val_mean_absolute_error: 0.0186
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0014 - mean_absolute_error: 0.0231 - val_loss: 4.8016e-04 - val_mean_absolute_error: 0.0159
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015 - mean_absolute_error: 0.0257 - val_loss: 4.9527e-04 - val_mean_absolute_error: 0.0158
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014 - mean_absolute_error: 0.0243 - val_loss: 5.4034e-04 - val_mean_absolute_error: 0.0187
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0018 - mean_absolute_error: 0.0275 - val_loss: 5.3085e-04 - val_mean_absolute_error: 0.0163
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014 - mean_absolute_error: 0.0232 - val_loss: 4.7729e-04 - val_mean_absolute_error: 0.0154
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014 - mean_absolute_error: 0.0233 - val_loss: 5.5693e-04 - val_mean_absolute_error: 0.0192
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013 - mean_absolute_error: 0.0224 - val_loss: 6.3141e-04 - val_mean_absolute_error: 0.0210
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - mean_absolute_error: 0.0222 - val_loss: 4.8295e-04 - val_mean_absolute_error: 0.0172
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014 - mean_absolute_error: 0.0243 - val_loss: 4.5298e-04 - val_mean_absolute_error: 0.0163
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - mean_absolute_error: 0.0210 - val_loss: 4.2193e-04 - val_mean_absolute_error: 0.0145
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0012 - mean_absolute_error: 0.0217 - val_loss: 4.1773e-04 - val_mean_absolute_error: 0.0150
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012 - mean_absolute_error: 0.0217 - val_loss: 4.0796e-04 - val_mean_absolute_error: 0.0144
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.3657e-04 - mean_absolute_error: 0.0193 - val_loss: 6.9368e-04 - val_mean_absolute_error: 0.0224
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0011 - mean_absolute_error: 0.0212 - val_loss: 3.9248e-04 - val_mean_absolute_error: 0.0142
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.5592e-04 - mean_absolute_error: 0.0188 - val_loss: 4.6748e-04 - val_mean_absolute_error: 0.0171
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.4389e-04 - mean_absolute_error: 0.0184 - val_loss: 0.0012 - val_mean_absolute_error: 0.0309
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014 - mean_absolute_error: 0.0246 - val_loss: 9.3328e-04 - val_mean_absolute_error: 0.0268
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - mean_absolute_error: 0.0215 - val_loss: 3.7954e-04 - val_mean_absolute_error: 0.0137
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9755e-04 - mean_absolute_error: 0.0183 - val_loss: 3.6867e-04 - val_mean_absolute_error: 0.0134
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.6664e-04 - mean_absolute_error: 0.0183 - val_loss: 7.3931e-04 - val_mean_absolute_error: 0.0235
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.6010e-04 - mean_absolute_error: 0.0190 - val_loss: 3.7063e-04 - val_mean_absolute_error: 0.0136
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.6262e-04 - mean_absolute_error: 0.0186 - val_loss: 5.0502e-04 - val_mean_absolute_error: 0.0183
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9333e-04 - mean_absolute_error: 0.0187 - val_loss: 4.5111e-04 - val_mean_absolute_error: 0.0168
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0011 - mean_absolute_error: 0.0215 - val_loss: 7.0229e-04 - val_mean_absolute_error: 0.0229
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.6622e-04 - mean_absolute_error: 0.0192 - val_loss: 3.7528e-04 - val_mean_absolute_error: 0.0142
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.7571e-04 - mean_absolute_error: 0.0176 - val_loss: 3.5357e-04 - val_mean_absolute_error: 0.0132
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1803e-04 - mean_absolute_error: 0.0179 - val_loss: 3.4568e-04 - val_mean_absolute_error: 0.0130
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.2551e-04 - mean_absolute_error: 0.0189 - val_loss: 3.7181e-04 - val_mean_absolute_error: 0.0136
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.8065e-04 - mean_absolute_error: 0.0197 - val_loss: 3.5246e-04 - val_mean_absolute_error: 0.0136
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.8209e-04 - mean_absolute_error: 0.0189 - val_loss: 3.3805e-04 - val_mean_absolute_error: 0.0131
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5572e-04 - mean_absolute_error: 0.0179 - val_loss: 3.7025e-04 - val_mean_absolute_error: 0.0137
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9480e-04 - mean_absolute_error: 0.0170 - val_loss: 4.4909e-04 - val_mean_absolute_error: 0.0171
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2196e-04 - mean_absolute_error: 0.0193 - val_loss: 3.2482e-04 - val_mean_absolute_error: 0.0128
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7052e-04 - mean_absolute_error: 0.0165 - val_loss: 3.7796e-04 - val_mean_absolute_error: 0.0149
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3252e-04 - mean_absolute_error: 0.0162 - val_loss: 3.4437e-04 - val_mean_absolute_error: 0.0137
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6143e-04 - mean_absolute_error: 0.0162 - val_loss: 5.1217e-04 - val_mean_absolute_error: 0.0177
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1232e-04 - mean_absolute_error: 0.0173 - val_loss: 3.2184e-04 - val_mean_absolute_error: 0.0130
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1094e-04 - mean_absolute_error: 0.0161 - val_loss: 3.0786e-04 - val_mean_absolute_error: 0.0125
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4188e-04 - mean_absolute_error: 0.0158 - val_loss: 3.3967e-04 - val_mean_absolute_error: 0.0131
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.8206e-04 - mean_absolute_error: 0.0199 - val_loss: 6.0521e-04 - val_mean_absolute_error: 0.0213
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.0599e-04 - mean_absolute_error: 0.0185 - val_loss: 3.5719e-04 - val_mean_absolute_error: 0.0136
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.0528e-04 - mean_absolute_error: 0.0157 - val_loss: 4.0303e-04 - val_mean_absolute_error: 0.0161
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9725e-04 - mean_absolute_error: 0.0157 - val_loss: 2.9386e-04 - val_mean_absolute_error: 0.0121
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6697e-04 - mean_absolute_error: 0.0162 - val_loss: 2.9046e-04 - val_mean_absolute_error: 0.0120
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.0428e-04 - mean_absolute_error: 0.0168 - val_loss: 6.7772e-04 - val_mean_absolute_error: 0.0228
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2205e-04 - mean_absolute_error: 0.0202 - val_loss: 4.4612e-04 - val_mean_absolute_error: 0.0163
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.0446e-04 - mean_absolute_error: 0.0179 - val_loss: 4.6699e-04 - val_mean_absolute_error: 0.0182
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9479e-04 - mean_absolute_error: 0.0188 - val_loss: 4.1806e-04 - val_mean_absolute_error: 0.0168
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4860e-04 - mean_absolute_error: 0.0147 - val_loss: 2.8123e-04 - val_mean_absolute_error: 0.0121
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4875e-04 - mean_absolute_error: 0.0147 - val_loss: 2.8804e-04 - val_mean_absolute_error: 0.0120
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3668e-04 - mean_absolute_error: 0.0158 - val_loss: 3.4462e-04 - val_mean_absolute_error: 0.0146
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7785e-04 - mean_absolute_error: 0.0161 - val_loss: 3.2035e-04 - val_mean_absolute_error: 0.0130
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2940e-04 - mean_absolute_error: 0.0142 - val_loss: 4.4606e-04 - val_mean_absolute_error: 0.0177
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.3912e-04 - mean_absolute_error: 0.0164 - val_loss: 3.3414e-04 - val_mean_absolute_error: 0.0134
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6892e-04 - mean_absolute_error: 0.0153 - val_loss: 2.6021e-04 - val_mean_absolute_error: 0.0114
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.6846e-04 - mean_absolute_error: 0.0152 - val_loss: 2.5774e-04 - val_mean_absolute_error: 0.0114
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7089e-04 - mean_absolute_error: 0.0138 - val_loss: 3.4941e-04 - val_mean_absolute_error: 0.0141
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.5700e-04 - mean_absolute_error: 0.0153 - val_loss: 3.2281e-04 - val_mean_absolute_error: 0.0142
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9736e-04 - mean_absolute_error: 0.0159 - val_loss: 2.5282e-04 - val_mean_absolute_error: 0.0113
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7174e-04 - mean_absolute_error: 0.0141 - val_loss: 3.7992e-04 - val_mean_absolute_error: 0.0152
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.4707e-04 - mean_absolute_error: 0.0153 - val_loss: 2.4747e-04 - val_mean_absolute_error: 0.0112
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6036e-04 - mean_absolute_error: 0.0143 - val_loss: 9.2271e-04 - val_mean_absolute_error: 0.0273
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.7030e-04 - mean_absolute_error: 0.0199 - val_loss: 2.9136e-04 - val_mean_absolute_error: 0.0125
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3602e-04 - mean_absolute_error: 0.0155 - val_loss: 2.6883e-04 - val_mean_absolute_error: 0.0118
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9408e-04 - mean_absolute_error: 0.0128 - val_loss: 2.4256e-04 - val_mean_absolute_error: 0.0111
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.0970e-04 - mean_absolute_error: 0.0128 - val_loss: 2.4247e-04 - val_mean_absolute_error: 0.0111
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.3529e-04 - mean_absolute_error: 0.0151 - val_loss: 2.7888e-04 - val_mean_absolute_error: 0.0128
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0706e-04 - mean_absolute_error: 0.0155 - val_loss: 4.6341e-04 - val_mean_absolute_error: 0.0183
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.4031e-04 - mean_absolute_error: 0.0138 - val_loss: 2.5700e-04 - val_mean_absolute_error: 0.0120
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4172e-04 - mean_absolute_error: 0.0137 - val_loss: 4.1575e-04 - val_mean_absolute_error: 0.0171
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.6621e-04 - mean_absolute_error: 0.0144 - val_loss: 2.5785e-04 - val_mean_absolute_error: 0.0116
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1932e-04 - mean_absolute_error: 0.0134 - val_loss: 3.5815e-04 - val_mean_absolute_error: 0.0155
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9939e-04 - mean_absolute_error: 0.0129 - val_loss: 2.7307e-04 - val_mean_absolute_error: 0.0122
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.9349e-04 - mean_absolute_error: 0.0129 - val_loss: 3.1866e-04 - val_mean_absolute_error: 0.0137
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.0439e-04 - mean_absolute_error: 0.0145 - val_loss: 2.3356e-04 - val_mean_absolute_error: 0.0109
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.8177e-04 - mean_absolute_error: 0.0141 - val_loss: 2.6311e-04 - val_mean_absolute_error: 0.0123
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3089e-04 - mean_absolute_error: 0.0136 - val_loss: 4.8314e-04 - val_mean_absolute_error: 0.0183
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1531e-04 - mean_absolute_error: 0.0151 - val_loss: 2.6443e-04 - val_mean_absolute_error: 0.0120
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7082e-04 - mean_absolute_error: 0.0140 - val_loss: 2.3757e-04 - val_mean_absolute_error: 0.0110
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.0270e-04 - mean_absolute_error: 0.0127 - val_loss: 2.3281e-04 - val_mean_absolute_error: 0.0109
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.1596e-04 - mean_absolute_error: 0.0145 - val_loss: 4.4153e-04 - val_mean_absolute_error: 0.0178
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7321e-04 - mean_absolute_error: 0.0153 - val_loss: 2.8082e-04 - val_mean_absolute_error: 0.0126
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9924e-04 - mean_absolute_error: 0.0128 - val_loss: 3.1731e-04 - val_mean_absolute_error: 0.0142
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8695e-04 - mean_absolute_error: 0.0129 - val_loss: 5.9838e-04 - val_mean_absolute_error: 0.0213
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.6747e-04 - mean_absolute_error: 0.0147 - val_loss: 2.7365e-04 - val_mean_absolute_error: 0.0124
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4159e-04 - mean_absolute_error: 0.0134 - val_loss: 2.4750e-04 - val_mean_absolute_error: 0.0115
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4452e-04 - mean_absolute_error: 0.0137 - val_loss: 2.2938e-04 - val_mean_absolute_error: 0.0107
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1139e-04 - mean_absolute_error: 0.0133 - val_loss: 3.8795e-04 - val_mean_absolute_error: 0.0163
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.2522e-04 - mean_absolute_error: 0.0137 - val_loss: 2.3159e-04 - val_mean_absolute_error: 0.0109
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1564e-04 - mean_absolute_error: 0.0132 - val_loss: 2.6058e-04 - val_mean_absolute_error: 0.0122
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.7629e-04 - mean_absolute_error: 0.0130 - val_loss: 3.1491e-04 - val_mean_absolute_error: 0.0141
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4153e-04 - mean_absolute_error: 0.0163 - val_loss: 2.6473e-04 - val_mean_absolute_error: 0.0121
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.5645e-04 - mean_absolute_error: 0.0139 - val_loss: 2.3971e-04 - val_mean_absolute_error: 0.0112
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0420e-04 - mean_absolute_error: 0.0132 - val_loss: 2.4486e-04 - val_mean_absolute_error: 0.0114
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9105e-04 - mean_absolute_error: 0.0133 - val_loss: 2.5681e-04 - val_mean_absolute_error: 0.0120
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4982e-04 - mean_absolute_error: 0.0142 - val_loss: 3.1120e-04 - val_mean_absolute_error: 0.0138
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0099e-04 - mean_absolute_error: 0.0150 - val_loss: 3.6601e-04 - val_mean_absolute_error: 0.0156
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8299e-04 - mean_absolute_error: 0.0130 - val_loss: 2.7555e-04 - val_mean_absolute_error: 0.0127
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9477e-04 - mean_absolute_error: 0.0130 - val_loss: 3.4980e-04 - val_mean_absolute_error: 0.0148
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9741e-04 - mean_absolute_error: 0.0129 - val_loss: 2.3557e-04 - val_mean_absolute_error: 0.0110
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7854e-04 - mean_absolute_error: 0.0126 - val_loss: 2.6304e-04 - val_mean_absolute_error: 0.0122
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.2046e-04 - mean_absolute_error: 0.0134 - val_loss: 2.9503e-04 - val_mean_absolute_error: 0.0132
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9750e-04 - mean_absolute_error: 0.0127 - val_loss: 2.5712e-04 - val_mean_absolute_error: 0.0119
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6968e-04 - mean_absolute_error: 0.0129 - val_loss: 2.3477e-04 - val_mean_absolute_error: 0.0110
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7131e-04 - mean_absolute_error: 0.0124 - val_loss: 2.7932e-04 - val_mean_absolute_error: 0.0128
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7740e-04 - mean_absolute_error: 0.0123 - val_loss: 2.7079e-04 - val_mean_absolute_error: 0.0124
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3273e-04 - mean_absolute_error: 0.0141 - val_loss: 3.7210e-04 - val_mean_absolute_error: 0.0158
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.7756e-04 - mean_absolute_error: 0.0147 - val_loss: 2.5410e-04 - val_mean_absolute_error: 0.0118
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0450e-04 - mean_absolute_error: 0.0127 - val_loss: 2.3682e-04 - val_mean_absolute_error: 0.0111
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6142e-04 - mean_absolute_error: 0.0123 - val_loss: 2.6297e-04 - val_mean_absolute_error: 0.0122
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7359e-04 - mean_absolute_error: 0.0150 - val_loss: 2.5844e-04 - val_mean_absolute_error: 0.0120
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.4555e-04 - mean_absolute_error: 0.0126 - val_loss: 2.4200e-04 - val_mean_absolute_error: 0.0113
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3539e-04 - mean_absolute_error: 0.0138 - val_loss: 2.3971e-04 - val_mean_absolute_error: 0.0112
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.2319e-04 - mean_absolute_error: 0.0132 - val_loss: 2.6725e-04 - val_mean_absolute_error: 0.0122
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8847e-04 - mean_absolute_error: 0.0130 - val_loss: 2.7048e-04 - val_mean_absolute_error: 0.0123
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6818e-04 - mean_absolute_error: 0.0129 - val_loss: 3.2997e-04 - val_mean_absolute_error: 0.0145
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9649e-04 - mean_absolute_error: 0.0141 - val_loss: 3.2381e-04 - val_mean_absolute_error: 0.0143
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.8118e-04 - mean_absolute_error: 0.0146 - val_loss: 3.3437e-04 - val_mean_absolute_error: 0.0144
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8716e-04 - mean_absolute_error: 0.0133 - val_loss: 3.4172e-04 - val_mean_absolute_error: 0.0146
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7353e-04 - mean_absolute_error: 0.0133 - val_loss: 4.1130e-04 - val_mean_absolute_error: 0.0165
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.5081e-04 - mean_absolute_error: 0.0143 - val_loss: 4.4425e-04 - val_mean_absolute_error: 0.0173
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1980e-04 - mean_absolute_error: 0.0156 - val_loss: 3.4380e-04 - val_mean_absolute_error: 0.0150
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0136e-04 - mean_absolute_error: 0.0139 - val_loss: 2.4020e-04 - val_mean_absolute_error: 0.0112
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1220e-04 - mean_absolute_error: 0.0135 - val_loss: 2.7051e-04 - val_mean_absolute_error: 0.0123
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.0479e-04 - mean_absolute_error: 0.0133 - val_loss: 2.3756e-04 - val_mean_absolute_error: 0.0111
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5547e-04 - mean_absolute_error: 0.0123 - val_loss: 3.2653e-04 - val_mean_absolute_error: 0.0144
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2667e-04 - mean_absolute_error: 0.0134 - val_loss: 2.4644e-04 - val_mean_absolute_error: 0.0114
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7679e-04 - mean_absolute_error: 0.0144 - val_loss: 2.5070e-04 - val_mean_absolute_error: 0.0116
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1244e-04 - mean_absolute_error: 0.0132 - val_loss: 2.3738e-04 - val_mean_absolute_error: 0.0111
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9968e-04 - mean_absolute_error: 0.0126 - val_loss: 2.4970e-04 - val_mean_absolute_error: 0.0116
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6708e-04 - mean_absolute_error: 0.0129 - val_loss: 2.3853e-04 - val_mean_absolute_error: 0.0111
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7803e-04 - mean_absolute_error: 0.0127 - val_loss: 2.4813e-04 - val_mean_absolute_error: 0.0115
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8734e-04 - mean_absolute_error: 0.0127 - val_loss: 3.2325e-04 - val_mean_absolute_error: 0.0142
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4386e-04 - mean_absolute_error: 0.0125 - val_loss: 3.3214e-04 - val_mean_absolute_error: 0.0145
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9077e-04 - mean_absolute_error: 0.0133 - val_loss: 3.2058e-04 - val_mean_absolute_error: 0.0140
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5990e-04 - mean_absolute_error: 0.0128 - val_loss: 3.6405e-04 - val_mean_absolute_error: 0.0154
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.2525e-04 - mean_absolute_error: 0.0137 - val_loss: 2.4153e-04 - val_mean_absolute_error: 0.0112
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6912e-04 - mean_absolute_error: 0.0127 - val_loss: 3.2616e-04 - val_mean_absolute_error: 0.0143
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.5549e-04 - mean_absolute_error: 0.0141 - val_loss: 2.5465e-04 - val_mean_absolute_error: 0.0118
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5233e-04 - mean_absolute_error: 0.0122 - val_loss: 3.2353e-04 - val_mean_absolute_error: 0.0143
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8442e-04 - mean_absolute_error: 0.0132 - val_loss: 2.6301e-04 - val_mean_absolute_error: 0.0121
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3351e-04 - mean_absolute_error: 0.0141 - val_loss: 3.2116e-04 - val_mean_absolute_error: 0.0141
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7243e-04 - mean_absolute_error: 0.0127 - val_loss: 2.4253e-04 - val_mean_absolute_error: 0.0112
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5556e-04 - mean_absolute_error: 0.0124 - val_loss: 2.3842e-04 - val_mean_absolute_error: 0.0111
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8105e-04 - mean_absolute_error: 0.0134 - val_loss: 2.3825e-04 - val_mean_absolute_error: 0.0111
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2515e-04 - mean_absolute_error: 0.0136 - val_loss: 3.3766e-04 - val_mean_absolute_error: 0.0146
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2166e-04 - mean_absolute_error: 0.0138 - val_loss: 2.6832e-04 - val_mean_absolute_error: 0.0123
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.5343e-04 - mean_absolute_error: 0.0135 - val_loss: 2.5493e-04 - val_mean_absolute_error: 0.0118
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5627e-04 - mean_absolute_error: 0.0126 - val_loss: 2.5022e-04 - val_mean_absolute_error: 0.0116
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9681e-04 - mean_absolute_error: 0.0128 - val_loss: 2.7372e-04 - val_mean_absolute_error: 0.0124
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6516e-04 - mean_absolute_error: 0.0126 - val_loss: 2.9722e-04 - val_mean_absolute_error: 0.0133
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2443e-04 - mean_absolute_error: 0.0137 - val_loss: 2.9891e-04 - val_mean_absolute_error: 0.0133
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1639e-04 - mean_absolute_error: 0.0135 - val_loss: 2.3883e-04 - val_mean_absolute_error: 0.0111
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0791e-04 - mean_absolute_error: 0.0131 - val_loss: 2.5690e-04 - val_mean_absolute_error: 0.0118
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4435e-04 - mean_absolute_error: 0.0119 - val_loss: 2.3941e-04 - val_mean_absolute_error: 0.0111
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2265e-04 - mean_absolute_error: 0.0120 - val_loss: 2.6829e-04 - val_mean_absolute_error: 0.0123
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6854e-04 - mean_absolute_error: 0.0145 - val_loss: 2.6395e-04 - val_mean_absolute_error: 0.0121
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.5160e-04 - mean_absolute_error: 0.0135 - val_loss: 2.4716e-04 - val_mean_absolute_error: 0.0115
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1885e-04 - mean_absolute_error: 0.0136 - val_loss: 2.4314e-04 - val_mean_absolute_error: 0.0113
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1752e-04 - mean_absolute_error: 0.0135 - val_loss: 3.0679e-04 - val_mean_absolute_error: 0.0137
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.2565e-04 - mean_absolute_error: 0.0122 - val_loss: 2.4045e-04 - val_mean_absolute_error: 0.0112
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.3914e-04 - mean_absolute_error: 0.0120 - val_loss: 2.6391e-04 - val_mean_absolute_error: 0.0121
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1623e-04 - mean_absolute_error: 0.0134 - val_loss: 2.4007e-04 - val_mean_absolute_error: 0.0112
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8472e-04 - mean_absolute_error: 0.0131 - val_loss: 2.7207e-04 - val_mean_absolute_error: 0.0123
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.0983e-04 - mean_absolute_error: 0.0135 - val_loss: 2.4162e-04 - val_mean_absolute_error: 0.0112
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7824e-04 - mean_absolute_error: 0.0127 - val_loss: 4.8267e-04 - val_mean_absolute_error: 0.0185
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8429e-04 - mean_absolute_error: 0.0134 - val_loss: 2.5504e-04 - val_mean_absolute_error: 0.0118
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3552e-04 - mean_absolute_error: 0.0140 - val_loss: 2.5990e-04 - val_mean_absolute_error: 0.0120
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8313e-04 - mean_absolute_error: 0.0131 - val_loss: 2.4200e-04 - val_mean_absolute_error: 0.0113
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9449e-04 - mean_absolute_error: 0.0133 - val_loss: 2.5339e-04 - val_mean_absolute_error: 0.0117
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2711e-04 - mean_absolute_error: 0.0147 - val_loss: 2.4778e-04 - val_mean_absolute_error: 0.0115
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4071e-04 - mean_absolute_error: 0.0119 - val_loss: 2.8911e-04 - val_mean_absolute_error: 0.0130
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6214e-04 - mean_absolute_error: 0.0127 - val_loss: 2.4146e-04 - val_mean_absolute_error: 0.0112
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0218e-04 - mean_absolute_error: 0.0129 - val_loss: 4.3489e-04 - val_mean_absolute_error: 0.0173
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6588e-04 - mean_absolute_error: 0.0155 - val_loss: 3.2120e-04 - val_mean_absolute_error: 0.0141
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1210e-04 - mean_absolute_error: 0.0137 - val_loss: 2.7762e-04 - val_mean_absolute_error: 0.0125
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.2730e-04 - mean_absolute_error: 0.0142 - val_loss: 2.5692e-04 - val_mean_absolute_error: 0.0118
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0003e-04 - mean_absolute_error: 0.0132 - val_loss: 2.4109e-04 - val_mean_absolute_error: 0.0112
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8301e-04 - mean_absolute_error: 0.0125 - val_loss: 2.3935e-04 - val_mean_absolute_error: 0.0111
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5224e-04 - mean_absolute_error: 0.0123 - val_loss: 2.5994e-04 - val_mean_absolute_error: 0.0120
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4029e-04 - mean_absolute_error: 0.0120 - val_loss: 2.6089e-04 - val_mean_absolute_error: 0.0120
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.2749e-04 - mean_absolute_error: 0.0141 - val_loss: 2.6029e-04 - val_mean_absolute_error: 0.0120
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.6104e-04 - mean_absolute_error: 0.0149 - val_loss: 3.6331e-04 - val_mean_absolute_error: 0.0152
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8322e-04 - mean_absolute_error: 0.0134 - val_loss: 2.5779e-04 - val_mean_absolute_error: 0.0119
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9930e-04 - mean_absolute_error: 0.0132 - val_loss: 2.3921e-04 - val_mean_absolute_error: 0.0111
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6906e-04 - mean_absolute_error: 0.0124 - val_loss: 2.5144e-04 - val_mean_absolute_error: 0.0116
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8336e-04 - mean_absolute_error: 0.0131 - val_loss: 2.4427e-04 - val_mean_absolute_error: 0.0113
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.9567e-04 - mean_absolute_error: 0.0127 - val_loss: 2.3970e-04 - val_mean_absolute_error: 0.0111
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.1890e-04 - mean_absolute_error: 0.0116 - val_loss: 2.4645e-04 - val_mean_absolute_error: 0.0114

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1496e-04 - mean_absolute_error: 0.0129
# Test Loss: [0.0002464537392370403, 0.01144740916788578]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 101571.61389654472
# RMSE: 318.70301833610665
# MAE: 227.92270371638446
# MAPE: 2.0542011345404068 %
#
# Model evalution on validate set
# MSE: 76549.72433142229
# RMSE: 276.6762084665436
# MAE: 188.82455772210744
# MAPE: 1.809739227500885 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step

# %%
y_pred_30_days
# Out:
# array([[12693.739],
#        [12653.62 ],
#        [12686.16 ],
#        [12672.624],
#        [12680.292],
#        [12676.751],
#        [12678.614],
#        [12677.702],
#        [12678.166],
#        [12677.937],
#        [12678.053],
#        [12677.995],
#        [12678.022],
#        [12678.008],
#        [12678.016],
#        [12678.013],
#        [12678.015],
#        [12678.013],
#        [12678.014],
#        [12678.014],
#        [12678.013],
#        [12678.013],
#        [12678.014],
#        [12678.013],
#        [12678.013],
#        [12678.014],
#        [12678.013],
#        [12678.013],
#        [12678.014],
#        [12678.013],
#        [12678.013]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
