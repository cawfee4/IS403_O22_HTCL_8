# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

plt.style.use('default')

# %% [markdown]
# ## 1. Data preprocessing

# %%
split_type = [0.8,0.7,0.9]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 1  # 70% train, 30% test

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#              close
# time
# 2019-03-01   19270
# 2019-03-04   19440
# 2019-03-05   19390
# 2019-03-06   19270
# 2019-03-07   19330
# ...            ...
# 2024-05-27  132800
# 2024-05-28  137000
# 2024-05-29  135700
# 2024-05-30  135000
# 2024-05-31  134600
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using neural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split] * len(df_scaled))
test_size = len(df_scaled) - train_size

# %%
# Splitting data into train, test set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size:]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((908, 10), (908,), (383, 10), (383,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,961 (66.25 KB)
#  Trainable params: 16,961 (66.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE
)
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0223 - mean_absolute_error: 0.1057
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0278
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.4998e-04 - mean_absolute_error: 0.0111
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0490e-04 - mean_absolute_error: 0.0101
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9498e-04 - mean_absolute_error: 0.0093
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7245e-04 - mean_absolute_error: 0.0089
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.2625e-04 - mean_absolute_error: 0.0100
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7264e-04 - mean_absolute_error: 0.0089
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7214e-04 - mean_absolute_error: 0.0086
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9056e-04 - mean_absolute_error: 0.0089
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8359e-04 - mean_absolute_error: 0.0089
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7020e-04 - mean_absolute_error: 0.0085
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8880e-04 - mean_absolute_error: 0.0091
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6525e-04 - mean_absolute_error: 0.0088
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5622e-04 - mean_absolute_error: 0.0082
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6770e-04 - mean_absolute_error: 0.0084
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7597e-04 - mean_absolute_error: 0.0084
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7636e-04 - mean_absolute_error: 0.0087
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7596e-04 - mean_absolute_error: 0.0089
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6022e-04 - mean_absolute_error: 0.0086
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7038e-04 - mean_absolute_error: 0.0084
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6882e-04 - mean_absolute_error: 0.0083
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4102e-04 - mean_absolute_error: 0.0080
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5296e-04 - mean_absolute_error: 0.0079
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6344e-04 - mean_absolute_error: 0.0086
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5398e-04 - mean_absolute_error: 0.0082
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6449e-04 - mean_absolute_error: 0.0085
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4018e-04 - mean_absolute_error: 0.0078
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5974e-04 - mean_absolute_error: 0.0082
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5964e-04 - mean_absolute_error: 0.0088
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5916e-04 - mean_absolute_error: 0.0082
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4089e-04 - mean_absolute_error: 0.0080
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3230e-04 - mean_absolute_error: 0.0075
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6397e-04 - mean_absolute_error: 0.0087
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4742e-04 - mean_absolute_error: 0.0080
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4193e-04 - mean_absolute_error: 0.0081
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3165e-04 - mean_absolute_error: 0.0078
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4749e-04 - mean_absolute_error: 0.0081
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6248e-04 - mean_absolute_error: 0.0085
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3443e-04 - mean_absolute_error: 0.0078
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4278e-04 - mean_absolute_error: 0.0078
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4283e-04 - mean_absolute_error: 0.0079
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4424e-04 - mean_absolute_error: 0.0081
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2939e-04 - mean_absolute_error: 0.0078
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4576e-04 - mean_absolute_error: 0.0082
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4485e-04 - mean_absolute_error: 0.0079
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4331e-04 - mean_absolute_error: 0.0081
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2731e-04 - mean_absolute_error: 0.0074
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3751e-04 - mean_absolute_error: 0.0077
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4598e-04 - mean_absolute_error: 0.0084
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5020e-04 - mean_absolute_error: 0.0085
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2142e-04 - mean_absolute_error: 0.0074
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1639e-04 - mean_absolute_error: 0.0070
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6429e-04 - mean_absolute_error: 0.0084
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3547e-04 - mean_absolute_error: 0.0078
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2306e-04 - mean_absolute_error: 0.0078
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2759e-04 - mean_absolute_error: 0.0078
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2762e-04 - mean_absolute_error: 0.0081
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1542e-04 - mean_absolute_error: 0.0072
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1556e-04 - mean_absolute_error: 0.0072
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0065e-04 - mean_absolute_error: 0.0068
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1436e-04 - mean_absolute_error: 0.0072
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4218e-04 - mean_absolute_error: 0.0082
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0304e-04 - mean_absolute_error: 0.0067
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1517e-04 - mean_absolute_error: 0.0072
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1582e-04 - mean_absolute_error: 0.0069
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2286e-04 - mean_absolute_error: 0.0072
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3076e-04 - mean_absolute_error: 0.0079
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2674e-04 - mean_absolute_error: 0.0075
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4198e-05 - mean_absolute_error: 0.0065
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4682e-04 - mean_absolute_error: 0.0081
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0280e-04 - mean_absolute_error: 0.0067
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0545e-04 - mean_absolute_error: 0.0067
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0880e-04 - mean_absolute_error: 0.0071
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0411e-04 - mean_absolute_error: 0.0068
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0515e-04 - mean_absolute_error: 0.0069
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0879e-04 - mean_absolute_error: 0.0070
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0497e-04 - mean_absolute_error: 0.0068
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6484e-05 - mean_absolute_error: 0.0067
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1585e-04 - mean_absolute_error: 0.0071
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1910e-04 - mean_absolute_error: 0.0074
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0703e-04 - mean_absolute_error: 0.0070
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0111e-04 - mean_absolute_error: 0.0069
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9598e-05 - mean_absolute_error: 0.0068
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0743e-04 - mean_absolute_error: 0.0071
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2330e-04 - mean_absolute_error: 0.0071
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0430e-04 - mean_absolute_error: 0.0068
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.2171e-05 - mean_absolute_error: 0.0065
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.7681e-05 - mean_absolute_error: 0.0064
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1975e-04 - mean_absolute_error: 0.0076
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0827e-04 - mean_absolute_error: 0.0071
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0959e-04 - mean_absolute_error: 0.0075
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.4001e-05 - mean_absolute_error: 0.0065
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.9620e-05 - mean_absolute_error: 0.0068
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1726e-04 - mean_absolute_error: 0.0077
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0438e-04 - mean_absolute_error: 0.0068
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0904e-04 - mean_absolute_error: 0.0073
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.0609e-05 - mean_absolute_error: 0.0064
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.3685e-05 - mean_absolute_error: 0.0067
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0368e-04 - mean_absolute_error: 0.0072
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0919e-04 - mean_absolute_error: 0.0068
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0779e-04 - mean_absolute_error: 0.0070
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0536e-04 - mean_absolute_error: 0.0067
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7571e-05 - mean_absolute_error: 0.0062
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4314e-05 - mean_absolute_error: 0.0061
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.3591e-05 - mean_absolute_error: 0.0063
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0660e-04 - mean_absolute_error: 0.0068
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0290e-04 - mean_absolute_error: 0.0066
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7191e-05 - mean_absolute_error: 0.0062
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0553e-04 - mean_absolute_error: 0.0068
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0033e-04 - mean_absolute_error: 0.0067
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.9164e-05 - mean_absolute_error: 0.0064
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4883e-05 - mean_absolute_error: 0.0060
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5004e-05 - mean_absolute_error: 0.0062
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.8181e-05 - mean_absolute_error: 0.0066
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.1677e-05 - mean_absolute_error: 0.0063
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1551e-05 - mean_absolute_error: 0.0059
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0767e-04 - mean_absolute_error: 0.0066
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0188e-04 - mean_absolute_error: 0.0069
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.2724e-05 - mean_absolute_error: 0.0063
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4354e-05 - mean_absolute_error: 0.0065
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.9804e-05 - mean_absolute_error: 0.0063
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0206e-04 - mean_absolute_error: 0.0066
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6057e-05 - mean_absolute_error: 0.0065
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.1423e-05 - mean_absolute_error: 0.0061
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.6844e-05 - mean_absolute_error: 0.0063
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.9161e-05 - mean_absolute_error: 0.0065
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9814e-05 - mean_absolute_error: 0.0060
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4727e-05 - mean_absolute_error: 0.0062
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1900e-05 - mean_absolute_error: 0.0060
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.0560e-05 - mean_absolute_error: 0.0063
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.2993e-05 - mean_absolute_error: 0.0061
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4380e-05 - mean_absolute_error: 0.0059
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7743e-05 - mean_absolute_error: 0.0062
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.2146e-05 - mean_absolute_error: 0.0063
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1381e-05 - mean_absolute_error: 0.0058
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.5610e-05 - mean_absolute_error: 0.0066
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4874e-05 - mean_absolute_error: 0.0063
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0654e-05 - mean_absolute_error: 0.0059
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4810e-05 - mean_absolute_error: 0.0059
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7529e-05 - mean_absolute_error: 0.0062
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.1861e-05 - mean_absolute_error: 0.0068
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6152e-05 - mean_absolute_error: 0.0057
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.6095e-05 - mean_absolute_error: 0.0060
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1156e-04 - mean_absolute_error: 0.0072
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0216e-05 - mean_absolute_error: 0.0056
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.4983e-05 - mean_absolute_error: 0.0059
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.4856e-05 - mean_absolute_error: 0.0059
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7677e-05 - mean_absolute_error: 0.0061
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.6625e-05 - mean_absolute_error: 0.0061
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3017e-05 - mean_absolute_error: 0.0055
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9208e-05 - mean_absolute_error: 0.0059
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.6205e-05 - mean_absolute_error: 0.0054
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.6541e-05 - mean_absolute_error: 0.0064
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9171e-05 - mean_absolute_error: 0.0058
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.2482e-05 - mean_absolute_error: 0.0061
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.5366e-05 - mean_absolute_error: 0.0052
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.9617e-05 - mean_absolute_error: 0.0071
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.9101e-05 - mean_absolute_error: 0.0065
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8176e-05 - mean_absolute_error: 0.0058
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0082e-05 - mean_absolute_error: 0.0057
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.8498e-05 - mean_absolute_error: 0.0061
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1121e-05 - mean_absolute_error: 0.0058
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3948e-05 - mean_absolute_error: 0.0057
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9422e-05 - mean_absolute_error: 0.0058
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3720e-05 - mean_absolute_error: 0.0055
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9636e-05 - mean_absolute_error: 0.0057
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9037e-05 - mean_absolute_error: 0.0061
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9322e-05 - mean_absolute_error: 0.0061
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.2519e-05 - mean_absolute_error: 0.0059
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3348e-05 - mean_absolute_error: 0.0063
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8230e-05 - mean_absolute_error: 0.0058
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3013e-05 - mean_absolute_error: 0.0054
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8085e-05 - mean_absolute_error: 0.0055
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0266e-05 - mean_absolute_error: 0.0054
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0349e-05 - mean_absolute_error: 0.0058
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.2998e-05 - mean_absolute_error: 0.0051
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8951e-05 - mean_absolute_error: 0.0053
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.0880e-05 - mean_absolute_error: 0.0067
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1807e-05 - mean_absolute_error: 0.0054
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1605e-05 - mean_absolute_error: 0.0057
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8424e-05 - mean_absolute_error: 0.0055
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3148e-05 - mean_absolute_error: 0.0056
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8300e-05 - mean_absolute_error: 0.0059
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.3536e-05 - mean_absolute_error: 0.0057
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3375e-05 - mean_absolute_error: 0.0052
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.8339e-05 - mean_absolute_error: 0.0059
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.7995e-05 - mean_absolute_error: 0.0056
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3407e-05 - mean_absolute_error: 0.0054
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0530e-05 - mean_absolute_error: 0.0059
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.9655e-05 - mean_absolute_error: 0.0052
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.7754e-05 - mean_absolute_error: 0.0055
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.9012e-05 - mean_absolute_error: 0.0055
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1401e-05 - mean_absolute_error: 0.0055
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3014e-05 - mean_absolute_error: 0.0055
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0688e-05 - mean_absolute_error: 0.0054
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3418e-05 - mean_absolute_error: 0.0053
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.4235e-05 - mean_absolute_error: 0.0051
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6466e-05 - mean_absolute_error: 0.0058
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0866e-05 - mean_absolute_error: 0.0051

# %% [markdown]
# ### Predicting with test set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8674e-04 - mean_absolute_error: 0.0090
# Test Loss: [0.0005061145056970417, 0.015466590411961079]

# %%
# Splitting data into train, test set again to evaluate, because i shaped the data between 0 to 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 383
# 394

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)
# Out:
# Model evalution on test set
# MSE: 9968877.44442514
# RMSE: 3157.352917306702
# MAE: 2151.7670222748043
# MAPE: 2.231021171861619 %

# %% [markdown]
# ## 4. Forecast the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(test_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
y_pred_30_days
# Out:
# array([[131235.67 ],
#        [130796.49 ],
#        [130912.984],
#        [131061.15 ],
#        [131149.61 ],
#        [131159.61 ],
#        [131151.78 ],
#        [131145.48 ],
#        [131143.22 ],
#        [131143.19 ],
#        [131143.58 ],
#        [131143.78 ],
#        [131143.81 ],
#        [131143.84 ],
#        [131143.8  ],
#        [131143.8  ],
#        [131143.8  ],
#        [131143.8  ],
#        [131143.81 ],
#        [131143.8  ],
#        [131143.8  ],
#        [131143.8  ],
#        [131143.8  ],
#        [131143.8  ],
#        [131143.81 ],
#        [131143.8  ],
#        [131143.8  ],
#        [131143.8  ],
#        [131143.8  ],
#        [131143.8  ],
#        [131143.81 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(test_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
y_pred_90_days = forecast(test_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        test_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Next {days} Days",
        linestyle="--",
    )

    plt.title(f"Forecast {stock_name[stock]} Stock Closing Price Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
