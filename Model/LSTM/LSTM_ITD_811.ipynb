# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: ITD - Test/Train/Vaildation: 80/10/10
# - Dataset: 1313 rows x 7 columns (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 266.16634056860687
# - MAE: 195.51390787760417
# - MAPE: 1.8327296640262447 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170
# ...           ...
# 2024-05-27  11300
# 2024-05-28  12050
# 2024-05-29  12600
# 2024-05-30  12500
# 2024-05-31  12700
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        6900
# 1        7100
# 2        7100
# 3        7170
# 4        7170
#         ...
# 1308    11300
# 1309    12050
# 1310    12600
# 1311    12500
# 1312    12700
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((1039, 10), (1039,), (120, 10), (120,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 11s 43ms/step - loss: 0.0341 - mean_absolute_error: 0.1281 - val_loss: 0.0013 - val_mean_absolute_error: 0.0323
# Epoch 2/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0024 - mean_absolute_error: 0.0366 - val_loss: 4.0570e-04 - val_mean_absolute_error: 0.0151
# Epoch 3/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0017 - mean_absolute_error: 0.0256 - val_loss: 3.0310e-04 - val_mean_absolute_error: 0.0126
# Epoch 4/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - mean_absolute_error: 0.0260 - val_loss: 0.0012 - val_mean_absolute_error: 0.0320
# Epoch 5/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0019 - mean_absolute_error: 0.0292 - val_loss: 3.6042e-04 - val_mean_absolute_error: 0.0150
# Epoch 6/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0016 - mean_absolute_error: 0.0255 - val_loss: 5.6677e-04 - val_mean_absolute_error: 0.0206
# Epoch 7/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0015 - mean_absolute_error: 0.0244 - val_loss: 3.3541e-04 - val_mean_absolute_error: 0.0143
# Epoch 8/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - mean_absolute_error: 0.0236 - val_loss: 4.0066e-04 - val_mean_absolute_error: 0.0165
# Epoch 9/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0240 - val_loss: 3.0364e-04 - val_mean_absolute_error: 0.0132
# Epoch 10/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0012 - mean_absolute_error: 0.0228 - val_loss: 3.4115e-04 - val_mean_absolute_error: 0.0147
# Epoch 11/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0234 - val_loss: 4.7823e-04 - val_mean_absolute_error: 0.0184
# Epoch 12/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0013 - mean_absolute_error: 0.0231 - val_loss: 2.6251e-04 - val_mean_absolute_error: 0.0117
# Epoch 13/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013 - mean_absolute_error: 0.0245 - val_loss: 5.2217e-04 - val_mean_absolute_error: 0.0195
# Epoch 14/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0011 - mean_absolute_error: 0.0220 - val_loss: 4.4473e-04 - val_mean_absolute_error: 0.0178
# Epoch 15/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0011 - mean_absolute_error: 0.0220 - val_loss: 2.6078e-04 - val_mean_absolute_error: 0.0116
# Epoch 16/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0226 - val_loss: 2.8041e-04 - val_mean_absolute_error: 0.0129
# Epoch 17/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.4513e-04 - mean_absolute_error: 0.0189 - val_loss: 5.2868e-04 - val_mean_absolute_error: 0.0195
# Epoch 18/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0013 - mean_absolute_error: 0.0237 - val_loss: 2.3430e-04 - val_mean_absolute_error: 0.0109
# Epoch 19/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.6128e-04 - mean_absolute_error: 0.0198 - val_loss: 2.5873e-04 - val_mean_absolute_error: 0.0119
# Epoch 20/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0012 - mean_absolute_error: 0.0232 - val_loss: 3.0138e-04 - val_mean_absolute_error: 0.0138
# Epoch 21/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.3722e-04 - mean_absolute_error: 0.0188 - val_loss: 2.3730e-04 - val_mean_absolute_error: 0.0110
# Epoch 22/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.4713e-04 - mean_absolute_error: 0.0202 - val_loss: 2.2696e-04 - val_mean_absolute_error: 0.0106
# Epoch 23/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.0694e-04 - mean_absolute_error: 0.0198 - val_loss: 2.2332e-04 - val_mean_absolute_error: 0.0105
# Epoch 24/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.4712e-04 - mean_absolute_error: 0.0204 - val_loss: 2.2577e-04 - val_mean_absolute_error: 0.0106
# Epoch 25/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.7176e-04 - mean_absolute_error: 0.0176 - val_loss: 3.0826e-04 - val_mean_absolute_error: 0.0135
# Epoch 26/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.0196e-04 - mean_absolute_error: 0.0188 - val_loss: 3.8806e-04 - val_mean_absolute_error: 0.0167
# Epoch 27/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.6036e-04 - mean_absolute_error: 0.0179 - val_loss: 3.7538e-04 - val_mean_absolute_error: 0.0163
# Epoch 28/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.8184e-04 - mean_absolute_error: 0.0176 - val_loss: 2.5802e-04 - val_mean_absolute_error: 0.0123
# Epoch 29/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.1923e-04 - mean_absolute_error: 0.0175 - val_loss: 2.1644e-04 - val_mean_absolute_error: 0.0104
# Epoch 30/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.4213e-04 - mean_absolute_error: 0.0183 - val_loss: 2.1309e-04 - val_mean_absolute_error: 0.0103
# Epoch 31/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.4374e-04 - mean_absolute_error: 0.0186 - val_loss: 2.5643e-04 - val_mean_absolute_error: 0.0119
# Epoch 32/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.6766e-04 - mean_absolute_error: 0.0192 - val_loss: 3.4804e-04 - val_mean_absolute_error: 0.0149
# Epoch 33/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.2945e-04 - mean_absolute_error: 0.0182 - val_loss: 2.5983e-04 - val_mean_absolute_error: 0.0124
# Epoch 34/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.2392e-04 - mean_absolute_error: 0.0181 - val_loss: 2.0268e-04 - val_mean_absolute_error: 0.0100
# Epoch 35/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.2505e-04 - mean_absolute_error: 0.0168 - val_loss: 2.1109e-04 - val_mean_absolute_error: 0.0103
# Epoch 36/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.0918e-04 - mean_absolute_error: 0.0170 - val_loss: 4.6597e-04 - val_mean_absolute_error: 0.0188
# Epoch 37/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.1822e-04 - mean_absolute_error: 0.0180 - val_loss: 4.2113e-04 - val_mean_absolute_error: 0.0172
# Epoch 38/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.3644e-04 - mean_absolute_error: 0.0190 - val_loss: 1.9663e-04 - val_mean_absolute_error: 0.0098
# Epoch 39/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.4948e-04 - mean_absolute_error: 0.0162 - val_loss: 2.0202e-04 - val_mean_absolute_error: 0.0101
# Epoch 40/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.3051e-04 - mean_absolute_error: 0.0161 - val_loss: 2.0067e-04 - val_mean_absolute_error: 0.0100
# Epoch 41/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.0379e-04 - mean_absolute_error: 0.0162 - val_loss: 1.9945e-04 - val_mean_absolute_error: 0.0100
# Epoch 42/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.6873e-04 - mean_absolute_error: 0.0166 - val_loss: 2.0325e-04 - val_mean_absolute_error: 0.0102
# Epoch 43/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.0169e-04 - mean_absolute_error: 0.0161 - val_loss: 2.4976e-04 - val_mean_absolute_error: 0.0120
# Epoch 44/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.8744e-04 - mean_absolute_error: 0.0159 - val_loss: 2.0675e-04 - val_mean_absolute_error: 0.0103
# Epoch 45/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.5798e-04 - mean_absolute_error: 0.0182 - val_loss: 2.0442e-04 - val_mean_absolute_error: 0.0103
# Epoch 46/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.3543e-04 - mean_absolute_error: 0.0146 - val_loss: 4.1006e-04 - val_mean_absolute_error: 0.0175
# Epoch 47/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 8.5649e-04 - mean_absolute_error: 0.0203 - val_loss: 2.2386e-04 - val_mean_absolute_error: 0.0113
# Epoch 48/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.3238e-04 - mean_absolute_error: 0.0155 - val_loss: 1.8895e-04 - val_mean_absolute_error: 0.0096
# Epoch 49/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.3373e-04 - mean_absolute_error: 0.0164 - val_loss: 2.5735e-04 - val_mean_absolute_error: 0.0123
# Epoch 50/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.2786e-04 - mean_absolute_error: 0.0183 - val_loss: 2.9976e-04 - val_mean_absolute_error: 0.0139
# Epoch 51/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 6.1342e-04 - mean_absolute_error: 0.0167 - val_loss: 2.9303e-04 - val_mean_absolute_error: 0.0140
# Epoch 52/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.5307e-04 - mean_absolute_error: 0.0158 - val_loss: 2.3581e-04 - val_mean_absolute_error: 0.0120
# Epoch 53/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.0022e-04 - mean_absolute_error: 0.0144 - val_loss: 2.9509e-04 - val_mean_absolute_error: 0.0142
# Epoch 54/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.5899e-04 - mean_absolute_error: 0.0145 - val_loss: 1.7404e-04 - val_mean_absolute_error: 0.0092
# Epoch 55/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.9118e-04 - mean_absolute_error: 0.0143 - val_loss: 3.3627e-04 - val_mean_absolute_error: 0.0156
# Epoch 56/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.5274e-04 - mean_absolute_error: 0.0156 - val_loss: 1.8226e-04 - val_mean_absolute_error: 0.0096
# Epoch 57/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.4002e-04 - mean_absolute_error: 0.0152 - val_loss: 3.2143e-04 - val_mean_absolute_error: 0.0151
# Epoch 58/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.4670e-04 - mean_absolute_error: 0.0158 - val_loss: 4.8009e-04 - val_mean_absolute_error: 0.0192
# Epoch 59/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.2091e-04 - mean_absolute_error: 0.0172 - val_loss: 2.6340e-04 - val_mean_absolute_error: 0.0132
# Epoch 60/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.7184e-04 - mean_absolute_error: 0.0144 - val_loss: 1.8564e-04 - val_mean_absolute_error: 0.0098
# Epoch 61/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.6167e-04 - mean_absolute_error: 0.0156 - val_loss: 1.8193e-04 - val_mean_absolute_error: 0.0097
# Epoch 62/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.7766e-04 - mean_absolute_error: 0.0147 - val_loss: 5.9438e-04 - val_mean_absolute_error: 0.0220
# Epoch 63/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.9322e-04 - mean_absolute_error: 0.0173 - val_loss: 2.1549e-04 - val_mean_absolute_error: 0.0113
# Epoch 64/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.3629e-04 - mean_absolute_error: 0.0137 - val_loss: 1.6471e-04 - val_mean_absolute_error: 0.0090
# Epoch 65/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.7577e-04 - mean_absolute_error: 0.0142 - val_loss: 2.4852e-04 - val_mean_absolute_error: 0.0127
# Epoch 66/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.3576e-04 - mean_absolute_error: 0.0156 - val_loss: 2.0258e-04 - val_mean_absolute_error: 0.0105
# Epoch 67/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.6508e-04 - mean_absolute_error: 0.0139 - val_loss: 1.9227e-04 - val_mean_absolute_error: 0.0102
# Epoch 68/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.8025e-04 - mean_absolute_error: 0.0139 - val_loss: 3.2621e-04 - val_mean_absolute_error: 0.0153
# Epoch 69/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.8591e-04 - mean_absolute_error: 0.0151 - val_loss: 2.2102e-04 - val_mean_absolute_error: 0.0117
# Epoch 70/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.6253e-04 - mean_absolute_error: 0.0145 - val_loss: 1.6212e-04 - val_mean_absolute_error: 0.0089
# Epoch 71/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.3880e-04 - mean_absolute_error: 0.0141 - val_loss: 1.6265e-04 - val_mean_absolute_error: 0.0089
# Epoch 72/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.2975e-04 - mean_absolute_error: 0.0139 - val_loss: 5.5354e-04 - val_mean_absolute_error: 0.0212
# Epoch 73/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.3824e-04 - mean_absolute_error: 0.0162 - val_loss: 1.6591e-04 - val_mean_absolute_error: 0.0091
# Epoch 74/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.2969e-04 - mean_absolute_error: 0.0136 - val_loss: 3.1189e-04 - val_mean_absolute_error: 0.0150
# Epoch 75/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.6142e-04 - mean_absolute_error: 0.0140 - val_loss: 1.6890e-04 - val_mean_absolute_error: 0.0093
# Epoch 76/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.1481e-04 - mean_absolute_error: 0.0136 - val_loss: 3.0165e-04 - val_mean_absolute_error: 0.0147
# Epoch 77/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.1725e-04 - mean_absolute_error: 0.0139 - val_loss: 1.8107e-04 - val_mean_absolute_error: 0.0099
# Epoch 78/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.0682e-04 - mean_absolute_error: 0.0130 - val_loss: 1.6705e-04 - val_mean_absolute_error: 0.0092
# Epoch 79/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.6452e-04 - mean_absolute_error: 0.0124 - val_loss: 1.5529e-04 - val_mean_absolute_error: 0.0088
# Epoch 80/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.4034e-04 - mean_absolute_error: 0.0136 - val_loss: 2.4317e-04 - val_mean_absolute_error: 0.0127
# Epoch 81/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.9669e-04 - mean_absolute_error: 0.0133 - val_loss: 1.5363e-04 - val_mean_absolute_error: 0.0087
# Epoch 82/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.5679e-04 - mean_absolute_error: 0.0123 - val_loss: 1.7739e-04 - val_mean_absolute_error: 0.0098
# Epoch 83/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.0990e-04 - mean_absolute_error: 0.0131 - val_loss: 1.7775e-04 - val_mean_absolute_error: 0.0098
# Epoch 84/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.0250e-04 - mean_absolute_error: 0.0134 - val_loss: 2.1415e-04 - val_mean_absolute_error: 0.0115
# Epoch 85/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.4535e-04 - mean_absolute_error: 0.0126 - val_loss: 7.1951e-04 - val_mean_absolute_error: 0.0247
# Epoch 86/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.7872e-04 - mean_absolute_error: 0.0158 - val_loss: 1.7784e-04 - val_mean_absolute_error: 0.0099
# Epoch 87/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.5666e-04 - mean_absolute_error: 0.0129 - val_loss: 4.0809e-04 - val_mean_absolute_error: 0.0178
# Epoch 88/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.2783e-04 - mean_absolute_error: 0.0141 - val_loss: 1.5257e-04 - val_mean_absolute_error: 0.0087
# Epoch 89/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.4634e-04 - mean_absolute_error: 0.0141 - val_loss: 1.6860e-04 - val_mean_absolute_error: 0.0094
# Epoch 90/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.0327e-04 - mean_absolute_error: 0.0133 - val_loss: 1.7063e-04 - val_mean_absolute_error: 0.0095
# Epoch 91/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.8993e-04 - mean_absolute_error: 0.0129 - val_loss: 1.7825e-04 - val_mean_absolute_error: 0.0099
# Epoch 92/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.0916e-04 - mean_absolute_error: 0.0133 - val_loss: 1.5277e-04 - val_mean_absolute_error: 0.0087
# Epoch 93/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.5253e-04 - mean_absolute_error: 0.0124 - val_loss: 1.6324e-04 - val_mean_absolute_error: 0.0092
# Epoch 94/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9713e-04 - mean_absolute_error: 0.0132 - val_loss: 1.6588e-04 - val_mean_absolute_error: 0.0093
# Epoch 95/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.8554e-04 - mean_absolute_error: 0.0130 - val_loss: 4.0807e-04 - val_mean_absolute_error: 0.0178
# Epoch 96/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.9401e-04 - mean_absolute_error: 0.0135 - val_loss: 1.8237e-04 - val_mean_absolute_error: 0.0101
# Epoch 97/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.8734e-04 - mean_absolute_error: 0.0133 - val_loss: 1.7894e-04 - val_mean_absolute_error: 0.0100
# Epoch 98/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.5278e-04 - mean_absolute_error: 0.0145 - val_loss: 1.4934e-04 - val_mean_absolute_error: 0.0086
# Epoch 99/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.1489e-04 - mean_absolute_error: 0.0143 - val_loss: 3.1140e-04 - val_mean_absolute_error: 0.0148
# Epoch 100/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.4441e-04 - mean_absolute_error: 0.0169 - val_loss: 1.5577e-04 - val_mean_absolute_error: 0.0089
# Epoch 101/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7437e-04 - mean_absolute_error: 0.0129 - val_loss: 1.5081e-04 - val_mean_absolute_error: 0.0087
# Epoch 102/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.2421e-04 - mean_absolute_error: 0.0143 - val_loss: 2.8628e-04 - val_mean_absolute_error: 0.0140
# Epoch 103/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.0047e-04 - mean_absolute_error: 0.0137 - val_loss: 1.9021e-04 - val_mean_absolute_error: 0.0106
# Epoch 104/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.0458e-04 - mean_absolute_error: 0.0136 - val_loss: 1.5930e-04 - val_mean_absolute_error: 0.0092
# Epoch 105/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.0132e-04 - mean_absolute_error: 0.0137 - val_loss: 1.4874e-04 - val_mean_absolute_error: 0.0086
# Epoch 106/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.7181e-04 - mean_absolute_error: 0.0129 - val_loss: 1.5098e-04 - val_mean_absolute_error: 0.0088
# Epoch 107/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.6581e-04 - mean_absolute_error: 0.0129 - val_loss: 4.2191e-04 - val_mean_absolute_error: 0.0182
# Epoch 108/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.4443e-04 - mean_absolute_error: 0.0147 - val_loss: 1.8934e-04 - val_mean_absolute_error: 0.0105
# Epoch 109/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.4922e-04 - mean_absolute_error: 0.0123 - val_loss: 1.5980e-04 - val_mean_absolute_error: 0.0091
# Epoch 110/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.9250e-04 - mean_absolute_error: 0.0134 - val_loss: 2.0204e-04 - val_mean_absolute_error: 0.0111
# Epoch 111/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.6589e-04 - mean_absolute_error: 0.0131 - val_loss: 1.6112e-04 - val_mean_absolute_error: 0.0093
# Epoch 112/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.5055e-04 - mean_absolute_error: 0.0127 - val_loss: 1.4973e-04 - val_mean_absolute_error: 0.0086
# Epoch 113/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.7986e-04 - mean_absolute_error: 0.0131 - val_loss: 2.3111e-04 - val_mean_absolute_error: 0.0124
# Epoch 114/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.3157e-04 - mean_absolute_error: 0.0136 - val_loss: 2.6679e-04 - val_mean_absolute_error: 0.0136
# Epoch 115/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.7599e-04 - mean_absolute_error: 0.0131 - val_loss: 1.5307e-04 - val_mean_absolute_error: 0.0088
# Epoch 116/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.0507e-04 - mean_absolute_error: 0.0135 - val_loss: 1.4880e-04 - val_mean_absolute_error: 0.0086
# Epoch 117/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.7487e-04 - mean_absolute_error: 0.0128 - val_loss: 1.6223e-04 - val_mean_absolute_error: 0.0093
# Epoch 118/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.7191e-04 - mean_absolute_error: 0.0128 - val_loss: 1.5119e-04 - val_mean_absolute_error: 0.0088
# Epoch 119/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.7115e-04 - mean_absolute_error: 0.0129 - val_loss: 1.9116e-04 - val_mean_absolute_error: 0.0106
# Epoch 120/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.6294e-04 - mean_absolute_error: 0.0130 - val_loss: 1.6735e-04 - val_mean_absolute_error: 0.0095
# Epoch 121/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.4536e-04 - mean_absolute_error: 0.0122 - val_loss: 2.4283e-04 - val_mean_absolute_error: 0.0126
# Epoch 122/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.5185e-04 - mean_absolute_error: 0.0127 - val_loss: 2.1330e-04 - val_mean_absolute_error: 0.0115
# Epoch 123/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.5817e-04 - mean_absolute_error: 0.0143 - val_loss: 1.7661e-04 - val_mean_absolute_error: 0.0100
# Epoch 124/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.4097e-04 - mean_absolute_error: 0.0122 - val_loss: 1.4971e-04 - val_mean_absolute_error: 0.0087
# Epoch 125/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.7430e-04 - mean_absolute_error: 0.0125 - val_loss: 3.1562e-04 - val_mean_absolute_error: 0.0152
# Epoch 126/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.4938e-04 - mean_absolute_error: 0.0149 - val_loss: 1.5024e-04 - val_mean_absolute_error: 0.0087
# Epoch 127/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.0375e-04 - mean_absolute_error: 0.0132 - val_loss: 1.5289e-04 - val_mean_absolute_error: 0.0088
# Epoch 128/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.5498e-04 - mean_absolute_error: 0.0123 - val_loss: 1.5434e-04 - val_mean_absolute_error: 0.0090
# Epoch 129/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.5857e-04 - mean_absolute_error: 0.0129 - val_loss: 3.4843e-04 - val_mean_absolute_error: 0.0162
# Epoch 130/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.1694e-04 - mean_absolute_error: 0.0152 - val_loss: 1.5072e-04 - val_mean_absolute_error: 0.0087
# Epoch 131/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.6394e-04 - mean_absolute_error: 0.0128 - val_loss: 1.5555e-04 - val_mean_absolute_error: 0.0090
# Epoch 132/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.7155e-04 - mean_absolute_error: 0.0126 - val_loss: 2.0458e-04 - val_mean_absolute_error: 0.0111
# Epoch 133/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.9310e-04 - mean_absolute_error: 0.0130 - val_loss: 1.4866e-04 - val_mean_absolute_error: 0.0086
# Epoch 134/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.2935e-04 - mean_absolute_error: 0.0138 - val_loss: 1.7177e-04 - val_mean_absolute_error: 0.0098
# Epoch 135/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.3170e-04 - mean_absolute_error: 0.0121 - val_loss: 1.7269e-04 - val_mean_absolute_error: 0.0099
# Epoch 136/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.6554e-04 - mean_absolute_error: 0.0126 - val_loss: 1.9149e-04 - val_mean_absolute_error: 0.0106
# Epoch 137/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.1373e-04 - mean_absolute_error: 0.0137 - val_loss: 2.1070e-04 - val_mean_absolute_error: 0.0114
# Epoch 138/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.2037e-04 - mean_absolute_error: 0.0118 - val_loss: 1.6957e-04 - val_mean_absolute_error: 0.0097
# Epoch 139/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.2250e-04 - mean_absolute_error: 0.0137 - val_loss: 1.5703e-04 - val_mean_absolute_error: 0.0091
# Epoch 140/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.7071e-04 - mean_absolute_error: 0.0125 - val_loss: 1.4979e-04 - val_mean_absolute_error: 0.0087
# Epoch 141/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9536e-04 - mean_absolute_error: 0.0133 - val_loss: 2.0368e-04 - val_mean_absolute_error: 0.0111
# Epoch 142/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.5852e-04 - mean_absolute_error: 0.0130 - val_loss: 1.4930e-04 - val_mean_absolute_error: 0.0087
# Epoch 143/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.6486e-04 - mean_absolute_error: 0.0125 - val_loss: 1.5385e-04 - val_mean_absolute_error: 0.0090
# Epoch 144/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.4972e-04 - mean_absolute_error: 0.0124 - val_loss: 2.2582e-04 - val_mean_absolute_error: 0.0121
# Epoch 145/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.1471e-04 - mean_absolute_error: 0.0133 - val_loss: 2.7408e-04 - val_mean_absolute_error: 0.0138
# Epoch 146/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.0013e-04 - mean_absolute_error: 0.0140 - val_loss: 1.5232e-04 - val_mean_absolute_error: 0.0089
# Epoch 147/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.5514e-04 - mean_absolute_error: 0.0126 - val_loss: 1.6280e-04 - val_mean_absolute_error: 0.0093
# Epoch 148/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.2362e-04 - mean_absolute_error: 0.0145 - val_loss: 1.4821e-04 - val_mean_absolute_error: 0.0086
# Epoch 149/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.2535e-04 - mean_absolute_error: 0.0138 - val_loss: 1.4693e-04 - val_mean_absolute_error: 0.0086
# Epoch 150/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.4199e-04 - mean_absolute_error: 0.0123 - val_loss: 3.3391e-04 - val_mean_absolute_error: 0.0156
# Epoch 151/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.0244e-04 - mean_absolute_error: 0.0137 - val_loss: 1.4947e-04 - val_mean_absolute_error: 0.0087
# Epoch 152/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.2978e-04 - mean_absolute_error: 0.0141 - val_loss: 2.0282e-04 - val_mean_absolute_error: 0.0111
# Epoch 153/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.9348e-04 - mean_absolute_error: 0.0133 - val_loss: 1.9346e-04 - val_mean_absolute_error: 0.0108
# Epoch 154/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.0254e-04 - mean_absolute_error: 0.0137 - val_loss: 1.8632e-04 - val_mean_absolute_error: 0.0105
# Epoch 155/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.2735e-04 - mean_absolute_error: 0.0139 - val_loss: 1.6537e-04 - val_mean_absolute_error: 0.0095
# Epoch 156/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.3195e-04 - mean_absolute_error: 0.0142 - val_loss: 2.5712e-04 - val_mean_absolute_error: 0.0133
# Epoch 157/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 3.9992e-04 - mean_absolute_error: 0.0138 - val_loss: 1.5669e-04 - val_mean_absolute_error: 0.0091
# Epoch 158/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7166e-04 - mean_absolute_error: 0.0128 - val_loss: 1.6660e-04 - val_mean_absolute_error: 0.0096
# Epoch 159/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.4258e-04 - mean_absolute_error: 0.0124 - val_loss: 1.4830e-04 - val_mean_absolute_error: 0.0087
# Epoch 160/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.6531e-04 - mean_absolute_error: 0.0124 - val_loss: 2.6967e-04 - val_mean_absolute_error: 0.0137
# Epoch 161/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.0524e-04 - mean_absolute_error: 0.0137 - val_loss: 1.9186e-04 - val_mean_absolute_error: 0.0107
# Epoch 162/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.6522e-04 - mean_absolute_error: 0.0124 - val_loss: 1.6290e-04 - val_mean_absolute_error: 0.0094
# Epoch 163/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.8180e-04 - mean_absolute_error: 0.0130 - val_loss: 1.4857e-04 - val_mean_absolute_error: 0.0087
# Epoch 164/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.6232e-04 - mean_absolute_error: 0.0124 - val_loss: 2.3063e-04 - val_mean_absolute_error: 0.0124
# Epoch 165/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.4001e-04 - mean_absolute_error: 0.0135 - val_loss: 1.7032e-04 - val_mean_absolute_error: 0.0097
# Epoch 166/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.5769e-04 - mean_absolute_error: 0.0124 - val_loss: 1.7542e-04 - val_mean_absolute_error: 0.0100
# Epoch 167/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.9165e-04 - mean_absolute_error: 0.0129 - val_loss: 1.7206e-04 - val_mean_absolute_error: 0.0098
# Epoch 168/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.1357e-04 - mean_absolute_error: 0.0136 - val_loss: 1.4842e-04 - val_mean_absolute_error: 0.0087
# Epoch 169/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.5719e-04 - mean_absolute_error: 0.0151 - val_loss: 1.5441e-04 - val_mean_absolute_error: 0.0090
# Epoch 170/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.6096e-04 - mean_absolute_error: 0.0125 - val_loss: 1.7100e-04 - val_mean_absolute_error: 0.0097
# Epoch 171/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.3562e-04 - mean_absolute_error: 0.0144 - val_loss: 2.5643e-04 - val_mean_absolute_error: 0.0133
# Epoch 172/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.5345e-04 - mean_absolute_error: 0.0128 - val_loss: 2.9810e-04 - val_mean_absolute_error: 0.0147
# Epoch 173/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.6548e-04 - mean_absolute_error: 0.0128 - val_loss: 2.8893e-04 - val_mean_absolute_error: 0.0143
# Epoch 174/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.5622e-04 - mean_absolute_error: 0.0149 - val_loss: 2.0354e-04 - val_mean_absolute_error: 0.0112
# Epoch 175/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.8995e-04 - mean_absolute_error: 0.0134 - val_loss: 3.1390e-04 - val_mean_absolute_error: 0.0149
# Epoch 176/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.3056e-04 - mean_absolute_error: 0.0148 - val_loss: 1.8849e-04 - val_mean_absolute_error: 0.0106
# Epoch 177/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.7812e-04 - mean_absolute_error: 0.0132 - val_loss: 1.9037e-04 - val_mean_absolute_error: 0.0106
# Epoch 178/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.6983e-04 - mean_absolute_error: 0.0132 - val_loss: 1.6227e-04 - val_mean_absolute_error: 0.0094
# Epoch 179/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.4650e-04 - mean_absolute_error: 0.0129 - val_loss: 1.5728e-04 - val_mean_absolute_error: 0.0091
# Epoch 180/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.1932e-04 - mean_absolute_error: 0.0118 - val_loss: 1.5342e-04 - val_mean_absolute_error: 0.0089
# Epoch 181/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.6190e-04 - mean_absolute_error: 0.0123 - val_loss: 1.5141e-04 - val_mean_absolute_error: 0.0088
# Epoch 182/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.7490e-04 - mean_absolute_error: 0.0123 - val_loss: 1.4908e-04 - val_mean_absolute_error: 0.0087
# Epoch 183/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7028e-04 - mean_absolute_error: 0.0129 - val_loss: 1.4872e-04 - val_mean_absolute_error: 0.0087
# Epoch 184/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.4858e-04 - mean_absolute_error: 0.0121 - val_loss: 1.5214e-04 - val_mean_absolute_error: 0.0089
# Epoch 185/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8819e-04 - mean_absolute_error: 0.0133 - val_loss: 1.5526e-04 - val_mean_absolute_error: 0.0090
# Epoch 186/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.0751e-04 - mean_absolute_error: 0.0133 - val_loss: 1.9029e-04 - val_mean_absolute_error: 0.0107
# Epoch 187/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.9002e-04 - mean_absolute_error: 0.0132 - val_loss: 2.2377e-04 - val_mean_absolute_error: 0.0120
# Epoch 188/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.9193e-04 - mean_absolute_error: 0.0132 - val_loss: 1.9634e-04 - val_mean_absolute_error: 0.0109
# Epoch 189/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.8090e-04 - mean_absolute_error: 0.0134 - val_loss: 1.4796e-04 - val_mean_absolute_error: 0.0087
# Epoch 190/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.8146e-04 - mean_absolute_error: 0.0130 - val_loss: 1.8732e-04 - val_mean_absolute_error: 0.0105
# Epoch 191/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.2720e-04 - mean_absolute_error: 0.0144 - val_loss: 3.7607e-04 - val_mean_absolute_error: 0.0169
# Epoch 192/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.1931e-04 - mean_absolute_error: 0.0163 - val_loss: 1.6808e-04 - val_mean_absolute_error: 0.0097
# Epoch 193/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.9886e-04 - mean_absolute_error: 0.0138 - val_loss: 1.4810e-04 - val_mean_absolute_error: 0.0087
# Epoch 194/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8398e-04 - mean_absolute_error: 0.0128 - val_loss: 1.6242e-04 - val_mean_absolute_error: 0.0094
# Epoch 195/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.6311e-04 - mean_absolute_error: 0.0128 - val_loss: 1.6279e-04 - val_mean_absolute_error: 0.0094
# Epoch 196/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.4373e-04 - mean_absolute_error: 0.0139 - val_loss: 1.4808e-04 - val_mean_absolute_error: 0.0087
# Epoch 197/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.4547e-04 - mean_absolute_error: 0.0124 - val_loss: 1.5072e-04 - val_mean_absolute_error: 0.0088
# Epoch 198/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.9893e-04 - mean_absolute_error: 0.0133 - val_loss: 1.4806e-04 - val_mean_absolute_error: 0.0087
# Epoch 199/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.2945e-04 - mean_absolute_error: 0.0119 - val_loss: 1.6090e-04 - val_mean_absolute_error: 0.0093
# Epoch 200/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.5549e-04 - mean_absolute_error: 0.0127 - val_loss: 1.5123e-04 - val_mean_absolute_error: 0.0088

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 362ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1432e-04 - mean_absolute_error: 0.0078
# Test Loss: [0.0001512328744865954, 0.00877807755023241]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 120
# 131

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 70844.52085168361
# RMSE: 266.16634056860687
# MAE: 195.51390787760417
# MAPE: 1.8327296640262447 %
#
# Model evalution on validate set
# MSE: 80635.38054039853
# RMSE: 283.96369581409266
# MAE: 186.3294243930785
# MAPE: 1.7793238703935244 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 739ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step

# %%
y_pred_30_days
# Out:
# array([[12682.263],
#        [12659.074],
#        [12674.711],
#        [12671.403],
#        [12672.894],
#        [12672.486],
#        [12672.642],
#        [12672.593],
#        [12672.61 ],
#        [12672.605],
#        [12672.607],
#        [12672.606],
#        [12672.607],
#        [12672.606],
#        [12672.606],
#        [12672.606],
#        [12672.607],
#        [12672.607],
#        [12672.606],
#        [12672.607],
#        [12672.606],
#        [12672.606],
#        [12672.606],
#        [12672.607],
#        [12672.607],
#        [12672.606],
#        [12672.607],
#        [12672.606],
#        [12672.606],
#        [12672.606],
#        [12672.607]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Forecast Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
