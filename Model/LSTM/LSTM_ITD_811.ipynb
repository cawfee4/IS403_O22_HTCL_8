# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: ITD - Test/Train/Vaildation: 80/10/10
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 319.39
# - MAE: 270.72
# - MAPE: 2.35 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170
# ...           ...
# 2024-05-27  11300
# 2024-05-28  12050
# 2024-05-29  12600
# 2024-05-30  12500
# 2024-05-31  12700
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        6900
# 1        7100
# 2        7100
# 3        7170
# 4        7170
#         ...
# 1308    11300
# 1309    12050
# 1310    12600
# 1311    12500
# 1312    12700
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((1039, 10), (1039,), (120, 10), (120,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 27s 116ms/step - loss: 0.0427 - mean_absolute_error: 0.1486 - val_loss: 5.2855e-04 - val_mean_absolute_error: 0.0187
# Epoch 2/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0022 - mean_absolute_error: 0.0353 - val_loss: 3.5570e-04 - val_mean_absolute_error: 0.0138
# Epoch 3/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0015 - mean_absolute_error: 0.0250 - val_loss: 3.2113e-04 - val_mean_absolute_error: 0.0130
# Epoch 4/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - mean_absolute_error: 0.0262 - val_loss: 5.2531e-04 - val_mean_absolute_error: 0.0196
# Epoch 5/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0019 - mean_absolute_error: 0.0285 - val_loss: 3.2173e-04 - val_mean_absolute_error: 0.0137
# Epoch 6/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - mean_absolute_error: 0.0242 - val_loss: 3.3585e-04 - val_mean_absolute_error: 0.0143
# Epoch 7/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0014 - mean_absolute_error: 0.0234 - val_loss: 4.5392e-04 - val_mean_absolute_error: 0.0180
# Epoch 8/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0229 - val_loss: 4.4372e-04 - val_mean_absolute_error: 0.0177
# Epoch 9/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0015 - mean_absolute_error: 0.0244 - val_loss: 9.4475e-04 - val_mean_absolute_error: 0.0275
# Epoch 10/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0236 - val_loss: 3.2203e-04 - val_mean_absolute_error: 0.0141
# Epoch 11/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0231 - val_loss: 3.4062e-04 - val_mean_absolute_error: 0.0148
# Epoch 12/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0014 - mean_absolute_error: 0.0234 - val_loss: 3.0235e-04 - val_mean_absolute_error: 0.0134
# Epoch 13/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - mean_absolute_error: 0.0234 - val_loss: 8.7372e-04 - val_mean_absolute_error: 0.0264
# Epoch 14/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0012 - mean_absolute_error: 0.0230 - val_loss: 3.4034e-04 - val_mean_absolute_error: 0.0148
# Epoch 15/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0014 - mean_absolute_error: 0.0238 - val_loss: 7.0731e-04 - val_mean_absolute_error: 0.0235
# Epoch 16/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012 - mean_absolute_error: 0.0228 - val_loss: 4.0392e-04 - val_mean_absolute_error: 0.0167
# Epoch 17/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0011 - mean_absolute_error: 0.0223 - val_loss: 6.7311e-04 - val_mean_absolute_error: 0.0229
# Epoch 18/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0013 - mean_absolute_error: 0.0238 - val_loss: 4.2617e-04 - val_mean_absolute_error: 0.0175
# Epoch 19/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0219 - val_loss: 2.7915e-04 - val_mean_absolute_error: 0.0128
# Epoch 20/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0011 - mean_absolute_error: 0.0209 - val_loss: 2.9325e-04 - val_mean_absolute_error: 0.0128
# Epoch 21/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0011 - mean_absolute_error: 0.0210 - val_loss: 0.0016 - val_mean_absolute_error: 0.0371
# Epoch 22/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - mean_absolute_error: 0.0224 - val_loss: 3.1551e-04 - val_mean_absolute_error: 0.0144
# Epoch 23/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.6304e-04 - mean_absolute_error: 0.0185 - val_loss: 5.0012e-04 - val_mean_absolute_error: 0.0194
# Epoch 24/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.8929e-04 - mean_absolute_error: 0.0196 - val_loss: 3.0501e-04 - val_mean_absolute_error: 0.0140
# Epoch 25/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.4392e-04 - mean_absolute_error: 0.0181 - val_loss: 3.4046e-04 - val_mean_absolute_error: 0.0152
# Epoch 26/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.4612e-04 - mean_absolute_error: 0.0192 - val_loss: 2.8631e-04 - val_mean_absolute_error: 0.0133
# Epoch 27/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 9.5460e-04 - mean_absolute_error: 0.0204 - val_loss: 2.3142e-04 - val_mean_absolute_error: 0.0110
# Epoch 28/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.9482e-04 - mean_absolute_error: 0.0172 - val_loss: 3.1550e-04 - val_mean_absolute_error: 0.0144
# Epoch 29/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.1254e-04 - mean_absolute_error: 0.0175 - val_loss: 3.1116e-04 - val_mean_absolute_error: 0.0142
# Epoch 30/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.9776e-04 - mean_absolute_error: 0.0179 - val_loss: 2.1707e-04 - val_mean_absolute_error: 0.0104
# Epoch 31/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.5671e-04 - mean_absolute_error: 0.0172 - val_loss: 2.2827e-04 - val_mean_absolute_error: 0.0109
# Epoch 32/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.3482e-04 - mean_absolute_error: 0.0174 - val_loss: 5.6557e-04 - val_mean_absolute_error: 0.0212
# Epoch 33/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.5191e-04 - mean_absolute_error: 0.0173 - val_loss: 2.1514e-04 - val_mean_absolute_error: 0.0104
# Epoch 34/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.4238e-04 - mean_absolute_error: 0.0185 - val_loss: 2.6943e-04 - val_mean_absolute_error: 0.0125
# Epoch 35/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.2392e-04 - mean_absolute_error: 0.0169 - val_loss: 2.0061e-04 - val_mean_absolute_error: 0.0099
# Epoch 36/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.6981e-04 - mean_absolute_error: 0.0168 - val_loss: 2.6500e-04 - val_mean_absolute_error: 0.0123
# Epoch 37/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.9539e-04 - mean_absolute_error: 0.0203 - val_loss: 2.1558e-04 - val_mean_absolute_error: 0.0106
# Epoch 38/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.8061e-04 - mean_absolute_error: 0.0176 - val_loss: 2.8158e-04 - val_mean_absolute_error: 0.0134
# Epoch 39/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.1376e-04 - mean_absolute_error: 0.0152 - val_loss: 2.0212e-04 - val_mean_absolute_error: 0.0102
# Epoch 40/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.5755e-04 - mean_absolute_error: 0.0166 - val_loss: 2.3550e-04 - val_mean_absolute_error: 0.0114
# Epoch 41/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.5346e-04 - mean_absolute_error: 0.0166 - val_loss: 2.0756e-04 - val_mean_absolute_error: 0.0103
# Epoch 42/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.3068e-04 - mean_absolute_error: 0.0151 - val_loss: 2.0245e-04 - val_mean_absolute_error: 0.0102
# Epoch 43/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.0032e-04 - mean_absolute_error: 0.0158 - val_loss: 2.0196e-04 - val_mean_absolute_error: 0.0103
# Epoch 44/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.8185e-04 - mean_absolute_error: 0.0159 - val_loss: 2.7634e-04 - val_mean_absolute_error: 0.0135
# Epoch 45/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.2985e-04 - mean_absolute_error: 0.0163 - val_loss: 1.8690e-04 - val_mean_absolute_error: 0.0096
# Epoch 46/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.6104e-04 - mean_absolute_error: 0.0143 - val_loss: 5.6193e-04 - val_mean_absolute_error: 0.0213
# Epoch 47/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.3819e-04 - mean_absolute_error: 0.0172 - val_loss: 1.8716e-04 - val_mean_absolute_error: 0.0097
# Epoch 48/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.5212e-04 - mean_absolute_error: 0.0147 - val_loss: 2.7741e-04 - val_mean_absolute_error: 0.0136
# Epoch 49/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.4236e-04 - mean_absolute_error: 0.0160 - val_loss: 3.2404e-04 - val_mean_absolute_error: 0.0147
# Epoch 50/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.4853e-04 - mean_absolute_error: 0.0158 - val_loss: 2.0961e-04 - val_mean_absolute_error: 0.0108
# Epoch 51/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.0259e-04 - mean_absolute_error: 0.0171 - val_loss: 1.8786e-04 - val_mean_absolute_error: 0.0098
# Epoch 52/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.8281e-04 - mean_absolute_error: 0.0142 - val_loss: 1.7409e-04 - val_mean_absolute_error: 0.0093
# Epoch 53/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.6982e-04 - mean_absolute_error: 0.0139 - val_loss: 2.4031e-04 - val_mean_absolute_error: 0.0124
# Epoch 54/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.9438e-04 - mean_absolute_error: 0.0143 - val_loss: 1.6951e-04 - val_mean_absolute_error: 0.0091
# Epoch 55/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.1715e-04 - mean_absolute_error: 0.0151 - val_loss: 2.9987e-04 - val_mean_absolute_error: 0.0145
# Epoch 56/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.3844e-04 - mean_absolute_error: 0.0138 - val_loss: 1.8154e-04 - val_mean_absolute_error: 0.0097
# Epoch 57/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.0850e-04 - mean_absolute_error: 0.0132 - val_loss: 1.7186e-04 - val_mean_absolute_error: 0.0093
# Epoch 58/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.7575e-04 - mean_absolute_error: 0.0142 - val_loss: 1.6619e-04 - val_mean_absolute_error: 0.0090
# Epoch 59/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 4.4920e-04 - mean_absolute_error: 0.0138 - val_loss: 2.1690e-04 - val_mean_absolute_error: 0.0115
# Epoch 60/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.7578e-04 - mean_absolute_error: 0.0138 - val_loss: 2.1503e-04 - val_mean_absolute_error: 0.0114
# Epoch 61/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.0868e-04 - mean_absolute_error: 0.0148 - val_loss: 3.1648e-04 - val_mean_absolute_error: 0.0152
# Epoch 62/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.5094e-04 - mean_absolute_error: 0.0134 - val_loss: 1.9179e-04 - val_mean_absolute_error: 0.0104
# Epoch 63/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.6286e-04 - mean_absolute_error: 0.0138 - val_loss: 2.0934e-04 - val_mean_absolute_error: 0.0112
# Epoch 64/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 4.3809e-04 - mean_absolute_error: 0.0140 - val_loss: 1.6192e-04 - val_mean_absolute_error: 0.0091
# Epoch 65/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 4.8102e-04 - mean_absolute_error: 0.0140 - val_loss: 1.5626e-04 - val_mean_absolute_error: 0.0088
# Epoch 66/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.8128e-04 - mean_absolute_error: 0.0128 - val_loss: 1.6086e-04 - val_mean_absolute_error: 0.0091
# Epoch 67/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.5912e-04 - mean_absolute_error: 0.0135 - val_loss: 1.9028e-04 - val_mean_absolute_error: 0.0103
# Epoch 68/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5866e-04 - mean_absolute_error: 0.0139 - val_loss: 1.6164e-04 - val_mean_absolute_error: 0.0091
# Epoch 69/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.2758e-04 - mean_absolute_error: 0.0134 - val_loss: 1.6084e-04 - val_mean_absolute_error: 0.0091
# Epoch 70/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.6809e-04 - mean_absolute_error: 0.0127 - val_loss: 2.1490e-04 - val_mean_absolute_error: 0.0115
# Epoch 71/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.2171e-04 - mean_absolute_error: 0.0138 - val_loss: 2.3714e-04 - val_mean_absolute_error: 0.0125
# Epoch 72/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.8081e-04 - mean_absolute_error: 0.0129 - val_loss: 1.5277e-04 - val_mean_absolute_error: 0.0087
# Epoch 73/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.9705e-04 - mean_absolute_error: 0.0132 - val_loss: 3.5583e-04 - val_mean_absolute_error: 0.0164
# Epoch 74/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.8667e-04 - mean_absolute_error: 0.0149 - val_loss: 2.1702e-04 - val_mean_absolute_error: 0.0116
# Epoch 75/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.5369e-04 - mean_absolute_error: 0.0144 - val_loss: 1.8644e-04 - val_mean_absolute_error: 0.0102
# Epoch 76/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8443e-04 - mean_absolute_error: 0.0132 - val_loss: 1.5156e-04 - val_mean_absolute_error: 0.0087
# Epoch 77/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.6047e-04 - mean_absolute_error: 0.0122 - val_loss: 2.1783e-04 - val_mean_absolute_error: 0.0116
# Epoch 78/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.6082e-04 - mean_absolute_error: 0.0139 - val_loss: 2.2454e-04 - val_mean_absolute_error: 0.0120
# Epoch 79/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.9191e-04 - mean_absolute_error: 0.0133 - val_loss: 1.5101e-04 - val_mean_absolute_error: 0.0086
# Epoch 80/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.2923e-04 - mean_absolute_error: 0.0136 - val_loss: 3.0326e-04 - val_mean_absolute_error: 0.0145
# Epoch 81/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.5170e-04 - mean_absolute_error: 0.0146 - val_loss: 2.1836e-04 - val_mean_absolute_error: 0.0117
# Epoch 82/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.9126e-04 - mean_absolute_error: 0.0133 - val_loss: 1.5721e-04 - val_mean_absolute_error: 0.0089
# Epoch 83/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 3.9447e-04 - mean_absolute_error: 0.0132 - val_loss: 2.5614e-04 - val_mean_absolute_error: 0.0132
# Epoch 84/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.0883e-04 - mean_absolute_error: 0.0141 - val_loss: 1.7730e-04 - val_mean_absolute_error: 0.0099
# Epoch 85/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.8560e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1384e-04 - val_mean_absolute_error: 0.0151
# Epoch 86/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 5.4011e-04 - mean_absolute_error: 0.0162 - val_loss: 1.5418e-04 - val_mean_absolute_error: 0.0088
# Epoch 87/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 4.9651e-04 - mean_absolute_error: 0.0159 - val_loss: 2.4810e-04 - val_mean_absolute_error: 0.0127
# Epoch 88/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 3.9810e-04 - mean_absolute_error: 0.0137 - val_loss: 1.8497e-04 - val_mean_absolute_error: 0.0103
# Epoch 89/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.7226e-04 - mean_absolute_error: 0.0125 - val_loss: 1.7339e-04 - val_mean_absolute_error: 0.0098
# Epoch 90/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.8538e-04 - mean_absolute_error: 0.0125 - val_loss: 1.6234e-04 - val_mean_absolute_error: 0.0092
# Epoch 91/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.7459e-04 - mean_absolute_error: 0.0125 - val_loss: 2.0699e-04 - val_mean_absolute_error: 0.0114
# Epoch 92/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.9510e-04 - mean_absolute_error: 0.0132 - val_loss: 1.9228e-04 - val_mean_absolute_error: 0.0106
# Epoch 93/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.6633e-04 - mean_absolute_error: 0.0128 - val_loss: 1.5959e-04 - val_mean_absolute_error: 0.0092
# Epoch 94/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.0773e-04 - mean_absolute_error: 0.0138 - val_loss: 1.8141e-04 - val_mean_absolute_error: 0.0101
# Epoch 95/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.1780e-04 - mean_absolute_error: 0.0136 - val_loss: 1.5284e-04 - val_mean_absolute_error: 0.0088
# Epoch 96/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.4606e-04 - mean_absolute_error: 0.0122 - val_loss: 1.5254e-04 - val_mean_absolute_error: 0.0088
# Epoch 97/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.2111e-04 - mean_absolute_error: 0.0131 - val_loss: 1.7827e-04 - val_mean_absolute_error: 0.0100
# Epoch 98/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.0801e-04 - mean_absolute_error: 0.0134 - val_loss: 1.5317e-04 - val_mean_absolute_error: 0.0089
# Epoch 99/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.9625e-04 - mean_absolute_error: 0.0132 - val_loss: 1.5005e-04 - val_mean_absolute_error: 0.0087
# Epoch 100/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.4691e-04 - mean_absolute_error: 0.0126 - val_loss: 1.5125e-04 - val_mean_absolute_error: 0.0087
# Epoch 101/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.8817e-04 - mean_absolute_error: 0.0129 - val_loss: 2.5696e-04 - val_mean_absolute_error: 0.0131
# Epoch 102/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.7172e-04 - mean_absolute_error: 0.0127 - val_loss: 2.0604e-04 - val_mean_absolute_error: 0.0112
# Epoch 103/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.7454e-04 - mean_absolute_error: 0.0129 - val_loss: 1.4767e-04 - val_mean_absolute_error: 0.0086
# Epoch 104/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.6791e-04 - mean_absolute_error: 0.0126 - val_loss: 1.6667e-04 - val_mean_absolute_error: 0.0095
# Epoch 105/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.0500e-04 - mean_absolute_error: 0.0135 - val_loss: 1.5059e-04 - val_mean_absolute_error: 0.0087
# Epoch 106/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.8958e-04 - mean_absolute_error: 0.0130 - val_loss: 2.2761e-04 - val_mean_absolute_error: 0.0122
# Epoch 107/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.9273e-04 - mean_absolute_error: 0.0135 - val_loss: 1.5118e-04 - val_mean_absolute_error: 0.0087
# Epoch 108/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.8747e-04 - mean_absolute_error: 0.0127 - val_loss: 1.4908e-04 - val_mean_absolute_error: 0.0087
# Epoch 109/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.2148e-04 - mean_absolute_error: 0.0119 - val_loss: 2.1907e-04 - val_mean_absolute_error: 0.0119
# Epoch 110/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.6644e-04 - mean_absolute_error: 0.0127 - val_loss: 2.5785e-04 - val_mean_absolute_error: 0.0133
# Epoch 111/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.6354e-04 - mean_absolute_error: 0.0127 - val_loss: 1.7861e-04 - val_mean_absolute_error: 0.0100
# Epoch 112/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9923e-04 - mean_absolute_error: 0.0134 - val_loss: 1.5049e-04 - val_mean_absolute_error: 0.0087
# Epoch 113/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.8302e-04 - mean_absolute_error: 0.0131 - val_loss: 1.4949e-04 - val_mean_absolute_error: 0.0087
# Epoch 114/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.1519e-04 - mean_absolute_error: 0.0133 - val_loss: 1.7968e-04 - val_mean_absolute_error: 0.0101
# Epoch 115/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.5890e-04 - mean_absolute_error: 0.0123 - val_loss: 1.7156e-04 - val_mean_absolute_error: 0.0098
# Epoch 116/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.4788e-04 - mean_absolute_error: 0.0126 - val_loss: 2.4476e-04 - val_mean_absolute_error: 0.0129
# Epoch 117/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.7176e-04 - mean_absolute_error: 0.0128 - val_loss: 1.7312e-04 - val_mean_absolute_error: 0.0099
# Epoch 118/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.4212e-04 - mean_absolute_error: 0.0126 - val_loss: 1.5129e-04 - val_mean_absolute_error: 0.0088
# Epoch 119/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.3632e-04 - mean_absolute_error: 0.0121 - val_loss: 2.5982e-04 - val_mean_absolute_error: 0.0134
# Epoch 120/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.9742e-04 - mean_absolute_error: 0.0135 - val_loss: 1.5256e-04 - val_mean_absolute_error: 0.0088
# Epoch 121/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.4539e-04 - mean_absolute_error: 0.0135 - val_loss: 2.3127e-04 - val_mean_absolute_error: 0.0122
# Epoch 122/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.6574e-04 - mean_absolute_error: 0.0133 - val_loss: 1.5306e-04 - val_mean_absolute_error: 0.0089
# Epoch 123/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.6398e-04 - mean_absolute_error: 0.0131 - val_loss: 1.4817e-04 - val_mean_absolute_error: 0.0086
# Epoch 124/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.2379e-04 - mean_absolute_error: 0.0142 - val_loss: 1.4899e-04 - val_mean_absolute_error: 0.0087
# Epoch 125/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.7478e-04 - mean_absolute_error: 0.0129 - val_loss: 1.5789e-04 - val_mean_absolute_error: 0.0091
# Epoch 126/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.1640e-04 - mean_absolute_error: 0.0139 - val_loss: 1.6549e-04 - val_mean_absolute_error: 0.0095
# Epoch 127/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.5466e-04 - mean_absolute_error: 0.0124 - val_loss: 3.0044e-04 - val_mean_absolute_error: 0.0147
# Epoch 128/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.6491e-04 - mean_absolute_error: 0.0133 - val_loss: 2.5767e-04 - val_mean_absolute_error: 0.0131
# Epoch 129/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.9333e-04 - mean_absolute_error: 0.0135 - val_loss: 1.6268e-04 - val_mean_absolute_error: 0.0094
# Epoch 130/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.3647e-04 - mean_absolute_error: 0.0124 - val_loss: 1.9093e-04 - val_mean_absolute_error: 0.0107
# Epoch 131/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.4429e-04 - mean_absolute_error: 0.0123 - val_loss: 2.1737e-04 - val_mean_absolute_error: 0.0118
# Epoch 132/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.8023e-04 - mean_absolute_error: 0.0127 - val_loss: 1.7225e-04 - val_mean_absolute_error: 0.0098
# Epoch 133/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.5490e-04 - mean_absolute_error: 0.0126 - val_loss: 1.9034e-04 - val_mean_absolute_error: 0.0106
# Epoch 134/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.8102e-04 - mean_absolute_error: 0.0132 - val_loss: 1.4891e-04 - val_mean_absolute_error: 0.0087
# Epoch 135/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.0036e-04 - mean_absolute_error: 0.0137 - val_loss: 1.5452e-04 - val_mean_absolute_error: 0.0090
# Epoch 136/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.0705e-04 - mean_absolute_error: 0.0137 - val_loss: 1.5632e-04 - val_mean_absolute_error: 0.0091
# Epoch 137/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.7059e-04 - mean_absolute_error: 0.0129 - val_loss: 1.4956e-04 - val_mean_absolute_error: 0.0087
# Epoch 138/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.2231e-04 - mean_absolute_error: 0.0117 - val_loss: 1.8529e-04 - val_mean_absolute_error: 0.0103
# Epoch 139/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.3440e-04 - mean_absolute_error: 0.0138 - val_loss: 1.8250e-04 - val_mean_absolute_error: 0.0103
# Epoch 140/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.8308e-04 - mean_absolute_error: 0.0130 - val_loss: 1.4939e-04 - val_mean_absolute_error: 0.0087
# Epoch 141/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.1074e-04 - mean_absolute_error: 0.0138 - val_loss: 2.6201e-04 - val_mean_absolute_error: 0.0134
# Epoch 142/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.3695e-04 - mean_absolute_error: 0.0144 - val_loss: 2.2497e-04 - val_mean_absolute_error: 0.0121
# Epoch 143/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.0555e-04 - mean_absolute_error: 0.0137 - val_loss: 1.7506e-04 - val_mean_absolute_error: 0.0099
# Epoch 144/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.9847e-04 - mean_absolute_error: 0.0137 - val_loss: 2.1029e-04 - val_mean_absolute_error: 0.0113
# Epoch 145/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.4212e-04 - mean_absolute_error: 0.0148 - val_loss: 1.5690e-04 - val_mean_absolute_error: 0.0092
# Epoch 146/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.2272e-04 - mean_absolute_error: 0.0136 - val_loss: 3.3994e-04 - val_mean_absolute_error: 0.0159
# Epoch 147/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.8684e-04 - mean_absolute_error: 0.0135 - val_loss: 1.8035e-04 - val_mean_absolute_error: 0.0102
# Epoch 148/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.6712e-04 - mean_absolute_error: 0.0128 - val_loss: 1.8035e-04 - val_mean_absolute_error: 0.0102
# Epoch 149/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.8863e-04 - mean_absolute_error: 0.0134 - val_loss: 1.9115e-04 - val_mean_absolute_error: 0.0107
# Epoch 150/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.0083e-04 - mean_absolute_error: 0.0131 - val_loss: 1.9388e-04 - val_mean_absolute_error: 0.0108
# Epoch 151/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.5305e-04 - mean_absolute_error: 0.0126 - val_loss: 1.4925e-04 - val_mean_absolute_error: 0.0087
# Epoch 152/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.7489e-04 - mean_absolute_error: 0.0128 - val_loss: 1.8553e-04 - val_mean_absolute_error: 0.0105
# Epoch 153/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.5357e-04 - mean_absolute_error: 0.0123 - val_loss: 1.5033e-04 - val_mean_absolute_error: 0.0087
# Epoch 154/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.8938e-04 - mean_absolute_error: 0.0130 - val_loss: 1.5774e-04 - val_mean_absolute_error: 0.0092
# Epoch 155/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.6863e-04 - mean_absolute_error: 0.0127 - val_loss: 1.9623e-04 - val_mean_absolute_error: 0.0108
# Epoch 156/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.1469e-04 - mean_absolute_error: 0.0151 - val_loss: 1.6156e-04 - val_mean_absolute_error: 0.0093
# Epoch 157/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.7656e-04 - mean_absolute_error: 0.0131 - val_loss: 1.6736e-04 - val_mean_absolute_error: 0.0097
# Epoch 158/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.1332e-04 - mean_absolute_error: 0.0135 - val_loss: 1.7049e-04 - val_mean_absolute_error: 0.0098
# Epoch 159/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.7704e-04 - mean_absolute_error: 0.0128 - val_loss: 1.8443e-04 - val_mean_absolute_error: 0.0104
# Epoch 160/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.8595e-04 - mean_absolute_error: 0.0132 - val_loss: 1.9695e-04 - val_mean_absolute_error: 0.0110
# Epoch 161/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.0587e-04 - mean_absolute_error: 0.0135 - val_loss: 1.9120e-04 - val_mean_absolute_error: 0.0107
# Epoch 162/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.2146e-04 - mean_absolute_error: 0.0142 - val_loss: 1.5339e-04 - val_mean_absolute_error: 0.0089
# Epoch 163/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.7490e-04 - mean_absolute_error: 0.0129 - val_loss: 1.8589e-04 - val_mean_absolute_error: 0.0104
# Epoch 164/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.1427e-04 - mean_absolute_error: 0.0134 - val_loss: 1.5411e-04 - val_mean_absolute_error: 0.0090
# Epoch 165/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9716e-04 - mean_absolute_error: 0.0136 - val_loss: 1.6593e-04 - val_mean_absolute_error: 0.0095
# Epoch 166/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.5777e-04 - mean_absolute_error: 0.0125 - val_loss: 2.4035e-04 - val_mean_absolute_error: 0.0126
# Epoch 167/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8733e-04 - mean_absolute_error: 0.0132 - val_loss: 1.7670e-04 - val_mean_absolute_error: 0.0100
# Epoch 168/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.6799e-04 - mean_absolute_error: 0.0127 - val_loss: 1.4962e-04 - val_mean_absolute_error: 0.0087
# Epoch 169/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.6151e-04 - mean_absolute_error: 0.0126 - val_loss: 1.6679e-04 - val_mean_absolute_error: 0.0096
# Epoch 170/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.0550e-04 - mean_absolute_error: 0.0137 - val_loss: 1.9235e-04 - val_mean_absolute_error: 0.0108
# Epoch 171/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.3063e-04 - mean_absolute_error: 0.0142 - val_loss: 2.1922e-04 - val_mean_absolute_error: 0.0118
# Epoch 172/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.7569e-04 - mean_absolute_error: 0.0141 - val_loss: 1.6221e-04 - val_mean_absolute_error: 0.0094
# Epoch 173/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.5153e-04 - mean_absolute_error: 0.0125 - val_loss: 3.8051e-04 - val_mean_absolute_error: 0.0170
# Epoch 174/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.0377e-04 - mean_absolute_error: 0.0137 - val_loss: 1.7405e-04 - val_mean_absolute_error: 0.0100
# Epoch 175/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.8623e-04 - mean_absolute_error: 0.0129 - val_loss: 1.5546e-04 - val_mean_absolute_error: 0.0091
# Epoch 176/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.8050e-04 - mean_absolute_error: 0.0131 - val_loss: 1.5146e-04 - val_mean_absolute_error: 0.0089
# Epoch 177/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.3098e-04 - mean_absolute_error: 0.0140 - val_loss: 1.5052e-04 - val_mean_absolute_error: 0.0088
# Epoch 178/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6186e-04 - mean_absolute_error: 0.0125 - val_loss: 1.8107e-04 - val_mean_absolute_error: 0.0102
# Epoch 179/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.0297e-04 - mean_absolute_error: 0.0134 - val_loss: 1.4917e-04 - val_mean_absolute_error: 0.0088
# Epoch 180/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.0330e-04 - mean_absolute_error: 0.0136 - val_loss: 1.5060e-04 - val_mean_absolute_error: 0.0088
# Epoch 181/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.2995e-04 - mean_absolute_error: 0.0119 - val_loss: 1.5023e-04 - val_mean_absolute_error: 0.0087
# Epoch 182/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.6652e-04 - mean_absolute_error: 0.0129 - val_loss: 2.5614e-04 - val_mean_absolute_error: 0.0133
# Epoch 183/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7834e-04 - mean_absolute_error: 0.0130 - val_loss: 1.5139e-04 - val_mean_absolute_error: 0.0089
# Epoch 184/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.7165e-04 - mean_absolute_error: 0.0134 - val_loss: 1.5794e-04 - val_mean_absolute_error: 0.0092
# Epoch 185/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8320e-04 - mean_absolute_error: 0.0135 - val_loss: 1.5091e-04 - val_mean_absolute_error: 0.0088
# Epoch 186/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8751e-04 - mean_absolute_error: 0.0132 - val_loss: 1.6688e-04 - val_mean_absolute_error: 0.0096
# Epoch 187/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.1431e-04 - mean_absolute_error: 0.0134 - val_loss: 4.3595e-04 - val_mean_absolute_error: 0.0185
# Epoch 188/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.7597e-04 - mean_absolute_error: 0.0149 - val_loss: 1.4836e-04 - val_mean_absolute_error: 0.0087
# Epoch 189/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.9117e-04 - mean_absolute_error: 0.0130 - val_loss: 1.5191e-04 - val_mean_absolute_error: 0.0089
# Epoch 190/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.9670e-04 - mean_absolute_error: 0.0132 - val_loss: 1.5699e-04 - val_mean_absolute_error: 0.0091
# Epoch 191/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.4770e-04 - mean_absolute_error: 0.0127 - val_loss: 2.1918e-04 - val_mean_absolute_error: 0.0118
# Epoch 192/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.3308e-04 - mean_absolute_error: 0.0135 - val_loss: 1.9911e-04 - val_mean_absolute_error: 0.0111
# Epoch 193/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.2848e-04 - mean_absolute_error: 0.0137 - val_loss: 1.6832e-04 - val_mean_absolute_error: 0.0097
# Epoch 194/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.5446e-04 - mean_absolute_error: 0.0123 - val_loss: 1.4944e-04 - val_mean_absolute_error: 0.0088
# Epoch 195/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.8964e-04 - mean_absolute_error: 0.0132 - val_loss: 1.5625e-04 - val_mean_absolute_error: 0.0091
# Epoch 196/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.2431e-04 - mean_absolute_error: 0.0123 - val_loss: 1.4858e-04 - val_mean_absolute_error: 0.0087
# Epoch 197/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.0013e-04 - mean_absolute_error: 0.0133 - val_loss: 1.8110e-04 - val_mean_absolute_error: 0.0102
# Epoch 198/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7773e-04 - mean_absolute_error: 0.0129 - val_loss: 1.9765e-04 - val_mean_absolute_error: 0.0110
# Epoch 199/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.6514e-04 - mean_absolute_error: 0.0129 - val_loss: 2.2080e-04 - val_mean_absolute_error: 0.0117
# Epoch 200/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.7988e-04 - mean_absolute_error: 0.0135 - val_loss: 1.7900e-04 - val_mean_absolute_error: 0.0102

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 248ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4503e-04 - mean_absolute_error: 0.0093
# Test Loss: [0.00017900046077556908, 0.010212276130914688]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 120
# 131

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 81038.2655766805
# RMSE: 284.6722072431387
# MAE: 219.03361002604166
# MAPE: 2.045481553984764 %
#
# Model evalution on validate set
# MSE: 75859.01658565742
# RMSE: 275.42515605089056
# MAE: 192.08818117252065
# MAPE: 1.845003576229535 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 725ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step

# %%
y_pred_30_days
# Out:
# array([[12758.203 ],
#        [12710.734 ],
#        [12750.931 ],
#        [12734.699 ],
#        [12744.3125],
#        [12740.02  ],
#        [12742.317 ],
#        [12741.207 ],
#        [12741.775 ],
#        [12741.496 ],
#        [12741.638 ],
#        [12741.567 ],
#        [12741.602 ],
#        [12741.585 ],
#        [12741.594 ],
#        [12741.59  ],
#        [12741.593 ],
#        [12741.591 ],
#        [12741.593 ],
#        [12741.592 ],
#        [12741.592 ],
#        [12741.592 ],
#        [12741.592 ],
#        [12741.592 ],
#        [12741.591 ],
#        [12741.592 ],
#        [12741.592 ],
#        [12741.592 ],
#        [12741.592 ],
#        [12741.592 ],
#        [12741.591 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
