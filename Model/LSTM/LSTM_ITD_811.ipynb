# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: ITD - Test/Train/Vaildation: 80/10/10
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 319.39
# - MAE: 270.72
# - MAPE: 2.35 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170
# ...           ...
# 2024-02-26   9700
# 2024-02-27   9640
# 2024-02-28   9890
# 2024-02-29   9950
# 2024-03-01   9990
#
# [1252 rows x 1 columns]

# %%
df.shape
# Out:
# (1252, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       6900
# 1       7100
# 2       7100
# 3       7170
# 4       7170
#         ...
# 1247    9700
# 1248    9640
# 1249    9890
# 1250    9950
# 1251    9990
# Name: close, Length: 1252, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((990, 10), (990,), (114, 10), (114,), (115, 10), (115,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0500 - mean_absolute_error: 0.1599 - val_loss: 9.0763e-04 - val_mean_absolute_error: 0.0259
# Epoch 2/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mean_absolute_error: 0.0314 - val_loss: 2.9131e-04 - val_mean_absolute_error: 0.0127
# Epoch 3/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - mean_absolute_error: 0.0273 - val_loss: 3.1486e-04 - val_mean_absolute_error: 0.0127
# Epoch 4/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017 - mean_absolute_error: 0.0260 - val_loss: 3.2979e-04 - val_mean_absolute_error: 0.0130
# Epoch 5/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mean_absolute_error: 0.0251 - val_loss: 3.4054e-04 - val_mean_absolute_error: 0.0151
# Epoch 6/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - mean_absolute_error: 0.0243 - val_loss: 3.1875e-04 - val_mean_absolute_error: 0.0144
# Epoch 7/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0017 - mean_absolute_error: 0.0259 - val_loss: 3.1135e-04 - val_mean_absolute_error: 0.0126
# Epoch 8/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0237 - val_loss: 3.1506e-04 - val_mean_absolute_error: 0.0144
# Epoch 9/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mean_absolute_error: 0.0243 - val_loss: 7.9584e-04 - val_mean_absolute_error: 0.0254
# Epoch 10/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - mean_absolute_error: 0.0252 - val_loss: 4.7249e-04 - val_mean_absolute_error: 0.0167
# Epoch 11/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0247 - val_loss: 5.5048e-04 - val_mean_absolute_error: 0.0207
# Epoch 12/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0232 - val_loss: 2.9606e-04 - val_mean_absolute_error: 0.0122
# Epoch 13/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0228 - val_loss: 2.7921e-04 - val_mean_absolute_error: 0.0118
# Epoch 14/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0234 - val_loss: 2.4608e-04 - val_mean_absolute_error: 0.0113
# Epoch 15/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0209 - val_loss: 2.4372e-04 - val_mean_absolute_error: 0.0111
# Epoch 16/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0214 - val_loss: 4.6381e-04 - val_mean_absolute_error: 0.0190
# Epoch 17/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - mean_absolute_error: 0.0254 - val_loss: 2.5583e-04 - val_mean_absolute_error: 0.0126
# Epoch 18/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - mean_absolute_error: 0.0232 - val_loss: 3.8306e-04 - val_mean_absolute_error: 0.0169
# Epoch 19/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0209 - val_loss: 3.7168e-04 - val_mean_absolute_error: 0.0167
# Epoch 20/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0223 - val_loss: 2.2360e-04 - val_mean_absolute_error: 0.0105
# Epoch 21/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - mean_absolute_error: 0.0211 - val_loss: 2.4911e-04 - val_mean_absolute_error: 0.0111
# Epoch 22/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7946e-04 - mean_absolute_error: 0.0188 - val_loss: 2.2267e-04 - val_mean_absolute_error: 0.0115
# Epoch 23/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7401e-04 - mean_absolute_error: 0.0188 - val_loss: 2.3259e-04 - val_mean_absolute_error: 0.0120
# Epoch 24/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0010 - mean_absolute_error: 0.0208 - val_loss: 2.6326e-04 - val_mean_absolute_error: 0.0133
# Epoch 25/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.8130e-04 - mean_absolute_error: 0.0193 - val_loss: 2.1232e-04 - val_mean_absolute_error: 0.0112
# Epoch 26/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7742e-04 - mean_absolute_error: 0.0188 - val_loss: 1.9674e-04 - val_mean_absolute_error: 0.0104
# Epoch 27/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8739e-04 - mean_absolute_error: 0.0204 - val_loss: 4.5260e-04 - val_mean_absolute_error: 0.0190
# Epoch 28/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.9534e-04 - mean_absolute_error: 0.0195 - val_loss: 2.7893e-04 - val_mean_absolute_error: 0.0140
# Epoch 29/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2694e-04 - mean_absolute_error: 0.0187 - val_loss: 2.0156e-04 - val_mean_absolute_error: 0.0100
# Epoch 30/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4668e-04 - mean_absolute_error: 0.0184 - val_loss: 3.2711e-04 - val_mean_absolute_error: 0.0156
# Epoch 31/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6912e-04 - mean_absolute_error: 0.0176 - val_loss: 1.8246e-04 - val_mean_absolute_error: 0.0099
# Epoch 32/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4239e-04 - mean_absolute_error: 0.0187 - val_loss: 1.9027e-04 - val_mean_absolute_error: 0.0097
# Epoch 33/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.4034e-04 - mean_absolute_error: 0.0174 - val_loss: 2.3347e-04 - val_mean_absolute_error: 0.0125
# Epoch 34/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.3365e-04 - mean_absolute_error: 0.0187 - val_loss: 1.8581e-04 - val_mean_absolute_error: 0.0096
# Epoch 35/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.9440e-04 - mean_absolute_error: 0.0184 - val_loss: 1.7543e-04 - val_mean_absolute_error: 0.0098
# Epoch 36/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.2617e-04 - mean_absolute_error: 0.0176 - val_loss: 3.2929e-04 - val_mean_absolute_error: 0.0158
# Epoch 37/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6886e-04 - mean_absolute_error: 0.0169 - val_loss: 4.7301e-04 - val_mean_absolute_error: 0.0196
# Epoch 38/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6134e-04 - mean_absolute_error: 0.0187 - val_loss: 1.7995e-04 - val_mean_absolute_error: 0.0094
# Epoch 39/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.5916e-04 - mean_absolute_error: 0.0165 - val_loss: 2.7801e-04 - val_mean_absolute_error: 0.0128
# Epoch 40/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8543e-04 - mean_absolute_error: 0.0168 - val_loss: 1.6254e-04 - val_mean_absolute_error: 0.0091
# Epoch 41/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9427e-04 - mean_absolute_error: 0.0165 - val_loss: 2.1406e-04 - val_mean_absolute_error: 0.0120
# Epoch 42/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.0096e-04 - mean_absolute_error: 0.0189 - val_loss: 1.6744e-04 - val_mean_absolute_error: 0.0100
# Epoch 43/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6511e-04 - mean_absolute_error: 0.0176 - val_loss: 1.6123e-04 - val_mean_absolute_error: 0.0095
# Epoch 44/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8929e-04 - mean_absolute_error: 0.0153 - val_loss: 1.5796e-04 - val_mean_absolute_error: 0.0094
# Epoch 45/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5255e-04 - mean_absolute_error: 0.0154 - val_loss: 2.0535e-04 - val_mean_absolute_error: 0.0105
# Epoch 46/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8754e-04 - mean_absolute_error: 0.0154 - val_loss: 1.6208e-04 - val_mean_absolute_error: 0.0090
# Epoch 47/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0698e-04 - mean_absolute_error: 0.0156 - val_loss: 1.7826e-04 - val_mean_absolute_error: 0.0096
# Epoch 48/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0554e-04 - mean_absolute_error: 0.0164 - val_loss: 2.1798e-04 - val_mean_absolute_error: 0.0110
# Epoch 49/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4082e-04 - mean_absolute_error: 0.0154 - val_loss: 2.3242e-04 - val_mean_absolute_error: 0.0128
# Epoch 50/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.0027e-04 - mean_absolute_error: 0.0162 - val_loss: 1.6794e-04 - val_mean_absolute_error: 0.0092
# Epoch 51/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3604e-04 - mean_absolute_error: 0.0155 - val_loss: 1.6790e-04 - val_mean_absolute_error: 0.0103
# Epoch 52/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8050e-04 - mean_absolute_error: 0.0144 - val_loss: 4.0300e-04 - val_mean_absolute_error: 0.0178
# Epoch 53/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8202e-04 - mean_absolute_error: 0.0151 - val_loss: 4.1590e-04 - val_mean_absolute_error: 0.0181
# Epoch 54/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.8761e-04 - mean_absolute_error: 0.0158 - val_loss: 5.8294e-04 - val_mean_absolute_error: 0.0219
# Epoch 55/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.8158e-04 - mean_absolute_error: 0.0174 - val_loss: 3.7927e-04 - val_mean_absolute_error: 0.0172
# Epoch 56/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5865e-04 - mean_absolute_error: 0.0167 - val_loss: 3.6125e-04 - val_mean_absolute_error: 0.0160
# Epoch 57/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9699e-04 - mean_absolute_error: 0.0161 - val_loss: 5.2289e-04 - val_mean_absolute_error: 0.0203
# Epoch 58/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6077e-04 - mean_absolute_error: 0.0192 - val_loss: 6.0010e-04 - val_mean_absolute_error: 0.0223
# Epoch 59/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.6474e-04 - mean_absolute_error: 0.0154 - val_loss: 1.5018e-04 - val_mean_absolute_error: 0.0087
# Epoch 60/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3415e-04 - mean_absolute_error: 0.0169 - val_loss: 1.3944e-04 - val_mean_absolute_error: 0.0084
# Epoch 61/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8066e-04 - mean_absolute_error: 0.0139 - val_loss: 2.6225e-04 - val_mean_absolute_error: 0.0138
# Epoch 62/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3166e-04 - mean_absolute_error: 0.0156 - val_loss: 2.0988e-04 - val_mean_absolute_error: 0.0120
# Epoch 63/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5344e-04 - mean_absolute_error: 0.0135 - val_loss: 2.3776e-04 - val_mean_absolute_error: 0.0121
# Epoch 64/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4874e-04 - mean_absolute_error: 0.0137 - val_loss: 1.3622e-04 - val_mean_absolute_error: 0.0085
# Epoch 65/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1112e-04 - mean_absolute_error: 0.0131 - val_loss: 1.6441e-04 - val_mean_absolute_error: 0.0093
# Epoch 66/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1354e-04 - mean_absolute_error: 0.0146 - val_loss: 2.4391e-04 - val_mean_absolute_error: 0.0131
# Epoch 67/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1179e-04 - mean_absolute_error: 0.0140 - val_loss: 1.4930e-04 - val_mean_absolute_error: 0.0093
# Epoch 68/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0446e-04 - mean_absolute_error: 0.0136 - val_loss: 1.8159e-04 - val_mean_absolute_error: 0.0100
# Epoch 69/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1388e-04 - mean_absolute_error: 0.0149 - val_loss: 1.3764e-04 - val_mean_absolute_error: 0.0084
# Epoch 70/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3458e-04 - mean_absolute_error: 0.0138 - val_loss: 1.5201e-04 - val_mean_absolute_error: 0.0094
# Epoch 71/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1625e-04 - mean_absolute_error: 0.0133 - val_loss: 2.8419e-04 - val_mean_absolute_error: 0.0143
# Epoch 72/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1836e-04 - mean_absolute_error: 0.0138 - val_loss: 1.5589e-04 - val_mean_absolute_error: 0.0095
# Epoch 73/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2838e-04 - mean_absolute_error: 0.0140 - val_loss: 1.5732e-04 - val_mean_absolute_error: 0.0092
# Epoch 74/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9659e-04 - mean_absolute_error: 0.0129 - val_loss: 3.6752e-04 - val_mean_absolute_error: 0.0167
# Epoch 75/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0939e-04 - mean_absolute_error: 0.0159 - val_loss: 1.5425e-04 - val_mean_absolute_error: 0.0090
# Epoch 76/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8842e-04 - mean_absolute_error: 0.0129 - val_loss: 3.2161e-04 - val_mean_absolute_error: 0.0154
# Epoch 77/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2817e-04 - mean_absolute_error: 0.0142 - val_loss: 3.3761e-04 - val_mean_absolute_error: 0.0158
# Epoch 78/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0588e-04 - mean_absolute_error: 0.0153 - val_loss: 2.0752e-04 - val_mean_absolute_error: 0.0111
# Epoch 79/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5668e-04 - mean_absolute_error: 0.0144 - val_loss: 1.7205e-04 - val_mean_absolute_error: 0.0101
# Epoch 80/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1368e-04 - mean_absolute_error: 0.0132 - val_loss: 1.5120e-04 - val_mean_absolute_error: 0.0089
# Epoch 81/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0163e-04 - mean_absolute_error: 0.0131 - val_loss: 1.4822e-04 - val_mean_absolute_error: 0.0088
# Epoch 82/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0963e-04 - mean_absolute_error: 0.0130 - val_loss: 3.6988e-04 - val_mean_absolute_error: 0.0166
# Epoch 83/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4906e-04 - mean_absolute_error: 0.0140 - val_loss: 1.6730e-04 - val_mean_absolute_error: 0.0097
# Epoch 84/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8437e-04 - mean_absolute_error: 0.0127 - val_loss: 1.5829e-04 - val_mean_absolute_error: 0.0092
# Epoch 85/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2957e-04 - mean_absolute_error: 0.0137 - val_loss: 1.5087e-04 - val_mean_absolute_error: 0.0088
# Epoch 86/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9333e-04 - mean_absolute_error: 0.0126 - val_loss: 1.8456e-04 - val_mean_absolute_error: 0.0104
# Epoch 87/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7673e-04 - mean_absolute_error: 0.0127 - val_loss: 2.3159e-04 - val_mean_absolute_error: 0.0123
# Epoch 88/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0278e-04 - mean_absolute_error: 0.0131 - val_loss: 1.5233e-04 - val_mean_absolute_error: 0.0088
# Epoch 89/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4419e-04 - mean_absolute_error: 0.0139 - val_loss: 1.5688e-04 - val_mean_absolute_error: 0.0091
# Epoch 90/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5164e-04 - mean_absolute_error: 0.0123 - val_loss: 2.0499e-04 - val_mean_absolute_error: 0.0112
# Epoch 91/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9064e-04 - mean_absolute_error: 0.0131 - val_loss: 2.5443e-04 - val_mean_absolute_error: 0.0130
# Epoch 92/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2833e-04 - mean_absolute_error: 0.0143 - val_loss: 2.5999e-04 - val_mean_absolute_error: 0.0129
# Epoch 93/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4407e-04 - mean_absolute_error: 0.0146 - val_loss: 2.2512e-04 - val_mean_absolute_error: 0.0120
# Epoch 94/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6443e-04 - mean_absolute_error: 0.0144 - val_loss: 1.6779e-04 - val_mean_absolute_error: 0.0095
# Epoch 95/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7681e-04 - mean_absolute_error: 0.0130 - val_loss: 1.6202e-04 - val_mean_absolute_error: 0.0092
# Epoch 96/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4873e-04 - mean_absolute_error: 0.0123 - val_loss: 1.6128e-04 - val_mean_absolute_error: 0.0092
# Epoch 97/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3774e-04 - mean_absolute_error: 0.0141 - val_loss: 1.5757e-04 - val_mean_absolute_error: 0.0090
# Epoch 98/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8053e-04 - mean_absolute_error: 0.0125 - val_loss: 1.5807e-04 - val_mean_absolute_error: 0.0090
# Epoch 99/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6153e-04 - mean_absolute_error: 0.0120 - val_loss: 1.9938e-04 - val_mean_absolute_error: 0.0107
# Epoch 100/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1093e-04 - mean_absolute_error: 0.0118 - val_loss: 2.2828e-04 - val_mean_absolute_error: 0.0120
# Epoch 101/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1310e-04 - mean_absolute_error: 0.0134 - val_loss: 2.6215e-04 - val_mean_absolute_error: 0.0131
# Epoch 102/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6235e-04 - mean_absolute_error: 0.0147 - val_loss: 2.2419e-04 - val_mean_absolute_error: 0.0116
# Epoch 103/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9522e-04 - mean_absolute_error: 0.0132 - val_loss: 2.1498e-04 - val_mean_absolute_error: 0.0112
# Epoch 104/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1459e-04 - mean_absolute_error: 0.0146 - val_loss: 1.7799e-04 - val_mean_absolute_error: 0.0099
# Epoch 105/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7714e-04 - mean_absolute_error: 0.0133 - val_loss: 1.5874e-04 - val_mean_absolute_error: 0.0090
# Epoch 106/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8864e-04 - mean_absolute_error: 0.0130 - val_loss: 1.6522e-04 - val_mean_absolute_error: 0.0093
# Epoch 107/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5026e-04 - mean_absolute_error: 0.0122 - val_loss: 2.3489e-04 - val_mean_absolute_error: 0.0121
# Epoch 108/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9341e-04 - mean_absolute_error: 0.0131 - val_loss: 2.2870e-04 - val_mean_absolute_error: 0.0119
# Epoch 109/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6015e-04 - mean_absolute_error: 0.0127 - val_loss: 1.6090e-04 - val_mean_absolute_error: 0.0091
# Epoch 110/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7950e-04 - mean_absolute_error: 0.0128 - val_loss: 2.4123e-04 - val_mean_absolute_error: 0.0123
# Epoch 111/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0606e-04 - mean_absolute_error: 0.0137 - val_loss: 1.6416e-04 - val_mean_absolute_error: 0.0092
# Epoch 112/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7866e-04 - mean_absolute_error: 0.0130 - val_loss: 1.6328e-04 - val_mean_absolute_error: 0.0092
# Epoch 113/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7979e-04 - mean_absolute_error: 0.0127 - val_loss: 1.9484e-04 - val_mean_absolute_error: 0.0105
# Epoch 114/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5627e-04 - mean_absolute_error: 0.0144 - val_loss: 1.6864e-04 - val_mean_absolute_error: 0.0094
# Epoch 115/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5877e-04 - mean_absolute_error: 0.0126 - val_loss: 2.2567e-04 - val_mean_absolute_error: 0.0116
# Epoch 116/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6012e-04 - mean_absolute_error: 0.0145 - val_loss: 1.6278e-04 - val_mean_absolute_error: 0.0092
# Epoch 117/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1386e-04 - mean_absolute_error: 0.0135 - val_loss: 1.7109e-04 - val_mean_absolute_error: 0.0095
# Epoch 118/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7546e-04 - mean_absolute_error: 0.0128 - val_loss: 1.6997e-04 - val_mean_absolute_error: 0.0095
# Epoch 119/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0245e-04 - mean_absolute_error: 0.0132 - val_loss: 1.6371e-04 - val_mean_absolute_error: 0.0092
# Epoch 120/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8881e-04 - mean_absolute_error: 0.0131 - val_loss: 4.6014e-04 - val_mean_absolute_error: 0.0187
# Epoch 121/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4565e-04 - mean_absolute_error: 0.0144 - val_loss: 1.7214e-04 - val_mean_absolute_error: 0.0096
# Epoch 122/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9060e-04 - mean_absolute_error: 0.0129 - val_loss: 2.0424e-04 - val_mean_absolute_error: 0.0108
# Epoch 123/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1825e-04 - mean_absolute_error: 0.0138 - val_loss: 3.0646e-04 - val_mean_absolute_error: 0.0143
# Epoch 124/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9292e-04 - mean_absolute_error: 0.0131 - val_loss: 2.1980e-04 - val_mean_absolute_error: 0.0114
# Epoch 125/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2065e-04 - mean_absolute_error: 0.0137 - val_loss: 1.6444e-04 - val_mean_absolute_error: 0.0092
# Epoch 126/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8280e-04 - mean_absolute_error: 0.0132 - val_loss: 2.0314e-04 - val_mean_absolute_error: 0.0107
# Epoch 127/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6868e-04 - mean_absolute_error: 0.0124 - val_loss: 3.1208e-04 - val_mean_absolute_error: 0.0146
# Epoch 128/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4949e-04 - mean_absolute_error: 0.0145 - val_loss: 2.2615e-04 - val_mean_absolute_error: 0.0116
# Epoch 129/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5711e-04 - mean_absolute_error: 0.0130 - val_loss: 2.1996e-04 - val_mean_absolute_error: 0.0114
# Epoch 130/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0600e-04 - mean_absolute_error: 0.0130 - val_loss: 2.0758e-04 - val_mean_absolute_error: 0.0109
# Epoch 131/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8404e-04 - mean_absolute_error: 0.0133 - val_loss: 1.7911e-04 - val_mean_absolute_error: 0.0099
# Epoch 132/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2914e-04 - mean_absolute_error: 0.0142 - val_loss: 3.1361e-04 - val_mean_absolute_error: 0.0146
# Epoch 133/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3306e-04 - mean_absolute_error: 0.0145 - val_loss: 1.9701e-04 - val_mean_absolute_error: 0.0105
# Epoch 134/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1116e-04 - mean_absolute_error: 0.0132 - val_loss: 1.7016e-04 - val_mean_absolute_error: 0.0094
# Epoch 135/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7061e-04 - mean_absolute_error: 0.0125 - val_loss: 2.1757e-04 - val_mean_absolute_error: 0.0113
# Epoch 136/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2374e-04 - mean_absolute_error: 0.0137 - val_loss: 2.7420e-04 - val_mean_absolute_error: 0.0134
# Epoch 137/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5125e-04 - mean_absolute_error: 0.0128 - val_loss: 1.7707e-04 - val_mean_absolute_error: 0.0097
# Epoch 138/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6279e-04 - mean_absolute_error: 0.0125 - val_loss: 1.6499e-04 - val_mean_absolute_error: 0.0092
# Epoch 139/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9249e-04 - mean_absolute_error: 0.0132 - val_loss: 1.7058e-04 - val_mean_absolute_error: 0.0094
# Epoch 140/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0252e-04 - mean_absolute_error: 0.0131 - val_loss: 2.2232e-04 - val_mean_absolute_error: 0.0114
# Epoch 141/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8915e-04 - mean_absolute_error: 0.0132 - val_loss: 1.8053e-04 - val_mean_absolute_error: 0.0099
# Epoch 142/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6480e-04 - mean_absolute_error: 0.0128 - val_loss: 1.6932e-04 - val_mean_absolute_error: 0.0094
# Epoch 143/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9762e-04 - mean_absolute_error: 0.0140 - val_loss: 2.4351e-04 - val_mean_absolute_error: 0.0123
# Epoch 144/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7592e-04 - mean_absolute_error: 0.0125 - val_loss: 1.7066e-04 - val_mean_absolute_error: 0.0095
# Epoch 145/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7786e-04 - mean_absolute_error: 0.0134 - val_loss: 1.6872e-04 - val_mean_absolute_error: 0.0094
# Epoch 146/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8352e-04 - mean_absolute_error: 0.0133 - val_loss: 1.8922e-04 - val_mean_absolute_error: 0.0102
# Epoch 147/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7948e-04 - mean_absolute_error: 0.0132 - val_loss: 2.4802e-04 - val_mean_absolute_error: 0.0124
# Epoch 148/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6425e-04 - mean_absolute_error: 0.0128 - val_loss: 1.6932e-04 - val_mean_absolute_error: 0.0093
# Epoch 149/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7713e-04 - mean_absolute_error: 0.0129 - val_loss: 2.1770e-04 - val_mean_absolute_error: 0.0113
# Epoch 150/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7963e-04 - mean_absolute_error: 0.0130 - val_loss: 2.3168e-04 - val_mean_absolute_error: 0.0117
# Epoch 151/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7719e-04 - mean_absolute_error: 0.0127 - val_loss: 2.1218e-04 - val_mean_absolute_error: 0.0110
# Epoch 152/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3567e-04 - mean_absolute_error: 0.0137 - val_loss: 1.9034e-04 - val_mean_absolute_error: 0.0102
# Epoch 153/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4064e-04 - mean_absolute_error: 0.0121 - val_loss: 1.9726e-04 - val_mean_absolute_error: 0.0105
# Epoch 154/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0359e-04 - mean_absolute_error: 0.0132 - val_loss: 1.7131e-04 - val_mean_absolute_error: 0.0094
# Epoch 155/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4517e-04 - mean_absolute_error: 0.0124 - val_loss: 2.0682e-04 - val_mean_absolute_error: 0.0108
# Epoch 156/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6809e-04 - mean_absolute_error: 0.0127 - val_loss: 1.7089e-04 - val_mean_absolute_error: 0.0094
# Epoch 157/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5016e-04 - mean_absolute_error: 0.0122 - val_loss: 1.7741e-04 - val_mean_absolute_error: 0.0097
# Epoch 158/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0154e-04 - mean_absolute_error: 0.0131 - val_loss: 1.7331e-04 - val_mean_absolute_error: 0.0095
# Epoch 159/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7694e-04 - mean_absolute_error: 0.0129 - val_loss: 1.7357e-04 - val_mean_absolute_error: 0.0095
# Epoch 160/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4604e-04 - mean_absolute_error: 0.0122 - val_loss: 2.1363e-04 - val_mean_absolute_error: 0.0111
# Epoch 161/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6163e-04 - mean_absolute_error: 0.0129 - val_loss: 2.2724e-04 - val_mean_absolute_error: 0.0116
# Epoch 162/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0593e-04 - mean_absolute_error: 0.0132 - val_loss: 1.6760e-04 - val_mean_absolute_error: 0.0093
# Epoch 163/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0571e-04 - mean_absolute_error: 0.0128 - val_loss: 2.2623e-04 - val_mean_absolute_error: 0.0116
# Epoch 164/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2762e-04 - mean_absolute_error: 0.0118 - val_loss: 1.6783e-04 - val_mean_absolute_error: 0.0093
# Epoch 165/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5245e-04 - mean_absolute_error: 0.0121 - val_loss: 1.9377e-04 - val_mean_absolute_error: 0.0103
# Epoch 166/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6096e-04 - mean_absolute_error: 0.0122 - val_loss: 1.8249e-04 - val_mean_absolute_error: 0.0099
# Epoch 167/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8673e-04 - mean_absolute_error: 0.0132 - val_loss: 1.7881e-04 - val_mean_absolute_error: 0.0097
# Epoch 168/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2363e-04 - mean_absolute_error: 0.0116 - val_loss: 1.7476e-04 - val_mean_absolute_error: 0.0096
# Epoch 169/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5407e-04 - mean_absolute_error: 0.0124 - val_loss: 1.8733e-04 - val_mean_absolute_error: 0.0101
# Epoch 170/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1969e-04 - mean_absolute_error: 0.0135 - val_loss: 2.0823e-04 - val_mean_absolute_error: 0.0109
# Epoch 171/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6739e-04 - mean_absolute_error: 0.0129 - val_loss: 2.6028e-04 - val_mean_absolute_error: 0.0127
# Epoch 172/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0951e-04 - mean_absolute_error: 0.0136 - val_loss: 1.7524e-04 - val_mean_absolute_error: 0.0096
# Epoch 173/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1550e-04 - mean_absolute_error: 0.0131 - val_loss: 3.8801e-04 - val_mean_absolute_error: 0.0167
# Epoch 174/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4089e-04 - mean_absolute_error: 0.0142 - val_loss: 1.8589e-04 - val_mean_absolute_error: 0.0100
# Epoch 175/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7905e-04 - mean_absolute_error: 0.0127 - val_loss: 2.1130e-04 - val_mean_absolute_error: 0.0109
# Epoch 176/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6734e-04 - mean_absolute_error: 0.0129 - val_loss: 2.3773e-04 - val_mean_absolute_error: 0.0119
# Epoch 177/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1027e-04 - mean_absolute_error: 0.0144 - val_loss: 1.7371e-04 - val_mean_absolute_error: 0.0094
# Epoch 178/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0075e-04 - mean_absolute_error: 0.0131 - val_loss: 1.8021e-04 - val_mean_absolute_error: 0.0098
# Epoch 179/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1235e-04 - mean_absolute_error: 0.0134 - val_loss: 2.9607e-04 - val_mean_absolute_error: 0.0139
# Epoch 180/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0257e-04 - mean_absolute_error: 0.0137 - val_loss: 3.2140e-04 - val_mean_absolute_error: 0.0146
# Epoch 181/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8466e-04 - mean_absolute_error: 0.0129 - val_loss: 1.7644e-04 - val_mean_absolute_error: 0.0096
# Epoch 182/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6214e-04 - mean_absolute_error: 0.0126 - val_loss: 2.5307e-04 - val_mean_absolute_error: 0.0124
# Epoch 183/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8334e-04 - mean_absolute_error: 0.0134 - val_loss: 2.2244e-04 - val_mean_absolute_error: 0.0114
# Epoch 184/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6020e-04 - mean_absolute_error: 0.0140 - val_loss: 1.6922e-04 - val_mean_absolute_error: 0.0093
# Epoch 185/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6294e-04 - mean_absolute_error: 0.0126 - val_loss: 1.7033e-04 - val_mean_absolute_error: 0.0094
# Epoch 186/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2813e-04 - mean_absolute_error: 0.0135 - val_loss: 1.7793e-04 - val_mean_absolute_error: 0.0097
# Epoch 187/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9550e-04 - mean_absolute_error: 0.0133 - val_loss: 1.9315e-04 - val_mean_absolute_error: 0.0103
# Epoch 188/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9465e-04 - mean_absolute_error: 0.0134 - val_loss: 2.6168e-04 - val_mean_absolute_error: 0.0128
# Epoch 189/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1503e-04 - mean_absolute_error: 0.0142 - val_loss: 2.2619e-04 - val_mean_absolute_error: 0.0115
# Epoch 190/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8415e-04 - mean_absolute_error: 0.0136 - val_loss: 2.6267e-04 - val_mean_absolute_error: 0.0128
# Epoch 191/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8850e-04 - mean_absolute_error: 0.0135 - val_loss: 2.6450e-04 - val_mean_absolute_error: 0.0128
# Epoch 192/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0369e-04 - mean_absolute_error: 0.0141 - val_loss: 1.7534e-04 - val_mean_absolute_error: 0.0095
# Epoch 193/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7863e-04 - mean_absolute_error: 0.0127 - val_loss: 1.7287e-04 - val_mean_absolute_error: 0.0094
# Epoch 194/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2706e-04 - mean_absolute_error: 0.0116 - val_loss: 2.1037e-04 - val_mean_absolute_error: 0.0110
# Epoch 195/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1903e-04 - mean_absolute_error: 0.0139 - val_loss: 1.7916e-04 - val_mean_absolute_error: 0.0097
# Epoch 196/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4090e-04 - mean_absolute_error: 0.0123 - val_loss: 1.7394e-04 - val_mean_absolute_error: 0.0094
# Epoch 197/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4660e-04 - mean_absolute_error: 0.0124 - val_loss: 1.8467e-04 - val_mean_absolute_error: 0.0100
# Epoch 198/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0347e-04 - mean_absolute_error: 0.0131 - val_loss: 1.8317e-04 - val_mean_absolute_error: 0.0099
# Epoch 199/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4161e-04 - mean_absolute_error: 0.0140 - val_loss: 2.5730e-04 - val_mean_absolute_error: 0.0126
# Epoch 200/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2432e-04 - mean_absolute_error: 0.0140 - val_loss: 3.4632e-04 - val_mean_absolute_error: 0.0155

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5281e-04 - mean_absolute_error: 0.0156
# Test Loss: [0.0003463176544755697, 0.01548092532902956]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 114
# 125

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 102009.94241860876
# RMSE: 319.38995353424747
# MAE: 270.7207288240132
# MAPE: 2.3511514198033616 %
#
# Model evalution on validate set
# MSE: 91766.12829972143
# RMSE: 302.92924635914807
# MAE: 237.9495159646739
# MAPE: 2.3997562510361012 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %%
y_pred_30_days
# Out:
# array([[10059.471 ],
#        [10065.569 ],
#        [10076.599 ],
#        [10078.131 ],
#        [10080.008 ],
#        [10080.225 ],
#        [10080.4795],
#        [10080.518 ],
#        [10080.556 ],
#        [10080.562 ],
#        [10080.565 ],
#        [10080.567 ],
#        [10080.568 ],
#        [10080.568 ],
#        [10080.569 ],
#        [10080.569 ],
#        [10080.569 ],
#        [10080.569 ],
#        [10080.569 ],
#        [10080.569 ],
#        [10080.569 ],
#        [10080.569 ],
#        [10080.569 ],
#        [10080.569 ],
#        [10080.569 ],
#        [10080.569 ],
#        [10080.569 ],
#        [10080.569 ],
#        [10080.569 ],
#        [10080.569 ],
#        [10080.569 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
