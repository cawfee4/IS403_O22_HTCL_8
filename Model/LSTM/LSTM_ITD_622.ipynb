# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: ITD - Test/Train/Vaildation: 60/20/20
# - Dataset: 1313 rows x 7 columns (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 405.0625621742215
# - MAE: 294.23096870331176
# - MAPE: 2.693790468159049 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170
# ...           ...
# 2024-05-27  11300
# 2024-05-28  12050
# 2024-05-29  12600
# 2024-05-30  12500
# 2024-05-31  12700
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        6900
# 1        7100
# 2        7100
# 3        7170
# 4        7170
#         ...
# 1308    11300
# 1309    12050
# 1310    12600
# 1311    12500
# 1312    12700
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((776, 10), (776,), (251, 10), (251,), (253, 10), (253,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 91ms/step - loss: 0.0571 - mean_absolute_error: 0.1564 - val_loss: 0.0034 - val_mean_absolute_error: 0.0500
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0038 - mean_absolute_error: 0.0385 - val_loss: 0.0016 - val_mean_absolute_error: 0.0306
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0018 - mean_absolute_error: 0.0255 - val_loss: 0.0013 - val_mean_absolute_error: 0.0265
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0015 - mean_absolute_error: 0.0246 - val_loss: 0.0013 - val_mean_absolute_error: 0.0264
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0016 - mean_absolute_error: 0.0240 - val_loss: 0.0013 - val_mean_absolute_error: 0.0269
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0015 - mean_absolute_error: 0.0228 - val_loss: 0.0013 - val_mean_absolute_error: 0.0263
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0016 - mean_absolute_error: 0.0245 - val_loss: 0.0013 - val_mean_absolute_error: 0.0264
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0013 - mean_absolute_error: 0.0212 - val_loss: 0.0014 - val_mean_absolute_error: 0.0288
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0015 - mean_absolute_error: 0.0237 - val_loss: 0.0013 - val_mean_absolute_error: 0.0269
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0018 - mean_absolute_error: 0.0262 - val_loss: 0.0012 - val_mean_absolute_error: 0.0253
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0012 - mean_absolute_error: 0.0208 - val_loss: 0.0015 - val_mean_absolute_error: 0.0300
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0014 - mean_absolute_error: 0.0224 - val_loss: 0.0013 - val_mean_absolute_error: 0.0267
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0227 - val_loss: 0.0015 - val_mean_absolute_error: 0.0298
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0013 - mean_absolute_error: 0.0219 - val_loss: 0.0011 - val_mean_absolute_error: 0.0243
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0014 - mean_absolute_error: 0.0226 - val_loss: 0.0013 - val_mean_absolute_error: 0.0271
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0014 - mean_absolute_error: 0.0232 - val_loss: 0.0014 - val_mean_absolute_error: 0.0289
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - mean_absolute_error: 0.0228 - val_loss: 0.0014 - val_mean_absolute_error: 0.0290
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0011 - mean_absolute_error: 0.0208 - val_loss: 0.0014 - val_mean_absolute_error: 0.0297
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0013 - mean_absolute_error: 0.0224 - val_loss: 0.0016 - val_mean_absolute_error: 0.0325
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0015 - mean_absolute_error: 0.0259 - val_loss: 0.0012 - val_mean_absolute_error: 0.0264
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0014 - mean_absolute_error: 0.0249 - val_loss: 0.0012 - val_mean_absolute_error: 0.0270
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - mean_absolute_error: 0.0240 - val_loss: 0.0011 - val_mean_absolute_error: 0.0252
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0010 - mean_absolute_error: 0.0198 - val_loss: 9.9275e-04 - val_mean_absolute_error: 0.0231
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0011 - mean_absolute_error: 0.0205 - val_loss: 0.0011 - val_mean_absolute_error: 0.0249
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0012 - mean_absolute_error: 0.0219 - val_loss: 0.0010 - val_mean_absolute_error: 0.0239
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0013 - mean_absolute_error: 0.0233 - val_loss: 0.0013 - val_mean_absolute_error: 0.0280
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0012 - mean_absolute_error: 0.0212 - val_loss: 9.2506e-04 - val_mean_absolute_error: 0.0222
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0011 - mean_absolute_error: 0.0206 - val_loss: 8.5706e-04 - val_mean_absolute_error: 0.0212
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0011 - mean_absolute_error: 0.0210 - val_loss: 8.4697e-04 - val_mean_absolute_error: 0.0210
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 9.8410e-04 - mean_absolute_error: 0.0192 - val_loss: 9.2591e-04 - val_mean_absolute_error: 0.0226
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 0.0011 - mean_absolute_error: 0.0201 - val_loss: 8.1744e-04 - val_mean_absolute_error: 0.0206
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0010 - mean_absolute_error: 0.0201 - val_loss: 8.7229e-04 - val_mean_absolute_error: 0.0219
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0010 - mean_absolute_error: 0.0224 - val_loss: 7.6936e-04 - val_mean_absolute_error: 0.0200
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.4282e-04 - mean_absolute_error: 0.0177 - val_loss: 7.7486e-04 - val_mean_absolute_error: 0.0204
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.4301e-04 - mean_absolute_error: 0.0185 - val_loss: 8.1841e-04 - val_mean_absolute_error: 0.0211
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 9.5764e-04 - mean_absolute_error: 0.0198 - val_loss: 7.3485e-04 - val_mean_absolute_error: 0.0194
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.0063e-04 - mean_absolute_error: 0.0171 - val_loss: 9.5969e-04 - val_mean_absolute_error: 0.0241
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.5200e-04 - mean_absolute_error: 0.0178 - val_loss: 7.0390e-04 - val_mean_absolute_error: 0.0190
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.7178e-04 - mean_absolute_error: 0.0184 - val_loss: 7.6386e-04 - val_mean_absolute_error: 0.0203
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.0056e-04 - mean_absolute_error: 0.0178 - val_loss: 7.7489e-04 - val_mean_absolute_error: 0.0211
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0011 - mean_absolute_error: 0.0206 - val_loss: 6.6061e-04 - val_mean_absolute_error: 0.0186
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.0151e-04 - mean_absolute_error: 0.0178 - val_loss: 6.9947e-04 - val_mean_absolute_error: 0.0195
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.8309e-04 - mean_absolute_error: 0.0199 - val_loss: 6.6144e-04 - val_mean_absolute_error: 0.0183
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 7.8707e-04 - mean_absolute_error: 0.0173 - val_loss: 9.1278e-04 - val_mean_absolute_error: 0.0236
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 9.1642e-04 - mean_absolute_error: 0.0185 - val_loss: 7.4320e-04 - val_mean_absolute_error: 0.0203
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 9.3941e-04 - mean_absolute_error: 0.0199 - val_loss: 6.6398e-04 - val_mean_absolute_error: 0.0186
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.0976e-04 - mean_absolute_error: 0.0186 - val_loss: 6.5809e-04 - val_mean_absolute_error: 0.0188
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.8600e-04 - mean_absolute_error: 0.0180 - val_loss: 8.6283e-04 - val_mean_absolute_error: 0.0229
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.5024e-04 - mean_absolute_error: 0.0174 - val_loss: 6.2200e-04 - val_mean_absolute_error: 0.0183
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.9185e-04 - mean_absolute_error: 0.0174 - val_loss: 5.7761e-04 - val_mean_absolute_error: 0.0172
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.5185e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0010 - val_mean_absolute_error: 0.0260
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 7.8062e-04 - mean_absolute_error: 0.0173 - val_loss: 6.8713e-04 - val_mean_absolute_error: 0.0196
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 6.6513e-04 - mean_absolute_error: 0.0161 - val_loss: 6.0166e-04 - val_mean_absolute_error: 0.0177
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 8.7695e-04 - mean_absolute_error: 0.0182 - val_loss: 5.6561e-04 - val_mean_absolute_error: 0.0172
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.8801e-04 - mean_absolute_error: 0.0169 - val_loss: 5.6675e-04 - val_mean_absolute_error: 0.0171
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 6.9508e-04 - mean_absolute_error: 0.0162 - val_loss: 5.4556e-04 - val_mean_absolute_error: 0.0167
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.9579e-04 - mean_absolute_error: 0.0161 - val_loss: 8.4779e-04 - val_mean_absolute_error: 0.0233
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.9498e-04 - mean_absolute_error: 0.0169 - val_loss: 5.6283e-04 - val_mean_absolute_error: 0.0173
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.0641e-04 - mean_absolute_error: 0.0153 - val_loss: 5.4603e-04 - val_mean_absolute_error: 0.0169
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.8974e-04 - mean_absolute_error: 0.0165 - val_loss: 6.5340e-04 - val_mean_absolute_error: 0.0196
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 9.2850e-04 - mean_absolute_error: 0.0193 - val_loss: 5.2150e-04 - val_mean_absolute_error: 0.0163
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.5085e-04 - mean_absolute_error: 0.0165 - val_loss: 5.4404e-04 - val_mean_absolute_error: 0.0170
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.8217e-04 - mean_absolute_error: 0.0162 - val_loss: 5.2531e-04 - val_mean_absolute_error: 0.0167
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 5.4212e-04 - mean_absolute_error: 0.0146 - val_loss: 5.4234e-04 - val_mean_absolute_error: 0.0170
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.5835e-04 - mean_absolute_error: 0.0189 - val_loss: 4.8824e-04 - val_mean_absolute_error: 0.0159
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.5610e-04 - mean_absolute_error: 0.0161 - val_loss: 5.1852e-04 - val_mean_absolute_error: 0.0166
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.2264e-04 - mean_absolute_error: 0.0167 - val_loss: 4.8549e-04 - val_mean_absolute_error: 0.0159
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.1200e-04 - mean_absolute_error: 0.0155 - val_loss: 6.7146e-04 - val_mean_absolute_error: 0.0205
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.3824e-04 - mean_absolute_error: 0.0160 - val_loss: 4.6346e-04 - val_mean_absolute_error: 0.0155
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.4219e-04 - mean_absolute_error: 0.0140 - val_loss: 4.9170e-04 - val_mean_absolute_error: 0.0164
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.1389e-04 - mean_absolute_error: 0.0156 - val_loss: 4.5446e-04 - val_mean_absolute_error: 0.0155
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 6.6283e-04 - mean_absolute_error: 0.0161 - val_loss: 5.8914e-04 - val_mean_absolute_error: 0.0185
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 6.4211e-04 - mean_absolute_error: 0.0164 - val_loss: 5.0342e-04 - val_mean_absolute_error: 0.0166
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 5.1976e-04 - mean_absolute_error: 0.0146 - val_loss: 4.5063e-04 - val_mean_absolute_error: 0.0154
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 6.6202e-04 - mean_absolute_error: 0.0171 - val_loss: 4.9925e-04 - val_mean_absolute_error: 0.0166
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.0930e-04 - mean_absolute_error: 0.0142 - val_loss: 4.3402e-04 - val_mean_absolute_error: 0.0151
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 5.2643e-04 - mean_absolute_error: 0.0145 - val_loss: 5.5871e-04 - val_mean_absolute_error: 0.0181
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.3825e-04 - mean_absolute_error: 0.0141 - val_loss: 5.2191e-04 - val_mean_absolute_error: 0.0175
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.2892e-04 - mean_absolute_error: 0.0146 - val_loss: 4.4236e-04 - val_mean_absolute_error: 0.0156
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.5503e-04 - mean_absolute_error: 0.0150 - val_loss: 4.8474e-04 - val_mean_absolute_error: 0.0167
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.0604e-04 - mean_absolute_error: 0.0142 - val_loss: 4.7267e-04 - val_mean_absolute_error: 0.0166
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 6.0680e-04 - mean_absolute_error: 0.0155 - val_loss: 4.2918e-04 - val_mean_absolute_error: 0.0153
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5448e-04 - mean_absolute_error: 0.0139 - val_loss: 4.4390e-04 - val_mean_absolute_error: 0.0157
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.8464e-04 - mean_absolute_error: 0.0139 - val_loss: 4.4726e-04 - val_mean_absolute_error: 0.0158
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.9800e-04 - mean_absolute_error: 0.0146 - val_loss: 4.2445e-04 - val_mean_absolute_error: 0.0150
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.4947e-04 - mean_absolute_error: 0.0151 - val_loss: 5.6495e-04 - val_mean_absolute_error: 0.0185
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 6.1362e-04 - mean_absolute_error: 0.0158 - val_loss: 4.1712e-04 - val_mean_absolute_error: 0.0148
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.8512e-04 - mean_absolute_error: 0.0158 - val_loss: 4.0018e-04 - val_mean_absolute_error: 0.0146
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.0042e-04 - mean_absolute_error: 0.0139 - val_loss: 3.9666e-04 - val_mean_absolute_error: 0.0146
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.9655e-04 - mean_absolute_error: 0.0132 - val_loss: 4.4302e-04 - val_mean_absolute_error: 0.0159
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.3277e-04 - mean_absolute_error: 0.0130 - val_loss: 3.8898e-04 - val_mean_absolute_error: 0.0145
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.6981e-04 - mean_absolute_error: 0.0132 - val_loss: 4.7202e-04 - val_mean_absolute_error: 0.0167
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.5699e-04 - mean_absolute_error: 0.0136 - val_loss: 4.4615e-04 - val_mean_absolute_error: 0.0162
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.6106e-04 - mean_absolute_error: 0.0135 - val_loss: 3.9552e-04 - val_mean_absolute_error: 0.0148
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.0854e-04 - mean_absolute_error: 0.0127 - val_loss: 5.4761e-04 - val_mean_absolute_error: 0.0185
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.0397e-04 - mean_absolute_error: 0.0146 - val_loss: 6.1962e-04 - val_mean_absolute_error: 0.0200
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.3508e-04 - mean_absolute_error: 0.0153 - val_loss: 5.4922e-04 - val_mean_absolute_error: 0.0185
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.7114e-04 - mean_absolute_error: 0.0139 - val_loss: 4.1135e-04 - val_mean_absolute_error: 0.0151
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.0797e-04 - mean_absolute_error: 0.0141 - val_loss: 3.7010e-04 - val_mean_absolute_error: 0.0140
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.8616e-04 - mean_absolute_error: 0.0122 - val_loss: 4.2920e-04 - val_mean_absolute_error: 0.0158
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.2999e-04 - mean_absolute_error: 0.0153 - val_loss: 4.0481e-04 - val_mean_absolute_error: 0.0150
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.2368e-04 - mean_absolute_error: 0.0129 - val_loss: 3.7755e-04 - val_mean_absolute_error: 0.0144
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 4.1499e-04 - mean_absolute_error: 0.0128 - val_loss: 4.0350e-04 - val_mean_absolute_error: 0.0150
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 4.1976e-04 - mean_absolute_error: 0.0129 - val_loss: 3.6973e-04 - val_mean_absolute_error: 0.0140
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.6950e-04 - mean_absolute_error: 0.0134 - val_loss: 3.6285e-04 - val_mean_absolute_error: 0.0140
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.2573e-04 - mean_absolute_error: 0.0129 - val_loss: 3.5350e-04 - val_mean_absolute_error: 0.0137
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 3.8447e-04 - mean_absolute_error: 0.0121 - val_loss: 4.4550e-04 - val_mean_absolute_error: 0.0162
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.1899e-04 - mean_absolute_error: 0.0134 - val_loss: 3.6049e-04 - val_mean_absolute_error: 0.0140
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.7086e-04 - mean_absolute_error: 0.0141 - val_loss: 4.0484e-04 - val_mean_absolute_error: 0.0152
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.1216e-04 - mean_absolute_error: 0.0127 - val_loss: 4.0657e-04 - val_mean_absolute_error: 0.0153
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.8903e-04 - mean_absolute_error: 0.0135 - val_loss: 3.5010e-04 - val_mean_absolute_error: 0.0137
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9327e-04 - mean_absolute_error: 0.0130 - val_loss: 4.4806e-04 - val_mean_absolute_error: 0.0163
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.1688e-04 - mean_absolute_error: 0.0150 - val_loss: 6.4345e-04 - val_mean_absolute_error: 0.0208
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.4749e-04 - mean_absolute_error: 0.0162 - val_loss: 8.5762e-04 - val_mean_absolute_error: 0.0246
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.5438e-04 - mean_absolute_error: 0.0169 - val_loss: 4.0511e-04 - val_mean_absolute_error: 0.0151
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.8079e-04 - mean_absolute_error: 0.0150 - val_loss: 5.4405e-04 - val_mean_absolute_error: 0.0186
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.7712e-04 - mean_absolute_error: 0.0142 - val_loss: 3.7085e-04 - val_mean_absolute_error: 0.0144
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.9271e-04 - mean_absolute_error: 0.0123 - val_loss: 3.4678e-04 - val_mean_absolute_error: 0.0137
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.9535e-04 - mean_absolute_error: 0.0158 - val_loss: 3.5050e-04 - val_mean_absolute_error: 0.0138
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.0850e-04 - mean_absolute_error: 0.0126 - val_loss: 3.3051e-04 - val_mean_absolute_error: 0.0133
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.7236e-04 - mean_absolute_error: 0.0129 - val_loss: 3.3652e-04 - val_mean_absolute_error: 0.0134
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.3375e-04 - mean_absolute_error: 0.0138 - val_loss: 3.3592e-04 - val_mean_absolute_error: 0.0134
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.2601e-04 - mean_absolute_error: 0.0133 - val_loss: 3.2719e-04 - val_mean_absolute_error: 0.0132
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.9281e-04 - mean_absolute_error: 0.0131 - val_loss: 4.2988e-04 - val_mean_absolute_error: 0.0160
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.6359e-04 - mean_absolute_error: 0.0139 - val_loss: 3.2483e-04 - val_mean_absolute_error: 0.0132
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.0606e-04 - mean_absolute_error: 0.0127 - val_loss: 3.3440e-04 - val_mean_absolute_error: 0.0134
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 4.4668e-04 - mean_absolute_error: 0.0133 - val_loss: 3.4789e-04 - val_mean_absolute_error: 0.0138
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.1605e-04 - mean_absolute_error: 0.0135 - val_loss: 3.7239e-04 - val_mean_absolute_error: 0.0146
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.4399e-04 - mean_absolute_error: 0.0140 - val_loss: 3.5341e-04 - val_mean_absolute_error: 0.0141
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.9570e-04 - mean_absolute_error: 0.0127 - val_loss: 4.5318e-04 - val_mean_absolute_error: 0.0168
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.8643e-04 - mean_absolute_error: 0.0135 - val_loss: 3.3309e-04 - val_mean_absolute_error: 0.0134
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.8974e-04 - mean_absolute_error: 0.0124 - val_loss: 3.2903e-04 - val_mean_absolute_error: 0.0133
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.3488e-04 - mean_absolute_error: 0.0118 - val_loss: 3.3537e-04 - val_mean_absolute_error: 0.0136
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.4888e-04 - mean_absolute_error: 0.0122 - val_loss: 3.2442e-04 - val_mean_absolute_error: 0.0131
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.3583e-04 - mean_absolute_error: 0.0120 - val_loss: 3.4206e-04 - val_mean_absolute_error: 0.0139
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.3419e-04 - mean_absolute_error: 0.0115 - val_loss: 3.7994e-04 - val_mean_absolute_error: 0.0148
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.9558e-04 - mean_absolute_error: 0.0129 - val_loss: 3.1626e-04 - val_mean_absolute_error: 0.0131
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.7586e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1610e-04 - val_mean_absolute_error: 0.0130
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.2878e-04 - mean_absolute_error: 0.0128 - val_loss: 3.3698e-04 - val_mean_absolute_error: 0.0138
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 3.9111e-04 - mean_absolute_error: 0.0121 - val_loss: 4.1490e-04 - val_mean_absolute_error: 0.0157
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.8762e-04 - mean_absolute_error: 0.0165 - val_loss: 6.1269e-04 - val_mean_absolute_error: 0.0203
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.2323e-04 - mean_absolute_error: 0.0151 - val_loss: 6.5225e-04 - val_mean_absolute_error: 0.0211
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.5398e-04 - mean_absolute_error: 0.0136 - val_loss: 3.8922e-04 - val_mean_absolute_error: 0.0153
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 4.7789e-04 - mean_absolute_error: 0.0146 - val_loss: 3.1962e-04 - val_mean_absolute_error: 0.0130
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.4424e-04 - mean_absolute_error: 0.0143 - val_loss: 3.2512e-04 - val_mean_absolute_error: 0.0134
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.8468e-04 - mean_absolute_error: 0.0128 - val_loss: 3.3471e-04 - val_mean_absolute_error: 0.0136
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.8908e-04 - mean_absolute_error: 0.0128 - val_loss: 4.9129e-04 - val_mean_absolute_error: 0.0178
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 5.0713e-04 - mean_absolute_error: 0.0157 - val_loss: 4.2115e-04 - val_mean_absolute_error: 0.0159
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.8197e-04 - mean_absolute_error: 0.0127 - val_loss: 4.6695e-04 - val_mean_absolute_error: 0.0170
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.9780e-04 - mean_absolute_error: 0.0136 - val_loss: 6.7064e-04 - val_mean_absolute_error: 0.0215
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.5350e-04 - mean_absolute_error: 0.0152 - val_loss: 4.3071e-04 - val_mean_absolute_error: 0.0162
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.8521e-04 - mean_absolute_error: 0.0130 - val_loss: 6.3759e-04 - val_mean_absolute_error: 0.0208
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.7984e-04 - mean_absolute_error: 0.0147 - val_loss: 5.1454e-04 - val_mean_absolute_error: 0.0182
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.0304e-04 - mean_absolute_error: 0.0133 - val_loss: 3.2117e-04 - val_mean_absolute_error: 0.0132
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.3944e-04 - mean_absolute_error: 0.0123 - val_loss: 3.1599e-04 - val_mean_absolute_error: 0.0131
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.2837e-04 - mean_absolute_error: 0.0132 - val_loss: 3.2410e-04 - val_mean_absolute_error: 0.0133
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.9678e-04 - mean_absolute_error: 0.0144 - val_loss: 4.7872e-04 - val_mean_absolute_error: 0.0174
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.0123e-04 - mean_absolute_error: 0.0131 - val_loss: 3.5990e-04 - val_mean_absolute_error: 0.0144
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.5911e-04 - mean_absolute_error: 0.0120 - val_loss: 3.2255e-04 - val_mean_absolute_error: 0.0133
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.4020e-04 - mean_absolute_error: 0.0117 - val_loss: 3.1524e-04 - val_mean_absolute_error: 0.0130
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.8194e-04 - mean_absolute_error: 0.0125 - val_loss: 3.2560e-04 - val_mean_absolute_error: 0.0133
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.0044e-04 - mean_absolute_error: 0.0128 - val_loss: 3.1205e-04 - val_mean_absolute_error: 0.0130
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.3468e-04 - mean_absolute_error: 0.0132 - val_loss: 3.2122e-04 - val_mean_absolute_error: 0.0134
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.9136e-04 - mean_absolute_error: 0.0130 - val_loss: 3.1624e-04 - val_mean_absolute_error: 0.0131
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.0497e-04 - mean_absolute_error: 0.0129 - val_loss: 3.7693e-04 - val_mean_absolute_error: 0.0149
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.5628e-04 - mean_absolute_error: 0.0121 - val_loss: 3.1388e-04 - val_mean_absolute_error: 0.0131
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.8857e-04 - mean_absolute_error: 0.0126 - val_loss: 3.3792e-04 - val_mean_absolute_error: 0.0140
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.5335e-04 - mean_absolute_error: 0.0132 - val_loss: 4.5856e-04 - val_mean_absolute_error: 0.0169
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.4577e-04 - mean_absolute_error: 0.0121 - val_loss: 4.4944e-04 - val_mean_absolute_error: 0.0167
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.7463e-04 - mean_absolute_error: 0.0125 - val_loss: 5.2508e-04 - val_mean_absolute_error: 0.0185
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.7709e-04 - mean_absolute_error: 0.0133 - val_loss: 3.6947e-04 - val_mean_absolute_error: 0.0147
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.5564e-04 - mean_absolute_error: 0.0124 - val_loss: 3.2181e-04 - val_mean_absolute_error: 0.0133
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.7367e-04 - mean_absolute_error: 0.0129 - val_loss: 3.0748e-04 - val_mean_absolute_error: 0.0129
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.7440e-04 - mean_absolute_error: 0.0129 - val_loss: 3.3091e-04 - val_mean_absolute_error: 0.0136
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.3615e-04 - mean_absolute_error: 0.0124 - val_loss: 3.1191e-04 - val_mean_absolute_error: 0.0130
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.8840e-04 - mean_absolute_error: 0.0122 - val_loss: 3.0975e-04 - val_mean_absolute_error: 0.0129
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.4632e-04 - mean_absolute_error: 0.0140 - val_loss: 3.1153e-04 - val_mean_absolute_error: 0.0130
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.4332e-04 - mean_absolute_error: 0.0119 - val_loss: 3.1469e-04 - val_mean_absolute_error: 0.0130
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.8201e-04 - mean_absolute_error: 0.0127 - val_loss: 3.2688e-04 - val_mean_absolute_error: 0.0136
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.8050e-04 - mean_absolute_error: 0.0124 - val_loss: 3.1086e-04 - val_mean_absolute_error: 0.0130
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.6026e-04 - mean_absolute_error: 0.0124 - val_loss: 3.8211e-04 - val_mean_absolute_error: 0.0153
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.9472e-04 - mean_absolute_error: 0.0154 - val_loss: 3.7664e-04 - val_mean_absolute_error: 0.0147
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.6364e-04 - mean_absolute_error: 0.0123 - val_loss: 3.4285e-04 - val_mean_absolute_error: 0.0138
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.2113e-04 - mean_absolute_error: 0.0131 - val_loss: 3.6530e-04 - val_mean_absolute_error: 0.0145
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.5882e-04 - mean_absolute_error: 0.0124 - val_loss: 3.3281e-04 - val_mean_absolute_error: 0.0135
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.6530e-04 - mean_absolute_error: 0.0120 - val_loss: 3.6786e-04 - val_mean_absolute_error: 0.0146
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.8641e-04 - mean_absolute_error: 0.0128 - val_loss: 3.4871e-04 - val_mean_absolute_error: 0.0141
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9521e-04 - mean_absolute_error: 0.0133 - val_loss: 3.4519e-04 - val_mean_absolute_error: 0.0139
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.0450e-04 - mean_absolute_error: 0.0127 - val_loss: 3.1180e-04 - val_mean_absolute_error: 0.0130
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.5995e-04 - mean_absolute_error: 0.0119 - val_loss: 3.0722e-04 - val_mean_absolute_error: 0.0129
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.5310e-04 - mean_absolute_error: 0.0119 - val_loss: 4.3957e-04 - val_mean_absolute_error: 0.0165
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.0373e-04 - mean_absolute_error: 0.0133 - val_loss: 3.2443e-04 - val_mean_absolute_error: 0.0133
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.5368e-04 - mean_absolute_error: 0.0119 - val_loss: 3.1862e-04 - val_mean_absolute_error: 0.0132
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.2088e-04 - mean_absolute_error: 0.0134 - val_loss: 3.3599e-04 - val_mean_absolute_error: 0.0140
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.1930e-04 - mean_absolute_error: 0.0115 - val_loss: 3.0800e-04 - val_mean_absolute_error: 0.0129
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.6141e-04 - mean_absolute_error: 0.0124 - val_loss: 3.5563e-04 - val_mean_absolute_error: 0.0143
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.0864e-04 - mean_absolute_error: 0.0129 - val_loss: 4.9508e-04 - val_mean_absolute_error: 0.0178
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.1319e-04 - mean_absolute_error: 0.0135 - val_loss: 3.0893e-04 - val_mean_absolute_error: 0.0130
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.4430e-04 - mean_absolute_error: 0.0129 - val_loss: 3.7078e-04 - val_mean_absolute_error: 0.0150
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.8049e-04 - mean_absolute_error: 0.0124 - val_loss: 3.2328e-04 - val_mean_absolute_error: 0.0134

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 150ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7206e-04 - mean_absolute_error: 0.0144
# Test Loss: [0.00032327778171747923, 0.013412303291261196]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 164075.67927514508
# RMSE: 405.0625621742215
# MAE: 294.23096870331176
# MAPE: 2.693790468159049 %
#
# Model evalution on validate set
# MSE: 75948.28251729747
# RMSE: 275.5871595653496
# MAE: 186.13591202445653
# MAPE: 1.7629230998791958 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 754ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step

# %%
y_pred_30_days
# Out:
# array([[12681.809],
#        [12665.615],
#        [12682.137],
#        [12680.222],
#        [12681.41 ],
#        [12681.22 ],
#        [12681.299],
#        [12681.282],
#        [12681.286],
#        [12681.287],
#        [12681.286],
#        [12681.285],
#        [12681.286],
#        [12681.285],
#        [12681.287],
#        [12681.286],
#        [12681.287],
#        [12681.286],
#        [12681.287],
#        [12681.285],
#        [12681.287],
#        [12681.287],
#        [12681.285],
#        [12681.287],
#        [12681.286],
#        [12681.287],
#        [12681.286],
#        [12681.287],
#        [12681.287],
#        [12681.286],
#        [12681.286]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Forecast Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
