# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: ITD - Test/Train/Vaildation: 60/20/20
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 527.12
# - MAE: 374.68
# - MAPE: 3.26 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170
# ...           ...
# 2024-05-27  11300
# 2024-05-28  12050
# 2024-05-29  12600
# 2024-05-30  12500
# 2024-05-31  12700
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        6900
# 1        7100
# 2        7100
# 3        7170
# 4        7170
#         ...
# 1308    11300
# 1309    12050
# 1310    12600
# 1311    12500
# 1312    12700
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((776, 10), (776,), (251, 10), (251,), (253, 10), (253,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 27s 186ms/step - loss: 0.0552 - mean_absolute_error: 0.1624 - val_loss: 0.0038 - val_mean_absolute_error: 0.0537
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0036 - mean_absolute_error: 0.0384 - val_loss: 0.0019 - val_mean_absolute_error: 0.0357
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 0.0021 - mean_absolute_error: 0.0283 - val_loss: 0.0014 - val_mean_absolute_error: 0.0287
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.0017 - mean_absolute_error: 0.0257 - val_loss: 0.0013 - val_mean_absolute_error: 0.0266
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0015 - mean_absolute_error: 0.0238 - val_loss: 0.0013 - val_mean_absolute_error: 0.0277
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0014 - mean_absolute_error: 0.0238 - val_loss: 0.0015 - val_mean_absolute_error: 0.0301
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0016 - mean_absolute_error: 0.0258 - val_loss: 0.0011 - val_mean_absolute_error: 0.0246
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0014 - mean_absolute_error: 0.0219 - val_loss: 0.0013 - val_mean_absolute_error: 0.0279
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0012 - mean_absolute_error: 0.0220 - val_loss: 0.0014 - val_mean_absolute_error: 0.0285
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0012 - mean_absolute_error: 0.0224 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - mean_absolute_error: 0.0230 - val_loss: 0.0011 - val_mean_absolute_error: 0.0246
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0012 - mean_absolute_error: 0.0213 - val_loss: 0.0013 - val_mean_absolute_error: 0.0271
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0014 - mean_absolute_error: 0.0229 - val_loss: 0.0017 - val_mean_absolute_error: 0.0330
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0016 - mean_absolute_error: 0.0260 - val_loss: 0.0013 - val_mean_absolute_error: 0.0272
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0016 - mean_absolute_error: 0.0263 - val_loss: 0.0018 - val_mean_absolute_error: 0.0340
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0014 - mean_absolute_error: 0.0226 - val_loss: 0.0010 - val_mean_absolute_error: 0.0232
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - mean_absolute_error: 0.0222 - val_loss: 0.0010 - val_mean_absolute_error: 0.0237
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0011 - mean_absolute_error: 0.0197 - val_loss: 0.0018 - val_mean_absolute_error: 0.0348
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0243 - val_loss: 9.7532e-04 - val_mean_absolute_error: 0.0228
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012 - mean_absolute_error: 0.0219 - val_loss: 0.0012 - val_mean_absolute_error: 0.0262
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0011 - mean_absolute_error: 0.0206 - val_loss: 0.0011 - val_mean_absolute_error: 0.0247
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0012 - mean_absolute_error: 0.0212 - val_loss: 9.0186e-04 - val_mean_absolute_error: 0.0219
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0010 - mean_absolute_error: 0.0196 - val_loss: 9.1274e-04 - val_mean_absolute_error: 0.0219
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0012 - mean_absolute_error: 0.0214 - val_loss: 0.0010 - val_mean_absolute_error: 0.0242
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0011 - mean_absolute_error: 0.0201 - val_loss: 8.3312e-04 - val_mean_absolute_error: 0.0208
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - mean_absolute_error: 0.0209 - val_loss: 0.0010 - val_mean_absolute_error: 0.0243
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0011 - mean_absolute_error: 0.0207 - val_loss: 9.5203e-04 - val_mean_absolute_error: 0.0233
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - mean_absolute_error: 0.0230 - val_loss: 7.7592e-04 - val_mean_absolute_error: 0.0200
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0011 - mean_absolute_error: 0.0211 - val_loss: 8.4347e-04 - val_mean_absolute_error: 0.0216
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.5162e-04 - mean_absolute_error: 0.0200 - val_loss: 8.8924e-04 - val_mean_absolute_error: 0.0224
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.0542e-04 - mean_absolute_error: 0.0189 - val_loss: 8.4606e-04 - val_mean_absolute_error: 0.0216
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.1896e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0014 - val_mean_absolute_error: 0.0305
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0011 - mean_absolute_error: 0.0200 - val_loss: 8.8126e-04 - val_mean_absolute_error: 0.0227
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 8.0421e-04 - mean_absolute_error: 0.0182 - val_loss: 6.8815e-04 - val_mean_absolute_error: 0.0187
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.6864e-04 - mean_absolute_error: 0.0177 - val_loss: 6.7392e-04 - val_mean_absolute_error: 0.0185
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.9164e-04 - mean_absolute_error: 0.0173 - val_loss: 7.4265e-04 - val_mean_absolute_error: 0.0201
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.0379e-04 - mean_absolute_error: 0.0177 - val_loss: 9.7417e-04 - val_mean_absolute_error: 0.0248
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 0.0012 - mean_absolute_error: 0.0231 - val_loss: 0.0011 - val_mean_absolute_error: 0.0266
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.9993e-04 - mean_absolute_error: 0.0206 - val_loss: 6.4575e-04 - val_mean_absolute_error: 0.0181
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.6458e-04 - mean_absolute_error: 0.0182 - val_loss: 6.2752e-04 - val_mean_absolute_error: 0.0180
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.5727e-04 - mean_absolute_error: 0.0188 - val_loss: 6.1192e-04 - val_mean_absolute_error: 0.0177
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.2138e-04 - mean_absolute_error: 0.0161 - val_loss: 8.7968e-04 - val_mean_absolute_error: 0.0233
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.5001e-04 - mean_absolute_error: 0.0178 - val_loss: 7.9418e-04 - val_mean_absolute_error: 0.0219
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.7181e-04 - mean_absolute_error: 0.0154 - val_loss: 6.6986e-04 - val_mean_absolute_error: 0.0194
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 8.6661e-04 - mean_absolute_error: 0.0185 - val_loss: 7.1583e-04 - val_mean_absolute_error: 0.0202
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 7.7709e-04 - mean_absolute_error: 0.0180 - val_loss: 6.1159e-04 - val_mean_absolute_error: 0.0177
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.4980e-04 - mean_absolute_error: 0.0157 - val_loss: 5.7308e-04 - val_mean_absolute_error: 0.0172
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 7.1107e-04 - mean_absolute_error: 0.0173 - val_loss: 7.2667e-04 - val_mean_absolute_error: 0.0206
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.4751e-04 - mean_absolute_error: 0.0163 - val_loss: 6.2172e-04 - val_mean_absolute_error: 0.0184
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.8731e-04 - mean_absolute_error: 0.0182 - val_loss: 6.8388e-04 - val_mean_absolute_error: 0.0198
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.7940e-04 - mean_absolute_error: 0.0165 - val_loss: 5.4478e-04 - val_mean_absolute_error: 0.0167
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.7279e-04 - mean_absolute_error: 0.0164 - val_loss: 6.3910e-04 - val_mean_absolute_error: 0.0189
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.1781e-04 - mean_absolute_error: 0.0160 - val_loss: 5.2001e-04 - val_mean_absolute_error: 0.0164
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.9216e-04 - mean_absolute_error: 0.0181 - val_loss: 5.6850e-04 - val_mean_absolute_error: 0.0175
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.1709e-04 - mean_absolute_error: 0.0161 - val_loss: 5.3587e-04 - val_mean_absolute_error: 0.0167
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 6.3396e-04 - mean_absolute_error: 0.0158 - val_loss: 5.1294e-04 - val_mean_absolute_error: 0.0163
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.0936e-04 - mean_absolute_error: 0.0180 - val_loss: 0.0015 - val_mean_absolute_error: 0.0337
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.1274e-04 - mean_absolute_error: 0.0178 - val_loss: 5.6214e-04 - val_mean_absolute_error: 0.0174
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.8466e-04 - mean_absolute_error: 0.0182 - val_loss: 4.9443e-04 - val_mean_absolute_error: 0.0159
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.5402e-04 - mean_absolute_error: 0.0153 - val_loss: 4.9187e-04 - val_mean_absolute_error: 0.0159
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.7026e-04 - mean_absolute_error: 0.0151 - val_loss: 8.1391e-04 - val_mean_absolute_error: 0.0229
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.1363e-04 - mean_absolute_error: 0.0170 - val_loss: 6.0194e-04 - val_mean_absolute_error: 0.0186
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.4500e-04 - mean_absolute_error: 0.0164 - val_loss: 7.1512e-04 - val_mean_absolute_error: 0.0210
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.9474e-04 - mean_absolute_error: 0.0158 - val_loss: 5.6040e-04 - val_mean_absolute_error: 0.0179
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.0003e-04 - mean_absolute_error: 0.0143 - val_loss: 5.0769e-04 - val_mean_absolute_error: 0.0163
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 6.5834e-04 - mean_absolute_error: 0.0166 - val_loss: 4.7296e-04 - val_mean_absolute_error: 0.0157
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.2272e-04 - mean_absolute_error: 0.0171 - val_loss: 4.9002e-04 - val_mean_absolute_error: 0.0164
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 6.1332e-04 - mean_absolute_error: 0.0152 - val_loss: 4.5726e-04 - val_mean_absolute_error: 0.0156
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.0234e-04 - mean_absolute_error: 0.0140 - val_loss: 6.0206e-04 - val_mean_absolute_error: 0.0190
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.9813e-04 - mean_absolute_error: 0.0152 - val_loss: 4.8411e-04 - val_mean_absolute_error: 0.0163
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.1471e-04 - mean_absolute_error: 0.0155 - val_loss: 4.5063e-04 - val_mean_absolute_error: 0.0156
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.1560e-04 - mean_absolute_error: 0.0143 - val_loss: 4.6064e-04 - val_mean_absolute_error: 0.0159
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.6849e-04 - mean_absolute_error: 0.0133 - val_loss: 5.5091e-04 - val_mean_absolute_error: 0.0180
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 6.1284e-04 - mean_absolute_error: 0.0160 - val_loss: 5.9304e-04 - val_mean_absolute_error: 0.0190
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 6.5143e-04 - mean_absolute_error: 0.0158 - val_loss: 5.0728e-04 - val_mean_absolute_error: 0.0171
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 4.7091e-04 - mean_absolute_error: 0.0137 - val_loss: 6.2553e-04 - val_mean_absolute_error: 0.0197
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 5.0616e-04 - mean_absolute_error: 0.0141 - val_loss: 6.0958e-04 - val_mean_absolute_error: 0.0194
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 6.2918e-04 - mean_absolute_error: 0.0160 - val_loss: 5.4888e-04 - val_mean_absolute_error: 0.0181
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 4.5267e-04 - mean_absolute_error: 0.0137 - val_loss: 4.3656e-04 - val_mean_absolute_error: 0.0154
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 5.1651e-04 - mean_absolute_error: 0.0136 - val_loss: 8.1825e-04 - val_mean_absolute_error: 0.0235
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.9917e-04 - mean_absolute_error: 0.0143 - val_loss: 7.9292e-04 - val_mean_absolute_error: 0.0230
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.9331e-04 - mean_absolute_error: 0.0151 - val_loss: 3.9791e-04 - val_mean_absolute_error: 0.0146
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.3025e-04 - mean_absolute_error: 0.0125 - val_loss: 4.1140e-04 - val_mean_absolute_error: 0.0150
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.8355e-04 - mean_absolute_error: 0.0136 - val_loss: 4.8534e-04 - val_mean_absolute_error: 0.0169
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 5.1903e-04 - mean_absolute_error: 0.0145 - val_loss: 5.0403e-04 - val_mean_absolute_error: 0.0173
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 4.9162e-04 - mean_absolute_error: 0.0139 - val_loss: 4.1122e-04 - val_mean_absolute_error: 0.0148
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 5.1041e-04 - mean_absolute_error: 0.0142 - val_loss: 4.3545e-04 - val_mean_absolute_error: 0.0158
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 5.2739e-04 - mean_absolute_error: 0.0146 - val_loss: 3.7982e-04 - val_mean_absolute_error: 0.0142
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.9873e-04 - mean_absolute_error: 0.0141 - val_loss: 5.3595e-04 - val_mean_absolute_error: 0.0182
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 5.0276e-04 - mean_absolute_error: 0.0148 - val_loss: 3.7769e-04 - val_mean_absolute_error: 0.0141
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 5.5737e-04 - mean_absolute_error: 0.0154 - val_loss: 5.8214e-04 - val_mean_absolute_error: 0.0191
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 5.4105e-04 - mean_absolute_error: 0.0155 - val_loss: 5.8107e-04 - val_mean_absolute_error: 0.0191
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.5570e-04 - mean_absolute_error: 0.0138 - val_loss: 4.2855e-04 - val_mean_absolute_error: 0.0155
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.1522e-04 - mean_absolute_error: 0.0135 - val_loss: 4.2166e-04 - val_mean_absolute_error: 0.0154
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.5166e-04 - mean_absolute_error: 0.0136 - val_loss: 4.5031e-04 - val_mean_absolute_error: 0.0162
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 5.0145e-04 - mean_absolute_error: 0.0142 - val_loss: 3.6646e-04 - val_mean_absolute_error: 0.0139
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.9725e-04 - mean_absolute_error: 0.0121 - val_loss: 3.6190e-04 - val_mean_absolute_error: 0.0138
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.4872e-04 - mean_absolute_error: 0.0133 - val_loss: 3.5955e-04 - val_mean_absolute_error: 0.0138
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.3950e-04 - mean_absolute_error: 0.0133 - val_loss: 3.6930e-04 - val_mean_absolute_error: 0.0140
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.0476e-04 - mean_absolute_error: 0.0142 - val_loss: 3.6011e-04 - val_mean_absolute_error: 0.0138
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.8641e-04 - mean_absolute_error: 0.0131 - val_loss: 3.9820e-04 - val_mean_absolute_error: 0.0149
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.1491e-04 - mean_absolute_error: 0.0133 - val_loss: 3.6282e-04 - val_mean_absolute_error: 0.0140
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.8371e-04 - mean_absolute_error: 0.0121 - val_loss: 4.0043e-04 - val_mean_absolute_error: 0.0151
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.1011e-04 - mean_absolute_error: 0.0128 - val_loss: 3.5122e-04 - val_mean_absolute_error: 0.0136
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.2605e-04 - mean_absolute_error: 0.0128 - val_loss: 3.8654e-04 - val_mean_absolute_error: 0.0146
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.5359e-04 - mean_absolute_error: 0.0144 - val_loss: 3.7115e-04 - val_mean_absolute_error: 0.0143
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.6540e-04 - mean_absolute_error: 0.0119 - val_loss: 3.4220e-04 - val_mean_absolute_error: 0.0134
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 4.0444e-04 - mean_absolute_error: 0.0127 - val_loss: 3.5948e-04 - val_mean_absolute_error: 0.0140
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 7.0610e-04 - mean_absolute_error: 0.0178 - val_loss: 3.4909e-04 - val_mean_absolute_error: 0.0137
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.2940e-04 - mean_absolute_error: 0.0131 - val_loss: 3.4073e-04 - val_mean_absolute_error: 0.0135
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.3766e-04 - mean_absolute_error: 0.0137 - val_loss: 3.6068e-04 - val_mean_absolute_error: 0.0141
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.9094e-04 - mean_absolute_error: 0.0125 - val_loss: 3.3809e-04 - val_mean_absolute_error: 0.0135
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.1999e-04 - mean_absolute_error: 0.0127 - val_loss: 3.4213e-04 - val_mean_absolute_error: 0.0136
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 4.7361e-04 - mean_absolute_error: 0.0139 - val_loss: 3.3728e-04 - val_mean_absolute_error: 0.0136
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9568e-04 - mean_absolute_error: 0.0134 - val_loss: 3.3629e-04 - val_mean_absolute_error: 0.0135
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.6291e-04 - mean_absolute_error: 0.0125 - val_loss: 3.5342e-04 - val_mean_absolute_error: 0.0140
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.7339e-04 - mean_absolute_error: 0.0122 - val_loss: 3.9735e-04 - val_mean_absolute_error: 0.0152
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.8507e-04 - mean_absolute_error: 0.0128 - val_loss: 3.3855e-04 - val_mean_absolute_error: 0.0135
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.8087e-04 - mean_absolute_error: 0.0127 - val_loss: 3.6963e-04 - val_mean_absolute_error: 0.0145
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.7572e-04 - mean_absolute_error: 0.0126 - val_loss: 5.1203e-04 - val_mean_absolute_error: 0.0180
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.0854e-04 - mean_absolute_error: 0.0151 - val_loss: 3.4155e-04 - val_mean_absolute_error: 0.0136
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 4.2891e-04 - mean_absolute_error: 0.0133 - val_loss: 4.9125e-04 - val_mean_absolute_error: 0.0176
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.2557e-04 - mean_absolute_error: 0.0135 - val_loss: 3.3499e-04 - val_mean_absolute_error: 0.0135
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 3.8075e-04 - mean_absolute_error: 0.0118 - val_loss: 3.9296e-04 - val_mean_absolute_error: 0.0152
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.9466e-04 - mean_absolute_error: 0.0128 - val_loss: 3.2699e-04 - val_mean_absolute_error: 0.0132
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.0010e-04 - mean_absolute_error: 0.0124 - val_loss: 3.3352e-04 - val_mean_absolute_error: 0.0135
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.9617e-04 - mean_absolute_error: 0.0126 - val_loss: 3.4033e-04 - val_mean_absolute_error: 0.0136
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 4.3744e-04 - mean_absolute_error: 0.0127 - val_loss: 3.2409e-04 - val_mean_absolute_error: 0.0133
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.7033e-04 - mean_absolute_error: 0.0126 - val_loss: 3.4682e-04 - val_mean_absolute_error: 0.0139
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.7679e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1705e-04 - val_mean_absolute_error: 0.0130
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.9806e-04 - mean_absolute_error: 0.0131 - val_loss: 4.1460e-04 - val_mean_absolute_error: 0.0157
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.9000e-04 - mean_absolute_error: 0.0148 - val_loss: 3.7581e-04 - val_mean_absolute_error: 0.0148
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.2892e-04 - mean_absolute_error: 0.0132 - val_loss: 3.1817e-04 - val_mean_absolute_error: 0.0130
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.7895e-04 - mean_absolute_error: 0.0124 - val_loss: 3.6191e-04 - val_mean_absolute_error: 0.0143
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.2827e-04 - mean_absolute_error: 0.0150 - val_loss: 3.2367e-04 - val_mean_absolute_error: 0.0132
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.1245e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1802e-04 - val_mean_absolute_error: 0.0130
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.3479e-04 - mean_absolute_error: 0.0131 - val_loss: 3.2233e-04 - val_mean_absolute_error: 0.0131
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.6290e-04 - mean_absolute_error: 0.0126 - val_loss: 3.2368e-04 - val_mean_absolute_error: 0.0133
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.3792e-04 - mean_absolute_error: 0.0135 - val_loss: 4.3786e-04 - val_mean_absolute_error: 0.0166
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.7469e-04 - mean_absolute_error: 0.0155 - val_loss: 3.8614e-04 - val_mean_absolute_error: 0.0153
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.8212e-04 - mean_absolute_error: 0.0127 - val_loss: 3.2641e-04 - val_mean_absolute_error: 0.0132
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.4759e-04 - mean_absolute_error: 0.0128 - val_loss: 3.4106e-04 - val_mean_absolute_error: 0.0137
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.8702e-04 - mean_absolute_error: 0.0123 - val_loss: 3.2060e-04 - val_mean_absolute_error: 0.0131
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.8774e-04 - mean_absolute_error: 0.0123 - val_loss: 3.2191e-04 - val_mean_absolute_error: 0.0131
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 4.0136e-04 - mean_absolute_error: 0.0131 - val_loss: 3.4028e-04 - val_mean_absolute_error: 0.0136
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.1781e-04 - mean_absolute_error: 0.0130 - val_loss: 3.6804e-04 - val_mean_absolute_error: 0.0146
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.0198e-04 - mean_absolute_error: 0.0128 - val_loss: 3.2526e-04 - val_mean_absolute_error: 0.0133
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.3708e-04 - mean_absolute_error: 0.0136 - val_loss: 3.1558e-04 - val_mean_absolute_error: 0.0131
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.8506e-04 - mean_absolute_error: 0.0124 - val_loss: 3.1933e-04 - val_mean_absolute_error: 0.0132
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.0242e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1790e-04 - val_mean_absolute_error: 0.0130
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.5914e-04 - mean_absolute_error: 0.0119 - val_loss: 3.3350e-04 - val_mean_absolute_error: 0.0137
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.9832e-04 - mean_absolute_error: 0.0130 - val_loss: 4.6001e-04 - val_mean_absolute_error: 0.0171
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 5.9962e-04 - mean_absolute_error: 0.0159 - val_loss: 3.3414e-04 - val_mean_absolute_error: 0.0138
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.4998e-04 - mean_absolute_error: 0.0143 - val_loss: 4.6873e-04 - val_mean_absolute_error: 0.0173
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.5668e-04 - mean_absolute_error: 0.0140 - val_loss: 3.3487e-04 - val_mean_absolute_error: 0.0135
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.5598e-04 - mean_absolute_error: 0.0120 - val_loss: 4.2156e-04 - val_mean_absolute_error: 0.0162
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.8986e-04 - mean_absolute_error: 0.0130 - val_loss: 3.2007e-04 - val_mean_absolute_error: 0.0132
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.3831e-04 - mean_absolute_error: 0.0117 - val_loss: 3.2369e-04 - val_mean_absolute_error: 0.0132
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.7638e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1598e-04 - val_mean_absolute_error: 0.0130
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.7056e-04 - mean_absolute_error: 0.0128 - val_loss: 3.4896e-04 - val_mean_absolute_error: 0.0140
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.9237e-04 - mean_absolute_error: 0.0134 - val_loss: 3.9646e-04 - val_mean_absolute_error: 0.0153
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.5997e-04 - mean_absolute_error: 0.0123 - val_loss: 4.4514e-04 - val_mean_absolute_error: 0.0166
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.7873e-04 - mean_absolute_error: 0.0131 - val_loss: 3.1300e-04 - val_mean_absolute_error: 0.0130
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.2697e-04 - mean_absolute_error: 0.0114 - val_loss: 3.4058e-04 - val_mean_absolute_error: 0.0141
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.2209e-04 - mean_absolute_error: 0.0116 - val_loss: 4.0468e-04 - val_mean_absolute_error: 0.0154
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.7192e-04 - mean_absolute_error: 0.0128 - val_loss: 3.8739e-04 - val_mean_absolute_error: 0.0153
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.7794e-04 - mean_absolute_error: 0.0143 - val_loss: 3.4115e-04 - val_mean_absolute_error: 0.0140
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.9300e-04 - mean_absolute_error: 0.0132 - val_loss: 3.3206e-04 - val_mean_absolute_error: 0.0135
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.2937e-04 - mean_absolute_error: 0.0114 - val_loss: 3.4794e-04 - val_mean_absolute_error: 0.0140
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.6816e-04 - mean_absolute_error: 0.0133 - val_loss: 3.2361e-04 - val_mean_absolute_error: 0.0132
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.1043e-04 - mean_absolute_error: 0.0115 - val_loss: 3.1818e-04 - val_mean_absolute_error: 0.0131
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.9802e-04 - mean_absolute_error: 0.0130 - val_loss: 3.1867e-04 - val_mean_absolute_error: 0.0131
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.0014e-04 - mean_absolute_error: 0.0125 - val_loss: 3.1903e-04 - val_mean_absolute_error: 0.0131
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.6323e-04 - mean_absolute_error: 0.0120 - val_loss: 3.1088e-04 - val_mean_absolute_error: 0.0130
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.4046e-04 - mean_absolute_error: 0.0118 - val_loss: 6.5525e-04 - val_mean_absolute_error: 0.0211
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.0080e-04 - mean_absolute_error: 0.0142 - val_loss: 3.7381e-04 - val_mean_absolute_error: 0.0147
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.2259e-04 - mean_absolute_error: 0.0116 - val_loss: 3.3416e-04 - val_mean_absolute_error: 0.0136
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.5889e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1214e-04 - val_mean_absolute_error: 0.0130
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.1612e-04 - mean_absolute_error: 0.0112 - val_loss: 3.0809e-04 - val_mean_absolute_error: 0.0129
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.9177e-04 - mean_absolute_error: 0.0122 - val_loss: 3.2940e-04 - val_mean_absolute_error: 0.0137
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.4630e-04 - mean_absolute_error: 0.0117 - val_loss: 3.1513e-04 - val_mean_absolute_error: 0.0132
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.8656e-04 - mean_absolute_error: 0.0127 - val_loss: 3.2334e-04 - val_mean_absolute_error: 0.0133
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.6407e-04 - mean_absolute_error: 0.0118 - val_loss: 3.2820e-04 - val_mean_absolute_error: 0.0134
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 3.5148e-04 - mean_absolute_error: 0.0121 - val_loss: 3.0907e-04 - val_mean_absolute_error: 0.0129
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.5927e-04 - mean_absolute_error: 0.0120 - val_loss: 3.6436e-04 - val_mean_absolute_error: 0.0145
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.2793e-04 - mean_absolute_error: 0.0122 - val_loss: 3.5196e-04 - val_mean_absolute_error: 0.0144
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.7316e-04 - mean_absolute_error: 0.0128 - val_loss: 3.4684e-04 - val_mean_absolute_error: 0.0139
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6789e-04 - mean_absolute_error: 0.0124 - val_loss: 3.9316e-04 - val_mean_absolute_error: 0.0152
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.9728e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1524e-04 - val_mean_absolute_error: 0.0131
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.5765e-04 - mean_absolute_error: 0.0123 - val_loss: 3.1240e-04 - val_mean_absolute_error: 0.0130
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.8953e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1810e-04 - val_mean_absolute_error: 0.0132
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.6614e-04 - mean_absolute_error: 0.0122 - val_loss: 3.8000e-04 - val_mean_absolute_error: 0.0150
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 4.0683e-04 - mean_absolute_error: 0.0126 - val_loss: 3.5477e-04 - val_mean_absolute_error: 0.0142
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.9147e-04 - mean_absolute_error: 0.0128 - val_loss: 3.0598e-04 - val_mean_absolute_error: 0.0129
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.3628e-04 - mean_absolute_error: 0.0130 - val_loss: 3.0731e-04 - val_mean_absolute_error: 0.0130
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 3.9731e-04 - mean_absolute_error: 0.0130 - val_loss: 3.6659e-04 - val_mean_absolute_error: 0.0146
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9476e-04 - mean_absolute_error: 0.0131 - val_loss: 3.1374e-04 - val_mean_absolute_error: 0.0131
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.7637e-04 - mean_absolute_error: 0.0122 - val_loss: 3.5651e-04 - val_mean_absolute_error: 0.0146
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.9169e-04 - mean_absolute_error: 0.0131 - val_loss: 3.1690e-04 - val_mean_absolute_error: 0.0133
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 3.6687e-04 - mean_absolute_error: 0.0118 - val_loss: 3.1898e-04 - val_mean_absolute_error: 0.0132

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 5s 729ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7754e-04 - mean_absolute_error: 0.0142
# Test Loss: [0.0003189808630850166, 0.013179621659219265]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 163760.4042732687
# RMSE: 404.6732067647532
# MAE: 291.16546703809763
# MAPE: 2.6743805106013414 %
#
# Model evalution on validate set
# MSE: 72925.01751938168
# RMSE: 270.04632476555145
# MAE: 191.9101948493083
# MAPE: 1.8162656069897702 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 932ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step

# %%
y_pred_30_days
# Out:
# array([[12793.297 ],
#        [12786.579 ],
#        [12808.612 ],
#        [12809.959 ],
#        [12811.626 ],
#        [12811.8545],
#        [12811.993 ],
#        [12812.02  ],
#        [12812.033 ],
#        [12812.036 ],
#        [12812.037 ],
#        [12812.037 ],
#        [12812.037 ],
#        [12812.037 ],
#        [12812.037 ],
#        [12812.037 ],
#        [12812.037 ],
#        [12812.037 ],
#        [12812.037 ],
#        [12812.037 ],
#        [12812.037 ],
#        [12812.037 ],
#        [12812.037 ],
#        [12812.037 ],
#        [12812.037 ],
#        [12812.037 ],
#        [12812.037 ],
#        [12812.037 ],
#        [12812.037 ],
#        [12812.037 ],
#        [12812.037 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
