# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: ITD - Test/Train/Vaildation: 60/20/20
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 527.12
# - MAE: 374.68
# - MAPE: 3.26 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170
# ...           ...
# 2024-02-26   9700
# 2024-02-27   9640
# 2024-02-28   9890
# 2024-02-29   9950
# 2024-03-01   9990
#
# [1252 rows x 1 columns]

# %%
df.shape
# Out:
# (1252, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       6900
# 1       7100
# 2       7100
# 3       7170
# 4       7170
#         ...
# 1247    9700
# 1248    9640
# 1249    9890
# 1250    9950
# 1251    9990
# Name: close, Length: 1252, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((740, 10), (740,), (239, 10), (239,), (240, 10), (240,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 0.0589 - mean_absolute_error: 0.1649 - val_loss: 0.0068 - val_mean_absolute_error: 0.0693
# Epoch 2/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0052 - mean_absolute_error: 0.0449 - val_loss: 0.0022 - val_mean_absolute_error: 0.0355
# Epoch 3/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018 - mean_absolute_error: 0.0273 - val_loss: 0.0022 - val_mean_absolute_error: 0.0361
# Epoch 4/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016 - mean_absolute_error: 0.0241 - val_loss: 0.0020 - val_mean_absolute_error: 0.0327
# Epoch 5/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0222 - val_loss: 0.0020 - val_mean_absolute_error: 0.0324
# Epoch 6/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0237 - val_loss: 0.0026 - val_mean_absolute_error: 0.0369
# Epoch 7/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mean_absolute_error: 0.0246 - val_loss: 0.0021 - val_mean_absolute_error: 0.0336
# Epoch 8/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0229 - val_loss: 0.0024 - val_mean_absolute_error: 0.0354
# Epoch 9/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0225 - val_loss: 0.0018 - val_mean_absolute_error: 0.0320
# Epoch 10/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mean_absolute_error: 0.0229 - val_loss: 0.0019 - val_mean_absolute_error: 0.0318
# Epoch 11/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mean_absolute_error: 0.0221 - val_loss: 0.0020 - val_mean_absolute_error: 0.0322
# Epoch 12/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0198 - val_loss: 0.0018 - val_mean_absolute_error: 0.0310
# Epoch 13/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0205 - val_loss: 0.0018 - val_mean_absolute_error: 0.0307
# Epoch 14/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0219 - val_loss: 0.0017 - val_mean_absolute_error: 0.0306
# Epoch 15/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - mean_absolute_error: 0.0222 - val_loss: 0.0018 - val_mean_absolute_error: 0.0310
# Epoch 16/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0203 - val_loss: 0.0017 - val_mean_absolute_error: 0.0301
# Epoch 17/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0228 - val_loss: 0.0017 - val_mean_absolute_error: 0.0299
# Epoch 18/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0206 - val_loss: 0.0016 - val_mean_absolute_error: 0.0294
# Epoch 19/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0203 - val_loss: 0.0019 - val_mean_absolute_error: 0.0320
# Epoch 20/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0213 - val_loss: 0.0016 - val_mean_absolute_error: 0.0287
# Epoch 21/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0208 - val_loss: 0.0016 - val_mean_absolute_error: 0.0289
# Epoch 22/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1670e-04 - mean_absolute_error: 0.0188 - val_loss: 0.0017 - val_mean_absolute_error: 0.0316
# Epoch 23/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0242 - val_loss: 0.0015 - val_mean_absolute_error: 0.0280
# Epoch 24/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0223 - val_loss: 0.0020 - val_mean_absolute_error: 0.0326
# Epoch 25/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6409e-04 - mean_absolute_error: 0.0201 - val_loss: 0.0013 - val_mean_absolute_error: 0.0268
# Epoch 26/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6156e-04 - mean_absolute_error: 0.0186 - val_loss: 0.0014 - val_mean_absolute_error: 0.0268
# Epoch 27/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010 - mean_absolute_error: 0.0202 - val_loss: 0.0013 - val_mean_absolute_error: 0.0265
# Epoch 28/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1672e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0014 - val_mean_absolute_error: 0.0272
# Epoch 29/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010 - mean_absolute_error: 0.0193 - val_loss: 0.0016 - val_mean_absolute_error: 0.0291
# Epoch 30/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.9168e-04 - mean_absolute_error: 0.0188 - val_loss: 0.0014 - val_mean_absolute_error: 0.0265
# Epoch 31/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.3574e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0016 - val_mean_absolute_error: 0.0286
# Epoch 32/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.9250e-04 - mean_absolute_error: 0.0201 - val_loss: 0.0012 - val_mean_absolute_error: 0.0245
# Epoch 33/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.8090e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0011 - val_mean_absolute_error: 0.0241
# Epoch 34/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1143e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0019 - val_mean_absolute_error: 0.0337
# Epoch 35/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.0204e-04 - mean_absolute_error: 0.0196 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248
# Epoch 36/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5479e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0011 - val_mean_absolute_error: 0.0236
# Epoch 37/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4209e-04 - mean_absolute_error: 0.0166 - val_loss: 0.0011 - val_mean_absolute_error: 0.0237
# Epoch 38/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.6781e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0012 - val_mean_absolute_error: 0.0248
# Epoch 39/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.8267e-04 - mean_absolute_error: 0.0162 - val_loss: 9.9788e-04 - val_mean_absolute_error: 0.0226
# Epoch 40/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.0308e-04 - mean_absolute_error: 0.0172 - val_loss: 9.5609e-04 - val_mean_absolute_error: 0.0225
# Epoch 41/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.0709e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0011 - val_mean_absolute_error: 0.0235
# Epoch 42/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7008e-04 - mean_absolute_error: 0.0159 - val_loss: 0.0016 - val_mean_absolute_error: 0.0306
# Epoch 43/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8363e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0017 - val_mean_absolute_error: 0.0318
# Epoch 44/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.9925e-04 - mean_absolute_error: 0.0185 - val_loss: 0.0011 - val_mean_absolute_error: 0.0236
# Epoch 45/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.3353e-04 - mean_absolute_error: 0.0177 - val_loss: 0.0010 - val_mean_absolute_error: 0.0237
# Epoch 46/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.6820e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0011 - val_mean_absolute_error: 0.0238
# Epoch 47/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6153e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0011 - val_mean_absolute_error: 0.0232
# Epoch 48/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2718e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0014 - val_mean_absolute_error: 0.0287
# Epoch 49/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3578e-04 - mean_absolute_error: 0.0178 - val_loss: 0.0016 - val_mean_absolute_error: 0.0311
# Epoch 50/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.2530e-04 - mean_absolute_error: 0.0195 - val_loss: 0.0013 - val_mean_absolute_error: 0.0273
# Epoch 51/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.7285e-04 - mean_absolute_error: 0.0182 - val_loss: 9.3167e-04 - val_mean_absolute_error: 0.0215
# Epoch 52/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1068e-04 - mean_absolute_error: 0.0164 - val_loss: 8.6615e-04 - val_mean_absolute_error: 0.0210
# Epoch 53/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.8129e-04 - mean_absolute_error: 0.0169 - val_loss: 0.0011 - val_mean_absolute_error: 0.0237
# Epoch 54/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.2902e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0013 - val_mean_absolute_error: 0.0279
# Epoch 55/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.8990e-04 - mean_absolute_error: 0.0154 - val_loss: 8.5386e-04 - val_mean_absolute_error: 0.0214
# Epoch 56/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0212 - val_loss: 8.5632e-04 - val_mean_absolute_error: 0.0215
# Epoch 57/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4493e-04 - mean_absolute_error: 0.0165 - val_loss: 9.1425e-04 - val_mean_absolute_error: 0.0216
# Epoch 58/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2310e-04 - mean_absolute_error: 0.0146 - val_loss: 8.5917e-04 - val_mean_absolute_error: 0.0219
# Epoch 59/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6601e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0011 - val_mean_absolute_error: 0.0242
# Epoch 60/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5166e-04 - mean_absolute_error: 0.0162 - val_loss: 8.0845e-04 - val_mean_absolute_error: 0.0201
# Epoch 61/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4515e-04 - mean_absolute_error: 0.0155 - val_loss: 8.2253e-04 - val_mean_absolute_error: 0.0206
# Epoch 62/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6274e-04 - mean_absolute_error: 0.0146 - val_loss: 7.6236e-04 - val_mean_absolute_error: 0.0195
# Epoch 63/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.1508e-04 - mean_absolute_error: 0.0152 - val_loss: 8.5030e-04 - val_mean_absolute_error: 0.0206
# Epoch 64/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9789e-04 - mean_absolute_error: 0.0136 - val_loss: 8.2346e-04 - val_mean_absolute_error: 0.0205
# Epoch 65/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9817e-04 - mean_absolute_error: 0.0150 - val_loss: 7.5581e-04 - val_mean_absolute_error: 0.0202
# Epoch 66/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.4029e-04 - mean_absolute_error: 0.0144 - val_loss: 9.4560e-04 - val_mean_absolute_error: 0.0225
# Epoch 67/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0536e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0013 - val_mean_absolute_error: 0.0290
# Epoch 68/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3669e-04 - mean_absolute_error: 0.0163 - val_loss: 7.2829e-04 - val_mean_absolute_error: 0.0200
# Epoch 69/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5332e-04 - mean_absolute_error: 0.0162 - val_loss: 7.0659e-04 - val_mean_absolute_error: 0.0193
# Epoch 70/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1622e-04 - mean_absolute_error: 0.0151 - val_loss: 7.3892e-04 - val_mean_absolute_error: 0.0202
# Epoch 71/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6245e-04 - mean_absolute_error: 0.0167 - val_loss: 9.4353e-04 - val_mean_absolute_error: 0.0245
# Epoch 72/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6094e-04 - mean_absolute_error: 0.0176 - val_loss: 8.4955e-04 - val_mean_absolute_error: 0.0227
# Epoch 73/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.0538e-04 - mean_absolute_error: 0.0195 - val_loss: 9.9479e-04 - val_mean_absolute_error: 0.0234
# Epoch 74/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9130e-04 - mean_absolute_error: 0.0142 - val_loss: 7.4846e-04 - val_mean_absolute_error: 0.0207
# Epoch 75/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.2238e-04 - mean_absolute_error: 0.0172 - val_loss: 7.5389e-04 - val_mean_absolute_error: 0.0198
# Epoch 76/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3827e-04 - mean_absolute_error: 0.0127 - val_loss: 7.8724e-04 - val_mean_absolute_error: 0.0200
# Epoch 77/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1307e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0014 - val_mean_absolute_error: 0.0291
# Epoch 78/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.9882e-04 - mean_absolute_error: 0.0185 - val_loss: 6.3957e-04 - val_mean_absolute_error: 0.0184
# Epoch 79/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7409e-04 - mean_absolute_error: 0.0130 - val_loss: 6.3907e-04 - val_mean_absolute_error: 0.0184
# Epoch 80/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5074e-04 - mean_absolute_error: 0.0130 - val_loss: 7.7671e-04 - val_mean_absolute_error: 0.0202
# Epoch 81/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7695e-04 - mean_absolute_error: 0.0139 - val_loss: 6.8008e-04 - val_mean_absolute_error: 0.0189
# Epoch 82/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7519e-04 - mean_absolute_error: 0.0145 - val_loss: 6.2351e-04 - val_mean_absolute_error: 0.0179
# Epoch 83/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6925e-04 - mean_absolute_error: 0.0137 - val_loss: 6.2844e-04 - val_mean_absolute_error: 0.0179
# Epoch 84/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0163e-04 - mean_absolute_error: 0.0146 - val_loss: 6.7518e-04 - val_mean_absolute_error: 0.0189
# Epoch 85/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0007e-04 - mean_absolute_error: 0.0126 - val_loss: 6.4839e-04 - val_mean_absolute_error: 0.0182
# Epoch 86/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1194e-04 - mean_absolute_error: 0.0122 - val_loss: 6.2087e-04 - val_mean_absolute_error: 0.0180
# Epoch 87/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4711e-04 - mean_absolute_error: 0.0138 - val_loss: 6.2798e-04 - val_mean_absolute_error: 0.0179
# Epoch 88/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9902e-04 - mean_absolute_error: 0.0122 - val_loss: 5.9828e-04 - val_mean_absolute_error: 0.0174
# Epoch 89/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6381e-04 - mean_absolute_error: 0.0135 - val_loss: 6.2707e-04 - val_mean_absolute_error: 0.0179
# Epoch 90/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5562e-04 - mean_absolute_error: 0.0134 - val_loss: 5.7037e-04 - val_mean_absolute_error: 0.0171
# Epoch 91/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3651e-04 - mean_absolute_error: 0.0136 - val_loss: 6.6662e-04 - val_mean_absolute_error: 0.0198
# Epoch 92/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1840e-04 - mean_absolute_error: 0.0127 - val_loss: 7.0898e-04 - val_mean_absolute_error: 0.0197
# Epoch 93/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4411e-04 - mean_absolute_error: 0.0143 - val_loss: 6.2708e-04 - val_mean_absolute_error: 0.0189
# Epoch 94/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4666e-04 - mean_absolute_error: 0.0137 - val_loss: 5.6104e-04 - val_mean_absolute_error: 0.0170
# Epoch 95/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9515e-04 - mean_absolute_error: 0.0127 - val_loss: 6.4042e-04 - val_mean_absolute_error: 0.0183
# Epoch 96/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1880e-04 - mean_absolute_error: 0.0128 - val_loss: 5.9971e-04 - val_mean_absolute_error: 0.0175
# Epoch 97/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6982e-04 - mean_absolute_error: 0.0122 - val_loss: 5.7949e-04 - val_mean_absolute_error: 0.0172
# Epoch 98/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6897e-04 - mean_absolute_error: 0.0124 - val_loss: 8.0444e-04 - val_mean_absolute_error: 0.0211
# Epoch 99/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5226e-04 - mean_absolute_error: 0.0154 - val_loss: 5.3571e-04 - val_mean_absolute_error: 0.0166
# Epoch 100/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4837e-04 - mean_absolute_error: 0.0112 - val_loss: 5.6399e-04 - val_mean_absolute_error: 0.0175
# Epoch 101/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5251e-04 - mean_absolute_error: 0.0137 - val_loss: 6.8244e-04 - val_mean_absolute_error: 0.0204
# Epoch 102/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5553e-04 - mean_absolute_error: 0.0136 - val_loss: 5.3717e-04 - val_mean_absolute_error: 0.0169
# Epoch 103/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2368e-04 - mean_absolute_error: 0.0123 - val_loss: 5.6230e-04 - val_mean_absolute_error: 0.0172
# Epoch 104/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5433e-04 - mean_absolute_error: 0.0114 - val_loss: 5.1606e-04 - val_mean_absolute_error: 0.0164
# Epoch 105/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8959e-04 - mean_absolute_error: 0.0123 - val_loss: 6.9943e-04 - val_mean_absolute_error: 0.0210
# Epoch 106/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7575e-04 - mean_absolute_error: 0.0151 - val_loss: 5.5572e-04 - val_mean_absolute_error: 0.0170
# Epoch 107/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0469e-04 - mean_absolute_error: 0.0125 - val_loss: 5.4915e-04 - val_mean_absolute_error: 0.0172
# Epoch 108/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8767e-04 - mean_absolute_error: 0.0126 - val_loss: 5.1309e-04 - val_mean_absolute_error: 0.0164
# Epoch 109/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0181e-04 - mean_absolute_error: 0.0126 - val_loss: 5.1647e-04 - val_mean_absolute_error: 0.0164
# Epoch 110/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2951e-04 - mean_absolute_error: 0.0115 - val_loss: 5.2084e-04 - val_mean_absolute_error: 0.0166
# Epoch 111/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6946e-04 - mean_absolute_error: 0.0102 - val_loss: 5.2184e-04 - val_mean_absolute_error: 0.0165
# Epoch 112/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8897e-04 - mean_absolute_error: 0.0127 - val_loss: 4.8455e-04 - val_mean_absolute_error: 0.0159
# Epoch 113/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6777e-04 - mean_absolute_error: 0.0126 - val_loss: 5.9560e-04 - val_mean_absolute_error: 0.0182
# Epoch 114/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5675e-04 - mean_absolute_error: 0.0115 - val_loss: 4.8847e-04 - val_mean_absolute_error: 0.0160
# Epoch 115/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4919e-04 - mean_absolute_error: 0.0115 - val_loss: 8.8323e-04 - val_mean_absolute_error: 0.0232
# Epoch 116/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1077e-04 - mean_absolute_error: 0.0133 - val_loss: 5.4574e-04 - val_mean_absolute_error: 0.0172
# Epoch 117/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4589e-04 - mean_absolute_error: 0.0123 - val_loss: 9.1552e-04 - val_mean_absolute_error: 0.0240
# Epoch 118/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8661e-04 - mean_absolute_error: 0.0155 - val_loss: 5.3382e-04 - val_mean_absolute_error: 0.0168
# Epoch 119/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6741e-04 - mean_absolute_error: 0.0124 - val_loss: 6.9249e-04 - val_mean_absolute_error: 0.0195
# Epoch 120/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5489e-04 - mean_absolute_error: 0.0119 - val_loss: 4.8370e-04 - val_mean_absolute_error: 0.0160
# Epoch 121/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2216e-04 - mean_absolute_error: 0.0122 - val_loss: 5.3618e-04 - val_mean_absolute_error: 0.0174
# Epoch 122/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5446e-04 - mean_absolute_error: 0.0122 - val_loss: 5.4244e-04 - val_mean_absolute_error: 0.0172
# Epoch 123/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8429e-04 - mean_absolute_error: 0.0131 - val_loss: 6.0450e-04 - val_mean_absolute_error: 0.0187
# Epoch 124/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3456e-04 - mean_absolute_error: 0.0127 - val_loss: 5.8654e-04 - val_mean_absolute_error: 0.0182
# Epoch 125/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4436e-04 - mean_absolute_error: 0.0151 - val_loss: 5.2580e-04 - val_mean_absolute_error: 0.0173
# Epoch 126/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1298e-04 - mean_absolute_error: 0.0124 - val_loss: 4.7018e-04 - val_mean_absolute_error: 0.0157
# Epoch 127/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9497e-04 - mean_absolute_error: 0.0109 - val_loss: 7.0872e-04 - val_mean_absolute_error: 0.0203
# Epoch 128/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4102e-04 - mean_absolute_error: 0.0120 - val_loss: 4.7697e-04 - val_mean_absolute_error: 0.0159
# Epoch 129/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7221e-04 - mean_absolute_error: 0.0121 - val_loss: 5.2117e-04 - val_mean_absolute_error: 0.0170
# Epoch 130/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4669e-04 - mean_absolute_error: 0.0136 - val_loss: 7.6423e-04 - val_mean_absolute_error: 0.0211
# Epoch 131/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0560e-04 - mean_absolute_error: 0.0136 - val_loss: 5.4313e-04 - val_mean_absolute_error: 0.0177
# Epoch 132/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8670e-04 - mean_absolute_error: 0.0128 - val_loss: 5.0541e-04 - val_mean_absolute_error: 0.0168
# Epoch 133/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4273e-04 - mean_absolute_error: 0.0120 - val_loss: 5.0816e-04 - val_mean_absolute_error: 0.0163
# Epoch 134/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5529e-04 - mean_absolute_error: 0.0120 - val_loss: 5.3540e-04 - val_mean_absolute_error: 0.0169
# Epoch 135/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3148e-04 - mean_absolute_error: 0.0114 - val_loss: 4.7384e-04 - val_mean_absolute_error: 0.0160
# Epoch 136/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6832e-04 - mean_absolute_error: 0.0119 - val_loss: 7.7021e-04 - val_mean_absolute_error: 0.0226
# Epoch 137/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3491e-04 - mean_absolute_error: 0.0160 - val_loss: 5.1636e-04 - val_mean_absolute_error: 0.0173
# Epoch 138/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8390e-04 - mean_absolute_error: 0.0143 - val_loss: 5.1959e-04 - val_mean_absolute_error: 0.0171
# Epoch 139/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1811e-04 - mean_absolute_error: 0.0130 - val_loss: 4.9095e-04 - val_mean_absolute_error: 0.0161
# Epoch 140/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4645e-04 - mean_absolute_error: 0.0118 - val_loss: 4.8774e-04 - val_mean_absolute_error: 0.0160
# Epoch 141/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8095e-04 - mean_absolute_error: 0.0104 - val_loss: 4.7486e-04 - val_mean_absolute_error: 0.0159
# Epoch 142/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5572e-04 - mean_absolute_error: 0.0127 - val_loss: 4.9903e-04 - val_mean_absolute_error: 0.0168
# Epoch 143/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9401e-04 - mean_absolute_error: 0.0126 - val_loss: 7.6915e-04 - val_mean_absolute_error: 0.0226
# Epoch 144/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9229e-04 - mean_absolute_error: 0.0155 - val_loss: 6.0472e-04 - val_mean_absolute_error: 0.0184
# Epoch 145/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6080e-04 - mean_absolute_error: 0.0123 - val_loss: 5.4726e-04 - val_mean_absolute_error: 0.0172
# Epoch 146/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7311e-04 - mean_absolute_error: 0.0118 - val_loss: 4.5893e-04 - val_mean_absolute_error: 0.0156
# Epoch 147/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8754e-04 - mean_absolute_error: 0.0135 - val_loss: 5.9954e-04 - val_mean_absolute_error: 0.0183
# Epoch 148/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2874e-04 - mean_absolute_error: 0.0117 - val_loss: 4.8669e-04 - val_mean_absolute_error: 0.0162
# Epoch 149/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0099e-04 - mean_absolute_error: 0.0111 - val_loss: 7.5464e-04 - val_mean_absolute_error: 0.0211
# Epoch 150/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6942e-04 - mean_absolute_error: 0.0129 - val_loss: 4.7138e-04 - val_mean_absolute_error: 0.0158
# Epoch 151/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2796e-04 - mean_absolute_error: 0.0115 - val_loss: 4.9408e-04 - val_mean_absolute_error: 0.0167
# Epoch 152/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1464e-04 - mean_absolute_error: 0.0131 - val_loss: 4.9545e-04 - val_mean_absolute_error: 0.0167
# Epoch 153/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6162e-04 - mean_absolute_error: 0.0119 - val_loss: 4.8717e-04 - val_mean_absolute_error: 0.0162
# Epoch 154/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9738e-04 - mean_absolute_error: 0.0135 - val_loss: 4.6113e-04 - val_mean_absolute_error: 0.0156
# Epoch 155/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0616e-04 - mean_absolute_error: 0.0108 - val_loss: 5.1080e-04 - val_mean_absolute_error: 0.0165
# Epoch 156/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4147e-04 - mean_absolute_error: 0.0116 - val_loss: 7.5356e-04 - val_mean_absolute_error: 0.0214
# Epoch 157/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0090e-04 - mean_absolute_error: 0.0138 - val_loss: 6.8020e-04 - val_mean_absolute_error: 0.0203
# Epoch 158/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2245e-04 - mean_absolute_error: 0.0143 - val_loss: 7.8661e-04 - val_mean_absolute_error: 0.0220
# Epoch 159/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6033e-04 - mean_absolute_error: 0.0142 - val_loss: 4.8059e-04 - val_mean_absolute_error: 0.0160
# Epoch 160/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0873e-04 - mean_absolute_error: 0.0138 - val_loss: 4.8014e-04 - val_mean_absolute_error: 0.0164
# Epoch 161/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2184e-04 - mean_absolute_error: 0.0116 - val_loss: 5.8340e-04 - val_mean_absolute_error: 0.0186
# Epoch 162/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8217e-04 - mean_absolute_error: 0.0143 - val_loss: 5.3245e-04 - val_mean_absolute_error: 0.0172
# Epoch 163/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1323e-04 - mean_absolute_error: 0.0116 - val_loss: 4.6214e-04 - val_mean_absolute_error: 0.0156
# Epoch 164/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0810e-04 - mean_absolute_error: 0.0137 - val_loss: 5.7938e-04 - val_mean_absolute_error: 0.0186
# Epoch 165/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5440e-04 - mean_absolute_error: 0.0136 - val_loss: 4.6190e-04 - val_mean_absolute_error: 0.0158
# Epoch 166/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3801e-04 - mean_absolute_error: 0.0113 - val_loss: 7.1490e-04 - val_mean_absolute_error: 0.0204
# Epoch 167/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6481e-04 - mean_absolute_error: 0.0130 - val_loss: 4.5368e-04 - val_mean_absolute_error: 0.0155
# Epoch 168/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1500e-04 - mean_absolute_error: 0.0108 - val_loss: 4.9843e-04 - val_mean_absolute_error: 0.0169
# Epoch 169/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6285e-04 - mean_absolute_error: 0.0126 - val_loss: 6.3180e-04 - val_mean_absolute_error: 0.0189
# Epoch 170/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4670e-04 - mean_absolute_error: 0.0131 - val_loss: 4.6617e-04 - val_mean_absolute_error: 0.0158
# Epoch 171/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2813e-04 - mean_absolute_error: 0.0119 - val_loss: 4.6421e-04 - val_mean_absolute_error: 0.0159
# Epoch 172/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9612e-04 - mean_absolute_error: 0.0107 - val_loss: 4.7447e-04 - val_mean_absolute_error: 0.0159
# Epoch 173/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7599e-04 - mean_absolute_error: 0.0126 - val_loss: 5.2057e-04 - val_mean_absolute_error: 0.0175
# Epoch 174/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3196e-04 - mean_absolute_error: 0.0120 - val_loss: 5.0422e-04 - val_mean_absolute_error: 0.0169
# Epoch 175/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2791e-04 - mean_absolute_error: 0.0118 - val_loss: 4.6513e-04 - val_mean_absolute_error: 0.0157
# Epoch 176/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1347e-04 - mean_absolute_error: 0.0114 - val_loss: 4.6820e-04 - val_mean_absolute_error: 0.0157
# Epoch 177/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1535e-04 - mean_absolute_error: 0.0112 - val_loss: 4.8842e-04 - val_mean_absolute_error: 0.0161
# Epoch 178/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1522e-04 - mean_absolute_error: 0.0109 - val_loss: 4.5743e-04 - val_mean_absolute_error: 0.0156
# Epoch 179/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2098e-04 - mean_absolute_error: 0.0110 - val_loss: 4.5348e-04 - val_mean_absolute_error: 0.0155
# Epoch 180/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0385e-04 - mean_absolute_error: 0.0108 - val_loss: 4.5287e-04 - val_mean_absolute_error: 0.0155
# Epoch 181/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0167e-04 - mean_absolute_error: 0.0112 - val_loss: 4.6419e-04 - val_mean_absolute_error: 0.0160
# Epoch 182/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7423e-04 - mean_absolute_error: 0.0124 - val_loss: 4.6068e-04 - val_mean_absolute_error: 0.0157
# Epoch 183/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8467e-04 - mean_absolute_error: 0.0123 - val_loss: 4.5617e-04 - val_mean_absolute_error: 0.0156
# Epoch 184/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2901e-04 - mean_absolute_error: 0.0119 - val_loss: 4.7825e-04 - val_mean_absolute_error: 0.0160
# Epoch 185/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2145e-04 - mean_absolute_error: 0.0117 - val_loss: 4.5716e-04 - val_mean_absolute_error: 0.0157
# Epoch 186/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6553e-04 - mean_absolute_error: 0.0129 - val_loss: 4.5486e-04 - val_mean_absolute_error: 0.0155
# Epoch 187/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1576e-04 - mean_absolute_error: 0.0140 - val_loss: 4.6854e-04 - val_mean_absolute_error: 0.0158
# Epoch 188/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1136e-04 - mean_absolute_error: 0.0113 - val_loss: 4.5860e-04 - val_mean_absolute_error: 0.0156
# Epoch 189/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6375e-04 - mean_absolute_error: 0.0122 - val_loss: 4.7856e-04 - val_mean_absolute_error: 0.0164
# Epoch 190/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7837e-04 - mean_absolute_error: 0.0119 - val_loss: 4.5736e-04 - val_mean_absolute_error: 0.0157
# Epoch 191/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4241e-04 - mean_absolute_error: 0.0113 - val_loss: 4.9544e-04 - val_mean_absolute_error: 0.0164
# Epoch 192/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2836e-04 - mean_absolute_error: 0.0117 - val_loss: 4.5504e-04 - val_mean_absolute_error: 0.0155
# Epoch 193/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3637e-04 - mean_absolute_error: 0.0111 - val_loss: 5.0877e-04 - val_mean_absolute_error: 0.0171
# Epoch 194/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1298e-04 - mean_absolute_error: 0.0126 - val_loss: 4.7306e-04 - val_mean_absolute_error: 0.0159
# Epoch 195/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5532e-04 - mean_absolute_error: 0.0122 - val_loss: 8.3153e-04 - val_mean_absolute_error: 0.0227
# Epoch 196/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7652e-04 - mean_absolute_error: 0.0147 - val_loss: 6.3253e-04 - val_mean_absolute_error: 0.0192
# Epoch 197/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5168e-04 - mean_absolute_error: 0.0118 - val_loss: 5.2157e-04 - val_mean_absolute_error: 0.0173
# Epoch 198/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3351e-04 - mean_absolute_error: 0.0115 - val_loss: 4.9795e-04 - val_mean_absolute_error: 0.0162
# Epoch 199/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1529e-04 - mean_absolute_error: 0.0112 - val_loss: 4.5513e-04 - val_mean_absolute_error: 0.0157
# Epoch 200/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5706e-04 - mean_absolute_error: 0.0118 - val_loss: 5.1299e-04 - val_mean_absolute_error: 0.0168

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0017e-04 - mean_absolute_error: 0.0199
# Test Loss: [0.0005129852797836065, 0.01679031364619732]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 239
# 250

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 277855.9367054177
# RMSE: 527.1204195489089
# MAE: 374.6858655857741
# MAPE: 3.2607955017395955 %
#
# Model evalution on validate set
# MSE: 70442.19507857163
# RMSE: 265.4094856605009
# MAE: 206.76743977864584
# MAPE: 1.9291341718210873 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
y_pred_30_days
# Out:
# array([[ 9981.828],
#        [ 9995.03 ],
#        [10002.54 ],
#        [10005.59 ],
#        [10007.043],
#        [10007.709],
#        [10008.022],
#        [10008.164],
#        [10008.231],
#        [10008.261],
#        [10008.275],
#        [10008.281],
#        [10008.285],
#        [10008.285],
#        [10008.287],
#        [10008.287],
#        [10008.287],
#        [10008.287],
#        [10008.287],
#        [10008.287],
#        [10008.287],
#        [10008.287],
#        [10008.287],
#        [10008.287],
#        [10008.287],
#        [10008.287],
#        [10008.287],
#        [10008.287],
#        [10008.287],
#        [10008.287],
#        [10008.287]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
