# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: CMG - Test/Train/Vaildation: 70/20/10
# - Dataset: 1313 rows x 7 columns (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 769.3075034342694
# - MAE: 568.2007672435259
# - MAPE: 1.6936853472179696 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 0

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830
# ...           ...
# 2024-05-27  59000
# 2024-05-28  62100
# 2024-05-29  60000
# 2024-05-30  59200
# 2024-05-31  60900
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((908, 10), (908,), (251, 10), (251,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 27s 161ms/step - loss: 0.0267 - mean_absolute_error: 0.1163 - val_loss: 0.0032 - val_mean_absolute_error: 0.0531
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.8476e-04 - mean_absolute_error: 0.0239 - val_loss: 6.4355e-04 - val_mean_absolute_error: 0.0205
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.1163e-04 - mean_absolute_error: 0.0154 - val_loss: 5.1838e-04 - val_mean_absolute_error: 0.0166
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.5743e-04 - mean_absolute_error: 0.0169 - val_loss: 4.3569e-04 - val_mean_absolute_error: 0.0148
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.9333e-04 - mean_absolute_error: 0.0170 - val_loss: 4.1781e-04 - val_mean_absolute_error: 0.0145
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.1358e-04 - mean_absolute_error: 0.0163 - val_loss: 5.4479e-04 - val_mean_absolute_error: 0.0172
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 6.1860e-04 - mean_absolute_error: 0.0176 - val_loss: 3.8812e-04 - val_mean_absolute_error: 0.0141
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.1585e-04 - mean_absolute_error: 0.0174 - val_loss: 4.1516e-04 - val_mean_absolute_error: 0.0145
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 5.4935e-04 - mean_absolute_error: 0.0164 - val_loss: 3.7347e-04 - val_mean_absolute_error: 0.0144
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.6994e-04 - mean_absolute_error: 0.0169 - val_loss: 4.5543e-04 - val_mean_absolute_error: 0.0154
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.8773e-04 - mean_absolute_error: 0.0174 - val_loss: 4.0742e-04 - val_mean_absolute_error: 0.0159
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.9913e-04 - mean_absolute_error: 0.0175 - val_loss: 3.5823e-04 - val_mean_absolute_error: 0.0145
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.1899e-04 - mean_absolute_error: 0.0164 - val_loss: 3.3797e-04 - val_mean_absolute_error: 0.0137
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.0259e-04 - mean_absolute_error: 0.0161 - val_loss: 4.0242e-04 - val_mean_absolute_error: 0.0162
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.2510e-04 - mean_absolute_error: 0.0165 - val_loss: 8.6118e-04 - val_mean_absolute_error: 0.0246
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.3976e-04 - mean_absolute_error: 0.0164 - val_loss: 3.2403e-04 - val_mean_absolute_error: 0.0135
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.6198e-04 - mean_absolute_error: 0.0157 - val_loss: 4.6860e-04 - val_mean_absolute_error: 0.0160
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.1350e-04 - mean_absolute_error: 0.0168 - val_loss: 3.0628e-04 - val_mean_absolute_error: 0.0134
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.8236e-04 - mean_absolute_error: 0.0160 - val_loss: 3.6217e-04 - val_mean_absolute_error: 0.0136
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.1378e-04 - mean_absolute_error: 0.0145 - val_loss: 3.4495e-04 - val_mean_absolute_error: 0.0133
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.9088e-04 - mean_absolute_error: 0.0161 - val_loss: 3.4065e-04 - val_mean_absolute_error: 0.0132
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.6568e-04 - mean_absolute_error: 0.0155 - val_loss: 4.3266e-04 - val_mean_absolute_error: 0.0155
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.3257e-04 - mean_absolute_error: 0.0149 - val_loss: 2.6544e-04 - val_mean_absolute_error: 0.0121
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.6137e-04 - mean_absolute_error: 0.0153 - val_loss: 5.5335e-04 - val_mean_absolute_error: 0.0188
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.3540e-04 - mean_absolute_error: 0.0153 - val_loss: 7.0206e-04 - val_mean_absolute_error: 0.0235
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.0841e-04 - mean_absolute_error: 0.0149 - val_loss: 7.9248e-04 - val_mean_absolute_error: 0.0240
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.3478e-04 - mean_absolute_error: 0.0151 - val_loss: 2.4347e-04 - val_mean_absolute_error: 0.0116
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.8984e-04 - mean_absolute_error: 0.0143 - val_loss: 2.5773e-04 - val_mean_absolute_error: 0.0117
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.2600e-04 - mean_absolute_error: 0.0130 - val_loss: 3.6641e-04 - val_mean_absolute_error: 0.0144
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.4469e-04 - mean_absolute_error: 0.0136 - val_loss: 9.9953e-04 - val_mean_absolute_error: 0.0276
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.1865e-04 - mean_absolute_error: 0.0134 - val_loss: 2.3106e-04 - val_mean_absolute_error: 0.0118
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.1827e-04 - mean_absolute_error: 0.0127 - val_loss: 2.2565e-04 - val_mean_absolute_error: 0.0113
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.1436e-04 - mean_absolute_error: 0.0130 - val_loss: 2.3858e-04 - val_mean_absolute_error: 0.0115
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.5602e-04 - mean_absolute_error: 0.0137 - val_loss: 2.2316e-04 - val_mean_absolute_error: 0.0115
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.4529e-04 - mean_absolute_error: 0.0134 - val_loss: 2.2802e-04 - val_mean_absolute_error: 0.0114
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.9894e-04 - mean_absolute_error: 0.0126 - val_loss: 3.3858e-04 - val_mean_absolute_error: 0.0157
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.2713e-04 - mean_absolute_error: 0.0131 - val_loss: 4.4342e-04 - val_mean_absolute_error: 0.0167
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 3.1566e-04 - mean_absolute_error: 0.0134 - val_loss: 3.3522e-04 - val_mean_absolute_error: 0.0139
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.3728e-04 - mean_absolute_error: 0.0131 - val_loss: 2.1523e-04 - val_mean_absolute_error: 0.0108
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.2024e-04 - mean_absolute_error: 0.0129 - val_loss: 3.8540e-04 - val_mean_absolute_error: 0.0153
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.8936e-04 - mean_absolute_error: 0.0121 - val_loss: 4.0743e-04 - val_mean_absolute_error: 0.0161
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.0509e-04 - mean_absolute_error: 0.0123 - val_loss: 2.3421e-04 - val_mean_absolute_error: 0.0112
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.5631e-04 - mean_absolute_error: 0.0134 - val_loss: 2.0934e-04 - val_mean_absolute_error: 0.0106
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.8722e-04 - mean_absolute_error: 0.0120 - val_loss: 2.2999e-04 - val_mean_absolute_error: 0.0112
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.8597e-04 - mean_absolute_error: 0.0123 - val_loss: 2.0532e-04 - val_mean_absolute_error: 0.0104
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.4132e-04 - mean_absolute_error: 0.0113 - val_loss: 3.0180e-04 - val_mean_absolute_error: 0.0146
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.8629e-04 - mean_absolute_error: 0.0121 - val_loss: 2.3990e-04 - val_mean_absolute_error: 0.0115
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.4396e-04 - mean_absolute_error: 0.0109 - val_loss: 2.2214e-04 - val_mean_absolute_error: 0.0109
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.8405e-04 - mean_absolute_error: 0.0119 - val_loss: 3.7784e-04 - val_mean_absolute_error: 0.0155
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.4049e-04 - mean_absolute_error: 0.0110 - val_loss: 2.6437e-04 - val_mean_absolute_error: 0.0122
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.6875e-04 - mean_absolute_error: 0.0119 - val_loss: 3.0448e-04 - val_mean_absolute_error: 0.0134
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.8492e-04 - mean_absolute_error: 0.0117 - val_loss: 2.1145e-04 - val_mean_absolute_error: 0.0114
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.9089e-04 - mean_absolute_error: 0.0122 - val_loss: 2.5934e-04 - val_mean_absolute_error: 0.0133
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.6317e-04 - mean_absolute_error: 0.0118 - val_loss: 2.1310e-04 - val_mean_absolute_error: 0.0108
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.4292e-04 - mean_absolute_error: 0.0110 - val_loss: 3.6947e-04 - val_mean_absolute_error: 0.0154
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.8645e-04 - mean_absolute_error: 0.0121 - val_loss: 1.7403e-04 - val_mean_absolute_error: 0.0096
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.7635e-04 - mean_absolute_error: 0.0118 - val_loss: 4.5482e-04 - val_mean_absolute_error: 0.0177
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 3.0244e-04 - mean_absolute_error: 0.0120 - val_loss: 1.9197e-04 - val_mean_absolute_error: 0.0101
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.3839e-04 - mean_absolute_error: 0.0107 - val_loss: 2.3821e-04 - val_mean_absolute_error: 0.0116
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 2.6220e-04 - mean_absolute_error: 0.0116 - val_loss: 4.6799e-04 - val_mean_absolute_error: 0.0182
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.3173e-04 - mean_absolute_error: 0.0109 - val_loss: 2.4793e-04 - val_mean_absolute_error: 0.0120
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.3300e-04 - mean_absolute_error: 0.0107 - val_loss: 2.4607e-04 - val_mean_absolute_error: 0.0120
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.3659e-04 - mean_absolute_error: 0.0110 - val_loss: 1.6744e-04 - val_mean_absolute_error: 0.0094
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.2835e-04 - mean_absolute_error: 0.0106 - val_loss: 1.9031e-04 - val_mean_absolute_error: 0.0101
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.9927e-04 - mean_absolute_error: 0.0099 - val_loss: 1.7529e-04 - val_mean_absolute_error: 0.0097
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.2794e-04 - mean_absolute_error: 0.0106 - val_loss: 1.7368e-04 - val_mean_absolute_error: 0.0096
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.4055e-04 - mean_absolute_error: 0.0107 - val_loss: 1.6080e-04 - val_mean_absolute_error: 0.0093
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.4012e-04 - mean_absolute_error: 0.0110 - val_loss: 2.7604e-04 - val_mean_absolute_error: 0.0131
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.2133e-04 - mean_absolute_error: 0.0104 - val_loss: 1.7323e-04 - val_mean_absolute_error: 0.0099
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.0759e-04 - mean_absolute_error: 0.0103 - val_loss: 6.1060e-04 - val_mean_absolute_error: 0.0217
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.5172e-04 - mean_absolute_error: 0.0111 - val_loss: 4.0971e-04 - val_mean_absolute_error: 0.0171
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.3015e-04 - mean_absolute_error: 0.0108 - val_loss: 1.8939e-04 - val_mean_absolute_error: 0.0102
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.1570e-04 - mean_absolute_error: 0.0103 - val_loss: 1.7745e-04 - val_mean_absolute_error: 0.0098
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.1414e-04 - mean_absolute_error: 0.0104 - val_loss: 2.1684e-04 - val_mean_absolute_error: 0.0117
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.2702e-04 - mean_absolute_error: 0.0110 - val_loss: 1.5020e-04 - val_mean_absolute_error: 0.0089
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.2338e-04 - mean_absolute_error: 0.0107 - val_loss: 1.8619e-04 - val_mean_absolute_error: 0.0101
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.0209e-04 - mean_absolute_error: 0.0101 - val_loss: 1.9346e-04 - val_mean_absolute_error: 0.0104
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.5295e-04 - mean_absolute_error: 0.0117 - val_loss: 3.8378e-04 - val_mean_absolute_error: 0.0167
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.4059e-04 - mean_absolute_error: 0.0112 - val_loss: 5.4869e-04 - val_mean_absolute_error: 0.0207
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.4620e-04 - mean_absolute_error: 0.0113 - val_loss: 1.6501e-04 - val_mean_absolute_error: 0.0094
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.4989e-04 - mean_absolute_error: 0.0110 - val_loss: 1.6353e-04 - val_mean_absolute_error: 0.0094
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 2.0821e-04 - mean_absolute_error: 0.0099 - val_loss: 1.4922e-04 - val_mean_absolute_error: 0.0090
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.1228e-04 - mean_absolute_error: 0.0101 - val_loss: 1.6933e-04 - val_mean_absolute_error: 0.0097
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.0143e-04 - mean_absolute_error: 0.0101 - val_loss: 1.7904e-04 - val_mean_absolute_error: 0.0100
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.1615e-04 - mean_absolute_error: 0.0105 - val_loss: 5.8027e-04 - val_mean_absolute_error: 0.0215
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.3250e-04 - mean_absolute_error: 0.0113 - val_loss: 1.4563e-04 - val_mean_absolute_error: 0.0087
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.8898e-04 - mean_absolute_error: 0.0094 - val_loss: 1.3940e-04 - val_mean_absolute_error: 0.0085
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7667e-04 - mean_absolute_error: 0.0094 - val_loss: 1.5189e-04 - val_mean_absolute_error: 0.0090
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.9725e-04 - mean_absolute_error: 0.0097 - val_loss: 1.4025e-04 - val_mean_absolute_error: 0.0085
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.7084e-04 - mean_absolute_error: 0.0092 - val_loss: 1.7101e-04 - val_mean_absolute_error: 0.0098
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.8823e-04 - mean_absolute_error: 0.0096 - val_loss: 1.3856e-04 - val_mean_absolute_error: 0.0085
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8242e-04 - mean_absolute_error: 0.0093 - val_loss: 1.5379e-04 - val_mean_absolute_error: 0.0091
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.9720e-04 - mean_absolute_error: 0.0098 - val_loss: 1.8786e-04 - val_mean_absolute_error: 0.0105
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.7554e-04 - mean_absolute_error: 0.0090 - val_loss: 1.4518e-04 - val_mean_absolute_error: 0.0087
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2328e-04 - mean_absolute_error: 0.0112 - val_loss: 1.8801e-04 - val_mean_absolute_error: 0.0106
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.9163e-04 - mean_absolute_error: 0.0096 - val_loss: 1.7518e-04 - val_mean_absolute_error: 0.0100
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.8271e-04 - mean_absolute_error: 0.0093 - val_loss: 1.5063e-04 - val_mean_absolute_error: 0.0090
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.8630e-04 - mean_absolute_error: 0.0095 - val_loss: 2.2405e-04 - val_mean_absolute_error: 0.0120
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 2.1016e-04 - mean_absolute_error: 0.0101 - val_loss: 2.2513e-04 - val_mean_absolute_error: 0.0121
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.0445e-04 - mean_absolute_error: 0.0103 - val_loss: 1.9148e-04 - val_mean_absolute_error: 0.0108
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.1175e-04 - mean_absolute_error: 0.0101 - val_loss: 1.5608e-04 - val_mean_absolute_error: 0.0092
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8301e-04 - mean_absolute_error: 0.0096 - val_loss: 1.5509e-04 - val_mean_absolute_error: 0.0092
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.6621e-04 - mean_absolute_error: 0.0089 - val_loss: 1.4624e-04 - val_mean_absolute_error: 0.0088
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.7996e-04 - mean_absolute_error: 0.0095 - val_loss: 1.8093e-04 - val_mean_absolute_error: 0.0104
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.9806e-04 - mean_absolute_error: 0.0098 - val_loss: 1.5632e-04 - val_mean_absolute_error: 0.0093
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7460e-04 - mean_absolute_error: 0.0093 - val_loss: 1.3349e-04 - val_mean_absolute_error: 0.0084
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.8025e-04 - mean_absolute_error: 0.0093 - val_loss: 1.5059e-04 - val_mean_absolute_error: 0.0091
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7435e-04 - mean_absolute_error: 0.0095 - val_loss: 2.1182e-04 - val_mean_absolute_error: 0.0117
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.6964e-04 - mean_absolute_error: 0.0092 - val_loss: 1.3293e-04 - val_mean_absolute_error: 0.0083
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.6565e-04 - mean_absolute_error: 0.0089 - val_loss: 1.3642e-04 - val_mean_absolute_error: 0.0085
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8573e-04 - mean_absolute_error: 0.0095 - val_loss: 1.9210e-04 - val_mean_absolute_error: 0.0109
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6137e-04 - mean_absolute_error: 0.0088 - val_loss: 1.3219e-04 - val_mean_absolute_error: 0.0083
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6355e-04 - mean_absolute_error: 0.0089 - val_loss: 1.2845e-04 - val_mean_absolute_error: 0.0081
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.7469e-04 - mean_absolute_error: 0.0094 - val_loss: 1.3114e-04 - val_mean_absolute_error: 0.0083
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.9305e-04 - mean_absolute_error: 0.0098 - val_loss: 1.6704e-04 - val_mean_absolute_error: 0.0099
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.7504e-04 - mean_absolute_error: 0.0091 - val_loss: 1.6080e-04 - val_mean_absolute_error: 0.0095
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6783e-04 - mean_absolute_error: 0.0091 - val_loss: 1.4340e-04 - val_mean_absolute_error: 0.0088
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.6450e-04 - mean_absolute_error: 0.0088 - val_loss: 1.6737e-04 - val_mean_absolute_error: 0.0099
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.7621e-04 - mean_absolute_error: 0.0095 - val_loss: 1.6655e-04 - val_mean_absolute_error: 0.0099
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.6754e-04 - mean_absolute_error: 0.0090 - val_loss: 1.2934e-04 - val_mean_absolute_error: 0.0082
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6372e-04 - mean_absolute_error: 0.0089 - val_loss: 1.4807e-04 - val_mean_absolute_error: 0.0091
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6982e-04 - mean_absolute_error: 0.0092 - val_loss: 2.3270e-04 - val_mean_absolute_error: 0.0125
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5939e-04 - mean_absolute_error: 0.0087 - val_loss: 1.6970e-04 - val_mean_absolute_error: 0.0100
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.0632e-04 - mean_absolute_error: 0.0101 - val_loss: 4.1606e-04 - val_mean_absolute_error: 0.0179
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.3739e-04 - mean_absolute_error: 0.0112 - val_loss: 1.3622e-04 - val_mean_absolute_error: 0.0086
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7962e-04 - mean_absolute_error: 0.0092 - val_loss: 1.2273e-04 - val_mean_absolute_error: 0.0080
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.8659e-04 - mean_absolute_error: 0.0095 - val_loss: 2.0833e-04 - val_mean_absolute_error: 0.0116
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6765e-04 - mean_absolute_error: 0.0089 - val_loss: 1.4434e-04 - val_mean_absolute_error: 0.0089
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5838e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2975e-04 - val_mean_absolute_error: 0.0083
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5378e-04 - mean_absolute_error: 0.0088 - val_loss: 2.4014e-04 - val_mean_absolute_error: 0.0127
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6549e-04 - mean_absolute_error: 0.0090 - val_loss: 1.2749e-04 - val_mean_absolute_error: 0.0082
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6748e-04 - mean_absolute_error: 0.0091 - val_loss: 1.3864e-04 - val_mean_absolute_error: 0.0086
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6952e-04 - mean_absolute_error: 0.0089 - val_loss: 1.3167e-04 - val_mean_absolute_error: 0.0086
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7225e-04 - mean_absolute_error: 0.0092 - val_loss: 1.2530e-04 - val_mean_absolute_error: 0.0083
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.6068e-04 - mean_absolute_error: 0.0087 - val_loss: 1.4583e-04 - val_mean_absolute_error: 0.0090
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6629e-04 - mean_absolute_error: 0.0089 - val_loss: 1.6931e-04 - val_mean_absolute_error: 0.0100
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6665e-04 - mean_absolute_error: 0.0091 - val_loss: 1.2399e-04 - val_mean_absolute_error: 0.0082
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5486e-04 - mean_absolute_error: 0.0089 - val_loss: 1.7681e-04 - val_mean_absolute_error: 0.0105
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.7409e-04 - mean_absolute_error: 0.0095 - val_loss: 1.6737e-04 - val_mean_absolute_error: 0.0099
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6761e-04 - mean_absolute_error: 0.0091 - val_loss: 1.6069e-04 - val_mean_absolute_error: 0.0096
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.9282e-04 - mean_absolute_error: 0.0099 - val_loss: 1.5031e-04 - val_mean_absolute_error: 0.0092
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2907e-04 - mean_absolute_error: 0.0080 - val_loss: 1.7828e-04 - val_mean_absolute_error: 0.0103
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.7034e-04 - mean_absolute_error: 0.0091 - val_loss: 1.2161e-04 - val_mean_absolute_error: 0.0081
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.5144e-04 - mean_absolute_error: 0.0083 - val_loss: 1.7092e-04 - val_mean_absolute_error: 0.0100
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6659e-04 - mean_absolute_error: 0.0089 - val_loss: 2.5727e-04 - val_mean_absolute_error: 0.0133
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7091e-04 - mean_absolute_error: 0.0094 - val_loss: 1.2073e-04 - val_mean_absolute_error: 0.0080
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.5814e-04 - mean_absolute_error: 0.0090 - val_loss: 1.6343e-04 - val_mean_absolute_error: 0.0099
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6200e-04 - mean_absolute_error: 0.0091 - val_loss: 1.3023e-04 - val_mean_absolute_error: 0.0084
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7968e-04 - mean_absolute_error: 0.0095 - val_loss: 1.7612e-04 - val_mean_absolute_error: 0.0105
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4575e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2969e-04 - val_mean_absolute_error: 0.0086
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4401e-04 - mean_absolute_error: 0.0084 - val_loss: 1.9925e-04 - val_mean_absolute_error: 0.0111
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5337e-04 - mean_absolute_error: 0.0083 - val_loss: 2.0849e-04 - val_mean_absolute_error: 0.0115
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8746e-04 - mean_absolute_error: 0.0097 - val_loss: 3.4240e-04 - val_mean_absolute_error: 0.0160
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5516e-04 - mean_absolute_error: 0.0089 - val_loss: 2.5307e-04 - val_mean_absolute_error: 0.0131
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.5130e-04 - mean_absolute_error: 0.0085 - val_loss: 2.2460e-04 - val_mean_absolute_error: 0.0121
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5247e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2391e-04 - val_mean_absolute_error: 0.0083
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3623e-04 - mean_absolute_error: 0.0082 - val_loss: 1.4658e-04 - val_mean_absolute_error: 0.0091
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5740e-04 - mean_absolute_error: 0.0091 - val_loss: 2.5075e-04 - val_mean_absolute_error: 0.0133
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6110e-04 - mean_absolute_error: 0.0088 - val_loss: 1.3370e-04 - val_mean_absolute_error: 0.0085
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4697e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3844e-04 - val_mean_absolute_error: 0.0087
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2649e-04 - mean_absolute_error: 0.0077 - val_loss: 1.4809e-04 - val_mean_absolute_error: 0.0091
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5657e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2377e-04 - val_mean_absolute_error: 0.0084
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6272e-04 - mean_absolute_error: 0.0090 - val_loss: 1.2963e-04 - val_mean_absolute_error: 0.0084
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.3994e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2836e-04 - val_mean_absolute_error: 0.0084
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.4785e-04 - mean_absolute_error: 0.0083 - val_loss: 1.8300e-04 - val_mean_absolute_error: 0.0105
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.6720e-04 - mean_absolute_error: 0.0089 - val_loss: 2.0730e-04 - val_mean_absolute_error: 0.0115
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5836e-04 - mean_absolute_error: 0.0087 - val_loss: 2.7404e-04 - val_mean_absolute_error: 0.0140
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.9418e-04 - mean_absolute_error: 0.0098 - val_loss: 1.2232e-04 - val_mean_absolute_error: 0.0083
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6223e-04 - mean_absolute_error: 0.0092 - val_loss: 2.7777e-04 - val_mean_absolute_error: 0.0140
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.6160e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2699e-04 - val_mean_absolute_error: 0.0086
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5132e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2278e-04 - val_mean_absolute_error: 0.0082
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5148e-04 - mean_absolute_error: 0.0086 - val_loss: 2.5485e-04 - val_mean_absolute_error: 0.0132
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6788e-04 - mean_absolute_error: 0.0089 - val_loss: 4.7355e-04 - val_mean_absolute_error: 0.0193
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7318e-04 - mean_absolute_error: 0.0092 - val_loss: 1.7540e-04 - val_mean_absolute_error: 0.0102
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.4682e-04 - mean_absolute_error: 0.0084 - val_loss: 4.8620e-04 - val_mean_absolute_error: 0.0196
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7969e-04 - mean_absolute_error: 0.0091 - val_loss: 1.4250e-04 - val_mean_absolute_error: 0.0089
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.6656e-04 - mean_absolute_error: 0.0090 - val_loss: 2.0494e-04 - val_mean_absolute_error: 0.0114
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4562e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2550e-04 - val_mean_absolute_error: 0.0085
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4411e-04 - mean_absolute_error: 0.0082 - val_loss: 1.3880e-04 - val_mean_absolute_error: 0.0090
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5010e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2437e-04 - val_mean_absolute_error: 0.0083
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6223e-04 - mean_absolute_error: 0.0086 - val_loss: 1.4988e-04 - val_mean_absolute_error: 0.0094
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4255e-04 - mean_absolute_error: 0.0081 - val_loss: 1.7356e-04 - val_mean_absolute_error: 0.0101
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5462e-04 - mean_absolute_error: 0.0088 - val_loss: 1.4056e-04 - val_mean_absolute_error: 0.0088
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4884e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2971e-04 - val_mean_absolute_error: 0.0085
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6418e-04 - mean_absolute_error: 0.0089 - val_loss: 3.4300e-04 - val_mean_absolute_error: 0.0158
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5893e-04 - mean_absolute_error: 0.0085 - val_loss: 1.5784e-04 - val_mean_absolute_error: 0.0095
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4413e-04 - mean_absolute_error: 0.0081 - val_loss: 2.3186e-04 - val_mean_absolute_error: 0.0123
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7050e-04 - mean_absolute_error: 0.0090 - val_loss: 1.4384e-04 - val_mean_absolute_error: 0.0090
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3632e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2513e-04 - val_mean_absolute_error: 0.0085
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5078e-04 - mean_absolute_error: 0.0085 - val_loss: 1.6401e-04 - val_mean_absolute_error: 0.0098
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3972e-04 - mean_absolute_error: 0.0080 - val_loss: 1.3509e-04 - val_mean_absolute_error: 0.0089
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4841e-04 - mean_absolute_error: 0.0085 - val_loss: 1.8023e-04 - val_mean_absolute_error: 0.0104
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5595e-04 - mean_absolute_error: 0.0083 - val_loss: 1.4582e-04 - val_mean_absolute_error: 0.0090
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4431e-04 - mean_absolute_error: 0.0080 - val_loss: 1.3488e-04 - val_mean_absolute_error: 0.0087
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.6970e-04 - mean_absolute_error: 0.0092 - val_loss: 1.4947e-04 - val_mean_absolute_error: 0.0093
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5256e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2900e-04 - val_mean_absolute_error: 0.0085
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3183e-04 - mean_absolute_error: 0.0079 - val_loss: 1.3672e-04 - val_mean_absolute_error: 0.0086
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3077e-04 - mean_absolute_error: 0.0078 - val_loss: 2.7170e-04 - val_mean_absolute_error: 0.0137
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4287e-04 - mean_absolute_error: 0.0081 - val_loss: 1.6898e-04 - val_mean_absolute_error: 0.0100
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3955e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2597e-04 - val_mean_absolute_error: 0.0085

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5737e-04 - mean_absolute_error: 0.0097
# Test Loss: [0.00012596906162798405, 0.00851380918174982]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 591834.0348402684
# RMSE: 769.3075034342694
# MAE: 568.2007672435259
# MAPE: 1.6936853472179696 %
#
# Model evalution on validate set
# MSE: 5156325.081070324
# RMSE: 2270.7542978205115
# MAE: 1432.6137654958677
# MAPE: 2.94759030266885 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 737ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step

# %%
y_pred_30_days
# Out:
# array([[61093.176],
#        [60430.035],
#        [61330.96 ],
#        [60384.637],
#        [61275.734],
#        [60406.72 ],
#        [61266.395],
#        [60424.84 ],
#        [61249.47 ],
#        [60440.664],
#        [61233.934],
#        [60456.24 ],
#        [61218.945],
#        [60471.133],
#        [61204.516],
#        [60485.457],
#        [61190.65 ],
#        [60499.22 ],
#        [61177.33 ],
#        [60512.45 ],
#        [61164.51 ],
#        [60525.176],
#        [61152.18 ],
#        [60537.39 ],
#        [61140.33 ],
#        [60549.133],
#        [61128.94 ],
#        [60560.434],
#        [61117.973],
#        [60571.277],
#        [61107.43 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Forecast Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
