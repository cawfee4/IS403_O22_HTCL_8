# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: CMG - Test/Train/Vaildation: 70/20/10
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1055.83
# - MAE: 750.46
# - MAPE: 2.33 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 0

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830
# ...           ...
# 2024-02-26  40000
# 2024-02-27  40200
# 2024-02-28  40000
# 2024-02-29  39950
# 2024-03-01  41200
#
# [1252 rows x 1 columns]

# %%
df.shape
# Out:
# (1252, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1247    40000
# 1248    40200
# 1249    40000
# 1250    39950
# 1251    41200
# Name: close, Length: 1252, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((865, 10), (865,), (239, 10), (239,), (115, 10), (115,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0925 - mean_absolute_error: 0.2197 - val_loss: 0.0204 - val_mean_absolute_error: 0.1342
# Epoch 2/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0039 - mean_absolute_error: 0.0470 - val_loss: 0.0022 - val_mean_absolute_error: 0.0309
# Epoch 3/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0271 - val_loss: 0.0031 - val_mean_absolute_error: 0.0430
# Epoch 4/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0276 - val_loss: 0.0022 - val_mean_absolute_error: 0.0310
# Epoch 5/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0262 - val_loss: 0.0021 - val_mean_absolute_error: 0.0305
# Epoch 6/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0253 - val_loss: 0.0021 - val_mean_absolute_error: 0.0303
# Epoch 7/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0254 - val_loss: 0.0028 - val_mean_absolute_error: 0.0398
# Epoch 8/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0263 - val_loss: 0.0021 - val_mean_absolute_error: 0.0310
# Epoch 9/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0240 - val_loss: 0.0020 - val_mean_absolute_error: 0.0302
# Epoch 10/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0248 - val_loss: 0.0020 - val_mean_absolute_error: 0.0300
# Epoch 11/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0258 - val_loss: 0.0021 - val_mean_absolute_error: 0.0319
# Epoch 12/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0250 - val_loss: 0.0021 - val_mean_absolute_error: 0.0319
# Epoch 13/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0252 - val_loss: 0.0025 - val_mean_absolute_error: 0.0371
# Epoch 14/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014 - mean_absolute_error: 0.0264 - val_loss: 0.0022 - val_mean_absolute_error: 0.0331
# Epoch 15/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0243 - val_loss: 0.0019 - val_mean_absolute_error: 0.0294
# Epoch 16/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010 - mean_absolute_error: 0.0227 - val_loss: 0.0022 - val_mean_absolute_error: 0.0344
# Epoch 17/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015 - mean_absolute_error: 0.0274 - val_loss: 0.0019 - val_mean_absolute_error: 0.0295
# Epoch 18/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0230 - val_loss: 0.0018 - val_mean_absolute_error: 0.0285
# Epoch 19/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0243 - val_loss: 0.0017 - val_mean_absolute_error: 0.0280
# Epoch 20/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0247 - val_loss: 0.0017 - val_mean_absolute_error: 0.0277
# Epoch 21/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0243 - val_loss: 0.0021 - val_mean_absolute_error: 0.0336
# Epoch 22/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0244 - val_loss: 0.0016 - val_mean_absolute_error: 0.0270
# Epoch 23/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010 - mean_absolute_error: 0.0235 - val_loss: 0.0016 - val_mean_absolute_error: 0.0268
# Epoch 24/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0246 - val_loss: 0.0025 - val_mean_absolute_error: 0.0392
# Epoch 25/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010 - mean_absolute_error: 0.0241 - val_loss: 0.0018 - val_mean_absolute_error: 0.0306
# Epoch 26/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010 - mean_absolute_error: 0.0228 - val_loss: 0.0024 - val_mean_absolute_error: 0.0396
# Epoch 27/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0264 - val_loss: 0.0014 - val_mean_absolute_error: 0.0252
# Epoch 28/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.4807e-04 - mean_absolute_error: 0.0214 - val_loss: 0.0029 - val_mean_absolute_error: 0.0446
# Epoch 29/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0021 - mean_absolute_error: 0.0342 - val_loss: 0.0031 - val_mean_absolute_error: 0.0469
# Epoch 30/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010 - mean_absolute_error: 0.0237 - val_loss: 0.0016 - val_mean_absolute_error: 0.0286
# Epoch 31/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7916e-04 - mean_absolute_error: 0.0234 - val_loss: 0.0016 - val_mean_absolute_error: 0.0291
# Epoch 32/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010 - mean_absolute_error: 0.0236 - val_loss: 0.0013 - val_mean_absolute_error: 0.0242
# Epoch 33/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8414e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0013 - val_mean_absolute_error: 0.0243
# Epoch 34/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8332e-04 - mean_absolute_error: 0.0226 - val_loss: 0.0015 - val_mean_absolute_error: 0.0284
# Epoch 35/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0238 - val_loss: 0.0015 - val_mean_absolute_error: 0.0279
# Epoch 36/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0013 - mean_absolute_error: 0.0258 - val_loss: 0.0019 - val_mean_absolute_error: 0.0340
# Epoch 37/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020 - mean_absolute_error: 0.0337 - val_loss: 0.0012 - val_mean_absolute_error: 0.0235
# Epoch 38/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5099e-04 - mean_absolute_error: 0.0223 - val_loss: 0.0012 - val_mean_absolute_error: 0.0228
# Epoch 39/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1974e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0012 - val_mean_absolute_error: 0.0232
# Epoch 40/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.6243e-04 - mean_absolute_error: 0.0209 - val_loss: 0.0011 - val_mean_absolute_error: 0.0231
# Epoch 41/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.0541e-04 - mean_absolute_error: 0.0203 - val_loss: 0.0016 - val_mean_absolute_error: 0.0310
# Epoch 42/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.7168e-04 - mean_absolute_error: 0.0218 - val_loss: 0.0010 - val_mean_absolute_error: 0.0217
# Epoch 43/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6217e-04 - mean_absolute_error: 0.0187 - val_loss: 0.0011 - val_mean_absolute_error: 0.0235
# Epoch 44/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.9377e-04 - mean_absolute_error: 0.0201 - val_loss: 9.7944e-04 - val_mean_absolute_error: 0.0216
# Epoch 45/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.2366e-04 - mean_absolute_error: 0.0194 - val_loss: 0.0014 - val_mean_absolute_error: 0.0293
# Epoch 46/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.0936e-04 - mean_absolute_error: 0.0188 - val_loss: 8.8278e-04 - val_mean_absolute_error: 0.0202
# Epoch 47/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3196e-04 - mean_absolute_error: 0.0194 - val_loss: 8.7639e-04 - val_mean_absolute_error: 0.0204
# Epoch 48/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5951e-04 - mean_absolute_error: 0.0188 - val_loss: 0.0013 - val_mean_absolute_error: 0.0291
# Epoch 49/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.6276e-04 - mean_absolute_error: 0.0215 - val_loss: 8.4972e-04 - val_mean_absolute_error: 0.0199
# Epoch 50/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5156e-04 - mean_absolute_error: 0.0181 - val_loss: 8.0970e-04 - val_mean_absolute_error: 0.0194
# Epoch 51/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6387e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0015 - val_mean_absolute_error: 0.0321
# Epoch 52/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.0615e-04 - mean_absolute_error: 0.0224 - val_loss: 0.0012 - val_mean_absolute_error: 0.0281
# Epoch 53/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.5153e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0013 - val_mean_absolute_error: 0.0287
# Epoch 54/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.0558e-04 - mean_absolute_error: 0.0202 - val_loss: 0.0010 - val_mean_absolute_error: 0.0247
# Epoch 55/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.2602e-04 - mean_absolute_error: 0.0194 - val_loss: 8.6124e-04 - val_mean_absolute_error: 0.0210
# Epoch 56/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6855e-04 - mean_absolute_error: 0.0186 - val_loss: 0.0011 - val_mean_absolute_error: 0.0263
# Epoch 57/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.6426e-04 - mean_absolute_error: 0.0191 - val_loss: 0.0015 - val_mean_absolute_error: 0.0326
# Epoch 58/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.1987e-04 - mean_absolute_error: 0.0202 - val_loss: 9.0218e-04 - val_mean_absolute_error: 0.0220
# Epoch 59/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6545e-04 - mean_absolute_error: 0.0183 - val_loss: 0.0019 - val_mean_absolute_error: 0.0380
# Epoch 60/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.8917e-04 - mean_absolute_error: 0.0184 - val_loss: 7.1228e-04 - val_mean_absolute_error: 0.0179
# Epoch 61/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5873e-04 - mean_absolute_error: 0.0172 - val_loss: 7.8199e-04 - val_mean_absolute_error: 0.0198
# Epoch 62/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.2822e-04 - mean_absolute_error: 0.0191 - val_loss: 8.8476e-04 - val_mean_absolute_error: 0.0224
# Epoch 63/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6323e-04 - mean_absolute_error: 0.0168 - val_loss: 8.9719e-04 - val_mean_absolute_error: 0.0228
# Epoch 64/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1351e-04 - mean_absolute_error: 0.0193 - val_loss: 7.0578e-04 - val_mean_absolute_error: 0.0184
# Epoch 65/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.8274e-04 - mean_absolute_error: 0.0186 - val_loss: 7.5854e-04 - val_mean_absolute_error: 0.0196
# Epoch 66/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.0649e-04 - mean_absolute_error: 0.0179 - val_loss: 0.0014 - val_mean_absolute_error: 0.0321
# Epoch 67/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.6714e-04 - mean_absolute_error: 0.0213 - val_loss: 7.0704e-04 - val_mean_absolute_error: 0.0181
# Epoch 68/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6444e-04 - mean_absolute_error: 0.0169 - val_loss: 7.4718e-04 - val_mean_absolute_error: 0.0193
# Epoch 69/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.6464e-04 - mean_absolute_error: 0.0169 - val_loss: 7.1186e-04 - val_mean_absolute_error: 0.0186
# Epoch 70/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0884e-04 - mean_absolute_error: 0.0161 - val_loss: 6.4804e-04 - val_mean_absolute_error: 0.0173
# Epoch 71/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1435e-04 - mean_absolute_error: 0.0160 - val_loss: 8.3416e-04 - val_mean_absolute_error: 0.0218
# Epoch 72/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5729e-04 - mean_absolute_error: 0.0163 - val_loss: 6.7609e-04 - val_mean_absolute_error: 0.0186
# Epoch 73/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8908e-04 - mean_absolute_error: 0.0154 - val_loss: 6.7279e-04 - val_mean_absolute_error: 0.0187
# Epoch 74/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6504e-04 - mean_absolute_error: 0.0152 - val_loss: 7.9386e-04 - val_mean_absolute_error: 0.0217
# Epoch 75/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3602e-04 - mean_absolute_error: 0.0163 - val_loss: 0.0019 - val_mean_absolute_error: 0.0379
# Epoch 76/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5260e-04 - mean_absolute_error: 0.0190 - val_loss: 0.0019 - val_mean_absolute_error: 0.0384
# Epoch 77/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.5896e-04 - mean_absolute_error: 0.0193 - val_loss: 6.1072e-04 - val_mean_absolute_error: 0.0169
# Epoch 78/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5846e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0011 - val_mean_absolute_error: 0.0282
# Epoch 79/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9287e-04 - mean_absolute_error: 0.0177 - val_loss: 0.0011 - val_mean_absolute_error: 0.0270
# Epoch 80/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6382e-04 - mean_absolute_error: 0.0168 - val_loss: 8.9251e-04 - val_mean_absolute_error: 0.0241
# Epoch 81/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4440e-04 - mean_absolute_error: 0.0164 - val_loss: 5.7702e-04 - val_mean_absolute_error: 0.0161
# Epoch 82/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0122e-04 - mean_absolute_error: 0.0158 - val_loss: 6.2383e-04 - val_mean_absolute_error: 0.0172
# Epoch 83/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2437e-04 - mean_absolute_error: 0.0171 - val_loss: 5.7764e-04 - val_mean_absolute_error: 0.0163
# Epoch 84/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6410e-04 - mean_absolute_error: 0.0167 - val_loss: 6.4013e-04 - val_mean_absolute_error: 0.0176
# Epoch 85/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9470e-04 - mean_absolute_error: 0.0158 - val_loss: 9.2621e-04 - val_mean_absolute_error: 0.0252
# Epoch 86/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0497e-04 - mean_absolute_error: 0.0159 - val_loss: 9.4228e-04 - val_mean_absolute_error: 0.0242
# Epoch 87/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.8169e-04 - mean_absolute_error: 0.0193 - val_loss: 6.0091e-04 - val_mean_absolute_error: 0.0173
# Epoch 88/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5613e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0016 - val_mean_absolute_error: 0.0360
# Epoch 89/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0011 - mean_absolute_error: 0.0240 - val_loss: 6.0105e-04 - val_mean_absolute_error: 0.0174
# Epoch 90/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4784e-04 - mean_absolute_error: 0.0149 - val_loss: 5.7288e-04 - val_mean_absolute_error: 0.0167
# Epoch 91/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5062e-04 - mean_absolute_error: 0.0150 - val_loss: 7.8523e-04 - val_mean_absolute_error: 0.0225
# Epoch 92/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1733e-04 - mean_absolute_error: 0.0163 - val_loss: 7.3102e-04 - val_mean_absolute_error: 0.0198
# Epoch 93/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6243e-04 - mean_absolute_error: 0.0150 - val_loss: 7.9681e-04 - val_mean_absolute_error: 0.0213
# Epoch 94/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8234e-04 - mean_absolute_error: 0.0160 - val_loss: 5.4145e-04 - val_mean_absolute_error: 0.0160
# Epoch 95/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1218e-04 - mean_absolute_error: 0.0139 - val_loss: 6.2508e-04 - val_mean_absolute_error: 0.0187
# Epoch 96/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0974e-04 - mean_absolute_error: 0.0143 - val_loss: 5.4958e-04 - val_mean_absolute_error: 0.0157
# Epoch 97/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6863e-04 - mean_absolute_error: 0.0159 - val_loss: 5.2979e-04 - val_mean_absolute_error: 0.0159
# Epoch 98/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3453e-04 - mean_absolute_error: 0.0146 - val_loss: 5.3476e-04 - val_mean_absolute_error: 0.0161
# Epoch 99/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1859e-04 - mean_absolute_error: 0.0142 - val_loss: 6.0540e-04 - val_mean_absolute_error: 0.0184
# Epoch 100/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2058e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0023 - val_mean_absolute_error: 0.0437
# Epoch 101/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012 - mean_absolute_error: 0.0252 - val_loss: 7.6747e-04 - val_mean_absolute_error: 0.0224
# Epoch 102/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1922e-04 - mean_absolute_error: 0.0145 - val_loss: 6.5296e-04 - val_mean_absolute_error: 0.0181
# Epoch 103/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4946e-04 - mean_absolute_error: 0.0151 - val_loss: 5.6914e-04 - val_mean_absolute_error: 0.0161
# Epoch 104/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2892e-04 - mean_absolute_error: 0.0144 - val_loss: 5.2790e-04 - val_mean_absolute_error: 0.0158
# Epoch 105/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7474e-04 - mean_absolute_error: 0.0137 - val_loss: 6.4358e-04 - val_mean_absolute_error: 0.0195
# Epoch 106/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4030e-04 - mean_absolute_error: 0.0147 - val_loss: 5.2715e-04 - val_mean_absolute_error: 0.0155
# Epoch 107/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1656e-04 - mean_absolute_error: 0.0145 - val_loss: 5.4714e-04 - val_mean_absolute_error: 0.0167
# Epoch 108/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7809e-04 - mean_absolute_error: 0.0138 - val_loss: 5.7019e-04 - val_mean_absolute_error: 0.0164
# Epoch 109/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6190e-04 - mean_absolute_error: 0.0131 - val_loss: 5.2349e-04 - val_mean_absolute_error: 0.0159
# Epoch 110/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8407e-04 - mean_absolute_error: 0.0139 - val_loss: 5.6711e-04 - val_mean_absolute_error: 0.0166
# Epoch 111/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1337e-04 - mean_absolute_error: 0.0141 - val_loss: 7.1152e-04 - val_mean_absolute_error: 0.0213
# Epoch 112/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1121e-04 - mean_absolute_error: 0.0145 - val_loss: 8.6335e-04 - val_mean_absolute_error: 0.0244
# Epoch 113/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0609e-04 - mean_absolute_error: 0.0138 - val_loss: 6.1783e-04 - val_mean_absolute_error: 0.0190
# Epoch 114/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7566e-04 - mean_absolute_error: 0.0133 - val_loss: 6.4925e-04 - val_mean_absolute_error: 0.0198
# Epoch 115/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7149e-04 - mean_absolute_error: 0.0135 - val_loss: 5.5715e-04 - val_mean_absolute_error: 0.0164
# Epoch 116/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9709e-04 - mean_absolute_error: 0.0140 - val_loss: 5.1146e-04 - val_mean_absolute_error: 0.0156
# Epoch 117/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5298e-04 - mean_absolute_error: 0.0129 - val_loss: 5.4126e-04 - val_mean_absolute_error: 0.0162
# Epoch 118/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6266e-04 - mean_absolute_error: 0.0135 - val_loss: 5.1354e-04 - val_mean_absolute_error: 0.0157
# Epoch 119/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3111e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0011 - val_mean_absolute_error: 0.0281
# Epoch 120/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.9727e-04 - mean_absolute_error: 0.0180 - val_loss: 5.3338e-04 - val_mean_absolute_error: 0.0162
# Epoch 121/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6418e-04 - mean_absolute_error: 0.0137 - val_loss: 8.2147e-04 - val_mean_absolute_error: 0.0222
# Epoch 122/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.9975e-04 - mean_absolute_error: 0.0213 - val_loss: 5.4540e-04 - val_mean_absolute_error: 0.0163
# Epoch 123/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5312e-04 - mean_absolute_error: 0.0129 - val_loss: 5.1006e-04 - val_mean_absolute_error: 0.0155
# Epoch 124/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5663e-04 - mean_absolute_error: 0.0130 - val_loss: 6.5570e-04 - val_mean_absolute_error: 0.0200
# Epoch 125/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5912e-04 - mean_absolute_error: 0.0136 - val_loss: 5.1285e-04 - val_mean_absolute_error: 0.0157
# Epoch 126/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3549e-04 - mean_absolute_error: 0.0126 - val_loss: 8.0228e-04 - val_mean_absolute_error: 0.0233
# Epoch 127/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9819e-04 - mean_absolute_error: 0.0139 - val_loss: 5.1637e-04 - val_mean_absolute_error: 0.0159
# Epoch 128/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5314e-04 - mean_absolute_error: 0.0134 - val_loss: 8.2678e-04 - val_mean_absolute_error: 0.0237
# Epoch 129/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3618e-04 - mean_absolute_error: 0.0144 - val_loss: 5.4464e-04 - val_mean_absolute_error: 0.0166
# Epoch 130/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5539e-04 - mean_absolute_error: 0.0135 - val_loss: 5.8354e-04 - val_mean_absolute_error: 0.0174
# Epoch 131/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0274e-04 - mean_absolute_error: 0.0142 - val_loss: 7.1504e-04 - val_mean_absolute_error: 0.0213
# Epoch 132/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6462e-04 - mean_absolute_error: 0.0127 - val_loss: 5.1501e-04 - val_mean_absolute_error: 0.0160
# Epoch 133/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4050e-04 - mean_absolute_error: 0.0127 - val_loss: 5.7547e-04 - val_mean_absolute_error: 0.0177
# Epoch 134/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8008e-04 - mean_absolute_error: 0.0139 - val_loss: 5.1300e-04 - val_mean_absolute_error: 0.0158
# Epoch 135/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4267e-04 - mean_absolute_error: 0.0128 - val_loss: 7.2843e-04 - val_mean_absolute_error: 0.0205
# Epoch 136/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7047e-04 - mean_absolute_error: 0.0156 - val_loss: 5.1520e-04 - val_mean_absolute_error: 0.0158
# Epoch 137/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4144e-04 - mean_absolute_error: 0.0128 - val_loss: 5.1209e-04 - val_mean_absolute_error: 0.0158
# Epoch 138/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7615e-04 - mean_absolute_error: 0.0139 - val_loss: 5.8165e-04 - val_mean_absolute_error: 0.0174
# Epoch 139/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2103e-04 - mean_absolute_error: 0.0124 - val_loss: 5.4062e-04 - val_mean_absolute_error: 0.0166
# Epoch 140/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8455e-04 - mean_absolute_error: 0.0115 - val_loss: 5.1029e-04 - val_mean_absolute_error: 0.0158
# Epoch 141/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4126e-04 - mean_absolute_error: 0.0128 - val_loss: 5.0981e-04 - val_mean_absolute_error: 0.0157
# Epoch 142/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3710e-04 - mean_absolute_error: 0.0125 - val_loss: 5.1613e-04 - val_mean_absolute_error: 0.0160
# Epoch 143/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.6377e-04 - mean_absolute_error: 0.0132 - val_loss: 8.2624e-04 - val_mean_absolute_error: 0.0237
# Epoch 144/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7728e-04 - mean_absolute_error: 0.0143 - val_loss: 5.3756e-04 - val_mean_absolute_error: 0.0166
# Epoch 145/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4155e-04 - mean_absolute_error: 0.0128 - val_loss: 7.6358e-04 - val_mean_absolute_error: 0.0223
# Epoch 146/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.5880e-04 - mean_absolute_error: 0.0182 - val_loss: 5.0829e-04 - val_mean_absolute_error: 0.0157
# Epoch 147/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5557e-04 - mean_absolute_error: 0.0130 - val_loss: 5.5277e-04 - val_mean_absolute_error: 0.0169
# Epoch 148/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8205e-04 - mean_absolute_error: 0.0145 - val_loss: 5.2658e-04 - val_mean_absolute_error: 0.0161
# Epoch 149/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4591e-04 - mean_absolute_error: 0.0127 - val_loss: 8.0202e-04 - val_mean_absolute_error: 0.0222
# Epoch 150/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.5786e-04 - mean_absolute_error: 0.0188 - val_loss: 5.1536e-04 - val_mean_absolute_error: 0.0157
# Epoch 151/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2544e-04 - mean_absolute_error: 0.0126 - val_loss: 5.1447e-04 - val_mean_absolute_error: 0.0157
# Epoch 152/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5650e-04 - mean_absolute_error: 0.0135 - val_loss: 5.7918e-04 - val_mean_absolute_error: 0.0175
# Epoch 153/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7347e-04 - mean_absolute_error: 0.0144 - val_loss: 6.9078e-04 - val_mean_absolute_error: 0.0205
# Epoch 154/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3860e-04 - mean_absolute_error: 0.0134 - val_loss: 5.5497e-04 - val_mean_absolute_error: 0.0170
# Epoch 155/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4280e-04 - mean_absolute_error: 0.0128 - val_loss: 7.8140e-04 - val_mean_absolute_error: 0.0218
# Epoch 156/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5677e-04 - mean_absolute_error: 0.0135 - val_loss: 5.4566e-04 - val_mean_absolute_error: 0.0167
# Epoch 157/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3917e-04 - mean_absolute_error: 0.0128 - val_loss: 5.5852e-04 - val_mean_absolute_error: 0.0170
# Epoch 158/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6757e-04 - mean_absolute_error: 0.0135 - val_loss: 6.4310e-04 - val_mean_absolute_error: 0.0193
# Epoch 159/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7022e-04 - mean_absolute_error: 0.0138 - val_loss: 5.8308e-04 - val_mean_absolute_error: 0.0177
# Epoch 160/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8789e-04 - mean_absolute_error: 0.0139 - val_loss: 5.2641e-04 - val_mean_absolute_error: 0.0161
# Epoch 161/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3867e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0021 - val_mean_absolute_error: 0.0411
# Epoch 162/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.9968e-04 - mean_absolute_error: 0.0246 - val_loss: 5.1352e-04 - val_mean_absolute_error: 0.0155
# Epoch 163/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8592e-04 - mean_absolute_error: 0.0140 - val_loss: 9.4130e-04 - val_mean_absolute_error: 0.0259
# Epoch 164/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4189e-04 - mean_absolute_error: 0.0134 - val_loss: 6.5089e-04 - val_mean_absolute_error: 0.0190
# Epoch 165/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1569e-04 - mean_absolute_error: 0.0152 - val_loss: 7.3768e-04 - val_mean_absolute_error: 0.0208
# Epoch 166/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6017e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0010 - val_mean_absolute_error: 0.0263
# Epoch 167/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1838e-04 - mean_absolute_error: 0.0150 - val_loss: 5.1442e-04 - val_mean_absolute_error: 0.0157
# Epoch 168/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3390e-04 - mean_absolute_error: 0.0123 - val_loss: 5.1195e-04 - val_mean_absolute_error: 0.0156
# Epoch 169/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0363e-04 - mean_absolute_error: 0.0119 - val_loss: 5.1680e-04 - val_mean_absolute_error: 0.0157
# Epoch 170/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1195e-04 - mean_absolute_error: 0.0120 - val_loss: 5.4159e-04 - val_mean_absolute_error: 0.0165
# Epoch 171/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8947e-04 - mean_absolute_error: 0.0113 - val_loss: 5.1834e-04 - val_mean_absolute_error: 0.0157
# Epoch 172/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3375e-04 - mean_absolute_error: 0.0132 - val_loss: 5.2031e-04 - val_mean_absolute_error: 0.0160
# Epoch 173/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3576e-04 - mean_absolute_error: 0.0122 - val_loss: 5.3087e-04 - val_mean_absolute_error: 0.0162
# Epoch 174/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9129e-04 - mean_absolute_error: 0.0134 - val_loss: 8.9364e-04 - val_mean_absolute_error: 0.0241
# Epoch 175/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5825e-04 - mean_absolute_error: 0.0155 - val_loss: 5.2306e-04 - val_mean_absolute_error: 0.0160
# Epoch 176/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6058e-04 - mean_absolute_error: 0.0128 - val_loss: 6.8035e-04 - val_mean_absolute_error: 0.0204
# Epoch 177/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1522e-04 - mean_absolute_error: 0.0121 - val_loss: 6.2180e-04 - val_mean_absolute_error: 0.0188
# Epoch 178/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3719e-04 - mean_absolute_error: 0.0122 - val_loss: 6.0812e-04 - val_mean_absolute_error: 0.0181
# Epoch 179/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9839e-04 - mean_absolute_error: 0.0119 - val_loss: 5.9062e-04 - val_mean_absolute_error: 0.0177
# Epoch 180/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4593e-04 - mean_absolute_error: 0.0139 - val_loss: 5.5901e-04 - val_mean_absolute_error: 0.0170
# Epoch 181/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0272e-04 - mean_absolute_error: 0.0120 - val_loss: 5.1367e-04 - val_mean_absolute_error: 0.0157
# Epoch 182/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8458e-04 - mean_absolute_error: 0.0113 - val_loss: 5.4904e-04 - val_mean_absolute_error: 0.0168
# Epoch 183/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5048e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0019 - val_mean_absolute_error: 0.0383
# Epoch 184/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.7397e-04 - mean_absolute_error: 0.0195 - val_loss: 6.3437e-04 - val_mean_absolute_error: 0.0186
# Epoch 185/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6886e-04 - mean_absolute_error: 0.0137 - val_loss: 5.3125e-04 - val_mean_absolute_error: 0.0161
# Epoch 186/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0826e-04 - mean_absolute_error: 0.0120 - val_loss: 5.3871e-04 - val_mean_absolute_error: 0.0163
# Epoch 187/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1216e-04 - mean_absolute_error: 0.0119 - val_loss: 5.1782e-04 - val_mean_absolute_error: 0.0158
# Epoch 188/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0956e-04 - mean_absolute_error: 0.0126 - val_loss: 5.6411e-04 - val_mean_absolute_error: 0.0171
# Epoch 189/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.9223e-04 - mean_absolute_error: 0.0117 - val_loss: 5.2610e-04 - val_mean_absolute_error: 0.0161
# Epoch 190/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.6007e-04 - mean_absolute_error: 0.0110 - val_loss: 5.1712e-04 - val_mean_absolute_error: 0.0158
# Epoch 191/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1252e-04 - mean_absolute_error: 0.0129 - val_loss: 5.1580e-04 - val_mean_absolute_error: 0.0157
# Epoch 192/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1172e-04 - mean_absolute_error: 0.0122 - val_loss: 5.7617e-04 - val_mean_absolute_error: 0.0175
# Epoch 193/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9777e-04 - mean_absolute_error: 0.0118 - val_loss: 5.0839e-04 - val_mean_absolute_error: 0.0156
# Epoch 194/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0717e-04 - mean_absolute_error: 0.0118 - val_loss: 5.1149e-04 - val_mean_absolute_error: 0.0158
# Epoch 195/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2600e-04 - mean_absolute_error: 0.0124 - val_loss: 5.1234e-04 - val_mean_absolute_error: 0.0157
# Epoch 196/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1317e-04 - mean_absolute_error: 0.0118 - val_loss: 5.2182e-04 - val_mean_absolute_error: 0.0161
# Epoch 197/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9922e-04 - mean_absolute_error: 0.0122 - val_loss: 5.1476e-04 - val_mean_absolute_error: 0.0159
# Epoch 198/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4802e-04 - mean_absolute_error: 0.0133 - val_loss: 5.3711e-04 - val_mean_absolute_error: 0.0165
# Epoch 199/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3563e-04 - mean_absolute_error: 0.0125 - val_loss: 5.4026e-04 - val_mean_absolute_error: 0.0166
# Epoch 200/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.1621e-04 - mean_absolute_error: 0.0121 - val_loss: 6.1523e-04 - val_mean_absolute_error: 0.0183

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.3788e-04 - mean_absolute_error: 0.0228
# Test Loss: [0.0006152339628897607, 0.018330905586481094]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 239
# 250

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 1114775.139599932
# RMSE: 1055.8291242430907
# MAE: 750.4605861009414
# MAPE: 2.3270561749009886 %
#
# Model evalution on validate set
# MSE: 705683.7510551121
# RMSE: 840.0498503393189
# MAE: 627.555910326087
# MAPE: 1.6185780925392035 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
y_pred_30_days
# Out:
# array([[40851.445],
#        [40808.406],
#        [40876.293],
#        [40888.51 ],
#        [40905.418],
#        [40906.31 ],
#        [40908.867],
#        [40909.344],
#        [40909.785],
#        [40909.875],
#        [40909.953],
#        [40909.973],
#        [40909.984],
#        [40909.99 ],
#        [40909.992],
#        [40909.992],
#        [40909.99 ],
#        [40909.99 ],
#        [40909.992],
#        [40909.992],
#        [40909.992],
#        [40909.992],
#        [40909.99 ],
#        [40909.992],
#        [40909.992],
#        [40909.992],
#        [40909.992],
#        [40909.992],
#        [40909.992],
#        [40909.992],
#        [40909.992]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
