# %% [markdown]
# # Model: LSTM (Long-Short Term Memory) - Stock Token: CMG - Test/Train/Vaildation: 70/20/10
# - Dataset: 1252 rows x 7 columns (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1055.83
# - MAE: 750.46
# - MAPE: 2.33 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 0

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830
# ...           ...
# 2024-05-27  59000
# 2024-05-28  62100
# 2024-05-29  60000
# 2024-05-30  59200
# 2024-05-31  60900
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((908, 10), (908,), (251, 10), (251,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64, return_sequences=True),
        LSTM(32),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 10, 64)         │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 29,345 (114.63 KB)
#  Trainable params: 29,345 (114.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_data=(X_test, y_test),
)
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - loss: 0.0283 - mean_absolute_error: 0.1219 - val_loss: 0.0047 - val_mean_absolute_error: 0.0652
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - mean_absolute_error: 0.0280 - val_loss: 5.5191e-04 - val_mean_absolute_error: 0.0178
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.2098e-04 - mean_absolute_error: 0.0176 - val_loss: 4.4077e-04 - val_mean_absolute_error: 0.0149
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.0907e-04 - mean_absolute_error: 0.0176 - val_loss: 4.3138e-04 - val_mean_absolute_error: 0.0155
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.0514e-04 - mean_absolute_error: 0.0173 - val_loss: 4.1527e-04 - val_mean_absolute_error: 0.0146
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.1131e-04 - mean_absolute_error: 0.0182 - val_loss: 3.9741e-04 - val_mean_absolute_error: 0.0144
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.2150e-04 - mean_absolute_error: 0.0161 - val_loss: 5.3563e-04 - val_mean_absolute_error: 0.0170
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.2889e-04 - mean_absolute_error: 0.0167 - val_loss: 3.9577e-04 - val_mean_absolute_error: 0.0142
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.2119e-04 - mean_absolute_error: 0.0158 - val_loss: 4.1281e-04 - val_mean_absolute_error: 0.0160
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.6480e-04 - mean_absolute_error: 0.0167 - val_loss: 3.7811e-04 - val_mean_absolute_error: 0.0149
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.9803e-04 - mean_absolute_error: 0.0161 - val_loss: 3.8819e-04 - val_mean_absolute_error: 0.0140
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.3193e-04 - mean_absolute_error: 0.0161 - val_loss: 4.4438e-04 - val_mean_absolute_error: 0.0153
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.9283e-04 - mean_absolute_error: 0.0175 - val_loss: 8.6752e-04 - val_mean_absolute_error: 0.0247
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.4063e-04 - mean_absolute_error: 0.0182 - val_loss: 4.1916e-04 - val_mean_absolute_error: 0.0166
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.7836e-04 - mean_absolute_error: 0.0181 - val_loss: 4.0046e-04 - val_mean_absolute_error: 0.0162
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.8987e-04 - mean_absolute_error: 0.0159 - val_loss: 3.7352e-04 - val_mean_absolute_error: 0.0138
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.4314e-04 - mean_absolute_error: 0.0167 - val_loss: 3.1318e-04 - val_mean_absolute_error: 0.0128
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.4195e-04 - mean_absolute_error: 0.0165 - val_loss: 3.7646e-04 - val_mean_absolute_error: 0.0139
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.9711e-04 - mean_absolute_error: 0.0157 - val_loss: 2.9933e-04 - val_mean_absolute_error: 0.0132
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.0912e-04 - mean_absolute_error: 0.0145 - val_loss: 5.2170e-04 - val_mean_absolute_error: 0.0177
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.0686e-04 - mean_absolute_error: 0.0145 - val_loss: 4.1574e-04 - val_mean_absolute_error: 0.0151
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.2580e-04 - mean_absolute_error: 0.0144 - val_loss: 3.0372e-04 - val_mean_absolute_error: 0.0139
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.9864e-04 - mean_absolute_error: 0.0144 - val_loss: 2.9308e-04 - val_mean_absolute_error: 0.0122
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.2180e-04 - mean_absolute_error: 0.0149 - val_loss: 3.8133e-04 - val_mean_absolute_error: 0.0144
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.4754e-04 - mean_absolute_error: 0.0155 - val_loss: 4.4503e-04 - val_mean_absolute_error: 0.0181
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.9569e-04 - mean_absolute_error: 0.0147 - val_loss: 4.8364e-04 - val_mean_absolute_error: 0.0172
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 3.6001e-04 - mean_absolute_error: 0.0134 - val_loss: 2.3694e-04 - val_mean_absolute_error: 0.0113
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.2733e-04 - mean_absolute_error: 0.0129 - val_loss: 2.5028e-04 - val_mean_absolute_error: 0.0114
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 3.2844e-04 - mean_absolute_error: 0.0131 - val_loss: 2.2784e-04 - val_mean_absolute_error: 0.0115
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 3.5467e-04 - mean_absolute_error: 0.0137 - val_loss: 5.3660e-04 - val_mean_absolute_error: 0.0189
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.1963e-04 - mean_absolute_error: 0.0145 - val_loss: 2.3509e-04 - val_mean_absolute_error: 0.0120
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.0284e-04 - mean_absolute_error: 0.0124 - val_loss: 2.3263e-04 - val_mean_absolute_error: 0.0111
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.9893e-04 - mean_absolute_error: 0.0123 - val_loss: 2.2902e-04 - val_mean_absolute_error: 0.0110
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.2272e-04 - mean_absolute_error: 0.0126 - val_loss: 2.1263e-04 - val_mean_absolute_error: 0.0111
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 3.2505e-04 - mean_absolute_error: 0.0133 - val_loss: 3.3136e-04 - val_mean_absolute_error: 0.0138
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.8546e-04 - mean_absolute_error: 0.0121 - val_loss: 2.0587e-04 - val_mean_absolute_error: 0.0107
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 3.0148e-04 - mean_absolute_error: 0.0124 - val_loss: 5.4334e-04 - val_mean_absolute_error: 0.0208
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 3.8008e-04 - mean_absolute_error: 0.0140 - val_loss: 4.3445e-04 - val_mean_absolute_error: 0.0167
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.9448e-04 - mean_absolute_error: 0.0121 - val_loss: 4.3170e-04 - val_mean_absolute_error: 0.0167
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 3.5220e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0012 - val_mean_absolute_error: 0.0308
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.6308e-04 - mean_absolute_error: 0.0153 - val_loss: 2.6132e-04 - val_mean_absolute_error: 0.0118
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.3041e-04 - mean_absolute_error: 0.0130 - val_loss: 8.7023e-04 - val_mean_absolute_error: 0.0262
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.4769e-04 - mean_absolute_error: 0.0138 - val_loss: 1.9362e-04 - val_mean_absolute_error: 0.0104
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.1190e-04 - mean_absolute_error: 0.0127 - val_loss: 2.0889e-04 - val_mean_absolute_error: 0.0104
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.0266e-04 - mean_absolute_error: 0.0127 - val_loss: 2.4743e-04 - val_mean_absolute_error: 0.0129
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.1794e-04 - mean_absolute_error: 0.0128 - val_loss: 3.2025e-04 - val_mean_absolute_error: 0.0139
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.9388e-04 - mean_absolute_error: 0.0122 - val_loss: 4.9048e-04 - val_mean_absolute_error: 0.0186
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.7480e-04 - mean_absolute_error: 0.0118 - val_loss: 2.1886e-04 - val_mean_absolute_error: 0.0107
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.4611e-04 - mean_absolute_error: 0.0112 - val_loss: 1.8664e-04 - val_mean_absolute_error: 0.0103
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.9879e-04 - mean_absolute_error: 0.0122 - val_loss: 1.9776e-04 - val_mean_absolute_error: 0.0101
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.5973e-04 - mean_absolute_error: 0.0115 - val_loss: 2.9681e-04 - val_mean_absolute_error: 0.0134
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.6957e-04 - mean_absolute_error: 0.0117 - val_loss: 2.4003e-04 - val_mean_absolute_error: 0.0115
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.5152e-04 - mean_absolute_error: 0.0112 - val_loss: 1.8586e-04 - val_mean_absolute_error: 0.0103
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.5332e-04 - mean_absolute_error: 0.0111 - val_loss: 2.3920e-04 - val_mean_absolute_error: 0.0115
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.7654e-04 - mean_absolute_error: 0.0118 - val_loss: 2.7896e-04 - val_mean_absolute_error: 0.0130
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.6135e-04 - mean_absolute_error: 0.0115 - val_loss: 4.1893e-04 - val_mean_absolute_error: 0.0171
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.6306e-04 - mean_absolute_error: 0.0115 - val_loss: 1.7754e-04 - val_mean_absolute_error: 0.0095
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.5924e-04 - mean_absolute_error: 0.0116 - val_loss: 2.2586e-04 - val_mean_absolute_error: 0.0121
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.6231e-04 - mean_absolute_error: 0.0113 - val_loss: 2.0282e-04 - val_mean_absolute_error: 0.0112
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.3532e-04 - mean_absolute_error: 0.0108 - val_loss: 1.9007e-04 - val_mean_absolute_error: 0.0099
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.4599e-04 - mean_absolute_error: 0.0107 - val_loss: 1.6990e-04 - val_mean_absolute_error: 0.0093
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.3879e-04 - mean_absolute_error: 0.0106 - val_loss: 1.7366e-04 - val_mean_absolute_error: 0.0099
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.5680e-04 - mean_absolute_error: 0.0112 - val_loss: 1.6203e-04 - val_mean_absolute_error: 0.0093
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 2.3089e-04 - mean_absolute_error: 0.0105 - val_loss: 2.5869e-04 - val_mean_absolute_error: 0.0126
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.2188e-04 - mean_absolute_error: 0.0105 - val_loss: 1.6583e-04 - val_mean_absolute_error: 0.0095
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 2.4100e-04 - mean_absolute_error: 0.0112 - val_loss: 2.6023e-04 - val_mean_absolute_error: 0.0127
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.0361e-04 - mean_absolute_error: 0.0127 - val_loss: 2.6732e-04 - val_mean_absolute_error: 0.0130
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.2837e-04 - mean_absolute_error: 0.0107 - val_loss: 3.6314e-04 - val_mean_absolute_error: 0.0160
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.4354e-04 - mean_absolute_error: 0.0111 - val_loss: 1.5811e-04 - val_mean_absolute_error: 0.0089
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.2646e-04 - mean_absolute_error: 0.0107 - val_loss: 2.2237e-04 - val_mean_absolute_error: 0.0120
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.4895e-04 - mean_absolute_error: 0.0113 - val_loss: 3.1786e-04 - val_mean_absolute_error: 0.0153
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.4543e-04 - mean_absolute_error: 0.0114 - val_loss: 1.6892e-04 - val_mean_absolute_error: 0.0098
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.0793e-04 - mean_absolute_error: 0.0103 - val_loss: 1.6964e-04 - val_mean_absolute_error: 0.0094
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.2910e-04 - mean_absolute_error: 0.0107 - val_loss: 1.5925e-04 - val_mean_absolute_error: 0.0093
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.4893e-04 - mean_absolute_error: 0.0112 - val_loss: 5.5680e-04 - val_mean_absolute_error: 0.0215
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 2.9352e-04 - mean_absolute_error: 0.0127 - val_loss: 1.5740e-04 - val_mean_absolute_error: 0.0092
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.9813e-04 - mean_absolute_error: 0.0100 - val_loss: 2.5310e-04 - val_mean_absolute_error: 0.0131
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.2153e-04 - mean_absolute_error: 0.0106 - val_loss: 2.2317e-04 - val_mean_absolute_error: 0.0118
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.8409e-04 - mean_absolute_error: 0.0094 - val_loss: 1.9859e-04 - val_mean_absolute_error: 0.0110
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.0730e-04 - mean_absolute_error: 0.0102 - val_loss: 1.6034e-04 - val_mean_absolute_error: 0.0094
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.9821e-04 - mean_absolute_error: 0.0099 - val_loss: 1.3985e-04 - val_mean_absolute_error: 0.0084
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.2506e-04 - mean_absolute_error: 0.0106 - val_loss: 1.3775e-04 - val_mean_absolute_error: 0.0083
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.9271e-04 - mean_absolute_error: 0.0097 - val_loss: 1.4878e-04 - val_mean_absolute_error: 0.0088
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.0935e-04 - mean_absolute_error: 0.0103 - val_loss: 1.4918e-04 - val_mean_absolute_error: 0.0088
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 2.0265e-04 - mean_absolute_error: 0.0102 - val_loss: 2.5162e-04 - val_mean_absolute_error: 0.0130
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.8027e-04 - mean_absolute_error: 0.0097 - val_loss: 1.8061e-04 - val_mean_absolute_error: 0.0103
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.3564e-04 - mean_absolute_error: 0.0113 - val_loss: 1.5899e-04 - val_mean_absolute_error: 0.0092
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8696e-04 - mean_absolute_error: 0.0096 - val_loss: 1.3205e-04 - val_mean_absolute_error: 0.0080
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.0684e-04 - mean_absolute_error: 0.0104 - val_loss: 1.7589e-04 - val_mean_absolute_error: 0.0101
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.9770e-04 - mean_absolute_error: 0.0101 - val_loss: 1.9799e-04 - val_mean_absolute_error: 0.0110
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7456e-04 - mean_absolute_error: 0.0091 - val_loss: 1.5632e-04 - val_mean_absolute_error: 0.0092
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.9349e-04 - mean_absolute_error: 0.0100 - val_loss: 1.2990e-04 - val_mean_absolute_error: 0.0080
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.8856e-04 - mean_absolute_error: 0.0097 - val_loss: 1.4329e-04 - val_mean_absolute_error: 0.0086
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.0086e-04 - mean_absolute_error: 0.0098 - val_loss: 1.2875e-04 - val_mean_absolute_error: 0.0079
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6680e-04 - mean_absolute_error: 0.0090 - val_loss: 1.3833e-04 - val_mean_absolute_error: 0.0084
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7349e-04 - mean_absolute_error: 0.0093 - val_loss: 1.6934e-04 - val_mean_absolute_error: 0.0098
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 2.0745e-04 - mean_absolute_error: 0.0102 - val_loss: 1.8501e-04 - val_mean_absolute_error: 0.0105
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.7803e-04 - mean_absolute_error: 0.0095 - val_loss: 1.4801e-04 - val_mean_absolute_error: 0.0089
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.8745e-04 - mean_absolute_error: 0.0097 - val_loss: 1.2662e-04 - val_mean_absolute_error: 0.0079
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.8839e-04 - mean_absolute_error: 0.0096 - val_loss: 1.3891e-04 - val_mean_absolute_error: 0.0085
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.8069e-04 - mean_absolute_error: 0.0093 - val_loss: 1.5809e-04 - val_mean_absolute_error: 0.0093
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.7168e-04 - mean_absolute_error: 0.0092 - val_loss: 1.4764e-04 - val_mean_absolute_error: 0.0089
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.8400e-04 - mean_absolute_error: 0.0094 - val_loss: 1.7875e-04 - val_mean_absolute_error: 0.0103
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 2.0414e-04 - mean_absolute_error: 0.0100 - val_loss: 2.2890e-04 - val_mean_absolute_error: 0.0124
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.7477e-04 - mean_absolute_error: 0.0093 - val_loss: 1.4803e-04 - val_mean_absolute_error: 0.0089
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.6083e-04 - mean_absolute_error: 0.0089 - val_loss: 1.2987e-04 - val_mean_absolute_error: 0.0081
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 2.2861e-04 - mean_absolute_error: 0.0107 - val_loss: 1.2424e-04 - val_mean_absolute_error: 0.0079
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.9542e-04 - mean_absolute_error: 0.0097 - val_loss: 1.2898e-04 - val_mean_absolute_error: 0.0081
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.0544e-04 - mean_absolute_error: 0.0099 - val_loss: 1.9973e-04 - val_mean_absolute_error: 0.0113
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 2.0110e-04 - mean_absolute_error: 0.0101 - val_loss: 1.2728e-04 - val_mean_absolute_error: 0.0081
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 1.7985e-04 - mean_absolute_error: 0.0096 - val_loss: 2.2246e-04 - val_mean_absolute_error: 0.0122
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.0128e-04 - mean_absolute_error: 0.0103 - val_loss: 1.5914e-04 - val_mean_absolute_error: 0.0095
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.6549e-04 - mean_absolute_error: 0.0091 - val_loss: 1.2842e-04 - val_mean_absolute_error: 0.0082
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.9062e-04 - mean_absolute_error: 0.0097 - val_loss: 1.7010e-04 - val_mean_absolute_error: 0.0100
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.6634e-04 - mean_absolute_error: 0.0092 - val_loss: 1.2335e-04 - val_mean_absolute_error: 0.0079
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.6855e-04 - mean_absolute_error: 0.0091 - val_loss: 2.6950e-04 - val_mean_absolute_error: 0.0138
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.9584e-04 - mean_absolute_error: 0.0098 - val_loss: 1.2759e-04 - val_mean_absolute_error: 0.0082
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.6516e-04 - mean_absolute_error: 0.0089 - val_loss: 1.7855e-04 - val_mean_absolute_error: 0.0104
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.7732e-04 - mean_absolute_error: 0.0095 - val_loss: 1.4111e-04 - val_mean_absolute_error: 0.0088
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7991e-04 - mean_absolute_error: 0.0091 - val_loss: 1.2788e-04 - val_mean_absolute_error: 0.0082
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.5838e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2806e-04 - val_mean_absolute_error: 0.0082
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.8583e-04 - mean_absolute_error: 0.0098 - val_loss: 2.4050e-04 - val_mean_absolute_error: 0.0128
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.7917e-04 - mean_absolute_error: 0.0093 - val_loss: 1.2355e-04 - val_mean_absolute_error: 0.0080
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.5495e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3407e-04 - val_mean_absolute_error: 0.0086
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.7078e-04 - mean_absolute_error: 0.0093 - val_loss: 1.8311e-04 - val_mean_absolute_error: 0.0107
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6329e-04 - mean_absolute_error: 0.0088 - val_loss: 1.3798e-04 - val_mean_absolute_error: 0.0085
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.5428e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2997e-04 - val_mean_absolute_error: 0.0082
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.5581e-04 - mean_absolute_error: 0.0088 - val_loss: 1.3315e-04 - val_mean_absolute_error: 0.0084
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.5095e-04 - mean_absolute_error: 0.0087 - val_loss: 2.0226e-04 - val_mean_absolute_error: 0.0113
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6423e-04 - mean_absolute_error: 0.0089 - val_loss: 1.5207e-04 - val_mean_absolute_error: 0.0092
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.9356e-04 - mean_absolute_error: 0.0102 - val_loss: 1.5954e-04 - val_mean_absolute_error: 0.0095
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.6831e-04 - mean_absolute_error: 0.0091 - val_loss: 1.2401e-04 - val_mean_absolute_error: 0.0079
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.5977e-04 - mean_absolute_error: 0.0088 - val_loss: 1.3160e-04 - val_mean_absolute_error: 0.0083
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 1.9248e-04 - mean_absolute_error: 0.0098 - val_loss: 1.2018e-04 - val_mean_absolute_error: 0.0079
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.7371e-04 - mean_absolute_error: 0.0095 - val_loss: 1.5650e-04 - val_mean_absolute_error: 0.0094
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7225e-04 - mean_absolute_error: 0.0091 - val_loss: 2.5428e-04 - val_mean_absolute_error: 0.0133
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 1.6888e-04 - mean_absolute_error: 0.0092 - val_loss: 1.5449e-04 - val_mean_absolute_error: 0.0096
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.8392e-04 - mean_absolute_error: 0.0095 - val_loss: 2.3471e-04 - val_mean_absolute_error: 0.0126
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.8039e-04 - mean_absolute_error: 0.0095 - val_loss: 1.2050e-04 - val_mean_absolute_error: 0.0080
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.5973e-04 - mean_absolute_error: 0.0089 - val_loss: 1.4275e-04 - val_mean_absolute_error: 0.0088
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6276e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2400e-04 - val_mean_absolute_error: 0.0083
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5868e-04 - mean_absolute_error: 0.0092 - val_loss: 2.9463e-04 - val_mean_absolute_error: 0.0146
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.9350e-04 - mean_absolute_error: 0.0096 - val_loss: 4.5975e-04 - val_mean_absolute_error: 0.0191
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 2.3338e-04 - mean_absolute_error: 0.0113 - val_loss: 1.2303e-04 - val_mean_absolute_error: 0.0079
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.5530e-04 - mean_absolute_error: 0.0084 - val_loss: 1.4381e-04 - val_mean_absolute_error: 0.0089
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 1.6544e-04 - mean_absolute_error: 0.0092 - val_loss: 1.3968e-04 - val_mean_absolute_error: 0.0087
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.6232e-04 - mean_absolute_error: 0.0089 - val_loss: 1.3032e-04 - val_mean_absolute_error: 0.0083
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5633e-04 - mean_absolute_error: 0.0086 - val_loss: 1.8629e-04 - val_mean_absolute_error: 0.0107
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7712e-04 - mean_absolute_error: 0.0093 - val_loss: 2.0247e-04 - val_mean_absolute_error: 0.0113
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5189e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2496e-04 - val_mean_absolute_error: 0.0081
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.4593e-04 - mean_absolute_error: 0.0085 - val_loss: 1.9885e-04 - val_mean_absolute_error: 0.0111
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7383e-04 - mean_absolute_error: 0.0095 - val_loss: 1.7661e-04 - val_mean_absolute_error: 0.0103
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.6162e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2849e-04 - val_mean_absolute_error: 0.0085
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.6551e-04 - mean_absolute_error: 0.0092 - val_loss: 1.2786e-04 - val_mean_absolute_error: 0.0085
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.4989e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3247e-04 - val_mean_absolute_error: 0.0087
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6375e-04 - mean_absolute_error: 0.0092 - val_loss: 1.8143e-04 - val_mean_absolute_error: 0.0105
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5189e-04 - mean_absolute_error: 0.0084 - val_loss: 1.5209e-04 - val_mean_absolute_error: 0.0092
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5804e-04 - mean_absolute_error: 0.0087 - val_loss: 1.6991e-04 - val_mean_absolute_error: 0.0100
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.6367e-04 - mean_absolute_error: 0.0088 - val_loss: 4.1957e-04 - val_mean_absolute_error: 0.0180
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.0805e-04 - mean_absolute_error: 0.0102 - val_loss: 1.3467e-04 - val_mean_absolute_error: 0.0084
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.7177e-04 - mean_absolute_error: 0.0089 - val_loss: 1.3932e-04 - val_mean_absolute_error: 0.0090
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.3298e-04 - mean_absolute_error: 0.0082 - val_loss: 1.5488e-04 - val_mean_absolute_error: 0.0093
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4520e-04 - mean_absolute_error: 0.0080 - val_loss: 1.4165e-04 - val_mean_absolute_error: 0.0088
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4504e-04 - mean_absolute_error: 0.0083 - val_loss: 2.1075e-04 - val_mean_absolute_error: 0.0116
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3480e-04 - mean_absolute_error: 0.0079 - val_loss: 1.3917e-04 - val_mean_absolute_error: 0.0087
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6742e-04 - mean_absolute_error: 0.0090 - val_loss: 1.2449e-04 - val_mean_absolute_error: 0.0084
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4844e-04 - mean_absolute_error: 0.0083 - val_loss: 1.6260e-04 - val_mean_absolute_error: 0.0096
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.4719e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3992e-04 - val_mean_absolute_error: 0.0091
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.4262e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2116e-04 - val_mean_absolute_error: 0.0080
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.4838e-04 - mean_absolute_error: 0.0083 - val_loss: 1.8291e-04 - val_mean_absolute_error: 0.0105
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5867e-04 - mean_absolute_error: 0.0084 - val_loss: 1.4210e-04 - val_mean_absolute_error: 0.0091
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6905e-04 - mean_absolute_error: 0.0092 - val_loss: 1.2190e-04 - val_mean_absolute_error: 0.0082
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.5017e-04 - mean_absolute_error: 0.0086 - val_loss: 1.6480e-04 - val_mean_absolute_error: 0.0097
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.6302e-04 - mean_absolute_error: 0.0086 - val_loss: 1.4183e-04 - val_mean_absolute_error: 0.0091
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7810e-04 - mean_absolute_error: 0.0092 - val_loss: 1.2633e-04 - val_mean_absolute_error: 0.0082
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.3431e-04 - mean_absolute_error: 0.0079 - val_loss: 1.4915e-04 - val_mean_absolute_error: 0.0095
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6727e-04 - mean_absolute_error: 0.0091 - val_loss: 1.8906e-04 - val_mean_absolute_error: 0.0107
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.4638e-04 - mean_absolute_error: 0.0080 - val_loss: 1.3779e-04 - val_mean_absolute_error: 0.0086
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4658e-04 - mean_absolute_error: 0.0081 - val_loss: 1.4025e-04 - val_mean_absolute_error: 0.0087
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.5636e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2241e-04 - val_mean_absolute_error: 0.0083
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.5835e-04 - mean_absolute_error: 0.0088 - val_loss: 1.6779e-04 - val_mean_absolute_error: 0.0103
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.8167e-04 - mean_absolute_error: 0.0093 - val_loss: 1.2346e-04 - val_mean_absolute_error: 0.0084
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.7234e-04 - mean_absolute_error: 0.0093 - val_loss: 1.8058e-04 - val_mean_absolute_error: 0.0104
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4528e-04 - mean_absolute_error: 0.0083 - val_loss: 1.3921e-04 - val_mean_absolute_error: 0.0091
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.6922e-04 - mean_absolute_error: 0.0089 - val_loss: 1.2184e-04 - val_mean_absolute_error: 0.0082
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7110e-04 - mean_absolute_error: 0.0090 - val_loss: 2.0377e-04 - val_mean_absolute_error: 0.0113
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3542e-04 - mean_absolute_error: 0.0078 - val_loss: 1.2137e-04 - val_mean_absolute_error: 0.0082
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3317e-04 - mean_absolute_error: 0.0079 - val_loss: 1.4756e-04 - val_mean_absolute_error: 0.0090
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.5701e-04 - mean_absolute_error: 0.0087 - val_loss: 1.8126e-04 - val_mean_absolute_error: 0.0104
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.8473e-04 - mean_absolute_error: 0.0099 - val_loss: 1.3218e-04 - val_mean_absolute_error: 0.0085
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.4761e-04 - mean_absolute_error: 0.0084 - val_loss: 1.8769e-04 - val_mean_absolute_error: 0.0110
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.8045e-04 - mean_absolute_error: 0.0097 - val_loss: 1.3854e-04 - val_mean_absolute_error: 0.0086
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.5988e-04 - mean_absolute_error: 0.0084 - val_loss: 1.7213e-04 - val_mean_absolute_error: 0.0105
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2322e-04 - mean_absolute_error: 0.0075 - val_loss: 1.6585e-04 - val_mean_absolute_error: 0.0098
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.5844e-04 - mean_absolute_error: 0.0089 - val_loss: 1.7526e-04 - val_mean_absolute_error: 0.0102
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3649e-04 - mean_absolute_error: 0.0077 - val_loss: 2.0082e-04 - val_mean_absolute_error: 0.0115
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.6690e-04 - mean_absolute_error: 0.0087 - val_loss: 2.1886e-04 - val_mean_absolute_error: 0.0119
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.2192e-04 - mean_absolute_error: 0.0076 - val_loss: 1.2067e-04 - val_mean_absolute_error: 0.0081
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2855e-04 - mean_absolute_error: 0.0079 - val_loss: 1.6367e-04 - val_mean_absolute_error: 0.0097
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4587e-04 - mean_absolute_error: 0.0082 - val_loss: 2.0562e-04 - val_mean_absolute_error: 0.0117

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.4391e-04 - mean_absolute_error: 0.0129
# Test Loss: [0.00020562279678415507, 0.011707878671586514]

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 789969.4423189657
# RMSE: 888.8022515267194
# MAE: 703.1573938620518
# MAPE: 2.1052794144470295 %
#
# Model evalution on validate set
# MSE: 4653160.056336332
# RMSE: 2157.118461359119
# MAE: 1391.8543065599174
# MAPE: 2.875557784129308 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 833ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step

# %%
y_pred_30_days
# Out:
# array([[60834.383],
#        [60198.375],
#        [61063.242],
#        [60132.26 ],
#        [61050.883],
#        [60120.6  ],
#        [61073.27 ],
#        [60104.49 ],
#        [61089.75 ],
#        [60086.707],
#        [61107.445],
#        [60068.55 ],
#        [61125.703],
#        [60049.71 ],
#        [61144.61 ],
#        [60030.203],
#        [61164.16 ],
#        [60010.004],
#        [61184.39 ],
#        [59989.094],
#        [61205.332],
#        [59967.45 ],
#        [61226.996],
#        [59945.047],
#        [61249.406],
#        [59921.848],
#        [61272.58 ],
#        [59897.85 ],
#        [61296.547],
#        [59873.016],
#        [61321.33 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
