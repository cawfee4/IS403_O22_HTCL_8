# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

plt.style.use('default')

# %% [markdown]
# ## 1. Data preprocessing

# %%
split_type = [0.8,0.7,0.9]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2 # ITD
split = 0

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)
df
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170
# ...           ...
# 2024-05-27  11300
# 2024-05-28  12050
# 2024-05-29  12600
# 2024-05-30  12500
# 2024-05-31  12700
#
# [1313 rows x 1 columns]

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        6900
# 1        7100
# 2        7100
# 3        7170
# 4        7170
#         ...
# 1308    11300
# 1309    12050
# 1310    12600
# 1311    12500
# 1312    12700
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using neural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split] * len(df_scaled))
test_size = len(df_scaled) - train_size

# %%
# Splitting data into train, test set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size:]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1039, 10), (1039,), (252, 10), (252,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Input

# Initialize LSTM model
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        LSTM(64),
        Dense(1),  # activation default is linear
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 64)             │        16,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 16,961 (66.25 KB)
#  Trainable params: 16,961 (66.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="mse", metrics=["mean_absolute_error"])

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Train the model
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE
)
# Out:
# Epoch 1/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.1065 - mean_absolute_error: 0.2382
# Epoch 2/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - mean_absolute_error: 0.0547
# Epoch 3/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0020 - mean_absolute_error: 0.0300
# Epoch 4/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017 - mean_absolute_error: 0.0280
# Epoch 5/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0019 - mean_absolute_error: 0.0285
# Epoch 6/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0269
# Epoch 7/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015 - mean_absolute_error: 0.0252
# Epoch 8/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0260
# Epoch 9/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0014 - mean_absolute_error: 0.0236
# Epoch 10/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mean_absolute_error: 0.0252
# Epoch 11/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0226
# Epoch 12/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0236
# Epoch 13/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0223
# Epoch 14/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015 - mean_absolute_error: 0.0235
# Epoch 15/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0224
# Epoch 16/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0224
# Epoch 17/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0013 - mean_absolute_error: 0.0231
# Epoch 18/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0204
# Epoch 19/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0213
# Epoch 20/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0213
# Epoch 21/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0012 - mean_absolute_error: 0.0220
# Epoch 22/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7612e-04 - mean_absolute_error: 0.0197
# Epoch 23/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0203
# Epoch 24/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0199
# Epoch 25/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0010 - mean_absolute_error: 0.0204
# Epoch 26/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.8051e-04 - mean_absolute_error: 0.0192
# Epoch 27/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.3479e-04 - mean_absolute_error: 0.0192
# Epoch 28/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.7976e-04 - mean_absolute_error: 0.0185
# Epoch 29/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.5647e-04 - mean_absolute_error: 0.0176
# Epoch 30/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7788e-04 - mean_absolute_error: 0.0185
# Epoch 31/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7281e-04 - mean_absolute_error: 0.0192
# Epoch 32/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9426e-04 - mean_absolute_error: 0.0184
# Epoch 33/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0221
# Epoch 34/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011 - mean_absolute_error: 0.0211
# Epoch 35/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.5601e-04 - mean_absolute_error: 0.0182
# Epoch 36/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6495e-04 - mean_absolute_error: 0.0176
# Epoch 37/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.2707e-04 - mean_absolute_error: 0.0186
# Epoch 38/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.4102e-04 - mean_absolute_error: 0.0198
# Epoch 39/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.9961e-04 - mean_absolute_error: 0.0199
# Epoch 40/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1846e-04 - mean_absolute_error: 0.0171
# Epoch 41/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.2581e-04 - mean_absolute_error: 0.0187
# Epoch 42/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.1341e-04 - mean_absolute_error: 0.0174
# Epoch 43/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0402e-04 - mean_absolute_error: 0.0167
# Epoch 44/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.0147e-04 - mean_absolute_error: 0.0165
# Epoch 45/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.5239e-04 - mean_absolute_error: 0.0169
# Epoch 46/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2663e-04 - mean_absolute_error: 0.0177
# Epoch 47/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.1391e-04 - mean_absolute_error: 0.0193
# Epoch 48/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3596e-04 - mean_absolute_error: 0.0162
# Epoch 49/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.2026e-04 - mean_absolute_error: 0.0177
# Epoch 50/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1768e-04 - mean_absolute_error: 0.0156
# Epoch 51/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8701e-04 - mean_absolute_error: 0.0163
# Epoch 52/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.3008e-04 - mean_absolute_error: 0.0175
# Epoch 53/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8171e-04 - mean_absolute_error: 0.0168
# Epoch 54/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4956e-04 - mean_absolute_error: 0.0159
# Epoch 55/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8671e-04 - mean_absolute_error: 0.0153
# Epoch 56/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8925e-04 - mean_absolute_error: 0.0157
# Epoch 57/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8063e-04 - mean_absolute_error: 0.0173
# Epoch 58/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0422e-04 - mean_absolute_error: 0.0162
# Epoch 59/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0540e-04 - mean_absolute_error: 0.0156
# Epoch 60/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.4563e-04 - mean_absolute_error: 0.0164
# Epoch 61/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7224e-04 - mean_absolute_error: 0.0157
# Epoch 62/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5892e-04 - mean_absolute_error: 0.0156
# Epoch 63/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5159e-04 - mean_absolute_error: 0.0154
# Epoch 64/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.7411e-04 - mean_absolute_error: 0.0155
# Epoch 65/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2721e-04 - mean_absolute_error: 0.0150
# Epoch 66/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5614e-04 - mean_absolute_error: 0.0152
# Epoch 67/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.6824e-04 - mean_absolute_error: 0.0151
# Epoch 68/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0602e-04 - mean_absolute_error: 0.0161
# Epoch 69/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6328e-04 - mean_absolute_error: 0.0160
# Epoch 70/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.8569e-04 - mean_absolute_error: 0.0147
# Epoch 71/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3379e-04 - mean_absolute_error: 0.0147
# Epoch 72/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1578e-04 - mean_absolute_error: 0.0149
# Epoch 73/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.1166e-04 - mean_absolute_error: 0.0156
# Epoch 74/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9570e-04 - mean_absolute_error: 0.0141
# Epoch 75/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3642e-04 - mean_absolute_error: 0.0149
# Epoch 76/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5112e-04 - mean_absolute_error: 0.0152
# Epoch 77/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8294e-04 - mean_absolute_error: 0.0143
# Epoch 78/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4978e-04 - mean_absolute_error: 0.0139
# Epoch 79/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5772e-04 - mean_absolute_error: 0.0159
# Epoch 80/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1916e-04 - mean_absolute_error: 0.0151
# Epoch 81/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1369e-04 - mean_absolute_error: 0.0143
# Epoch 82/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3768e-04 - mean_absolute_error: 0.0148
# Epoch 83/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0608e-04 - mean_absolute_error: 0.0142
# Epoch 84/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7681e-04 - mean_absolute_error: 0.0142
# Epoch 85/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8520e-04 - mean_absolute_error: 0.0145
# Epoch 86/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1028e-04 - mean_absolute_error: 0.0146
# Epoch 87/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0458e-04 - mean_absolute_error: 0.0145
# Epoch 88/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7501e-04 - mean_absolute_error: 0.0144
# Epoch 89/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.1608e-04 - mean_absolute_error: 0.0147
# Epoch 90/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3454e-04 - mean_absolute_error: 0.0138
# Epoch 91/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3625e-04 - mean_absolute_error: 0.0147
# Epoch 92/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9703e-04 - mean_absolute_error: 0.0141
# Epoch 93/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0072e-04 - mean_absolute_error: 0.0151
# Epoch 94/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.5465e-04 - mean_absolute_error: 0.0150
# Epoch 95/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.0929e-04 - mean_absolute_error: 0.0140
# Epoch 96/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7503e-04 - mean_absolute_error: 0.0137
# Epoch 97/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8543e-04 - mean_absolute_error: 0.0146
# Epoch 98/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9885e-04 - mean_absolute_error: 0.0144
# Epoch 99/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6612e-04 - mean_absolute_error: 0.0140
# Epoch 100/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8498e-04 - mean_absolute_error: 0.0141
# Epoch 101/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3569e-04 - mean_absolute_error: 0.0134
# Epoch 102/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.8224e-04 - mean_absolute_error: 0.0143
# Epoch 103/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4896e-04 - mean_absolute_error: 0.0134
# Epoch 104/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3465e-04 - mean_absolute_error: 0.0137
# Epoch 105/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6160e-04 - mean_absolute_error: 0.0141
# Epoch 106/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7117e-04 - mean_absolute_error: 0.0137
# Epoch 107/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4365e-04 - mean_absolute_error: 0.0139
# Epoch 108/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9387e-04 - mean_absolute_error: 0.0128
# Epoch 109/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4660e-04 - mean_absolute_error: 0.0135
# Epoch 110/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5936e-04 - mean_absolute_error: 0.0145
# Epoch 111/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3661e-04 - mean_absolute_error: 0.0142
# Epoch 112/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9072e-04 - mean_absolute_error: 0.0128
# Epoch 113/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8075e-04 - mean_absolute_error: 0.0127
# Epoch 114/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7184e-04 - mean_absolute_error: 0.0143
# Epoch 115/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2938e-04 - mean_absolute_error: 0.0131
# Epoch 116/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.5935e-04 - mean_absolute_error: 0.0137
# Epoch 117/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6449e-04 - mean_absolute_error: 0.0145
# Epoch 118/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2778e-04 - mean_absolute_error: 0.0134
# Epoch 119/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9703e-04 - mean_absolute_error: 0.0132
# Epoch 120/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8784e-04 - mean_absolute_error: 0.0129
# Epoch 121/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9767e-04 - mean_absolute_error: 0.0132
# Epoch 122/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1048e-04 - mean_absolute_error: 0.0132
# Epoch 123/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6897e-04 - mean_absolute_error: 0.0124
# Epoch 124/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3354e-04 - mean_absolute_error: 0.0140
# Epoch 125/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7496e-04 - mean_absolute_error: 0.0126
# Epoch 126/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6242e-04 - mean_absolute_error: 0.0122
# Epoch 127/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0334e-04 - mean_absolute_error: 0.0129
# Epoch 128/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2236e-04 - mean_absolute_error: 0.0135
# Epoch 129/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4152e-04 - mean_absolute_error: 0.0137
# Epoch 130/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6715e-04 - mean_absolute_error: 0.0127
# Epoch 131/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6887e-04 - mean_absolute_error: 0.0126
# Epoch 132/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4689e-04 - mean_absolute_error: 0.0121
# Epoch 133/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8133e-04 - mean_absolute_error: 0.0126
# Epoch 134/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6215e-04 - mean_absolute_error: 0.0143
# Epoch 135/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3213e-04 - mean_absolute_error: 0.0136
# Epoch 136/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8766e-04 - mean_absolute_error: 0.0126
# Epoch 137/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9961e-04 - mean_absolute_error: 0.0132
# Epoch 138/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6158e-04 - mean_absolute_error: 0.0122
# Epoch 139/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8708e-04 - mean_absolute_error: 0.0128
# Epoch 140/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2941e-04 - mean_absolute_error: 0.0141
# Epoch 141/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8596e-04 - mean_absolute_error: 0.0137
# Epoch 142/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3652e-04 - mean_absolute_error: 0.0122
# Epoch 143/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6880e-04 - mean_absolute_error: 0.0128
# Epoch 144/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6866e-04 - mean_absolute_error: 0.0128
# Epoch 145/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5786e-04 - mean_absolute_error: 0.0125
# Epoch 146/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2339e-04 - mean_absolute_error: 0.0140
# Epoch 147/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7788e-04 - mean_absolute_error: 0.0129
# Epoch 148/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5149e-04 - mean_absolute_error: 0.0127
# Epoch 149/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1943e-04 - mean_absolute_error: 0.0135
# Epoch 150/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2266e-04 - mean_absolute_error: 0.0132
# Epoch 151/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7164e-04 - mean_absolute_error: 0.0126
# Epoch 152/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6449e-04 - mean_absolute_error: 0.0126
# Epoch 153/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2543e-04 - mean_absolute_error: 0.0133
# Epoch 154/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6301e-04 - mean_absolute_error: 0.0122
# Epoch 155/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4657e-04 - mean_absolute_error: 0.0122
# Epoch 156/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5986e-04 - mean_absolute_error: 0.0126
# Epoch 157/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6690e-04 - mean_absolute_error: 0.0123
# Epoch 158/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4269e-04 - mean_absolute_error: 0.0122
# Epoch 159/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6850e-04 - mean_absolute_error: 0.0127
# Epoch 160/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8586e-04 - mean_absolute_error: 0.0130
# Epoch 161/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8257e-04 - mean_absolute_error: 0.0134
# Epoch 162/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7645e-04 - mean_absolute_error: 0.0126
# Epoch 163/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9433e-04 - mean_absolute_error: 0.0135
# Epoch 164/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0649e-04 - mean_absolute_error: 0.0140
# Epoch 165/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6137e-04 - mean_absolute_error: 0.0132
# Epoch 166/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7787e-04 - mean_absolute_error: 0.0129
# Epoch 167/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6725e-04 - mean_absolute_error: 0.0130
# Epoch 168/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9841e-04 - mean_absolute_error: 0.0133
# Epoch 169/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8398e-04 - mean_absolute_error: 0.0131
# Epoch 170/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9937e-04 - mean_absolute_error: 0.0132
# Epoch 171/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6660e-04 - mean_absolute_error: 0.0122
# Epoch 172/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6004e-04 - mean_absolute_error: 0.0125
# Epoch 173/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2501e-04 - mean_absolute_error: 0.0117
# Epoch 174/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4834e-04 - mean_absolute_error: 0.0123
# Epoch 175/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9737e-04 - mean_absolute_error: 0.0129
# Epoch 176/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4280e-04 - mean_absolute_error: 0.0119
# Epoch 177/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7777e-04 - mean_absolute_error: 0.0135
# Epoch 178/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4433e-04 - mean_absolute_error: 0.0120
# Epoch 179/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9020e-04 - mean_absolute_error: 0.0133
# Epoch 180/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3104e-04 - mean_absolute_error: 0.0118
# Epoch 181/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0618e-04 - mean_absolute_error: 0.0135
# Epoch 182/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2186e-04 - mean_absolute_error: 0.0136
# Epoch 183/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6963e-04 - mean_absolute_error: 0.0125
# Epoch 184/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7320e-04 - mean_absolute_error: 0.0131
# Epoch 185/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1881e-04 - mean_absolute_error: 0.0137
# Epoch 186/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7045e-04 - mean_absolute_error: 0.0124
# Epoch 187/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7531e-04 - mean_absolute_error: 0.0129
# Epoch 188/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6106e-04 - mean_absolute_error: 0.0123
# Epoch 189/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6398e-04 - mean_absolute_error: 0.0125
# Epoch 190/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9533e-04 - mean_absolute_error: 0.0135
# Epoch 191/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3290e-04 - mean_absolute_error: 0.0124
# Epoch 192/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2207e-04 - mean_absolute_error: 0.0117
# Epoch 193/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6178e-04 - mean_absolute_error: 0.0124
# Epoch 194/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9612e-04 - mean_absolute_error: 0.0128
# Epoch 195/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9413e-04 - mean_absolute_error: 0.0135
# Epoch 196/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1985e-04 - mean_absolute_error: 0.0141
# Epoch 197/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4771e-04 - mean_absolute_error: 0.0123
# Epoch 198/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5347e-04 - mean_absolute_error: 0.0124
# Epoch 199/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4739e-04 - mean_absolute_error: 0.0128
# Epoch 200/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3506e-04 - mean_absolute_error: 0.0123

# %% [markdown]
# ### Predicting with test set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Evaluate the model on test data
loss = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2134e-04 - mean_absolute_error: 0.0081
# Test Loss: [0.0001457008911529556, 0.008702260442078114]

# %%
# Splitting data into train, test set again to evaluate, because i shaped the data between 0 to 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 252
# 263

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)


def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f"MSE: {mse(y, y_pred)}")
    print(f"RMSE: {np.sqrt(mse(y, y_pred))}")
    print(f"MAE: {mae(y, y_pred)}")
    print(f"MAPE: {mape(y, y_pred) * 100} %")

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will less than 2 %(test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)
# Out:
# Model evalution on test set
# MSE: 72384.68258933794
# RMSE: 269.04401608164034
# MAE: 190.12191142733136
# MAPE: 1.8037069036100983 %

# %% [markdown]
# ## 4. Forecast the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(test_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
y_pred_30_days
# Out:
# array([[12811.887],
#        [12777.792],
#        [12807.784],
#        [12804.025],
#        [12807.213],
#        [12806.699],
#        [12807.052],
#        [12806.984],
#        [12807.023],
#        [12807.016],
#        [12807.02 ],
#        [12807.02 ],
#        [12807.02 ],
#        [12807.02 ],
#        [12807.02 ],
#        [12807.02 ],
#        [12807.02 ],
#        [12807.02 ],
#        [12807.02 ],
#        [12807.02 ],
#        [12807.02 ],
#        [12807.02 ],
#        [12807.02 ],
#        [12807.02 ],
#        [12807.02 ],
#        [12807.02 ],
#        [12807.02 ],
#        [12807.02 ],
#        [12807.02 ],
#        [12807.02 ],
#        [12807.02 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(test_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
y_pred_90_days = forecast(test_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %% [markdown]
# ### Plot the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        test_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Next {days} Days",
        linestyle="--",
    )

    plt.title(f"Forecast {stock_name[stock]} Stock Closing Price Using LSTM")
    plt.legend()
    plt.show()

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
