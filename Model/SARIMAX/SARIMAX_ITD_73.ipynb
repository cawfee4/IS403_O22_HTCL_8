# %% [markdown]
# ### Import neccesary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    root_mean_squared_error as rmse,
    mean_absolute_error as mae,
)
from sklearn.linear_model import LinearRegression

plt.style.use("default")

# %% [markdown]
# ### Define the split type and stock name

# %%
split_type = [0.8,0.7,0.9]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
split = 1
stock = 2 # ITD

# %% [markdown]
# ## 1.Data preprocessing

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")
df
# Out:
#             time   open   high    low  close  volume ticker
# 0     2019-03-01   6900   6900   6900   6900   37940    ITD
# 1     2019-03-04   6900   7100   6900   7100   36140    ITD
# 2     2019-03-05   7100   7100   6900   7100   14270    ITD
# 3     2019-03-06   6940   7230   6940   7170  224810    ITD
# 4     2019-03-07   7270   7270   7100   7170   80680    ITD
# ...          ...    ...    ...    ...    ...     ...    ...
# 1308  2024-05-27  11300  11600  11300  11300   47400    ITD
# 1309  2024-05-28  11650  12050  11400  12050  322600    ITD
# 1310  2024-05-29  12850  12850  12450  12600  334600    ITD
# 1311  2024-05-30  12600  12600  12100  12500  299000    ITD
# 1312  2024-05-31  12500  13300  12500  12700  258300    ITD
#
# [1313 rows x 7 columns]

# %%
# Create a correlation matrix
df1 = df.drop(columns=["time", "ticker"], axis=1)
corr_matrix = df1.corr()

# Draw the heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# #### Low price and close price are correlated => Good for forecast the "close price" in SARIMAX model

# %%
df = df[["low", "close"]] # Using low and close price to predict the next day close price, the low price is the exogenous variable

df
# Out:
#         low  close
# 0      6900   6900
# 1      6900   7100
# 2      6900   7100
# 3      6940   7170
# 4      7100   7170
# ...     ...    ...
# 1308  11300  11300
# 1309  11400  12050
# 1310  12450  12600
# 1311  12100  12500
# 1312  12500  12700
#
# [1313 rows x 2 columns]

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Price")
plt.xlabel("Date")
plt.show()

# %%
df.reset_index(drop=True)
df
# Out:
#         low  close
# 0      6900   6900
# 1      6900   7100
# 2      6900   7100
# 3      6940   7170
# 4      7100   7170
# ...     ...    ...
# 1308  11300  11300
# 1309  11400  12050
# 1310  12450  12600
# 1311  12100  12500
# 1312  12500  12700
#
# [1313 rows x 2 columns]

# %%
# Shape of the dataframe
df.shape
# Out:
# (1313, 2)

# %%
df.dtypes
# Out:
# low      int64
# close    int64
# dtype: object

# %%
# Describe the dataframe
df.describe()
# Out:
#                 low         close
# count   1313.000000   1313.000000
# mean    9972.168317  10160.894897
# std     2917.997297   3002.802575
# min     5130.000000   5320.000000
# 25%     7460.000000   7550.000000
# 50%     9900.000000  10040.000000
# 75%    11500.000000  11650.000000
# max    20700.000000  21430.000000

# %% [markdown]
# ## 2. Train model

# %%
# Defining the split size
train_size = int(split_type[split] * len(df))
test_size = len(df) - train_size

# %%
# splitting data into train, test set
train_data = df[:train_size]
test_data = df[train_size:]

# %%
# splitting sets into independent and dependent variable
X_train = np.array(train_data.index).reshape(-1, 1)
y_train = np.array(train_data["close"])

X_test = np.array(test_data.index).reshape(-1, 1)
y_test = np.array(test_data["close"])

# %%
# Check if the dataset is stationary or not
from statsmodels.tsa.stattools import adfuller

adfuller(df["close"])
# Out:
# (-1.584523707127448,
#  0.4913629480785365,
#  12,
#  1300,
#  {'1%': -3.435390199468821,
#   '5%': -2.8637658312426035,
#   '10%': -2.567955046745562},
#  18249.61406238007)

# %% [markdown]
# The high p-value close to 1 suggests that we fail to reject the null hypothesis -> the data is likely non-stationary.

# %%
# Agugmented Dickey-Fuller test
def adf_test(dataset, name):
    dftest = adfuller(dataset, autolag="AIC", regression="ct")
    print(f"ADF Test on '{name}' -> p-value: {dftest[1]:.3f}")
    if (
        dftest[0] < dftest[4]["5%"]
        or dftest[0] < dftest[4]["1%"]
        or dftest[0] < dftest[4]["10%"]
    ):
        print("\033[92mReject Ho - Time Series is Stationary\033[0m")
        return True
    else:
        print("\033[91mFailed to Reject Ho - Time Series is Non-Stationary\033[0m")
        return False

# %%
# Differencing all features for stationarity until all features are stationary
is_all_stationary = False
diff_order = 0
while not is_all_stationary:
    print("*" * 50 + f" Differencing of order {diff_order} " + "*" * 50)
    train_diff = pd.DataFrame(
        np.diff(train_data, diff_order, axis=0), columns=train_data.columns
    )
    if all([adf_test(train_diff[feature], feature) for feature in train_diff.columns]):
        is_all_stationary = True
        print(f"Dataset is stationary after differencing of order {diff_order}")
        break
    diff_order += 1
# Out:
# ************************************************** Differencing of order 0 **************************************************
# ADF Test on 'low' -> p-value: 0.848
# Failed to Reject Ho - Time Series is Non-Stationary
# ADF Test on 'close' -> p-value: 0.843
# Failed to Reject Ho - Time Series is Non-Stationary
# ************************************************** Differencing of order 1 **************************************************
# ADF Test on 'low' -> p-value: 0.000
# Reject Ho - Time Series is Stationary
# ADF Test on 'close' -> p-value: 0.000
# Reject Ho - Time Series is Stationary
# Dataset is stationary after differencing of order 1

# %%
# Decompose the data to see the trend, seasonality and noise
from statsmodels.tsa.seasonal import seasonal_decompose

decompose = seasonal_decompose(df["close"], model="additive", period=30)
decompose.plot()

# %%
df1 = df
df_diff = np.diff(train_data["close"], n=1)

# %%
# Check again
adfuller(df_diff)
# Out:
# (-9.05389535852299,
#  4.7585079585462e-15,
#  11,
#  906,
#  {'1%': -3.4375883271133243,
#   '5%': -2.8647353885968214,
#   '10%': -2.568471435365895},
#  12798.627520578957)

# %% [markdown]
# The p-value is less than 0.05 -> Dataset is stationary -> Draw ACF to find m

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

plt.figure(figsize=(10, 6))
plot_acf(df_diff, lags=20, zero=False)
plot_pacf(df_diff, lags=20, zero=False)
plt.show()

# %% [markdown]
# => m = 5

# %%
# Review the dataset again
df
# Out:
#         low  close
# 0      6900   6900
# 1      6900   7100
# 2      6900   7100
# 3      6940   7170
# 4      7100   7170
# ...     ...    ...
# 1308  11300  11300
# 1309  11400  12050
# 1310  12450  12600
# 1311  12100  12500
# 1312  12500  12700
#
# [1313 rows x 2 columns]

# %%
# Use auto_arima to find the best (p, d, q) and (P, D, Q)
from pmdarima.arima import auto_arima

model = auto_arima(
    y_train,
    trace=True,
    d=1,
    max_p=7,
    max_d=7,
    error_action="ignore",
    suppress_warnings=True,
    seasonal=True,
    m=5,
)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[5] intercept   : AIC=13104.732, Time=0.78 sec
#  ARIMA(0,1,0)(0,0,0)[5] intercept   : AIC=13127.555, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[5] intercept   : AIC=13113.967, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,1)[5] intercept   : AIC=13111.886, Time=0.06 sec
#  ARIMA(0,1,0)(0,0,0)[5]             : AIC=13125.653, Time=0.00 sec
#  ARIMA(2,1,2)(0,0,1)[5] intercept   : AIC=13107.874, Time=0.73 sec
#  ARIMA(2,1,2)(1,0,0)[5] intercept   : AIC=13106.736, Time=0.61 sec
#  ARIMA(2,1,2)(2,0,1)[5] intercept   : AIC=13100.037, Time=1.38 sec
#  ARIMA(2,1,2)(2,0,0)[5] intercept   : AIC=13101.970, Time=0.90 sec
#  ARIMA(2,1,2)(2,0,2)[5] intercept   : AIC=13101.252, Time=1.15 sec
#  ARIMA(2,1,2)(1,0,2)[5] intercept   : AIC=13101.733, Time=1.35 sec
#  ARIMA(1,1,2)(2,0,1)[5] intercept   : AIC=13098.450, Time=1.16 sec
#  ARIMA(1,1,2)(1,0,1)[5] intercept   : AIC=13103.904, Time=0.58 sec
#  ARIMA(1,1,2)(2,0,0)[5] intercept   : AIC=13101.288, Time=0.78 sec
#  ARIMA(1,1,2)(2,0,2)[5] intercept   : AIC=13099.462, Time=1.01 sec
#  ARIMA(1,1,2)(1,0,0)[5] intercept   : AIC=13105.485, Time=0.18 sec
#  ARIMA(1,1,2)(1,0,2)[5] intercept   : AIC=13099.966, Time=1.28 sec
#  ARIMA(0,1,2)(2,0,1)[5] intercept   : AIC=13098.636, Time=1.16 sec
#  ARIMA(1,1,1)(2,0,1)[5] intercept   : AIC=13100.102, Time=1.17 sec
#  ARIMA(1,1,3)(2,0,1)[5] intercept   : AIC=13100.136, Time=1.03 sec
#  ARIMA(0,1,1)(2,0,1)[5] intercept   : AIC=13102.653, Time=0.45 sec
#  ARIMA(0,1,3)(2,0,1)[5] intercept   : AIC=13100.068, Time=0.60 sec
#  ARIMA(2,1,1)(2,0,1)[5] intercept   : AIC=13100.343, Time=1.02 sec
#  ARIMA(2,1,3)(2,0,1)[5] intercept   : AIC=inf, Time=1.50 sec
#  ARIMA(1,1,2)(2,0,1)[5]             : AIC=13096.536, Time=0.55 sec
#  ARIMA(1,1,2)(1,0,1)[5]             : AIC=13102.023, Time=0.22 sec
#  ARIMA(1,1,2)(2,0,0)[5]             : AIC=13099.449, Time=0.16 sec
#  ARIMA(1,1,2)(2,0,2)[5]             : AIC=13097.459, Time=0.74 sec
#  ARIMA(1,1,2)(1,0,0)[5]             : AIC=13103.543, Time=0.10 sec
#  ARIMA(1,1,2)(1,0,2)[5]             : AIC=13098.056, Time=0.63 sec
#  ARIMA(0,1,2)(2,0,1)[5]             : AIC=13096.694, Time=0.32 sec
#  ARIMA(1,1,1)(2,0,1)[5]             : AIC=13098.145, Time=0.39 sec
#  ARIMA(2,1,2)(2,0,1)[5]             : AIC=13098.115, Time=0.76 sec
#  ARIMA(1,1,3)(2,0,1)[5]             : AIC=13098.184, Time=0.90 sec
#  ARIMA(0,1,1)(2,0,1)[5]             : AIC=13100.984, Time=0.18 sec
#  ARIMA(0,1,3)(2,0,1)[5]             : AIC=13098.119, Time=0.36 sec
#  ARIMA(2,1,1)(2,0,1)[5]             : AIC=13098.276, Time=0.79 sec
#  ARIMA(2,1,3)(2,0,1)[5]             : AIC=inf, Time=0.91 sec
#
# Best model:  ARIMA(1,1,2)(2,0,1)[5]
# Total fit time: 25.973 seconds

# %%
print(model.summary())
# Out:
#                                       SARIMAX Results
# ===========================================================================================
# Dep. Variable:                                   y   No. Observations:                  919
# Model:             SARIMAX(1, 1, 2)x(2, 0, [1], 5)   Log Likelihood               -6541.268
# Date:                             Thu, 20 Jun 2024   AIC                          13096.536
# Time:                                     07:06:05   BIC                          13130.291
# Sample:                                          0   HQIC                         13109.419
#                                              - 919
# Covariance Type:                               opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6703      0.121      5.555      0.000       0.434       0.907
# ma.L1         -0.5379      0.123     -4.381      0.000      -0.779      -0.297
# ma.L2         -0.1684      0.022     -7.526      0.000      -0.212      -0.125
# ar.S.L5       -0.7258      0.074     -9.822      0.000      -0.871      -0.581
# ar.S.L10       0.1511      0.025      6.067      0.000       0.102       0.200
# ma.S.L5        0.8373      0.073     11.393      0.000       0.693       0.981
# sigma2      9.048e+04   2608.636     34.685      0.000    8.54e+04    9.56e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               487.77
# Prob(Q):                              0.93   Prob(JB):                         0.00
# Heteroskedasticity (H):               9.47   Skew:                             0.27
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.53
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# #### Use SARIMAX to train model

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# Use 'low price' for the exogenous variable
model1 = SARIMAX(
    y_train,
    exog=np.array(train_data["low"]),
    order=(1, 1, 2),
    seasonal_order=(2, 0, 1, 5),
)

model_fit = model1.fit()
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# ### Test

# %%
exg = np.array(test_data["low"])

y_pred_test = model_fit.predict(
    start=len(y_train), end=len(y_test) + len(y_train) - 1, exog=exg
)

y_pred_test
# Out:
# array([10002.02395989, 10243.9406622 , 10629.23549686, 10956.76009841,
#        10523.52428656, 10456.87328674, 10535.71974172, 10795.27954285,
#        10057.47494163,  9982.75430341,  9933.57021151,  9724.15622431,
#         9273.08350567, 10345.07775983, 10873.99944082, 11061.56362974,
#        11037.78590229, 10977.44430903, 10835.17851326, 10958.78962305,
#        11138.04521939, 11396.72664108, 11405.89794066, 11497.23394101,
#        11097.9265776 , 11479.92992629, 10659.92029627, 10507.80353047,
#        10559.36242962, 10774.9461967 , 11086.96825294, 10835.27571173,
#        11038.43987354, 11129.76883863, 11240.77212055, 11153.28418903,
#        10853.84175896, 11252.8332482 , 10977.78513469, 11142.36885564,
#        10954.28319704, 10886.27315123, 10711.84645503, 10660.28658381,
#        10454.86175493, 10642.94336905, 11037.57790153, 11018.05741564,
#        10885.89979311, 10672.87280179, 10770.57553283, 10978.10525321,
#        11038.47490395, 10854.23183967, 10679.39818234, 11061.3965974 ,
#        11037.60113713, 11252.78285756, 11396.19951859, 11979.30651831,
#        12107.63527354, 12549.87860845, 12151.00366088, 12242.3363855 ,
#        12261.39743639, 12265.74964168, 12384.8803935 , 12732.69948242,
#        12784.25706449, 12356.95101778, 12352.60204394, 12274.27948783,
#        12447.01427796, 12446.48947819, 12261.39253444, 12418.83545675,
#        12395.11090956, 12273.38511024, 12069.7799203 , 11744.56706186,
#        12046.41896529, 12070.12582445, 12038.77781206, 11834.12420144,
#        11853.12848846, 11755.40294169, 12037.90814672, 11916.13559316,
#        11865.62681875, 11846.63669821, 11587.13868806, 11508.74541807,
#        11273.31453157, 11476.92089225, 11291.76726104, 11245.06764617,
#        11680.70535351, 11763.01570954, 11712.5061549 , 11387.34994453,
#        11485.085188  , 11508.72143606, 11273.33720042, 10864.55555609,
#        11189.697631  , 11347.12115365, 11323.50252561, 11456.79866442,
#        11559.3855268 , 11540.4519692 , 11485.09646914, 11610.76228774,
#        11579.55422834, 11579.03255261, 11597.95199586, 11602.27187444,
#        11578.6884471 , 11762.97043814, 11967.62131994, 11540.45679057,
#        11944.39932225, 11967.96516892, 11936.80362135, 11732.15312814,
#        11700.01197552, 11857.42261207, 11731.80953549, 11967.07744812,
#        11967.59795804, 11897.68839598, 12046.47536741, 12325.16808575,
#        12498.18257565, 12446.63005501, 12261.36355105, 12367.7353602 ,
#        12548.35177192, 12273.24928925, 12375.83382089, 12254.91999421,
#        11995.45419957, 12069.98225326, 12192.0107177 , 12191.49137099,
#        12159.29395011, 12163.5945427 , 12140.11640299, 12120.12957531,
#        12171.68093361, 11999.76280038, 12046.49781249, 11967.89365253,
#        11936.87122492, 11783.255456  , 11853.09476135, 11857.38894443,
#        11731.88099856, 11864.94509745, 11865.46328357, 11897.70279562,
#        11842.37941498, 11916.83748601, 11732.76409734, 11936.37589248,
#        11904.12237094, 11857.37775532, 12089.13153981, 11966.98744429,
#        12069.5696556 , 12050.80477743, 11842.39059575, 11967.8461524 ,
#        11987.94852495, 11936.3990981 , 11853.08519019, 11755.3017854 ,
#        11833.99326076, 11762.83543214, 11865.41687231, 11795.64756217,
#        11791.36936111, 11814.7252592 , 11732.80893171, 11681.26027543,
#        11751.01561781, 11551.16103465, 11527.82254762, 11660.74825089,
#        11610.23172484, 11489.45794105, 11485.18611613, 11508.50720508,
#        11477.66930509, 11477.15381696, 11495.84885633, 11244.95550304,
#        11221.65179919, 11252.46671055, 11252.98181439, 11234.30071156,
#        10515.58167088, 10640.93280007, 10712.2056577 , 10609.62614037,
#        10679.32571579, 10632.55559558, 10609.28662307, 10640.05560854,
#        10589.53754594, 10519.85188629, 10566.62518389, 11100.20079756,
#        11222.55194559, 11273.07039161, 11291.70974713, 11244.9332745 ,
#        11221.69898158, 11099.32491338, 10997.77368548, 10877.08342751,
#        10872.83067404, 10998.11244405, 11018.44461784, 10915.86663362,
#        10934.47820945, 10938.72779262, 10864.49572885, 10895.17306779,
#        10844.65347322, 10877.08817046, 10821.80935646, 10742.92692942,
#        10610.20766195, 10609.69524005, 10628.27907758, 10683.55472601,
#        10660.38963726, 10639.98885661, 10589.46849777, 10213.67172269,
#        10209.4316362 , 10130.51465866,  9814.12444248,  9844.23222353,
#        10220.0151553 , 10040.53544547, 10109.26319921,  9823.44829239,
#         9823.95956916,  9805.41726157,  9392.92430449,  8762.82292151,
#         9385.47446086,  9589.0931602 ,  9719.89292233,  9815.98185108,
#         9690.8209629 ,  9751.98078286,  9762.69777738,  9805.42198335,
#         9750.16212737, 10079.43539314,  9997.88538054,  9905.5169286 ,
#         9760.71412307,  9775.14490863,  9935.79987532,  9843.81698232,
#         9803.50081724,  9703.3619006 ,  9801.20554136,  9926.31481591,
#         9742.74548862,  9946.36570968,  9964.83900682, 10020.08941555,
#         9894.99731991,  9976.47913374,  9772.85853295,  9703.36660831,
#         9903.28133767,  9936.49794949,  9906.07123344,  9895.35613894,
#         9760.70470765,  9826.1553097 ,  9895.02064867,  9925.4246826 ,
#         9925.93291819,  9805.43610648, 10005.3571176 ,  9854.82280013,
#         9824.44143141,  9823.93357469, 10077.10088266, 10071.09984941,
#         9997.10874014, 10027.46746055, 10079.00733742, 10060.60279388,
#        10056.40048241,  9977.27728048,  9895.90879276,  9905.60817269,
#         9760.69532028,  9836.3398573 ,  9966.51256017, 10017.23899409,
#         9823.82260067,  9887.09732485,  9750.21703968,  9773.12444358,
#         9773.4530061 ,  9793.35962155,  9607.59344085,  9611.78636127,
#         9537.86363535,  9598.75137047,  9589.0508573 ,  9591.11409185,
#         9597.13077686,  9640.41699955,  9661.20366645,  9589.2527188 ,
#         9719.86004187,  9621.98191576,  9701.19050132,  9731.41368597,
#         9731.91889848,  9407.40212911,  9597.14169398,  9650.60030659,
#         9702.05149032,  9691.34017469,  9832.12664985,  9846.51356125,
#         9701.21365676,  9721.18531767,  9833.96105445, 10009.58910004,
#         9913.55346702, 10232.34651408, 10161.36495123, 10405.81638171,
#        10373.06541422, 10275.17481797, 10405.48388032, 10333.55224664,
#        10334.05595436, 10213.72335382, 10209.55226432, 10089.43269391,
#        10202.21270987, 10160.88345866, 10219.96356266, 10081.24082627,
#        10099.31257433, 10088.57490933,  9517.51500041,  9621.75218028,
#         9842.12986175, 10150.64850315, 10406.36411192, 10303.79673238,
#        10015.82931929, 10122.05588499, 10007.47730866, 10047.7271995 ,
#        10211.53308287, 10111.66785314, 10209.57398487, 10334.34210374,
#        10100.19149406, 10099.68966104, 10066.85707655, 10428.23943336,
#        10201.42344158, 10200.80263737, 10333.98833302, 10724.06127606,
#        11332.29759319, 11967.35586294, 11427.05560348, 11630.68411335,
#        11495.75960677, 11550.94137776, 11426.22399478, 11660.30751547,
#        11558.74342954, 11540.58428704, 11638.5028055 , 12732.81887781,
#        12345.66049057, 12753.41934221])

# %% [markdown]
# ### Forecast the next 30/60/90 days

# %%
num_of_days_30 = 30
num_of_days_60 = 60
num_of_days_90 = 90

# %%
df
# Out:
#         low  close
# 0      6900   6900
# 1      6900   7100
# 2      6900   7100
# 3      6940   7170
# 4      7100   7170
# ...     ...    ...
# 1308  11300  11300
# 1309  11400  12050
# 1310  12450  12600
# 1311  12100  12500
# 1312  12500  12700
#
# [1313 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression

ln_model = LinearRegression()

# Use LM to find the low price the next 30/60/90 days
ln_model.fit(np.array(train_data.index).reshape(-1, 1), train_data["low"])

last_index = df.index[-1]
last_data_30 = pd.RangeIndex(start=last_index, stop=last_index + num_of_days_30, step=1)
last_data_60 = pd.RangeIndex(start=last_index, stop=last_index + num_of_days_60, step=1)
last_data_90 = pd.RangeIndex(start=last_index, stop=last_index + num_of_days_90, step=1)

# Create an array of 30/60/90 consecutive integers starting from last_index
x_30_days_pred = np.array(
    range(last_index + 1, last_index + num_of_days_30 + 1)
).reshape(-1, 1)

x_60_days_pred = np.array(
    range(last_index + 1, last_index + num_of_days_60 + 1)
).reshape(-1, 1)

x_90_days_pred = np.array(
    range(last_index + 1, last_index + num_of_days_90 + 1)
).reshape(-1, 1)

# Predict the low price - extrapolation variable for the next 30/60/90 days to predict the closeing price
low_30_days_pred = ln_model.predict(x_30_days_pred)
low_60_days_pred = ln_model.predict(x_60_days_pred)
low_90_days_pred = ln_model.predict(x_90_days_pred)

# Predict the closing prices of FPT for the next 30/60/90 days
y_30_days_pred = model_fit.predict(
    start=len(X_train),
    end=len(X_train) + len(x_30_days_pred) - 1,
    exog=low_30_days_pred,
)

y_60_days_pred = model_fit.predict(
    start=len(X_train),
    end=len(X_train) + len(x_60_days_pred) - 1,
    exog=low_60_days_pred,
)

y_90_days_pred = model_fit.predict(
    start=len(X_train),
    end=len(X_train) + len(x_90_days_pred) - 1,
    exog=low_90_days_pred,
)

# Print the predicted closing prices for the next 30 days
print("Forecast closing prices for the next 30 days:")
print(y_30_days_pred)
# Out:
# Forecast closing prices for the next 30 days:
# [17232.08051952 17349.95576715 17274.39531544 17334.98774584
#  17328.86038572 17311.67808695 17307.30900625 17340.76255522
#  17356.67375769 17341.62830026 17341.9129094  17375.89073847
#  17351.92647157 17360.8831342  17388.12360982 17400.61394533
#  17385.47899993 17425.63850646 17434.90620922 17424.26938459
#  17428.45112751 17461.02629704 17438.01445967 17446.13492435
#  17473.93601267 17486.94239272 17471.68096513 17511.92361686
#  17521.09289932 17510.57041423]

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(x_next_days, y_next_day, days):
    plt.figure(figsize=(10, 6))
    plt.plot(train_data.index, train_data["close"], label="Train")
    plt.plot(test_data.index, test_data["close"], label="Test")

    plt.plot(test_data.index, y_pred_test, label="Predicted Test", linestyle="--")

    plt.plot(
        x_next_days, y_next_day, label=f"Next {days} days", linestyle="--"
    )
    plt.title(f"Forecast {stock_name[stock]} Stock Price Using SARIMAX")
    plt.legend()
    plt.show()

# %%
draw_plot(x_30_days_pred, y_30_days_pred, 30)
draw_plot(x_60_days_pred, y_60_days_pred, 60)
draw_plot(x_90_days_pred, y_90_days_pred, 90)

# %% [markdown]
# ## 3. Model evaluation

# %%
# Model evaluation on test set
print(f"RMSE: {rmse(y_test, y_pred_test)}")
print(f"MAE: {mae(y_test, y_pred_test)}")
print(f"MAPE: {mape(y_test, y_pred_test) * 100} %")
# Out:
# RMSE: 187.48032898948406
# MAE: 153.96821710365708
# MAPE: 1.4172248459642007 %
