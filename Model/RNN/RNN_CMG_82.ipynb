# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Input

plt.style.use('default')

# %% [markdown]
# ## 1. Data preprocessing

# %%
split_type = [0.8,0.7,0.9]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 0

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using neural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split] * len(df_scaled))
test_size = len(df_scaled) - train_size

# %%
# Splitting data into train, test set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size:]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test set
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1039, 10), (1039,), (252, 10), (252,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
UNITS = 64

# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(UNITS),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 64)             │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,289 (16.75 KB)
#  Trainable params: 4,289 (16.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0075 - mean_absolute_error: 0.0631
# Epoch 2/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9891e-04 - mean_absolute_error: 0.0146
# Epoch 3/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8274e-04 - mean_absolute_error: 0.0115
# Epoch 4/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2846e-04 - mean_absolute_error: 0.0105
# Epoch 5/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 2.5685e-04 - mean_absolute_error: 0.0113
# Epoch 6/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3826e-04 - mean_absolute_error: 0.0112
# Epoch 7/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - loss: 2.0677e-04 - mean_absolute_error: 0.0099
# Epoch 8/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7517e-04 - mean_absolute_error: 0.0116
# Epoch 9/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - loss: 1.8736e-04 - mean_absolute_error: 0.0096
# Epoch 10/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - loss: 1.6239e-04 - mean_absolute_error: 0.0085
# Epoch 11/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0683e-04 - mean_absolute_error: 0.0100
# Epoch 12/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 2.0868e-04 - mean_absolute_error: 0.0105
# Epoch 13/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 1.6656e-04 - mean_absolute_error: 0.0092
# Epoch 14/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1068e-04 - mean_absolute_error: 0.0102
# Epoch 15/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - loss: 2.0042e-04 - mean_absolute_error: 0.0100
# Epoch 16/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - loss: 1.8224e-04 - mean_absolute_error: 0.0092
# Epoch 17/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9100e-04 - mean_absolute_error: 0.0098
# Epoch 18/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7034e-04 - mean_absolute_error: 0.0091
# Epoch 19/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6442e-04 - mean_absolute_error: 0.0086
# Epoch 20/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - loss: 1.7203e-04 - mean_absolute_error: 0.0090
# Epoch 21/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - loss: 1.8181e-04 - mean_absolute_error: 0.0094
# Epoch 22/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - loss: 1.5989e-04 - mean_absolute_error: 0.0089
# Epoch 23/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8059e-04 - mean_absolute_error: 0.0092
# Epoch 24/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6788e-04 - mean_absolute_error: 0.0087
# Epoch 25/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 1.7157e-04 - mean_absolute_error: 0.0090
# Epoch 26/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8261e-04 - mean_absolute_error: 0.0094
# Epoch 27/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - loss: 1.7718e-04 - mean_absolute_error: 0.0094
# Epoch 28/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 1.5631e-04 - mean_absolute_error: 0.0089
# Epoch 29/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7455e-04 - mean_absolute_error: 0.0096
# Epoch 30/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.3980e-04 - mean_absolute_error: 0.0111
# Epoch 31/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6868e-04 - mean_absolute_error: 0.0120
# Epoch 32/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - loss: 1.5587e-04 - mean_absolute_error: 0.0089
# Epoch 33/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - loss: 1.6560e-04 - mean_absolute_error: 0.0088
# Epoch 34/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 1.8116e-04 - mean_absolute_error: 0.0096
# Epoch 35/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5191e-04 - mean_absolute_error: 0.0084
# Epoch 36/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 1.8182e-04 - mean_absolute_error: 0.0090
# Epoch 37/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6520e-04 - mean_absolute_error: 0.0088
# Epoch 38/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5211e-04 - mean_absolute_error: 0.0082
# Epoch 39/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6421e-04 - mean_absolute_error: 0.0090
# Epoch 40/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7382e-04 - mean_absolute_error: 0.0096
# Epoch 41/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4939e-04 - mean_absolute_error: 0.0083
# Epoch 42/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 1.4852e-04 - mean_absolute_error: 0.0085
# Epoch 43/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 2.1269e-04 - mean_absolute_error: 0.0107
# Epoch 44/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4003e-04 - mean_absolute_error: 0.0080
# Epoch 45/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4394e-04 - mean_absolute_error: 0.0081
# Epoch 46/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 1.5633e-04 - mean_absolute_error: 0.0088
# Epoch 47/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5741e-04 - mean_absolute_error: 0.0088
# Epoch 48/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 1.6571e-04 - mean_absolute_error: 0.0087
# Epoch 49/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4796e-04 - mean_absolute_error: 0.0084
# Epoch 50/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5525e-04 - mean_absolute_error: 0.0086
# Epoch 51/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6026e-04 - mean_absolute_error: 0.0086
# Epoch 52/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0201e-04 - mean_absolute_error: 0.0103
# Epoch 53/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5013e-04 - mean_absolute_error: 0.0084
# Epoch 54/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5329e-04 - mean_absolute_error: 0.0086
# Epoch 55/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - loss: 1.6047e-04 - mean_absolute_error: 0.0087
# Epoch 56/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - loss: 1.7882e-04 - mean_absolute_error: 0.0095
# Epoch 57/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - loss: 1.7243e-04 - mean_absolute_error: 0.0091
# Epoch 58/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5764e-04 - mean_absolute_error: 0.0088
# Epoch 59/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5369e-04 - mean_absolute_error: 0.0083
# Epoch 60/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - loss: 1.3608e-04 - mean_absolute_error: 0.0080
# Epoch 61/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - loss: 1.3986e-04 - mean_absolute_error: 0.0083
# Epoch 62/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 1.6045e-04 - mean_absolute_error: 0.0086
# Epoch 63/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - loss: 1.5938e-04 - mean_absolute_error: 0.0089
# Epoch 64/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 1.3348e-04 - mean_absolute_error: 0.0081
# Epoch 65/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - loss: 1.6330e-04 - mean_absolute_error: 0.0089
# Epoch 66/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - loss: 1.4596e-04 - mean_absolute_error: 0.0084
# Epoch 67/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 1.6332e-04 - mean_absolute_error: 0.0088
# Epoch 68/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 1.5375e-04 - mean_absolute_error: 0.0085
# Epoch 69/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3233e-04 - mean_absolute_error: 0.0080
# Epoch 70/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6155e-04 - mean_absolute_error: 0.0087
# Epoch 71/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4450e-04 - mean_absolute_error: 0.0083
# Epoch 72/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6228e-04 - mean_absolute_error: 0.0089
# Epoch 73/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - loss: 1.3922e-04 - mean_absolute_error: 0.0083
# Epoch 74/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3183e-04 - mean_absolute_error: 0.0081
# Epoch 75/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4701e-04 - mean_absolute_error: 0.0084
# Epoch 76/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6059e-04 - mean_absolute_error: 0.0091
# Epoch 77/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - loss: 1.3553e-04 - mean_absolute_error: 0.0082
# Epoch 78/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3475e-04 - mean_absolute_error: 0.0079
# Epoch 79/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5397e-04 - mean_absolute_error: 0.0085
# Epoch 80/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4222e-04 - mean_absolute_error: 0.0082
# Epoch 81/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4255e-04 - mean_absolute_error: 0.0082
# Epoch 82/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6717e-04 - mean_absolute_error: 0.0090
# Epoch 83/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 1.5608e-04 - mean_absolute_error: 0.0088
# Epoch 84/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 1.4628e-04 - mean_absolute_error: 0.0085
# Epoch 85/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4128e-04 - mean_absolute_error: 0.0084
# Epoch 86/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5090e-04 - mean_absolute_error: 0.0086
# Epoch 87/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5208e-04 - mean_absolute_error: 0.0088
# Epoch 88/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - loss: 1.4054e-04 - mean_absolute_error: 0.0080
# Epoch 89/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - loss: 1.6710e-04 - mean_absolute_error: 0.0095
# Epoch 90/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - loss: 1.3033e-04 - mean_absolute_error: 0.0080
# Epoch 91/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 1.5103e-04 - mean_absolute_error: 0.0086
# Epoch 92/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 1.4665e-04 - mean_absolute_error: 0.0083
# Epoch 93/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - loss: 1.4052e-04 - mean_absolute_error: 0.0083
# Epoch 94/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - loss: 1.4042e-04 - mean_absolute_error: 0.0083
# Epoch 95/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step - loss: 1.5880e-04 - mean_absolute_error: 0.0084
# Epoch 96/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4596e-04 - mean_absolute_error: 0.0083
# Epoch 97/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4581e-04 - mean_absolute_error: 0.0083
# Epoch 98/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6211e-04 - mean_absolute_error: 0.0089
# Epoch 99/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6606e-04 - mean_absolute_error: 0.0089
# Epoch 100/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5184e-04 - mean_absolute_error: 0.0086
# Epoch 101/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4988e-04 - mean_absolute_error: 0.0086
# Epoch 102/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - loss: 1.4122e-04 - mean_absolute_error: 0.0083
# Epoch 103/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 1.6106e-04 - mean_absolute_error: 0.0086
# Epoch 104/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - loss: 1.6445e-04 - mean_absolute_error: 0.0090
# Epoch 105/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - loss: 1.5573e-04 - mean_absolute_error: 0.0088
# Epoch 106/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 1.3932e-04 - mean_absolute_error: 0.0083
# Epoch 107/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - loss: 1.7325e-04 - mean_absolute_error: 0.0095
# Epoch 108/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - loss: 1.4151e-04 - mean_absolute_error: 0.0084
# Epoch 109/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3467e-04 - mean_absolute_error: 0.0081
# Epoch 110/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5074e-04 - mean_absolute_error: 0.0084
# Epoch 111/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4909e-04 - mean_absolute_error: 0.0085
# Epoch 112/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6141e-04 - mean_absolute_error: 0.0088
# Epoch 113/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5719e-04 - mean_absolute_error: 0.0087
# Epoch 114/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3368e-04 - mean_absolute_error: 0.0080
# Epoch 115/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6656e-04 - mean_absolute_error: 0.0087
# Epoch 116/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - loss: 1.5065e-04 - mean_absolute_error: 0.0084
# Epoch 117/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 1.4393e-04 - mean_absolute_error: 0.0083
# Epoch 118/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5271e-04 - mean_absolute_error: 0.0087
# Epoch 119/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6100e-04 - mean_absolute_error: 0.0087
# Epoch 120/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6220e-04 - mean_absolute_error: 0.0087
# Epoch 121/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - loss: 1.7027e-04 - mean_absolute_error: 0.0094
# Epoch 122/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - loss: 1.7054e-04 - mean_absolute_error: 0.0093
# Epoch 123/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 1.3209e-04 - mean_absolute_error: 0.0080
# Epoch 124/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 1.6020e-04 - mean_absolute_error: 0.0087
# Epoch 125/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4127e-04 - mean_absolute_error: 0.0083
# Epoch 126/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4628e-04 - mean_absolute_error: 0.0081
# Epoch 127/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 1.3833e-04 - mean_absolute_error: 0.0084
# Epoch 128/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3576e-04 - mean_absolute_error: 0.0084
# Epoch 129/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 1.6246e-04 - mean_absolute_error: 0.0089
# Epoch 130/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4717e-04 - mean_absolute_error: 0.0085
# Epoch 131/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5244e-04 - mean_absolute_error: 0.0089
# Epoch 132/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3852e-04 - mean_absolute_error: 0.0081
# Epoch 133/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8898e-04 - mean_absolute_error: 0.0102
# Epoch 134/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7076e-04 - mean_absolute_error: 0.0093
# Epoch 135/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6712e-04 - mean_absolute_error: 0.0093
# Epoch 136/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - loss: 1.5336e-04 - mean_absolute_error: 0.0084
# Epoch 137/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - loss: 1.3973e-04 - mean_absolute_error: 0.0084
# Epoch 138/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 1.5143e-04 - mean_absolute_error: 0.0086
# Epoch 139/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5685e-04 - mean_absolute_error: 0.0087
# Epoch 140/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - loss: 1.5005e-04 - mean_absolute_error: 0.0085
# Epoch 141/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - loss: 1.4322e-04 - mean_absolute_error: 0.0085
# Epoch 142/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - loss: 1.5099e-04 - mean_absolute_error: 0.0084
# Epoch 143/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - loss: 1.3906e-04 - mean_absolute_error: 0.0086
# Epoch 144/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 1.6496e-04 - mean_absolute_error: 0.0088
# Epoch 145/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step - loss: 1.3536e-04 - mean_absolute_error: 0.0080
# Epoch 146/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - loss: 1.5463e-04 - mean_absolute_error: 0.0089
# Epoch 147/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 1.3291e-04 - mean_absolute_error: 0.0080
# Epoch 148/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 1.4664e-04 - mean_absolute_error: 0.0083
# Epoch 149/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - loss: 1.4433e-04 - mean_absolute_error: 0.0083
# Epoch 150/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 1.5071e-04 - mean_absolute_error: 0.0084
# Epoch 151/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - loss: 1.4285e-04 - mean_absolute_error: 0.0081
# Epoch 152/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5259e-04 - mean_absolute_error: 0.0083
# Epoch 153/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 1.7817e-04 - mean_absolute_error: 0.0094
# Epoch 154/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - loss: 1.5269e-04 - mean_absolute_error: 0.0087
# Epoch 155/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - loss: 1.5489e-04 - mean_absolute_error: 0.0089
# Epoch 156/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 1.3687e-04 - mean_absolute_error: 0.0080
# Epoch 157/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - loss: 1.4753e-04 - mean_absolute_error: 0.0084
# Epoch 158/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 1.4213e-04 - mean_absolute_error: 0.0082
# Epoch 159/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 1.3943e-04 - mean_absolute_error: 0.0081
# Epoch 160/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - loss: 1.4254e-04 - mean_absolute_error: 0.0082
# Epoch 161/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - loss: 1.7727e-04 - mean_absolute_error: 0.0096
# Epoch 162/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - loss: 1.3500e-04 - mean_absolute_error: 0.0080
# Epoch 163/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - loss: 1.5583e-04 - mean_absolute_error: 0.0086
# Epoch 164/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - loss: 1.5984e-04 - mean_absolute_error: 0.0091
# Epoch 165/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 1.6121e-04 - mean_absolute_error: 0.0087
# Epoch 166/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 1.3445e-04 - mean_absolute_error: 0.0079
# Epoch 167/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - loss: 1.4577e-04 - mean_absolute_error: 0.0083
# Epoch 168/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 1.5706e-04 - mean_absolute_error: 0.0086
# Epoch 169/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3436e-04 - mean_absolute_error: 0.0085
# Epoch 170/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4835e-04 - mean_absolute_error: 0.0084
# Epoch 171/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3587e-04 - mean_absolute_error: 0.0083
# Epoch 172/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5236e-04 - mean_absolute_error: 0.0086
# Epoch 173/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - loss: 1.7354e-04 - mean_absolute_error: 0.0092
# Epoch 174/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4038e-04 - mean_absolute_error: 0.0083
# Epoch 175/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 1.6182e-04 - mean_absolute_error: 0.0091
# Epoch 176/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - loss: 1.4905e-04 - mean_absolute_error: 0.0088
# Epoch 177/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 1.3436e-04 - mean_absolute_error: 0.0078
# Epoch 178/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 1.5151e-04 - mean_absolute_error: 0.0085
# Epoch 179/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 1.6910e-04 - mean_absolute_error: 0.0089
# Epoch 180/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4859e-04 - mean_absolute_error: 0.0083
# Epoch 181/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - loss: 1.7181e-04 - mean_absolute_error: 0.0091
# Epoch 182/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 1.6584e-04 - mean_absolute_error: 0.0087
# Epoch 183/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - loss: 1.4275e-04 - mean_absolute_error: 0.0082
# Epoch 184/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - loss: 1.5033e-04 - mean_absolute_error: 0.0087
# Epoch 185/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step - loss: 1.5306e-04 - mean_absolute_error: 0.0084
# Epoch 186/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 1.3676e-04 - mean_absolute_error: 0.0082
# Epoch 187/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - loss: 1.3871e-04 - mean_absolute_error: 0.0080
# Epoch 188/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 1.3660e-04 - mean_absolute_error: 0.0081
# Epoch 189/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6565e-04 - mean_absolute_error: 0.0091
# Epoch 190/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 1.4677e-04 - mean_absolute_error: 0.0084
# Epoch 191/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4764e-04 - mean_absolute_error: 0.0084
# Epoch 192/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4270e-04 - mean_absolute_error: 0.0084
# Epoch 193/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5058e-04 - mean_absolute_error: 0.0085
# Epoch 194/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4654e-04 - mean_absolute_error: 0.0081
# Epoch 195/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3570e-04 - mean_absolute_error: 0.0079
# Epoch 196/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5805e-04 - mean_absolute_error: 0.0090
# Epoch 197/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4240e-04 - mean_absolute_error: 0.0082
# Epoch 198/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 1.3633e-04 - mean_absolute_error: 0.0083
# Epoch 199/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5370e-04 - mean_absolute_error: 0.0085
# Epoch 200/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4961e-04 - mean_absolute_error: 0.0082

# %% [markdown]
# ### Predicting with test set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test set again to evaluate, because i shaped the data between 0 to 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 252
# 263

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)
# Out:
# Model evalution on test set
# MSE: 2057989.726790171
# RMSE: 1434.5695266490818
# MAE: 973.5837983630952
# MAPE: 2.283033563035191 %

# %% [markdown]
# ## 4. Forecast the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(test_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
y_pred_30_days
# Out:
# array([[62161.18 ],
#        [61867.82 ],
#        [62174.508],
#        [62092.703],
#        [62146.934],
#        [62130.46 ],
#        [62139.316],
#        [62136.13 ],
#        [62137.65 ],
#        [62137.07 ],
#        [62137.336],
#        [62137.223],
#        [62137.277],
#        [62137.242],
#        [62137.266],
#        [62137.246],
#        [62137.273],
#        [62137.246],
#        [62137.266],
#        [62137.246],
#        [62137.26 ],
#        [62137.254],
#        [62137.266],
#        [62137.254],
#        [62137.254],
#        [62137.246],
#        [62137.26 ],
#        [62137.26 ],
#        [62137.254],
#        [62137.254],
#        [62137.26 ]], dtype=float32)

# %% [markdown]
# ### Continue forecast the next 60/90 days

# %%
y_pred_60_days = forecast(test_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
y_pred_90_days = forecast(test_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")

    # Predict test
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        test_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Next {days} Days",
        linestyle="--",
    )

    plt.title(f"Forecast {stock_name[stock]} Stock Closing Price Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Forecast the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
