# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: FPT - Test/Train/Vaildation: 80/10/10
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1951.7846329625693
# - MAE: 1427.613671875
# - MAPE: 1.6427097970854798 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 2  # 8 1 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.tail()
# Out:
#              close
# time
# 2024-05-27  132800
# 2024-05-28  137000
# 2024-05-29  135700
# 2024-05-30  135000
# 2024-05-31  134600

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((1039, 10), (1039,), (120, 10), (120,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 46ms/step - loss: 0.0223 - mean_absolute_error: 0.0988 - val_loss: 0.0015 - val_mean_absolute_error: 0.0297
# Epoch 2/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.7322e-04 - mean_absolute_error: 0.0152 - val_loss: 0.0014 - val_mean_absolute_error: 0.0294
# Epoch 3/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9331e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0013 - val_mean_absolute_error: 0.0290
# Epoch 4/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9200e-04 - mean_absolute_error: 0.0092 - val_loss: 6.1291e-04 - val_mean_absolute_error: 0.0177
# Epoch 5/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8257e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0011 - val_mean_absolute_error: 0.0271
# Epoch 6/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5610e-04 - mean_absolute_error: 0.0082 - val_loss: 6.6727e-04 - val_mean_absolute_error: 0.0190
# Epoch 7/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.3067e-04 - mean_absolute_error: 0.0076 - val_loss: 6.6999e-04 - val_mean_absolute_error: 0.0195
# Epoch 8/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4249e-04 - mean_absolute_error: 0.0079 - val_loss: 6.2378e-04 - val_mean_absolute_error: 0.0190
# Epoch 9/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4208e-04 - mean_absolute_error: 0.0078 - val_loss: 7.2231e-04 - val_mean_absolute_error: 0.0215
# Epoch 10/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1329e-04 - mean_absolute_error: 0.0071 - val_loss: 8.2850e-04 - val_mean_absolute_error: 0.0240
# Epoch 11/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.2874e-04 - mean_absolute_error: 0.0078 - val_loss: 4.6793e-04 - val_mean_absolute_error: 0.0163
# Epoch 12/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0682e-04 - mean_absolute_error: 0.0069 - val_loss: 0.0011 - val_mean_absolute_error: 0.0289
# Epoch 13/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2178e-04 - mean_absolute_error: 0.0075 - val_loss: 7.0039e-04 - val_mean_absolute_error: 0.0220
# Epoch 14/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.8759e-05 - mean_absolute_error: 0.0067 - val_loss: 4.6418e-04 - val_mean_absolute_error: 0.0167
# Epoch 15/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0570e-04 - mean_absolute_error: 0.0066 - val_loss: 2.9341e-04 - val_mean_absolute_error: 0.0126
# Epoch 16/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.3210e-05 - mean_absolute_error: 0.0064 - val_loss: 6.1836e-04 - val_mean_absolute_error: 0.0205
# Epoch 17/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1673e-04 - mean_absolute_error: 0.0075 - val_loss: 5.9685e-04 - val_mean_absolute_error: 0.0201
# Epoch 18/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1073e-04 - mean_absolute_error: 0.0072 - val_loss: 2.7932e-04 - val_mean_absolute_error: 0.0123
# Epoch 19/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.9464e-05 - mean_absolute_error: 0.0060 - val_loss: 4.5281e-04 - val_mean_absolute_error: 0.0168
# Epoch 20/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0747e-04 - mean_absolute_error: 0.0074 - val_loss: 4.8422e-04 - val_mean_absolute_error: 0.0176
# Epoch 21/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.4804e-05 - mean_absolute_error: 0.0063 - val_loss: 3.8121e-04 - val_mean_absolute_error: 0.0151
# Epoch 22/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.9571e-05 - mean_absolute_error: 0.0064 - val_loss: 2.4153e-04 - val_mean_absolute_error: 0.0114
# Epoch 23/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0980e-05 - mean_absolute_error: 0.0062 - val_loss: 1.9074e-04 - val_mean_absolute_error: 0.0101
# Epoch 24/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.2555e-05 - mean_absolute_error: 0.0067 - val_loss: 2.2534e-04 - val_mean_absolute_error: 0.0109
# Epoch 25/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.0044e-05 - mean_absolute_error: 0.0058 - val_loss: 2.4839e-04 - val_mean_absolute_error: 0.0116
# Epoch 26/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.1882e-05 - mean_absolute_error: 0.0056 - val_loss: 2.6317e-04 - val_mean_absolute_error: 0.0121
# Epoch 27/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0512e-05 - mean_absolute_error: 0.0060 - val_loss: 3.0958e-04 - val_mean_absolute_error: 0.0134
# Epoch 28/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.5686e-05 - mean_absolute_error: 0.0063 - val_loss: 3.8186e-04 - val_mean_absolute_error: 0.0154
# Epoch 29/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.4980e-05 - mean_absolute_error: 0.0056 - val_loss: 2.3667e-04 - val_mean_absolute_error: 0.0113
# Epoch 30/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.4184e-05 - mean_absolute_error: 0.0064 - val_loss: 5.7334e-04 - val_mean_absolute_error: 0.0202
# Epoch 31/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.1288e-05 - mean_absolute_error: 0.0064 - val_loss: 2.8164e-04 - val_mean_absolute_error: 0.0126
# Epoch 32/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.7626e-05 - mean_absolute_error: 0.0058 - val_loss: 1.7931e-04 - val_mean_absolute_error: 0.0097
# Epoch 33/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.6759e-05 - mean_absolute_error: 0.0067 - val_loss: 2.3849e-04 - val_mean_absolute_error: 0.0114
# Epoch 34/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.2194e-05 - mean_absolute_error: 0.0064 - val_loss: 2.1669e-04 - val_mean_absolute_error: 0.0108
# Epoch 35/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.3840e-05 - mean_absolute_error: 0.0060 - val_loss: 1.7743e-04 - val_mean_absolute_error: 0.0096
# Epoch 36/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.1724e-05 - mean_absolute_error: 0.0061 - val_loss: 1.6421e-04 - val_mean_absolute_error: 0.0094
# Epoch 37/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.9276e-05 - mean_absolute_error: 0.0063 - val_loss: 2.0395e-04 - val_mean_absolute_error: 0.0104
# Epoch 38/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.4282e-05 - mean_absolute_error: 0.0061 - val_loss: 4.9397e-04 - val_mean_absolute_error: 0.0185
# Epoch 39/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0034e-04 - mean_absolute_error: 0.0070 - val_loss: 4.6469e-04 - val_mean_absolute_error: 0.0178
# Epoch 40/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.4983e-05 - mean_absolute_error: 0.0065 - val_loss: 2.7756e-04 - val_mean_absolute_error: 0.0126
# Epoch 41/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.6984e-05 - mean_absolute_error: 0.0064 - val_loss: 1.8414e-04 - val_mean_absolute_error: 0.0108
# Epoch 42/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0348e-04 - mean_absolute_error: 0.0071 - val_loss: 1.6855e-04 - val_mean_absolute_error: 0.0093
# Epoch 43/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0206e-04 - mean_absolute_error: 0.0069 - val_loss: 4.7007e-04 - val_mean_absolute_error: 0.0182
# Epoch 44/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0910e-05 - mean_absolute_error: 0.0062 - val_loss: 1.5805e-04 - val_mean_absolute_error: 0.0091
# Epoch 45/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0553e-04 - mean_absolute_error: 0.0072 - val_loss: 1.9716e-04 - val_mean_absolute_error: 0.0113
# Epoch 46/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3443e-04 - mean_absolute_error: 0.0078 - val_loss: 4.4596e-04 - val_mean_absolute_error: 0.0175
# Epoch 47/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.9865e-05 - mean_absolute_error: 0.0058 - val_loss: 2.9519e-04 - val_mean_absolute_error: 0.0134
# Epoch 48/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7458e-05 - mean_absolute_error: 0.0060 - val_loss: 3.0835e-04 - val_mean_absolute_error: 0.0137
# Epoch 49/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.2750e-05 - mean_absolute_error: 0.0058 - val_loss: 2.2186e-04 - val_mean_absolute_error: 0.0110
# Epoch 50/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.5483e-05 - mean_absolute_error: 0.0063 - val_loss: 2.1043e-04 - val_mean_absolute_error: 0.0107
# Epoch 51/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.9661e-05 - mean_absolute_error: 0.0059 - val_loss: 4.6095e-04 - val_mean_absolute_error: 0.0181
# Epoch 52/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.9950e-05 - mean_absolute_error: 0.0061 - val_loss: 1.5207e-04 - val_mean_absolute_error: 0.0088
# Epoch 53/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.8228e-05 - mean_absolute_error: 0.0057 - val_loss: 2.1948e-04 - val_mean_absolute_error: 0.0110
# Epoch 54/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.6236e-05 - mean_absolute_error: 0.0057 - val_loss: 2.4869e-04 - val_mean_absolute_error: 0.0120
# Epoch 55/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.0199e-05 - mean_absolute_error: 0.0059 - val_loss: 2.9282e-04 - val_mean_absolute_error: 0.0134
# Epoch 56/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.9521e-05 - mean_absolute_error: 0.0061 - val_loss: 1.7849e-04 - val_mean_absolute_error: 0.0097
# Epoch 57/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.3145e-05 - mean_absolute_error: 0.0056 - val_loss: 1.5884e-04 - val_mean_absolute_error: 0.0090
# Epoch 58/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2478e-05 - mean_absolute_error: 0.0052 - val_loss: 1.4195e-04 - val_mean_absolute_error: 0.0086
# Epoch 59/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.5124e-05 - mean_absolute_error: 0.0061 - val_loss: 2.4554e-04 - val_mean_absolute_error: 0.0119
# Epoch 60/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.3529e-05 - mean_absolute_error: 0.0060 - val_loss: 2.1939e-04 - val_mean_absolute_error: 0.0110
# Epoch 61/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.8998e-05 - mean_absolute_error: 0.0059 - val_loss: 1.8275e-04 - val_mean_absolute_error: 0.0098
# Epoch 62/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.7744e-05 - mean_absolute_error: 0.0056 - val_loss: 1.8436e-04 - val_mean_absolute_error: 0.0099
# Epoch 63/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4721e-05 - mean_absolute_error: 0.0055 - val_loss: 1.7586e-04 - val_mean_absolute_error: 0.0096
# Epoch 64/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.4922e-05 - mean_absolute_error: 0.0054 - val_loss: 2.4820e-04 - val_mean_absolute_error: 0.0120
# Epoch 65/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.9015e-05 - mean_absolute_error: 0.0055 - val_loss: 3.0233e-04 - val_mean_absolute_error: 0.0139
# Epoch 66/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.4117e-05 - mean_absolute_error: 0.0064 - val_loss: 2.9395e-04 - val_mean_absolute_error: 0.0136
# Epoch 67/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.8931e-05 - mean_absolute_error: 0.0060 - val_loss: 4.5485e-04 - val_mean_absolute_error: 0.0182
# Epoch 68/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.8597e-05 - mean_absolute_error: 0.0064 - val_loss: 1.7611e-04 - val_mean_absolute_error: 0.0096
# Epoch 69/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4397e-05 - mean_absolute_error: 0.0056 - val_loss: 2.5052e-04 - val_mean_absolute_error: 0.0122
# Epoch 70/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1846e-05 - mean_absolute_error: 0.0054 - val_loss: 1.3863e-04 - val_mean_absolute_error: 0.0083
# Epoch 71/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.2935e-05 - mean_absolute_error: 0.0056 - val_loss: 5.2786e-04 - val_mean_absolute_error: 0.0201
# Epoch 72/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.2355e-05 - mean_absolute_error: 0.0068 - val_loss: 1.7860e-04 - val_mean_absolute_error: 0.0097
# Epoch 73/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.2061e-05 - mean_absolute_error: 0.0051 - val_loss: 1.3691e-04 - val_mean_absolute_error: 0.0086
# Epoch 74/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2557e-05 - mean_absolute_error: 0.0055 - val_loss: 2.6814e-04 - val_mean_absolute_error: 0.0128
# Epoch 75/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.1402e-05 - mean_absolute_error: 0.0068 - val_loss: 2.3252e-04 - val_mean_absolute_error: 0.0116
# Epoch 76/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.0002e-05 - mean_absolute_error: 0.0055 - val_loss: 1.5902e-04 - val_mean_absolute_error: 0.0090
# Epoch 77/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.4126e-05 - mean_absolute_error: 0.0061 - val_loss: 1.4656e-04 - val_mean_absolute_error: 0.0086
# Epoch 78/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.0355e-05 - mean_absolute_error: 0.0058 - val_loss: 1.3711e-04 - val_mean_absolute_error: 0.0082
# Epoch 79/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.1899e-05 - mean_absolute_error: 0.0051 - val_loss: 2.0469e-04 - val_mean_absolute_error: 0.0107
# Epoch 80/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7277e-05 - mean_absolute_error: 0.0053 - val_loss: 1.5808e-04 - val_mean_absolute_error: 0.0090
# Epoch 81/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1519e-05 - mean_absolute_error: 0.0051 - val_loss: 1.3772e-04 - val_mean_absolute_error: 0.0083
# Epoch 82/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.3139e-05 - mean_absolute_error: 0.0061 - val_loss: 1.4403e-04 - val_mean_absolute_error: 0.0085
# Epoch 83/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.0115e-05 - mean_absolute_error: 0.0052 - val_loss: 2.1813e-04 - val_mean_absolute_error: 0.0112
# Epoch 84/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.1976e-05 - mean_absolute_error: 0.0050 - val_loss: 2.0815e-04 - val_mean_absolute_error: 0.0108
# Epoch 85/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.2512e-05 - mean_absolute_error: 0.0062 - val_loss: 2.5257e-04 - val_mean_absolute_error: 0.0125
# Epoch 86/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2405e-05 - mean_absolute_error: 0.0052 - val_loss: 1.4655e-04 - val_mean_absolute_error: 0.0093
# Epoch 87/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.6031e-05 - mean_absolute_error: 0.0055 - val_loss: 1.2790e-04 - val_mean_absolute_error: 0.0081
# Epoch 88/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.0800e-05 - mean_absolute_error: 0.0054 - val_loss: 2.5145e-04 - val_mean_absolute_error: 0.0124
# Epoch 89/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9427e-05 - mean_absolute_error: 0.0056 - val_loss: 1.9510e-04 - val_mean_absolute_error: 0.0104
# Epoch 90/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.8481e-05 - mean_absolute_error: 0.0056 - val_loss: 2.2788e-04 - val_mean_absolute_error: 0.0116
# Epoch 91/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.7912e-05 - mean_absolute_error: 0.0053 - val_loss: 1.6197e-04 - val_mean_absolute_error: 0.0098
# Epoch 92/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.5979e-05 - mean_absolute_error: 0.0053 - val_loss: 2.0905e-04 - val_mean_absolute_error: 0.0109
# Epoch 93/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.7770e-05 - mean_absolute_error: 0.0049 - val_loss: 1.2654e-04 - val_mean_absolute_error: 0.0081
# Epoch 94/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.3309e-05 - mean_absolute_error: 0.0052 - val_loss: 1.5571e-04 - val_mean_absolute_error: 0.0089
# Epoch 95/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.9574e-05 - mean_absolute_error: 0.0051 - val_loss: 1.7597e-04 - val_mean_absolute_error: 0.0096
# Epoch 96/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.5132e-05 - mean_absolute_error: 0.0058 - val_loss: 3.2205e-04 - val_mean_absolute_error: 0.0149
# Epoch 97/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7625e-05 - mean_absolute_error: 0.0066 - val_loss: 1.5927e-04 - val_mean_absolute_error: 0.0090
# Epoch 98/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.3864e-05 - mean_absolute_error: 0.0059 - val_loss: 1.2747e-04 - val_mean_absolute_error: 0.0079
# Epoch 99/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3711e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3338e-04 - val_mean_absolute_error: 0.0085
# Epoch 100/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 8.0730e-05 - mean_absolute_error: 0.0060 - val_loss: 2.0800e-04 - val_mean_absolute_error: 0.0109
# Epoch 101/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.9302e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2828e-04 - val_mean_absolute_error: 0.0079
# Epoch 102/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.0519e-05 - mean_absolute_error: 0.0057 - val_loss: 1.8709e-04 - val_mean_absolute_error: 0.0101
# Epoch 103/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.8762e-05 - mean_absolute_error: 0.0055 - val_loss: 1.3182e-04 - val_mean_absolute_error: 0.0084
# Epoch 104/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1425e-05 - mean_absolute_error: 0.0050 - val_loss: 1.6533e-04 - val_mean_absolute_error: 0.0093
# Epoch 105/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.5399e-05 - mean_absolute_error: 0.0055 - val_loss: 2.0036e-04 - val_mean_absolute_error: 0.0106
# Epoch 106/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.9865e-05 - mean_absolute_error: 0.0056 - val_loss: 1.2712e-04 - val_mean_absolute_error: 0.0079
# Epoch 107/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.3355e-05 - mean_absolute_error: 0.0052 - val_loss: 1.2524e-04 - val_mean_absolute_error: 0.0079
# Epoch 108/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.9109e-05 - mean_absolute_error: 0.0057 - val_loss: 1.5028e-04 - val_mean_absolute_error: 0.0087
# Epoch 109/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.4533e-05 - mean_absolute_error: 0.0051 - val_loss: 4.2931e-04 - val_mean_absolute_error: 0.0179
# Epoch 110/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.6984e-05 - mean_absolute_error: 0.0065 - val_loss: 2.3263e-04 - val_mean_absolute_error: 0.0119
# Epoch 111/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.6396e-05 - mean_absolute_error: 0.0055 - val_loss: 3.2065e-04 - val_mean_absolute_error: 0.0149
# Epoch 112/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 8.7238e-05 - mean_absolute_error: 0.0064 - val_loss: 2.0302e-04 - val_mean_absolute_error: 0.0108
# Epoch 113/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1902e-05 - mean_absolute_error: 0.0052 - val_loss: 1.2350e-04 - val_mean_absolute_error: 0.0079
# Epoch 114/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8310e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2445e-04 - val_mean_absolute_error: 0.0078
# Epoch 115/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.2631e-05 - mean_absolute_error: 0.0052 - val_loss: 2.7676e-04 - val_mean_absolute_error: 0.0135
# Epoch 116/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.3807e-05 - mean_absolute_error: 0.0053 - val_loss: 1.6443e-04 - val_mean_absolute_error: 0.0092
# Epoch 117/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8367e-05 - mean_absolute_error: 0.0051 - val_loss: 1.4352e-04 - val_mean_absolute_error: 0.0089
# Epoch 118/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.4001e-05 - mean_absolute_error: 0.0056 - val_loss: 1.4156e-04 - val_mean_absolute_error: 0.0083
# Epoch 119/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3250e-05 - mean_absolute_error: 0.0051 - val_loss: 1.3344e-04 - val_mean_absolute_error: 0.0081
# Epoch 120/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.2878e-05 - mean_absolute_error: 0.0060 - val_loss: 1.2695e-04 - val_mean_absolute_error: 0.0078
# Epoch 121/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.2322e-05 - mean_absolute_error: 0.0051 - val_loss: 2.6512e-04 - val_mean_absolute_error: 0.0138
# Epoch 122/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.1806e-05 - mean_absolute_error: 0.0063 - val_loss: 1.2422e-04 - val_mean_absolute_error: 0.0079
# Epoch 123/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.5510e-05 - mean_absolute_error: 0.0049 - val_loss: 1.3011e-04 - val_mean_absolute_error: 0.0083
# Epoch 124/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.7324e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2647e-04 - val_mean_absolute_error: 0.0080
# Epoch 125/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7807e-05 - mean_absolute_error: 0.0054 - val_loss: 1.3087e-04 - val_mean_absolute_error: 0.0084
# Epoch 126/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.5158e-05 - mean_absolute_error: 0.0053 - val_loss: 1.3532e-04 - val_mean_absolute_error: 0.0081
# Epoch 127/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4335e-05 - mean_absolute_error: 0.0048 - val_loss: 2.1558e-04 - val_mean_absolute_error: 0.0113
# Epoch 128/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.2856e-05 - mean_absolute_error: 0.0052 - val_loss: 4.3341e-04 - val_mean_absolute_error: 0.0180
# Epoch 129/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.0411e-05 - mean_absolute_error: 0.0067 - val_loss: 2.5107e-04 - val_mean_absolute_error: 0.0127
# Epoch 130/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.7674e-05 - mean_absolute_error: 0.0051 - val_loss: 1.2329e-04 - val_mean_absolute_error: 0.0078
# Epoch 131/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.4069e-05 - mean_absolute_error: 0.0051 - val_loss: 1.8278e-04 - val_mean_absolute_error: 0.0100
# Epoch 132/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6362e-05 - mean_absolute_error: 0.0052 - val_loss: 1.7378e-04 - val_mean_absolute_error: 0.0096
# Epoch 133/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8554e-05 - mean_absolute_error: 0.0051 - val_loss: 1.4401e-04 - val_mean_absolute_error: 0.0085
# Epoch 134/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.5379e-05 - mean_absolute_error: 0.0060 - val_loss: 1.2616e-04 - val_mean_absolute_error: 0.0078
# Epoch 135/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.5041e-05 - mean_absolute_error: 0.0052 - val_loss: 1.5015e-04 - val_mean_absolute_error: 0.0088
# Epoch 136/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.9562e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3030e-04 - val_mean_absolute_error: 0.0079
# Epoch 137/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3565e-05 - mean_absolute_error: 0.0054 - val_loss: 1.3381e-04 - val_mean_absolute_error: 0.0085
# Epoch 138/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.4992e-05 - mean_absolute_error: 0.0060 - val_loss: 3.8594e-04 - val_mean_absolute_error: 0.0168
# Epoch 139/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.3126e-05 - mean_absolute_error: 0.0065 - val_loss: 2.7778e-04 - val_mean_absolute_error: 0.0136
# Epoch 140/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.6636e-05 - mean_absolute_error: 0.0055 - val_loss: 1.2664e-04 - val_mean_absolute_error: 0.0081
# Epoch 141/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.0050e-05 - mean_absolute_error: 0.0056 - val_loss: 1.9166e-04 - val_mean_absolute_error: 0.0105
# Epoch 142/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.9887e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3280e-04 - val_mean_absolute_error: 0.0080
# Epoch 143/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2321e-05 - mean_absolute_error: 0.0045 - val_loss: 2.0245e-04 - val_mean_absolute_error: 0.0108
# Epoch 144/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6206e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2549e-04 - val_mean_absolute_error: 0.0078
# Epoch 145/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.6985e-05 - mean_absolute_error: 0.0049 - val_loss: 1.5618e-04 - val_mean_absolute_error: 0.0090
# Epoch 146/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.9593e-05 - mean_absolute_error: 0.0055 - val_loss: 1.2619e-04 - val_mean_absolute_error: 0.0078
# Epoch 147/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.6886e-05 - mean_absolute_error: 0.0049 - val_loss: 2.1544e-04 - val_mean_absolute_error: 0.0113
# Epoch 148/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.9857e-05 - mean_absolute_error: 0.0054 - val_loss: 1.9666e-04 - val_mean_absolute_error: 0.0106
# Epoch 149/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.1199e-05 - mean_absolute_error: 0.0055 - val_loss: 1.4257e-04 - val_mean_absolute_error: 0.0090
# Epoch 150/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.7468e-05 - mean_absolute_error: 0.0059 - val_loss: 1.5716e-04 - val_mean_absolute_error: 0.0096
# Epoch 151/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.9365e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2869e-04 - val_mean_absolute_error: 0.0082
# Epoch 152/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.3334e-05 - mean_absolute_error: 0.0056 - val_loss: 1.5128e-04 - val_mean_absolute_error: 0.0087
# Epoch 153/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7382e-05 - mean_absolute_error: 0.0049 - val_loss: 2.6655e-04 - val_mean_absolute_error: 0.0132
# Epoch 154/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6496e-05 - mean_absolute_error: 0.0056 - val_loss: 1.2533e-04 - val_mean_absolute_error: 0.0078
# Epoch 155/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1227e-05 - mean_absolute_error: 0.0055 - val_loss: 1.3945e-04 - val_mean_absolute_error: 0.0083
# Epoch 156/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.5657e-05 - mean_absolute_error: 0.0057 - val_loss: 1.9894e-04 - val_mean_absolute_error: 0.0107
# Epoch 157/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.4074e-05 - mean_absolute_error: 0.0055 - val_loss: 2.2943e-04 - val_mean_absolute_error: 0.0119
# Epoch 158/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.9227e-05 - mean_absolute_error: 0.0061 - val_loss: 1.3800e-04 - val_mean_absolute_error: 0.0082
# Epoch 159/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.1076e-05 - mean_absolute_error: 0.0056 - val_loss: 1.2952e-04 - val_mean_absolute_error: 0.0083
# Epoch 160/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.0159e-05 - mean_absolute_error: 0.0052 - val_loss: 2.2951e-04 - val_mean_absolute_error: 0.0119
# Epoch 161/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7795e-05 - mean_absolute_error: 0.0065 - val_loss: 1.2797e-04 - val_mean_absolute_error: 0.0079
# Epoch 162/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7614e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2992e-04 - val_mean_absolute_error: 0.0082
# Epoch 163/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1380e-05 - mean_absolute_error: 0.0057 - val_loss: 1.3040e-04 - val_mean_absolute_error: 0.0079
# Epoch 164/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0740e-05 - mean_absolute_error: 0.0054 - val_loss: 2.1068e-04 - val_mean_absolute_error: 0.0112
# Epoch 165/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3256e-05 - mean_absolute_error: 0.0054 - val_loss: 2.8014e-04 - val_mean_absolute_error: 0.0137
# Epoch 166/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.9096e-05 - mean_absolute_error: 0.0062 - val_loss: 1.3760e-04 - val_mean_absolute_error: 0.0082
# Epoch 167/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.7567e-05 - mean_absolute_error: 0.0051 - val_loss: 1.2482e-04 - val_mean_absolute_error: 0.0080
# Epoch 168/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5854e-05 - mean_absolute_error: 0.0048 - val_loss: 1.8297e-04 - val_mean_absolute_error: 0.0101
# Epoch 169/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.0483e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2828e-04 - val_mean_absolute_error: 0.0082
# Epoch 170/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.3501e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2467e-04 - val_mean_absolute_error: 0.0078
# Epoch 171/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4281e-05 - mean_absolute_error: 0.0054 - val_loss: 1.5146e-04 - val_mean_absolute_error: 0.0088
# Epoch 172/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4876e-05 - mean_absolute_error: 0.0052 - val_loss: 1.2751e-04 - val_mean_absolute_error: 0.0078
# Epoch 173/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6720e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2582e-04 - val_mean_absolute_error: 0.0078
# Epoch 174/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7116e-05 - mean_absolute_error: 0.0051 - val_loss: 1.2676e-04 - val_mean_absolute_error: 0.0080
# Epoch 175/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.8296e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2556e-04 - val_mean_absolute_error: 0.0079
# Epoch 176/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.8410e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2749e-04 - val_mean_absolute_error: 0.0080
# Epoch 177/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.4984e-05 - mean_absolute_error: 0.0052 - val_loss: 2.0462e-04 - val_mean_absolute_error: 0.0110
# Epoch 178/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.3081e-05 - mean_absolute_error: 0.0051 - val_loss: 2.5340e-04 - val_mean_absolute_error: 0.0127
# Epoch 179/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.0699e-05 - mean_absolute_error: 0.0051 - val_loss: 1.2914e-04 - val_mean_absolute_error: 0.0079
# Epoch 180/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4252e-05 - mean_absolute_error: 0.0048 - val_loss: 1.2968e-04 - val_mean_absolute_error: 0.0079
# Epoch 181/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6919e-05 - mean_absolute_error: 0.0049 - val_loss: 2.1824e-04 - val_mean_absolute_error: 0.0115
# Epoch 182/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0533e-05 - mean_absolute_error: 0.0055 - val_loss: 1.4970e-04 - val_mean_absolute_error: 0.0091
# Epoch 183/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.1464e-05 - mean_absolute_error: 0.0052 - val_loss: 1.4160e-04 - val_mean_absolute_error: 0.0087
# Epoch 184/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6062e-05 - mean_absolute_error: 0.0057 - val_loss: 1.3074e-04 - val_mean_absolute_error: 0.0080
# Epoch 185/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8188e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2609e-04 - val_mean_absolute_error: 0.0079
# Epoch 186/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5697e-05 - mean_absolute_error: 0.0053 - val_loss: 1.4860e-04 - val_mean_absolute_error: 0.0086
# Epoch 187/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5515e-05 - mean_absolute_error: 0.0051 - val_loss: 2.1791e-04 - val_mean_absolute_error: 0.0115
# Epoch 188/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.1451e-05 - mean_absolute_error: 0.0053 - val_loss: 1.4257e-04 - val_mean_absolute_error: 0.0088
# Epoch 189/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2270e-05 - mean_absolute_error: 0.0054 - val_loss: 1.3016e-04 - val_mean_absolute_error: 0.0080
# Epoch 190/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.9698e-05 - mean_absolute_error: 0.0050 - val_loss: 1.9118e-04 - val_mean_absolute_error: 0.0111
# Epoch 191/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.3280e-05 - mean_absolute_error: 0.0057 - val_loss: 1.2714e-04 - val_mean_absolute_error: 0.0080
# Epoch 192/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6528e-05 - mean_absolute_error: 0.0052 - val_loss: 1.2658e-04 - val_mean_absolute_error: 0.0081
# Epoch 193/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.4369e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2600e-04 - val_mean_absolute_error: 0.0078
# Epoch 194/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9736e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2837e-04 - val_mean_absolute_error: 0.0079
# Epoch 195/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.5495e-05 - mean_absolute_error: 0.0058 - val_loss: 1.7596e-04 - val_mean_absolute_error: 0.0098
# Epoch 196/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.7657e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2974e-04 - val_mean_absolute_error: 0.0082
# Epoch 197/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.4038e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2758e-04 - val_mean_absolute_error: 0.0079
# Epoch 198/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4620e-05 - mean_absolute_error: 0.0049 - val_loss: 1.2848e-04 - val_mean_absolute_error: 0.0079
# Epoch 199/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1101e-05 - mean_absolute_error: 0.0053 - val_loss: 2.7489e-04 - val_mean_absolute_error: 0.0135
# Epoch 200/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4016e-05 - mean_absolute_error: 0.0053 - val_loss: 1.3898e-04 - val_mean_absolute_error: 0.0083

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 120
# 131

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 3809463.2534688315
# RMSE: 1951.7846329625693
# MAE: 1427.613671875
# MAPE: 1.6427097970854798 %
#
# Model evalution on validate set
# MSE: 8594908.241514096
# RMSE: 2931.7073935701865
# MAE: 2098.84420196281
# MAPE: 1.843496223313348 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 623ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step

# %%
y_pred_30_days
# Out:
# array([[130751.38 ],
#        [131085.8  ],
#        [130828.81 ],
#        [130766.75 ],
#        [130926.555],
#        [130881.05 ],
#        [130903.38 ],
#        [130905.44 ],
#        [130899.08 ],
#        [130902.445],
#        [130900.86 ],
#        [130900.96 ],
#        [130901.2  ],
#        [130901.   ],
#        [130901.1  ],
#        [130901.07 ],
#        [130901.1  ],
#        [130901.1  ],
#        [130901.1  ],
#        [130901.086],
#        [130901.1  ],
#        [130901.1  ],
#        [130901.086],
#        [130901.1  ],
#        [130901.12 ],
#        [130901.086],
#        [130901.086],
#        [130901.1  ],
#        [130901.086],
#        [130901.12 ],
#        [130901.086]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Forecast Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Forecast the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
