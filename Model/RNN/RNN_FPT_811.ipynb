# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: FPT - Test/Train/Vaildation: 80/10/10
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1938.4103665573612
# - MAE: 1416.5708333333334
# - MAPE: 1.6295596940079111 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 2  # 8 1 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01  19270
# 2019-03-04  19440
# 2019-03-05  19390
# 2019-03-06  19270
# 2019-03-07  19330

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((1039, 10), (1039,), (120, 10), (120,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 11s 51ms/step - loss: 0.0082 - mean_absolute_error: 0.0594 - val_loss: 9.6798e-04 - val_mean_absolute_error: 0.0258
# Epoch 2/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8558e-04 - mean_absolute_error: 0.0139 - val_loss: 7.1119e-04 - val_mean_absolute_error: 0.0194
# Epoch 3/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9313e-04 - mean_absolute_error: 0.0091 - val_loss: 5.2414e-04 - val_mean_absolute_error: 0.0165
# Epoch 4/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7505e-04 - mean_absolute_error: 0.0089 - val_loss: 7.0174e-04 - val_mean_absolute_error: 0.0204
# Epoch 5/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3739e-04 - mean_absolute_error: 0.0079 - val_loss: 3.2208e-04 - val_mean_absolute_error: 0.0134
# Epoch 6/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6779e-04 - mean_absolute_error: 0.0083 - val_loss: 2.9943e-04 - val_mean_absolute_error: 0.0125
# Epoch 7/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1471e-04 - mean_absolute_error: 0.0071 - val_loss: 6.5390e-04 - val_mean_absolute_error: 0.0213
# Epoch 8/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.1379e-04 - mean_absolute_error: 0.0070 - val_loss: 2.3651e-04 - val_mean_absolute_error: 0.0111
# Epoch 9/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0385e-04 - mean_absolute_error: 0.0069 - val_loss: 2.6839e-04 - val_mean_absolute_error: 0.0120
# Epoch 10/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.4029e-05 - mean_absolute_error: 0.0062 - val_loss: 5.4348e-04 - val_mean_absolute_error: 0.0194
# Epoch 11/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.4786e-05 - mean_absolute_error: 0.0062 - val_loss: 3.9697e-04 - val_mean_absolute_error: 0.0159
# Epoch 12/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.9061e-05 - mean_absolute_error: 0.0066 - val_loss: 2.2472e-04 - val_mean_absolute_error: 0.0108
# Epoch 13/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0487e-04 - mean_absolute_error: 0.0067 - val_loss: 2.1098e-04 - val_mean_absolute_error: 0.0104
# Epoch 14/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0329e-04 - mean_absolute_error: 0.0067 - val_loss: 2.7150e-04 - val_mean_absolute_error: 0.0123
# Epoch 15/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.0100e-04 - mean_absolute_error: 0.0065 - val_loss: 2.2205e-04 - val_mean_absolute_error: 0.0109
# Epoch 16/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.5085e-05 - mean_absolute_error: 0.0062 - val_loss: 3.2294e-04 - val_mean_absolute_error: 0.0141
# Epoch 17/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.3427e-05 - mean_absolute_error: 0.0065 - val_loss: 4.3046e-04 - val_mean_absolute_error: 0.0170
# Epoch 18/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0242e-04 - mean_absolute_error: 0.0067 - val_loss: 2.6777e-04 - val_mean_absolute_error: 0.0124
# Epoch 19/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.4366e-05 - mean_absolute_error: 0.0057 - val_loss: 1.7364e-04 - val_mean_absolute_error: 0.0095
# Epoch 20/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3754e-04 - mean_absolute_error: 0.0082 - val_loss: 4.1644e-04 - val_mean_absolute_error: 0.0167
# Epoch 21/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.1130e-05 - mean_absolute_error: 0.0063 - val_loss: 1.7592e-04 - val_mean_absolute_error: 0.0099
# Epoch 22/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.1881e-05 - mean_absolute_error: 0.0063 - val_loss: 1.6762e-04 - val_mean_absolute_error: 0.0094
# Epoch 23/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.6821e-05 - mean_absolute_error: 0.0066 - val_loss: 1.6459e-04 - val_mean_absolute_error: 0.0091
# Epoch 24/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1112e-04 - mean_absolute_error: 0.0070 - val_loss: 1.9948e-04 - val_mean_absolute_error: 0.0103
# Epoch 25/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.3319e-05 - mean_absolute_error: 0.0065 - val_loss: 2.5523e-04 - val_mean_absolute_error: 0.0122
# Epoch 26/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.8720e-05 - mean_absolute_error: 0.0058 - val_loss: 1.7342e-04 - val_mean_absolute_error: 0.0095
# Epoch 27/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9542e-05 - mean_absolute_error: 0.0064 - val_loss: 1.6557e-04 - val_mean_absolute_error: 0.0096
# Epoch 28/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.4239e-05 - mean_absolute_error: 0.0066 - val_loss: 1.7109e-04 - val_mean_absolute_error: 0.0094
# Epoch 29/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 9.7481e-05 - mean_absolute_error: 0.0067 - val_loss: 1.6960e-04 - val_mean_absolute_error: 0.0093
# Epoch 30/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2216e-04 - mean_absolute_error: 0.0078 - val_loss: 1.9697e-04 - val_mean_absolute_error: 0.0103
# Epoch 31/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 8.6510e-05 - mean_absolute_error: 0.0060 - val_loss: 1.5222e-04 - val_mean_absolute_error: 0.0089
# Epoch 32/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.4892e-05 - mean_absolute_error: 0.0066 - val_loss: 3.8506e-04 - val_mean_absolute_error: 0.0162
# Epoch 33/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.8190e-05 - mean_absolute_error: 0.0063 - val_loss: 1.5304e-04 - val_mean_absolute_error: 0.0090
# Epoch 34/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.3592e-05 - mean_absolute_error: 0.0058 - val_loss: 4.5382e-04 - val_mean_absolute_error: 0.0181
# Epoch 35/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.3323e-05 - mean_absolute_error: 0.0063 - val_loss: 1.6596e-04 - val_mean_absolute_error: 0.0099
# Epoch 36/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.3840e-05 - mean_absolute_error: 0.0061 - val_loss: 2.0227e-04 - val_mean_absolute_error: 0.0105
# Epoch 37/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.4094e-05 - mean_absolute_error: 0.0059 - val_loss: 4.0597e-04 - val_mean_absolute_error: 0.0169
# Epoch 38/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.2976e-05 - mean_absolute_error: 0.0065 - val_loss: 3.2411e-04 - val_mean_absolute_error: 0.0146
# Epoch 39/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.0301e-05 - mean_absolute_error: 0.0057 - val_loss: 2.3753e-04 - val_mean_absolute_error: 0.0119
# Epoch 40/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2868e-04 - mean_absolute_error: 0.0079 - val_loss: 1.6142e-04 - val_mean_absolute_error: 0.0092
# Epoch 41/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.6003e-05 - mean_absolute_error: 0.0061 - val_loss: 1.4379e-04 - val_mean_absolute_error: 0.0085
# Epoch 42/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.6696e-05 - mean_absolute_error: 0.0056 - val_loss: 1.9019e-04 - val_mean_absolute_error: 0.0102
# Epoch 43/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.6512e-05 - mean_absolute_error: 0.0056 - val_loss: 1.5499e-04 - val_mean_absolute_error: 0.0089
# Epoch 44/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.8253e-05 - mean_absolute_error: 0.0064 - val_loss: 7.6687e-04 - val_mean_absolute_error: 0.0252
# Epoch 45/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2352e-04 - mean_absolute_error: 0.0076 - val_loss: 4.7994e-04 - val_mean_absolute_error: 0.0190
# Epoch 46/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.1074e-05 - mean_absolute_error: 0.0065 - val_loss: 4.8732e-04 - val_mean_absolute_error: 0.0192
# Epoch 47/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.7076e-05 - mean_absolute_error: 0.0061 - val_loss: 1.3801e-04 - val_mean_absolute_error: 0.0085
# Epoch 48/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.7888e-05 - mean_absolute_error: 0.0053 - val_loss: 1.7634e-04 - val_mean_absolute_error: 0.0098
# Epoch 49/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 7.0595e-05 - mean_absolute_error: 0.0052 - val_loss: 2.1590e-04 - val_mean_absolute_error: 0.0112
# Epoch 50/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1378e-05 - mean_absolute_error: 0.0054 - val_loss: 1.3837e-04 - val_mean_absolute_error: 0.0084
# Epoch 51/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.9447e-05 - mean_absolute_error: 0.0054 - val_loss: 2.1675e-04 - val_mean_absolute_error: 0.0112
# Epoch 52/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.8997e-05 - mean_absolute_error: 0.0055 - val_loss: 1.3403e-04 - val_mean_absolute_error: 0.0084
# Epoch 53/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.5789e-05 - mean_absolute_error: 0.0065 - val_loss: 2.2762e-04 - val_mean_absolute_error: 0.0117
# Epoch 54/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6437e-05 - mean_absolute_error: 0.0058 - val_loss: 1.6914e-04 - val_mean_absolute_error: 0.0095
# Epoch 55/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6799e-05 - mean_absolute_error: 0.0053 - val_loss: 1.6658e-04 - val_mean_absolute_error: 0.0100
# Epoch 56/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.2196e-05 - mean_absolute_error: 0.0062 - val_loss: 2.0815e-04 - val_mean_absolute_error: 0.0110
# Epoch 57/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2806e-05 - mean_absolute_error: 0.0058 - val_loss: 1.3443e-04 - val_mean_absolute_error: 0.0082
# Epoch 58/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.0231e-05 - mean_absolute_error: 0.0050 - val_loss: 2.0034e-04 - val_mean_absolute_error: 0.0107
# Epoch 59/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.2906e-05 - mean_absolute_error: 0.0058 - val_loss: 3.9894e-04 - val_mean_absolute_error: 0.0171
# Epoch 60/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.7198e-05 - mean_absolute_error: 0.0059 - val_loss: 1.6823e-04 - val_mean_absolute_error: 0.0095
# Epoch 61/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.4302e-05 - mean_absolute_error: 0.0059 - val_loss: 2.1206e-04 - val_mean_absolute_error: 0.0112
# Epoch 62/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.1498e-05 - mean_absolute_error: 0.0066 - val_loss: 3.7459e-04 - val_mean_absolute_error: 0.0165
# Epoch 63/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.8279e-05 - mean_absolute_error: 0.0063 - val_loss: 2.0021e-04 - val_mean_absolute_error: 0.0107
# Epoch 64/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1734e-05 - mean_absolute_error: 0.0056 - val_loss: 1.5062e-04 - val_mean_absolute_error: 0.0088
# Epoch 65/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.7716e-05 - mean_absolute_error: 0.0053 - val_loss: 3.5162e-04 - val_mean_absolute_error: 0.0158
# Epoch 66/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.7040e-05 - mean_absolute_error: 0.0059 - val_loss: 1.8609e-04 - val_mean_absolute_error: 0.0102
# Epoch 67/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.0609e-05 - mean_absolute_error: 0.0053 - val_loss: 1.5296e-04 - val_mean_absolute_error: 0.0094
# Epoch 68/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.6143e-05 - mean_absolute_error: 0.0055 - val_loss: 1.3993e-04 - val_mean_absolute_error: 0.0088
# Epoch 69/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.8716e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3965e-04 - val_mean_absolute_error: 0.0083
# Epoch 70/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.0044e-05 - mean_absolute_error: 0.0050 - val_loss: 1.7096e-04 - val_mean_absolute_error: 0.0101
# Epoch 71/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.9401e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2732e-04 - val_mean_absolute_error: 0.0080
# Epoch 72/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.9460e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2671e-04 - val_mean_absolute_error: 0.0081
# Epoch 73/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.7611e-05 - mean_absolute_error: 0.0050 - val_loss: 1.4765e-04 - val_mean_absolute_error: 0.0087
# Epoch 74/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.8690e-05 - mean_absolute_error: 0.0049 - val_loss: 3.0875e-04 - val_mean_absolute_error: 0.0146
# Epoch 75/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.8455e-05 - mean_absolute_error: 0.0061 - val_loss: 1.3078e-04 - val_mean_absolute_error: 0.0081
# Epoch 76/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.8877e-05 - mean_absolute_error: 0.0065 - val_loss: 1.3370e-04 - val_mean_absolute_error: 0.0085
# Epoch 77/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.3429e-05 - mean_absolute_error: 0.0057 - val_loss: 1.6109e-04 - val_mean_absolute_error: 0.0092
# Epoch 78/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1987e-05 - mean_absolute_error: 0.0050 - val_loss: 3.7153e-04 - val_mean_absolute_error: 0.0164
# Epoch 79/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.6013e-05 - mean_absolute_error: 0.0065 - val_loss: 1.3694e-04 - val_mean_absolute_error: 0.0082
# Epoch 80/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.4452e-05 - mean_absolute_error: 0.0047 - val_loss: 1.6988e-04 - val_mean_absolute_error: 0.0096
# Epoch 81/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.1884e-05 - mean_absolute_error: 0.0049 - val_loss: 1.2552e-04 - val_mean_absolute_error: 0.0080
# Epoch 82/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.1917e-05 - mean_absolute_error: 0.0050 - val_loss: 2.3655e-04 - val_mean_absolute_error: 0.0121
# Epoch 83/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.5877e-05 - mean_absolute_error: 0.0059 - val_loss: 1.2844e-04 - val_mean_absolute_error: 0.0080
# Epoch 84/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.5549e-05 - mean_absolute_error: 0.0051 - val_loss: 1.5961e-04 - val_mean_absolute_error: 0.0092
# Epoch 85/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.0753e-05 - mean_absolute_error: 0.0049 - val_loss: 1.6093e-04 - val_mean_absolute_error: 0.0092
# Epoch 86/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4879e-05 - mean_absolute_error: 0.0048 - val_loss: 2.2744e-04 - val_mean_absolute_error: 0.0118
# Epoch 87/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1528e-05 - mean_absolute_error: 0.0057 - val_loss: 1.3503e-04 - val_mean_absolute_error: 0.0085
# Epoch 88/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8519e-05 - mean_absolute_error: 0.0054 - val_loss: 2.3112e-04 - val_mean_absolute_error: 0.0125
# Epoch 89/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.5221e-05 - mean_absolute_error: 0.0070 - val_loss: 1.3159e-04 - val_mean_absolute_error: 0.0084
# Epoch 90/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.2003e-05 - mean_absolute_error: 0.0057 - val_loss: 1.6767e-04 - val_mean_absolute_error: 0.0096
# Epoch 91/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6790e-05 - mean_absolute_error: 0.0053 - val_loss: 1.5136e-04 - val_mean_absolute_error: 0.0089
# Epoch 92/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3965e-05 - mean_absolute_error: 0.0053 - val_loss: 1.4822e-04 - val_mean_absolute_error: 0.0087
# Epoch 93/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1431e-05 - mean_absolute_error: 0.0051 - val_loss: 1.6322e-04 - val_mean_absolute_error: 0.0094
# Epoch 94/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2569e-05 - mean_absolute_error: 0.0056 - val_loss: 1.9205e-04 - val_mean_absolute_error: 0.0105
# Epoch 95/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3131e-05 - mean_absolute_error: 0.0052 - val_loss: 1.4971e-04 - val_mean_absolute_error: 0.0088
# Epoch 96/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.7415e-05 - mean_absolute_error: 0.0058 - val_loss: 1.3941e-04 - val_mean_absolute_error: 0.0088
# Epoch 97/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 7.9095e-05 - mean_absolute_error: 0.0064 - val_loss: 1.2562e-04 - val_mean_absolute_error: 0.0079
# Epoch 98/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.6879e-05 - mean_absolute_error: 0.0056 - val_loss: 1.6871e-04 - val_mean_absolute_error: 0.0100
# Epoch 99/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7716e-05 - mean_absolute_error: 0.0051 - val_loss: 1.3070e-04 - val_mean_absolute_error: 0.0083
# Epoch 100/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.6373e-05 - mean_absolute_error: 0.0054 - val_loss: 1.4665e-04 - val_mean_absolute_error: 0.0086
# Epoch 101/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.5586e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2460e-04 - val_mean_absolute_error: 0.0079
# Epoch 102/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.2759e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2917e-04 - val_mean_absolute_error: 0.0082
# Epoch 103/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.4260e-05 - mean_absolute_error: 0.0061 - val_loss: 2.3524e-04 - val_mean_absolute_error: 0.0121
# Epoch 104/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.8044e-05 - mean_absolute_error: 0.0051 - val_loss: 1.6510e-04 - val_mean_absolute_error: 0.0095
# Epoch 105/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.2151e-05 - mean_absolute_error: 0.0059 - val_loss: 3.4460e-04 - val_mean_absolute_error: 0.0162
# Epoch 106/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.2720e-05 - mean_absolute_error: 0.0068 - val_loss: 1.8256e-04 - val_mean_absolute_error: 0.0106
# Epoch 107/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.3904e-05 - mean_absolute_error: 0.0055 - val_loss: 1.2427e-04 - val_mean_absolute_error: 0.0079
# Epoch 108/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 7.0006e-05 - mean_absolute_error: 0.0057 - val_loss: 1.2758e-04 - val_mean_absolute_error: 0.0079
# Epoch 109/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7995e-05 - mean_absolute_error: 0.0057 - val_loss: 2.1862e-04 - val_mean_absolute_error: 0.0115
# Epoch 110/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.7241e-05 - mean_absolute_error: 0.0057 - val_loss: 2.1257e-04 - val_mean_absolute_error: 0.0119
# Epoch 111/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.1439e-05 - mean_absolute_error: 0.0059 - val_loss: 2.4255e-04 - val_mean_absolute_error: 0.0124
# Epoch 112/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.3819e-05 - mean_absolute_error: 0.0052 - val_loss: 1.2441e-04 - val_mean_absolute_error: 0.0080
# Epoch 113/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.0047e-05 - mean_absolute_error: 0.0056 - val_loss: 1.2382e-04 - val_mean_absolute_error: 0.0078
# Epoch 114/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.0820e-05 - mean_absolute_error: 0.0062 - val_loss: 1.2589e-04 - val_mean_absolute_error: 0.0080
# Epoch 115/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7071e-05 - mean_absolute_error: 0.0049 - val_loss: 1.6201e-04 - val_mean_absolute_error: 0.0093
# Epoch 116/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.0070e-05 - mean_absolute_error: 0.0053 - val_loss: 1.3075e-04 - val_mean_absolute_error: 0.0080
# Epoch 117/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.7956e-05 - mean_absolute_error: 0.0052 - val_loss: 1.2654e-04 - val_mean_absolute_error: 0.0079
# Epoch 118/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.6613e-05 - mean_absolute_error: 0.0051 - val_loss: 2.9294e-04 - val_mean_absolute_error: 0.0141
# Epoch 119/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.5691e-05 - mean_absolute_error: 0.0055 - val_loss: 1.3752e-04 - val_mean_absolute_error: 0.0082
# Epoch 120/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.7045e-05 - mean_absolute_error: 0.0051 - val_loss: 1.7033e-04 - val_mean_absolute_error: 0.0097
# Epoch 121/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2521e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2992e-04 - val_mean_absolute_error: 0.0079
# Epoch 122/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8400e-05 - mean_absolute_error: 0.0055 - val_loss: 1.4459e-04 - val_mean_absolute_error: 0.0085
# Epoch 123/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.6429e-05 - mean_absolute_error: 0.0049 - val_loss: 1.3155e-04 - val_mean_absolute_error: 0.0083
# Epoch 124/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1364e-05 - mean_absolute_error: 0.0052 - val_loss: 2.0353e-04 - val_mean_absolute_error: 0.0109
# Epoch 125/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7395e-05 - mean_absolute_error: 0.0052 - val_loss: 1.4070e-04 - val_mean_absolute_error: 0.0083
# Epoch 126/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.5343e-05 - mean_absolute_error: 0.0053 - val_loss: 1.9471e-04 - val_mean_absolute_error: 0.0106
# Epoch 127/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.3992e-05 - mean_absolute_error: 0.0058 - val_loss: 1.7086e-04 - val_mean_absolute_error: 0.0097
# Epoch 128/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2383e-05 - mean_absolute_error: 0.0058 - val_loss: 1.2516e-04 - val_mean_absolute_error: 0.0078
# Epoch 129/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.3024e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2802e-04 - val_mean_absolute_error: 0.0079
# Epoch 130/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.1408e-05 - mean_absolute_error: 0.0054 - val_loss: 1.6335e-04 - val_mean_absolute_error: 0.0093
# Epoch 131/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.5870e-05 - mean_absolute_error: 0.0050 - val_loss: 1.3442e-04 - val_mean_absolute_error: 0.0084
# Epoch 132/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5234e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2889e-04 - val_mean_absolute_error: 0.0079
# Epoch 133/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0664e-05 - mean_absolute_error: 0.0054 - val_loss: 1.9811e-04 - val_mean_absolute_error: 0.0107
# Epoch 134/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1780e-05 - mean_absolute_error: 0.0054 - val_loss: 1.3805e-04 - val_mean_absolute_error: 0.0082
# Epoch 135/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.7818e-05 - mean_absolute_error: 0.0052 - val_loss: 1.4367e-04 - val_mean_absolute_error: 0.0085
# Epoch 136/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4471e-05 - mean_absolute_error: 0.0054 - val_loss: 1.5175e-04 - val_mean_absolute_error: 0.0089
# Epoch 137/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.7790e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2702e-04 - val_mean_absolute_error: 0.0079
# Epoch 138/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.5663e-05 - mean_absolute_error: 0.0049 - val_loss: 2.8181e-04 - val_mean_absolute_error: 0.0138
# Epoch 139/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.1850e-05 - mean_absolute_error: 0.0062 - val_loss: 1.8410e-04 - val_mean_absolute_error: 0.0102
# Epoch 140/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0025e-05 - mean_absolute_error: 0.0057 - val_loss: 1.8810e-04 - val_mean_absolute_error: 0.0104
# Epoch 141/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.3803e-05 - mean_absolute_error: 0.0057 - val_loss: 1.5197e-04 - val_mean_absolute_error: 0.0089
# Epoch 142/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.3987e-05 - mean_absolute_error: 0.0056 - val_loss: 4.2493e-04 - val_mean_absolute_error: 0.0179
# Epoch 143/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.9411e-05 - mean_absolute_error: 0.0062 - val_loss: 1.4956e-04 - val_mean_absolute_error: 0.0088
# Epoch 144/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.8653e-05 - mean_absolute_error: 0.0050 - val_loss: 2.2215e-04 - val_mean_absolute_error: 0.0116
# Epoch 145/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.1086e-05 - mean_absolute_error: 0.0062 - val_loss: 1.2669e-04 - val_mean_absolute_error: 0.0079
# Epoch 146/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.2898e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3574e-04 - val_mean_absolute_error: 0.0082
# Epoch 147/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.2464e-05 - mean_absolute_error: 0.0051 - val_loss: 1.7095e-04 - val_mean_absolute_error: 0.0096
# Epoch 148/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9491e-05 - mean_absolute_error: 0.0055 - val_loss: 1.3135e-04 - val_mean_absolute_error: 0.0080
# Epoch 149/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.8425e-05 - mean_absolute_error: 0.0063 - val_loss: 1.2792e-04 - val_mean_absolute_error: 0.0081
# Epoch 150/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.0564e-05 - mean_absolute_error: 0.0055 - val_loss: 1.8078e-04 - val_mean_absolute_error: 0.0106
# Epoch 151/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.8107e-05 - mean_absolute_error: 0.0061 - val_loss: 1.3287e-04 - val_mean_absolute_error: 0.0081
# Epoch 152/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.4962e-05 - mean_absolute_error: 0.0056 - val_loss: 1.4081e-04 - val_mean_absolute_error: 0.0084
# Epoch 153/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.9949e-05 - mean_absolute_error: 0.0049 - val_loss: 1.3442e-04 - val_mean_absolute_error: 0.0085
# Epoch 154/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1782e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3233e-04 - val_mean_absolute_error: 0.0084
# Epoch 155/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.8542e-05 - mean_absolute_error: 0.0062 - val_loss: 1.4400e-04 - val_mean_absolute_error: 0.0089
# Epoch 156/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7935e-05 - mean_absolute_error: 0.0051 - val_loss: 1.2623e-04 - val_mean_absolute_error: 0.0079
# Epoch 157/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.6109e-05 - mean_absolute_error: 0.0058 - val_loss: 1.2676e-04 - val_mean_absolute_error: 0.0080
# Epoch 158/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0537e-04 - mean_absolute_error: 0.0071 - val_loss: 2.1471e-04 - val_mean_absolute_error: 0.0115
# Epoch 159/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8491e-05 - mean_absolute_error: 0.0058 - val_loss: 1.2583e-04 - val_mean_absolute_error: 0.0080
# Epoch 160/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.9021e-05 - mean_absolute_error: 0.0054 - val_loss: 1.4657e-04 - val_mean_absolute_error: 0.0091
# Epoch 161/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.5223e-05 - mean_absolute_error: 0.0057 - val_loss: 1.4309e-04 - val_mean_absolute_error: 0.0085
# Epoch 162/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.4908e-05 - mean_absolute_error: 0.0051 - val_loss: 1.2860e-04 - val_mean_absolute_error: 0.0079
# Epoch 163/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.6614e-05 - mean_absolute_error: 0.0053 - val_loss: 2.1696e-04 - val_mean_absolute_error: 0.0119
# Epoch 164/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.2066e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2804e-04 - val_mean_absolute_error: 0.0079
# Epoch 165/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.7674e-05 - mean_absolute_error: 0.0051 - val_loss: 1.8470e-04 - val_mean_absolute_error: 0.0102
# Epoch 166/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.5107e-05 - mean_absolute_error: 0.0056 - val_loss: 1.3908e-04 - val_mean_absolute_error: 0.0083
# Epoch 167/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6166e-05 - mean_absolute_error: 0.0052 - val_loss: 1.2663e-04 - val_mean_absolute_error: 0.0079
# Epoch 168/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4023e-05 - mean_absolute_error: 0.0055 - val_loss: 1.5570e-04 - val_mean_absolute_error: 0.0090
# Epoch 169/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9855e-05 - mean_absolute_error: 0.0057 - val_loss: 1.2611e-04 - val_mean_absolute_error: 0.0079
# Epoch 170/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.6920e-05 - mean_absolute_error: 0.0068 - val_loss: 1.5466e-04 - val_mean_absolute_error: 0.0091
# Epoch 171/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1588e-05 - mean_absolute_error: 0.0058 - val_loss: 1.3499e-04 - val_mean_absolute_error: 0.0082
# Epoch 172/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.2376e-05 - mean_absolute_error: 0.0060 - val_loss: 1.5461e-04 - val_mean_absolute_error: 0.0093
# Epoch 173/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2471e-05 - mean_absolute_error: 0.0051 - val_loss: 1.6082e-04 - val_mean_absolute_error: 0.0096
# Epoch 174/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.7347e-05 - mean_absolute_error: 0.0055 - val_loss: 1.7641e-04 - val_mean_absolute_error: 0.0104
# Epoch 175/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.5670e-05 - mean_absolute_error: 0.0058 - val_loss: 1.5787e-04 - val_mean_absolute_error: 0.0090
# Epoch 176/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8295e-05 - mean_absolute_error: 0.0053 - val_loss: 1.3631e-04 - val_mean_absolute_error: 0.0082
# Epoch 177/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.4873e-05 - mean_absolute_error: 0.0049 - val_loss: 1.4646e-04 - val_mean_absolute_error: 0.0086
# Epoch 178/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6691e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3090e-04 - val_mean_absolute_error: 0.0080
# Epoch 179/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.2305e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2955e-04 - val_mean_absolute_error: 0.0082
# Epoch 180/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.3652e-05 - mean_absolute_error: 0.0054 - val_loss: 1.5249e-04 - val_mean_absolute_error: 0.0093
# Epoch 181/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.4715e-05 - mean_absolute_error: 0.0053 - val_loss: 1.7869e-04 - val_mean_absolute_error: 0.0100
# Epoch 182/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6569e-05 - mean_absolute_error: 0.0055 - val_loss: 2.2455e-04 - val_mean_absolute_error: 0.0117
# Epoch 183/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9187e-05 - mean_absolute_error: 0.0061 - val_loss: 1.6885e-04 - val_mean_absolute_error: 0.0099
# Epoch 184/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.4477e-05 - mean_absolute_error: 0.0051 - val_loss: 1.2832e-04 - val_mean_absolute_error: 0.0081
# Epoch 185/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.2149e-05 - mean_absolute_error: 0.0052 - val_loss: 1.4534e-04 - val_mean_absolute_error: 0.0085
# Epoch 186/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8566e-05 - mean_absolute_error: 0.0051 - val_loss: 1.5009e-04 - val_mean_absolute_error: 0.0087
# Epoch 187/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.7404e-05 - mean_absolute_error: 0.0048 - val_loss: 1.6326e-04 - val_mean_absolute_error: 0.0093
# Epoch 188/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1190e-05 - mean_absolute_error: 0.0052 - val_loss: 1.4609e-04 - val_mean_absolute_error: 0.0086
# Epoch 189/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7852e-05 - mean_absolute_error: 0.0051 - val_loss: 1.4526e-04 - val_mean_absolute_error: 0.0090
# Epoch 190/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.5794e-05 - mean_absolute_error: 0.0059 - val_loss: 1.3065e-04 - val_mean_absolute_error: 0.0082
# Epoch 191/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.3485e-05 - mean_absolute_error: 0.0053 - val_loss: 1.9159e-04 - val_mean_absolute_error: 0.0106
# Epoch 192/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6522e-05 - mean_absolute_error: 0.0054 - val_loss: 1.3042e-04 - val_mean_absolute_error: 0.0080
# Epoch 193/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.7481e-05 - mean_absolute_error: 0.0049 - val_loss: 1.2559e-04 - val_mean_absolute_error: 0.0079
# Epoch 194/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2702e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2936e-04 - val_mean_absolute_error: 0.0079
# Epoch 195/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.5019e-05 - mean_absolute_error: 0.0051 - val_loss: 1.3232e-04 - val_mean_absolute_error: 0.0084
# Epoch 196/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3653e-05 - mean_absolute_error: 0.0054 - val_loss: 1.5623e-04 - val_mean_absolute_error: 0.0095
# Epoch 197/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.0297e-05 - mean_absolute_error: 0.0054 - val_loss: 3.0904e-04 - val_mean_absolute_error: 0.0146
# Epoch 198/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.5478e-05 - mean_absolute_error: 0.0064 - val_loss: 1.2984e-04 - val_mean_absolute_error: 0.0081
# Epoch 199/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4633e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2658e-04 - val_mean_absolute_error: 0.0081
# Epoch 200/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1624e-05 - mean_absolute_error: 0.0051 - val_loss: 1.3667e-04 - val_mean_absolute_error: 0.0082

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 120
# 131

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 3757434.749177043
# RMSE: 1938.4103665573612
# MAE: 1416.5708333333334
# MAPE: 1.6295596940079111 %
#
# Model evalution on validate set
# MSE: 8335553.487364209
# RMSE: 2887.1358622974794
# MAE: 2061.403667355372
# MAPE: 1.8119059430448055 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step

# %%
y_pred_30_days
# Out:
# array([[130840.266],
#        [131176.94 ],
#        [130898.49 ],
#        [130892.49 ],
#        [131037.54 ],
#        [130998.74 ],
#        [131023.484],
#        [131021.09 ],
#        [131016.76 ],
#        [131019.164],
#        [131017.58 ],
#        [131017.93 ],
#        [131018.03 ],
#        [131017.92 ],
#        [131018.01 ],
#        [131017.98 ],
#        [131017.945],
#        [131017.98 ],
#        [131017.98 ],
#        [131017.98 ],
#        [131017.98 ],
#        [131017.98 ],
#        [131017.98 ],
#        [131017.98 ],
#        [131017.98 ],
#        [131017.98 ],
#        [131017.98 ],
#        [131017.98 ],
#        [131017.98 ],
#        [131017.98 ],
#        [131017.98 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Predict the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
