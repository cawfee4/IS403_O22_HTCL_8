# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: FPT - Test/Train/Vaildation: 80/10/10
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 2118.001422171495
# - MAE: 1599.253125
# - MAPE: 1.8467563890794285 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 2  # 8 1 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.tail()
# Out:
#              close
# time
# 2024-05-27  132800
# 2024-05-28  137000
# 2024-05-29  135700
# 2024-05-30  135000
# 2024-05-31  134600

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((1039, 10), (1039,), (120, 10), (120,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - loss: 0.0080 - mean_absolute_error: 0.0634 - val_loss: 0.0061 - val_mean_absolute_error: 0.0707
# Epoch 2/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3781e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0018 - val_mean_absolute_error: 0.0327
# Epoch 3/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.1082e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0017 - val_mean_absolute_error: 0.0329
# Epoch 4/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6393e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0016 - val_mean_absolute_error: 0.0315
# Epoch 5/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4434e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0011 - val_mean_absolute_error: 0.0251
# Epoch 6/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1890e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0014 - val_mean_absolute_error: 0.0309
# Epoch 7/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.1823e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0010 - val_mean_absolute_error: 0.0246
# Epoch 8/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7208e-04 - mean_absolute_error: 0.0088 - val_loss: 8.2280e-04 - val_mean_absolute_error: 0.0216
# Epoch 9/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6878e-04 - mean_absolute_error: 0.0086 - val_loss: 5.8450e-04 - val_mean_absolute_error: 0.0177
# Epoch 10/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6388e-04 - mean_absolute_error: 0.0089 - val_loss: 7.8366e-04 - val_mean_absolute_error: 0.0215
# Epoch 11/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6553e-04 - mean_absolute_error: 0.0086 - val_loss: 5.5578e-04 - val_mean_absolute_error: 0.0173
# Epoch 12/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6624e-04 - mean_absolute_error: 0.0091 - val_loss: 3.9853e-04 - val_mean_absolute_error: 0.0148
# Epoch 13/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6307e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0013 - val_mean_absolute_error: 0.0302
# Epoch 14/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5108e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0010 - val_mean_absolute_error: 0.0264
# Epoch 15/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.1525e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0012 - val_mean_absolute_error: 0.0290
# Epoch 16/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5343e-04 - mean_absolute_error: 0.0085 - val_loss: 4.1359e-04 - val_mean_absolute_error: 0.0149
# Epoch 17/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0899e-04 - mean_absolute_error: 0.0069 - val_loss: 3.0441e-04 - val_mean_absolute_error: 0.0129
# Epoch 18/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.1676e-04 - mean_absolute_error: 0.0072 - val_loss: 8.1030e-04 - val_mean_absolute_error: 0.0233
# Epoch 19/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4527e-04 - mean_absolute_error: 0.0082 - val_loss: 4.6686e-04 - val_mean_absolute_error: 0.0163
# Epoch 20/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4205e-04 - mean_absolute_error: 0.0081 - val_loss: 9.6184e-04 - val_mean_absolute_error: 0.0263
# Epoch 21/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3003e-04 - mean_absolute_error: 0.0081 - val_loss: 3.5498e-04 - val_mean_absolute_error: 0.0138
# Epoch 22/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2760e-04 - mean_absolute_error: 0.0073 - val_loss: 4.4395e-04 - val_mean_absolute_error: 0.0159
# Epoch 23/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1343e-04 - mean_absolute_error: 0.0074 - val_loss: 4.1853e-04 - val_mean_absolute_error: 0.0154
# Epoch 24/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1924e-04 - mean_absolute_error: 0.0071 - val_loss: 7.7819e-04 - val_mean_absolute_error: 0.0233
# Epoch 25/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1519e-04 - mean_absolute_error: 0.0073 - val_loss: 6.9463e-04 - val_mean_absolute_error: 0.0217
# Epoch 26/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1306e-04 - mean_absolute_error: 0.0071 - val_loss: 3.9470e-04 - val_mean_absolute_error: 0.0150
# Epoch 27/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5564e-04 - mean_absolute_error: 0.0087 - val_loss: 2.2887e-04 - val_mean_absolute_error: 0.0114
# Epoch 28/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4180e-04 - mean_absolute_error: 0.0083 - val_loss: 3.5556e-04 - val_mean_absolute_error: 0.0142
# Epoch 29/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.4230e-04 - mean_absolute_error: 0.0083 - val_loss: 2.4517e-04 - val_mean_absolute_error: 0.0114
# Epoch 30/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0212e-04 - mean_absolute_error: 0.0067 - val_loss: 2.3251e-04 - val_mean_absolute_error: 0.0111
# Epoch 31/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2674e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0017 - val_mean_absolute_error: 0.0383
# Epoch 32/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9237e-04 - mean_absolute_error: 0.0099 - val_loss: 5.3553e-04 - val_mean_absolute_error: 0.0189
# Epoch 33/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.4791e-05 - mean_absolute_error: 0.0064 - val_loss: 2.9051e-04 - val_mean_absolute_error: 0.0127
# Epoch 34/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.5498e-05 - mean_absolute_error: 0.0063 - val_loss: 3.1068e-04 - val_mean_absolute_error: 0.0133
# Epoch 35/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0177e-04 - mean_absolute_error: 0.0065 - val_loss: 2.2153e-04 - val_mean_absolute_error: 0.0108
# Epoch 36/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0491e-04 - mean_absolute_error: 0.0068 - val_loss: 7.4969e-04 - val_mean_absolute_error: 0.0237
# Epoch 37/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1650e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9498e-04 - val_mean_absolute_error: 0.0130
# Epoch 38/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.8865e-05 - mean_absolute_error: 0.0063 - val_loss: 3.6305e-04 - val_mean_absolute_error: 0.0149
# Epoch 39/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1300e-04 - mean_absolute_error: 0.0069 - val_loss: 4.9280e-04 - val_mean_absolute_error: 0.0183
# Epoch 40/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.9327e-05 - mean_absolute_error: 0.0062 - val_loss: 1.9172e-04 - val_mean_absolute_error: 0.0108
# Epoch 41/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9723e-05 - mean_absolute_error: 0.0068 - val_loss: 6.7468e-04 - val_mean_absolute_error: 0.0224
# Epoch 42/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1441e-04 - mean_absolute_error: 0.0072 - val_loss: 2.2790e-04 - val_mean_absolute_error: 0.0111
# Epoch 43/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.0332e-05 - mean_absolute_error: 0.0064 - val_loss: 3.0534e-04 - val_mean_absolute_error: 0.0135
# Epoch 44/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0046e-04 - mean_absolute_error: 0.0065 - val_loss: 1.9723e-04 - val_mean_absolute_error: 0.0102
# Epoch 45/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.2366e-05 - mean_absolute_error: 0.0063 - val_loss: 1.6917e-04 - val_mean_absolute_error: 0.0098
# Epoch 46/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.8113e-05 - mean_absolute_error: 0.0062 - val_loss: 1.9345e-04 - val_mean_absolute_error: 0.0101
# Epoch 47/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.7044e-05 - mean_absolute_error: 0.0056 - val_loss: 1.9576e-04 - val_mean_absolute_error: 0.0101
# Epoch 48/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2256e-04 - mean_absolute_error: 0.0077 - val_loss: 1.5972e-04 - val_mean_absolute_error: 0.0092
# Epoch 49/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.7424e-05 - mean_absolute_error: 0.0066 - val_loss: 1.5777e-04 - val_mean_absolute_error: 0.0091
# Epoch 50/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.7090e-05 - mean_absolute_error: 0.0069 - val_loss: 1.5682e-04 - val_mean_absolute_error: 0.0090
# Epoch 51/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0467e-04 - mean_absolute_error: 0.0073 - val_loss: 4.0162e-04 - val_mean_absolute_error: 0.0164
# Epoch 52/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.0577e-04 - mean_absolute_error: 0.0069 - val_loss: 3.0135e-04 - val_mean_absolute_error: 0.0137
# Epoch 53/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.6496e-05 - mean_absolute_error: 0.0063 - val_loss: 1.7352e-04 - val_mean_absolute_error: 0.0095
# Epoch 54/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 7.3899e-05 - mean_absolute_error: 0.0056 - val_loss: 2.1768e-04 - val_mean_absolute_error: 0.0110
# Epoch 55/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.0022e-05 - mean_absolute_error: 0.0053 - val_loss: 2.0547e-04 - val_mean_absolute_error: 0.0106
# Epoch 56/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.9025e-05 - mean_absolute_error: 0.0054 - val_loss: 1.8562e-04 - val_mean_absolute_error: 0.0099
# Epoch 57/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.4206e-05 - mean_absolute_error: 0.0059 - val_loss: 1.4769e-04 - val_mean_absolute_error: 0.0089
# Epoch 58/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.3511e-05 - mean_absolute_error: 0.0058 - val_loss: 2.9979e-04 - val_mean_absolute_error: 0.0137
# Epoch 59/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.5296e-05 - mean_absolute_error: 0.0057 - val_loss: 2.4655e-04 - val_mean_absolute_error: 0.0120
# Epoch 60/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.1894e-05 - mean_absolute_error: 0.0054 - val_loss: 3.3202e-04 - val_mean_absolute_error: 0.0147
# Epoch 61/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.7441e-05 - mean_absolute_error: 0.0056 - val_loss: 1.4624e-04 - val_mean_absolute_error: 0.0091
# Epoch 62/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 8.1212e-05 - mean_absolute_error: 0.0061 - val_loss: 1.9665e-04 - val_mean_absolute_error: 0.0103
# Epoch 63/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.2140e-05 - mean_absolute_error: 0.0056 - val_loss: 1.3939e-04 - val_mean_absolute_error: 0.0086
# Epoch 64/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.0902e-05 - mean_absolute_error: 0.0056 - val_loss: 2.0147e-04 - val_mean_absolute_error: 0.0105
# Epoch 65/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.8933e-05 - mean_absolute_error: 0.0059 - val_loss: 1.5416e-04 - val_mean_absolute_error: 0.0088
# Epoch 66/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.0311e-05 - mean_absolute_error: 0.0052 - val_loss: 2.2003e-04 - val_mean_absolute_error: 0.0111
# Epoch 67/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.6787e-05 - mean_absolute_error: 0.0058 - val_loss: 1.3697e-04 - val_mean_absolute_error: 0.0084
# Epoch 68/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4989e-05 - mean_absolute_error: 0.0055 - val_loss: 2.2235e-04 - val_mean_absolute_error: 0.0113
# Epoch 69/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4102e-05 - mean_absolute_error: 0.0055 - val_loss: 1.9917e-04 - val_mean_absolute_error: 0.0104
# Epoch 70/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3677e-05 - mean_absolute_error: 0.0052 - val_loss: 3.7826e-04 - val_mean_absolute_error: 0.0163
# Epoch 71/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4828e-05 - mean_absolute_error: 0.0060 - val_loss: 2.5241e-04 - val_mean_absolute_error: 0.0123
# Epoch 72/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6479e-05 - mean_absolute_error: 0.0054 - val_loss: 2.3501e-04 - val_mean_absolute_error: 0.0118
# Epoch 73/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.3042e-05 - mean_absolute_error: 0.0056 - val_loss: 1.9370e-04 - val_mean_absolute_error: 0.0102
# Epoch 74/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7179e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3730e-04 - val_mean_absolute_error: 0.0083
# Epoch 75/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.2831e-05 - mean_absolute_error: 0.0051 - val_loss: 1.7890e-04 - val_mean_absolute_error: 0.0097
# Epoch 76/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.9945e-05 - mean_absolute_error: 0.0051 - val_loss: 1.3145e-04 - val_mean_absolute_error: 0.0082
# Epoch 77/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5462e-05 - mean_absolute_error: 0.0053 - val_loss: 1.5125e-04 - val_mean_absolute_error: 0.0088
# Epoch 78/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.6904e-05 - mean_absolute_error: 0.0053 - val_loss: 1.6643e-04 - val_mean_absolute_error: 0.0093
# Epoch 79/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.7995e-05 - mean_absolute_error: 0.0057 - val_loss: 3.2395e-04 - val_mean_absolute_error: 0.0149
# Epoch 80/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.7900e-05 - mean_absolute_error: 0.0057 - val_loss: 1.3861e-04 - val_mean_absolute_error: 0.0083
# Epoch 81/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.8091e-05 - mean_absolute_error: 0.0061 - val_loss: 1.8337e-04 - val_mean_absolute_error: 0.0099
# Epoch 82/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8943e-05 - mean_absolute_error: 0.0052 - val_loss: 2.3309e-04 - val_mean_absolute_error: 0.0118
# Epoch 83/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0331e-04 - mean_absolute_error: 0.0070 - val_loss: 1.3495e-04 - val_mean_absolute_error: 0.0082
# Epoch 84/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3414e-05 - mean_absolute_error: 0.0053 - val_loss: 1.3953e-04 - val_mean_absolute_error: 0.0083
# Epoch 85/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.0748e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2963e-04 - val_mean_absolute_error: 0.0080
# Epoch 86/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.3933e-05 - mean_absolute_error: 0.0056 - val_loss: 2.2557e-04 - val_mean_absolute_error: 0.0116
# Epoch 87/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.0230e-05 - mean_absolute_error: 0.0056 - val_loss: 1.2681e-04 - val_mean_absolute_error: 0.0080
# Epoch 88/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.9750e-05 - mean_absolute_error: 0.0049 - val_loss: 1.4812e-04 - val_mean_absolute_error: 0.0086
# Epoch 89/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0496e-05 - mean_absolute_error: 0.0050 - val_loss: 1.8171e-04 - val_mean_absolute_error: 0.0099
# Epoch 90/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0419e-05 - mean_absolute_error: 0.0056 - val_loss: 1.8721e-04 - val_mean_absolute_error: 0.0101
# Epoch 91/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4649e-05 - mean_absolute_error: 0.0053 - val_loss: 1.5848e-04 - val_mean_absolute_error: 0.0090
# Epoch 92/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.9334e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2807e-04 - val_mean_absolute_error: 0.0083
# Epoch 93/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6467e-05 - mean_absolute_error: 0.0057 - val_loss: 1.4810e-04 - val_mean_absolute_error: 0.0086
# Epoch 94/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.9535e-05 - mean_absolute_error: 0.0052 - val_loss: 1.5567e-04 - val_mean_absolute_error: 0.0089
# Epoch 95/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4020e-05 - mean_absolute_error: 0.0051 - val_loss: 1.4488e-04 - val_mean_absolute_error: 0.0085
# Epoch 96/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0767e-05 - mean_absolute_error: 0.0052 - val_loss: 1.2535e-04 - val_mean_absolute_error: 0.0079
# Epoch 97/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.2215e-05 - mean_absolute_error: 0.0050 - val_loss: 1.4333e-04 - val_mean_absolute_error: 0.0084
# Epoch 98/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.2064e-05 - mean_absolute_error: 0.0050 - val_loss: 2.1396e-04 - val_mean_absolute_error: 0.0112
# Epoch 99/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9889e-05 - mean_absolute_error: 0.0057 - val_loss: 1.3869e-04 - val_mean_absolute_error: 0.0083
# Epoch 100/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.2186e-05 - mean_absolute_error: 0.0048 - val_loss: 1.7962e-04 - val_mean_absolute_error: 0.0106
# Epoch 101/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.7204e-05 - mean_absolute_error: 0.0063 - val_loss: 1.2480e-04 - val_mean_absolute_error: 0.0081
# Epoch 102/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.3318e-05 - mean_absolute_error: 0.0060 - val_loss: 1.2569e-04 - val_mean_absolute_error: 0.0079
# Epoch 103/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6835e-05 - mean_absolute_error: 0.0058 - val_loss: 1.8191e-04 - val_mean_absolute_error: 0.0099
# Epoch 104/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1725e-05 - mean_absolute_error: 0.0050 - val_loss: 1.4157e-04 - val_mean_absolute_error: 0.0084
# Epoch 105/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.0722e-05 - mean_absolute_error: 0.0052 - val_loss: 1.2588e-04 - val_mean_absolute_error: 0.0078
# Epoch 106/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5887e-05 - mean_absolute_error: 0.0055 - val_loss: 1.3966e-04 - val_mean_absolute_error: 0.0083
# Epoch 107/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.7682e-05 - mean_absolute_error: 0.0055 - val_loss: 1.3760e-04 - val_mean_absolute_error: 0.0082
# Epoch 108/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.4964e-05 - mean_absolute_error: 0.0050 - val_loss: 1.4837e-04 - val_mean_absolute_error: 0.0093
# Epoch 109/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.8430e-05 - mean_absolute_error: 0.0060 - val_loss: 1.4253e-04 - val_mean_absolute_error: 0.0084
# Epoch 110/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.6686e-05 - mean_absolute_error: 0.0052 - val_loss: 1.2355e-04 - val_mean_absolute_error: 0.0078
# Epoch 111/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6997e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3929e-04 - val_mean_absolute_error: 0.0083
# Epoch 112/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.4046e-05 - mean_absolute_error: 0.0052 - val_loss: 2.2451e-04 - val_mean_absolute_error: 0.0117
# Epoch 113/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.6372e-05 - mean_absolute_error: 0.0058 - val_loss: 1.9385e-04 - val_mean_absolute_error: 0.0105
# Epoch 114/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5471e-05 - mean_absolute_error: 0.0052 - val_loss: 1.2865e-04 - val_mean_absolute_error: 0.0079
# Epoch 115/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.3565e-05 - mean_absolute_error: 0.0056 - val_loss: 1.5625e-04 - val_mean_absolute_error: 0.0095
# Epoch 116/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.4121e-05 - mean_absolute_error: 0.0049 - val_loss: 1.4315e-04 - val_mean_absolute_error: 0.0089
# Epoch 117/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4490e-05 - mean_absolute_error: 0.0057 - val_loss: 1.2588e-04 - val_mean_absolute_error: 0.0081
# Epoch 118/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.2761e-05 - mean_absolute_error: 0.0065 - val_loss: 1.4062e-04 - val_mean_absolute_error: 0.0089
# Epoch 119/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.9475e-05 - mean_absolute_error: 0.0056 - val_loss: 1.2626e-04 - val_mean_absolute_error: 0.0078
# Epoch 120/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.2160e-05 - mean_absolute_error: 0.0051 - val_loss: 1.4690e-04 - val_mean_absolute_error: 0.0085
# Epoch 121/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.2529e-05 - mean_absolute_error: 0.0055 - val_loss: 1.2485e-04 - val_mean_absolute_error: 0.0078
# Epoch 122/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.0315e-05 - mean_absolute_error: 0.0049 - val_loss: 1.5676e-04 - val_mean_absolute_error: 0.0090
# Epoch 123/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.0559e-05 - mean_absolute_error: 0.0054 - val_loss: 1.8738e-04 - val_mean_absolute_error: 0.0103
# Epoch 124/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.1032e-05 - mean_absolute_error: 0.0060 - val_loss: 1.5364e-04 - val_mean_absolute_error: 0.0088
# Epoch 125/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.3394e-05 - mean_absolute_error: 0.0051 - val_loss: 1.3026e-04 - val_mean_absolute_error: 0.0084
# Epoch 126/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1328e-05 - mean_absolute_error: 0.0056 - val_loss: 1.5592e-04 - val_mean_absolute_error: 0.0090
# Epoch 127/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.4598e-05 - mean_absolute_error: 0.0069 - val_loss: 1.3589e-04 - val_mean_absolute_error: 0.0082
# Epoch 128/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.0231e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2523e-04 - val_mean_absolute_error: 0.0081
# Epoch 129/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.4536e-05 - mean_absolute_error: 0.0051 - val_loss: 2.0929e-04 - val_mean_absolute_error: 0.0111
# Epoch 130/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.1046e-05 - mean_absolute_error: 0.0065 - val_loss: 2.0473e-04 - val_mean_absolute_error: 0.0116
# Epoch 131/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.0888e-05 - mean_absolute_error: 0.0058 - val_loss: 2.1349e-04 - val_mean_absolute_error: 0.0112
# Epoch 132/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.5509e-05 - mean_absolute_error: 0.0057 - val_loss: 1.3933e-04 - val_mean_absolute_error: 0.0083
# Epoch 133/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.2396e-05 - mean_absolute_error: 0.0051 - val_loss: 2.3395e-04 - val_mean_absolute_error: 0.0120
# Epoch 134/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.7548e-05 - mean_absolute_error: 0.0050 - val_loss: 1.3635e-04 - val_mean_absolute_error: 0.0085
# Epoch 135/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.8533e-05 - mean_absolute_error: 0.0058 - val_loss: 1.2602e-04 - val_mean_absolute_error: 0.0078
# Epoch 136/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.2700e-05 - mean_absolute_error: 0.0052 - val_loss: 1.9836e-04 - val_mean_absolute_error: 0.0107
# Epoch 137/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.7683e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2668e-04 - val_mean_absolute_error: 0.0079
# Epoch 138/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.2020e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2396e-04 - val_mean_absolute_error: 0.0079
# Epoch 139/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 7.0845e-05 - mean_absolute_error: 0.0059 - val_loss: 3.8152e-04 - val_mean_absolute_error: 0.0166
# Epoch 140/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.1893e-05 - mean_absolute_error: 0.0057 - val_loss: 1.2910e-04 - val_mean_absolute_error: 0.0079
# Epoch 141/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.7585e-05 - mean_absolute_error: 0.0055 - val_loss: 1.2520e-04 - val_mean_absolute_error: 0.0079
# Epoch 142/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.8855e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2453e-04 - val_mean_absolute_error: 0.0078
# Epoch 143/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.0007e-05 - mean_absolute_error: 0.0054 - val_loss: 1.6788e-04 - val_mean_absolute_error: 0.0095
# Epoch 144/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.4998e-05 - mean_absolute_error: 0.0048 - val_loss: 2.1478e-04 - val_mean_absolute_error: 0.0113
# Epoch 145/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.7426e-05 - mean_absolute_error: 0.0053 - val_loss: 2.0831e-04 - val_mean_absolute_error: 0.0111
# Epoch 146/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.3591e-05 - mean_absolute_error: 0.0051 - val_loss: 1.6151e-04 - val_mean_absolute_error: 0.0092
# Epoch 147/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.2323e-05 - mean_absolute_error: 0.0053 - val_loss: 1.5769e-04 - val_mean_absolute_error: 0.0090
# Epoch 148/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.5061e-05 - mean_absolute_error: 0.0057 - val_loss: 1.5287e-04 - val_mean_absolute_error: 0.0089
# Epoch 149/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1532e-05 - mean_absolute_error: 0.0052 - val_loss: 1.7541e-04 - val_mean_absolute_error: 0.0098
# Epoch 150/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7339e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2529e-04 - val_mean_absolute_error: 0.0079
# Epoch 151/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3108e-05 - mean_absolute_error: 0.0047 - val_loss: 1.2488e-04 - val_mean_absolute_error: 0.0078
# Epoch 152/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.2242e-05 - mean_absolute_error: 0.0049 - val_loss: 1.4035e-04 - val_mean_absolute_error: 0.0088
# Epoch 153/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1543e-05 - mean_absolute_error: 0.0060 - val_loss: 1.2680e-04 - val_mean_absolute_error: 0.0079
# Epoch 154/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1825e-05 - mean_absolute_error: 0.0052 - val_loss: 1.7310e-04 - val_mean_absolute_error: 0.0103
# Epoch 155/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4764e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2361e-04 - val_mean_absolute_error: 0.0079
# Epoch 156/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9569e-05 - mean_absolute_error: 0.0051 - val_loss: 1.3803e-04 - val_mean_absolute_error: 0.0082
# Epoch 157/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0025e-05 - mean_absolute_error: 0.0057 - val_loss: 1.8008e-04 - val_mean_absolute_error: 0.0100
# Epoch 158/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8370e-05 - mean_absolute_error: 0.0054 - val_loss: 1.4578e-04 - val_mean_absolute_error: 0.0085
# Epoch 159/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.4623e-05 - mean_absolute_error: 0.0055 - val_loss: 1.4240e-04 - val_mean_absolute_error: 0.0089
# Epoch 160/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1897e-05 - mean_absolute_error: 0.0056 - val_loss: 1.6791e-04 - val_mean_absolute_error: 0.0101
# Epoch 161/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.6934e-05 - mean_absolute_error: 0.0061 - val_loss: 1.3613e-04 - val_mean_absolute_error: 0.0085
# Epoch 162/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.2132e-05 - mean_absolute_error: 0.0055 - val_loss: 1.6760e-04 - val_mean_absolute_error: 0.0095
# Epoch 163/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.9526e-05 - mean_absolute_error: 0.0051 - val_loss: 1.3594e-04 - val_mean_absolute_error: 0.0085
# Epoch 164/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.3553e-05 - mean_absolute_error: 0.0057 - val_loss: 1.8979e-04 - val_mean_absolute_error: 0.0103
# Epoch 165/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1897e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3125e-04 - val_mean_absolute_error: 0.0080
# Epoch 166/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.1296e-05 - mean_absolute_error: 0.0051 - val_loss: 1.4923e-04 - val_mean_absolute_error: 0.0093
# Epoch 167/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4435e-05 - mean_absolute_error: 0.0061 - val_loss: 2.5950e-04 - val_mean_absolute_error: 0.0129
# Epoch 168/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.9634e-05 - mean_absolute_error: 0.0057 - val_loss: 1.6988e-04 - val_mean_absolute_error: 0.0096
# Epoch 169/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2043e-05 - mean_absolute_error: 0.0060 - val_loss: 1.5430e-04 - val_mean_absolute_error: 0.0094
# Epoch 170/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.0161e-05 - mean_absolute_error: 0.0061 - val_loss: 1.4984e-04 - val_mean_absolute_error: 0.0093
# Epoch 171/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0980e-05 - mean_absolute_error: 0.0057 - val_loss: 1.2525e-04 - val_mean_absolute_error: 0.0078
# Epoch 172/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4971e-05 - mean_absolute_error: 0.0057 - val_loss: 1.8789e-04 - val_mean_absolute_error: 0.0110
# Epoch 173/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.6816e-05 - mean_absolute_error: 0.0061 - val_loss: 1.5407e-04 - val_mean_absolute_error: 0.0089
# Epoch 174/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.7307e-05 - mean_absolute_error: 0.0057 - val_loss: 3.8382e-04 - val_mean_absolute_error: 0.0167
# Epoch 175/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5093e-05 - mean_absolute_error: 0.0056 - val_loss: 1.3529e-04 - val_mean_absolute_error: 0.0081
# Epoch 176/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.7910e-05 - mean_absolute_error: 0.0053 - val_loss: 1.3019e-04 - val_mean_absolute_error: 0.0082
# Epoch 177/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.7368e-05 - mean_absolute_error: 0.0052 - val_loss: 1.5866e-04 - val_mean_absolute_error: 0.0090
# Epoch 178/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9952e-05 - mean_absolute_error: 0.0055 - val_loss: 1.4217e-04 - val_mean_absolute_error: 0.0088
# Epoch 179/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.1997e-05 - mean_absolute_error: 0.0053 - val_loss: 1.3860e-04 - val_mean_absolute_error: 0.0083
# Epoch 180/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.6939e-05 - mean_absolute_error: 0.0056 - val_loss: 1.4136e-04 - val_mean_absolute_error: 0.0083
# Epoch 181/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9664e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2631e-04 - val_mean_absolute_error: 0.0078
# Epoch 182/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.9979e-05 - mean_absolute_error: 0.0052 - val_loss: 1.9664e-04 - val_mean_absolute_error: 0.0106
# Epoch 183/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.9176e-05 - mean_absolute_error: 0.0059 - val_loss: 1.2425e-04 - val_mean_absolute_error: 0.0079
# Epoch 184/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.7240e-05 - mean_absolute_error: 0.0056 - val_loss: 1.2591e-04 - val_mean_absolute_error: 0.0078
# Epoch 185/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.0857e-05 - mean_absolute_error: 0.0056 - val_loss: 1.4167e-04 - val_mean_absolute_error: 0.0088
# Epoch 186/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.0985e-05 - mean_absolute_error: 0.0051 - val_loss: 1.8875e-04 - val_mean_absolute_error: 0.0103
# Epoch 187/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2591e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2802e-04 - val_mean_absolute_error: 0.0079
# Epoch 188/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.3253e-05 - mean_absolute_error: 0.0058 - val_loss: 1.2950e-04 - val_mean_absolute_error: 0.0079
# Epoch 189/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7628e-05 - mean_absolute_error: 0.0046 - val_loss: 1.3379e-04 - val_mean_absolute_error: 0.0084
# Epoch 190/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7845e-05 - mean_absolute_error: 0.0055 - val_loss: 1.4210e-04 - val_mean_absolute_error: 0.0089
# Epoch 191/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6684e-05 - mean_absolute_error: 0.0056 - val_loss: 1.2505e-04 - val_mean_absolute_error: 0.0079
# Epoch 192/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7035e-05 - mean_absolute_error: 0.0050 - val_loss: 1.7437e-04 - val_mean_absolute_error: 0.0103
# Epoch 193/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.0469e-05 - mean_absolute_error: 0.0061 - val_loss: 1.4249e-04 - val_mean_absolute_error: 0.0089
# Epoch 194/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8412e-05 - mean_absolute_error: 0.0056 - val_loss: 1.5326e-04 - val_mean_absolute_error: 0.0089
# Epoch 195/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1546e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2772e-04 - val_mean_absolute_error: 0.0081
# Epoch 196/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2428e-05 - mean_absolute_error: 0.0055 - val_loss: 1.2779e-04 - val_mean_absolute_error: 0.0079
# Epoch 197/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1802e-05 - mean_absolute_error: 0.0058 - val_loss: 1.9535e-04 - val_mean_absolute_error: 0.0111
# Epoch 198/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2020e-05 - mean_absolute_error: 0.0056 - val_loss: 1.4772e-04 - val_mean_absolute_error: 0.0086
# Epoch 199/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.3752e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2698e-04 - val_mean_absolute_error: 0.0080
# Epoch 200/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7177e-05 - mean_absolute_error: 0.0048 - val_loss: 1.7837e-04 - val_mean_absolute_error: 0.0099

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 120
# 131

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 4485930.024320475
# RMSE: 2118.001422171495
# MAE: 1599.253125
# MAPE: 1.8467563890794285 %
#
# Model evalution on validate set
# MSE: 10745178.001670647
# RMSE: 3277.9838318195907
# MAE: 2411.198992768595
# MAPE: 2.1258054390853403 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 560ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step

# %%
y_pred_30_days
# Out:
# array([[129571.38 ],
#        [130029.28 ],
#        [129763.47 ],
#        [129649.3  ],
#        [129895.1  ],
#        [129829.33 ],
#        [129855.47 ],
#        [129862.94 ],
#        [129850.45 ],
#        [129856.09 ],
#        [129853.984],
#        [129853.74 ],
#        [129854.42 ],
#        [129854.   ],
#        [129854.18 ],
#        [129854.164],
#        [129854.11 ],
#        [129854.16 ],
#        [129854.16 ],
#        [129854.16 ],
#        [129854.16 ],
#        [129854.14 ],
#        [129854.16 ],
#        [129854.164],
#        [129854.16 ],
#        [129854.14 ],
#        [129854.14 ],
#        [129854.16 ],
#        [129854.14 ],
#        [129854.14 ],
#        [129854.16 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Predict the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
