# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: FPT - Test/Train/Vaildation: 80/10/10
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 2793.2776418019885
# - MAE: 2309.7888020833334
# - MAPE: 2.6829903292913735 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 2  # 8 1 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01  19270
# 2019-03-04  19440
# 2019-03-05  19390
# 2019-03-06  19270
# 2019-03-07  19330

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((1039, 10), (1039,), (120, 10), (120,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_1 (SimpleRNN)        │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - loss: 0.1138 - mean_absolute_error: 0.2086 - val_loss: 0.0045 - val_mean_absolute_error: 0.0488
# Epoch 2/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0015 - mean_absolute_error: 0.0274 - val_loss: 0.0060 - val_mean_absolute_error: 0.0622
# Epoch 3/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4143e-04 - mean_absolute_error: 0.0188 - val_loss: 0.0041 - val_mean_absolute_error: 0.0475
# Epoch 4/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.5370e-04 - mean_absolute_error: 0.0171 - val_loss: 0.0045 - val_mean_absolute_error: 0.0521
# Epoch 5/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.0485e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0036 - val_mean_absolute_error: 0.0441
# Epoch 6/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2306e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0033 - val_mean_absolute_error: 0.0421
# Epoch 7/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8881e-04 - mean_absolute_error: 0.0165 - val_loss: 0.0037 - val_mean_absolute_error: 0.0472
# Epoch 8/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6987e-04 - mean_absolute_error: 0.0161 - val_loss: 0.0031 - val_mean_absolute_error: 0.0424
# Epoch 9/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4931e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0029 - val_mean_absolute_error: 0.0410
# Epoch 10/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.1158e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0023 - val_mean_absolute_error: 0.0351
# Epoch 11/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.1180e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0038 - val_mean_absolute_error: 0.0517
# Epoch 12/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5963e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0025 - val_mean_absolute_error: 0.0384
# Epoch 13/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.0121e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0029 - val_mean_absolute_error: 0.0441
# Epoch 14/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.5684e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0021 - val_mean_absolute_error: 0.0348
# Epoch 15/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4879e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0031 - val_mean_absolute_error: 0.0466
# Epoch 16/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.4030e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0021 - val_mean_absolute_error: 0.0360
# Epoch 17/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.9948e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0022 - val_mean_absolute_error: 0.0385
# Epoch 18/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.5189e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0014 - val_mean_absolute_error: 0.0279
# Epoch 19/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.7779e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0022 - val_mean_absolute_error: 0.0379
# Epoch 20/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.8504e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0031 - val_mean_absolute_error: 0.0484
# Epoch 21/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5352e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0043 - val_mean_absolute_error: 0.0597
# Epoch 22/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0111e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0014 - val_mean_absolute_error: 0.0291
# Epoch 23/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7870e-04 - mean_absolute_error: 0.0115 - val_loss: 6.4871e-04 - val_mean_absolute_error: 0.0201
# Epoch 24/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.4127e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0014 - val_mean_absolute_error: 0.0296
# Epoch 25/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3245e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0019 - val_mean_absolute_error: 0.0365
# Epoch 26/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3622e-04 - mean_absolute_error: 0.0104 - val_loss: 7.0740e-04 - val_mean_absolute_error: 0.0193
# Epoch 27/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2582e-04 - mean_absolute_error: 0.0101 - val_loss: 6.3695e-04 - val_mean_absolute_error: 0.0186
# Epoch 28/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2521e-04 - mean_absolute_error: 0.0105 - val_loss: 8.6951e-04 - val_mean_absolute_error: 0.0219
# Epoch 29/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.4305e-04 - mean_absolute_error: 0.0104 - val_loss: 9.5080e-04 - val_mean_absolute_error: 0.0234
# Epoch 30/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.9004e-04 - mean_absolute_error: 0.0093 - val_loss: 4.9221e-04 - val_mean_absolute_error: 0.0171
# Epoch 31/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.0660e-04 - mean_absolute_error: 0.0125 - val_loss: 5.9962e-04 - val_mean_absolute_error: 0.0178
# Epoch 32/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1800e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0014 - val_mean_absolute_error: 0.0316
# Epoch 33/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9049e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0015 - val_mean_absolute_error: 0.0331
# Epoch 34/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0466e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0015 - val_mean_absolute_error: 0.0326
# Epoch 35/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.6570e-04 - mean_absolute_error: 0.0115 - val_loss: 5.2114e-04 - val_mean_absolute_error: 0.0166
# Epoch 36/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.1606e-04 - mean_absolute_error: 0.0099 - val_loss: 6.8590e-04 - val_mean_absolute_error: 0.0195
# Epoch 37/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8901e-04 - mean_absolute_error: 0.0092 - val_loss: 7.1797e-04 - val_mean_absolute_error: 0.0202
# Epoch 38/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7420e-04 - mean_absolute_error: 0.0090 - val_loss: 5.4048e-04 - val_mean_absolute_error: 0.0170
# Epoch 39/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.7935e-04 - mean_absolute_error: 0.0094 - val_loss: 4.1720e-04 - val_mean_absolute_error: 0.0150
# Epoch 40/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.9882e-04 - mean_absolute_error: 0.0093 - val_loss: 3.8935e-04 - val_mean_absolute_error: 0.0148
# Epoch 41/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2939e-04 - mean_absolute_error: 0.0107 - val_loss: 6.2589e-04 - val_mean_absolute_error: 0.0188
# Epoch 42/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6837e-04 - mean_absolute_error: 0.0086 - val_loss: 5.4999e-04 - val_mean_absolute_error: 0.0174
# Epoch 43/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6165e-04 - mean_absolute_error: 0.0083 - val_loss: 5.4446e-04 - val_mean_absolute_error: 0.0173
# Epoch 44/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6697e-04 - mean_absolute_error: 0.0087 - val_loss: 9.5995e-04 - val_mean_absolute_error: 0.0254
# Epoch 45/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5115e-04 - mean_absolute_error: 0.0085 - val_loss: 5.4059e-04 - val_mean_absolute_error: 0.0174
# Epoch 46/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5023e-04 - mean_absolute_error: 0.0084 - val_loss: 7.8801e-04 - val_mean_absolute_error: 0.0223
# Epoch 47/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9224e-04 - mean_absolute_error: 0.0095 - val_loss: 4.2427e-04 - val_mean_absolute_error: 0.0151
# Epoch 48/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4634e-04 - mean_absolute_error: 0.0082 - val_loss: 5.9292e-04 - val_mean_absolute_error: 0.0186
# Epoch 49/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.4590e-04 - mean_absolute_error: 0.0079 - val_loss: 4.4805e-04 - val_mean_absolute_error: 0.0156
# Epoch 50/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4045e-04 - mean_absolute_error: 0.0077 - val_loss: 4.0173e-04 - val_mean_absolute_error: 0.0147
# Epoch 51/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5280e-04 - mean_absolute_error: 0.0084 - val_loss: 8.1955e-04 - val_mean_absolute_error: 0.0234
# Epoch 52/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5741e-04 - mean_absolute_error: 0.0085 - val_loss: 4.0806e-04 - val_mean_absolute_error: 0.0149
# Epoch 53/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3523e-04 - mean_absolute_error: 0.0078 - val_loss: 3.4847e-04 - val_mean_absolute_error: 0.0137
# Epoch 54/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6211e-04 - mean_absolute_error: 0.0087 - val_loss: 4.3343e-04 - val_mean_absolute_error: 0.0155
# Epoch 55/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.3669e-04 - mean_absolute_error: 0.0078 - val_loss: 4.0056e-04 - val_mean_absolute_error: 0.0148
# Epoch 56/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1162e-04 - mean_absolute_error: 0.0071 - val_loss: 8.7194e-04 - val_mean_absolute_error: 0.0247
# Epoch 57/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.3242e-04 - mean_absolute_error: 0.0077 - val_loss: 9.6280e-04 - val_mean_absolute_error: 0.0264
# Epoch 58/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4019e-04 - mean_absolute_error: 0.0080 - val_loss: 3.4926e-04 - val_mean_absolute_error: 0.0137
# Epoch 59/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.1776e-04 - mean_absolute_error: 0.0075 - val_loss: 3.9375e-04 - val_mean_absolute_error: 0.0148
# Epoch 60/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2947e-04 - mean_absolute_error: 0.0075 - val_loss: 2.8579e-04 - val_mean_absolute_error: 0.0123
# Epoch 61/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1986e-04 - mean_absolute_error: 0.0073 - val_loss: 4.2650e-04 - val_mean_absolute_error: 0.0156
# Epoch 62/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2658e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0011 - val_mean_absolute_error: 0.0288
# Epoch 63/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6469e-04 - mean_absolute_error: 0.0088 - val_loss: 2.8227e-04 - val_mean_absolute_error: 0.0123
# Epoch 64/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3357e-04 - mean_absolute_error: 0.0080 - val_loss: 5.2384e-04 - val_mean_absolute_error: 0.0180
# Epoch 65/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2687e-04 - mean_absolute_error: 0.0078 - val_loss: 6.2562e-04 - val_mean_absolute_error: 0.0203
# Epoch 66/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.5800e-04 - mean_absolute_error: 0.0086 - val_loss: 2.7681e-04 - val_mean_absolute_error: 0.0121
# Epoch 67/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2798e-04 - mean_absolute_error: 0.0078 - val_loss: 3.8243e-04 - val_mean_absolute_error: 0.0147
# Epoch 68/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.2793e-04 - mean_absolute_error: 0.0076 - val_loss: 8.3020e-04 - val_mean_absolute_error: 0.0246
# Epoch 69/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3710e-04 - mean_absolute_error: 0.0078 - val_loss: 5.3614e-04 - val_mean_absolute_error: 0.0185
# Epoch 70/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1367e-04 - mean_absolute_error: 0.0067 - val_loss: 3.9676e-04 - val_mean_absolute_error: 0.0152
# Epoch 71/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0749e-04 - mean_absolute_error: 0.0069 - val_loss: 4.1226e-04 - val_mean_absolute_error: 0.0157
# Epoch 72/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2373e-04 - mean_absolute_error: 0.0077 - val_loss: 2.6455e-04 - val_mean_absolute_error: 0.0119
# Epoch 73/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1139e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9312e-04 - val_mean_absolute_error: 0.0127
# Epoch 74/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1197e-04 - mean_absolute_error: 0.0071 - val_loss: 3.7847e-04 - val_mean_absolute_error: 0.0149
# Epoch 75/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0881e-04 - mean_absolute_error: 0.0069 - val_loss: 4.0438e-04 - val_mean_absolute_error: 0.0155
# Epoch 76/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2549e-04 - mean_absolute_error: 0.0074 - val_loss: 5.9265e-04 - val_mean_absolute_error: 0.0201
# Epoch 77/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.1403e-04 - mean_absolute_error: 0.0074 - val_loss: 5.4043e-04 - val_mean_absolute_error: 0.0190
# Epoch 78/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1082e-04 - mean_absolute_error: 0.0069 - val_loss: 2.2360e-04 - val_mean_absolute_error: 0.0119
# Epoch 79/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2877e-04 - mean_absolute_error: 0.0078 - val_loss: 3.2387e-04 - val_mean_absolute_error: 0.0136
# Epoch 80/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0381e-04 - mean_absolute_error: 0.0064 - val_loss: 4.2259e-04 - val_mean_absolute_error: 0.0162
# Epoch 81/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1310e-04 - mean_absolute_error: 0.0070 - val_loss: 2.2635e-04 - val_mean_absolute_error: 0.0110
# Epoch 82/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1000e-04 - mean_absolute_error: 0.0068 - val_loss: 6.1941e-04 - val_mean_absolute_error: 0.0209
# Epoch 83/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.9543e-05 - mean_absolute_error: 0.0066 - val_loss: 2.6206e-04 - val_mean_absolute_error: 0.0120
# Epoch 84/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.9598e-05 - mean_absolute_error: 0.0070 - val_loss: 2.7754e-04 - val_mean_absolute_error: 0.0125
# Epoch 85/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0985e-04 - mean_absolute_error: 0.0071 - val_loss: 3.8625e-04 - val_mean_absolute_error: 0.0155
# Epoch 86/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1352e-04 - mean_absolute_error: 0.0072 - val_loss: 5.1297e-04 - val_mean_absolute_error: 0.0187
# Epoch 87/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0686e-04 - mean_absolute_error: 0.0068 - val_loss: 1.8223e-04 - val_mean_absolute_error: 0.0100
# Epoch 88/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.1641e-04 - mean_absolute_error: 0.0075 - val_loss: 4.2694e-04 - val_mean_absolute_error: 0.0166
# Epoch 89/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.3297e-05 - mean_absolute_error: 0.0060 - val_loss: 1.8458e-04 - val_mean_absolute_error: 0.0099
# Epoch 90/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0998e-04 - mean_absolute_error: 0.0073 - val_loss: 1.7677e-04 - val_mean_absolute_error: 0.0097
# Epoch 91/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0212e-04 - mean_absolute_error: 0.0071 - val_loss: 3.2889e-04 - val_mean_absolute_error: 0.0141
# Epoch 92/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.8183e-05 - mean_absolute_error: 0.0060 - val_loss: 1.7463e-04 - val_mean_absolute_error: 0.0095
# Epoch 93/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0534e-04 - mean_absolute_error: 0.0070 - val_loss: 3.4157e-04 - val_mean_absolute_error: 0.0144
# Epoch 94/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.2671e-05 - mean_absolute_error: 0.0061 - val_loss: 1.8174e-04 - val_mean_absolute_error: 0.0098
# Epoch 95/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.0698e-05 - mean_absolute_error: 0.0057 - val_loss: 3.9627e-04 - val_mean_absolute_error: 0.0160
# Epoch 96/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1896e-04 - mean_absolute_error: 0.0073 - val_loss: 3.9214e-04 - val_mean_absolute_error: 0.0160
# Epoch 97/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.0524e-05 - mean_absolute_error: 0.0063 - val_loss: 3.4431e-04 - val_mean_absolute_error: 0.0146
# Epoch 98/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.2531e-05 - mean_absolute_error: 0.0062 - val_loss: 2.4337e-04 - val_mean_absolute_error: 0.0117
# Epoch 99/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.6386e-05 - mean_absolute_error: 0.0059 - val_loss: 1.9525e-04 - val_mean_absolute_error: 0.0102
# Epoch 100/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.5647e-05 - mean_absolute_error: 0.0061 - val_loss: 2.3723e-04 - val_mean_absolute_error: 0.0115
# Epoch 101/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7639e-05 - mean_absolute_error: 0.0059 - val_loss: 2.8707e-04 - val_mean_absolute_error: 0.0130
# Epoch 102/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.4325e-05 - mean_absolute_error: 0.0061 - val_loss: 3.1371e-04 - val_mean_absolute_error: 0.0138
# Epoch 103/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0846e-04 - mean_absolute_error: 0.0068 - val_loss: 2.9395e-04 - val_mean_absolute_error: 0.0133
# Epoch 104/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.0920e-05 - mean_absolute_error: 0.0062 - val_loss: 4.6513e-04 - val_mean_absolute_error: 0.0180
# Epoch 105/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.6088e-05 - mean_absolute_error: 0.0067 - val_loss: 6.0005e-04 - val_mean_absolute_error: 0.0212
# Epoch 106/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.4939e-05 - mean_absolute_error: 0.0069 - val_loss: 2.1918e-04 - val_mean_absolute_error: 0.0110
# Epoch 107/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.8029e-05 - mean_absolute_error: 0.0062 - val_loss: 1.6993e-04 - val_mean_absolute_error: 0.0094
# Epoch 108/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.5633e-05 - mean_absolute_error: 0.0060 - val_loss: 6.1197e-04 - val_mean_absolute_error: 0.0216
# Epoch 109/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1890e-04 - mean_absolute_error: 0.0077 - val_loss: 1.7062e-04 - val_mean_absolute_error: 0.0095
# Epoch 110/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.7076e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4866e-04 - val_mean_absolute_error: 0.0089
# Epoch 111/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.7255e-05 - mean_absolute_error: 0.0067 - val_loss: 2.0571e-04 - val_mean_absolute_error: 0.0106
# Epoch 112/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2895e-05 - mean_absolute_error: 0.0054 - val_loss: 2.2615e-04 - val_mean_absolute_error: 0.0113
# Epoch 113/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9521e-05 - mean_absolute_error: 0.0057 - val_loss: 2.7602e-04 - val_mean_absolute_error: 0.0129
# Epoch 114/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.7377e-05 - mean_absolute_error: 0.0055 - val_loss: 1.7192e-04 - val_mean_absolute_error: 0.0095
# Epoch 115/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.6421e-05 - mean_absolute_error: 0.0056 - val_loss: 2.2333e-04 - val_mean_absolute_error: 0.0112
# Epoch 116/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.9289e-05 - mean_absolute_error: 0.0058 - val_loss: 1.9081e-04 - val_mean_absolute_error: 0.0101
# Epoch 117/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.2737e-05 - mean_absolute_error: 0.0051 - val_loss: 2.4344e-04 - val_mean_absolute_error: 0.0118
# Epoch 118/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.0609e-05 - mean_absolute_error: 0.0059 - val_loss: 1.4636e-04 - val_mean_absolute_error: 0.0092
# Epoch 119/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.1947e-05 - mean_absolute_error: 0.0060 - val_loss: 5.8083e-04 - val_mean_absolute_error: 0.0211
# Epoch 120/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0040e-04 - mean_absolute_error: 0.0071 - val_loss: 2.0843e-04 - val_mean_absolute_error: 0.0108
# Epoch 121/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.8104e-05 - mean_absolute_error: 0.0053 - val_loss: 3.2493e-04 - val_mean_absolute_error: 0.0145
# Epoch 122/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7649e-05 - mean_absolute_error: 0.0054 - val_loss: 1.5150e-04 - val_mean_absolute_error: 0.0088
# Epoch 123/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2419e-05 - mean_absolute_error: 0.0052 - val_loss: 2.2350e-04 - val_mean_absolute_error: 0.0122
# Epoch 124/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.9825e-05 - mean_absolute_error: 0.0065 - val_loss: 1.3675e-04 - val_mean_absolute_error: 0.0085
# Epoch 125/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.7573e-05 - mean_absolute_error: 0.0057 - val_loss: 1.7259e-04 - val_mean_absolute_error: 0.0095
# Epoch 126/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.3816e-05 - mean_absolute_error: 0.0060 - val_loss: 1.4540e-04 - val_mean_absolute_error: 0.0093
# Epoch 127/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5501e-05 - mean_absolute_error: 0.0056 - val_loss: 3.2527e-04 - val_mean_absolute_error: 0.0147
# Epoch 128/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.3702e-05 - mean_absolute_error: 0.0058 - val_loss: 1.3425e-04 - val_mean_absolute_error: 0.0084
# Epoch 129/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8861e-05 - mean_absolute_error: 0.0057 - val_loss: 1.3354e-04 - val_mean_absolute_error: 0.0084
# Epoch 130/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.5110e-05 - mean_absolute_error: 0.0053 - val_loss: 1.5918e-04 - val_mean_absolute_error: 0.0091
# Epoch 131/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1331e-05 - mean_absolute_error: 0.0054 - val_loss: 1.3334e-04 - val_mean_absolute_error: 0.0086
# Epoch 132/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.9548e-05 - mean_absolute_error: 0.0059 - val_loss: 1.3498e-04 - val_mean_absolute_error: 0.0084
# Epoch 133/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3591e-05 - mean_absolute_error: 0.0054 - val_loss: 1.3344e-04 - val_mean_absolute_error: 0.0084
# Epoch 134/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6565e-05 - mean_absolute_error: 0.0053 - val_loss: 1.7677e-04 - val_mean_absolute_error: 0.0097
# Epoch 135/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8050e-05 - mean_absolute_error: 0.0052 - val_loss: 2.1618e-04 - val_mean_absolute_error: 0.0110
# Epoch 136/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3717e-05 - mean_absolute_error: 0.0053 - val_loss: 1.3021e-04 - val_mean_absolute_error: 0.0084
# Epoch 137/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.2911e-05 - mean_absolute_error: 0.0057 - val_loss: 2.9454e-04 - val_mean_absolute_error: 0.0138
# Epoch 138/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.4579e-05 - mean_absolute_error: 0.0057 - val_loss: 4.3704e-04 - val_mean_absolute_error: 0.0179
# Epoch 139/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0577e-04 - mean_absolute_error: 0.0072 - val_loss: 1.3810e-04 - val_mean_absolute_error: 0.0089
# Epoch 140/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.3238e-05 - mean_absolute_error: 0.0059 - val_loss: 1.5626e-04 - val_mean_absolute_error: 0.0097
# Epoch 141/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.0691e-05 - mean_absolute_error: 0.0067 - val_loss: 2.2046e-04 - val_mean_absolute_error: 0.0112
# Epoch 142/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 6.9142e-05 - mean_absolute_error: 0.0055 - val_loss: 1.3276e-04 - val_mean_absolute_error: 0.0082
# Epoch 143/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.2188e-05 - mean_absolute_error: 0.0056 - val_loss: 1.3622e-04 - val_mean_absolute_error: 0.0083
# Epoch 144/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.3866e-05 - mean_absolute_error: 0.0059 - val_loss: 2.4327e-04 - val_mean_absolute_error: 0.0120
# Epoch 145/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.8390e-05 - mean_absolute_error: 0.0058 - val_loss: 5.2833e-04 - val_mean_absolute_error: 0.0203
# Epoch 146/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.6483e-05 - mean_absolute_error: 0.0070 - val_loss: 1.4408e-04 - val_mean_absolute_error: 0.0085
# Epoch 147/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.7101e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2644e-04 - val_mean_absolute_error: 0.0083
# Epoch 148/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6974e-05 - mean_absolute_error: 0.0052 - val_loss: 1.7148e-04 - val_mean_absolute_error: 0.0096
# Epoch 149/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.3610e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2547e-04 - val_mean_absolute_error: 0.0081
# Epoch 150/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9931e-05 - mean_absolute_error: 0.0059 - val_loss: 3.8712e-04 - val_mean_absolute_error: 0.0167
# Epoch 151/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9162e-05 - mean_absolute_error: 0.0061 - val_loss: 2.0288e-04 - val_mean_absolute_error: 0.0107
# Epoch 152/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1165e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2871e-04 - val_mean_absolute_error: 0.0080
# Epoch 153/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8321e-05 - mean_absolute_error: 0.0054 - val_loss: 1.3326e-04 - val_mean_absolute_error: 0.0082
# Epoch 154/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.4017e-05 - mean_absolute_error: 0.0057 - val_loss: 1.3666e-04 - val_mean_absolute_error: 0.0083
# Epoch 155/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.0716e-05 - mean_absolute_error: 0.0050 - val_loss: 2.3432e-04 - val_mean_absolute_error: 0.0118
# Epoch 156/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.6644e-05 - mean_absolute_error: 0.0058 - val_loss: 2.1171e-04 - val_mean_absolute_error: 0.0111
# Epoch 157/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3221e-05 - mean_absolute_error: 0.0052 - val_loss: 1.6527e-04 - val_mean_absolute_error: 0.0093
# Epoch 158/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9874e-05 - mean_absolute_error: 0.0051 - val_loss: 2.2107e-04 - val_mean_absolute_error: 0.0114
# Epoch 159/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1343e-05 - mean_absolute_error: 0.0056 - val_loss: 2.8433e-04 - val_mean_absolute_error: 0.0136
# Epoch 160/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3487e-05 - mean_absolute_error: 0.0054 - val_loss: 1.6775e-04 - val_mean_absolute_error: 0.0094
# Epoch 161/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.5731e-05 - mean_absolute_error: 0.0048 - val_loss: 2.1682e-04 - val_mean_absolute_error: 0.0112
# Epoch 162/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8284e-05 - mean_absolute_error: 0.0054 - val_loss: 2.3880e-04 - val_mean_absolute_error: 0.0121
# Epoch 163/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1296e-05 - mean_absolute_error: 0.0052 - val_loss: 1.4600e-04 - val_mean_absolute_error: 0.0086
# Epoch 164/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.7588e-05 - mean_absolute_error: 0.0057 - val_loss: 2.4054e-04 - val_mean_absolute_error: 0.0121
# Epoch 165/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.4654e-05 - mean_absolute_error: 0.0059 - val_loss: 1.3381e-04 - val_mean_absolute_error: 0.0081
# Epoch 166/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.0142e-05 - mean_absolute_error: 0.0051 - val_loss: 1.7858e-04 - val_mean_absolute_error: 0.0099
# Epoch 167/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.9623e-05 - mean_absolute_error: 0.0055 - val_loss: 1.2491e-04 - val_mean_absolute_error: 0.0079
# Epoch 168/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.4460e-05 - mean_absolute_error: 0.0049 - val_loss: 1.2374e-04 - val_mean_absolute_error: 0.0079
# Epoch 169/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.0164e-05 - mean_absolute_error: 0.0055 - val_loss: 2.3080e-04 - val_mean_absolute_error: 0.0118
# Epoch 170/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.2800e-05 - mean_absolute_error: 0.0056 - val_loss: 1.2700e-04 - val_mean_absolute_error: 0.0079
# Epoch 171/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.9786e-05 - mean_absolute_error: 0.0051 - val_loss: 1.5747e-04 - val_mean_absolute_error: 0.0096
# Epoch 172/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4724e-05 - mean_absolute_error: 0.0053 - val_loss: 1.4254e-04 - val_mean_absolute_error: 0.0090
# Epoch 173/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4495e-05 - mean_absolute_error: 0.0057 - val_loss: 1.2453e-04 - val_mean_absolute_error: 0.0079
# Epoch 174/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.9749e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2678e-04 - val_mean_absolute_error: 0.0082
# Epoch 175/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5455e-05 - mean_absolute_error: 0.0056 - val_loss: 1.4012e-04 - val_mean_absolute_error: 0.0089
# Epoch 176/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.0418e-05 - mean_absolute_error: 0.0065 - val_loss: 1.5264e-04 - val_mean_absolute_error: 0.0095
# Epoch 177/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0915e-04 - mean_absolute_error: 0.0074 - val_loss: 1.2261e-04 - val_mean_absolute_error: 0.0079
# Epoch 178/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6431e-05 - mean_absolute_error: 0.0058 - val_loss: 1.4579e-04 - val_mean_absolute_error: 0.0086
# Epoch 179/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0456e-05 - mean_absolute_error: 0.0056 - val_loss: 1.2463e-04 - val_mean_absolute_error: 0.0080
# Epoch 180/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.1184e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3632e-04 - val_mean_absolute_error: 0.0082
# Epoch 181/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4442e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2290e-04 - val_mean_absolute_error: 0.0078
# Epoch 182/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5805e-05 - mean_absolute_error: 0.0052 - val_loss: 1.2465e-04 - val_mean_absolute_error: 0.0078
# Epoch 183/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4431e-05 - mean_absolute_error: 0.0053 - val_loss: 1.8131e-04 - val_mean_absolute_error: 0.0100
# Epoch 184/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6962e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3462e-04 - val_mean_absolute_error: 0.0086
# Epoch 185/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1043e-05 - mean_absolute_error: 0.0054 - val_loss: 1.3402e-04 - val_mean_absolute_error: 0.0081
# Epoch 186/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6976e-05 - mean_absolute_error: 0.0049 - val_loss: 1.5428e-04 - val_mean_absolute_error: 0.0089
# Epoch 187/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7819e-05 - mean_absolute_error: 0.0050 - val_loss: 2.1174e-04 - val_mean_absolute_error: 0.0111
# Epoch 188/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3404e-05 - mean_absolute_error: 0.0055 - val_loss: 2.3715e-04 - val_mean_absolute_error: 0.0120
# Epoch 189/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.0727e-05 - mean_absolute_error: 0.0052 - val_loss: 1.4271e-04 - val_mean_absolute_error: 0.0084
# Epoch 190/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6459e-05 - mean_absolute_error: 0.0056 - val_loss: 1.2394e-04 - val_mean_absolute_error: 0.0080
# Epoch 191/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6623e-05 - mean_absolute_error: 0.0056 - val_loss: 1.9343e-04 - val_mean_absolute_error: 0.0113
# Epoch 192/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.6410e-05 - mean_absolute_error: 0.0060 - val_loss: 1.2570e-04 - val_mean_absolute_error: 0.0078
# Epoch 193/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.0246e-05 - mean_absolute_error: 0.0055 - val_loss: 1.5903e-04 - val_mean_absolute_error: 0.0091
# Epoch 194/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.9712e-05 - mean_absolute_error: 0.0051 - val_loss: 1.2695e-04 - val_mean_absolute_error: 0.0082
# Epoch 195/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6362e-05 - mean_absolute_error: 0.0052 - val_loss: 1.2343e-04 - val_mean_absolute_error: 0.0079
# Epoch 196/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1216e-05 - mean_absolute_error: 0.0057 - val_loss: 1.2545e-04 - val_mean_absolute_error: 0.0080
# Epoch 197/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2348e-05 - mean_absolute_error: 0.0055 - val_loss: 1.3744e-04 - val_mean_absolute_error: 0.0082
# Epoch 198/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1378e-05 - mean_absolute_error: 0.0051 - val_loss: 2.0681e-04 - val_mean_absolute_error: 0.0109
# Epoch 199/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.8097e-05 - mean_absolute_error: 0.0061 - val_loss: 1.5967e-04 - val_mean_absolute_error: 0.0090
# Epoch 200/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.2571e-05 - mean_absolute_error: 0.0061 - val_loss: 3.8985e-04 - val_mean_absolute_error: 0.0168

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 1s 590ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 120
# 131

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 7802399.9841908775
# RMSE: 2793.2776418019885
# MAE: 2309.7888020833334
# MAPE: 2.6829903292913735 %
#
# Model evalution on validate set
# MSE: 21181981.52767566
# RMSE: 4602.388676293611
# MAE: 3774.2964876033056
# MAPE: 3.3532792581008617 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 586ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step

# %%
y_pred_30_days
# Out:
# array([[128446.14 ],
#        [128727.99 ],
#        [128464.14 ],
#        [128310.16 ],
#        [128527.75 ],
#        [128488.36 ],
#        [128503.57 ],
#        [128512.58 ],
#        [128504.35 ],
#        [128507.12 ],
#        [128506.36 ],
#        [128505.97 ],
#        [128506.32 ],
#        [128506.164],
#        [128506.195],
#        [128506.21 ],
#        [128506.195],
#        [128506.21 ],
#        [128506.22 ],
#        [128506.22 ],
#        [128506.21 ],
#        [128506.21 ],
#        [128506.21 ],
#        [128506.22 ],
#        [128506.21 ],
#        [128506.22 ],
#        [128506.22 ],
#        [128506.195],
#        [128506.21 ],
#        [128506.22 ],
#        [128506.21 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Forecast Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Forecast the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
