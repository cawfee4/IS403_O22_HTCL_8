# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: FPT - Test/Train/Vaildation: 80/10/10
# - Dataset: 1252 rows x 7 column (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1188.1379227731193
# - MAE: 854.495545504386
# - MAPE: 1.124459294159712 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 2  # 8 1 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01  19270
# 2019-03-04  19440
# 2019-03-05  19390
# 2019-03-06  19270
# 2019-03-07  19330

# %%
df.shape
# Out:
# (1252, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1247    108000
# 1248    107900
# 1249    108500
# 1250    109000
# 1251    110800
# Name: close, Length: 1252, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((990, 10), (990,), (114, 10), (114,), (115, 10), (115,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0322 - mean_absolute_error: 0.1167 - val_loss: 0.0067 - val_mean_absolute_error: 0.0755
# Epoch 2/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.7350e-04 - mean_absolute_error: 0.0204 - val_loss: 0.0015 - val_mean_absolute_error: 0.0283
# Epoch 3/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1556e-04 - mean_absolute_error: 0.0154 - val_loss: 9.6198e-04 - val_mean_absolute_error: 0.0221
# Epoch 4/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7749e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0010 - val_mean_absolute_error: 0.0233
# Epoch 5/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3433e-04 - mean_absolute_error: 0.0123 - val_loss: 4.8856e-04 - val_mean_absolute_error: 0.0164
# Epoch 6/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3287e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0016 - val_mean_absolute_error: 0.0340
# Epoch 7/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6993e-04 - mean_absolute_error: 0.0136 - val_loss: 4.0039e-04 - val_mean_absolute_error: 0.0145
# Epoch 8/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0719e-04 - mean_absolute_error: 0.0121 - val_loss: 6.3494e-04 - val_mean_absolute_error: 0.0179
# Epoch 9/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.7313e-04 - mean_absolute_error: 0.0111 - val_loss: 5.2069e-04 - val_mean_absolute_error: 0.0159
# Epoch 10/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8835e-04 - mean_absolute_error: 0.0114 - val_loss: 4.8829e-04 - val_mean_absolute_error: 0.0154
# Epoch 11/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1495e-04 - mean_absolute_error: 0.0098 - val_loss: 4.1455e-04 - val_mean_absolute_error: 0.0141
# Epoch 12/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3057e-04 - mean_absolute_error: 0.0099 - val_loss: 3.7268e-04 - val_mean_absolute_error: 0.0133
# Epoch 13/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2599e-04 - mean_absolute_error: 0.0104 - val_loss: 2.7743e-04 - val_mean_absolute_error: 0.0113
# Epoch 14/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3100e-04 - mean_absolute_error: 0.0105 - val_loss: 3.7091e-04 - val_mean_absolute_error: 0.0136
# Epoch 15/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1214e-04 - mean_absolute_error: 0.0099 - val_loss: 2.0564e-04 - val_mean_absolute_error: 0.0114
# Epoch 16/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8363e-04 - mean_absolute_error: 0.0093 - val_loss: 2.0210e-04 - val_mean_absolute_error: 0.0102
# Epoch 17/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9827e-04 - mean_absolute_error: 0.0095 - val_loss: 8.5975e-04 - val_mean_absolute_error: 0.0254
# Epoch 18/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2455e-04 - mean_absolute_error: 0.0102 - val_loss: 7.5675e-04 - val_mean_absolute_error: 0.0235
# Epoch 19/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1846e-04 - mean_absolute_error: 0.0101 - val_loss: 2.1014e-04 - val_mean_absolute_error: 0.0097
# Epoch 20/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7577e-04 - mean_absolute_error: 0.0090 - val_loss: 7.4686e-04 - val_mean_absolute_error: 0.0236
# Epoch 21/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1871e-04 - mean_absolute_error: 0.0099 - val_loss: 4.7576e-04 - val_mean_absolute_error: 0.0173
# Epoch 22/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7927e-04 - mean_absolute_error: 0.0086 - val_loss: 1.6430e-04 - val_mean_absolute_error: 0.0094
# Epoch 23/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7712e-04 - mean_absolute_error: 0.0090 - val_loss: 1.6343e-04 - val_mean_absolute_error: 0.0093
# Epoch 24/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8321e-04 - mean_absolute_error: 0.0091 - val_loss: 1.5471e-04 - val_mean_absolute_error: 0.0093
# Epoch 25/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6372e-04 - mean_absolute_error: 0.0086 - val_loss: 2.7823e-04 - val_mean_absolute_error: 0.0120
# Epoch 26/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5034e-04 - mean_absolute_error: 0.0105 - val_loss: 6.9119e-04 - val_mean_absolute_error: 0.0227
# Epoch 27/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8198e-04 - mean_absolute_error: 0.0091 - val_loss: 1.7215e-04 - val_mean_absolute_error: 0.0089
# Epoch 28/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4048e-04 - mean_absolute_error: 0.0078 - val_loss: 2.1728e-04 - val_mean_absolute_error: 0.0100
# Epoch 29/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3326e-04 - mean_absolute_error: 0.0074 - val_loss: 1.5315e-04 - val_mean_absolute_error: 0.0085
# Epoch 30/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5839e-04 - mean_absolute_error: 0.0080 - val_loss: 2.7764e-04 - val_mean_absolute_error: 0.0148
# Epoch 31/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.4089e-04 - mean_absolute_error: 0.0108 - val_loss: 1.4004e-04 - val_mean_absolute_error: 0.0088
# Epoch 32/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6826e-04 - mean_absolute_error: 0.0084 - val_loss: 2.4028e-04 - val_mean_absolute_error: 0.0109
# Epoch 33/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5570e-04 - mean_absolute_error: 0.0083 - val_loss: 2.2233e-04 - val_mean_absolute_error: 0.0104
# Epoch 34/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4334e-04 - mean_absolute_error: 0.0082 - val_loss: 1.7602e-04 - val_mean_absolute_error: 0.0089
# Epoch 35/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4140e-04 - mean_absolute_error: 0.0078 - val_loss: 2.4570e-04 - val_mean_absolute_error: 0.0113
# Epoch 36/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7480e-04 - mean_absolute_error: 0.0088 - val_loss: 4.5365e-04 - val_mean_absolute_error: 0.0176
# Epoch 37/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2710e-04 - mean_absolute_error: 0.0107 - val_loss: 2.9326e-04 - val_mean_absolute_error: 0.0127
# Epoch 38/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3850e-04 - mean_absolute_error: 0.0076 - val_loss: 1.4546e-04 - val_mean_absolute_error: 0.0082
# Epoch 39/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9440e-04 - mean_absolute_error: 0.0090 - val_loss: 1.8719e-04 - val_mean_absolute_error: 0.0093
# Epoch 40/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6913e-04 - mean_absolute_error: 0.0085 - val_loss: 1.7566e-04 - val_mean_absolute_error: 0.0090
# Epoch 41/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9006e-04 - mean_absolute_error: 0.0090 - val_loss: 2.7601e-04 - val_mean_absolute_error: 0.0127
# Epoch 42/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7641e-04 - mean_absolute_error: 0.0090 - val_loss: 3.8891e-04 - val_mean_absolute_error: 0.0161
# Epoch 43/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5465e-04 - mean_absolute_error: 0.0081 - val_loss: 1.4617e-04 - val_mean_absolute_error: 0.0081
# Epoch 44/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3608e-04 - mean_absolute_error: 0.0076 - val_loss: 4.7506e-04 - val_mean_absolute_error: 0.0186
# Epoch 45/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5199e-04 - mean_absolute_error: 0.0083 - val_loss: 1.3351e-04 - val_mean_absolute_error: 0.0077
# Epoch 46/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4195e-04 - mean_absolute_error: 0.0073 - val_loss: 1.2992e-04 - val_mean_absolute_error: 0.0076
# Epoch 47/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8443e-04 - mean_absolute_error: 0.0088 - val_loss: 1.3211e-04 - val_mean_absolute_error: 0.0094
# Epoch 48/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4583e-04 - mean_absolute_error: 0.0082 - val_loss: 1.1300e-04 - val_mean_absolute_error: 0.0081
# Epoch 49/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3662e-04 - mean_absolute_error: 0.0077 - val_loss: 1.4732e-04 - val_mean_absolute_error: 0.0082
# Epoch 50/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1083e-04 - mean_absolute_error: 0.0068 - val_loss: 1.4179e-04 - val_mean_absolute_error: 0.0080
# Epoch 51/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3177e-04 - mean_absolute_error: 0.0075 - val_loss: 1.0820e-04 - val_mean_absolute_error: 0.0079
# Epoch 52/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5669e-04 - mean_absolute_error: 0.0084 - val_loss: 1.1988e-04 - val_mean_absolute_error: 0.0087
# Epoch 53/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6740e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0809e-04 - val_mean_absolute_error: 0.0074
# Epoch 54/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3587e-04 - mean_absolute_error: 0.0075 - val_loss: 2.2830e-04 - val_mean_absolute_error: 0.0113
# Epoch 55/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1963e-04 - mean_absolute_error: 0.0072 - val_loss: 1.5633e-04 - val_mean_absolute_error: 0.0086
# Epoch 56/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5083e-04 - mean_absolute_error: 0.0078 - val_loss: 3.2524e-04 - val_mean_absolute_error: 0.0147
# Epoch 57/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4128e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2240e-04 - val_mean_absolute_error: 0.0091
# Epoch 58/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2581e-04 - mean_absolute_error: 0.0073 - val_loss: 1.1668e-04 - val_mean_absolute_error: 0.0088
# Epoch 59/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4720e-04 - mean_absolute_error: 0.0077 - val_loss: 1.0124e-04 - val_mean_absolute_error: 0.0071
# Epoch 60/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0681e-04 - mean_absolute_error: 0.0066 - val_loss: 2.4171e-04 - val_mean_absolute_error: 0.0120
# Epoch 61/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4667e-04 - mean_absolute_error: 0.0080 - val_loss: 1.1202e-04 - val_mean_absolute_error: 0.0084
# Epoch 62/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6826e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0153e-04 - val_mean_absolute_error: 0.0076
# Epoch 63/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2117e-04 - mean_absolute_error: 0.0074 - val_loss: 3.0155e-04 - val_mean_absolute_error: 0.0141
# Epoch 64/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3359e-04 - mean_absolute_error: 0.0078 - val_loss: 1.0135e-04 - val_mean_absolute_error: 0.0078
# Epoch 65/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4225e-04 - mean_absolute_error: 0.0080 - val_loss: 1.3557e-04 - val_mean_absolute_error: 0.0079
# Epoch 66/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2785e-04 - mean_absolute_error: 0.0073 - val_loss: 1.5249e-04 - val_mean_absolute_error: 0.0107
# Epoch 67/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3112e-04 - mean_absolute_error: 0.0077 - val_loss: 1.1732e-04 - val_mean_absolute_error: 0.0072
# Epoch 68/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2848e-04 - mean_absolute_error: 0.0071 - val_loss: 1.0200e-04 - val_mean_absolute_error: 0.0080
# Epoch 69/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2021e-04 - mean_absolute_error: 0.0074 - val_loss: 3.8720e-04 - val_mean_absolute_error: 0.0169
# Epoch 70/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6005e-04 - mean_absolute_error: 0.0089 - val_loss: 9.3947e-05 - val_mean_absolute_error: 0.0068
# Epoch 71/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2277e-04 - mean_absolute_error: 0.0075 - val_loss: 3.2437e-04 - val_mean_absolute_error: 0.0150
# Epoch 72/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2202e-04 - mean_absolute_error: 0.0074 - val_loss: 1.2809e-04 - val_mean_absolute_error: 0.0077
# Epoch 73/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0643e-04 - mean_absolute_error: 0.0068 - val_loss: 3.0070e-04 - val_mean_absolute_error: 0.0143
# Epoch 74/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1754e-04 - mean_absolute_error: 0.0072 - val_loss: 1.0748e-04 - val_mean_absolute_error: 0.0069
# Epoch 75/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0008e-04 - mean_absolute_error: 0.0065 - val_loss: 8.8474e-05 - val_mean_absolute_error: 0.0067
# Epoch 76/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0414e-04 - mean_absolute_error: 0.0066 - val_loss: 9.2133e-05 - val_mean_absolute_error: 0.0066
# Epoch 77/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2001e-04 - mean_absolute_error: 0.0072 - val_loss: 1.7602e-04 - val_mean_absolute_error: 0.0097
# Epoch 78/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7120e-04 - mean_absolute_error: 0.0093 - val_loss: 2.3751e-04 - val_mean_absolute_error: 0.0121
# Epoch 79/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4076e-04 - mean_absolute_error: 0.0079 - val_loss: 9.1816e-05 - val_mean_absolute_error: 0.0075
# Epoch 80/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3472e-04 - mean_absolute_error: 0.0073 - val_loss: 8.8126e-05 - val_mean_absolute_error: 0.0064
# Epoch 81/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3210e-04 - mean_absolute_error: 0.0072 - val_loss: 8.4488e-05 - val_mean_absolute_error: 0.0067
# Epoch 82/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3389e-04 - mean_absolute_error: 0.0077 - val_loss: 5.1648e-04 - val_mean_absolute_error: 0.0204
# Epoch 83/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2152e-04 - mean_absolute_error: 0.0073 - val_loss: 8.5037e-05 - val_mean_absolute_error: 0.0066
# Epoch 84/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1046e-04 - mean_absolute_error: 0.0069 - val_loss: 3.6122e-04 - val_mean_absolute_error: 0.0163
# Epoch 85/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1236e-04 - mean_absolute_error: 0.0071 - val_loss: 1.1302e-04 - val_mean_absolute_error: 0.0072
# Epoch 86/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4642e-04 - mean_absolute_error: 0.0082 - val_loss: 8.4195e-05 - val_mean_absolute_error: 0.0064
# Epoch 87/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1099e-04 - mean_absolute_error: 0.0068 - val_loss: 8.5112e-05 - val_mean_absolute_error: 0.0065
# Epoch 88/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1596e-04 - mean_absolute_error: 0.0069 - val_loss: 1.2088e-04 - val_mean_absolute_error: 0.0075
# Epoch 89/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0467e-04 - mean_absolute_error: 0.0066 - val_loss: 1.2255e-04 - val_mean_absolute_error: 0.0095
# Epoch 90/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3659e-04 - mean_absolute_error: 0.0076 - val_loss: 9.7644e-05 - val_mean_absolute_error: 0.0081
# Epoch 91/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2961e-04 - mean_absolute_error: 0.0076 - val_loss: 8.9943e-05 - val_mean_absolute_error: 0.0075
# Epoch 92/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3601e-04 - mean_absolute_error: 0.0077 - val_loss: 1.0135e-04 - val_mean_absolute_error: 0.0067
# Epoch 93/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1380e-04 - mean_absolute_error: 0.0068 - val_loss: 1.3430e-04 - val_mean_absolute_error: 0.0082
# Epoch 94/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0764e-04 - mean_absolute_error: 0.0067 - val_loss: 1.3207e-04 - val_mean_absolute_error: 0.0081
# Epoch 95/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0719e-04 - mean_absolute_error: 0.0068 - val_loss: 1.0733e-04 - val_mean_absolute_error: 0.0070
# Epoch 96/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.9425e-05 - mean_absolute_error: 0.0064 - val_loss: 9.3072e-05 - val_mean_absolute_error: 0.0065
# Epoch 97/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0843e-04 - mean_absolute_error: 0.0065 - val_loss: 1.0346e-04 - val_mean_absolute_error: 0.0068
# Epoch 98/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1308e-04 - mean_absolute_error: 0.0069 - val_loss: 8.2294e-05 - val_mean_absolute_error: 0.0062
# Epoch 99/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8872e-05 - mean_absolute_error: 0.0064 - val_loss: 1.1484e-04 - val_mean_absolute_error: 0.0073
# Epoch 100/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0491e-04 - mean_absolute_error: 0.0067 - val_loss: 1.0854e-04 - val_mean_absolute_error: 0.0071
# Epoch 101/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3524e-04 - mean_absolute_error: 0.0074 - val_loss: 8.0269e-05 - val_mean_absolute_error: 0.0062
# Epoch 102/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2258e-04 - mean_absolute_error: 0.0071 - val_loss: 1.6023e-04 - val_mean_absolute_error: 0.0094
# Epoch 103/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0081e-04 - mean_absolute_error: 0.0064 - val_loss: 7.7334e-05 - val_mean_absolute_error: 0.0062
# Epoch 104/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1247e-04 - mean_absolute_error: 0.0065 - val_loss: 1.2134e-04 - val_mean_absolute_error: 0.0077
# Epoch 105/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1301e-04 - mean_absolute_error: 0.0066 - val_loss: 1.2430e-04 - val_mean_absolute_error: 0.0077
# Epoch 106/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1284e-04 - mean_absolute_error: 0.0068 - val_loss: 1.2383e-04 - val_mean_absolute_error: 0.0077
# Epoch 107/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3303e-04 - mean_absolute_error: 0.0075 - val_loss: 2.0746e-04 - val_mean_absolute_error: 0.0114
# Epoch 108/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4189e-04 - mean_absolute_error: 0.0078 - val_loss: 1.1206e-04 - val_mean_absolute_error: 0.0072
# Epoch 109/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2506e-04 - mean_absolute_error: 0.0072 - val_loss: 1.0016e-04 - val_mean_absolute_error: 0.0067
# Epoch 110/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0767e-04 - mean_absolute_error: 0.0067 - val_loss: 1.0576e-04 - val_mean_absolute_error: 0.0086
# Epoch 111/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4742e-04 - mean_absolute_error: 0.0082 - val_loss: 7.7583e-05 - val_mean_absolute_error: 0.0065
# Epoch 112/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2643e-04 - mean_absolute_error: 0.0072 - val_loss: 2.3604e-04 - val_mean_absolute_error: 0.0126
# Epoch 113/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1854e-04 - mean_absolute_error: 0.0070 - val_loss: 8.4590e-05 - val_mean_absolute_error: 0.0061
# Epoch 114/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0938e-04 - mean_absolute_error: 0.0067 - val_loss: 1.3047e-04 - val_mean_absolute_error: 0.0081
# Epoch 115/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7701e-05 - mean_absolute_error: 0.0064 - val_loss: 1.4008e-04 - val_mean_absolute_error: 0.0086
# Epoch 116/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1133e-04 - mean_absolute_error: 0.0070 - val_loss: 7.8191e-05 - val_mean_absolute_error: 0.0067
# Epoch 117/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1095e-04 - mean_absolute_error: 0.0070 - val_loss: 9.0434e-05 - val_mean_absolute_error: 0.0063
# Epoch 118/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1992e-04 - mean_absolute_error: 0.0072 - val_loss: 9.3732e-05 - val_mean_absolute_error: 0.0079
# Epoch 119/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.8681e-05 - mean_absolute_error: 0.0061 - val_loss: 7.4077e-05 - val_mean_absolute_error: 0.0060
# Epoch 120/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.8611e-05 - mean_absolute_error: 0.0065 - val_loss: 8.1234e-05 - val_mean_absolute_error: 0.0060
# Epoch 121/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1141e-04 - mean_absolute_error: 0.0067 - val_loss: 8.0787e-05 - val_mean_absolute_error: 0.0061
# Epoch 122/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0661e-04 - mean_absolute_error: 0.0064 - val_loss: 8.1637e-05 - val_mean_absolute_error: 0.0060
# Epoch 123/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0492e-04 - mean_absolute_error: 0.0067 - val_loss: 1.3392e-04 - val_mean_absolute_error: 0.0083
# Epoch 124/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0678e-04 - mean_absolute_error: 0.0069 - val_loss: 7.7365e-05 - val_mean_absolute_error: 0.0062
# Epoch 125/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1237e-05 - mean_absolute_error: 0.0064 - val_loss: 1.5539e-04 - val_mean_absolute_error: 0.0093
# Epoch 126/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2489e-04 - mean_absolute_error: 0.0074 - val_loss: 3.2817e-04 - val_mean_absolute_error: 0.0157
# Epoch 127/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2224e-04 - mean_absolute_error: 0.0072 - val_loss: 3.6883e-04 - val_mean_absolute_error: 0.0169
# Epoch 128/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3093e-04 - mean_absolute_error: 0.0079 - val_loss: 8.8971e-05 - val_mean_absolute_error: 0.0063
# Epoch 129/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6684e-05 - mean_absolute_error: 0.0064 - val_loss: 1.7079e-04 - val_mean_absolute_error: 0.0101
# Epoch 130/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0710e-04 - mean_absolute_error: 0.0067 - val_loss: 8.1057e-05 - val_mean_absolute_error: 0.0070
# Epoch 131/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2240e-04 - mean_absolute_error: 0.0071 - val_loss: 1.5935e-04 - val_mean_absolute_error: 0.0095
# Epoch 132/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2260e-04 - mean_absolute_error: 0.0071 - val_loss: 1.4843e-04 - val_mean_absolute_error: 0.0091
# Epoch 133/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3276e-05 - mean_absolute_error: 0.0063 - val_loss: 1.7482e-04 - val_mean_absolute_error: 0.0116
# Epoch 134/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5167e-04 - mean_absolute_error: 0.0087 - val_loss: 2.0926e-04 - val_mean_absolute_error: 0.0117
# Epoch 135/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0411e-04 - mean_absolute_error: 0.0066 - val_loss: 1.9166e-04 - val_mean_absolute_error: 0.0109
# Epoch 136/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1594e-04 - mean_absolute_error: 0.0072 - val_loss: 1.1838e-04 - val_mean_absolute_error: 0.0076
# Epoch 137/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0659e-04 - mean_absolute_error: 0.0068 - val_loss: 7.2184e-05 - val_mean_absolute_error: 0.0060
# Epoch 138/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0964e-04 - mean_absolute_error: 0.0067 - val_loss: 1.6520e-04 - val_mean_absolute_error: 0.0098
# Epoch 139/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3378e-04 - mean_absolute_error: 0.0074 - val_loss: 7.6924e-05 - val_mean_absolute_error: 0.0059
# Epoch 140/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0758e-04 - mean_absolute_error: 0.0069 - val_loss: 1.1692e-04 - val_mean_absolute_error: 0.0075
# Epoch 141/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1297e-04 - mean_absolute_error: 0.0071 - val_loss: 9.2445e-05 - val_mean_absolute_error: 0.0078
# Epoch 142/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2175e-04 - mean_absolute_error: 0.0076 - val_loss: 2.5342e-04 - val_mean_absolute_error: 0.0133
# Epoch 143/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0443e-04 - mean_absolute_error: 0.0069 - val_loss: 7.4163e-05 - val_mean_absolute_error: 0.0059
# Epoch 144/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.0898e-05 - mean_absolute_error: 0.0062 - val_loss: 1.2093e-04 - val_mean_absolute_error: 0.0077
# Epoch 145/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1500e-04 - mean_absolute_error: 0.0066 - val_loss: 7.1506e-05 - val_mean_absolute_error: 0.0060
# Epoch 146/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.8962e-05 - mean_absolute_error: 0.0063 - val_loss: 8.5265e-05 - val_mean_absolute_error: 0.0073
# Epoch 147/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1354e-04 - mean_absolute_error: 0.0068 - val_loss: 3.1077e-04 - val_mean_absolute_error: 0.0153
# Epoch 148/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4720e-04 - mean_absolute_error: 0.0082 - val_loss: 1.3880e-04 - val_mean_absolute_error: 0.0086
# Epoch 149/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1801e-04 - mean_absolute_error: 0.0072 - val_loss: 1.6038e-04 - val_mean_absolute_error: 0.0097
# Epoch 150/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8179e-05 - mean_absolute_error: 0.0066 - val_loss: 8.1854e-05 - val_mean_absolute_error: 0.0071
# Epoch 151/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0883e-04 - mean_absolute_error: 0.0070 - val_loss: 7.3101e-05 - val_mean_absolute_error: 0.0063
# Epoch 152/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0216e-04 - mean_absolute_error: 0.0065 - val_loss: 8.2443e-05 - val_mean_absolute_error: 0.0060
# Epoch 153/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7203e-05 - mean_absolute_error: 0.0062 - val_loss: 7.2155e-05 - val_mean_absolute_error: 0.0061
# Epoch 154/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0924e-04 - mean_absolute_error: 0.0067 - val_loss: 7.4032e-05 - val_mean_absolute_error: 0.0059
# Epoch 155/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8773e-05 - mean_absolute_error: 0.0064 - val_loss: 1.9121e-04 - val_mean_absolute_error: 0.0110
# Epoch 156/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2502e-04 - mean_absolute_error: 0.0073 - val_loss: 7.4813e-05 - val_mean_absolute_error: 0.0064
# Epoch 157/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3278e-04 - mean_absolute_error: 0.0078 - val_loss: 7.3959e-05 - val_mean_absolute_error: 0.0060
# Epoch 158/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1931e-04 - mean_absolute_error: 0.0076 - val_loss: 3.1105e-04 - val_mean_absolute_error: 0.0152
# Epoch 159/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1263e-04 - mean_absolute_error: 0.0071 - val_loss: 7.0885e-05 - val_mean_absolute_error: 0.0060
# Epoch 160/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8946e-05 - mean_absolute_error: 0.0066 - val_loss: 9.3556e-05 - val_mean_absolute_error: 0.0078
# Epoch 161/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8806e-05 - mean_absolute_error: 0.0067 - val_loss: 7.4569e-05 - val_mean_absolute_error: 0.0063
# Epoch 162/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1723e-04 - mean_absolute_error: 0.0075 - val_loss: 1.2482e-04 - val_mean_absolute_error: 0.0080
# Epoch 163/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2674e-04 - mean_absolute_error: 0.0076 - val_loss: 7.2816e-05 - val_mean_absolute_error: 0.0063
# Epoch 164/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1454e-04 - mean_absolute_error: 0.0069 - val_loss: 2.8257e-04 - val_mean_absolute_error: 0.0144
# Epoch 165/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1714e-04 - mean_absolute_error: 0.0074 - val_loss: 7.7872e-05 - val_mean_absolute_error: 0.0067
# Epoch 166/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0322e-04 - mean_absolute_error: 0.0066 - val_loss: 7.6127e-05 - val_mean_absolute_error: 0.0066
# Epoch 167/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2966e-04 - mean_absolute_error: 0.0074 - val_loss: 1.3518e-04 - val_mean_absolute_error: 0.0085
# Epoch 168/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2022e-04 - mean_absolute_error: 0.0068 - val_loss: 8.0401e-05 - val_mean_absolute_error: 0.0059
# Epoch 169/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2996e-04 - mean_absolute_error: 0.0075 - val_loss: 7.9013e-05 - val_mean_absolute_error: 0.0059
# Epoch 170/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1129e-04 - mean_absolute_error: 0.0067 - val_loss: 8.2467e-05 - val_mean_absolute_error: 0.0060
# Epoch 171/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0478e-04 - mean_absolute_error: 0.0066 - val_loss: 7.1241e-05 - val_mean_absolute_error: 0.0060
# Epoch 172/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2042e-04 - mean_absolute_error: 0.0069 - val_loss: 2.6738e-04 - val_mean_absolute_error: 0.0139
# Epoch 173/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3634e-04 - mean_absolute_error: 0.0080 - val_loss: 8.9214e-05 - val_mean_absolute_error: 0.0063
# Epoch 174/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0787e-04 - mean_absolute_error: 0.0067 - val_loss: 1.3451e-04 - val_mean_absolute_error: 0.0085
# Epoch 175/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2555e-04 - mean_absolute_error: 0.0077 - val_loss: 1.6757e-04 - val_mean_absolute_error: 0.0113
# Epoch 176/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4024e-04 - mean_absolute_error: 0.0081 - val_loss: 1.0917e-04 - val_mean_absolute_error: 0.0072
# Epoch 177/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1090e-04 - mean_absolute_error: 0.0068 - val_loss: 2.0624e-04 - val_mean_absolute_error: 0.0128
# Epoch 178/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4009e-04 - mean_absolute_error: 0.0082 - val_loss: 8.4747e-05 - val_mean_absolute_error: 0.0061
# Epoch 179/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0137e-04 - mean_absolute_error: 0.0065 - val_loss: 7.1517e-05 - val_mean_absolute_error: 0.0058
# Epoch 180/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4632e-05 - mean_absolute_error: 0.0064 - val_loss: 1.6682e-04 - val_mean_absolute_error: 0.0100
# Epoch 181/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0703e-04 - mean_absolute_error: 0.0071 - val_loss: 7.0726e-05 - val_mean_absolute_error: 0.0057
# Epoch 182/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0980e-04 - mean_absolute_error: 0.0070 - val_loss: 2.3002e-04 - val_mean_absolute_error: 0.0137
# Epoch 183/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9052e-04 - mean_absolute_error: 0.0099 - val_loss: 8.2854e-05 - val_mean_absolute_error: 0.0060
# Epoch 184/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.0740e-05 - mean_absolute_error: 0.0063 - val_loss: 1.5073e-04 - val_mean_absolute_error: 0.0094
# Epoch 185/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5150e-04 - mean_absolute_error: 0.0088 - val_loss: 7.3747e-05 - val_mean_absolute_error: 0.0058
# Epoch 186/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2635e-04 - mean_absolute_error: 0.0074 - val_loss: 1.3985e-04 - val_mean_absolute_error: 0.0102
# Epoch 187/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.5619e-05 - mean_absolute_error: 0.0065 - val_loss: 7.4413e-05 - val_mean_absolute_error: 0.0065
# Epoch 188/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1321e-04 - mean_absolute_error: 0.0070 - val_loss: 1.2667e-04 - val_mean_absolute_error: 0.0081
# Epoch 189/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0156e-04 - mean_absolute_error: 0.0066 - val_loss: 1.1032e-04 - val_mean_absolute_error: 0.0073
# Epoch 190/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4041e-05 - mean_absolute_error: 0.0062 - val_loss: 7.9704e-05 - val_mean_absolute_error: 0.0059
# Epoch 191/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0415e-04 - mean_absolute_error: 0.0068 - val_loss: 1.9092e-04 - val_mean_absolute_error: 0.0111
# Epoch 192/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1701e-04 - mean_absolute_error: 0.0071 - val_loss: 1.0723e-04 - val_mean_absolute_error: 0.0071
# Epoch 193/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0782e-04 - mean_absolute_error: 0.0068 - val_loss: 1.1748e-04 - val_mean_absolute_error: 0.0078
# Epoch 194/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2437e-04 - mean_absolute_error: 0.0075 - val_loss: 6.9741e-05 - val_mean_absolute_error: 0.0058
# Epoch 195/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2813e-04 - mean_absolute_error: 0.0078 - val_loss: 8.4790e-05 - val_mean_absolute_error: 0.0072
# Epoch 196/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2272e-04 - mean_absolute_error: 0.0075 - val_loss: 2.1529e-04 - val_mean_absolute_error: 0.0120
# Epoch 197/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0798e-04 - mean_absolute_error: 0.0072 - val_loss: 7.1683e-05 - val_mean_absolute_error: 0.0057
# Epoch 198/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.9649e-05 - mean_absolute_error: 0.0063 - val_loss: 7.0979e-05 - val_mean_absolute_error: 0.0059
# Epoch 199/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.8290e-05 - mean_absolute_error: 0.0061 - val_loss: 8.7232e-05 - val_mean_absolute_error: 0.0062
# Epoch 200/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0838e-04 - mean_absolute_error: 0.0065 - val_loss: 7.0805e-05 - val_mean_absolute_error: 0.0061

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 114
# 125

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 1411671.7235316227
# RMSE: 1188.1379227731193
# MAE: 854.495545504386
# MAPE: 1.124459294159712 %
#
# Model evalution on validate set
# MSE: 3929395.871691364
# RMSE: 1982.270383093932
# MAE: 1448.8478260869565
# MAPE: 1.519003394066144 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %%
y_pred_30_days
# Out:
# array([[108767.52 ],
#        [108859.83 ],
#        [108823.54 ],
#        [108811.52 ],
#        [108821.086],
#        [108814.62 ],
#        [108817.125],
#        [108816.96 ],
#        [108816.66 ],
#        [108816.984],
#        [108816.84 ],
#        [108816.87 ],
#        [108816.875],
#        [108816.85 ],
#        [108816.875],
#        [108816.875],
#        [108816.87 ],
#        [108816.875],
#        [108816.875],
#        [108816.87 ],
#        [108816.85 ],
#        [108816.87 ],
#        [108816.87 ],
#        [108816.875],
#        [108816.875],
#        [108816.85 ],
#        [108816.87 ],
#        [108816.85 ],
#        [108816.875],
#        [108816.85 ],
#        [108816.88 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Predict the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
