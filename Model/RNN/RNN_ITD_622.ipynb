# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: ITD - Test/Train/Vaildation: 60/20/20
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 427.7750456600651
# - MAE: 314.5279954401145
# - MAPE: 2.8987159264462057 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 1  # 6 2 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        6900
# 1        7100
# 2        7100
# 3        7170
# 4        7170
#         ...
# 1308    11300
# 1309    12050
# 1310    12600
# 1311    12500
# 1312    12700
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((776, 10), (776,), (251, 10), (251,), (253, 10), (253,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - loss: 0.0428 - mean_absolute_error: 0.1330 - val_loss: 0.0041 - val_mean_absolute_error: 0.0528
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0028 - mean_absolute_error: 0.0347 - val_loss: 0.0017 - val_mean_absolute_error: 0.0304
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0022 - mean_absolute_error: 0.0298 - val_loss: 0.0017 - val_mean_absolute_error: 0.0328
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0015 - mean_absolute_error: 0.0250 - val_loss: 0.0011 - val_mean_absolute_error: 0.0237
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0017 - mean_absolute_error: 0.0249 - val_loss: 0.0013 - val_mean_absolute_error: 0.0286
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0011 - mean_absolute_error: 0.0215 - val_loss: 7.5558e-04 - val_mean_absolute_error: 0.0198
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.5878e-04 - mean_absolute_error: 0.0189 - val_loss: 9.1008e-04 - val_mean_absolute_error: 0.0231
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.1169e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0012 - val_mean_absolute_error: 0.0290
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 8.7888e-04 - mean_absolute_error: 0.0190 - val_loss: 7.6928e-04 - val_mean_absolute_error: 0.0210
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.8601e-04 - mean_absolute_error: 0.0197 - val_loss: 7.3348e-04 - val_mean_absolute_error: 0.0204
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.3725e-04 - mean_absolute_error: 0.0180 - val_loss: 7.9357e-04 - val_mean_absolute_error: 0.0218
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.5224e-04 - mean_absolute_error: 0.0191 - val_loss: 7.2566e-04 - val_mean_absolute_error: 0.0206
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.0577e-04 - mean_absolute_error: 0.0158 - val_loss: 5.7991e-04 - val_mean_absolute_error: 0.0176
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.1523e-04 - mean_absolute_error: 0.0177 - val_loss: 6.6050e-04 - val_mean_absolute_error: 0.0194
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.7835e-04 - mean_absolute_error: 0.0180 - val_loss: 5.6612e-04 - val_mean_absolute_error: 0.0174
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6124e-04 - mean_absolute_error: 0.0166 - val_loss: 6.6029e-04 - val_mean_absolute_error: 0.0195
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.5619e-04 - mean_absolute_error: 0.0156 - val_loss: 6.5973e-04 - val_mean_absolute_error: 0.0197
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9911e-04 - mean_absolute_error: 0.0154 - val_loss: 0.0014 - val_mean_absolute_error: 0.0318
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.6446e-04 - mean_absolute_error: 0.0186 - val_loss: 7.5543e-04 - val_mean_absolute_error: 0.0218
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.7261e-04 - mean_absolute_error: 0.0170 - val_loss: 5.0403e-04 - val_mean_absolute_error: 0.0162
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.6107e-04 - mean_absolute_error: 0.0143 - val_loss: 7.9647e-04 - val_mean_absolute_error: 0.0226
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6009e-04 - mean_absolute_error: 0.0161 - val_loss: 4.6249e-04 - val_mean_absolute_error: 0.0155
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.2870e-04 - mean_absolute_error: 0.0152 - val_loss: 4.6056e-04 - val_mean_absolute_error: 0.0155
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1314e-04 - mean_absolute_error: 0.0152 - val_loss: 4.7771e-04 - val_mean_absolute_error: 0.0160
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.6944e-04 - mean_absolute_error: 0.0144 - val_loss: 6.4667e-04 - val_mean_absolute_error: 0.0199
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.6795e-04 - mean_absolute_error: 0.0147 - val_loss: 7.9783e-04 - val_mean_absolute_error: 0.0228
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.2590e-04 - mean_absolute_error: 0.0163 - val_loss: 5.4999e-04 - val_mean_absolute_error: 0.0180
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.7500e-04 - mean_absolute_error: 0.0145 - val_loss: 4.2925e-04 - val_mean_absolute_error: 0.0149
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.9019e-04 - mean_absolute_error: 0.0192 - val_loss: 5.2171e-04 - val_mean_absolute_error: 0.0173
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.9884e-04 - mean_absolute_error: 0.0165 - val_loss: 4.1791e-04 - val_mean_absolute_error: 0.0147
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.0695e-04 - mean_absolute_error: 0.0147 - val_loss: 4.2031e-04 - val_mean_absolute_error: 0.0149
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4826e-04 - mean_absolute_error: 0.0144 - val_loss: 4.8532e-04 - val_mean_absolute_error: 0.0167
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.1911e-04 - mean_absolute_error: 0.0148 - val_loss: 4.0983e-04 - val_mean_absolute_error: 0.0146
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.2533e-04 - mean_absolute_error: 0.0140 - val_loss: 3.9945e-04 - val_mean_absolute_error: 0.0144
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.8598e-04 - mean_absolute_error: 0.0137 - val_loss: 4.1329e-04 - val_mean_absolute_error: 0.0147
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.6491e-04 - mean_absolute_error: 0.0144 - val_loss: 4.3896e-04 - val_mean_absolute_error: 0.0156
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.7998e-04 - mean_absolute_error: 0.0131 - val_loss: 4.0736e-04 - val_mean_absolute_error: 0.0148
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.1709e-04 - mean_absolute_error: 0.0139 - val_loss: 8.2774e-04 - val_mean_absolute_error: 0.0239
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.1495e-04 - mean_absolute_error: 0.0164 - val_loss: 5.3190e-04 - val_mean_absolute_error: 0.0182
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.8560e-04 - mean_absolute_error: 0.0140 - val_loss: 3.6690e-04 - val_mean_absolute_error: 0.0138
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5333e-04 - mean_absolute_error: 0.0144 - val_loss: 3.7939e-04 - val_mean_absolute_error: 0.0142
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.2418e-04 - mean_absolute_error: 0.0141 - val_loss: 8.0472e-04 - val_mean_absolute_error: 0.0236
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.9967e-04 - mean_absolute_error: 0.0166 - val_loss: 3.8354e-04 - val_mean_absolute_error: 0.0144
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.9456e-04 - mean_absolute_error: 0.0158 - val_loss: 4.1455e-04 - val_mean_absolute_error: 0.0152
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1541e-04 - mean_absolute_error: 0.0124 - val_loss: 4.7074e-04 - val_mean_absolute_error: 0.0169
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.8940e-04 - mean_absolute_error: 0.0142 - val_loss: 3.5357e-04 - val_mean_absolute_error: 0.0137
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.6462e-04 - mean_absolute_error: 0.0137 - val_loss: 4.5607e-04 - val_mean_absolute_error: 0.0166
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.9331e-04 - mean_absolute_error: 0.0143 - val_loss: 4.5828e-04 - val_mean_absolute_error: 0.0166
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4701e-04 - mean_absolute_error: 0.0136 - val_loss: 3.6203e-04 - val_mean_absolute_error: 0.0140
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.4711e-04 - mean_absolute_error: 0.0142 - val_loss: 3.3740e-04 - val_mean_absolute_error: 0.0133
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8515e-04 - mean_absolute_error: 0.0121 - val_loss: 3.7418e-04 - val_mean_absolute_error: 0.0145
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.7312e-04 - mean_absolute_error: 0.0134 - val_loss: 3.3696e-04 - val_mean_absolute_error: 0.0133
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.7553e-04 - mean_absolute_error: 0.0135 - val_loss: 3.4745e-04 - val_mean_absolute_error: 0.0137
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.5865e-04 - mean_absolute_error: 0.0116 - val_loss: 4.0261e-04 - val_mean_absolute_error: 0.0153
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7362e-04 - mean_absolute_error: 0.0121 - val_loss: 3.3753e-04 - val_mean_absolute_error: 0.0135
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.7162e-04 - mean_absolute_error: 0.0120 - val_loss: 5.1465e-04 - val_mean_absolute_error: 0.0181
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.7749e-04 - mean_absolute_error: 0.0144 - val_loss: 4.4880e-04 - val_mean_absolute_error: 0.0166
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.5403e-04 - mean_absolute_error: 0.0130 - val_loss: 3.3007e-04 - val_mean_absolute_error: 0.0133
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.0001e-04 - mean_absolute_error: 0.0121 - val_loss: 3.2823e-04 - val_mean_absolute_error: 0.0133
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.0831e-04 - mean_absolute_error: 0.0124 - val_loss: 3.3749e-04 - val_mean_absolute_error: 0.0137
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8692e-04 - mean_absolute_error: 0.0122 - val_loss: 3.3720e-04 - val_mean_absolute_error: 0.0137
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6749e-04 - mean_absolute_error: 0.0121 - val_loss: 3.1967e-04 - val_mean_absolute_error: 0.0131
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.2917e-04 - mean_absolute_error: 0.0129 - val_loss: 3.8146e-04 - val_mean_absolute_error: 0.0151
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8120e-04 - mean_absolute_error: 0.0124 - val_loss: 3.2521e-04 - val_mean_absolute_error: 0.0133
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.7079e-04 - mean_absolute_error: 0.0123 - val_loss: 5.8773e-04 - val_mean_absolute_error: 0.0198
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.3515e-04 - mean_absolute_error: 0.0139 - val_loss: 3.6322e-04 - val_mean_absolute_error: 0.0144
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.0994e-04 - mean_absolute_error: 0.0130 - val_loss: 3.7960e-04 - val_mean_absolute_error: 0.0149
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.9751e-04 - mean_absolute_error: 0.0123 - val_loss: 3.1285e-04 - val_mean_absolute_error: 0.0130
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.9456e-04 - mean_absolute_error: 0.0127 - val_loss: 3.1384e-04 - val_mean_absolute_error: 0.0131
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.0885e-04 - mean_absolute_error: 0.0125 - val_loss: 3.8330e-04 - val_mean_absolute_error: 0.0150
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.7889e-04 - mean_absolute_error: 0.0141 - val_loss: 3.1551e-04 - val_mean_absolute_error: 0.0132
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.8679e-04 - mean_absolute_error: 0.0119 - val_loss: 3.1679e-04 - val_mean_absolute_error: 0.0132
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.1741e-04 - mean_absolute_error: 0.0130 - val_loss: 3.1309e-04 - val_mean_absolute_error: 0.0131
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8523e-04 - mean_absolute_error: 0.0127 - val_loss: 3.6184e-04 - val_mean_absolute_error: 0.0145
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.4524e-04 - mean_absolute_error: 0.0118 - val_loss: 3.1902e-04 - val_mean_absolute_error: 0.0133
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5731e-04 - mean_absolute_error: 0.0118 - val_loss: 3.0959e-04 - val_mean_absolute_error: 0.0131
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8672e-04 - mean_absolute_error: 0.0119 - val_loss: 3.1949e-04 - val_mean_absolute_error: 0.0133
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.5281e-04 - mean_absolute_error: 0.0120 - val_loss: 3.1194e-04 - val_mean_absolute_error: 0.0131
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.4042e-04 - mean_absolute_error: 0.0111 - val_loss: 4.3686e-04 - val_mean_absolute_error: 0.0164
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3222e-04 - mean_absolute_error: 0.0135 - val_loss: 3.6642e-04 - val_mean_absolute_error: 0.0146
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.6603e-04 - mean_absolute_error: 0.0123 - val_loss: 4.1215e-04 - val_mean_absolute_error: 0.0159
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1877e-04 - mean_absolute_error: 0.0128 - val_loss: 3.0969e-04 - val_mean_absolute_error: 0.0131
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.5542e-04 - mean_absolute_error: 0.0140 - val_loss: 4.7308e-04 - val_mean_absolute_error: 0.0173
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9906e-04 - mean_absolute_error: 0.0130 - val_loss: 3.0860e-04 - val_mean_absolute_error: 0.0131
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9554e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1328e-04 - val_mean_absolute_error: 0.0132
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9618e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1277e-04 - val_mean_absolute_error: 0.0134
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9027e-04 - mean_absolute_error: 0.0122 - val_loss: 4.7376e-04 - val_mean_absolute_error: 0.0173
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.1103e-04 - mean_absolute_error: 0.0135 - val_loss: 3.3192e-04 - val_mean_absolute_error: 0.0137
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5997e-04 - mean_absolute_error: 0.0125 - val_loss: 3.1835e-04 - val_mean_absolute_error: 0.0133
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 3.6129e-04 - mean_absolute_error: 0.0124 - val_loss: 6.0805e-04 - val_mean_absolute_error: 0.0201
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.7459e-04 - mean_absolute_error: 0.0149 - val_loss: 3.1600e-04 - val_mean_absolute_error: 0.0134
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5099e-04 - mean_absolute_error: 0.0118 - val_loss: 3.1537e-04 - val_mean_absolute_error: 0.0132
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6848e-04 - mean_absolute_error: 0.0127 - val_loss: 3.2571e-04 - val_mean_absolute_error: 0.0138
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5687e-04 - mean_absolute_error: 0.0126 - val_loss: 3.2422e-04 - val_mean_absolute_error: 0.0137
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.3391e-04 - mean_absolute_error: 0.0114 - val_loss: 6.0923e-04 - val_mean_absolute_error: 0.0201
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.2568e-04 - mean_absolute_error: 0.0136 - val_loss: 3.2628e-04 - val_mean_absolute_error: 0.0136
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.2831e-04 - mean_absolute_error: 0.0121 - val_loss: 3.2728e-04 - val_mean_absolute_error: 0.0136
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3984e-04 - mean_absolute_error: 0.0130 - val_loss: 3.2112e-04 - val_mean_absolute_error: 0.0134
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7432e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1428e-04 - val_mean_absolute_error: 0.0134
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7152e-04 - mean_absolute_error: 0.0120 - val_loss: 3.0961e-04 - val_mean_absolute_error: 0.0132
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8511e-04 - mean_absolute_error: 0.0124 - val_loss: 3.2581e-04 - val_mean_absolute_error: 0.0136
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1087e-04 - mean_absolute_error: 0.0131 - val_loss: 3.1079e-04 - val_mean_absolute_error: 0.0132
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7122e-04 - mean_absolute_error: 0.0123 - val_loss: 3.2563e-04 - val_mean_absolute_error: 0.0135
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.4740e-04 - mean_absolute_error: 0.0115 - val_loss: 3.2352e-04 - val_mean_absolute_error: 0.0135
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.6095e-04 - mean_absolute_error: 0.0123 - val_loss: 3.1150e-04 - val_mean_absolute_error: 0.0133
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.0273e-04 - mean_absolute_error: 0.0132 - val_loss: 3.1365e-04 - val_mean_absolute_error: 0.0132
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.6888e-04 - mean_absolute_error: 0.0123 - val_loss: 3.2428e-04 - val_mean_absolute_error: 0.0138
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.0666e-04 - mean_absolute_error: 0.0128 - val_loss: 3.1211e-04 - val_mean_absolute_error: 0.0132
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.1395e-04 - mean_absolute_error: 0.0129 - val_loss: 3.2473e-04 - val_mean_absolute_error: 0.0136
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7456e-04 - mean_absolute_error: 0.0127 - val_loss: 3.1277e-04 - val_mean_absolute_error: 0.0133
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5509e-04 - mean_absolute_error: 0.0121 - val_loss: 3.1698e-04 - val_mean_absolute_error: 0.0134
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6827e-04 - mean_absolute_error: 0.0121 - val_loss: 3.6723e-04 - val_mean_absolute_error: 0.0147
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.8533e-04 - mean_absolute_error: 0.0129 - val_loss: 3.2835e-04 - val_mean_absolute_error: 0.0137
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6405e-04 - mean_absolute_error: 0.0122 - val_loss: 3.2776e-04 - val_mean_absolute_error: 0.0138
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7096e-04 - mean_absolute_error: 0.0123 - val_loss: 3.5141e-04 - val_mean_absolute_error: 0.0146
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.0572e-04 - mean_absolute_error: 0.0129 - val_loss: 3.1829e-04 - val_mean_absolute_error: 0.0133
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8042e-04 - mean_absolute_error: 0.0121 - val_loss: 3.4375e-04 - val_mean_absolute_error: 0.0144
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8699e-04 - mean_absolute_error: 0.0126 - val_loss: 4.0088e-04 - val_mean_absolute_error: 0.0156
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8264e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1402e-04 - val_mean_absolute_error: 0.0133
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6972e-04 - mean_absolute_error: 0.0130 - val_loss: 4.6845e-04 - val_mean_absolute_error: 0.0174
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.2848e-04 - mean_absolute_error: 0.0152 - val_loss: 3.1977e-04 - val_mean_absolute_error: 0.0136
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.4472e-04 - mean_absolute_error: 0.0116 - val_loss: 3.2663e-04 - val_mean_absolute_error: 0.0138
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.7567e-04 - mean_absolute_error: 0.0124 - val_loss: 3.7404e-04 - val_mean_absolute_error: 0.0151
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.1574e-04 - mean_absolute_error: 0.0128 - val_loss: 3.2421e-04 - val_mean_absolute_error: 0.0135
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.2750e-04 - mean_absolute_error: 0.0116 - val_loss: 3.8165e-04 - val_mean_absolute_error: 0.0153
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7491e-04 - mean_absolute_error: 0.0125 - val_loss: 3.1806e-04 - val_mean_absolute_error: 0.0134
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.4187e-04 - mean_absolute_error: 0.0115 - val_loss: 3.3872e-04 - val_mean_absolute_error: 0.0140
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.6485e-04 - mean_absolute_error: 0.0122 - val_loss: 3.4993e-04 - val_mean_absolute_error: 0.0143
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0627e-04 - mean_absolute_error: 0.0135 - val_loss: 4.0791e-04 - val_mean_absolute_error: 0.0157
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.1184e-04 - mean_absolute_error: 0.0132 - val_loss: 3.1542e-04 - val_mean_absolute_error: 0.0134
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.0166e-04 - mean_absolute_error: 0.0127 - val_loss: 3.2346e-04 - val_mean_absolute_error: 0.0135
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6638e-04 - mean_absolute_error: 0.0120 - val_loss: 3.3395e-04 - val_mean_absolute_error: 0.0138
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.4078e-04 - mean_absolute_error: 0.0118 - val_loss: 3.3231e-04 - val_mean_absolute_error: 0.0138
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.2786e-04 - mean_absolute_error: 0.0140 - val_loss: 3.4834e-04 - val_mean_absolute_error: 0.0143
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.6326e-04 - mean_absolute_error: 0.0123 - val_loss: 3.2369e-04 - val_mean_absolute_error: 0.0137
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.1120e-04 - mean_absolute_error: 0.0129 - val_loss: 3.3980e-04 - val_mean_absolute_error: 0.0142
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4706e-04 - mean_absolute_error: 0.0120 - val_loss: 3.3576e-04 - val_mean_absolute_error: 0.0139
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.6128e-04 - mean_absolute_error: 0.0119 - val_loss: 3.1663e-04 - val_mean_absolute_error: 0.0134
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.5769e-04 - mean_absolute_error: 0.0122 - val_loss: 3.2241e-04 - val_mean_absolute_error: 0.0135
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.4494e-04 - mean_absolute_error: 0.0120 - val_loss: 3.3878e-04 - val_mean_absolute_error: 0.0140
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9606e-04 - mean_absolute_error: 0.0123 - val_loss: 3.8237e-04 - val_mean_absolute_error: 0.0151
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.1554e-04 - mean_absolute_error: 0.0115 - val_loss: 3.1426e-04 - val_mean_absolute_error: 0.0133
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5005e-04 - mean_absolute_error: 0.0127 - val_loss: 3.2396e-04 - val_mean_absolute_error: 0.0135
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1399e-04 - mean_absolute_error: 0.0131 - val_loss: 4.2760e-04 - val_mean_absolute_error: 0.0162
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6699e-04 - mean_absolute_error: 0.0128 - val_loss: 3.4488e-04 - val_mean_absolute_error: 0.0141
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6923e-04 - mean_absolute_error: 0.0130 - val_loss: 3.1654e-04 - val_mean_absolute_error: 0.0134
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7273e-04 - mean_absolute_error: 0.0127 - val_loss: 3.2043e-04 - val_mean_absolute_error: 0.0135
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.5472e-04 - mean_absolute_error: 0.0121 - val_loss: 3.1796e-04 - val_mean_absolute_error: 0.0134
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.2430e-04 - mean_absolute_error: 0.0130 - val_loss: 4.0973e-04 - val_mean_absolute_error: 0.0160
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9977e-04 - mean_absolute_error: 0.0126 - val_loss: 3.2469e-04 - val_mean_absolute_error: 0.0136
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5788e-04 - mean_absolute_error: 0.0122 - val_loss: 3.1685e-04 - val_mean_absolute_error: 0.0133
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8343e-04 - mean_absolute_error: 0.0131 - val_loss: 3.4789e-04 - val_mean_absolute_error: 0.0145
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.9057e-04 - mean_absolute_error: 0.0129 - val_loss: 3.6790e-04 - val_mean_absolute_error: 0.0150
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7273e-04 - mean_absolute_error: 0.0125 - val_loss: 3.1926e-04 - val_mean_absolute_error: 0.0136
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2429e-04 - mean_absolute_error: 0.0112 - val_loss: 4.3658e-04 - val_mean_absolute_error: 0.0164
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6119e-04 - mean_absolute_error: 0.0129 - val_loss: 3.1730e-04 - val_mean_absolute_error: 0.0133
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5451e-04 - mean_absolute_error: 0.0125 - val_loss: 6.2063e-04 - val_mean_absolute_error: 0.0205
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.8335e-04 - mean_absolute_error: 0.0155 - val_loss: 3.7930e-04 - val_mean_absolute_error: 0.0153
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.4681e-04 - mean_absolute_error: 0.0132 - val_loss: 3.6594e-04 - val_mean_absolute_error: 0.0147
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.3708e-04 - mean_absolute_error: 0.0121 - val_loss: 3.5007e-04 - val_mean_absolute_error: 0.0143
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.8722e-04 - mean_absolute_error: 0.0132 - val_loss: 3.1456e-04 - val_mean_absolute_error: 0.0133
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.8114e-04 - mean_absolute_error: 0.0125 - val_loss: 3.1685e-04 - val_mean_absolute_error: 0.0135
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6568e-04 - mean_absolute_error: 0.0121 - val_loss: 3.7167e-04 - val_mean_absolute_error: 0.0149
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.5585e-04 - mean_absolute_error: 0.0142 - val_loss: 3.1747e-04 - val_mean_absolute_error: 0.0134
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8530e-04 - mean_absolute_error: 0.0127 - val_loss: 3.4779e-04 - val_mean_absolute_error: 0.0142
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7150e-04 - mean_absolute_error: 0.0121 - val_loss: 3.2025e-04 - val_mean_absolute_error: 0.0136
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8433e-04 - mean_absolute_error: 0.0123 - val_loss: 3.8544e-04 - val_mean_absolute_error: 0.0152
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9038e-04 - mean_absolute_error: 0.0132 - val_loss: 4.0804e-04 - val_mean_absolute_error: 0.0160
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3673e-04 - mean_absolute_error: 0.0133 - val_loss: 3.5668e-04 - val_mean_absolute_error: 0.0145
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.1648e-04 - mean_absolute_error: 0.0113 - val_loss: 3.1558e-04 - val_mean_absolute_error: 0.0134
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.8525e-04 - mean_absolute_error: 0.0129 - val_loss: 3.1460e-04 - val_mean_absolute_error: 0.0133
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3163e-04 - mean_absolute_error: 0.0117 - val_loss: 3.6199e-04 - val_mean_absolute_error: 0.0146
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.8717e-04 - mean_absolute_error: 0.0130 - val_loss: 6.6454e-04 - val_mean_absolute_error: 0.0212
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.3041e-04 - mean_absolute_error: 0.0159 - val_loss: 4.7855e-04 - val_mean_absolute_error: 0.0173
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.0015e-04 - mean_absolute_error: 0.0138 - val_loss: 3.2247e-04 - val_mean_absolute_error: 0.0137
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.6596e-04 - mean_absolute_error: 0.0124 - val_loss: 3.6588e-04 - val_mean_absolute_error: 0.0147
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.5540e-04 - mean_absolute_error: 0.0137 - val_loss: 3.3060e-04 - val_mean_absolute_error: 0.0140
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.1919e-04 - mean_absolute_error: 0.0158 - val_loss: 3.5400e-04 - val_mean_absolute_error: 0.0146
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.3894e-04 - mean_absolute_error: 0.0134 - val_loss: 3.3269e-04 - val_mean_absolute_error: 0.0140
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.5745e-04 - mean_absolute_error: 0.0120 - val_loss: 3.4177e-04 - val_mean_absolute_error: 0.0140
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7498e-04 - mean_absolute_error: 0.0120 - val_loss: 3.2500e-04 - val_mean_absolute_error: 0.0136
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.3999e-04 - mean_absolute_error: 0.0120 - val_loss: 3.1767e-04 - val_mean_absolute_error: 0.0133
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.7935e-04 - mean_absolute_error: 0.0126 - val_loss: 3.4916e-04 - val_mean_absolute_error: 0.0143
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.6004e-04 - mean_absolute_error: 0.0120 - val_loss: 3.2443e-04 - val_mean_absolute_error: 0.0138
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.7641e-04 - mean_absolute_error: 0.0122 - val_loss: 3.1887e-04 - val_mean_absolute_error: 0.0134
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.8773e-04 - mean_absolute_error: 0.0119 - val_loss: 3.3379e-04 - val_mean_absolute_error: 0.0140
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.5542e-04 - mean_absolute_error: 0.0134 - val_loss: 3.1767e-04 - val_mean_absolute_error: 0.0133
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7928e-04 - mean_absolute_error: 0.0124 - val_loss: 3.4130e-04 - val_mean_absolute_error: 0.0140
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.2552e-04 - mean_absolute_error: 0.0117 - val_loss: 3.3619e-04 - val_mean_absolute_error: 0.0142
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.0936e-04 - mean_absolute_error: 0.0128 - val_loss: 3.3108e-04 - val_mean_absolute_error: 0.0140
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.7230e-04 - mean_absolute_error: 0.0124 - val_loss: 3.3040e-04 - val_mean_absolute_error: 0.0139
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.5917e-04 - mean_absolute_error: 0.0123 - val_loss: 3.3069e-04 - val_mean_absolute_error: 0.0137
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.6078e-04 - mean_absolute_error: 0.0122 - val_loss: 3.4179e-04 - val_mean_absolute_error: 0.0143
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3963e-04 - mean_absolute_error: 0.0118 - val_loss: 3.1608e-04 - val_mean_absolute_error: 0.0134
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8474e-04 - mean_absolute_error: 0.0133 - val_loss: 3.3470e-04 - val_mean_absolute_error: 0.0141
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8709e-04 - mean_absolute_error: 0.0124 - val_loss: 3.1636e-04 - val_mean_absolute_error: 0.0133
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5470e-04 - mean_absolute_error: 0.0115 - val_loss: 3.1306e-04 - val_mean_absolute_error: 0.0133
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0521e-04 - mean_absolute_error: 0.0134 - val_loss: 3.3286e-04 - val_mean_absolute_error: 0.0138
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4303e-04 - mean_absolute_error: 0.0120 - val_loss: 3.8847e-04 - val_mean_absolute_error: 0.0153
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9636e-04 - mean_absolute_error: 0.0129 - val_loss: 3.8033e-04 - val_mean_absolute_error: 0.0151

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 182991.48968947076
# RMSE: 427.7750456600651
# MAE: 314.5279954401145
# MAPE: 2.8987159264462057 %
#
# Model evalution on validate set
# MSE: 88503.42898547508
# RMSE: 297.49525876133737
# MAE: 228.57376327816206
# MAPE: 2.1702454348502687 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 579ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step

# %%
y_pred_30_days
# Out:
# array([[13249.031],
#        [13092.141],
#        [13296.326],
#        [13178.826],
#        [13315.726],
#        [13240.259],
#        [13303.555],
#        [13259.464],
#        [13296.01 ],
#        [13270.476],
#        [13290.131],
#        [13275.694],
#        [13286.76 ],
#        [13278.597],
#        [13284.753],
#        [13280.167],
#        [13283.619],
#        [13281.043],
#        [13282.976],
#        [13281.529],
#        [13282.612],
#        [13281.803],
#        [13282.411],
#        [13281.954],
#        [13282.295],
#        [13282.04 ],
#        [13282.233],
#        [13282.089],
#        [13282.196],
#        [13282.115],
#        [13282.176]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Predict the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
