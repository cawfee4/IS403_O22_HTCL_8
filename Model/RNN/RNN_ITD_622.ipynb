# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: ITD - Test/Train/Vaildation: 60/20/20
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 461.79581457465713
# - MAE: 351.52664731698206
# - MAPE: 3.251177900140655 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 1  # 6 2 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.tail()
# Out:
#             close
# time
# 2024-05-27  11300
# 2024-05-28  12050
# 2024-05-29  12600
# 2024-05-30  12500
# 2024-05-31  12700

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        6900
# 1        7100
# 2        7100
# 3        7170
# 4        7170
#         ...
# 1308    11300
# 1309    12050
# 1310    12600
# 1311    12500
# 1312    12700
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((776, 10), (776,), (251, 10), (251,), (253, 10), (253,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - loss: 0.0477 - mean_absolute_error: 0.1381 - val_loss: 0.0040 - val_mean_absolute_error: 0.0522
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0027 - mean_absolute_error: 0.0335 - val_loss: 0.0016 - val_mean_absolute_error: 0.0298
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0017 - mean_absolute_error: 0.0269 - val_loss: 0.0012 - val_mean_absolute_error: 0.0250
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0015 - mean_absolute_error: 0.0232 - val_loss: 0.0013 - val_mean_absolute_error: 0.0277
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0220 - val_loss: 0.0011 - val_mean_absolute_error: 0.0254
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0011 - mean_absolute_error: 0.0204 - val_loss: 9.0707e-04 - val_mean_absolute_error: 0.0227
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.8162e-04 - mean_absolute_error: 0.0194 - val_loss: 6.9626e-04 - val_mean_absolute_error: 0.0189
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013 - mean_absolute_error: 0.0214 - val_loss: 0.0019 - val_mean_absolute_error: 0.0378
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014 - mean_absolute_error: 0.0242 - val_loss: 0.0011 - val_mean_absolute_error: 0.0273
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.0813e-04 - mean_absolute_error: 0.0199 - val_loss: 9.3629e-04 - val_mean_absolute_error: 0.0242
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0215 - val_loss: 7.2934e-04 - val_mean_absolute_error: 0.0203
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.1838e-04 - mean_absolute_error: 0.0175 - val_loss: 6.7923e-04 - val_mean_absolute_error: 0.0193
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.4253e-04 - mean_absolute_error: 0.0184 - val_loss: 6.2927e-04 - val_mean_absolute_error: 0.0185
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.2600e-04 - mean_absolute_error: 0.0168 - val_loss: 8.4527e-04 - val_mean_absolute_error: 0.0230
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.0723e-04 - mean_absolute_error: 0.0175 - val_loss: 7.8804e-04 - val_mean_absolute_error: 0.0221
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.4086e-04 - mean_absolute_error: 0.0189 - val_loss: 6.7338e-04 - val_mean_absolute_error: 0.0198
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.4016e-04 - mean_absolute_error: 0.0166 - val_loss: 5.2303e-04 - val_mean_absolute_error: 0.0166
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.3423e-04 - mean_absolute_error: 0.0163 - val_loss: 6.7347e-04 - val_mean_absolute_error: 0.0198
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7965e-04 - mean_absolute_error: 0.0190 - val_loss: 7.0063e-04 - val_mean_absolute_error: 0.0205
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7026e-04 - mean_absolute_error: 0.0195 - val_loss: 0.0010 - val_mean_absolute_error: 0.0263
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0010 - mean_absolute_error: 0.0204 - val_loss: 5.1984e-04 - val_mean_absolute_error: 0.0164
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.9258e-04 - mean_absolute_error: 0.0170 - val_loss: 5.5786e-04 - val_mean_absolute_error: 0.0176
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.8495e-04 - mean_absolute_error: 0.0152 - val_loss: 4.8102e-04 - val_mean_absolute_error: 0.0158
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6647e-04 - mean_absolute_error: 0.0160 - val_loss: 8.2302e-04 - val_mean_absolute_error: 0.0231
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.2428e-04 - mean_absolute_error: 0.0153 - val_loss: 4.8561e-04 - val_mean_absolute_error: 0.0162
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.3652e-04 - mean_absolute_error: 0.0151 - val_loss: 6.0691e-04 - val_mean_absolute_error: 0.0189
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.9036e-04 - mean_absolute_error: 0.0192 - val_loss: 5.5886e-04 - val_mean_absolute_error: 0.0179
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1193e-04 - mean_absolute_error: 0.0158 - val_loss: 4.7654e-04 - val_mean_absolute_error: 0.0160
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7653e-04 - mean_absolute_error: 0.0146 - val_loss: 5.2263e-04 - val_mean_absolute_error: 0.0174
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9098e-04 - mean_absolute_error: 0.0153 - val_loss: 5.4367e-04 - val_mean_absolute_error: 0.0178
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4649e-04 - mean_absolute_error: 0.0144 - val_loss: 5.0280e-04 - val_mean_absolute_error: 0.0170
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.2748e-04 - mean_absolute_error: 0.0140 - val_loss: 4.2018e-04 - val_mean_absolute_error: 0.0147
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.6291e-04 - mean_absolute_error: 0.0151 - val_loss: 4.3445e-04 - val_mean_absolute_error: 0.0151
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.6673e-04 - mean_absolute_error: 0.0175 - val_loss: 9.1264e-04 - val_mean_absolute_error: 0.0251
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8853e-04 - mean_absolute_error: 0.0153 - val_loss: 7.3746e-04 - val_mean_absolute_error: 0.0220
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.4833e-04 - mean_absolute_error: 0.0152 - val_loss: 8.2093e-04 - val_mean_absolute_error: 0.0237
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.6599e-04 - mean_absolute_error: 0.0158 - val_loss: 3.9939e-04 - val_mean_absolute_error: 0.0144
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.4056e-04 - mean_absolute_error: 0.0156 - val_loss: 4.1457e-04 - val_mean_absolute_error: 0.0149
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.4564e-04 - mean_absolute_error: 0.0144 - val_loss: 3.8890e-04 - val_mean_absolute_error: 0.0142
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.2687e-04 - mean_absolute_error: 0.0139 - val_loss: 4.0105e-04 - val_mean_absolute_error: 0.0146
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.7907e-04 - mean_absolute_error: 0.0132 - val_loss: 3.8843e-04 - val_mean_absolute_error: 0.0143
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4931e-04 - mean_absolute_error: 0.0152 - val_loss: 3.9067e-04 - val_mean_absolute_error: 0.0143
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.6916e-04 - mean_absolute_error: 0.0136 - val_loss: 3.9911e-04 - val_mean_absolute_error: 0.0146
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.9958e-04 - mean_absolute_error: 0.0153 - val_loss: 3.7393e-04 - val_mean_absolute_error: 0.0140
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.9798e-04 - mean_absolute_error: 0.0137 - val_loss: 3.7346e-04 - val_mean_absolute_error: 0.0140
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.6012e-04 - mean_absolute_error: 0.0129 - val_loss: 3.9772e-04 - val_mean_absolute_error: 0.0147
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.7142e-04 - mean_absolute_error: 0.0150 - val_loss: 5.1770e-04 - val_mean_absolute_error: 0.0179
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.6976e-04 - mean_absolute_error: 0.0137 - val_loss: 3.7631e-04 - val_mean_absolute_error: 0.0141
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.6876e-04 - mean_absolute_error: 0.0136 - val_loss: 4.3532e-04 - val_mean_absolute_error: 0.0159
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.4679e-04 - mean_absolute_error: 0.0150 - val_loss: 3.5880e-04 - val_mean_absolute_error: 0.0138
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.7020e-04 - mean_absolute_error: 0.0131 - val_loss: 5.4391e-04 - val_mean_absolute_error: 0.0185
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.8979e-04 - mean_absolute_error: 0.0137 - val_loss: 4.7193e-04 - val_mean_absolute_error: 0.0170
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.1018e-04 - mean_absolute_error: 0.0146 - val_loss: 3.7146e-04 - val_mean_absolute_error: 0.0142
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.4890e-04 - mean_absolute_error: 0.0138 - val_loss: 3.7133e-04 - val_mean_absolute_error: 0.0142
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.5604e-04 - mean_absolute_error: 0.0135 - val_loss: 5.7162e-04 - val_mean_absolute_error: 0.0193
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.2713e-04 - mean_absolute_error: 0.0130 - val_loss: 4.4993e-04 - val_mean_absolute_error: 0.0164
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7967e-04 - mean_absolute_error: 0.0137 - val_loss: 3.4332e-04 - val_mean_absolute_error: 0.0134
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.1353e-04 - mean_absolute_error: 0.0135 - val_loss: 3.9702e-04 - val_mean_absolute_error: 0.0150
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.2938e-04 - mean_absolute_error: 0.0124 - val_loss: 3.7012e-04 - val_mean_absolute_error: 0.0143
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.0017e-04 - mean_absolute_error: 0.0127 - val_loss: 3.2705e-04 - val_mean_absolute_error: 0.0132
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.2780e-04 - mean_absolute_error: 0.0128 - val_loss: 3.8719e-04 - val_mean_absolute_error: 0.0148
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.2208e-04 - mean_absolute_error: 0.0130 - val_loss: 3.4880e-04 - val_mean_absolute_error: 0.0138
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.9312e-04 - mean_absolute_error: 0.0127 - val_loss: 4.7400e-04 - val_mean_absolute_error: 0.0172
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.5407e-04 - mean_absolute_error: 0.0151 - val_loss: 3.2467e-04 - val_mean_absolute_error: 0.0131
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.1002e-04 - mean_absolute_error: 0.0141 - val_loss: 3.5043e-04 - val_mean_absolute_error: 0.0139
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0445e-04 - mean_absolute_error: 0.0124 - val_loss: 3.4190e-04 - val_mean_absolute_error: 0.0136
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.6726e-04 - mean_absolute_error: 0.0135 - val_loss: 3.4671e-04 - val_mean_absolute_error: 0.0140
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.1505e-04 - mean_absolute_error: 0.0127 - val_loss: 3.1950e-04 - val_mean_absolute_error: 0.0131
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.5618e-04 - mean_absolute_error: 0.0130 - val_loss: 3.2037e-04 - val_mean_absolute_error: 0.0131
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.0624e-04 - mean_absolute_error: 0.0128 - val_loss: 3.3691e-04 - val_mean_absolute_error: 0.0138
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9645e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1407e-04 - val_mean_absolute_error: 0.0130
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.9704e-04 - mean_absolute_error: 0.0124 - val_loss: 4.2138e-04 - val_mean_absolute_error: 0.0160
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9998e-04 - mean_absolute_error: 0.0125 - val_loss: 3.8466e-04 - val_mean_absolute_error: 0.0149
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.9331e-04 - mean_absolute_error: 0.0126 - val_loss: 3.4218e-04 - val_mean_absolute_error: 0.0138
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.4657e-04 - mean_absolute_error: 0.0117 - val_loss: 3.1658e-04 - val_mean_absolute_error: 0.0131
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.5333e-04 - mean_absolute_error: 0.0141 - val_loss: 3.3142e-04 - val_mean_absolute_error: 0.0137
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.1466e-04 - mean_absolute_error: 0.0128 - val_loss: 3.1541e-04 - val_mean_absolute_error: 0.0131
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8911e-04 - mean_absolute_error: 0.0118 - val_loss: 3.1582e-04 - val_mean_absolute_error: 0.0131
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.0655e-04 - mean_absolute_error: 0.0125 - val_loss: 3.6470e-04 - val_mean_absolute_error: 0.0145
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.5345e-04 - mean_absolute_error: 0.0134 - val_loss: 4.1028e-04 - val_mean_absolute_error: 0.0158
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.5755e-04 - mean_absolute_error: 0.0122 - val_loss: 4.4103e-04 - val_mean_absolute_error: 0.0165
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5234e-04 - mean_absolute_error: 0.0124 - val_loss: 3.1399e-04 - val_mean_absolute_error: 0.0131
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.2450e-04 - mean_absolute_error: 0.0112 - val_loss: 3.3599e-04 - val_mean_absolute_error: 0.0137
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6934e-04 - mean_absolute_error: 0.0123 - val_loss: 4.3317e-04 - val_mean_absolute_error: 0.0164
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.2833e-04 - mean_absolute_error: 0.0137 - val_loss: 3.8269e-04 - val_mean_absolute_error: 0.0150
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9139e-04 - mean_absolute_error: 0.0124 - val_loss: 4.7238e-04 - val_mean_absolute_error: 0.0172
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9625e-04 - mean_absolute_error: 0.0135 - val_loss: 3.2564e-04 - val_mean_absolute_error: 0.0135
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9754e-04 - mean_absolute_error: 0.0128 - val_loss: 3.1439e-04 - val_mean_absolute_error: 0.0132
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9829e-04 - mean_absolute_error: 0.0125 - val_loss: 3.2919e-04 - val_mean_absolute_error: 0.0139
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.1852e-04 - mean_absolute_error: 0.0115 - val_loss: 3.6753e-04 - val_mean_absolute_error: 0.0146
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9221e-04 - mean_absolute_error: 0.0147 - val_loss: 3.7996e-04 - val_mean_absolute_error: 0.0150
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.5408e-04 - mean_absolute_error: 0.0124 - val_loss: 3.1323e-04 - val_mean_absolute_error: 0.0133
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.7723e-04 - mean_absolute_error: 0.0123 - val_loss: 3.8074e-04 - val_mean_absolute_error: 0.0153
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.8291e-04 - mean_absolute_error: 0.0149 - val_loss: 3.8251e-04 - val_mean_absolute_error: 0.0153
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3042e-04 - mean_absolute_error: 0.0130 - val_loss: 3.2500e-04 - val_mean_absolute_error: 0.0135
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.7823e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1052e-04 - val_mean_absolute_error: 0.0132
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.6020e-04 - mean_absolute_error: 0.0121 - val_loss: 3.7255e-04 - val_mean_absolute_error: 0.0151
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8877e-04 - mean_absolute_error: 0.0125 - val_loss: 3.1076e-04 - val_mean_absolute_error: 0.0132
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0270e-04 - mean_absolute_error: 0.0125 - val_loss: 3.2682e-04 - val_mean_absolute_error: 0.0135
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.6427e-04 - mean_absolute_error: 0.0117 - val_loss: 3.1126e-04 - val_mean_absolute_error: 0.0131
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.1840e-04 - mean_absolute_error: 0.0110 - val_loss: 3.3099e-04 - val_mean_absolute_error: 0.0137
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.6085e-04 - mean_absolute_error: 0.0119 - val_loss: 3.2316e-04 - val_mean_absolute_error: 0.0134
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.6613e-04 - mean_absolute_error: 0.0120 - val_loss: 3.1746e-04 - val_mean_absolute_error: 0.0133
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.8177e-04 - mean_absolute_error: 0.0120 - val_loss: 3.1064e-04 - val_mean_absolute_error: 0.0133
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8565e-04 - mean_absolute_error: 0.0121 - val_loss: 3.1453e-04 - val_mean_absolute_error: 0.0132
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4368e-04 - mean_absolute_error: 0.0115 - val_loss: 3.1247e-04 - val_mean_absolute_error: 0.0132
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5575e-04 - mean_absolute_error: 0.0118 - val_loss: 3.3844e-04 - val_mean_absolute_error: 0.0141
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6538e-04 - mean_absolute_error: 0.0121 - val_loss: 3.2536e-04 - val_mean_absolute_error: 0.0135
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.2515e-04 - mean_absolute_error: 0.0117 - val_loss: 4.3716e-04 - val_mean_absolute_error: 0.0166
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8108e-04 - mean_absolute_error: 0.0128 - val_loss: 3.1759e-04 - val_mean_absolute_error: 0.0133
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.5029e-04 - mean_absolute_error: 0.0116 - val_loss: 3.1292e-04 - val_mean_absolute_error: 0.0132
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.8549e-04 - mean_absolute_error: 0.0125 - val_loss: 3.2613e-04 - val_mean_absolute_error: 0.0136
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.9897e-04 - mean_absolute_error: 0.0126 - val_loss: 3.2274e-04 - val_mean_absolute_error: 0.0135
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.5803e-04 - mean_absolute_error: 0.0119 - val_loss: 3.2130e-04 - val_mean_absolute_error: 0.0135
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.3953e-04 - mean_absolute_error: 0.0131 - val_loss: 3.1252e-04 - val_mean_absolute_error: 0.0132
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7424e-04 - mean_absolute_error: 0.0119 - val_loss: 3.1012e-04 - val_mean_absolute_error: 0.0132
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7071e-04 - mean_absolute_error: 0.0139 - val_loss: 3.1251e-04 - val_mean_absolute_error: 0.0132
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.9107e-04 - mean_absolute_error: 0.0125 - val_loss: 4.6669e-04 - val_mean_absolute_error: 0.0171
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5060e-04 - mean_absolute_error: 0.0137 - val_loss: 3.5560e-04 - val_mean_absolute_error: 0.0144
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.3494e-04 - mean_absolute_error: 0.0121 - val_loss: 3.1869e-04 - val_mean_absolute_error: 0.0136
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.5351e-04 - mean_absolute_error: 0.0120 - val_loss: 3.8677e-04 - val_mean_absolute_error: 0.0155
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.5936e-04 - mean_absolute_error: 0.0135 - val_loss: 3.1674e-04 - val_mean_absolute_error: 0.0133
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0374e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1352e-04 - val_mean_absolute_error: 0.0133
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4907e-04 - mean_absolute_error: 0.0122 - val_loss: 3.4543e-04 - val_mean_absolute_error: 0.0141
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.2674e-04 - mean_absolute_error: 0.0117 - val_loss: 3.2101e-04 - val_mean_absolute_error: 0.0134
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.6370e-04 - mean_absolute_error: 0.0118 - val_loss: 3.1745e-04 - val_mean_absolute_error: 0.0136
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9140e-04 - mean_absolute_error: 0.0125 - val_loss: 4.0080e-04 - val_mean_absolute_error: 0.0155
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1279e-04 - mean_absolute_error: 0.0132 - val_loss: 3.1498e-04 - val_mean_absolute_error: 0.0134
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8376e-04 - mean_absolute_error: 0.0120 - val_loss: 3.5631e-04 - val_mean_absolute_error: 0.0144
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3995e-04 - mean_absolute_error: 0.0119 - val_loss: 3.4266e-04 - val_mean_absolute_error: 0.0141
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.7547e-04 - mean_absolute_error: 0.0123 - val_loss: 3.8200e-04 - val_mean_absolute_error: 0.0151
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.0734e-04 - mean_absolute_error: 0.0136 - val_loss: 3.5104e-04 - val_mean_absolute_error: 0.0146
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.2858e-04 - mean_absolute_error: 0.0129 - val_loss: 3.1194e-04 - val_mean_absolute_error: 0.0132
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.6883e-04 - mean_absolute_error: 0.0123 - val_loss: 3.6314e-04 - val_mean_absolute_error: 0.0149
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.4630e-04 - mean_absolute_error: 0.0125 - val_loss: 3.1397e-04 - val_mean_absolute_error: 0.0134
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1452e-04 - mean_absolute_error: 0.0129 - val_loss: 3.1485e-04 - val_mean_absolute_error: 0.0134
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.9388e-04 - mean_absolute_error: 0.0133 - val_loss: 4.2077e-04 - val_mean_absolute_error: 0.0160
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.9325e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1879e-04 - val_mean_absolute_error: 0.0134
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8684e-04 - mean_absolute_error: 0.0127 - val_loss: 4.3176e-04 - val_mean_absolute_error: 0.0163
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9534e-04 - mean_absolute_error: 0.0129 - val_loss: 3.3066e-04 - val_mean_absolute_error: 0.0137
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.5753e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1859e-04 - val_mean_absolute_error: 0.0135
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9394e-04 - mean_absolute_error: 0.0130 - val_loss: 3.3522e-04 - val_mean_absolute_error: 0.0138
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.4355e-04 - mean_absolute_error: 0.0122 - val_loss: 3.1923e-04 - val_mean_absolute_error: 0.0136
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8606e-04 - mean_absolute_error: 0.0130 - val_loss: 3.1859e-04 - val_mean_absolute_error: 0.0133
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.8719e-04 - mean_absolute_error: 0.0133 - val_loss: 3.1735e-04 - val_mean_absolute_error: 0.0134
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.5008e-04 - mean_absolute_error: 0.0119 - val_loss: 3.2134e-04 - val_mean_absolute_error: 0.0134
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8336e-04 - mean_absolute_error: 0.0125 - val_loss: 3.1643e-04 - val_mean_absolute_error: 0.0133
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7346e-04 - mean_absolute_error: 0.0123 - val_loss: 3.4728e-04 - val_mean_absolute_error: 0.0142
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.0864e-04 - mean_absolute_error: 0.0117 - val_loss: 3.4565e-04 - val_mean_absolute_error: 0.0142
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.0386e-04 - mean_absolute_error: 0.0112 - val_loss: 3.2740e-04 - val_mean_absolute_error: 0.0136
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.4004e-04 - mean_absolute_error: 0.0118 - val_loss: 3.2800e-04 - val_mean_absolute_error: 0.0137
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.6031e-04 - mean_absolute_error: 0.0123 - val_loss: 3.4121e-04 - val_mean_absolute_error: 0.0140
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1942e-04 - mean_absolute_error: 0.0143 - val_loss: 4.6478e-04 - val_mean_absolute_error: 0.0171
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.4684e-04 - mean_absolute_error: 0.0126 - val_loss: 3.6609e-04 - val_mean_absolute_error: 0.0147
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.4453e-04 - mean_absolute_error: 0.0121 - val_loss: 4.3744e-04 - val_mean_absolute_error: 0.0164
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.3665e-04 - mean_absolute_error: 0.0144 - val_loss: 4.0063e-04 - val_mean_absolute_error: 0.0158
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0992e-04 - mean_absolute_error: 0.0131 - val_loss: 3.2350e-04 - val_mean_absolute_error: 0.0135
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0708e-04 - mean_absolute_error: 0.0128 - val_loss: 3.2311e-04 - val_mean_absolute_error: 0.0135
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6877e-04 - mean_absolute_error: 0.0126 - val_loss: 4.0866e-04 - val_mean_absolute_error: 0.0160
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9771e-04 - mean_absolute_error: 0.0139 - val_loss: 3.1970e-04 - val_mean_absolute_error: 0.0135
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8072e-04 - mean_absolute_error: 0.0120 - val_loss: 3.3535e-04 - val_mean_absolute_error: 0.0141
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.1518e-04 - mean_absolute_error: 0.0128 - val_loss: 3.3164e-04 - val_mean_absolute_error: 0.0137
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6672e-04 - mean_absolute_error: 0.0118 - val_loss: 3.1679e-04 - val_mean_absolute_error: 0.0134
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.3245e-04 - mean_absolute_error: 0.0120 - val_loss: 3.2283e-04 - val_mean_absolute_error: 0.0135
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.9856e-04 - mean_absolute_error: 0.0132 - val_loss: 3.3781e-04 - val_mean_absolute_error: 0.0142
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.9049e-04 - mean_absolute_error: 0.0127 - val_loss: 3.2997e-04 - val_mean_absolute_error: 0.0137
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7934e-04 - mean_absolute_error: 0.0123 - val_loss: 3.2688e-04 - val_mean_absolute_error: 0.0138
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3656e-04 - mean_absolute_error: 0.0132 - val_loss: 3.7196e-04 - val_mean_absolute_error: 0.0151
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6190e-04 - mean_absolute_error: 0.0124 - val_loss: 3.6082e-04 - val_mean_absolute_error: 0.0146
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4300e-04 - mean_absolute_error: 0.0136 - val_loss: 3.2712e-04 - val_mean_absolute_error: 0.0138
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5713e-04 - mean_absolute_error: 0.0126 - val_loss: 3.3546e-04 - val_mean_absolute_error: 0.0139
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.8325e-04 - mean_absolute_error: 0.0131 - val_loss: 3.2584e-04 - val_mean_absolute_error: 0.0136
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7045e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1749e-04 - val_mean_absolute_error: 0.0135
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.6533e-04 - mean_absolute_error: 0.0146 - val_loss: 4.2234e-04 - val_mean_absolute_error: 0.0163
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7462e-04 - mean_absolute_error: 0.0127 - val_loss: 3.4734e-04 - val_mean_absolute_error: 0.0144
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1987e-04 - mean_absolute_error: 0.0131 - val_loss: 5.2012e-04 - val_mean_absolute_error: 0.0185
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6120e-04 - mean_absolute_error: 0.0158 - val_loss: 3.4531e-04 - val_mean_absolute_error: 0.0145
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5469e-04 - mean_absolute_error: 0.0126 - val_loss: 3.3544e-04 - val_mean_absolute_error: 0.0139
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5939e-04 - mean_absolute_error: 0.0120 - val_loss: 4.6961e-04 - val_mean_absolute_error: 0.0174
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2664e-04 - mean_absolute_error: 0.0134 - val_loss: 3.5896e-04 - val_mean_absolute_error: 0.0147
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8783e-04 - mean_absolute_error: 0.0127 - val_loss: 5.0268e-04 - val_mean_absolute_error: 0.0178
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.0700e-04 - mean_absolute_error: 0.0136 - val_loss: 4.1270e-04 - val_mean_absolute_error: 0.0161
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.0024e-04 - mean_absolute_error: 0.0127 - val_loss: 3.6024e-04 - val_mean_absolute_error: 0.0148
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.6317e-04 - mean_absolute_error: 0.0136 - val_loss: 3.3045e-04 - val_mean_absolute_error: 0.0137
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0012e-04 - mean_absolute_error: 0.0129 - val_loss: 3.1805e-04 - val_mean_absolute_error: 0.0134
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3245e-04 - mean_absolute_error: 0.0114 - val_loss: 3.1605e-04 - val_mean_absolute_error: 0.0134
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0111e-04 - mean_absolute_error: 0.0123 - val_loss: 4.0041e-04 - val_mean_absolute_error: 0.0155
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.8321e-04 - mean_absolute_error: 0.0123 - val_loss: 3.9226e-04 - val_mean_absolute_error: 0.0154
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.8830e-04 - mean_absolute_error: 0.0129 - val_loss: 3.2954e-04 - val_mean_absolute_error: 0.0139
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.7140e-04 - mean_absolute_error: 0.0125 - val_loss: 3.6649e-04 - val_mean_absolute_error: 0.0147
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.7759e-04 - mean_absolute_error: 0.0124 - val_loss: 3.3160e-04 - val_mean_absolute_error: 0.0140
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.5866e-04 - mean_absolute_error: 0.0122 - val_loss: 6.3346e-04 - val_mean_absolute_error: 0.0206
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.5468e-04 - mean_absolute_error: 0.0167 - val_loss: 3.2034e-04 - val_mean_absolute_error: 0.0134
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9916e-04 - mean_absolute_error: 0.0129 - val_loss: 3.2755e-04 - val_mean_absolute_error: 0.0136
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6715e-04 - mean_absolute_error: 0.0120 - val_loss: 4.3392e-04 - val_mean_absolute_error: 0.0163
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0835e-04 - mean_absolute_error: 0.0141 - val_loss: 3.3556e-04 - val_mean_absolute_error: 0.0141
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.0021e-04 - mean_absolute_error: 0.0133 - val_loss: 3.1825e-04 - val_mean_absolute_error: 0.0135
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7231e-04 - mean_absolute_error: 0.0123 - val_loss: 3.2087e-04 - val_mean_absolute_error: 0.0135
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7681e-04 - mean_absolute_error: 0.0119 - val_loss: 3.2110e-04 - val_mean_absolute_error: 0.0136
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.1677e-04 - mean_absolute_error: 0.0109 - val_loss: 4.9732e-04 - val_mean_absolute_error: 0.0178

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 4s 609ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 213255.3743586711
# RMSE: 461.79581457465713
# MAE: 351.52664731698206
# MAPE: 3.251177900140655 %
#
# Model evalution on validate set
# MSE: 116872.4572357811
# RMSE: 341.86613935249727
# MAE: 278.121842576581
# MAPE: 2.646708611344649 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 599ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step

# %%
y_pred_30_days
# Out:
# array([[13217.057 ],
#        [13037.247 ],
#        [13243.973 ],
#        [13124.834 ],
#        [13252.0625],
#        [13176.592 ],
#        [13237.615 ],
#        [13195.086 ],
#        [13228.967 ],
#        [13204.878 ],
#        [13223.103 ],
#        [13209.7705],
#        [13219.805 ],
#        [13212.414 ],
#        [13217.926 ],
#        [13213.848 ],
#        [13216.883 ],
#        [13214.632 ],
#        [13216.306 ],
#        [13215.066 ],
#        [13215.986 ],
#        [13215.302 ],
#        [13215.81  ],
#        [13215.435 ],
#        [13215.714 ],
#        [13215.507 ],
#        [13215.66  ],
#        [13215.546 ],
#        [13215.629 ],
#        [13215.567 ],
#        [13215.613 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Predict the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
