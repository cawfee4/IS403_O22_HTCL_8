# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: ITD - Test/Train/Vaildation: 60/20/20
# - Dataset: 1252 rows x 7 column (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 512.4025254349162
# - MAE: 361.1381856367678
# - MAPE: 3.128950601050917 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 1  # 6 2 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170

# %%
df.shape
# Out:
# (1252, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       6900
# 1       7100
# 2       7100
# 3       7170
# 4       7170
#         ...
# 1247    9700
# 1248    9640
# 1249    9890
# 1250    9950
# 1251    9990
# Name: close, Length: 1252, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((740, 10), (740,), (239, 10), (239,), (240, 10), (240,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - loss: 0.0964 - mean_absolute_error: 0.1916 - val_loss: 0.0165 - val_mean_absolute_error: 0.1138
# Epoch 2/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - mean_absolute_error: 0.0417 - val_loss: 0.0051 - val_mean_absolute_error: 0.0569
# Epoch 3/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0023 - mean_absolute_error: 0.0305 - val_loss: 0.0026 - val_mean_absolute_error: 0.0381
# Epoch 4/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0015 - mean_absolute_error: 0.0248 - val_loss: 0.0028 - val_mean_absolute_error: 0.0408
# Epoch 5/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - mean_absolute_error: 0.0208 - val_loss: 0.0032 - val_mean_absolute_error: 0.0445
# Epoch 6/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014 - mean_absolute_error: 0.0245 - val_loss: 0.0020 - val_mean_absolute_error: 0.0331
# Epoch 7/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - mean_absolute_error: 0.0197 - val_loss: 0.0013 - val_mean_absolute_error: 0.0261
# Epoch 8/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - mean_absolute_error: 0.0202 - val_loss: 0.0014 - val_mean_absolute_error: 0.0290
# Epoch 9/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - mean_absolute_error: 0.0238 - val_loss: 0.0011 - val_mean_absolute_error: 0.0239
# Epoch 10/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9054e-04 - mean_absolute_error: 0.0189 - val_loss: 0.0011 - val_mean_absolute_error: 0.0238
# Epoch 11/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8057e-04 - mean_absolute_error: 0.0190 - val_loss: 0.0020 - val_mean_absolute_error: 0.0349
# Epoch 12/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.4445e-04 - mean_absolute_error: 0.0194 - val_loss: 0.0018 - val_mean_absolute_error: 0.0331
# Epoch 13/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.0084e-04 - mean_absolute_error: 0.0197 - val_loss: 0.0014 - val_mean_absolute_error: 0.0280
# Epoch 14/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6231e-04 - mean_absolute_error: 0.0175 - val_loss: 9.8325e-04 - val_mean_absolute_error: 0.0223
# Epoch 15/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5664e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0014 - val_mean_absolute_error: 0.0289
# Epoch 16/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9382e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0012 - val_mean_absolute_error: 0.0258
# Epoch 17/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.1492e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0011 - val_mean_absolute_error: 0.0245
# Epoch 18/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.5289e-04 - mean_absolute_error: 0.0158 - val_loss: 8.1494e-04 - val_mean_absolute_error: 0.0209
# Epoch 19/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6244e-04 - mean_absolute_error: 0.0146 - val_loss: 7.7127e-04 - val_mean_absolute_error: 0.0196
# Epoch 20/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.3500e-04 - mean_absolute_error: 0.0165 - val_loss: 8.1383e-04 - val_mean_absolute_error: 0.0201
# Epoch 21/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6095e-04 - mean_absolute_error: 0.0156 - val_loss: 0.0013 - val_mean_absolute_error: 0.0271
# Epoch 22/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.7597e-04 - mean_absolute_error: 0.0195 - val_loss: 9.4014e-04 - val_mean_absolute_error: 0.0222
# Epoch 23/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.4054e-04 - mean_absolute_error: 0.0149 - val_loss: 9.0562e-04 - val_mean_absolute_error: 0.0215
# Epoch 24/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0791e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0012 - val_mean_absolute_error: 0.0265
# Epoch 25/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7480e-04 - mean_absolute_error: 0.0149 - val_loss: 6.8842e-04 - val_mean_absolute_error: 0.0187
# Epoch 26/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6211e-04 - mean_absolute_error: 0.0162 - val_loss: 7.0383e-04 - val_mean_absolute_error: 0.0193
# Epoch 27/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.2662e-04 - mean_absolute_error: 0.0168 - val_loss: 6.7132e-04 - val_mean_absolute_error: 0.0183
# Epoch 28/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.0825e-04 - mean_absolute_error: 0.0138 - val_loss: 6.6219e-04 - val_mean_absolute_error: 0.0184
# Epoch 29/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.1326e-04 - mean_absolute_error: 0.0133 - val_loss: 8.7482e-04 - val_mean_absolute_error: 0.0217
# Epoch 30/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9541e-04 - mean_absolute_error: 0.0143 - val_loss: 8.3153e-04 - val_mean_absolute_error: 0.0224
# Epoch 31/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.3251e-04 - mean_absolute_error: 0.0160 - val_loss: 9.1740e-04 - val_mean_absolute_error: 0.0225
# Epoch 32/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.5944e-04 - mean_absolute_error: 0.0160 - val_loss: 6.3668e-04 - val_mean_absolute_error: 0.0181
# Epoch 33/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - mean_absolute_error: 0.0213 - val_loss: 6.5050e-04 - val_mean_absolute_error: 0.0180
# Epoch 34/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6413e-04 - mean_absolute_error: 0.0127 - val_loss: 7.5063e-04 - val_mean_absolute_error: 0.0197
# Epoch 35/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7994e-04 - mean_absolute_error: 0.0136 - val_loss: 7.9348e-04 - val_mean_absolute_error: 0.0205
# Epoch 36/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.0295e-04 - mean_absolute_error: 0.0136 - val_loss: 8.2649e-04 - val_mean_absolute_error: 0.0213
# Epoch 37/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.8714e-04 - mean_absolute_error: 0.0134 - val_loss: 7.4522e-04 - val_mean_absolute_error: 0.0197
# Epoch 38/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8818e-04 - mean_absolute_error: 0.0125 - val_loss: 6.5842e-04 - val_mean_absolute_error: 0.0182
# Epoch 39/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1471e-04 - mean_absolute_error: 0.0126 - val_loss: 6.0705e-04 - val_mean_absolute_error: 0.0172
# Epoch 40/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1039e-04 - mean_absolute_error: 0.0121 - val_loss: 5.9498e-04 - val_mean_absolute_error: 0.0176
# Epoch 41/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7277e-04 - mean_absolute_error: 0.0115 - val_loss: 7.7855e-04 - val_mean_absolute_error: 0.0205
# Epoch 42/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1094e-04 - mean_absolute_error: 0.0122 - val_loss: 5.9489e-04 - val_mean_absolute_error: 0.0170
# Epoch 43/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8603e-04 - mean_absolute_error: 0.0117 - val_loss: 6.3111e-04 - val_mean_absolute_error: 0.0178
# Epoch 44/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0175e-04 - mean_absolute_error: 0.0127 - val_loss: 5.6843e-04 - val_mean_absolute_error: 0.0168
# Epoch 45/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0966e-04 - mean_absolute_error: 0.0124 - val_loss: 5.9153e-04 - val_mean_absolute_error: 0.0171
# Epoch 46/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6447e-04 - mean_absolute_error: 0.0128 - val_loss: 5.7257e-04 - val_mean_absolute_error: 0.0168
# Epoch 47/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6160e-04 - mean_absolute_error: 0.0119 - val_loss: 5.7682e-04 - val_mean_absolute_error: 0.0168
# Epoch 48/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4016e-04 - mean_absolute_error: 0.0116 - val_loss: 5.5300e-04 - val_mean_absolute_error: 0.0165
# Epoch 49/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2863e-04 - mean_absolute_error: 0.0146 - val_loss: 5.5534e-04 - val_mean_absolute_error: 0.0165
# Epoch 50/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3418e-04 - mean_absolute_error: 0.0130 - val_loss: 5.7430e-04 - val_mean_absolute_error: 0.0177
# Epoch 51/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0967e-04 - mean_absolute_error: 0.0120 - val_loss: 8.8869e-04 - val_mean_absolute_error: 0.0228
# Epoch 52/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3556e-04 - mean_absolute_error: 0.0148 - val_loss: 8.7397e-04 - val_mean_absolute_error: 0.0225
# Epoch 53/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5978e-04 - mean_absolute_error: 0.0138 - val_loss: 5.3737e-04 - val_mean_absolute_error: 0.0163
# Epoch 54/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2287e-04 - mean_absolute_error: 0.0144 - val_loss: 5.2992e-04 - val_mean_absolute_error: 0.0163
# Epoch 55/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3306e-04 - mean_absolute_error: 0.0125 - val_loss: 5.9655e-04 - val_mean_absolute_error: 0.0175
# Epoch 56/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4233e-04 - mean_absolute_error: 0.0118 - val_loss: 5.2645e-04 - val_mean_absolute_error: 0.0162
# Epoch 57/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1592e-04 - mean_absolute_error: 0.0126 - val_loss: 6.0839e-04 - val_mean_absolute_error: 0.0177
# Epoch 58/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5850e-04 - mean_absolute_error: 0.0115 - val_loss: 9.0433e-04 - val_mean_absolute_error: 0.0233
# Epoch 59/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.0811e-04 - mean_absolute_error: 0.0148 - val_loss: 5.1603e-04 - val_mean_absolute_error: 0.0162
# Epoch 60/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7287e-04 - mean_absolute_error: 0.0117 - val_loss: 6.1822e-04 - val_mean_absolute_error: 0.0180
# Epoch 61/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6105e-04 - mean_absolute_error: 0.0135 - val_loss: 6.2179e-04 - val_mean_absolute_error: 0.0181
# Epoch 62/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9498e-04 - mean_absolute_error: 0.0128 - val_loss: 5.7088e-04 - val_mean_absolute_error: 0.0173
# Epoch 63/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6034e-04 - mean_absolute_error: 0.0140 - val_loss: 5.7828e-04 - val_mean_absolute_error: 0.0174
# Epoch 64/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3348e-04 - mean_absolute_error: 0.0116 - val_loss: 5.2484e-04 - val_mean_absolute_error: 0.0169
# Epoch 65/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3200e-04 - mean_absolute_error: 0.0147 - val_loss: 7.3176e-04 - val_mean_absolute_error: 0.0202
# Epoch 66/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1300e-04 - mean_absolute_error: 0.0127 - val_loss: 5.4902e-04 - val_mean_absolute_error: 0.0176
# Epoch 67/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1200e-04 - mean_absolute_error: 0.0122 - val_loss: 5.4279e-04 - val_mean_absolute_error: 0.0169
# Epoch 68/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5349e-04 - mean_absolute_error: 0.0129 - val_loss: 6.9045e-04 - val_mean_absolute_error: 0.0195
# Epoch 69/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1471e-04 - mean_absolute_error: 0.0125 - val_loss: 5.8990e-04 - val_mean_absolute_error: 0.0177
# Epoch 70/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9487e-04 - mean_absolute_error: 0.0126 - val_loss: 5.0044e-04 - val_mean_absolute_error: 0.0161
# Epoch 71/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3829e-04 - mean_absolute_error: 0.0114 - val_loss: 6.6841e-04 - val_mean_absolute_error: 0.0194
# Epoch 72/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0154e-04 - mean_absolute_error: 0.0124 - val_loss: 4.9179e-04 - val_mean_absolute_error: 0.0160
# Epoch 73/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0521e-04 - mean_absolute_error: 0.0123 - val_loss: 6.0972e-04 - val_mean_absolute_error: 0.0182
# Epoch 74/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.9022e-04 - mean_absolute_error: 0.0137 - val_loss: 5.9050e-04 - val_mean_absolute_error: 0.0178
# Epoch 75/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2357e-04 - mean_absolute_error: 0.0114 - val_loss: 6.4649e-04 - val_mean_absolute_error: 0.0190
# Epoch 76/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4562e-04 - mean_absolute_error: 0.0135 - val_loss: 5.1456e-04 - val_mean_absolute_error: 0.0165
# Epoch 77/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8087e-04 - mean_absolute_error: 0.0125 - val_loss: 4.8043e-04 - val_mean_absolute_error: 0.0161
# Epoch 78/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7126e-04 - mean_absolute_error: 0.0122 - val_loss: 5.2097e-04 - val_mean_absolute_error: 0.0174
# Epoch 79/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3748e-04 - mean_absolute_error: 0.0135 - val_loss: 4.7948e-04 - val_mean_absolute_error: 0.0159
# Epoch 80/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1130e-04 - mean_absolute_error: 0.0107 - val_loss: 6.2398e-04 - val_mean_absolute_error: 0.0186
# Epoch 81/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2129e-04 - mean_absolute_error: 0.0127 - val_loss: 5.5155e-04 - val_mean_absolute_error: 0.0172
# Epoch 82/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4336e-04 - mean_absolute_error: 0.0117 - val_loss: 6.4937e-04 - val_mean_absolute_error: 0.0192
# Epoch 83/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6203e-04 - mean_absolute_error: 0.0127 - val_loss: 5.8476e-04 - val_mean_absolute_error: 0.0188
# Epoch 84/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2082e-04 - mean_absolute_error: 0.0132 - val_loss: 5.7602e-04 - val_mean_absolute_error: 0.0177
# Epoch 85/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2048e-04 - mean_absolute_error: 0.0114 - val_loss: 4.9717e-04 - val_mean_absolute_error: 0.0162
# Epoch 86/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7247e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0011 - val_mean_absolute_error: 0.0272
# Epoch 87/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1230e-04 - mean_absolute_error: 0.0148 - val_loss: 4.6811e-04 - val_mean_absolute_error: 0.0158
# Epoch 88/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1513e-04 - mean_absolute_error: 0.0135 - val_loss: 4.7152e-04 - val_mean_absolute_error: 0.0161
# Epoch 89/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0772e-04 - mean_absolute_error: 0.0132 - val_loss: 5.3089e-04 - val_mean_absolute_error: 0.0170
# Epoch 90/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2551e-04 - mean_absolute_error: 0.0112 - val_loss: 6.6118e-04 - val_mean_absolute_error: 0.0194
# Epoch 91/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4021e-04 - mean_absolute_error: 0.0117 - val_loss: 5.2423e-04 - val_mean_absolute_error: 0.0169
# Epoch 92/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5592e-04 - mean_absolute_error: 0.0119 - val_loss: 4.6469e-04 - val_mean_absolute_error: 0.0158
# Epoch 93/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1458e-04 - mean_absolute_error: 0.0111 - val_loss: 4.6727e-04 - val_mean_absolute_error: 0.0159
# Epoch 94/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4652e-04 - mean_absolute_error: 0.0116 - val_loss: 5.7256e-04 - val_mean_absolute_error: 0.0180
# Epoch 95/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5165e-04 - mean_absolute_error: 0.0129 - val_loss: 4.6282e-04 - val_mean_absolute_error: 0.0158
# Epoch 96/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4548e-04 - mean_absolute_error: 0.0113 - val_loss: 6.3954e-04 - val_mean_absolute_error: 0.0190
# Epoch 97/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6679e-04 - mean_absolute_error: 0.0147 - val_loss: 5.5853e-04 - val_mean_absolute_error: 0.0183
# Epoch 98/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.8733e-04 - mean_absolute_error: 0.0141 - val_loss: 5.2308e-04 - val_mean_absolute_error: 0.0170
# Epoch 99/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6368e-04 - mean_absolute_error: 0.0121 - val_loss: 4.7883e-04 - val_mean_absolute_error: 0.0161
# Epoch 100/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7637e-04 - mean_absolute_error: 0.0124 - val_loss: 4.9797e-04 - val_mean_absolute_error: 0.0165
# Epoch 101/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1351e-04 - mean_absolute_error: 0.0110 - val_loss: 4.7726e-04 - val_mean_absolute_error: 0.0161
# Epoch 102/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5633e-04 - mean_absolute_error: 0.0119 - val_loss: 4.8627e-04 - val_mean_absolute_error: 0.0162
# Epoch 103/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7625e-04 - mean_absolute_error: 0.0121 - val_loss: 6.3382e-04 - val_mean_absolute_error: 0.0198
# Epoch 104/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2911e-04 - mean_absolute_error: 0.0117 - val_loss: 6.9500e-04 - val_mean_absolute_error: 0.0200
# Epoch 105/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3463e-04 - mean_absolute_error: 0.0133 - val_loss: 4.5543e-04 - val_mean_absolute_error: 0.0157
# Epoch 106/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2789e-04 - mean_absolute_error: 0.0118 - val_loss: 6.8135e-04 - val_mean_absolute_error: 0.0199
# Epoch 107/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4496e-04 - mean_absolute_error: 0.0140 - val_loss: 4.6277e-04 - val_mean_absolute_error: 0.0158
# Epoch 108/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2228e-04 - mean_absolute_error: 0.0112 - val_loss: 5.8681e-04 - val_mean_absolute_error: 0.0183
# Epoch 109/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0138e-04 - mean_absolute_error: 0.0137 - val_loss: 6.9103e-04 - val_mean_absolute_error: 0.0209
# Epoch 110/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4300e-04 - mean_absolute_error: 0.0137 - val_loss: 4.8980e-04 - val_mean_absolute_error: 0.0163
# Epoch 111/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6185e-04 - mean_absolute_error: 0.0119 - val_loss: 4.5749e-04 - val_mean_absolute_error: 0.0158
# Epoch 112/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1221e-04 - mean_absolute_error: 0.0110 - val_loss: 7.1597e-04 - val_mean_absolute_error: 0.0205
# Epoch 113/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3896e-04 - mean_absolute_error: 0.0119 - val_loss: 4.5828e-04 - val_mean_absolute_error: 0.0158
# Epoch 114/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9424e-04 - mean_absolute_error: 0.0109 - val_loss: 4.6944e-04 - val_mean_absolute_error: 0.0160
# Epoch 115/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4712e-04 - mean_absolute_error: 0.0119 - val_loss: 4.6520e-04 - val_mean_absolute_error: 0.0159
# Epoch 116/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4311e-04 - mean_absolute_error: 0.0111 - val_loss: 4.8935e-04 - val_mean_absolute_error: 0.0168
# Epoch 117/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9833e-04 - mean_absolute_error: 0.0129 - val_loss: 4.8842e-04 - val_mean_absolute_error: 0.0163
# Epoch 118/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1907e-04 - mean_absolute_error: 0.0112 - val_loss: 4.6336e-04 - val_mean_absolute_error: 0.0159
# Epoch 119/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6261e-04 - mean_absolute_error: 0.0116 - val_loss: 5.1840e-04 - val_mean_absolute_error: 0.0171
# Epoch 120/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8343e-04 - mean_absolute_error: 0.0130 - val_loss: 4.5834e-04 - val_mean_absolute_error: 0.0159
# Epoch 121/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6166e-04 - mean_absolute_error: 0.0135 - val_loss: 5.6781e-04 - val_mean_absolute_error: 0.0180
# Epoch 122/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4477e-04 - mean_absolute_error: 0.0117 - val_loss: 4.8116e-04 - val_mean_absolute_error: 0.0167
# Epoch 123/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1044e-04 - mean_absolute_error: 0.0115 - val_loss: 5.5490e-04 - val_mean_absolute_error: 0.0176
# Epoch 124/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5212e-04 - mean_absolute_error: 0.0121 - val_loss: 4.5505e-04 - val_mean_absolute_error: 0.0158
# Epoch 125/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1827e-04 - mean_absolute_error: 0.0110 - val_loss: 4.8091e-04 - val_mean_absolute_error: 0.0166
# Epoch 126/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.2793e-04 - mean_absolute_error: 0.0114 - val_loss: 4.8416e-04 - val_mean_absolute_error: 0.0162
# Epoch 127/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8474e-04 - mean_absolute_error: 0.0130 - val_loss: 4.7246e-04 - val_mean_absolute_error: 0.0165
# Epoch 128/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6378e-04 - mean_absolute_error: 0.0115 - val_loss: 4.8435e-04 - val_mean_absolute_error: 0.0163
# Epoch 129/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5431e-04 - mean_absolute_error: 0.0118 - val_loss: 9.1823e-04 - val_mean_absolute_error: 0.0241
# Epoch 130/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2795e-04 - mean_absolute_error: 0.0157 - val_loss: 4.7361e-04 - val_mean_absolute_error: 0.0161
# Epoch 131/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2519e-04 - mean_absolute_error: 0.0120 - val_loss: 4.5650e-04 - val_mean_absolute_error: 0.0159
# Epoch 132/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6703e-04 - mean_absolute_error: 0.0119 - val_loss: 4.8894e-04 - val_mean_absolute_error: 0.0165
# Epoch 133/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0401e-04 - mean_absolute_error: 0.0112 - val_loss: 4.7653e-04 - val_mean_absolute_error: 0.0162
# Epoch 134/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4220e-04 - mean_absolute_error: 0.0117 - val_loss: 4.6675e-04 - val_mean_absolute_error: 0.0163
# Epoch 135/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6833e-04 - mean_absolute_error: 0.0126 - val_loss: 5.4663e-04 - val_mean_absolute_error: 0.0176
# Epoch 136/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0663e-04 - mean_absolute_error: 0.0114 - val_loss: 9.2453e-04 - val_mean_absolute_error: 0.0239
# Epoch 137/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.5476e-04 - mean_absolute_error: 0.0173 - val_loss: 7.1767e-04 - val_mean_absolute_error: 0.0213
# Epoch 138/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0291e-04 - mean_absolute_error: 0.0136 - val_loss: 6.7586e-04 - val_mean_absolute_error: 0.0199
# Epoch 139/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2612e-04 - mean_absolute_error: 0.0128 - val_loss: 4.7303e-04 - val_mean_absolute_error: 0.0164
# Epoch 140/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5580e-04 - mean_absolute_error: 0.0121 - val_loss: 4.6184e-04 - val_mean_absolute_error: 0.0159
# Epoch 141/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9688e-04 - mean_absolute_error: 0.0121 - val_loss: 4.8013e-04 - val_mean_absolute_error: 0.0163
# Epoch 142/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3317e-04 - mean_absolute_error: 0.0114 - val_loss: 5.2175e-04 - val_mean_absolute_error: 0.0172
# Epoch 143/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0861e-04 - mean_absolute_error: 0.0131 - val_loss: 4.6019e-04 - val_mean_absolute_error: 0.0161
# Epoch 144/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4475e-04 - mean_absolute_error: 0.0116 - val_loss: 4.7641e-04 - val_mean_absolute_error: 0.0162
# Epoch 145/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8108e-04 - mean_absolute_error: 0.0107 - val_loss: 5.0816e-04 - val_mean_absolute_error: 0.0169
# Epoch 146/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0119e-04 - mean_absolute_error: 0.0110 - val_loss: 4.6406e-04 - val_mean_absolute_error: 0.0162
# Epoch 147/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9373e-04 - mean_absolute_error: 0.0125 - val_loss: 4.5533e-04 - val_mean_absolute_error: 0.0160
# Epoch 148/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.5021e-04 - mean_absolute_error: 0.0132 - val_loss: 4.8149e-04 - val_mean_absolute_error: 0.0166
# Epoch 149/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1760e-04 - mean_absolute_error: 0.0115 - val_loss: 4.6505e-04 - val_mean_absolute_error: 0.0160
# Epoch 150/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1422e-04 - mean_absolute_error: 0.0117 - val_loss: 5.5705e-04 - val_mean_absolute_error: 0.0178
# Epoch 151/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7875e-04 - mean_absolute_error: 0.0125 - val_loss: 5.7300e-04 - val_mean_absolute_error: 0.0181
# Epoch 152/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2114e-04 - mean_absolute_error: 0.0115 - val_loss: 7.7643e-04 - val_mean_absolute_error: 0.0214
# Epoch 153/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4957e-04 - mean_absolute_error: 0.0164 - val_loss: 5.3993e-04 - val_mean_absolute_error: 0.0180
# Epoch 154/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0855e-04 - mean_absolute_error: 0.0134 - val_loss: 4.8868e-04 - val_mean_absolute_error: 0.0165
# Epoch 155/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9024e-04 - mean_absolute_error: 0.0109 - val_loss: 5.4020e-04 - val_mean_absolute_error: 0.0174
# Epoch 156/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1883e-04 - mean_absolute_error: 0.0114 - val_loss: 4.5597e-04 - val_mean_absolute_error: 0.0160
# Epoch 157/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2299e-04 - mean_absolute_error: 0.0115 - val_loss: 4.5870e-04 - val_mean_absolute_error: 0.0161
# Epoch 158/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.4212e-04 - mean_absolute_error: 0.0116 - val_loss: 4.5904e-04 - val_mean_absolute_error: 0.0161
# Epoch 159/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1222e-04 - mean_absolute_error: 0.0112 - val_loss: 4.5566e-04 - val_mean_absolute_error: 0.0159
# Epoch 160/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1021e-04 - mean_absolute_error: 0.0110 - val_loss: 4.5745e-04 - val_mean_absolute_error: 0.0159
# Epoch 161/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6301e-04 - mean_absolute_error: 0.0120 - val_loss: 6.3887e-04 - val_mean_absolute_error: 0.0192
# Epoch 162/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1717e-04 - mean_absolute_error: 0.0120 - val_loss: 4.5419e-04 - val_mean_absolute_error: 0.0158
# Epoch 163/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4087e-04 - mean_absolute_error: 0.0118 - val_loss: 4.7682e-04 - val_mean_absolute_error: 0.0163
# Epoch 164/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8328e-04 - mean_absolute_error: 0.0124 - val_loss: 4.5076e-04 - val_mean_absolute_error: 0.0158
# Epoch 165/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6171e-04 - mean_absolute_error: 0.0124 - val_loss: 5.1894e-04 - val_mean_absolute_error: 0.0170
# Epoch 166/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8035e-04 - mean_absolute_error: 0.0123 - val_loss: 5.1368e-04 - val_mean_absolute_error: 0.0174
# Epoch 167/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8171e-04 - mean_absolute_error: 0.0125 - val_loss: 5.1422e-04 - val_mean_absolute_error: 0.0170
# Epoch 168/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.0731e-04 - mean_absolute_error: 0.0111 - val_loss: 4.8587e-04 - val_mean_absolute_error: 0.0168
# Epoch 169/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6041e-04 - mean_absolute_error: 0.0128 - val_loss: 4.6198e-04 - val_mean_absolute_error: 0.0160
# Epoch 170/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6325e-04 - mean_absolute_error: 0.0117 - val_loss: 4.8117e-04 - val_mean_absolute_error: 0.0163
# Epoch 171/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5161e-04 - mean_absolute_error: 0.0117 - val_loss: 4.9291e-04 - val_mean_absolute_error: 0.0166
# Epoch 172/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4091e-04 - mean_absolute_error: 0.0114 - val_loss: 5.6356e-04 - val_mean_absolute_error: 0.0180
# Epoch 173/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7245e-04 - mean_absolute_error: 0.0119 - val_loss: 5.2622e-04 - val_mean_absolute_error: 0.0173
# Epoch 174/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3926e-04 - mean_absolute_error: 0.0115 - val_loss: 4.7524e-04 - val_mean_absolute_error: 0.0165
# Epoch 175/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8308e-04 - mean_absolute_error: 0.0107 - val_loss: 5.2620e-04 - val_mean_absolute_error: 0.0172
# Epoch 176/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4513e-04 - mean_absolute_error: 0.0120 - val_loss: 5.9581e-04 - val_mean_absolute_error: 0.0187
# Epoch 177/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6191e-04 - mean_absolute_error: 0.0127 - val_loss: 4.7105e-04 - val_mean_absolute_error: 0.0164
# Epoch 178/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2271e-04 - mean_absolute_error: 0.0110 - val_loss: 4.6968e-04 - val_mean_absolute_error: 0.0164
# Epoch 179/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6731e-04 - mean_absolute_error: 0.0116 - val_loss: 4.5732e-04 - val_mean_absolute_error: 0.0159
# Epoch 180/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6650e-04 - mean_absolute_error: 0.0116 - val_loss: 4.7654e-04 - val_mean_absolute_error: 0.0163
# Epoch 181/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1868e-04 - mean_absolute_error: 0.0114 - val_loss: 4.5853e-04 - val_mean_absolute_error: 0.0159
# Epoch 182/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5335e-04 - mean_absolute_error: 0.0117 - val_loss: 4.6176e-04 - val_mean_absolute_error: 0.0159
# Epoch 183/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3011e-04 - mean_absolute_error: 0.0113 - val_loss: 4.6549e-04 - val_mean_absolute_error: 0.0160
# Epoch 184/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8339e-04 - mean_absolute_error: 0.0108 - val_loss: 5.0785e-04 - val_mean_absolute_error: 0.0174
# Epoch 185/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0160e-04 - mean_absolute_error: 0.0137 - val_loss: 4.6433e-04 - val_mean_absolute_error: 0.0161
# Epoch 186/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7766e-04 - mean_absolute_error: 0.0123 - val_loss: 5.5203e-04 - val_mean_absolute_error: 0.0179
# Epoch 187/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9412e-04 - mean_absolute_error: 0.0128 - val_loss: 6.6736e-04 - val_mean_absolute_error: 0.0199
# Epoch 188/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5448e-04 - mean_absolute_error: 0.0120 - val_loss: 5.6599e-04 - val_mean_absolute_error: 0.0180
# Epoch 189/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4109e-04 - mean_absolute_error: 0.0159 - val_loss: 5.2771e-04 - val_mean_absolute_error: 0.0176
# Epoch 190/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8238e-04 - mean_absolute_error: 0.0125 - val_loss: 4.7084e-04 - val_mean_absolute_error: 0.0162
# Epoch 191/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3360e-04 - mean_absolute_error: 0.0117 - val_loss: 4.9973e-04 - val_mean_absolute_error: 0.0168
# Epoch 192/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4928e-04 - mean_absolute_error: 0.0124 - val_loss: 4.5629e-04 - val_mean_absolute_error: 0.0159
# Epoch 193/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3445e-04 - mean_absolute_error: 0.0128 - val_loss: 5.3511e-04 - val_mean_absolute_error: 0.0175
# Epoch 194/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1674e-04 - mean_absolute_error: 0.0119 - val_loss: 6.7832e-04 - val_mean_absolute_error: 0.0206
# Epoch 195/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4349e-04 - mean_absolute_error: 0.0143 - val_loss: 5.5977e-04 - val_mean_absolute_error: 0.0179
# Epoch 196/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3254e-04 - mean_absolute_error: 0.0118 - val_loss: 4.6013e-04 - val_mean_absolute_error: 0.0161
# Epoch 197/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.1389e-04 - mean_absolute_error: 0.0112 - val_loss: 5.2254e-04 - val_mean_absolute_error: 0.0172
# Epoch 198/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5353e-04 - mean_absolute_error: 0.0117 - val_loss: 4.6365e-04 - val_mean_absolute_error: 0.0160
# Epoch 199/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2224e-04 - mean_absolute_error: 0.0115 - val_loss: 5.5734e-04 - val_mean_absolute_error: 0.0184
# Epoch 200/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4089e-04 - mean_absolute_error: 0.0144 - val_loss: 4.5783e-04 - val_mean_absolute_error: 0.0158

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 239
# 250

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 262556.34807207994
# RMSE: 512.4025254349162
# MAE: 361.1381856367678
# MAPE: 3.128950601050917 %
#
# Model evalution on validate set
# MSE: 62839.35410758257
# RMSE: 250.67778941817437
# MAE: 185.31859130859374
# MAPE: 1.7264776565350624 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step

# %%
y_pred_30_days
# Out:
# array([[10243.56  ],
#        [10168.836 ],
#        [10227.341 ],
#        [10206.581 ],
#        [10246.86  ],
#        [10227.293 ],
#        [10240.719 ],
#        [10233.163 ],
#        [10240.358 ],
#        [10235.898 ],
#        [10238.93  ],
#        [10236.99  ],
#        [10238.476 ],
#        [10237.4795],
#        [10238.161 ],
#        [10237.705 ],
#        [10238.03  ],
#        [10237.808 ],
#        [10237.961 ],
#        [10237.856 ],
#        [10237.928 ],
#        [10237.879 ],
#        [10237.914 ],
#        [10237.89  ],
#        [10237.906 ],
#        [10237.8955],
#        [10237.904 ],
#        [10237.897 ],
#        [10237.902 ],
#        [10237.899 ],
#        [10237.899 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Predict the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
