# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: ITD - Test/Train/Vaildation: 60/20/20
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 411.1055783844739
# - MAE: 303.06645682893424
# - MAPE: 2.7710047213717215 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 1  # 6 2 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        6900
# 1        7100
# 2        7100
# 3        7170
# 4        7170
#         ...
# 1308    11300
# 1309    12050
# 1310    12600
# 1311    12500
# 1312    12700
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((776, 10), (776,), (251, 10), (251,), (253, 10), (253,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_1 (SimpleRNN)        │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 89ms/step - loss: 0.0663 - mean_absolute_error: 0.1731 - val_loss: 0.0139 - val_mean_absolute_error: 0.1073
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0035 - mean_absolute_error: 0.0411 - val_loss: 0.0034 - val_mean_absolute_error: 0.0484
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0020 - mean_absolute_error: 0.0281 - val_loss: 0.0015 - val_mean_absolute_error: 0.0292
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0015 - mean_absolute_error: 0.0235 - val_loss: 0.0014 - val_mean_absolute_error: 0.0290
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0012 - mean_absolute_error: 0.0216 - val_loss: 9.5522e-04 - val_mean_absolute_error: 0.0226
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0013 - mean_absolute_error: 0.0227 - val_loss: 0.0011 - val_mean_absolute_error: 0.0259
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0013 - mean_absolute_error: 0.0230 - val_loss: 0.0012 - val_mean_absolute_error: 0.0272
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.0597e-04 - mean_absolute_error: 0.0186 - val_loss: 7.1876e-04 - val_mean_absolute_error: 0.0194
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0011 - mean_absolute_error: 0.0205 - val_loss: 7.5813e-04 - val_mean_absolute_error: 0.0204
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.7837e-04 - mean_absolute_error: 0.0175 - val_loss: 7.6083e-04 - val_mean_absolute_error: 0.0209
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.1275e-04 - mean_absolute_error: 0.0181 - val_loss: 0.0013 - val_mean_absolute_error: 0.0299
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0013 - mean_absolute_error: 0.0229 - val_loss: 6.6693e-04 - val_mean_absolute_error: 0.0193
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 8.6320e-04 - mean_absolute_error: 0.0183 - val_loss: 6.4248e-04 - val_mean_absolute_error: 0.0188
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.8011e-04 - mean_absolute_error: 0.0203 - val_loss: 0.0012 - val_mean_absolute_error: 0.0286
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0218e-04 - mean_absolute_error: 0.0190 - val_loss: 5.9270e-04 - val_mean_absolute_error: 0.0179
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.0702e-04 - mean_absolute_error: 0.0172 - val_loss: 5.7091e-04 - val_mean_absolute_error: 0.0176
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0010 - mean_absolute_error: 0.0204 - val_loss: 7.5603e-04 - val_mean_absolute_error: 0.0217
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.3755e-04 - mean_absolute_error: 0.0183 - val_loss: 7.1762e-04 - val_mean_absolute_error: 0.0210
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4700e-04 - mean_absolute_error: 0.0158 - val_loss: 5.8110e-04 - val_mean_absolute_error: 0.0180
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.9993e-04 - mean_absolute_error: 0.0146 - val_loss: 5.2884e-04 - val_mean_absolute_error: 0.0169
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.4327e-04 - mean_absolute_error: 0.0155 - val_loss: 5.1769e-04 - val_mean_absolute_error: 0.0168
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.8962e-04 - mean_absolute_error: 0.0148 - val_loss: 6.3417e-04 - val_mean_absolute_error: 0.0195
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.8079e-04 - mean_absolute_error: 0.0169 - val_loss: 4.8078e-04 - val_mean_absolute_error: 0.0160
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.5581e-04 - mean_absolute_error: 0.0144 - val_loss: 6.7141e-04 - val_mean_absolute_error: 0.0203
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.6363e-04 - mean_absolute_error: 0.0155 - val_loss: 6.1709e-04 - val_mean_absolute_error: 0.0192
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0203e-04 - mean_absolute_error: 0.0144 - val_loss: 4.7208e-04 - val_mean_absolute_error: 0.0160
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.2577e-04 - mean_absolute_error: 0.0155 - val_loss: 4.7354e-04 - val_mean_absolute_error: 0.0160
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8051e-04 - mean_absolute_error: 0.0160 - val_loss: 4.4858e-04 - val_mean_absolute_error: 0.0154
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.0636e-04 - mean_absolute_error: 0.0134 - val_loss: 4.2225e-04 - val_mean_absolute_error: 0.0148
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.9274e-04 - mean_absolute_error: 0.0148 - val_loss: 4.2691e-04 - val_mean_absolute_error: 0.0149
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.4046e-04 - mean_absolute_error: 0.0137 - val_loss: 4.8340e-04 - val_mean_absolute_error: 0.0166
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.7053e-04 - mean_absolute_error: 0.0164 - val_loss: 7.1967e-04 - val_mean_absolute_error: 0.0216
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.3362e-04 - mean_absolute_error: 0.0156 - val_loss: 4.3430e-04 - val_mean_absolute_error: 0.0152
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.3095e-04 - mean_absolute_error: 0.0141 - val_loss: 6.8692e-04 - val_mean_absolute_error: 0.0211
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.3939e-04 - mean_absolute_error: 0.0142 - val_loss: 3.9981e-04 - val_mean_absolute_error: 0.0143
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.2449e-04 - mean_absolute_error: 0.0133 - val_loss: 3.9396e-04 - val_mean_absolute_error: 0.0143
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.6291e-04 - mean_absolute_error: 0.0147 - val_loss: 4.1780e-04 - val_mean_absolute_error: 0.0150
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.9505e-04 - mean_absolute_error: 0.0139 - val_loss: 4.0224e-04 - val_mean_absolute_error: 0.0145
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.2639e-04 - mean_absolute_error: 0.0141 - val_loss: 3.8324e-04 - val_mean_absolute_error: 0.0142
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.8860e-04 - mean_absolute_error: 0.0127 - val_loss: 3.9837e-04 - val_mean_absolute_error: 0.0145
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.3799e-04 - mean_absolute_error: 0.0138 - val_loss: 5.5871e-04 - val_mean_absolute_error: 0.0187
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.2020e-04 - mean_absolute_error: 0.0147 - val_loss: 4.0930e-04 - val_mean_absolute_error: 0.0150
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.6621e-04 - mean_absolute_error: 0.0150 - val_loss: 4.8757e-04 - val_mean_absolute_error: 0.0170
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3123e-04 - mean_absolute_error: 0.0156 - val_loss: 3.9892e-04 - val_mean_absolute_error: 0.0148
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.5510e-04 - mean_absolute_error: 0.0130 - val_loss: 3.6389e-04 - val_mean_absolute_error: 0.0137
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.6489e-04 - mean_absolute_error: 0.0128 - val_loss: 4.5731e-04 - val_mean_absolute_error: 0.0164
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.5730e-04 - mean_absolute_error: 0.0133 - val_loss: 3.6057e-04 - val_mean_absolute_error: 0.0137
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.6224e-04 - mean_absolute_error: 0.0133 - val_loss: 5.0769e-04 - val_mean_absolute_error: 0.0178
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.4615e-04 - mean_absolute_error: 0.0125 - val_loss: 3.4961e-04 - val_mean_absolute_error: 0.0135
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.0087e-04 - mean_absolute_error: 0.0139 - val_loss: 3.4507e-04 - val_mean_absolute_error: 0.0134
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3143e-04 - mean_absolute_error: 0.0128 - val_loss: 3.4757e-04 - val_mean_absolute_error: 0.0134
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.7279e-04 - mean_absolute_error: 0.0130 - val_loss: 3.4195e-04 - val_mean_absolute_error: 0.0133
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.3762e-04 - mean_absolute_error: 0.0124 - val_loss: 3.4088e-04 - val_mean_absolute_error: 0.0133
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.6737e-04 - mean_absolute_error: 0.0138 - val_loss: 5.2378e-04 - val_mean_absolute_error: 0.0182
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.4457e-04 - mean_absolute_error: 0.0134 - val_loss: 4.2566e-04 - val_mean_absolute_error: 0.0157
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.9764e-04 - mean_absolute_error: 0.0135 - val_loss: 5.3060e-04 - val_mean_absolute_error: 0.0184
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.8151e-04 - mean_absolute_error: 0.0140 - val_loss: 3.7553e-04 - val_mean_absolute_error: 0.0144
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.4663e-04 - mean_absolute_error: 0.0118 - val_loss: 3.3565e-04 - val_mean_absolute_error: 0.0133
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7662e-04 - mean_absolute_error: 0.0121 - val_loss: 3.3513e-04 - val_mean_absolute_error: 0.0133
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.5897e-04 - mean_absolute_error: 0.0132 - val_loss: 3.2809e-04 - val_mean_absolute_error: 0.0132
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.7393e-04 - mean_absolute_error: 0.0118 - val_loss: 3.6876e-04 - val_mean_absolute_error: 0.0143
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.0655e-04 - mean_absolute_error: 0.0126 - val_loss: 3.7143e-04 - val_mean_absolute_error: 0.0144
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.0617e-04 - mean_absolute_error: 0.0125 - val_loss: 3.2331e-04 - val_mean_absolute_error: 0.0132
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.5561e-04 - mean_absolute_error: 0.0130 - val_loss: 3.2891e-04 - val_mean_absolute_error: 0.0134
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.5869e-04 - mean_absolute_error: 0.0132 - val_loss: 3.8462e-04 - val_mean_absolute_error: 0.0150
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.8049e-04 - mean_absolute_error: 0.0136 - val_loss: 4.3927e-04 - val_mean_absolute_error: 0.0163
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.0526e-04 - mean_absolute_error: 0.0126 - val_loss: 3.2108e-04 - val_mean_absolute_error: 0.0131
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.1942e-04 - mean_absolute_error: 0.0126 - val_loss: 3.2472e-04 - val_mean_absolute_error: 0.0133
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0315e-04 - mean_absolute_error: 0.0126 - val_loss: 4.2148e-04 - val_mean_absolute_error: 0.0159
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.2912e-04 - mean_absolute_error: 0.0129 - val_loss: 3.4369e-04 - val_mean_absolute_error: 0.0138
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5779e-04 - mean_absolute_error: 0.0121 - val_loss: 3.3329e-04 - val_mean_absolute_error: 0.0135
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.4405e-04 - mean_absolute_error: 0.0117 - val_loss: 3.2842e-04 - val_mean_absolute_error: 0.0136
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.2535e-04 - mean_absolute_error: 0.0134 - val_loss: 3.2783e-04 - val_mean_absolute_error: 0.0135
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.2412e-04 - mean_absolute_error: 0.0127 - val_loss: 3.2990e-04 - val_mean_absolute_error: 0.0136
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7926e-04 - mean_absolute_error: 0.0120 - val_loss: 3.1578e-04 - val_mean_absolute_error: 0.0131
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9022e-04 - mean_absolute_error: 0.0120 - val_loss: 3.7796e-04 - val_mean_absolute_error: 0.0152
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.2241e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1168e-04 - val_mean_absolute_error: 0.0130
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.0973e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1840e-04 - val_mean_absolute_error: 0.0132
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.5904e-04 - mean_absolute_error: 0.0122 - val_loss: 3.5445e-04 - val_mean_absolute_error: 0.0145
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.4333e-04 - mean_absolute_error: 0.0128 - val_loss: 3.1078e-04 - val_mean_absolute_error: 0.0130
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.9124e-04 - mean_absolute_error: 0.0122 - val_loss: 3.7099e-04 - val_mean_absolute_error: 0.0150
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.9841e-04 - mean_absolute_error: 0.0134 - val_loss: 3.5846e-04 - val_mean_absolute_error: 0.0143
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.2267e-04 - mean_absolute_error: 0.0109 - val_loss: 4.0991e-04 - val_mean_absolute_error: 0.0158
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.2199e-04 - mean_absolute_error: 0.0132 - val_loss: 3.9969e-04 - val_mean_absolute_error: 0.0155
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.0289e-04 - mean_absolute_error: 0.0129 - val_loss: 3.1585e-04 - val_mean_absolute_error: 0.0134
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.4974e-04 - mean_absolute_error: 0.0119 - val_loss: 6.4112e-04 - val_mean_absolute_error: 0.0207
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.3796e-04 - mean_absolute_error: 0.0150 - val_loss: 4.7811e-04 - val_mean_absolute_error: 0.0174
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.7780e-04 - mean_absolute_error: 0.0144 - val_loss: 3.1533e-04 - val_mean_absolute_error: 0.0132
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5733e-04 - mean_absolute_error: 0.0121 - val_loss: 3.3851e-04 - val_mean_absolute_error: 0.0141
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8915e-04 - mean_absolute_error: 0.0128 - val_loss: 3.1471e-04 - val_mean_absolute_error: 0.0133
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6644e-04 - mean_absolute_error: 0.0120 - val_loss: 3.6572e-04 - val_mean_absolute_error: 0.0149
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.6044e-04 - mean_absolute_error: 0.0125 - val_loss: 3.6731e-04 - val_mean_absolute_error: 0.0147
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.6951e-04 - mean_absolute_error: 0.0120 - val_loss: 4.5915e-04 - val_mean_absolute_error: 0.0170
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.5876e-04 - mean_absolute_error: 0.0137 - val_loss: 3.3989e-04 - val_mean_absolute_error: 0.0139
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.8753e-04 - mean_absolute_error: 0.0127 - val_loss: 3.9236e-04 - val_mean_absolute_error: 0.0154
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.2717e-04 - mean_absolute_error: 0.0134 - val_loss: 3.5578e-04 - val_mean_absolute_error: 0.0144
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.7473e-04 - mean_absolute_error: 0.0143 - val_loss: 3.1868e-04 - val_mean_absolute_error: 0.0133
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7905e-04 - mean_absolute_error: 0.0126 - val_loss: 3.8219e-04 - val_mean_absolute_error: 0.0151
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.6462e-04 - mean_absolute_error: 0.0129 - val_loss: 3.1056e-04 - val_mean_absolute_error: 0.0132
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.1538e-04 - mean_absolute_error: 0.0111 - val_loss: 3.8854e-04 - val_mean_absolute_error: 0.0153
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.0511e-04 - mean_absolute_error: 0.0126 - val_loss: 3.1635e-04 - val_mean_absolute_error: 0.0133
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.9679e-04 - mean_absolute_error: 0.0129 - val_loss: 3.2219e-04 - val_mean_absolute_error: 0.0136
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.0934e-04 - mean_absolute_error: 0.0132 - val_loss: 3.7543e-04 - val_mean_absolute_error: 0.0149
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.4405e-04 - mean_absolute_error: 0.0118 - val_loss: 3.6542e-04 - val_mean_absolute_error: 0.0150
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5787e-04 - mean_absolute_error: 0.0122 - val_loss: 3.4189e-04 - val_mean_absolute_error: 0.0140
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.0953e-04 - mean_absolute_error: 0.0125 - val_loss: 3.6639e-04 - val_mean_absolute_error: 0.0147
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.6377e-04 - mean_absolute_error: 0.0129 - val_loss: 3.1105e-04 - val_mean_absolute_error: 0.0132
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.4613e-04 - mean_absolute_error: 0.0137 - val_loss: 3.5766e-04 - val_mean_absolute_error: 0.0144
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5442e-04 - mean_absolute_error: 0.0117 - val_loss: 3.2864e-04 - val_mean_absolute_error: 0.0139
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.2631e-04 - mean_absolute_error: 0.0155 - val_loss: 3.5766e-04 - val_mean_absolute_error: 0.0144
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1421e-04 - mean_absolute_error: 0.0127 - val_loss: 3.1712e-04 - val_mean_absolute_error: 0.0133
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9152e-04 - mean_absolute_error: 0.0127 - val_loss: 3.0947e-04 - val_mean_absolute_error: 0.0132
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.5021e-04 - mean_absolute_error: 0.0116 - val_loss: 3.1187e-04 - val_mean_absolute_error: 0.0132
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.9100e-04 - mean_absolute_error: 0.0131 - val_loss: 3.0790e-04 - val_mean_absolute_error: 0.0131
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.6648e-04 - mean_absolute_error: 0.0123 - val_loss: 3.3952e-04 - val_mean_absolute_error: 0.0139
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.5342e-04 - mean_absolute_error: 0.0123 - val_loss: 3.6755e-04 - val_mean_absolute_error: 0.0150
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.0481e-04 - mean_absolute_error: 0.0134 - val_loss: 5.2822e-04 - val_mean_absolute_error: 0.0184
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7112e-04 - mean_absolute_error: 0.0127 - val_loss: 3.1347e-04 - val_mean_absolute_error: 0.0132
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.6217e-04 - mean_absolute_error: 0.0118 - val_loss: 3.4896e-04 - val_mean_absolute_error: 0.0145
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.8878e-04 - mean_absolute_error: 0.0121 - val_loss: 3.1907e-04 - val_mean_absolute_error: 0.0134
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2187e-04 - mean_absolute_error: 0.0114 - val_loss: 3.9710e-04 - val_mean_absolute_error: 0.0155
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8016e-04 - mean_absolute_error: 0.0173 - val_loss: 3.1406e-04 - val_mean_absolute_error: 0.0134
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7963e-04 - mean_absolute_error: 0.0126 - val_loss: 3.8647e-04 - val_mean_absolute_error: 0.0152
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.9763e-04 - mean_absolute_error: 0.0129 - val_loss: 3.8033e-04 - val_mean_absolute_error: 0.0151
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.5281e-04 - mean_absolute_error: 0.0138 - val_loss: 3.3446e-04 - val_mean_absolute_error: 0.0139
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.5932e-04 - mean_absolute_error: 0.0132 - val_loss: 3.1482e-04 - val_mean_absolute_error: 0.0133
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.8595e-04 - mean_absolute_error: 0.0125 - val_loss: 3.2654e-04 - val_mean_absolute_error: 0.0136
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.3576e-04 - mean_absolute_error: 0.0116 - val_loss: 4.1317e-04 - val_mean_absolute_error: 0.0158
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.7153e-04 - mean_absolute_error: 0.0120 - val_loss: 5.8903e-04 - val_mean_absolute_error: 0.0196
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.1588e-04 - mean_absolute_error: 0.0127 - val_loss: 4.4884e-04 - val_mean_absolute_error: 0.0167
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9667e-04 - mean_absolute_error: 0.0131 - val_loss: 3.3670e-04 - val_mean_absolute_error: 0.0139
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6825e-04 - mean_absolute_error: 0.0124 - val_loss: 4.3886e-04 - val_mean_absolute_error: 0.0164
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3157e-04 - mean_absolute_error: 0.0134 - val_loss: 3.6901e-04 - val_mean_absolute_error: 0.0148
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8637e-04 - mean_absolute_error: 0.0124 - val_loss: 3.6090e-04 - val_mean_absolute_error: 0.0146
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.6082e-04 - mean_absolute_error: 0.0123 - val_loss: 3.1662e-04 - val_mean_absolute_error: 0.0133
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6251e-04 - mean_absolute_error: 0.0123 - val_loss: 3.7807e-04 - val_mean_absolute_error: 0.0152
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.3035e-04 - mean_absolute_error: 0.0136 - val_loss: 5.6485e-04 - val_mean_absolute_error: 0.0194
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.8828e-04 - mean_absolute_error: 0.0148 - val_loss: 3.1462e-04 - val_mean_absolute_error: 0.0133
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.6395e-04 - mean_absolute_error: 0.0125 - val_loss: 3.5453e-04 - val_mean_absolute_error: 0.0147
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.3602e-04 - mean_absolute_error: 0.0116 - val_loss: 3.1583e-04 - val_mean_absolute_error: 0.0133
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2951e-04 - mean_absolute_error: 0.0119 - val_loss: 3.6229e-04 - val_mean_absolute_error: 0.0149
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.0183e-04 - mean_absolute_error: 0.0113 - val_loss: 3.1940e-04 - val_mean_absolute_error: 0.0134
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.3583e-04 - mean_absolute_error: 0.0119 - val_loss: 3.7847e-04 - val_mean_absolute_error: 0.0150
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5807e-04 - mean_absolute_error: 0.0126 - val_loss: 4.1197e-04 - val_mean_absolute_error: 0.0158
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8759e-04 - mean_absolute_error: 0.0129 - val_loss: 5.8051e-04 - val_mean_absolute_error: 0.0195
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9142e-04 - mean_absolute_error: 0.0139 - val_loss: 3.3243e-04 - val_mean_absolute_error: 0.0140
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8177e-04 - mean_absolute_error: 0.0125 - val_loss: 3.2644e-04 - val_mean_absolute_error: 0.0136
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5060e-04 - mean_absolute_error: 0.0119 - val_loss: 3.5394e-04 - val_mean_absolute_error: 0.0144
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.3256e-04 - mean_absolute_error: 0.0117 - val_loss: 3.3400e-04 - val_mean_absolute_error: 0.0139
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5177e-04 - mean_absolute_error: 0.0127 - val_loss: 3.8638e-04 - val_mean_absolute_error: 0.0152
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.5077e-04 - mean_absolute_error: 0.0137 - val_loss: 3.3911e-04 - val_mean_absolute_error: 0.0140
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.1839e-04 - mean_absolute_error: 0.0114 - val_loss: 3.5045e-04 - val_mean_absolute_error: 0.0143
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.4089e-04 - mean_absolute_error: 0.0114 - val_loss: 3.2030e-04 - val_mean_absolute_error: 0.0134
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2538e-04 - mean_absolute_error: 0.0117 - val_loss: 3.1819e-04 - val_mean_absolute_error: 0.0133
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4361e-04 - mean_absolute_error: 0.0114 - val_loss: 4.5918e-04 - val_mean_absolute_error: 0.0169
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.6442e-04 - mean_absolute_error: 0.0126 - val_loss: 4.1564e-04 - val_mean_absolute_error: 0.0159
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.0121e-04 - mean_absolute_error: 0.0134 - val_loss: 4.2106e-04 - val_mean_absolute_error: 0.0160
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7000e-04 - mean_absolute_error: 0.0129 - val_loss: 3.1811e-04 - val_mean_absolute_error: 0.0134
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.1366e-04 - mean_absolute_error: 0.0113 - val_loss: 3.2175e-04 - val_mean_absolute_error: 0.0136
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.8885e-04 - mean_absolute_error: 0.0125 - val_loss: 3.7920e-04 - val_mean_absolute_error: 0.0153
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.6963e-04 - mean_absolute_error: 0.0126 - val_loss: 3.2407e-04 - val_mean_absolute_error: 0.0137
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.3039e-04 - mean_absolute_error: 0.0119 - val_loss: 3.8804e-04 - val_mean_absolute_error: 0.0153
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.5735e-04 - mean_absolute_error: 0.0120 - val_loss: 3.3290e-04 - val_mean_absolute_error: 0.0138
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.5855e-04 - mean_absolute_error: 0.0123 - val_loss: 3.1556e-04 - val_mean_absolute_error: 0.0133
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5549e-04 - mean_absolute_error: 0.0116 - val_loss: 3.2581e-04 - val_mean_absolute_error: 0.0136
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.2594e-04 - mean_absolute_error: 0.0127 - val_loss: 3.1451e-04 - val_mean_absolute_error: 0.0133
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7060e-04 - mean_absolute_error: 0.0120 - val_loss: 3.3636e-04 - val_mean_absolute_error: 0.0142
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1880e-04 - mean_absolute_error: 0.0125 - val_loss: 5.4058e-04 - val_mean_absolute_error: 0.0189
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.6513e-04 - mean_absolute_error: 0.0146 - val_loss: 3.2355e-04 - val_mean_absolute_error: 0.0137
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1948e-04 - mean_absolute_error: 0.0131 - val_loss: 3.2477e-04 - val_mean_absolute_error: 0.0136
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8963e-04 - mean_absolute_error: 0.0132 - val_loss: 3.3264e-04 - val_mean_absolute_error: 0.0140
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.5737e-04 - mean_absolute_error: 0.0135 - val_loss: 3.1854e-04 - val_mean_absolute_error: 0.0133
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.4335e-04 - mean_absolute_error: 0.0120 - val_loss: 3.2932e-04 - val_mean_absolute_error: 0.0137
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.4775e-04 - mean_absolute_error: 0.0117 - val_loss: 4.6670e-04 - val_mean_absolute_error: 0.0171
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.1609e-04 - mean_absolute_error: 0.0134 - val_loss: 3.6665e-04 - val_mean_absolute_error: 0.0147
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.5767e-04 - mean_absolute_error: 0.0137 - val_loss: 5.4954e-04 - val_mean_absolute_error: 0.0188
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7358e-04 - mean_absolute_error: 0.0129 - val_loss: 3.7441e-04 - val_mean_absolute_error: 0.0149
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2711e-04 - mean_absolute_error: 0.0116 - val_loss: 3.2196e-04 - val_mean_absolute_error: 0.0135
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.6757e-04 - mean_absolute_error: 0.0121 - val_loss: 3.1537e-04 - val_mean_absolute_error: 0.0133
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6115e-04 - mean_absolute_error: 0.0122 - val_loss: 3.1994e-04 - val_mean_absolute_error: 0.0137
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.5508e-04 - mean_absolute_error: 0.0126 - val_loss: 4.1839e-04 - val_mean_absolute_error: 0.0162
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.5579e-04 - mean_absolute_error: 0.0163 - val_loss: 3.3236e-04 - val_mean_absolute_error: 0.0138
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.3401e-04 - mean_absolute_error: 0.0114 - val_loss: 3.1308e-04 - val_mean_absolute_error: 0.0133
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3885e-04 - mean_absolute_error: 0.0118 - val_loss: 3.2915e-04 - val_mean_absolute_error: 0.0137
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1913e-04 - mean_absolute_error: 0.0133 - val_loss: 3.2136e-04 - val_mean_absolute_error: 0.0137
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.2217e-04 - mean_absolute_error: 0.0130 - val_loss: 3.1816e-04 - val_mean_absolute_error: 0.0135
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.3633e-04 - mean_absolute_error: 0.0116 - val_loss: 3.8935e-04 - val_mean_absolute_error: 0.0153
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4696e-04 - mean_absolute_error: 0.0144 - val_loss: 3.9798e-04 - val_mean_absolute_error: 0.0155
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7812e-04 - mean_absolute_error: 0.0121 - val_loss: 3.6950e-04 - val_mean_absolute_error: 0.0148
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.9008e-04 - mean_absolute_error: 0.0128 - val_loss: 3.1541e-04 - val_mean_absolute_error: 0.0134
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7991e-04 - mean_absolute_error: 0.0123 - val_loss: 3.1659e-04 - val_mean_absolute_error: 0.0135
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.2407e-04 - mean_absolute_error: 0.0116 - val_loss: 3.2217e-04 - val_mean_absolute_error: 0.0137
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7839e-04 - mean_absolute_error: 0.0129 - val_loss: 3.2352e-04 - val_mean_absolute_error: 0.0135
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4690e-04 - mean_absolute_error: 0.0136 - val_loss: 3.1834e-04 - val_mean_absolute_error: 0.0134
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7829e-04 - mean_absolute_error: 0.0122 - val_loss: 3.1487e-04 - val_mean_absolute_error: 0.0133
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4409e-04 - mean_absolute_error: 0.0116 - val_loss: 4.0882e-04 - val_mean_absolute_error: 0.0157
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3511e-04 - mean_absolute_error: 0.0133 - val_loss: 4.2235e-04 - val_mean_absolute_error: 0.0160
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.9023e-04 - mean_absolute_error: 0.0129 - val_loss: 4.1406e-04 - val_mean_absolute_error: 0.0158
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.0429e-04 - mean_absolute_error: 0.0137 - val_loss: 3.3321e-04 - val_mean_absolute_error: 0.0138
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.6364e-04 - mean_absolute_error: 0.0121 - val_loss: 3.3981e-04 - val_mean_absolute_error: 0.0143

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 3s 558ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 169007.79657883284
# RMSE: 411.1055783844739
# MAE: 303.06645682893424
# MAPE: 2.7710047213717215 %
#
# Model evalution on validate set
# MSE: 80732.39997377132
# RMSE: 284.1344751588081
# MAE: 194.665834208251
# MAPE: 1.8413415928518657 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 620ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step

# %%
y_pred_30_days
# Out:
# array([[13020.032],
#        [12908.499],
#        [13079.302],
#        [12970.821],
#        [13087.624],
#        [13016.968],
#        [13078.444],
#        [13032.153],
#        [13070.738],
#        [13041.948],
#        [13064.975],
#        [13047.057],
#        [13061.277],
#        [13050.228],
#        [13058.924],
#        [13052.114],
#        [13057.469],
#        [13053.277],
#        [13056.565],
#        [13053.984],
#        [13056.01 ],
#        [13054.423],
#        [13055.669],
#        [13054.69 ],
#        [13055.459],
#        [13054.857],
#        [13055.328],
#        [13054.957],
#        [13055.248],
#        [13055.021],
#        [13055.198]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Forecast Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Forecast the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
