# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: ITD - Test/Train/Vaildation: 60/20/20
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 417.0305220302021
# - MAE: 308.3766554874253
# - MAPE: 2.819663318458329 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 1  # 6 2 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.tail()
# Out:
#             close
# time
# 2024-05-27  11300
# 2024-05-28  12050
# 2024-05-29  12600
# 2024-05-30  12500
# 2024-05-31  12700

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        6900
# 1        7100
# 2        7100
# 3        7170
# 4        7170
#         ...
# 1308    11300
# 1309    12050
# 1310    12600
# 1311    12500
# 1312    12700
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((776, 10), (776,), (251, 10), (251,), (253, 10), (253,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 51ms/step - loss: 0.0286 - mean_absolute_error: 0.1122 - val_loss: 0.0014 - val_mean_absolute_error: 0.0278
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0021 - mean_absolute_error: 0.0309 - val_loss: 0.0016 - val_mean_absolute_error: 0.0319
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0219 - val_loss: 9.1493e-04 - val_mean_absolute_error: 0.0229
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0012 - mean_absolute_error: 0.0211 - val_loss: 7.2152e-04 - val_mean_absolute_error: 0.0198
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0010 - mean_absolute_error: 0.0195 - val_loss: 7.2475e-04 - val_mean_absolute_error: 0.0205
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.3806e-04 - mean_absolute_error: 0.0167 - val_loss: 7.0579e-04 - val_mean_absolute_error: 0.0204
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7195e-04 - mean_absolute_error: 0.0168 - val_loss: 5.9050e-04 - val_mean_absolute_error: 0.0181
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1620e-04 - mean_absolute_error: 0.0168 - val_loss: 6.8378e-04 - val_mean_absolute_error: 0.0205
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.9929e-04 - mean_absolute_error: 0.0178 - val_loss: 8.8207e-04 - val_mean_absolute_error: 0.0243
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.9725e-04 - mean_absolute_error: 0.0165 - val_loss: 4.9245e-04 - val_mean_absolute_error: 0.0161
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.7160e-04 - mean_absolute_error: 0.0175 - val_loss: 5.8164e-04 - val_mean_absolute_error: 0.0183
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.8305e-04 - mean_absolute_error: 0.0148 - val_loss: 5.3367e-04 - val_mean_absolute_error: 0.0174
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.1771e-04 - mean_absolute_error: 0.0155 - val_loss: 7.7203e-04 - val_mean_absolute_error: 0.0224
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.0400e-04 - mean_absolute_error: 0.0181 - val_loss: 4.7717e-04 - val_mean_absolute_error: 0.0160
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.0332e-04 - mean_absolute_error: 0.0169 - val_loss: 4.7092e-04 - val_mean_absolute_error: 0.0159
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.9071e-04 - mean_absolute_error: 0.0175 - val_loss: 7.9731e-04 - val_mean_absolute_error: 0.0230
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9431e-04 - mean_absolute_error: 0.0172 - val_loss: 5.0185e-04 - val_mean_absolute_error: 0.0169
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.0460e-04 - mean_absolute_error: 0.0168 - val_loss: 4.3043e-04 - val_mean_absolute_error: 0.0150
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3107e-04 - mean_absolute_error: 0.0159 - val_loss: 4.1453e-04 - val_mean_absolute_error: 0.0148
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.3185e-04 - mean_absolute_error: 0.0165 - val_loss: 4.0727e-04 - val_mean_absolute_error: 0.0146
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.6655e-04 - mean_absolute_error: 0.0132 - val_loss: 4.3508e-04 - val_mean_absolute_error: 0.0153
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.4839e-04 - mean_absolute_error: 0.0147 - val_loss: 5.2789e-04 - val_mean_absolute_error: 0.0176
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.3558e-04 - mean_absolute_error: 0.0149 - val_loss: 8.2412e-04 - val_mean_absolute_error: 0.0237
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 8.3523e-04 - mean_absolute_error: 0.0192 - val_loss: 0.0011 - val_mean_absolute_error: 0.0281
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.6469e-04 - mean_absolute_error: 0.0153 - val_loss: 4.4564e-04 - val_mean_absolute_error: 0.0156
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.2079e-04 - mean_absolute_error: 0.0137 - val_loss: 3.8636e-04 - val_mean_absolute_error: 0.0142
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.8708e-04 - mean_absolute_error: 0.0136 - val_loss: 4.8833e-04 - val_mean_absolute_error: 0.0171
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3845e-04 - mean_absolute_error: 0.0151 - val_loss: 4.2120e-04 - val_mean_absolute_error: 0.0154
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.3989e-04 - mean_absolute_error: 0.0142 - val_loss: 3.7040e-04 - val_mean_absolute_error: 0.0139
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.1833e-04 - mean_absolute_error: 0.0146 - val_loss: 4.3242e-04 - val_mean_absolute_error: 0.0157
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.5269e-04 - mean_absolute_error: 0.0129 - val_loss: 5.2923e-04 - val_mean_absolute_error: 0.0181
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.6115e-04 - mean_absolute_error: 0.0147 - val_loss: 4.0377e-04 - val_mean_absolute_error: 0.0149
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0745e-04 - mean_absolute_error: 0.0123 - val_loss: 5.5113e-04 - val_mean_absolute_error: 0.0187
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.7247e-04 - mean_absolute_error: 0.0157 - val_loss: 3.6100e-04 - val_mean_absolute_error: 0.0137
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3784e-04 - mean_absolute_error: 0.0125 - val_loss: 4.2506e-04 - val_mean_absolute_error: 0.0157
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.3169e-04 - mean_absolute_error: 0.0140 - val_loss: 4.3677e-04 - val_mean_absolute_error: 0.0159
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.9665e-04 - mean_absolute_error: 0.0137 - val_loss: 6.4229e-04 - val_mean_absolute_error: 0.0206
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.9042e-04 - mean_absolute_error: 0.0142 - val_loss: 4.3721e-04 - val_mean_absolute_error: 0.0160
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.7697e-04 - mean_absolute_error: 0.0131 - val_loss: 3.4399e-04 - val_mean_absolute_error: 0.0134
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4380e-04 - mean_absolute_error: 0.0134 - val_loss: 3.6814e-04 - val_mean_absolute_error: 0.0143
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.3628e-04 - mean_absolute_error: 0.0150 - val_loss: 3.8955e-04 - val_mean_absolute_error: 0.0148
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.6508e-04 - mean_absolute_error: 0.0149 - val_loss: 5.5267e-04 - val_mean_absolute_error: 0.0189
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.1815e-04 - mean_absolute_error: 0.0148 - val_loss: 3.6317e-04 - val_mean_absolute_error: 0.0141
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.2410e-04 - mean_absolute_error: 0.0135 - val_loss: 3.5990e-04 - val_mean_absolute_error: 0.0141
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.3505e-04 - mean_absolute_error: 0.0132 - val_loss: 5.5001e-04 - val_mean_absolute_error: 0.0189
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.7847e-04 - mean_absolute_error: 0.0159 - val_loss: 5.0027e-04 - val_mean_absolute_error: 0.0178
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.5656e-04 - mean_absolute_error: 0.0134 - val_loss: 3.6117e-04 - val_mean_absolute_error: 0.0141
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.6622e-04 - mean_absolute_error: 0.0136 - val_loss: 4.4641e-04 - val_mean_absolute_error: 0.0166
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6101e-04 - mean_absolute_error: 0.0165 - val_loss: 3.9692e-04 - val_mean_absolute_error: 0.0153
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.1178e-04 - mean_absolute_error: 0.0145 - val_loss: 3.3967e-04 - val_mean_absolute_error: 0.0136
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9139e-04 - mean_absolute_error: 0.0124 - val_loss: 3.9600e-04 - val_mean_absolute_error: 0.0152
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1208e-04 - mean_absolute_error: 0.0128 - val_loss: 3.2138e-04 - val_mean_absolute_error: 0.0131
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.3584e-04 - mean_absolute_error: 0.0129 - val_loss: 3.7120e-04 - val_mean_absolute_error: 0.0147
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9869e-04 - mean_absolute_error: 0.0131 - val_loss: 3.3053e-04 - val_mean_absolute_error: 0.0134
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6910e-04 - mean_absolute_error: 0.0119 - val_loss: 3.1814e-04 - val_mean_absolute_error: 0.0131
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.4067e-04 - mean_absolute_error: 0.0130 - val_loss: 3.2478e-04 - val_mean_absolute_error: 0.0134
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.8485e-04 - mean_absolute_error: 0.0124 - val_loss: 3.2342e-04 - val_mean_absolute_error: 0.0131
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.9689e-04 - mean_absolute_error: 0.0146 - val_loss: 4.2710e-04 - val_mean_absolute_error: 0.0161
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0544e-04 - mean_absolute_error: 0.0125 - val_loss: 3.1709e-04 - val_mean_absolute_error: 0.0131
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.9000e-04 - mean_absolute_error: 0.0119 - val_loss: 3.4080e-04 - val_mean_absolute_error: 0.0137
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5631e-04 - mean_absolute_error: 0.0118 - val_loss: 4.1844e-04 - val_mean_absolute_error: 0.0158
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.0150e-04 - mean_absolute_error: 0.0143 - val_loss: 3.8659e-04 - val_mean_absolute_error: 0.0150
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0968e-04 - mean_absolute_error: 0.0129 - val_loss: 4.1840e-04 - val_mean_absolute_error: 0.0159
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.6690e-04 - mean_absolute_error: 0.0124 - val_loss: 4.5834e-04 - val_mean_absolute_error: 0.0169
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.9300e-04 - mean_absolute_error: 0.0141 - val_loss: 5.0638e-04 - val_mean_absolute_error: 0.0180
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0892e-04 - mean_absolute_error: 0.0133 - val_loss: 3.0988e-04 - val_mean_absolute_error: 0.0130
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.6591e-04 - mean_absolute_error: 0.0120 - val_loss: 3.1729e-04 - val_mean_absolute_error: 0.0134
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.1415e-04 - mean_absolute_error: 0.0129 - val_loss: 3.1519e-04 - val_mean_absolute_error: 0.0132
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.1469e-04 - mean_absolute_error: 0.0126 - val_loss: 3.5550e-04 - val_mean_absolute_error: 0.0145
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.1127e-04 - mean_absolute_error: 0.0135 - val_loss: 3.4966e-04 - val_mean_absolute_error: 0.0141
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9365e-04 - mean_absolute_error: 0.0124 - val_loss: 3.6482e-04 - val_mean_absolute_error: 0.0145
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.3152e-04 - mean_absolute_error: 0.0119 - val_loss: 3.2580e-04 - val_mean_absolute_error: 0.0134
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.7184e-04 - mean_absolute_error: 0.0125 - val_loss: 3.5872e-04 - val_mean_absolute_error: 0.0144
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.1632e-04 - mean_absolute_error: 0.0130 - val_loss: 3.0951e-04 - val_mean_absolute_error: 0.0131
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.9457e-04 - mean_absolute_error: 0.0145 - val_loss: 3.1119e-04 - val_mean_absolute_error: 0.0131
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.8552e-04 - mean_absolute_error: 0.0121 - val_loss: 3.2536e-04 - val_mean_absolute_error: 0.0137
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.9507e-04 - mean_absolute_error: 0.0124 - val_loss: 3.4056e-04 - val_mean_absolute_error: 0.0139
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.0785e-04 - mean_absolute_error: 0.0123 - val_loss: 4.1027e-04 - val_mean_absolute_error: 0.0158
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.1790e-04 - mean_absolute_error: 0.0146 - val_loss: 3.0931e-04 - val_mean_absolute_error: 0.0131
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.9692e-04 - mean_absolute_error: 0.0110 - val_loss: 3.2489e-04 - val_mean_absolute_error: 0.0134
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.9809e-04 - mean_absolute_error: 0.0108 - val_loss: 3.6127e-04 - val_mean_absolute_error: 0.0149
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9622e-04 - mean_absolute_error: 0.0129 - val_loss: 3.1675e-04 - val_mean_absolute_error: 0.0135
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3687e-04 - mean_absolute_error: 0.0122 - val_loss: 3.0961e-04 - val_mean_absolute_error: 0.0131
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.8248e-04 - mean_absolute_error: 0.0122 - val_loss: 3.2854e-04 - val_mean_absolute_error: 0.0138
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8748e-04 - mean_absolute_error: 0.0126 - val_loss: 3.2708e-04 - val_mean_absolute_error: 0.0135
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8343e-04 - mean_absolute_error: 0.0126 - val_loss: 5.5302e-04 - val_mean_absolute_error: 0.0189
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4917e-04 - mean_absolute_error: 0.0132 - val_loss: 3.3754e-04 - val_mean_absolute_error: 0.0139
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.6125e-04 - mean_absolute_error: 0.0121 - val_loss: 3.1790e-04 - val_mean_absolute_error: 0.0135
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8456e-04 - mean_absolute_error: 0.0120 - val_loss: 3.3379e-04 - val_mean_absolute_error: 0.0141
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.3695e-04 - mean_absolute_error: 0.0134 - val_loss: 3.8707e-04 - val_mean_absolute_error: 0.0155
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9078e-04 - mean_absolute_error: 0.0128 - val_loss: 3.3272e-04 - val_mean_absolute_error: 0.0140
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.4754e-04 - mean_absolute_error: 0.0135 - val_loss: 3.3577e-04 - val_mean_absolute_error: 0.0138
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.0325e-04 - mean_absolute_error: 0.0129 - val_loss: 3.3530e-04 - val_mean_absolute_error: 0.0138
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7074e-04 - mean_absolute_error: 0.0123 - val_loss: 3.8850e-04 - val_mean_absolute_error: 0.0152
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.2745e-04 - mean_absolute_error: 0.0132 - val_loss: 3.5479e-04 - val_mean_absolute_error: 0.0144
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.8808e-04 - mean_absolute_error: 0.0123 - val_loss: 3.2160e-04 - val_mean_absolute_error: 0.0137
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.9349e-04 - mean_absolute_error: 0.0121 - val_loss: 3.4637e-04 - val_mean_absolute_error: 0.0141
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.4548e-04 - mean_absolute_error: 0.0116 - val_loss: 3.1097e-04 - val_mean_absolute_error: 0.0131
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4406e-04 - mean_absolute_error: 0.0136 - val_loss: 3.3965e-04 - val_mean_absolute_error: 0.0142
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9390e-04 - mean_absolute_error: 0.0122 - val_loss: 3.9335e-04 - val_mean_absolute_error: 0.0154
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.5474e-04 - mean_absolute_error: 0.0143 - val_loss: 3.1676e-04 - val_mean_absolute_error: 0.0136
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.0836e-04 - mean_absolute_error: 0.0125 - val_loss: 3.6094e-04 - val_mean_absolute_error: 0.0146
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5519e-04 - mean_absolute_error: 0.0124 - val_loss: 3.1782e-04 - val_mean_absolute_error: 0.0133
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.2852e-04 - mean_absolute_error: 0.0114 - val_loss: 3.3537e-04 - val_mean_absolute_error: 0.0138
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.6626e-04 - mean_absolute_error: 0.0123 - val_loss: 3.1431e-04 - val_mean_absolute_error: 0.0132
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.9756e-04 - mean_absolute_error: 0.0127 - val_loss: 3.1712e-04 - val_mean_absolute_error: 0.0133
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.9364e-04 - mean_absolute_error: 0.0125 - val_loss: 3.3141e-04 - val_mean_absolute_error: 0.0137
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.4961e-04 - mean_absolute_error: 0.0117 - val_loss: 3.1038e-04 - val_mean_absolute_error: 0.0132
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.7122e-04 - mean_absolute_error: 0.0124 - val_loss: 3.3571e-04 - val_mean_absolute_error: 0.0139
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7194e-04 - mean_absolute_error: 0.0124 - val_loss: 3.1598e-04 - val_mean_absolute_error: 0.0133
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.8681e-04 - mean_absolute_error: 0.0146 - val_loss: 3.4437e-04 - val_mean_absolute_error: 0.0143
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.3758e-04 - mean_absolute_error: 0.0117 - val_loss: 3.4999e-04 - val_mean_absolute_error: 0.0143
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8735e-04 - mean_absolute_error: 0.0125 - val_loss: 3.6678e-04 - val_mean_absolute_error: 0.0149
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3.6701e-04 - mean_absolute_error: 0.0129 - val_loss: 3.1744e-04 - val_mean_absolute_error: 0.0135
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7234e-04 - mean_absolute_error: 0.0125 - val_loss: 3.2621e-04 - val_mean_absolute_error: 0.0136
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.6469e-04 - mean_absolute_error: 0.0124 - val_loss: 3.3995e-04 - val_mean_absolute_error: 0.0142
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5309e-04 - mean_absolute_error: 0.0121 - val_loss: 4.0560e-04 - val_mean_absolute_error: 0.0160
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.1968e-04 - mean_absolute_error: 0.0135 - val_loss: 3.7524e-04 - val_mean_absolute_error: 0.0152
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.0563e-04 - mean_absolute_error: 0.0127 - val_loss: 3.1761e-04 - val_mean_absolute_error: 0.0133
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7757e-04 - mean_absolute_error: 0.0133 - val_loss: 4.5826e-04 - val_mean_absolute_error: 0.0171
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4363e-04 - mean_absolute_error: 0.0142 - val_loss: 3.3210e-04 - val_mean_absolute_error: 0.0140
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7738e-04 - mean_absolute_error: 0.0125 - val_loss: 3.1507e-04 - val_mean_absolute_error: 0.0135
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.8718e-04 - mean_absolute_error: 0.0122 - val_loss: 3.1164e-04 - val_mean_absolute_error: 0.0133
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.6835e-04 - mean_absolute_error: 0.0119 - val_loss: 4.2385e-04 - val_mean_absolute_error: 0.0161
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6480e-04 - mean_absolute_error: 0.0131 - val_loss: 3.4608e-04 - val_mean_absolute_error: 0.0144
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.3401e-04 - mean_absolute_error: 0.0127 - val_loss: 3.1488e-04 - val_mean_absolute_error: 0.0134
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6312e-04 - mean_absolute_error: 0.0124 - val_loss: 3.4917e-04 - val_mean_absolute_error: 0.0142
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.0420e-04 - mean_absolute_error: 0.0133 - val_loss: 3.2163e-04 - val_mean_absolute_error: 0.0137
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.9183e-04 - mean_absolute_error: 0.0127 - val_loss: 3.4338e-04 - val_mean_absolute_error: 0.0143
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.7796e-04 - mean_absolute_error: 0.0121 - val_loss: 4.6078e-04 - val_mean_absolute_error: 0.0172
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.3541e-04 - mean_absolute_error: 0.0141 - val_loss: 3.7024e-04 - val_mean_absolute_error: 0.0150
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.9122e-04 - mean_absolute_error: 0.0126 - val_loss: 3.4016e-04 - val_mean_absolute_error: 0.0142
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.8463e-04 - mean_absolute_error: 0.0136 - val_loss: 3.1413e-04 - val_mean_absolute_error: 0.0133
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9111e-04 - mean_absolute_error: 0.0121 - val_loss: 3.6139e-04 - val_mean_absolute_error: 0.0146
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.4925e-04 - mean_absolute_error: 0.0120 - val_loss: 3.2076e-04 - val_mean_absolute_error: 0.0134
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.6612e-04 - mean_absolute_error: 0.0125 - val_loss: 3.3111e-04 - val_mean_absolute_error: 0.0140
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.5617e-04 - mean_absolute_error: 0.0121 - val_loss: 3.1593e-04 - val_mean_absolute_error: 0.0133
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.0748e-04 - mean_absolute_error: 0.0129 - val_loss: 3.3979e-04 - val_mean_absolute_error: 0.0143
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4093e-04 - mean_absolute_error: 0.0139 - val_loss: 3.1986e-04 - val_mean_absolute_error: 0.0136
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8897e-04 - mean_absolute_error: 0.0127 - val_loss: 3.1799e-04 - val_mean_absolute_error: 0.0134
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.8534e-04 - mean_absolute_error: 0.0125 - val_loss: 3.2210e-04 - val_mean_absolute_error: 0.0135
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6700e-04 - mean_absolute_error: 0.0119 - val_loss: 3.5975e-04 - val_mean_absolute_error: 0.0145
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.7383e-04 - mean_absolute_error: 0.0132 - val_loss: 3.5359e-04 - val_mean_absolute_error: 0.0144
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9744e-04 - mean_absolute_error: 0.0129 - val_loss: 3.1412e-04 - val_mean_absolute_error: 0.0133
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.5936e-04 - mean_absolute_error: 0.0125 - val_loss: 3.1900e-04 - val_mean_absolute_error: 0.0134
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5351e-04 - mean_absolute_error: 0.0122 - val_loss: 3.2462e-04 - val_mean_absolute_error: 0.0135
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.5636e-04 - mean_absolute_error: 0.0122 - val_loss: 3.2177e-04 - val_mean_absolute_error: 0.0134
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.5315e-04 - mean_absolute_error: 0.0121 - val_loss: 3.2984e-04 - val_mean_absolute_error: 0.0139
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6297e-04 - mean_absolute_error: 0.0118 - val_loss: 3.5005e-04 - val_mean_absolute_error: 0.0145
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6076e-04 - mean_absolute_error: 0.0122 - val_loss: 5.4355e-04 - val_mean_absolute_error: 0.0187
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.0898e-04 - mean_absolute_error: 0.0136 - val_loss: 3.6900e-04 - val_mean_absolute_error: 0.0148
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.7970e-04 - mean_absolute_error: 0.0131 - val_loss: 3.4015e-04 - val_mean_absolute_error: 0.0142
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.6875e-04 - mean_absolute_error: 0.0138 - val_loss: 3.2950e-04 - val_mean_absolute_error: 0.0139
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.1677e-04 - mean_absolute_error: 0.0129 - val_loss: 3.1806e-04 - val_mean_absolute_error: 0.0135
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.4140e-04 - mean_absolute_error: 0.0120 - val_loss: 3.6096e-04 - val_mean_absolute_error: 0.0146
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.1846e-04 - mean_absolute_error: 0.0146 - val_loss: 4.4269e-04 - val_mean_absolute_error: 0.0165
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9554e-04 - mean_absolute_error: 0.0137 - val_loss: 4.1427e-04 - val_mean_absolute_error: 0.0159
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.1795e-04 - mean_absolute_error: 0.0136 - val_loss: 3.1798e-04 - val_mean_absolute_error: 0.0135
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4745e-04 - mean_absolute_error: 0.0120 - val_loss: 3.2452e-04 - val_mean_absolute_error: 0.0138
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4492e-04 - mean_absolute_error: 0.0122 - val_loss: 3.2919e-04 - val_mean_absolute_error: 0.0137
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.6171e-04 - mean_absolute_error: 0.0141 - val_loss: 3.1586e-04 - val_mean_absolute_error: 0.0133
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5442e-04 - mean_absolute_error: 0.0119 - val_loss: 4.3464e-04 - val_mean_absolute_error: 0.0166
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6580e-04 - mean_absolute_error: 0.0121 - val_loss: 3.1485e-04 - val_mean_absolute_error: 0.0133
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.0037e-04 - mean_absolute_error: 0.0110 - val_loss: 3.2508e-04 - val_mean_absolute_error: 0.0136
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3005e-04 - mean_absolute_error: 0.0135 - val_loss: 5.1840e-04 - val_mean_absolute_error: 0.0182
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.5547e-04 - mean_absolute_error: 0.0133 - val_loss: 3.6408e-04 - val_mean_absolute_error: 0.0147
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4202e-04 - mean_absolute_error: 0.0122 - val_loss: 3.7046e-04 - val_mean_absolute_error: 0.0148
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7446e-04 - mean_absolute_error: 0.0128 - val_loss: 3.2201e-04 - val_mean_absolute_error: 0.0137
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7976e-04 - mean_absolute_error: 0.0121 - val_loss: 3.1465e-04 - val_mean_absolute_error: 0.0133
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8466e-04 - mean_absolute_error: 0.0130 - val_loss: 3.3859e-04 - val_mean_absolute_error: 0.0142
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6496e-04 - mean_absolute_error: 0.0146 - val_loss: 3.1369e-04 - val_mean_absolute_error: 0.0134
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7821e-04 - mean_absolute_error: 0.0122 - val_loss: 4.7573e-04 - val_mean_absolute_error: 0.0175
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2379e-04 - mean_absolute_error: 0.0137 - val_loss: 4.3115e-04 - val_mean_absolute_error: 0.0162
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4671e-04 - mean_absolute_error: 0.0144 - val_loss: 3.3842e-04 - val_mean_absolute_error: 0.0139
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4400e-04 - mean_absolute_error: 0.0123 - val_loss: 4.2280e-04 - val_mean_absolute_error: 0.0161
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.5859e-04 - mean_absolute_error: 0.0144 - val_loss: 3.6807e-04 - val_mean_absolute_error: 0.0150
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6671e-04 - mean_absolute_error: 0.0127 - val_loss: 3.5990e-04 - val_mean_absolute_error: 0.0145
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8529e-04 - mean_absolute_error: 0.0126 - val_loss: 3.4708e-04 - val_mean_absolute_error: 0.0145
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7317e-04 - mean_absolute_error: 0.0120 - val_loss: 4.1570e-04 - val_mean_absolute_error: 0.0162
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1355e-04 - mean_absolute_error: 0.0138 - val_loss: 3.9645e-04 - val_mean_absolute_error: 0.0155
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6634e-04 - mean_absolute_error: 0.0124 - val_loss: 3.1444e-04 - val_mean_absolute_error: 0.0133
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7190e-04 - mean_absolute_error: 0.0121 - val_loss: 3.9047e-04 - val_mean_absolute_error: 0.0153
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4033e-04 - mean_absolute_error: 0.0122 - val_loss: 3.7627e-04 - val_mean_absolute_error: 0.0153
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5278e-04 - mean_absolute_error: 0.0123 - val_loss: 4.9356e-04 - val_mean_absolute_error: 0.0179
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.8003e-04 - mean_absolute_error: 0.0144 - val_loss: 3.1873e-04 - val_mean_absolute_error: 0.0134
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2744e-04 - mean_absolute_error: 0.0139 - val_loss: 4.0975e-04 - val_mean_absolute_error: 0.0158
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8991e-04 - mean_absolute_error: 0.0124 - val_loss: 3.1945e-04 - val_mean_absolute_error: 0.0136
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3904e-04 - mean_absolute_error: 0.0117 - val_loss: 3.5810e-04 - val_mean_absolute_error: 0.0145
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0782e-04 - mean_absolute_error: 0.0134 - val_loss: 3.1840e-04 - val_mean_absolute_error: 0.0135
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5454e-04 - mean_absolute_error: 0.0119 - val_loss: 4.0140e-04 - val_mean_absolute_error: 0.0156
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3551e-04 - mean_absolute_error: 0.0121 - val_loss: 4.4666e-04 - val_mean_absolute_error: 0.0166
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9460e-04 - mean_absolute_error: 0.0130 - val_loss: 3.8296e-04 - val_mean_absolute_error: 0.0151
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2350e-04 - mean_absolute_error: 0.0144 - val_loss: 3.4328e-04 - val_mean_absolute_error: 0.0141
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7413e-04 - mean_absolute_error: 0.0123 - val_loss: 3.5615e-04 - val_mean_absolute_error: 0.0145
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1889e-04 - mean_absolute_error: 0.0115 - val_loss: 3.1783e-04 - val_mean_absolute_error: 0.0135
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7321e-04 - mean_absolute_error: 0.0123 - val_loss: 3.1897e-04 - val_mean_absolute_error: 0.0136
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0147e-04 - mean_absolute_error: 0.0132 - val_loss: 3.2099e-04 - val_mean_absolute_error: 0.0136
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0156e-04 - mean_absolute_error: 0.0128 - val_loss: 3.2840e-04 - val_mean_absolute_error: 0.0138
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1927e-04 - mean_absolute_error: 0.0129 - val_loss: 3.2902e-04 - val_mean_absolute_error: 0.0139
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4498e-04 - mean_absolute_error: 0.0124 - val_loss: 3.5315e-04 - val_mean_absolute_error: 0.0146

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 173914.45630478289
# RMSE: 417.0305220302021
# MAE: 308.3766554874253
# MAPE: 2.819663318458329 %
#
# Model evalution on validate set
# MSE: 85535.55860823982
# RMSE: 292.464627960784
# MAE: 200.08364470108697
# MAPE: 1.8931713096183456 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 633ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step

# %%
y_pred_30_days
# Out:
# array([[12961.227 ],
#        [12889.869 ],
#        [13040.409 ],
#        [12955.486 ],
#        [13056.185 ],
#        [13002.428 ],
#        [13052.093 ],
#        [13016.658 ],
#        [13047.245 ],
#        [13025.609 ],
#        [13043.048 ],
#        [13029.831 ],
#        [13040.346 ],
#        [13032.377 ],
#        [13038.607 ],
#        [13033.809 ],
#        [13037.552 ],
#        [13034.666 ],
#        [13036.905 ],
#        [13035.176 ],
#        [13036.518 ],
#        [13035.479 ],
#        [13036.281 ],
#        [13035.661 ],
#        [13036.143 ],
#        [13035.7705],
#        [13036.058 ],
#        [13035.836 ],
#        [13036.005 ],
#        [13035.875 ],
#        [13035.978 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Forecast Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Forecast the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
