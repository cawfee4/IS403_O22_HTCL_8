# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Input

plt.style.use('default')

# %% [markdown]
# ## 1. Data preprocessing

# %%
split_type = [0.8,0.7,0.9]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 1 # 70% train, 30% test

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01  19270
# 2019-03-04  19440
# 2019-03-05  19390
# 2019-03-06  19270
# 2019-03-07  19330

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using neural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split] * len(df_scaled))
test_size = len(df_scaled) - train_size

# %%
# Splitting data into train, test set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size:]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test set
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((908, 10), (908,), (383, 10), (383,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
UNITS = 64

# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(UNITS),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 64)             │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,289 (16.75 KB)
#  Trainable params: 4,289 (16.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1258 - mean_absolute_error: 0.2281
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016 - mean_absolute_error: 0.0316
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.5034e-04 - mean_absolute_error: 0.0171
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.2644e-04 - mean_absolute_error: 0.0158
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0873e-04 - mean_absolute_error: 0.0154
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2319e-04 - mean_absolute_error: 0.0141
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3497e-04 - mean_absolute_error: 0.0143
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2382e-04 - mean_absolute_error: 0.0140
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6952e-04 - mean_absolute_error: 0.0131
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0784e-04 - mean_absolute_error: 0.0138
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4798e-04 - mean_absolute_error: 0.0128
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6903e-04 - mean_absolute_error: 0.0131
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0423e-04 - mean_absolute_error: 0.0115
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0086e-04 - mean_absolute_error: 0.0118
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0040e-04 - mean_absolute_error: 0.0116
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6978e-04 - mean_absolute_error: 0.0111
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5725e-04 - mean_absolute_error: 0.0109
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - loss: 2.3374e-04 - mean_absolute_error: 0.0102
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - loss: 2.3243e-04 - mean_absolute_error: 0.0104
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - loss: 2.3950e-04 - mean_absolute_error: 0.0105
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - loss: 2.1555e-04 - mean_absolute_error: 0.0102
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - loss: 2.3556e-04 - mean_absolute_error: 0.0103
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - loss: 2.1558e-04 - mean_absolute_error: 0.0098
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - loss: 2.5952e-04 - mean_absolute_error: 0.0110
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - loss: 2.2017e-04 - mean_absolute_error: 0.0099
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 2.0718e-04 - mean_absolute_error: 0.0099
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - loss: 1.9445e-04 - mean_absolute_error: 0.0095
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2563e-04 - mean_absolute_error: 0.0103
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1108e-04 - mean_absolute_error: 0.0102
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7664e-04 - mean_absolute_error: 0.0091
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - loss: 1.8571e-04 - mean_absolute_error: 0.0090
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - loss: 1.8076e-04 - mean_absolute_error: 0.0093
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 1.6956e-04 - mean_absolute_error: 0.0087
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4523e-04 - mean_absolute_error: 0.0081
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6865e-04 - mean_absolute_error: 0.0087
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7240e-04 - mean_absolute_error: 0.0088
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3982e-04 - mean_absolute_error: 0.0081
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8802e-04 - mean_absolute_error: 0.0094
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2872e-04 - mean_absolute_error: 0.0078
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5051e-04 - mean_absolute_error: 0.0083
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8190e-04 - mean_absolute_error: 0.0091
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9888e-04 - mean_absolute_error: 0.0099
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6494e-04 - mean_absolute_error: 0.0084
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1802e-04 - mean_absolute_error: 0.0097
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3396e-04 - mean_absolute_error: 0.0080
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7079e-04 - mean_absolute_error: 0.0088
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6895e-04 - mean_absolute_error: 0.0088
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2829e-04 - mean_absolute_error: 0.0076
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3859e-04 - mean_absolute_error: 0.0078
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2987e-04 - mean_absolute_error: 0.0077
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1861e-04 - mean_absolute_error: 0.0072
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1748e-04 - mean_absolute_error: 0.0074
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8744e-04 - mean_absolute_error: 0.0093
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0184e-04 - mean_absolute_error: 0.0067
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - loss: 1.2994e-04 - mean_absolute_error: 0.0079
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - loss: 1.3240e-04 - mean_absolute_error: 0.0076
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3468e-04 - mean_absolute_error: 0.0078
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8296e-04 - mean_absolute_error: 0.0089
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1076e-04 - mean_absolute_error: 0.0070
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6986e-04 - mean_absolute_error: 0.0088
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3625e-04 - mean_absolute_error: 0.0080
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0491e-04 - mean_absolute_error: 0.0067
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1707e-04 - mean_absolute_error: 0.0072
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0340e-04 - mean_absolute_error: 0.0065
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0014e-04 - mean_absolute_error: 0.0066
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1750e-04 - mean_absolute_error: 0.0073
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4229e-04 - mean_absolute_error: 0.0078
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7934e-04 - mean_absolute_error: 0.0095
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0428e-04 - mean_absolute_error: 0.0067
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - loss: 1.0969e-04 - mean_absolute_error: 0.0069
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.7821e-05 - mean_absolute_error: 0.0065
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - loss: 1.0569e-04 - mean_absolute_error: 0.0069
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - loss: 1.0232e-04 - mean_absolute_error: 0.0068
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - loss: 1.1509e-04 - mean_absolute_error: 0.0074
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - loss: 1.2884e-04 - mean_absolute_error: 0.0077
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - loss: 1.3490e-04 - mean_absolute_error: 0.0080
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 1.1979e-04 - mean_absolute_error: 0.0070
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 1.0154e-04 - mean_absolute_error: 0.0065
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 1.0129e-04 - mean_absolute_error: 0.0067
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0316e-04 - mean_absolute_error: 0.0067
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - loss: 1.0129e-04 - mean_absolute_error: 0.0066
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0447e-04 - mean_absolute_error: 0.0066
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 1.0754e-04 - mean_absolute_error: 0.0068
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 8.1577e-05 - mean_absolute_error: 0.0061
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0988e-04 - mean_absolute_error: 0.0069
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - loss: 8.8024e-05 - mean_absolute_error: 0.0061
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.2681e-05 - mean_absolute_error: 0.0066
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - loss: 9.7873e-05 - mean_absolute_error: 0.0066
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - loss: 9.5227e-05 - mean_absolute_error: 0.0063
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 1.0101e-04 - mean_absolute_error: 0.0066
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 8.3379e-05 - mean_absolute_error: 0.0060
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 1.0816e-04 - mean_absolute_error: 0.0069
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - loss: 8.4881e-05 - mean_absolute_error: 0.0061
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - loss: 1.1043e-04 - mean_absolute_error: 0.0072
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - loss: 9.8047e-05 - mean_absolute_error: 0.0065
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 1.0451e-04 - mean_absolute_error: 0.0065
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - loss: 8.0216e-05 - mean_absolute_error: 0.0059
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - loss: 1.1632e-04 - mean_absolute_error: 0.0073
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 1.2472e-04 - mean_absolute_error: 0.0079
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - loss: 8.7953e-05 - mean_absolute_error: 0.0062
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - loss: 1.0725e-04 - mean_absolute_error: 0.0065
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - loss: 7.8014e-05 - mean_absolute_error: 0.0057
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 9.6326e-05 - mean_absolute_error: 0.0065
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - loss: 8.4859e-05 - mean_absolute_error: 0.0060
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 9.1624e-05 - mean_absolute_error: 0.0066
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 8.2123e-05 - mean_absolute_error: 0.0057
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 9.7191e-05 - mean_absolute_error: 0.0066
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - loss: 8.6504e-05 - mean_absolute_error: 0.0062
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 7.1267e-05 - mean_absolute_error: 0.0055
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - loss: 1.3785e-04 - mean_absolute_error: 0.0082
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 992us/step - loss: 9.0369e-05 - mean_absolute_error: 0.0063
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - loss: 8.5739e-05 - mean_absolute_error: 0.0062
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - loss: 8.7456e-05 - mean_absolute_error: 0.0061
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.6268e-05 - mean_absolute_error: 0.0065
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.0822e-05 - mean_absolute_error: 0.0064
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 958us/step - loss: 6.6968e-05 - mean_absolute_error: 0.0055
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.5037e-05 - mean_absolute_error: 0.0062
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.9134e-05 - mean_absolute_error: 0.0059
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.8790e-05 - mean_absolute_error: 0.0059
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.1578e-05 - mean_absolute_error: 0.0056
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2420e-04 - mean_absolute_error: 0.0072
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.1912e-05 - mean_absolute_error: 0.0063
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - loss: 8.2212e-05 - mean_absolute_error: 0.0061
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - loss: 1.1484e-04 - mean_absolute_error: 0.0069
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.6306e-05 - mean_absolute_error: 0.0057
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - loss: 1.0230e-04 - mean_absolute_error: 0.0063
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1976e-04 - mean_absolute_error: 0.0076
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.2075e-05 - mean_absolute_error: 0.0060
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2095e-04 - mean_absolute_error: 0.0074
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.3415e-05 - mean_absolute_error: 0.0059
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.6324e-05 - mean_absolute_error: 0.0060
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.8263e-05 - mean_absolute_error: 0.0057
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.1238e-05 - mean_absolute_error: 0.0058
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.7522e-05 - mean_absolute_error: 0.0057
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - loss: 8.5917e-05 - mean_absolute_error: 0.0060
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.3007e-05 - mean_absolute_error: 0.0060
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.6404e-05 - mean_absolute_error: 0.0057
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.1142e-05 - mean_absolute_error: 0.0057
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.2240e-05 - mean_absolute_error: 0.0061
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.7418e-05 - mean_absolute_error: 0.0054
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.2686e-05 - mean_absolute_error: 0.0053
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.0259e-05 - mean_absolute_error: 0.0053
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.3536e-05 - mean_absolute_error: 0.0060
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.4117e-05 - mean_absolute_error: 0.0054
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.8477e-05 - mean_absolute_error: 0.0058
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.0302e-05 - mean_absolute_error: 0.0059
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.0165e-05 - mean_absolute_error: 0.0054
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.9854e-05 - mean_absolute_error: 0.0059
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.6993e-05 - mean_absolute_error: 0.0056
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.0293e-05 - mean_absolute_error: 0.0058
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.6242e-05 - mean_absolute_error: 0.0052
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.4892e-05 - mean_absolute_error: 0.0053
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.2355e-05 - mean_absolute_error: 0.0062
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.6860e-05 - mean_absolute_error: 0.0057
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.9156e-05 - mean_absolute_error: 0.0052
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.0093e-05 - mean_absolute_error: 0.0054
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.9949e-05 - mean_absolute_error: 0.0057
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.0389e-05 - mean_absolute_error: 0.0054
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1093e-04 - mean_absolute_error: 0.0071
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.2919e-05 - mean_absolute_error: 0.0052
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.9776e-05 - mean_absolute_error: 0.0059
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2103e-04 - mean_absolute_error: 0.0073
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.9893e-05 - mean_absolute_error: 0.0059
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.8412e-05 - mean_absolute_error: 0.0060
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.5989e-05 - mean_absolute_error: 0.0060
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.3164e-05 - mean_absolute_error: 0.0062
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.4398e-05 - mean_absolute_error: 0.0055
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - loss: 9.1072e-05 - mean_absolute_error: 0.0064
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 7.4286e-05 - mean_absolute_error: 0.0056
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.4145e-05 - mean_absolute_error: 0.0056
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - loss: 6.1659e-05 - mean_absolute_error: 0.0052
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.3800e-05 - mean_absolute_error: 0.0056
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.9661e-05 - mean_absolute_error: 0.0051
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1599e-04 - mean_absolute_error: 0.0073
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.6903e-05 - mean_absolute_error: 0.0053
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step - loss: 9.5535e-05 - mean_absolute_error: 0.0066
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.7369e-05 - mean_absolute_error: 0.0062
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - loss: 5.8526e-05 - mean_absolute_error: 0.0050
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.1173e-05 - mean_absolute_error: 0.0062
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - loss: 7.2342e-05 - mean_absolute_error: 0.0056
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - loss: 7.5740e-05 - mean_absolute_error: 0.0058
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - loss: 7.2552e-05 - mean_absolute_error: 0.0055
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.4379e-05 - mean_absolute_error: 0.0052
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - loss: 6.8893e-05 - mean_absolute_error: 0.0054
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.4673e-05 - mean_absolute_error: 0.0051
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.7653e-05 - mean_absolute_error: 0.0054
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 6.6074e-05 - mean_absolute_error: 0.0053
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - loss: 8.5754e-05 - mean_absolute_error: 0.0059
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 6.8209e-05 - mean_absolute_error: 0.0055
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 6.5727e-05 - mean_absolute_error: 0.0053
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 9.3296e-05 - mean_absolute_error: 0.0067
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - loss: 8.4488e-05 - mean_absolute_error: 0.0068
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - loss: 6.2441e-05 - mean_absolute_error: 0.0051
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - loss: 7.1862e-05 - mean_absolute_error: 0.0058
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 7.2067e-05 - mean_absolute_error: 0.0055
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 7.0541e-05 - mean_absolute_error: 0.0056
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 5.5969e-05 - mean_absolute_error: 0.0049
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - loss: 7.1363e-05 - mean_absolute_error: 0.0058
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 5.9713e-05 - mean_absolute_error: 0.0049
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.6069e-05 - mean_absolute_error: 0.0058

# %% [markdown]
# ### Predicting with test set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test set again to evaluate, because i shaped the data between 0 to 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 383
# 394

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)
# Out:
# Model evalution on test set
# MSE: 5197674.457694908
# RMSE: 2279.8408842932236
# MAE: 1514.5332286227153
# MAPE: 1.633081287688489 %

# %% [markdown]
# ## 4. Forecast the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(test_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
y_pred_30_days
# Out:
# array([[126517.66 ],
#        [125519.93 ],
#        [125553.99 ],
#        [125016.336],
#        [125161.85 ],
#        [125217.61 ],
#        [125183.086],
#        [125205.875],
#        [125207.695],
#        [125203.41 ],
#        [125205.62 ],
#        [125205.27 ],
#        [125204.87 ],
#        [125205.12 ],
#        [125205.05 ],
#        [125205.02 ],
#        [125205.06 ],
#        [125205.05 ],
#        [125205.04 ],
#        [125205.06 ],
#        [125205.06 ],
#        [125205.05 ],
#        [125205.05 ],
#        [125205.05 ],
#        [125205.05 ],
#        [125205.05 ],
#        [125205.06 ],
#        [125205.05 ],
#        [125205.05 ],
#        [125205.06 ],
#        [125205.05 ]], dtype=float32)

# %% [markdown]
# ### Continue forecast the next 60/90 days

# %%
y_pred_60_days = forecast(test_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
y_pred_90_days = forecast(test_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")

    # Predict test set
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        test_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Next {days} Days",
        linestyle="--",
    )

    plt.title(f"Forecast {stock_name[stock]} Stock Closing Price Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Forecast the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
