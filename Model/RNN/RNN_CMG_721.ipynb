# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: CMG - Test/Train/Vaildation: 70/20/10
# - Dataset: 1252 rows x 7 column (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1024.6240825867706
# - MAE: 723.023560081067
# - MAPE: 2.220558575041821 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 0  # 7 2 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830

# %%
df.shape
# Out:
# (1252, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1247    40000
# 1248    40200
# 1249    40000
# 1250    39950
# 1251    41200
# Name: close, Length: 1252, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((865, 10), (865,), (239, 10), (239,), (115, 10), (115,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.0639 - mean_absolute_error: 0.1773 - val_loss: 0.0027 - val_mean_absolute_error: 0.0392
# Epoch 2/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - mean_absolute_error: 0.0282 - val_loss: 0.0021 - val_mean_absolute_error: 0.0338
# Epoch 3/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - mean_absolute_error: 0.0244 - val_loss: 0.0017 - val_mean_absolute_error: 0.0302
# Epoch 4/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.9704e-04 - mean_absolute_error: 0.0233 - val_loss: 0.0015 - val_mean_absolute_error: 0.0282
# Epoch 5/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4153e-04 - mean_absolute_error: 0.0205 - val_loss: 0.0013 - val_mean_absolute_error: 0.0262
# Epoch 6/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4610e-04 - mean_absolute_error: 0.0186 - val_loss: 0.0010 - val_mean_absolute_error: 0.0228
# Epoch 7/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6474e-04 - mean_absolute_error: 0.0172 - val_loss: 0.0011 - val_mean_absolute_error: 0.0247
# Epoch 8/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3688e-04 - mean_absolute_error: 0.0168 - val_loss: 8.5847e-04 - val_mean_absolute_error: 0.0210
# Epoch 9/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1033e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0011 - val_mean_absolute_error: 0.0263
# Epoch 10/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3578e-04 - mean_absolute_error: 0.0168 - val_loss: 6.9196e-04 - val_mean_absolute_error: 0.0177
# Epoch 11/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1216e-04 - mean_absolute_error: 0.0164 - val_loss: 7.3646e-04 - val_mean_absolute_error: 0.0186
# Epoch 12/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0323e-04 - mean_absolute_error: 0.0158 - val_loss: 7.0471e-04 - val_mean_absolute_error: 0.0183
# Epoch 13/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1659e-04 - mean_absolute_error: 0.0143 - val_loss: 6.5310e-04 - val_mean_absolute_error: 0.0172
# Epoch 14/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2825e-04 - mean_absolute_error: 0.0146 - val_loss: 7.8754e-04 - val_mean_absolute_error: 0.0201
# Epoch 15/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6177e-04 - mean_absolute_error: 0.0155 - val_loss: 7.3336e-04 - val_mean_absolute_error: 0.0192
# Epoch 16/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9203e-04 - mean_absolute_error: 0.0159 - val_loss: 6.1032e-04 - val_mean_absolute_error: 0.0164
# Epoch 17/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9780e-04 - mean_absolute_error: 0.0141 - val_loss: 8.3071e-04 - val_mean_absolute_error: 0.0226
# Epoch 18/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3462e-04 - mean_absolute_error: 0.0145 - val_loss: 9.4844e-04 - val_mean_absolute_error: 0.0238
# Epoch 19/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7035e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0011 - val_mean_absolute_error: 0.0285
# Epoch 20/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.1464e-04 - mean_absolute_error: 0.0159 - val_loss: 7.7080e-04 - val_mean_absolute_error: 0.0213
# Epoch 21/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.5492e-04 - mean_absolute_error: 0.0146 - val_loss: 5.9046e-04 - val_mean_absolute_error: 0.0162
# Epoch 22/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4083e-04 - mean_absolute_error: 0.0141 - val_loss: 7.1101e-04 - val_mean_absolute_error: 0.0200
# Epoch 23/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.9853e-04 - mean_absolute_error: 0.0155 - val_loss: 0.0021 - val_mean_absolute_error: 0.0419
# Epoch 24/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4270e-04 - mean_absolute_error: 0.0175 - val_loss: 5.8373e-04 - val_mean_absolute_error: 0.0160
# Epoch 25/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6338e-04 - mean_absolute_error: 0.0145 - val_loss: 5.9156e-04 - val_mean_absolute_error: 0.0161
# Epoch 26/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9712e-04 - mean_absolute_error: 0.0137 - val_loss: 6.2882e-04 - val_mean_absolute_error: 0.0169
# Epoch 27/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0879e-04 - mean_absolute_error: 0.0138 - val_loss: 6.0203e-04 - val_mean_absolute_error: 0.0172
# Epoch 28/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9796e-04 - mean_absolute_error: 0.0135 - val_loss: 8.0567e-04 - val_mean_absolute_error: 0.0211
# Epoch 29/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6590e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0011 - val_mean_absolute_error: 0.0272
# Epoch 30/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7951e-04 - mean_absolute_error: 0.0152 - val_loss: 6.8646e-04 - val_mean_absolute_error: 0.0183
# Epoch 31/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1186e-04 - mean_absolute_error: 0.0143 - val_loss: 5.6969e-04 - val_mean_absolute_error: 0.0162
# Epoch 32/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8741e-04 - mean_absolute_error: 0.0137 - val_loss: 5.6702e-04 - val_mean_absolute_error: 0.0161
# Epoch 33/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1819e-04 - mean_absolute_error: 0.0143 - val_loss: 6.1884e-04 - val_mean_absolute_error: 0.0179
# Epoch 34/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6982e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0026 - val_mean_absolute_error: 0.0469
# Epoch 35/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - mean_absolute_error: 0.0242 - val_loss: 0.0020 - val_mean_absolute_error: 0.0387
# Epoch 36/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4083e-04 - mean_absolute_error: 0.0170 - val_loss: 5.8178e-04 - val_mean_absolute_error: 0.0158
# Epoch 37/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.5405e-04 - mean_absolute_error: 0.0148 - val_loss: 5.9633e-04 - val_mean_absolute_error: 0.0175
# Epoch 38/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7116e-04 - mean_absolute_error: 0.0135 - val_loss: 7.3711e-04 - val_mean_absolute_error: 0.0197
# Epoch 39/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.8939e-04 - mean_absolute_error: 0.0175 - val_loss: 5.6525e-04 - val_mean_absolute_error: 0.0165
# Epoch 40/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5578e-04 - mean_absolute_error: 0.0128 - val_loss: 6.0283e-04 - val_mean_absolute_error: 0.0165
# Epoch 41/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5681e-04 - mean_absolute_error: 0.0130 - val_loss: 6.0886e-04 - val_mean_absolute_error: 0.0182
# Epoch 42/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4152e-04 - mean_absolute_error: 0.0126 - val_loss: 6.2892e-04 - val_mean_absolute_error: 0.0173
# Epoch 43/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9998e-04 - mean_absolute_error: 0.0139 - val_loss: 5.4911e-04 - val_mean_absolute_error: 0.0155
# Epoch 44/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.2786e-04 - mean_absolute_error: 0.0140 - val_loss: 5.3462e-04 - val_mean_absolute_error: 0.0159
# Epoch 45/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9617e-04 - mean_absolute_error: 0.0121 - val_loss: 7.6818e-04 - val_mean_absolute_error: 0.0225
# Epoch 46/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1636e-04 - mean_absolute_error: 0.0138 - val_loss: 5.9494e-04 - val_mean_absolute_error: 0.0167
# Epoch 47/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0338e-04 - mean_absolute_error: 0.0138 - val_loss: 5.6450e-04 - val_mean_absolute_error: 0.0170
# Epoch 48/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9589e-04 - mean_absolute_error: 0.0118 - val_loss: 5.4801e-04 - val_mean_absolute_error: 0.0166
# Epoch 49/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3360e-04 - mean_absolute_error: 0.0126 - val_loss: 5.4486e-04 - val_mean_absolute_error: 0.0156
# Epoch 50/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3718e-04 - mean_absolute_error: 0.0131 - val_loss: 5.2717e-04 - val_mean_absolute_error: 0.0152
# Epoch 51/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.3939e-04 - mean_absolute_error: 0.0126 - val_loss: 5.4909e-04 - val_mean_absolute_error: 0.0167
# Epoch 52/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5411e-04 - mean_absolute_error: 0.0133 - val_loss: 5.3682e-04 - val_mean_absolute_error: 0.0162
# Epoch 53/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6114e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0012 - val_mean_absolute_error: 0.0285
# Epoch 54/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3009e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0023 - val_mean_absolute_error: 0.0428
# Epoch 55/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0014 - mean_absolute_error: 0.0279 - val_loss: 5.6491e-04 - val_mean_absolute_error: 0.0161
# Epoch 56/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8598e-04 - mean_absolute_error: 0.0140 - val_loss: 7.4059e-04 - val_mean_absolute_error: 0.0219
# Epoch 57/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7643e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0012 - val_mean_absolute_error: 0.0287
# Epoch 58/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2145e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0029 - val_mean_absolute_error: 0.0490
# Epoch 59/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - mean_absolute_error: 0.0252 - val_loss: 5.6423e-04 - val_mean_absolute_error: 0.0175
# Epoch 60/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9027e-04 - mean_absolute_error: 0.0139 - val_loss: 5.4542e-04 - val_mean_absolute_error: 0.0161
# Epoch 61/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.0648e-04 - mean_absolute_error: 0.0123 - val_loss: 6.4182e-04 - val_mean_absolute_error: 0.0199
# Epoch 62/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1032e-04 - mean_absolute_error: 0.0138 - val_loss: 5.2341e-04 - val_mean_absolute_error: 0.0159
# Epoch 63/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7125e-04 - mean_absolute_error: 0.0133 - val_loss: 6.3833e-04 - val_mean_absolute_error: 0.0196
# Epoch 64/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8374e-04 - mean_absolute_error: 0.0137 - val_loss: 5.9910e-04 - val_mean_absolute_error: 0.0186
# Epoch 65/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9115e-04 - mean_absolute_error: 0.0133 - val_loss: 7.2309e-04 - val_mean_absolute_error: 0.0218
# Epoch 66/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4179e-04 - mean_absolute_error: 0.0128 - val_loss: 5.0135e-04 - val_mean_absolute_error: 0.0152
# Epoch 67/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1524e-04 - mean_absolute_error: 0.0119 - val_loss: 6.8850e-04 - val_mean_absolute_error: 0.0194
# Epoch 68/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6180e-04 - mean_absolute_error: 0.0136 - val_loss: 5.2692e-04 - val_mean_absolute_error: 0.0158
# Epoch 69/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2126e-04 - mean_absolute_error: 0.0124 - val_loss: 5.5394e-04 - val_mean_absolute_error: 0.0172
# Epoch 70/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9337e-04 - mean_absolute_error: 0.0118 - val_loss: 6.5267e-04 - val_mean_absolute_error: 0.0200
# Epoch 71/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9225e-04 - mean_absolute_error: 0.0137 - val_loss: 6.5747e-04 - val_mean_absolute_error: 0.0201
# Epoch 72/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5530e-04 - mean_absolute_error: 0.0125 - val_loss: 5.0326e-04 - val_mean_absolute_error: 0.0153
# Epoch 73/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0893e-04 - mean_absolute_error: 0.0124 - val_loss: 9.5622e-04 - val_mean_absolute_error: 0.0265
# Epoch 74/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.8327e-04 - mean_absolute_error: 0.0161 - val_loss: 6.3954e-04 - val_mean_absolute_error: 0.0196
# Epoch 75/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2826e-04 - mean_absolute_error: 0.0131 - val_loss: 5.0752e-04 - val_mean_absolute_error: 0.0154
# Epoch 76/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1566e-04 - mean_absolute_error: 0.0124 - val_loss: 5.4061e-04 - val_mean_absolute_error: 0.0163
# Epoch 77/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2792e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0011 - val_mean_absolute_error: 0.0274
# Epoch 78/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4648e-04 - mean_absolute_error: 0.0131 - val_loss: 6.2832e-04 - val_mean_absolute_error: 0.0194
# Epoch 79/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8064e-04 - mean_absolute_error: 0.0174 - val_loss: 5.8038e-04 - val_mean_absolute_error: 0.0173
# Epoch 80/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.2477e-04 - mean_absolute_error: 0.0150 - val_loss: 5.5380e-04 - val_mean_absolute_error: 0.0166
# Epoch 81/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0629e-04 - mean_absolute_error: 0.0123 - val_loss: 5.0734e-04 - val_mean_absolute_error: 0.0154
# Epoch 82/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3816e-04 - mean_absolute_error: 0.0124 - val_loss: 5.2729e-04 - val_mean_absolute_error: 0.0160
# Epoch 83/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0897e-04 - mean_absolute_error: 0.0119 - val_loss: 5.0441e-04 - val_mean_absolute_error: 0.0154
# Epoch 84/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9809e-04 - mean_absolute_error: 0.0117 - val_loss: 5.4233e-04 - val_mean_absolute_error: 0.0167
# Epoch 85/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1587e-04 - mean_absolute_error: 0.0141 - val_loss: 7.2057e-04 - val_mean_absolute_error: 0.0217
# Epoch 86/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0524e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0010 - val_mean_absolute_error: 0.0273
# Epoch 87/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5212e-04 - mean_absolute_error: 0.0151 - val_loss: 7.5187e-04 - val_mean_absolute_error: 0.0224
# Epoch 88/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6597e-04 - mean_absolute_error: 0.0131 - val_loss: 5.1574e-04 - val_mean_absolute_error: 0.0157
# Epoch 89/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4092e-04 - mean_absolute_error: 0.0148 - val_loss: 5.0811e-04 - val_mean_absolute_error: 0.0155
# Epoch 90/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0545e-04 - mean_absolute_error: 0.0119 - val_loss: 5.1881e-04 - val_mean_absolute_error: 0.0158
# Epoch 91/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2029e-04 - mean_absolute_error: 0.0123 - val_loss: 6.2176e-04 - val_mean_absolute_error: 0.0183
# Epoch 92/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7682e-04 - mean_absolute_error: 0.0114 - val_loss: 5.3337e-04 - val_mean_absolute_error: 0.0164
# Epoch 93/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1059e-04 - mean_absolute_error: 0.0123 - val_loss: 5.0555e-04 - val_mean_absolute_error: 0.0155
# Epoch 94/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8565e-04 - mean_absolute_error: 0.0118 - val_loss: 5.6045e-04 - val_mean_absolute_error: 0.0173
# Epoch 95/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8394e-04 - mean_absolute_error: 0.0117 - val_loss: 7.7999e-04 - val_mean_absolute_error: 0.0230
# Epoch 96/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3641e-04 - mean_absolute_error: 0.0167 - val_loss: 8.3368e-04 - val_mean_absolute_error: 0.0240
# Epoch 97/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.1071e-04 - mean_absolute_error: 0.0147 - val_loss: 5.7246e-04 - val_mean_absolute_error: 0.0176
# Epoch 98/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7254e-04 - mean_absolute_error: 0.0134 - val_loss: 6.0592e-04 - val_mean_absolute_error: 0.0186
# Epoch 99/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1739e-04 - mean_absolute_error: 0.0124 - val_loss: 7.4454e-04 - val_mean_absolute_error: 0.0222
# Epoch 100/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7022e-04 - mean_absolute_error: 0.0132 - val_loss: 5.1392e-04 - val_mean_absolute_error: 0.0159
# Epoch 101/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6099e-04 - mean_absolute_error: 0.0139 - val_loss: 5.1150e-04 - val_mean_absolute_error: 0.0157
# Epoch 102/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7777e-04 - mean_absolute_error: 0.0116 - val_loss: 6.2029e-04 - val_mean_absolute_error: 0.0185
# Epoch 103/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2960e-04 - mean_absolute_error: 0.0124 - val_loss: 5.6413e-04 - val_mean_absolute_error: 0.0172
# Epoch 104/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0511e-04 - mean_absolute_error: 0.0121 - val_loss: 5.8935e-04 - val_mean_absolute_error: 0.0178
# Epoch 105/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4708e-04 - mean_absolute_error: 0.0135 - val_loss: 5.6878e-04 - val_mean_absolute_error: 0.0174
# Epoch 106/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0536e-04 - mean_absolute_error: 0.0125 - val_loss: 5.4956e-04 - val_mean_absolute_error: 0.0168
# Epoch 107/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9001e-04 - mean_absolute_error: 0.0117 - val_loss: 5.7031e-04 - val_mean_absolute_error: 0.0174
# Epoch 108/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5700e-04 - mean_absolute_error: 0.0112 - val_loss: 5.3451e-04 - val_mean_absolute_error: 0.0164
# Epoch 109/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3813e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0014 - val_mean_absolute_error: 0.0326
# Epoch 110/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6207e-04 - mean_absolute_error: 0.0187 - val_loss: 6.2279e-04 - val_mean_absolute_error: 0.0190
# Epoch 111/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1963e-04 - mean_absolute_error: 0.0128 - val_loss: 5.2210e-04 - val_mean_absolute_error: 0.0160
# Epoch 112/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1212e-04 - mean_absolute_error: 0.0116 - val_loss: 5.1690e-04 - val_mean_absolute_error: 0.0158
# Epoch 113/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9138e-04 - mean_absolute_error: 0.0115 - val_loss: 7.5625e-04 - val_mean_absolute_error: 0.0223
# Epoch 114/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9278e-04 - mean_absolute_error: 0.0139 - val_loss: 5.1184e-04 - val_mean_absolute_error: 0.0156
# Epoch 115/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8060e-04 - mean_absolute_error: 0.0115 - val_loss: 5.2455e-04 - val_mean_absolute_error: 0.0160
# Epoch 116/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6219e-04 - mean_absolute_error: 0.0111 - val_loss: 5.5522e-04 - val_mean_absolute_error: 0.0169
# Epoch 117/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1768e-04 - mean_absolute_error: 0.0125 - val_loss: 5.1829e-04 - val_mean_absolute_error: 0.0158
# Epoch 118/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.8250e-04 - mean_absolute_error: 0.0121 - val_loss: 5.2716e-04 - val_mean_absolute_error: 0.0161
# Epoch 119/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9308e-04 - mean_absolute_error: 0.0119 - val_loss: 6.1005e-04 - val_mean_absolute_error: 0.0182
# Epoch 120/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3400e-04 - mean_absolute_error: 0.0129 - val_loss: 5.6291e-04 - val_mean_absolute_error: 0.0171
# Epoch 121/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5799e-04 - mean_absolute_error: 0.0111 - val_loss: 5.1779e-04 - val_mean_absolute_error: 0.0157
# Epoch 122/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4852e-04 - mean_absolute_error: 0.0107 - val_loss: 5.8439e-04 - val_mean_absolute_error: 0.0175
# Epoch 123/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2574e-04 - mean_absolute_error: 0.0123 - val_loss: 5.1509e-04 - val_mean_absolute_error: 0.0157
# Epoch 124/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0747e-04 - mean_absolute_error: 0.0119 - val_loss: 5.1523e-04 - val_mean_absolute_error: 0.0157
# Epoch 125/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0169e-04 - mean_absolute_error: 0.0118 - val_loss: 5.5964e-04 - val_mean_absolute_error: 0.0171
# Epoch 126/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2755e-04 - mean_absolute_error: 0.0120 - val_loss: 8.3122e-04 - val_mean_absolute_error: 0.0237
# Epoch 127/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9723e-04 - mean_absolute_error: 0.0160 - val_loss: 0.0012 - val_mean_absolute_error: 0.0283
# Epoch 128/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.4653e-04 - mean_absolute_error: 0.0237 - val_loss: 0.0016 - val_mean_absolute_error: 0.0344
# Epoch 129/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2034e-04 - mean_absolute_error: 0.0150 - val_loss: 6.3340e-04 - val_mean_absolute_error: 0.0192
# Epoch 130/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7400e-04 - mean_absolute_error: 0.0174 - val_loss: 5.5073e-04 - val_mean_absolute_error: 0.0168
# Epoch 131/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6412e-04 - mean_absolute_error: 0.0134 - val_loss: 5.4469e-04 - val_mean_absolute_error: 0.0166
# Epoch 132/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2930e-04 - mean_absolute_error: 0.0129 - val_loss: 6.2216e-04 - val_mean_absolute_error: 0.0187
# Epoch 133/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3010e-04 - mean_absolute_error: 0.0128 - val_loss: 5.2916e-04 - val_mean_absolute_error: 0.0160
# Epoch 134/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4423e-04 - mean_absolute_error: 0.0126 - val_loss: 5.3126e-04 - val_mean_absolute_error: 0.0161
# Epoch 135/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8151e-04 - mean_absolute_error: 0.0114 - val_loss: 5.4746e-04 - val_mean_absolute_error: 0.0165
# Epoch 136/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8613e-04 - mean_absolute_error: 0.0116 - val_loss: 5.3634e-04 - val_mean_absolute_error: 0.0162
# Epoch 137/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5762e-04 - mean_absolute_error: 0.0127 - val_loss: 5.7571e-04 - val_mean_absolute_error: 0.0173
# Epoch 138/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0122e-04 - mean_absolute_error: 0.0116 - val_loss: 5.8969e-04 - val_mean_absolute_error: 0.0176
# Epoch 139/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1058e-04 - mean_absolute_error: 0.0122 - val_loss: 7.7388e-04 - val_mean_absolute_error: 0.0225
# Epoch 140/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5555e-04 - mean_absolute_error: 0.0137 - val_loss: 5.6175e-04 - val_mean_absolute_error: 0.0169
# Epoch 141/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6157e-04 - mean_absolute_error: 0.0113 - val_loss: 5.8077e-04 - val_mean_absolute_error: 0.0174
# Epoch 142/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0179e-04 - mean_absolute_error: 0.0121 - val_loss: 5.3408e-04 - val_mean_absolute_error: 0.0162
# Epoch 143/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6633e-04 - mean_absolute_error: 0.0111 - val_loss: 8.3648e-04 - val_mean_absolute_error: 0.0229
# Epoch 144/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3962e-04 - mean_absolute_error: 0.0136 - val_loss: 5.4303e-04 - val_mean_absolute_error: 0.0165
# Epoch 145/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3155e-04 - mean_absolute_error: 0.0127 - val_loss: 5.5335e-04 - val_mean_absolute_error: 0.0168
# Epoch 146/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9923e-04 - mean_absolute_error: 0.0120 - val_loss: 5.2240e-04 - val_mean_absolute_error: 0.0159
# Epoch 147/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5771e-04 - mean_absolute_error: 0.0133 - val_loss: 5.4466e-04 - val_mean_absolute_error: 0.0165
# Epoch 148/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2308e-04 - mean_absolute_error: 0.0124 - val_loss: 5.7519e-04 - val_mean_absolute_error: 0.0174
# Epoch 149/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1216e-04 - mean_absolute_error: 0.0122 - val_loss: 5.3061e-04 - val_mean_absolute_error: 0.0159
# Epoch 150/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9853e-04 - mean_absolute_error: 0.0122 - val_loss: 8.4450e-04 - val_mean_absolute_error: 0.0231
# Epoch 151/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5988e-04 - mean_absolute_error: 0.0137 - val_loss: 6.3774e-04 - val_mean_absolute_error: 0.0189
# Epoch 152/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4886e-04 - mean_absolute_error: 0.0129 - val_loss: 5.4635e-04 - val_mean_absolute_error: 0.0164
# Epoch 153/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0824e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0012 - val_mean_absolute_error: 0.0296
# Epoch 154/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5569e-04 - mean_absolute_error: 0.0155 - val_loss: 5.7683e-04 - val_mean_absolute_error: 0.0174
# Epoch 155/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1705e-04 - mean_absolute_error: 0.0125 - val_loss: 5.2908e-04 - val_mean_absolute_error: 0.0159
# Epoch 156/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1706e-04 - mean_absolute_error: 0.0121 - val_loss: 5.5014e-04 - val_mean_absolute_error: 0.0166
# Epoch 157/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0374e-04 - mean_absolute_error: 0.0122 - val_loss: 5.7590e-04 - val_mean_absolute_error: 0.0174
# Epoch 158/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5447e-04 - mean_absolute_error: 0.0129 - val_loss: 5.4577e-04 - val_mean_absolute_error: 0.0166
# Epoch 159/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8002e-04 - mean_absolute_error: 0.0118 - val_loss: 5.7143e-04 - val_mean_absolute_error: 0.0172
# Epoch 160/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9062e-04 - mean_absolute_error: 0.0118 - val_loss: 6.2735e-04 - val_mean_absolute_error: 0.0186
# Epoch 161/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9888e-04 - mean_absolute_error: 0.0122 - val_loss: 6.3597e-04 - val_mean_absolute_error: 0.0192
# Epoch 162/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9837e-04 - mean_absolute_error: 0.0120 - val_loss: 5.8005e-04 - val_mean_absolute_error: 0.0175
# Epoch 163/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2797e-04 - mean_absolute_error: 0.0125 - val_loss: 6.9406e-04 - val_mean_absolute_error: 0.0207
# Epoch 164/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1623e-04 - mean_absolute_error: 0.0124 - val_loss: 5.5223e-04 - val_mean_absolute_error: 0.0166
# Epoch 165/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.0192e-04 - mean_absolute_error: 0.0119 - val_loss: 5.2428e-04 - val_mean_absolute_error: 0.0160
# Epoch 166/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3700e-04 - mean_absolute_error: 0.0125 - val_loss: 6.9218e-04 - val_mean_absolute_error: 0.0206
# Epoch 167/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5732e-04 - mean_absolute_error: 0.0132 - val_loss: 5.5964e-04 - val_mean_absolute_error: 0.0169
# Epoch 168/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.9954e-04 - mean_absolute_error: 0.0116 - val_loss: 5.5106e-04 - val_mean_absolute_error: 0.0166
# Epoch 169/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3652e-04 - mean_absolute_error: 0.0128 - val_loss: 5.7659e-04 - val_mean_absolute_error: 0.0174
# Epoch 170/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9762e-04 - mean_absolute_error: 0.0120 - val_loss: 5.2796e-04 - val_mean_absolute_error: 0.0160
# Epoch 171/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0747e-04 - mean_absolute_error: 0.0123 - val_loss: 5.9392e-04 - val_mean_absolute_error: 0.0178
# Epoch 172/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7490e-04 - mean_absolute_error: 0.0114 - val_loss: 5.3481e-04 - val_mean_absolute_error: 0.0162
# Epoch 173/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8315e-04 - mean_absolute_error: 0.0114 - val_loss: 5.2811e-04 - val_mean_absolute_error: 0.0159
# Epoch 174/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8053e-04 - mean_absolute_error: 0.0112 - val_loss: 5.7872e-04 - val_mean_absolute_error: 0.0175
# Epoch 175/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9292e-04 - mean_absolute_error: 0.0121 - val_loss: 7.0552e-04 - val_mean_absolute_error: 0.0209
# Epoch 176/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2142e-04 - mean_absolute_error: 0.0121 - val_loss: 5.3495e-04 - val_mean_absolute_error: 0.0162
# Epoch 177/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9306e-04 - mean_absolute_error: 0.0120 - val_loss: 5.5241e-04 - val_mean_absolute_error: 0.0166
# Epoch 178/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0869e-04 - mean_absolute_error: 0.0120 - val_loss: 6.5286e-04 - val_mean_absolute_error: 0.0192
# Epoch 179/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8939e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0012 - val_mean_absolute_error: 0.0287
# Epoch 180/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3335e-04 - mean_absolute_error: 0.0145 - val_loss: 5.3586e-04 - val_mean_absolute_error: 0.0161
# Epoch 181/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.1082e-04 - mean_absolute_error: 0.0123 - val_loss: 7.8476e-04 - val_mean_absolute_error: 0.0226
# Epoch 182/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3167e-04 - mean_absolute_error: 0.0132 - val_loss: 5.3304e-04 - val_mean_absolute_error: 0.0160
# Epoch 183/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8591e-04 - mean_absolute_error: 0.0119 - val_loss: 5.4578e-04 - val_mean_absolute_error: 0.0165
# Epoch 184/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9003e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0012 - val_mean_absolute_error: 0.0301
# Epoch 185/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0209e-04 - mean_absolute_error: 0.0136 - val_loss: 5.2776e-04 - val_mean_absolute_error: 0.0159
# Epoch 186/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.6642e-04 - mean_absolute_error: 0.0134 - val_loss: 5.4370e-04 - val_mean_absolute_error: 0.0165
# Epoch 187/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.3322e-04 - mean_absolute_error: 0.0129 - val_loss: 5.5198e-04 - val_mean_absolute_error: 0.0167
# Epoch 188/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9673e-04 - mean_absolute_error: 0.0120 - val_loss: 9.5990e-04 - val_mean_absolute_error: 0.0261
# Epoch 189/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6269e-04 - mean_absolute_error: 0.0148 - val_loss: 6.3489e-04 - val_mean_absolute_error: 0.0191
# Epoch 190/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2805e-04 - mean_absolute_error: 0.0127 - val_loss: 5.2681e-04 - val_mean_absolute_error: 0.0160
# Epoch 191/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7935e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0011 - val_mean_absolute_error: 0.0280
# Epoch 192/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9352e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0015 - val_mean_absolute_error: 0.0328
# Epoch 193/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.7158e-04 - mean_absolute_error: 0.0218 - val_loss: 0.0015 - val_mean_absolute_error: 0.0332
# Epoch 194/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3820e-04 - mean_absolute_error: 0.0190 - val_loss: 6.5527e-04 - val_mean_absolute_error: 0.0193
# Epoch 195/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.0923e-04 - mean_absolute_error: 0.0125 - val_loss: 5.5510e-04 - val_mean_absolute_error: 0.0164
# Epoch 196/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.8855e-04 - mean_absolute_error: 0.0115 - val_loss: 5.5702e-04 - val_mean_absolute_error: 0.0166
# Epoch 197/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5488e-04 - mean_absolute_error: 0.0125 - val_loss: 5.4302e-04 - val_mean_absolute_error: 0.0163
# Epoch 198/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8544e-04 - mean_absolute_error: 0.0116 - val_loss: 5.4156e-04 - val_mean_absolute_error: 0.0162
# Epoch 199/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7441e-04 - mean_absolute_error: 0.0113 - val_loss: 5.5826e-04 - val_mean_absolute_error: 0.0168
# Epoch 200/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0749e-04 - mean_absolute_error: 0.0121 - val_loss: 5.6866e-04 - val_mean_absolute_error: 0.0170

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 239
# 250

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 1049854.5106167814
# RMSE: 1024.6240825867706
# MAE: 723.023560081067
# MAPE: 2.220558575041821 %
#
# Model evalution on validate set
# MSE: 818505.7431332795
# RMSE: 904.7130722683737
# MAE: 680.991304347826
# MAPE: 1.7454569374106974 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
y_pred_30_days
# Out:
# array([[41331.965],
#        [40993.305],
#        [41142.68 ],
#        [41210.152],
#        [41121.22 ],
#        [41170.156],
#        [41154.633],
#        [41150.535],
#        [41158.19 ],
#        [41153.082],
#        [41154.875],
#        [41155.01 ],
#        [41154.35 ],
#        [41154.84 ],
#        [41154.645],
#        [41154.652],
#        [41154.71 ],
#        [41154.664],
#        [41154.684],
#        [41154.684],
#        [41154.684],
#        [41154.68 ],
#        [41154.684],
#        [41154.684],
#        [41154.68 ],
#        [41154.68 ],
#        [41154.684],
#        [41154.688],
#        [41154.68 ],
#        [41154.68 ],
#        [41154.684]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Predict the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
