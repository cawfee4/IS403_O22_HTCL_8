# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: CMG - Test/Train/Vaildation: 70/20/10
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 769.9537457314558
# - MAE: 556.3831704432271
# - MAPE: 1.6583823228466334 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 0  # 7 2 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.tail()
# Out:
#             close
# time
# 2024-05-27  59000
# 2024-05-28  62100
# 2024-05-29  60000
# 2024-05-30  59200
# 2024-05-31  60900

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((908, 10), (908,), (251, 10), (251,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0927 - mean_absolute_error: 0.1933 - val_loss: 0.0039 - val_mean_absolute_error: 0.0562
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0019 - mean_absolute_error: 0.0317 - val_loss: 0.0011 - val_mean_absolute_error: 0.0251
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - mean_absolute_error: 0.0254 - val_loss: 8.0226e-04 - val_mean_absolute_error: 0.0221
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - mean_absolute_error: 0.0251 - val_loss: 8.5699e-04 - val_mean_absolute_error: 0.0234
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0010 - mean_absolute_error: 0.0234 - val_loss: 6.3153e-04 - val_mean_absolute_error: 0.0194
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.9279e-04 - mean_absolute_error: 0.0218 - val_loss: 5.9670e-04 - val_mean_absolute_error: 0.0182
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.8549e-04 - mean_absolute_error: 0.0216 - val_loss: 5.1980e-04 - val_mean_absolute_error: 0.0171
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.9896e-04 - mean_absolute_error: 0.0189 - val_loss: 9.6466e-04 - val_mean_absolute_error: 0.0247
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.2479e-04 - mean_absolute_error: 0.0189 - val_loss: 5.3174e-04 - val_mean_absolute_error: 0.0190
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.8435e-04 - mean_absolute_error: 0.0201 - val_loss: 5.2794e-04 - val_mean_absolute_error: 0.0191
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2450e-04 - mean_absolute_error: 0.0183 - val_loss: 4.5511e-04 - val_mean_absolute_error: 0.0155
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.7582e-04 - mean_absolute_error: 0.0168 - val_loss: 3.7697e-04 - val_mean_absolute_error: 0.0141
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7369e-04 - mean_absolute_error: 0.0153 - val_loss: 4.6432e-04 - val_mean_absolute_error: 0.0158
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9641e-04 - mean_absolute_error: 0.0158 - val_loss: 3.7990e-04 - val_mean_absolute_error: 0.0157
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.8186e-04 - mean_absolute_error: 0.0158 - val_loss: 3.7217e-04 - val_mean_absolute_error: 0.0140
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4713e-04 - mean_absolute_error: 0.0170 - val_loss: 3.2422e-04 - val_mean_absolute_error: 0.0138
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.8712e-04 - mean_absolute_error: 0.0174 - val_loss: 4.6272e-04 - val_mean_absolute_error: 0.0181
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0829e-04 - mean_absolute_error: 0.0160 - val_loss: 4.5165e-04 - val_mean_absolute_error: 0.0160
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.8096e-04 - mean_absolute_error: 0.0156 - val_loss: 3.6527e-04 - val_mean_absolute_error: 0.0155
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.6229e-04 - mean_absolute_error: 0.0154 - val_loss: 4.8722e-04 - val_mean_absolute_error: 0.0170
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9002e-04 - mean_absolute_error: 0.0138 - val_loss: 3.2383e-04 - val_mean_absolute_error: 0.0143
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5845e-04 - mean_absolute_error: 0.0132 - val_loss: 2.8166e-04 - val_mean_absolute_error: 0.0127
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1556e-04 - mean_absolute_error: 0.0145 - val_loss: 3.5945e-04 - val_mean_absolute_error: 0.0140
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0574e-04 - mean_absolute_error: 0.0144 - val_loss: 3.2905e-04 - val_mean_absolute_error: 0.0146
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7943e-04 - mean_absolute_error: 0.0138 - val_loss: 2.7529e-04 - val_mean_absolute_error: 0.0127
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.7908e-04 - mean_absolute_error: 0.0139 - val_loss: 4.3017e-04 - val_mean_absolute_error: 0.0161
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9560e-04 - mean_absolute_error: 0.0137 - val_loss: 2.5601e-04 - val_mean_absolute_error: 0.0115
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.6580e-04 - mean_absolute_error: 0.0133 - val_loss: 2.5941e-04 - val_mean_absolute_error: 0.0116
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.9383e-04 - mean_absolute_error: 0.0121 - val_loss: 7.8562e-04 - val_mean_absolute_error: 0.0241
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9382e-04 - mean_absolute_error: 0.0142 - val_loss: 2.3168e-04 - val_mean_absolute_error: 0.0109
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.2132e-04 - mean_absolute_error: 0.0122 - val_loss: 5.2146e-04 - val_mean_absolute_error: 0.0200
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.3305e-04 - mean_absolute_error: 0.0145 - val_loss: 2.4083e-04 - val_mean_absolute_error: 0.0117
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.4514e-04 - mean_absolute_error: 0.0130 - val_loss: 2.5185e-04 - val_mean_absolute_error: 0.0115
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.2772e-04 - mean_absolute_error: 0.0142 - val_loss: 3.3826e-04 - val_mean_absolute_error: 0.0141
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.3982e-04 - mean_absolute_error: 0.0125 - val_loss: 2.1501e-04 - val_mean_absolute_error: 0.0106
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8695e-04 - mean_absolute_error: 0.0120 - val_loss: 2.1335e-04 - val_mean_absolute_error: 0.0105
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.8830e-04 - mean_absolute_error: 0.0119 - val_loss: 5.1967e-04 - val_mean_absolute_error: 0.0190
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0862e-04 - mean_absolute_error: 0.0140 - val_loss: 2.1813e-04 - val_mean_absolute_error: 0.0110
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8817e-04 - mean_absolute_error: 0.0117 - val_loss: 3.1068e-04 - val_mean_absolute_error: 0.0135
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.0498e-04 - mean_absolute_error: 0.0144 - val_loss: 5.2271e-04 - val_mean_absolute_error: 0.0192
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7223e-04 - mean_absolute_error: 0.0114 - val_loss: 2.0673e-04 - val_mean_absolute_error: 0.0103
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6370e-04 - mean_absolute_error: 0.0113 - val_loss: 2.0161e-04 - val_mean_absolute_error: 0.0104
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7030e-04 - mean_absolute_error: 0.0117 - val_loss: 6.7265e-04 - val_mean_absolute_error: 0.0235
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9394e-04 - mean_absolute_error: 0.0143 - val_loss: 7.9865e-04 - val_mean_absolute_error: 0.0251
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9569e-04 - mean_absolute_error: 0.0120 - val_loss: 2.7954e-04 - val_mean_absolute_error: 0.0135
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.0262e-04 - mean_absolute_error: 0.0123 - val_loss: 1.8816e-04 - val_mean_absolute_error: 0.0099
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.6146e-04 - mean_absolute_error: 0.0110 - val_loss: 1.8678e-04 - val_mean_absolute_error: 0.0098
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6587e-04 - mean_absolute_error: 0.0115 - val_loss: 2.7402e-04 - val_mean_absolute_error: 0.0133
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2114e-04 - mean_absolute_error: 0.0127 - val_loss: 2.7046e-04 - val_mean_absolute_error: 0.0126
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5716e-04 - mean_absolute_error: 0.0113 - val_loss: 2.0402e-04 - val_mean_absolute_error: 0.0107
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2427e-04 - mean_absolute_error: 0.0105 - val_loss: 2.6705e-04 - val_mean_absolute_error: 0.0131
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4784e-04 - mean_absolute_error: 0.0110 - val_loss: 1.9614e-04 - val_mean_absolute_error: 0.0102
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.4724e-04 - mean_absolute_error: 0.0110 - val_loss: 2.2594e-04 - val_mean_absolute_error: 0.0112
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2968e-04 - mean_absolute_error: 0.0106 - val_loss: 1.7702e-04 - val_mean_absolute_error: 0.0096
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.4481e-04 - mean_absolute_error: 0.0110 - val_loss: 4.1599e-04 - val_mean_absolute_error: 0.0172
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.4872e-04 - mean_absolute_error: 0.0113 - val_loss: 1.6900e-04 - val_mean_absolute_error: 0.0093
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1624e-04 - mean_absolute_error: 0.0103 - val_loss: 2.2266e-04 - val_mean_absolute_error: 0.0112
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.7580e-04 - mean_absolute_error: 0.0113 - val_loss: 1.8772e-04 - val_mean_absolute_error: 0.0101
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.5337e-04 - mean_absolute_error: 0.0111 - val_loss: 1.6418e-04 - val_mean_absolute_error: 0.0091
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3182e-04 - mean_absolute_error: 0.0105 - val_loss: 1.6823e-04 - val_mean_absolute_error: 0.0093
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.3388e-04 - mean_absolute_error: 0.0107 - val_loss: 1.7948e-04 - val_mean_absolute_error: 0.0098
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0088e-04 - mean_absolute_error: 0.0099 - val_loss: 1.7095e-04 - val_mean_absolute_error: 0.0095
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3649e-04 - mean_absolute_error: 0.0107 - val_loss: 2.3390e-04 - val_mean_absolute_error: 0.0118
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.2204e-04 - mean_absolute_error: 0.0101 - val_loss: 1.6824e-04 - val_mean_absolute_error: 0.0093
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.1744e-04 - mean_absolute_error: 0.0101 - val_loss: 1.8668e-04 - val_mean_absolute_error: 0.0101
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0884e-04 - mean_absolute_error: 0.0099 - val_loss: 4.2220e-04 - val_mean_absolute_error: 0.0177
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3036e-04 - mean_absolute_error: 0.0106 - val_loss: 1.5800e-04 - val_mean_absolute_error: 0.0089
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9925e-04 - mean_absolute_error: 0.0099 - val_loss: 1.6399e-04 - val_mean_absolute_error: 0.0092
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.8624e-04 - mean_absolute_error: 0.0095 - val_loss: 1.5304e-04 - val_mean_absolute_error: 0.0087
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.9274e-04 - mean_absolute_error: 0.0096 - val_loss: 2.0504e-04 - val_mean_absolute_error: 0.0109
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7596e-04 - mean_absolute_error: 0.0092 - val_loss: 1.4908e-04 - val_mean_absolute_error: 0.0086
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0410e-04 - mean_absolute_error: 0.0099 - val_loss: 1.5118e-04 - val_mean_absolute_error: 0.0087
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9728e-04 - mean_absolute_error: 0.0098 - val_loss: 2.0880e-04 - val_mean_absolute_error: 0.0113
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.5074e-04 - mean_absolute_error: 0.0109 - val_loss: 3.7830e-04 - val_mean_absolute_error: 0.0168
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.2244e-04 - mean_absolute_error: 0.0106 - val_loss: 1.5903e-04 - val_mean_absolute_error: 0.0090
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2617e-04 - mean_absolute_error: 0.0105 - val_loss: 1.8530e-04 - val_mean_absolute_error: 0.0102
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.9981e-04 - mean_absolute_error: 0.0094 - val_loss: 1.4798e-04 - val_mean_absolute_error: 0.0086
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7956e-04 - mean_absolute_error: 0.0093 - val_loss: 1.3947e-04 - val_mean_absolute_error: 0.0083
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9029e-04 - mean_absolute_error: 0.0093 - val_loss: 1.5141e-04 - val_mean_absolute_error: 0.0089
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.9319e-04 - mean_absolute_error: 0.0094 - val_loss: 1.3755e-04 - val_mean_absolute_error: 0.0082
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9599e-04 - mean_absolute_error: 0.0096 - val_loss: 1.8056e-04 - val_mean_absolute_error: 0.0102
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9688e-04 - mean_absolute_error: 0.0097 - val_loss: 1.4991e-04 - val_mean_absolute_error: 0.0088
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8124e-04 - mean_absolute_error: 0.0093 - val_loss: 1.3711e-04 - val_mean_absolute_error: 0.0082
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7399e-04 - mean_absolute_error: 0.0092 - val_loss: 1.6723e-04 - val_mean_absolute_error: 0.0096
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6785e-04 - mean_absolute_error: 0.0093 - val_loss: 1.4934e-04 - val_mean_absolute_error: 0.0088
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7484e-04 - mean_absolute_error: 0.0089 - val_loss: 4.2360e-04 - val_mean_absolute_error: 0.0183
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8815e-04 - mean_absolute_error: 0.0097 - val_loss: 1.8219e-04 - val_mean_absolute_error: 0.0103
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7217e-04 - mean_absolute_error: 0.0089 - val_loss: 1.3485e-04 - val_mean_absolute_error: 0.0081
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6581e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2958e-04 - val_mean_absolute_error: 0.0080
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5218e-04 - mean_absolute_error: 0.0083 - val_loss: 1.3528e-04 - val_mean_absolute_error: 0.0082
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5852e-04 - mean_absolute_error: 0.0090 - val_loss: 1.3711e-04 - val_mean_absolute_error: 0.0083
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7376e-04 - mean_absolute_error: 0.0089 - val_loss: 1.4459e-04 - val_mean_absolute_error: 0.0087
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4644e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2820e-04 - val_mean_absolute_error: 0.0079
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6171e-04 - mean_absolute_error: 0.0087 - val_loss: 1.7128e-04 - val_mean_absolute_error: 0.0099
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6639e-04 - mean_absolute_error: 0.0088 - val_loss: 1.4366e-04 - val_mean_absolute_error: 0.0087
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8214e-04 - mean_absolute_error: 0.0093 - val_loss: 1.4205e-04 - val_mean_absolute_error: 0.0086
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9121e-04 - mean_absolute_error: 0.0093 - val_loss: 3.1409e-04 - val_mean_absolute_error: 0.0153
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7547e-04 - mean_absolute_error: 0.0094 - val_loss: 1.4981e-04 - val_mean_absolute_error: 0.0090
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6618e-04 - mean_absolute_error: 0.0088 - val_loss: 3.1035e-04 - val_mean_absolute_error: 0.0151
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.7513e-04 - mean_absolute_error: 0.0090 - val_loss: 2.8048e-04 - val_mean_absolute_error: 0.0143
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.9563e-04 - mean_absolute_error: 0.0096 - val_loss: 1.3580e-04 - val_mean_absolute_error: 0.0083
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.6379e-04 - mean_absolute_error: 0.0089 - val_loss: 1.2397e-04 - val_mean_absolute_error: 0.0078
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5180e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2460e-04 - val_mean_absolute_error: 0.0078
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.4243e-04 - mean_absolute_error: 0.0083 - val_loss: 1.4217e-04 - val_mean_absolute_error: 0.0087
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.5951e-04 - mean_absolute_error: 0.0086 - val_loss: 1.5658e-04 - val_mean_absolute_error: 0.0093
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6017e-04 - mean_absolute_error: 0.0086 - val_loss: 1.5055e-04 - val_mean_absolute_error: 0.0090
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5781e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2457e-04 - val_mean_absolute_error: 0.0079
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.5293e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2673e-04 - val_mean_absolute_error: 0.0079
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6516e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2547e-04 - val_mean_absolute_error: 0.0080
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.5397e-04 - mean_absolute_error: 0.0086 - val_loss: 2.5560e-04 - val_mean_absolute_error: 0.0134
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5681e-04 - mean_absolute_error: 0.0086 - val_loss: 1.5640e-04 - val_mean_absolute_error: 0.0093
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5605e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3798e-04 - val_mean_absolute_error: 0.0084
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5673e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3159e-04 - val_mean_absolute_error: 0.0081
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4068e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2987e-04 - val_mean_absolute_error: 0.0081
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3939e-04 - mean_absolute_error: 0.0080 - val_loss: 1.5994e-04 - val_mean_absolute_error: 0.0097
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6664e-04 - mean_absolute_error: 0.0091 - val_loss: 1.9259e-04 - val_mean_absolute_error: 0.0110
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6685e-04 - mean_absolute_error: 0.0090 - val_loss: 1.4299e-04 - val_mean_absolute_error: 0.0090
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5740e-04 - mean_absolute_error: 0.0085 - val_loss: 1.4353e-04 - val_mean_absolute_error: 0.0090
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5950e-04 - mean_absolute_error: 0.0088 - val_loss: 2.6826e-04 - val_mean_absolute_error: 0.0139
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5911e-04 - mean_absolute_error: 0.0089 - val_loss: 1.2112e-04 - val_mean_absolute_error: 0.0079
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3424e-04 - mean_absolute_error: 0.0081 - val_loss: 1.1904e-04 - val_mean_absolute_error: 0.0077
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5778e-04 - mean_absolute_error: 0.0085 - val_loss: 1.1889e-04 - val_mean_absolute_error: 0.0077
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4011e-04 - mean_absolute_error: 0.0081 - val_loss: 3.0255e-04 - val_mean_absolute_error: 0.0151
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9260e-04 - mean_absolute_error: 0.0100 - val_loss: 1.2281e-04 - val_mean_absolute_error: 0.0078
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5360e-04 - mean_absolute_error: 0.0085 - val_loss: 1.5822e-04 - val_mean_absolute_error: 0.0094
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5640e-04 - mean_absolute_error: 0.0083 - val_loss: 1.1802e-04 - val_mean_absolute_error: 0.0077
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4622e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3119e-04 - val_mean_absolute_error: 0.0081
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6308e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2321e-04 - val_mean_absolute_error: 0.0080
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3901e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2341e-04 - val_mean_absolute_error: 0.0078
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4565e-04 - mean_absolute_error: 0.0081 - val_loss: 1.1950e-04 - val_mean_absolute_error: 0.0078
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4160e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2373e-04 - val_mean_absolute_error: 0.0078
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9281e-04 - mean_absolute_error: 0.0095 - val_loss: 1.1897e-04 - val_mean_absolute_error: 0.0078
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4413e-04 - mean_absolute_error: 0.0083 - val_loss: 1.7925e-04 - val_mean_absolute_error: 0.0104
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6295e-04 - mean_absolute_error: 0.0088 - val_loss: 3.3400e-04 - val_mean_absolute_error: 0.0159
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6633e-04 - mean_absolute_error: 0.0092 - val_loss: 1.2485e-04 - val_mean_absolute_error: 0.0082
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3550e-04 - mean_absolute_error: 0.0081 - val_loss: 1.2149e-04 - val_mean_absolute_error: 0.0078
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5410e-04 - mean_absolute_error: 0.0085 - val_loss: 1.3052e-04 - val_mean_absolute_error: 0.0081
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5588e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2075e-04 - val_mean_absolute_error: 0.0080
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2836e-04 - mean_absolute_error: 0.0076 - val_loss: 1.1908e-04 - val_mean_absolute_error: 0.0078
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2584e-04 - mean_absolute_error: 0.0076 - val_loss: 1.2613e-04 - val_mean_absolute_error: 0.0079
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4994e-04 - mean_absolute_error: 0.0083 - val_loss: 2.6241e-04 - val_mean_absolute_error: 0.0138
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4100e-04 - mean_absolute_error: 0.0087 - val_loss: 2.1244e-04 - val_mean_absolute_error: 0.0117
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5787e-04 - mean_absolute_error: 0.0083 - val_loss: 1.3971e-04 - val_mean_absolute_error: 0.0090
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4327e-04 - mean_absolute_error: 0.0083 - val_loss: 1.8587e-04 - val_mean_absolute_error: 0.0107
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6408e-04 - mean_absolute_error: 0.0089 - val_loss: 1.6273e-04 - val_mean_absolute_error: 0.0100
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3503e-04 - mean_absolute_error: 0.0079 - val_loss: 1.5472e-04 - val_mean_absolute_error: 0.0093
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5189e-04 - mean_absolute_error: 0.0082 - val_loss: 1.4122e-04 - val_mean_absolute_error: 0.0091
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4282e-04 - mean_absolute_error: 0.0081 - val_loss: 1.2039e-04 - val_mean_absolute_error: 0.0078
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5288e-04 - mean_absolute_error: 0.0084 - val_loss: 1.1902e-04 - val_mean_absolute_error: 0.0079
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4202e-04 - mean_absolute_error: 0.0082 - val_loss: 1.3453e-04 - val_mean_absolute_error: 0.0088
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5943e-04 - mean_absolute_error: 0.0090 - val_loss: 1.1974e-04 - val_mean_absolute_error: 0.0078
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4114e-04 - mean_absolute_error: 0.0080 - val_loss: 1.8720e-04 - val_mean_absolute_error: 0.0107
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3789e-04 - mean_absolute_error: 0.0081 - val_loss: 1.3478e-04 - val_mean_absolute_error: 0.0083
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5114e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2891e-04 - val_mean_absolute_error: 0.0081
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3000e-04 - mean_absolute_error: 0.0077 - val_loss: 1.6005e-04 - val_mean_absolute_error: 0.0095
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4256e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2913e-04 - val_mean_absolute_error: 0.0081
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4004e-04 - mean_absolute_error: 0.0084 - val_loss: 1.5776e-04 - val_mean_absolute_error: 0.0094
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5095e-04 - mean_absolute_error: 0.0084 - val_loss: 1.4008e-04 - val_mean_absolute_error: 0.0086
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3789e-04 - mean_absolute_error: 0.0081 - val_loss: 1.3249e-04 - val_mean_absolute_error: 0.0083
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2639e-04 - mean_absolute_error: 0.0076 - val_loss: 1.2006e-04 - val_mean_absolute_error: 0.0079
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5641e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2457e-04 - val_mean_absolute_error: 0.0080
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5319e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3552e-04 - val_mean_absolute_error: 0.0084
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3939e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2076e-04 - val_mean_absolute_error: 0.0079
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5311e-04 - mean_absolute_error: 0.0085 - val_loss: 1.6309e-04 - val_mean_absolute_error: 0.0101
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4569e-04 - mean_absolute_error: 0.0083 - val_loss: 1.3440e-04 - val_mean_absolute_error: 0.0083
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5367e-04 - mean_absolute_error: 0.0085 - val_loss: 1.1928e-04 - val_mean_absolute_error: 0.0079
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3668e-04 - mean_absolute_error: 0.0080 - val_loss: 1.5346e-04 - val_mean_absolute_error: 0.0092
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3504e-04 - mean_absolute_error: 0.0080 - val_loss: 1.9156e-04 - val_mean_absolute_error: 0.0112
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.5094e-04 - mean_absolute_error: 0.0084 - val_loss: 1.4346e-04 - val_mean_absolute_error: 0.0092
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3438e-04 - mean_absolute_error: 0.0080 - val_loss: 1.8198e-04 - val_mean_absolute_error: 0.0108
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6713e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2700e-04 - val_mean_absolute_error: 0.0080
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4373e-04 - mean_absolute_error: 0.0081 - val_loss: 1.2025e-04 - val_mean_absolute_error: 0.0080
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3283e-04 - mean_absolute_error: 0.0077 - val_loss: 1.7789e-04 - val_mean_absolute_error: 0.0103
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6170e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3472e-04 - val_mean_absolute_error: 0.0084
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.4790e-04 - mean_absolute_error: 0.0082 - val_loss: 1.4670e-04 - val_mean_absolute_error: 0.0089
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4913e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2019e-04 - val_mean_absolute_error: 0.0080
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5823e-04 - mean_absolute_error: 0.0091 - val_loss: 1.6085e-04 - val_mean_absolute_error: 0.0095
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4596e-04 - mean_absolute_error: 0.0083 - val_loss: 1.3386e-04 - val_mean_absolute_error: 0.0087
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3899e-04 - mean_absolute_error: 0.0080 - val_loss: 1.3956e-04 - val_mean_absolute_error: 0.0086
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4428e-04 - mean_absolute_error: 0.0081 - val_loss: 1.2095e-04 - val_mean_absolute_error: 0.0080
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4728e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2260e-04 - val_mean_absolute_error: 0.0081
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3497e-04 - mean_absolute_error: 0.0079 - val_loss: 1.8946e-04 - val_mean_absolute_error: 0.0107
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4709e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2065e-04 - val_mean_absolute_error: 0.0080
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5125e-04 - mean_absolute_error: 0.0084 - val_loss: 2.3519e-04 - val_mean_absolute_error: 0.0125
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6768e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2019e-04 - val_mean_absolute_error: 0.0079
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3691e-04 - mean_absolute_error: 0.0081 - val_loss: 1.4073e-04 - val_mean_absolute_error: 0.0086
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5946e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2128e-04 - val_mean_absolute_error: 0.0080
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2725e-04 - mean_absolute_error: 0.0076 - val_loss: 1.2065e-04 - val_mean_absolute_error: 0.0080
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2930e-04 - mean_absolute_error: 0.0079 - val_loss: 1.8828e-04 - val_mean_absolute_error: 0.0111
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6174e-04 - mean_absolute_error: 0.0089 - val_loss: 1.4491e-04 - val_mean_absolute_error: 0.0088
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6858e-04 - mean_absolute_error: 0.0089 - val_loss: 3.1785e-04 - val_mean_absolute_error: 0.0153
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7056e-04 - mean_absolute_error: 0.0092 - val_loss: 1.1989e-04 - val_mean_absolute_error: 0.0079
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5051e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2513e-04 - val_mean_absolute_error: 0.0080
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2755e-04 - mean_absolute_error: 0.0077 - val_loss: 1.9306e-04 - val_mean_absolute_error: 0.0113
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5759e-04 - mean_absolute_error: 0.0086 - val_loss: 1.4301e-04 - val_mean_absolute_error: 0.0092
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4136e-04 - mean_absolute_error: 0.0081 - val_loss: 1.2402e-04 - val_mean_absolute_error: 0.0080
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2248e-04 - mean_absolute_error: 0.0075 - val_loss: 1.2442e-04 - val_mean_absolute_error: 0.0082
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3462e-04 - mean_absolute_error: 0.0081 - val_loss: 1.2682e-04 - val_mean_absolute_error: 0.0081
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6394e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2795e-04 - val_mean_absolute_error: 0.0081
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3475e-04 - mean_absolute_error: 0.0079 - val_loss: 1.2085e-04 - val_mean_absolute_error: 0.0079

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 109ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 592828.7705658992
# RMSE: 769.9537457314558
# MAE: 556.3831704432271
# MAPE: 1.6583823228466334 %
#
# Model evalution on validate set
# MSE: 3778460.3741354193
# RMSE: 1943.8262201481436
# MAE: 1236.6973140495868
# MAPE: 2.5908225293086855 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 716ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step

# %%
y_pred_30_days
# Out:
# array([[62236.938],
#        [61754.414],
#        [62137.26 ],
#        [62061.656],
#        [62127.188],
#        [62111.535],
#        [62122.33 ],
#        [62119.46 ],
#        [62121.242],
#        [62120.71 ],
#        [62121.016],
#        [62120.92 ],
#        [62120.977],
#        [62120.953],
#        [62120.945],
#        [62120.953],
#        [62120.965],
#        [62120.945],
#        [62120.953],
#        [62120.945],
#        [62120.953],
#        [62120.953],
#        [62120.953],
#        [62120.953],
#        [62120.953],
#        [62120.945],
#        [62120.957],
#        [62120.945],
#        [62120.953],
#        [62120.953],
#        [62120.953]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Predict the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
