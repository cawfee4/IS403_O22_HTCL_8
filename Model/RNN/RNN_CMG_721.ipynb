# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: CMG - Test/Train/Vaildation: 70/20/10
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 795.6262011800723
# - MAE: 593.2092100348606
# - MAPE: 1.7676684057448693 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 0  # 7 2 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.tail()
# Out:
#             close
# time
# 2024-05-27  59000
# 2024-05-28  62100
# 2024-05-29  60000
# 2024-05-30  59200
# 2024-05-31  60900

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((908, 10), (908,), (251, 10), (251,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: 0.0631 - mean_absolute_error: 0.1706 - val_loss: 0.0029 - val_mean_absolute_error: 0.0492
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0013 - mean_absolute_error: 0.0261 - val_loss: 5.5900e-04 - val_mean_absolute_error: 0.0183
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.1467e-04 - mean_absolute_error: 0.0199 - val_loss: 6.2788e-04 - val_mean_absolute_error: 0.0195
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8775e-04 - mean_absolute_error: 0.0191 - val_loss: 5.5125e-04 - val_mean_absolute_error: 0.0181
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.7397e-04 - mean_absolute_error: 0.0171 - val_loss: 3.9984e-04 - val_mean_absolute_error: 0.0151
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.1291e-04 - mean_absolute_error: 0.0166 - val_loss: 4.8098e-04 - val_mean_absolute_error: 0.0168
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.1127e-04 - mean_absolute_error: 0.0166 - val_loss: 4.2992e-04 - val_mean_absolute_error: 0.0157
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.3663e-04 - mean_absolute_error: 0.0146 - val_loss: 2.9105e-04 - val_mean_absolute_error: 0.0126
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.6338e-04 - mean_absolute_error: 0.0135 - val_loss: 2.7775e-04 - val_mean_absolute_error: 0.0122
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.4485e-04 - mean_absolute_error: 0.0127 - val_loss: 2.6500e-04 - val_mean_absolute_error: 0.0120
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.3626e-04 - mean_absolute_error: 0.0143 - val_loss: 3.7519e-04 - val_mean_absolute_error: 0.0148
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.2183e-04 - mean_absolute_error: 0.0128 - val_loss: 3.8272e-04 - val_mean_absolute_error: 0.0151
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.4016e-04 - mean_absolute_error: 0.0131 - val_loss: 2.9475e-04 - val_mean_absolute_error: 0.0127
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2353e-04 - mean_absolute_error: 0.0126 - val_loss: 2.4272e-04 - val_mean_absolute_error: 0.0113
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.8042e-04 - mean_absolute_error: 0.0117 - val_loss: 2.2838e-04 - val_mean_absolute_error: 0.0112
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.0362e-04 - mean_absolute_error: 0.0120 - val_loss: 3.8000e-04 - val_mean_absolute_error: 0.0152
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.5495e-04 - mean_absolute_error: 0.0127 - val_loss: 2.2058e-04 - val_mean_absolute_error: 0.0110
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.7731e-04 - mean_absolute_error: 0.0114 - val_loss: 2.3566e-04 - val_mean_absolute_error: 0.0112
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.7645e-04 - mean_absolute_error: 0.0113 - val_loss: 2.5851e-04 - val_mean_absolute_error: 0.0118
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.2195e-04 - mean_absolute_error: 0.0124 - val_loss: 2.2723e-04 - val_mean_absolute_error: 0.0110
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.0402e-04 - mean_absolute_error: 0.0120 - val_loss: 6.9742e-04 - val_mean_absolute_error: 0.0239
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.2395e-04 - mean_absolute_error: 0.0130 - val_loss: 3.0970e-04 - val_mean_absolute_error: 0.0144
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.2107e-04 - mean_absolute_error: 0.0125 - val_loss: 2.1657e-04 - val_mean_absolute_error: 0.0107
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.6061e-04 - mean_absolute_error: 0.0112 - val_loss: 3.5266e-04 - val_mean_absolute_error: 0.0148
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7410e-04 - mean_absolute_error: 0.0118 - val_loss: 2.7074e-04 - val_mean_absolute_error: 0.0132
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.9625e-04 - mean_absolute_error: 0.0122 - val_loss: 9.0353e-04 - val_mean_absolute_error: 0.0269
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9612e-04 - mean_absolute_error: 0.0123 - val_loss: 2.0568e-04 - val_mean_absolute_error: 0.0104
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7073e-04 - mean_absolute_error: 0.0115 - val_loss: 2.6109e-04 - val_mean_absolute_error: 0.0128
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.8828e-04 - mean_absolute_error: 0.0118 - val_loss: 1.9404e-04 - val_mean_absolute_error: 0.0102
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.8393e-04 - mean_absolute_error: 0.0119 - val_loss: 3.0076e-04 - val_mean_absolute_error: 0.0135
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7139e-04 - mean_absolute_error: 0.0114 - val_loss: 2.0521e-04 - val_mean_absolute_error: 0.0107
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.4902e-04 - mean_absolute_error: 0.0110 - val_loss: 3.5346e-04 - val_mean_absolute_error: 0.0151
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.8034e-04 - mean_absolute_error: 0.0119 - val_loss: 2.1746e-04 - val_mean_absolute_error: 0.0112
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.5607e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0017 - val_mean_absolute_error: 0.0385
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.9385e-04 - mean_absolute_error: 0.0144 - val_loss: 2.4047e-04 - val_mean_absolute_error: 0.0121
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.8797e-04 - mean_absolute_error: 0.0117 - val_loss: 1.9363e-04 - val_mean_absolute_error: 0.0101
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.6331e-04 - mean_absolute_error: 0.0116 - val_loss: 2.7596e-04 - val_mean_absolute_error: 0.0129
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.5138e-04 - mean_absolute_error: 0.0108 - val_loss: 1.8443e-04 - val_mean_absolute_error: 0.0100
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.2031e-04 - mean_absolute_error: 0.0102 - val_loss: 2.9383e-04 - val_mean_absolute_error: 0.0135
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3931e-04 - mean_absolute_error: 0.0107 - val_loss: 2.2755e-04 - val_mean_absolute_error: 0.0113
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.3908e-04 - mean_absolute_error: 0.0107 - val_loss: 1.8246e-04 - val_mean_absolute_error: 0.0099
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.4212e-04 - mean_absolute_error: 0.0106 - val_loss: 3.7331e-04 - val_mean_absolute_error: 0.0160
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1393e-04 - mean_absolute_error: 0.0102 - val_loss: 3.0874e-04 - val_mean_absolute_error: 0.0145
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.1712e-04 - mean_absolute_error: 0.0127 - val_loss: 3.7011e-04 - val_mean_absolute_error: 0.0160
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.4800e-04 - mean_absolute_error: 0.0109 - val_loss: 3.6668e-04 - val_mean_absolute_error: 0.0163
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.6184e-04 - mean_absolute_error: 0.0111 - val_loss: 3.1077e-04 - val_mean_absolute_error: 0.0142
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1850e-04 - mean_absolute_error: 0.0104 - val_loss: 2.8020e-04 - val_mean_absolute_error: 0.0136
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.0227e-04 - mean_absolute_error: 0.0100 - val_loss: 1.6596e-04 - val_mean_absolute_error: 0.0093
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.7294e-04 - mean_absolute_error: 0.0119 - val_loss: 1.7498e-04 - val_mean_absolute_error: 0.0096
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1539e-04 - mean_absolute_error: 0.0099 - val_loss: 1.6286e-04 - val_mean_absolute_error: 0.0092
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.2564e-04 - mean_absolute_error: 0.0103 - val_loss: 2.0487e-04 - val_mean_absolute_error: 0.0107
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1465e-04 - mean_absolute_error: 0.0099 - val_loss: 2.9107e-04 - val_mean_absolute_error: 0.0137
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.6382e-04 - mean_absolute_error: 0.0113 - val_loss: 1.6054e-04 - val_mean_absolute_error: 0.0090
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2078e-04 - mean_absolute_error: 0.0101 - val_loss: 1.5703e-04 - val_mean_absolute_error: 0.0089
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2424e-04 - mean_absolute_error: 0.0103 - val_loss: 2.6137e-04 - val_mean_absolute_error: 0.0128
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0385e-04 - mean_absolute_error: 0.0098 - val_loss: 3.5701e-04 - val_mean_absolute_error: 0.0159
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3128e-04 - mean_absolute_error: 0.0110 - val_loss: 2.6771e-04 - val_mean_absolute_error: 0.0133
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.1261e-04 - mean_absolute_error: 0.0098 - val_loss: 1.8212e-04 - val_mean_absolute_error: 0.0099
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.4854e-04 - mean_absolute_error: 0.0107 - val_loss: 1.5405e-04 - val_mean_absolute_error: 0.0088
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9650e-04 - mean_absolute_error: 0.0096 - val_loss: 1.5221e-04 - val_mean_absolute_error: 0.0087
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9505e-04 - mean_absolute_error: 0.0098 - val_loss: 1.5005e-04 - val_mean_absolute_error: 0.0087
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0910e-04 - mean_absolute_error: 0.0097 - val_loss: 2.8973e-04 - val_mean_absolute_error: 0.0141
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0625e-04 - mean_absolute_error: 0.0101 - val_loss: 1.8880e-04 - val_mean_absolute_error: 0.0103
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.9978e-04 - mean_absolute_error: 0.0096 - val_loss: 1.4877e-04 - val_mean_absolute_error: 0.0086
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1641e-04 - mean_absolute_error: 0.0098 - val_loss: 1.9108e-04 - val_mean_absolute_error: 0.0105
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.3255e-04 - mean_absolute_error: 0.0107 - val_loss: 4.1603e-04 - val_mean_absolute_error: 0.0178
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8847e-04 - mean_absolute_error: 0.0120 - val_loss: 1.9973e-04 - val_mean_absolute_error: 0.0109
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1723e-04 - mean_absolute_error: 0.0107 - val_loss: 1.4742e-04 - val_mean_absolute_error: 0.0086
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8924e-04 - mean_absolute_error: 0.0094 - val_loss: 1.5069e-04 - val_mean_absolute_error: 0.0088
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.9170e-04 - mean_absolute_error: 0.0097 - val_loss: 1.4287e-04 - val_mean_absolute_error: 0.0084
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1403e-04 - mean_absolute_error: 0.0100 - val_loss: 1.4849e-04 - val_mean_absolute_error: 0.0087
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8988e-04 - mean_absolute_error: 0.0093 - val_loss: 1.3870e-04 - val_mean_absolute_error: 0.0083
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8354e-04 - mean_absolute_error: 0.0094 - val_loss: 2.1135e-04 - val_mean_absolute_error: 0.0113
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9394e-04 - mean_absolute_error: 0.0095 - val_loss: 1.4993e-04 - val_mean_absolute_error: 0.0088
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7513e-04 - mean_absolute_error: 0.0090 - val_loss: 1.6905e-04 - val_mean_absolute_error: 0.0097
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9017e-04 - mean_absolute_error: 0.0091 - val_loss: 1.3589e-04 - val_mean_absolute_error: 0.0082
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7331e-04 - mean_absolute_error: 0.0090 - val_loss: 2.1907e-04 - val_mean_absolute_error: 0.0117
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7158e-04 - mean_absolute_error: 0.0093 - val_loss: 2.7599e-04 - val_mean_absolute_error: 0.0139
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8363e-04 - mean_absolute_error: 0.0094 - val_loss: 1.9344e-04 - val_mean_absolute_error: 0.0107
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6555e-04 - mean_absolute_error: 0.0090 - val_loss: 1.3278e-04 - val_mean_absolute_error: 0.0081
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6909e-04 - mean_absolute_error: 0.0091 - val_loss: 1.9553e-04 - val_mean_absolute_error: 0.0108
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8629e-04 - mean_absolute_error: 0.0094 - val_loss: 1.4809e-04 - val_mean_absolute_error: 0.0088
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0501e-04 - mean_absolute_error: 0.0098 - val_loss: 1.6024e-04 - val_mean_absolute_error: 0.0093
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7803e-04 - mean_absolute_error: 0.0093 - val_loss: 1.3311e-04 - val_mean_absolute_error: 0.0080
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8140e-04 - mean_absolute_error: 0.0093 - val_loss: 1.3005e-04 - val_mean_absolute_error: 0.0080
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7022e-04 - mean_absolute_error: 0.0089 - val_loss: 1.4001e-04 - val_mean_absolute_error: 0.0084
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.6743e-04 - mean_absolute_error: 0.0088 - val_loss: 1.3093e-04 - val_mean_absolute_error: 0.0080
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7720e-04 - mean_absolute_error: 0.0090 - val_loss: 1.3735e-04 - val_mean_absolute_error: 0.0083
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5202e-04 - mean_absolute_error: 0.0083 - val_loss: 1.4493e-04 - val_mean_absolute_error: 0.0087
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6011e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2934e-04 - val_mean_absolute_error: 0.0079
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.3812e-04 - mean_absolute_error: 0.0079 - val_loss: 2.1571e-04 - val_mean_absolute_error: 0.0118
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8970e-04 - mean_absolute_error: 0.0095 - val_loss: 1.7806e-04 - val_mean_absolute_error: 0.0103
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6112e-04 - mean_absolute_error: 0.0089 - val_loss: 1.2768e-04 - val_mean_absolute_error: 0.0079
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6478e-04 - mean_absolute_error: 0.0086 - val_loss: 2.5340e-04 - val_mean_absolute_error: 0.0133
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8988e-04 - mean_absolute_error: 0.0095 - val_loss: 2.9210e-04 - val_mean_absolute_error: 0.0145
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.8111e-04 - mean_absolute_error: 0.0093 - val_loss: 1.3146e-04 - val_mean_absolute_error: 0.0081
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5803e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2442e-04 - val_mean_absolute_error: 0.0078
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6293e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2946e-04 - val_mean_absolute_error: 0.0081
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5547e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2289e-04 - val_mean_absolute_error: 0.0077
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5433e-04 - mean_absolute_error: 0.0085 - val_loss: 2.6722e-04 - val_mean_absolute_error: 0.0138
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5938e-04 - mean_absolute_error: 0.0089 - val_loss: 1.8973e-04 - val_mean_absolute_error: 0.0109
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8081e-04 - mean_absolute_error: 0.0094 - val_loss: 1.4182e-04 - val_mean_absolute_error: 0.0086
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3899e-04 - mean_absolute_error: 0.0081 - val_loss: 1.2778e-04 - val_mean_absolute_error: 0.0080
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4360e-04 - mean_absolute_error: 0.0081 - val_loss: 1.2279e-04 - val_mean_absolute_error: 0.0078
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5879e-04 - mean_absolute_error: 0.0086 - val_loss: 1.5234e-04 - val_mean_absolute_error: 0.0091
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4718e-04 - mean_absolute_error: 0.0084 - val_loss: 2.0814e-04 - val_mean_absolute_error: 0.0116
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5068e-04 - mean_absolute_error: 0.0083 - val_loss: 1.4598e-04 - val_mean_absolute_error: 0.0090
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7019e-04 - mean_absolute_error: 0.0091 - val_loss: 1.8917e-04 - val_mean_absolute_error: 0.0108
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5539e-04 - mean_absolute_error: 0.0085 - val_loss: 1.6397e-04 - val_mean_absolute_error: 0.0097
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5633e-04 - mean_absolute_error: 0.0087 - val_loss: 1.5667e-04 - val_mean_absolute_error: 0.0095
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4298e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2057e-04 - val_mean_absolute_error: 0.0078
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5072e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2067e-04 - val_mean_absolute_error: 0.0076
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5025e-04 - mean_absolute_error: 0.0081 - val_loss: 1.2269e-04 - val_mean_absolute_error: 0.0079
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5092e-04 - mean_absolute_error: 0.0083 - val_loss: 1.5293e-04 - val_mean_absolute_error: 0.0092
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6275e-04 - mean_absolute_error: 0.0089 - val_loss: 1.4055e-04 - val_mean_absolute_error: 0.0086
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5762e-04 - mean_absolute_error: 0.0088 - val_loss: 1.3097e-04 - val_mean_absolute_error: 0.0084
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5199e-04 - mean_absolute_error: 0.0085 - val_loss: 1.9569e-04 - val_mean_absolute_error: 0.0111
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.6161e-04 - mean_absolute_error: 0.0089 - val_loss: 1.3382e-04 - val_mean_absolute_error: 0.0082
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5168e-04 - mean_absolute_error: 0.0085 - val_loss: 1.3865e-04 - val_mean_absolute_error: 0.0085
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5471e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2014e-04 - val_mean_absolute_error: 0.0079
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.4766e-04 - mean_absolute_error: 0.0086 - val_loss: 2.7279e-04 - val_mean_absolute_error: 0.0140
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6652e-04 - mean_absolute_error: 0.0094 - val_loss: 1.2134e-04 - val_mean_absolute_error: 0.0080
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6027e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2469e-04 - val_mean_absolute_error: 0.0078
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5497e-04 - mean_absolute_error: 0.0082 - val_loss: 1.8724e-04 - val_mean_absolute_error: 0.0109
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9195e-04 - mean_absolute_error: 0.0098 - val_loss: 1.1797e-04 - val_mean_absolute_error: 0.0077
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3873e-04 - mean_absolute_error: 0.0080 - val_loss: 1.7822e-04 - val_mean_absolute_error: 0.0103
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5732e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2465e-04 - val_mean_absolute_error: 0.0078
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.3520e-04 - mean_absolute_error: 0.0080 - val_loss: 2.2543e-04 - val_mean_absolute_error: 0.0125
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7280e-04 - mean_absolute_error: 0.0092 - val_loss: 1.2640e-04 - val_mean_absolute_error: 0.0079
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5003e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2167e-04 - val_mean_absolute_error: 0.0080
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2452e-04 - mean_absolute_error: 0.0076 - val_loss: 1.2160e-04 - val_mean_absolute_error: 0.0077
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2880e-04 - mean_absolute_error: 0.0077 - val_loss: 2.3923e-04 - val_mean_absolute_error: 0.0128
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5533e-04 - mean_absolute_error: 0.0086 - val_loss: 1.5545e-04 - val_mean_absolute_error: 0.0093
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6239e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2459e-04 - val_mean_absolute_error: 0.0079
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.4270e-04 - mean_absolute_error: 0.0082 - val_loss: 1.1786e-04 - val_mean_absolute_error: 0.0078
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6306e-04 - mean_absolute_error: 0.0086 - val_loss: 1.1891e-04 - val_mean_absolute_error: 0.0077
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3991e-04 - mean_absolute_error: 0.0079 - val_loss: 1.4732e-04 - val_mean_absolute_error: 0.0089
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.5661e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2241e-04 - val_mean_absolute_error: 0.0078
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3210e-04 - mean_absolute_error: 0.0077 - val_loss: 1.1916e-04 - val_mean_absolute_error: 0.0079
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6041e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2914e-04 - val_mean_absolute_error: 0.0085
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7748e-04 - mean_absolute_error: 0.0090 - val_loss: 1.8196e-04 - val_mean_absolute_error: 0.0104
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5118e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2264e-04 - val_mean_absolute_error: 0.0081
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5502e-04 - mean_absolute_error: 0.0084 - val_loss: 1.6103e-04 - val_mean_absolute_error: 0.0095
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.6625e-04 - mean_absolute_error: 0.0085 - val_loss: 1.4143e-04 - val_mean_absolute_error: 0.0086
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4205e-04 - mean_absolute_error: 0.0079 - val_loss: 1.2505e-04 - val_mean_absolute_error: 0.0083
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5130e-04 - mean_absolute_error: 0.0084 - val_loss: 1.8443e-04 - val_mean_absolute_error: 0.0106
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4296e-04 - mean_absolute_error: 0.0081 - val_loss: 1.3758e-04 - val_mean_absolute_error: 0.0089
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4044e-04 - mean_absolute_error: 0.0081 - val_loss: 2.0542e-04 - val_mean_absolute_error: 0.0115
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3738e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2125e-04 - val_mean_absolute_error: 0.0080
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5680e-04 - mean_absolute_error: 0.0084 - val_loss: 1.1976e-04 - val_mean_absolute_error: 0.0079
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3607e-04 - mean_absolute_error: 0.0079 - val_loss: 1.1945e-04 - val_mean_absolute_error: 0.0078
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3577e-04 - mean_absolute_error: 0.0078 - val_loss: 1.7621e-04 - val_mean_absolute_error: 0.0102
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3457e-04 - mean_absolute_error: 0.0081 - val_loss: 1.4841e-04 - val_mean_absolute_error: 0.0094
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3698e-04 - mean_absolute_error: 0.0079 - val_loss: 1.6889e-04 - val_mean_absolute_error: 0.0099
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6454e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2936e-04 - val_mean_absolute_error: 0.0085
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7801e-04 - mean_absolute_error: 0.0095 - val_loss: 1.5485e-04 - val_mean_absolute_error: 0.0097
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4252e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2858e-04 - val_mean_absolute_error: 0.0080
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6284e-04 - mean_absolute_error: 0.0087 - val_loss: 2.0198e-04 - val_mean_absolute_error: 0.0116
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.5154e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2002e-04 - val_mean_absolute_error: 0.0078
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4917e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2981e-04 - val_mean_absolute_error: 0.0081
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8056e-04 - mean_absolute_error: 0.0093 - val_loss: 1.4891e-04 - val_mean_absolute_error: 0.0094
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4941e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3138e-04 - val_mean_absolute_error: 0.0082
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.3819e-04 - mean_absolute_error: 0.0078 - val_loss: 1.5052e-04 - val_mean_absolute_error: 0.0091
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.4736e-04 - mean_absolute_error: 0.0083 - val_loss: 1.3821e-04 - val_mean_absolute_error: 0.0085
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5444e-04 - mean_absolute_error: 0.0084 - val_loss: 2.1256e-04 - val_mean_absolute_error: 0.0117
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3830e-04 - mean_absolute_error: 0.0079 - val_loss: 2.1638e-04 - val_mean_absolute_error: 0.0121
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5911e-04 - mean_absolute_error: 0.0087 - val_loss: 1.3292e-04 - val_mean_absolute_error: 0.0083
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.3195e-04 - mean_absolute_error: 0.0078 - val_loss: 1.2413e-04 - val_mean_absolute_error: 0.0079
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6997e-04 - mean_absolute_error: 0.0089 - val_loss: 1.3533e-04 - val_mean_absolute_error: 0.0084
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6372e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2248e-04 - val_mean_absolute_error: 0.0079
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4102e-04 - mean_absolute_error: 0.0081 - val_loss: 1.2001e-04 - val_mean_absolute_error: 0.0079
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3004e-04 - mean_absolute_error: 0.0080 - val_loss: 1.1992e-04 - val_mean_absolute_error: 0.0078
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3991e-04 - mean_absolute_error: 0.0081 - val_loss: 1.4263e-04 - val_mean_absolute_error: 0.0092
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4915e-04 - mean_absolute_error: 0.0084 - val_loss: 1.5963e-04 - val_mean_absolute_error: 0.0095
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6274e-04 - mean_absolute_error: 0.0086 - val_loss: 1.4369e-04 - val_mean_absolute_error: 0.0092
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3046e-04 - mean_absolute_error: 0.0078 - val_loss: 1.1990e-04 - val_mean_absolute_error: 0.0079
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3970e-04 - mean_absolute_error: 0.0080 - val_loss: 2.5739e-04 - val_mean_absolute_error: 0.0133
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.7526e-04 - mean_absolute_error: 0.0098 - val_loss: 1.5326e-04 - val_mean_absolute_error: 0.0092
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.3475e-04 - mean_absolute_error: 0.0080 - val_loss: 1.3120e-04 - val_mean_absolute_error: 0.0082
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0834e-04 - mean_absolute_error: 0.0103 - val_loss: 2.2747e-04 - val_mean_absolute_error: 0.0125
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.5638e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2059e-04 - val_mean_absolute_error: 0.0079
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4095e-04 - mean_absolute_error: 0.0081 - val_loss: 1.2815e-04 - val_mean_absolute_error: 0.0085
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4969e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2405e-04 - val_mean_absolute_error: 0.0082
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4405e-04 - mean_absolute_error: 0.0080 - val_loss: 1.7762e-04 - val_mean_absolute_error: 0.0103
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.6807e-04 - mean_absolute_error: 0.0091 - val_loss: 1.3237e-04 - val_mean_absolute_error: 0.0083
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.2617e-04 - mean_absolute_error: 0.0078 - val_loss: 1.2268e-04 - val_mean_absolute_error: 0.0081
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5764e-04 - mean_absolute_error: 0.0088 - val_loss: 1.6093e-04 - val_mean_absolute_error: 0.0095
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2936e-04 - mean_absolute_error: 0.0079 - val_loss: 3.3949e-04 - val_mean_absolute_error: 0.0160
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6375e-04 - mean_absolute_error: 0.0090 - val_loss: 1.3078e-04 - val_mean_absolute_error: 0.0086
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5787e-04 - mean_absolute_error: 0.0089 - val_loss: 1.9110e-04 - val_mean_absolute_error: 0.0108
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6528e-04 - mean_absolute_error: 0.0089 - val_loss: 1.3095e-04 - val_mean_absolute_error: 0.0082
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3886e-04 - mean_absolute_error: 0.0079 - val_loss: 1.2057e-04 - val_mean_absolute_error: 0.0079
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4270e-04 - mean_absolute_error: 0.0081 - val_loss: 1.5175e-04 - val_mean_absolute_error: 0.0091
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4478e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2468e-04 - val_mean_absolute_error: 0.0082
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7443e-04 - mean_absolute_error: 0.0094 - val_loss: 2.1643e-04 - val_mean_absolute_error: 0.0118
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.4026e-04 - mean_absolute_error: 0.0084 - val_loss: 1.9055e-04 - val_mean_absolute_error: 0.0112
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6489e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2224e-04 - val_mean_absolute_error: 0.0081
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2338e-04 - mean_absolute_error: 0.0077 - val_loss: 1.2280e-04 - val_mean_absolute_error: 0.0081
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3402e-04 - mean_absolute_error: 0.0078 - val_loss: 1.7031e-04 - val_mean_absolute_error: 0.0104
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3997e-04 - mean_absolute_error: 0.0080 - val_loss: 1.4188e-04 - val_mean_absolute_error: 0.0092

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 633021.0520042328
# RMSE: 795.6262011800723
# MAE: 593.2092100348606
# MAPE: 1.7676684057448693 %
#
# Model evalution on validate set
# MSE: 3510365.2813211237
# RMSE: 1873.5968833559484
# MAE: 1254.7157799586778
# MAPE: 2.662181012481001 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step

# %%
y_pred_30_days
# Out:
# array([[62887.285],
#        [62498.758],
#        [62850.625],
#        [62799.89 ],
#        [62833.555],
#        [62827.434],
#        [62830.68 ],
#        [62829.98 ],
#        [62830.28 ],
#        [62830.23 ],
#        [62830.23 ],
#        [62830.24 ],
#        [62830.23 ],
#        [62830.23 ],
#        [62830.242],
#        [62830.227],
#        [62830.23 ],
#        [62830.24 ],
#        [62830.227],
#        [62830.24 ],
#        [62830.24 ],
#        [62830.23 ],
#        [62830.23 ],
#        [62830.23 ],
#        [62830.227],
#        [62830.23 ],
#        [62830.24 ],
#        [62830.23 ],
#        [62830.24 ],
#        [62830.227],
#        [62830.24 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Forecast Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Forecast the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
