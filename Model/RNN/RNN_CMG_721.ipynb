# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: CMG - Test/Train/Vaildation: 70/20/10
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 869.4067839959008
# - MAE: 651.7954354457171
# - MAPE: 1.926241875026581 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 0  # 7 2 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((908, 10), (908,), (251, 10), (251,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 0.0131 - mean_absolute_error: 0.0774 - val_loss: 4.4922e-04 - val_mean_absolute_error: 0.0163
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.7077e-04 - mean_absolute_error: 0.0203 - val_loss: 4.7130e-04 - val_mean_absolute_error: 0.0167
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.4620e-04 - mean_absolute_error: 0.0150 - val_loss: 2.7189e-04 - val_mean_absolute_error: 0.0122
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7935e-04 - mean_absolute_error: 0.0136 - val_loss: 2.6428e-04 - val_mean_absolute_error: 0.0119
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.9220e-04 - mean_absolute_error: 0.0120 - val_loss: 2.7411e-04 - val_mean_absolute_error: 0.0122
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.9220e-04 - mean_absolute_error: 0.0119 - val_loss: 3.2589e-04 - val_mean_absolute_error: 0.0139
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.8360e-04 - mean_absolute_error: 0.0117 - val_loss: 2.0512e-04 - val_mean_absolute_error: 0.0107
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8980e-04 - mean_absolute_error: 0.0116 - val_loss: 2.0965e-04 - val_mean_absolute_error: 0.0109
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.8857e-04 - mean_absolute_error: 0.0119 - val_loss: 2.5119e-04 - val_mean_absolute_error: 0.0126
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.9028e-04 - mean_absolute_error: 0.0121 - val_loss: 6.3426e-04 - val_mean_absolute_error: 0.0220
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.8672e-04 - mean_absolute_error: 0.0121 - val_loss: 1.9646e-04 - val_mean_absolute_error: 0.0105
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.7558e-04 - mean_absolute_error: 0.0117 - val_loss: 4.8177e-04 - val_mean_absolute_error: 0.0194
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.7235e-04 - mean_absolute_error: 0.0115 - val_loss: 3.1716e-04 - val_mean_absolute_error: 0.0149
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5728e-04 - mean_absolute_error: 0.0119 - val_loss: 1.9132e-04 - val_mean_absolute_error: 0.0104
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.6449e-04 - mean_absolute_error: 0.0111 - val_loss: 6.4768e-04 - val_mean_absolute_error: 0.0232
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5021e-04 - mean_absolute_error: 0.0115 - val_loss: 1.6883e-04 - val_mean_absolute_error: 0.0094
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.4580e-04 - mean_absolute_error: 0.0107 - val_loss: 3.5010e-04 - val_mean_absolute_error: 0.0159
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.5547e-04 - mean_absolute_error: 0.0116 - val_loss: 3.4750e-04 - val_mean_absolute_error: 0.0158
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.5820e-04 - mean_absolute_error: 0.0118 - val_loss: 3.3537e-04 - val_mean_absolute_error: 0.0152
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.2222e-04 - mean_absolute_error: 0.0104 - val_loss: 1.5459e-04 - val_mean_absolute_error: 0.0088
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.9261e-04 - mean_absolute_error: 0.0094 - val_loss: 2.5751e-04 - val_mean_absolute_error: 0.0127
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.7021e-04 - mean_absolute_error: 0.0112 - val_loss: 1.7224e-04 - val_mean_absolute_error: 0.0097
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1149e-04 - mean_absolute_error: 0.0101 - val_loss: 1.6042e-04 - val_mean_absolute_error: 0.0091
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.2004e-04 - mean_absolute_error: 0.0102 - val_loss: 1.9163e-04 - val_mean_absolute_error: 0.0105
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0780e-04 - mean_absolute_error: 0.0104 - val_loss: 1.5484e-04 - val_mean_absolute_error: 0.0089
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0027e-04 - mean_absolute_error: 0.0098 - val_loss: 1.4394e-04 - val_mean_absolute_error: 0.0085
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8701e-04 - mean_absolute_error: 0.0095 - val_loss: 2.3296e-04 - val_mean_absolute_error: 0.0120
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2460e-04 - mean_absolute_error: 0.0102 - val_loss: 1.5193e-04 - val_mean_absolute_error: 0.0088
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8570e-04 - mean_absolute_error: 0.0092 - val_loss: 5.0709e-04 - val_mean_absolute_error: 0.0201
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0049e-04 - mean_absolute_error: 0.0098 - val_loss: 1.4983e-04 - val_mean_absolute_error: 0.0088
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2180e-04 - mean_absolute_error: 0.0104 - val_loss: 3.4933e-04 - val_mean_absolute_error: 0.0161
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3093e-04 - mean_absolute_error: 0.0106 - val_loss: 2.4593e-04 - val_mean_absolute_error: 0.0127
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9594e-04 - mean_absolute_error: 0.0098 - val_loss: 1.6243e-04 - val_mean_absolute_error: 0.0094
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7786e-04 - mean_absolute_error: 0.0092 - val_loss: 3.2151e-04 - val_mean_absolute_error: 0.0153
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9198e-04 - mean_absolute_error: 0.0093 - val_loss: 1.3193e-04 - val_mean_absolute_error: 0.0080
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8998e-04 - mean_absolute_error: 0.0094 - val_loss: 2.0292e-04 - val_mean_absolute_error: 0.0112
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6404e-04 - mean_absolute_error: 0.0088 - val_loss: 2.7380e-04 - val_mean_absolute_error: 0.0139
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1258e-04 - mean_absolute_error: 0.0101 - val_loss: 6.9635e-04 - val_mean_absolute_error: 0.0242
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.6064e-04 - mean_absolute_error: 0.0115 - val_loss: 3.1212e-04 - val_mean_absolute_error: 0.0151
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.5880e-04 - mean_absolute_error: 0.0115 - val_loss: 1.3570e-04 - val_mean_absolute_error: 0.0083
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4109e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2595e-04 - val_mean_absolute_error: 0.0078
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4842e-04 - mean_absolute_error: 0.0084 - val_loss: 3.2357e-04 - val_mean_absolute_error: 0.0156
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8069e-04 - mean_absolute_error: 0.0094 - val_loss: 1.3473e-04 - val_mean_absolute_error: 0.0083
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6511e-04 - mean_absolute_error: 0.0087 - val_loss: 1.5673e-04 - val_mean_absolute_error: 0.0094
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5069e-04 - mean_absolute_error: 0.0083 - val_loss: 1.4192e-04 - val_mean_absolute_error: 0.0087
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4252e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3522e-04 - val_mean_absolute_error: 0.0084
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5401e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2170e-04 - val_mean_absolute_error: 0.0077
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4391e-04 - mean_absolute_error: 0.0083 - val_loss: 5.3913e-04 - val_mean_absolute_error: 0.0211
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.2454e-04 - mean_absolute_error: 0.0106 - val_loss: 1.2385e-04 - val_mean_absolute_error: 0.0078
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4473e-04 - mean_absolute_error: 0.0082 - val_loss: 1.4434e-04 - val_mean_absolute_error: 0.0088
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5421e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2654e-04 - val_mean_absolute_error: 0.0081
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5230e-04 - mean_absolute_error: 0.0087 - val_loss: 1.3098e-04 - val_mean_absolute_error: 0.0081
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4990e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2502e-04 - val_mean_absolute_error: 0.0081
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5195e-04 - mean_absolute_error: 0.0082 - val_loss: 1.5119e-04 - val_mean_absolute_error: 0.0094
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8950e-04 - mean_absolute_error: 0.0098 - val_loss: 1.6621e-04 - val_mean_absolute_error: 0.0100
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7533e-04 - mean_absolute_error: 0.0097 - val_loss: 1.6976e-04 - val_mean_absolute_error: 0.0102
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5127e-04 - mean_absolute_error: 0.0085 - val_loss: 2.0469e-04 - val_mean_absolute_error: 0.0115
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4355e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2003e-04 - val_mean_absolute_error: 0.0078
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5107e-04 - mean_absolute_error: 0.0085 - val_loss: 1.3140e-04 - val_mean_absolute_error: 0.0085
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8401e-04 - mean_absolute_error: 0.0096 - val_loss: 1.4480e-04 - val_mean_absolute_error: 0.0088
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4700e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2541e-04 - val_mean_absolute_error: 0.0079
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.4486e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2100e-04 - val_mean_absolute_error: 0.0077
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4582e-04 - mean_absolute_error: 0.0083 - val_loss: 2.3311e-04 - val_mean_absolute_error: 0.0126
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5425e-04 - mean_absolute_error: 0.0085 - val_loss: 1.4787e-04 - val_mean_absolute_error: 0.0089
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5458e-04 - mean_absolute_error: 0.0086 - val_loss: 1.4417e-04 - val_mean_absolute_error: 0.0088
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.4497e-04 - mean_absolute_error: 0.0080 - val_loss: 1.1880e-04 - val_mean_absolute_error: 0.0078
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.7334e-04 - mean_absolute_error: 0.0087 - val_loss: 1.4033e-04 - val_mean_absolute_error: 0.0090
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4952e-04 - mean_absolute_error: 0.0085 - val_loss: 1.3000e-04 - val_mean_absolute_error: 0.0085
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7143e-04 - mean_absolute_error: 0.0088 - val_loss: 1.1896e-04 - val_mean_absolute_error: 0.0079
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6265e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2320e-04 - val_mean_absolute_error: 0.0081
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3960e-04 - mean_absolute_error: 0.0080 - val_loss: 1.3118e-04 - val_mean_absolute_error: 0.0086
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8556e-04 - mean_absolute_error: 0.0100 - val_loss: 1.2537e-04 - val_mean_absolute_error: 0.0079
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4310e-04 - mean_absolute_error: 0.0083 - val_loss: 1.9390e-04 - val_mean_absolute_error: 0.0110
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.6390e-04 - mean_absolute_error: 0.0087 - val_loss: 1.1842e-04 - val_mean_absolute_error: 0.0079
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4229e-04 - mean_absolute_error: 0.0081 - val_loss: 1.5148e-04 - val_mean_absolute_error: 0.0091
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4449e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3796e-04 - val_mean_absolute_error: 0.0089
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.3802e-04 - mean_absolute_error: 0.0081 - val_loss: 1.7169e-04 - val_mean_absolute_error: 0.0100
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3068e-04 - mean_absolute_error: 0.0079 - val_loss: 1.2888e-04 - val_mean_absolute_error: 0.0085
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5719e-04 - mean_absolute_error: 0.0084 - val_loss: 3.4790e-04 - val_mean_absolute_error: 0.0164
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8785e-04 - mean_absolute_error: 0.0098 - val_loss: 1.3607e-04 - val_mean_absolute_error: 0.0084
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3564e-04 - mean_absolute_error: 0.0078 - val_loss: 4.3345e-04 - val_mean_absolute_error: 0.0186
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8342e-04 - mean_absolute_error: 0.0095 - val_loss: 1.1843e-04 - val_mean_absolute_error: 0.0079
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8589e-04 - mean_absolute_error: 0.0098 - val_loss: 1.5132e-04 - val_mean_absolute_error: 0.0091
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4828e-04 - mean_absolute_error: 0.0083 - val_loss: 5.8172e-04 - val_mean_absolute_error: 0.0220
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2237e-04 - mean_absolute_error: 0.0108 - val_loss: 1.8163e-04 - val_mean_absolute_error: 0.0108
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5463e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2805e-04 - val_mean_absolute_error: 0.0080
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4787e-04 - mean_absolute_error: 0.0083 - val_loss: 1.1988e-04 - val_mean_absolute_error: 0.0079
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4334e-04 - mean_absolute_error: 0.0081 - val_loss: 2.6838e-04 - val_mean_absolute_error: 0.0140
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5133e-04 - mean_absolute_error: 0.0085 - val_loss: 1.8173e-04 - val_mean_absolute_error: 0.0105
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5278e-04 - mean_absolute_error: 0.0085 - val_loss: 1.1911e-04 - val_mean_absolute_error: 0.0079
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3124e-04 - mean_absolute_error: 0.0077 - val_loss: 1.2244e-04 - val_mean_absolute_error: 0.0081
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5580e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2299e-04 - val_mean_absolute_error: 0.0079
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4592e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2165e-04 - val_mean_absolute_error: 0.0078
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3758e-04 - mean_absolute_error: 0.0082 - val_loss: 1.3152e-04 - val_mean_absolute_error: 0.0087
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4877e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2001e-04 - val_mean_absolute_error: 0.0079
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3429e-04 - mean_absolute_error: 0.0080 - val_loss: 1.4013e-04 - val_mean_absolute_error: 0.0091
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4355e-04 - mean_absolute_error: 0.0082 - val_loss: 2.3763e-04 - val_mean_absolute_error: 0.0126
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4417e-04 - mean_absolute_error: 0.0082 - val_loss: 1.3929e-04 - val_mean_absolute_error: 0.0086
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5149e-04 - mean_absolute_error: 0.0082 - val_loss: 1.5762e-04 - val_mean_absolute_error: 0.0098
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7260e-04 - mean_absolute_error: 0.0093 - val_loss: 1.5943e-04 - val_mean_absolute_error: 0.0094
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5350e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2842e-04 - val_mean_absolute_error: 0.0081
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4828e-04 - mean_absolute_error: 0.0085 - val_loss: 1.8777e-04 - val_mean_absolute_error: 0.0107
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4645e-04 - mean_absolute_error: 0.0081 - val_loss: 2.5216e-04 - val_mean_absolute_error: 0.0132
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5093e-04 - mean_absolute_error: 0.0086 - val_loss: 1.3362e-04 - val_mean_absolute_error: 0.0088
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5029e-04 - mean_absolute_error: 0.0084 - val_loss: 1.4311e-04 - val_mean_absolute_error: 0.0087
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4858e-04 - mean_absolute_error: 0.0082 - val_loss: 2.2425e-04 - val_mean_absolute_error: 0.0124
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5453e-04 - mean_absolute_error: 0.0089 - val_loss: 2.5354e-04 - val_mean_absolute_error: 0.0132
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7057e-04 - mean_absolute_error: 0.0093 - val_loss: 1.2204e-04 - val_mean_absolute_error: 0.0078
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5769e-04 - mean_absolute_error: 0.0084 - val_loss: 1.4496e-04 - val_mean_absolute_error: 0.0093
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5336e-04 - mean_absolute_error: 0.0085 - val_loss: 1.1976e-04 - val_mean_absolute_error: 0.0079
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3918e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2553e-04 - val_mean_absolute_error: 0.0080
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.5494e-04 - mean_absolute_error: 0.0083 - val_loss: 1.7086e-04 - val_mean_absolute_error: 0.0100
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4628e-04 - mean_absolute_error: 0.0082 - val_loss: 1.3161e-04 - val_mean_absolute_error: 0.0087
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5279e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2581e-04 - val_mean_absolute_error: 0.0083
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5327e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2001e-04 - val_mean_absolute_error: 0.0079
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4358e-04 - mean_absolute_error: 0.0081 - val_loss: 1.4237e-04 - val_mean_absolute_error: 0.0087
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5862e-04 - mean_absolute_error: 0.0083 - val_loss: 1.3838e-04 - val_mean_absolute_error: 0.0090
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.4821e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3240e-04 - val_mean_absolute_error: 0.0083
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3660e-04 - mean_absolute_error: 0.0079 - val_loss: 1.2070e-04 - val_mean_absolute_error: 0.0079
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2383e-04 - mean_absolute_error: 0.0078 - val_loss: 1.2015e-04 - val_mean_absolute_error: 0.0079
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5284e-04 - mean_absolute_error: 0.0085 - val_loss: 1.5867e-04 - val_mean_absolute_error: 0.0099
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6512e-04 - mean_absolute_error: 0.0089 - val_loss: 2.6240e-04 - val_mean_absolute_error: 0.0138
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3691e-04 - mean_absolute_error: 0.0081 - val_loss: 1.4772e-04 - val_mean_absolute_error: 0.0090
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4539e-04 - mean_absolute_error: 0.0082 - val_loss: 1.3634e-04 - val_mean_absolute_error: 0.0089
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3972e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2205e-04 - val_mean_absolute_error: 0.0080
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4438e-04 - mean_absolute_error: 0.0081 - val_loss: 1.9517e-04 - val_mean_absolute_error: 0.0114
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.5369e-04 - mean_absolute_error: 0.0083 - val_loss: 1.3106e-04 - val_mean_absolute_error: 0.0086
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4445e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2495e-04 - val_mean_absolute_error: 0.0083
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4352e-04 - mean_absolute_error: 0.0083 - val_loss: 1.3776e-04 - val_mean_absolute_error: 0.0085
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3834e-04 - mean_absolute_error: 0.0079 - val_loss: 1.3003e-04 - val_mean_absolute_error: 0.0082
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4847e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2568e-04 - val_mean_absolute_error: 0.0083
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3890e-04 - mean_absolute_error: 0.0078 - val_loss: 1.2318e-04 - val_mean_absolute_error: 0.0082
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.4338e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2344e-04 - val_mean_absolute_error: 0.0082
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6926e-04 - mean_absolute_error: 0.0091 - val_loss: 1.8648e-04 - val_mean_absolute_error: 0.0106
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2894e-04 - mean_absolute_error: 0.0078 - val_loss: 1.4016e-04 - val_mean_absolute_error: 0.0086
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3916e-04 - mean_absolute_error: 0.0080 - val_loss: 1.7224e-04 - val_mean_absolute_error: 0.0101
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5028e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2061e-04 - val_mean_absolute_error: 0.0079
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2821e-04 - mean_absolute_error: 0.0077 - val_loss: 1.9920e-04 - val_mean_absolute_error: 0.0111
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4392e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2103e-04 - val_mean_absolute_error: 0.0080
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3347e-04 - mean_absolute_error: 0.0078 - val_loss: 1.4100e-04 - val_mean_absolute_error: 0.0086
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6059e-04 - mean_absolute_error: 0.0090 - val_loss: 1.4377e-04 - val_mean_absolute_error: 0.0088
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3151e-04 - mean_absolute_error: 0.0079 - val_loss: 1.8982e-04 - val_mean_absolute_error: 0.0112
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4414e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2165e-04 - val_mean_absolute_error: 0.0080
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3214e-04 - mean_absolute_error: 0.0078 - val_loss: 1.8773e-04 - val_mean_absolute_error: 0.0111
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.0440e-04 - mean_absolute_error: 0.0105 - val_loss: 2.1126e-04 - val_mean_absolute_error: 0.0116
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.0282e-04 - mean_absolute_error: 0.0100 - val_loss: 2.3497e-04 - val_mean_absolute_error: 0.0125
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5373e-04 - mean_absolute_error: 0.0086 - val_loss: 2.0264e-04 - val_mean_absolute_error: 0.0113
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4480e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2397e-04 - val_mean_absolute_error: 0.0080
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4638e-04 - mean_absolute_error: 0.0083 - val_loss: 1.6032e-04 - val_mean_absolute_error: 0.0100
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3850e-04 - mean_absolute_error: 0.0082 - val_loss: 2.1231e-04 - val_mean_absolute_error: 0.0117
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4387e-04 - mean_absolute_error: 0.0084 - val_loss: 1.5314e-04 - val_mean_absolute_error: 0.0097
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5572e-04 - mean_absolute_error: 0.0090 - val_loss: 1.2100e-04 - val_mean_absolute_error: 0.0080
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3111e-04 - mean_absolute_error: 0.0078 - val_loss: 1.2521e-04 - val_mean_absolute_error: 0.0082
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4070e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2147e-04 - val_mean_absolute_error: 0.0079
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3870e-04 - mean_absolute_error: 0.0078 - val_loss: 1.2036e-04 - val_mean_absolute_error: 0.0079
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2963e-04 - mean_absolute_error: 0.0078 - val_loss: 1.2152e-04 - val_mean_absolute_error: 0.0081
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3246e-04 - mean_absolute_error: 0.0078 - val_loss: 1.2232e-04 - val_mean_absolute_error: 0.0081
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2241e-04 - mean_absolute_error: 0.0076 - val_loss: 1.2451e-04 - val_mean_absolute_error: 0.0080
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3488e-04 - mean_absolute_error: 0.0078 - val_loss: 1.2668e-04 - val_mean_absolute_error: 0.0084
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5014e-04 - mean_absolute_error: 0.0084 - val_loss: 1.6833e-04 - val_mean_absolute_error: 0.0099
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5894e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2597e-04 - val_mean_absolute_error: 0.0080
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4829e-04 - mean_absolute_error: 0.0083 - val_loss: 1.3136e-04 - val_mean_absolute_error: 0.0086
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4030e-04 - mean_absolute_error: 0.0078 - val_loss: 1.3520e-04 - val_mean_absolute_error: 0.0084
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7846e-04 - mean_absolute_error: 0.0092 - val_loss: 1.2182e-04 - val_mean_absolute_error: 0.0080
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2790e-04 - mean_absolute_error: 0.0077 - val_loss: 1.8470e-04 - val_mean_absolute_error: 0.0105
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6114e-04 - mean_absolute_error: 0.0090 - val_loss: 1.2954e-04 - val_mean_absolute_error: 0.0085
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2778e-04 - mean_absolute_error: 0.0080 - val_loss: 1.3182e-04 - val_mean_absolute_error: 0.0083
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3782e-04 - mean_absolute_error: 0.0085 - val_loss: 2.2099e-04 - val_mean_absolute_error: 0.0120
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6366e-04 - mean_absolute_error: 0.0086 - val_loss: 1.4706e-04 - val_mean_absolute_error: 0.0089
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3144e-04 - mean_absolute_error: 0.0081 - val_loss: 1.2836e-04 - val_mean_absolute_error: 0.0082
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4862e-04 - mean_absolute_error: 0.0084 - val_loss: 1.8465e-04 - val_mean_absolute_error: 0.0110
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7138e-04 - mean_absolute_error: 0.0091 - val_loss: 1.6246e-04 - val_mean_absolute_error: 0.0101
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6538e-04 - mean_absolute_error: 0.0093 - val_loss: 1.2180e-04 - val_mean_absolute_error: 0.0079
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5276e-04 - mean_absolute_error: 0.0085 - val_loss: 1.4560e-04 - val_mean_absolute_error: 0.0093
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4639e-04 - mean_absolute_error: 0.0083 - val_loss: 2.1685e-04 - val_mean_absolute_error: 0.0122
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5996e-04 - mean_absolute_error: 0.0087 - val_loss: 1.3784e-04 - val_mean_absolute_error: 0.0090
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.2723e-04 - mean_absolute_error: 0.0114 - val_loss: 2.4315e-04 - val_mean_absolute_error: 0.0131
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.9043e-04 - mean_absolute_error: 0.0099 - val_loss: 1.2364e-04 - val_mean_absolute_error: 0.0081
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.4487e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2830e-04 - val_mean_absolute_error: 0.0084
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.3568e-04 - mean_absolute_error: 0.0081 - val_loss: 1.3488e-04 - val_mean_absolute_error: 0.0088
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6274e-04 - mean_absolute_error: 0.0088 - val_loss: 1.7998e-04 - val_mean_absolute_error: 0.0108
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.3894e-04 - mean_absolute_error: 0.0083 - val_loss: 1.3713e-04 - val_mean_absolute_error: 0.0085
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4103e-04 - mean_absolute_error: 0.0081 - val_loss: 1.2175e-04 - val_mean_absolute_error: 0.0081
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3258e-04 - mean_absolute_error: 0.0078 - val_loss: 1.2689e-04 - val_mean_absolute_error: 0.0080
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3952e-04 - mean_absolute_error: 0.0082 - val_loss: 2.1456e-04 - val_mean_absolute_error: 0.0117
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4881e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2393e-04 - val_mean_absolute_error: 0.0081
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5686e-04 - mean_absolute_error: 0.0088 - val_loss: 1.3508e-04 - val_mean_absolute_error: 0.0083
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3837e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2065e-04 - val_mean_absolute_error: 0.0080
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3516e-04 - mean_absolute_error: 0.0077 - val_loss: 1.2711e-04 - val_mean_absolute_error: 0.0084
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3581e-04 - mean_absolute_error: 0.0078 - val_loss: 1.2235e-04 - val_mean_absolute_error: 0.0079
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6012e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2113e-04 - val_mean_absolute_error: 0.0080
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4858e-04 - mean_absolute_error: 0.0082 - val_loss: 1.4404e-04 - val_mean_absolute_error: 0.0088
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3421e-04 - mean_absolute_error: 0.0079 - val_loss: 1.9185e-04 - val_mean_absolute_error: 0.0109
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5539e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2094e-04 - val_mean_absolute_error: 0.0080
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7414e-04 - mean_absolute_error: 0.0091 - val_loss: 1.3743e-04 - val_mean_absolute_error: 0.0085
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4169e-04 - mean_absolute_error: 0.0079 - val_loss: 1.5919e-04 - val_mean_absolute_error: 0.0095
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4101e-04 - mean_absolute_error: 0.0081 - val_loss: 1.3318e-04 - val_mean_absolute_error: 0.0083
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6074e-04 - mean_absolute_error: 0.0091 - val_loss: 1.2784e-04 - val_mean_absolute_error: 0.0084
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5404e-04 - mean_absolute_error: 0.0087 - val_loss: 1.8672e-04 - val_mean_absolute_error: 0.0106
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6289e-04 - mean_absolute_error: 0.0085 - val_loss: 1.7061e-04 - val_mean_absolute_error: 0.0100

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 755868.1560580949
# RMSE: 869.4067839959008
# MAE: 651.7954354457171
# MAPE: 1.926241875026581 %
#
# Model evalution on validate set
# MSE: 4357139.892344072
# RMSE: 2087.376317855521
# MAE: 1384.1266787190082
# MAPE: 2.924820069283885 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step

# %%
y_pred_30_days
# Out:
# array([[62090.63 ],
#        [61611.57 ],
#        [61960.547],
#        [61911.676],
#        [61954.016],
#        [61948.117],
#        [61953.37 ],
#        [61952.66 ],
#        [61953.312],
#        [61953.23 ],
#        [61953.32 ],
#        [61953.312],
#        [61953.324],
#        [61953.32 ],
#        [61953.324],
#        [61953.32 ],
#        [61953.332],
#        [61953.32 ],
#        [61953.332],
#        [61953.324],
#        [61953.324],
#        [61953.324],
#        [61953.332],
#        [61953.32 ],
#        [61953.324],
#        [61953.324],
#        [61953.324],
#        [61953.332],
#        [61953.324],
#        [61953.324],
#        [61953.324]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Predict the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
