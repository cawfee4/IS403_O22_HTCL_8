# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: CMG - Test/Train/Vaildation: 70/20/10
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 766.8431818692948
# - MAE: 555.2558360308765
# - MAPE: 1.6549177548688214 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 0  # 7 2 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((908, 10), (908,), (251, 10), (251,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_1 (SimpleRNN)        │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0230 - mean_absolute_error: 0.0993 - val_loss: 0.0034 - val_mean_absolute_error: 0.0547
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.1719e-04 - mean_absolute_error: 0.0220 - val_loss: 5.1910e-04 - val_mean_absolute_error: 0.0182
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7299e-04 - mean_absolute_error: 0.0174 - val_loss: 5.1095e-04 - val_mean_absolute_error: 0.0176
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4644e-04 - mean_absolute_error: 0.0152 - val_loss: 3.9385e-04 - val_mean_absolute_error: 0.0150
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9898e-04 - mean_absolute_error: 0.0146 - val_loss: 3.5199e-04 - val_mean_absolute_error: 0.0140
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7699e-04 - mean_absolute_error: 0.0137 - val_loss: 2.8593e-04 - val_mean_absolute_error: 0.0136
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7018e-04 - mean_absolute_error: 0.0140 - val_loss: 2.5488e-04 - val_mean_absolute_error: 0.0126
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.3603e-04 - mean_absolute_error: 0.0129 - val_loss: 3.0290e-04 - val_mean_absolute_error: 0.0143
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7899e-04 - mean_absolute_error: 0.0140 - val_loss: 2.2127e-04 - val_mean_absolute_error: 0.0106
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4922e-04 - mean_absolute_error: 0.0132 - val_loss: 2.5973e-04 - val_mean_absolute_error: 0.0118
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.2033e-04 - mean_absolute_error: 0.0125 - val_loss: 2.1861e-04 - val_mean_absolute_error: 0.0114
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2950e-04 - mean_absolute_error: 0.0107 - val_loss: 2.1521e-04 - val_mean_absolute_error: 0.0113
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.8328e-04 - mean_absolute_error: 0.0118 - val_loss: 8.2863e-04 - val_mean_absolute_error: 0.0266
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3365e-04 - mean_absolute_error: 0.0131 - val_loss: 3.3409e-04 - val_mean_absolute_error: 0.0155
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8435e-04 - mean_absolute_error: 0.0119 - val_loss: 2.0383e-04 - val_mean_absolute_error: 0.0109
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5011e-04 - mean_absolute_error: 0.0112 - val_loss: 3.8080e-04 - val_mean_absolute_error: 0.0160
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.6443e-04 - mean_absolute_error: 0.0112 - val_loss: 1.7508e-04 - val_mean_absolute_error: 0.0096
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.4299e-04 - mean_absolute_error: 0.0105 - val_loss: 2.7151e-04 - val_mean_absolute_error: 0.0136
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2902e-04 - mean_absolute_error: 0.0104 - val_loss: 1.6845e-04 - val_mean_absolute_error: 0.0091
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.3065e-04 - mean_absolute_error: 0.0104 - val_loss: 3.0821e-04 - val_mean_absolute_error: 0.0141
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4282e-04 - mean_absolute_error: 0.0107 - val_loss: 7.9139e-04 - val_mean_absolute_error: 0.0254
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.0182e-04 - mean_absolute_error: 0.0122 - val_loss: 1.8628e-04 - val_mean_absolute_error: 0.0104
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3506e-04 - mean_absolute_error: 0.0107 - val_loss: 1.8164e-04 - val_mean_absolute_error: 0.0097
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0321e-04 - mean_absolute_error: 0.0096 - val_loss: 2.8483e-04 - val_mean_absolute_error: 0.0136
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2864e-04 - mean_absolute_error: 0.0106 - val_loss: 3.9105e-04 - val_mean_absolute_error: 0.0168
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.2094e-04 - mean_absolute_error: 0.0102 - val_loss: 1.7848e-04 - val_mean_absolute_error: 0.0096
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.2692e-04 - mean_absolute_error: 0.0103 - val_loss: 2.3292e-04 - val_mean_absolute_error: 0.0118
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0869e-04 - mean_absolute_error: 0.0101 - val_loss: 2.5668e-04 - val_mean_absolute_error: 0.0127
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7927e-04 - mean_absolute_error: 0.0093 - val_loss: 1.4758e-04 - val_mean_absolute_error: 0.0086
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0015e-04 - mean_absolute_error: 0.0098 - val_loss: 2.4756e-04 - val_mean_absolute_error: 0.0128
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1591e-04 - mean_absolute_error: 0.0102 - val_loss: 4.1531e-04 - val_mean_absolute_error: 0.0176
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5780e-04 - mean_absolute_error: 0.0112 - val_loss: 6.3817e-04 - val_mean_absolute_error: 0.0228
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1219e-04 - mean_absolute_error: 0.0125 - val_loss: 3.5150e-04 - val_mean_absolute_error: 0.0159
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4853e-04 - mean_absolute_error: 0.0114 - val_loss: 2.9523e-04 - val_mean_absolute_error: 0.0145
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9431e-04 - mean_absolute_error: 0.0101 - val_loss: 1.6829e-04 - val_mean_absolute_error: 0.0095
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9052e-04 - mean_absolute_error: 0.0094 - val_loss: 1.5143e-04 - val_mean_absolute_error: 0.0088
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9119e-04 - mean_absolute_error: 0.0093 - val_loss: 1.8247e-04 - val_mean_absolute_error: 0.0101
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9630e-04 - mean_absolute_error: 0.0093 - val_loss: 1.5626e-04 - val_mean_absolute_error: 0.0090
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7509e-04 - mean_absolute_error: 0.0090 - val_loss: 1.5128e-04 - val_mean_absolute_error: 0.0089
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8191e-04 - mean_absolute_error: 0.0094 - val_loss: 2.0667e-04 - val_mean_absolute_error: 0.0112
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.9276e-04 - mean_absolute_error: 0.0093 - val_loss: 1.3974e-04 - val_mean_absolute_error: 0.0083
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8681e-04 - mean_absolute_error: 0.0094 - val_loss: 3.3225e-04 - val_mean_absolute_error: 0.0157
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9879e-04 - mean_absolute_error: 0.0101 - val_loss: 1.3508e-04 - val_mean_absolute_error: 0.0081
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7063e-04 - mean_absolute_error: 0.0089 - val_loss: 2.1784e-04 - val_mean_absolute_error: 0.0117
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.6933e-04 - mean_absolute_error: 0.0089 - val_loss: 2.5079e-04 - val_mean_absolute_error: 0.0131
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8086e-04 - mean_absolute_error: 0.0093 - val_loss: 1.4198e-04 - val_mean_absolute_error: 0.0085
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7113e-04 - mean_absolute_error: 0.0091 - val_loss: 1.2996e-04 - val_mean_absolute_error: 0.0080
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7394e-04 - mean_absolute_error: 0.0091 - val_loss: 1.4561e-04 - val_mean_absolute_error: 0.0087
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8596e-04 - mean_absolute_error: 0.0093 - val_loss: 1.2867e-04 - val_mean_absolute_error: 0.0079
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6712e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2853e-04 - val_mean_absolute_error: 0.0079
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6306e-04 - mean_absolute_error: 0.0087 - val_loss: 4.0753e-04 - val_mean_absolute_error: 0.0178
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1778e-04 - mean_absolute_error: 0.0102 - val_loss: 1.4394e-04 - val_mean_absolute_error: 0.0086
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.9853e-04 - mean_absolute_error: 0.0096 - val_loss: 1.2789e-04 - val_mean_absolute_error: 0.0079
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5393e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2583e-04 - val_mean_absolute_error: 0.0078
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7042e-04 - mean_absolute_error: 0.0091 - val_loss: 1.2585e-04 - val_mean_absolute_error: 0.0078
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0268e-04 - mean_absolute_error: 0.0101 - val_loss: 1.3502e-04 - val_mean_absolute_error: 0.0083
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6748e-04 - mean_absolute_error: 0.0090 - val_loss: 1.9536e-04 - val_mean_absolute_error: 0.0111
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8384e-04 - mean_absolute_error: 0.0097 - val_loss: 1.2954e-04 - val_mean_absolute_error: 0.0081
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5843e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2389e-04 - val_mean_absolute_error: 0.0078
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6729e-04 - mean_absolute_error: 0.0090 - val_loss: 1.8256e-04 - val_mean_absolute_error: 0.0105
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2850e-04 - mean_absolute_error: 0.0077 - val_loss: 1.2916e-04 - val_mean_absolute_error: 0.0080
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4864e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2341e-04 - val_mean_absolute_error: 0.0078
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5173e-04 - mean_absolute_error: 0.0085 - val_loss: 1.4655e-04 - val_mean_absolute_error: 0.0090
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7510e-04 - mean_absolute_error: 0.0087 - val_loss: 2.3420e-04 - val_mean_absolute_error: 0.0127
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6407e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2515e-04 - val_mean_absolute_error: 0.0080
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3599e-04 - mean_absolute_error: 0.0078 - val_loss: 1.8912e-04 - val_mean_absolute_error: 0.0108
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7116e-04 - mean_absolute_error: 0.0089 - val_loss: 3.1574e-04 - val_mean_absolute_error: 0.0153
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8040e-04 - mean_absolute_error: 0.0095 - val_loss: 1.5511e-04 - val_mean_absolute_error: 0.0093
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6160e-04 - mean_absolute_error: 0.0086 - val_loss: 1.9868e-04 - val_mean_absolute_error: 0.0112
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6464e-04 - mean_absolute_error: 0.0090 - val_loss: 1.2112e-04 - val_mean_absolute_error: 0.0076
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4492e-04 - mean_absolute_error: 0.0080 - val_loss: 1.5457e-04 - val_mean_absolute_error: 0.0095
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5746e-04 - mean_absolute_error: 0.0085 - val_loss: 1.3138e-04 - val_mean_absolute_error: 0.0084
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6091e-04 - mean_absolute_error: 0.0087 - val_loss: 1.1939e-04 - val_mean_absolute_error: 0.0078
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7223e-04 - mean_absolute_error: 0.0087 - val_loss: 1.8265e-04 - val_mean_absolute_error: 0.0107
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6908e-04 - mean_absolute_error: 0.0093 - val_loss: 1.8862e-04 - val_mean_absolute_error: 0.0108
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5166e-04 - mean_absolute_error: 0.0084 - val_loss: 1.1880e-04 - val_mean_absolute_error: 0.0077
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5496e-04 - mean_absolute_error: 0.0084 - val_loss: 2.5607e-04 - val_mean_absolute_error: 0.0134
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4934e-04 - mean_absolute_error: 0.0086 - val_loss: 1.3214e-04 - val_mean_absolute_error: 0.0085
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6067e-04 - mean_absolute_error: 0.0092 - val_loss: 1.9575e-04 - val_mean_absolute_error: 0.0111
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7033e-04 - mean_absolute_error: 0.0094 - val_loss: 1.4928e-04 - val_mean_absolute_error: 0.0090
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5094e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3311e-04 - val_mean_absolute_error: 0.0086
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5835e-04 - mean_absolute_error: 0.0086 - val_loss: 1.6434e-04 - val_mean_absolute_error: 0.0097
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3811e-04 - mean_absolute_error: 0.0083 - val_loss: 1.3479e-04 - val_mean_absolute_error: 0.0083
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4369e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2080e-04 - val_mean_absolute_error: 0.0077
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5583e-04 - mean_absolute_error: 0.0085 - val_loss: 1.1928e-04 - val_mean_absolute_error: 0.0078
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4215e-04 - mean_absolute_error: 0.0080 - val_loss: 2.2607e-04 - val_mean_absolute_error: 0.0125
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.8359e-04 - mean_absolute_error: 0.0091 - val_loss: 1.1849e-04 - val_mean_absolute_error: 0.0077
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3503e-04 - mean_absolute_error: 0.0078 - val_loss: 2.1741e-04 - val_mean_absolute_error: 0.0122
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4903e-04 - mean_absolute_error: 0.0082 - val_loss: 1.5549e-04 - val_mean_absolute_error: 0.0096
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3655e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2340e-04 - val_mean_absolute_error: 0.0081
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3180e-04 - mean_absolute_error: 0.0076 - val_loss: 1.2234e-04 - val_mean_absolute_error: 0.0081
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3902e-04 - mean_absolute_error: 0.0081 - val_loss: 1.2033e-04 - val_mean_absolute_error: 0.0077
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3928e-04 - mean_absolute_error: 0.0081 - val_loss: 1.3050e-04 - val_mean_absolute_error: 0.0086
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4619e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2084e-04 - val_mean_absolute_error: 0.0081
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4883e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2134e-04 - val_mean_absolute_error: 0.0081
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5332e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2495e-04 - val_mean_absolute_error: 0.0082
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4251e-04 - mean_absolute_error: 0.0081 - val_loss: 2.2213e-04 - val_mean_absolute_error: 0.0121
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6813e-04 - mean_absolute_error: 0.0091 - val_loss: 1.4893e-04 - val_mean_absolute_error: 0.0090
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3642e-04 - mean_absolute_error: 0.0079 - val_loss: 1.3349e-04 - val_mean_absolute_error: 0.0083
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5467e-04 - mean_absolute_error: 0.0083 - val_loss: 1.4925e-04 - val_mean_absolute_error: 0.0094
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4812e-04 - mean_absolute_error: 0.0085 - val_loss: 2.6182e-04 - val_mean_absolute_error: 0.0138
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.8904e-04 - mean_absolute_error: 0.0095 - val_loss: 1.2201e-04 - val_mean_absolute_error: 0.0078
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6909e-04 - mean_absolute_error: 0.0088 - val_loss: 1.6226e-04 - val_mean_absolute_error: 0.0100
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5577e-04 - mean_absolute_error: 0.0087 - val_loss: 1.1994e-04 - val_mean_absolute_error: 0.0077
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5053e-04 - mean_absolute_error: 0.0083 - val_loss: 2.2022e-04 - val_mean_absolute_error: 0.0122
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7396e-04 - mean_absolute_error: 0.0094 - val_loss: 1.3852e-04 - val_mean_absolute_error: 0.0085
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5618e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2819e-04 - val_mean_absolute_error: 0.0085
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3205e-04 - mean_absolute_error: 0.0080 - val_loss: 1.3664e-04 - val_mean_absolute_error: 0.0084
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6180e-04 - mean_absolute_error: 0.0086 - val_loss: 1.1937e-04 - val_mean_absolute_error: 0.0079
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5230e-04 - mean_absolute_error: 0.0081 - val_loss: 1.4427e-04 - val_mean_absolute_error: 0.0088
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3957e-04 - mean_absolute_error: 0.0081 - val_loss: 1.7141e-04 - val_mean_absolute_error: 0.0104
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5844e-04 - mean_absolute_error: 0.0088 - val_loss: 1.6885e-04 - val_mean_absolute_error: 0.0099
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5540e-04 - mean_absolute_error: 0.0086 - val_loss: 2.2678e-04 - val_mean_absolute_error: 0.0123
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5787e-04 - mean_absolute_error: 0.0089 - val_loss: 1.1856e-04 - val_mean_absolute_error: 0.0078
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.3962e-04 - mean_absolute_error: 0.0080 - val_loss: 2.5975e-04 - val_mean_absolute_error: 0.0135
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.5820e-04 - mean_absolute_error: 0.0087 - val_loss: 1.3606e-04 - val_mean_absolute_error: 0.0089
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.6413e-04 - mean_absolute_error: 0.0090 - val_loss: 2.3497e-04 - val_mean_absolute_error: 0.0126
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4027e-04 - mean_absolute_error: 0.0083 - val_loss: 1.1921e-04 - val_mean_absolute_error: 0.0079
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7143e-04 - mean_absolute_error: 0.0094 - val_loss: 1.9832e-04 - val_mean_absolute_error: 0.0114
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6140e-04 - mean_absolute_error: 0.0091 - val_loss: 1.3845e-04 - val_mean_absolute_error: 0.0086
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3803e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2500e-04 - val_mean_absolute_error: 0.0083
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5954e-04 - mean_absolute_error: 0.0091 - val_loss: 1.3542e-04 - val_mean_absolute_error: 0.0084
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4159e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2846e-04 - val_mean_absolute_error: 0.0081
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.4125e-04 - mean_absolute_error: 0.0078 - val_loss: 1.7950e-04 - val_mean_absolute_error: 0.0103
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7979e-04 - mean_absolute_error: 0.0091 - val_loss: 1.3249e-04 - val_mean_absolute_error: 0.0082
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3690e-04 - mean_absolute_error: 0.0078 - val_loss: 1.2290e-04 - val_mean_absolute_error: 0.0079
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3828e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2196e-04 - val_mean_absolute_error: 0.0079
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3705e-04 - mean_absolute_error: 0.0080 - val_loss: 1.9891e-04 - val_mean_absolute_error: 0.0115
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.8034e-04 - mean_absolute_error: 0.0092 - val_loss: 1.2324e-04 - val_mean_absolute_error: 0.0079
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7708e-04 - mean_absolute_error: 0.0095 - val_loss: 1.8560e-04 - val_mean_absolute_error: 0.0106
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6423e-04 - mean_absolute_error: 0.0092 - val_loss: 2.0014e-04 - val_mean_absolute_error: 0.0115
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7436e-04 - mean_absolute_error: 0.0094 - val_loss: 2.8510e-04 - val_mean_absolute_error: 0.0143
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5844e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2695e-04 - val_mean_absolute_error: 0.0081
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3630e-04 - mean_absolute_error: 0.0081 - val_loss: 1.9292e-04 - val_mean_absolute_error: 0.0109
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4096e-04 - mean_absolute_error: 0.0082 - val_loss: 1.5978e-04 - val_mean_absolute_error: 0.0099
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6197e-04 - mean_absolute_error: 0.0090 - val_loss: 1.2083e-04 - val_mean_absolute_error: 0.0079
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6005e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2076e-04 - val_mean_absolute_error: 0.0080
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7325e-04 - mean_absolute_error: 0.0088 - val_loss: 1.4409e-04 - val_mean_absolute_error: 0.0092
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.3939e-04 - mean_absolute_error: 0.0086 - val_loss: 3.8835e-04 - val_mean_absolute_error: 0.0173
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4944e-04 - mean_absolute_error: 0.0088 - val_loss: 1.9333e-04 - val_mean_absolute_error: 0.0113
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5269e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2076e-04 - val_mean_absolute_error: 0.0079
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5348e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2111e-04 - val_mean_absolute_error: 0.0080
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4373e-04 - mean_absolute_error: 0.0082 - val_loss: 1.5476e-04 - val_mean_absolute_error: 0.0093
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.6985e-04 - mean_absolute_error: 0.0090 - val_loss: 1.5405e-04 - val_mean_absolute_error: 0.0097
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5579e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2097e-04 - val_mean_absolute_error: 0.0080
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3148e-04 - mean_absolute_error: 0.0078 - val_loss: 3.4066e-04 - val_mean_absolute_error: 0.0160
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.5314e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3392e-04 - val_mean_absolute_error: 0.0088
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4497e-04 - mean_absolute_error: 0.0081 - val_loss: 1.6542e-04 - val_mean_absolute_error: 0.0097
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4252e-04 - mean_absolute_error: 0.0079 - val_loss: 1.2898e-04 - val_mean_absolute_error: 0.0085
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4024e-04 - mean_absolute_error: 0.0082 - val_loss: 1.4270e-04 - val_mean_absolute_error: 0.0087
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5340e-04 - mean_absolute_error: 0.0084 - val_loss: 1.7615e-04 - val_mean_absolute_error: 0.0106
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5320e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2837e-04 - val_mean_absolute_error: 0.0085
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6293e-04 - mean_absolute_error: 0.0088 - val_loss: 2.3300e-04 - val_mean_absolute_error: 0.0125
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6805e-04 - mean_absolute_error: 0.0090 - val_loss: 1.3846e-04 - val_mean_absolute_error: 0.0090
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7272e-04 - mean_absolute_error: 0.0092 - val_loss: 1.2823e-04 - val_mean_absolute_error: 0.0085
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3296e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2110e-04 - val_mean_absolute_error: 0.0080
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2752e-04 - mean_absolute_error: 0.0075 - val_loss: 1.6665e-04 - val_mean_absolute_error: 0.0098
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3581e-04 - mean_absolute_error: 0.0079 - val_loss: 1.9200e-04 - val_mean_absolute_error: 0.0109
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4534e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2680e-04 - val_mean_absolute_error: 0.0084
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4459e-04 - mean_absolute_error: 0.0083 - val_loss: 1.7723e-04 - val_mean_absolute_error: 0.0102
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4212e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2543e-04 - val_mean_absolute_error: 0.0081
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6096e-04 - mean_absolute_error: 0.0086 - val_loss: 1.4932e-04 - val_mean_absolute_error: 0.0090
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3740e-04 - mean_absolute_error: 0.0079 - val_loss: 1.7078e-04 - val_mean_absolute_error: 0.0104
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5217e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2074e-04 - val_mean_absolute_error: 0.0080
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2649e-04 - mean_absolute_error: 0.0077 - val_loss: 1.2075e-04 - val_mean_absolute_error: 0.0079
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3121e-04 - mean_absolute_error: 0.0077 - val_loss: 1.3619e-04 - val_mean_absolute_error: 0.0084
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4439e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2059e-04 - val_mean_absolute_error: 0.0080
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4681e-04 - mean_absolute_error: 0.0081 - val_loss: 1.2835e-04 - val_mean_absolute_error: 0.0085
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6038e-04 - mean_absolute_error: 0.0093 - val_loss: 1.5167e-04 - val_mean_absolute_error: 0.0091
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3374e-04 - mean_absolute_error: 0.0077 - val_loss: 1.4916e-04 - val_mean_absolute_error: 0.0090
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4285e-04 - mean_absolute_error: 0.0079 - val_loss: 2.7799e-04 - val_mean_absolute_error: 0.0142
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9362e-04 - mean_absolute_error: 0.0097 - val_loss: 1.2038e-04 - val_mean_absolute_error: 0.0079
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4064e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2848e-04 - val_mean_absolute_error: 0.0085
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4781e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2305e-04 - val_mean_absolute_error: 0.0081
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4316e-04 - mean_absolute_error: 0.0085 - val_loss: 2.3368e-04 - val_mean_absolute_error: 0.0125
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4303e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2132e-04 - val_mean_absolute_error: 0.0079
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.5038e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2071e-04 - val_mean_absolute_error: 0.0079
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5800e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2156e-04 - val_mean_absolute_error: 0.0081
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3567e-04 - mean_absolute_error: 0.0079 - val_loss: 1.5209e-04 - val_mean_absolute_error: 0.0096
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5999e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2186e-04 - val_mean_absolute_error: 0.0079
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3376e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2658e-04 - val_mean_absolute_error: 0.0081
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5432e-04 - mean_absolute_error: 0.0090 - val_loss: 1.2369e-04 - val_mean_absolute_error: 0.0080
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4135e-04 - mean_absolute_error: 0.0079 - val_loss: 1.3396e-04 - val_mean_absolute_error: 0.0084
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3421e-04 - mean_absolute_error: 0.0079 - val_loss: 1.2384e-04 - val_mean_absolute_error: 0.0082
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3419e-04 - mean_absolute_error: 0.0080 - val_loss: 2.1515e-04 - val_mean_absolute_error: 0.0121
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4722e-04 - mean_absolute_error: 0.0085 - val_loss: 2.7043e-04 - val_mean_absolute_error: 0.0140
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4382e-04 - mean_absolute_error: 0.0084 - val_loss: 1.9242e-04 - val_mean_absolute_error: 0.0109
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.4486e-04 - mean_absolute_error: 0.0081 - val_loss: 1.2395e-04 - val_mean_absolute_error: 0.0080
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4681e-04 - mean_absolute_error: 0.0081 - val_loss: 1.3499e-04 - val_mean_absolute_error: 0.0084
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.4397e-04 - mean_absolute_error: 0.0083 - val_loss: 1.6492e-04 - val_mean_absolute_error: 0.0102
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.6410e-04 - mean_absolute_error: 0.0090 - val_loss: 1.3121e-04 - val_mean_absolute_error: 0.0087
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6012e-04 - mean_absolute_error: 0.0090 - val_loss: 1.4175e-04 - val_mean_absolute_error: 0.0087
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2997e-04 - mean_absolute_error: 0.0080 - val_loss: 1.3540e-04 - val_mean_absolute_error: 0.0085
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4274e-04 - mean_absolute_error: 0.0083 - val_loss: 2.1096e-04 - val_mean_absolute_error: 0.0119
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7425e-04 - mean_absolute_error: 0.0100 - val_loss: 3.2914e-04 - val_mean_absolute_error: 0.0156
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5392e-04 - mean_absolute_error: 0.0085 - val_loss: 1.3783e-04 - val_mean_absolute_error: 0.0085
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5072e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2965e-04 - val_mean_absolute_error: 0.0086
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5076e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2297e-04 - val_mean_absolute_error: 0.0079
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6667e-04 - mean_absolute_error: 0.0089 - val_loss: 1.2483e-04 - val_mean_absolute_error: 0.0080
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4343e-04 - mean_absolute_error: 0.0081 - val_loss: 1.2064e-04 - val_mean_absolute_error: 0.0080

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 588048.4655794243
# RMSE: 766.8431818692948
# MAE: 555.2558360308765
# MAPE: 1.6549177548688214 %
#
# Model evalution on validate set
# MSE: 3779021.711658194
# RMSE: 1943.9706046281137
# MAE: 1235.6413675103306
# MAPE: 2.5852495050206015 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 703ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step

# %%
y_pred_30_days
# Out:
# array([[62338.54 ],
#        [61948.38 ],
#        [62308.41 ],
#        [62160.82 ],
#        [62287.54 ],
#        [62242.7  ],
#        [62271.406],
#        [62258.195],
#        [62266.133],
#        [62262.406],
#        [62264.508],
#        [62263.45 ],
#        [62264.035],
#        [62263.746],
#        [62263.883],
#        [62263.816],
#        [62263.86 ],
#        [62263.84 ],
#        [62263.848],
#        [62263.848],
#        [62263.84 ],
#        [62263.84 ],
#        [62263.848],
#        [62263.84 ],
#        [62263.84 ],
#        [62263.85 ],
#        [62263.848],
#        [62263.84 ],
#        [62263.848],
#        [62263.848],
#        [62263.848]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Forecast Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Forecast the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
