# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Input

plt.style.use('default')

# %% [markdown]
# ## 1. Data preprocessing

# %%
split_type = [0.8,0.7,0.9]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 0

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        6900
# 1        7100
# 2        7100
# 3        7170
# 4        7170
#         ...
# 1308    11300
# 1309    12050
# 1310    12600
# 1311    12500
# 1312    12700
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using neural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split] * len(df_scaled))
test_size = len(df_scaled) - train_size

# %%
# Splitting data into train, test set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size:]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test set
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1039, 10), (1039,), (252, 10), (252,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
UNITS = 64

# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(UNITS),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 64)             │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,289 (16.75 KB)
#  Trainable params: 4,289 (16.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0202 - mean_absolute_error: 0.0995
# Epoch 2/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.1846e-04 - mean_absolute_error: 0.0201
# Epoch 3/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.0730e-04 - mean_absolute_error: 0.0172
# Epoch 4/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.9067e-04 - mean_absolute_error: 0.0168
# Epoch 5/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.7805e-04 - mean_absolute_error: 0.0171
# Epoch 6/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.4545e-04 - mean_absolute_error: 0.0158
# Epoch 7/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.1256e-04 - mean_absolute_error: 0.0145
# Epoch 8/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.2615e-04 - mean_absolute_error: 0.0151
# Epoch 9/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.7429e-04 - mean_absolute_error: 0.0156
# Epoch 10/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.4701e-04 - mean_absolute_error: 0.0162
# Epoch 11/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.1941e-04 - mean_absolute_error: 0.0143
# Epoch 12/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4717e-04 - mean_absolute_error: 0.0136
# Epoch 13/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9843e-04 - mean_absolute_error: 0.0146
# Epoch 14/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.6852e-04 - mean_absolute_error: 0.0140
# Epoch 15/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.1673e-04 - mean_absolute_error: 0.0149
# Epoch 16/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7823e-04 - mean_absolute_error: 0.0145
# Epoch 17/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.3508e-04 - mean_absolute_error: 0.0183
# Epoch 18/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.6593e-04 - mean_absolute_error: 0.0155
# Epoch 19/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.2551e-04 - mean_absolute_error: 0.0148
# Epoch 20/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0149e-04 - mean_absolute_error: 0.0145
# Epoch 21/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5198e-04 - mean_absolute_error: 0.0142
# Epoch 22/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.3055e-04 - mean_absolute_error: 0.0174
# Epoch 23/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.0231e-04 - mean_absolute_error: 0.0166
# Epoch 24/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6436e-04 - mean_absolute_error: 0.0141
# Epoch 25/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7929e-04 - mean_absolute_error: 0.0125
# Epoch 26/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8364e-04 - mean_absolute_error: 0.0130
# Epoch 27/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3580e-04 - mean_absolute_error: 0.0157
# Epoch 28/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2711e-04 - mean_absolute_error: 0.0140
# Epoch 29/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4109e-04 - mean_absolute_error: 0.0137
# Epoch 30/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0128e-04 - mean_absolute_error: 0.0135
# Epoch 31/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3526e-04 - mean_absolute_error: 0.0137
# Epoch 32/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6419e-04 - mean_absolute_error: 0.0124
# Epoch 33/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2706e-04 - mean_absolute_error: 0.0144
# Epoch 34/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7629e-04 - mean_absolute_error: 0.0122
# Epoch 35/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8694e-04 - mean_absolute_error: 0.0127
# Epoch 36/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5505e-04 - mean_absolute_error: 0.0150
# Epoch 37/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0832e-04 - mean_absolute_error: 0.0138
# Epoch 38/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4375e-04 - mean_absolute_error: 0.0141
# Epoch 39/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6670e-04 - mean_absolute_error: 0.0126
# Epoch 40/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.6178e-04 - mean_absolute_error: 0.0144
# Epoch 41/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6512e-04 - mean_absolute_error: 0.0125
# Epoch 42/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0680e-04 - mean_absolute_error: 0.0115
# Epoch 43/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4767e-04 - mean_absolute_error: 0.0124
# Epoch 44/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8338e-04 - mean_absolute_error: 0.0129
# Epoch 45/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5246e-04 - mean_absolute_error: 0.0139
# Epoch 46/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2643e-04 - mean_absolute_error: 0.0136
# Epoch 47/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9215e-04 - mean_absolute_error: 0.0133
# Epoch 48/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6122e-04 - mean_absolute_error: 0.0126
# Epoch 49/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2795e-04 - mean_absolute_error: 0.0125
# Epoch 50/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6395e-04 - mean_absolute_error: 0.0124
# Epoch 51/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9470e-04 - mean_absolute_error: 0.0131
# Epoch 52/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6691e-04 - mean_absolute_error: 0.0127
# Epoch 53/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4891e-04 - mean_absolute_error: 0.0141
# Epoch 54/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7393e-04 - mean_absolute_error: 0.0129
# Epoch 55/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8411e-04 - mean_absolute_error: 0.0134
# Epoch 56/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8183e-04 - mean_absolute_error: 0.0129
# Epoch 57/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3064e-04 - mean_absolute_error: 0.0142
# Epoch 58/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6913e-04 - mean_absolute_error: 0.0128
# Epoch 59/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7878e-04 - mean_absolute_error: 0.0144
# Epoch 60/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4544e-04 - mean_absolute_error: 0.0123
# Epoch 61/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.9504e-04 - mean_absolute_error: 0.0153
# Epoch 62/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8172e-04 - mean_absolute_error: 0.0125
# Epoch 63/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0512e-04 - mean_absolute_error: 0.0132
# Epoch 64/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8769e-04 - mean_absolute_error: 0.0129
# Epoch 65/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.3743e-04 - mean_absolute_error: 0.0135
# Epoch 66/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7836e-04 - mean_absolute_error: 0.0132
# Epoch 67/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9603e-04 - mean_absolute_error: 0.0134
# Epoch 68/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2544e-04 - mean_absolute_error: 0.0118
# Epoch 69/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5019e-04 - mean_absolute_error: 0.0127
# Epoch 70/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7554e-04 - mean_absolute_error: 0.0129
# Epoch 71/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3800e-04 - mean_absolute_error: 0.0121
# Epoch 72/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0903e-04 - mean_absolute_error: 0.0139
# Epoch 73/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1352e-04 - mean_absolute_error: 0.0142
# Epoch 74/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3296e-04 - mean_absolute_error: 0.0135
# Epoch 75/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7752e-04 - mean_absolute_error: 0.0129
# Epoch 76/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5017e-04 - mean_absolute_error: 0.0123
# Epoch 77/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8478e-04 - mean_absolute_error: 0.0129
# Epoch 78/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6376e-04 - mean_absolute_error: 0.0126
# Epoch 79/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1209e-04 - mean_absolute_error: 0.0139
# Epoch 80/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6205e-04 - mean_absolute_error: 0.0127
# Epoch 81/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8011e-04 - mean_absolute_error: 0.0160
# Epoch 82/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2582e-04 - mean_absolute_error: 0.0138
# Epoch 83/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8055e-04 - mean_absolute_error: 0.0129
# Epoch 84/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8041e-04 - mean_absolute_error: 0.0129
# Epoch 85/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8719e-04 - mean_absolute_error: 0.0130
# Epoch 86/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1223e-04 - mean_absolute_error: 0.0145
# Epoch 87/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7586e-04 - mean_absolute_error: 0.0129
# Epoch 88/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7417e-04 - mean_absolute_error: 0.0130
# Epoch 89/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3813e-04 - mean_absolute_error: 0.0139
# Epoch 90/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6526e-04 - mean_absolute_error: 0.0127
# Epoch 91/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5926e-04 - mean_absolute_error: 0.0125
# Epoch 92/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8248e-04 - mean_absolute_error: 0.0133
# Epoch 93/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6824e-04 - mean_absolute_error: 0.0129
# Epoch 94/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7612e-04 - mean_absolute_error: 0.0130
# Epoch 95/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.2630e-04 - mean_absolute_error: 0.0118
# Epoch 96/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6761e-04 - mean_absolute_error: 0.0130
# Epoch 97/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.5315e-04 - mean_absolute_error: 0.0123
# Epoch 98/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9711e-04 - mean_absolute_error: 0.0138
# Epoch 99/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6302e-04 - mean_absolute_error: 0.0125
# Epoch 100/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1738e-04 - mean_absolute_error: 0.0135
# Epoch 101/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0671e-04 - mean_absolute_error: 0.0136
# Epoch 102/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8479e-04 - mean_absolute_error: 0.0131
# Epoch 103/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1779e-04 - mean_absolute_error: 0.0120
# Epoch 104/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8555e-04 - mean_absolute_error: 0.0134
# Epoch 105/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0757e-04 - mean_absolute_error: 0.0135
# Epoch 106/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8983e-04 - mean_absolute_error: 0.0133
# Epoch 107/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.2731e-04 - mean_absolute_error: 0.0121
# Epoch 108/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.7311e-04 - mean_absolute_error: 0.0146
# Epoch 109/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4248e-04 - mean_absolute_error: 0.0124
# Epoch 110/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7160e-04 - mean_absolute_error: 0.0126
# Epoch 111/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1589e-04 - mean_absolute_error: 0.0145
# Epoch 112/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8368e-04 - mean_absolute_error: 0.0126
# Epoch 113/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2257e-04 - mean_absolute_error: 0.0136
# Epoch 114/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6621e-04 - mean_absolute_error: 0.0129
# Epoch 115/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6675e-04 - mean_absolute_error: 0.0130
# Epoch 116/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5362e-04 - mean_absolute_error: 0.0126
# Epoch 117/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6554e-04 - mean_absolute_error: 0.0128
# Epoch 118/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6088e-04 - mean_absolute_error: 0.0125
# Epoch 119/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8064e-04 - mean_absolute_error: 0.0130
# Epoch 120/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0178e-04 - mean_absolute_error: 0.0137
# Epoch 121/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.3079e-04 - mean_absolute_error: 0.0156
# Epoch 122/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9498e-04 - mean_absolute_error: 0.0130
# Epoch 123/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6653e-04 - mean_absolute_error: 0.0124
# Epoch 124/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3317e-04 - mean_absolute_error: 0.0141
# Epoch 125/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6174e-04 - mean_absolute_error: 0.0126
# Epoch 126/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7852e-04 - mean_absolute_error: 0.0130
# Epoch 127/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2112e-04 - mean_absolute_error: 0.0134
# Epoch 128/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6582e-04 - mean_absolute_error: 0.0135
# Epoch 129/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.6572e-04 - mean_absolute_error: 0.0149
# Epoch 130/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.4493e-04 - mean_absolute_error: 0.0162
# Epoch 131/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0886e-04 - mean_absolute_error: 0.0136
# Epoch 132/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4322e-04 - mean_absolute_error: 0.0122
# Epoch 133/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4700e-04 - mean_absolute_error: 0.0118
# Epoch 134/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5028e-04 - mean_absolute_error: 0.0126
# Epoch 135/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5823e-04 - mean_absolute_error: 0.0125
# Epoch 136/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.6227e-04 - mean_absolute_error: 0.0143
# Epoch 137/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6027e-04 - mean_absolute_error: 0.0124
# Epoch 138/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5838e-04 - mean_absolute_error: 0.0127
# Epoch 139/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4747e-04 - mean_absolute_error: 0.0125
# Epoch 140/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6753e-04 - mean_absolute_error: 0.0127
# Epoch 141/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6544e-04 - mean_absolute_error: 0.0129
# Epoch 142/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5833e-04 - mean_absolute_error: 0.0130
# Epoch 143/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8419e-04 - mean_absolute_error: 0.0132
# Epoch 144/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4973e-04 - mean_absolute_error: 0.0123
# Epoch 145/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3693e-04 - mean_absolute_error: 0.0125
# Epoch 146/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7958e-04 - mean_absolute_error: 0.0128
# Epoch 147/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4210e-04 - mean_absolute_error: 0.0124
# Epoch 148/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5426e-04 - mean_absolute_error: 0.0123
# Epoch 149/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5018e-04 - mean_absolute_error: 0.0124
# Epoch 150/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7486e-04 - mean_absolute_error: 0.0130
# Epoch 151/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2062e-04 - mean_absolute_error: 0.0141
# Epoch 152/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3433e-04 - mean_absolute_error: 0.0153
# Epoch 153/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.7538e-04 - mean_absolute_error: 0.0132
# Epoch 154/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1204e-04 - mean_absolute_error: 0.0132
# Epoch 155/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9870e-04 - mean_absolute_error: 0.0133
# Epoch 156/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8144e-04 - mean_absolute_error: 0.0132
# Epoch 157/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6455e-04 - mean_absolute_error: 0.0129
# Epoch 158/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8337e-04 - mean_absolute_error: 0.0127
# Epoch 159/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1445e-04 - mean_absolute_error: 0.0134
# Epoch 160/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8339e-04 - mean_absolute_error: 0.0133
# Epoch 161/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5052e-04 - mean_absolute_error: 0.0130
# Epoch 162/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4520e-04 - mean_absolute_error: 0.0140
# Epoch 163/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7046e-04 - mean_absolute_error: 0.0131
# Epoch 164/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9277e-04 - mean_absolute_error: 0.0133
# Epoch 165/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4290e-04 - mean_absolute_error: 0.0123
# Epoch 166/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7460e-04 - mean_absolute_error: 0.0129
# Epoch 167/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4996e-04 - mean_absolute_error: 0.0125
# Epoch 168/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8679e-04 - mean_absolute_error: 0.0132
# Epoch 169/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0101e-04 - mean_absolute_error: 0.0134
# Epoch 170/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4660e-04 - mean_absolute_error: 0.0124
# Epoch 171/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9686e-04 - mean_absolute_error: 0.0135
# Epoch 172/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6570e-04 - mean_absolute_error: 0.0129
# Epoch 173/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8842e-04 - mean_absolute_error: 0.0135
# Epoch 174/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1318e-04 - mean_absolute_error: 0.0137
# Epoch 175/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6592e-04 - mean_absolute_error: 0.0127
# Epoch 176/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9022e-04 - mean_absolute_error: 0.0133
# Epoch 177/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7326e-04 - mean_absolute_error: 0.0129
# Epoch 178/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8240e-04 - mean_absolute_error: 0.0134
# Epoch 179/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6178e-04 - mean_absolute_error: 0.0126
# Epoch 180/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0077e-04 - mean_absolute_error: 0.0135
# Epoch 181/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.2186e-04 - mean_absolute_error: 0.0138
# Epoch 182/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4121e-04 - mean_absolute_error: 0.0125
# Epoch 183/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3032e-04 - mean_absolute_error: 0.0129
# Epoch 184/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8549e-04 - mean_absolute_error: 0.0131
# Epoch 185/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9159e-04 - mean_absolute_error: 0.0134
# Epoch 186/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7850e-04 - mean_absolute_error: 0.0131
# Epoch 187/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7873e-04 - mean_absolute_error: 0.0131
# Epoch 188/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0937e-04 - mean_absolute_error: 0.0133
# Epoch 189/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2585e-04 - mean_absolute_error: 0.0122
# Epoch 190/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7625e-04 - mean_absolute_error: 0.0128
# Epoch 191/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7361e-04 - mean_absolute_error: 0.0130
# Epoch 192/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4511e-04 - mean_absolute_error: 0.0125
# Epoch 193/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0757e-04 - mean_absolute_error: 0.0140
# Epoch 194/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4397e-04 - mean_absolute_error: 0.0127
# Epoch 195/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4639e-04 - mean_absolute_error: 0.0127
# Epoch 196/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7637e-04 - mean_absolute_error: 0.0135
# Epoch 197/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0369e-04 - mean_absolute_error: 0.0135
# Epoch 198/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9237e-04 - mean_absolute_error: 0.0133
# Epoch 199/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8131e-04 - mean_absolute_error: 0.0129
# Epoch 200/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7603e-04 - mean_absolute_error: 0.0133

# %% [markdown]
# ### Predicting with test set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test set again to evaluate, because i shaped the data between 0 to 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 252
# 263

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)
# Out:
# Model evalution on test set
# MSE: 74267.3047886576
# RMSE: 272.5202832610035
# MAE: 191.92605251736111
# MAPE: 1.823531380594752 %

# %% [markdown]
# ## 4. Forecast the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(test_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
y_pred_30_days
# Out:
# array([[12917.113],
#        [12840.767],
#        [12949.971],
#        [12896.48 ],
#        [12952.782],
#        [12924.673],
#        [12947.086],
#        [12933.163],
#        [12943.786],
#        [12937.042],
#        [12941.841],
#        [12938.642],
#        [12940.893],
#        [12939.381],
#        [12940.425],
#        [12939.714],
#        [12940.203],
#        [12939.872],
#        [12940.1  ],
#        [12939.942],
#        [12940.052],
#        [12939.976],
#        [12940.028],
#        [12939.992],
#        [12940.017],
#        [12940.001],
#        [12940.011],
#        [12940.004],
#        [12940.01 ],
#        [12940.005],
#        [12940.008]], dtype=float32)

# %% [markdown]
# ### Continue forecast the next 60/90 days

# %%
y_pred_60_days = forecast(test_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
y_pred_90_days = forecast(test_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")

    # Predict test set
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        test_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Next {days} Days",
        linestyle="--",
    )

    plt.title(f"Forecast {stock_name[stock]} Stock Closing Price Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Forecast the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
