# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Input 

plt.style.use('default')

# %% [markdown]
# ## 1. Data preprocessing

# %%
split_type = [0.8,0.7,0.9]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 1  # 70% train, 30% test

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using neural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split] * len(df_scaled))
test_size = len(df_scaled) - train_size

# %%
# Splitting data into train, test set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size:]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test set
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((908, 10), (908,), (383, 10), (383,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
UNITS = 64

# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(UNITS),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 64)             │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,289 (16.75 KB)
#  Trainable params: 4,289 (16.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0132 - mean_absolute_error: 0.0838
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012 - mean_absolute_error: 0.0259
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.4376e-04 - mean_absolute_error: 0.0202
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.6547e-04 - mean_absolute_error: 0.0173
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5699e-04 - mean_absolute_error: 0.0154
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3115e-04 - mean_absolute_error: 0.0150
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9840e-04 - mean_absolute_error: 0.0145
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 3.6758e-04 - mean_absolute_error: 0.0139
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.0846e-04 - mean_absolute_error: 0.0125
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9159e-04 - mean_absolute_error: 0.0119
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6398e-04 - mean_absolute_error: 0.0114
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7367e-04 - mean_absolute_error: 0.0119
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.6476e-04 - mean_absolute_error: 0.0119
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3700e-04 - mean_absolute_error: 0.0132
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 2.4035e-04 - mean_absolute_error: 0.0109
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2585e-04 - mean_absolute_error: 0.0128
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4275e-04 - mean_absolute_error: 0.0157
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8988e-04 - mean_absolute_error: 0.0119
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - loss: 2.3771e-04 - mean_absolute_error: 0.0107
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 2.4224e-04 - mean_absolute_error: 0.0109
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 3.0365e-04 - mean_absolute_error: 0.0127
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - loss: 2.9985e-04 - mean_absolute_error: 0.0117
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 2.1258e-04 - mean_absolute_error: 0.0100
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - loss: 2.6833e-04 - mean_absolute_error: 0.0117
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - loss: 2.2645e-04 - mean_absolute_error: 0.0106
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 2.8887e-04 - mean_absolute_error: 0.0120
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4706e-04 - mean_absolute_error: 0.0111
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - loss: 2.8259e-04 - mean_absolute_error: 0.0121
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0454e-04 - mean_absolute_error: 0.0099
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 1.8600e-04 - mean_absolute_error: 0.0096
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1744e-04 - mean_absolute_error: 0.0102
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 1.7575e-04 - mean_absolute_error: 0.0090
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8436e-04 - mean_absolute_error: 0.0094
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6678e-04 - mean_absolute_error: 0.0093
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8663e-04 - mean_absolute_error: 0.0096
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0730e-04 - mean_absolute_error: 0.0100
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8195e-04 - mean_absolute_error: 0.0093
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - loss: 1.9425e-04 - mean_absolute_error: 0.0095
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - loss: 1.6364e-04 - mean_absolute_error: 0.0089
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 2.0514e-04 - mean_absolute_error: 0.0098
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 2.0648e-04 - mean_absolute_error: 0.0099
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9967e-04 - mean_absolute_error: 0.0097
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2632e-04 - mean_absolute_error: 0.0098
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9644e-04 - mean_absolute_error: 0.0095
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - loss: 1.5337e-04 - mean_absolute_error: 0.0084
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7558e-04 - mean_absolute_error: 0.0090
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6327e-04 - mean_absolute_error: 0.0089
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7882e-04 - mean_absolute_error: 0.0093
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7231e-04 - mean_absolute_error: 0.0092
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 1.7258e-04 - mean_absolute_error: 0.0093
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 1.7827e-04 - mean_absolute_error: 0.0092
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2961e-04 - mean_absolute_error: 0.0105
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5531e-04 - mean_absolute_error: 0.0086
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8040e-04 - mean_absolute_error: 0.0093
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7403e-04 - mean_absolute_error: 0.0090
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7336e-04 - mean_absolute_error: 0.0090
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9777e-04 - mean_absolute_error: 0.0100
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6886e-04 - mean_absolute_error: 0.0091
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6049e-04 - mean_absolute_error: 0.0087
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7117e-04 - mean_absolute_error: 0.0090
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6887e-04 - mean_absolute_error: 0.0087
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6093e-04 - mean_absolute_error: 0.0086
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4726e-04 - mean_absolute_error: 0.0083
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5114e-04 - mean_absolute_error: 0.0082
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5747e-04 - mean_absolute_error: 0.0085
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5158e-04 - mean_absolute_error: 0.0082
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6145e-04 - mean_absolute_error: 0.0088
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6427e-04 - mean_absolute_error: 0.0087
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5341e-04 - mean_absolute_error: 0.0092
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4218e-04 - mean_absolute_error: 0.0081
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4926e-04 - mean_absolute_error: 0.0082
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4949e-04 - mean_absolute_error: 0.0082
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5686e-04 - mean_absolute_error: 0.0083
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5435e-04 - mean_absolute_error: 0.0085
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6411e-04 - mean_absolute_error: 0.0088
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6276e-04 - mean_absolute_error: 0.0087
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6682e-04 - mean_absolute_error: 0.0086
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4227e-04 - mean_absolute_error: 0.0085
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8232e-04 - mean_absolute_error: 0.0092
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4680e-04 - mean_absolute_error: 0.0085
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4368e-04 - mean_absolute_error: 0.0083
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6241e-04 - mean_absolute_error: 0.0087
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7418e-04 - mean_absolute_error: 0.0090
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7218e-04 - mean_absolute_error: 0.0093
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5984e-04 - mean_absolute_error: 0.0086
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3709e-04 - mean_absolute_error: 0.0081
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3560e-04 - mean_absolute_error: 0.0079
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6806e-04 - mean_absolute_error: 0.0092
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8873e-04 - mean_absolute_error: 0.0094
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5927e-04 - mean_absolute_error: 0.0092
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6109e-04 - mean_absolute_error: 0.0085
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4295e-04 - mean_absolute_error: 0.0081
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6964e-04 - mean_absolute_error: 0.0094
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4862e-04 - mean_absolute_error: 0.0088
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8965e-04 - mean_absolute_error: 0.0099
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3834e-04 - mean_absolute_error: 0.0080
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3498e-04 - mean_absolute_error: 0.0082
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0501e-04 - mean_absolute_error: 0.0102
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3560e-04 - mean_absolute_error: 0.0078
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4028e-04 - mean_absolute_error: 0.0079
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6217e-04 - mean_absolute_error: 0.0087
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4318e-04 - mean_absolute_error: 0.0081
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4617e-04 - mean_absolute_error: 0.0081
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4444e-04 - mean_absolute_error: 0.0083
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4525e-04 - mean_absolute_error: 0.0083
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2532e-04 - mean_absolute_error: 0.0077
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2028e-04 - mean_absolute_error: 0.0074
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3516e-04 - mean_absolute_error: 0.0082
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3896e-04 - mean_absolute_error: 0.0080
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3619e-04 - mean_absolute_error: 0.0080
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6019e-04 - mean_absolute_error: 0.0084
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3999e-04 - mean_absolute_error: 0.0083
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2993e-04 - mean_absolute_error: 0.0078
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3855e-04 - mean_absolute_error: 0.0081
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2734e-04 - mean_absolute_error: 0.0077
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5385e-04 - mean_absolute_error: 0.0084
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4880e-04 - mean_absolute_error: 0.0084
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4819e-04 - mean_absolute_error: 0.0083
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - loss: 1.4019e-04 - mean_absolute_error: 0.0083
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4639e-04 - mean_absolute_error: 0.0085
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4266e-04 - mean_absolute_error: 0.0083
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - loss: 1.4839e-04 - mean_absolute_error: 0.0083
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - loss: 1.5389e-04 - mean_absolute_error: 0.0083
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6505e-04 - mean_absolute_error: 0.0094
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2541e-04 - mean_absolute_error: 0.0077
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4680e-04 - mean_absolute_error: 0.0087
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5179e-04 - mean_absolute_error: 0.0084
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3484e-04 - mean_absolute_error: 0.0078
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4733e-04 - mean_absolute_error: 0.0082
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4330e-04 - mean_absolute_error: 0.0084
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5167e-04 - mean_absolute_error: 0.0084
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3099e-04 - mean_absolute_error: 0.0079
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3383e-04 - mean_absolute_error: 0.0078
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5465e-04 - mean_absolute_error: 0.0085
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4631e-04 - mean_absolute_error: 0.0081
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4241e-04 - mean_absolute_error: 0.0082
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4725e-04 - mean_absolute_error: 0.0083
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3354e-04 - mean_absolute_error: 0.0079
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4083e-04 - mean_absolute_error: 0.0081
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6196e-04 - mean_absolute_error: 0.0087
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5028e-04 - mean_absolute_error: 0.0085
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3616e-04 - mean_absolute_error: 0.0081
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6325e-04 - mean_absolute_error: 0.0091
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5236e-04 - mean_absolute_error: 0.0084
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4434e-04 - mean_absolute_error: 0.0082
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 1.3325e-04 - mean_absolute_error: 0.0079
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6848e-04 - mean_absolute_error: 0.0087
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4623e-04 - mean_absolute_error: 0.0083
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3836e-04 - mean_absolute_error: 0.0081
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4858e-04 - mean_absolute_error: 0.0086
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5721e-04 - mean_absolute_error: 0.0085
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3759e-04 - mean_absolute_error: 0.0082
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6495e-04 - mean_absolute_error: 0.0090
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2513e-04 - mean_absolute_error: 0.0075
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3626e-04 - mean_absolute_error: 0.0080
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5172e-04 - mean_absolute_error: 0.0084
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4946e-04 - mean_absolute_error: 0.0083
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4523e-04 - mean_absolute_error: 0.0080
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6216e-04 - mean_absolute_error: 0.0087
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0619e-04 - mean_absolute_error: 0.0103
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5241e-04 - mean_absolute_error: 0.0083
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 1.4665e-04 - mean_absolute_error: 0.0084
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6090e-04 - mean_absolute_error: 0.0090
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7310e-04 - mean_absolute_error: 0.0094
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - loss: 1.8019e-04 - mean_absolute_error: 0.0097
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5460e-04 - mean_absolute_error: 0.0085
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3672e-04 - mean_absolute_error: 0.0079
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4389e-04 - mean_absolute_error: 0.0085
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4076e-04 - mean_absolute_error: 0.0083
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3690e-04 - mean_absolute_error: 0.0080
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5276e-04 - mean_absolute_error: 0.0083
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1842e-04 - mean_absolute_error: 0.0075
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3061e-04 - mean_absolute_error: 0.0078
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5657e-04 - mean_absolute_error: 0.0087
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6066e-04 - mean_absolute_error: 0.0091
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6922e-04 - mean_absolute_error: 0.0092
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7534e-04 - mean_absolute_error: 0.0098
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5978e-04 - mean_absolute_error: 0.0084
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5077e-04 - mean_absolute_error: 0.0082
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4305e-04 - mean_absolute_error: 0.0082
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4132e-04 - mean_absolute_error: 0.0083
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3284e-04 - mean_absolute_error: 0.0078
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3626e-04 - mean_absolute_error: 0.0080
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3986e-04 - mean_absolute_error: 0.0080
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 1.3594e-04 - mean_absolute_error: 0.0083
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - loss: 1.4935e-04 - mean_absolute_error: 0.0087
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6825e-04 - mean_absolute_error: 0.0091
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5476e-04 - mean_absolute_error: 0.0085
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7400e-04 - mean_absolute_error: 0.0096
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5268e-04 - mean_absolute_error: 0.0085
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3449e-04 - mean_absolute_error: 0.0076
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5002e-04 - mean_absolute_error: 0.0084
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3824e-04 - mean_absolute_error: 0.0078
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3184e-04 - mean_absolute_error: 0.0077
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7065e-04 - mean_absolute_error: 0.0089
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6085e-04 - mean_absolute_error: 0.0090
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - loss: 1.4430e-04 - mean_absolute_error: 0.0084
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - loss: 1.5416e-04 - mean_absolute_error: 0.0087
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 1.4222e-04 - mean_absolute_error: 0.0081
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5346e-04 - mean_absolute_error: 0.0085

# %% [markdown]
# ### Predicting with test set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test set again to evaluate, because i shaped the data between 0 to 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 383
# 394

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)
# Out:
# Model evalution on test set
# MSE: 1716235.036691541
# RMSE: 1310.0515397080915
# MAE: 803.0270428769583
# MAPE: 2.0223150643550234 %

# %% [markdown]
# ## 4. Forecast the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(test_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
y_pred_30_days
# Out:
# array([[62125.426],
#        [61692.46 ],
#        [61970.92 ],
#        [61942.72 ],
#        [61977.71 ],
#        [61973.6  ],
#        [61977.91 ],
#        [61977.477],
#        [61977.992],
#        [61977.938],
#        [61978.004],
#        [61977.992],
#        [61978.02 ],
#        [61978.004],
#        [61978.004],
#        [61978.004],
#        [61978.01 ],
#        [61978.004],
#        [61978.004],
#        [61978.004],
#        [61978.   ],
#        [61978.01 ],
#        [61978.004],
#        [61978.   ],
#        [61978.004],
#        [61978.004],
#        [61978.004],
#        [61978.004],
#        [61978.01 ],
#        [61978.01 ],
#        [61978.01 ]], dtype=float32)

# %% [markdown]
# ### Continue forecast the next 60/90 days

# %%
y_pred_60_days = forecast(test_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
y_pred_90_days = forecast(test_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")

    # Predict test set
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        test_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Next {days} Days",
        linestyle="--",
    )

    plt.title(f"Forecast {stock_name[stock]} Stock Closing Price Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Forecast the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
