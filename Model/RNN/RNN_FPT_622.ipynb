# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: FPT - Test/Train/Vaildation: 60/20/20
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 2082.693398048574
# - MAE: 1615.0599321464144
# - MAPE: 2.3782694048114132 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 1  # 6 2 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.tail()
# Out:
#              close
# time
# 2024-05-27  132800
# 2024-05-28  137000
# 2024-05-29  135700
# 2024-05-30  135000
# 2024-05-31  134600

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((776, 10), (776,), (251, 10), (251,), (253, 10), (253,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 0.0069 - mean_absolute_error: 0.0549 - val_loss: 0.0041 - val_mean_absolute_error: 0.0609
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.6410e-04 - mean_absolute_error: 0.0198 - val_loss: 0.0011 - val_mean_absolute_error: 0.0280
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.5704e-04 - mean_absolute_error: 0.0111 - val_loss: 3.3737e-04 - val_mean_absolute_error: 0.0130
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5588e-04 - mean_absolute_error: 0.0086 - val_loss: 3.1270e-04 - val_mean_absolute_error: 0.0124
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2243e-04 - mean_absolute_error: 0.0077 - val_loss: 3.3537e-04 - val_mean_absolute_error: 0.0137
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5330e-04 - mean_absolute_error: 0.0085 - val_loss: 2.7295e-04 - val_mean_absolute_error: 0.0115
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0976e-04 - mean_absolute_error: 0.0073 - val_loss: 2.5610e-04 - val_mean_absolute_error: 0.0112
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2391e-04 - mean_absolute_error: 0.0074 - val_loss: 2.6383e-04 - val_mean_absolute_error: 0.0119
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4141e-04 - mean_absolute_error: 0.0085 - val_loss: 3.1707e-04 - val_mean_absolute_error: 0.0139
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1910e-04 - mean_absolute_error: 0.0076 - val_loss: 4.2620e-04 - val_mean_absolute_error: 0.0169
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1419e-04 - mean_absolute_error: 0.0074 - val_loss: 2.2084e-04 - val_mean_absolute_error: 0.0105
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3170e-04 - mean_absolute_error: 0.0081 - val_loss: 2.4923e-04 - val_mean_absolute_error: 0.0118
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0606e-04 - mean_absolute_error: 0.0070 - val_loss: 2.1354e-04 - val_mean_absolute_error: 0.0103
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.5607e-05 - mean_absolute_error: 0.0060 - val_loss: 2.3499e-04 - val_mean_absolute_error: 0.0112
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0201e-04 - mean_absolute_error: 0.0069 - val_loss: 2.0413e-04 - val_mean_absolute_error: 0.0101
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.8370e-05 - mean_absolute_error: 0.0064 - val_loss: 1.9453e-04 - val_mean_absolute_error: 0.0097
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.9138e-05 - mean_absolute_error: 0.0064 - val_loss: 2.3647e-04 - val_mean_absolute_error: 0.0114
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.6970e-05 - mean_absolute_error: 0.0059 - val_loss: 2.3095e-04 - val_mean_absolute_error: 0.0114
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.6750e-05 - mean_absolute_error: 0.0067 - val_loss: 1.8955e-04 - val_mean_absolute_error: 0.0097
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.0010e-05 - mean_absolute_error: 0.0061 - val_loss: 1.9164e-04 - val_mean_absolute_error: 0.0097
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.5076e-05 - mean_absolute_error: 0.0068 - val_loss: 1.8723e-04 - val_mean_absolute_error: 0.0096
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0727e-04 - mean_absolute_error: 0.0071 - val_loss: 3.1815e-04 - val_mean_absolute_error: 0.0146
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.5489e-05 - mean_absolute_error: 0.0064 - val_loss: 1.7742e-04 - val_mean_absolute_error: 0.0092
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.0711e-05 - mean_absolute_error: 0.0058 - val_loss: 2.0827e-04 - val_mean_absolute_error: 0.0107
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.8256e-05 - mean_absolute_error: 0.0061 - val_loss: 2.2944e-04 - val_mean_absolute_error: 0.0116
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1224e-05 - mean_absolute_error: 0.0063 - val_loss: 1.7309e-04 - val_mean_absolute_error: 0.0091
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.3417e-05 - mean_absolute_error: 0.0058 - val_loss: 1.8533e-04 - val_mean_absolute_error: 0.0098
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.0253e-05 - mean_absolute_error: 0.0058 - val_loss: 2.6322e-04 - val_mean_absolute_error: 0.0130
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.8932e-05 - mean_absolute_error: 0.0065 - val_loss: 4.5382e-04 - val_mean_absolute_error: 0.0184
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.3920e-05 - mean_absolute_error: 0.0068 - val_loss: 1.6286e-04 - val_mean_absolute_error: 0.0087
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.9672e-05 - mean_absolute_error: 0.0055 - val_loss: 1.8404e-04 - val_mean_absolute_error: 0.0098
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6893e-05 - mean_absolute_error: 0.0057 - val_loss: 1.8089e-04 - val_mean_absolute_error: 0.0097
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.3951e-05 - mean_absolute_error: 0.0057 - val_loss: 1.5898e-04 - val_mean_absolute_error: 0.0086
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4322e-05 - mean_absolute_error: 0.0053 - val_loss: 1.6617e-04 - val_mean_absolute_error: 0.0091
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.2471e-05 - mean_absolute_error: 0.0057 - val_loss: 1.6019e-04 - val_mean_absolute_error: 0.0088
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.8084e-05 - mean_absolute_error: 0.0056 - val_loss: 1.5622e-04 - val_mean_absolute_error: 0.0085
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3513e-05 - mean_absolute_error: 0.0053 - val_loss: 1.6281e-04 - val_mean_absolute_error: 0.0090
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3540e-05 - mean_absolute_error: 0.0051 - val_loss: 1.9209e-04 - val_mean_absolute_error: 0.0103
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.4036e-05 - mean_absolute_error: 0.0056 - val_loss: 1.4985e-04 - val_mean_absolute_error: 0.0082
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.1290e-05 - mean_absolute_error: 0.0048 - val_loss: 2.8604e-04 - val_mean_absolute_error: 0.0140
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9165e-05 - mean_absolute_error: 0.0068 - val_loss: 1.6409e-04 - val_mean_absolute_error: 0.0092
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.8352e-05 - mean_absolute_error: 0.0055 - val_loss: 1.4847e-04 - val_mean_absolute_error: 0.0082
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.0689e-05 - mean_absolute_error: 0.0058 - val_loss: 1.4668e-04 - val_mean_absolute_error: 0.0081
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9089e-05 - mean_absolute_error: 0.0050 - val_loss: 1.4903e-04 - val_mean_absolute_error: 0.0084
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4376e-05 - mean_absolute_error: 0.0049 - val_loss: 2.1351e-04 - val_mean_absolute_error: 0.0115
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.2811e-05 - mean_absolute_error: 0.0054 - val_loss: 1.4233e-04 - val_mean_absolute_error: 0.0080
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.5190e-05 - mean_absolute_error: 0.0055 - val_loss: 3.1828e-04 - val_mean_absolute_error: 0.0151
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0906e-04 - mean_absolute_error: 0.0071 - val_loss: 1.4505e-04 - val_mean_absolute_error: 0.0082
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.6619e-05 - mean_absolute_error: 0.0051 - val_loss: 2.6428e-04 - val_mean_absolute_error: 0.0133
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.0058e-05 - mean_absolute_error: 0.0066 - val_loss: 1.3863e-04 - val_mean_absolute_error: 0.0078
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5737e-05 - mean_absolute_error: 0.0048 - val_loss: 1.6754e-04 - val_mean_absolute_error: 0.0096
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.4666e-05 - mean_absolute_error: 0.0055 - val_loss: 1.4627e-04 - val_mean_absolute_error: 0.0085
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.7352e-05 - mean_absolute_error: 0.0058 - val_loss: 1.4089e-04 - val_mean_absolute_error: 0.0082
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6747e-05 - mean_absolute_error: 0.0058 - val_loss: 1.4336e-04 - val_mean_absolute_error: 0.0084
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5468e-05 - mean_absolute_error: 0.0050 - val_loss: 1.5380e-04 - val_mean_absolute_error: 0.0089
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.0093e-05 - mean_absolute_error: 0.0054 - val_loss: 1.3759e-04 - val_mean_absolute_error: 0.0080
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.6263e-05 - mean_absolute_error: 0.0050 - val_loss: 1.3201e-04 - val_mean_absolute_error: 0.0077
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.9939e-05 - mean_absolute_error: 0.0047 - val_loss: 1.4695e-04 - val_mean_absolute_error: 0.0087
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.2015e-05 - mean_absolute_error: 0.0048 - val_loss: 1.5926e-04 - val_mean_absolute_error: 0.0094
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1716e-05 - mean_absolute_error: 0.0051 - val_loss: 1.4828e-04 - val_mean_absolute_error: 0.0089
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7652e-05 - mean_absolute_error: 0.0047 - val_loss: 1.5694e-04 - val_mean_absolute_error: 0.0092
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.3518e-05 - mean_absolute_error: 0.0050 - val_loss: 1.7281e-04 - val_mean_absolute_error: 0.0099
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7965e-05 - mean_absolute_error: 0.0051 - val_loss: 1.3439e-04 - val_mean_absolute_error: 0.0081
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1350e-05 - mean_absolute_error: 0.0051 - val_loss: 1.2694e-04 - val_mean_absolute_error: 0.0076
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.5318e-05 - mean_absolute_error: 0.0045 - val_loss: 1.2684e-04 - val_mean_absolute_error: 0.0076
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.7583e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2628e-04 - val_mean_absolute_error: 0.0075
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.6001e-05 - mean_absolute_error: 0.0046 - val_loss: 1.3180e-04 - val_mean_absolute_error: 0.0078
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.5590e-05 - mean_absolute_error: 0.0050 - val_loss: 1.3659e-04 - val_mean_absolute_error: 0.0084
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8076e-05 - mean_absolute_error: 0.0052 - val_loss: 1.2363e-04 - val_mean_absolute_error: 0.0075
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.9149e-05 - mean_absolute_error: 0.0055 - val_loss: 4.0141e-04 - val_mean_absolute_error: 0.0176
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3574e-04 - mean_absolute_error: 0.0083 - val_loss: 2.2894e-04 - val_mean_absolute_error: 0.0123
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6667e-05 - mean_absolute_error: 0.0059 - val_loss: 2.4731e-04 - val_mean_absolute_error: 0.0129
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.8244e-05 - mean_absolute_error: 0.0058 - val_loss: 1.3819e-04 - val_mean_absolute_error: 0.0083
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.5615e-05 - mean_absolute_error: 0.0051 - val_loss: 4.0110e-04 - val_mean_absolute_error: 0.0179
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.4030e-05 - mean_absolute_error: 0.0064 - val_loss: 1.4513e-04 - val_mean_absolute_error: 0.0087
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5408e-05 - mean_absolute_error: 0.0049 - val_loss: 1.2794e-04 - val_mean_absolute_error: 0.0077
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.6182e-05 - mean_absolute_error: 0.0046 - val_loss: 1.5348e-04 - val_mean_absolute_error: 0.0094
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.2495e-05 - mean_absolute_error: 0.0058 - val_loss: 1.5277e-04 - val_mean_absolute_error: 0.0094
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3285e-05 - mean_absolute_error: 0.0043 - val_loss: 1.1895e-04 - val_mean_absolute_error: 0.0073
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.8420e-05 - mean_absolute_error: 0.0049 - val_loss: 1.3961e-04 - val_mean_absolute_error: 0.0085
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2796e-05 - mean_absolute_error: 0.0050 - val_loss: 2.3364e-04 - val_mean_absolute_error: 0.0125
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.2304e-05 - mean_absolute_error: 0.0049 - val_loss: 1.1787e-04 - val_mean_absolute_error: 0.0072
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.5112e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1675e-04 - val_mean_absolute_error: 0.0072
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.4070e-05 - mean_absolute_error: 0.0044 - val_loss: 1.3889e-04 - val_mean_absolute_error: 0.0085
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.2848e-05 - mean_absolute_error: 0.0045 - val_loss: 1.9526e-04 - val_mean_absolute_error: 0.0111
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.6850e-05 - mean_absolute_error: 0.0052 - val_loss: 1.1561e-04 - val_mean_absolute_error: 0.0073
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.6892e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1516e-04 - val_mean_absolute_error: 0.0071
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.1051e-05 - mean_absolute_error: 0.0042 - val_loss: 1.1850e-04 - val_mean_absolute_error: 0.0073
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.3310e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1392e-04 - val_mean_absolute_error: 0.0072
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4276e-05 - mean_absolute_error: 0.0045 - val_loss: 1.3887e-04 - val_mean_absolute_error: 0.0088
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.1868e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1807e-04 - val_mean_absolute_error: 0.0076
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3288e-05 - mean_absolute_error: 0.0045 - val_loss: 1.1216e-04 - val_mean_absolute_error: 0.0070
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.2498e-05 - mean_absolute_error: 0.0050 - val_loss: 1.5407e-04 - val_mean_absolute_error: 0.0097
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.9446e-05 - mean_absolute_error: 0.0041 - val_loss: 1.5653e-04 - val_mean_absolute_error: 0.0094
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.0197e-05 - mean_absolute_error: 0.0051 - val_loss: 2.6731e-04 - val_mean_absolute_error: 0.0137
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.7786e-05 - mean_absolute_error: 0.0053 - val_loss: 1.1713e-04 - val_mean_absolute_error: 0.0073
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.3437e-05 - mean_absolute_error: 0.0044 - val_loss: 1.2354e-04 - val_mean_absolute_error: 0.0080
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.5606e-05 - mean_absolute_error: 0.0044 - val_loss: 1.2141e-04 - val_mean_absolute_error: 0.0078
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.5788e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1769e-04 - val_mean_absolute_error: 0.0076
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2229e-05 - mean_absolute_error: 0.0043 - val_loss: 1.1306e-04 - val_mean_absolute_error: 0.0071
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8489e-05 - mean_absolute_error: 0.0041 - val_loss: 1.1503e-04 - val_mean_absolute_error: 0.0074
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.4079e-05 - mean_absolute_error: 0.0043 - val_loss: 1.7583e-04 - val_mean_absolute_error: 0.0104
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.2646e-05 - mean_absolute_error: 0.0044 - val_loss: 1.0915e-04 - val_mean_absolute_error: 0.0069
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.7993e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1268e-04 - val_mean_absolute_error: 0.0072
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.8270e-05 - mean_absolute_error: 0.0048 - val_loss: 1.4991e-04 - val_mean_absolute_error: 0.0092
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.6518e-05 - mean_absolute_error: 0.0050 - val_loss: 1.3324e-04 - val_mean_absolute_error: 0.0086
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.2264e-05 - mean_absolute_error: 0.0062 - val_loss: 1.1554e-04 - val_mean_absolute_error: 0.0075
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3640e-05 - mean_absolute_error: 0.0056 - val_loss: 1.0921e-04 - val_mean_absolute_error: 0.0070
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.6311e-05 - mean_absolute_error: 0.0049 - val_loss: 1.0914e-04 - val_mean_absolute_error: 0.0069
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.2134e-05 - mean_absolute_error: 0.0044 - val_loss: 1.2517e-04 - val_mean_absolute_error: 0.0079
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.5105e-05 - mean_absolute_error: 0.0046 - val_loss: 1.5530e-04 - val_mean_absolute_error: 0.0095
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.7589e-05 - mean_absolute_error: 0.0042 - val_loss: 1.0877e-04 - val_mean_absolute_error: 0.0068
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8453e-05 - mean_absolute_error: 0.0042 - val_loss: 1.1067e-04 - val_mean_absolute_error: 0.0069
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.2231e-05 - mean_absolute_error: 0.0043 - val_loss: 1.0741e-04 - val_mean_absolute_error: 0.0068
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0974e-05 - mean_absolute_error: 0.0043 - val_loss: 1.6203e-04 - val_mean_absolute_error: 0.0099
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2975e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1371e-04 - val_mean_absolute_error: 0.0071
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.8631e-05 - mean_absolute_error: 0.0047 - val_loss: 1.6728e-04 - val_mean_absolute_error: 0.0104
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9966e-05 - mean_absolute_error: 0.0047 - val_loss: 1.0987e-04 - val_mean_absolute_error: 0.0069
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.6406e-05 - mean_absolute_error: 0.0045 - val_loss: 1.2566e-04 - val_mean_absolute_error: 0.0082
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.6631e-05 - mean_absolute_error: 0.0046 - val_loss: 1.4264e-04 - val_mean_absolute_error: 0.0092
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.0991e-05 - mean_absolute_error: 0.0048 - val_loss: 1.2822e-04 - val_mean_absolute_error: 0.0084
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0347e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1296e-04 - val_mean_absolute_error: 0.0074
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.7347e-05 - mean_absolute_error: 0.0045 - val_loss: 1.9737e-04 - val_mean_absolute_error: 0.0114
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.2200e-05 - mean_absolute_error: 0.0059 - val_loss: 1.3048e-04 - val_mean_absolute_error: 0.0082
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0615e-05 - mean_absolute_error: 0.0051 - val_loss: 1.1182e-04 - val_mean_absolute_error: 0.0073
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.2671e-05 - mean_absolute_error: 0.0046 - val_loss: 1.7909e-04 - val_mean_absolute_error: 0.0109
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7878e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3450e-04 - val_mean_absolute_error: 0.0088
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7162e-05 - mean_absolute_error: 0.0041 - val_loss: 1.7008e-04 - val_mean_absolute_error: 0.0105
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.2719e-05 - mean_absolute_error: 0.0050 - val_loss: 1.0699e-04 - val_mean_absolute_error: 0.0068
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 3.7177e-05 - mean_absolute_error: 0.0042 - val_loss: 1.6997e-04 - val_mean_absolute_error: 0.0105
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0593e-05 - mean_absolute_error: 0.0051 - val_loss: 1.0658e-04 - val_mean_absolute_error: 0.0068
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8559e-05 - mean_absolute_error: 0.0042 - val_loss: 1.1456e-04 - val_mean_absolute_error: 0.0072
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.5026e-05 - mean_absolute_error: 0.0046 - val_loss: 1.2786e-04 - val_mean_absolute_error: 0.0084
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4029e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1744e-04 - val_mean_absolute_error: 0.0074
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7511e-05 - mean_absolute_error: 0.0043 - val_loss: 2.5551e-04 - val_mean_absolute_error: 0.0135
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.4991e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2101e-04 - val_mean_absolute_error: 0.0079
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.2428e-05 - mean_absolute_error: 0.0045 - val_loss: 1.0597e-04 - val_mean_absolute_error: 0.0067
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8455e-05 - mean_absolute_error: 0.0041 - val_loss: 1.0775e-04 - val_mean_absolute_error: 0.0068
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.5783e-05 - mean_absolute_error: 0.0046 - val_loss: 1.0597e-04 - val_mean_absolute_error: 0.0067
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.0638e-05 - mean_absolute_error: 0.0042 - val_loss: 1.5373e-04 - val_mean_absolute_error: 0.0098
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.6350e-05 - mean_absolute_error: 0.0048 - val_loss: 2.9407e-04 - val_mean_absolute_error: 0.0151
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.8425e-05 - mean_absolute_error: 0.0061 - val_loss: 1.0845e-04 - val_mean_absolute_error: 0.0070
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0012e-05 - mean_absolute_error: 0.0043 - val_loss: 1.5235e-04 - val_mean_absolute_error: 0.0097
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.4998e-05 - mean_absolute_error: 0.0051 - val_loss: 1.1723e-04 - val_mean_absolute_error: 0.0074
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.1034e-05 - mean_absolute_error: 0.0042 - val_loss: 1.0931e-04 - val_mean_absolute_error: 0.0069
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.6741e-05 - mean_absolute_error: 0.0041 - val_loss: 1.4900e-04 - val_mean_absolute_error: 0.0094
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6686e-05 - mean_absolute_error: 0.0059 - val_loss: 2.0585e-04 - val_mean_absolute_error: 0.0118
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.0594e-05 - mean_absolute_error: 0.0054 - val_loss: 1.1162e-04 - val_mean_absolute_error: 0.0070
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 3.9997e-05 - mean_absolute_error: 0.0042 - val_loss: 1.1447e-04 - val_mean_absolute_error: 0.0075
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8428e-05 - mean_absolute_error: 0.0042 - val_loss: 1.1563e-04 - val_mean_absolute_error: 0.0076
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.0829e-05 - mean_absolute_error: 0.0044 - val_loss: 1.0588e-04 - val_mean_absolute_error: 0.0067
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7338e-05 - mean_absolute_error: 0.0041 - val_loss: 1.1178e-04 - val_mean_absolute_error: 0.0071
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.0308e-05 - mean_absolute_error: 0.0043 - val_loss: 1.0940e-04 - val_mean_absolute_error: 0.0069
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0416e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1899e-04 - val_mean_absolute_error: 0.0076
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.9409e-05 - mean_absolute_error: 0.0043 - val_loss: 2.2448e-04 - val_mean_absolute_error: 0.0127
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.7396e-05 - mean_absolute_error: 0.0063 - val_loss: 1.2226e-04 - val_mean_absolute_error: 0.0080
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.7634e-05 - mean_absolute_error: 0.0055 - val_loss: 1.2729e-04 - val_mean_absolute_error: 0.0081
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.5656e-05 - mean_absolute_error: 0.0040 - val_loss: 1.3537e-04 - val_mean_absolute_error: 0.0088
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.5549e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1038e-04 - val_mean_absolute_error: 0.0070
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.0972e-05 - mean_absolute_error: 0.0043 - val_loss: 1.0679e-04 - val_mean_absolute_error: 0.0069
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.6247e-05 - mean_absolute_error: 0.0042 - val_loss: 1.3649e-04 - val_mean_absolute_error: 0.0089
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.3230e-05 - mean_absolute_error: 0.0043 - val_loss: 1.0699e-04 - val_mean_absolute_error: 0.0068
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.5441e-05 - mean_absolute_error: 0.0045 - val_loss: 1.2945e-04 - val_mean_absolute_error: 0.0082
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.6923e-05 - mean_absolute_error: 0.0048 - val_loss: 1.3159e-04 - val_mean_absolute_error: 0.0083
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.1666e-05 - mean_absolute_error: 0.0043 - val_loss: 1.3339e-04 - val_mean_absolute_error: 0.0084
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.6686e-05 - mean_absolute_error: 0.0053 - val_loss: 1.0660e-04 - val_mean_absolute_error: 0.0069
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.1537e-05 - mean_absolute_error: 0.0043 - val_loss: 1.3650e-04 - val_mean_absolute_error: 0.0086
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.8833e-05 - mean_absolute_error: 0.0049 - val_loss: 1.5338e-04 - val_mean_absolute_error: 0.0095
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.2709e-05 - mean_absolute_error: 0.0047 - val_loss: 1.0803e-04 - val_mean_absolute_error: 0.0068
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.4685e-05 - mean_absolute_error: 0.0045 - val_loss: 1.1897e-04 - val_mean_absolute_error: 0.0075
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.8680e-05 - mean_absolute_error: 0.0043 - val_loss: 1.0713e-04 - val_mean_absolute_error: 0.0069
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.9534e-05 - mean_absolute_error: 0.0050 - val_loss: 1.5608e-04 - val_mean_absolute_error: 0.0098
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.8233e-05 - mean_absolute_error: 0.0049 - val_loss: 2.1936e-04 - val_mean_absolute_error: 0.0124
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.9969e-05 - mean_absolute_error: 0.0056 - val_loss: 1.1345e-04 - val_mean_absolute_error: 0.0074
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.1047e-05 - mean_absolute_error: 0.0043 - val_loss: 1.5246e-04 - val_mean_absolute_error: 0.0095
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.4235e-05 - mean_absolute_error: 0.0044 - val_loss: 1.0745e-04 - val_mean_absolute_error: 0.0069
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.9565e-05 - mean_absolute_error: 0.0048 - val_loss: 1.1744e-04 - val_mean_absolute_error: 0.0075
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5841e-05 - mean_absolute_error: 0.0040 - val_loss: 1.1107e-04 - val_mean_absolute_error: 0.0072
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.2722e-05 - mean_absolute_error: 0.0043 - val_loss: 1.1037e-04 - val_mean_absolute_error: 0.0070
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7810e-05 - mean_absolute_error: 0.0042 - val_loss: 1.1872e-04 - val_mean_absolute_error: 0.0075
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.6033e-05 - mean_absolute_error: 0.0041 - val_loss: 1.0918e-04 - val_mean_absolute_error: 0.0069
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8606e-05 - mean_absolute_error: 0.0040 - val_loss: 1.0696e-04 - val_mean_absolute_error: 0.0069
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8350e-05 - mean_absolute_error: 0.0042 - val_loss: 1.6178e-04 - val_mean_absolute_error: 0.0100
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.1877e-05 - mean_absolute_error: 0.0051 - val_loss: 1.1388e-04 - val_mean_absolute_error: 0.0072
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.7384e-05 - mean_absolute_error: 0.0043 - val_loss: 1.1544e-04 - val_mean_absolute_error: 0.0075
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.4106e-05 - mean_absolute_error: 0.0044 - val_loss: 1.8772e-04 - val_mean_absolute_error: 0.0112
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.4889e-05 - mean_absolute_error: 0.0050 - val_loss: 1.0858e-04 - val_mean_absolute_error: 0.0071
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.6037e-05 - mean_absolute_error: 0.0053 - val_loss: 1.3052e-04 - val_mean_absolute_error: 0.0085
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0595e-05 - mean_absolute_error: 0.0053 - val_loss: 1.1132e-04 - val_mean_absolute_error: 0.0073
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1393e-05 - mean_absolute_error: 0.0043 - val_loss: 1.1111e-04 - val_mean_absolute_error: 0.0070
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0473e-05 - mean_absolute_error: 0.0044 - val_loss: 1.7311e-04 - val_mean_absolute_error: 0.0105
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.7701e-05 - mean_absolute_error: 0.0048 - val_loss: 1.0867e-04 - val_mean_absolute_error: 0.0069
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7812e-05 - mean_absolute_error: 0.0042 - val_loss: 1.1127e-04 - val_mean_absolute_error: 0.0071
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.2817e-05 - mean_absolute_error: 0.0044 - val_loss: 1.0759e-04 - val_mean_absolute_error: 0.0068
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3362e-05 - mean_absolute_error: 0.0044 - val_loss: 1.0924e-04 - val_mean_absolute_error: 0.0069
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5789e-05 - mean_absolute_error: 0.0042 - val_loss: 1.0803e-04 - val_mean_absolute_error: 0.0070
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.4228e-05 - mean_absolute_error: 0.0047 - val_loss: 1.2258e-04 - val_mean_absolute_error: 0.0080
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.2006e-05 - mean_absolute_error: 0.0043 - val_loss: 1.0682e-04 - val_mean_absolute_error: 0.0068
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.2691e-05 - mean_absolute_error: 0.0043 - val_loss: 1.0688e-04 - val_mean_absolute_error: 0.0068
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.5626e-05 - mean_absolute_error: 0.0045 - val_loss: 2.0158e-04 - val_mean_absolute_error: 0.0116

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 4337611.790275117
# RMSE: 2082.693398048574
# MAE: 1615.0599321464144
# MAPE: 2.3782694048114132 %
#
# Model evalution on validate set
# MSE: 5817554.161364408
# RMSE: 2411.96064672797
# MAE: 1872.8711709486165
# MAPE: 1.9087260997248174 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 880ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step

# %%
y_pred_30_days
# Out:
# array([[128617.09 ],
#        [128875.95 ],
#        [128564.95 ],
#        [128406.   ],
#        [128989.516],
#        [128877.5  ],
#        [128945.14 ],
#        [128970.16 ],
#        [128914.055],
#        [128934.81 ],
#        [128924.22 ],
#        [128921.95 ],
#        [128927.54 ],
#        [128924.48 ],
#        [128925.99 ],
#        [128926.06 ],
#        [128925.51 ],
#        [128925.92 ],
#        [128925.71 ],
#        [128925.734],
#        [128925.805],
#        [128925.73 ],
#        [128925.78 ],
#        [128925.8  ],
#        [128925.766],
#        [128925.78 ],
#        [128925.766],
#        [128925.766],
#        [128925.766],
#        [128925.766],
#        [128925.78 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Predict the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
