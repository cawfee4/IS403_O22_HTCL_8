# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: FPT - Test/Train/Vaildation: 60/20/20
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1748.7641991579826
# - MAE: 1225.5009960159362
# - MAPE: 1.7926008608978683 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 1  # 6 2 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01  19270
# 2019-03-04  19440
# 2019-03-05  19390
# 2019-03-06  19270
# 2019-03-07  19330

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((776, 10), (776,), (251, 10), (251,), (253, 10), (253,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 28ms/step - loss: 0.0256 - mean_absolute_error: 0.0992 - val_loss: 0.0024 - val_mean_absolute_error: 0.0456
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.5738e-04 - mean_absolute_error: 0.0160 - val_loss: 4.7089e-04 - val_mean_absolute_error: 0.0154
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.4124e-04 - mean_absolute_error: 0.0103 - val_loss: 4.1375e-04 - val_mean_absolute_error: 0.0144
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7604e-04 - mean_absolute_error: 0.0091 - val_loss: 5.1148e-04 - val_mean_absolute_error: 0.0175
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7814e-04 - mean_absolute_error: 0.0092 - val_loss: 3.7982e-04 - val_mean_absolute_error: 0.0138
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9397e-04 - mean_absolute_error: 0.0092 - val_loss: 3.5832e-04 - val_mean_absolute_error: 0.0137
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4072e-04 - mean_absolute_error: 0.0081 - val_loss: 4.2464e-04 - val_mean_absolute_error: 0.0159
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4207e-04 - mean_absolute_error: 0.0081 - val_loss: 3.0913e-04 - val_mean_absolute_error: 0.0126
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1849e-04 - mean_absolute_error: 0.0075 - val_loss: 4.3995e-04 - val_mean_absolute_error: 0.0168
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2532e-04 - mean_absolute_error: 0.0078 - val_loss: 2.8742e-04 - val_mean_absolute_error: 0.0124
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2219e-04 - mean_absolute_error: 0.0075 - val_loss: 2.4935e-04 - val_mean_absolute_error: 0.0111
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1505e-04 - mean_absolute_error: 0.0071 - val_loss: 2.3348e-04 - val_mean_absolute_error: 0.0108
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.9865e-05 - mean_absolute_error: 0.0069 - val_loss: 2.5495e-04 - val_mean_absolute_error: 0.0120
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.1013e-05 - mean_absolute_error: 0.0065 - val_loss: 2.1558e-04 - val_mean_absolute_error: 0.0103
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.3978e-05 - mean_absolute_error: 0.0063 - val_loss: 1.9824e-04 - val_mean_absolute_error: 0.0100
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.2086e-05 - mean_absolute_error: 0.0058 - val_loss: 1.8766e-04 - val_mean_absolute_error: 0.0097
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.8837e-05 - mean_absolute_error: 0.0055 - val_loss: 1.8152e-04 - val_mean_absolute_error: 0.0096
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.2934e-05 - mean_absolute_error: 0.0059 - val_loss: 2.3066e-04 - val_mean_absolute_error: 0.0118
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.7768e-05 - mean_absolute_error: 0.0060 - val_loss: 1.6171e-04 - val_mean_absolute_error: 0.0089
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.3645e-05 - mean_absolute_error: 0.0054 - val_loss: 1.5875e-04 - val_mean_absolute_error: 0.0087
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.6527e-05 - mean_absolute_error: 0.0062 - val_loss: 2.1504e-04 - val_mean_absolute_error: 0.0114
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.2592e-05 - mean_absolute_error: 0.0058 - val_loss: 2.2177e-04 - val_mean_absolute_error: 0.0116
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.4409e-05 - mean_absolute_error: 0.0064 - val_loss: 2.7128e-04 - val_mean_absolute_error: 0.0133
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.0441e-05 - mean_absolute_error: 0.0059 - val_loss: 2.7937e-04 - val_mean_absolute_error: 0.0139
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0171e-04 - mean_absolute_error: 0.0069 - val_loss: 1.6099e-04 - val_mean_absolute_error: 0.0091
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.0607e-05 - mean_absolute_error: 0.0052 - val_loss: 2.6568e-04 - val_mean_absolute_error: 0.0134
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.5497e-05 - mean_absolute_error: 0.0057 - val_loss: 1.4503e-04 - val_mean_absolute_error: 0.0083
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.6294e-05 - mean_absolute_error: 0.0050 - val_loss: 1.4559e-04 - val_mean_absolute_error: 0.0084
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4361e-05 - mean_absolute_error: 0.0052 - val_loss: 1.4481e-04 - val_mean_absolute_error: 0.0083
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.5320e-05 - mean_absolute_error: 0.0050 - val_loss: 1.6837e-04 - val_mean_absolute_error: 0.0095
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.6302e-05 - mean_absolute_error: 0.0060 - val_loss: 3.0975e-04 - val_mean_absolute_error: 0.0147
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.2888e-05 - mean_absolute_error: 0.0069 - val_loss: 2.6125e-04 - val_mean_absolute_error: 0.0131
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.7801e-05 - mean_absolute_error: 0.0062 - val_loss: 4.5258e-04 - val_mean_absolute_error: 0.0186
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.9124e-05 - mean_absolute_error: 0.0065 - val_loss: 1.3798e-04 - val_mean_absolute_error: 0.0079
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.6138e-05 - mean_absolute_error: 0.0058 - val_loss: 1.5821e-04 - val_mean_absolute_error: 0.0092
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0520e-05 - mean_absolute_error: 0.0052 - val_loss: 1.6257e-04 - val_mean_absolute_error: 0.0094
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.6575e-05 - mean_absolute_error: 0.0050 - val_loss: 2.1058e-04 - val_mean_absolute_error: 0.0114
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.0407e-05 - mean_absolute_error: 0.0055 - val_loss: 1.5210e-04 - val_mean_absolute_error: 0.0088
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5837e-05 - mean_absolute_error: 0.0050 - val_loss: 1.4022e-04 - val_mean_absolute_error: 0.0081
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.1015e-05 - mean_absolute_error: 0.0051 - val_loss: 1.5741e-04 - val_mean_absolute_error: 0.0091
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.5987e-05 - mean_absolute_error: 0.0054 - val_loss: 1.9354e-04 - val_mean_absolute_error: 0.0108
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.3499e-05 - mean_absolute_error: 0.0062 - val_loss: 3.6950e-04 - val_mean_absolute_error: 0.0166
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7629e-05 - mean_absolute_error: 0.0066 - val_loss: 3.4796e-04 - val_mean_absolute_error: 0.0160
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.8283e-05 - mean_absolute_error: 0.0068 - val_loss: 2.9969e-04 - val_mean_absolute_error: 0.0148
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.7210e-05 - mean_absolute_error: 0.0066 - val_loss: 1.3286e-04 - val_mean_absolute_error: 0.0078
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.5013e-05 - mean_absolute_error: 0.0050 - val_loss: 1.3045e-04 - val_mean_absolute_error: 0.0076
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9634e-05 - mean_absolute_error: 0.0053 - val_loss: 1.5275e-04 - val_mean_absolute_error: 0.0091
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.0175e-05 - mean_absolute_error: 0.0048 - val_loss: 1.6905e-04 - val_mean_absolute_error: 0.0099
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.6692e-05 - mean_absolute_error: 0.0059 - val_loss: 1.2960e-04 - val_mean_absolute_error: 0.0076
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.5275e-05 - mean_absolute_error: 0.0052 - val_loss: 1.5873e-04 - val_mean_absolute_error: 0.0092
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8381e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3315e-04 - val_mean_absolute_error: 0.0078
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.3072e-05 - mean_absolute_error: 0.0049 - val_loss: 1.2809e-04 - val_mean_absolute_error: 0.0076
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3307e-05 - mean_absolute_error: 0.0044 - val_loss: 2.6247e-04 - val_mean_absolute_error: 0.0137
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.9757e-05 - mean_absolute_error: 0.0056 - val_loss: 1.5805e-04 - val_mean_absolute_error: 0.0092
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 6.6389e-05 - mean_absolute_error: 0.0057 - val_loss: 1.2500e-04 - val_mean_absolute_error: 0.0075
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.6355e-05 - mean_absolute_error: 0.0047 - val_loss: 1.6459e-04 - val_mean_absolute_error: 0.0098
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9762e-05 - mean_absolute_error: 0.0048 - val_loss: 1.8046e-04 - val_mean_absolute_error: 0.0103
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.7538e-05 - mean_absolute_error: 0.0046 - val_loss: 1.2537e-04 - val_mean_absolute_error: 0.0075
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.0786e-05 - mean_absolute_error: 0.0060 - val_loss: 1.2490e-04 - val_mean_absolute_error: 0.0075
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.0490e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2706e-04 - val_mean_absolute_error: 0.0078
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.7876e-05 - mean_absolute_error: 0.0046 - val_loss: 1.2395e-04 - val_mean_absolute_error: 0.0075
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.7580e-05 - mean_absolute_error: 0.0047 - val_loss: 1.6862e-04 - val_mean_absolute_error: 0.0097
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.3856e-05 - mean_absolute_error: 0.0058 - val_loss: 1.4128e-04 - val_mean_absolute_error: 0.0084
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.8051e-05 - mean_absolute_error: 0.0047 - val_loss: 1.4613e-04 - val_mean_absolute_error: 0.0086
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.7502e-05 - mean_absolute_error: 0.0045 - val_loss: 1.2765e-04 - val_mean_absolute_error: 0.0077
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.9824e-05 - mean_absolute_error: 0.0046 - val_loss: 1.4301e-04 - val_mean_absolute_error: 0.0085
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.3616e-05 - mean_absolute_error: 0.0045 - val_loss: 1.3485e-04 - val_mean_absolute_error: 0.0081
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.7170e-05 - mean_absolute_error: 0.0044 - val_loss: 1.2242e-04 - val_mean_absolute_error: 0.0076
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.5344e-05 - mean_absolute_error: 0.0046 - val_loss: 1.2060e-04 - val_mean_absolute_error: 0.0074
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.2083e-05 - mean_absolute_error: 0.0043 - val_loss: 1.2462e-04 - val_mean_absolute_error: 0.0075
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.4862e-05 - mean_absolute_error: 0.0045 - val_loss: 1.3503e-04 - val_mean_absolute_error: 0.0081
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.9934e-05 - mean_absolute_error: 0.0046 - val_loss: 1.2905e-04 - val_mean_absolute_error: 0.0078
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.5147e-05 - mean_absolute_error: 0.0046 - val_loss: 1.5897e-04 - val_mean_absolute_error: 0.0093
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.2768e-05 - mean_absolute_error: 0.0050 - val_loss: 1.3722e-04 - val_mean_absolute_error: 0.0086
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.0634e-05 - mean_absolute_error: 0.0045 - val_loss: 1.1975e-04 - val_mean_absolute_error: 0.0073
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.6541e-05 - mean_absolute_error: 0.0046 - val_loss: 2.3864e-04 - val_mean_absolute_error: 0.0126
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.0063e-05 - mean_absolute_error: 0.0067 - val_loss: 1.1834e-04 - val_mean_absolute_error: 0.0073
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.8325e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1888e-04 - val_mean_absolute_error: 0.0073
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.8352e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1722e-04 - val_mean_absolute_error: 0.0073
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.0129e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1663e-04 - val_mean_absolute_error: 0.0073
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.7897e-05 - mean_absolute_error: 0.0049 - val_loss: 1.2822e-04 - val_mean_absolute_error: 0.0078
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.8251e-05 - mean_absolute_error: 0.0048 - val_loss: 3.1734e-04 - val_mean_absolute_error: 0.0156
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4735e-05 - mean_absolute_error: 0.0060 - val_loss: 1.7328e-04 - val_mean_absolute_error: 0.0105
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.8323e-05 - mean_absolute_error: 0.0053 - val_loss: 1.1659e-04 - val_mean_absolute_error: 0.0072
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.6238e-05 - mean_absolute_error: 0.0044 - val_loss: 1.2746e-04 - val_mean_absolute_error: 0.0081
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.5200e-05 - mean_absolute_error: 0.0049 - val_loss: 1.5351e-04 - val_mean_absolute_error: 0.0092
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.5154e-05 - mean_absolute_error: 0.0045 - val_loss: 1.6922e-04 - val_mean_absolute_error: 0.0099
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3952e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1554e-04 - val_mean_absolute_error: 0.0072
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.4012e-05 - mean_absolute_error: 0.0045 - val_loss: 1.1973e-04 - val_mean_absolute_error: 0.0074
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.8005e-05 - mean_absolute_error: 0.0046 - val_loss: 2.0168e-04 - val_mean_absolute_error: 0.0113
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.6719e-05 - mean_absolute_error: 0.0053 - val_loss: 1.1466e-04 - val_mean_absolute_error: 0.0072
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0396e-05 - mean_absolute_error: 0.0042 - val_loss: 1.5007e-04 - val_mean_absolute_error: 0.0094
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.1736e-05 - mean_absolute_error: 0.0048 - val_loss: 1.3318e-04 - val_mean_absolute_error: 0.0082
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6619e-05 - mean_absolute_error: 0.0052 - val_loss: 3.1925e-04 - val_mean_absolute_error: 0.0153
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.1457e-05 - mean_absolute_error: 0.0059 - val_loss: 1.1412e-04 - val_mean_absolute_error: 0.0072
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.1278e-05 - mean_absolute_error: 0.0050 - val_loss: 1.6655e-04 - val_mean_absolute_error: 0.0102
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.5397e-05 - mean_absolute_error: 0.0051 - val_loss: 1.1358e-04 - val_mean_absolute_error: 0.0071
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.5006e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1337e-04 - val_mean_absolute_error: 0.0071
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5332e-05 - mean_absolute_error: 0.0046 - val_loss: 1.3351e-04 - val_mean_absolute_error: 0.0085
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.8887e-05 - mean_absolute_error: 0.0051 - val_loss: 1.2647e-04 - val_mean_absolute_error: 0.0081
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.1459e-05 - mean_absolute_error: 0.0044 - val_loss: 1.4849e-04 - val_mean_absolute_error: 0.0090
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.9534e-05 - mean_absolute_error: 0.0054 - val_loss: 2.3003e-04 - val_mean_absolute_error: 0.0124
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8329e-05 - mean_absolute_error: 0.0057 - val_loss: 1.3132e-04 - val_mean_absolute_error: 0.0081
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.7781e-05 - mean_absolute_error: 0.0048 - val_loss: 1.2808e-04 - val_mean_absolute_error: 0.0079
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.9286e-05 - mean_absolute_error: 0.0042 - val_loss: 1.1446e-04 - val_mean_absolute_error: 0.0073
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4668e-05 - mean_absolute_error: 0.0043 - val_loss: 1.5112e-04 - val_mean_absolute_error: 0.0095
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 4.3310e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1171e-04 - val_mean_absolute_error: 0.0070
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9931e-05 - mean_absolute_error: 0.0042 - val_loss: 1.2025e-04 - val_mean_absolute_error: 0.0075
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.0078e-05 - mean_absolute_error: 0.0042 - val_loss: 1.2063e-04 - val_mean_absolute_error: 0.0075
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.9870e-05 - mean_absolute_error: 0.0047 - val_loss: 1.2559e-04 - val_mean_absolute_error: 0.0081
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.5888e-05 - mean_absolute_error: 0.0047 - val_loss: 1.3316e-04 - val_mean_absolute_error: 0.0086
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7545e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1796e-04 - val_mean_absolute_error: 0.0074
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.8520e-05 - mean_absolute_error: 0.0048 - val_loss: 1.1141e-04 - val_mean_absolute_error: 0.0071
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.5495e-05 - mean_absolute_error: 0.0052 - val_loss: 1.1365e-04 - val_mean_absolute_error: 0.0073
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7240e-05 - mean_absolute_error: 0.0041 - val_loss: 1.1485e-04 - val_mean_absolute_error: 0.0074
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4466e-05 - mean_absolute_error: 0.0041 - val_loss: 1.5919e-04 - val_mean_absolute_error: 0.0096
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.8630e-05 - mean_absolute_error: 0.0048 - val_loss: 1.1267e-04 - val_mean_absolute_error: 0.0072
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4331e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1378e-04 - val_mean_absolute_error: 0.0071
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1558e-05 - mean_absolute_error: 0.0049 - val_loss: 1.0916e-04 - val_mean_absolute_error: 0.0069
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.0311e-05 - mean_absolute_error: 0.0043 - val_loss: 1.1193e-04 - val_mean_absolute_error: 0.0070
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.3402e-05 - mean_absolute_error: 0.0044 - val_loss: 1.3400e-04 - val_mean_absolute_error: 0.0083
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9235e-05 - mean_absolute_error: 0.0042 - val_loss: 1.1073e-04 - val_mean_absolute_error: 0.0070
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.1233e-05 - mean_absolute_error: 0.0042 - val_loss: 1.2450e-04 - val_mean_absolute_error: 0.0078
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.5143e-05 - mean_absolute_error: 0.0049 - val_loss: 1.1604e-04 - val_mean_absolute_error: 0.0073
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.7448e-05 - mean_absolute_error: 0.0041 - val_loss: 1.3643e-04 - val_mean_absolute_error: 0.0088
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.8842e-05 - mean_absolute_error: 0.0049 - val_loss: 1.3937e-04 - val_mean_absolute_error: 0.0090
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.1901e-05 - mean_absolute_error: 0.0052 - val_loss: 1.4835e-04 - val_mean_absolute_error: 0.0091
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.0287e-05 - mean_absolute_error: 0.0043 - val_loss: 2.2676e-04 - val_mean_absolute_error: 0.0124
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.7068e-05 - mean_absolute_error: 0.0055 - val_loss: 1.0894e-04 - val_mean_absolute_error: 0.0069
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.3820e-05 - mean_absolute_error: 0.0040 - val_loss: 1.0845e-04 - val_mean_absolute_error: 0.0069
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3789e-05 - mean_absolute_error: 0.0045 - val_loss: 1.1870e-04 - val_mean_absolute_error: 0.0074
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4697e-05 - mean_absolute_error: 0.0056 - val_loss: 1.1300e-04 - val_mean_absolute_error: 0.0071
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.2000e-05 - mean_absolute_error: 0.0043 - val_loss: 1.1022e-04 - val_mean_absolute_error: 0.0069
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3765e-05 - mean_absolute_error: 0.0047 - val_loss: 1.0948e-04 - val_mean_absolute_error: 0.0069
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0203e-05 - mean_absolute_error: 0.0046 - val_loss: 1.2921e-04 - val_mean_absolute_error: 0.0081
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1457e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1791e-04 - val_mean_absolute_error: 0.0077
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.2219e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1756e-04 - val_mean_absolute_error: 0.0074
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.2966e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1297e-04 - val_mean_absolute_error: 0.0073
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.6034e-05 - mean_absolute_error: 0.0040 - val_loss: 2.2164e-04 - val_mean_absolute_error: 0.0123
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.7454e-05 - mean_absolute_error: 0.0059 - val_loss: 1.1318e-04 - val_mean_absolute_error: 0.0073
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.0223e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1584e-04 - val_mean_absolute_error: 0.0076
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.5391e-05 - mean_absolute_error: 0.0045 - val_loss: 2.1361e-04 - val_mean_absolute_error: 0.0123
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.5286e-05 - mean_absolute_error: 0.0055 - val_loss: 1.1114e-04 - val_mean_absolute_error: 0.0069
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4482e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1449e-04 - val_mean_absolute_error: 0.0072
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3608e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1889e-04 - val_mean_absolute_error: 0.0078
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.5380e-05 - mean_absolute_error: 0.0043 - val_loss: 1.0810e-04 - val_mean_absolute_error: 0.0070
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.1182e-05 - mean_absolute_error: 0.0045 - val_loss: 1.4671e-04 - val_mean_absolute_error: 0.0091
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.0130e-05 - mean_absolute_error: 0.0042 - val_loss: 1.1745e-04 - val_mean_absolute_error: 0.0077
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.5573e-05 - mean_absolute_error: 0.0045 - val_loss: 1.1240e-04 - val_mean_absolute_error: 0.0073
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.0044e-05 - mean_absolute_error: 0.0041 - val_loss: 1.5717e-04 - val_mean_absolute_error: 0.0099
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 3.9160e-05 - mean_absolute_error: 0.0043 - val_loss: 1.1262e-04 - val_mean_absolute_error: 0.0073
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.8344e-05 - mean_absolute_error: 0.0049 - val_loss: 1.0832e-04 - val_mean_absolute_error: 0.0068
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8495e-05 - mean_absolute_error: 0.0042 - val_loss: 1.3850e-04 - val_mean_absolute_error: 0.0090
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.1854e-05 - mean_absolute_error: 0.0046 - val_loss: 1.2550e-04 - val_mean_absolute_error: 0.0082
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.1254e-05 - mean_absolute_error: 0.0043 - val_loss: 2.2932e-04 - val_mean_absolute_error: 0.0126
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.7413e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3883e-04 - val_mean_absolute_error: 0.0087
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.0439e-05 - mean_absolute_error: 0.0047 - val_loss: 1.7427e-04 - val_mean_absolute_error: 0.0105
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.0753e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1050e-04 - val_mean_absolute_error: 0.0071
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.0017e-05 - mean_absolute_error: 0.0049 - val_loss: 2.4189e-04 - val_mean_absolute_error: 0.0131
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.8423e-05 - mean_absolute_error: 0.0054 - val_loss: 1.0706e-04 - val_mean_absolute_error: 0.0068
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.4944e-05 - mean_absolute_error: 0.0045 - val_loss: 1.0719e-04 - val_mean_absolute_error: 0.0069
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.4015e-05 - mean_absolute_error: 0.0043 - val_loss: 1.1200e-04 - val_mean_absolute_error: 0.0070
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4811e-05 - mean_absolute_error: 0.0045 - val_loss: 1.2985e-04 - val_mean_absolute_error: 0.0082
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.0269e-05 - mean_absolute_error: 0.0051 - val_loss: 1.4987e-04 - val_mean_absolute_error: 0.0095
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.3679e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1186e-04 - val_mean_absolute_error: 0.0070
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.7032e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1317e-04 - val_mean_absolute_error: 0.0071
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.6681e-05 - mean_absolute_error: 0.0040 - val_loss: 1.4205e-04 - val_mean_absolute_error: 0.0089
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3808e-05 - mean_absolute_error: 0.0046 - val_loss: 1.2975e-04 - val_mean_absolute_error: 0.0082
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.1752e-05 - mean_absolute_error: 0.0045 - val_loss: 1.0784e-04 - val_mean_absolute_error: 0.0069
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.8075e-05 - mean_absolute_error: 0.0041 - val_loss: 1.0828e-04 - val_mean_absolute_error: 0.0068
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0061e-05 - mean_absolute_error: 0.0043 - val_loss: 1.1162e-04 - val_mean_absolute_error: 0.0073
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0306e-05 - mean_absolute_error: 0.0043 - val_loss: 1.2783e-04 - val_mean_absolute_error: 0.0081
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.0228e-05 - mean_absolute_error: 0.0044 - val_loss: 1.0702e-04 - val_mean_absolute_error: 0.0068
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1311e-05 - mean_absolute_error: 0.0044 - val_loss: 1.0686e-04 - val_mean_absolute_error: 0.0067
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.7124e-05 - mean_absolute_error: 0.0046 - val_loss: 1.0726e-04 - val_mean_absolute_error: 0.0068
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.7605e-05 - mean_absolute_error: 0.0043 - val_loss: 1.2102e-04 - val_mean_absolute_error: 0.0079
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.1321e-05 - mean_absolute_error: 0.0044 - val_loss: 1.4435e-04 - val_mean_absolute_error: 0.0092
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.9872e-05 - mean_absolute_error: 0.0050 - val_loss: 2.0225e-04 - val_mean_absolute_error: 0.0117
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9623e-05 - mean_absolute_error: 0.0061 - val_loss: 1.4315e-04 - val_mean_absolute_error: 0.0092
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.5722e-05 - mean_absolute_error: 0.0047 - val_loss: 1.0742e-04 - val_mean_absolute_error: 0.0068
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7715e-05 - mean_absolute_error: 0.0042 - val_loss: 1.5933e-04 - val_mean_absolute_error: 0.0098
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.9145e-05 - mean_absolute_error: 0.0050 - val_loss: 1.5119e-04 - val_mean_absolute_error: 0.0096
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.7509e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1464e-04 - val_mean_absolute_error: 0.0072
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.9373e-05 - mean_absolute_error: 0.0043 - val_loss: 1.1819e-04 - val_mean_absolute_error: 0.0077
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9425e-05 - mean_absolute_error: 0.0042 - val_loss: 1.4422e-04 - val_mean_absolute_error: 0.0090
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9605e-05 - mean_absolute_error: 0.0044 - val_loss: 1.0708e-04 - val_mean_absolute_error: 0.0068
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.2005e-05 - mean_absolute_error: 0.0044 - val_loss: 1.3262e-04 - val_mean_absolute_error: 0.0084
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.1058e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1451e-04 - val_mean_absolute_error: 0.0072
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.3893e-05 - mean_absolute_error: 0.0044 - val_loss: 1.0720e-04 - val_mean_absolute_error: 0.0068
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.6797e-05 - mean_absolute_error: 0.0042 - val_loss: 1.0829e-04 - val_mean_absolute_error: 0.0070
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.3429e-05 - mean_absolute_error: 0.0044 - val_loss: 1.2276e-04 - val_mean_absolute_error: 0.0080
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.1315e-05 - mean_absolute_error: 0.0046 - val_loss: 1.0812e-04 - val_mean_absolute_error: 0.0068
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.9284e-05 - mean_absolute_error: 0.0042 - val_loss: 1.7615e-04 - val_mean_absolute_error: 0.0107
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.4160e-05 - mean_absolute_error: 0.0052 - val_loss: 1.1216e-04 - val_mean_absolute_error: 0.0071
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.6764e-05 - mean_absolute_error: 0.0048 - val_loss: 1.0930e-04 - val_mean_absolute_error: 0.0071
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.0387e-05 - mean_absolute_error: 0.0042 - val_loss: 1.2237e-04 - val_mean_absolute_error: 0.0078
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.0710e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1765e-04 - val_mean_absolute_error: 0.0077
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.8799e-05 - mean_absolute_error: 0.0046 - val_loss: 1.0759e-04 - val_mean_absolute_error: 0.0068
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.2505e-05 - mean_absolute_error: 0.0042 - val_loss: 1.1692e-04 - val_mean_absolute_error: 0.0074
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.7591e-05 - mean_absolute_error: 0.0041 - val_loss: 1.1506e-04 - val_mean_absolute_error: 0.0075

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 3058176.22425666
# RMSE: 1748.7641991579826
# MAE: 1225.5009960159362
# MAPE: 1.7926008608978683 %
#
# Model evalution on validate set
# MSE: 8006549.186859252
# RMSE: 2829.584631506761
# MAE: 2060.148777173913
# MAPE: 2.0309863924271077 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step

# %%
y_pred_30_days
# Out:
# array([[124270.67 ],
#        [124723.19 ],
#        [124444.31 ],
#        [124136.11 ],
#        [125101.03 ],
#        [124963.35 ],
#        [125016.21 ],
#        [125070.81 ],
#        [124978.82 ],
#        [125001.92 ],
#        [124994.74 ],
#        [124987.79 ],
#        [124997.02 ],
#        [124993.79 ],
#        [124994.695],
#        [124995.48 ],
#        [124994.516],
#        [124994.91 ],
#        [124994.83 ],
#        [124994.74 ],
#        [124994.87 ],
#        [124994.8  ],
#        [124994.8  ],
#        [124994.81 ],
#        [124994.8  ],
#        [124994.78 ],
#        [124994.8  ],
#        [124994.8  ],
#        [124994.81 ],
#        [124994.81 ],
#        [124994.8  ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Predict the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
