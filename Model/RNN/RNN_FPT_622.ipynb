# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: FPT - Test/Train/Vaildation: 60/20/20
# - Dataset: 1252 rows x 7 column (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 2220.908174757369
# - MAE: 1635.4079661349372
# - MAPE: 2.3452887895223937 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 1  # 6 2 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01  19270
# 2019-03-04  19440
# 2019-03-05  19390
# 2019-03-06  19270
# 2019-03-07  19330

# %%
df.shape
# Out:
# (1252, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1247    108000
# 1248    107900
# 1249    108500
# 1250    109000
# 1251    110800
# Name: close, Length: 1252, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((740, 10), (740,), (239, 10), (239,), (240, 10), (240,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 0.0200 - mean_absolute_error: 0.0936 - val_loss: 0.0017 - val_mean_absolute_error: 0.0341
# Epoch 2/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5911e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0020 - val_mean_absolute_error: 0.0376
# Epoch 3/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0620e-04 - mean_absolute_error: 0.0109 - val_loss: 8.1375e-04 - val_mean_absolute_error: 0.0208
# Epoch 4/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4440e-04 - mean_absolute_error: 0.0092 - val_loss: 8.1267e-04 - val_mean_absolute_error: 0.0210
# Epoch 5/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4471e-04 - mean_absolute_error: 0.0089 - val_loss: 6.9788e-04 - val_mean_absolute_error: 0.0192
# Epoch 6/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3983e-04 - mean_absolute_error: 0.0086 - val_loss: 8.6947e-04 - val_mean_absolute_error: 0.0226
# Epoch 7/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2587e-04 - mean_absolute_error: 0.0082 - val_loss: 7.8254e-04 - val_mean_absolute_error: 0.0213
# Epoch 8/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2094e-04 - mean_absolute_error: 0.0080 - val_loss: 5.9363e-04 - val_mean_absolute_error: 0.0178
# Epoch 9/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1440e-04 - mean_absolute_error: 0.0076 - val_loss: 6.0563e-04 - val_mean_absolute_error: 0.0183
# Epoch 10/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.6022e-05 - mean_absolute_error: 0.0071 - val_loss: 5.5416e-04 - val_mean_absolute_error: 0.0174
# Epoch 11/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0567e-04 - mean_absolute_error: 0.0073 - val_loss: 5.1868e-04 - val_mean_absolute_error: 0.0168
# Epoch 12/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.9826e-05 - mean_absolute_error: 0.0071 - val_loss: 5.1247e-04 - val_mean_absolute_error: 0.0168
# Epoch 13/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0647e-04 - mean_absolute_error: 0.0073 - val_loss: 5.1654e-04 - val_mean_absolute_error: 0.0171
# Epoch 14/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0211e-04 - mean_absolute_error: 0.0071 - val_loss: 5.0034e-04 - val_mean_absolute_error: 0.0168
# Epoch 15/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.8319e-05 - mean_absolute_error: 0.0065 - val_loss: 4.3664e-04 - val_mean_absolute_error: 0.0153
# Epoch 16/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.7591e-05 - mean_absolute_error: 0.0066 - val_loss: 3.8944e-04 - val_mean_absolute_error: 0.0141
# Epoch 17/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.9140e-05 - mean_absolute_error: 0.0068 - val_loss: 3.8712e-04 - val_mean_absolute_error: 0.0140
# Epoch 18/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.4022e-05 - mean_absolute_error: 0.0063 - val_loss: 4.2324e-04 - val_mean_absolute_error: 0.0152
# Epoch 19/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.7015e-05 - mean_absolute_error: 0.0070 - val_loss: 3.7085e-04 - val_mean_absolute_error: 0.0137
# Epoch 20/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.5572e-05 - mean_absolute_error: 0.0061 - val_loss: 4.4822e-04 - val_mean_absolute_error: 0.0161
# Epoch 21/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0483e-04 - mean_absolute_error: 0.0071 - val_loss: 5.2115e-04 - val_mean_absolute_error: 0.0178
# Epoch 22/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.6710e-05 - mean_absolute_error: 0.0068 - val_loss: 3.8811e-04 - val_mean_absolute_error: 0.0144
# Epoch 23/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0411e-04 - mean_absolute_error: 0.0070 - val_loss: 3.9096e-04 - val_mean_absolute_error: 0.0145
# Epoch 24/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1587e-04 - mean_absolute_error: 0.0077 - val_loss: 4.5108e-04 - val_mean_absolute_error: 0.0161
# Epoch 25/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.2895e-05 - mean_absolute_error: 0.0063 - val_loss: 3.5450e-04 - val_mean_absolute_error: 0.0133
# Epoch 26/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5664e-05 - mean_absolute_error: 0.0062 - val_loss: 3.4943e-04 - val_mean_absolute_error: 0.0133
# Epoch 27/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1977e-05 - mean_absolute_error: 0.0063 - val_loss: 3.6969e-04 - val_mean_absolute_error: 0.0139
# Epoch 28/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0633e-05 - mean_absolute_error: 0.0067 - val_loss: 3.7669e-04 - val_mean_absolute_error: 0.0141
# Epoch 29/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.2025e-05 - mean_absolute_error: 0.0062 - val_loss: 3.8871e-04 - val_mean_absolute_error: 0.0146
# Epoch 30/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5991e-05 - mean_absolute_error: 0.0061 - val_loss: 3.5314e-04 - val_mean_absolute_error: 0.0135
# Epoch 31/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.8511e-05 - mean_absolute_error: 0.0063 - val_loss: 4.5240e-04 - val_mean_absolute_error: 0.0165
# Epoch 32/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.8032e-05 - mean_absolute_error: 0.0060 - val_loss: 3.8127e-04 - val_mean_absolute_error: 0.0145
# Epoch 33/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.0760e-05 - mean_absolute_error: 0.0061 - val_loss: 3.2415e-04 - val_mean_absolute_error: 0.0125
# Epoch 34/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.7778e-05 - mean_absolute_error: 0.0061 - val_loss: 4.0119e-04 - val_mean_absolute_error: 0.0152
# Epoch 35/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4998e-05 - mean_absolute_error: 0.0060 - val_loss: 3.5251e-04 - val_mean_absolute_error: 0.0137
# Epoch 36/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5855e-05 - mean_absolute_error: 0.0060 - val_loss: 3.5574e-04 - val_mean_absolute_error: 0.0138
# Epoch 37/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.0594e-05 - mean_absolute_error: 0.0058 - val_loss: 6.9832e-04 - val_mean_absolute_error: 0.0224
# Epoch 38/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0672e-04 - mean_absolute_error: 0.0074 - val_loss: 4.9440e-04 - val_mean_absolute_error: 0.0178
# Epoch 39/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.8477e-05 - mean_absolute_error: 0.0062 - val_loss: 3.2275e-04 - val_mean_absolute_error: 0.0126
# Epoch 40/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4833e-05 - mean_absolute_error: 0.0060 - val_loss: 3.2559e-04 - val_mean_absolute_error: 0.0126
# Epoch 41/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.7406e-05 - mean_absolute_error: 0.0056 - val_loss: 3.1314e-04 - val_mean_absolute_error: 0.0121
# Epoch 42/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6817e-05 - mean_absolute_error: 0.0058 - val_loss: 3.5789e-04 - val_mean_absolute_error: 0.0138
# Epoch 43/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.3362e-05 - mean_absolute_error: 0.0065 - val_loss: 3.8978e-04 - val_mean_absolute_error: 0.0148
# Epoch 44/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.3074e-05 - mean_absolute_error: 0.0060 - val_loss: 3.5576e-04 - val_mean_absolute_error: 0.0139
# Epoch 45/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4878e-05 - mean_absolute_error: 0.0057 - val_loss: 3.2700e-04 - val_mean_absolute_error: 0.0129
# Epoch 46/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.8696e-05 - mean_absolute_error: 0.0068 - val_loss: 3.1433e-04 - val_mean_absolute_error: 0.0121
# Epoch 47/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4046e-05 - mean_absolute_error: 0.0056 - val_loss: 4.2144e-04 - val_mean_absolute_error: 0.0160
# Epoch 48/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.7164e-05 - mean_absolute_error: 0.0055 - val_loss: 3.0525e-04 - val_mean_absolute_error: 0.0119
# Epoch 49/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9607e-05 - mean_absolute_error: 0.0053 - val_loss: 3.1411e-04 - val_mean_absolute_error: 0.0125
# Epoch 50/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8724e-05 - mean_absolute_error: 0.0056 - val_loss: 3.1683e-04 - val_mean_absolute_error: 0.0123
# Epoch 51/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1745e-05 - mean_absolute_error: 0.0059 - val_loss: 4.3325e-04 - val_mean_absolute_error: 0.0161
# Epoch 52/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2018e-04 - mean_absolute_error: 0.0077 - val_loss: 3.0418e-04 - val_mean_absolute_error: 0.0119
# Epoch 53/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.2035e-05 - mean_absolute_error: 0.0058 - val_loss: 3.0736e-04 - val_mean_absolute_error: 0.0124
# Epoch 54/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4799e-05 - mean_absolute_error: 0.0055 - val_loss: 3.1172e-04 - val_mean_absolute_error: 0.0126
# Epoch 55/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4714e-05 - mean_absolute_error: 0.0055 - val_loss: 3.1495e-04 - val_mean_absolute_error: 0.0123
# Epoch 56/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.0128e-05 - mean_absolute_error: 0.0065 - val_loss: 3.0345e-04 - val_mean_absolute_error: 0.0122
# Epoch 57/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.5349e-05 - mean_absolute_error: 0.0061 - val_loss: 3.1233e-04 - val_mean_absolute_error: 0.0127
# Epoch 58/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.1385e-05 - mean_absolute_error: 0.0063 - val_loss: 3.0498e-04 - val_mean_absolute_error: 0.0123
# Epoch 59/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4982e-05 - mean_absolute_error: 0.0054 - val_loss: 3.0555e-04 - val_mean_absolute_error: 0.0124
# Epoch 60/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.8470e-05 - mean_absolute_error: 0.0057 - val_loss: 3.0163e-04 - val_mean_absolute_error: 0.0119
# Epoch 61/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1609e-05 - mean_absolute_error: 0.0059 - val_loss: 5.0682e-04 - val_mean_absolute_error: 0.0186
# Epoch 62/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0121e-04 - mean_absolute_error: 0.0073 - val_loss: 2.9194e-04 - val_mean_absolute_error: 0.0115
# Epoch 63/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.4965e-05 - mean_absolute_error: 0.0062 - val_loss: 3.1461e-04 - val_mean_absolute_error: 0.0124
# Epoch 64/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2564e-05 - mean_absolute_error: 0.0060 - val_loss: 2.8771e-04 - val_mean_absolute_error: 0.0115
# Epoch 65/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9769e-05 - mean_absolute_error: 0.0053 - val_loss: 3.0700e-04 - val_mean_absolute_error: 0.0121
# Epoch 66/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1139e-05 - mean_absolute_error: 0.0058 - val_loss: 4.2471e-04 - val_mean_absolute_error: 0.0160
# Epoch 67/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.3831e-05 - mean_absolute_error: 0.0064 - val_loss: 2.9482e-04 - val_mean_absolute_error: 0.0121
# Epoch 68/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.7045e-05 - mean_absolute_error: 0.0057 - val_loss: 2.9140e-04 - val_mean_absolute_error: 0.0115
# Epoch 69/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4440e-05 - mean_absolute_error: 0.0052 - val_loss: 3.1425e-04 - val_mean_absolute_error: 0.0124
# Epoch 70/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8025e-05 - mean_absolute_error: 0.0057 - val_loss: 2.8737e-04 - val_mean_absolute_error: 0.0118
# Epoch 71/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4667e-05 - mean_absolute_error: 0.0061 - val_loss: 3.7295e-04 - val_mean_absolute_error: 0.0145
# Epoch 72/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.2894e-05 - mean_absolute_error: 0.0065 - val_loss: 2.9006e-04 - val_mean_absolute_error: 0.0115
# Epoch 73/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1306e-05 - mean_absolute_error: 0.0053 - val_loss: 4.4807e-04 - val_mean_absolute_error: 0.0167
# Epoch 74/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.7194e-05 - mean_absolute_error: 0.0069 - val_loss: 2.8478e-04 - val_mean_absolute_error: 0.0114
# Epoch 75/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.2970e-05 - mean_absolute_error: 0.0054 - val_loss: 3.5438e-04 - val_mean_absolute_error: 0.0145
# Epoch 76/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.8051e-05 - mean_absolute_error: 0.0058 - val_loss: 2.8955e-04 - val_mean_absolute_error: 0.0116
# Epoch 77/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4083e-05 - mean_absolute_error: 0.0056 - val_loss: 3.0679e-04 - val_mean_absolute_error: 0.0122
# Epoch 78/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.0952e-05 - mean_absolute_error: 0.0054 - val_loss: 2.9701e-04 - val_mean_absolute_error: 0.0123
# Epoch 79/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0225e-04 - mean_absolute_error: 0.0071 - val_loss: 3.8527e-04 - val_mean_absolute_error: 0.0149
# Epoch 80/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.7803e-05 - mean_absolute_error: 0.0065 - val_loss: 2.8140e-04 - val_mean_absolute_error: 0.0116
# Epoch 81/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.9760e-05 - mean_absolute_error: 0.0052 - val_loss: 2.8889e-04 - val_mean_absolute_error: 0.0116
# Epoch 82/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7860e-05 - mean_absolute_error: 0.0052 - val_loss: 4.2370e-04 - val_mean_absolute_error: 0.0167
# Epoch 83/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.8844e-05 - mean_absolute_error: 0.0066 - val_loss: 3.7971e-04 - val_mean_absolute_error: 0.0154
# Epoch 84/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6738e-05 - mean_absolute_error: 0.0052 - val_loss: 3.0582e-04 - val_mean_absolute_error: 0.0123
# Epoch 85/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8584e-05 - mean_absolute_error: 0.0059 - val_loss: 2.7485e-04 - val_mean_absolute_error: 0.0111
# Epoch 86/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3740e-05 - mean_absolute_error: 0.0056 - val_loss: 3.9460e-04 - val_mean_absolute_error: 0.0159
# Epoch 87/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.9016e-05 - mean_absolute_error: 0.0057 - val_loss: 3.1806e-04 - val_mean_absolute_error: 0.0133
# Epoch 88/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.7716e-05 - mean_absolute_error: 0.0055 - val_loss: 5.5368e-04 - val_mean_absolute_error: 0.0193
# Epoch 89/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0283e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0013 - val_mean_absolute_error: 0.0321
# Epoch 90/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7923e-04 - mean_absolute_error: 0.0092 - val_loss: 2.8362e-04 - val_mean_absolute_error: 0.0117
# Epoch 91/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4872e-05 - mean_absolute_error: 0.0060 - val_loss: 2.7439e-04 - val_mean_absolute_error: 0.0111
# Epoch 92/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4398e-05 - mean_absolute_error: 0.0060 - val_loss: 3.0511e-04 - val_mean_absolute_error: 0.0127
# Epoch 93/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1433e-04 - mean_absolute_error: 0.0075 - val_loss: 3.4680e-04 - val_mean_absolute_error: 0.0138
# Epoch 94/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.2392e-05 - mean_absolute_error: 0.0069 - val_loss: 3.2818e-04 - val_mean_absolute_error: 0.0136
# Epoch 95/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.0652e-05 - mean_absolute_error: 0.0058 - val_loss: 2.7802e-04 - val_mean_absolute_error: 0.0116
# Epoch 96/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9332e-05 - mean_absolute_error: 0.0051 - val_loss: 2.6898e-04 - val_mean_absolute_error: 0.0110
# Epoch 97/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.9707e-05 - mean_absolute_error: 0.0052 - val_loss: 2.6897e-04 - val_mean_absolute_error: 0.0111
# Epoch 98/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1596e-05 - mean_absolute_error: 0.0054 - val_loss: 2.8387e-04 - val_mean_absolute_error: 0.0120
# Epoch 99/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2878e-05 - mean_absolute_error: 0.0054 - val_loss: 3.3000e-04 - val_mean_absolute_error: 0.0139
# Epoch 100/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.1874e-05 - mean_absolute_error: 0.0060 - val_loss: 4.0681e-04 - val_mean_absolute_error: 0.0164
# Epoch 101/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.3939e-05 - mean_absolute_error: 0.0056 - val_loss: 2.7209e-04 - val_mean_absolute_error: 0.0115
# Epoch 102/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.8386e-05 - mean_absolute_error: 0.0052 - val_loss: 2.8893e-04 - val_mean_absolute_error: 0.0117
# Epoch 103/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4588e-05 - mean_absolute_error: 0.0061 - val_loss: 2.8720e-04 - val_mean_absolute_error: 0.0117
# Epoch 104/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.2832e-05 - mean_absolute_error: 0.0060 - val_loss: 2.6792e-04 - val_mean_absolute_error: 0.0113
# Epoch 105/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2056e-05 - mean_absolute_error: 0.0052 - val_loss: 7.0627e-04 - val_mean_absolute_error: 0.0234
# Epoch 106/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4672e-04 - mean_absolute_error: 0.0087 - val_loss: 2.9395e-04 - val_mean_absolute_error: 0.0119
# Epoch 107/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9592e-05 - mean_absolute_error: 0.0053 - val_loss: 3.3947e-04 - val_mean_absolute_error: 0.0137
# Epoch 108/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.5269e-05 - mean_absolute_error: 0.0058 - val_loss: 2.7744e-04 - val_mean_absolute_error: 0.0112
# Epoch 109/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.9125e-05 - mean_absolute_error: 0.0055 - val_loss: 3.0291e-04 - val_mean_absolute_error: 0.0123
# Epoch 110/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.7452e-05 - mean_absolute_error: 0.0063 - val_loss: 2.6760e-04 - val_mean_absolute_error: 0.0112
# Epoch 111/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.0435e-05 - mean_absolute_error: 0.0050 - val_loss: 5.1362e-04 - val_mean_absolute_error: 0.0192
# Epoch 112/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1433e-04 - mean_absolute_error: 0.0076 - val_loss: 2.6446e-04 - val_mean_absolute_error: 0.0111
# Epoch 113/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3691e-05 - mean_absolute_error: 0.0055 - val_loss: 5.1644e-04 - val_mean_absolute_error: 0.0186
# Epoch 114/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.4645e-05 - mean_absolute_error: 0.0066 - val_loss: 4.0948e-04 - val_mean_absolute_error: 0.0165
# Epoch 115/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.7967e-05 - mean_absolute_error: 0.0061 - val_loss: 2.6179e-04 - val_mean_absolute_error: 0.0108
# Epoch 116/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8902e-05 - mean_absolute_error: 0.0057 - val_loss: 2.7128e-04 - val_mean_absolute_error: 0.0111
# Epoch 117/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3422e-05 - mean_absolute_error: 0.0053 - val_loss: 3.0164e-04 - val_mean_absolute_error: 0.0129
# Epoch 118/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1892e-05 - mean_absolute_error: 0.0058 - val_loss: 3.0778e-04 - val_mean_absolute_error: 0.0132
# Epoch 119/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2385e-05 - mean_absolute_error: 0.0054 - val_loss: 2.5875e-04 - val_mean_absolute_error: 0.0107
# Epoch 120/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.6834e-05 - mean_absolute_error: 0.0059 - val_loss: 2.6006e-04 - val_mean_absolute_error: 0.0107
# Epoch 121/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.1987e-05 - mean_absolute_error: 0.0054 - val_loss: 2.6468e-04 - val_mean_absolute_error: 0.0112
# Epoch 122/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6154e-05 - mean_absolute_error: 0.0050 - val_loss: 3.1650e-04 - val_mean_absolute_error: 0.0135
# Epoch 123/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0524e-05 - mean_absolute_error: 0.0064 - val_loss: 3.0993e-04 - val_mean_absolute_error: 0.0133
# Epoch 124/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7254e-05 - mean_absolute_error: 0.0050 - val_loss: 7.1120e-04 - val_mean_absolute_error: 0.0229
# Epoch 125/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6022e-04 - mean_absolute_error: 0.0092 - val_loss: 4.1991e-04 - val_mean_absolute_error: 0.0162
# Epoch 126/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6649e-05 - mean_absolute_error: 0.0058 - val_loss: 2.6360e-04 - val_mean_absolute_error: 0.0111
# Epoch 127/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.8663e-05 - mean_absolute_error: 0.0048 - val_loss: 3.1951e-04 - val_mean_absolute_error: 0.0131
# Epoch 128/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4796e-05 - mean_absolute_error: 0.0060 - val_loss: 2.9048e-04 - val_mean_absolute_error: 0.0126
# Epoch 129/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.9951e-05 - mean_absolute_error: 0.0052 - val_loss: 2.7348e-04 - val_mean_absolute_error: 0.0118
# Epoch 130/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5486e-05 - mean_absolute_error: 0.0050 - val_loss: 2.5599e-04 - val_mean_absolute_error: 0.0107
# Epoch 131/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7307e-05 - mean_absolute_error: 0.0051 - val_loss: 3.7750e-04 - val_mean_absolute_error: 0.0156
# Epoch 132/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4415e-05 - mean_absolute_error: 0.0061 - val_loss: 4.1385e-04 - val_mean_absolute_error: 0.0167
# Epoch 133/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.8721e-05 - mean_absolute_error: 0.0054 - val_loss: 2.6463e-04 - val_mean_absolute_error: 0.0108
# Epoch 134/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.2326e-05 - mean_absolute_error: 0.0058 - val_loss: 3.1992e-04 - val_mean_absolute_error: 0.0137
# Epoch 135/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8498e-05 - mean_absolute_error: 0.0058 - val_loss: 2.5814e-04 - val_mean_absolute_error: 0.0110
# Epoch 136/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.3306e-05 - mean_absolute_error: 0.0052 - val_loss: 3.2955e-04 - val_mean_absolute_error: 0.0140
# Epoch 137/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.4844e-05 - mean_absolute_error: 0.0054 - val_loss: 3.0423e-04 - val_mean_absolute_error: 0.0131
# Epoch 138/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2050e-05 - mean_absolute_error: 0.0054 - val_loss: 2.9329e-04 - val_mean_absolute_error: 0.0122
# Epoch 139/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3350e-05 - mean_absolute_error: 0.0052 - val_loss: 3.8578e-04 - val_mean_absolute_error: 0.0159
# Epoch 140/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.6468e-05 - mean_absolute_error: 0.0062 - val_loss: 3.1907e-04 - val_mean_absolute_error: 0.0132
# Epoch 141/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8613e-05 - mean_absolute_error: 0.0058 - val_loss: 3.2315e-04 - val_mean_absolute_error: 0.0133
# Epoch 142/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.0991e-05 - mean_absolute_error: 0.0063 - val_loss: 4.0505e-04 - val_mean_absolute_error: 0.0164
# Epoch 143/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1030e-05 - mean_absolute_error: 0.0058 - val_loss: 4.4535e-04 - val_mean_absolute_error: 0.0175
# Epoch 144/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.6323e-05 - mean_absolute_error: 0.0063 - val_loss: 4.1565e-04 - val_mean_absolute_error: 0.0161
# Epoch 145/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.4899e-05 - mean_absolute_error: 0.0066 - val_loss: 3.6737e-04 - val_mean_absolute_error: 0.0147
# Epoch 146/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.8506e-05 - mean_absolute_error: 0.0070 - val_loss: 6.0086e-04 - val_mean_absolute_error: 0.0213
# Epoch 147/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.8238e-05 - mean_absolute_error: 0.0066 - val_loss: 2.6372e-04 - val_mean_absolute_error: 0.0113
# Epoch 148/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.5958e-05 - mean_absolute_error: 0.0055 - val_loss: 2.8089e-04 - val_mean_absolute_error: 0.0116
# Epoch 149/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3982e-05 - mean_absolute_error: 0.0052 - val_loss: 3.3350e-04 - val_mean_absolute_error: 0.0142
# Epoch 150/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.1270e-05 - mean_absolute_error: 0.0054 - val_loss: 2.6376e-04 - val_mean_absolute_error: 0.0115
# Epoch 151/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.5455e-05 - mean_absolute_error: 0.0052 - val_loss: 2.5846e-04 - val_mean_absolute_error: 0.0106
# Epoch 152/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.5557e-05 - mean_absolute_error: 0.0050 - val_loss: 2.6190e-04 - val_mean_absolute_error: 0.0108
# Epoch 153/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2074e-05 - mean_absolute_error: 0.0050 - val_loss: 2.6513e-04 - val_mean_absolute_error: 0.0116
# Epoch 154/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7910e-05 - mean_absolute_error: 0.0059 - val_loss: 2.9150e-04 - val_mean_absolute_error: 0.0122
# Epoch 155/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0358e-04 - mean_absolute_error: 0.0072 - val_loss: 2.5502e-04 - val_mean_absolute_error: 0.0109
# Epoch 156/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.7407e-05 - mean_absolute_error: 0.0052 - val_loss: 2.6857e-04 - val_mean_absolute_error: 0.0117
# Epoch 157/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.9467e-05 - mean_absolute_error: 0.0052 - val_loss: 2.5310e-04 - val_mean_absolute_error: 0.0108
# Epoch 158/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.3052e-05 - mean_absolute_error: 0.0050 - val_loss: 3.1993e-04 - val_mean_absolute_error: 0.0138
# Epoch 159/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4660e-05 - mean_absolute_error: 0.0056 - val_loss: 3.1521e-04 - val_mean_absolute_error: 0.0136
# Epoch 160/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6933e-05 - mean_absolute_error: 0.0056 - val_loss: 2.8758e-04 - val_mean_absolute_error: 0.0126
# Epoch 161/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1067e-05 - mean_absolute_error: 0.0058 - val_loss: 2.5332e-04 - val_mean_absolute_error: 0.0108
# Epoch 162/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.3750e-05 - mean_absolute_error: 0.0050 - val_loss: 2.7696e-04 - val_mean_absolute_error: 0.0121
# Epoch 163/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6228e-05 - mean_absolute_error: 0.0052 - val_loss: 2.5948e-04 - val_mean_absolute_error: 0.0112
# Epoch 164/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9005e-05 - mean_absolute_error: 0.0051 - val_loss: 2.7905e-04 - val_mean_absolute_error: 0.0116
# Epoch 165/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6825e-05 - mean_absolute_error: 0.0051 - val_loss: 2.6203e-04 - val_mean_absolute_error: 0.0114
# Epoch 166/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9831e-05 - mean_absolute_error: 0.0051 - val_loss: 2.6752e-04 - val_mean_absolute_error: 0.0111
# Epoch 167/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5073e-05 - mean_absolute_error: 0.0051 - val_loss: 2.8977e-04 - val_mean_absolute_error: 0.0121
# Epoch 168/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1767e-05 - mean_absolute_error: 0.0054 - val_loss: 2.4804e-04 - val_mean_absolute_error: 0.0105
# Epoch 169/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.7002e-05 - mean_absolute_error: 0.0051 - val_loss: 2.6189e-04 - val_mean_absolute_error: 0.0114
# Epoch 170/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2425e-05 - mean_absolute_error: 0.0050 - val_loss: 2.5578e-04 - val_mean_absolute_error: 0.0112
# Epoch 171/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2157e-05 - mean_absolute_error: 0.0055 - val_loss: 3.2489e-04 - val_mean_absolute_error: 0.0140
# Epoch 172/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9082e-05 - mean_absolute_error: 0.0058 - val_loss: 2.4944e-04 - val_mean_absolute_error: 0.0107
# Epoch 173/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.9117e-05 - mean_absolute_error: 0.0060 - val_loss: 2.9527e-04 - val_mean_absolute_error: 0.0129
# Epoch 174/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9499e-05 - mean_absolute_error: 0.0058 - val_loss: 2.5706e-04 - val_mean_absolute_error: 0.0111
# Epoch 175/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8424e-05 - mean_absolute_error: 0.0055 - val_loss: 4.0512e-04 - val_mean_absolute_error: 0.0159
# Epoch 176/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8421e-05 - mean_absolute_error: 0.0059 - val_loss: 3.5116e-04 - val_mean_absolute_error: 0.0143
# Epoch 177/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.8159e-05 - mean_absolute_error: 0.0064 - val_loss: 2.5012e-04 - val_mean_absolute_error: 0.0105
# Epoch 178/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6748e-05 - mean_absolute_error: 0.0062 - val_loss: 3.0462e-04 - val_mean_absolute_error: 0.0132
# Epoch 179/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.5759e-05 - mean_absolute_error: 0.0054 - val_loss: 3.3054e-04 - val_mean_absolute_error: 0.0141
# Epoch 180/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0874e-05 - mean_absolute_error: 0.0063 - val_loss: 2.9996e-04 - val_mean_absolute_error: 0.0125
# Epoch 181/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5474e-05 - mean_absolute_error: 0.0056 - val_loss: 2.8234e-04 - val_mean_absolute_error: 0.0123
# Epoch 182/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6785e-05 - mean_absolute_error: 0.0052 - val_loss: 2.6446e-04 - val_mean_absolute_error: 0.0110
# Epoch 183/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1813e-05 - mean_absolute_error: 0.0060 - val_loss: 2.8445e-04 - val_mean_absolute_error: 0.0124
# Epoch 184/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4539e-05 - mean_absolute_error: 0.0052 - val_loss: 2.5089e-04 - val_mean_absolute_error: 0.0105
# Epoch 185/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.9831e-05 - mean_absolute_error: 0.0052 - val_loss: 2.5636e-04 - val_mean_absolute_error: 0.0111
# Epoch 186/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5987e-05 - mean_absolute_error: 0.0051 - val_loss: 2.8753e-04 - val_mean_absolute_error: 0.0120
# Epoch 187/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2570e-05 - mean_absolute_error: 0.0056 - val_loss: 5.5235e-04 - val_mean_absolute_error: 0.0202
# Epoch 188/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.3559e-05 - mean_absolute_error: 0.0066 - val_loss: 2.4951e-04 - val_mean_absolute_error: 0.0106
# Epoch 189/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.1538e-05 - mean_absolute_error: 0.0053 - val_loss: 2.5149e-04 - val_mean_absolute_error: 0.0105
# Epoch 190/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.8551e-05 - mean_absolute_error: 0.0063 - val_loss: 3.0429e-04 - val_mean_absolute_error: 0.0133
# Epoch 191/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8311e-05 - mean_absolute_error: 0.0060 - val_loss: 2.5401e-04 - val_mean_absolute_error: 0.0109
# Epoch 192/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8224e-05 - mean_absolute_error: 0.0058 - val_loss: 2.7877e-04 - val_mean_absolute_error: 0.0116
# Epoch 193/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.1813e-05 - mean_absolute_error: 0.0055 - val_loss: 3.0281e-04 - val_mean_absolute_error: 0.0126
# Epoch 194/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.3915e-05 - mean_absolute_error: 0.0060 - val_loss: 3.7947e-04 - val_mean_absolute_error: 0.0157
# Epoch 195/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.5671e-05 - mean_absolute_error: 0.0062 - val_loss: 2.5043e-04 - val_mean_absolute_error: 0.0106
# Epoch 196/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3431e-05 - mean_absolute_error: 0.0050 - val_loss: 2.5454e-04 - val_mean_absolute_error: 0.0109
# Epoch 197/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.5826e-05 - mean_absolute_error: 0.0052 - val_loss: 2.6203e-04 - val_mean_absolute_error: 0.0109
# Epoch 198/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9531e-05 - mean_absolute_error: 0.0055 - val_loss: 2.5656e-04 - val_mean_absolute_error: 0.0111
# Epoch 199/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.9564e-05 - mean_absolute_error: 0.0054 - val_loss: 2.7696e-04 - val_mean_absolute_error: 0.0122
# Epoch 200/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6480e-05 - mean_absolute_error: 0.0053 - val_loss: 3.2313e-04 - val_mean_absolute_error: 0.0139

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 239
# 250

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 4932433.120704108
# RMSE: 2220.908174757369
# MAE: 1635.4079661349372
# MAPE: 2.3452887895223937 %
#
# Model evalution on validate set
# MSE: 5630842.6887819925
# RMSE: 2372.9396723857085
# MAE: 1858.50458984375
# MAPE: 2.109063119545347 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step

# %%
y_pred_30_days
# Out:
# array([[104092.37 ],
#        [104253.63 ],
#        [104450.48 ],
#        [104064.5  ],
#        [104366.31 ],
#        [104378.08 ],
#        [104326.86 ],
#        [104371.63 ],
#        [104355.57 ],
#        [104349.92 ],
#        [104356.86 ],
#        [104353.164],
#        [104353.52 ],
#        [104354.484],
#        [104353.766],
#        [104353.99 ],
#        [104354.05 ],
#        [104353.94 ],
#        [104354.01 ],
#        [104353.99 ],
#        [104353.96 ],
#        [104353.984],
#        [104353.984],
#        [104353.984],
#        [104353.98 ],
#        [104353.984],
#        [104353.984],
#        [104353.984],
#        [104353.984],
#        [104353.984],
#        [104353.984]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Predict the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
