# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: FPT - Test/Train/Vaildation: 60/20/20
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1804.7283434504354
# - MAE: 1284.949094248008
# - MAPE: 1.8914344320188552 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 1  # 6 2 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01  19270
# 2019-03-04  19440
# 2019-03-05  19390
# 2019-03-06  19270
# 2019-03-07  19330

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((776, 10), (776,), (251, 10), (251,), (253, 10), (253,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - loss: 0.0391 - mean_absolute_error: 0.1273 - val_loss: 0.0085 - val_mean_absolute_error: 0.0878
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0011 - mean_absolute_error: 0.0242 - val_loss: 0.0019 - val_mean_absolute_error: 0.0385
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3049e-04 - mean_absolute_error: 0.0145 - val_loss: 7.4311e-04 - val_mean_absolute_error: 0.0196
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.2837e-04 - mean_absolute_error: 0.0124 - val_loss: 6.9599e-04 - val_mean_absolute_error: 0.0184
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.0472e-04 - mean_absolute_error: 0.0120 - val_loss: 7.3011e-04 - val_mean_absolute_error: 0.0203
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.6079e-04 - mean_absolute_error: 0.0111 - val_loss: 6.9390e-04 - val_mean_absolute_error: 0.0199
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.4696e-04 - mean_absolute_error: 0.0110 - val_loss: 5.7466e-04 - val_mean_absolute_error: 0.0177
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3844e-04 - mean_absolute_error: 0.0107 - val_loss: 5.0263e-04 - val_mean_absolute_error: 0.0161
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1364e-04 - mean_absolute_error: 0.0103 - val_loss: 4.7154e-04 - val_mean_absolute_error: 0.0159
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2296e-04 - mean_absolute_error: 0.0101 - val_loss: 4.8335e-04 - val_mean_absolute_error: 0.0155
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.1831e-04 - mean_absolute_error: 0.0098 - val_loss: 3.8102e-04 - val_mean_absolute_error: 0.0137
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6444e-04 - mean_absolute_error: 0.0088 - val_loss: 3.7235e-04 - val_mean_absolute_error: 0.0132
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6885e-04 - mean_absolute_error: 0.0090 - val_loss: 3.5499e-04 - val_mean_absolute_error: 0.0130
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.8624e-04 - mean_absolute_error: 0.0089 - val_loss: 3.9323e-04 - val_mean_absolute_error: 0.0146
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1244e-04 - mean_absolute_error: 0.0073 - val_loss: 4.0125e-04 - val_mean_absolute_error: 0.0157
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2187e-04 - mean_absolute_error: 0.0077 - val_loss: 3.4169e-04 - val_mean_absolute_error: 0.0142
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2944e-04 - mean_absolute_error: 0.0078 - val_loss: 2.5692e-04 - val_mean_absolute_error: 0.0112
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.7208e-05 - mean_absolute_error: 0.0067 - val_loss: 2.6255e-04 - val_mean_absolute_error: 0.0117
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 9.1812e-05 - mean_absolute_error: 0.0066 - val_loss: 2.6819e-04 - val_mean_absolute_error: 0.0120
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0542e-04 - mean_absolute_error: 0.0070 - val_loss: 2.5671e-04 - val_mean_absolute_error: 0.0117
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.8107e-05 - mean_absolute_error: 0.0068 - val_loss: 2.2056e-04 - val_mean_absolute_error: 0.0102
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0700e-04 - mean_absolute_error: 0.0072 - val_loss: 2.8604e-04 - val_mean_absolute_error: 0.0129
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0969e-04 - mean_absolute_error: 0.0070 - val_loss: 2.4160e-04 - val_mean_absolute_error: 0.0113
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.3251e-05 - mean_absolute_error: 0.0064 - val_loss: 3.8719e-04 - val_mean_absolute_error: 0.0159
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0403e-04 - mean_absolute_error: 0.0071 - val_loss: 2.0398e-04 - val_mean_absolute_error: 0.0098
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.2750e-05 - mean_absolute_error: 0.0063 - val_loss: 2.0167e-04 - val_mean_absolute_error: 0.0098
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.1813e-05 - mean_absolute_error: 0.0061 - val_loss: 2.6770e-04 - val_mean_absolute_error: 0.0125
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0802e-04 - mean_absolute_error: 0.0070 - val_loss: 2.3689e-04 - val_mean_absolute_error: 0.0114
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.7713e-05 - mean_absolute_error: 0.0064 - val_loss: 2.3771e-04 - val_mean_absolute_error: 0.0115
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.0369e-05 - mean_absolute_error: 0.0068 - val_loss: 2.4706e-04 - val_mean_absolute_error: 0.0118
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.2193e-05 - mean_absolute_error: 0.0066 - val_loss: 3.4196e-04 - val_mean_absolute_error: 0.0149
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0200e-04 - mean_absolute_error: 0.0065 - val_loss: 2.0514e-04 - val_mean_absolute_error: 0.0102
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.0763e-05 - mean_absolute_error: 0.0060 - val_loss: 2.0053e-04 - val_mean_absolute_error: 0.0101
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.2787e-05 - mean_absolute_error: 0.0060 - val_loss: 1.9727e-04 - val_mean_absolute_error: 0.0101
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.2368e-05 - mean_absolute_error: 0.0060 - val_loss: 3.4218e-04 - val_mean_absolute_error: 0.0151
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2640e-04 - mean_absolute_error: 0.0073 - val_loss: 3.5416e-04 - val_mean_absolute_error: 0.0155
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.0986e-05 - mean_absolute_error: 0.0062 - val_loss: 2.0468e-04 - val_mean_absolute_error: 0.0104
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.9546e-05 - mean_absolute_error: 0.0059 - val_loss: 2.9121e-04 - val_mean_absolute_error: 0.0135
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5018e-04 - mean_absolute_error: 0.0082 - val_loss: 5.0798e-04 - val_mean_absolute_error: 0.0194
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.0865e-04 - mean_absolute_error: 0.0075 - val_loss: 2.5398e-04 - val_mean_absolute_error: 0.0123
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.8145e-05 - mean_absolute_error: 0.0058 - val_loss: 4.0164e-04 - val_mean_absolute_error: 0.0168
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3084e-04 - mean_absolute_error: 0.0080 - val_loss: 3.6540e-04 - val_mean_absolute_error: 0.0159
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0630e-04 - mean_absolute_error: 0.0071 - val_loss: 2.1391e-04 - val_mean_absolute_error: 0.0109
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.9053e-05 - mean_absolute_error: 0.0066 - val_loss: 2.4487e-04 - val_mean_absolute_error: 0.0121
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0904e-05 - mean_absolute_error: 0.0058 - val_loss: 1.8776e-04 - val_mean_absolute_error: 0.0099
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.3720e-05 - mean_absolute_error: 0.0061 - val_loss: 2.0902e-04 - val_mean_absolute_error: 0.0108
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.6920e-05 - mean_absolute_error: 0.0062 - val_loss: 3.0317e-04 - val_mean_absolute_error: 0.0142
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1352e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9513e-04 - val_mean_absolute_error: 0.0139
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.3481e-05 - mean_absolute_error: 0.0063 - val_loss: 1.7506e-04 - val_mean_absolute_error: 0.0092
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.5505e-05 - mean_absolute_error: 0.0066 - val_loss: 2.5698e-04 - val_mean_absolute_error: 0.0126
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.5092e-05 - mean_absolute_error: 0.0065 - val_loss: 1.9883e-04 - val_mean_absolute_error: 0.0104
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.5076e-05 - mean_absolute_error: 0.0062 - val_loss: 1.9728e-04 - val_mean_absolute_error: 0.0104
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.4069e-05 - mean_absolute_error: 0.0054 - val_loss: 1.6226e-04 - val_mean_absolute_error: 0.0087
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.0138e-05 - mean_absolute_error: 0.0051 - val_loss: 1.7548e-04 - val_mean_absolute_error: 0.0095
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.4910e-05 - mean_absolute_error: 0.0066 - val_loss: 2.2703e-04 - val_mean_absolute_error: 0.0116
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.5807e-05 - mean_absolute_error: 0.0057 - val_loss: 1.6013e-04 - val_mean_absolute_error: 0.0086
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4066e-05 - mean_absolute_error: 0.0053 - val_loss: 1.5763e-04 - val_mean_absolute_error: 0.0085
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.2849e-05 - mean_absolute_error: 0.0068 - val_loss: 1.5876e-04 - val_mean_absolute_error: 0.0086
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.6097e-05 - mean_absolute_error: 0.0056 - val_loss: 5.0857e-04 - val_mean_absolute_error: 0.0197
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.4455e-04 - mean_absolute_error: 0.0086 - val_loss: 1.9534e-04 - val_mean_absolute_error: 0.0103
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.9646e-05 - mean_absolute_error: 0.0057 - val_loss: 1.7485e-04 - val_mean_absolute_error: 0.0094
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.8560e-05 - mean_absolute_error: 0.0050 - val_loss: 1.5573e-04 - val_mean_absolute_error: 0.0085
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.3211e-05 - mean_absolute_error: 0.0053 - val_loss: 1.8516e-04 - val_mean_absolute_error: 0.0100
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.6422e-05 - mean_absolute_error: 0.0055 - val_loss: 1.8939e-04 - val_mean_absolute_error: 0.0102
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.5518e-05 - mean_absolute_error: 0.0057 - val_loss: 2.1365e-04 - val_mean_absolute_error: 0.0112
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.0745e-05 - mean_absolute_error: 0.0060 - val_loss: 2.6171e-04 - val_mean_absolute_error: 0.0130
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1066e-04 - mean_absolute_error: 0.0071 - val_loss: 1.5154e-04 - val_mean_absolute_error: 0.0083
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.7494e-05 - mean_absolute_error: 0.0066 - val_loss: 1.6128e-04 - val_mean_absolute_error: 0.0090
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.2592e-05 - mean_absolute_error: 0.0053 - val_loss: 1.4984e-04 - val_mean_absolute_error: 0.0082
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.2639e-05 - mean_absolute_error: 0.0053 - val_loss: 1.8202e-04 - val_mean_absolute_error: 0.0101
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.7551e-05 - mean_absolute_error: 0.0057 - val_loss: 1.7466e-04 - val_mean_absolute_error: 0.0096
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8052e-05 - mean_absolute_error: 0.0053 - val_loss: 2.7220e-04 - val_mean_absolute_error: 0.0133
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.8290e-05 - mean_absolute_error: 0.0060 - val_loss: 1.5376e-04 - val_mean_absolute_error: 0.0085
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.7058e-05 - mean_absolute_error: 0.0051 - val_loss: 2.5132e-04 - val_mean_absolute_error: 0.0127
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.6728e-05 - mean_absolute_error: 0.0056 - val_loss: 4.0234e-04 - val_mean_absolute_error: 0.0173
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.1523e-05 - mean_absolute_error: 0.0062 - val_loss: 1.6916e-04 - val_mean_absolute_error: 0.0094
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.2034e-05 - mean_absolute_error: 0.0053 - val_loss: 1.5167e-04 - val_mean_absolute_error: 0.0087
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.4719e-05 - mean_absolute_error: 0.0050 - val_loss: 2.3239e-04 - val_mean_absolute_error: 0.0122
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5706e-05 - mean_absolute_error: 0.0054 - val_loss: 1.5489e-04 - val_mean_absolute_error: 0.0089
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5786e-05 - mean_absolute_error: 0.0054 - val_loss: 1.8326e-04 - val_mean_absolute_error: 0.0103
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.1292e-05 - mean_absolute_error: 0.0067 - val_loss: 1.4161e-04 - val_mean_absolute_error: 0.0080
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4134e-05 - mean_absolute_error: 0.0054 - val_loss: 2.2160e-04 - val_mean_absolute_error: 0.0116
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.2788e-05 - mean_absolute_error: 0.0058 - val_loss: 1.4242e-04 - val_mean_absolute_error: 0.0080
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.7039e-05 - mean_absolute_error: 0.0056 - val_loss: 1.6496e-04 - val_mean_absolute_error: 0.0093
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4495e-05 - mean_absolute_error: 0.0054 - val_loss: 2.1168e-04 - val_mean_absolute_error: 0.0113
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.6370e-05 - mean_absolute_error: 0.0056 - val_loss: 1.6375e-04 - val_mean_absolute_error: 0.0092
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.8302e-05 - mean_absolute_error: 0.0051 - val_loss: 1.5854e-04 - val_mean_absolute_error: 0.0093
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.6852e-05 - mean_absolute_error: 0.0053 - val_loss: 1.3674e-04 - val_mean_absolute_error: 0.0079
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.5595e-05 - mean_absolute_error: 0.0050 - val_loss: 1.3817e-04 - val_mean_absolute_error: 0.0080
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.0559e-05 - mean_absolute_error: 0.0047 - val_loss: 1.6440e-04 - val_mean_absolute_error: 0.0096
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.4266e-05 - mean_absolute_error: 0.0056 - val_loss: 2.9138e-04 - val_mean_absolute_error: 0.0144
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.5417e-05 - mean_absolute_error: 0.0052 - val_loss: 1.6036e-04 - val_mean_absolute_error: 0.0091
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7333e-05 - mean_absolute_error: 0.0051 - val_loss: 1.4840e-04 - val_mean_absolute_error: 0.0088
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.0893e-05 - mean_absolute_error: 0.0058 - val_loss: 1.3855e-04 - val_mean_absolute_error: 0.0083
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.6022e-05 - mean_absolute_error: 0.0048 - val_loss: 1.7461e-04 - val_mean_absolute_error: 0.0101
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.2023e-05 - mean_absolute_error: 0.0050 - val_loss: 1.3591e-04 - val_mean_absolute_error: 0.0079
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6590e-05 - mean_absolute_error: 0.0050 - val_loss: 1.6159e-04 - val_mean_absolute_error: 0.0096
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.9010e-05 - mean_absolute_error: 0.0055 - val_loss: 2.5835e-04 - val_mean_absolute_error: 0.0134
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.1221e-05 - mean_absolute_error: 0.0056 - val_loss: 1.3694e-04 - val_mean_absolute_error: 0.0082
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6351e-05 - mean_absolute_error: 0.0053 - val_loss: 1.5891e-04 - val_mean_absolute_error: 0.0095
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.7560e-05 - mean_absolute_error: 0.0063 - val_loss: 1.3801e-04 - val_mean_absolute_error: 0.0080
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.4489e-05 - mean_absolute_error: 0.0049 - val_loss: 1.4778e-04 - val_mean_absolute_error: 0.0086
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.3365e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2928e-04 - val_mean_absolute_error: 0.0076
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.3343e-05 - mean_absolute_error: 0.0049 - val_loss: 1.3384e-04 - val_mean_absolute_error: 0.0082
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.8516e-05 - mean_absolute_error: 0.0047 - val_loss: 1.3420e-04 - val_mean_absolute_error: 0.0079
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.1757e-05 - mean_absolute_error: 0.0047 - val_loss: 1.2627e-04 - val_mean_absolute_error: 0.0075
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.3484e-05 - mean_absolute_error: 0.0048 - val_loss: 1.5106e-04 - val_mean_absolute_error: 0.0088
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5255e-05 - mean_absolute_error: 0.0051 - val_loss: 3.1410e-04 - val_mean_absolute_error: 0.0150
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.6181e-05 - mean_absolute_error: 0.0058 - val_loss: 1.4215e-04 - val_mean_absolute_error: 0.0087
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.8076e-05 - mean_absolute_error: 0.0049 - val_loss: 1.3215e-04 - val_mean_absolute_error: 0.0078
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.7491e-05 - mean_absolute_error: 0.0047 - val_loss: 1.6328e-04 - val_mean_absolute_error: 0.0094
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.4898e-05 - mean_absolute_error: 0.0049 - val_loss: 1.2772e-04 - val_mean_absolute_error: 0.0076
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.0172e-05 - mean_absolute_error: 0.0043 - val_loss: 1.7028e-04 - val_mean_absolute_error: 0.0097
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.7195e-05 - mean_absolute_error: 0.0049 - val_loss: 1.7087e-04 - val_mean_absolute_error: 0.0098
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.1508e-05 - mean_absolute_error: 0.0054 - val_loss: 2.3541e-04 - val_mean_absolute_error: 0.0124
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.2331e-05 - mean_absolute_error: 0.0053 - val_loss: 1.3631e-04 - val_mean_absolute_error: 0.0081
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.0909e-05 - mean_absolute_error: 0.0048 - val_loss: 1.2118e-04 - val_mean_absolute_error: 0.0074
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.0204e-05 - mean_absolute_error: 0.0048 - val_loss: 1.2799e-04 - val_mean_absolute_error: 0.0080
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.7360e-05 - mean_absolute_error: 0.0047 - val_loss: 2.1018e-04 - val_mean_absolute_error: 0.0115
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.8441e-05 - mean_absolute_error: 0.0054 - val_loss: 1.9628e-04 - val_mean_absolute_error: 0.0109
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.8398e-05 - mean_absolute_error: 0.0047 - val_loss: 1.5699e-04 - val_mean_absolute_error: 0.0096
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.4244e-05 - mean_absolute_error: 0.0052 - val_loss: 1.4008e-04 - val_mean_absolute_error: 0.0084
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.7505e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2633e-04 - val_mean_absolute_error: 0.0077
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.3041e-05 - mean_absolute_error: 0.0049 - val_loss: 1.6808e-04 - val_mean_absolute_error: 0.0102
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.9396e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1953e-04 - val_mean_absolute_error: 0.0075
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9067e-05 - mean_absolute_error: 0.0047 - val_loss: 1.5134e-04 - val_mean_absolute_error: 0.0094
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.8712e-05 - mean_absolute_error: 0.0048 - val_loss: 1.2169e-04 - val_mean_absolute_error: 0.0074
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9987e-05 - mean_absolute_error: 0.0049 - val_loss: 1.4026e-04 - val_mean_absolute_error: 0.0084
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5032e-05 - mean_absolute_error: 0.0051 - val_loss: 1.1714e-04 - val_mean_absolute_error: 0.0072
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8126e-05 - mean_absolute_error: 0.0055 - val_loss: 1.1965e-04 - val_mean_absolute_error: 0.0073
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8848e-05 - mean_absolute_error: 0.0041 - val_loss: 1.1829e-04 - val_mean_absolute_error: 0.0075
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.4181e-05 - mean_absolute_error: 0.0052 - val_loss: 2.8862e-04 - val_mean_absolute_error: 0.0148
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3650e-05 - mean_absolute_error: 0.0055 - val_loss: 1.2307e-04 - val_mean_absolute_error: 0.0078
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.9625e-05 - mean_absolute_error: 0.0047 - val_loss: 1.5792e-04 - val_mean_absolute_error: 0.0094
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.0379e-05 - mean_absolute_error: 0.0049 - val_loss: 1.1643e-04 - val_mean_absolute_error: 0.0073
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.2908e-05 - mean_absolute_error: 0.0043 - val_loss: 1.3092e-04 - val_mean_absolute_error: 0.0080
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.1509e-05 - mean_absolute_error: 0.0054 - val_loss: 1.1708e-04 - val_mean_absolute_error: 0.0072
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.8502e-05 - mean_absolute_error: 0.0047 - val_loss: 1.6472e-04 - val_mean_absolute_error: 0.0097
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4810e-05 - mean_absolute_error: 0.0045 - val_loss: 3.3874e-04 - val_mean_absolute_error: 0.0160
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6037e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3986e-04 - val_mean_absolute_error: 0.0085
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4301e-05 - mean_absolute_error: 0.0045 - val_loss: 1.1281e-04 - val_mean_absolute_error: 0.0071
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.5341e-05 - mean_absolute_error: 0.0052 - val_loss: 1.1650e-04 - val_mean_absolute_error: 0.0072
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.5429e-05 - mean_absolute_error: 0.0052 - val_loss: 1.1741e-04 - val_mean_absolute_error: 0.0075
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0378e-05 - mean_absolute_error: 0.0041 - val_loss: 1.5078e-04 - val_mean_absolute_error: 0.0095
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.9780e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1897e-04 - val_mean_absolute_error: 0.0076
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.4448e-05 - mean_absolute_error: 0.0049 - val_loss: 1.1363e-04 - val_mean_absolute_error: 0.0073
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3857e-05 - mean_absolute_error: 0.0046 - val_loss: 1.7067e-04 - val_mean_absolute_error: 0.0105
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.1241e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1637e-04 - val_mean_absolute_error: 0.0072
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.2157e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1615e-04 - val_mean_absolute_error: 0.0072
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8898e-05 - mean_absolute_error: 0.0042 - val_loss: 1.3016e-04 - val_mean_absolute_error: 0.0081
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3308e-05 - mean_absolute_error: 0.0057 - val_loss: 1.2542e-04 - val_mean_absolute_error: 0.0078
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.7743e-05 - mean_absolute_error: 0.0048 - val_loss: 1.2355e-04 - val_mean_absolute_error: 0.0080
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 4.4368e-05 - mean_absolute_error: 0.0044 - val_loss: 1.3066e-04 - val_mean_absolute_error: 0.0085
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.1466e-05 - mean_absolute_error: 0.0049 - val_loss: 1.8887e-04 - val_mean_absolute_error: 0.0113
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6106e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1367e-04 - val_mean_absolute_error: 0.0073
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.6344e-05 - mean_absolute_error: 0.0048 - val_loss: 1.1607e-04 - val_mean_absolute_error: 0.0072
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9466e-05 - mean_absolute_error: 0.0048 - val_loss: 1.1033e-04 - val_mean_absolute_error: 0.0069
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 4.5065e-05 - mean_absolute_error: 0.0043 - val_loss: 1.1487e-04 - val_mean_absolute_error: 0.0075
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.7353e-05 - mean_absolute_error: 0.0048 - val_loss: 1.7908e-04 - val_mean_absolute_error: 0.0105
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.9154e-05 - mean_absolute_error: 0.0055 - val_loss: 1.8919e-04 - val_mean_absolute_error: 0.0109
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.1183e-05 - mean_absolute_error: 0.0056 - val_loss: 1.1552e-04 - val_mean_absolute_error: 0.0075
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.7578e-05 - mean_absolute_error: 0.0048 - val_loss: 1.0871e-04 - val_mean_absolute_error: 0.0069
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.3671e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2664e-04 - val_mean_absolute_error: 0.0083
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.6682e-05 - mean_absolute_error: 0.0048 - val_loss: 1.0852e-04 - val_mean_absolute_error: 0.0068
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.8192e-05 - mean_absolute_error: 0.0045 - val_loss: 1.2820e-04 - val_mean_absolute_error: 0.0080
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.7518e-05 - mean_absolute_error: 0.0052 - val_loss: 2.9945e-04 - val_mean_absolute_error: 0.0149
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.9853e-05 - mean_absolute_error: 0.0057 - val_loss: 1.1063e-04 - val_mean_absolute_error: 0.0069
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9985e-05 - mean_absolute_error: 0.0043 - val_loss: 1.1701e-04 - val_mean_absolute_error: 0.0073
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.1642e-05 - mean_absolute_error: 0.0044 - val_loss: 1.0788e-04 - val_mean_absolute_error: 0.0068
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.8298e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1937e-04 - val_mean_absolute_error: 0.0075
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.4849e-05 - mean_absolute_error: 0.0046 - val_loss: 1.7164e-04 - val_mean_absolute_error: 0.0103
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.5646e-05 - mean_absolute_error: 0.0057 - val_loss: 1.9580e-04 - val_mean_absolute_error: 0.0113
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.1404e-05 - mean_absolute_error: 0.0048 - val_loss: 1.2757e-04 - val_mean_absolute_error: 0.0080
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0912e-05 - mean_absolute_error: 0.0043 - val_loss: 1.3593e-04 - val_mean_absolute_error: 0.0085
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.7981e-05 - mean_absolute_error: 0.0045 - val_loss: 1.0712e-04 - val_mean_absolute_error: 0.0068
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.1969e-05 - mean_absolute_error: 0.0044 - val_loss: 1.6957e-04 - val_mean_absolute_error: 0.0102
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7729e-05 - mean_absolute_error: 0.0048 - val_loss: 1.5543e-04 - val_mean_absolute_error: 0.0095
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.1968e-05 - mean_absolute_error: 0.0045 - val_loss: 1.7281e-04 - val_mean_absolute_error: 0.0104
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.9008e-05 - mean_absolute_error: 0.0054 - val_loss: 1.1149e-04 - val_mean_absolute_error: 0.0069
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.0804e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1112e-04 - val_mean_absolute_error: 0.0069
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.5674e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1187e-04 - val_mean_absolute_error: 0.0072
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7717e-05 - mean_absolute_error: 0.0040 - val_loss: 1.1224e-04 - val_mean_absolute_error: 0.0073
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.7177e-05 - mean_absolute_error: 0.0046 - val_loss: 1.0931e-04 - val_mean_absolute_error: 0.0070
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3348e-05 - mean_absolute_error: 0.0043 - val_loss: 1.1366e-04 - val_mean_absolute_error: 0.0074
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4321e-05 - mean_absolute_error: 0.0047 - val_loss: 1.7517e-04 - val_mean_absolute_error: 0.0105
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4694e-05 - mean_absolute_error: 0.0048 - val_loss: 2.3519e-04 - val_mean_absolute_error: 0.0128
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.1664e-05 - mean_absolute_error: 0.0052 - val_loss: 1.2440e-04 - val_mean_absolute_error: 0.0081
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 5.7770e-05 - mean_absolute_error: 0.0053 - val_loss: 3.1207e-04 - val_mean_absolute_error: 0.0156
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.9916e-05 - mean_absolute_error: 0.0058 - val_loss: 1.4962e-04 - val_mean_absolute_error: 0.0093
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 3.7815e-05 - mean_absolute_error: 0.0043 - val_loss: 2.5559e-04 - val_mean_absolute_error: 0.0135
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.5299e-05 - mean_absolute_error: 0.0054 - val_loss: 2.1991e-04 - val_mean_absolute_error: 0.0125
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.0489e-05 - mean_absolute_error: 0.0051 - val_loss: 1.3501e-04 - val_mean_absolute_error: 0.0085
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.7067e-05 - mean_absolute_error: 0.0042 - val_loss: 1.2396e-04 - val_mean_absolute_error: 0.0081
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0660e-05 - mean_absolute_error: 0.0041 - val_loss: 1.1476e-04 - val_mean_absolute_error: 0.0075
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4146e-05 - mean_absolute_error: 0.0045 - val_loss: 1.1930e-04 - val_mean_absolute_error: 0.0078
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.1458e-05 - mean_absolute_error: 0.0055 - val_loss: 1.4482e-04 - val_mean_absolute_error: 0.0090
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.0043e-05 - mean_absolute_error: 0.0043 - val_loss: 1.7109e-04 - val_mean_absolute_error: 0.0103
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.0889e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1069e-04 - val_mean_absolute_error: 0.0069
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1085e-05 - mean_absolute_error: 0.0053 - val_loss: 1.3020e-04 - val_mean_absolute_error: 0.0082
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.7207e-05 - mean_absolute_error: 0.0047 - val_loss: 1.2791e-04 - val_mean_absolute_error: 0.0080

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 3257044.3936533527
# RMSE: 1804.7283434504354
# MAE: 1284.949094248008
# MAPE: 1.8914344320188552 %
#
# Model evalution on validate set
# MSE: 5152295.078973943
# RMSE: 2269.8667535725403
# MAE: 1617.7258213932807
# MAPE: 1.6127729979807552 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step

# %%
y_pred_30_days
# Out:
# array([[125797.54 ],
#        [125390.86 ],
#        [125222.19 ],
#        [124837.99 ],
#        [125562.79 ],
#        [125578.62 ],
#        [125592.95 ],
#        [125658.09 ],
#        [125600.12 ],
#        [125601.125],
#        [125601.49 ],
#        [125593.53 ],
#        [125598.305],
#        [125598.06 ],
#        [125597.766],
#        [125598.63 ],
#        [125598.234],
#        [125598.266],
#        [125598.305],
#        [125598.21 ],
#        [125598.25 ],
#        [125598.266],
#        [125598.266],
#        [125598.234],
#        [125598.25 ],
#        [125598.25 ],
#        [125598.266],
#        [125598.25 ],
#        [125598.234],
#        [125598.25 ],
#        [125598.25 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Forecast Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Forecast the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
