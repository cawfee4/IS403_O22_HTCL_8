# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: FPT - Test/Train/Vaildation: 60/20/20
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1745.1191275136425
# - MAE: 1196.8378828436255
# - MAPE: 1.760382557622311 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 1  # 6 2 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.tail()
# Out:
#              close
# time
# 2024-05-27  132800
# 2024-05-28  137000
# 2024-05-29  135700
# 2024-05-30  135000
# 2024-05-31  134600

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((776, 10), (776,), (251, 10), (251,), (253, 10), (253,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - loss: 0.0139 - mean_absolute_error: 0.0777 - val_loss: 0.0021 - val_mean_absolute_error: 0.0422
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.2435e-04 - mean_absolute_error: 0.0186 - val_loss: 3.6548e-04 - val_mean_absolute_error: 0.0133
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.9519e-04 - mean_absolute_error: 0.0100 - val_loss: 3.3386e-04 - val_mean_absolute_error: 0.0128
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7952e-04 - mean_absolute_error: 0.0088 - val_loss: 3.3307e-04 - val_mean_absolute_error: 0.0133
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.1092e-04 - mean_absolute_error: 0.0075 - val_loss: 2.8920e-04 - val_mean_absolute_error: 0.0121
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.2075e-04 - mean_absolute_error: 0.0076 - val_loss: 2.8728e-04 - val_mean_absolute_error: 0.0125
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0503e-04 - mean_absolute_error: 0.0072 - val_loss: 2.5357e-04 - val_mean_absolute_error: 0.0110
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1902e-04 - mean_absolute_error: 0.0070 - val_loss: 2.1958e-04 - val_mean_absolute_error: 0.0102
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.4510e-05 - mean_absolute_error: 0.0063 - val_loss: 2.0894e-04 - val_mean_absolute_error: 0.0099
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0740e-04 - mean_absolute_error: 0.0069 - val_loss: 1.9938e-04 - val_mean_absolute_error: 0.0099
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.5046e-05 - mean_absolute_error: 0.0065 - val_loss: 1.8605e-04 - val_mean_absolute_error: 0.0094
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.1742e-05 - mean_absolute_error: 0.0063 - val_loss: 1.7572e-04 - val_mean_absolute_error: 0.0091
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0743e-05 - mean_absolute_error: 0.0059 - val_loss: 2.1367e-04 - val_mean_absolute_error: 0.0110
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.5577e-05 - mean_absolute_error: 0.0062 - val_loss: 1.7256e-04 - val_mean_absolute_error: 0.0091
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.7553e-05 - mean_absolute_error: 0.0060 - val_loss: 2.0293e-04 - val_mean_absolute_error: 0.0106
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.5273e-05 - mean_absolute_error: 0.0060 - val_loss: 1.9817e-04 - val_mean_absolute_error: 0.0104
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 7.2912e-05 - mean_absolute_error: 0.0058 - val_loss: 5.8332e-04 - val_mean_absolute_error: 0.0215
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.5003e-05 - mean_absolute_error: 0.0065 - val_loss: 1.6827e-04 - val_mean_absolute_error: 0.0091
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.7211e-05 - mean_absolute_error: 0.0059 - val_loss: 1.5843e-04 - val_mean_absolute_error: 0.0086
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.2106e-05 - mean_absolute_error: 0.0053 - val_loss: 1.7207e-04 - val_mean_absolute_error: 0.0095
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.7004e-05 - mean_absolute_error: 0.0062 - val_loss: 2.5658e-04 - val_mean_absolute_error: 0.0128
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.9949e-05 - mean_absolute_error: 0.0061 - val_loss: 1.6012e-04 - val_mean_absolute_error: 0.0087
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4783e-05 - mean_absolute_error: 0.0054 - val_loss: 2.4166e-04 - val_mean_absolute_error: 0.0124
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.4150e-05 - mean_absolute_error: 0.0060 - val_loss: 1.9129e-04 - val_mean_absolute_error: 0.0104
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.9226e-05 - mean_absolute_error: 0.0055 - val_loss: 1.7620e-04 - val_mean_absolute_error: 0.0097
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.0795e-05 - mean_absolute_error: 0.0060 - val_loss: 1.5197e-04 - val_mean_absolute_error: 0.0085
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.2932e-05 - mean_absolute_error: 0.0053 - val_loss: 2.0641e-04 - val_mean_absolute_error: 0.0110
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.9849e-05 - mean_absolute_error: 0.0053 - val_loss: 1.7583e-04 - val_mean_absolute_error: 0.0097
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.3321e-05 - mean_absolute_error: 0.0054 - val_loss: 1.8337e-04 - val_mean_absolute_error: 0.0101
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.7979e-05 - mean_absolute_error: 0.0062 - val_loss: 1.6262e-04 - val_mean_absolute_error: 0.0090
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.7824e-05 - mean_absolute_error: 0.0051 - val_loss: 1.5713e-04 - val_mean_absolute_error: 0.0088
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.1555e-05 - mean_absolute_error: 0.0059 - val_loss: 1.4600e-04 - val_mean_absolute_error: 0.0082
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 5.0987e-05 - mean_absolute_error: 0.0048 - val_loss: 1.4917e-04 - val_mean_absolute_error: 0.0083
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.8963e-05 - mean_absolute_error: 0.0055 - val_loss: 1.5627e-04 - val_mean_absolute_error: 0.0089
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.2155e-05 - mean_absolute_error: 0.0056 - val_loss: 1.4195e-04 - val_mean_absolute_error: 0.0080
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.1375e-05 - mean_absolute_error: 0.0052 - val_loss: 1.7805e-04 - val_mean_absolute_error: 0.0099
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.2769e-05 - mean_absolute_error: 0.0055 - val_loss: 2.1052e-04 - val_mean_absolute_error: 0.0114
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4570e-05 - mean_absolute_error: 0.0056 - val_loss: 1.4266e-04 - val_mean_absolute_error: 0.0080
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.1798e-05 - mean_absolute_error: 0.0048 - val_loss: 1.3889e-04 - val_mean_absolute_error: 0.0079
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.9974e-05 - mean_absolute_error: 0.0048 - val_loss: 1.7952e-04 - val_mean_absolute_error: 0.0102
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.7642e-05 - mean_absolute_error: 0.0052 - val_loss: 1.4037e-04 - val_mean_absolute_error: 0.0080
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.8778e-05 - mean_absolute_error: 0.0049 - val_loss: 1.5467e-04 - val_mean_absolute_error: 0.0088
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.0874e-05 - mean_absolute_error: 0.0055 - val_loss: 1.3694e-04 - val_mean_absolute_error: 0.0079
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.5165e-05 - mean_absolute_error: 0.0049 - val_loss: 1.8426e-04 - val_mean_absolute_error: 0.0103
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.3660e-05 - mean_absolute_error: 0.0050 - val_loss: 1.3576e-04 - val_mean_absolute_error: 0.0078
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.0787e-05 - mean_absolute_error: 0.0059 - val_loss: 1.3973e-04 - val_mean_absolute_error: 0.0082
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4726e-05 - mean_absolute_error: 0.0049 - val_loss: 1.7077e-04 - val_mean_absolute_error: 0.0097
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.7253e-05 - mean_absolute_error: 0.0056 - val_loss: 1.6418e-04 - val_mean_absolute_error: 0.0094
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.7058e-05 - mean_absolute_error: 0.0053 - val_loss: 2.2811e-04 - val_mean_absolute_error: 0.0121
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.2567e-05 - mean_absolute_error: 0.0061 - val_loss: 1.7802e-04 - val_mean_absolute_error: 0.0100
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.4819e-05 - mean_absolute_error: 0.0058 - val_loss: 1.8000e-04 - val_mean_absolute_error: 0.0101
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.5638e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3146e-04 - val_mean_absolute_error: 0.0078
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.8937e-05 - mean_absolute_error: 0.0050 - val_loss: 1.4241e-04 - val_mean_absolute_error: 0.0086
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.5761e-05 - mean_absolute_error: 0.0048 - val_loss: 1.7466e-04 - val_mean_absolute_error: 0.0102
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.4150e-05 - mean_absolute_error: 0.0056 - val_loss: 1.3306e-04 - val_mean_absolute_error: 0.0081
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0181e-05 - mean_absolute_error: 0.0054 - val_loss: 2.0030e-04 - val_mean_absolute_error: 0.0113
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.6510e-05 - mean_absolute_error: 0.0061 - val_loss: 2.5520e-04 - val_mean_absolute_error: 0.0134
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.0704e-05 - mean_absolute_error: 0.0064 - val_loss: 1.2834e-04 - val_mean_absolute_error: 0.0076
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8741e-05 - mean_absolute_error: 0.0049 - val_loss: 1.2752e-04 - val_mean_absolute_error: 0.0076
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.5518e-05 - mean_absolute_error: 0.0049 - val_loss: 1.9449e-04 - val_mean_absolute_error: 0.0108
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.3560e-05 - mean_absolute_error: 0.0049 - val_loss: 1.3845e-04 - val_mean_absolute_error: 0.0081
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.0781e-05 - mean_absolute_error: 0.0046 - val_loss: 1.6225e-04 - val_mean_absolute_error: 0.0097
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4393e-05 - mean_absolute_error: 0.0055 - val_loss: 1.6695e-04 - val_mean_absolute_error: 0.0100
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.1128e-05 - mean_absolute_error: 0.0055 - val_loss: 1.3279e-04 - val_mean_absolute_error: 0.0082
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.6621e-05 - mean_absolute_error: 0.0060 - val_loss: 1.5017e-04 - val_mean_absolute_error: 0.0088
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.5450e-05 - mean_absolute_error: 0.0052 - val_loss: 1.5274e-04 - val_mean_absolute_error: 0.0090
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.4273e-05 - mean_absolute_error: 0.0052 - val_loss: 1.7902e-04 - val_mean_absolute_error: 0.0106
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.9192e-05 - mean_absolute_error: 0.0050 - val_loss: 1.7778e-04 - val_mean_absolute_error: 0.0101
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4362e-05 - mean_absolute_error: 0.0056 - val_loss: 2.1254e-04 - val_mean_absolute_error: 0.0116
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6088e-05 - mean_absolute_error: 0.0057 - val_loss: 1.8049e-04 - val_mean_absolute_error: 0.0103
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0258e-05 - mean_absolute_error: 0.0048 - val_loss: 1.2555e-04 - val_mean_absolute_error: 0.0078
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.8372e-05 - mean_absolute_error: 0.0042 - val_loss: 1.2050e-04 - val_mean_absolute_error: 0.0073
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.2665e-05 - mean_absolute_error: 0.0042 - val_loss: 1.7016e-04 - val_mean_absolute_error: 0.0098
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0027e-05 - mean_absolute_error: 0.0054 - val_loss: 1.3224e-04 - val_mean_absolute_error: 0.0080
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.9734e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1925e-04 - val_mean_absolute_error: 0.0074
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.0540e-05 - mean_absolute_error: 0.0047 - val_loss: 1.2030e-04 - val_mean_absolute_error: 0.0075
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7920e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1727e-04 - val_mean_absolute_error: 0.0073
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.9311e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1695e-04 - val_mean_absolute_error: 0.0072
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.3927e-05 - mean_absolute_error: 0.0049 - val_loss: 1.5915e-04 - val_mean_absolute_error: 0.0098
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1071e-05 - mean_absolute_error: 0.0057 - val_loss: 1.3331e-04 - val_mean_absolute_error: 0.0084
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.3027e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1779e-04 - val_mean_absolute_error: 0.0074
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.3938e-05 - mean_absolute_error: 0.0050 - val_loss: 1.5159e-04 - val_mean_absolute_error: 0.0091
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2749e-05 - mean_absolute_error: 0.0055 - val_loss: 1.1608e-04 - val_mean_absolute_error: 0.0073
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.8145e-05 - mean_absolute_error: 0.0048 - val_loss: 1.1566e-04 - val_mean_absolute_error: 0.0072
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.0463e-05 - mean_absolute_error: 0.0042 - val_loss: 1.2569e-04 - val_mean_absolute_error: 0.0077
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.8998e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1767e-04 - val_mean_absolute_error: 0.0075
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.6942e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2278e-04 - val_mean_absolute_error: 0.0079
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.1207e-05 - mean_absolute_error: 0.0057 - val_loss: 1.1451e-04 - val_mean_absolute_error: 0.0071
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 4.4711e-05 - mean_absolute_error: 0.0048 - val_loss: 3.2288e-04 - val_mean_absolute_error: 0.0155
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.2789e-05 - mean_absolute_error: 0.0061 - val_loss: 1.1488e-04 - val_mean_absolute_error: 0.0073
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.7206e-05 - mean_absolute_error: 0.0051 - val_loss: 1.1335e-04 - val_mean_absolute_error: 0.0071
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.4885e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1562e-04 - val_mean_absolute_error: 0.0071
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.5816e-05 - mean_absolute_error: 0.0041 - val_loss: 1.4452e-04 - val_mean_absolute_error: 0.0092
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.7235e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1818e-04 - val_mean_absolute_error: 0.0076
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.3758e-05 - mean_absolute_error: 0.0045 - val_loss: 1.3948e-04 - val_mean_absolute_error: 0.0089
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.2349e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1252e-04 - val_mean_absolute_error: 0.0070
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3847e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1091e-04 - val_mean_absolute_error: 0.0070
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2652e-05 - mean_absolute_error: 0.0042 - val_loss: 1.1609e-04 - val_mean_absolute_error: 0.0072
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9467e-05 - mean_absolute_error: 0.0043 - val_loss: 1.6223e-04 - val_mean_absolute_error: 0.0097
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.9583e-05 - mean_absolute_error: 0.0048 - val_loss: 1.1083e-04 - val_mean_absolute_error: 0.0071
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.3836e-05 - mean_absolute_error: 0.0044 - val_loss: 1.3194e-04 - val_mean_absolute_error: 0.0082
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.8168e-05 - mean_absolute_error: 0.0042 - val_loss: 1.1056e-04 - val_mean_absolute_error: 0.0069
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.2587e-05 - mean_absolute_error: 0.0043 - val_loss: 1.5825e-04 - val_mean_absolute_error: 0.0096
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.5871e-05 - mean_absolute_error: 0.0045 - val_loss: 1.0998e-04 - val_mean_absolute_error: 0.0070
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.3335e-05 - mean_absolute_error: 0.0045 - val_loss: 1.9870e-04 - val_mean_absolute_error: 0.0117
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.0667e-05 - mean_absolute_error: 0.0059 - val_loss: 1.2005e-04 - val_mean_absolute_error: 0.0078
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.8694e-05 - mean_absolute_error: 0.0053 - val_loss: 1.1023e-04 - val_mean_absolute_error: 0.0071
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.6536e-05 - mean_absolute_error: 0.0041 - val_loss: 1.1504e-04 - val_mean_absolute_error: 0.0072
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.6117e-05 - mean_absolute_error: 0.0046 - val_loss: 1.6386e-04 - val_mean_absolute_error: 0.0099
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3788e-05 - mean_absolute_error: 0.0056 - val_loss: 1.3822e-04 - val_mean_absolute_error: 0.0086
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.3437e-05 - mean_absolute_error: 0.0046 - val_loss: 1.0908e-04 - val_mean_absolute_error: 0.0068
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.4567e-05 - mean_absolute_error: 0.0045 - val_loss: 1.3600e-04 - val_mean_absolute_error: 0.0085
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.3039e-05 - mean_absolute_error: 0.0043 - val_loss: 1.4492e-04 - val_mean_absolute_error: 0.0093
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.2405e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2442e-04 - val_mean_absolute_error: 0.0078
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.9374e-05 - mean_absolute_error: 0.0041 - val_loss: 1.1350e-04 - val_mean_absolute_error: 0.0071
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.5519e-05 - mean_absolute_error: 0.0046 - val_loss: 1.4863e-04 - val_mean_absolute_error: 0.0095
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.8293e-05 - mean_absolute_error: 0.0042 - val_loss: 1.0753e-04 - val_mean_absolute_error: 0.0068
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.6377e-05 - mean_absolute_error: 0.0045 - val_loss: 1.1523e-04 - val_mean_absolute_error: 0.0072
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.2781e-05 - mean_absolute_error: 0.0049 - val_loss: 1.1522e-04 - val_mean_absolute_error: 0.0075
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.0759e-05 - mean_absolute_error: 0.0045 - val_loss: 1.2634e-04 - val_mean_absolute_error: 0.0083
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.6483e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1634e-04 - val_mean_absolute_error: 0.0073
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.7259e-05 - mean_absolute_error: 0.0048 - val_loss: 1.0878e-04 - val_mean_absolute_error: 0.0068
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.0364e-05 - mean_absolute_error: 0.0042 - val_loss: 1.0780e-04 - val_mean_absolute_error: 0.0069
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.0289e-05 - mean_absolute_error: 0.0050 - val_loss: 1.0991e-04 - val_mean_absolute_error: 0.0069
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.4113e-05 - mean_absolute_error: 0.0046 - val_loss: 1.2279e-04 - val_mean_absolute_error: 0.0081
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.5766e-05 - mean_absolute_error: 0.0045 - val_loss: 1.0656e-04 - val_mean_absolute_error: 0.0068
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.6175e-05 - mean_absolute_error: 0.0045 - val_loss: 1.0870e-04 - val_mean_absolute_error: 0.0070
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.6149e-05 - mean_absolute_error: 0.0047 - val_loss: 1.3084e-04 - val_mean_absolute_error: 0.0082
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3856e-05 - mean_absolute_error: 0.0044 - val_loss: 1.9415e-04 - val_mean_absolute_error: 0.0115
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.7829e-05 - mean_absolute_error: 0.0049 - val_loss: 1.1479e-04 - val_mean_absolute_error: 0.0075
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.9409e-05 - mean_absolute_error: 0.0041 - val_loss: 1.4667e-04 - val_mean_absolute_error: 0.0094
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.0244e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1159e-04 - val_mean_absolute_error: 0.0072
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.7519e-05 - mean_absolute_error: 0.0040 - val_loss: 1.4038e-04 - val_mean_absolute_error: 0.0088
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.1118e-05 - mean_absolute_error: 0.0042 - val_loss: 1.5135e-04 - val_mean_absolute_error: 0.0094
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.3306e-05 - mean_absolute_error: 0.0051 - val_loss: 2.0520e-04 - val_mean_absolute_error: 0.0118
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.2733e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3637e-04 - val_mean_absolute_error: 0.0086
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8036e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3956e-04 - val_mean_absolute_error: 0.0088
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.1447e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2075e-04 - val_mean_absolute_error: 0.0079
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.2567e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1219e-04 - val_mean_absolute_error: 0.0070
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.7636e-05 - mean_absolute_error: 0.0042 - val_loss: 1.0713e-04 - val_mean_absolute_error: 0.0067
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 4.3681e-05 - mean_absolute_error: 0.0043 - val_loss: 1.1098e-04 - val_mean_absolute_error: 0.0072
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.9423e-05 - mean_absolute_error: 0.0043 - val_loss: 1.0817e-04 - val_mean_absolute_error: 0.0068
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.0287e-05 - mean_absolute_error: 0.0047 - val_loss: 1.0892e-04 - val_mean_absolute_error: 0.0071
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.8582e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1333e-04 - val_mean_absolute_error: 0.0071
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.2094e-05 - mean_absolute_error: 0.0049 - val_loss: 1.5055e-04 - val_mean_absolute_error: 0.0094
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.9032e-05 - mean_absolute_error: 0.0053 - val_loss: 1.1957e-04 - val_mean_absolute_error: 0.0075
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.8262e-05 - mean_absolute_error: 0.0048 - val_loss: 1.1309e-04 - val_mean_absolute_error: 0.0074
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.5231e-05 - mean_absolute_error: 0.0045 - val_loss: 1.3342e-04 - val_mean_absolute_error: 0.0087
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.7719e-05 - mean_absolute_error: 0.0054 - val_loss: 1.1556e-04 - val_mean_absolute_error: 0.0073
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.4644e-05 - mean_absolute_error: 0.0047 - val_loss: 1.3488e-04 - val_mean_absolute_error: 0.0085
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.5072e-05 - mean_absolute_error: 0.0044 - val_loss: 1.1106e-04 - val_mean_absolute_error: 0.0070
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.8599e-05 - mean_absolute_error: 0.0043 - val_loss: 1.0756e-04 - val_mean_absolute_error: 0.0068
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8965e-05 - mean_absolute_error: 0.0043 - val_loss: 1.0874e-04 - val_mean_absolute_error: 0.0070
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.2497e-05 - mean_absolute_error: 0.0042 - val_loss: 1.1108e-04 - val_mean_absolute_error: 0.0072
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.0271e-05 - mean_absolute_error: 0.0046 - val_loss: 1.1981e-04 - val_mean_absolute_error: 0.0076
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.8346e-05 - mean_absolute_error: 0.0041 - val_loss: 1.0937e-04 - val_mean_absolute_error: 0.0071
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6577e-05 - mean_absolute_error: 0.0047 - val_loss: 1.8377e-04 - val_mean_absolute_error: 0.0109
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.0186e-05 - mean_absolute_error: 0.0050 - val_loss: 1.0971e-04 - val_mean_absolute_error: 0.0069
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.8530e-05 - mean_absolute_error: 0.0045 - val_loss: 1.3343e-04 - val_mean_absolute_error: 0.0087
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 5.1392e-05 - mean_absolute_error: 0.0050 - val_loss: 1.0636e-04 - val_mean_absolute_error: 0.0067
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.8689e-05 - mean_absolute_error: 0.0042 - val_loss: 1.1963e-04 - val_mean_absolute_error: 0.0078
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.5420e-05 - mean_absolute_error: 0.0045 - val_loss: 1.0866e-04 - val_mean_absolute_error: 0.0068
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.1294e-05 - mean_absolute_error: 0.0043 - val_loss: 1.1290e-04 - val_mean_absolute_error: 0.0073
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.4320e-05 - mean_absolute_error: 0.0043 - val_loss: 1.3389e-04 - val_mean_absolute_error: 0.0085
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 5.2290e-05 - mean_absolute_error: 0.0050 - val_loss: 2.0225e-04 - val_mean_absolute_error: 0.0117
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.3498e-05 - mean_absolute_error: 0.0046 - val_loss: 2.0633e-04 - val_mean_absolute_error: 0.0118
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3690e-05 - mean_absolute_error: 0.0057 - val_loss: 1.1572e-04 - val_mean_absolute_error: 0.0075
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.0826e-05 - mean_absolute_error: 0.0044 - val_loss: 1.0949e-04 - val_mean_absolute_error: 0.0071
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.0729e-05 - mean_absolute_error: 0.0043 - val_loss: 1.0984e-04 - val_mean_absolute_error: 0.0069
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 3.9416e-05 - mean_absolute_error: 0.0043 - val_loss: 1.0628e-04 - val_mean_absolute_error: 0.0067
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.9770e-05 - mean_absolute_error: 0.0043 - val_loss: 1.0891e-04 - val_mean_absolute_error: 0.0070
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.2856e-05 - mean_absolute_error: 0.0044 - val_loss: 1.3034e-04 - val_mean_absolute_error: 0.0085
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.9243e-05 - mean_absolute_error: 0.0042 - val_loss: 1.1152e-04 - val_mean_absolute_error: 0.0072
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.7931e-05 - mean_absolute_error: 0.0049 - val_loss: 1.3885e-04 - val_mean_absolute_error: 0.0087
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 4.2194e-05 - mean_absolute_error: 0.0044 - val_loss: 1.0928e-04 - val_mean_absolute_error: 0.0071
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.1130e-05 - mean_absolute_error: 0.0042 - val_loss: 1.3197e-04 - val_mean_absolute_error: 0.0084
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.3628e-05 - mean_absolute_error: 0.0046 - val_loss: 1.0836e-04 - val_mean_absolute_error: 0.0069
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.6160e-05 - mean_absolute_error: 0.0048 - val_loss: 1.4250e-04 - val_mean_absolute_error: 0.0089
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.6595e-05 - mean_absolute_error: 0.0047 - val_loss: 1.3520e-04 - val_mean_absolute_error: 0.0085
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.7745e-05 - mean_absolute_error: 0.0048 - val_loss: 1.1533e-04 - val_mean_absolute_error: 0.0073
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.7665e-05 - mean_absolute_error: 0.0048 - val_loss: 1.2768e-04 - val_mean_absolute_error: 0.0081
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.1365e-05 - mean_absolute_error: 0.0047 - val_loss: 1.2792e-04 - val_mean_absolute_error: 0.0081
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.6781e-05 - mean_absolute_error: 0.0048 - val_loss: 1.0651e-04 - val_mean_absolute_error: 0.0067
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 3.8028e-05 - mean_absolute_error: 0.0041 - val_loss: 1.3345e-04 - val_mean_absolute_error: 0.0086
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.7107e-05 - mean_absolute_error: 0.0048 - val_loss: 1.0783e-04 - val_mean_absolute_error: 0.0068
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.7661e-05 - mean_absolute_error: 0.0042 - val_loss: 1.4333e-04 - val_mean_absolute_error: 0.0090
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.6637e-05 - mean_absolute_error: 0.0049 - val_loss: 1.1141e-04 - val_mean_absolute_error: 0.0070
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.0544e-05 - mean_absolute_error: 0.0042 - val_loss: 1.0773e-04 - val_mean_absolute_error: 0.0068
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.5524e-05 - mean_absolute_error: 0.0041 - val_loss: 1.0680e-04 - val_mean_absolute_error: 0.0067
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.5744e-05 - mean_absolute_error: 0.0046 - val_loss: 1.4150e-04 - val_mean_absolute_error: 0.0089
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.5462e-05 - mean_absolute_error: 0.0046 - val_loss: 1.0848e-04 - val_mean_absolute_error: 0.0068
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.2848e-05 - mean_absolute_error: 0.0044 - val_loss: 1.4796e-04 - val_mean_absolute_error: 0.0094
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.6866e-05 - mean_absolute_error: 0.0048 - val_loss: 1.1446e-04 - val_mean_absolute_error: 0.0074
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5469e-05 - mean_absolute_error: 0.0040 - val_loss: 1.1190e-04 - val_mean_absolute_error: 0.0071
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.0849e-05 - mean_absolute_error: 0.0044 - val_loss: 1.0760e-04 - val_mean_absolute_error: 0.0068
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6798e-05 - mean_absolute_error: 0.0042 - val_loss: 1.3157e-04 - val_mean_absolute_error: 0.0083
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.6094e-05 - mean_absolute_error: 0.0046 - val_loss: 1.3533e-04 - val_mean_absolute_error: 0.0086
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.1623e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2777e-04 - val_mean_absolute_error: 0.0083
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.5002e-05 - mean_absolute_error: 0.0046 - val_loss: 1.3550e-04 - val_mean_absolute_error: 0.0085
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.4659e-05 - mean_absolute_error: 0.0047 - val_loss: 1.1164e-04 - val_mean_absolute_error: 0.0070

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 3045440.769213977
# RMSE: 1745.1191275136425
# MAE: 1196.8378828436255
# MAPE: 1.760382557622311 %
#
# Model evalution on validate set
# MSE: 5665212.337535753
# RMSE: 2380.1706530280035
# MAE: 1673.9703248517787
# MAPE: 1.6541157112960374 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step

# %%
y_pred_30_days
# Out:
# array([[125479.37 ],
#        [125794.87 ],
#        [125715.164],
#        [125372.76 ],
#        [126245.086],
#        [126141.33 ],
#        [126153.35 ],
#        [126219.01 ],
#        [126132.97 ],
#        [126150.234],
#        [126149.54 ],
#        [126140.32 ],
#        [126149.33 ],
#        [126146.94 ],
#        [126146.945],
#        [126148.08 ],
#        [126147.1  ],
#        [126147.39 ],
#        [126147.445],
#        [126147.27 ],
#        [126147.39 ],
#        [126147.36 ],
#        [126147.33 ],
#        [126147.36 ],
#        [126147.36 ],
#        [126147.33 ],
#        [126147.34 ],
#        [126147.34 ],
#        [126147.36 ],
#        [126147.34 ],
#        [126147.33 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Forecast Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Forecast the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
