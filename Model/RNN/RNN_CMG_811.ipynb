# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: CMG - Test/Train/Vaildation: 80/10/10
# - Dataset: 1252 rows x 7 column (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 760.5362077345704
# - MAE: 529.3999280427631
# - MAPE: 1.5048799600931175 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 2  # 8 1 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830

# %%
df.shape
# Out:
# (1252, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1247    40000
# 1248    40200
# 1249    40000
# 1250    39950
# 1251    41200
# Name: close, Length: 1252, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((990, 10), (990,), (114, 10), (114,), (115, 10), (115,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 0.0475 - mean_absolute_error: 0.1485 - val_loss: 0.0112 - val_mean_absolute_error: 0.0999
# Epoch 2/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0026 - mean_absolute_error: 0.0373 - val_loss: 9.9123e-04 - val_mean_absolute_error: 0.0260
# Epoch 3/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0016 - mean_absolute_error: 0.0297 - val_loss: 8.0725e-04 - val_mean_absolute_error: 0.0228
# Epoch 4/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0011 - mean_absolute_error: 0.0235 - val_loss: 5.5994e-04 - val_mean_absolute_error: 0.0193
# Epoch 5/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.3410e-04 - mean_absolute_error: 0.0216 - val_loss: 8.6933e-04 - val_mean_absolute_error: 0.0224
# Epoch 6/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.1885e-04 - mean_absolute_error: 0.0201 - val_loss: 0.0012 - val_mean_absolute_error: 0.0291
# Epoch 7/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.8059e-04 - mean_absolute_error: 0.0196 - val_loss: 8.9369e-04 - val_mean_absolute_error: 0.0234
# Epoch 8/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8174e-04 - mean_absolute_error: 0.0184 - val_loss: 0.0017 - val_mean_absolute_error: 0.0358
# Epoch 9/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.1154e-04 - mean_absolute_error: 0.0189 - val_loss: 3.6419e-04 - val_mean_absolute_error: 0.0133
# Epoch 10/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6952e-04 - mean_absolute_error: 0.0179 - val_loss: 7.2196e-04 - val_mean_absolute_error: 0.0205
# Epoch 11/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.1198e-04 - mean_absolute_error: 0.0174 - val_loss: 5.6305e-04 - val_mean_absolute_error: 0.0171
# Epoch 12/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6456e-04 - mean_absolute_error: 0.0178 - val_loss: 4.7596e-04 - val_mean_absolute_error: 0.0154
# Epoch 13/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6081e-04 - mean_absolute_error: 0.0177 - val_loss: 3.1819e-04 - val_mean_absolute_error: 0.0124
# Epoch 14/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2427e-04 - mean_absolute_error: 0.0156 - val_loss: 8.7066e-04 - val_mean_absolute_error: 0.0239
# Epoch 15/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.2525e-04 - mean_absolute_error: 0.0175 - val_loss: 8.5616e-04 - val_mean_absolute_error: 0.0237
# Epoch 16/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.1566e-04 - mean_absolute_error: 0.0170 - val_loss: 3.3123e-04 - val_mean_absolute_error: 0.0139
# Epoch 17/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.4253e-04 - mean_absolute_error: 0.0166 - val_loss: 4.3825e-04 - val_mean_absolute_error: 0.0148
# Epoch 18/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7199e-04 - mean_absolute_error: 0.0166 - val_loss: 4.4867e-04 - val_mean_absolute_error: 0.0151
# Epoch 19/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.6694e-04 - mean_absolute_error: 0.0162 - val_loss: 2.8249e-04 - val_mean_absolute_error: 0.0118
# Epoch 20/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.4538e-04 - mean_absolute_error: 0.0175 - val_loss: 7.3303e-04 - val_mean_absolute_error: 0.0217
# Epoch 21/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7403e-04 - mean_absolute_error: 0.0168 - val_loss: 3.4714e-04 - val_mean_absolute_error: 0.0147
# Epoch 22/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9585e-04 - mean_absolute_error: 0.0154 - val_loss: 2.7461e-04 - val_mean_absolute_error: 0.0118
# Epoch 23/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1864e-04 - mean_absolute_error: 0.0156 - val_loss: 2.7191e-04 - val_mean_absolute_error: 0.0113
# Epoch 24/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2468e-04 - mean_absolute_error: 0.0157 - val_loss: 8.4386e-04 - val_mean_absolute_error: 0.0242
# Epoch 25/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.6785e-04 - mean_absolute_error: 0.0180 - val_loss: 2.6861e-04 - val_mean_absolute_error: 0.0113
# Epoch 26/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6608e-04 - mean_absolute_error: 0.0149 - val_loss: 4.0664e-04 - val_mean_absolute_error: 0.0145
# Epoch 27/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.1076e-04 - mean_absolute_error: 0.0154 - val_loss: 7.4281e-04 - val_mean_absolute_error: 0.0223
# Epoch 28/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.5486e-04 - mean_absolute_error: 0.0166 - val_loss: 2.7055e-04 - val_mean_absolute_error: 0.0112
# Epoch 29/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9482e-04 - mean_absolute_error: 0.0153 - val_loss: 2.6832e-04 - val_mean_absolute_error: 0.0112
# Epoch 30/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9844e-04 - mean_absolute_error: 0.0153 - val_loss: 3.1647e-04 - val_mean_absolute_error: 0.0138
# Epoch 31/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3700e-04 - mean_absolute_error: 0.0146 - val_loss: 4.2513e-04 - val_mean_absolute_error: 0.0152
# Epoch 32/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.2183e-04 - mean_absolute_error: 0.0153 - val_loss: 3.6863e-04 - val_mean_absolute_error: 0.0155
# Epoch 33/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4119e-04 - mean_absolute_error: 0.0150 - val_loss: 2.6526e-04 - val_mean_absolute_error: 0.0110
# Epoch 34/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7417e-04 - mean_absolute_error: 0.0148 - val_loss: 2.4511e-04 - val_mean_absolute_error: 0.0111
# Epoch 35/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0952e-04 - mean_absolute_error: 0.0138 - val_loss: 5.7083e-04 - val_mean_absolute_error: 0.0189
# Epoch 36/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4459e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0010 - val_mean_absolute_error: 0.0281
# Epoch 37/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3549e-04 - mean_absolute_error: 0.0162 - val_loss: 0.0013 - val_mean_absolute_error: 0.0319
# Epoch 38/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.0254e-04 - mean_absolute_error: 0.0159 - val_loss: 3.3775e-04 - val_mean_absolute_error: 0.0130
# Epoch 39/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9796e-04 - mean_absolute_error: 0.0151 - val_loss: 3.6602e-04 - val_mean_absolute_error: 0.0157
# Epoch 40/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.8955e-04 - mean_absolute_error: 0.0157 - val_loss: 2.2999e-04 - val_mean_absolute_error: 0.0104
# Epoch 41/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6387e-04 - mean_absolute_error: 0.0150 - val_loss: 3.7228e-04 - val_mean_absolute_error: 0.0140
# Epoch 42/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.4521e-04 - mean_absolute_error: 0.0145 - val_loss: 3.3606e-04 - val_mean_absolute_error: 0.0130
# Epoch 43/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8951e-04 - mean_absolute_error: 0.0135 - val_loss: 3.3004e-04 - val_mean_absolute_error: 0.0128
# Epoch 44/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1632e-04 - mean_absolute_error: 0.0140 - val_loss: 2.3860e-04 - val_mean_absolute_error: 0.0103
# Epoch 45/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2148e-04 - mean_absolute_error: 0.0139 - val_loss: 2.3059e-04 - val_mean_absolute_error: 0.0102
# Epoch 46/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4209e-04 - mean_absolute_error: 0.0142 - val_loss: 2.5768e-04 - val_mean_absolute_error: 0.0108
# Epoch 47/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2981e-04 - mean_absolute_error: 0.0140 - val_loss: 2.4455e-04 - val_mean_absolute_error: 0.0117
# Epoch 48/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4384e-04 - mean_absolute_error: 0.0148 - val_loss: 2.4212e-04 - val_mean_absolute_error: 0.0105
# Epoch 49/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.9301e-04 - mean_absolute_error: 0.0159 - val_loss: 2.6722e-04 - val_mean_absolute_error: 0.0127
# Epoch 50/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0915e-04 - mean_absolute_error: 0.0135 - val_loss: 2.1611e-04 - val_mean_absolute_error: 0.0102
# Epoch 51/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0150e-04 - mean_absolute_error: 0.0131 - val_loss: 2.2820e-04 - val_mean_absolute_error: 0.0100
# Epoch 52/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7939e-04 - mean_absolute_error: 0.0135 - val_loss: 2.3689e-04 - val_mean_absolute_error: 0.0102
# Epoch 53/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9079e-04 - mean_absolute_error: 0.0135 - val_loss: 7.1676e-04 - val_mean_absolute_error: 0.0226
# Epoch 54/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2222e-04 - mean_absolute_error: 0.0144 - val_loss: 2.3089e-04 - val_mean_absolute_error: 0.0100
# Epoch 55/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8737e-04 - mean_absolute_error: 0.0132 - val_loss: 2.5564e-04 - val_mean_absolute_error: 0.0107
# Epoch 56/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5953e-04 - mean_absolute_error: 0.0133 - val_loss: 2.5700e-04 - val_mean_absolute_error: 0.0107
# Epoch 57/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9907e-04 - mean_absolute_error: 0.0133 - val_loss: 5.0209e-04 - val_mean_absolute_error: 0.0179
# Epoch 58/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0391e-04 - mean_absolute_error: 0.0139 - val_loss: 2.1209e-04 - val_mean_absolute_error: 0.0102
# Epoch 59/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8985e-04 - mean_absolute_error: 0.0138 - val_loss: 6.5850e-04 - val_mean_absolute_error: 0.0215
# Epoch 60/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.5800e-04 - mean_absolute_error: 0.0153 - val_loss: 2.3365e-04 - val_mean_absolute_error: 0.0101
# Epoch 61/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0363e-04 - mean_absolute_error: 0.0137 - val_loss: 2.7015e-04 - val_mean_absolute_error: 0.0130
# Epoch 62/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3140e-04 - mean_absolute_error: 0.0142 - val_loss: 2.1038e-04 - val_mean_absolute_error: 0.0098
# Epoch 63/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8747e-04 - mean_absolute_error: 0.0137 - val_loss: 3.5672e-04 - val_mean_absolute_error: 0.0157
# Epoch 64/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8326e-04 - mean_absolute_error: 0.0137 - val_loss: 2.3049e-04 - val_mean_absolute_error: 0.0100
# Epoch 65/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6800e-04 - mean_absolute_error: 0.0135 - val_loss: 2.8574e-04 - val_mean_absolute_error: 0.0136
# Epoch 66/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1862e-04 - mean_absolute_error: 0.0148 - val_loss: 2.8143e-04 - val_mean_absolute_error: 0.0134
# Epoch 67/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9549e-04 - mean_absolute_error: 0.0140 - val_loss: 2.1530e-04 - val_mean_absolute_error: 0.0106
# Epoch 68/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4522e-04 - mean_absolute_error: 0.0150 - val_loss: 2.4692e-04 - val_mean_absolute_error: 0.0106
# Epoch 69/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1266e-04 - mean_absolute_error: 0.0139 - val_loss: 2.8166e-04 - val_mean_absolute_error: 0.0115
# Epoch 70/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9697e-04 - mean_absolute_error: 0.0135 - val_loss: 2.3695e-04 - val_mean_absolute_error: 0.0118
# Epoch 71/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8938e-04 - mean_absolute_error: 0.0136 - val_loss: 5.9124e-04 - val_mean_absolute_error: 0.0201
# Epoch 72/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9234e-04 - mean_absolute_error: 0.0134 - val_loss: 3.4885e-04 - val_mean_absolute_error: 0.0136
# Epoch 73/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7235e-04 - mean_absolute_error: 0.0134 - val_loss: 2.4130e-04 - val_mean_absolute_error: 0.0119
# Epoch 74/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8956e-04 - mean_absolute_error: 0.0137 - val_loss: 2.5461e-04 - val_mean_absolute_error: 0.0125
# Epoch 75/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3750e-04 - mean_absolute_error: 0.0147 - val_loss: 2.7692e-04 - val_mean_absolute_error: 0.0114
# Epoch 76/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4279e-04 - mean_absolute_error: 0.0128 - val_loss: 2.5628e-04 - val_mean_absolute_error: 0.0108
# Epoch 77/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0095e-04 - mean_absolute_error: 0.0145 - val_loss: 7.6745e-04 - val_mean_absolute_error: 0.0238
# Epoch 78/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5972e-04 - mean_absolute_error: 0.0149 - val_loss: 2.1008e-04 - val_mean_absolute_error: 0.0098
# Epoch 79/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8520e-04 - mean_absolute_error: 0.0136 - val_loss: 2.1894e-04 - val_mean_absolute_error: 0.0109
# Epoch 80/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0682e-04 - mean_absolute_error: 0.0141 - val_loss: 2.0621e-04 - val_mean_absolute_error: 0.0100
# Epoch 81/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5070e-04 - mean_absolute_error: 0.0128 - val_loss: 2.1928e-04 - val_mean_absolute_error: 0.0098
# Epoch 82/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6931e-04 - mean_absolute_error: 0.0132 - val_loss: 2.0547e-04 - val_mean_absolute_error: 0.0098
# Epoch 83/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5644e-04 - mean_absolute_error: 0.0126 - val_loss: 3.4929e-04 - val_mean_absolute_error: 0.0137
# Epoch 84/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8455e-04 - mean_absolute_error: 0.0140 - val_loss: 2.2447e-04 - val_mean_absolute_error: 0.0100
# Epoch 85/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0034e-04 - mean_absolute_error: 0.0139 - val_loss: 4.2258e-04 - val_mean_absolute_error: 0.0159
# Epoch 86/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9411e-04 - mean_absolute_error: 0.0138 - val_loss: 3.4597e-04 - val_mean_absolute_error: 0.0136
# Epoch 87/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6929e-04 - mean_absolute_error: 0.0133 - val_loss: 2.0534e-04 - val_mean_absolute_error: 0.0100
# Epoch 88/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6721e-04 - mean_absolute_error: 0.0134 - val_loss: 4.0369e-04 - val_mean_absolute_error: 0.0154
# Epoch 89/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0291e-04 - mean_absolute_error: 0.0139 - val_loss: 2.2224e-04 - val_mean_absolute_error: 0.0110
# Epoch 90/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0901e-04 - mean_absolute_error: 0.0142 - val_loss: 2.1087e-04 - val_mean_absolute_error: 0.0105
# Epoch 91/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8402e-04 - mean_absolute_error: 0.0134 - val_loss: 2.0748e-04 - val_mean_absolute_error: 0.0099
# Epoch 92/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.8803e-04 - mean_absolute_error: 0.0133 - val_loss: 2.7618e-04 - val_mean_absolute_error: 0.0114
# Epoch 93/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9658e-04 - mean_absolute_error: 0.0135 - val_loss: 2.2717e-04 - val_mean_absolute_error: 0.0100
# Epoch 94/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9028e-04 - mean_absolute_error: 0.0138 - val_loss: 4.2039e-04 - val_mean_absolute_error: 0.0159
# Epoch 95/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5520e-04 - mean_absolute_error: 0.0130 - val_loss: 2.2924e-04 - val_mean_absolute_error: 0.0114
# Epoch 96/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9617e-04 - mean_absolute_error: 0.0138 - val_loss: 2.8713e-04 - val_mean_absolute_error: 0.0117
# Epoch 97/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0894e-04 - mean_absolute_error: 0.0141 - val_loss: 2.8561e-04 - val_mean_absolute_error: 0.0117
# Epoch 98/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5529e-04 - mean_absolute_error: 0.0125 - val_loss: 2.7083e-04 - val_mean_absolute_error: 0.0112
# Epoch 99/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1870e-04 - mean_absolute_error: 0.0139 - val_loss: 4.3064e-04 - val_mean_absolute_error: 0.0162
# Epoch 100/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4562e-04 - mean_absolute_error: 0.0146 - val_loss: 6.1412e-04 - val_mean_absolute_error: 0.0207
# Epoch 101/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4947e-04 - mean_absolute_error: 0.0148 - val_loss: 2.5596e-04 - val_mean_absolute_error: 0.0107
# Epoch 102/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1602e-04 - mean_absolute_error: 0.0143 - val_loss: 2.7684e-04 - val_mean_absolute_error: 0.0132
# Epoch 103/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.4201e-04 - mean_absolute_error: 0.0145 - val_loss: 2.2512e-04 - val_mean_absolute_error: 0.0112
# Epoch 104/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1998e-04 - mean_absolute_error: 0.0148 - val_loss: 2.4083e-04 - val_mean_absolute_error: 0.0119
# Epoch 105/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0639e-04 - mean_absolute_error: 0.0138 - val_loss: 2.7122e-04 - val_mean_absolute_error: 0.0112
# Epoch 106/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6227e-04 - mean_absolute_error: 0.0134 - val_loss: 2.0887e-04 - val_mean_absolute_error: 0.0104
# Epoch 107/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.7018e-04 - mean_absolute_error: 0.0151 - val_loss: 3.8693e-04 - val_mean_absolute_error: 0.0150
# Epoch 108/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5981e-04 - mean_absolute_error: 0.0133 - val_loss: 2.3098e-04 - val_mean_absolute_error: 0.0102
# Epoch 109/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7464e-04 - mean_absolute_error: 0.0135 - val_loss: 4.4144e-04 - val_mean_absolute_error: 0.0181
# Epoch 110/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.3511e-04 - mean_absolute_error: 0.0168 - val_loss: 2.1058e-04 - val_mean_absolute_error: 0.0105
# Epoch 111/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0381e-04 - mean_absolute_error: 0.0142 - val_loss: 4.5745e-04 - val_mean_absolute_error: 0.0169
# Epoch 112/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8859e-04 - mean_absolute_error: 0.0137 - val_loss: 3.2358e-04 - val_mean_absolute_error: 0.0148
# Epoch 113/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5752e-04 - mean_absolute_error: 0.0134 - val_loss: 3.8651e-04 - val_mean_absolute_error: 0.0166
# Epoch 114/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3902e-04 - mean_absolute_error: 0.0147 - val_loss: 2.5843e-04 - val_mean_absolute_error: 0.0125
# Epoch 115/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3692e-04 - mean_absolute_error: 0.0143 - val_loss: 5.2642e-04 - val_mean_absolute_error: 0.0187
# Epoch 116/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5708e-04 - mean_absolute_error: 0.0134 - val_loss: 3.5927e-04 - val_mean_absolute_error: 0.0158
# Epoch 117/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.9560e-04 - mean_absolute_error: 0.0141 - val_loss: 2.0576e-04 - val_mean_absolute_error: 0.0100
# Epoch 118/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9059e-04 - mean_absolute_error: 0.0138 - val_loss: 5.9067e-04 - val_mean_absolute_error: 0.0202
# Epoch 119/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8710e-04 - mean_absolute_error: 0.0134 - val_loss: 2.7588e-04 - val_mean_absolute_error: 0.0114
# Epoch 120/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7816e-04 - mean_absolute_error: 0.0131 - val_loss: 2.0740e-04 - val_mean_absolute_error: 0.0101
# Epoch 121/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4984e-04 - mean_absolute_error: 0.0130 - val_loss: 2.1304e-04 - val_mean_absolute_error: 0.0098
# Epoch 122/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7399e-04 - mean_absolute_error: 0.0137 - val_loss: 2.3965e-04 - val_mean_absolute_error: 0.0103
# Epoch 123/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6259e-04 - mean_absolute_error: 0.0129 - val_loss: 2.3019e-04 - val_mean_absolute_error: 0.0101
# Epoch 124/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4680e-04 - mean_absolute_error: 0.0127 - val_loss: 5.8652e-04 - val_mean_absolute_error: 0.0201
# Epoch 125/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8863e-04 - mean_absolute_error: 0.0138 - val_loss: 2.3593e-04 - val_mean_absolute_error: 0.0102
# Epoch 126/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7755e-04 - mean_absolute_error: 0.0133 - val_loss: 4.7908e-04 - val_mean_absolute_error: 0.0191
# Epoch 127/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.4243e-04 - mean_absolute_error: 0.0148 - val_loss: 2.1462e-04 - val_mean_absolute_error: 0.0107
# Epoch 128/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1789e-04 - mean_absolute_error: 0.0143 - val_loss: 2.2133e-04 - val_mean_absolute_error: 0.0110
# Epoch 129/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7457e-04 - mean_absolute_error: 0.0130 - val_loss: 3.6603e-04 - val_mean_absolute_error: 0.0144
# Epoch 130/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7877e-04 - mean_absolute_error: 0.0137 - val_loss: 4.6909e-04 - val_mean_absolute_error: 0.0172
# Epoch 131/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9144e-04 - mean_absolute_error: 0.0141 - val_loss: 2.1870e-04 - val_mean_absolute_error: 0.0098
# Epoch 132/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.6350e-04 - mean_absolute_error: 0.0147 - val_loss: 2.2669e-04 - val_mean_absolute_error: 0.0112
# Epoch 133/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7135e-04 - mean_absolute_error: 0.0135 - val_loss: 4.0330e-04 - val_mean_absolute_error: 0.0171
# Epoch 134/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7188e-04 - mean_absolute_error: 0.0134 - val_loss: 2.5920e-04 - val_mean_absolute_error: 0.0126
# Epoch 135/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9303e-04 - mean_absolute_error: 0.0135 - val_loss: 2.3568e-04 - val_mean_absolute_error: 0.0116
# Epoch 136/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5714e-04 - mean_absolute_error: 0.0130 - val_loss: 2.2563e-04 - val_mean_absolute_error: 0.0099
# Epoch 137/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7959e-04 - mean_absolute_error: 0.0136 - val_loss: 2.1250e-04 - val_mean_absolute_error: 0.0106
# Epoch 138/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7929e-04 - mean_absolute_error: 0.0132 - val_loss: 2.3701e-04 - val_mean_absolute_error: 0.0102
# Epoch 139/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1966e-04 - mean_absolute_error: 0.0126 - val_loss: 2.2737e-04 - val_mean_absolute_error: 0.0113
# Epoch 140/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0583e-04 - mean_absolute_error: 0.0140 - val_loss: 2.5659e-04 - val_mean_absolute_error: 0.0108
# Epoch 141/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7270e-04 - mean_absolute_error: 0.0132 - val_loss: 2.3101e-04 - val_mean_absolute_error: 0.0101
# Epoch 142/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6818e-04 - mean_absolute_error: 0.0131 - val_loss: 2.1741e-04 - val_mean_absolute_error: 0.0099
# Epoch 143/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.3461e-04 - mean_absolute_error: 0.0127 - val_loss: 7.6584e-04 - val_mean_absolute_error: 0.0238
# Epoch 144/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3164e-04 - mean_absolute_error: 0.0143 - val_loss: 2.8170e-04 - val_mean_absolute_error: 0.0116
# Epoch 145/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8105e-04 - mean_absolute_error: 0.0136 - val_loss: 2.2142e-04 - val_mean_absolute_error: 0.0110
# Epoch 146/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2159e-04 - mean_absolute_error: 0.0139 - val_loss: 2.1023e-04 - val_mean_absolute_error: 0.0104
# Epoch 147/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3942e-04 - mean_absolute_error: 0.0127 - val_loss: 2.0720e-04 - val_mean_absolute_error: 0.0098
# Epoch 148/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7375e-04 - mean_absolute_error: 0.0132 - val_loss: 4.9494e-04 - val_mean_absolute_error: 0.0179
# Epoch 149/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3721e-04 - mean_absolute_error: 0.0149 - val_loss: 2.6233e-04 - val_mean_absolute_error: 0.0109
# Epoch 150/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5965e-04 - mean_absolute_error: 0.0129 - val_loss: 2.0761e-04 - val_mean_absolute_error: 0.0102
# Epoch 151/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7730e-04 - mean_absolute_error: 0.0132 - val_loss: 2.8916e-04 - val_mean_absolute_error: 0.0119
# Epoch 152/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7096e-04 - mean_absolute_error: 0.0127 - val_loss: 2.8791e-04 - val_mean_absolute_error: 0.0118
# Epoch 153/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9724e-04 - mean_absolute_error: 0.0136 - val_loss: 2.3556e-04 - val_mean_absolute_error: 0.0116
# Epoch 154/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6685e-04 - mean_absolute_error: 0.0134 - val_loss: 2.9062e-04 - val_mean_absolute_error: 0.0119
# Epoch 155/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0144e-04 - mean_absolute_error: 0.0138 - val_loss: 2.2424e-04 - val_mean_absolute_error: 0.0111
# Epoch 156/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9441e-04 - mean_absolute_error: 0.0137 - val_loss: 2.4251e-04 - val_mean_absolute_error: 0.0119
# Epoch 157/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.2476e-04 - mean_absolute_error: 0.0142 - val_loss: 6.5714e-04 - val_mean_absolute_error: 0.0233
# Epoch 158/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1865e-04 - mean_absolute_error: 0.0166 - val_loss: 2.1807e-04 - val_mean_absolute_error: 0.0099
# Epoch 159/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8761e-04 - mean_absolute_error: 0.0137 - val_loss: 2.7469e-04 - val_mean_absolute_error: 0.0114
# Epoch 160/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7568e-04 - mean_absolute_error: 0.0133 - val_loss: 2.0581e-04 - val_mean_absolute_error: 0.0100
# Epoch 161/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5547e-04 - mean_absolute_error: 0.0129 - val_loss: 2.6154e-04 - val_mean_absolute_error: 0.0109
# Epoch 162/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4626e-04 - mean_absolute_error: 0.0127 - val_loss: 2.8892e-04 - val_mean_absolute_error: 0.0119
# Epoch 163/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6857e-04 - mean_absolute_error: 0.0129 - val_loss: 4.2352e-04 - val_mean_absolute_error: 0.0160
# Epoch 164/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6559e-04 - mean_absolute_error: 0.0135 - val_loss: 2.4230e-04 - val_mean_absolute_error: 0.0103
# Epoch 165/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8077e-04 - mean_absolute_error: 0.0135 - val_loss: 3.9293e-04 - val_mean_absolute_error: 0.0152
# Epoch 166/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8706e-04 - mean_absolute_error: 0.0138 - val_loss: 4.9949e-04 - val_mean_absolute_error: 0.0180
# Epoch 167/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.7288e-04 - mean_absolute_error: 0.0156 - val_loss: 3.6315e-04 - val_mean_absolute_error: 0.0143
# Epoch 168/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7183e-04 - mean_absolute_error: 0.0133 - val_loss: 2.6411e-04 - val_mean_absolute_error: 0.0110
# Epoch 169/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6027e-04 - mean_absolute_error: 0.0130 - val_loss: 2.0861e-04 - val_mean_absolute_error: 0.0100
# Epoch 170/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.8449e-04 - mean_absolute_error: 0.0138 - val_loss: 3.4510e-04 - val_mean_absolute_error: 0.0137
# Epoch 171/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4346e-04 - mean_absolute_error: 0.0130 - val_loss: 2.2861e-04 - val_mean_absolute_error: 0.0113
# Epoch 172/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0858e-04 - mean_absolute_error: 0.0146 - val_loss: 2.1125e-04 - val_mean_absolute_error: 0.0098
# Epoch 173/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9946e-04 - mean_absolute_error: 0.0135 - val_loss: 2.9923e-04 - val_mean_absolute_error: 0.0122
# Epoch 174/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7240e-04 - mean_absolute_error: 0.0129 - val_loss: 3.0149e-04 - val_mean_absolute_error: 0.0123
# Epoch 175/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9585e-04 - mean_absolute_error: 0.0136 - val_loss: 2.5693e-04 - val_mean_absolute_error: 0.0108
# Epoch 176/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4027e-04 - mean_absolute_error: 0.0130 - val_loss: 5.3210e-04 - val_mean_absolute_error: 0.0188
# Epoch 177/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2124e-04 - mean_absolute_error: 0.0124 - val_loss: 2.2576e-04 - val_mean_absolute_error: 0.0100
# Epoch 178/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4608e-04 - mean_absolute_error: 0.0127 - val_loss: 3.4057e-04 - val_mean_absolute_error: 0.0136
# Epoch 179/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.7300e-04 - mean_absolute_error: 0.0132 - val_loss: 2.0986e-04 - val_mean_absolute_error: 0.0103
# Epoch 180/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.0842e-04 - mean_absolute_error: 0.0140 - val_loss: 2.2553e-04 - val_mean_absolute_error: 0.0112
# Epoch 181/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.9815e-04 - mean_absolute_error: 0.0139 - val_loss: 6.3955e-04 - val_mean_absolute_error: 0.0229
# Epoch 182/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3531e-04 - mean_absolute_error: 0.0148 - val_loss: 2.8969e-04 - val_mean_absolute_error: 0.0119
# Epoch 183/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7910e-04 - mean_absolute_error: 0.0133 - val_loss: 2.2189e-04 - val_mean_absolute_error: 0.0110
# Epoch 184/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8100e-04 - mean_absolute_error: 0.0134 - val_loss: 2.7404e-04 - val_mean_absolute_error: 0.0131
# Epoch 185/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6425e-04 - mean_absolute_error: 0.0133 - val_loss: 2.0924e-04 - val_mean_absolute_error: 0.0099
# Epoch 186/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5830e-04 - mean_absolute_error: 0.0128 - val_loss: 3.7504e-04 - val_mean_absolute_error: 0.0147
# Epoch 187/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.3917e-04 - mean_absolute_error: 0.0148 - val_loss: 2.0728e-04 - val_mean_absolute_error: 0.0099
# Epoch 188/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4609e-04 - mean_absolute_error: 0.0129 - val_loss: 3.6953e-04 - val_mean_absolute_error: 0.0161
# Epoch 189/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0247e-04 - mean_absolute_error: 0.0137 - val_loss: 2.0959e-04 - val_mean_absolute_error: 0.0103
# Epoch 190/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0620e-04 - mean_absolute_error: 0.0139 - val_loss: 3.8551e-04 - val_mean_absolute_error: 0.0150
# Epoch 191/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.2586e-04 - mean_absolute_error: 0.0129 - val_loss: 2.3174e-04 - val_mean_absolute_error: 0.0101
# Epoch 192/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6406e-04 - mean_absolute_error: 0.0129 - val_loss: 2.0986e-04 - val_mean_absolute_error: 0.0104
# Epoch 193/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3811e-04 - mean_absolute_error: 0.0130 - val_loss: 2.1233e-04 - val_mean_absolute_error: 0.0105
# Epoch 194/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1639e-04 - mean_absolute_error: 0.0145 - val_loss: 3.6240e-04 - val_mean_absolute_error: 0.0159
# Epoch 195/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9798e-04 - mean_absolute_error: 0.0136 - val_loss: 3.0571e-04 - val_mean_absolute_error: 0.0124
# Epoch 196/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.6851e-04 - mean_absolute_error: 0.0129 - val_loss: 2.8997e-04 - val_mean_absolute_error: 0.0119
# Epoch 197/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.0918e-04 - mean_absolute_error: 0.0143 - val_loss: 2.1804e-04 - val_mean_absolute_error: 0.0099
# Epoch 198/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.5414e-04 - mean_absolute_error: 0.0125 - val_loss: 2.6678e-04 - val_mean_absolute_error: 0.0128
# Epoch 199/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.4420e-04 - mean_absolute_error: 0.0129 - val_loss: 2.9957e-04 - val_mean_absolute_error: 0.0122
# Epoch 200/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.3709e-04 - mean_absolute_error: 0.0128 - val_loss: 2.9776e-04 - val_mean_absolute_error: 0.0122

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 114
# 125

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 578415.3232752817
# RMSE: 760.5362077345704
# MAE: 529.3999280427631
# MAPE: 1.5048799600931175 %
#
# Model evalution on validate set
# MSE: 823091.5311701236
# RMSE: 907.2439204371245
# MAE: 685.9700407608696
# MAPE: 1.7556662495882507 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step

# %%
y_pred_30_days
# Out:
# array([[41387.605],
#        [41207.46 ],
#        [41408.633],
#        [41327.848],
#        [41387.38 ],
#        [41362.76 ],
#        [41377.926],
#        [41370.48 ],
#        [41374.69 ],
#        [41372.547],
#        [41373.72 ],
#        [41373.1  ],
#        [41373.43 ],
#        [41373.26 ],
#        [41373.355],
#        [41373.305],
#        [41373.332],
#        [41373.312],
#        [41373.324],
#        [41373.316],
#        [41373.316],
#        [41373.316],
#        [41373.324],
#        [41373.316],
#        [41373.32 ],
#        [41373.32 ],
#        [41373.32 ],
#        [41373.32 ],
#        [41373.316],
#        [41373.32 ],
#        [41373.316]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Predict the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
