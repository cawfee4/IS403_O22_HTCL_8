# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: CMG - Test/Train/Vaildation: 80/10/10
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 736.1344400461851
# - MAE: 530.8743815104167
# - MAPE: 1.4459109450602383 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 2  # 8 1 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((1039, 10), (1039,), (120, 10), (120,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 24ms/step - loss: 0.0163 - mean_absolute_error: 0.0853 - val_loss: 0.0011 - val_mean_absolute_error: 0.0285
# Epoch 2/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.3922e-04 - mean_absolute_error: 0.0199 - val_loss: 2.6146e-04 - val_mean_absolute_error: 0.0117
# Epoch 3/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.9824e-04 - mean_absolute_error: 0.0151 - val_loss: 2.0555e-04 - val_mean_absolute_error: 0.0107
# Epoch 4/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7081e-04 - mean_absolute_error: 0.0118 - val_loss: 2.1111e-04 - val_mean_absolute_error: 0.0111
# Epoch 5/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1625e-04 - mean_absolute_error: 0.0105 - val_loss: 1.4355e-04 - val_mean_absolute_error: 0.0085
# Epoch 6/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2165e-04 - mean_absolute_error: 0.0101 - val_loss: 2.0468e-04 - val_mean_absolute_error: 0.0109
# Epoch 7/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9538e-04 - mean_absolute_error: 0.0099 - val_loss: 1.3685e-04 - val_mean_absolute_error: 0.0082
# Epoch 8/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9890e-04 - mean_absolute_error: 0.0095 - val_loss: 1.2330e-04 - val_mean_absolute_error: 0.0078
# Epoch 9/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9685e-04 - mean_absolute_error: 0.0097 - val_loss: 5.4734e-04 - val_mean_absolute_error: 0.0211
# Epoch 10/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1919e-04 - mean_absolute_error: 0.0100 - val_loss: 1.1931e-04 - val_mean_absolute_error: 0.0077
# Epoch 11/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2259e-04 - mean_absolute_error: 0.0104 - val_loss: 4.4763e-04 - val_mean_absolute_error: 0.0188
# Epoch 12/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3911e-04 - mean_absolute_error: 0.0109 - val_loss: 2.6831e-04 - val_mean_absolute_error: 0.0134
# Epoch 13/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.1481e-04 - mean_absolute_error: 0.0102 - val_loss: 8.9892e-04 - val_mean_absolute_error: 0.0283
# Epoch 14/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.0514e-04 - mean_absolute_error: 0.0102 - val_loss: 1.5328e-04 - val_mean_absolute_error: 0.0090
# Epoch 15/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8965e-04 - mean_absolute_error: 0.0094 - val_loss: 1.9539e-04 - val_mean_absolute_error: 0.0108
# Epoch 16/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7303e-04 - mean_absolute_error: 0.0090 - val_loss: 8.5390e-04 - val_mean_absolute_error: 0.0275
# Epoch 17/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.7328e-04 - mean_absolute_error: 0.0120 - val_loss: 1.1945e-04 - val_mean_absolute_error: 0.0076
# Epoch 18/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7391e-04 - mean_absolute_error: 0.0089 - val_loss: 2.6334e-04 - val_mean_absolute_error: 0.0135
# Epoch 19/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7539e-04 - mean_absolute_error: 0.0090 - val_loss: 1.2014e-04 - val_mean_absolute_error: 0.0078
# Epoch 20/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7544e-04 - mean_absolute_error: 0.0091 - val_loss: 3.2339e-04 - val_mean_absolute_error: 0.0155
# Epoch 21/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7342e-04 - mean_absolute_error: 0.0091 - val_loss: 2.5044e-04 - val_mean_absolute_error: 0.0135
# Epoch 22/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7751e-04 - mean_absolute_error: 0.0092 - val_loss: 2.7289e-04 - val_mean_absolute_error: 0.0138
# Epoch 23/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8262e-04 - mean_absolute_error: 0.0092 - val_loss: 1.2589e-04 - val_mean_absolute_error: 0.0080
# Epoch 24/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4614e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2406e-04 - val_mean_absolute_error: 0.0079
# Epoch 25/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7512e-04 - mean_absolute_error: 0.0091 - val_loss: 1.1019e-04 - val_mean_absolute_error: 0.0072
# Epoch 26/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4390e-04 - mean_absolute_error: 0.0087 - val_loss: 5.9554e-04 - val_mean_absolute_error: 0.0225
# Epoch 27/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8772e-04 - mean_absolute_error: 0.0097 - val_loss: 2.6293e-04 - val_mean_absolute_error: 0.0136
# Epoch 28/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8884e-04 - mean_absolute_error: 0.0094 - val_loss: 1.0764e-04 - val_mean_absolute_error: 0.0071
# Epoch 29/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0576e-04 - mean_absolute_error: 0.0100 - val_loss: 1.1450e-04 - val_mean_absolute_error: 0.0075
# Epoch 30/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.8013e-04 - mean_absolute_error: 0.0093 - val_loss: 3.3559e-04 - val_mean_absolute_error: 0.0160
# Epoch 31/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1311e-04 - mean_absolute_error: 0.0105 - val_loss: 1.0911e-04 - val_mean_absolute_error: 0.0072
# Epoch 32/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6003e-04 - mean_absolute_error: 0.0085 - val_loss: 1.5794e-04 - val_mean_absolute_error: 0.0098
# Epoch 33/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5106e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0012 - val_mean_absolute_error: 0.0326
# Epoch 34/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4988e-04 - mean_absolute_error: 0.0115 - val_loss: 1.0351e-04 - val_mean_absolute_error: 0.0070
# Epoch 35/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6268e-04 - mean_absolute_error: 0.0088 - val_loss: 1.0484e-04 - val_mean_absolute_error: 0.0071
# Epoch 36/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6833e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0678e-04 - val_mean_absolute_error: 0.0071
# Epoch 37/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4375e-04 - mean_absolute_error: 0.0083 - val_loss: 1.4491e-04 - val_mean_absolute_error: 0.0088
# Epoch 38/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5137e-04 - mean_absolute_error: 0.0083 - val_loss: 1.3354e-04 - val_mean_absolute_error: 0.0086
# Epoch 39/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7334e-04 - mean_absolute_error: 0.0092 - val_loss: 1.0345e-04 - val_mean_absolute_error: 0.0070
# Epoch 40/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6149e-04 - mean_absolute_error: 0.0085 - val_loss: 1.4150e-04 - val_mean_absolute_error: 0.0087
# Epoch 41/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.3966e-04 - mean_absolute_error: 0.0081 - val_loss: 1.2113e-04 - val_mean_absolute_error: 0.0080
# Epoch 42/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7474e-04 - mean_absolute_error: 0.0093 - val_loss: 1.1589e-04 - val_mean_absolute_error: 0.0075
# Epoch 43/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4143e-04 - mean_absolute_error: 0.0084 - val_loss: 1.4707e-04 - val_mean_absolute_error: 0.0093
# Epoch 44/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8841e-04 - mean_absolute_error: 0.0098 - val_loss: 1.0364e-04 - val_mean_absolute_error: 0.0070
# Epoch 45/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5406e-04 - mean_absolute_error: 0.0086 - val_loss: 1.4307e-04 - val_mean_absolute_error: 0.0091
# Epoch 46/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6755e-04 - mean_absolute_error: 0.0088 - val_loss: 1.1438e-04 - val_mean_absolute_error: 0.0076
# Epoch 47/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9266e-04 - mean_absolute_error: 0.0095 - val_loss: 1.0095e-04 - val_mean_absolute_error: 0.0069
# Epoch 48/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9709e-04 - mean_absolute_error: 0.0103 - val_loss: 1.2417e-04 - val_mean_absolute_error: 0.0079
# Epoch 49/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6821e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0036e-04 - val_mean_absolute_error: 0.0070
# Epoch 50/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5414e-04 - mean_absolute_error: 0.0085 - val_loss: 1.6333e-04 - val_mean_absolute_error: 0.0100
# Epoch 51/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5632e-04 - mean_absolute_error: 0.0088 - val_loss: 1.0072e-04 - val_mean_absolute_error: 0.0070
# Epoch 52/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5014e-04 - mean_absolute_error: 0.0083 - val_loss: 1.1199e-04 - val_mean_absolute_error: 0.0074
# Epoch 53/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3844e-04 - mean_absolute_error: 0.0081 - val_loss: 1.0029e-04 - val_mean_absolute_error: 0.0070
# Epoch 54/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5429e-04 - mean_absolute_error: 0.0086 - val_loss: 1.9631e-04 - val_mean_absolute_error: 0.0115
# Epoch 55/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7845e-04 - mean_absolute_error: 0.0096 - val_loss: 1.6546e-04 - val_mean_absolute_error: 0.0098
# Epoch 56/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9384e-04 - mean_absolute_error: 0.0098 - val_loss: 1.4942e-04 - val_mean_absolute_error: 0.0094
# Epoch 57/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3346e-04 - mean_absolute_error: 0.0078 - val_loss: 1.0344e-04 - val_mean_absolute_error: 0.0070
# Epoch 58/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7381e-04 - mean_absolute_error: 0.0094 - val_loss: 1.6695e-04 - val_mean_absolute_error: 0.0102
# Epoch 59/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4821e-04 - mean_absolute_error: 0.0087 - val_loss: 2.4097e-04 - val_mean_absolute_error: 0.0132
# Epoch 60/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8988e-04 - mean_absolute_error: 0.0100 - val_loss: 1.3553e-04 - val_mean_absolute_error: 0.0084
# Epoch 61/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3556e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2087e-04 - val_mean_absolute_error: 0.0078
# Epoch 62/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4048e-04 - mean_absolute_error: 0.0083 - val_loss: 1.7253e-04 - val_mean_absolute_error: 0.0105
# Epoch 63/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5327e-04 - mean_absolute_error: 0.0087 - val_loss: 3.7387e-04 - val_mean_absolute_error: 0.0172
# Epoch 64/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.5216e-04 - mean_absolute_error: 0.0084 - val_loss: 1.1733e-04 - val_mean_absolute_error: 0.0079
# Epoch 65/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6168e-04 - mean_absolute_error: 0.0089 - val_loss: 1.2573e-04 - val_mean_absolute_error: 0.0080
# Epoch 66/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7561e-04 - mean_absolute_error: 0.0092 - val_loss: 1.0867e-04 - val_mean_absolute_error: 0.0072
# Epoch 67/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5239e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0581e-04 - val_mean_absolute_error: 0.0071
# Epoch 68/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5819e-04 - mean_absolute_error: 0.0086 - val_loss: 1.4952e-04 - val_mean_absolute_error: 0.0091
# Epoch 69/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5067e-04 - mean_absolute_error: 0.0085 - val_loss: 1.4155e-04 - val_mean_absolute_error: 0.0091
# Epoch 70/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7664e-04 - mean_absolute_error: 0.0093 - val_loss: 1.9320e-04 - val_mean_absolute_error: 0.0110
# Epoch 71/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4383e-04 - mean_absolute_error: 0.0082 - val_loss: 1.0988e-04 - val_mean_absolute_error: 0.0075
# Epoch 72/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7088e-04 - mean_absolute_error: 0.0091 - val_loss: 2.7175e-04 - val_mean_absolute_error: 0.0140
# Epoch 73/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7600e-04 - mean_absolute_error: 0.0094 - val_loss: 1.2263e-04 - val_mean_absolute_error: 0.0081
# Epoch 74/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6615e-04 - mean_absolute_error: 0.0092 - val_loss: 1.0185e-04 - val_mean_absolute_error: 0.0070
# Epoch 75/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6773e-04 - mean_absolute_error: 0.0090 - val_loss: 1.0114e-04 - val_mean_absolute_error: 0.0069
# Epoch 76/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5482e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2247e-04 - val_mean_absolute_error: 0.0082
# Epoch 77/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5054e-04 - mean_absolute_error: 0.0083 - val_loss: 1.0527e-04 - val_mean_absolute_error: 0.0071
# Epoch 78/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3821e-04 - mean_absolute_error: 0.0083 - val_loss: 1.6747e-04 - val_mean_absolute_error: 0.0099
# Epoch 79/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.6448e-04 - mean_absolute_error: 0.0091 - val_loss: 1.4057e-04 - val_mean_absolute_error: 0.0087
# Epoch 80/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.5387e-04 - mean_absolute_error: 0.0085 - val_loss: 1.1564e-04 - val_mean_absolute_error: 0.0075
# Epoch 81/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5588e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0105e-04 - val_mean_absolute_error: 0.0070
# Epoch 82/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6018e-04 - mean_absolute_error: 0.0087 - val_loss: 1.0257e-04 - val_mean_absolute_error: 0.0070
# Epoch 83/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5310e-04 - mean_absolute_error: 0.0088 - val_loss: 1.1717e-04 - val_mean_absolute_error: 0.0077
# Epoch 84/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6209e-04 - mean_absolute_error: 0.0087 - val_loss: 1.0222e-04 - val_mean_absolute_error: 0.0071
# Epoch 85/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.5200e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0856e-04 - val_mean_absolute_error: 0.0072
# Epoch 86/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5196e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3039e-04 - val_mean_absolute_error: 0.0082
# Epoch 87/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.0139e-04 - mean_absolute_error: 0.0103 - val_loss: 1.6146e-04 - val_mean_absolute_error: 0.0097
# Epoch 88/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6291e-04 - mean_absolute_error: 0.0094 - val_loss: 4.0549e-04 - val_mean_absolute_error: 0.0180
# Epoch 89/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2615e-04 - mean_absolute_error: 0.0108 - val_loss: 1.0170e-04 - val_mean_absolute_error: 0.0070
# Epoch 90/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5716e-04 - mean_absolute_error: 0.0088 - val_loss: 1.9944e-04 - val_mean_absolute_error: 0.0116
# Epoch 91/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6323e-04 - mean_absolute_error: 0.0090 - val_loss: 1.1547e-04 - val_mean_absolute_error: 0.0078
# Epoch 92/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.5906e-04 - mean_absolute_error: 0.0088 - val_loss: 1.9317e-04 - val_mean_absolute_error: 0.0113
# Epoch 93/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.5110e-04 - mean_absolute_error: 0.0087 - val_loss: 1.7935e-04 - val_mean_absolute_error: 0.0104
# Epoch 94/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.8139e-04 - mean_absolute_error: 0.0091 - val_loss: 1.0208e-04 - val_mean_absolute_error: 0.0070
# Epoch 95/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6369e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0726e-04 - val_mean_absolute_error: 0.0073
# Epoch 96/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5902e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3746e-04 - val_mean_absolute_error: 0.0089
# Epoch 97/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.4905e-04 - mean_absolute_error: 0.0086 - val_loss: 1.6893e-04 - val_mean_absolute_error: 0.0103
# Epoch 98/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5345e-04 - mean_absolute_error: 0.0089 - val_loss: 1.3725e-04 - val_mean_absolute_error: 0.0089
# Epoch 99/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5793e-04 - mean_absolute_error: 0.0089 - val_loss: 1.4077e-04 - val_mean_absolute_error: 0.0091
# Epoch 100/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5948e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0292e-04 - val_mean_absolute_error: 0.0070
# Epoch 101/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4659e-04 - mean_absolute_error: 0.0082 - val_loss: 1.0168e-04 - val_mean_absolute_error: 0.0070
# Epoch 102/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4320e-04 - mean_absolute_error: 0.0083 - val_loss: 1.0250e-04 - val_mean_absolute_error: 0.0071
# Epoch 103/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6073e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0350e-04 - val_mean_absolute_error: 0.0071
# Epoch 104/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5435e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0476e-04 - val_mean_absolute_error: 0.0072
# Epoch 105/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5148e-04 - mean_absolute_error: 0.0085 - val_loss: 1.5853e-04 - val_mean_absolute_error: 0.0095
# Epoch 106/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3951e-04 - mean_absolute_error: 0.0080 - val_loss: 1.6331e-04 - val_mean_absolute_error: 0.0101
# Epoch 107/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7028e-04 - mean_absolute_error: 0.0090 - val_loss: 1.3385e-04 - val_mean_absolute_error: 0.0084
# Epoch 108/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4344e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3853e-04 - val_mean_absolute_error: 0.0086
# Epoch 109/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5363e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0318e-04 - val_mean_absolute_error: 0.0070
# Epoch 110/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5938e-04 - mean_absolute_error: 0.0087 - val_loss: 1.3089e-04 - val_mean_absolute_error: 0.0083
# Epoch 111/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5437e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0157e-04 - val_mean_absolute_error: 0.0070
# Epoch 112/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.4447e-04 - mean_absolute_error: 0.0087 - val_loss: 1.5734e-04 - val_mean_absolute_error: 0.0095
# Epoch 113/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5104e-04 - mean_absolute_error: 0.0084 - val_loss: 1.7358e-04 - val_mean_absolute_error: 0.0105
# Epoch 114/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6771e-04 - mean_absolute_error: 0.0091 - val_loss: 1.0106e-04 - val_mean_absolute_error: 0.0070
# Epoch 115/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4549e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0190e-04 - val_mean_absolute_error: 0.0070
# Epoch 116/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.5991e-04 - mean_absolute_error: 0.0087 - val_loss: 2.1511e-04 - val_mean_absolute_error: 0.0119
# Epoch 117/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7286e-04 - mean_absolute_error: 0.0091 - val_loss: 1.2429e-04 - val_mean_absolute_error: 0.0080
# Epoch 118/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4480e-04 - mean_absolute_error: 0.0082 - val_loss: 1.0211e-04 - val_mean_absolute_error: 0.0070
# Epoch 119/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5084e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0944e-04 - val_mean_absolute_error: 0.0074
# Epoch 120/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5115e-04 - mean_absolute_error: 0.0085 - val_loss: 1.3637e-04 - val_mean_absolute_error: 0.0088
# Epoch 121/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4520e-04 - mean_absolute_error: 0.0082 - val_loss: 1.0276e-04 - val_mean_absolute_error: 0.0071
# Epoch 122/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3222e-04 - mean_absolute_error: 0.0080 - val_loss: 3.2555e-04 - val_mean_absolute_error: 0.0157
# Epoch 123/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6628e-04 - mean_absolute_error: 0.0090 - val_loss: 1.6099e-04 - val_mean_absolute_error: 0.0096
# Epoch 124/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6387e-04 - mean_absolute_error: 0.0086 - val_loss: 1.3784e-04 - val_mean_absolute_error: 0.0089
# Epoch 125/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7238e-04 - mean_absolute_error: 0.0093 - val_loss: 1.9406e-04 - val_mean_absolute_error: 0.0111
# Epoch 126/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4333e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2586e-04 - val_mean_absolute_error: 0.0080
# Epoch 127/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4550e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2273e-04 - val_mean_absolute_error: 0.0082
# Epoch 128/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5223e-04 - mean_absolute_error: 0.0084 - val_loss: 1.1596e-04 - val_mean_absolute_error: 0.0078
# Epoch 129/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4560e-04 - mean_absolute_error: 0.0085 - val_loss: 1.4259e-04 - val_mean_absolute_error: 0.0088
# Epoch 130/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4543e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2101e-04 - val_mean_absolute_error: 0.0078
# Epoch 131/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4907e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0440e-04 - val_mean_absolute_error: 0.0071
# Epoch 132/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5512e-04 - mean_absolute_error: 0.0085 - val_loss: 1.5344e-04 - val_mean_absolute_error: 0.0097
# Epoch 133/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5744e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2270e-04 - val_mean_absolute_error: 0.0079
# Epoch 134/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4252e-04 - mean_absolute_error: 0.0081 - val_loss: 1.0425e-04 - val_mean_absolute_error: 0.0071
# Epoch 135/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3900e-04 - mean_absolute_error: 0.0080 - val_loss: 1.0332e-04 - val_mean_absolute_error: 0.0070
# Epoch 136/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.5261e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0484e-04 - val_mean_absolute_error: 0.0071
# Epoch 137/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5558e-04 - mean_absolute_error: 0.0085 - val_loss: 1.4266e-04 - val_mean_absolute_error: 0.0092
# Epoch 138/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4706e-04 - mean_absolute_error: 0.0083 - val_loss: 1.0844e-04 - val_mean_absolute_error: 0.0072
# Epoch 139/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4107e-04 - mean_absolute_error: 0.0082 - val_loss: 1.0718e-04 - val_mean_absolute_error: 0.0072
# Epoch 140/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4758e-04 - mean_absolute_error: 0.0087 - val_loss: 2.2510e-04 - val_mean_absolute_error: 0.0126
# Epoch 141/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5918e-04 - mean_absolute_error: 0.0091 - val_loss: 1.2378e-04 - val_mean_absolute_error: 0.0080
# Epoch 142/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6750e-04 - mean_absolute_error: 0.0091 - val_loss: 2.2827e-04 - val_mean_absolute_error: 0.0124
# Epoch 143/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5571e-04 - mean_absolute_error: 0.0085 - val_loss: 2.8010e-04 - val_mean_absolute_error: 0.0142
# Epoch 144/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5652e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0767e-04 - val_mean_absolute_error: 0.0073
# Epoch 145/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6416e-04 - mean_absolute_error: 0.0093 - val_loss: 1.4018e-04 - val_mean_absolute_error: 0.0087
# Epoch 146/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5332e-04 - mean_absolute_error: 0.0087 - val_loss: 1.5703e-04 - val_mean_absolute_error: 0.0095
# Epoch 147/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5776e-04 - mean_absolute_error: 0.0090 - val_loss: 1.3301e-04 - val_mean_absolute_error: 0.0087
# Epoch 148/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4973e-04 - mean_absolute_error: 0.0087 - val_loss: 1.1589e-04 - val_mean_absolute_error: 0.0076
# Epoch 149/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4345e-04 - mean_absolute_error: 0.0081 - val_loss: 1.0712e-04 - val_mean_absolute_error: 0.0073
# Epoch 150/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4850e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0374e-04 - val_mean_absolute_error: 0.0071
# Epoch 151/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.5140e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0680e-04 - val_mean_absolute_error: 0.0072
# Epoch 152/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5037e-04 - mean_absolute_error: 0.0083 - val_loss: 1.3374e-04 - val_mean_absolute_error: 0.0084
# Epoch 153/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3653e-04 - mean_absolute_error: 0.0080 - val_loss: 1.3254e-04 - val_mean_absolute_error: 0.0084
# Epoch 154/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5432e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0257e-04 - val_mean_absolute_error: 0.0070
# Epoch 155/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5707e-04 - mean_absolute_error: 0.0086 - val_loss: 2.8313e-04 - val_mean_absolute_error: 0.0143
# Epoch 156/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6483e-04 - mean_absolute_error: 0.0091 - val_loss: 1.2732e-04 - val_mean_absolute_error: 0.0081
# Epoch 157/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5555e-04 - mean_absolute_error: 0.0086 - val_loss: 1.5462e-04 - val_mean_absolute_error: 0.0097
# Epoch 158/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4273e-04 - mean_absolute_error: 0.0084 - val_loss: 2.3784e-04 - val_mean_absolute_error: 0.0128
# Epoch 159/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4571e-04 - mean_absolute_error: 0.0085 - val_loss: 1.5305e-04 - val_mean_absolute_error: 0.0093
# Epoch 160/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.3587e-04 - mean_absolute_error: 0.0080 - val_loss: 1.1640e-04 - val_mean_absolute_error: 0.0076
# Epoch 161/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5493e-04 - mean_absolute_error: 0.0085 - val_loss: 2.2162e-04 - val_mean_absolute_error: 0.0124
# Epoch 162/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7758e-04 - mean_absolute_error: 0.0093 - val_loss: 1.1260e-04 - val_mean_absolute_error: 0.0077
# Epoch 163/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5458e-04 - mean_absolute_error: 0.0090 - val_loss: 1.0230e-04 - val_mean_absolute_error: 0.0070
# Epoch 164/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5222e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0671e-04 - val_mean_absolute_error: 0.0072
# Epoch 165/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4053e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0275e-04 - val_mean_absolute_error: 0.0070
# Epoch 166/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.3062e-04 - mean_absolute_error: 0.0079 - val_loss: 3.3411e-04 - val_mean_absolute_error: 0.0159
# Epoch 167/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6876e-04 - mean_absolute_error: 0.0094 - val_loss: 2.5921e-04 - val_mean_absolute_error: 0.0138
# Epoch 168/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6279e-04 - mean_absolute_error: 0.0091 - val_loss: 5.9733e-04 - val_mean_absolute_error: 0.0227
# Epoch 169/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1066e-04 - mean_absolute_error: 0.0103 - val_loss: 1.0332e-04 - val_mean_absolute_error: 0.0071
# Epoch 170/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6204e-04 - mean_absolute_error: 0.0087 - val_loss: 1.3892e-04 - val_mean_absolute_error: 0.0087
# Epoch 171/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3775e-04 - mean_absolute_error: 0.0082 - val_loss: 1.5162e-04 - val_mean_absolute_error: 0.0096
# Epoch 172/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7105e-04 - mean_absolute_error: 0.0093 - val_loss: 1.2892e-04 - val_mean_absolute_error: 0.0085
# Epoch 173/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.5585e-04 - mean_absolute_error: 0.0089 - val_loss: 1.3535e-04 - val_mean_absolute_error: 0.0085
# Epoch 174/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4792e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0359e-04 - val_mean_absolute_error: 0.0070
# Epoch 175/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3628e-04 - mean_absolute_error: 0.0080 - val_loss: 1.4228e-04 - val_mean_absolute_error: 0.0088
# Epoch 176/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7269e-04 - mean_absolute_error: 0.0091 - val_loss: 1.1369e-04 - val_mean_absolute_error: 0.0075
# Epoch 177/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.3615e-04 - mean_absolute_error: 0.0079 - val_loss: 1.0239e-04 - val_mean_absolute_error: 0.0070
# Epoch 178/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.8753e-04 - mean_absolute_error: 0.0098 - val_loss: 1.7579e-04 - val_mean_absolute_error: 0.0103
# Epoch 179/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7205e-04 - mean_absolute_error: 0.0094 - val_loss: 1.1148e-04 - val_mean_absolute_error: 0.0074
# Epoch 180/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4794e-04 - mean_absolute_error: 0.0083 - val_loss: 1.1831e-04 - val_mean_absolute_error: 0.0077
# Epoch 181/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4314e-04 - mean_absolute_error: 0.0083 - val_loss: 1.1617e-04 - val_mean_absolute_error: 0.0078
# Epoch 182/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5663e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0660e-04 - val_mean_absolute_error: 0.0072
# Epoch 183/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5818e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2781e-04 - val_mean_absolute_error: 0.0081
# Epoch 184/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3990e-04 - mean_absolute_error: 0.0083 - val_loss: 1.4806e-04 - val_mean_absolute_error: 0.0091
# Epoch 185/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4846e-04 - mean_absolute_error: 0.0084 - val_loss: 1.5178e-04 - val_mean_absolute_error: 0.0093
# Epoch 186/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5226e-04 - mean_absolute_error: 0.0081 - val_loss: 1.2579e-04 - val_mean_absolute_error: 0.0083
# Epoch 187/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.7340e-04 - mean_absolute_error: 0.0093 - val_loss: 1.1117e-04 - val_mean_absolute_error: 0.0074
# Epoch 188/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4412e-04 - mean_absolute_error: 0.0081 - val_loss: 1.3025e-04 - val_mean_absolute_error: 0.0082
# Epoch 189/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3694e-04 - mean_absolute_error: 0.0080 - val_loss: 1.1515e-04 - val_mean_absolute_error: 0.0076
# Epoch 190/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6907e-04 - mean_absolute_error: 0.0088 - val_loss: 1.0522e-04 - val_mean_absolute_error: 0.0071
# Epoch 191/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5436e-04 - mean_absolute_error: 0.0088 - val_loss: 1.0403e-04 - val_mean_absolute_error: 0.0070
# Epoch 192/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3340e-04 - mean_absolute_error: 0.0080 - val_loss: 1.0239e-04 - val_mean_absolute_error: 0.0070
# Epoch 193/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4249e-04 - mean_absolute_error: 0.0083 - val_loss: 1.8716e-04 - val_mean_absolute_error: 0.0108
# Epoch 194/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4215e-04 - mean_absolute_error: 0.0085 - val_loss: 1.1185e-04 - val_mean_absolute_error: 0.0075
# Epoch 195/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5949e-04 - mean_absolute_error: 0.0090 - val_loss: 1.3448e-04 - val_mean_absolute_error: 0.0087
# Epoch 196/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5390e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2208e-04 - val_mean_absolute_error: 0.0081
# Epoch 197/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5189e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0325e-04 - val_mean_absolute_error: 0.0070
# Epoch 198/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5443e-04 - mean_absolute_error: 0.0088 - val_loss: 1.1686e-04 - val_mean_absolute_error: 0.0079
# Epoch 199/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5197e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0389e-04 - val_mean_absolute_error: 0.0071
# Epoch 200/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4586e-04 - mean_absolute_error: 0.0082 - val_loss: 1.0289e-04 - val_mean_absolute_error: 0.0071

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 120
# 131

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 541893.9138221105
# RMSE: 736.1344400461851
# MAE: 530.8743815104167
# MAPE: 1.4459109450602383 %
#
# Model evalution on validate set
# MSE: 3647711.4892149367
# RMSE: 1909.8982928980633
# MAE: 1230.1107308884298
# MAPE: 2.581919633076421 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 599ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step

# %%
y_pred_30_days
# Out:
# array([[61889.977],
#        [61578.36 ],
#        [61937.355],
#        [61789.96 ],
#        [61861.926],
#        [61827.06 ],
#        [61843.82 ],
#        [61835.758],
#        [61839.652],
#        [61837.773],
#        [61838.67 ],
#        [61838.254],
#        [61838.445],
#        [61838.367],
#        [61838.43 ],
#        [61838.383],
#        [61838.4  ],
#        [61838.39 ],
#        [61838.38 ],
#        [61838.38 ],
#        [61838.38 ],
#        [61838.38 ],
#        [61838.38 ],
#        [61838.39 ],
#        [61838.38 ],
#        [61838.383],
#        [61838.39 ],
#        [61838.38 ],
#        [61838.38 ],
#        [61838.38 ],
#        [61838.38 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Predict the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
