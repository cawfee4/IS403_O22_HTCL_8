# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: CMG - Test/Train/Vaildation: 80/10/10
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 844.6762178597083
# - MAE: 640.2905598958333
# - MAPE: 1.732434854204543 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 2  # 8 1 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.tail()
# Out:
#             close
# time
# 2024-05-27  59000
# 2024-05-28  62100
# 2024-05-29  60000
# 2024-05-30  59200
# 2024-05-31  60900

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((1039, 10), (1039,), (120, 10), (120,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - loss: 0.0404 - mean_absolute_error: 0.1400 - val_loss: 0.0020 - val_mean_absolute_error: 0.0414
# Epoch 2/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1416e-04 - mean_absolute_error: 0.0210 - val_loss: 3.9854e-04 - val_mean_absolute_error: 0.0154
# Epoch 3/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.7145e-04 - mean_absolute_error: 0.0174 - val_loss: 3.1668e-04 - val_mean_absolute_error: 0.0132
# Epoch 4/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.9596e-04 - mean_absolute_error: 0.0164 - val_loss: 3.9697e-04 - val_mean_absolute_error: 0.0157
# Epoch 5/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 4.7731e-04 - mean_absolute_error: 0.0155 - val_loss: 2.4426e-04 - val_mean_absolute_error: 0.0115
# Epoch 6/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.7009e-04 - mean_absolute_error: 0.0138 - val_loss: 2.0852e-04 - val_mean_absolute_error: 0.0104
# Epoch 7/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.3762e-04 - mean_absolute_error: 0.0130 - val_loss: 2.3597e-04 - val_mean_absolute_error: 0.0113
# Epoch 8/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.7586e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0011 - val_mean_absolute_error: 0.0299
# Epoch 9/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.5583e-04 - mean_absolute_error: 0.0139 - val_loss: 2.1980e-04 - val_mean_absolute_error: 0.0108
# Epoch 10/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.2108e-04 - mean_absolute_error: 0.0123 - val_loss: 2.6706e-04 - val_mean_absolute_error: 0.0124
# Epoch 11/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7488e-04 - mean_absolute_error: 0.0118 - val_loss: 3.2652e-04 - val_mean_absolute_error: 0.0143
# Epoch 12/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.7622e-04 - mean_absolute_error: 0.0115 - val_loss: 6.7064e-04 - val_mean_absolute_error: 0.0228
# Epoch 13/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.8231e-04 - mean_absolute_error: 0.0116 - val_loss: 5.0710e-04 - val_mean_absolute_error: 0.0192
# Epoch 14/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.5936e-04 - mean_absolute_error: 0.0113 - val_loss: 1.7393e-04 - val_mean_absolute_error: 0.0094
# Epoch 15/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.7343e-04 - mean_absolute_error: 0.0112 - val_loss: 2.3668e-04 - val_mean_absolute_error: 0.0115
# Epoch 16/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.4676e-04 - mean_absolute_error: 0.0106 - val_loss: 3.2303e-04 - val_mean_absolute_error: 0.0145
# Epoch 17/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.6707e-04 - mean_absolute_error: 0.0116 - val_loss: 3.9558e-04 - val_mean_absolute_error: 0.0165
# Epoch 18/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.4915e-04 - mean_absolute_error: 0.0108 - val_loss: 1.5831e-04 - val_mean_absolute_error: 0.0090
# Epoch 19/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3549e-04 - mean_absolute_error: 0.0106 - val_loss: 2.4401e-04 - val_mean_absolute_error: 0.0119
# Epoch 20/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.2645e-04 - mean_absolute_error: 0.0128 - val_loss: 2.0184e-04 - val_mean_absolute_error: 0.0105
# Epoch 21/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.8387e-04 - mean_absolute_error: 0.0117 - val_loss: 1.5454e-04 - val_mean_absolute_error: 0.0090
# Epoch 22/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7029e-04 - mean_absolute_error: 0.0114 - val_loss: 1.8309e-04 - val_mean_absolute_error: 0.0099
# Epoch 23/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2234e-04 - mean_absolute_error: 0.0104 - val_loss: 4.9273e-04 - val_mean_absolute_error: 0.0192
# Epoch 24/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.4941e-04 - mean_absolute_error: 0.0107 - val_loss: 1.4626e-04 - val_mean_absolute_error: 0.0087
# Epoch 25/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.7666e-04 - mean_absolute_error: 0.0119 - val_loss: 1.4522e-04 - val_mean_absolute_error: 0.0086
# Epoch 26/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.3303e-04 - mean_absolute_error: 0.0106 - val_loss: 1.9351e-04 - val_mean_absolute_error: 0.0104
# Epoch 27/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.4935e-04 - mean_absolute_error: 0.0111 - val_loss: 1.8057e-04 - val_mean_absolute_error: 0.0100
# Epoch 28/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.4087e-04 - mean_absolute_error: 0.0107 - val_loss: 1.9307e-04 - val_mean_absolute_error: 0.0104
# Epoch 29/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.3813e-04 - mean_absolute_error: 0.0109 - val_loss: 1.4648e-04 - val_mean_absolute_error: 0.0086
# Epoch 30/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.2514e-04 - mean_absolute_error: 0.0106 - val_loss: 1.3739e-04 - val_mean_absolute_error: 0.0084
# Epoch 31/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 2.1298e-04 - mean_absolute_error: 0.0102 - val_loss: 2.5738e-04 - val_mean_absolute_error: 0.0127
# Epoch 32/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3035e-04 - mean_absolute_error: 0.0107 - val_loss: 2.2658e-04 - val_mean_absolute_error: 0.0123
# Epoch 33/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1236e-04 - mean_absolute_error: 0.0103 - val_loss: 3.1250e-04 - val_mean_absolute_error: 0.0146
# Epoch 34/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.1989e-04 - mean_absolute_error: 0.0103 - val_loss: 2.0512e-04 - val_mean_absolute_error: 0.0109
# Epoch 35/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.4164e-04 - mean_absolute_error: 0.0108 - val_loss: 1.5144e-04 - val_mean_absolute_error: 0.0089
# Epoch 36/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0772e-04 - mean_absolute_error: 0.0099 - val_loss: 1.4396e-04 - val_mean_absolute_error: 0.0086
# Epoch 37/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.0956e-04 - mean_absolute_error: 0.0098 - val_loss: 1.6281e-04 - val_mean_absolute_error: 0.0094
# Epoch 38/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0845e-04 - mean_absolute_error: 0.0100 - val_loss: 1.2826e-04 - val_mean_absolute_error: 0.0080
# Epoch 39/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0833e-04 - mean_absolute_error: 0.0102 - val_loss: 1.4724e-04 - val_mean_absolute_error: 0.0088
# Epoch 40/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.3803e-04 - mean_absolute_error: 0.0106 - val_loss: 2.9892e-04 - val_mean_absolute_error: 0.0148
# Epoch 41/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.5772e-04 - mean_absolute_error: 0.0138 - val_loss: 3.8618e-04 - val_mean_absolute_error: 0.0170
# Epoch 42/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9515e-04 - mean_absolute_error: 0.0095 - val_loss: 1.2730e-04 - val_mean_absolute_error: 0.0079
# Epoch 43/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8867e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0012 - val_mean_absolute_error: 0.0333
# Epoch 44/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5895e-04 - mean_absolute_error: 0.0140 - val_loss: 4.6765e-04 - val_mean_absolute_error: 0.0197
# Epoch 45/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.5953e-04 - mean_absolute_error: 0.0118 - val_loss: 1.2513e-04 - val_mean_absolute_error: 0.0078
# Epoch 46/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9234e-04 - mean_absolute_error: 0.0096 - val_loss: 1.4719e-04 - val_mean_absolute_error: 0.0090
# Epoch 47/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0414e-04 - mean_absolute_error: 0.0101 - val_loss: 1.2215e-04 - val_mean_absolute_error: 0.0078
# Epoch 48/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8418e-04 - mean_absolute_error: 0.0094 - val_loss: 4.9663e-04 - val_mean_absolute_error: 0.0199
# Epoch 49/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.0954e-04 - mean_absolute_error: 0.0100 - val_loss: 1.9950e-04 - val_mean_absolute_error: 0.0109
# Epoch 50/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9767e-04 - mean_absolute_error: 0.0099 - val_loss: 1.8646e-04 - val_mean_absolute_error: 0.0104
# Epoch 51/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.0678e-04 - mean_absolute_error: 0.0100 - val_loss: 3.9320e-04 - val_mean_absolute_error: 0.0173
# Epoch 52/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9215e-04 - mean_absolute_error: 0.0097 - val_loss: 1.6195e-04 - val_mean_absolute_error: 0.0098
# Epoch 53/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7872e-04 - mean_absolute_error: 0.0092 - val_loss: 1.3821e-04 - val_mean_absolute_error: 0.0085
# Epoch 54/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7692e-04 - mean_absolute_error: 0.0090 - val_loss: 1.9525e-04 - val_mean_absolute_error: 0.0108
# Epoch 55/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.7617e-04 - mean_absolute_error: 0.0091 - val_loss: 2.1612e-04 - val_mean_absolute_error: 0.0116
# Epoch 56/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1778e-04 - mean_absolute_error: 0.0103 - val_loss: 2.0157e-04 - val_mean_absolute_error: 0.0111
# Epoch 57/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6786e-04 - mean_absolute_error: 0.0091 - val_loss: 1.1410e-04 - val_mean_absolute_error: 0.0074
# Epoch 58/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8771e-04 - mean_absolute_error: 0.0094 - val_loss: 1.9454e-04 - val_mean_absolute_error: 0.0109
# Epoch 59/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7971e-04 - mean_absolute_error: 0.0091 - val_loss: 1.2663e-04 - val_mean_absolute_error: 0.0081
# Epoch 60/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6922e-04 - mean_absolute_error: 0.0091 - val_loss: 1.3138e-04 - val_mean_absolute_error: 0.0084
# Epoch 61/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8774e-04 - mean_absolute_error: 0.0095 - val_loss: 1.1109e-04 - val_mean_absolute_error: 0.0073
# Epoch 62/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.1009e-04 - mean_absolute_error: 0.0100 - val_loss: 1.6322e-04 - val_mean_absolute_error: 0.0095
# Epoch 63/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.9214e-04 - mean_absolute_error: 0.0096 - val_loss: 1.1806e-04 - val_mean_absolute_error: 0.0076
# Epoch 64/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7969e-04 - mean_absolute_error: 0.0091 - val_loss: 3.0524e-04 - val_mean_absolute_error: 0.0149
# Epoch 65/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8490e-04 - mean_absolute_error: 0.0093 - val_loss: 1.1834e-04 - val_mean_absolute_error: 0.0077
# Epoch 66/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7694e-04 - mean_absolute_error: 0.0090 - val_loss: 1.0959e-04 - val_mean_absolute_error: 0.0072
# Epoch 67/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5003e-04 - mean_absolute_error: 0.0084 - val_loss: 2.8085e-04 - val_mean_absolute_error: 0.0142
# Epoch 68/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7429e-04 - mean_absolute_error: 0.0094 - val_loss: 1.6658e-04 - val_mean_absolute_error: 0.0101
# Epoch 69/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8554e-04 - mean_absolute_error: 0.0100 - val_loss: 2.1774e-04 - val_mean_absolute_error: 0.0119
# Epoch 70/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6193e-04 - mean_absolute_error: 0.0087 - val_loss: 1.7433e-04 - val_mean_absolute_error: 0.0101
# Epoch 71/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7662e-04 - mean_absolute_error: 0.0091 - val_loss: 1.0660e-04 - val_mean_absolute_error: 0.0072
# Epoch 72/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7891e-04 - mean_absolute_error: 0.0093 - val_loss: 1.3694e-04 - val_mean_absolute_error: 0.0085
# Epoch 73/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.5694e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2739e-04 - val_mean_absolute_error: 0.0083
# Epoch 74/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.7491e-04 - mean_absolute_error: 0.0091 - val_loss: 2.0052e-04 - val_mean_absolute_error: 0.0112
# Epoch 75/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9289e-04 - mean_absolute_error: 0.0096 - val_loss: 1.0588e-04 - val_mean_absolute_error: 0.0070
# Epoch 76/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7360e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0421e-04 - val_mean_absolute_error: 0.0070
# Epoch 77/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0679e-04 - mean_absolute_error: 0.0097 - val_loss: 2.4211e-04 - val_mean_absolute_error: 0.0129
# Epoch 78/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6029e-04 - mean_absolute_error: 0.0090 - val_loss: 1.1959e-04 - val_mean_absolute_error: 0.0078
# Epoch 79/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4541e-04 - mean_absolute_error: 0.0084 - val_loss: 2.1280e-04 - val_mean_absolute_error: 0.0118
# Epoch 80/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7864e-04 - mean_absolute_error: 0.0088 - val_loss: 1.0721e-04 - val_mean_absolute_error: 0.0072
# Epoch 81/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7706e-04 - mean_absolute_error: 0.0098 - val_loss: 4.2630e-04 - val_mean_absolute_error: 0.0186
# Epoch 82/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9280e-04 - mean_absolute_error: 0.0101 - val_loss: 1.0904e-04 - val_mean_absolute_error: 0.0072
# Epoch 83/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.6715e-04 - mean_absolute_error: 0.0090 - val_loss: 4.1814e-04 - val_mean_absolute_error: 0.0184
# Epoch 84/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6453e-04 - mean_absolute_error: 0.0090 - val_loss: 1.1564e-04 - val_mean_absolute_error: 0.0075
# Epoch 85/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5528e-04 - mean_absolute_error: 0.0085 - val_loss: 1.1630e-04 - val_mean_absolute_error: 0.0075
# Epoch 86/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7908e-04 - mean_absolute_error: 0.0093 - val_loss: 1.2276e-04 - val_mean_absolute_error: 0.0078
# Epoch 87/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1157e-04 - mean_absolute_error: 0.0105 - val_loss: 6.3610e-04 - val_mean_absolute_error: 0.0238
# Epoch 88/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5287e-04 - mean_absolute_error: 0.0117 - val_loss: 1.1059e-04 - val_mean_absolute_error: 0.0074
# Epoch 89/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7768e-04 - mean_absolute_error: 0.0093 - val_loss: 1.4911e-04 - val_mean_absolute_error: 0.0091
# Epoch 90/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6365e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2453e-04 - val_mean_absolute_error: 0.0079
# Epoch 91/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4237e-04 - mean_absolute_error: 0.0081 - val_loss: 1.6508e-04 - val_mean_absolute_error: 0.0098
# Epoch 92/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4185e-04 - mean_absolute_error: 0.0080 - val_loss: 1.0747e-04 - val_mean_absolute_error: 0.0073
# Epoch 93/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6145e-04 - mean_absolute_error: 0.0087 - val_loss: 1.1125e-04 - val_mean_absolute_error: 0.0075
# Epoch 94/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.4695e-04 - mean_absolute_error: 0.0083 - val_loss: 1.6885e-04 - val_mean_absolute_error: 0.0100
# Epoch 95/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5987e-04 - mean_absolute_error: 0.0088 - val_loss: 1.0033e-04 - val_mean_absolute_error: 0.0070
# Epoch 96/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.9055e-04 - mean_absolute_error: 0.0096 - val_loss: 1.3608e-04 - val_mean_absolute_error: 0.0088
# Epoch 97/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5644e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0205e-04 - val_mean_absolute_error: 0.0070
# Epoch 98/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4711e-04 - mean_absolute_error: 0.0082 - val_loss: 1.3864e-04 - val_mean_absolute_error: 0.0089
# Epoch 99/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6592e-04 - mean_absolute_error: 0.0087 - val_loss: 1.1738e-04 - val_mean_absolute_error: 0.0076
# Epoch 100/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6018e-04 - mean_absolute_error: 0.0087 - val_loss: 1.3159e-04 - val_mean_absolute_error: 0.0086
# Epoch 101/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4657e-04 - mean_absolute_error: 0.0083 - val_loss: 3.6096e-04 - val_mean_absolute_error: 0.0168
# Epoch 102/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7428e-04 - mean_absolute_error: 0.0091 - val_loss: 1.5986e-04 - val_mean_absolute_error: 0.0099
# Epoch 103/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5559e-04 - mean_absolute_error: 0.0087 - val_loss: 2.4282e-04 - val_mean_absolute_error: 0.0130
# Epoch 104/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4135e-04 - mean_absolute_error: 0.0086 - val_loss: 1.8277e-04 - val_mean_absolute_error: 0.0106
# Epoch 105/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5965e-04 - mean_absolute_error: 0.0089 - val_loss: 1.1239e-04 - val_mean_absolute_error: 0.0074
# Epoch 106/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4121e-04 - mean_absolute_error: 0.0081 - val_loss: 1.0620e-04 - val_mean_absolute_error: 0.0073
# Epoch 107/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3828e-04 - mean_absolute_error: 0.0083 - val_loss: 1.0474e-04 - val_mean_absolute_error: 0.0072
# Epoch 108/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4785e-04 - mean_absolute_error: 0.0081 - val_loss: 1.6869e-04 - val_mean_absolute_error: 0.0100
# Epoch 109/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4956e-04 - mean_absolute_error: 0.0085 - val_loss: 1.6732e-04 - val_mean_absolute_error: 0.0103
# Epoch 110/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.5860e-04 - mean_absolute_error: 0.0087 - val_loss: 1.0065e-04 - val_mean_absolute_error: 0.0070
# Epoch 111/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4264e-04 - mean_absolute_error: 0.0083 - val_loss: 1.6990e-04 - val_mean_absolute_error: 0.0100
# Epoch 112/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.5178e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2363e-04 - val_mean_absolute_error: 0.0079
# Epoch 113/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8066e-04 - mean_absolute_error: 0.0095 - val_loss: 1.0278e-04 - val_mean_absolute_error: 0.0071
# Epoch 114/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5902e-04 - mean_absolute_error: 0.0086 - val_loss: 1.3521e-04 - val_mean_absolute_error: 0.0084
# Epoch 115/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4859e-04 - mean_absolute_error: 0.0086 - val_loss: 1.4608e-04 - val_mean_absolute_error: 0.0090
# Epoch 116/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4343e-04 - mean_absolute_error: 0.0082 - val_loss: 3.3775e-04 - val_mean_absolute_error: 0.0161
# Epoch 117/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.8936e-04 - mean_absolute_error: 0.0099 - val_loss: 1.2415e-04 - val_mean_absolute_error: 0.0080
# Epoch 118/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4313e-04 - mean_absolute_error: 0.0084 - val_loss: 1.5260e-04 - val_mean_absolute_error: 0.0093
# Epoch 119/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4468e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2482e-04 - val_mean_absolute_error: 0.0080
# Epoch 120/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3901e-04 - mean_absolute_error: 0.0079 - val_loss: 1.0334e-04 - val_mean_absolute_error: 0.0071
# Epoch 121/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2962e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2881e-04 - val_mean_absolute_error: 0.0082
# Epoch 122/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.4656e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2337e-04 - val_mean_absolute_error: 0.0083
# Epoch 123/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5760e-04 - mean_absolute_error: 0.0088 - val_loss: 1.1928e-04 - val_mean_absolute_error: 0.0080
# Epoch 124/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4446e-04 - mean_absolute_error: 0.0083 - val_loss: 1.0253e-04 - val_mean_absolute_error: 0.0071
# Epoch 125/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5933e-04 - mean_absolute_error: 0.0088 - val_loss: 1.4513e-04 - val_mean_absolute_error: 0.0089
# Epoch 126/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5922e-04 - mean_absolute_error: 0.0086 - val_loss: 1.4538e-04 - val_mean_absolute_error: 0.0090
# Epoch 127/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.4133e-04 - mean_absolute_error: 0.0083 - val_loss: 1.1200e-04 - val_mean_absolute_error: 0.0075
# Epoch 128/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4664e-04 - mean_absolute_error: 0.0088 - val_loss: 1.4623e-04 - val_mean_absolute_error: 0.0093
# Epoch 129/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5530e-04 - mean_absolute_error: 0.0088 - val_loss: 1.3893e-04 - val_mean_absolute_error: 0.0086
# Epoch 130/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.4277e-04 - mean_absolute_error: 0.0082 - val_loss: 1.4826e-04 - val_mean_absolute_error: 0.0094
# Epoch 131/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8801e-04 - mean_absolute_error: 0.0094 - val_loss: 1.6317e-04 - val_mean_absolute_error: 0.0098
# Epoch 132/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3562e-04 - mean_absolute_error: 0.0079 - val_loss: 1.0363e-04 - val_mean_absolute_error: 0.0071
# Epoch 133/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6061e-04 - mean_absolute_error: 0.0086 - val_loss: 1.9538e-04 - val_mean_absolute_error: 0.0111
# Epoch 134/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6413e-04 - mean_absolute_error: 0.0088 - val_loss: 1.0096e-04 - val_mean_absolute_error: 0.0070
# Epoch 135/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9770e-04 - mean_absolute_error: 0.0099 - val_loss: 2.5994e-04 - val_mean_absolute_error: 0.0135
# Epoch 136/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.6332e-04 - mean_absolute_error: 0.0091 - val_loss: 1.3965e-04 - val_mean_absolute_error: 0.0090
# Epoch 137/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3397e-04 - mean_absolute_error: 0.0079 - val_loss: 1.0268e-04 - val_mean_absolute_error: 0.0071
# Epoch 138/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.9324e-04 - mean_absolute_error: 0.0098 - val_loss: 1.2994e-04 - val_mean_absolute_error: 0.0082
# Epoch 139/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.5807e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0776e-04 - val_mean_absolute_error: 0.0072
# Epoch 140/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4444e-04 - mean_absolute_error: 0.0082 - val_loss: 1.3394e-04 - val_mean_absolute_error: 0.0087
# Epoch 141/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.8340e-04 - mean_absolute_error: 0.0098 - val_loss: 1.9524e-04 - val_mean_absolute_error: 0.0111
# Epoch 142/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6809e-04 - mean_absolute_error: 0.0088 - val_loss: 1.7690e-04 - val_mean_absolute_error: 0.0103
# Epoch 143/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4648e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2713e-04 - val_mean_absolute_error: 0.0081
# Epoch 144/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.4903e-04 - mean_absolute_error: 0.0083 - val_loss: 1.0768e-04 - val_mean_absolute_error: 0.0072
# Epoch 145/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4464e-04 - mean_absolute_error: 0.0085 - val_loss: 2.8672e-04 - val_mean_absolute_error: 0.0144
# Epoch 146/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4892e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0141e-04 - val_mean_absolute_error: 0.0070
# Epoch 147/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.3982e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2656e-04 - val_mean_absolute_error: 0.0084
# Epoch 148/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.9033e-04 - mean_absolute_error: 0.0096 - val_loss: 1.0203e-04 - val_mean_absolute_error: 0.0070
# Epoch 149/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3281e-04 - mean_absolute_error: 0.0079 - val_loss: 1.3180e-04 - val_mean_absolute_error: 0.0087
# Epoch 150/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6418e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0195e-04 - val_mean_absolute_error: 0.0070
# Epoch 151/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4500e-04 - mean_absolute_error: 0.0083 - val_loss: 1.5770e-04 - val_mean_absolute_error: 0.0098
# Epoch 152/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8915e-04 - mean_absolute_error: 0.0096 - val_loss: 2.0627e-04 - val_mean_absolute_error: 0.0119
# Epoch 153/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5653e-04 - mean_absolute_error: 0.0088 - val_loss: 1.0288e-04 - val_mean_absolute_error: 0.0070
# Epoch 154/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4797e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0544e-04 - val_mean_absolute_error: 0.0072
# Epoch 155/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4230e-04 - mean_absolute_error: 0.0083 - val_loss: 1.3498e-04 - val_mean_absolute_error: 0.0088
# Epoch 156/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6174e-04 - mean_absolute_error: 0.0088 - val_loss: 1.4091e-04 - val_mean_absolute_error: 0.0088
# Epoch 157/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5148e-04 - mean_absolute_error: 0.0087 - val_loss: 1.1087e-04 - val_mean_absolute_error: 0.0074
# Epoch 158/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4567e-04 - mean_absolute_error: 0.0085 - val_loss: 1.1273e-04 - val_mean_absolute_error: 0.0074
# Epoch 159/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4421e-04 - mean_absolute_error: 0.0082 - val_loss: 1.7384e-04 - val_mean_absolute_error: 0.0102
# Epoch 160/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3967e-04 - mean_absolute_error: 0.0080 - val_loss: 1.0211e-04 - val_mean_absolute_error: 0.0071
# Epoch 161/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4177e-04 - mean_absolute_error: 0.0080 - val_loss: 1.0819e-04 - val_mean_absolute_error: 0.0072
# Epoch 162/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5597e-04 - mean_absolute_error: 0.0089 - val_loss: 1.1411e-04 - val_mean_absolute_error: 0.0075
# Epoch 163/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4915e-04 - mean_absolute_error: 0.0083 - val_loss: 1.0490e-04 - val_mean_absolute_error: 0.0073
# Epoch 164/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4528e-04 - mean_absolute_error: 0.0085 - val_loss: 1.3773e-04 - val_mean_absolute_error: 0.0089
# Epoch 165/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5559e-04 - mean_absolute_error: 0.0089 - val_loss: 1.2295e-04 - val_mean_absolute_error: 0.0082
# Epoch 166/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4566e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0239e-04 - val_mean_absolute_error: 0.0070
# Epoch 167/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4821e-04 - mean_absolute_error: 0.0081 - val_loss: 1.0928e-04 - val_mean_absolute_error: 0.0073
# Epoch 168/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5487e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0135e-04 - val_mean_absolute_error: 0.0070
# Epoch 169/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5371e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2785e-04 - val_mean_absolute_error: 0.0082
# Epoch 170/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6399e-04 - mean_absolute_error: 0.0091 - val_loss: 1.7459e-04 - val_mean_absolute_error: 0.0106
# Epoch 171/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5357e-04 - mean_absolute_error: 0.0085 - val_loss: 1.3046e-04 - val_mean_absolute_error: 0.0083
# Epoch 172/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4335e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0514e-04 - val_mean_absolute_error: 0.0072
# Epoch 173/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6325e-04 - mean_absolute_error: 0.0091 - val_loss: 1.1260e-04 - val_mean_absolute_error: 0.0077
# Epoch 174/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4406e-04 - mean_absolute_error: 0.0085 - val_loss: 1.3791e-04 - val_mean_absolute_error: 0.0086
# Epoch 175/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.0255e-04 - mean_absolute_error: 0.0100 - val_loss: 1.5020e-04 - val_mean_absolute_error: 0.0092
# Epoch 176/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5385e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2632e-04 - val_mean_absolute_error: 0.0081
# Epoch 177/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6117e-04 - mean_absolute_error: 0.0091 - val_loss: 1.2754e-04 - val_mean_absolute_error: 0.0081
# Epoch 178/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3536e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2820e-04 - val_mean_absolute_error: 0.0081
# Epoch 179/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3617e-04 - mean_absolute_error: 0.0080 - val_loss: 1.1596e-04 - val_mean_absolute_error: 0.0078
# Epoch 180/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5215e-04 - mean_absolute_error: 0.0082 - val_loss: 1.9424e-04 - val_mean_absolute_error: 0.0111
# Epoch 181/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6671e-04 - mean_absolute_error: 0.0092 - val_loss: 2.1064e-04 - val_mean_absolute_error: 0.0117
# Epoch 182/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6595e-04 - mean_absolute_error: 0.0088 - val_loss: 1.0753e-04 - val_mean_absolute_error: 0.0072
# Epoch 183/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3863e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2699e-04 - val_mean_absolute_error: 0.0081
# Epoch 184/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3804e-04 - mean_absolute_error: 0.0083 - val_loss: 1.1145e-04 - val_mean_absolute_error: 0.0074
# Epoch 185/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3314e-04 - mean_absolute_error: 0.0081 - val_loss: 1.1506e-04 - val_mean_absolute_error: 0.0076
# Epoch 186/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2674e-04 - mean_absolute_error: 0.0077 - val_loss: 1.4818e-04 - val_mean_absolute_error: 0.0094
# Epoch 187/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6098e-04 - mean_absolute_error: 0.0088 - val_loss: 1.6478e-04 - val_mean_absolute_error: 0.0098
# Epoch 188/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7737e-04 - mean_absolute_error: 0.0094 - val_loss: 4.7892e-04 - val_mean_absolute_error: 0.0202
# Epoch 189/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9374e-04 - mean_absolute_error: 0.0101 - val_loss: 1.0996e-04 - val_mean_absolute_error: 0.0073
# Epoch 190/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4124e-04 - mean_absolute_error: 0.0082 - val_loss: 1.5402e-04 - val_mean_absolute_error: 0.0097
# Epoch 191/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6211e-04 - mean_absolute_error: 0.0090 - val_loss: 1.6260e-04 - val_mean_absolute_error: 0.0097
# Epoch 192/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6545e-04 - mean_absolute_error: 0.0089 - val_loss: 1.3936e-04 - val_mean_absolute_error: 0.0090
# Epoch 193/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4553e-04 - mean_absolute_error: 0.0083 - val_loss: 1.6012e-04 - val_mean_absolute_error: 0.0099
# Epoch 194/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6599e-04 - mean_absolute_error: 0.0088 - val_loss: 1.1888e-04 - val_mean_absolute_error: 0.0080
# Epoch 195/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3802e-04 - mean_absolute_error: 0.0081 - val_loss: 1.5493e-04 - val_mean_absolute_error: 0.0094
# Epoch 196/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4314e-04 - mean_absolute_error: 0.0081 - val_loss: 3.8495e-04 - val_mean_absolute_error: 0.0174
# Epoch 197/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4595e-04 - mean_absolute_error: 0.0086 - val_loss: 1.6300e-04 - val_mean_absolute_error: 0.0097
# Epoch 198/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4451e-04 - mean_absolute_error: 0.0084 - val_loss: 1.8283e-04 - val_mean_absolute_error: 0.0106
# Epoch 199/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7573e-04 - mean_absolute_error: 0.0093 - val_loss: 1.1458e-04 - val_mean_absolute_error: 0.0076
# Epoch 200/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4360e-04 - mean_absolute_error: 0.0083 - val_loss: 1.5447e-04 - val_mean_absolute_error: 0.0094

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 120
# 131

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 713477.9130177816
# RMSE: 844.6762178597083
# MAE: 640.2905598958333
# MAPE: 1.732434854204543 %
#
# Model evalution on validate set
# MSE: 4460600.734560375
# RMSE: 2112.0134314346524
# MAE: 1385.537125516529
# MAPE: 2.9195850054193726 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step

# %%
y_pred_30_days
# Out:
# array([[60877.258],
#        [60618.215],
#        [60808.63 ],
#        [60770.656],
#        [60782.28 ],
#        [60779.152],
#        [60779.44 ],
#        [60779.348],
#        [60779.31 ],
#        [60779.336],
#        [60779.32 ],
#        [60779.32 ],
#        [60779.32 ],
#        [60779.32 ],
#        [60779.32 ],
#        [60779.32 ],
#        [60779.32 ],
#        [60779.32 ],
#        [60779.32 ],
#        [60779.32 ],
#        [60779.32 ],
#        [60779.32 ],
#        [60779.32 ],
#        [60779.32 ],
#        [60779.32 ],
#        [60779.32 ],
#        [60779.32 ],
#        [60779.32 ],
#        [60779.32 ],
#        [60779.32 ],
#        [60779.32 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Forecast Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Forecast the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
