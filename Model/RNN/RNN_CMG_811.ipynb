# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: CMG - Test/Train/Vaildation: 80/10/10
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 916.1429606335861
# - MAE: 707.9215657552083
# - MAPE: 1.913374740867347 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 2  # 8 1 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.tail()
# Out:
#             close
# time
# 2024-05-27  59000
# 2024-05-28  62100
# 2024-05-29  60000
# 2024-05-30  59200
# 2024-05-31  60900

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((1039, 10), (1039,), (120, 10), (120,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0267 - mean_absolute_error: 0.1090 - val_loss: 0.0027 - val_mean_absolute_error: 0.0484
# Epoch 2/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - mean_absolute_error: 0.0254 - val_loss: 7.0825e-04 - val_mean_absolute_error: 0.0221
# Epoch 3/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8528e-04 - mean_absolute_error: 0.0175 - val_loss: 4.6223e-04 - val_mean_absolute_error: 0.0171
# Epoch 4/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.1504e-04 - mean_absolute_error: 0.0159 - val_loss: 4.2668e-04 - val_mean_absolute_error: 0.0165
# Epoch 5/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.2536e-04 - mean_absolute_error: 0.0143 - val_loss: 2.6954e-04 - val_mean_absolute_error: 0.0121
# Epoch 6/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.6280e-04 - mean_absolute_error: 0.0131 - val_loss: 1.8940e-04 - val_mean_absolute_error: 0.0098
# Epoch 7/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8959e-04 - mean_absolute_error: 0.0120 - val_loss: 3.8811e-04 - val_mean_absolute_error: 0.0162
# Epoch 8/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6519e-04 - mean_absolute_error: 0.0117 - val_loss: 2.2048e-04 - val_mean_absolute_error: 0.0110
# Epoch 9/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6273e-04 - mean_absolute_error: 0.0112 - val_loss: 4.7224e-04 - val_mean_absolute_error: 0.0186
# Epoch 10/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8235e-04 - mean_absolute_error: 0.0115 - val_loss: 1.6024e-04 - val_mean_absolute_error: 0.0093
# Epoch 11/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8720e-04 - mean_absolute_error: 0.0116 - val_loss: 2.3591e-04 - val_mean_absolute_error: 0.0117
# Epoch 12/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2603e-04 - mean_absolute_error: 0.0105 - val_loss: 1.7711e-04 - val_mean_absolute_error: 0.0100
# Epoch 13/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6747e-04 - mean_absolute_error: 0.0119 - val_loss: 1.6338e-04 - val_mean_absolute_error: 0.0092
# Epoch 14/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5229e-04 - mean_absolute_error: 0.0111 - val_loss: 1.4590e-04 - val_mean_absolute_error: 0.0087
# Epoch 15/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1896e-04 - mean_absolute_error: 0.0103 - val_loss: 1.4543e-04 - val_mean_absolute_error: 0.0086
# Epoch 16/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9479e-04 - mean_absolute_error: 0.0095 - val_loss: 4.6357e-04 - val_mean_absolute_error: 0.0192
# Epoch 17/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.5119e-04 - mean_absolute_error: 0.0140 - val_loss: 3.6359e-04 - val_mean_absolute_error: 0.0160
# Epoch 18/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.1252e-04 - mean_absolute_error: 0.0100 - val_loss: 2.2842e-04 - val_mean_absolute_error: 0.0117
# Epoch 19/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1417e-04 - mean_absolute_error: 0.0099 - val_loss: 6.3820e-04 - val_mean_absolute_error: 0.0228
# Epoch 20/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6585e-04 - mean_absolute_error: 0.0116 - val_loss: 1.5446e-04 - val_mean_absolute_error: 0.0090
# Epoch 21/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1438e-04 - mean_absolute_error: 0.0101 - val_loss: 1.3495e-04 - val_mean_absolute_error: 0.0082
# Epoch 22/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0804e-04 - mean_absolute_error: 0.0100 - val_loss: 1.6526e-04 - val_mean_absolute_error: 0.0097
# Epoch 23/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9826e-04 - mean_absolute_error: 0.0098 - val_loss: 1.5828e-04 - val_mean_absolute_error: 0.0095
# Epoch 24/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9474e-04 - mean_absolute_error: 0.0098 - val_loss: 1.3416e-04 - val_mean_absolute_error: 0.0083
# Epoch 25/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0365e-04 - mean_absolute_error: 0.0100 - val_loss: 1.9421e-04 - val_mean_absolute_error: 0.0106
# Epoch 26/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.3972e-04 - mean_absolute_error: 0.0114 - val_loss: 1.2675e-04 - val_mean_absolute_error: 0.0079
# Epoch 27/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7808e-04 - mean_absolute_error: 0.0092 - val_loss: 1.4687e-04 - val_mean_absolute_error: 0.0089
# Epoch 28/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1004e-04 - mean_absolute_error: 0.0103 - val_loss: 1.2806e-04 - val_mean_absolute_error: 0.0080
# Epoch 29/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0697e-04 - mean_absolute_error: 0.0100 - val_loss: 2.2191e-04 - val_mean_absolute_error: 0.0117
# Epoch 30/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0229e-04 - mean_absolute_error: 0.0097 - val_loss: 1.3510e-04 - val_mean_absolute_error: 0.0083
# Epoch 31/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9607e-04 - mean_absolute_error: 0.0100 - val_loss: 1.2251e-04 - val_mean_absolute_error: 0.0077
# Epoch 32/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0273e-04 - mean_absolute_error: 0.0100 - val_loss: 3.3213e-04 - val_mean_absolute_error: 0.0155
# Epoch 33/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3606e-04 - mean_absolute_error: 0.0110 - val_loss: 1.2827e-04 - val_mean_absolute_error: 0.0080
# Epoch 34/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7921e-04 - mean_absolute_error: 0.0091 - val_loss: 1.3758e-04 - val_mean_absolute_error: 0.0085
# Epoch 35/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0397e-04 - mean_absolute_error: 0.0098 - val_loss: 1.1932e-04 - val_mean_absolute_error: 0.0076
# Epoch 36/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9380e-04 - mean_absolute_error: 0.0096 - val_loss: 1.4207e-04 - val_mean_absolute_error: 0.0087
# Epoch 37/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8865e-04 - mean_absolute_error: 0.0094 - val_loss: 1.6824e-04 - val_mean_absolute_error: 0.0097
# Epoch 38/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7185e-04 - mean_absolute_error: 0.0091 - val_loss: 1.8926e-04 - val_mean_absolute_error: 0.0105
# Epoch 39/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9600e-04 - mean_absolute_error: 0.0098 - val_loss: 1.1775e-04 - val_mean_absolute_error: 0.0076
# Epoch 40/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8586e-04 - mean_absolute_error: 0.0093 - val_loss: 7.7072e-04 - val_mean_absolute_error: 0.0259
# Epoch 41/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5113e-04 - mean_absolute_error: 0.0114 - val_loss: 1.1375e-04 - val_mean_absolute_error: 0.0074
# Epoch 42/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9140e-04 - mean_absolute_error: 0.0098 - val_loss: 1.3198e-04 - val_mean_absolute_error: 0.0083
# Epoch 43/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8377e-04 - mean_absolute_error: 0.0094 - val_loss: 1.5782e-04 - val_mean_absolute_error: 0.0093
# Epoch 44/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7451e-04 - mean_absolute_error: 0.0093 - val_loss: 1.4398e-04 - val_mean_absolute_error: 0.0088
# Epoch 45/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8055e-04 - mean_absolute_error: 0.0091 - val_loss: 1.1542e-04 - val_mean_absolute_error: 0.0075
# Epoch 46/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7530e-04 - mean_absolute_error: 0.0092 - val_loss: 1.3564e-04 - val_mean_absolute_error: 0.0084
# Epoch 47/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7079e-04 - mean_absolute_error: 0.0090 - val_loss: 1.6633e-04 - val_mean_absolute_error: 0.0097
# Epoch 48/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4897e-04 - mean_absolute_error: 0.0083 - val_loss: 2.0794e-04 - val_mean_absolute_error: 0.0114
# Epoch 49/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7968e-04 - mean_absolute_error: 0.0093 - val_loss: 1.7184e-04 - val_mean_absolute_error: 0.0099
# Epoch 50/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7656e-04 - mean_absolute_error: 0.0089 - val_loss: 4.6528e-04 - val_mean_absolute_error: 0.0194
# Epoch 51/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0067e-04 - mean_absolute_error: 0.0101 - val_loss: 1.4954e-04 - val_mean_absolute_error: 0.0090
# Epoch 52/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5767e-04 - mean_absolute_error: 0.0085 - val_loss: 5.9905e-04 - val_mean_absolute_error: 0.0226
# Epoch 53/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8622e-04 - mean_absolute_error: 0.0094 - val_loss: 1.5836e-04 - val_mean_absolute_error: 0.0094
# Epoch 54/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7061e-04 - mean_absolute_error: 0.0091 - val_loss: 2.5537e-04 - val_mean_absolute_error: 0.0133
# Epoch 55/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7881e-04 - mean_absolute_error: 0.0091 - val_loss: 1.3026e-04 - val_mean_absolute_error: 0.0082
# Epoch 56/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.7596e-04 - mean_absolute_error: 0.0092 - val_loss: 2.6363e-04 - val_mean_absolute_error: 0.0136
# Epoch 57/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.5722e-04 - mean_absolute_error: 0.0087 - val_loss: 1.3426e-04 - val_mean_absolute_error: 0.0086
# Epoch 58/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7256e-04 - mean_absolute_error: 0.0092 - val_loss: 1.1906e-04 - val_mean_absolute_error: 0.0077
# Epoch 59/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4052e-04 - mean_absolute_error: 0.0082 - val_loss: 1.5095e-04 - val_mean_absolute_error: 0.0091
# Epoch 60/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.6361e-04 - mean_absolute_error: 0.0088 - val_loss: 1.1065e-04 - val_mean_absolute_error: 0.0072
# Epoch 61/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5433e-04 - mean_absolute_error: 0.0082 - val_loss: 1.1531e-04 - val_mean_absolute_error: 0.0075
# Epoch 62/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6366e-04 - mean_absolute_error: 0.0086 - val_loss: 1.8169e-04 - val_mean_absolute_error: 0.0104
# Epoch 63/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5856e-04 - mean_absolute_error: 0.0091 - val_loss: 1.0441e-04 - val_mean_absolute_error: 0.0071
# Epoch 64/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5022e-04 - mean_absolute_error: 0.0084 - val_loss: 1.1467e-04 - val_mean_absolute_error: 0.0075
# Epoch 65/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7745e-04 - mean_absolute_error: 0.0094 - val_loss: 1.0526e-04 - val_mean_absolute_error: 0.0071
# Epoch 66/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1267e-04 - mean_absolute_error: 0.0107 - val_loss: 1.5839e-04 - val_mean_absolute_error: 0.0095
# Epoch 67/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7037e-04 - mean_absolute_error: 0.0092 - val_loss: 1.1282e-04 - val_mean_absolute_error: 0.0074
# Epoch 68/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.5061e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0086e-04 - val_mean_absolute_error: 0.0070
# Epoch 69/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6851e-04 - mean_absolute_error: 0.0090 - val_loss: 3.3177e-04 - val_mean_absolute_error: 0.0159
# Epoch 70/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5459e-04 - mean_absolute_error: 0.0088 - val_loss: 1.1620e-04 - val_mean_absolute_error: 0.0075
# Epoch 71/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3412e-04 - mean_absolute_error: 0.0080 - val_loss: 1.0230e-04 - val_mean_absolute_error: 0.0070
# Epoch 72/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6456e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0146e-04 - val_mean_absolute_error: 0.0070
# Epoch 73/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4382e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0959e-04 - val_mean_absolute_error: 0.0074
# Epoch 74/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4998e-04 - mean_absolute_error: 0.0086 - val_loss: 4.5926e-04 - val_mean_absolute_error: 0.0194
# Epoch 75/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5364e-04 - mean_absolute_error: 0.0086 - val_loss: 1.3387e-04 - val_mean_absolute_error: 0.0087
# Epoch 76/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4379e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2671e-04 - val_mean_absolute_error: 0.0080
# Epoch 77/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0681e-04 - mean_absolute_error: 0.0103 - val_loss: 1.0370e-04 - val_mean_absolute_error: 0.0071
# Epoch 78/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0299e-04 - mean_absolute_error: 0.0098 - val_loss: 1.8296e-04 - val_mean_absolute_error: 0.0106
# Epoch 79/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5176e-04 - mean_absolute_error: 0.0085 - val_loss: 1.1869e-04 - val_mean_absolute_error: 0.0077
# Epoch 80/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6476e-04 - mean_absolute_error: 0.0087 - val_loss: 1.7435e-04 - val_mean_absolute_error: 0.0102
# Epoch 81/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7171e-04 - mean_absolute_error: 0.0090 - val_loss: 1.0302e-04 - val_mean_absolute_error: 0.0070
# Epoch 82/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.4611e-04 - mean_absolute_error: 0.0082 - val_loss: 1.0992e-04 - val_mean_absolute_error: 0.0073
# Epoch 83/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4375e-04 - mean_absolute_error: 0.0081 - val_loss: 1.2124e-04 - val_mean_absolute_error: 0.0082
# Epoch 84/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.4856e-04 - mean_absolute_error: 0.0084 - val_loss: 1.1250e-04 - val_mean_absolute_error: 0.0073
# Epoch 85/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.6839e-04 - mean_absolute_error: 0.0089 - val_loss: 1.8250e-04 - val_mean_absolute_error: 0.0106
# Epoch 86/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6924e-04 - mean_absolute_error: 0.0091 - val_loss: 1.7931e-04 - val_mean_absolute_error: 0.0104
# Epoch 87/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6406e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0519e-04 - val_mean_absolute_error: 0.0071
# Epoch 88/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6709e-04 - mean_absolute_error: 0.0088 - val_loss: 1.0661e-04 - val_mean_absolute_error: 0.0072
# Epoch 89/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.6528e-04 - mean_absolute_error: 0.0090 - val_loss: 2.1426e-04 - val_mean_absolute_error: 0.0122
# Epoch 90/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7781e-04 - mean_absolute_error: 0.0094 - val_loss: 1.2614e-04 - val_mean_absolute_error: 0.0080
# Epoch 91/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.5239e-04 - mean_absolute_error: 0.0083 - val_loss: 1.0479e-04 - val_mean_absolute_error: 0.0071
# Epoch 92/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.2689e-04 - mean_absolute_error: 0.0077 - val_loss: 1.1173e-04 - val_mean_absolute_error: 0.0073
# Epoch 93/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4675e-04 - mean_absolute_error: 0.0082 - val_loss: 2.0778e-04 - val_mean_absolute_error: 0.0116
# Epoch 94/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8265e-04 - mean_absolute_error: 0.0094 - val_loss: 2.2952e-04 - val_mean_absolute_error: 0.0128
# Epoch 95/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.4292e-04 - mean_absolute_error: 0.0083 - val_loss: 1.0785e-04 - val_mean_absolute_error: 0.0072
# Epoch 96/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4277e-04 - mean_absolute_error: 0.0082 - val_loss: 1.0108e-04 - val_mean_absolute_error: 0.0070
# Epoch 97/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4304e-04 - mean_absolute_error: 0.0081 - val_loss: 1.4224e-04 - val_mean_absolute_error: 0.0091
# Epoch 98/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4524e-04 - mean_absolute_error: 0.0085 - val_loss: 2.4117e-04 - val_mean_absolute_error: 0.0129
# Epoch 99/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.6438e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0747e-04 - val_mean_absolute_error: 0.0072
# Epoch 100/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.3770e-04 - mean_absolute_error: 0.0079 - val_loss: 1.0734e-04 - val_mean_absolute_error: 0.0074
# Epoch 101/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3155e-04 - mean_absolute_error: 0.0079 - val_loss: 1.0168e-04 - val_mean_absolute_error: 0.0070
# Epoch 102/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5304e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0807e-04 - val_mean_absolute_error: 0.0075
# Epoch 103/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4933e-04 - mean_absolute_error: 0.0087 - val_loss: 1.6767e-04 - val_mean_absolute_error: 0.0099
# Epoch 104/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3955e-04 - mean_absolute_error: 0.0084 - val_loss: 3.4781e-04 - val_mean_absolute_error: 0.0167
# Epoch 105/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9338e-04 - mean_absolute_error: 0.0099 - val_loss: 1.3955e-04 - val_mean_absolute_error: 0.0087
# Epoch 106/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5176e-04 - mean_absolute_error: 0.0086 - val_loss: 1.5642e-04 - val_mean_absolute_error: 0.0098
# Epoch 107/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3317e-04 - mean_absolute_error: 0.0082 - val_loss: 1.4808e-04 - val_mean_absolute_error: 0.0094
# Epoch 108/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.3885e-04 - mean_absolute_error: 0.0082 - val_loss: 1.0809e-04 - val_mean_absolute_error: 0.0072
# Epoch 109/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5115e-04 - mean_absolute_error: 0.0083 - val_loss: 2.6820e-04 - val_mean_absolute_error: 0.0138
# Epoch 110/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8847e-04 - mean_absolute_error: 0.0097 - val_loss: 3.4148e-04 - val_mean_absolute_error: 0.0162
# Epoch 111/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4213e-04 - mean_absolute_error: 0.0085 - val_loss: 1.1012e-04 - val_mean_absolute_error: 0.0075
# Epoch 112/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4708e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2167e-04 - val_mean_absolute_error: 0.0081
# Epoch 113/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4366e-04 - mean_absolute_error: 0.0084 - val_loss: 1.5131e-04 - val_mean_absolute_error: 0.0092
# Epoch 114/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6981e-04 - mean_absolute_error: 0.0089 - val_loss: 2.7031e-04 - val_mean_absolute_error: 0.0142
# Epoch 115/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6885e-04 - mean_absolute_error: 0.0089 - val_loss: 1.3060e-04 - val_mean_absolute_error: 0.0082
# Epoch 116/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3505e-04 - mean_absolute_error: 0.0080 - val_loss: 1.7100e-04 - val_mean_absolute_error: 0.0101
# Epoch 117/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8560e-04 - mean_absolute_error: 0.0097 - val_loss: 1.8489e-04 - val_mean_absolute_error: 0.0110
# Epoch 118/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6389e-04 - mean_absolute_error: 0.0092 - val_loss: 2.6761e-04 - val_mean_absolute_error: 0.0138
# Epoch 119/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3832e-04 - mean_absolute_error: 0.0083 - val_loss: 1.1237e-04 - val_mean_absolute_error: 0.0076
# Epoch 120/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.4153e-04 - mean_absolute_error: 0.0083 - val_loss: 1.0667e-04 - val_mean_absolute_error: 0.0072
# Epoch 121/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.3454e-04 - mean_absolute_error: 0.0080 - val_loss: 1.2332e-04 - val_mean_absolute_error: 0.0079
# Epoch 122/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4741e-04 - mean_absolute_error: 0.0083 - val_loss: 1.3923e-04 - val_mean_absolute_error: 0.0086
# Epoch 123/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5445e-04 - mean_absolute_error: 0.0086 - val_loss: 1.9336e-04 - val_mean_absolute_error: 0.0114
# Epoch 124/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7052e-04 - mean_absolute_error: 0.0087 - val_loss: 2.3803e-04 - val_mean_absolute_error: 0.0128
# Epoch 125/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6182e-04 - mean_absolute_error: 0.0088 - val_loss: 2.5688e-04 - val_mean_absolute_error: 0.0138
# Epoch 126/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7498e-04 - mean_absolute_error: 0.0094 - val_loss: 2.1255e-04 - val_mean_absolute_error: 0.0118
# Epoch 127/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5794e-04 - mean_absolute_error: 0.0086 - val_loss: 1.1116e-04 - val_mean_absolute_error: 0.0076
# Epoch 128/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0865e-04 - mean_absolute_error: 0.0105 - val_loss: 2.5220e-04 - val_mean_absolute_error: 0.0133
# Epoch 129/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6489e-04 - mean_absolute_error: 0.0092 - val_loss: 1.0679e-04 - val_mean_absolute_error: 0.0072
# Epoch 130/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4422e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0354e-04 - val_mean_absolute_error: 0.0071
# Epoch 131/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5311e-04 - mean_absolute_error: 0.0086 - val_loss: 1.4290e-04 - val_mean_absolute_error: 0.0092
# Epoch 132/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8753e-04 - mean_absolute_error: 0.0101 - val_loss: 1.9790e-04 - val_mean_absolute_error: 0.0112
# Epoch 133/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5349e-04 - mean_absolute_error: 0.0087 - val_loss: 1.8786e-04 - val_mean_absolute_error: 0.0108
# Epoch 134/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5288e-04 - mean_absolute_error: 0.0088 - val_loss: 1.2582e-04 - val_mean_absolute_error: 0.0084
# Epoch 135/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7276e-04 - mean_absolute_error: 0.0091 - val_loss: 1.8414e-04 - val_mean_absolute_error: 0.0107
# Epoch 136/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5818e-04 - mean_absolute_error: 0.0088 - val_loss: 1.9653e-04 - val_mean_absolute_error: 0.0112
# Epoch 137/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7774e-04 - mean_absolute_error: 0.0093 - val_loss: 1.0115e-04 - val_mean_absolute_error: 0.0070
# Epoch 138/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5023e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2621e-04 - val_mean_absolute_error: 0.0080
# Epoch 139/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4527e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3147e-04 - val_mean_absolute_error: 0.0086
# Epoch 140/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3898e-04 - mean_absolute_error: 0.0082 - val_loss: 1.1514e-04 - val_mean_absolute_error: 0.0075
# Epoch 141/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5817e-04 - mean_absolute_error: 0.0087 - val_loss: 1.4240e-04 - val_mean_absolute_error: 0.0088
# Epoch 142/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4995e-04 - mean_absolute_error: 0.0082 - val_loss: 1.1800e-04 - val_mean_absolute_error: 0.0080
# Epoch 143/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6159e-04 - mean_absolute_error: 0.0091 - val_loss: 2.1031e-04 - val_mean_absolute_error: 0.0117
# Epoch 144/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5040e-04 - mean_absolute_error: 0.0088 - val_loss: 1.1632e-04 - val_mean_absolute_error: 0.0076
# Epoch 145/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.4942e-04 - mean_absolute_error: 0.0083 - val_loss: 1.0801e-04 - val_mean_absolute_error: 0.0074
# Epoch 146/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.8543e-04 - mean_absolute_error: 0.0097 - val_loss: 1.1919e-04 - val_mean_absolute_error: 0.0077
# Epoch 147/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.4495e-04 - mean_absolute_error: 0.0083 - val_loss: 3.1353e-04 - val_mean_absolute_error: 0.0153
# Epoch 148/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9881e-04 - mean_absolute_error: 0.0100 - val_loss: 1.3578e-04 - val_mean_absolute_error: 0.0085
# Epoch 149/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4352e-04 - mean_absolute_error: 0.0083 - val_loss: 1.0936e-04 - val_mean_absolute_error: 0.0073
# Epoch 150/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4405e-04 - mean_absolute_error: 0.0081 - val_loss: 1.0685e-04 - val_mean_absolute_error: 0.0072
# Epoch 151/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4873e-04 - mean_absolute_error: 0.0084 - val_loss: 2.0669e-04 - val_mean_absolute_error: 0.0119
# Epoch 152/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6234e-04 - mean_absolute_error: 0.0091 - val_loss: 1.0135e-04 - val_mean_absolute_error: 0.0070
# Epoch 153/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7896e-04 - mean_absolute_error: 0.0093 - val_loss: 2.4277e-04 - val_mean_absolute_error: 0.0132
# Epoch 154/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6176e-04 - mean_absolute_error: 0.0088 - val_loss: 3.0308e-04 - val_mean_absolute_error: 0.0150
# Epoch 155/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6419e-04 - mean_absolute_error: 0.0093 - val_loss: 1.0747e-04 - val_mean_absolute_error: 0.0074
# Epoch 156/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3191e-04 - mean_absolute_error: 0.0081 - val_loss: 1.0344e-04 - val_mean_absolute_error: 0.0071
# Epoch 157/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.4577e-04 - mean_absolute_error: 0.0082 - val_loss: 1.0755e-04 - val_mean_absolute_error: 0.0073
# Epoch 158/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5313e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2576e-04 - val_mean_absolute_error: 0.0083
# Epoch 159/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6735e-04 - mean_absolute_error: 0.0090 - val_loss: 1.2463e-04 - val_mean_absolute_error: 0.0083
# Epoch 160/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.5648e-04 - mean_absolute_error: 0.0088 - val_loss: 1.0527e-04 - val_mean_absolute_error: 0.0071
# Epoch 161/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4218e-04 - mean_absolute_error: 0.0082 - val_loss: 1.1380e-04 - val_mean_absolute_error: 0.0075
# Epoch 162/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4692e-04 - mean_absolute_error: 0.0084 - val_loss: 1.1847e-04 - val_mean_absolute_error: 0.0077
# Epoch 163/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.6630e-04 - mean_absolute_error: 0.0094 - val_loss: 1.1851e-04 - val_mean_absolute_error: 0.0080
# Epoch 164/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6191e-04 - mean_absolute_error: 0.0088 - val_loss: 1.1643e-04 - val_mean_absolute_error: 0.0076
# Epoch 165/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5107e-04 - mean_absolute_error: 0.0087 - val_loss: 5.1622e-04 - val_mean_absolute_error: 0.0208
# Epoch 166/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0613e-04 - mean_absolute_error: 0.0105 - val_loss: 3.1490e-04 - val_mean_absolute_error: 0.0153
# Epoch 167/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5764e-04 - mean_absolute_error: 0.0093 - val_loss: 1.4890e-04 - val_mean_absolute_error: 0.0091
# Epoch 168/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6335e-04 - mean_absolute_error: 0.0088 - val_loss: 1.1233e-04 - val_mean_absolute_error: 0.0074
# Epoch 169/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5308e-04 - mean_absolute_error: 0.0086 - val_loss: 1.4229e-04 - val_mean_absolute_error: 0.0088
# Epoch 170/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6623e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0512e-04 - val_mean_absolute_error: 0.0071
# Epoch 171/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8127e-04 - mean_absolute_error: 0.0091 - val_loss: 1.0736e-04 - val_mean_absolute_error: 0.0072
# Epoch 172/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5706e-04 - mean_absolute_error: 0.0088 - val_loss: 1.4848e-04 - val_mean_absolute_error: 0.0091
# Epoch 173/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.6652e-04 - mean_absolute_error: 0.0090 - val_loss: 1.2889e-04 - val_mean_absolute_error: 0.0082
# Epoch 174/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4597e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0336e-04 - val_mean_absolute_error: 0.0071
# Epoch 175/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6907e-04 - mean_absolute_error: 0.0091 - val_loss: 1.4601e-04 - val_mean_absolute_error: 0.0090
# Epoch 176/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6581e-04 - mean_absolute_error: 0.0089 - val_loss: 1.5921e-04 - val_mean_absolute_error: 0.0096
# Epoch 177/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6868e-04 - mean_absolute_error: 0.0088 - val_loss: 1.1590e-04 - val_mean_absolute_error: 0.0076
# Epoch 178/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3605e-04 - mean_absolute_error: 0.0079 - val_loss: 1.4216e-04 - val_mean_absolute_error: 0.0088
# Epoch 179/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5980e-04 - mean_absolute_error: 0.0089 - val_loss: 1.4726e-04 - val_mean_absolute_error: 0.0090
# Epoch 180/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5508e-04 - mean_absolute_error: 0.0086 - val_loss: 1.4034e-04 - val_mean_absolute_error: 0.0087
# Epoch 181/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.5786e-04 - mean_absolute_error: 0.0086 - val_loss: 1.7546e-04 - val_mean_absolute_error: 0.0103
# Epoch 182/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5703e-04 - mean_absolute_error: 0.0087 - val_loss: 1.4920e-04 - val_mean_absolute_error: 0.0091
# Epoch 183/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4376e-04 - mean_absolute_error: 0.0082 - val_loss: 1.8129e-04 - val_mean_absolute_error: 0.0109
# Epoch 184/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4808e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2948e-04 - val_mean_absolute_error: 0.0082
# Epoch 185/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4695e-04 - mean_absolute_error: 0.0082 - val_loss: 1.5515e-04 - val_mean_absolute_error: 0.0098
# Epoch 186/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5196e-04 - mean_absolute_error: 0.0088 - val_loss: 1.0537e-04 - val_mean_absolute_error: 0.0071
# Epoch 187/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5838e-04 - mean_absolute_error: 0.0087 - val_loss: 1.4255e-04 - val_mean_absolute_error: 0.0091
# Epoch 188/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5591e-04 - mean_absolute_error: 0.0088 - val_loss: 3.8867e-04 - val_mean_absolute_error: 0.0175
# Epoch 189/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0810e-04 - mean_absolute_error: 0.0101 - val_loss: 3.1152e-04 - val_mean_absolute_error: 0.0152
# Epoch 190/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5121e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0579e-04 - val_mean_absolute_error: 0.0072
# Epoch 191/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5083e-04 - mean_absolute_error: 0.0082 - val_loss: 1.1504e-04 - val_mean_absolute_error: 0.0076
# Epoch 192/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5017e-04 - mean_absolute_error: 0.0083 - val_loss: 1.9902e-04 - val_mean_absolute_error: 0.0113
# Epoch 193/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7727e-04 - mean_absolute_error: 0.0094 - val_loss: 1.2093e-04 - val_mean_absolute_error: 0.0078
# Epoch 194/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5029e-04 - mean_absolute_error: 0.0084 - val_loss: 1.4462e-04 - val_mean_absolute_error: 0.0089
# Epoch 195/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3954e-04 - mean_absolute_error: 0.0080 - val_loss: 1.3406e-04 - val_mean_absolute_error: 0.0088
# Epoch 196/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7832e-04 - mean_absolute_error: 0.0093 - val_loss: 1.3202e-04 - val_mean_absolute_error: 0.0086
# Epoch 197/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9852e-04 - mean_absolute_error: 0.0099 - val_loss: 2.6037e-04 - val_mean_absolute_error: 0.0136
# Epoch 198/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7413e-04 - mean_absolute_error: 0.0094 - val_loss: 1.2906e-04 - val_mean_absolute_error: 0.0085
# Epoch 199/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3131e-04 - mean_absolute_error: 0.0080 - val_loss: 3.1742e-04 - val_mean_absolute_error: 0.0154
# Epoch 200/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5919e-04 - mean_absolute_error: 0.0088 - val_loss: 1.9576e-04 - val_mean_absolute_error: 0.0111

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 120
# 131

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 839317.9243184725
# RMSE: 916.1429606335861
# MAE: 707.9215657552083
# MAPE: 1.913374740867347 %
#
# Model evalution on validate set
# MSE: 4593918.666631399
# RMSE: 2143.342871924928
# MAE: 1437.5788029442149
# MAPE: 3.0455709159888467 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 960ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step

# %%
y_pred_30_days
# Out:
# array([[60614.582],
#        [60368.793],
#        [60566.164],
#        [60506.055],
#        [60526.85 ],
#        [60517.54 ],
#        [60520.152],
#        [60519.047],
#        [60519.426],
#        [60519.297],
#        [60519.355],
#        [60519.324],
#        [60519.336],
#        [60519.336],
#        [60519.33 ],
#        [60519.324],
#        [60519.33 ],
#        [60519.324],
#        [60519.33 ],
#        [60519.316],
#        [60519.324],
#        [60519.324],
#        [60519.324],
#        [60519.33 ],
#        [60519.33 ],
#        [60519.324],
#        [60519.316],
#        [60519.324],
#        [60519.316],
#        [60519.324],
#        [60519.33 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Predict the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
