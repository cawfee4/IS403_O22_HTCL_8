# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: CMG - Test/Train/Vaildation: 80/10/10
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 773.2636565917938
# - MAE: 569.712451171875
# - MAPE: 1.546152114025919 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 2  # 8 1 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((1039, 10), (1039,), (120, 10), (120,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_1 (SimpleRNN)        │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 0.0159 - mean_absolute_error: 0.0882 - val_loss: 0.0014 - val_mean_absolute_error: 0.0309
# Epoch 2/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0010 - mean_absolute_error: 0.0233 - val_loss: 3.9187e-04 - val_mean_absolute_error: 0.0147
# Epoch 3/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.7003e-04 - mean_absolute_error: 0.0174 - val_loss: 5.6178e-04 - val_mean_absolute_error: 0.0200
# Epoch 4/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 4.3671e-04 - mean_absolute_error: 0.0148 - val_loss: 2.5528e-04 - val_mean_absolute_error: 0.0119
# Epoch 5/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.6246e-04 - mean_absolute_error: 0.0132 - val_loss: 3.7608e-04 - val_mean_absolute_error: 0.0156
# Epoch 6/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5048e-04 - mean_absolute_error: 0.0129 - val_loss: 1.8802e-04 - val_mean_absolute_error: 0.0103
# Epoch 7/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8585e-04 - mean_absolute_error: 0.0118 - val_loss: 1.7964e-04 - val_mean_absolute_error: 0.0096
# Epoch 8/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7229e-04 - mean_absolute_error: 0.0112 - val_loss: 3.1003e-04 - val_mean_absolute_error: 0.0139
# Epoch 9/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8666e-04 - mean_absolute_error: 0.0116 - val_loss: 3.8414e-04 - val_mean_absolute_error: 0.0162
# Epoch 10/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4436e-04 - mean_absolute_error: 0.0110 - val_loss: 2.6322e-04 - val_mean_absolute_error: 0.0133
# Epoch 11/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6265e-04 - mean_absolute_error: 0.0113 - val_loss: 5.4602e-04 - val_mean_absolute_error: 0.0204
# Epoch 12/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1389e-04 - mean_absolute_error: 0.0102 - val_loss: 4.6525e-04 - val_mean_absolute_error: 0.0185
# Epoch 13/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2027e-04 - mean_absolute_error: 0.0104 - val_loss: 4.0208e-04 - val_mean_absolute_error: 0.0169
# Epoch 14/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5574e-04 - mean_absolute_error: 0.0111 - val_loss: 4.6761e-04 - val_mean_absolute_error: 0.0187
# Epoch 15/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3636e-04 - mean_absolute_error: 0.0107 - val_loss: 1.8721e-04 - val_mean_absolute_error: 0.0101
# Epoch 16/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0230e-04 - mean_absolute_error: 0.0099 - val_loss: 1.7971e-04 - val_mean_absolute_error: 0.0099
# Epoch 17/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9812e-04 - mean_absolute_error: 0.0097 - val_loss: 1.3543e-04 - val_mean_absolute_error: 0.0083
# Epoch 18/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2510e-04 - mean_absolute_error: 0.0101 - val_loss: 5.8339e-04 - val_mean_absolute_error: 0.0217
# Epoch 19/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5238e-04 - mean_absolute_error: 0.0109 - val_loss: 1.3196e-04 - val_mean_absolute_error: 0.0081
# Epoch 20/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2094e-04 - mean_absolute_error: 0.0106 - val_loss: 1.4568e-04 - val_mean_absolute_error: 0.0088
# Epoch 21/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2476e-04 - mean_absolute_error: 0.0104 - val_loss: 1.9554e-04 - val_mean_absolute_error: 0.0107
# Epoch 22/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0684e-04 - mean_absolute_error: 0.0102 - val_loss: 4.2432e-04 - val_mean_absolute_error: 0.0180
# Epoch 23/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1514e-04 - mean_absolute_error: 0.0106 - val_loss: 1.8478e-04 - val_mean_absolute_error: 0.0107
# Epoch 24/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1274e-04 - mean_absolute_error: 0.0104 - val_loss: 2.8817e-04 - val_mean_absolute_error: 0.0145
# Epoch 25/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2823e-04 - mean_absolute_error: 0.0107 - val_loss: 1.2726e-04 - val_mean_absolute_error: 0.0080
# Epoch 26/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2606e-04 - mean_absolute_error: 0.0103 - val_loss: 5.5771e-04 - val_mean_absolute_error: 0.0214
# Epoch 27/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2121e-04 - mean_absolute_error: 0.0103 - val_loss: 1.9338e-04 - val_mean_absolute_error: 0.0111
# Epoch 28/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0370e-04 - mean_absolute_error: 0.0100 - val_loss: 2.1961e-04 - val_mean_absolute_error: 0.0117
# Epoch 29/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8196e-04 - mean_absolute_error: 0.0094 - val_loss: 2.3594e-04 - val_mean_absolute_error: 0.0123
# Epoch 30/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0184e-04 - mean_absolute_error: 0.0097 - val_loss: 1.7924e-04 - val_mean_absolute_error: 0.0101
# Epoch 31/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7012e-04 - mean_absolute_error: 0.0092 - val_loss: 1.4525e-04 - val_mean_absolute_error: 0.0088
# Epoch 32/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9938e-04 - mean_absolute_error: 0.0096 - val_loss: 1.7534e-04 - val_mean_absolute_error: 0.0104
# Epoch 33/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9777e-04 - mean_absolute_error: 0.0098 - val_loss: 1.1460e-04 - val_mean_absolute_error: 0.0075
# Epoch 34/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7244e-04 - mean_absolute_error: 0.0090 - val_loss: 1.6319e-04 - val_mean_absolute_error: 0.0095
# Epoch 35/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8788e-04 - mean_absolute_error: 0.0094 - val_loss: 1.4460e-04 - val_mean_absolute_error: 0.0088
# Epoch 36/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6982e-04 - mean_absolute_error: 0.0090 - val_loss: 1.1079e-04 - val_mean_absolute_error: 0.0072
# Epoch 37/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8779e-04 - mean_absolute_error: 0.0093 - val_loss: 3.3373e-04 - val_mean_absolute_error: 0.0158
# Epoch 38/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6896e-04 - mean_absolute_error: 0.0089 - val_loss: 1.3096e-04 - val_mean_absolute_error: 0.0084
# Epoch 39/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5785e-04 - mean_absolute_error: 0.0085 - val_loss: 1.1160e-04 - val_mean_absolute_error: 0.0073
# Epoch 40/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9002e-04 - mean_absolute_error: 0.0096 - val_loss: 2.0331e-04 - val_mean_absolute_error: 0.0113
# Epoch 41/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6309e-04 - mean_absolute_error: 0.0086 - val_loss: 7.3768e-04 - val_mean_absolute_error: 0.0254
# Epoch 42/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5197e-04 - mean_absolute_error: 0.0113 - val_loss: 1.8167e-04 - val_mean_absolute_error: 0.0108
# Epoch 43/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8284e-04 - mean_absolute_error: 0.0094 - val_loss: 1.3585e-04 - val_mean_absolute_error: 0.0084
# Epoch 44/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6015e-04 - mean_absolute_error: 0.0087 - val_loss: 1.1493e-04 - val_mean_absolute_error: 0.0075
# Epoch 45/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6302e-04 - mean_absolute_error: 0.0086 - val_loss: 1.7959e-04 - val_mean_absolute_error: 0.0107
# Epoch 46/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5865e-04 - mean_absolute_error: 0.0086 - val_loss: 1.2176e-04 - val_mean_absolute_error: 0.0078
# Epoch 47/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6202e-04 - mean_absolute_error: 0.0091 - val_loss: 1.0678e-04 - val_mean_absolute_error: 0.0071
# Epoch 48/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 1.7695e-04 - mean_absolute_error: 0.0092 - val_loss: 2.1024e-04 - val_mean_absolute_error: 0.0121
# Epoch 49/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7608e-04 - mean_absolute_error: 0.0094 - val_loss: 1.3674e-04 - val_mean_absolute_error: 0.0085
# Epoch 50/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7111e-04 - mean_absolute_error: 0.0089 - val_loss: 2.6025e-04 - val_mean_absolute_error: 0.0136
# Epoch 51/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7345e-04 - mean_absolute_error: 0.0092 - val_loss: 1.1738e-04 - val_mean_absolute_error: 0.0077
# Epoch 52/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7162e-04 - mean_absolute_error: 0.0089 - val_loss: 4.0369e-04 - val_mean_absolute_error: 0.0180
# Epoch 53/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6841e-04 - mean_absolute_error: 0.0087 - val_loss: 3.2975e-04 - val_mean_absolute_error: 0.0159
# Epoch 54/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8095e-04 - mean_absolute_error: 0.0094 - val_loss: 1.0776e-04 - val_mean_absolute_error: 0.0072
# Epoch 55/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5106e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3296e-04 - val_mean_absolute_error: 0.0083
# Epoch 56/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6001e-04 - mean_absolute_error: 0.0087 - val_loss: 2.1048e-04 - val_mean_absolute_error: 0.0121
# Epoch 57/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6949e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0808e-04 - val_mean_absolute_error: 0.0073
# Epoch 58/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6531e-04 - mean_absolute_error: 0.0089 - val_loss: 1.4545e-04 - val_mean_absolute_error: 0.0089
# Epoch 59/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6335e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0210e-04 - val_mean_absolute_error: 0.0070
# Epoch 60/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6038e-04 - mean_absolute_error: 0.0087 - val_loss: 1.4137e-04 - val_mean_absolute_error: 0.0090
# Epoch 61/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6241e-04 - mean_absolute_error: 0.0087 - val_loss: 2.7824e-04 - val_mean_absolute_error: 0.0142
# Epoch 62/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5738e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0777e-04 - val_mean_absolute_error: 0.0072
# Epoch 63/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4631e-04 - mean_absolute_error: 0.0082 - val_loss: 1.1838e-04 - val_mean_absolute_error: 0.0076
# Epoch 64/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5245e-04 - mean_absolute_error: 0.0084 - val_loss: 1.8721e-04 - val_mean_absolute_error: 0.0108
# Epoch 65/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.4482e-04 - mean_absolute_error: 0.0083 - val_loss: 1.9490e-04 - val_mean_absolute_error: 0.0111
# Epoch 66/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5917e-04 - mean_absolute_error: 0.0088 - val_loss: 1.1892e-04 - val_mean_absolute_error: 0.0077
# Epoch 67/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5925e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0729e-04 - val_mean_absolute_error: 0.0071
# Epoch 68/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.4136e-04 - mean_absolute_error: 0.0082 - val_loss: 1.0741e-04 - val_mean_absolute_error: 0.0072
# Epoch 69/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4707e-04 - mean_absolute_error: 0.0085 - val_loss: 1.6082e-04 - val_mean_absolute_error: 0.0096
# Epoch 70/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5052e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0393e-04 - val_mean_absolute_error: 0.0070
# Epoch 71/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.4823e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0013e-04 - val_mean_absolute_error: 0.0069
# Epoch 72/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5698e-04 - mean_absolute_error: 0.0087 - val_loss: 1.0568e-04 - val_mean_absolute_error: 0.0072
# Epoch 73/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.5350e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0341e-04 - val_mean_absolute_error: 0.0070
# Epoch 74/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.5277e-04 - mean_absolute_error: 0.0083 - val_loss: 2.7712e-04 - val_mean_absolute_error: 0.0145
# Epoch 75/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0423e-04 - mean_absolute_error: 0.0100 - val_loss: 1.0241e-04 - val_mean_absolute_error: 0.0070
# Epoch 76/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.4916e-04 - mean_absolute_error: 0.0084 - val_loss: 1.7134e-04 - val_mean_absolute_error: 0.0101
# Epoch 77/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7007e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0636e-04 - val_mean_absolute_error: 0.0072
# Epoch 78/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5227e-04 - mean_absolute_error: 0.0085 - val_loss: 1.1118e-04 - val_mean_absolute_error: 0.0073
# Epoch 79/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4276e-04 - mean_absolute_error: 0.0081 - val_loss: 1.7627e-04 - val_mean_absolute_error: 0.0103
# Epoch 80/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4978e-04 - mean_absolute_error: 0.0085 - val_loss: 2.0231e-04 - val_mean_absolute_error: 0.0114
# Epoch 81/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5680e-04 - mean_absolute_error: 0.0086 - val_loss: 1.9201e-04 - val_mean_absolute_error: 0.0113
# Epoch 82/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7537e-04 - mean_absolute_error: 0.0093 - val_loss: 1.9184e-04 - val_mean_absolute_error: 0.0110
# Epoch 83/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5371e-04 - mean_absolute_error: 0.0086 - val_loss: 1.1198e-04 - val_mean_absolute_error: 0.0076
# Epoch 84/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7412e-04 - mean_absolute_error: 0.0094 - val_loss: 1.0313e-04 - val_mean_absolute_error: 0.0071
# Epoch 85/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5563e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0233e-04 - val_mean_absolute_error: 0.0070
# Epoch 86/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4519e-04 - mean_absolute_error: 0.0082 - val_loss: 1.3488e-04 - val_mean_absolute_error: 0.0087
# Epoch 87/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6309e-04 - mean_absolute_error: 0.0087 - val_loss: 1.0064e-04 - val_mean_absolute_error: 0.0070
# Epoch 88/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6269e-04 - mean_absolute_error: 0.0087 - val_loss: 1.3953e-04 - val_mean_absolute_error: 0.0087
# Epoch 89/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4438e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0385e-04 - val_mean_absolute_error: 0.0071
# Epoch 90/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.5391e-04 - mean_absolute_error: 0.0086 - val_loss: 1.3354e-04 - val_mean_absolute_error: 0.0084
# Epoch 91/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6232e-04 - mean_absolute_error: 0.0091 - val_loss: 1.1171e-04 - val_mean_absolute_error: 0.0074
# Epoch 92/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5521e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0560e-04 - val_mean_absolute_error: 0.0072
# Epoch 93/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4550e-04 - mean_absolute_error: 0.0082 - val_loss: 1.0184e-04 - val_mean_absolute_error: 0.0070
# Epoch 94/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 1.4080e-04 - mean_absolute_error: 0.0081 - val_loss: 1.6968e-04 - val_mean_absolute_error: 0.0104
# Epoch 95/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7055e-04 - mean_absolute_error: 0.0089 - val_loss: 1.1324e-04 - val_mean_absolute_error: 0.0076
# Epoch 96/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4154e-04 - mean_absolute_error: 0.0082 - val_loss: 1.0159e-04 - val_mean_absolute_error: 0.0070
# Epoch 97/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3277e-04 - mean_absolute_error: 0.0079 - val_loss: 1.0482e-04 - val_mean_absolute_error: 0.0071
# Epoch 98/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6780e-04 - mean_absolute_error: 0.0090 - val_loss: 1.5845e-04 - val_mean_absolute_error: 0.0099
# Epoch 99/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5088e-04 - mean_absolute_error: 0.0089 - val_loss: 2.0794e-04 - val_mean_absolute_error: 0.0116
# Epoch 100/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4457e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0185e-04 - val_mean_absolute_error: 0.0070
# Epoch 101/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.4780e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0297e-04 - val_mean_absolute_error: 0.0070
# Epoch 102/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4088e-04 - mean_absolute_error: 0.0082 - val_loss: 1.4009e-04 - val_mean_absolute_error: 0.0090
# Epoch 103/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5636e-04 - mean_absolute_error: 0.0090 - val_loss: 2.6520e-04 - val_mean_absolute_error: 0.0138
# Epoch 104/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3380e-04 - mean_absolute_error: 0.0084 - val_loss: 1.1151e-04 - val_mean_absolute_error: 0.0076
# Epoch 105/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.3826e-04 - mean_absolute_error: 0.0083 - val_loss: 1.0165e-04 - val_mean_absolute_error: 0.0070
# Epoch 106/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.5511e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0512e-04 - val_mean_absolute_error: 0.0071
# Epoch 107/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4779e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0476e-04 - val_mean_absolute_error: 0.0072
# Epoch 108/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4943e-04 - mean_absolute_error: 0.0085 - val_loss: 1.7124e-04 - val_mean_absolute_error: 0.0101
# Epoch 109/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.7620e-04 - mean_absolute_error: 0.0093 - val_loss: 1.1041e-04 - val_mean_absolute_error: 0.0075
# Epoch 110/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3560e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2197e-04 - val_mean_absolute_error: 0.0079
# Epoch 111/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3446e-04 - mean_absolute_error: 0.0080 - val_loss: 1.0056e-04 - val_mean_absolute_error: 0.0070
# Epoch 112/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5176e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0827e-04 - val_mean_absolute_error: 0.0074
# Epoch 113/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9447e-04 - mean_absolute_error: 0.0101 - val_loss: 1.9258e-04 - val_mean_absolute_error: 0.0113
# Epoch 114/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6886e-04 - mean_absolute_error: 0.0092 - val_loss: 1.1490e-04 - val_mean_absolute_error: 0.0075
# Epoch 115/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5536e-04 - mean_absolute_error: 0.0088 - val_loss: 1.0353e-04 - val_mean_absolute_error: 0.0070
# Epoch 116/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6070e-04 - mean_absolute_error: 0.0090 - val_loss: 1.0717e-04 - val_mean_absolute_error: 0.0072
# Epoch 117/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3319e-04 - mean_absolute_error: 0.0081 - val_loss: 1.0329e-04 - val_mean_absolute_error: 0.0070
# Epoch 118/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4825e-04 - mean_absolute_error: 0.0084 - val_loss: 3.9252e-04 - val_mean_absolute_error: 0.0180
# Epoch 119/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.8510e-04 - mean_absolute_error: 0.0099 - val_loss: 1.3689e-04 - val_mean_absolute_error: 0.0086
# Epoch 120/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5216e-04 - mean_absolute_error: 0.0087 - val_loss: 1.1995e-04 - val_mean_absolute_error: 0.0078
# Epoch 121/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5801e-04 - mean_absolute_error: 0.0088 - val_loss: 2.6950e-04 - val_mean_absolute_error: 0.0138
# Epoch 122/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6814e-04 - mean_absolute_error: 0.0092 - val_loss: 1.5698e-04 - val_mean_absolute_error: 0.0095
# Epoch 123/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7017e-04 - mean_absolute_error: 0.0089 - val_loss: 1.7822e-04 - val_mean_absolute_error: 0.0104
# Epoch 124/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4822e-04 - mean_absolute_error: 0.0083 - val_loss: 2.0989e-04 - val_mean_absolute_error: 0.0117
# Epoch 125/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7532e-04 - mean_absolute_error: 0.0091 - val_loss: 1.4033e-04 - val_mean_absolute_error: 0.0087
# Epoch 126/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3911e-04 - mean_absolute_error: 0.0081 - val_loss: 1.0154e-04 - val_mean_absolute_error: 0.0070
# Epoch 127/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5174e-04 - mean_absolute_error: 0.0085 - val_loss: 1.9813e-04 - val_mean_absolute_error: 0.0112
# Epoch 128/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5253e-04 - mean_absolute_error: 0.0085 - val_loss: 2.0294e-04 - val_mean_absolute_error: 0.0114
# Epoch 129/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7624e-04 - mean_absolute_error: 0.0095 - val_loss: 1.0593e-04 - val_mean_absolute_error: 0.0072
# Epoch 130/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5313e-04 - mean_absolute_error: 0.0084 - val_loss: 1.0652e-04 - val_mean_absolute_error: 0.0071
# Epoch 131/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4997e-04 - mean_absolute_error: 0.0084 - val_loss: 1.1194e-04 - val_mean_absolute_error: 0.0076
# Epoch 132/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3435e-04 - mean_absolute_error: 0.0082 - val_loss: 1.8367e-04 - val_mean_absolute_error: 0.0106
# Epoch 133/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6540e-04 - mean_absolute_error: 0.0090 - val_loss: 1.1423e-04 - val_mean_absolute_error: 0.0077
# Epoch 134/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.6473e-04 - mean_absolute_error: 0.0087 - val_loss: 2.9323e-04 - val_mean_absolute_error: 0.0146
# Epoch 135/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9089e-04 - mean_absolute_error: 0.0101 - val_loss: 1.0424e-04 - val_mean_absolute_error: 0.0071
# Epoch 136/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6569e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0281e-04 - val_mean_absolute_error: 0.0070
# Epoch 137/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4989e-04 - mean_absolute_error: 0.0085 - val_loss: 1.6920e-04 - val_mean_absolute_error: 0.0100
# Epoch 138/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.9404e-04 - mean_absolute_error: 0.0101 - val_loss: 2.2066e-04 - val_mean_absolute_error: 0.0121
# Epoch 139/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5823e-04 - mean_absolute_error: 0.0086 - val_loss: 1.3019e-04 - val_mean_absolute_error: 0.0083
# Epoch 140/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5438e-04 - mean_absolute_error: 0.0087 - val_loss: 1.0629e-04 - val_mean_absolute_error: 0.0071
# Epoch 141/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2744e-04 - mean_absolute_error: 0.0078 - val_loss: 1.1713e-04 - val_mean_absolute_error: 0.0077
# Epoch 142/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3250e-04 - mean_absolute_error: 0.0081 - val_loss: 1.0617e-04 - val_mean_absolute_error: 0.0073
# Epoch 143/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.6846e-04 - mean_absolute_error: 0.0091 - val_loss: 1.0895e-04 - val_mean_absolute_error: 0.0074
# Epoch 144/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.4546e-04 - mean_absolute_error: 0.0083 - val_loss: 1.0847e-04 - val_mean_absolute_error: 0.0074
# Epoch 145/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4489e-04 - mean_absolute_error: 0.0083 - val_loss: 1.4511e-04 - val_mean_absolute_error: 0.0093
# Epoch 146/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.5373e-04 - mean_absolute_error: 0.0086 - val_loss: 1.0232e-04 - val_mean_absolute_error: 0.0070
# Epoch 147/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4601e-04 - mean_absolute_error: 0.0081 - val_loss: 1.0700e-04 - val_mean_absolute_error: 0.0072
# Epoch 148/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5088e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0152e-04 - val_mean_absolute_error: 0.0070
# Epoch 149/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.4465e-04 - mean_absolute_error: 0.0085 - val_loss: 1.8099e-04 - val_mean_absolute_error: 0.0108
# Epoch 150/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7042e-04 - mean_absolute_error: 0.0092 - val_loss: 1.0985e-04 - val_mean_absolute_error: 0.0073
# Epoch 151/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4890e-04 - mean_absolute_error: 0.0082 - val_loss: 1.3472e-04 - val_mean_absolute_error: 0.0087
# Epoch 152/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4134e-04 - mean_absolute_error: 0.0082 - val_loss: 1.0992e-04 - val_mean_absolute_error: 0.0074
# Epoch 153/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4868e-04 - mean_absolute_error: 0.0085 - val_loss: 1.2472e-04 - val_mean_absolute_error: 0.0080
# Epoch 154/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4957e-04 - mean_absolute_error: 0.0088 - val_loss: 1.4218e-04 - val_mean_absolute_error: 0.0088
# Epoch 155/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4348e-04 - mean_absolute_error: 0.0083 - val_loss: 1.0609e-04 - val_mean_absolute_error: 0.0073
# Epoch 156/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.4458e-04 - mean_absolute_error: 0.0083 - val_loss: 1.1449e-04 - val_mean_absolute_error: 0.0078
# Epoch 157/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5483e-04 - mean_absolute_error: 0.0087 - val_loss: 1.5721e-04 - val_mean_absolute_error: 0.0098
# Epoch 158/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7183e-04 - mean_absolute_error: 0.0092 - val_loss: 1.1647e-04 - val_mean_absolute_error: 0.0079
# Epoch 159/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6315e-04 - mean_absolute_error: 0.0090 - val_loss: 1.0445e-04 - val_mean_absolute_error: 0.0071
# Epoch 160/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4654e-04 - mean_absolute_error: 0.0082 - val_loss: 1.2559e-04 - val_mean_absolute_error: 0.0080
# Epoch 161/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2023e-04 - mean_absolute_error: 0.0075 - val_loss: 3.0397e-04 - val_mean_absolute_error: 0.0153
# Epoch 162/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7110e-04 - mean_absolute_error: 0.0093 - val_loss: 1.2175e-04 - val_mean_absolute_error: 0.0079
# Epoch 163/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6067e-04 - mean_absolute_error: 0.0084 - val_loss: 1.5444e-04 - val_mean_absolute_error: 0.0094
# Epoch 164/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6239e-04 - mean_absolute_error: 0.0088 - val_loss: 1.0400e-04 - val_mean_absolute_error: 0.0070
# Epoch 165/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4216e-04 - mean_absolute_error: 0.0081 - val_loss: 1.1119e-04 - val_mean_absolute_error: 0.0074
# Epoch 166/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4626e-04 - mean_absolute_error: 0.0085 - val_loss: 1.8502e-04 - val_mean_absolute_error: 0.0107
# Epoch 167/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6925e-04 - mean_absolute_error: 0.0092 - val_loss: 1.1268e-04 - val_mean_absolute_error: 0.0076
# Epoch 168/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3933e-04 - mean_absolute_error: 0.0082 - val_loss: 1.0575e-04 - val_mean_absolute_error: 0.0071
# Epoch 169/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6742e-04 - mean_absolute_error: 0.0090 - val_loss: 1.1694e-04 - val_mean_absolute_error: 0.0079
# Epoch 170/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5213e-04 - mean_absolute_error: 0.0085 - val_loss: 3.1347e-04 - val_mean_absolute_error: 0.0156
# Epoch 171/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1597e-04 - mean_absolute_error: 0.0104 - val_loss: 1.2640e-04 - val_mean_absolute_error: 0.0081
# Epoch 172/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.4884e-04 - mean_absolute_error: 0.0085 - val_loss: 1.9652e-04 - val_mean_absolute_error: 0.0112
# Epoch 173/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.5733e-04 - mean_absolute_error: 0.0087 - val_loss: 1.0390e-04 - val_mean_absolute_error: 0.0071
# Epoch 174/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3904e-04 - mean_absolute_error: 0.0081 - val_loss: 1.0262e-04 - val_mean_absolute_error: 0.0071
# Epoch 175/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4379e-04 - mean_absolute_error: 0.0083 - val_loss: 1.1770e-04 - val_mean_absolute_error: 0.0077
# Epoch 176/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.5036e-04 - mean_absolute_error: 0.0085 - val_loss: 1.0311e-04 - val_mean_absolute_error: 0.0070
# Epoch 177/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3605e-04 - mean_absolute_error: 0.0081 - val_loss: 1.4875e-04 - val_mean_absolute_error: 0.0091
# Epoch 178/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7269e-04 - mean_absolute_error: 0.0096 - val_loss: 1.0330e-04 - val_mean_absolute_error: 0.0070
# Epoch 179/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5981e-04 - mean_absolute_error: 0.0086 - val_loss: 2.5409e-04 - val_mean_absolute_error: 0.0133
# Epoch 180/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6124e-04 - mean_absolute_error: 0.0088 - val_loss: 1.0690e-04 - val_mean_absolute_error: 0.0073
# Epoch 181/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6168e-04 - mean_absolute_error: 0.0087 - val_loss: 1.2028e-04 - val_mean_absolute_error: 0.0078
# Epoch 182/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6691e-04 - mean_absolute_error: 0.0089 - val_loss: 1.2008e-04 - val_mean_absolute_error: 0.0077
# Epoch 183/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4289e-04 - mean_absolute_error: 0.0081 - val_loss: 1.5066e-04 - val_mean_absolute_error: 0.0096
# Epoch 184/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4268e-04 - mean_absolute_error: 0.0084 - val_loss: 3.0293e-04 - val_mean_absolute_error: 0.0153
# Epoch 185/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7256e-04 - mean_absolute_error: 0.0096 - val_loss: 1.0150e-04 - val_mean_absolute_error: 0.0070
# Epoch 186/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4360e-04 - mean_absolute_error: 0.0083 - val_loss: 1.0603e-04 - val_mean_absolute_error: 0.0071
# Epoch 187/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2921e-04 - mean_absolute_error: 0.0077 - val_loss: 1.6347e-04 - val_mean_absolute_error: 0.0101
# Epoch 188/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5991e-04 - mean_absolute_error: 0.0086 - val_loss: 1.5556e-04 - val_mean_absolute_error: 0.0094
# Epoch 189/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4443e-04 - mean_absolute_error: 0.0084 - val_loss: 1.4276e-04 - val_mean_absolute_error: 0.0088
# Epoch 190/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6173e-04 - mean_absolute_error: 0.0088 - val_loss: 2.0881e-04 - val_mean_absolute_error: 0.0116
# Epoch 191/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5787e-04 - mean_absolute_error: 0.0091 - val_loss: 2.0722e-04 - val_mean_absolute_error: 0.0119
# Epoch 192/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9104e-04 - mean_absolute_error: 0.0103 - val_loss: 1.0165e-04 - val_mean_absolute_error: 0.0070
# Epoch 193/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3806e-04 - mean_absolute_error: 0.0081 - val_loss: 1.0291e-04 - val_mean_absolute_error: 0.0070
# Epoch 194/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6150e-04 - mean_absolute_error: 0.0086 - val_loss: 1.4226e-04 - val_mean_absolute_error: 0.0091
# Epoch 195/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4367e-04 - mean_absolute_error: 0.0084 - val_loss: 1.6581e-04 - val_mean_absolute_error: 0.0099
# Epoch 196/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7490e-04 - mean_absolute_error: 0.0089 - val_loss: 1.0746e-04 - val_mean_absolute_error: 0.0072
# Epoch 197/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5202e-04 - mean_absolute_error: 0.0087 - val_loss: 1.7827e-04 - val_mean_absolute_error: 0.0107
# Epoch 198/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.6668e-04 - mean_absolute_error: 0.0088 - val_loss: 1.3440e-04 - val_mean_absolute_error: 0.0084
# Epoch 199/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4924e-04 - mean_absolute_error: 0.0084 - val_loss: 1.9578e-04 - val_mean_absolute_error: 0.0114
# Epoch 200/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5569e-04 - mean_absolute_error: 0.0089 - val_loss: 1.1749e-04 - val_mean_absolute_error: 0.0077

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 1/4 ━━━━━━━━━━━━━━━━━━━━ 1s 640ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 257ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 120
# 131

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 597936.6826057116
# RMSE: 773.2636565917938
# MAE: 569.712451171875
# MAPE: 1.546152114025919 %
#
# Model evalution on validate set
# MSE: 4103013.823837028
# RMSE: 2025.589747169211
# MAE: 1290.0480694731405
# MAPE: 2.7009691059732366 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 648ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step

# %%
y_pred_30_days
# Out:
# array([[61524.766],
#        [61298.395],
#        [61596.39 ],
#        [61405.863],
#        [61540.355],
#        [61479.992],
#        [61520.93 ],
#        [61497.086],
#        [61511.543],
#        [61503.27 ],
#        [61508.297],
#        [61505.324],
#        [61507.105],
#        [61506.055],
#        [61506.676],
#        [61506.305],
#        [61506.52 ],
#        [61506.406],
#        [61506.48 ],
#        [61506.438],
#        [61506.465],
#        [61506.438],
#        [61506.457],
#        [61506.445],
#        [61506.457],
#        [61506.445],
#        [61506.45 ],
#        [61506.45 ],
#        [61506.445],
#        [61506.45 ],
#        [61506.45 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Forecast Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Forecast the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
