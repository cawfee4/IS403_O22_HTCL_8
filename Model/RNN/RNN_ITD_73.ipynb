# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

plt.style.use('default')

# %% [markdown]
# ## 1. Data preprocessing

# %%
split_type = [0.8,0.7,0.9]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 1  # 70% train, 30% test

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        6900
# 1        7100
# 2        7100
# 3        7170
# 4        7170
#         ...
# 1308    11300
# 1309    12050
# 1310    12600
# 1311    12500
# 1312    12700
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using neural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split] * len(df_scaled))
test_size = len(df_scaled) - train_size

# %%
# Splitting data into train, test set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size:]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((908, 10), (908,), (383, 10), (383,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
UNITS = 64

# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(UNITS),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 64)             │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,289 (16.75 KB)
#  Trainable params: 4,289 (16.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0561 - mean_absolute_error: 0.1546
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0047 - mean_absolute_error: 0.0471
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0037 - mean_absolute_error: 0.0381
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0025 - mean_absolute_error: 0.0307
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0018 - mean_absolute_error: 0.0261
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0015 - mean_absolute_error: 0.0235
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0016 - mean_absolute_error: 0.0246
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013 - mean_absolute_error: 0.0229
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0014 - mean_absolute_error: 0.0235
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0012 - mean_absolute_error: 0.0232
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.2759e-04 - mean_absolute_error: 0.0190
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013 - mean_absolute_error: 0.0240
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0013 - mean_absolute_error: 0.0234
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0010 - mean_absolute_error: 0.0203
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0011 - mean_absolute_error: 0.0213
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.3815e-04 - mean_absolute_error: 0.0187
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.6321e-04 - mean_absolute_error: 0.0201
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0010 - mean_absolute_error: 0.0216
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.7368e-04 - mean_absolute_error: 0.0193
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 8.5423e-04 - mean_absolute_error: 0.0186
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.6935e-04 - mean_absolute_error: 0.0187
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.0821e-04 - mean_absolute_error: 0.0178
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.7004e-04 - mean_absolute_error: 0.0189
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.6278e-04 - mean_absolute_error: 0.0168
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.4078e-04 - mean_absolute_error: 0.0184
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.1949e-04 - mean_absolute_error: 0.0165
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.4349e-04 - mean_absolute_error: 0.0157
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.5517e-04 - mean_absolute_error: 0.0173
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.6280e-04 - mean_absolute_error: 0.0160
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.5938e-04 - mean_absolute_error: 0.0166
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.6732e-04 - mean_absolute_error: 0.0162
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.9311e-04 - mean_absolute_error: 0.0177
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.2195e-04 - mean_absolute_error: 0.0158
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.4797e-04 - mean_absolute_error: 0.0153
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.8154e-04 - mean_absolute_error: 0.0149
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.7079e-04 - mean_absolute_error: 0.0170
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.4921e-04 - mean_absolute_error: 0.0157
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.6013e-04 - mean_absolute_error: 0.0147
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.3745e-04 - mean_absolute_error: 0.0149
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.6521e-04 - mean_absolute_error: 0.0139
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.9721e-04 - mean_absolute_error: 0.0158
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9226e-04 - mean_absolute_error: 0.0141
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.3501e-04 - mean_absolute_error: 0.0184
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.0863e-04 - mean_absolute_error: 0.0195
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.7117e-04 - mean_absolute_error: 0.0165
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8483e-04 - mean_absolute_error: 0.0136
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 4.9682e-04 - mean_absolute_error: 0.0136
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5486e-04 - mean_absolute_error: 0.0133
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7088e-04 - mean_absolute_error: 0.0134
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.6927e-04 - mean_absolute_error: 0.0143
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.5085e-04 - mean_absolute_error: 0.0148
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2876e-04 - mean_absolute_error: 0.0134
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8767e-04 - mean_absolute_error: 0.0140
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - loss: 4.2753e-04 - mean_absolute_error: 0.0131
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7051e-04 - mean_absolute_error: 0.0136
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8833e-04 - mean_absolute_error: 0.0124
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9198e-04 - mean_absolute_error: 0.0125
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1397e-04 - mean_absolute_error: 0.0129
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9281e-04 - mean_absolute_error: 0.0126
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4268e-04 - mean_absolute_error: 0.0132
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - loss: 3.7017e-04 - mean_absolute_error: 0.0119
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - loss: 4.1861e-04 - mean_absolute_error: 0.0127
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 3.8095e-04 - mean_absolute_error: 0.0126
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4485e-04 - mean_absolute_error: 0.0132
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 4.3874e-04 - mean_absolute_error: 0.0131
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1889e-04 - mean_absolute_error: 0.0132
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 4.1895e-04 - mean_absolute_error: 0.0129
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7888e-04 - mean_absolute_error: 0.0140
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3162e-04 - mean_absolute_error: 0.0134
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8902e-04 - mean_absolute_error: 0.0124
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9549e-04 - mean_absolute_error: 0.0125
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0492e-04 - mean_absolute_error: 0.0133
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.0605e-04 - mean_absolute_error: 0.0150
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5557e-04 - mean_absolute_error: 0.0142
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6011e-04 - mean_absolute_error: 0.0128
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9817e-04 - mean_absolute_error: 0.0126
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8755e-04 - mean_absolute_error: 0.0128
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5216e-04 - mean_absolute_error: 0.0120
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3736e-04 - mean_absolute_error: 0.0135
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1873e-04 - mean_absolute_error: 0.0129
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1567e-04 - mean_absolute_error: 0.0129
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9318e-04 - mean_absolute_error: 0.0126
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9421e-04 - mean_absolute_error: 0.0134
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8437e-04 - mean_absolute_error: 0.0125
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8764e-04 - mean_absolute_error: 0.0133
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4258e-04 - mean_absolute_error: 0.0124
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4346e-04 - mean_absolute_error: 0.0122
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3040e-04 - mean_absolute_error: 0.0142
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5808e-04 - mean_absolute_error: 0.0140
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2244e-04 - mean_absolute_error: 0.0135
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6804e-04 - mean_absolute_error: 0.0127
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5155e-04 - mean_absolute_error: 0.0122
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5345e-04 - mean_absolute_error: 0.0123
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9315e-04 - mean_absolute_error: 0.0127
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8937e-04 - mean_absolute_error: 0.0129
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3864e-04 - mean_absolute_error: 0.0139
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8323e-04 - mean_absolute_error: 0.0139
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9368e-04 - mean_absolute_error: 0.0128
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4810e-04 - mean_absolute_error: 0.0142
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8094e-04 - mean_absolute_error: 0.0131
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.7655e-04 - mean_absolute_error: 0.0148
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5562e-04 - mean_absolute_error: 0.0137
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6718e-04 - mean_absolute_error: 0.0120
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3166e-04 - mean_absolute_error: 0.0121
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2822e-04 - mean_absolute_error: 0.0136
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7125e-04 - mean_absolute_error: 0.0125
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4068e-04 - mean_absolute_error: 0.0123
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3672e-04 - mean_absolute_error: 0.0119
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3954e-04 - mean_absolute_error: 0.0136
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8287e-04 - mean_absolute_error: 0.0127
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2715e-04 - mean_absolute_error: 0.0135
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8651e-04 - mean_absolute_error: 0.0129
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8836e-04 - mean_absolute_error: 0.0131
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2522e-04 - mean_absolute_error: 0.0134
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6969e-04 - mean_absolute_error: 0.0129
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1161e-04 - mean_absolute_error: 0.0131
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6517e-04 - mean_absolute_error: 0.0125
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4277e-04 - mean_absolute_error: 0.0120
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4834e-04 - mean_absolute_error: 0.0124
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8408e-04 - mean_absolute_error: 0.0127
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7819e-04 - mean_absolute_error: 0.0128
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0710e-04 - mean_absolute_error: 0.0135
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6665e-04 - mean_absolute_error: 0.0125
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5433e-04 - mean_absolute_error: 0.0125
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1169e-04 - mean_absolute_error: 0.0137
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8145e-04 - mean_absolute_error: 0.0127
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9538e-04 - mean_absolute_error: 0.0132
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9972e-04 - mean_absolute_error: 0.0132
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8082e-04 - mean_absolute_error: 0.0128
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9066e-04 - mean_absolute_error: 0.0143
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1647e-04 - mean_absolute_error: 0.0131
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8906e-04 - mean_absolute_error: 0.0126
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1670e-04 - mean_absolute_error: 0.0139
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6795e-04 - mean_absolute_error: 0.0125
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7967e-04 - mean_absolute_error: 0.0124
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6961e-04 - mean_absolute_error: 0.0128
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8001e-04 - mean_absolute_error: 0.0129
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1931e-04 - mean_absolute_error: 0.0137
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9284e-04 - mean_absolute_error: 0.0132
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2361e-04 - mean_absolute_error: 0.0124
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1019e-04 - mean_absolute_error: 0.0134
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4860e-04 - mean_absolute_error: 0.0117
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8901e-04 - mean_absolute_error: 0.0130
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3955e-04 - mean_absolute_error: 0.0118
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7473e-04 - mean_absolute_error: 0.0129
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4420e-04 - mean_absolute_error: 0.0123
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6316e-04 - mean_absolute_error: 0.0134
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4566e-04 - mean_absolute_error: 0.0124
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5494e-04 - mean_absolute_error: 0.0124
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3722e-04 - mean_absolute_error: 0.0145
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4934e-04 - mean_absolute_error: 0.0122
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4208e-04 - mean_absolute_error: 0.0136
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0025e-04 - mean_absolute_error: 0.0136
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8346e-04 - mean_absolute_error: 0.0127
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 985us/step - loss: 4.1644e-04 - mean_absolute_error: 0.0137
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1231e-04 - mean_absolute_error: 0.0137
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6974e-04 - mean_absolute_error: 0.0119
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8578e-04 - mean_absolute_error: 0.0132
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9774e-04 - mean_absolute_error: 0.0134
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7044e-04 - mean_absolute_error: 0.0127
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7691e-04 - mean_absolute_error: 0.0126
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4039e-04 - mean_absolute_error: 0.0122
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.8198e-04 - mean_absolute_error: 0.0147
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7521e-04 - mean_absolute_error: 0.0131
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8069e-04 - mean_absolute_error: 0.0128
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2492e-04 - mean_absolute_error: 0.0137
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3128e-04 - mean_absolute_error: 0.0134
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9621e-04 - mean_absolute_error: 0.0133
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6421e-04 - mean_absolute_error: 0.0132
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6683e-04 - mean_absolute_error: 0.0123
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5198e-04 - mean_absolute_error: 0.0123
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5044e-04 - mean_absolute_error: 0.0130
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6528e-04 - mean_absolute_error: 0.0128
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3830e-04 - mean_absolute_error: 0.0124
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4919e-04 - mean_absolute_error: 0.0123
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8321e-04 - mean_absolute_error: 0.0129
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1308e-04 - mean_absolute_error: 0.0139
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2391e-04 - mean_absolute_error: 0.0138
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8514e-04 - mean_absolute_error: 0.0135
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3747e-04 - mean_absolute_error: 0.0120
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7397e-04 - mean_absolute_error: 0.0128
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7381e-04 - mean_absolute_error: 0.0132
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8420e-04 - mean_absolute_error: 0.0133
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5660e-04 - mean_absolute_error: 0.0144
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4683e-04 - mean_absolute_error: 0.0143
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.6435e-04 - mean_absolute_error: 0.0160
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7159e-04 - mean_absolute_error: 0.0128
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4894e-04 - mean_absolute_error: 0.0121
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3109e-04 - mean_absolute_error: 0.0140
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8349e-04 - mean_absolute_error: 0.0142
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7973e-04 - mean_absolute_error: 0.0129
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0866e-04 - mean_absolute_error: 0.0133
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0265e-04 - mean_absolute_error: 0.0125
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9794e-04 - mean_absolute_error: 0.0133
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6977e-04 - mean_absolute_error: 0.0125
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2435e-04 - mean_absolute_error: 0.0137
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0333e-04 - mean_absolute_error: 0.0137
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6935e-04 - mean_absolute_error: 0.0130
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3705e-04 - mean_absolute_error: 0.0121
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9302e-04 - mean_absolute_error: 0.0131

# %% [markdown]
# ### Predicting with test set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test set again to evaluate, because i shaped the data between 0 to 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 383
# 394

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)
# Out:
# Model evalution on test set
# MSE: 103521.06841247946
# RMSE: 321.7469011699716
# MAE: 223.30500622144257
# MAPE: 2.0451580575289614 %

# %% [markdown]
# ## 4. Forecast the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(test_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
y_pred_30_days
# Out:
# array([[13053.569 ],
#        [12959.882 ],
#        [13095.933 ],
#        [13030.4   ],
#        [13112.462 ],
#        [13073.598 ],
#        [13105.779 ],
#        [13085.879 ],
#        [13102.458 ],
#        [13092.008 ],
#        [13099.711 ],
#        [13094.52  ],
#        [13098.355 ],
#        [13095.738 ],
#        [13097.603 ],
#        [13096.31  ],
#        [13097.232 ],
#        [13096.59  ],
#        [13097.042 ],
#        [13096.726 ],
#        [13096.948 ],
#        [13096.793 ],
#        [13096.902 ],
#        [13096.824 ],
#        [13096.88  ],
#        [13096.842 ],
#        [13096.868 ],
#        [13096.849 ],
#        [13096.861 ],
#        [13096.8545],
#        [13096.859 ]], dtype=float32)

# %% [markdown]
# ### Continue forecast the next 60/90 days

# %%
y_pred_60_days = forecast(test_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
y_pred_90_days = forecast(test_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")

    # Predict test and
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        test_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Next {days} Days",
        linestyle="--",
    )

    plt.title(f"Forecast {stock_name[stock]} Stock Closing Price Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Forecast the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
