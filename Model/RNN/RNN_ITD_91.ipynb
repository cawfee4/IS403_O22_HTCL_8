# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

plt.style.use('default')

# %% [markdown]
# ## 1. Data preprocessing

# %%
split_type = [0.8,0.7,0.9]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 2  # ITD
split = 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01   6900
# 2019-03-04   7100
# 2019-03-05   7100
# 2019-03-06   7170
# 2019-03-07   7170

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        6900
# 1        7100
# 2        7100
# 3        7170
# 4        7170
#         ...
# 1308    11300
# 1309    12050
# 1310    12600
# 1311    12500
# 1312    12700
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using neural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split] * len(df_scaled))
test_size = len(df_scaled) - train_size

# %%
# Splitting data into train, test set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size:]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1170, 10), (1170,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
UNITS = 64

# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(UNITS),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 64)             │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,289 (16.75 KB)
#  Trainable params: 4,289 (16.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - mean_absolute_error: 0.0692
# Epoch 2/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.7765e-04 - mean_absolute_error: 0.0183
# Epoch 3/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.8704e-04 - mean_absolute_error: 0.0174
# Epoch 4/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.1458e-04 - mean_absolute_error: 0.0158
# Epoch 5/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9012e-04 - mean_absolute_error: 0.0143
# Epoch 6/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9221e-04 - mean_absolute_error: 0.0148
# Epoch 7/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.5003e-04 - mean_absolute_error: 0.0147
# Epoch 8/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5955e-04 - mean_absolute_error: 0.0143
# Epoch 9/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.4408e-04 - mean_absolute_error: 0.0148
# Epoch 10/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4926e-04 - mean_absolute_error: 0.0138
# Epoch 11/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.4911e-04 - mean_absolute_error: 0.0153
# Epoch 12/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.5500e-04 - mean_absolute_error: 0.0161
# Epoch 13/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5817e-04 - mean_absolute_error: 0.0139
# Epoch 14/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2742e-04 - mean_absolute_error: 0.0130
# Epoch 15/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3112e-04 - mean_absolute_error: 0.0134
# Epoch 16/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3599e-04 - mean_absolute_error: 0.0134
# Epoch 17/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.6903e-04 - mean_absolute_error: 0.0143
# Epoch 18/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.1718e-04 - mean_absolute_error: 0.0155
# Epoch 19/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.6533e-04 - mean_absolute_error: 0.0150
# Epoch 20/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2037e-04 - mean_absolute_error: 0.0133
# Epoch 21/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8932e-04 - mean_absolute_error: 0.0125
# Epoch 22/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.8263e-04 - mean_absolute_error: 0.0146
# Epoch 23/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6417e-04 - mean_absolute_error: 0.0122
# Epoch 24/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4437e-04 - mean_absolute_error: 0.0140
# Epoch 25/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.9744e-04 - mean_absolute_error: 0.0147
# Epoch 26/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6954e-04 - mean_absolute_error: 0.0124
# Epoch 27/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0565e-04 - mean_absolute_error: 0.0132
# Epoch 28/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8811e-04 - mean_absolute_error: 0.0126
# Epoch 29/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9603e-04 - mean_absolute_error: 0.0133
# Epoch 30/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1385e-04 - mean_absolute_error: 0.0139
# Epoch 31/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0209e-04 - mean_absolute_error: 0.0131
# Epoch 32/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8415e-04 - mean_absolute_error: 0.0126
# Epoch 33/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6399e-04 - mean_absolute_error: 0.0124
# Epoch 34/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8058e-04 - mean_absolute_error: 0.0131
# Epoch 35/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0692e-04 - mean_absolute_error: 0.0139
# Epoch 36/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0190e-04 - mean_absolute_error: 0.0135
# Epoch 37/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4917e-04 - mean_absolute_error: 0.0126
# Epoch 38/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9868e-04 - mean_absolute_error: 0.0133
# Epoch 39/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9080e-04 - mean_absolute_error: 0.0130
# Epoch 40/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4483e-04 - mean_absolute_error: 0.0124
# Epoch 41/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5012e-04 - mean_absolute_error: 0.0131
# Epoch 42/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6684e-04 - mean_absolute_error: 0.0125
# Epoch 43/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2053e-04 - mean_absolute_error: 0.0141
# Epoch 44/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.5282e-04 - mean_absolute_error: 0.0162
# Epoch 45/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7229e-04 - mean_absolute_error: 0.0127
# Epoch 46/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7517e-04 - mean_absolute_error: 0.0131
# Epoch 47/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4033e-04 - mean_absolute_error: 0.0145
# Epoch 48/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5038e-04 - mean_absolute_error: 0.0124
# Epoch 49/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2301e-04 - mean_absolute_error: 0.0122
# Epoch 50/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3377e-04 - mean_absolute_error: 0.0121
# Epoch 51/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1984e-04 - mean_absolute_error: 0.0121
# Epoch 52/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9316e-04 - mean_absolute_error: 0.0131
# Epoch 53/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9890e-04 - mean_absolute_error: 0.0137
# Epoch 54/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4598e-04 - mean_absolute_error: 0.0127
# Epoch 55/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3274e-04 - mean_absolute_error: 0.0120
# Epoch 56/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7132e-04 - mean_absolute_error: 0.0122
# Epoch 57/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9073e-04 - mean_absolute_error: 0.0133
# Epoch 58/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3579e-04 - mean_absolute_error: 0.0121
# Epoch 59/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1360e-04 - mean_absolute_error: 0.0120
# Epoch 60/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.4919e-04 - mean_absolute_error: 0.0143
# Epoch 61/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3379e-04 - mean_absolute_error: 0.0124
# Epoch 62/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3395e-04 - mean_absolute_error: 0.0144
# Epoch 63/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5698e-04 - mean_absolute_error: 0.0126
# Epoch 64/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8152e-04 - mean_absolute_error: 0.0134
# Epoch 65/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4532e-04 - mean_absolute_error: 0.0125
# Epoch 66/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2558e-04 - mean_absolute_error: 0.0140
# Epoch 67/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8997e-04 - mean_absolute_error: 0.0130
# Epoch 68/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4707e-04 - mean_absolute_error: 0.0124
# Epoch 69/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1423e-04 - mean_absolute_error: 0.0135
# Epoch 70/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6332e-04 - mean_absolute_error: 0.0132
# Epoch 71/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4070e-04 - mean_absolute_error: 0.0123
# Epoch 72/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5524e-04 - mean_absolute_error: 0.0128
# Epoch 73/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4194e-04 - mean_absolute_error: 0.0126
# Epoch 74/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7147e-04 - mean_absolute_error: 0.0129
# Epoch 75/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1221e-04 - mean_absolute_error: 0.0118
# Epoch 76/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5505e-04 - mean_absolute_error: 0.0129
# Epoch 77/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3037e-04 - mean_absolute_error: 0.0121
# Epoch 78/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8222e-04 - mean_absolute_error: 0.0132
# Epoch 79/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6837e-04 - mean_absolute_error: 0.0132
# Epoch 80/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0645e-04 - mean_absolute_error: 0.0138
# Epoch 81/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2040e-04 - mean_absolute_error: 0.0122
# Epoch 82/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2573e-04 - mean_absolute_error: 0.0122
# Epoch 83/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8523e-04 - mean_absolute_error: 0.0133
# Epoch 84/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5651e-04 - mean_absolute_error: 0.0126
# Epoch 85/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8289e-04 - mean_absolute_error: 0.0134
# Epoch 86/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5215e-04 - mean_absolute_error: 0.0123
# Epoch 87/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.9723e-04 - mean_absolute_error: 0.0111
# Epoch 88/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7926e-04 - mean_absolute_error: 0.0132
# Epoch 89/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2157e-04 - mean_absolute_error: 0.0139
# Epoch 90/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6603e-04 - mean_absolute_error: 0.0126
# Epoch 91/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6854e-04 - mean_absolute_error: 0.0135
# Epoch 92/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6431e-04 - mean_absolute_error: 0.0129
# Epoch 93/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3291e-04 - mean_absolute_error: 0.0128
# Epoch 94/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6750e-04 - mean_absolute_error: 0.0133
# Epoch 95/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1718e-04 - mean_absolute_error: 0.0134
# Epoch 96/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3929e-04 - mean_absolute_error: 0.0128
# Epoch 97/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2868e-04 - mean_absolute_error: 0.0121
# Epoch 98/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3335e-04 - mean_absolute_error: 0.0122
# Epoch 99/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4613e-04 - mean_absolute_error: 0.0123
# Epoch 100/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1728e-04 - mean_absolute_error: 0.0122
# Epoch 101/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2299e-04 - mean_absolute_error: 0.0120
# Epoch 102/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5289e-04 - mean_absolute_error: 0.0129
# Epoch 103/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2441e-04 - mean_absolute_error: 0.0125
# Epoch 104/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1175e-04 - mean_absolute_error: 0.0116
# Epoch 105/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5346e-04 - mean_absolute_error: 0.0130
# Epoch 106/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2498e-04 - mean_absolute_error: 0.0121
# Epoch 107/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3818e-04 - mean_absolute_error: 0.0124
# Epoch 108/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.6942e-04 - mean_absolute_error: 0.0145
# Epoch 109/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2647e-04 - mean_absolute_error: 0.0136
# Epoch 110/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3444e-04 - mean_absolute_error: 0.0123
# Epoch 111/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3143e-04 - mean_absolute_error: 0.0126
# Epoch 112/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3196e-04 - mean_absolute_error: 0.0121
# Epoch 113/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6794e-04 - mean_absolute_error: 0.0130
# Epoch 114/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6900e-04 - mean_absolute_error: 0.0128
# Epoch 115/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4269e-04 - mean_absolute_error: 0.0126
# Epoch 116/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7550e-04 - mean_absolute_error: 0.0131
# Epoch 117/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7595e-04 - mean_absolute_error: 0.0128
# Epoch 118/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3120e-04 - mean_absolute_error: 0.0125
# Epoch 119/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4940e-04 - mean_absolute_error: 0.0147
# Epoch 120/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7710e-04 - mean_absolute_error: 0.0131
# Epoch 121/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6482e-04 - mean_absolute_error: 0.0129
# Epoch 122/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4297e-04 - mean_absolute_error: 0.0126
# Epoch 123/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1427e-04 - mean_absolute_error: 0.0120
# Epoch 124/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2823e-04 - mean_absolute_error: 0.0120
# Epoch 125/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8196e-04 - mean_absolute_error: 0.0135
# Epoch 126/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8930e-04 - mean_absolute_error: 0.0137
# Epoch 127/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1873e-04 - mean_absolute_error: 0.0118
# Epoch 128/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6990e-04 - mean_absolute_error: 0.0130
# Epoch 129/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 3.5595e-04 - mean_absolute_error: 0.0127
# Epoch 130/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8522e-04 - mean_absolute_error: 0.0133
# Epoch 131/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3846e-04 - mean_absolute_error: 0.0118
# Epoch 132/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5214e-04 - mean_absolute_error: 0.0124
# Epoch 133/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8603e-04 - mean_absolute_error: 0.0134
# Epoch 134/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1525e-04 - mean_absolute_error: 0.0118
# Epoch 135/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3005e-04 - mean_absolute_error: 0.0123
# Epoch 136/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8010e-04 - mean_absolute_error: 0.0133
# Epoch 137/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7593e-04 - mean_absolute_error: 0.0133
# Epoch 138/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2506e-04 - mean_absolute_error: 0.0120
# Epoch 139/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4867e-04 - mean_absolute_error: 0.0127
# Epoch 140/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1449e-04 - mean_absolute_error: 0.0119
# Epoch 141/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.9176e-04 - mean_absolute_error: 0.0133
# Epoch 142/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.8548e-04 - mean_absolute_error: 0.0112
# Epoch 143/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6641e-04 - mean_absolute_error: 0.0132
# Epoch 144/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2291e-04 - mean_absolute_error: 0.0120
# Epoch 145/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4618e-04 - mean_absolute_error: 0.0125
# Epoch 146/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4580e-04 - mean_absolute_error: 0.0122
# Epoch 147/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.2120e-04 - mean_absolute_error: 0.0137
# Epoch 148/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3555e-04 - mean_absolute_error: 0.0123
# Epoch 149/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.3504e-04 - mean_absolute_error: 0.0150
# Epoch 150/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1218e-04 - mean_absolute_error: 0.0118
# Epoch 151/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5629e-04 - mean_absolute_error: 0.0129
# Epoch 152/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.4493e-04 - mean_absolute_error: 0.0122
# Epoch 153/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7382e-04 - mean_absolute_error: 0.0130
# Epoch 154/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6565e-04 - mean_absolute_error: 0.0127
# Epoch 155/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2190e-04 - mean_absolute_error: 0.0122
# Epoch 156/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7496e-04 - mean_absolute_error: 0.0134
# Epoch 157/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.9139e-04 - mean_absolute_error: 0.0132
# Epoch 158/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4530e-04 - mean_absolute_error: 0.0123
# Epoch 159/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6115e-04 - mean_absolute_error: 0.0124
# Epoch 160/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5572e-04 - mean_absolute_error: 0.0126
# Epoch 161/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3631e-04 - mean_absolute_error: 0.0123
# Epoch 162/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6321e-04 - mean_absolute_error: 0.0127
# Epoch 163/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.8642e-04 - mean_absolute_error: 0.0135
# Epoch 164/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4407e-04 - mean_absolute_error: 0.0125
# Epoch 165/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.1863e-04 - mean_absolute_error: 0.0143
# Epoch 166/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2343e-04 - mean_absolute_error: 0.0120
# Epoch 167/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7631e-04 - mean_absolute_error: 0.0128
# Epoch 168/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0428e-04 - mean_absolute_error: 0.0136
# Epoch 169/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5475e-04 - mean_absolute_error: 0.0126
# Epoch 170/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4289e-04 - mean_absolute_error: 0.0124
# Epoch 171/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2860e-04 - mean_absolute_error: 0.0121
# Epoch 172/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.3431e-04 - mean_absolute_error: 0.0122
# Epoch 173/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2880e-04 - mean_absolute_error: 0.0123
# Epoch 174/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5116e-04 - mean_absolute_error: 0.0124
# Epoch 175/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5782e-04 - mean_absolute_error: 0.0128
# Epoch 176/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5225e-04 - mean_absolute_error: 0.0130
# Epoch 177/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5768e-04 - mean_absolute_error: 0.0125
# Epoch 178/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2876e-04 - mean_absolute_error: 0.0126
# Epoch 179/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8442e-04 - mean_absolute_error: 0.0134
# Epoch 180/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5003e-04 - mean_absolute_error: 0.0127
# Epoch 181/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4863e-04 - mean_absolute_error: 0.0130
# Epoch 182/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4866e-04 - mean_absolute_error: 0.0127
# Epoch 183/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0816e-04 - mean_absolute_error: 0.0140
# Epoch 184/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1204e-04 - mean_absolute_error: 0.0119
# Epoch 185/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3527e-04 - mean_absolute_error: 0.0125
# Epoch 186/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5816e-04 - mean_absolute_error: 0.0127
# Epoch 187/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.7530e-04 - mean_absolute_error: 0.0132
# Epoch 188/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.8327e-04 - mean_absolute_error: 0.0133
# Epoch 189/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6189e-04 - mean_absolute_error: 0.0127
# Epoch 190/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6298e-04 - mean_absolute_error: 0.0126
# Epoch 191/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3407e-04 - mean_absolute_error: 0.0122
# Epoch 192/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6683e-04 - mean_absolute_error: 0.0126
# Epoch 193/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2947e-04 - mean_absolute_error: 0.0125
# Epoch 194/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.5166e-04 - mean_absolute_error: 0.0125
# Epoch 195/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.1925e-04 - mean_absolute_error: 0.0119
# Epoch 196/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.1149e-04 - mean_absolute_error: 0.0139
# Epoch 197/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.3688e-04 - mean_absolute_error: 0.0122
# Epoch 198/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.6556e-04 - mean_absolute_error: 0.0135
# Epoch 199/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.6013e-04 - mean_absolute_error: 0.0126
# Epoch 200/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.1892e-04 - mean_absolute_error: 0.0122

# %% [markdown]
# ### Predicting with test set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test set again to evaluate, because i shaped the data between 0 to 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 121
# 132

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)
# Out:
# Model evalution on test set
# MSE: 81597.78161279032
# RMSE: 285.6532541610376
# MAE: 210.60472623966942
# MAPE: 2.037679504092721 %

# %% [markdown]
# ## 4. Forecast the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(test_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
y_pred_30_days
# Out:
# array([[13158.465],
#        [13075.267],
#        [13155.905],
#        [13139.858],
#        [13171.479],
#        [13162.902],
#        [13169.376],
#        [13167.435],
#        [13169.283],
#        [13168.595],
#        [13169.057],
#        [13168.88 ],
#        [13169.002],
#        [13168.946],
#        [13168.98 ],
#        [13168.967],
#        [13168.976],
#        [13168.971],
#        [13168.975],
#        [13168.974],
#        [13168.975],
#        [13168.976],
#        [13168.976],
#        [13168.976],
#        [13168.976],
#        [13168.975],
#        [13168.975],
#        [13168.976],
#        [13168.976],
#        [13168.975],
#        [13168.976]], dtype=float32)

# %% [markdown]
# ### Continue forecast the next 60/90 days

# %%
y_pred_60_days = forecast(test_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
y_pred_90_days = forecast(test_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")

    # Predict test and
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        test_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Next {days} Days",
        linestyle="--",
    )

    plt.title(f"Forecast {stock_name[stock]} Stock Closing Price Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Forecast the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
