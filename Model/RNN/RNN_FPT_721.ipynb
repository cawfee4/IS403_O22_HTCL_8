# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: FPT - Test/Train/Vaildation: 70/20/10
# - Dataset: 1252 rows x 7 column (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1496.2661263138236
# - MAE: 1090.3984375
# - MAPE: 1.5657470931959738 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 0  # 7 2 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01  19270
# 2019-03-04  19440
# 2019-03-05  19390
# 2019-03-06  19270
# 2019-03-07  19330

# %%
df.shape
# Out:
# (1252, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1247    108000
# 1248    107900
# 1249    108500
# 1250    109000
# 1251    110800
# Name: close, Length: 1252, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((865, 10), (865,), (239, 10), (239,), (115, 10), (115,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_1 (SimpleRNN)        │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 26ms/step - loss: 0.0359 - mean_absolute_error: 0.1245 - val_loss: 0.0049 - val_mean_absolute_error: 0.0624
# Epoch 2/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0017 - mean_absolute_error: 0.0303 - val_loss: 9.6541e-04 - val_mean_absolute_error: 0.0219
# Epoch 3/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 4.3357e-04 - mean_absolute_error: 0.0146 - val_loss: 7.8278e-04 - val_mean_absolute_error: 0.0202
# Epoch 4/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.7360e-04 - mean_absolute_error: 0.0135 - val_loss: 8.0998e-04 - val_mean_absolute_error: 0.0200
# Epoch 5/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8507e-04 - mean_absolute_error: 0.0131 - val_loss: 6.1716e-04 - val_mean_absolute_error: 0.0181
# Epoch 6/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.0179e-04 - mean_absolute_error: 0.0121 - val_loss: 5.5797e-04 - val_mean_absolute_error: 0.0171
# Epoch 7/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.4084e-04 - mean_absolute_error: 0.0127 - val_loss: 5.4720e-04 - val_mean_absolute_error: 0.0163
# Epoch 8/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9488e-04 - mean_absolute_error: 0.0115 - val_loss: 4.5903e-04 - val_mean_absolute_error: 0.0156
# Epoch 9/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8748e-04 - mean_absolute_error: 0.0118 - val_loss: 4.2659e-04 - val_mean_absolute_error: 0.0153
# Epoch 10/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3014e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0018 - val_mean_absolute_error: 0.0383
# Epoch 11/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.6699e-04 - mean_absolute_error: 0.0187 - val_loss: 6.4786e-04 - val_mean_absolute_error: 0.0194
# Epoch 12/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5010e-04 - mean_absolute_error: 0.0104 - val_loss: 3.7938e-04 - val_mean_absolute_error: 0.0135
# Epoch 13/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4656e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0012 - val_mean_absolute_error: 0.0302
# Epoch 14/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0690e-04 - mean_absolute_error: 0.0117 - val_loss: 3.5395e-04 - val_mean_absolute_error: 0.0133
# Epoch 15/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3379e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0037 - val_mean_absolute_error: 0.0589
# Epoch 16/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0015 - mean_absolute_error: 0.0270 - val_loss: 3.5177e-04 - val_mean_absolute_error: 0.0131
# Epoch 17/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3796e-04 - mean_absolute_error: 0.0100 - val_loss: 5.3497e-04 - val_mean_absolute_error: 0.0177
# Epoch 18/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7239e-04 - mean_absolute_error: 0.0110 - val_loss: 7.6519e-04 - val_mean_absolute_error: 0.0230
# Epoch 19/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5853e-04 - mean_absolute_error: 0.0104 - val_loss: 3.3946e-04 - val_mean_absolute_error: 0.0132
# Epoch 20/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6565e-04 - mean_absolute_error: 0.0086 - val_loss: 2.6915e-04 - val_mean_absolute_error: 0.0115
# Epoch 21/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6075e-04 - mean_absolute_error: 0.0085 - val_loss: 2.5495e-04 - val_mean_absolute_error: 0.0112
# Epoch 22/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8854e-04 - mean_absolute_error: 0.0090 - val_loss: 2.4891e-04 - val_mean_absolute_error: 0.0111
# Epoch 23/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6111e-04 - mean_absolute_error: 0.0084 - val_loss: 3.8640e-04 - val_mean_absolute_error: 0.0160
# Epoch 24/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2649e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0010 - val_mean_absolute_error: 0.0285
# Epoch 25/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.2915e-04 - mean_absolute_error: 0.0126 - val_loss: 4.2164e-04 - val_mean_absolute_error: 0.0160
# Epoch 26/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.0560e-04 - mean_absolute_error: 0.0120 - val_loss: 5.7431e-04 - val_mean_absolute_error: 0.0197
# Epoch 27/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5417e-04 - mean_absolute_error: 0.0110 - val_loss: 2.7213e-04 - val_mean_absolute_error: 0.0118
# Epoch 28/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5036e-04 - mean_absolute_error: 0.0079 - val_loss: 2.9705e-04 - val_mean_absolute_error: 0.0134
# Epoch 29/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9260e-04 - mean_absolute_error: 0.0092 - val_loss: 2.1857e-04 - val_mean_absolute_error: 0.0104
# Epoch 30/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4839e-04 - mean_absolute_error: 0.0078 - val_loss: 2.1289e-04 - val_mean_absolute_error: 0.0104
# Epoch 31/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3729e-04 - mean_absolute_error: 0.0078 - val_loss: 2.3109e-04 - val_mean_absolute_error: 0.0109
# Epoch 32/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5218e-04 - mean_absolute_error: 0.0079 - val_loss: 2.2298e-04 - val_mean_absolute_error: 0.0106
# Epoch 33/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4511e-04 - mean_absolute_error: 0.0080 - val_loss: 4.7266e-04 - val_mean_absolute_error: 0.0179
# Epoch 34/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0615e-04 - mean_absolute_error: 0.0096 - val_loss: 3.1288e-04 - val_mean_absolute_error: 0.0142
# Epoch 35/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6602e-04 - mean_absolute_error: 0.0086 - val_loss: 1.9895e-04 - val_mean_absolute_error: 0.0101
# Epoch 36/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4341e-04 - mean_absolute_error: 0.0077 - val_loss: 1.9780e-04 - val_mean_absolute_error: 0.0100
# Epoch 37/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5715e-04 - mean_absolute_error: 0.0080 - val_loss: 3.1826e-04 - val_mean_absolute_error: 0.0139
# Epoch 38/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5761e-04 - mean_absolute_error: 0.0081 - val_loss: 2.3148e-04 - val_mean_absolute_error: 0.0116
# Epoch 39/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6694e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0011 - val_mean_absolute_error: 0.0311
# Epoch 40/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1537e-04 - mean_absolute_error: 0.0122 - val_loss: 2.1635e-04 - val_mean_absolute_error: 0.0106
# Epoch 41/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3972e-04 - mean_absolute_error: 0.0075 - val_loss: 1.8566e-04 - val_mean_absolute_error: 0.0097
# Epoch 42/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3991e-04 - mean_absolute_error: 0.0075 - val_loss: 2.4395e-04 - val_mean_absolute_error: 0.0117
# Epoch 43/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5949e-04 - mean_absolute_error: 0.0080 - val_loss: 4.2622e-04 - val_mean_absolute_error: 0.0170
# Epoch 44/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7478e-04 - mean_absolute_error: 0.0093 - val_loss: 3.4228e-04 - val_mean_absolute_error: 0.0153
# Epoch 45/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7307e-04 - mean_absolute_error: 0.0090 - val_loss: 3.5995e-04 - val_mean_absolute_error: 0.0152
# Epoch 46/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3578e-04 - mean_absolute_error: 0.0101 - val_loss: 1.8290e-04 - val_mean_absolute_error: 0.0097
# Epoch 47/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4068e-04 - mean_absolute_error: 0.0076 - val_loss: 2.3611e-04 - val_mean_absolute_error: 0.0115
# Epoch 48/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3820e-04 - mean_absolute_error: 0.0075 - val_loss: 2.0009e-04 - val_mean_absolute_error: 0.0106
# Epoch 49/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6312e-04 - mean_absolute_error: 0.0084 - val_loss: 1.9410e-04 - val_mean_absolute_error: 0.0100
# Epoch 50/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5750e-04 - mean_absolute_error: 0.0080 - val_loss: 2.4240e-04 - val_mean_absolute_error: 0.0122
# Epoch 51/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3234e-04 - mean_absolute_error: 0.0077 - val_loss: 1.7697e-04 - val_mean_absolute_error: 0.0093
# Epoch 52/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4564e-04 - mean_absolute_error: 0.0079 - val_loss: 6.0988e-04 - val_mean_absolute_error: 0.0216
# Epoch 53/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.7701e-04 - mean_absolute_error: 0.0144 - val_loss: 1.9191e-04 - val_mean_absolute_error: 0.0101
# Epoch 54/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5917e-04 - mean_absolute_error: 0.0085 - val_loss: 1.8480e-04 - val_mean_absolute_error: 0.0098
# Epoch 55/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3449e-04 - mean_absolute_error: 0.0072 - val_loss: 1.8644e-04 - val_mean_absolute_error: 0.0100
# Epoch 56/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3418e-04 - mean_absolute_error: 0.0073 - val_loss: 1.8819e-04 - val_mean_absolute_error: 0.0098
# Epoch 57/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2722e-04 - mean_absolute_error: 0.0071 - val_loss: 3.4165e-04 - val_mean_absolute_error: 0.0150
# Epoch 58/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4883e-04 - mean_absolute_error: 0.0085 - val_loss: 1.6782e-04 - val_mean_absolute_error: 0.0093
# Epoch 59/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3000e-04 - mean_absolute_error: 0.0074 - val_loss: 3.6934e-04 - val_mean_absolute_error: 0.0159
# Epoch 60/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6647e-04 - mean_absolute_error: 0.0083 - val_loss: 2.4255e-04 - val_mean_absolute_error: 0.0119
# Epoch 61/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2241e-04 - mean_absolute_error: 0.0071 - val_loss: 3.3310e-04 - val_mean_absolute_error: 0.0153
# Epoch 62/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8638e-04 - mean_absolute_error: 0.0099 - val_loss: 2.9993e-04 - val_mean_absolute_error: 0.0138
# Epoch 63/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5446e-04 - mean_absolute_error: 0.0081 - val_loss: 2.0187e-04 - val_mean_absolute_error: 0.0108
# Epoch 64/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5040e-04 - mean_absolute_error: 0.0081 - val_loss: 7.6025e-04 - val_mean_absolute_error: 0.0252
# Epoch 65/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2707e-04 - mean_absolute_error: 0.0182 - val_loss: 2.7036e-04 - val_mean_absolute_error: 0.0133
# Epoch 66/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5581e-04 - mean_absolute_error: 0.0083 - val_loss: 1.6901e-04 - val_mean_absolute_error: 0.0091
# Epoch 67/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2161e-04 - mean_absolute_error: 0.0070 - val_loss: 2.2225e-04 - val_mean_absolute_error: 0.0113
# Epoch 68/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2113e-04 - mean_absolute_error: 0.0073 - val_loss: 2.2209e-04 - val_mean_absolute_error: 0.0113
# Epoch 69/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2538e-04 - mean_absolute_error: 0.0075 - val_loss: 1.7648e-04 - val_mean_absolute_error: 0.0096
# Epoch 70/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1824e-04 - mean_absolute_error: 0.0068 - val_loss: 1.5511e-04 - val_mean_absolute_error: 0.0089
# Epoch 71/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1973e-04 - mean_absolute_error: 0.0071 - val_loss: 1.4807e-04 - val_mean_absolute_error: 0.0086
# Epoch 72/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4232e-04 - mean_absolute_error: 0.0076 - val_loss: 1.5258e-04 - val_mean_absolute_error: 0.0088
# Epoch 73/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9373e-05 - mean_absolute_error: 0.0066 - val_loss: 1.9864e-04 - val_mean_absolute_error: 0.0106
# Epoch 74/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4763e-04 - mean_absolute_error: 0.0075 - val_loss: 2.1411e-04 - val_mean_absolute_error: 0.0115
# Epoch 75/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1273e-04 - mean_absolute_error: 0.0071 - val_loss: 1.6805e-04 - val_mean_absolute_error: 0.0095
# Epoch 76/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0398e-04 - mean_absolute_error: 0.0065 - val_loss: 1.5088e-04 - val_mean_absolute_error: 0.0087
# Epoch 77/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2891e-04 - mean_absolute_error: 0.0075 - val_loss: 3.1072e-04 - val_mean_absolute_error: 0.0146
# Epoch 78/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5614e-04 - mean_absolute_error: 0.0085 - val_loss: 1.4434e-04 - val_mean_absolute_error: 0.0085
# Epoch 79/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1251e-04 - mean_absolute_error: 0.0069 - val_loss: 1.5284e-04 - val_mean_absolute_error: 0.0088
# Epoch 80/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4949e-04 - mean_absolute_error: 0.0084 - val_loss: 4.7732e-04 - val_mean_absolute_error: 0.0192
# Epoch 81/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6171e-04 - mean_absolute_error: 0.0085 - val_loss: 1.8738e-04 - val_mean_absolute_error: 0.0103
# Epoch 82/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1409e-04 - mean_absolute_error: 0.0069 - val_loss: 1.5510e-04 - val_mean_absolute_error: 0.0089
# Epoch 83/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2782e-04 - mean_absolute_error: 0.0069 - val_loss: 1.5980e-04 - val_mean_absolute_error: 0.0092
# Epoch 84/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2129e-04 - mean_absolute_error: 0.0070 - val_loss: 0.0010 - val_mean_absolute_error: 0.0297
# Epoch 85/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.8415e-04 - mean_absolute_error: 0.0190 - val_loss: 1.3678e-04 - val_mean_absolute_error: 0.0082
# Epoch 86/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2945e-04 - mean_absolute_error: 0.0074 - val_loss: 1.5107e-04 - val_mean_absolute_error: 0.0088
# Epoch 87/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1030e-04 - mean_absolute_error: 0.0065 - val_loss: 1.3452e-04 - val_mean_absolute_error: 0.0081
# Epoch 88/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1594e-04 - mean_absolute_error: 0.0068 - val_loss: 1.3698e-04 - val_mean_absolute_error: 0.0083
# Epoch 89/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1579e-04 - mean_absolute_error: 0.0067 - val_loss: 1.3547e-04 - val_mean_absolute_error: 0.0081
# Epoch 90/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1856e-04 - mean_absolute_error: 0.0069 - val_loss: 3.8523e-04 - val_mean_absolute_error: 0.0170
# Epoch 91/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6954e-04 - mean_absolute_error: 0.0084 - val_loss: 1.3269e-04 - val_mean_absolute_error: 0.0081
# Epoch 92/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0347e-04 - mean_absolute_error: 0.0063 - val_loss: 2.0186e-04 - val_mean_absolute_error: 0.0111
# Epoch 93/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1927e-04 - mean_absolute_error: 0.0071 - val_loss: 1.3202e-04 - val_mean_absolute_error: 0.0080
# Epoch 94/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.4100e-05 - mean_absolute_error: 0.0062 - val_loss: 1.3036e-04 - val_mean_absolute_error: 0.0080
# Epoch 95/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0715e-04 - mean_absolute_error: 0.0062 - val_loss: 2.9012e-04 - val_mean_absolute_error: 0.0143
# Epoch 96/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8656e-04 - mean_absolute_error: 0.0097 - val_loss: 2.0946e-04 - val_mean_absolute_error: 0.0114
# Epoch 97/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2408e-04 - mean_absolute_error: 0.0069 - val_loss: 1.8488e-04 - val_mean_absolute_error: 0.0106
# Epoch 98/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4109e-04 - mean_absolute_error: 0.0082 - val_loss: 1.3547e-04 - val_mean_absolute_error: 0.0083
# Epoch 99/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.7340e-05 - mean_absolute_error: 0.0064 - val_loss: 2.1497e-04 - val_mean_absolute_error: 0.0116
# Epoch 100/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2281e-04 - mean_absolute_error: 0.0071 - val_loss: 1.2791e-04 - val_mean_absolute_error: 0.0079
# Epoch 101/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.1456e-05 - mean_absolute_error: 0.0060 - val_loss: 1.2826e-04 - val_mean_absolute_error: 0.0079
# Epoch 102/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0141e-04 - mean_absolute_error: 0.0062 - val_loss: 3.9248e-04 - val_mean_absolute_error: 0.0173
# Epoch 103/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2905e-04 - mean_absolute_error: 0.0105 - val_loss: 2.7291e-04 - val_mean_absolute_error: 0.0137
# Epoch 104/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2835e-04 - mean_absolute_error: 0.0074 - val_loss: 1.3616e-04 - val_mean_absolute_error: 0.0083
# Epoch 105/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2340e-04 - mean_absolute_error: 0.0072 - val_loss: 1.4367e-04 - val_mean_absolute_error: 0.0086
# Epoch 106/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2249e-04 - mean_absolute_error: 0.0072 - val_loss: 1.3096e-04 - val_mean_absolute_error: 0.0081
# Epoch 107/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.2788e-05 - mean_absolute_error: 0.0063 - val_loss: 1.5535e-04 - val_mean_absolute_error: 0.0093
# Epoch 108/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0533e-04 - mean_absolute_error: 0.0069 - val_loss: 1.5332e-04 - val_mean_absolute_error: 0.0092
# Epoch 109/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0574e-04 - mean_absolute_error: 0.0066 - val_loss: 1.2926e-04 - val_mean_absolute_error: 0.0079
# Epoch 110/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0402e-04 - mean_absolute_error: 0.0070 - val_loss: 2.5359e-04 - val_mean_absolute_error: 0.0131
# Epoch 111/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1527e-04 - mean_absolute_error: 0.0070 - val_loss: 2.0997e-04 - val_mean_absolute_error: 0.0116
# Epoch 112/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2296e-04 - mean_absolute_error: 0.0069 - val_loss: 1.3566e-04 - val_mean_absolute_error: 0.0083
# Epoch 113/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3370e-04 - mean_absolute_error: 0.0076 - val_loss: 1.3773e-04 - val_mean_absolute_error: 0.0085
# Epoch 114/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0188e-04 - mean_absolute_error: 0.0067 - val_loss: 1.4699e-04 - val_mean_absolute_error: 0.0089
# Epoch 115/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2287e-04 - mean_absolute_error: 0.0070 - val_loss: 1.2755e-04 - val_mean_absolute_error: 0.0079
# Epoch 116/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.2107e-05 - mean_absolute_error: 0.0063 - val_loss: 1.2633e-04 - val_mean_absolute_error: 0.0078
# Epoch 117/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0426e-04 - mean_absolute_error: 0.0069 - val_loss: 1.2611e-04 - val_mean_absolute_error: 0.0078
# Epoch 118/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0745e-04 - mean_absolute_error: 0.0067 - val_loss: 2.3651e-04 - val_mean_absolute_error: 0.0125
# Epoch 119/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4955e-04 - mean_absolute_error: 0.0084 - val_loss: 1.2681e-04 - val_mean_absolute_error: 0.0077
# Epoch 120/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0922e-04 - mean_absolute_error: 0.0069 - val_loss: 1.2684e-04 - val_mean_absolute_error: 0.0078
# Epoch 121/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0850e-04 - mean_absolute_error: 0.0067 - val_loss: 1.3364e-04 - val_mean_absolute_error: 0.0081
# Epoch 122/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1630e-04 - mean_absolute_error: 0.0076 - val_loss: 1.3628e-04 - val_mean_absolute_error: 0.0083
# Epoch 123/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2011e-04 - mean_absolute_error: 0.0071 - val_loss: 1.4248e-04 - val_mean_absolute_error: 0.0088
# Epoch 124/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.8168e-05 - mean_absolute_error: 0.0068 - val_loss: 1.2238e-04 - val_mean_absolute_error: 0.0076
# Epoch 125/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.5120e-05 - mean_absolute_error: 0.0063 - val_loss: 1.2204e-04 - val_mean_absolute_error: 0.0076
# Epoch 126/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.6061e-05 - mean_absolute_error: 0.0058 - val_loss: 1.3060e-04 - val_mean_absolute_error: 0.0081
# Epoch 127/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.4783e-05 - mean_absolute_error: 0.0061 - val_loss: 1.5731e-04 - val_mean_absolute_error: 0.0095
# Epoch 128/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1323e-04 - mean_absolute_error: 0.0069 - val_loss: 2.4556e-04 - val_mean_absolute_error: 0.0130
# Epoch 129/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1797e-04 - mean_absolute_error: 0.0074 - val_loss: 4.9955e-04 - val_mean_absolute_error: 0.0202
# Epoch 130/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.5215e-04 - mean_absolute_error: 0.0111 - val_loss: 1.2110e-04 - val_mean_absolute_error: 0.0076
# Epoch 131/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1466e-04 - mean_absolute_error: 0.0073 - val_loss: 1.2464e-04 - val_mean_absolute_error: 0.0077
# Epoch 132/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.5062e-05 - mean_absolute_error: 0.0062 - val_loss: 1.3681e-04 - val_mean_absolute_error: 0.0084
# Epoch 133/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0409e-04 - mean_absolute_error: 0.0062 - val_loss: 3.4788e-04 - val_mean_absolute_error: 0.0162
# Epoch 134/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1915e-04 - mean_absolute_error: 0.0105 - val_loss: 1.4735e-04 - val_mean_absolute_error: 0.0090
# Epoch 135/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.3684e-05 - mean_absolute_error: 0.0061 - val_loss: 1.2263e-04 - val_mean_absolute_error: 0.0076
# Epoch 136/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.6212e-05 - mean_absolute_error: 0.0061 - val_loss: 1.4067e-04 - val_mean_absolute_error: 0.0085
# Epoch 137/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2841e-04 - mean_absolute_error: 0.0076 - val_loss: 1.5592e-04 - val_mean_absolute_error: 0.0094
# Epoch 138/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1300e-04 - mean_absolute_error: 0.0075 - val_loss: 1.2970e-04 - val_mean_absolute_error: 0.0081
# Epoch 139/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.7398e-05 - mean_absolute_error: 0.0061 - val_loss: 1.4990e-04 - val_mean_absolute_error: 0.0091
# Epoch 140/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9482e-05 - mean_absolute_error: 0.0064 - val_loss: 1.9653e-04 - val_mean_absolute_error: 0.0112
# Epoch 141/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1598e-04 - mean_absolute_error: 0.0067 - val_loss: 0.0012 - val_mean_absolute_error: 0.0331
# Epoch 142/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.2017e-04 - mean_absolute_error: 0.0170 - val_loss: 3.1687e-04 - val_mean_absolute_error: 0.0154
# Epoch 143/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2151e-04 - mean_absolute_error: 0.0077 - val_loss: 1.3996e-04 - val_mean_absolute_error: 0.0085
# Epoch 144/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0864e-04 - mean_absolute_error: 0.0064 - val_loss: 1.6083e-04 - val_mean_absolute_error: 0.0096
# Epoch 145/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1750e-04 - mean_absolute_error: 0.0069 - val_loss: 1.2050e-04 - val_mean_absolute_error: 0.0075
# Epoch 146/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4230e-04 - mean_absolute_error: 0.0083 - val_loss: 1.2077e-04 - val_mean_absolute_error: 0.0075
# Epoch 147/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0156e-04 - mean_absolute_error: 0.0062 - val_loss: 1.4109e-04 - val_mean_absolute_error: 0.0086
# Epoch 148/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1985e-04 - mean_absolute_error: 0.0067 - val_loss: 1.4456e-04 - val_mean_absolute_error: 0.0088
# Epoch 149/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0166e-04 - mean_absolute_error: 0.0069 - val_loss: 1.2070e-04 - val_mean_absolute_error: 0.0075
# Epoch 150/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.1693e-05 - mean_absolute_error: 0.0059 - val_loss: 1.7631e-04 - val_mean_absolute_error: 0.0104
# Epoch 151/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.3118e-05 - mean_absolute_error: 0.0064 - val_loss: 1.1561e-04 - val_mean_absolute_error: 0.0074
# Epoch 152/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.8732e-05 - mean_absolute_error: 0.0063 - val_loss: 1.1656e-04 - val_mean_absolute_error: 0.0074
# Epoch 153/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9913e-05 - mean_absolute_error: 0.0058 - val_loss: 1.3772e-04 - val_mean_absolute_error: 0.0085
# Epoch 154/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7957e-05 - mean_absolute_error: 0.0065 - val_loss: 7.8163e-04 - val_mean_absolute_error: 0.0260
# Epoch 155/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.8531e-04 - mean_absolute_error: 0.0144 - val_loss: 1.4364e-04 - val_mean_absolute_error: 0.0085
# Epoch 156/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1584e-04 - mean_absolute_error: 0.0076 - val_loss: 1.5765e-04 - val_mean_absolute_error: 0.0095
# Epoch 157/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1113e-04 - mean_absolute_error: 0.0070 - val_loss: 1.8288e-04 - val_mean_absolute_error: 0.0107
# Epoch 158/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2818e-04 - mean_absolute_error: 0.0077 - val_loss: 1.3481e-04 - val_mean_absolute_error: 0.0083
# Epoch 159/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0118e-04 - mean_absolute_error: 0.0064 - val_loss: 1.2039e-04 - val_mean_absolute_error: 0.0076
# Epoch 160/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.6020e-05 - mean_absolute_error: 0.0061 - val_loss: 1.8387e-04 - val_mean_absolute_error: 0.0107
# Epoch 161/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1709e-04 - mean_absolute_error: 0.0071 - val_loss: 2.4014e-04 - val_mean_absolute_error: 0.0129
# Epoch 162/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0037e-04 - mean_absolute_error: 0.0066 - val_loss: 2.2661e-04 - val_mean_absolute_error: 0.0123
# Epoch 163/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3793e-04 - mean_absolute_error: 0.0083 - val_loss: 1.1766e-04 - val_mean_absolute_error: 0.0074
# Epoch 164/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0451e-04 - mean_absolute_error: 0.0067 - val_loss: 1.2216e-04 - val_mean_absolute_error: 0.0076
# Epoch 165/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6131e-05 - mean_absolute_error: 0.0062 - val_loss: 1.2018e-04 - val_mean_absolute_error: 0.0075
# Epoch 166/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0391e-04 - mean_absolute_error: 0.0068 - val_loss: 1.1756e-04 - val_mean_absolute_error: 0.0074
# Epoch 167/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.2628e-05 - mean_absolute_error: 0.0058 - val_loss: 1.1723e-04 - val_mean_absolute_error: 0.0073
# Epoch 168/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.7947e-05 - mean_absolute_error: 0.0060 - val_loss: 1.8157e-04 - val_mean_absolute_error: 0.0107
# Epoch 169/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1229e-04 - mean_absolute_error: 0.0069 - val_loss: 1.1742e-04 - val_mean_absolute_error: 0.0073
# Epoch 170/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.1656e-05 - mean_absolute_error: 0.0065 - val_loss: 1.1624e-04 - val_mean_absolute_error: 0.0074
# Epoch 171/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0101e-04 - mean_absolute_error: 0.0062 - val_loss: 1.1981e-04 - val_mean_absolute_error: 0.0075
# Epoch 172/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.7013e-05 - mean_absolute_error: 0.0063 - val_loss: 1.1647e-04 - val_mean_absolute_error: 0.0073
# Epoch 173/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2076e-04 - mean_absolute_error: 0.0067 - val_loss: 1.3389e-04 - val_mean_absolute_error: 0.0083
# Epoch 174/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.9247e-05 - mean_absolute_error: 0.0061 - val_loss: 1.2916e-04 - val_mean_absolute_error: 0.0080
# Epoch 175/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6260e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4018e-04 - val_mean_absolute_error: 0.0087
# Epoch 176/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2920e-04 - mean_absolute_error: 0.0077 - val_loss: 1.2441e-04 - val_mean_absolute_error: 0.0079
# Epoch 177/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0723e-04 - mean_absolute_error: 0.0065 - val_loss: 1.1691e-04 - val_mean_absolute_error: 0.0073
# Epoch 178/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.5336e-05 - mean_absolute_error: 0.0064 - val_loss: 1.6148e-04 - val_mean_absolute_error: 0.0097
# Epoch 179/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.3794e-05 - mean_absolute_error: 0.0064 - val_loss: 1.4065e-04 - val_mean_absolute_error: 0.0087
# Epoch 180/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0794e-04 - mean_absolute_error: 0.0067 - val_loss: 1.2042e-04 - val_mean_absolute_error: 0.0075
# Epoch 181/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.9706e-05 - mean_absolute_error: 0.0060 - val_loss: 1.1896e-04 - val_mean_absolute_error: 0.0075
# Epoch 182/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0612e-04 - mean_absolute_error: 0.0070 - val_loss: 1.1628e-04 - val_mean_absolute_error: 0.0073
# Epoch 183/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.4256e-05 - mean_absolute_error: 0.0065 - val_loss: 1.6967e-04 - val_mean_absolute_error: 0.0100
# Epoch 184/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1449e-04 - mean_absolute_error: 0.0073 - val_loss: 1.6438e-04 - val_mean_absolute_error: 0.0099
# Epoch 185/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.5102e-05 - mean_absolute_error: 0.0063 - val_loss: 1.2108e-04 - val_mean_absolute_error: 0.0075
# Epoch 186/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1052e-04 - mean_absolute_error: 0.0072 - val_loss: 1.3408e-04 - val_mean_absolute_error: 0.0083
# Epoch 187/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0105e-04 - mean_absolute_error: 0.0066 - val_loss: 1.2840e-04 - val_mean_absolute_error: 0.0081
# Epoch 188/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.2023e-05 - mean_absolute_error: 0.0060 - val_loss: 1.2920e-04 - val_mean_absolute_error: 0.0080
# Epoch 189/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.2017e-05 - mean_absolute_error: 0.0060 - val_loss: 1.1778e-04 - val_mean_absolute_error: 0.0073
# Epoch 190/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0265e-04 - mean_absolute_error: 0.0066 - val_loss: 1.8226e-04 - val_mean_absolute_error: 0.0106
# Epoch 191/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0782e-04 - mean_absolute_error: 0.0069 - val_loss: 1.2857e-04 - val_mean_absolute_error: 0.0080
# Epoch 192/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1161e-04 - mean_absolute_error: 0.0070 - val_loss: 1.9030e-04 - val_mean_absolute_error: 0.0110
# Epoch 193/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6007e-04 - mean_absolute_error: 0.0090 - val_loss: 1.3628e-04 - val_mean_absolute_error: 0.0085
# Epoch 194/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1399e-04 - mean_absolute_error: 0.0076 - val_loss: 1.2078e-04 - val_mean_absolute_error: 0.0077
# Epoch 195/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0818e-04 - mean_absolute_error: 0.0067 - val_loss: 1.1835e-04 - val_mean_absolute_error: 0.0075
# Epoch 196/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0770e-04 - mean_absolute_error: 0.0073 - val_loss: 1.4266e-04 - val_mean_absolute_error: 0.0088
# Epoch 197/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0934e-04 - mean_absolute_error: 0.0065 - val_loss: 1.2710e-04 - val_mean_absolute_error: 0.0080
# Epoch 198/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0866e-04 - mean_absolute_error: 0.0071 - val_loss: 1.1990e-04 - val_mean_absolute_error: 0.0076
# Epoch 199/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6860e-05 - mean_absolute_error: 0.0061 - val_loss: 1.1936e-04 - val_mean_absolute_error: 0.0075
# Epoch 200/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7217e-05 - mean_absolute_error: 0.0066 - val_loss: 1.3204e-04 - val_mean_absolute_error: 0.0082

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 239
# 250

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 2238812.320754175
# RMSE: 1496.2661263138236
# MAE: 1090.3984375
# MAPE: 1.5657470931959738 %
#
# Model evalution on validate set
# MSE: 5290920.477321459
# RMSE: 2300.2000950616143
# MAE: 1767.3641304347825
# MAPE: 1.8382461398428769 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step

# %%
y_pred_30_days
# Out:
# array([[105658.17 ],
#        [106051.76 ],
#        [105830.94 ],
#        [105712.7  ],
#        [105934.38 ],
#        [105873.33 ],
#        [105899.41 ],
#        [105909.58 ],
#        [105893.86 ],
#        [105900.73 ],
#        [105898.04 ],
#        [105897.41 ],
#        [105898.57 ],
#        [105897.88 ],
#        [105898.16 ],
#        [105898.18 ],
#        [105898.09 ],
#        [105898.17 ],
#        [105898.125],
#        [105898.15 ],
#        [105898.13 ],
#        [105898.13 ],
#        [105898.125],
#        [105898.13 ],
#        [105898.125],
#        [105898.15 ],
#        [105898.125],
#        [105898.13 ],
#        [105898.125],
#        [105898.125],
#        [105898.15 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Predict the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
