# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: FPT - Test/Train/Vaildation: 70/20/10
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1553.365689405445
# - MAE: 1106.49640500498
# - MAPE: 1.4411187001330938 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 0  # 7 2 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.tail()
# Out:
#              close
# time
# 2024-05-27  132800
# 2024-05-28  137000
# 2024-05-29  135700
# 2024-05-30  135000
# 2024-05-31  134600

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((908, 10), (908,), (251, 10), (251,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 36ms/step - loss: 0.0113 - mean_absolute_error: 0.0723 - val_loss: 0.0026 - val_mean_absolute_error: 0.0456
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.6726e-04 - mean_absolute_error: 0.0137 - val_loss: 8.9266e-04 - val_mean_absolute_error: 0.0230
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9239e-04 - mean_absolute_error: 0.0093 - val_loss: 5.4288e-04 - val_mean_absolute_error: 0.0164
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2075e-04 - mean_absolute_error: 0.0072 - val_loss: 3.9816e-04 - val_mean_absolute_error: 0.0136
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3281e-04 - mean_absolute_error: 0.0076 - val_loss: 3.2612e-04 - val_mean_absolute_error: 0.0124
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3181e-04 - mean_absolute_error: 0.0076 - val_loss: 3.4240e-04 - val_mean_absolute_error: 0.0126
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3129e-04 - mean_absolute_error: 0.0073 - val_loss: 3.1815e-04 - val_mean_absolute_error: 0.0122
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2754e-04 - mean_absolute_error: 0.0073 - val_loss: 2.9753e-04 - val_mean_absolute_error: 0.0118
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.5455e-04 - mean_absolute_error: 0.0084 - val_loss: 2.6950e-04 - val_mean_absolute_error: 0.0113
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2387e-04 - mean_absolute_error: 0.0073 - val_loss: 2.1623e-04 - val_mean_absolute_error: 0.0113
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3846e-04 - mean_absolute_error: 0.0082 - val_loss: 4.5877e-04 - val_mean_absolute_error: 0.0162
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1156e-04 - mean_absolute_error: 0.0068 - val_loss: 4.1263e-04 - val_mean_absolute_error: 0.0152
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7668e-05 - mean_absolute_error: 0.0066 - val_loss: 2.3410e-04 - val_mean_absolute_error: 0.0105
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1256e-04 - mean_absolute_error: 0.0070 - val_loss: 3.9647e-04 - val_mean_absolute_error: 0.0150
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2231e-04 - mean_absolute_error: 0.0075 - val_loss: 3.4453e-04 - val_mean_absolute_error: 0.0137
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1340e-04 - mean_absolute_error: 0.0069 - val_loss: 3.0647e-04 - val_mean_absolute_error: 0.0127
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0309e-04 - mean_absolute_error: 0.0063 - val_loss: 1.7464e-04 - val_mean_absolute_error: 0.0097
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1264e-04 - mean_absolute_error: 0.0071 - val_loss: 5.5741e-04 - val_mean_absolute_error: 0.0193
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2529e-04 - mean_absolute_error: 0.0076 - val_loss: 1.7232e-04 - val_mean_absolute_error: 0.0098
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2928e-04 - mean_absolute_error: 0.0073 - val_loss: 2.1855e-04 - val_mean_absolute_error: 0.0122
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1518e-04 - mean_absolute_error: 0.0075 - val_loss: 1.8596e-04 - val_mean_absolute_error: 0.0095
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0552e-04 - mean_absolute_error: 0.0068 - val_loss: 3.5383e-04 - val_mean_absolute_error: 0.0143
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1193e-04 - mean_absolute_error: 0.0070 - val_loss: 1.6164e-04 - val_mean_absolute_error: 0.0095
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0084e-04 - mean_absolute_error: 0.0070 - val_loss: 2.7039e-04 - val_mean_absolute_error: 0.0119
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.5765e-05 - mean_absolute_error: 0.0060 - val_loss: 3.0058e-04 - val_mean_absolute_error: 0.0129
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.4242e-05 - mean_absolute_error: 0.0060 - val_loss: 1.7207e-04 - val_mean_absolute_error: 0.0091
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 9.4014e-05 - mean_absolute_error: 0.0064 - val_loss: 1.6957e-04 - val_mean_absolute_error: 0.0090
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2266e-04 - mean_absolute_error: 0.0074 - val_loss: 3.0387e-04 - val_mean_absolute_error: 0.0152
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3482e-04 - mean_absolute_error: 0.0080 - val_loss: 2.7622e-04 - val_mean_absolute_error: 0.0123
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1021e-04 - mean_absolute_error: 0.0067 - val_loss: 1.9807e-04 - val_mean_absolute_error: 0.0099
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 8.9893e-05 - mean_absolute_error: 0.0061 - val_loss: 1.5695e-04 - val_mean_absolute_error: 0.0088
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.1067e-04 - mean_absolute_error: 0.0067 - val_loss: 6.1008e-04 - val_mean_absolute_error: 0.0212
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3121e-04 - mean_absolute_error: 0.0079 - val_loss: 1.5236e-04 - val_mean_absolute_error: 0.0086
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.4979e-05 - mean_absolute_error: 0.0064 - val_loss: 3.6067e-04 - val_mean_absolute_error: 0.0151
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.1501e-04 - mean_absolute_error: 0.0072 - val_loss: 1.8503e-04 - val_mean_absolute_error: 0.0096
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.1279e-05 - mean_absolute_error: 0.0061 - val_loss: 1.8680e-04 - val_mean_absolute_error: 0.0097
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.1518e-05 - mean_absolute_error: 0.0061 - val_loss: 1.3998e-04 - val_mean_absolute_error: 0.0084
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.4562e-05 - mean_absolute_error: 0.0063 - val_loss: 1.3829e-04 - val_mean_absolute_error: 0.0083
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0284e-04 - mean_absolute_error: 0.0069 - val_loss: 1.6407e-04 - val_mean_absolute_error: 0.0103
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0194e-04 - mean_absolute_error: 0.0065 - val_loss: 1.9177e-04 - val_mean_absolute_error: 0.0099
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.1758e-05 - mean_absolute_error: 0.0058 - val_loss: 2.5164e-04 - val_mean_absolute_error: 0.0118
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.8702e-05 - mean_absolute_error: 0.0058 - val_loss: 2.0443e-04 - val_mean_absolute_error: 0.0104
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.9408e-05 - mean_absolute_error: 0.0061 - val_loss: 4.6567e-04 - val_mean_absolute_error: 0.0181
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0905e-04 - mean_absolute_error: 0.0069 - val_loss: 1.6669e-04 - val_mean_absolute_error: 0.0105
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0802e-04 - mean_absolute_error: 0.0071 - val_loss: 4.5542e-04 - val_mean_absolute_error: 0.0179
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0375e-04 - mean_absolute_error: 0.0068 - val_loss: 1.3468e-04 - val_mean_absolute_error: 0.0089
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.4397e-05 - mean_absolute_error: 0.0057 - val_loss: 1.4684e-04 - val_mean_absolute_error: 0.0084
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.8833e-05 - mean_absolute_error: 0.0061 - val_loss: 1.2073e-04 - val_mean_absolute_error: 0.0078
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.5929e-05 - mean_absolute_error: 0.0054 - val_loss: 1.7313e-04 - val_mean_absolute_error: 0.0094
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1684e-05 - mean_absolute_error: 0.0052 - val_loss: 1.4063e-04 - val_mean_absolute_error: 0.0094
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.5591e-05 - mean_absolute_error: 0.0058 - val_loss: 2.4396e-04 - val_mean_absolute_error: 0.0119
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0038e-04 - mean_absolute_error: 0.0065 - val_loss: 2.1086e-04 - val_mean_absolute_error: 0.0108
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.5611e-05 - mean_absolute_error: 0.0061 - val_loss: 2.6398e-04 - val_mean_absolute_error: 0.0125
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.6816e-05 - mean_absolute_error: 0.0060 - val_loss: 3.4321e-04 - val_mean_absolute_error: 0.0151
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.4915e-05 - mean_absolute_error: 0.0062 - val_loss: 2.0019e-04 - val_mean_absolute_error: 0.0104
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.8715e-05 - mean_absolute_error: 0.0061 - val_loss: 1.3829e-04 - val_mean_absolute_error: 0.0082
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0554e-05 - mean_absolute_error: 0.0061 - val_loss: 1.7116e-04 - val_mean_absolute_error: 0.0095
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2873e-04 - mean_absolute_error: 0.0079 - val_loss: 1.1459e-04 - val_mean_absolute_error: 0.0074
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.2889e-05 - mean_absolute_error: 0.0066 - val_loss: 1.1059e-04 - val_mean_absolute_error: 0.0073
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.5277e-05 - mean_absolute_error: 0.0056 - val_loss: 2.0170e-04 - val_mean_absolute_error: 0.0106
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.8728e-05 - mean_absolute_error: 0.0060 - val_loss: 1.2545e-04 - val_mean_absolute_error: 0.0087
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.2244e-04 - mean_absolute_error: 0.0078 - val_loss: 1.8323e-04 - val_mean_absolute_error: 0.0099
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.2674e-05 - mean_absolute_error: 0.0057 - val_loss: 3.6732e-04 - val_mean_absolute_error: 0.0160
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 9.9248e-05 - mean_absolute_error: 0.0066 - val_loss: 1.2466e-04 - val_mean_absolute_error: 0.0077
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.4811e-05 - mean_absolute_error: 0.0057 - val_loss: 2.8411e-04 - val_mean_absolute_error: 0.0136
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.4010e-05 - mean_absolute_error: 0.0061 - val_loss: 1.0737e-04 - val_mean_absolute_error: 0.0072
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 7.5950e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2633e-04 - val_mean_absolute_error: 0.0088
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.0034e-05 - mean_absolute_error: 0.0055 - val_loss: 1.2648e-04 - val_mean_absolute_error: 0.0078
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.3360e-05 - mean_absolute_error: 0.0055 - val_loss: 1.5211e-04 - val_mean_absolute_error: 0.0088
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.6748e-05 - mean_absolute_error: 0.0056 - val_loss: 1.2312e-04 - val_mean_absolute_error: 0.0077
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.5384e-05 - mean_absolute_error: 0.0054 - val_loss: 1.1609e-04 - val_mean_absolute_error: 0.0074
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.9152e-05 - mean_absolute_error: 0.0059 - val_loss: 1.0581e-04 - val_mean_absolute_error: 0.0076
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.7186e-05 - mean_absolute_error: 0.0051 - val_loss: 1.1241e-04 - val_mean_absolute_error: 0.0073
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.0437e-05 - mean_absolute_error: 0.0054 - val_loss: 1.1331e-04 - val_mean_absolute_error: 0.0073
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.0278e-05 - mean_absolute_error: 0.0054 - val_loss: 2.4250e-04 - val_mean_absolute_error: 0.0124
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.3241e-05 - mean_absolute_error: 0.0062 - val_loss: 1.0334e-04 - val_mean_absolute_error: 0.0070
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.5548e-05 - mean_absolute_error: 0.0055 - val_loss: 2.2943e-04 - val_mean_absolute_error: 0.0119
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.5726e-05 - mean_absolute_error: 0.0056 - val_loss: 2.1005e-04 - val_mean_absolute_error: 0.0113
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.3890e-05 - mean_absolute_error: 0.0057 - val_loss: 1.0271e-04 - val_mean_absolute_error: 0.0069
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.9006e-05 - mean_absolute_error: 0.0055 - val_loss: 9.7192e-05 - val_mean_absolute_error: 0.0069
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.2100e-05 - mean_absolute_error: 0.0054 - val_loss: 1.1609e-04 - val_mean_absolute_error: 0.0074
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.3162e-05 - mean_absolute_error: 0.0056 - val_loss: 1.3881e-04 - val_mean_absolute_error: 0.0085
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.2602e-05 - mean_absolute_error: 0.0059 - val_loss: 1.6260e-04 - val_mean_absolute_error: 0.0105
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.4338e-05 - mean_absolute_error: 0.0063 - val_loss: 1.6678e-04 - val_mean_absolute_error: 0.0096
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7889e-05 - mean_absolute_error: 0.0053 - val_loss: 1.0704e-04 - val_mean_absolute_error: 0.0079
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.0292e-05 - mean_absolute_error: 0.0059 - val_loss: 3.3098e-04 - val_mean_absolute_error: 0.0155
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.9756e-05 - mean_absolute_error: 0.0059 - val_loss: 2.8098e-04 - val_mean_absolute_error: 0.0139
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0588e-04 - mean_absolute_error: 0.0071 - val_loss: 1.3937e-04 - val_mean_absolute_error: 0.0095
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.2310e-05 - mean_absolute_error: 0.0064 - val_loss: 1.0048e-04 - val_mean_absolute_error: 0.0068
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.4787e-05 - mean_absolute_error: 0.0059 - val_loss: 9.5408e-05 - val_mean_absolute_error: 0.0070
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.9851e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2151e-04 - val_mean_absolute_error: 0.0087
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.6912e-05 - mean_absolute_error: 0.0059 - val_loss: 1.1649e-04 - val_mean_absolute_error: 0.0075
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0039e-04 - mean_absolute_error: 0.0069 - val_loss: 9.2792e-05 - val_mean_absolute_error: 0.0066
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.0390e-05 - mean_absolute_error: 0.0048 - val_loss: 1.4088e-04 - val_mean_absolute_error: 0.0086
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8140e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2459e-04 - val_mean_absolute_error: 0.0079
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.4252e-05 - mean_absolute_error: 0.0056 - val_loss: 1.8586e-04 - val_mean_absolute_error: 0.0106
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7629e-05 - mean_absolute_error: 0.0062 - val_loss: 1.0117e-04 - val_mean_absolute_error: 0.0068
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.8210e-05 - mean_absolute_error: 0.0055 - val_loss: 1.2137e-04 - val_mean_absolute_error: 0.0087
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.9420e-05 - mean_absolute_error: 0.0055 - val_loss: 1.3239e-04 - val_mean_absolute_error: 0.0083
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.4427e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1171e-04 - val_mean_absolute_error: 0.0073
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.7466e-05 - mean_absolute_error: 0.0051 - val_loss: 9.6240e-05 - val_mean_absolute_error: 0.0066
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.7324e-05 - mean_absolute_error: 0.0049 - val_loss: 1.5085e-04 - val_mean_absolute_error: 0.0091
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6347e-05 - mean_absolute_error: 0.0050 - val_loss: 9.8554e-05 - val_mean_absolute_error: 0.0074
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7444e-05 - mean_absolute_error: 0.0054 - val_loss: 1.1825e-04 - val_mean_absolute_error: 0.0075
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1937e-05 - mean_absolute_error: 0.0053 - val_loss: 9.4464e-05 - val_mean_absolute_error: 0.0065
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.5726e-05 - mean_absolute_error: 0.0048 - val_loss: 1.0137e-04 - val_mean_absolute_error: 0.0075
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.7732e-05 - mean_absolute_error: 0.0063 - val_loss: 9.4316e-05 - val_mean_absolute_error: 0.0071
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.3616e-05 - mean_absolute_error: 0.0052 - val_loss: 9.0975e-05 - val_mean_absolute_error: 0.0067
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.2246e-05 - mean_absolute_error: 0.0051 - val_loss: 1.2421e-04 - val_mean_absolute_error: 0.0078
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.8265e-05 - mean_absolute_error: 0.0060 - val_loss: 1.0958e-04 - val_mean_absolute_error: 0.0081
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.3112e-05 - mean_absolute_error: 0.0056 - val_loss: 4.0088e-04 - val_mean_absolute_error: 0.0176
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.0015e-05 - mean_absolute_error: 0.0066 - val_loss: 9.2102e-05 - val_mean_absolute_error: 0.0069
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1885e-05 - mean_absolute_error: 0.0051 - val_loss: 2.0368e-04 - val_mean_absolute_error: 0.0114
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.2442e-05 - mean_absolute_error: 0.0057 - val_loss: 9.4524e-05 - val_mean_absolute_error: 0.0065
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.7890e-05 - mean_absolute_error: 0.0053 - val_loss: 9.8622e-05 - val_mean_absolute_error: 0.0073
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.7725e-05 - mean_absolute_error: 0.0049 - val_loss: 9.2143e-05 - val_mean_absolute_error: 0.0064
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.8317e-05 - mean_absolute_error: 0.0053 - val_loss: 1.0328e-04 - val_mean_absolute_error: 0.0069
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.9876e-05 - mean_absolute_error: 0.0054 - val_loss: 1.0925e-04 - val_mean_absolute_error: 0.0080
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.5215e-05 - mean_absolute_error: 0.0056 - val_loss: 8.8751e-05 - val_mean_absolute_error: 0.0063
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.3243e-05 - mean_absolute_error: 0.0056 - val_loss: 3.3306e-04 - val_mean_absolute_error: 0.0157
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0030e-04 - mean_absolute_error: 0.0069 - val_loss: 1.4299e-04 - val_mean_absolute_error: 0.0090
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.4332e-05 - mean_absolute_error: 0.0056 - val_loss: 1.0489e-04 - val_mean_absolute_error: 0.0071
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.9364e-05 - mean_absolute_error: 0.0051 - val_loss: 9.7252e-05 - val_mean_absolute_error: 0.0067
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.3563e-05 - mean_absolute_error: 0.0054 - val_loss: 9.3347e-05 - val_mean_absolute_error: 0.0065
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.0130e-05 - mean_absolute_error: 0.0056 - val_loss: 9.5344e-05 - val_mean_absolute_error: 0.0066
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.5214e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2026e-04 - val_mean_absolute_error: 0.0078
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.5641e-05 - mean_absolute_error: 0.0053 - val_loss: 9.4162e-05 - val_mean_absolute_error: 0.0066
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9813e-05 - mean_absolute_error: 0.0059 - val_loss: 9.2987e-05 - val_mean_absolute_error: 0.0070
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1377e-05 - mean_absolute_error: 0.0055 - val_loss: 9.2804e-05 - val_mean_absolute_error: 0.0064
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.8238e-05 - mean_absolute_error: 0.0050 - val_loss: 9.0398e-05 - val_mean_absolute_error: 0.0068
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1489e-05 - mean_absolute_error: 0.0056 - val_loss: 1.1032e-04 - val_mean_absolute_error: 0.0072
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3870e-05 - mean_absolute_error: 0.0050 - val_loss: 1.0049e-04 - val_mean_absolute_error: 0.0068
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.3459e-05 - mean_absolute_error: 0.0052 - val_loss: 3.1573e-04 - val_mean_absolute_error: 0.0153
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.6631e-05 - mean_absolute_error: 0.0072 - val_loss: 2.0061e-04 - val_mean_absolute_error: 0.0115
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.1356e-05 - mean_absolute_error: 0.0056 - val_loss: 8.9652e-05 - val_mean_absolute_error: 0.0067
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.8884e-05 - mean_absolute_error: 0.0050 - val_loss: 1.0900e-04 - val_mean_absolute_error: 0.0073
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.0264e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3745e-04 - val_mean_absolute_error: 0.0088
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.2869e-05 - mean_absolute_error: 0.0051 - val_loss: 8.9960e-05 - val_mean_absolute_error: 0.0063
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.1793e-05 - mean_absolute_error: 0.0057 - val_loss: 1.3895e-04 - val_mean_absolute_error: 0.0088
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.4141e-05 - mean_absolute_error: 0.0052 - val_loss: 8.7018e-05 - val_mean_absolute_error: 0.0063
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.8828e-05 - mean_absolute_error: 0.0050 - val_loss: 1.8681e-04 - val_mean_absolute_error: 0.0115
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.6215e-05 - mean_absolute_error: 0.0064 - val_loss: 9.2561e-05 - val_mean_absolute_error: 0.0065
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.4856e-05 - mean_absolute_error: 0.0055 - val_loss: 8.9346e-05 - val_mean_absolute_error: 0.0063
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.0960e-05 - mean_absolute_error: 0.0049 - val_loss: 8.8436e-05 - val_mean_absolute_error: 0.0064
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.4172e-05 - mean_absolute_error: 0.0051 - val_loss: 1.6504e-04 - val_mean_absolute_error: 0.0100
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.0497e-05 - mean_absolute_error: 0.0053 - val_loss: 9.3320e-05 - val_mean_absolute_error: 0.0064
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.2799e-05 - mean_absolute_error: 0.0053 - val_loss: 9.8399e-05 - val_mean_absolute_error: 0.0068
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.7425e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1582e-04 - val_mean_absolute_error: 0.0077
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.2429e-05 - mean_absolute_error: 0.0048 - val_loss: 1.3994e-04 - val_mean_absolute_error: 0.0095
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.3896e-05 - mean_absolute_error: 0.0060 - val_loss: 1.7967e-04 - val_mean_absolute_error: 0.0113
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.4720e-05 - mean_absolute_error: 0.0064 - val_loss: 1.2405e-04 - val_mean_absolute_error: 0.0081
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0265e-05 - mean_absolute_error: 0.0060 - val_loss: 8.8753e-05 - val_mean_absolute_error: 0.0063
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0026e-05 - mean_absolute_error: 0.0067 - val_loss: 9.0626e-05 - val_mean_absolute_error: 0.0067
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.9372e-05 - mean_absolute_error: 0.0061 - val_loss: 1.4563e-04 - val_mean_absolute_error: 0.0098
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.8452e-05 - mean_absolute_error: 0.0069 - val_loss: 9.5133e-05 - val_mean_absolute_error: 0.0065
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.3468e-05 - mean_absolute_error: 0.0057 - val_loss: 8.6830e-05 - val_mean_absolute_error: 0.0062
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.6090e-05 - mean_absolute_error: 0.0048 - val_loss: 8.8179e-05 - val_mean_absolute_error: 0.0065
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.7483e-05 - mean_absolute_error: 0.0059 - val_loss: 1.0377e-04 - val_mean_absolute_error: 0.0076
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.4043e-05 - mean_absolute_error: 0.0058 - val_loss: 9.1832e-05 - val_mean_absolute_error: 0.0064
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5281e-05 - mean_absolute_error: 0.0052 - val_loss: 9.1346e-05 - val_mean_absolute_error: 0.0068
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8943e-05 - mean_absolute_error: 0.0049 - val_loss: 1.4637e-04 - val_mean_absolute_error: 0.0091
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.2122e-05 - mean_absolute_error: 0.0050 - val_loss: 1.0109e-04 - val_mean_absolute_error: 0.0074
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.6097e-05 - mean_absolute_error: 0.0052 - val_loss: 8.6690e-05 - val_mean_absolute_error: 0.0063
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.2083e-05 - mean_absolute_error: 0.0048 - val_loss: 9.9348e-05 - val_mean_absolute_error: 0.0073
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.5490e-05 - mean_absolute_error: 0.0059 - val_loss: 8.7760e-05 - val_mean_absolute_error: 0.0062
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.3250e-05 - mean_absolute_error: 0.0054 - val_loss: 1.1555e-04 - val_mean_absolute_error: 0.0077
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.5920e-05 - mean_absolute_error: 0.0054 - val_loss: 8.7198e-05 - val_mean_absolute_error: 0.0063
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.5008e-05 - mean_absolute_error: 0.0053 - val_loss: 9.5923e-05 - val_mean_absolute_error: 0.0065
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.6606e-05 - mean_absolute_error: 0.0053 - val_loss: 8.6825e-05 - val_mean_absolute_error: 0.0062
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.5526e-05 - mean_absolute_error: 0.0052 - val_loss: 1.5515e-04 - val_mean_absolute_error: 0.0096
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.0492e-05 - mean_absolute_error: 0.0052 - val_loss: 8.6842e-05 - val_mean_absolute_error: 0.0063
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.9572e-05 - mean_absolute_error: 0.0046 - val_loss: 1.4784e-04 - val_mean_absolute_error: 0.0098
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.5960e-05 - mean_absolute_error: 0.0060 - val_loss: 9.9016e-05 - val_mean_absolute_error: 0.0073
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9911e-05 - mean_absolute_error: 0.0058 - val_loss: 9.7124e-05 - val_mean_absolute_error: 0.0067
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8570e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2269e-04 - val_mean_absolute_error: 0.0081
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1746e-05 - mean_absolute_error: 0.0055 - val_loss: 8.8065e-05 - val_mean_absolute_error: 0.0063
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8772e-05 - mean_absolute_error: 0.0050 - val_loss: 9.4562e-05 - val_mean_absolute_error: 0.0066
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.7865e-05 - mean_absolute_error: 0.0049 - val_loss: 1.2515e-04 - val_mean_absolute_error: 0.0087
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.9533e-05 - mean_absolute_error: 0.0058 - val_loss: 1.6286e-04 - val_mean_absolute_error: 0.0100
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9627e-05 - mean_absolute_error: 0.0054 - val_loss: 9.6640e-05 - val_mean_absolute_error: 0.0067
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.0228e-05 - mean_absolute_error: 0.0056 - val_loss: 1.0714e-04 - val_mean_absolute_error: 0.0077
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.0602e-05 - mean_absolute_error: 0.0062 - val_loss: 9.4139e-05 - val_mean_absolute_error: 0.0065
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.0812e-05 - mean_absolute_error: 0.0050 - val_loss: 1.0977e-04 - val_mean_absolute_error: 0.0079
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3067e-05 - mean_absolute_error: 0.0055 - val_loss: 1.0368e-04 - val_mean_absolute_error: 0.0076
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.7896e-05 - mean_absolute_error: 0.0055 - val_loss: 1.2978e-04 - val_mean_absolute_error: 0.0084
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.3714e-05 - mean_absolute_error: 0.0059 - val_loss: 9.7457e-05 - val_mean_absolute_error: 0.0067
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.9179e-05 - mean_absolute_error: 0.0063 - val_loss: 8.9968e-05 - val_mean_absolute_error: 0.0063
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.2709e-05 - mean_absolute_error: 0.0052 - val_loss: 1.1044e-04 - val_mean_absolute_error: 0.0080
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6329e-05 - mean_absolute_error: 0.0056 - val_loss: 9.0284e-05 - val_mean_absolute_error: 0.0063
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.5239e-05 - mean_absolute_error: 0.0054 - val_loss: 9.5019e-05 - val_mean_absolute_error: 0.0069
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.7898e-05 - mean_absolute_error: 0.0056 - val_loss: 1.5206e-04 - val_mean_absolute_error: 0.0095
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.4998e-05 - mean_absolute_error: 0.0052 - val_loss: 1.8253e-04 - val_mean_absolute_error: 0.0109
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.3456e-05 - mean_absolute_error: 0.0060 - val_loss: 2.0559e-04 - val_mean_absolute_error: 0.0117
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.6720e-05 - mean_absolute_error: 0.0061 - val_loss: 8.6939e-05 - val_mean_absolute_error: 0.0063
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.0588e-05 - mean_absolute_error: 0.0052 - val_loss: 8.9463e-05 - val_mean_absolute_error: 0.0063
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.2064e-05 - mean_absolute_error: 0.0051 - val_loss: 2.4977e-04 - val_mean_absolute_error: 0.0138
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4291e-04 - mean_absolute_error: 0.0087 - val_loss: 9.0928e-05 - val_mean_absolute_error: 0.0067
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6762e-05 - mean_absolute_error: 0.0053 - val_loss: 1.8189e-04 - val_mean_absolute_error: 0.0113
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.0636e-05 - mean_absolute_error: 0.0063 - val_loss: 9.5461e-05 - val_mean_absolute_error: 0.0069
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.6895e-05 - mean_absolute_error: 0.0058 - val_loss: 9.1223e-05 - val_mean_absolute_error: 0.0067

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 3s 525ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 2412944.965022053
# RMSE: 1553.365689405445
# MAE: 1106.49640500498
# MAPE: 1.4411187001330938 %
#
# Model evalution on validate set
# MSE: 7294590.745620097
# RMSE: 2700.850004280152
# MAE: 1907.193117252066
# MAPE: 1.6735054212676206 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step

# %%
y_pred_30_days
# Out:
# array([[130155.9  ],
#        [130471.06 ],
#        [130258.08 ],
#        [130170.25 ],
#        [130423.94 ],
#        [130365.88 ],
#        [130392.016],
#        [130399.14 ],
#        [130384.805],
#        [130390.69 ],
#        [130388.28 ],
#        [130387.98 ],
#        [130388.83 ],
#        [130388.32 ],
#        [130388.53 ],
#        [130388.516],
#        [130388.46 ],
#        [130388.53 ],
#        [130388.49 ],
#        [130388.48 ],
#        [130388.49 ],
#        [130388.516],
#        [130388.49 ],
#        [130388.516],
#        [130388.48 ],
#        [130388.516],
#        [130388.49 ],
#        [130388.51 ],
#        [130388.49 ],
#        [130388.51 ],
#        [130388.48 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Predict the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
