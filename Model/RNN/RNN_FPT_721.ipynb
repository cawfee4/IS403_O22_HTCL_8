# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: FPT - Test/Train/Vaildation: 70/20/10
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1552.6938572917852
# - MAE: 1099.2845959910358
# - MAPE: 1.4273695615435715 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 0  # 7 2 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.tail()
# Out:
#              close
# time
# 2024-05-27  132800
# 2024-05-28  137000
# 2024-05-29  135700
# 2024-05-30  135000
# 2024-05-31  134600

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((908, 10), (908,), (251, 10), (251,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 43ms/step - loss: 0.0134 - mean_absolute_error: 0.0752 - val_loss: 0.0015 - val_mean_absolute_error: 0.0304
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.3830e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0011 - val_mean_absolute_error: 0.0243
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3699e-04 - mean_absolute_error: 0.0103 - val_loss: 5.0948e-04 - val_mean_absolute_error: 0.0154
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8219e-04 - mean_absolute_error: 0.0090 - val_loss: 4.9132e-04 - val_mean_absolute_error: 0.0152
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0039e-04 - mean_absolute_error: 0.0091 - val_loss: 5.7397e-04 - val_mean_absolute_error: 0.0168
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4251e-04 - mean_absolute_error: 0.0077 - val_loss: 4.2564e-04 - val_mean_absolute_error: 0.0142
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.4379e-04 - mean_absolute_error: 0.0079 - val_loss: 6.1403e-04 - val_mean_absolute_error: 0.0183
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5981e-04 - mean_absolute_error: 0.0082 - val_loss: 6.2350e-04 - val_mean_absolute_error: 0.0189
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3117e-04 - mean_absolute_error: 0.0076 - val_loss: 4.1478e-04 - val_mean_absolute_error: 0.0144
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3614e-04 - mean_absolute_error: 0.0078 - val_loss: 4.8849e-04 - val_mean_absolute_error: 0.0162
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0974e-04 - mean_absolute_error: 0.0069 - val_loss: 2.2447e-04 - val_mean_absolute_error: 0.0116
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0801e-04 - mean_absolute_error: 0.0070 - val_loss: 3.0592e-04 - val_mean_absolute_error: 0.0150
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5615e-04 - mean_absolute_error: 0.0084 - val_loss: 3.0445e-04 - val_mean_absolute_error: 0.0121
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0297e-04 - mean_absolute_error: 0.0066 - val_loss: 4.7356e-04 - val_mean_absolute_error: 0.0165
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0935e-04 - mean_absolute_error: 0.0068 - val_loss: 2.1776e-04 - val_mean_absolute_error: 0.0103
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0679e-04 - mean_absolute_error: 0.0065 - val_loss: 3.0481e-04 - val_mean_absolute_error: 0.0125
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2003e-04 - mean_absolute_error: 0.0073 - val_loss: 2.9628e-04 - val_mean_absolute_error: 0.0122
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.4626e-05 - mean_absolute_error: 0.0064 - val_loss: 3.0159e-04 - val_mean_absolute_error: 0.0125
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1690e-04 - mean_absolute_error: 0.0074 - val_loss: 4.9773e-04 - val_mean_absolute_error: 0.0178
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0921e-04 - mean_absolute_error: 0.0069 - val_loss: 2.5530e-04 - val_mean_absolute_error: 0.0112
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0289e-04 - mean_absolute_error: 0.0067 - val_loss: 3.5218e-04 - val_mean_absolute_error: 0.0141
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1182e-04 - mean_absolute_error: 0.0068 - val_loss: 1.6942e-04 - val_mean_absolute_error: 0.0093
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.1267e-04 - mean_absolute_error: 0.0067 - val_loss: 5.9816e-04 - val_mean_absolute_error: 0.0204
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1030e-04 - mean_absolute_error: 0.0074 - val_loss: 1.9026e-04 - val_mean_absolute_error: 0.0095
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1189e-04 - mean_absolute_error: 0.0071 - val_loss: 5.7411e-04 - val_mean_absolute_error: 0.0199
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2545e-04 - mean_absolute_error: 0.0075 - val_loss: 2.1229e-04 - val_mean_absolute_error: 0.0121
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0971e-04 - mean_absolute_error: 0.0072 - val_loss: 6.4818e-04 - val_mean_absolute_error: 0.0216
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1761e-04 - mean_absolute_error: 0.0073 - val_loss: 2.2793e-04 - val_mean_absolute_error: 0.0107
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.1300e-05 - mean_absolute_error: 0.0061 - val_loss: 2.7415e-04 - val_mean_absolute_error: 0.0122
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0510e-04 - mean_absolute_error: 0.0067 - val_loss: 1.9006e-04 - val_mean_absolute_error: 0.0096
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.7665e-05 - mean_absolute_error: 0.0056 - val_loss: 3.1918e-04 - val_mean_absolute_error: 0.0135
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.4358e-05 - mean_absolute_error: 0.0063 - val_loss: 7.8333e-04 - val_mean_absolute_error: 0.0246
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5091e-04 - mean_absolute_error: 0.0084 - val_loss: 1.4219e-04 - val_mean_absolute_error: 0.0087
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0102e-04 - mean_absolute_error: 0.0066 - val_loss: 2.0995e-04 - val_mean_absolute_error: 0.0102
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.9204e-05 - mean_absolute_error: 0.0059 - val_loss: 1.4059e-04 - val_mean_absolute_error: 0.0087
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0027e-04 - mean_absolute_error: 0.0069 - val_loss: 1.4460e-04 - val_mean_absolute_error: 0.0084
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.4813e-05 - mean_absolute_error: 0.0059 - val_loss: 1.8531e-04 - val_mean_absolute_error: 0.0096
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.3644e-05 - mean_absolute_error: 0.0058 - val_loss: 1.3239e-04 - val_mean_absolute_error: 0.0086
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.7349e-05 - mean_absolute_error: 0.0057 - val_loss: 1.3527e-04 - val_mean_absolute_error: 0.0089
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.1190e-05 - mean_absolute_error: 0.0059 - val_loss: 1.2929e-04 - val_mean_absolute_error: 0.0083
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.2558e-05 - mean_absolute_error: 0.0057 - val_loss: 1.3313e-04 - val_mean_absolute_error: 0.0088
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.8172e-05 - mean_absolute_error: 0.0059 - val_loss: 1.3531e-04 - val_mean_absolute_error: 0.0082
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.4643e-05 - mean_absolute_error: 0.0062 - val_loss: 5.0370e-04 - val_mean_absolute_error: 0.0190
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1328e-04 - mean_absolute_error: 0.0072 - val_loss: 1.8409e-04 - val_mean_absolute_error: 0.0095
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1153e-04 - mean_absolute_error: 0.0069 - val_loss: 1.5336e-04 - val_mean_absolute_error: 0.0085
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.4437e-05 - mean_absolute_error: 0.0058 - val_loss: 1.9706e-04 - val_mean_absolute_error: 0.0101
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1931e-05 - mean_absolute_error: 0.0058 - val_loss: 2.1556e-04 - val_mean_absolute_error: 0.0107
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0541e-05 - mean_absolute_error: 0.0059 - val_loss: 1.4894e-04 - val_mean_absolute_error: 0.0098
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.7272e-05 - mean_absolute_error: 0.0057 - val_loss: 1.9781e-04 - val_mean_absolute_error: 0.0102
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0197e-04 - mean_absolute_error: 0.0067 - val_loss: 1.1764e-04 - val_mean_absolute_error: 0.0076
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1564e-05 - mean_absolute_error: 0.0058 - val_loss: 1.6137e-04 - val_mean_absolute_error: 0.0090
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.7047e-05 - mean_absolute_error: 0.0057 - val_loss: 1.1878e-04 - val_mean_absolute_error: 0.0077
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.5580e-05 - mean_absolute_error: 0.0055 - val_loss: 1.1492e-04 - val_mean_absolute_error: 0.0078
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.5813e-05 - mean_absolute_error: 0.0063 - val_loss: 1.3947e-04 - val_mean_absolute_error: 0.0094
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2803e-04 - mean_absolute_error: 0.0078 - val_loss: 4.2345e-04 - val_mean_absolute_error: 0.0175
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.1896e-05 - mean_absolute_error: 0.0062 - val_loss: 4.5105e-04 - val_mean_absolute_error: 0.0181
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7760e-05 - mean_absolute_error: 0.0067 - val_loss: 1.5298e-04 - val_mean_absolute_error: 0.0086
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.8856e-05 - mean_absolute_error: 0.0056 - val_loss: 1.0830e-04 - val_mean_absolute_error: 0.0075
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.7338e-05 - mean_absolute_error: 0.0055 - val_loss: 3.0513e-04 - val_mean_absolute_error: 0.0142
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.8199e-05 - mean_absolute_error: 0.0056 - val_loss: 1.0929e-04 - val_mean_absolute_error: 0.0077
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.1311e-05 - mean_absolute_error: 0.0057 - val_loss: 1.5956e-04 - val_mean_absolute_error: 0.0090
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8780e-05 - mean_absolute_error: 0.0053 - val_loss: 1.8353e-04 - val_mean_absolute_error: 0.0114
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.7322e-05 - mean_absolute_error: 0.0056 - val_loss: 1.2057e-04 - val_mean_absolute_error: 0.0085
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.0868e-05 - mean_absolute_error: 0.0055 - val_loss: 1.6395e-04 - val_mean_absolute_error: 0.0092
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.5611e-05 - mean_absolute_error: 0.0057 - val_loss: 1.6439e-04 - val_mean_absolute_error: 0.0093
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.6210e-05 - mean_absolute_error: 0.0056 - val_loss: 1.0551e-04 - val_mean_absolute_error: 0.0073
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9855e-05 - mean_absolute_error: 0.0052 - val_loss: 1.0487e-04 - val_mean_absolute_error: 0.0071
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.8970e-05 - mean_absolute_error: 0.0053 - val_loss: 1.0591e-04 - val_mean_absolute_error: 0.0073
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.6384e-05 - mean_absolute_error: 0.0058 - val_loss: 1.4949e-04 - val_mean_absolute_error: 0.0087
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.1912e-05 - mean_absolute_error: 0.0057 - val_loss: 1.7826e-04 - val_mean_absolute_error: 0.0099
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6079e-05 - mean_absolute_error: 0.0052 - val_loss: 1.2127e-04 - val_mean_absolute_error: 0.0075
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.5436e-05 - mean_absolute_error: 0.0052 - val_loss: 1.2593e-04 - val_mean_absolute_error: 0.0077
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6583e-05 - mean_absolute_error: 0.0053 - val_loss: 1.5534e-04 - val_mean_absolute_error: 0.0090
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0058e-05 - mean_absolute_error: 0.0058 - val_loss: 1.0387e-04 - val_mean_absolute_error: 0.0070
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.0385e-05 - mean_absolute_error: 0.0053 - val_loss: 1.9473e-04 - val_mean_absolute_error: 0.0106
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.8426e-05 - mean_absolute_error: 0.0052 - val_loss: 1.1412e-04 - val_mean_absolute_error: 0.0083
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.3582e-05 - mean_absolute_error: 0.0055 - val_loss: 1.0291e-04 - val_mean_absolute_error: 0.0069
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.1144e-05 - mean_absolute_error: 0.0056 - val_loss: 1.0955e-04 - val_mean_absolute_error: 0.0071
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9514e-05 - mean_absolute_error: 0.0052 - val_loss: 9.9313e-05 - val_mean_absolute_error: 0.0068
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.4181e-05 - mean_absolute_error: 0.0057 - val_loss: 1.2024e-04 - val_mean_absolute_error: 0.0075
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.0197e-05 - mean_absolute_error: 0.0054 - val_loss: 3.3413e-04 - val_mean_absolute_error: 0.0154
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.4194e-05 - mean_absolute_error: 0.0061 - val_loss: 1.3776e-04 - val_mean_absolute_error: 0.0083
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.0707e-05 - mean_absolute_error: 0.0055 - val_loss: 2.5788e-04 - val_mean_absolute_error: 0.0129
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.6401e-05 - mean_absolute_error: 0.0060 - val_loss: 1.3393e-04 - val_mean_absolute_error: 0.0081
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.9374e-05 - mean_absolute_error: 0.0056 - val_loss: 1.2065e-04 - val_mean_absolute_error: 0.0076
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.7473e-05 - mean_absolute_error: 0.0047 - val_loss: 1.3407e-04 - val_mean_absolute_error: 0.0081
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.5789e-05 - mean_absolute_error: 0.0056 - val_loss: 1.0753e-04 - val_mean_absolute_error: 0.0070
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.3729e-05 - mean_absolute_error: 0.0053 - val_loss: 1.0683e-04 - val_mean_absolute_error: 0.0070
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.1049e-05 - mean_absolute_error: 0.0056 - val_loss: 1.2296e-04 - val_mean_absolute_error: 0.0076
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.2030e-05 - mean_absolute_error: 0.0050 - val_loss: 1.3013e-04 - val_mean_absolute_error: 0.0080
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.4596e-05 - mean_absolute_error: 0.0049 - val_loss: 1.6787e-04 - val_mean_absolute_error: 0.0096
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.2569e-05 - mean_absolute_error: 0.0053 - val_loss: 1.3414e-04 - val_mean_absolute_error: 0.0082
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8586e-05 - mean_absolute_error: 0.0054 - val_loss: 1.0177e-04 - val_mean_absolute_error: 0.0068
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.8639e-05 - mean_absolute_error: 0.0053 - val_loss: 1.0888e-04 - val_mean_absolute_error: 0.0071
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.4585e-05 - mean_absolute_error: 0.0061 - val_loss: 1.3488e-04 - val_mean_absolute_error: 0.0082
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.4026e-05 - mean_absolute_error: 0.0057 - val_loss: 1.0669e-04 - val_mean_absolute_error: 0.0070
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.9312e-05 - mean_absolute_error: 0.0053 - val_loss: 1.4904e-04 - val_mean_absolute_error: 0.0090
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.0585e-05 - mean_absolute_error: 0.0051 - val_loss: 1.8880e-04 - val_mean_absolute_error: 0.0107
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.5686e-05 - mean_absolute_error: 0.0059 - val_loss: 1.6268e-04 - val_mean_absolute_error: 0.0096
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.6330e-05 - mean_absolute_error: 0.0058 - val_loss: 9.9116e-05 - val_mean_absolute_error: 0.0067
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.6688e-05 - mean_absolute_error: 0.0059 - val_loss: 1.2084e-04 - val_mean_absolute_error: 0.0087
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.0243e-05 - mean_absolute_error: 0.0051 - val_loss: 9.5237e-05 - val_mean_absolute_error: 0.0066
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.8593e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2972e-04 - val_mean_absolute_error: 0.0091
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.3836e-05 - mean_absolute_error: 0.0059 - val_loss: 1.3790e-04 - val_mean_absolute_error: 0.0095
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.2002e-05 - mean_absolute_error: 0.0053 - val_loss: 1.4776e-04 - val_mean_absolute_error: 0.0099
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.1785e-05 - mean_absolute_error: 0.0057 - val_loss: 9.4449e-05 - val_mean_absolute_error: 0.0065
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9843e-05 - mean_absolute_error: 0.0054 - val_loss: 1.5752e-04 - val_mean_absolute_error: 0.0094
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.3985e-05 - mean_absolute_error: 0.0058 - val_loss: 1.5305e-04 - val_mean_absolute_error: 0.0093
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.3142e-05 - mean_absolute_error: 0.0051 - val_loss: 9.2122e-05 - val_mean_absolute_error: 0.0064
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.9114e-05 - mean_absolute_error: 0.0053 - val_loss: 1.0433e-04 - val_mean_absolute_error: 0.0078
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.8368e-05 - mean_absolute_error: 0.0061 - val_loss: 9.0038e-05 - val_mean_absolute_error: 0.0066
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.6745e-05 - mean_absolute_error: 0.0050 - val_loss: 8.9845e-05 - val_mean_absolute_error: 0.0067
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.2727e-05 - mean_absolute_error: 0.0050 - val_loss: 1.4770e-04 - val_mean_absolute_error: 0.0091
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4348e-05 - mean_absolute_error: 0.0052 - val_loss: 1.6033e-04 - val_mean_absolute_error: 0.0096
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.3808e-05 - mean_absolute_error: 0.0052 - val_loss: 8.8769e-05 - val_mean_absolute_error: 0.0065
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.3573e-05 - mean_absolute_error: 0.0046 - val_loss: 1.2080e-04 - val_mean_absolute_error: 0.0077
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3165e-05 - mean_absolute_error: 0.0053 - val_loss: 1.1706e-04 - val_mean_absolute_error: 0.0084
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.4062e-05 - mean_absolute_error: 0.0052 - val_loss: 8.8581e-05 - val_mean_absolute_error: 0.0065
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.7437e-05 - mean_absolute_error: 0.0052 - val_loss: 8.9032e-05 - val_mean_absolute_error: 0.0065
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.6606e-05 - mean_absolute_error: 0.0050 - val_loss: 1.0699e-04 - val_mean_absolute_error: 0.0079
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.7849e-05 - mean_absolute_error: 0.0068 - val_loss: 1.1417e-04 - val_mean_absolute_error: 0.0083
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.3353e-05 - mean_absolute_error: 0.0063 - val_loss: 1.2512e-04 - val_mean_absolute_error: 0.0079
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.1666e-05 - mean_absolute_error: 0.0060 - val_loss: 9.1420e-05 - val_mean_absolute_error: 0.0064
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.0102e-05 - mean_absolute_error: 0.0048 - val_loss: 8.9753e-05 - val_mean_absolute_error: 0.0067
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.4238e-05 - mean_absolute_error: 0.0057 - val_loss: 9.4767e-05 - val_mean_absolute_error: 0.0071
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4451e-05 - mean_absolute_error: 0.0053 - val_loss: 8.9734e-05 - val_mean_absolute_error: 0.0063
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.2915e-05 - mean_absolute_error: 0.0052 - val_loss: 1.7006e-04 - val_mean_absolute_error: 0.0101
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8268e-05 - mean_absolute_error: 0.0053 - val_loss: 1.1118e-04 - val_mean_absolute_error: 0.0081
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.5930e-05 - mean_absolute_error: 0.0052 - val_loss: 9.5149e-05 - val_mean_absolute_error: 0.0066
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.5418e-05 - mean_absolute_error: 0.0052 - val_loss: 8.9602e-05 - val_mean_absolute_error: 0.0066
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5781e-05 - mean_absolute_error: 0.0049 - val_loss: 8.8446e-05 - val_mean_absolute_error: 0.0064
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.6861e-05 - mean_absolute_error: 0.0052 - val_loss: 1.0136e-04 - val_mean_absolute_error: 0.0068
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.2177e-05 - mean_absolute_error: 0.0050 - val_loss: 8.8943e-05 - val_mean_absolute_error: 0.0065
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.1832e-05 - mean_absolute_error: 0.0054 - val_loss: 1.1662e-04 - val_mean_absolute_error: 0.0076
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.4659e-05 - mean_absolute_error: 0.0054 - val_loss: 9.1774e-05 - val_mean_absolute_error: 0.0064
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6884e-05 - mean_absolute_error: 0.0057 - val_loss: 1.0655e-04 - val_mean_absolute_error: 0.0078
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.1066e-05 - mean_absolute_error: 0.0061 - val_loss: 1.1970e-04 - val_mean_absolute_error: 0.0086
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.9408e-05 - mean_absolute_error: 0.0058 - val_loss: 8.8468e-05 - val_mean_absolute_error: 0.0065
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.3841e-05 - mean_absolute_error: 0.0052 - val_loss: 9.2606e-05 - val_mean_absolute_error: 0.0069
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4739e-05 - mean_absolute_error: 0.0046 - val_loss: 1.3292e-04 - val_mean_absolute_error: 0.0084
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3087e-05 - mean_absolute_error: 0.0052 - val_loss: 8.8008e-05 - val_mean_absolute_error: 0.0064
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3473e-05 - mean_absolute_error: 0.0056 - val_loss: 1.2318e-04 - val_mean_absolute_error: 0.0079
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.7132e-05 - mean_absolute_error: 0.0049 - val_loss: 8.8528e-05 - val_mean_absolute_error: 0.0063
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.6149e-05 - mean_absolute_error: 0.0053 - val_loss: 9.3088e-05 - val_mean_absolute_error: 0.0069
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.1411e-05 - mean_absolute_error: 0.0051 - val_loss: 9.9066e-05 - val_mean_absolute_error: 0.0067
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.4897e-05 - mean_absolute_error: 0.0048 - val_loss: 1.3480e-04 - val_mean_absolute_error: 0.0085
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.1441e-05 - mean_absolute_error: 0.0051 - val_loss: 9.0200e-05 - val_mean_absolute_error: 0.0067
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 4.8955e-05 - mean_absolute_error: 0.0047 - val_loss: 1.9018e-04 - val_mean_absolute_error: 0.0111
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.5817e-05 - mean_absolute_error: 0.0057 - val_loss: 1.0035e-04 - val_mean_absolute_error: 0.0067
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.7870e-05 - mean_absolute_error: 0.0050 - val_loss: 9.2817e-05 - val_mean_absolute_error: 0.0064
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.1276e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1102e-04 - val_mean_absolute_error: 0.0073
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.1140e-05 - mean_absolute_error: 0.0051 - val_loss: 8.9654e-05 - val_mean_absolute_error: 0.0064
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6355e-05 - mean_absolute_error: 0.0052 - val_loss: 1.9143e-04 - val_mean_absolute_error: 0.0109
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.5093e-05 - mean_absolute_error: 0.0063 - val_loss: 1.3386e-04 - val_mean_absolute_error: 0.0093
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.9471e-05 - mean_absolute_error: 0.0061 - val_loss: 1.2598e-04 - val_mean_absolute_error: 0.0082
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.6303e-05 - mean_absolute_error: 0.0049 - val_loss: 9.2970e-05 - val_mean_absolute_error: 0.0064
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6106e-05 - mean_absolute_error: 0.0051 - val_loss: 1.4084e-04 - val_mean_absolute_error: 0.0090
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.2718e-05 - mean_absolute_error: 0.0053 - val_loss: 1.0683e-04 - val_mean_absolute_error: 0.0071
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 7.1616e-05 - mean_absolute_error: 0.0053 - val_loss: 9.6843e-05 - val_mean_absolute_error: 0.0066
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.3693e-05 - mean_absolute_error: 0.0047 - val_loss: 1.0403e-04 - val_mean_absolute_error: 0.0077
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.1796e-05 - mean_absolute_error: 0.0063 - val_loss: 8.8802e-05 - val_mean_absolute_error: 0.0065
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.6932e-05 - mean_absolute_error: 0.0054 - val_loss: 1.1068e-04 - val_mean_absolute_error: 0.0080
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.0378e-05 - mean_absolute_error: 0.0052 - val_loss: 1.9241e-04 - val_mean_absolute_error: 0.0111
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.2609e-05 - mean_absolute_error: 0.0059 - val_loss: 1.0618e-04 - val_mean_absolute_error: 0.0072
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8064e-05 - mean_absolute_error: 0.0052 - val_loss: 1.1250e-04 - val_mean_absolute_error: 0.0081
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.4378e-05 - mean_absolute_error: 0.0055 - val_loss: 9.9169e-05 - val_mean_absolute_error: 0.0067
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.9555e-05 - mean_absolute_error: 0.0048 - val_loss: 1.1249e-04 - val_mean_absolute_error: 0.0074
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.5296e-05 - mean_absolute_error: 0.0055 - val_loss: 1.5287e-04 - val_mean_absolute_error: 0.0095
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.1204e-05 - mean_absolute_error: 0.0058 - val_loss: 9.0185e-05 - val_mean_absolute_error: 0.0064
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9543e-05 - mean_absolute_error: 0.0051 - val_loss: 9.0119e-05 - val_mean_absolute_error: 0.0066
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4810e-05 - mean_absolute_error: 0.0053 - val_loss: 1.0227e-04 - val_mean_absolute_error: 0.0069
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1681e-05 - mean_absolute_error: 0.0052 - val_loss: 9.5433e-05 - val_mean_absolute_error: 0.0071
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.2691e-05 - mean_absolute_error: 0.0054 - val_loss: 8.8777e-05 - val_mean_absolute_error: 0.0064
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4119e-05 - mean_absolute_error: 0.0054 - val_loss: 1.1213e-04 - val_mean_absolute_error: 0.0081
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.3904e-05 - mean_absolute_error: 0.0061 - val_loss: 1.3707e-04 - val_mean_absolute_error: 0.0093
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4378e-05 - mean_absolute_error: 0.0057 - val_loss: 1.1354e-04 - val_mean_absolute_error: 0.0076
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6030e-05 - mean_absolute_error: 0.0050 - val_loss: 1.6668e-04 - val_mean_absolute_error: 0.0101
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9674e-05 - mean_absolute_error: 0.0065 - val_loss: 2.1107e-04 - val_mean_absolute_error: 0.0120
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.5580e-05 - mean_absolute_error: 0.0060 - val_loss: 1.0123e-04 - val_mean_absolute_error: 0.0069
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.4173e-05 - mean_absolute_error: 0.0047 - val_loss: 9.1889e-05 - val_mean_absolute_error: 0.0064
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3725e-05 - mean_absolute_error: 0.0055 - val_loss: 1.4534e-04 - val_mean_absolute_error: 0.0091
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.4947e-05 - mean_absolute_error: 0.0058 - val_loss: 1.1658e-04 - val_mean_absolute_error: 0.0082
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5501e-05 - mean_absolute_error: 0.0053 - val_loss: 9.6778e-05 - val_mean_absolute_error: 0.0066
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 7.1336e-05 - mean_absolute_error: 0.0056 - val_loss: 2.7839e-04 - val_mean_absolute_error: 0.0141
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.5851e-05 - mean_absolute_error: 0.0065 - val_loss: 1.0740e-04 - val_mean_absolute_error: 0.0072
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.8886e-05 - mean_absolute_error: 0.0051 - val_loss: 1.0898e-04 - val_mean_absolute_error: 0.0079
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.5826e-05 - mean_absolute_error: 0.0052 - val_loss: 8.7703e-05 - val_mean_absolute_error: 0.0063
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.0381e-05 - mean_absolute_error: 0.0053 - val_loss: 1.0432e-04 - val_mean_absolute_error: 0.0070
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.5128e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1330e-04 - val_mean_absolute_error: 0.0076
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.6467e-05 - mean_absolute_error: 0.0053 - val_loss: 8.8006e-05 - val_mean_absolute_error: 0.0063
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6998e-05 - mean_absolute_error: 0.0049 - val_loss: 1.0832e-04 - val_mean_absolute_error: 0.0072
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.1314e-05 - mean_absolute_error: 0.0051 - val_loss: 1.5679e-04 - val_mean_absolute_error: 0.0097
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.0848e-05 - mean_absolute_error: 0.0054 - val_loss: 9.1174e-05 - val_mean_absolute_error: 0.0063
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.3625e-05 - mean_absolute_error: 0.0055 - val_loss: 1.3141e-04 - val_mean_absolute_error: 0.0090
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.2493e-05 - mean_absolute_error: 0.0055 - val_loss: 9.2942e-05 - val_mean_absolute_error: 0.0065
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.2667e-05 - mean_absolute_error: 0.0060 - val_loss: 1.6037e-04 - val_mean_absolute_error: 0.0103
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.3625e-05 - mean_absolute_error: 0.0053 - val_loss: 1.0596e-04 - val_mean_absolute_error: 0.0072
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9916e-05 - mean_absolute_error: 0.0056 - val_loss: 1.3951e-04 - val_mean_absolute_error: 0.0089
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.6480e-05 - mean_absolute_error: 0.0059 - val_loss: 9.0910e-05 - val_mean_absolute_error: 0.0067
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.9316e-05 - mean_absolute_error: 0.0050 - val_loss: 8.8454e-05 - val_mean_absolute_error: 0.0064

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 2410858.2144716424
# RMSE: 1552.6938572917852
# MAE: 1099.2845959910358
# MAPE: 1.4273695615435715 %
#
# Model evalution on validate set
# MSE: 7875382.545749129
# RMSE: 2806.311199020723
# MAE: 1974.609375
# MAPE: 1.7273275631432967 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step

# %%
y_pred_30_days
# Out:
# array([[128213.56 ],
#        [128830.875],
#        [128358.43 ],
#        [128387.86 ],
#        [128630.55 ],
#        [128571.13 ],
#        [128613.21 ],
#        [128606.44 ],
#        [128599.55 ],
#        [128602.88 ],
#        [128600.28 ],
#        [128600.98 ],
#        [128601.05 ],
#        [128600.91 ],
#        [128601.06 ],
#        [128600.984],
#        [128601.016],
#        [128600.984],
#        [128601.   ],
#        [128600.984],
#        [128600.984],
#        [128601.   ],
#        [128601.016],
#        [128601.   ],
#        [128600.984],
#        [128601.   ],
#        [128601.   ],
#        [128601.016],
#        [128601.   ],
#        [128600.984],
#        [128601.   ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Forecast Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Forecast the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
