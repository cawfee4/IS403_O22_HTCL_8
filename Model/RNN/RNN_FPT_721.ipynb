# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: FPT - Test/Train/Vaildation: 70/20/10
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1551.2919230375933
# - MAE: 1092.3033024153387
# - MAPE: 1.4176190654373286 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 0  # 7 2 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01  19270
# 2019-03-04  19440
# 2019-03-05  19390
# 2019-03-06  19270
# 2019-03-07  19330

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((908, 10), (908,), (251, 10), (251,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - loss: 0.0066 - mean_absolute_error: 0.0599 - val_loss: 9.4340e-04 - val_mean_absolute_error: 0.0241
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 4.2655e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0012 - val_mean_absolute_error: 0.0245
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.3453e-04 - mean_absolute_error: 0.0119 - val_loss: 8.2428e-04 - val_mean_absolute_error: 0.0196
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8878e-04 - mean_absolute_error: 0.0116 - val_loss: 7.4189e-04 - val_mean_absolute_error: 0.0187
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7769e-04 - mean_absolute_error: 0.0110 - val_loss: 6.7960e-04 - val_mean_absolute_error: 0.0179
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1125e-04 - mean_absolute_error: 0.0096 - val_loss: 8.6459e-04 - val_mean_absolute_error: 0.0216
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8417e-04 - mean_absolute_error: 0.0090 - val_loss: 4.9399e-04 - val_mean_absolute_error: 0.0152
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.8514e-04 - mean_absolute_error: 0.0088 - val_loss: 4.1476e-04 - val_mean_absolute_error: 0.0139
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7766e-04 - mean_absolute_error: 0.0092 - val_loss: 4.6231e-04 - val_mean_absolute_error: 0.0149
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6729e-04 - mean_absolute_error: 0.0086 - val_loss: 4.9694e-04 - val_mean_absolute_error: 0.0160
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6124e-04 - mean_absolute_error: 0.0084 - val_loss: 2.7972e-04 - val_mean_absolute_error: 0.0126
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6318e-04 - mean_absolute_error: 0.0086 - val_loss: 7.1620e-04 - val_mean_absolute_error: 0.0208
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.8247e-04 - mean_absolute_error: 0.0090 - val_loss: 5.0169e-04 - val_mean_absolute_error: 0.0164
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2979e-04 - mean_absolute_error: 0.0075 - val_loss: 2.4358e-04 - val_mean_absolute_error: 0.0118
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3226e-04 - mean_absolute_error: 0.0076 - val_loss: 2.3051e-04 - val_mean_absolute_error: 0.0110
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7991e-04 - mean_absolute_error: 0.0091 - val_loss: 5.4202e-04 - val_mean_absolute_error: 0.0179
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3263e-04 - mean_absolute_error: 0.0076 - val_loss: 4.2102e-04 - val_mean_absolute_error: 0.0152
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.2016e-04 - mean_absolute_error: 0.0074 - val_loss: 4.0266e-04 - val_mean_absolute_error: 0.0148
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.5491e-04 - mean_absolute_error: 0.0082 - val_loss: 3.4705e-04 - val_mean_absolute_error: 0.0135
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2786e-04 - mean_absolute_error: 0.0073 - val_loss: 4.2596e-04 - val_mean_absolute_error: 0.0157
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3221e-04 - mean_absolute_error: 0.0078 - val_loss: 3.0029e-04 - val_mean_absolute_error: 0.0125
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1028e-04 - mean_absolute_error: 0.0072 - val_loss: 6.1504e-04 - val_mean_absolute_error: 0.0204
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3097e-04 - mean_absolute_error: 0.0078 - val_loss: 5.7890e-04 - val_mean_absolute_error: 0.0217
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.1577e-04 - mean_absolute_error: 0.0128 - val_loss: 4.1051e-04 - val_mean_absolute_error: 0.0154
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2349e-04 - mean_absolute_error: 0.0072 - val_loss: 2.0251e-04 - val_mean_absolute_error: 0.0099
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0244e-04 - mean_absolute_error: 0.0067 - val_loss: 1.8461e-04 - val_mean_absolute_error: 0.0105
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4794e-04 - mean_absolute_error: 0.0084 - val_loss: 2.7042e-04 - val_mean_absolute_error: 0.0120
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2264e-04 - mean_absolute_error: 0.0073 - val_loss: 4.0018e-04 - val_mean_absolute_error: 0.0157
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1518e-04 - mean_absolute_error: 0.0071 - val_loss: 2.9134e-04 - val_mean_absolute_error: 0.0128
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1113e-04 - mean_absolute_error: 0.0069 - val_loss: 2.0068e-04 - val_mean_absolute_error: 0.0100
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.9713e-05 - mean_absolute_error: 0.0066 - val_loss: 1.7175e-04 - val_mean_absolute_error: 0.0091
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.6206e-05 - mean_absolute_error: 0.0064 - val_loss: 1.5997e-04 - val_mean_absolute_error: 0.0097
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0604e-04 - mean_absolute_error: 0.0071 - val_loss: 1.5009e-04 - val_mean_absolute_error: 0.0092
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0100e-04 - mean_absolute_error: 0.0069 - val_loss: 4.6097e-04 - val_mean_absolute_error: 0.0177
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.1433e-04 - mean_absolute_error: 0.0073 - val_loss: 1.7418e-04 - val_mean_absolute_error: 0.0105
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0778e-04 - mean_absolute_error: 0.0067 - val_loss: 2.3626e-04 - val_mean_absolute_error: 0.0114
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.8817e-05 - mean_absolute_error: 0.0062 - val_loss: 4.5776e-04 - val_mean_absolute_error: 0.0178
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0178e-04 - mean_absolute_error: 0.0068 - val_loss: 2.0213e-04 - val_mean_absolute_error: 0.0103
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.0012e-05 - mean_absolute_error: 0.0059 - val_loss: 1.3332e-04 - val_mean_absolute_error: 0.0083
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.8855e-05 - mean_absolute_error: 0.0060 - val_loss: 1.9103e-04 - val_mean_absolute_error: 0.0100
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4055e-04 - mean_absolute_error: 0.0080 - val_loss: 1.5890e-04 - val_mean_absolute_error: 0.0088
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1942e-04 - mean_absolute_error: 0.0071 - val_loss: 1.8068e-04 - val_mean_absolute_error: 0.0097
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.7867e-05 - mean_absolute_error: 0.0061 - val_loss: 3.3352e-04 - val_mean_absolute_error: 0.0161
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3291e-04 - mean_absolute_error: 0.0079 - val_loss: 1.2547e-04 - val_mean_absolute_error: 0.0082
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.3678e-05 - mean_absolute_error: 0.0060 - val_loss: 1.8000e-04 - val_mean_absolute_error: 0.0110
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.5660e-05 - mean_absolute_error: 0.0064 - val_loss: 2.3021e-04 - val_mean_absolute_error: 0.0115
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.0447e-05 - mean_absolute_error: 0.0063 - val_loss: 1.5795e-04 - val_mean_absolute_error: 0.0089
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.7486e-05 - mean_absolute_error: 0.0058 - val_loss: 1.1652e-04 - val_mean_absolute_error: 0.0076
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.4088e-05 - mean_absolute_error: 0.0058 - val_loss: 2.0615e-04 - val_mean_absolute_error: 0.0107
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.6202e-05 - mean_absolute_error: 0.0063 - val_loss: 1.2030e-04 - val_mean_absolute_error: 0.0081
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.9448e-05 - mean_absolute_error: 0.0063 - val_loss: 3.2193e-04 - val_mean_absolute_error: 0.0146
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0143e-04 - mean_absolute_error: 0.0065 - val_loss: 1.4571e-04 - val_mean_absolute_error: 0.0085
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.5505e-05 - mean_absolute_error: 0.0055 - val_loss: 1.3726e-04 - val_mean_absolute_error: 0.0082
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.4806e-05 - mean_absolute_error: 0.0060 - val_loss: 2.0701e-04 - val_mean_absolute_error: 0.0108
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.4493e-05 - mean_absolute_error: 0.0057 - val_loss: 1.1061e-04 - val_mean_absolute_error: 0.0074
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.4136e-05 - mean_absolute_error: 0.0060 - val_loss: 6.7948e-04 - val_mean_absolute_error: 0.0235
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2869e-04 - mean_absolute_error: 0.0080 - val_loss: 1.4785e-04 - val_mean_absolute_error: 0.0087
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.4470e-05 - mean_absolute_error: 0.0065 - val_loss: 2.2766e-04 - val_mean_absolute_error: 0.0118
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.7634e-05 - mean_absolute_error: 0.0065 - val_loss: 1.6179e-04 - val_mean_absolute_error: 0.0093
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.4216e-05 - mean_absolute_error: 0.0055 - val_loss: 1.0500e-04 - val_mean_absolute_error: 0.0073
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.4704e-05 - mean_absolute_error: 0.0061 - val_loss: 1.3650e-04 - val_mean_absolute_error: 0.0083
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.8441e-05 - mean_absolute_error: 0.0055 - val_loss: 1.0844e-04 - val_mean_absolute_error: 0.0072
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.6027e-05 - mean_absolute_error: 0.0061 - val_loss: 1.0770e-04 - val_mean_absolute_error: 0.0077
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.4058e-05 - mean_absolute_error: 0.0054 - val_loss: 1.0287e-04 - val_mean_absolute_error: 0.0072
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.1745e-05 - mean_absolute_error: 0.0054 - val_loss: 1.5161e-04 - val_mean_absolute_error: 0.0090
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.8159e-05 - mean_absolute_error: 0.0060 - val_loss: 1.7628e-04 - val_mean_absolute_error: 0.0100
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.2016e-05 - mean_absolute_error: 0.0052 - val_loss: 1.5766e-04 - val_mean_absolute_error: 0.0091
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.5449e-05 - mean_absolute_error: 0.0060 - val_loss: 1.0633e-04 - val_mean_absolute_error: 0.0071
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9640e-05 - mean_absolute_error: 0.0057 - val_loss: 4.3582e-04 - val_mean_absolute_error: 0.0183
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0479e-04 - mean_absolute_error: 0.0065 - val_loss: 1.0349e-04 - val_mean_absolute_error: 0.0070
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.6960e-05 - mean_absolute_error: 0.0052 - val_loss: 9.9000e-05 - val_mean_absolute_error: 0.0068
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.3899e-05 - mean_absolute_error: 0.0055 - val_loss: 1.2295e-04 - val_mean_absolute_error: 0.0087
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.8447e-05 - mean_absolute_error: 0.0061 - val_loss: 1.4219e-04 - val_mean_absolute_error: 0.0087
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.6487e-05 - mean_absolute_error: 0.0056 - val_loss: 1.3391e-04 - val_mean_absolute_error: 0.0083
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.9493e-05 - mean_absolute_error: 0.0054 - val_loss: 9.7928e-05 - val_mean_absolute_error: 0.0068
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.9781e-05 - mean_absolute_error: 0.0052 - val_loss: 1.0998e-04 - val_mean_absolute_error: 0.0072
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6248e-05 - mean_absolute_error: 0.0054 - val_loss: 9.4669e-05 - val_mean_absolute_error: 0.0067
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.6355e-05 - mean_absolute_error: 0.0055 - val_loss: 1.0419e-04 - val_mean_absolute_error: 0.0070
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.7154e-05 - mean_absolute_error: 0.0053 - val_loss: 1.2023e-04 - val_mean_absolute_error: 0.0077
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.8727e-05 - mean_absolute_error: 0.0053 - val_loss: 2.2582e-04 - val_mean_absolute_error: 0.0121
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.1787e-05 - mean_absolute_error: 0.0052 - val_loss: 9.9543e-05 - val_mean_absolute_error: 0.0068
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.8864e-05 - mean_absolute_error: 0.0050 - val_loss: 9.2490e-05 - val_mean_absolute_error: 0.0066
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.4097e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1177e-04 - val_mean_absolute_error: 0.0073
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.0711e-05 - mean_absolute_error: 0.0049 - val_loss: 9.3179e-05 - val_mean_absolute_error: 0.0066
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.4754e-05 - mean_absolute_error: 0.0054 - val_loss: 9.1543e-05 - val_mean_absolute_error: 0.0067
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9509e-05 - mean_absolute_error: 0.0053 - val_loss: 9.4567e-05 - val_mean_absolute_error: 0.0070
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.6976e-05 - mean_absolute_error: 0.0059 - val_loss: 9.5990e-05 - val_mean_absolute_error: 0.0066
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8625e-05 - mean_absolute_error: 0.0050 - val_loss: 1.6229e-04 - val_mean_absolute_error: 0.0097
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.8517e-05 - mean_absolute_error: 0.0054 - val_loss: 1.0334e-04 - val_mean_absolute_error: 0.0069
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.9309e-05 - mean_absolute_error: 0.0048 - val_loss: 1.0526e-04 - val_mean_absolute_error: 0.0070
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9813e-05 - mean_absolute_error: 0.0053 - val_loss: 1.3934e-04 - val_mean_absolute_error: 0.0095
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.8034e-05 - mean_absolute_error: 0.0055 - val_loss: 9.5941e-05 - val_mean_absolute_error: 0.0072
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.1137e-05 - mean_absolute_error: 0.0060 - val_loss: 9.1589e-05 - val_mean_absolute_error: 0.0068
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.7796e-05 - mean_absolute_error: 0.0061 - val_loss: 8.9429e-05 - val_mean_absolute_error: 0.0066
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.9985e-05 - mean_absolute_error: 0.0049 - val_loss: 1.0457e-04 - val_mean_absolute_error: 0.0070
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.6765e-05 - mean_absolute_error: 0.0049 - val_loss: 2.1245e-04 - val_mean_absolute_error: 0.0118
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.3648e-05 - mean_absolute_error: 0.0056 - val_loss: 8.8824e-05 - val_mean_absolute_error: 0.0064
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.8503e-05 - mean_absolute_error: 0.0053 - val_loss: 8.9824e-05 - val_mean_absolute_error: 0.0066
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.3290e-05 - mean_absolute_error: 0.0051 - val_loss: 1.1276e-04 - val_mean_absolute_error: 0.0074
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.7731e-05 - mean_absolute_error: 0.0053 - val_loss: 9.8995e-05 - val_mean_absolute_error: 0.0074
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.1088e-05 - mean_absolute_error: 0.0051 - val_loss: 2.2573e-04 - val_mean_absolute_error: 0.0124
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.0507e-05 - mean_absolute_error: 0.0061 - val_loss: 1.9139e-04 - val_mean_absolute_error: 0.0110
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.4834e-05 - mean_absolute_error: 0.0059 - val_loss: 8.9773e-05 - val_mean_absolute_error: 0.0064
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.1218e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1881e-04 - val_mean_absolute_error: 0.0085
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.9432e-05 - mean_absolute_error: 0.0063 - val_loss: 2.4713e-04 - val_mean_absolute_error: 0.0138
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.7193e-05 - mean_absolute_error: 0.0071 - val_loss: 9.8720e-05 - val_mean_absolute_error: 0.0073
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1495e-05 - mean_absolute_error: 0.0055 - val_loss: 9.9999e-05 - val_mean_absolute_error: 0.0068
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.8821e-05 - mean_absolute_error: 0.0051 - val_loss: 9.8247e-05 - val_mean_absolute_error: 0.0073
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4605e-05 - mean_absolute_error: 0.0052 - val_loss: 2.4305e-04 - val_mean_absolute_error: 0.0130
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.3825e-05 - mean_absolute_error: 0.0051 - val_loss: 1.1581e-04 - val_mean_absolute_error: 0.0076
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6799e-05 - mean_absolute_error: 0.0055 - val_loss: 9.4297e-05 - val_mean_absolute_error: 0.0071
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.4523e-05 - mean_absolute_error: 0.0058 - val_loss: 1.0632e-04 - val_mean_absolute_error: 0.0072
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.0726e-05 - mean_absolute_error: 0.0055 - val_loss: 9.9784e-05 - val_mean_absolute_error: 0.0068
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8160e-05 - mean_absolute_error: 0.0053 - val_loss: 9.9420e-05 - val_mean_absolute_error: 0.0073
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.4915e-05 - mean_absolute_error: 0.0054 - val_loss: 1.4781e-04 - val_mean_absolute_error: 0.0093
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.0310e-05 - mean_absolute_error: 0.0052 - val_loss: 1.2022e-04 - val_mean_absolute_error: 0.0085
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9034e-05 - mean_absolute_error: 0.0056 - val_loss: 1.7085e-04 - val_mean_absolute_error: 0.0109
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.5835e-05 - mean_absolute_error: 0.0064 - val_loss: 1.0696e-04 - val_mean_absolute_error: 0.0072
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.2809e-05 - mean_absolute_error: 0.0061 - val_loss: 8.8351e-05 - val_mean_absolute_error: 0.0065
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.8744e-05 - mean_absolute_error: 0.0050 - val_loss: 8.6911e-05 - val_mean_absolute_error: 0.0063
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.3238e-05 - mean_absolute_error: 0.0049 - val_loss: 8.9215e-05 - val_mean_absolute_error: 0.0063
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3976e-05 - mean_absolute_error: 0.0050 - val_loss: 2.2348e-04 - val_mean_absolute_error: 0.0123
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1590e-05 - mean_absolute_error: 0.0057 - val_loss: 8.8835e-05 - val_mean_absolute_error: 0.0063
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1497e-05 - mean_absolute_error: 0.0059 - val_loss: 8.8318e-05 - val_mean_absolute_error: 0.0065
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.8350e-05 - mean_absolute_error: 0.0049 - val_loss: 1.2583e-04 - val_mean_absolute_error: 0.0083
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.1823e-05 - mean_absolute_error: 0.0057 - val_loss: 1.1590e-04 - val_mean_absolute_error: 0.0077
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.6487e-05 - mean_absolute_error: 0.0049 - val_loss: 1.0604e-04 - val_mean_absolute_error: 0.0078
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4056e-05 - mean_absolute_error: 0.0056 - val_loss: 8.7529e-05 - val_mean_absolute_error: 0.0064
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.8303e-05 - mean_absolute_error: 0.0057 - val_loss: 9.5647e-05 - val_mean_absolute_error: 0.0066
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.2367e-05 - mean_absolute_error: 0.0049 - val_loss: 9.8938e-05 - val_mean_absolute_error: 0.0073
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.3839e-05 - mean_absolute_error: 0.0052 - val_loss: 9.4870e-05 - val_mean_absolute_error: 0.0066
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8927e-05 - mean_absolute_error: 0.0048 - val_loss: 9.7792e-05 - val_mean_absolute_error: 0.0067
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.5279e-05 - mean_absolute_error: 0.0053 - val_loss: 9.7428e-05 - val_mean_absolute_error: 0.0072
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6619e-05 - mean_absolute_error: 0.0054 - val_loss: 1.5702e-04 - val_mean_absolute_error: 0.0097
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.9175e-05 - mean_absolute_error: 0.0054 - val_loss: 9.9134e-05 - val_mean_absolute_error: 0.0068
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.5426e-05 - mean_absolute_error: 0.0048 - val_loss: 2.1022e-04 - val_mean_absolute_error: 0.0119
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.7503e-05 - mean_absolute_error: 0.0060 - val_loss: 1.4610e-04 - val_mean_absolute_error: 0.0093
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.5779e-05 - mean_absolute_error: 0.0053 - val_loss: 9.5960e-05 - val_mean_absolute_error: 0.0066
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.6558e-05 - mean_absolute_error: 0.0052 - val_loss: 1.0349e-04 - val_mean_absolute_error: 0.0071
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.9609e-05 - mean_absolute_error: 0.0050 - val_loss: 1.6702e-04 - val_mean_absolute_error: 0.0101
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.1121e-05 - mean_absolute_error: 0.0053 - val_loss: 9.7429e-05 - val_mean_absolute_error: 0.0067
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.8433e-05 - mean_absolute_error: 0.0055 - val_loss: 8.6741e-05 - val_mean_absolute_error: 0.0063
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.1392e-05 - mean_absolute_error: 0.0052 - val_loss: 1.2110e-04 - val_mean_absolute_error: 0.0086
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.2659e-05 - mean_absolute_error: 0.0056 - val_loss: 1.1380e-04 - val_mean_absolute_error: 0.0076
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.6159e-05 - mean_absolute_error: 0.0049 - val_loss: 9.4277e-05 - val_mean_absolute_error: 0.0070
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.7956e-05 - mean_absolute_error: 0.0052 - val_loss: 8.7960e-05 - val_mean_absolute_error: 0.0063
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.9262e-05 - mean_absolute_error: 0.0057 - val_loss: 9.5190e-05 - val_mean_absolute_error: 0.0070
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.8746e-05 - mean_absolute_error: 0.0056 - val_loss: 1.4254e-04 - val_mean_absolute_error: 0.0091
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.3091e-05 - mean_absolute_error: 0.0063 - val_loss: 1.1450e-04 - val_mean_absolute_error: 0.0076
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.1649e-05 - mean_absolute_error: 0.0053 - val_loss: 1.1692e-04 - val_mean_absolute_error: 0.0077
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.2750e-05 - mean_absolute_error: 0.0050 - val_loss: 8.8021e-05 - val_mean_absolute_error: 0.0063
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.8125e-05 - mean_absolute_error: 0.0053 - val_loss: 1.4544e-04 - val_mean_absolute_error: 0.0092
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2423e-05 - mean_absolute_error: 0.0052 - val_loss: 1.0153e-04 - val_mean_absolute_error: 0.0069
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3199e-05 - mean_absolute_error: 0.0051 - val_loss: 1.2376e-04 - val_mean_absolute_error: 0.0081
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.5826e-05 - mean_absolute_error: 0.0049 - val_loss: 8.8005e-05 - val_mean_absolute_error: 0.0064
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.6461e-05 - mean_absolute_error: 0.0049 - val_loss: 1.3174e-04 - val_mean_absolute_error: 0.0086
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.2177e-05 - mean_absolute_error: 0.0048 - val_loss: 9.8120e-05 - val_mean_absolute_error: 0.0067
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.4070e-05 - mean_absolute_error: 0.0053 - val_loss: 1.0300e-04 - val_mean_absolute_error: 0.0070
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.3518e-05 - mean_absolute_error: 0.0053 - val_loss: 1.0128e-04 - val_mean_absolute_error: 0.0074
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.5338e-05 - mean_absolute_error: 0.0065 - val_loss: 1.2385e-04 - val_mean_absolute_error: 0.0087
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.4773e-05 - mean_absolute_error: 0.0058 - val_loss: 1.0300e-04 - val_mean_absolute_error: 0.0070
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.7107e-05 - mean_absolute_error: 0.0053 - val_loss: 9.2456e-05 - val_mean_absolute_error: 0.0064
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.2740e-05 - mean_absolute_error: 0.0057 - val_loss: 9.5657e-05 - val_mean_absolute_error: 0.0066
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.0044e-05 - mean_absolute_error: 0.0052 - val_loss: 1.0938e-04 - val_mean_absolute_error: 0.0079
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6853e-05 - mean_absolute_error: 0.0054 - val_loss: 1.4510e-04 - val_mean_absolute_error: 0.0097
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.9285e-05 - mean_absolute_error: 0.0061 - val_loss: 1.1419e-04 - val_mean_absolute_error: 0.0076
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.0325e-05 - mean_absolute_error: 0.0055 - val_loss: 1.3649e-04 - val_mean_absolute_error: 0.0093
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1852e-05 - mean_absolute_error: 0.0057 - val_loss: 8.9788e-05 - val_mean_absolute_error: 0.0066
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.8176e-05 - mean_absolute_error: 0.0057 - val_loss: 1.1751e-04 - val_mean_absolute_error: 0.0083
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.3812e-05 - mean_absolute_error: 0.0063 - val_loss: 1.2898e-04 - val_mean_absolute_error: 0.0085
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.8514e-05 - mean_absolute_error: 0.0061 - val_loss: 1.0356e-04 - val_mean_absolute_error: 0.0070
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.9118e-05 - mean_absolute_error: 0.0054 - val_loss: 8.8818e-05 - val_mean_absolute_error: 0.0065
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1875e-05 - mean_absolute_error: 0.0061 - val_loss: 8.7457e-05 - val_mean_absolute_error: 0.0064
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.1797e-05 - mean_absolute_error: 0.0053 - val_loss: 8.8142e-05 - val_mean_absolute_error: 0.0063
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0952e-05 - mean_absolute_error: 0.0058 - val_loss: 1.7223e-04 - val_mean_absolute_error: 0.0109
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9098e-05 - mean_absolute_error: 0.0058 - val_loss: 9.5198e-05 - val_mean_absolute_error: 0.0066
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.5439e-05 - mean_absolute_error: 0.0052 - val_loss: 8.6696e-05 - val_mean_absolute_error: 0.0063
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.1712e-05 - mean_absolute_error: 0.0051 - val_loss: 8.9946e-05 - val_mean_absolute_error: 0.0063
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.0711e-05 - mean_absolute_error: 0.0054 - val_loss: 1.0872e-04 - val_mean_absolute_error: 0.0078
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.7152e-05 - mean_absolute_error: 0.0058 - val_loss: 9.0682e-05 - val_mean_absolute_error: 0.0063
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.5349e-05 - mean_absolute_error: 0.0055 - val_loss: 8.7655e-05 - val_mean_absolute_error: 0.0064
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 6.3972e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3211e-04 - val_mean_absolute_error: 0.0087
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.7048e-05 - mean_absolute_error: 0.0058 - val_loss: 8.6959e-05 - val_mean_absolute_error: 0.0063
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.6081e-05 - mean_absolute_error: 0.0056 - val_loss: 8.7735e-05 - val_mean_absolute_error: 0.0064
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.5378e-05 - mean_absolute_error: 0.0050 - val_loss: 1.1100e-04 - val_mean_absolute_error: 0.0074
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.9258e-05 - mean_absolute_error: 0.0058 - val_loss: 1.0961e-04 - val_mean_absolute_error: 0.0074
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1798e-05 - mean_absolute_error: 0.0055 - val_loss: 1.0419e-04 - val_mean_absolute_error: 0.0071
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3239e-05 - mean_absolute_error: 0.0052 - val_loss: 9.1634e-05 - val_mean_absolute_error: 0.0068
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4324e-05 - mean_absolute_error: 0.0053 - val_loss: 1.4556e-04 - val_mean_absolute_error: 0.0093
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.5182e-05 - mean_absolute_error: 0.0059 - val_loss: 1.3180e-04 - val_mean_absolute_error: 0.0085
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.4255e-05 - mean_absolute_error: 0.0053 - val_loss: 8.9308e-05 - val_mean_absolute_error: 0.0065
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.3618e-05 - mean_absolute_error: 0.0054 - val_loss: 1.1832e-04 - val_mean_absolute_error: 0.0078
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.5949e-05 - mean_absolute_error: 0.0061 - val_loss: 1.9896e-04 - val_mean_absolute_error: 0.0115
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0128e-05 - mean_absolute_error: 0.0060 - val_loss: 9.4763e-05 - val_mean_absolute_error: 0.0070
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.9290e-05 - mean_absolute_error: 0.0055 - val_loss: 9.0181e-05 - val_mean_absolute_error: 0.0066
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 6.0625e-05 - mean_absolute_error: 0.0052 - val_loss: 8.6942e-05 - val_mean_absolute_error: 0.0063
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.4094e-05 - mean_absolute_error: 0.0049 - val_loss: 2.1483e-04 - val_mean_absolute_error: 0.0120
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.5205e-05 - mean_absolute_error: 0.0057 - val_loss: 1.7467e-04 - val_mean_absolute_error: 0.0106
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.9521e-05 - mean_absolute_error: 0.0057 - val_loss: 1.1347e-04 - val_mean_absolute_error: 0.0076
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.5717e-05 - mean_absolute_error: 0.0059 - val_loss: 8.6912e-05 - val_mean_absolute_error: 0.0063

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 2406506.6304816743
# RMSE: 1551.2919230375933
# MAE: 1092.3033024153387
# MAPE: 1.4176190654373286 %
#
# Model evalution on validate set
# MSE: 7316954.763888272
# RMSE: 2704.987017323424
# MAE: 1909.3270273760331
# MAPE: 1.6762320847061836 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step

# %%
y_pred_30_days
# Out:
# array([[129746.89 ],
#        [130131.625],
#        [129904.97 ],
#        [129858.6  ],
#        [130118.68 ],
#        [130060.66 ],
#        [130088.87 ],
#        [130091.36 ],
#        [130078.23 ],
#        [130083.45 ],
#        [130080.945],
#        [130081.02 ],
#        [130081.69 ],
#        [130081.27 ],
#        [130081.484],
#        [130081.445],
#        [130081.414],
#        [130081.46 ],
#        [130081.445],
#        [130081.445],
#        [130081.46 ],
#        [130081.46 ],
#        [130081.46 ],
#        [130081.445],
#        [130081.445],
#        [130081.46 ],
#        [130081.46 ],
#        [130081.48 ],
#        [130081.445],
#        [130081.445],
#        [130081.48 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Predict the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
