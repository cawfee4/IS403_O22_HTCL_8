# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: FPT - Test/Train/Vaildation: 70/20/10
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1572.7294959700616
# - MAE: 1106.492452066733
# - MAPE: 1.4336370200391644 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 0  # 7 2 1

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01  19270
# 2019-03-04  19440
# 2019-03-05  19390
# 2019-03-06  19270
# 2019-03-07  19330

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((908, 10), (908,), (251, 10), (251,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_1 (SimpleRNN)        │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - loss: 0.0195 - mean_absolute_error: 0.0941 - val_loss: 0.0085 - val_mean_absolute_error: 0.0864
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0011 - mean_absolute_error: 0.0230 - val_loss: 7.4116e-04 - val_mean_absolute_error: 0.0189
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 3.2368e-04 - mean_absolute_error: 0.0118 - val_loss: 7.1604e-04 - val_mean_absolute_error: 0.0184
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.7700e-04 - mean_absolute_error: 0.0109 - val_loss: 5.6363e-04 - val_mean_absolute_error: 0.0168
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.1126e-04 - mean_absolute_error: 0.0117 - val_loss: 9.0300e-04 - val_mean_absolute_error: 0.0217
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6523e-04 - mean_absolute_error: 0.0102 - val_loss: 5.7728e-04 - val_mean_absolute_error: 0.0165
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.2559e-04 - mean_absolute_error: 0.0098 - val_loss: 6.0686e-04 - val_mean_absolute_error: 0.0171
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8601e-04 - mean_absolute_error: 0.0091 - val_loss: 3.7037e-04 - val_mean_absolute_error: 0.0141
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9376e-04 - mean_absolute_error: 0.0092 - val_loss: 4.8959e-04 - val_mean_absolute_error: 0.0153
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6810e-04 - mean_absolute_error: 0.0084 - val_loss: 5.5345e-04 - val_mean_absolute_error: 0.0169
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.6375e-04 - mean_absolute_error: 0.0085 - val_loss: 3.5471e-04 - val_mean_absolute_error: 0.0129
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4888e-04 - mean_absolute_error: 0.0081 - val_loss: 3.6176e-04 - val_mean_absolute_error: 0.0131
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4294e-04 - mean_absolute_error: 0.0080 - val_loss: 3.6865e-04 - val_mean_absolute_error: 0.0133
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3566e-04 - mean_absolute_error: 0.0075 - val_loss: 3.3974e-04 - val_mean_absolute_error: 0.0128
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1738e-04 - mean_absolute_error: 0.0072 - val_loss: 2.3685e-04 - val_mean_absolute_error: 0.0114
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5632e-04 - mean_absolute_error: 0.0083 - val_loss: 2.9168e-04 - val_mean_absolute_error: 0.0118
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.8439e-05 - mean_absolute_error: 0.0066 - val_loss: 4.1215e-04 - val_mean_absolute_error: 0.0149
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0795e-04 - mean_absolute_error: 0.0098 - val_loss: 2.2309e-04 - val_mean_absolute_error: 0.0105
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0663e-04 - mean_absolute_error: 0.0067 - val_loss: 2.6235e-04 - val_mean_absolute_error: 0.0112
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0716e-04 - mean_absolute_error: 0.0068 - val_loss: 2.7526e-04 - val_mean_absolute_error: 0.0115
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1594e-04 - mean_absolute_error: 0.0072 - val_loss: 4.1063e-04 - val_mean_absolute_error: 0.0151
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1992e-04 - mean_absolute_error: 0.0072 - val_loss: 4.6913e-04 - val_mean_absolute_error: 0.0167
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4569e-04 - mean_absolute_error: 0.0081 - val_loss: 2.6124e-04 - val_mean_absolute_error: 0.0136
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2441e-04 - mean_absolute_error: 0.0075 - val_loss: 2.0674e-04 - val_mean_absolute_error: 0.0101
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2055e-04 - mean_absolute_error: 0.0073 - val_loss: 3.5815e-04 - val_mean_absolute_error: 0.0141
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0878e-04 - mean_absolute_error: 0.0067 - val_loss: 2.0043e-04 - val_mean_absolute_error: 0.0099
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.1236e-04 - mean_absolute_error: 0.0067 - val_loss: 2.0178e-04 - val_mean_absolute_error: 0.0099
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1600e-04 - mean_absolute_error: 0.0070 - val_loss: 1.8051e-04 - val_mean_absolute_error: 0.0096
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0551e-04 - mean_absolute_error: 0.0070 - val_loss: 6.6063e-04 - val_mean_absolute_error: 0.0217
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2011e-04 - mean_absolute_error: 0.0076 - val_loss: 1.6758e-04 - val_mean_absolute_error: 0.0097
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0416e-04 - mean_absolute_error: 0.0069 - val_loss: 3.5664e-04 - val_mean_absolute_error: 0.0144
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1613e-04 - mean_absolute_error: 0.0071 - val_loss: 2.0557e-04 - val_mean_absolute_error: 0.0117
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4697e-04 - mean_absolute_error: 0.0079 - val_loss: 2.2671e-04 - val_mean_absolute_error: 0.0107
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.1316e-05 - mean_absolute_error: 0.0062 - val_loss: 1.9432e-04 - val_mean_absolute_error: 0.0113
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7285e-04 - mean_absolute_error: 0.0088 - val_loss: 1.6213e-04 - val_mean_absolute_error: 0.0091
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4168e-04 - mean_absolute_error: 0.0080 - val_loss: 2.3400e-04 - val_mean_absolute_error: 0.0109
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.0195e-05 - mean_absolute_error: 0.0063 - val_loss: 1.7540e-04 - val_mean_absolute_error: 0.0105
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2366e-04 - mean_absolute_error: 0.0074 - val_loss: 3.0351e-04 - val_mean_absolute_error: 0.0132
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1297e-04 - mean_absolute_error: 0.0071 - val_loss: 2.0252e-04 - val_mean_absolute_error: 0.0101
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.4871e-05 - mean_absolute_error: 0.0065 - val_loss: 2.1346e-04 - val_mean_absolute_error: 0.0104
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.5359e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4126e-04 - val_mean_absolute_error: 0.0085
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.6288e-05 - mean_absolute_error: 0.0061 - val_loss: 3.6251e-04 - val_mean_absolute_error: 0.0151
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.2609e-05 - mean_absolute_error: 0.0065 - val_loss: 1.6432e-04 - val_mean_absolute_error: 0.0090
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0511e-04 - mean_absolute_error: 0.0069 - val_loss: 1.3373e-04 - val_mean_absolute_error: 0.0084
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.4208e-05 - mean_absolute_error: 0.0062 - val_loss: 1.6142e-04 - val_mean_absolute_error: 0.0089
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.1081e-05 - mean_absolute_error: 0.0063 - val_loss: 1.6086e-04 - val_mean_absolute_error: 0.0089
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0042e-04 - mean_absolute_error: 0.0063 - val_loss: 1.5160e-04 - val_mean_absolute_error: 0.0086
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.7087e-05 - mean_absolute_error: 0.0067 - val_loss: 2.9678e-04 - val_mean_absolute_error: 0.0133
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.5498e-05 - mean_absolute_error: 0.0064 - val_loss: 1.3120e-04 - val_mean_absolute_error: 0.0081
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.5962e-05 - mean_absolute_error: 0.0064 - val_loss: 1.8258e-04 - val_mean_absolute_error: 0.0111
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0736e-04 - mean_absolute_error: 0.0069 - val_loss: 1.2820e-04 - val_mean_absolute_error: 0.0082
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0019e-04 - mean_absolute_error: 0.0065 - val_loss: 1.2667e-04 - val_mean_absolute_error: 0.0081
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.3798e-05 - mean_absolute_error: 0.0057 - val_loss: 1.2538e-04 - val_mean_absolute_error: 0.0080
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.0154e-05 - mean_absolute_error: 0.0064 - val_loss: 1.2454e-04 - val_mean_absolute_error: 0.0079
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0702e-05 - mean_absolute_error: 0.0057 - val_loss: 3.7606e-04 - val_mean_absolute_error: 0.0160
# Epoch 56/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3016e-04 - mean_absolute_error: 0.0076 - val_loss: 1.4388e-04 - val_mean_absolute_error: 0.0084
# Epoch 57/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.3198e-05 - mean_absolute_error: 0.0061 - val_loss: 1.2003e-04 - val_mean_absolute_error: 0.0078
# Epoch 58/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.5235e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4135e-04 - val_mean_absolute_error: 0.0083
# Epoch 59/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.1446e-05 - mean_absolute_error: 0.0062 - val_loss: 3.8181e-04 - val_mean_absolute_error: 0.0162
# Epoch 60/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1965e-04 - mean_absolute_error: 0.0075 - val_loss: 1.6697e-04 - val_mean_absolute_error: 0.0092
# Epoch 61/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.5302e-05 - mean_absolute_error: 0.0058 - val_loss: 1.1636e-04 - val_mean_absolute_error: 0.0077
# Epoch 62/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 8.8306e-05 - mean_absolute_error: 0.0061 - val_loss: 1.7807e-04 - val_mean_absolute_error: 0.0098
# Epoch 63/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0805e-04 - mean_absolute_error: 0.0069 - val_loss: 2.7458e-04 - val_mean_absolute_error: 0.0131
# Epoch 64/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.0596e-05 - mean_absolute_error: 0.0063 - val_loss: 1.1632e-04 - val_mean_absolute_error: 0.0075
# Epoch 65/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.1693e-05 - mean_absolute_error: 0.0061 - val_loss: 1.2938e-04 - val_mean_absolute_error: 0.0079
# Epoch 66/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.7881e-05 - mean_absolute_error: 0.0059 - val_loss: 1.1362e-04 - val_mean_absolute_error: 0.0074
# Epoch 67/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.8232e-05 - mean_absolute_error: 0.0057 - val_loss: 1.1213e-04 - val_mean_absolute_error: 0.0074
# Epoch 68/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.0742e-05 - mean_absolute_error: 0.0057 - val_loss: 1.7481e-04 - val_mean_absolute_error: 0.0097
# Epoch 69/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.8323e-05 - mean_absolute_error: 0.0055 - val_loss: 1.1315e-04 - val_mean_absolute_error: 0.0074
# Epoch 70/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.6040e-05 - mean_absolute_error: 0.0059 - val_loss: 1.5288e-04 - val_mean_absolute_error: 0.0090
# Epoch 71/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.8196e-05 - mean_absolute_error: 0.0056 - val_loss: 1.7531e-04 - val_mean_absolute_error: 0.0098
# Epoch 72/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.9259e-05 - mean_absolute_error: 0.0054 - val_loss: 1.1100e-04 - val_mean_absolute_error: 0.0078
# Epoch 73/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.9275e-05 - mean_absolute_error: 0.0056 - val_loss: 2.4327e-04 - val_mean_absolute_error: 0.0124
# Epoch 74/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.2041e-05 - mean_absolute_error: 0.0057 - val_loss: 1.5042e-04 - val_mean_absolute_error: 0.0089
# Epoch 75/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.8146e-05 - mean_absolute_error: 0.0057 - val_loss: 1.3856e-04 - val_mean_absolute_error: 0.0084
# Epoch 76/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7262e-05 - mean_absolute_error: 0.0054 - val_loss: 1.0840e-04 - val_mean_absolute_error: 0.0072
# Epoch 77/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.6248e-05 - mean_absolute_error: 0.0055 - val_loss: 1.3871e-04 - val_mean_absolute_error: 0.0094
# Epoch 78/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0489e-04 - mean_absolute_error: 0.0066 - val_loss: 1.5721e-04 - val_mean_absolute_error: 0.0091
# Epoch 79/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.4841e-05 - mean_absolute_error: 0.0055 - val_loss: 1.0221e-04 - val_mean_absolute_error: 0.0071
# Epoch 80/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.0520e-05 - mean_absolute_error: 0.0063 - val_loss: 4.3227e-04 - val_mean_absolute_error: 0.0181
# Epoch 81/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1482e-04 - mean_absolute_error: 0.0069 - val_loss: 1.9442e-04 - val_mean_absolute_error: 0.0107
# Epoch 82/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.2888e-05 - mean_absolute_error: 0.0056 - val_loss: 1.1452e-04 - val_mean_absolute_error: 0.0082
# Epoch 83/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.6686e-05 - mean_absolute_error: 0.0055 - val_loss: 1.0055e-04 - val_mean_absolute_error: 0.0070
# Epoch 84/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.4025e-05 - mean_absolute_error: 0.0058 - val_loss: 2.1277e-04 - val_mean_absolute_error: 0.0114
# Epoch 85/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.4939e-05 - mean_absolute_error: 0.0056 - val_loss: 1.0010e-04 - val_mean_absolute_error: 0.0069
# Epoch 86/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.8422e-05 - mean_absolute_error: 0.0054 - val_loss: 1.3893e-04 - val_mean_absolute_error: 0.0094
# Epoch 87/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.5375e-05 - mean_absolute_error: 0.0058 - val_loss: 1.0271e-04 - val_mean_absolute_error: 0.0074
# Epoch 88/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 8.6694e-05 - mean_absolute_error: 0.0062 - val_loss: 3.1409e-04 - val_mean_absolute_error: 0.0149
# Epoch 89/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.4629e-05 - mean_absolute_error: 0.0064 - val_loss: 1.7846e-04 - val_mean_absolute_error: 0.0102
# Epoch 90/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 7.2061e-05 - mean_absolute_error: 0.0055 - val_loss: 1.0056e-04 - val_mean_absolute_error: 0.0069
# Epoch 91/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.2963e-05 - mean_absolute_error: 0.0057 - val_loss: 1.0164e-04 - val_mean_absolute_error: 0.0074
# Epoch 92/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.7623e-05 - mean_absolute_error: 0.0051 - val_loss: 9.6154e-05 - val_mean_absolute_error: 0.0068
# Epoch 93/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.9533e-05 - mean_absolute_error: 0.0050 - val_loss: 1.0926e-04 - val_mean_absolute_error: 0.0073
# Epoch 94/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.6217e-05 - mean_absolute_error: 0.0052 - val_loss: 9.5431e-05 - val_mean_absolute_error: 0.0067
# Epoch 95/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.4337e-05 - mean_absolute_error: 0.0053 - val_loss: 9.7591e-05 - val_mean_absolute_error: 0.0072
# Epoch 96/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.9200e-05 - mean_absolute_error: 0.0055 - val_loss: 2.3282e-04 - val_mean_absolute_error: 0.0124
# Epoch 97/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 7.2321e-05 - mean_absolute_error: 0.0058 - val_loss: 1.2243e-04 - val_mean_absolute_error: 0.0086
# Epoch 98/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.2179e-05 - mean_absolute_error: 0.0061 - val_loss: 9.5451e-05 - val_mean_absolute_error: 0.0067
# Epoch 99/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0429e-05 - mean_absolute_error: 0.0051 - val_loss: 9.3856e-05 - val_mean_absolute_error: 0.0069
# Epoch 100/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.3074e-05 - mean_absolute_error: 0.0053 - val_loss: 2.0974e-04 - val_mean_absolute_error: 0.0116
# Epoch 101/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.2930e-05 - mean_absolute_error: 0.0060 - val_loss: 1.3226e-04 - val_mean_absolute_error: 0.0084
# Epoch 102/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.7833e-05 - mean_absolute_error: 0.0055 - val_loss: 9.6362e-05 - val_mean_absolute_error: 0.0067
# Epoch 103/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4958e-05 - mean_absolute_error: 0.0048 - val_loss: 1.0153e-04 - val_mean_absolute_error: 0.0069
# Epoch 104/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 5.9037e-05 - mean_absolute_error: 0.0051 - val_loss: 1.2322e-04 - val_mean_absolute_error: 0.0079
# Epoch 105/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.2460e-05 - mean_absolute_error: 0.0061 - val_loss: 1.1340e-04 - val_mean_absolute_error: 0.0074
# Epoch 106/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.3963e-05 - mean_absolute_error: 0.0050 - val_loss: 9.9178e-05 - val_mean_absolute_error: 0.0068
# Epoch 107/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.7926e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2736e-04 - val_mean_absolute_error: 0.0081
# Epoch 108/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.7432e-05 - mean_absolute_error: 0.0054 - val_loss: 1.3136e-04 - val_mean_absolute_error: 0.0084
# Epoch 109/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4608e-05 - mean_absolute_error: 0.0050 - val_loss: 9.3977e-05 - val_mean_absolute_error: 0.0066
# Epoch 110/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.2517e-05 - mean_absolute_error: 0.0053 - val_loss: 1.0663e-04 - val_mean_absolute_error: 0.0078
# Epoch 111/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3543e-05 - mean_absolute_error: 0.0050 - val_loss: 9.4921e-05 - val_mean_absolute_error: 0.0066
# Epoch 112/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9828e-05 - mean_absolute_error: 0.0052 - val_loss: 9.2679e-05 - val_mean_absolute_error: 0.0069
# Epoch 113/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.3530e-05 - mean_absolute_error: 0.0055 - val_loss: 1.4590e-04 - val_mean_absolute_error: 0.0089
# Epoch 114/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.3576e-05 - mean_absolute_error: 0.0053 - val_loss: 9.5772e-05 - val_mean_absolute_error: 0.0066
# Epoch 115/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.4004e-05 - mean_absolute_error: 0.0049 - val_loss: 9.0084e-05 - val_mean_absolute_error: 0.0065
# Epoch 116/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.8297e-05 - mean_absolute_error: 0.0050 - val_loss: 9.0820e-05 - val_mean_absolute_error: 0.0067
# Epoch 117/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.3585e-05 - mean_absolute_error: 0.0056 - val_loss: 2.2067e-04 - val_mean_absolute_error: 0.0121
# Epoch 118/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 7.8336e-05 - mean_absolute_error: 0.0058 - val_loss: 9.7732e-05 - val_mean_absolute_error: 0.0072
# Epoch 119/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.5576e-05 - mean_absolute_error: 0.0060 - val_loss: 2.2917e-04 - val_mean_absolute_error: 0.0124
# Epoch 120/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.9768e-05 - mean_absolute_error: 0.0062 - val_loss: 9.9190e-05 - val_mean_absolute_error: 0.0068
# Epoch 121/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.8822e-05 - mean_absolute_error: 0.0049 - val_loss: 1.3269e-04 - val_mean_absolute_error: 0.0086
# Epoch 122/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.9032e-05 - mean_absolute_error: 0.0060 - val_loss: 9.0535e-05 - val_mean_absolute_error: 0.0067
# Epoch 123/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.6357e-05 - mean_absolute_error: 0.0054 - val_loss: 1.2167e-04 - val_mean_absolute_error: 0.0079
# Epoch 124/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0971e-05 - mean_absolute_error: 0.0050 - val_loss: 9.9906e-05 - val_mean_absolute_error: 0.0068
# Epoch 125/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.7872e-05 - mean_absolute_error: 0.0049 - val_loss: 9.9612e-05 - val_mean_absolute_error: 0.0068
# Epoch 126/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.1475e-05 - mean_absolute_error: 0.0057 - val_loss: 1.2713e-04 - val_mean_absolute_error: 0.0082
# Epoch 127/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.6247e-05 - mean_absolute_error: 0.0068 - val_loss: 9.8485e-05 - val_mean_absolute_error: 0.0067
# Epoch 128/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.0245e-05 - mean_absolute_error: 0.0050 - val_loss: 2.3884e-04 - val_mean_absolute_error: 0.0129
# Epoch 129/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.7219e-05 - mean_absolute_error: 0.0059 - val_loss: 1.0678e-04 - val_mean_absolute_error: 0.0072
# Epoch 130/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.2069e-05 - mean_absolute_error: 0.0067 - val_loss: 9.4698e-05 - val_mean_absolute_error: 0.0066
# Epoch 131/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.1018e-05 - mean_absolute_error: 0.0050 - val_loss: 9.3834e-05 - val_mean_absolute_error: 0.0070
# Epoch 132/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7463e-05 - mean_absolute_error: 0.0063 - val_loss: 9.6943e-05 - val_mean_absolute_error: 0.0072
# Epoch 133/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3341e-05 - mean_absolute_error: 0.0052 - val_loss: 1.1201e-04 - val_mean_absolute_error: 0.0074
# Epoch 134/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.6365e-05 - mean_absolute_error: 0.0052 - val_loss: 9.1209e-05 - val_mean_absolute_error: 0.0065
# Epoch 135/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.6852e-05 - mean_absolute_error: 0.0055 - val_loss: 9.1747e-05 - val_mean_absolute_error: 0.0069
# Epoch 136/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.7965e-05 - mean_absolute_error: 0.0054 - val_loss: 8.7849e-05 - val_mean_absolute_error: 0.0065
# Epoch 137/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.4618e-05 - mean_absolute_error: 0.0056 - val_loss: 1.9022e-04 - val_mean_absolute_error: 0.0111
# Epoch 138/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.1865e-05 - mean_absolute_error: 0.0062 - val_loss: 1.5779e-04 - val_mean_absolute_error: 0.0098
# Epoch 139/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.0785e-05 - mean_absolute_error: 0.0053 - val_loss: 9.6820e-05 - val_mean_absolute_error: 0.0067
# Epoch 140/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.3907e-05 - mean_absolute_error: 0.0055 - val_loss: 1.2375e-04 - val_mean_absolute_error: 0.0080
# Epoch 141/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.0804e-05 - mean_absolute_error: 0.0056 - val_loss: 8.9444e-05 - val_mean_absolute_error: 0.0063
# Epoch 142/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.6403e-05 - mean_absolute_error: 0.0051 - val_loss: 1.1429e-04 - val_mean_absolute_error: 0.0081
# Epoch 143/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.2384e-05 - mean_absolute_error: 0.0063 - val_loss: 1.4554e-04 - val_mean_absolute_error: 0.0098
# Epoch 144/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.3227e-05 - mean_absolute_error: 0.0063 - val_loss: 9.4595e-05 - val_mean_absolute_error: 0.0070
# Epoch 145/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 5.7031e-05 - mean_absolute_error: 0.0050 - val_loss: 1.0958e-04 - val_mean_absolute_error: 0.0073
# Epoch 146/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.8859e-05 - mean_absolute_error: 0.0053 - val_loss: 2.1637e-04 - val_mean_absolute_error: 0.0126
# Epoch 147/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7919e-05 - mean_absolute_error: 0.0064 - val_loss: 1.3183e-04 - val_mean_absolute_error: 0.0091
# Epoch 148/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.3467e-05 - mean_absolute_error: 0.0058 - val_loss: 8.7230e-05 - val_mean_absolute_error: 0.0063
# Epoch 149/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.1396e-05 - mean_absolute_error: 0.0052 - val_loss: 9.7386e-05 - val_mean_absolute_error: 0.0068
# Epoch 150/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.8791e-05 - mean_absolute_error: 0.0052 - val_loss: 1.5971e-04 - val_mean_absolute_error: 0.0099
# Epoch 151/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.2264e-05 - mean_absolute_error: 0.0060 - val_loss: 1.9890e-04 - val_mean_absolute_error: 0.0115
# Epoch 152/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.4833e-05 - mean_absolute_error: 0.0056 - val_loss: 9.9203e-05 - val_mean_absolute_error: 0.0072
# Epoch 153/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4136e-05 - mean_absolute_error: 0.0055 - val_loss: 8.6803e-05 - val_mean_absolute_error: 0.0064
# Epoch 154/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.4680e-05 - mean_absolute_error: 0.0058 - val_loss: 8.8078e-05 - val_mean_absolute_error: 0.0065
# Epoch 155/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 5.4992e-05 - mean_absolute_error: 0.0048 - val_loss: 1.1588e-04 - val_mean_absolute_error: 0.0078
# Epoch 156/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.1339e-05 - mean_absolute_error: 0.0052 - val_loss: 8.7323e-05 - val_mean_absolute_error: 0.0063
# Epoch 157/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.3281e-05 - mean_absolute_error: 0.0052 - val_loss: 8.7201e-05 - val_mean_absolute_error: 0.0065
# Epoch 158/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.8262e-05 - mean_absolute_error: 0.0053 - val_loss: 1.0449e-04 - val_mean_absolute_error: 0.0076
# Epoch 159/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 6.6584e-05 - mean_absolute_error: 0.0055 - val_loss: 9.1194e-05 - val_mean_absolute_error: 0.0064
# Epoch 160/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.0823e-05 - mean_absolute_error: 0.0050 - val_loss: 1.0782e-04 - val_mean_absolute_error: 0.0078
# Epoch 161/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.7832e-05 - mean_absolute_error: 0.0053 - val_loss: 1.0969e-04 - val_mean_absolute_error: 0.0079
# Epoch 162/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.3156e-05 - mean_absolute_error: 0.0053 - val_loss: 1.0173e-04 - val_mean_absolute_error: 0.0074
# Epoch 163/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 6.0970e-05 - mean_absolute_error: 0.0052 - val_loss: 3.4168e-04 - val_mean_absolute_error: 0.0162
# Epoch 164/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.2923e-05 - mean_absolute_error: 0.0067 - val_loss: 1.4536e-04 - val_mean_absolute_error: 0.0093
# Epoch 165/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.1893e-05 - mean_absolute_error: 0.0063 - val_loss: 8.8546e-05 - val_mean_absolute_error: 0.0063
# Epoch 166/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 7.0753e-05 - mean_absolute_error: 0.0058 - val_loss: 1.0284e-04 - val_mean_absolute_error: 0.0075
# Epoch 167/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 7.4026e-05 - mean_absolute_error: 0.0053 - val_loss: 9.0145e-05 - val_mean_absolute_error: 0.0066
# Epoch 168/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.1372e-05 - mean_absolute_error: 0.0055 - val_loss: 1.1358e-04 - val_mean_absolute_error: 0.0081
# Epoch 169/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 5.5702e-05 - mean_absolute_error: 0.0049 - val_loss: 8.7518e-05 - val_mean_absolute_error: 0.0064
# Epoch 170/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 7.6131e-05 - mean_absolute_error: 0.0057 - val_loss: 1.0003e-04 - val_mean_absolute_error: 0.0072
# Epoch 171/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.3325e-05 - mean_absolute_error: 0.0056 - val_loss: 1.5180e-04 - val_mean_absolute_error: 0.0099
# Epoch 172/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.0137e-05 - mean_absolute_error: 0.0060 - val_loss: 8.8968e-05 - val_mean_absolute_error: 0.0063
# Epoch 173/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.0775e-05 - mean_absolute_error: 0.0051 - val_loss: 1.0121e-04 - val_mean_absolute_error: 0.0070
# Epoch 174/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1617e-05 - mean_absolute_error: 0.0051 - val_loss: 9.2507e-05 - val_mean_absolute_error: 0.0065
# Epoch 175/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.0343e-05 - mean_absolute_error: 0.0052 - val_loss: 8.7585e-05 - val_mean_absolute_error: 0.0064
# Epoch 176/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.9455e-05 - mean_absolute_error: 0.0052 - val_loss: 9.5145e-05 - val_mean_absolute_error: 0.0066
# Epoch 177/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.0294e-05 - mean_absolute_error: 0.0049 - val_loss: 9.5140e-05 - val_mean_absolute_error: 0.0066
# Epoch 178/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1298e-05 - mean_absolute_error: 0.0050 - val_loss: 1.2703e-04 - val_mean_absolute_error: 0.0084
# Epoch 179/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.4266e-05 - mean_absolute_error: 0.0052 - val_loss: 8.7528e-05 - val_mean_absolute_error: 0.0063
# Epoch 180/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 7.0026e-05 - mean_absolute_error: 0.0056 - val_loss: 1.3144e-04 - val_mean_absolute_error: 0.0086
# Epoch 181/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.0137e-05 - mean_absolute_error: 0.0057 - val_loss: 8.7148e-05 - val_mean_absolute_error: 0.0063
# Epoch 182/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.1279e-05 - mean_absolute_error: 0.0050 - val_loss: 9.9477e-05 - val_mean_absolute_error: 0.0068
# Epoch 183/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 6.9273e-05 - mean_absolute_error: 0.0056 - val_loss: 3.1486e-04 - val_mean_absolute_error: 0.0153
# Epoch 184/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.6196e-05 - mean_absolute_error: 0.0064 - val_loss: 1.0909e-04 - val_mean_absolute_error: 0.0074
# Epoch 185/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 5.3975e-05 - mean_absolute_error: 0.0047 - val_loss: 9.9339e-05 - val_mean_absolute_error: 0.0073
# Epoch 186/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.1115e-05 - mean_absolute_error: 0.0056 - val_loss: 9.6334e-05 - val_mean_absolute_error: 0.0071
# Epoch 187/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.5705e-05 - mean_absolute_error: 0.0054 - val_loss: 9.7111e-05 - val_mean_absolute_error: 0.0071
# Epoch 188/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.2685e-05 - mean_absolute_error: 0.0059 - val_loss: 1.3431e-04 - val_mean_absolute_error: 0.0092
# Epoch 189/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.9831e-05 - mean_absolute_error: 0.0060 - val_loss: 8.9587e-05 - val_mean_absolute_error: 0.0063
# Epoch 190/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.9697e-05 - mean_absolute_error: 0.0051 - val_loss: 1.7468e-04 - val_mean_absolute_error: 0.0109
# Epoch 191/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.2505e-05 - mean_absolute_error: 0.0061 - val_loss: 1.5140e-04 - val_mean_absolute_error: 0.0100
# Epoch 192/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.7440e-05 - mean_absolute_error: 0.0055 - val_loss: 8.7520e-05 - val_mean_absolute_error: 0.0064
# Epoch 193/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.4102e-05 - mean_absolute_error: 0.0054 - val_loss: 1.8916e-04 - val_mean_absolute_error: 0.0116
# Epoch 194/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.1557e-05 - mean_absolute_error: 0.0067 - val_loss: 9.9608e-05 - val_mean_absolute_error: 0.0074
# Epoch 195/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 6.8057e-05 - mean_absolute_error: 0.0057 - val_loss: 9.5068e-05 - val_mean_absolute_error: 0.0066
# Epoch 196/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.8976e-05 - mean_absolute_error: 0.0053 - val_loss: 1.0268e-04 - val_mean_absolute_error: 0.0075
# Epoch 197/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.6238e-05 - mean_absolute_error: 0.0062 - val_loss: 9.9534e-05 - val_mean_absolute_error: 0.0073
# Epoch 198/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 7.4058e-05 - mean_absolute_error: 0.0060 - val_loss: 8.8375e-05 - val_mean_absolute_error: 0.0063
# Epoch 199/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.8290e-05 - mean_absolute_error: 0.0052 - val_loss: 1.3710e-04 - val_mean_absolute_error: 0.0089
# Epoch 200/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 6.6016e-05 - mean_absolute_error: 0.0052 - val_loss: 8.8226e-05 - val_mean_absolute_error: 0.0063

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 2473478.0674942443
# RMSE: 1572.7294959700616
# MAE: 1106.492452066733
# MAPE: 1.4336370200391644 %
#
# Model evalution on validate set
# MSE: 8156529.398150483
# RMSE: 2855.963829979379
# MAE: 2031.2039643595042
# MAPE: 1.7830374700861105 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 641ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step

# %%
y_pred_30_days
# Out:
# array([[129926.15 ],
#        [130215.22 ],
#        [130087.98 ],
#        [130014.85 ],
#        [130208.13 ],
#        [130174.31 ],
#        [130185.34 ],
#        [130190.555],
#        [130182.57 ],
#        [130184.98 ],
#        [130184.23 ],
#        [130184.03 ],
#        [130184.37 ],
#        [130184.23 ],
#        [130184.26 ],
#        [130184.27 ],
#        [130184.28 ],
#        [130184.28 ],
#        [130184.28 ],
#        [130184.28 ],
#        [130184.28 ],
#        [130184.28 ],
#        [130184.28 ],
#        [130184.28 ],
#        [130184.27 ],
#        [130184.28 ],
#        [130184.28 ],
#        [130184.28 ],
#        [130184.28 ],
#        [130184.28 ],
#        [130184.28 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Forecast Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Forecast the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
