# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Input

plt.style.use('default')

# %% [markdown]
# ## 1. Data preprocessing

# %%
split_type = [0.8,0.7,0.9]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01  19270
# 2019-03-04  19440
# 2019-03-05  19390
# 2019-03-06  19270
# 2019-03-07  19330

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using neural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split] * len(df_scaled))
test_size = len(df_scaled) - train_size

# %%
# Splitting data into train, test set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size:]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test set
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1170, 10), (1170,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
UNITS = 64

# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(UNITS),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 64)             │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,289 (16.75 KB)
#  Trainable params: 4,289 (16.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0398 - mean_absolute_error: 0.1326
# Epoch 2/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.6154e-04 - mean_absolute_error: 0.0180
# Epoch 3/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.2666e-04 - mean_absolute_error: 0.0121
# Epoch 4/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.7014e-04 - mean_absolute_error: 0.0111
# Epoch 5/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.5659e-04 - mean_absolute_error: 0.0109
# Epoch 6/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7480e-04 - mean_absolute_error: 0.0089
# Epoch 7/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 1.6213e-04 - mean_absolute_error: 0.0085
# Epoch 8/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 1.7097e-04 - mean_absolute_error: 0.0088
# Epoch 9/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - loss: 1.5910e-04 - mean_absolute_error: 0.0082
# Epoch 10/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 1.4032e-04 - mean_absolute_error: 0.0077
# Epoch 11/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - loss: 1.5258e-04 - mean_absolute_error: 0.0080
# Epoch 12/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3077e-04 - mean_absolute_error: 0.0075
# Epoch 13/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - loss: 1.4806e-04 - mean_absolute_error: 0.0083
# Epoch 14/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - loss: 1.5979e-04 - mean_absolute_error: 0.0086
# Epoch 15/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2322e-04 - mean_absolute_error: 0.0072
# Epoch 16/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - loss: 1.1779e-04 - mean_absolute_error: 0.0071
# Epoch 17/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2004e-04 - mean_absolute_error: 0.0072
# Epoch 18/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1280e-04 - mean_absolute_error: 0.0071
# Epoch 19/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5568e-04 - mean_absolute_error: 0.0085
# Epoch 20/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8106e-04 - mean_absolute_error: 0.0096
# Epoch 21/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1287e-04 - mean_absolute_error: 0.0071
# Epoch 22/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1505e-04 - mean_absolute_error: 0.0072
# Epoch 23/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0139e-04 - mean_absolute_error: 0.0070
# Epoch 24/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1381e-04 - mean_absolute_error: 0.0071
# Epoch 25/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1880e-04 - mean_absolute_error: 0.0071
# Epoch 26/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - loss: 1.1886e-04 - mean_absolute_error: 0.0072
# Epoch 27/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 960us/step - loss: 1.1193e-04 - mean_absolute_error: 0.0069
# Epoch 28/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2897e-04 - mean_absolute_error: 0.0079
# Epoch 29/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3122e-04 - mean_absolute_error: 0.0077
# Epoch 30/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1007e-04 - mean_absolute_error: 0.0067
# Epoch 31/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3223e-04 - mean_absolute_error: 0.0079
# Epoch 32/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1678e-04 - mean_absolute_error: 0.0073
# Epoch 33/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1372e-04 - mean_absolute_error: 0.0074
# Epoch 34/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3889e-04 - mean_absolute_error: 0.0081
# Epoch 35/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1337e-04 - mean_absolute_error: 0.0071
# Epoch 36/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 1.1474e-04 - mean_absolute_error: 0.0072
# Epoch 37/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - loss: 1.1005e-04 - mean_absolute_error: 0.0070
# Epoch 38/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0249e-04 - mean_absolute_error: 0.0068
# Epoch 39/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.6776e-05 - mean_absolute_error: 0.0067
# Epoch 40/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - loss: 1.0099e-04 - mean_absolute_error: 0.0068
# Epoch 41/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - loss: 1.0803e-04 - mean_absolute_error: 0.0069
# Epoch 42/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2983e-04 - mean_absolute_error: 0.0083
# Epoch 43/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1655e-04 - mean_absolute_error: 0.0073
# Epoch 44/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2251e-04 - mean_absolute_error: 0.0076
# Epoch 45/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5393e-04 - mean_absolute_error: 0.0087
# Epoch 46/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1191e-04 - mean_absolute_error: 0.0072
# Epoch 47/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1974e-04 - mean_absolute_error: 0.0073
# Epoch 48/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.8327e-05 - mean_absolute_error: 0.0067
# Epoch 49/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1122e-04 - mean_absolute_error: 0.0074
# Epoch 50/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0491e-04 - mean_absolute_error: 0.0070
# Epoch 51/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8578e-04 - mean_absolute_error: 0.0100
# Epoch 52/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0320e-04 - mean_absolute_error: 0.0067
# Epoch 53/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.2168e-05 - mean_absolute_error: 0.0065
# Epoch 54/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0735e-04 - mean_absolute_error: 0.0070
# Epoch 55/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1084e-04 - mean_absolute_error: 0.0070
# Epoch 56/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0635e-04 - mean_absolute_error: 0.0070
# Epoch 57/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.8323e-05 - mean_absolute_error: 0.0065
# Epoch 58/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - loss: 1.1414e-04 - mean_absolute_error: 0.0072
# Epoch 59/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - loss: 9.0184e-05 - mean_absolute_error: 0.0062
# Epoch 60/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - loss: 1.2340e-04 - mean_absolute_error: 0.0078
# Epoch 61/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - loss: 9.2032e-05 - mean_absolute_error: 0.0063
# Epoch 62/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8638e-04 - mean_absolute_error: 0.0098
# Epoch 63/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 1.1272e-04 - mean_absolute_error: 0.0073
# Epoch 64/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 1.1929e-04 - mean_absolute_error: 0.0077
# Epoch 65/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.0966e-05 - mean_absolute_error: 0.0065
# Epoch 66/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - loss: 9.7472e-05 - mean_absolute_error: 0.0064
# Epoch 67/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0059e-04 - mean_absolute_error: 0.0068
# Epoch 68/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.3490e-05 - mean_absolute_error: 0.0064
# Epoch 69/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.2132e-05 - mean_absolute_error: 0.0061
# Epoch 70/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2950e-04 - mean_absolute_error: 0.0080
# Epoch 71/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.5966e-05 - mean_absolute_error: 0.0066
# Epoch 72/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.9804e-05 - mean_absolute_error: 0.0061
# Epoch 73/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.9674e-05 - mean_absolute_error: 0.0069
# Epoch 74/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1343e-04 - mean_absolute_error: 0.0074
# Epoch 75/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0791e-04 - mean_absolute_error: 0.0070
# Epoch 76/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.6330e-05 - mean_absolute_error: 0.0068
# Epoch 77/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.3017e-05 - mean_absolute_error: 0.0064
# Epoch 78/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1035e-04 - mean_absolute_error: 0.0074
# Epoch 79/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.9460e-05 - mean_absolute_error: 0.0057
# Epoch 80/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - loss: 1.0026e-04 - mean_absolute_error: 0.0069
# Epoch 81/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - loss: 1.1324e-04 - mean_absolute_error: 0.0074
# Epoch 82/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6396e-04 - mean_absolute_error: 0.0092
# Epoch 83/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1445e-04 - mean_absolute_error: 0.0072
# Epoch 84/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - loss: 7.7642e-05 - mean_absolute_error: 0.0059
# Epoch 85/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.9797e-05 - mean_absolute_error: 0.0064
# Epoch 86/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.3721e-05 - mean_absolute_error: 0.0059
# Epoch 87/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.0211e-05 - mean_absolute_error: 0.0064
# Epoch 88/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.1093e-05 - mean_absolute_error: 0.0058
# Epoch 89/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.9665e-05 - mean_absolute_error: 0.0057
# Epoch 90/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.8754e-05 - mean_absolute_error: 0.0059
# Epoch 91/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.2900e-05 - mean_absolute_error: 0.0060
# Epoch 92/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.5779e-05 - mean_absolute_error: 0.0064
# Epoch 93/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.8247e-05 - mean_absolute_error: 0.0063
# Epoch 94/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0045e-04 - mean_absolute_error: 0.0064
# Epoch 95/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.4034e-05 - mean_absolute_error: 0.0060
# Epoch 96/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.5578e-05 - mean_absolute_error: 0.0068
# Epoch 97/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.7771e-05 - mean_absolute_error: 0.0067
# Epoch 98/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.7146e-05 - mean_absolute_error: 0.0062
# Epoch 99/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.6257e-05 - mean_absolute_error: 0.0065
# Epoch 100/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.2734e-05 - mean_absolute_error: 0.0062
# Epoch 101/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.4190e-05 - mean_absolute_error: 0.0067
# Epoch 102/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.3604e-05 - mean_absolute_error: 0.0061
# Epoch 103/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.1640e-05 - mean_absolute_error: 0.0062
# Epoch 104/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.0763e-05 - mean_absolute_error: 0.0059
# Epoch 105/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.9080e-05 - mean_absolute_error: 0.0059
# Epoch 106/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.8841e-05 - mean_absolute_error: 0.0058
# Epoch 107/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.2424e-05 - mean_absolute_error: 0.0057
# Epoch 108/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.9138e-05 - mean_absolute_error: 0.0059
# Epoch 109/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.6185e-05 - mean_absolute_error: 0.0067
# Epoch 110/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.4706e-05 - mean_absolute_error: 0.0061
# Epoch 111/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.8161e-05 - mean_absolute_error: 0.0068
# Epoch 112/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.8069e-05 - mean_absolute_error: 0.0062
# Epoch 113/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.8877e-05 - mean_absolute_error: 0.0058
# Epoch 114/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.4956e-05 - mean_absolute_error: 0.0061
# Epoch 115/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 994us/step - loss: 9.4389e-05 - mean_absolute_error: 0.0065
# Epoch 116/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.5624e-05 - mean_absolute_error: 0.0052
# Epoch 117/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.4871e-05 - mean_absolute_error: 0.0058
# Epoch 118/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.2952e-05 - mean_absolute_error: 0.0065
# Epoch 119/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.8471e-05 - mean_absolute_error: 0.0062
# Epoch 120/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0288e-04 - mean_absolute_error: 0.0069
# Epoch 121/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.5890e-05 - mean_absolute_error: 0.0056
# Epoch 122/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.4894e-05 - mean_absolute_error: 0.0053
# Epoch 123/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.8221e-05 - mean_absolute_error: 0.0058
# Epoch 124/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.1090e-05 - mean_absolute_error: 0.0061
# Epoch 125/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.8675e-05 - mean_absolute_error: 0.0053
# Epoch 126/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.9794e-05 - mean_absolute_error: 0.0055
# Epoch 127/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.8159e-05 - mean_absolute_error: 0.0062
# Epoch 128/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.7258e-05 - mean_absolute_error: 0.0056
# Epoch 129/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.2520e-05 - mean_absolute_error: 0.0055
# Epoch 130/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.9805e-05 - mean_absolute_error: 0.0053
# Epoch 131/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.1453e-05 - mean_absolute_error: 0.0056
# Epoch 132/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.0091e-05 - mean_absolute_error: 0.0058
# Epoch 133/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.2102e-05 - mean_absolute_error: 0.0055
# Epoch 134/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.7299e-05 - mean_absolute_error: 0.0058
# Epoch 135/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0169e-04 - mean_absolute_error: 0.0072
# Epoch 136/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.1980e-05 - mean_absolute_error: 0.0064
# Epoch 137/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.1571e-05 - mean_absolute_error: 0.0058
# Epoch 138/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.6089e-05 - mean_absolute_error: 0.0062
# Epoch 139/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.0724e-05 - mean_absolute_error: 0.0059
# Epoch 140/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.5415e-05 - mean_absolute_error: 0.0056
# Epoch 141/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.0548e-05 - mean_absolute_error: 0.0055
# Epoch 142/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.8159e-05 - mean_absolute_error: 0.0054
# Epoch 143/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - loss: 8.0599e-05 - mean_absolute_error: 0.0063
# Epoch 144/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - loss: 8.1905e-05 - mean_absolute_error: 0.0060
# Epoch 145/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - loss: 6.8343e-05 - mean_absolute_error: 0.0054
# Epoch 146/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - loss: 6.7547e-05 - mean_absolute_error: 0.0052
# Epoch 147/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.1538e-05 - mean_absolute_error: 0.0058
# Epoch 148/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2193e-04 - mean_absolute_error: 0.0078
# Epoch 149/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.8004e-05 - mean_absolute_error: 0.0057
# Epoch 150/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - loss: 7.3289e-05 - mean_absolute_error: 0.0057
# Epoch 151/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 7.6005e-05 - mean_absolute_error: 0.0054
# Epoch 152/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 9.1272e-05 - mean_absolute_error: 0.0064
# Epoch 153/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.2061e-05 - mean_absolute_error: 0.0056
# Epoch 154/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step - loss: 7.8239e-05 - mean_absolute_error: 0.0057
# Epoch 155/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 6.9290e-05 - mean_absolute_error: 0.0054
# Epoch 156/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.4655e-05 - mean_absolute_error: 0.0053
# Epoch 157/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.9169e-05 - mean_absolute_error: 0.0057
# Epoch 158/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.5491e-05 - mean_absolute_error: 0.0054
# Epoch 159/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.0678e-05 - mean_absolute_error: 0.0060
# Epoch 160/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.0375e-05 - mean_absolute_error: 0.0054
# Epoch 161/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.8054e-05 - mean_absolute_error: 0.0059
# Epoch 162/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 8.1881e-05 - mean_absolute_error: 0.0061
# Epoch 163/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - loss: 5.9978e-05 - mean_absolute_error: 0.0051
# Epoch 164/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - loss: 8.3884e-05 - mean_absolute_error: 0.0062
# Epoch 165/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - loss: 9.6676e-05 - mean_absolute_error: 0.0072
# Epoch 166/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 882us/step - loss: 7.6092e-05 - mean_absolute_error: 0.0057
# Epoch 167/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - loss: 7.0189e-05 - mean_absolute_error: 0.0055
# Epoch 168/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - loss: 8.9965e-05 - mean_absolute_error: 0.0067
# Epoch 169/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - loss: 7.9547e-05 - mean_absolute_error: 0.0059
# Epoch 170/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - loss: 7.3815e-05 - mean_absolute_error: 0.0056
# Epoch 171/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.0688e-05 - mean_absolute_error: 0.0057
# Epoch 172/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.8205e-05 - mean_absolute_error: 0.0053
# Epoch 173/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 7.8054e-05 - mean_absolute_error: 0.0058
# Epoch 174/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - loss: 7.3532e-05 - mean_absolute_error: 0.0056
# Epoch 175/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - loss: 7.4027e-05 - mean_absolute_error: 0.0056
# Epoch 176/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.1583e-05 - mean_absolute_error: 0.0060
# Epoch 177/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.8165e-05 - mean_absolute_error: 0.0056
# Epoch 178/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.2814e-05 - mean_absolute_error: 0.0067
# Epoch 179/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.2425e-05 - mean_absolute_error: 0.0055
# Epoch 180/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - loss: 8.0554e-05 - mean_absolute_error: 0.0060
# Epoch 181/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - loss: 8.4319e-05 - mean_absolute_error: 0.0064
# Epoch 182/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.7176e-05 - mean_absolute_error: 0.0058
# Epoch 183/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - loss: 6.4771e-05 - mean_absolute_error: 0.0053
# Epoch 184/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - loss: 7.1631e-05 - mean_absolute_error: 0.0056
# Epoch 185/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - loss: 7.4368e-05 - mean_absolute_error: 0.0056
# Epoch 186/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - loss: 7.5468e-05 - mean_absolute_error: 0.0058
# Epoch 187/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 6.3032e-05 - mean_absolute_error: 0.0053
# Epoch 188/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 923us/step - loss: 6.5499e-05 - mean_absolute_error: 0.0056
# Epoch 189/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - loss: 7.3034e-05 - mean_absolute_error: 0.0057
# Epoch 190/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 8.6118e-05 - mean_absolute_error: 0.0060
# Epoch 191/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 975us/step - loss: 6.4854e-05 - mean_absolute_error: 0.0054
# Epoch 192/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 6.6148e-05 - mean_absolute_error: 0.0054
# Epoch 193/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 7.0438e-05 - mean_absolute_error: 0.0054
# Epoch 194/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 7.8598e-05 - mean_absolute_error: 0.0060
# Epoch 195/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - loss: 6.6102e-05 - mean_absolute_error: 0.0054
# Epoch 196/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - loss: 7.1104e-05 - mean_absolute_error: 0.0056
# Epoch 197/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 950us/step - loss: 7.0010e-05 - mean_absolute_error: 0.0056
# Epoch 198/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - loss: 7.7277e-05 - mean_absolute_error: 0.0057
# Epoch 199/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.8096e-05 - mean_absolute_error: 0.0066
# Epoch 200/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.0007e-05 - mean_absolute_error: 0.0054

# %% [markdown]
# ### Predicting with test set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test set again to evaluate, because i shaped the data between 0 to 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 121
# 132

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)
# Out:
# Model evalution on test set
# MSE: 9631242.847758144
# RMSE: 3103.4243744222517
# MAE: 2241.3729338842977
# MAPE: 1.9699877507707484 %

# %% [markdown]
# ## 4. Forecast the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(test_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
y_pred_30_days
# Out:
# array([[130974.54 ],
#        [130972.31 ],
#        [130898.875],
#        [130795.08 ],
#        [130949.51 ],
#        [130936.44 ],
#        [130940.25 ],
#        [130948.734],
#        [130942.16 ],
#        [130943.336],
#        [130943.234],
#        [130942.76 ],
#        [130943.055],
#        [130942.97 ],
#        [130942.99 ],
#        [130942.99 ],
#        [130942.984],
#        [130942.99 ],
#        [130942.984],
#        [130942.984],
#        [130942.984],
#        [130942.99 ],
#        [130942.984],
#        [130942.984],
#        [130942.984],
#        [130942.99 ],
#        [130942.984],
#        [130942.984],
#        [130942.984],
#        [130942.99 ],
#        [130942.984]], dtype=float32)

# %% [markdown]
# ### Continue forecast the next 60/90 days

# %%
y_pred_60_days = forecast(test_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step

# %%
y_pred_90_days = forecast(test_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")

    # Predict test set
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        test_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Next {days} Days",
        linestyle="--",
    )

    plt.title(f"Forecast {stock_name[stock]} Stock Closing Price Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Forecast the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
