# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Input

plt.style.use('default')

# %% [markdown]
# ## 1. Data preprocessing

# %%
split_type = [0.8,0.7,0.9]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 0  # FPT
split = 0

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01  19270
# 2019-03-04  19440
# 2019-03-05  19390
# 2019-03-06  19270
# 2019-03-07  19330

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0        19270
# 1        19440
# 2        19390
# 3        19270
# 4        19330
#          ...
# 1308    132800
# 1309    137000
# 1310    135700
# 1311    135000
# 1312    134600
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using neural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split] * len(df_scaled))
test_size = len(df_scaled) - train_size

# %%
# Splitting data into train, test set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size:]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test set
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1039, 10), (1039,), (252, 10), (252,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
UNITS = 64

# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(UNITS),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 64)             │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,289 (16.75 KB)
#  Trainable params: 4,289 (16.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.1526 - mean_absolute_error: 0.2577
# Epoch 2/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0021 - mean_absolute_error: 0.0350
# Epoch 3/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.9887e-04 - mean_absolute_error: 0.0176
# Epoch 4/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - loss: 5.6564e-04 - mean_absolute_error: 0.0170
# Epoch 5/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.7118e-04 - mean_absolute_error: 0.0173
# Epoch 6/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - loss: 5.5149e-04 - mean_absolute_error: 0.0164
# Epoch 7/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 4.6824e-04 - mean_absolute_error: 0.0158
# Epoch 8/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - loss: 5.1322e-04 - mean_absolute_error: 0.0160
# Epoch 9/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.5386e-04 - mean_absolute_error: 0.0151
# Epoch 10/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.0998e-04 - mean_absolute_error: 0.0145
# Epoch 11/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.6709e-04 - mean_absolute_error: 0.0148
# Epoch 12/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4.4380e-04 - mean_absolute_error: 0.0146
# Epoch 13/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - loss: 3.2687e-04 - mean_absolute_error: 0.0125
# Epoch 14/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - loss: 3.8020e-04 - mean_absolute_error: 0.0137
# Epoch 15/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3.4960e-04 - mean_absolute_error: 0.0133
# Epoch 16/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - loss: 3.7184e-04 - mean_absolute_error: 0.0133
# Epoch 17/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 3.3279e-04 - mean_absolute_error: 0.0126
# Epoch 18/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - loss: 3.1888e-04 - mean_absolute_error: 0.0121
# Epoch 19/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 3.3320e-04 - mean_absolute_error: 0.0122
# Epoch 20/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 2.8908e-04 - mean_absolute_error: 0.0120
# Epoch 21/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 3.0123e-04 - mean_absolute_error: 0.0123
# Epoch 22/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - loss: 2.9434e-04 - mean_absolute_error: 0.0117
# Epoch 23/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - loss: 2.2463e-04 - mean_absolute_error: 0.0105
# Epoch 24/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4807e-04 - mean_absolute_error: 0.0108
# Epoch 25/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - loss: 2.1274e-04 - mean_absolute_error: 0.0100
# Epoch 26/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - loss: 2.4843e-04 - mean_absolute_error: 0.0107
# Epoch 27/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - loss: 2.5607e-04 - mean_absolute_error: 0.0108
# Epoch 28/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - loss: 2.1400e-04 - mean_absolute_error: 0.0101
# Epoch 29/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.2120e-04 - mean_absolute_error: 0.0100
# Epoch 30/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1953e-04 - mean_absolute_error: 0.0099
# Epoch 31/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0636e-04 - mean_absolute_error: 0.0095
# Epoch 32/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0319e-04 - mean_absolute_error: 0.0096
# Epoch 33/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - loss: 2.5886e-04 - mean_absolute_error: 0.0113
# Epoch 34/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6402e-04 - mean_absolute_error: 0.0088
# Epoch 35/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 2.1798e-04 - mean_absolute_error: 0.0103
# Epoch 36/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 1.6785e-04 - mean_absolute_error: 0.0089
# Epoch 37/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - loss: 1.9723e-04 - mean_absolute_error: 0.0098
# Epoch 38/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 991us/step - loss: 2.2503e-04 - mean_absolute_error: 0.0102
# Epoch 39/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7750e-04 - mean_absolute_error: 0.0095
# Epoch 40/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9463e-04 - mean_absolute_error: 0.0095
# Epoch 41/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4285e-04 - mean_absolute_error: 0.0082
# Epoch 42/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6896e-04 - mean_absolute_error: 0.0088
# Epoch 43/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6844e-04 - mean_absolute_error: 0.0088
# Epoch 44/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6085e-04 - mean_absolute_error: 0.0086
# Epoch 45/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5718e-04 - mean_absolute_error: 0.0082
# Epoch 46/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5226e-04 - mean_absolute_error: 0.0081
# Epoch 47/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 1.6452e-04 - mean_absolute_error: 0.0086
# Epoch 48/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - loss: 2.1349e-04 - mean_absolute_error: 0.0101
# Epoch 49/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 986us/step - loss: 1.3276e-04 - mean_absolute_error: 0.0078
# Epoch 50/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - loss: 1.2901e-04 - mean_absolute_error: 0.0078
# Epoch 51/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 1.4739e-04 - mean_absolute_error: 0.0081
# Epoch 52/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 1.3699e-04 - mean_absolute_error: 0.0076
# Epoch 53/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 1.5568e-04 - mean_absolute_error: 0.0085
# Epoch 54/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - loss: 1.6469e-04 - mean_absolute_error: 0.0084
# Epoch 55/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 1.2955e-04 - mean_absolute_error: 0.0076
# Epoch 56/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - loss: 1.4155e-04 - mean_absolute_error: 0.0080
# Epoch 57/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - loss: 1.5969e-04 - mean_absolute_error: 0.0087
# Epoch 58/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7022e-04 - mean_absolute_error: 0.0089
# Epoch 59/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6963e-04 - mean_absolute_error: 0.0091
# Epoch 60/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 1.3630e-04 - mean_absolute_error: 0.0080
# Epoch 61/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - loss: 1.4600e-04 - mean_absolute_error: 0.0081
# Epoch 62/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 1.4874e-04 - mean_absolute_error: 0.0083
# Epoch 63/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4988e-04 - mean_absolute_error: 0.0083
# Epoch 64/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4191e-04 - mean_absolute_error: 0.0080
# Epoch 65/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 1.3329e-04 - mean_absolute_error: 0.0078
# Epoch 66/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 1.3686e-04 - mean_absolute_error: 0.0079
# Epoch 67/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - loss: 1.1542e-04 - mean_absolute_error: 0.0073
# Epoch 68/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - loss: 1.7223e-04 - mean_absolute_error: 0.0095
# Epoch 69/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - loss: 1.7018e-04 - mean_absolute_error: 0.0088
# Epoch 70/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - loss: 1.3753e-04 - mean_absolute_error: 0.0083
# Epoch 71/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - loss: 1.2220e-04 - mean_absolute_error: 0.0072
# Epoch 72/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2775e-04 - mean_absolute_error: 0.0076
# Epoch 73/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6031e-04 - mean_absolute_error: 0.0089
# Epoch 74/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2564e-04 - mean_absolute_error: 0.0079
# Epoch 75/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - loss: 1.0531e-04 - mean_absolute_error: 0.0070
# Epoch 76/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 1.1776e-04 - mean_absolute_error: 0.0073
# Epoch 77/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7912e-04 - mean_absolute_error: 0.0092
# Epoch 78/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - loss: 1.3294e-04 - mean_absolute_error: 0.0077
# Epoch 79/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 1.2808e-04 - mean_absolute_error: 0.0072
# Epoch 80/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - loss: 1.4520e-04 - mean_absolute_error: 0.0084
# Epoch 81/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 1.1846e-04 - mean_absolute_error: 0.0074
# Epoch 82/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 1.3154e-04 - mean_absolute_error: 0.0077
# Epoch 83/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 1.0791e-04 - mean_absolute_error: 0.0071
# Epoch 84/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1177e-04 - mean_absolute_error: 0.0071
# Epoch 85/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1542e-04 - mean_absolute_error: 0.0071
# Epoch 86/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0237e-04 - mean_absolute_error: 0.0069
# Epoch 87/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - loss: 1.2704e-04 - mean_absolute_error: 0.0075
# Epoch 88/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 1.0565e-04 - mean_absolute_error: 0.0069
# Epoch 89/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - loss: 1.0464e-04 - mean_absolute_error: 0.0068
# Epoch 90/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2736e-04 - mean_absolute_error: 0.0075
# Epoch 91/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - loss: 1.1223e-04 - mean_absolute_error: 0.0073
# Epoch 92/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1459e-04 - mean_absolute_error: 0.0071
# Epoch 93/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 1.0611e-04 - mean_absolute_error: 0.0070
# Epoch 94/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0907e-04 - mean_absolute_error: 0.0071
# Epoch 95/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 989us/step - loss: 1.2121e-04 - mean_absolute_error: 0.0073
# Epoch 96/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - loss: 1.0217e-04 - mean_absolute_error: 0.0067
# Epoch 97/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 1.0420e-04 - mean_absolute_error: 0.0069
# Epoch 98/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - loss: 1.1400e-04 - mean_absolute_error: 0.0070
# Epoch 99/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2243e-04 - mean_absolute_error: 0.0072
# Epoch 100/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.2989e-05 - mean_absolute_error: 0.0065
# Epoch 101/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2409e-04 - mean_absolute_error: 0.0078
# Epoch 102/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.0383e-05 - mean_absolute_error: 0.0064
# Epoch 103/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0272e-04 - mean_absolute_error: 0.0067
# Epoch 104/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.9370e-05 - mean_absolute_error: 0.0066
# Epoch 105/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0291e-04 - mean_absolute_error: 0.0066
# Epoch 106/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.9678e-05 - mean_absolute_error: 0.0064
# Epoch 107/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.7416e-05 - mean_absolute_error: 0.0063
# Epoch 108/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5435e-04 - mean_absolute_error: 0.0083
# Epoch 109/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.8745e-05 - mean_absolute_error: 0.0065
# Epoch 110/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0151e-04 - mean_absolute_error: 0.0068
# Epoch 111/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1248e-04 - mean_absolute_error: 0.0072
# Epoch 112/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.8450e-05 - mean_absolute_error: 0.0065
# Epoch 113/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0550e-04 - mean_absolute_error: 0.0070
# Epoch 114/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.8946e-05 - mean_absolute_error: 0.0065
# Epoch 115/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0082e-04 - mean_absolute_error: 0.0066
# Epoch 116/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1587e-04 - mean_absolute_error: 0.0071
# Epoch 117/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.1229e-04 - mean_absolute_error: 0.0069
# Epoch 118/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.2818e-05 - mean_absolute_error: 0.0062
# Epoch 119/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.9283e-05 - mean_absolute_error: 0.0061
# Epoch 120/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.6217e-05 - mean_absolute_error: 0.0062
# Epoch 121/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.7660e-05 - mean_absolute_error: 0.0059
# Epoch 122/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.6821e-05 - mean_absolute_error: 0.0057
# Epoch 123/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - loss: 7.9518e-05 - mean_absolute_error: 0.0059
# Epoch 124/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 8.9261e-05 - mean_absolute_error: 0.0063
# Epoch 125/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 1.0735e-04 - mean_absolute_error: 0.0066
# Epoch 126/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - loss: 1.0216e-04 - mean_absolute_error: 0.0068
# Epoch 127/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.0789e-05 - mean_absolute_error: 0.0060
# Epoch 128/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - loss: 8.7588e-05 - mean_absolute_error: 0.0060
# Epoch 129/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 843us/step - loss: 8.9461e-05 - mean_absolute_error: 0.0062
# Epoch 130/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - loss: 9.4377e-05 - mean_absolute_error: 0.0068
# Epoch 131/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 7.8776e-05 - mean_absolute_error: 0.0060
# Epoch 132/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 7.5346e-05 - mean_absolute_error: 0.0058
# Epoch 133/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 9.8393e-05 - mean_absolute_error: 0.0071
# Epoch 134/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 9.1154e-05 - mean_absolute_error: 0.0065
# Epoch 135/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 8.6035e-05 - mean_absolute_error: 0.0062
# Epoch 136/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - loss: 9.1155e-05 - mean_absolute_error: 0.0064
# Epoch 137/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 912us/step - loss: 7.4934e-05 - mean_absolute_error: 0.0057
# Epoch 138/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - loss: 7.9175e-05 - mean_absolute_error: 0.0058
# Epoch 139/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 7.9284e-05 - mean_absolute_error: 0.0057
# Epoch 140/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - loss: 8.3828e-05 - mean_absolute_error: 0.0061
# Epoch 141/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - loss: 7.5510e-05 - mean_absolute_error: 0.0058
# Epoch 142/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 7.1440e-05 - mean_absolute_error: 0.0054
# Epoch 143/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.5675e-05 - mean_absolute_error: 0.0057
# Epoch 144/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 993us/step - loss: 8.1294e-05 - mean_absolute_error: 0.0060
# Epoch 145/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.5569e-05 - mean_absolute_error: 0.0058
# Epoch 146/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.6391e-05 - mean_absolute_error: 0.0061
# Epoch 147/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - loss: 6.5438e-05 - mean_absolute_error: 0.0053
# Epoch 148/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 926us/step - loss: 7.7795e-05 - mean_absolute_error: 0.0058
# Epoch 149/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 870us/step - loss: 7.8222e-05 - mean_absolute_error: 0.0058
# Epoch 150/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - loss: 6.2667e-05 - mean_absolute_error: 0.0050
# Epoch 151/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 880us/step - loss: 7.0495e-05 - mean_absolute_error: 0.0054
# Epoch 152/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 8.1142e-05 - mean_absolute_error: 0.0063
# Epoch 153/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 868us/step - loss: 6.6951e-05 - mean_absolute_error: 0.0054
# Epoch 154/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step - loss: 8.6179e-05 - mean_absolute_error: 0.0062
# Epoch 155/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 830us/step - loss: 8.2329e-05 - mean_absolute_error: 0.0062
# Epoch 156/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 906us/step - loss: 8.3857e-05 - mean_absolute_error: 0.0062
# Epoch 157/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 889us/step - loss: 7.0900e-05 - mean_absolute_error: 0.0056
# Epoch 158/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - loss: 8.9859e-05 - mean_absolute_error: 0.0065
# Epoch 159/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 7.4465e-05 - mean_absolute_error: 0.0059
# Epoch 160/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 5.8126e-05 - mean_absolute_error: 0.0052
# Epoch 161/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 9.2892e-05 - mean_absolute_error: 0.0065
# Epoch 162/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7.6798e-05 - mean_absolute_error: 0.0057
# Epoch 163/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.1428e-05 - mean_absolute_error: 0.0055
# Epoch 164/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.2040e-05 - mean_absolute_error: 0.0054
# Epoch 165/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.5539e-05 - mean_absolute_error: 0.0053
# Epoch 166/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 7.3656e-05 - mean_absolute_error: 0.0057
# Epoch 167/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 1.0477e-04 - mean_absolute_error: 0.0068
# Epoch 168/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step - loss: 5.9866e-05 - mean_absolute_error: 0.0051
# Epoch 169/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - loss: 7.8442e-05 - mean_absolute_error: 0.0056
# Epoch 170/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - loss: 6.1457e-05 - mean_absolute_error: 0.0052
# Epoch 171/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - loss: 6.7937e-05 - mean_absolute_error: 0.0055
# Epoch 172/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 891us/step - loss: 6.6672e-05 - mean_absolute_error: 0.0052
# Epoch 173/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 6.6221e-05 - mean_absolute_error: 0.0051
# Epoch 174/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - loss: 7.1270e-05 - mean_absolute_error: 0.0055
# Epoch 175/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7.9090e-05 - mean_absolute_error: 0.0058
# Epoch 176/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.1724e-05 - mean_absolute_error: 0.0054
# Epoch 177/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 979us/step - loss: 7.7444e-05 - mean_absolute_error: 0.0061
# Epoch 178/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - loss: 6.9575e-05 - mean_absolute_error: 0.0054
# Epoch 179/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 866us/step - loss: 7.4827e-05 - mean_absolute_error: 0.0059
# Epoch 180/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - loss: 7.3783e-05 - mean_absolute_error: 0.0059
# Epoch 181/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - loss: 8.1303e-05 - mean_absolute_error: 0.0060
# Epoch 182/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - loss: 8.0474e-05 - mean_absolute_error: 0.0061
# Epoch 183/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - loss: 5.6819e-05 - mean_absolute_error: 0.0049
# Epoch 184/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.6067e-05 - mean_absolute_error: 0.0053
# Epoch 185/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 6.0719e-05 - mean_absolute_error: 0.0052
# Epoch 186/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 851us/step - loss: 6.6476e-05 - mean_absolute_error: 0.0053
# Epoch 187/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 6.1026e-05 - mean_absolute_error: 0.0051
# Epoch 188/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - loss: 6.4450e-05 - mean_absolute_error: 0.0051
# Epoch 189/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - loss: 5.9517e-05 - mean_absolute_error: 0.0050
# Epoch 190/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - loss: 5.8411e-05 - mean_absolute_error: 0.0050
# Epoch 191/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 7.4679e-05 - mean_absolute_error: 0.0056
# Epoch 192/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - loss: 6.6086e-05 - mean_absolute_error: 0.0054
# Epoch 193/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 6.0231e-05 - mean_absolute_error: 0.0049
# Epoch 194/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 5.8275e-05 - mean_absolute_error: 0.0050
# Epoch 195/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.6730e-05 - mean_absolute_error: 0.0063
# Epoch 196/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - loss: 6.3102e-05 - mean_absolute_error: 0.0053
# Epoch 197/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 867us/step - loss: 6.6397e-05 - mean_absolute_error: 0.0052
# Epoch 198/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 6.0381e-05 - mean_absolute_error: 0.0055
# Epoch 199/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - loss: 7.6462e-05 - mean_absolute_error: 0.0055
# Epoch 200/200
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 6.5557e-05 - mean_absolute_error: 0.0052

# %% [markdown]
# ### Predicting with test set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test set again to evaluate, because i shaped the data between 0 to 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 252
# 263

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)
# Out:
# Model evalution on test set
# MSE: 8514117.532766676
# RMSE: 2917.8960798436046
# MAE: 1973.960193452381
# MAPE: 1.8904714160048222 %

# %% [markdown]
# ## 4. Forecast the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(test_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
y_pred_30_days
# Out:
# array([[129079.82 ],
#        [128553.71 ],
#        [128538.67 ],
#        [128229.87 ],
#        [128248.65 ],
#        [128257.77 ],
#        [128241.89 ],
#        [128245.42 ],
#        [128246.055],
#        [128245.09 ],
#        [128245.43 ],
#        [128245.46 ],
#        [128245.42 ],
#        [128245.42 ],
#        [128245.41 ],
#        [128245.41 ],
#        [128245.39 ],
#        [128245.39 ],
#        [128245.42 ],
#        [128245.41 ],
#        [128245.375],
#        [128245.39 ],
#        [128245.39 ],
#        [128245.39 ],
#        [128245.39 ],
#        [128245.41 ],
#        [128245.35 ],
#        [128245.39 ],
#        [128245.39 ],
#        [128245.41 ],
#        [128245.39 ]], dtype=float32)

# %% [markdown]
# ### Continue forecast the next 60/90 days

# %%
y_pred_60_days = forecast(test_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step

# %%
y_pred_90_days = forecast(test_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")

    # Predict test set
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        test_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Next {days} Days",
        linestyle="--",
    )

    plt.title(f"Forecast {stock_name[stock]} Stock Closing Price Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Forecast the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
