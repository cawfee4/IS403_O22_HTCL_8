# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: CMG - Test/Train/Vaildation: 60/20/20
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1282.1916118787983
# - MAE: 979.5341835781873
# - MAPE: 3.010620249219632 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 1  # 6 2 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.tail()
# Out:
#             close
# time
# 2024-05-27  59000
# 2024-05-28  62100
# 2024-05-29  60000
# 2024-05-30  59200
# 2024-05-31  60900

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((776, 10), (776,), (251, 10), (251,), (253, 10), (253,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - loss: 0.0151 - mean_absolute_error: 0.0873 - val_loss: 0.0042 - val_mean_absolute_error: 0.0571
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0011 - mean_absolute_error: 0.0241 - val_loss: 0.0012 - val_mean_absolute_error: 0.0259
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.7349e-04 - mean_absolute_error: 0.0165 - val_loss: 8.3912e-04 - val_mean_absolute_error: 0.0212
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.6503e-04 - mean_absolute_error: 0.0140 - val_loss: 6.8413e-04 - val_mean_absolute_error: 0.0190
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5731e-04 - mean_absolute_error: 0.0115 - val_loss: 7.6618e-04 - val_mean_absolute_error: 0.0214
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5531e-04 - mean_absolute_error: 0.0114 - val_loss: 7.4620e-04 - val_mean_absolute_error: 0.0216
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8002e-04 - mean_absolute_error: 0.0121 - val_loss: 5.6406e-04 - val_mean_absolute_error: 0.0179
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2120e-04 - mean_absolute_error: 0.0105 - val_loss: 7.3132e-04 - val_mean_absolute_error: 0.0218
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0856e-04 - mean_absolute_error: 0.0105 - val_loss: 4.5385e-04 - val_mean_absolute_error: 0.0153
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9092e-04 - mean_absolute_error: 0.0096 - val_loss: 8.1506e-04 - val_mean_absolute_error: 0.0235
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0611e-04 - mean_absolute_error: 0.0103 - val_loss: 4.3241e-04 - val_mean_absolute_error: 0.0150
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9951e-04 - mean_absolute_error: 0.0100 - val_loss: 4.4307e-04 - val_mean_absolute_error: 0.0154
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8554e-04 - mean_absolute_error: 0.0096 - val_loss: 4.5170e-04 - val_mean_absolute_error: 0.0157
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6613e-04 - mean_absolute_error: 0.0090 - val_loss: 4.2766e-04 - val_mean_absolute_error: 0.0151
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7006e-04 - mean_absolute_error: 0.0097 - val_loss: 6.4806e-04 - val_mean_absolute_error: 0.0206
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.5898e-04 - mean_absolute_error: 0.0119 - val_loss: 6.2121e-04 - val_mean_absolute_error: 0.0198
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.9478e-04 - mean_absolute_error: 0.0099 - val_loss: 6.0567e-04 - val_mean_absolute_error: 0.0195
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6335e-04 - mean_absolute_error: 0.0094 - val_loss: 4.1147e-04 - val_mean_absolute_error: 0.0149
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5270e-04 - mean_absolute_error: 0.0088 - val_loss: 4.0145e-04 - val_mean_absolute_error: 0.0145
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7013e-04 - mean_absolute_error: 0.0088 - val_loss: 3.8163e-04 - val_mean_absolute_error: 0.0139
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7885e-04 - mean_absolute_error: 0.0093 - val_loss: 4.3207e-04 - val_mean_absolute_error: 0.0156
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7104e-04 - mean_absolute_error: 0.0093 - val_loss: 4.6306e-04 - val_mean_absolute_error: 0.0163
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6380e-04 - mean_absolute_error: 0.0088 - val_loss: 3.9431e-04 - val_mean_absolute_error: 0.0145
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0494e-04 - mean_absolute_error: 0.0099 - val_loss: 3.8745e-04 - val_mean_absolute_error: 0.0143
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7973e-04 - mean_absolute_error: 0.0094 - val_loss: 3.7679e-04 - val_mean_absolute_error: 0.0140
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6175e-04 - mean_absolute_error: 0.0091 - val_loss: 4.6569e-04 - val_mean_absolute_error: 0.0164
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8151e-04 - mean_absolute_error: 0.0093 - val_loss: 3.6656e-04 - val_mean_absolute_error: 0.0138
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7908e-04 - mean_absolute_error: 0.0095 - val_loss: 3.7598e-04 - val_mean_absolute_error: 0.0142
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4418e-04 - mean_absolute_error: 0.0080 - val_loss: 4.0456e-04 - val_mean_absolute_error: 0.0152
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6521e-04 - mean_absolute_error: 0.0090 - val_loss: 3.5601e-04 - val_mean_absolute_error: 0.0136
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5557e-04 - mean_absolute_error: 0.0087 - val_loss: 5.8188e-04 - val_mean_absolute_error: 0.0198
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8223e-04 - mean_absolute_error: 0.0094 - val_loss: 3.6704e-04 - val_mean_absolute_error: 0.0139
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5513e-04 - mean_absolute_error: 0.0088 - val_loss: 3.4726e-04 - val_mean_absolute_error: 0.0134
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6937e-04 - mean_absolute_error: 0.0092 - val_loss: 4.0202e-04 - val_mean_absolute_error: 0.0154
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7318e-04 - mean_absolute_error: 0.0093 - val_loss: 5.0865e-04 - val_mean_absolute_error: 0.0183
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1576e-04 - mean_absolute_error: 0.0106 - val_loss: 3.5984e-04 - val_mean_absolute_error: 0.0137
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3975e-04 - mean_absolute_error: 0.0079 - val_loss: 3.3897e-04 - val_mean_absolute_error: 0.0133
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3643e-04 - mean_absolute_error: 0.0081 - val_loss: 3.3357e-04 - val_mean_absolute_error: 0.0132
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4499e-04 - mean_absolute_error: 0.0082 - val_loss: 4.3695e-04 - val_mean_absolute_error: 0.0166
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5712e-04 - mean_absolute_error: 0.0087 - val_loss: 5.0451e-04 - val_mean_absolute_error: 0.0177
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5000e-04 - mean_absolute_error: 0.0086 - val_loss: 3.9556e-04 - val_mean_absolute_error: 0.0155
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1962e-04 - mean_absolute_error: 0.0108 - val_loss: 3.2700e-04 - val_mean_absolute_error: 0.0129
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4661e-04 - mean_absolute_error: 0.0084 - val_loss: 5.1263e-04 - val_mean_absolute_error: 0.0179
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4846e-04 - mean_absolute_error: 0.0085 - val_loss: 3.9920e-04 - val_mean_absolute_error: 0.0157
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2127e-04 - mean_absolute_error: 0.0078 - val_loss: 3.6538e-04 - val_mean_absolute_error: 0.0147
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1909e-04 - mean_absolute_error: 0.0077 - val_loss: 3.6903e-04 - val_mean_absolute_error: 0.0142
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2795e-04 - mean_absolute_error: 0.0079 - val_loss: 4.9537e-04 - val_mean_absolute_error: 0.0176
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4696e-04 - mean_absolute_error: 0.0086 - val_loss: 5.0100e-04 - val_mean_absolute_error: 0.0185
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4611e-04 - mean_absolute_error: 0.0085 - val_loss: 6.0380e-04 - val_mean_absolute_error: 0.0201
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3904e-04 - mean_absolute_error: 0.0088 - val_loss: 3.7657e-04 - val_mean_absolute_error: 0.0146
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5310e-04 - mean_absolute_error: 0.0086 - val_loss: 3.1437e-04 - val_mean_absolute_error: 0.0131
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1521e-04 - mean_absolute_error: 0.0076 - val_loss: 3.2674e-04 - val_mean_absolute_error: 0.0130
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2211e-04 - mean_absolute_error: 0.0075 - val_loss: 3.5457e-04 - val_mean_absolute_error: 0.0140
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3147e-04 - mean_absolute_error: 0.0082 - val_loss: 3.5959e-04 - val_mean_absolute_error: 0.0149
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2615e-04 - mean_absolute_error: 0.0080 - val_loss: 3.0091e-04 - val_mean_absolute_error: 0.0126
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1927e-04 - mean_absolute_error: 0.0075 - val_loss: 3.2664e-04 - val_mean_absolute_error: 0.0132
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2002e-04 - mean_absolute_error: 0.0076 - val_loss: 2.9829e-04 - val_mean_absolute_error: 0.0126
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2686e-04 - mean_absolute_error: 0.0077 - val_loss: 2.9545e-04 - val_mean_absolute_error: 0.0125
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2189e-04 - mean_absolute_error: 0.0076 - val_loss: 2.9608e-04 - val_mean_absolute_error: 0.0125
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1894e-04 - mean_absolute_error: 0.0077 - val_loss: 3.4855e-04 - val_mean_absolute_error: 0.0141
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0782e-04 - mean_absolute_error: 0.0075 - val_loss: 2.9795e-04 - val_mean_absolute_error: 0.0125
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2625e-04 - mean_absolute_error: 0.0080 - val_loss: 3.6564e-04 - val_mean_absolute_error: 0.0144
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0815e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9248e-04 - val_mean_absolute_error: 0.0124
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1007e-04 - mean_absolute_error: 0.0072 - val_loss: 3.3916e-04 - val_mean_absolute_error: 0.0144
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1481e-04 - mean_absolute_error: 0.0075 - val_loss: 2.9313e-04 - val_mean_absolute_error: 0.0125
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1914e-04 - mean_absolute_error: 0.0077 - val_loss: 2.9868e-04 - val_mean_absolute_error: 0.0126
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1116e-04 - mean_absolute_error: 0.0073 - val_loss: 2.9578e-04 - val_mean_absolute_error: 0.0129
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1022e-04 - mean_absolute_error: 0.0070 - val_loss: 2.9348e-04 - val_mean_absolute_error: 0.0125
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0925e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9163e-04 - val_mean_absolute_error: 0.0127
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1364e-04 - mean_absolute_error: 0.0075 - val_loss: 3.0361e-04 - val_mean_absolute_error: 0.0128
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0290e-04 - mean_absolute_error: 0.0072 - val_loss: 4.3924e-04 - val_mean_absolute_error: 0.0167
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1064e-04 - mean_absolute_error: 0.0076 - val_loss: 5.5350e-04 - val_mean_absolute_error: 0.0193
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3282e-04 - mean_absolute_error: 0.0084 - val_loss: 2.9409e-04 - val_mean_absolute_error: 0.0126
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.2103e-05 - mean_absolute_error: 0.0067 - val_loss: 2.8223e-04 - val_mean_absolute_error: 0.0122
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8319e-05 - mean_absolute_error: 0.0068 - val_loss: 2.8149e-04 - val_mean_absolute_error: 0.0123
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0716e-04 - mean_absolute_error: 0.0069 - val_loss: 3.6383e-04 - val_mean_absolute_error: 0.0153
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3547e-04 - mean_absolute_error: 0.0084 - val_loss: 3.1345e-04 - val_mean_absolute_error: 0.0133
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0015e-04 - mean_absolute_error: 0.0069 - val_loss: 2.9444e-04 - val_mean_absolute_error: 0.0128
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1223e-04 - mean_absolute_error: 0.0069 - val_loss: 3.1093e-04 - val_mean_absolute_error: 0.0133
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0458e-04 - mean_absolute_error: 0.0074 - val_loss: 5.7862e-04 - val_mean_absolute_error: 0.0197
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0961e-04 - mean_absolute_error: 0.0077 - val_loss: 2.9941e-04 - val_mean_absolute_error: 0.0129
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0759e-04 - mean_absolute_error: 0.0068 - val_loss: 2.8947e-04 - val_mean_absolute_error: 0.0128
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1435e-04 - mean_absolute_error: 0.0074 - val_loss: 4.6850e-04 - val_mean_absolute_error: 0.0175
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1349e-04 - mean_absolute_error: 0.0075 - val_loss: 2.8740e-04 - val_mean_absolute_error: 0.0128
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1372e-04 - mean_absolute_error: 0.0070 - val_loss: 2.7913e-04 - val_mean_absolute_error: 0.0123
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0360e-04 - mean_absolute_error: 0.0069 - val_loss: 2.8026e-04 - val_mean_absolute_error: 0.0123
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.5494e-05 - mean_absolute_error: 0.0065 - val_loss: 2.9104e-04 - val_mean_absolute_error: 0.0128
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1771e-04 - mean_absolute_error: 0.0076 - val_loss: 4.0612e-04 - val_mean_absolute_error: 0.0159
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0542e-04 - mean_absolute_error: 0.0071 - val_loss: 4.9287e-04 - val_mean_absolute_error: 0.0180
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1067e-04 - mean_absolute_error: 0.0075 - val_loss: 2.8394e-04 - val_mean_absolute_error: 0.0126
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7235e-05 - mean_absolute_error: 0.0066 - val_loss: 3.0333e-04 - val_mean_absolute_error: 0.0133
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1650e-04 - mean_absolute_error: 0.0076 - val_loss: 2.7525e-04 - val_mean_absolute_error: 0.0122
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7616e-05 - mean_absolute_error: 0.0068 - val_loss: 3.2583e-04 - val_mean_absolute_error: 0.0140
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0100e-04 - mean_absolute_error: 0.0072 - val_loss: 2.8533e-04 - val_mean_absolute_error: 0.0127
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.9376e-05 - mean_absolute_error: 0.0062 - val_loss: 2.9130e-04 - val_mean_absolute_error: 0.0128
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3598e-05 - mean_absolute_error: 0.0065 - val_loss: 3.0534e-04 - val_mean_absolute_error: 0.0134
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.2150e-05 - mean_absolute_error: 0.0068 - val_loss: 3.7644e-04 - val_mean_absolute_error: 0.0153
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2409e-04 - mean_absolute_error: 0.0079 - val_loss: 3.4074e-04 - val_mean_absolute_error: 0.0145
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0342e-04 - mean_absolute_error: 0.0072 - val_loss: 2.8863e-04 - val_mean_absolute_error: 0.0128
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0428e-04 - mean_absolute_error: 0.0071 - val_loss: 2.9266e-04 - val_mean_absolute_error: 0.0129
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7110e-05 - mean_absolute_error: 0.0067 - val_loss: 3.4070e-04 - val_mean_absolute_error: 0.0143
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1700e-04 - mean_absolute_error: 0.0078 - val_loss: 3.1884e-04 - val_mean_absolute_error: 0.0138
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1859e-04 - mean_absolute_error: 0.0079 - val_loss: 2.9337e-04 - val_mean_absolute_error: 0.0130
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6303e-05 - mean_absolute_error: 0.0068 - val_loss: 2.7956e-04 - val_mean_absolute_error: 0.0125
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8586e-05 - mean_absolute_error: 0.0070 - val_loss: 3.0865e-04 - val_mean_absolute_error: 0.0135
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.4328e-05 - mean_absolute_error: 0.0063 - val_loss: 3.5194e-04 - val_mean_absolute_error: 0.0148
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0227e-04 - mean_absolute_error: 0.0074 - val_loss: 3.1620e-04 - val_mean_absolute_error: 0.0137
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0273e-04 - mean_absolute_error: 0.0070 - val_loss: 3.1744e-04 - val_mean_absolute_error: 0.0138
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1084e-04 - mean_absolute_error: 0.0073 - val_loss: 3.1431e-04 - val_mean_absolute_error: 0.0137
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7962e-05 - mean_absolute_error: 0.0071 - val_loss: 2.8105e-04 - val_mean_absolute_error: 0.0125
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5334e-05 - mean_absolute_error: 0.0067 - val_loss: 2.9058e-04 - val_mean_absolute_error: 0.0128
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.9884e-05 - mean_absolute_error: 0.0071 - val_loss: 2.8876e-04 - val_mean_absolute_error: 0.0127
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0421e-04 - mean_absolute_error: 0.0073 - val_loss: 2.8497e-04 - val_mean_absolute_error: 0.0126
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1712e-04 - mean_absolute_error: 0.0079 - val_loss: 3.1747e-04 - val_mean_absolute_error: 0.0138
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1474e-04 - mean_absolute_error: 0.0072 - val_loss: 3.5989e-04 - val_mean_absolute_error: 0.0149
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0001e-04 - mean_absolute_error: 0.0069 - val_loss: 3.6537e-04 - val_mean_absolute_error: 0.0151
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4233e-05 - mean_absolute_error: 0.0068 - val_loss: 2.9216e-04 - val_mean_absolute_error: 0.0129
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.2297e-05 - mean_absolute_error: 0.0069 - val_loss: 2.8581e-04 - val_mean_absolute_error: 0.0126
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1417e-04 - mean_absolute_error: 0.0075 - val_loss: 2.8423e-04 - val_mean_absolute_error: 0.0126
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0566e-04 - mean_absolute_error: 0.0072 - val_loss: 3.3442e-04 - val_mean_absolute_error: 0.0143
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1501e-04 - mean_absolute_error: 0.0075 - val_loss: 3.1000e-04 - val_mean_absolute_error: 0.0135
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0189e-04 - mean_absolute_error: 0.0067 - val_loss: 3.2923e-04 - val_mean_absolute_error: 0.0141
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0207e-04 - mean_absolute_error: 0.0070 - val_loss: 3.0004e-04 - val_mean_absolute_error: 0.0132
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0569e-04 - mean_absolute_error: 0.0071 - val_loss: 3.1871e-04 - val_mean_absolute_error: 0.0138
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0100e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9993e-04 - val_mean_absolute_error: 0.0131
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.5546e-05 - mean_absolute_error: 0.0065 - val_loss: 3.0853e-04 - val_mean_absolute_error: 0.0135
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.5377e-05 - mean_absolute_error: 0.0068 - val_loss: 2.8614e-04 - val_mean_absolute_error: 0.0127
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.9314e-05 - mean_absolute_error: 0.0067 - val_loss: 3.0469e-04 - val_mean_absolute_error: 0.0134
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1273e-04 - mean_absolute_error: 0.0073 - val_loss: 3.0250e-04 - val_mean_absolute_error: 0.0133
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.7260e-05 - mean_absolute_error: 0.0066 - val_loss: 2.8965e-04 - val_mean_absolute_error: 0.0128
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.0267e-05 - mean_absolute_error: 0.0066 - val_loss: 3.5510e-04 - val_mean_absolute_error: 0.0149
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0833e-04 - mean_absolute_error: 0.0073 - val_loss: 2.9975e-04 - val_mean_absolute_error: 0.0132
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0350e-04 - mean_absolute_error: 0.0070 - val_loss: 2.8624e-04 - val_mean_absolute_error: 0.0127
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.4328e-05 - mean_absolute_error: 0.0067 - val_loss: 4.1720e-04 - val_mean_absolute_error: 0.0163
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1240e-04 - mean_absolute_error: 0.0078 - val_loss: 3.8087e-04 - val_mean_absolute_error: 0.0154
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.9433e-05 - mean_absolute_error: 0.0070 - val_loss: 3.3184e-04 - val_mean_absolute_error: 0.0142
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1525e-04 - mean_absolute_error: 0.0070 - val_loss: 2.8972e-04 - val_mean_absolute_error: 0.0128
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7741e-05 - mean_absolute_error: 0.0067 - val_loss: 3.1768e-04 - val_mean_absolute_error: 0.0138
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8280e-05 - mean_absolute_error: 0.0069 - val_loss: 3.0895e-04 - val_mean_absolute_error: 0.0135
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.1560e-05 - mean_absolute_error: 0.0066 - val_loss: 2.9405e-04 - val_mean_absolute_error: 0.0130
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.9295e-05 - mean_absolute_error: 0.0067 - val_loss: 2.9302e-04 - val_mean_absolute_error: 0.0129
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4378e-05 - mean_absolute_error: 0.0067 - val_loss: 3.8099e-04 - val_mean_absolute_error: 0.0155
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.9344e-05 - mean_absolute_error: 0.0071 - val_loss: 3.3909e-04 - val_mean_absolute_error: 0.0144
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0458e-04 - mean_absolute_error: 0.0074 - val_loss: 3.1664e-04 - val_mean_absolute_error: 0.0137
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.7149e-05 - mean_absolute_error: 0.0069 - val_loss: 3.3543e-04 - val_mean_absolute_error: 0.0142
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.9406e-05 - mean_absolute_error: 0.0069 - val_loss: 2.9891e-04 - val_mean_absolute_error: 0.0132
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2484e-04 - mean_absolute_error: 0.0087 - val_loss: 3.4843e-04 - val_mean_absolute_error: 0.0146
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0928e-04 - mean_absolute_error: 0.0076 - val_loss: 3.1921e-04 - val_mean_absolute_error: 0.0137
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0652e-04 - mean_absolute_error: 0.0073 - val_loss: 4.3175e-04 - val_mean_absolute_error: 0.0168
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2790e-04 - mean_absolute_error: 0.0077 - val_loss: 3.0347e-04 - val_mean_absolute_error: 0.0134
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2114e-04 - mean_absolute_error: 0.0082 - val_loss: 3.1609e-04 - val_mean_absolute_error: 0.0138
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6686e-05 - mean_absolute_error: 0.0069 - val_loss: 3.0866e-04 - val_mean_absolute_error: 0.0134
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.6855e-05 - mean_absolute_error: 0.0069 - val_loss: 2.8925e-04 - val_mean_absolute_error: 0.0128
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.8506e-05 - mean_absolute_error: 0.0066 - val_loss: 3.0305e-04 - val_mean_absolute_error: 0.0132
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.3796e-05 - mean_absolute_error: 0.0067 - val_loss: 2.9165e-04 - val_mean_absolute_error: 0.0129
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.0505e-05 - mean_absolute_error: 0.0064 - val_loss: 2.9032e-04 - val_mean_absolute_error: 0.0128
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0650e-04 - mean_absolute_error: 0.0071 - val_loss: 3.0374e-04 - val_mean_absolute_error: 0.0133
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0252e-04 - mean_absolute_error: 0.0069 - val_loss: 3.0360e-04 - val_mean_absolute_error: 0.0133
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0296e-04 - mean_absolute_error: 0.0073 - val_loss: 3.5213e-04 - val_mean_absolute_error: 0.0147
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0094e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9853e-04 - val_mean_absolute_error: 0.0132
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5693e-05 - mean_absolute_error: 0.0066 - val_loss: 5.7333e-04 - val_mean_absolute_error: 0.0198
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2018e-04 - mean_absolute_error: 0.0081 - val_loss: 3.5018e-04 - val_mean_absolute_error: 0.0147
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0667e-04 - mean_absolute_error: 0.0072 - val_loss: 3.1788e-04 - val_mean_absolute_error: 0.0137
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0754e-04 - mean_absolute_error: 0.0072 - val_loss: 3.3814e-04 - val_mean_absolute_error: 0.0143
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0035e-04 - mean_absolute_error: 0.0070 - val_loss: 2.9971e-04 - val_mean_absolute_error: 0.0131
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8570e-05 - mean_absolute_error: 0.0068 - val_loss: 4.1823e-04 - val_mean_absolute_error: 0.0164
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2216e-04 - mean_absolute_error: 0.0076 - val_loss: 2.9623e-04 - val_mean_absolute_error: 0.0130
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.0614e-05 - mean_absolute_error: 0.0064 - val_loss: 2.9637e-04 - val_mean_absolute_error: 0.0130
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0272e-04 - mean_absolute_error: 0.0069 - val_loss: 3.8115e-04 - val_mean_absolute_error: 0.0155
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0351e-04 - mean_absolute_error: 0.0068 - val_loss: 2.9868e-04 - val_mean_absolute_error: 0.0131
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0199e-04 - mean_absolute_error: 0.0070 - val_loss: 5.3391e-04 - val_mean_absolute_error: 0.0190
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0881e-04 - mean_absolute_error: 0.0076 - val_loss: 3.8284e-04 - val_mean_absolute_error: 0.0154
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0236e-04 - mean_absolute_error: 0.0071 - val_loss: 2.9771e-04 - val_mean_absolute_error: 0.0130
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1422e-04 - mean_absolute_error: 0.0071 - val_loss: 3.1719e-04 - val_mean_absolute_error: 0.0137
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6769e-05 - mean_absolute_error: 0.0068 - val_loss: 3.3107e-04 - val_mean_absolute_error: 0.0141
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.0488e-05 - mean_absolute_error: 0.0067 - val_loss: 2.9532e-04 - val_mean_absolute_error: 0.0130
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4419e-05 - mean_absolute_error: 0.0068 - val_loss: 2.9201e-04 - val_mean_absolute_error: 0.0129
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.4484e-05 - mean_absolute_error: 0.0066 - val_loss: 4.0390e-04 - val_mean_absolute_error: 0.0161
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3092e-04 - mean_absolute_error: 0.0081 - val_loss: 3.0846e-04 - val_mean_absolute_error: 0.0134
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9466e-05 - mean_absolute_error: 0.0072 - val_loss: 3.0565e-04 - val_mean_absolute_error: 0.0133
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.1964e-05 - mean_absolute_error: 0.0067 - val_loss: 3.1375e-04 - val_mean_absolute_error: 0.0137
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0974e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9257e-04 - val_mean_absolute_error: 0.0129
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.8539e-05 - mean_absolute_error: 0.0066 - val_loss: 2.9187e-04 - val_mean_absolute_error: 0.0130
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0679e-04 - mean_absolute_error: 0.0074 - val_loss: 4.1224e-04 - val_mean_absolute_error: 0.0163
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2209e-04 - mean_absolute_error: 0.0081 - val_loss: 3.3998e-04 - val_mean_absolute_error: 0.0144
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1732e-04 - mean_absolute_error: 0.0074 - val_loss: 3.0556e-04 - val_mean_absolute_error: 0.0134
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.8697e-05 - mean_absolute_error: 0.0068 - val_loss: 3.1594e-04 - val_mean_absolute_error: 0.0136
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.2139e-05 - mean_absolute_error: 0.0070 - val_loss: 3.5946e-04 - val_mean_absolute_error: 0.0150
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.4764e-05 - mean_absolute_error: 0.0069 - val_loss: 3.3451e-04 - val_mean_absolute_error: 0.0142
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1447e-04 - mean_absolute_error: 0.0078 - val_loss: 3.8351e-04 - val_mean_absolute_error: 0.0155
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3706e-04 - mean_absolute_error: 0.0088 - val_loss: 3.2487e-04 - val_mean_absolute_error: 0.0139
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9366e-05 - mean_absolute_error: 0.0065 - val_loss: 3.8410e-04 - val_mean_absolute_error: 0.0156
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1273e-04 - mean_absolute_error: 0.0076 - val_loss: 2.9174e-04 - val_mean_absolute_error: 0.0129
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0062e-04 - mean_absolute_error: 0.0070 - val_loss: 3.8957e-04 - val_mean_absolute_error: 0.0157
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3418e-04 - mean_absolute_error: 0.0080 - val_loss: 3.9653e-04 - val_mean_absolute_error: 0.0158
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4097e-04 - mean_absolute_error: 0.0085 - val_loss: 3.1495e-04 - val_mean_absolute_error: 0.0136
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.9568e-05 - mean_absolute_error: 0.0066 - val_loss: 3.4516e-04 - val_mean_absolute_error: 0.0145
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0326e-04 - mean_absolute_error: 0.0071 - val_loss: 3.0121e-04 - val_mean_absolute_error: 0.0133
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9326e-05 - mean_absolute_error: 0.0070 - val_loss: 3.0306e-04 - val_mean_absolute_error: 0.0132
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1646e-04 - mean_absolute_error: 0.0078 - val_loss: 3.6070e-04 - val_mean_absolute_error: 0.0151

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 1644015.329572351
# RMSE: 1282.1916118787983
# MAE: 979.5341835781873
# MAPE: 3.010620249219632 %
#
# Model evalution on validate set
# MSE: 2058137.0980432383
# RMSE: 1434.6208900065683
# MAE: 978.7108139822135
# MAPE: 2.2906217543531953 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %%
y_pred_30_days
# Out:
# array([[63613.86 ],
#        [62348.035],
#        [62860.535],
#        [63174.258],
#        [62801.258],
#        [63003.695],
#        [62950.527],
#        [62919.523],
#        [62960.89 ],
#        [62936.047],
#        [62942.62 ],
#        [62945.613],
#        [62940.91 ],
#        [62943.836],
#        [62942.984],
#        [62942.71 ],
#        [62943.223],
#        [62942.88 ],
#        [62943.023],
#        [62943.01 ],
#        [62942.965],
#        [62943.   ],
#        [62942.984],
#        [62942.98 ],
#        [62943.   ],
#        [62942.984],
#        [62942.992],
#        [62942.992],
#        [62943.   ],
#        [62942.992],
#        [62942.984]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Predict the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
