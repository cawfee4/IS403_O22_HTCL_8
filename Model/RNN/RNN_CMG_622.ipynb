# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: CMG - Test/Train/Vaildation: 60/20/20
# - Dataset: 1252 rows x 7 column (01/03/2019 - 01/03/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1414.9827638346885
# - MAE: 1068.7955102641213
# - MAPE: 3.1972206080926164 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 1  # 6 2 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830

# %%
df.shape
# Out:
# (1252, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1247    40000
# 1248    40200
# 1249    40000
# 1250    39950
# 1251    41200
# Name: close, Length: 1252, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((740, 10), (740,), (239, 10), (239,), (240, 10), (240,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0100 - mean_absolute_error: 0.0763 - val_loss: 0.0021 - val_mean_absolute_error: 0.0372
# Epoch 2/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.8372e-04 - mean_absolute_error: 0.0210 - val_loss: 0.0019 - val_mean_absolute_error: 0.0329
# Epoch 3/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.4416e-04 - mean_absolute_error: 0.0153 - val_loss: 0.0013 - val_mean_absolute_error: 0.0265
# Epoch 4/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.0624e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0017 - val_mean_absolute_error: 0.0326
# Epoch 5/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6210e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0014 - val_mean_absolute_error: 0.0293
# Epoch 6/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.7514e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248
# Epoch 7/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.3885e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0015 - val_mean_absolute_error: 0.0307
# Epoch 8/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.1744e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0011 - val_mean_absolute_error: 0.0245
# Epoch 9/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2897e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0013 - val_mean_absolute_error: 0.0274
# Epoch 10/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.2301e-04 - mean_absolute_error: 0.0146 - val_loss: 0.0011 - val_mean_absolute_error: 0.0241
# Epoch 11/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2127e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0010 - val_mean_absolute_error: 0.0235
# Epoch 12/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7046e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0010 - val_mean_absolute_error: 0.0237
# Epoch 13/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5611e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0011 - val_mean_absolute_error: 0.0246
# Epoch 14/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0576e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0015 - val_mean_absolute_error: 0.0306
# Epoch 15/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4607e-04 - mean_absolute_error: 0.0131 - val_loss: 9.9865e-04 - val_mean_absolute_error: 0.0236
# Epoch 16/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.7772e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0015 - val_mean_absolute_error: 0.0313
# Epoch 17/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.7921e-04 - mean_absolute_error: 0.0119 - val_loss: 9.6850e-04 - val_mean_absolute_error: 0.0232
# Epoch 18/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6611e-04 - mean_absolute_error: 0.0112 - val_loss: 9.7754e-04 - val_mean_absolute_error: 0.0235
# Epoch 19/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8976e-04 - mean_absolute_error: 0.0115 - val_loss: 9.7869e-04 - val_mean_absolute_error: 0.0235
# Epoch 20/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9140e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0013 - val_mean_absolute_error: 0.0287
# Epoch 21/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2903e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0013 - val_mean_absolute_error: 0.0294
# Epoch 22/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6168e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0011 - val_mean_absolute_error: 0.0244
# Epoch 23/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8953e-04 - mean_absolute_error: 0.0122 - val_loss: 9.2694e-04 - val_mean_absolute_error: 0.0224
# Epoch 24/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6683e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0011 - val_mean_absolute_error: 0.0266
# Epoch 25/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0720e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0014 - val_mean_absolute_error: 0.0304
# Epoch 26/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0463e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0023 - val_mean_absolute_error: 0.0410
# Epoch 27/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 5.6405e-04 - mean_absolute_error: 0.0177 - val_loss: 9.7053e-04 - val_mean_absolute_error: 0.0240
# Epoch 28/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.7483e-04 - mean_absolute_error: 0.0113 - val_loss: 8.9936e-04 - val_mean_absolute_error: 0.0225
# Epoch 29/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2967e-04 - mean_absolute_error: 0.0104 - val_loss: 9.5570e-04 - val_mean_absolute_error: 0.0239
# Epoch 30/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.6340e-04 - mean_absolute_error: 0.0110 - val_loss: 9.0611e-04 - val_mean_absolute_error: 0.0229
# Epoch 31/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4353e-04 - mean_absolute_error: 0.0105 - val_loss: 9.4588e-04 - val_mean_absolute_error: 0.0229
# Epoch 32/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.8169e-04 - mean_absolute_error: 0.0118 - val_loss: 8.9157e-04 - val_mean_absolute_error: 0.0222
# Epoch 33/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6268e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0017 - val_mean_absolute_error: 0.0347
# Epoch 34/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.5809e-04 - mean_absolute_error: 0.0131 - val_loss: 0.0011 - val_mean_absolute_error: 0.0255
# Epoch 35/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.6960e-04 - mean_absolute_error: 0.0118 - val_loss: 8.7919e-04 - val_mean_absolute_error: 0.0225
# Epoch 36/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2544e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0011 - val_mean_absolute_error: 0.0250
# Epoch 37/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.8573e-04 - mean_absolute_error: 0.0128 - val_loss: 9.0575e-04 - val_mean_absolute_error: 0.0226
# Epoch 38/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0980e-04 - mean_absolute_error: 0.0103 - val_loss: 8.7565e-04 - val_mean_absolute_error: 0.0225
# Epoch 39/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.1575e-04 - mean_absolute_error: 0.0101 - val_loss: 8.6727e-04 - val_mean_absolute_error: 0.0221
# Epoch 40/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3154e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0014 - val_mean_absolute_error: 0.0315
# Epoch 41/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.4084e-04 - mean_absolute_error: 0.0135 - val_loss: 9.9550e-04 - val_mean_absolute_error: 0.0240
# Epoch 42/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.5151e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0010 - val_mean_absolute_error: 0.0254
# Epoch 43/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2984e-04 - mean_absolute_error: 0.0102 - val_loss: 8.6743e-04 - val_mean_absolute_error: 0.0222
# Epoch 44/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5630e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0022 - val_mean_absolute_error: 0.0403
# Epoch 45/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.9895e-04 - mean_absolute_error: 0.0126 - val_loss: 9.0979e-04 - val_mean_absolute_error: 0.0233
# Epoch 46/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1250e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0018 - val_mean_absolute_error: 0.0345
# Epoch 47/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.6832e-04 - mean_absolute_error: 0.0182 - val_loss: 0.0017 - val_mean_absolute_error: 0.0331
# Epoch 48/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0453e-04 - mean_absolute_error: 0.0136 - val_loss: 8.6207e-04 - val_mean_absolute_error: 0.0224
# Epoch 49/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0260e-04 - mean_absolute_error: 0.0099 - val_loss: 9.0362e-04 - val_mean_absolute_error: 0.0229
# Epoch 50/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2045e-04 - mean_absolute_error: 0.0104 - val_loss: 8.6683e-04 - val_mean_absolute_error: 0.0224
# Epoch 51/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4024e-04 - mean_absolute_error: 0.0110 - val_loss: 8.9388e-04 - val_mean_absolute_error: 0.0231
# Epoch 52/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9155e-04 - mean_absolute_error: 0.0098 - val_loss: 8.7096e-04 - val_mean_absolute_error: 0.0226
# Epoch 53/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8820e-04 - mean_absolute_error: 0.0094 - val_loss: 8.6664e-04 - val_mean_absolute_error: 0.0225
# Epoch 54/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0750e-04 - mean_absolute_error: 0.0098 - val_loss: 8.6760e-04 - val_mean_absolute_error: 0.0224
# Epoch 55/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7544e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0011 - val_mean_absolute_error: 0.0268
# Epoch 56/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4946e-04 - mean_absolute_error: 0.0113 - val_loss: 8.8359e-04 - val_mean_absolute_error: 0.0229
# Epoch 57/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0105e-04 - mean_absolute_error: 0.0105 - val_loss: 8.6763e-04 - val_mean_absolute_error: 0.0225
# Epoch 58/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1393e-04 - mean_absolute_error: 0.0102 - val_loss: 8.7461e-04 - val_mean_absolute_error: 0.0226
# Epoch 59/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0549e-04 - mean_absolute_error: 0.0102 - val_loss: 8.8729e-04 - val_mean_absolute_error: 0.0229
# Epoch 60/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9322e-04 - mean_absolute_error: 0.0096 - val_loss: 9.0966e-04 - val_mean_absolute_error: 0.0233
# Epoch 61/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8649e-04 - mean_absolute_error: 0.0094 - val_loss: 9.5800e-04 - val_mean_absolute_error: 0.0241
# Epoch 62/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.4336e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0011 - val_mean_absolute_error: 0.0259
# Epoch 63/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1248e-04 - mean_absolute_error: 0.0101 - val_loss: 9.2540e-04 - val_mean_absolute_error: 0.0234
# Epoch 64/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9016e-04 - mean_absolute_error: 0.0095 - val_loss: 9.8167e-04 - val_mean_absolute_error: 0.0243
# Epoch 65/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2395e-04 - mean_absolute_error: 0.0110 - val_loss: 9.0896e-04 - val_mean_absolute_error: 0.0232
# Epoch 66/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8889e-04 - mean_absolute_error: 0.0097 - val_loss: 8.8645e-04 - val_mean_absolute_error: 0.0229
# Epoch 67/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7834e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0010 - val_mean_absolute_error: 0.0245
# Epoch 68/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0081e-04 - mean_absolute_error: 0.0102 - val_loss: 9.4225e-04 - val_mean_absolute_error: 0.0237
# Epoch 69/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1243e-04 - mean_absolute_error: 0.0105 - val_loss: 8.9375e-04 - val_mean_absolute_error: 0.0230
# Epoch 70/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0825e-04 - mean_absolute_error: 0.0103 - val_loss: 9.2731e-04 - val_mean_absolute_error: 0.0235
# Epoch 71/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1774e-04 - mean_absolute_error: 0.0105 - val_loss: 9.4675e-04 - val_mean_absolute_error: 0.0239
# Epoch 72/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3161e-04 - mean_absolute_error: 0.0109 - val_loss: 8.9819e-04 - val_mean_absolute_error: 0.0230
# Epoch 73/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2992e-04 - mean_absolute_error: 0.0110 - val_loss: 9.6075e-04 - val_mean_absolute_error: 0.0240
# Epoch 74/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2132e-04 - mean_absolute_error: 0.0106 - val_loss: 9.2396e-04 - val_mean_absolute_error: 0.0235
# Epoch 75/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1951e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0013 - val_mean_absolute_error: 0.0286
# Epoch 76/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1201e-04 - mean_absolute_error: 0.0103 - val_loss: 9.7714e-04 - val_mean_absolute_error: 0.0242
# Epoch 77/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0981e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0010 - val_mean_absolute_error: 0.0247
# Epoch 78/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2157e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0011 - val_mean_absolute_error: 0.0256
# Epoch 79/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9279e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0010 - val_mean_absolute_error: 0.0247
# Epoch 80/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3200e-04 - mean_absolute_error: 0.0111 - val_loss: 9.0612e-04 - val_mean_absolute_error: 0.0232
# Epoch 81/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9206e-04 - mean_absolute_error: 0.0099 - val_loss: 9.0969e-04 - val_mean_absolute_error: 0.0232
# Epoch 82/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9581e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0011 - val_mean_absolute_error: 0.0262
# Epoch 83/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4855e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0010 - val_mean_absolute_error: 0.0248
# Epoch 84/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1817e-04 - mean_absolute_error: 0.0107 - val_loss: 9.0227e-04 - val_mean_absolute_error: 0.0232
# Epoch 85/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0004e-04 - mean_absolute_error: 0.0100 - val_loss: 9.7663e-04 - val_mean_absolute_error: 0.0244
# Epoch 86/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1203e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0012 - val_mean_absolute_error: 0.0275
# Epoch 87/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1153e-04 - mean_absolute_error: 0.0103 - val_loss: 9.9553e-04 - val_mean_absolute_error: 0.0247
# Epoch 88/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9889e-04 - mean_absolute_error: 0.0098 - val_loss: 9.0360e-04 - val_mean_absolute_error: 0.0231
# Epoch 89/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1828e-04 - mean_absolute_error: 0.0106 - val_loss: 9.0511e-04 - val_mean_absolute_error: 0.0232
# Epoch 90/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8375e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0010 - val_mean_absolute_error: 0.0249
# Epoch 91/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9341e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0010 - val_mean_absolute_error: 0.0248
# Epoch 92/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8779e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0012 - val_mean_absolute_error: 0.0271
# Epoch 93/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4126e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0014 - val_mean_absolute_error: 0.0297
# Epoch 94/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.9749e-04 - mean_absolute_error: 0.0135 - val_loss: 9.4675e-04 - val_mean_absolute_error: 0.0238
# Epoch 95/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2721e-04 - mean_absolute_error: 0.0104 - val_loss: 9.1561e-04 - val_mean_absolute_error: 0.0233
# Epoch 96/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7363e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0012 - val_mean_absolute_error: 0.0268
# Epoch 97/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0130e-04 - mean_absolute_error: 0.0103 - val_loss: 9.6446e-04 - val_mean_absolute_error: 0.0241
# Epoch 98/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1453e-04 - mean_absolute_error: 0.0107 - val_loss: 9.4094e-04 - val_mean_absolute_error: 0.0237
# Epoch 99/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9716e-04 - mean_absolute_error: 0.0101 - val_loss: 9.1852e-04 - val_mean_absolute_error: 0.0234
# Epoch 100/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2156e-04 - mean_absolute_error: 0.0104 - val_loss: 9.1502e-04 - val_mean_absolute_error: 0.0233
# Epoch 101/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9854e-04 - mean_absolute_error: 0.0099 - val_loss: 9.9879e-04 - val_mean_absolute_error: 0.0246
# Epoch 102/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9518e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0011 - val_mean_absolute_error: 0.0265
# Epoch 103/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.0398e-04 - mean_absolute_error: 0.0125 - val_loss: 0.0012 - val_mean_absolute_error: 0.0267
# Epoch 104/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6756e-04 - mean_absolute_error: 0.0119 - val_loss: 0.0010 - val_mean_absolute_error: 0.0247
# Epoch 105/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0649e-04 - mean_absolute_error: 0.0105 - val_loss: 9.1893e-04 - val_mean_absolute_error: 0.0234
# Epoch 106/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9262e-04 - mean_absolute_error: 0.0102 - val_loss: 9.6876e-04 - val_mean_absolute_error: 0.0242
# Epoch 107/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8217e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0011 - val_mean_absolute_error: 0.0267
# Epoch 108/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4044e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0011 - val_mean_absolute_error: 0.0262
# Epoch 109/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3279e-04 - mean_absolute_error: 0.0109 - val_loss: 9.2515e-04 - val_mean_absolute_error: 0.0234
# Epoch 110/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0129e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0012 - val_mean_absolute_error: 0.0272
# Epoch 111/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.8992e-04 - mean_absolute_error: 0.0121 - val_loss: 9.8943e-04 - val_mean_absolute_error: 0.0244
# Epoch 112/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0776e-04 - mean_absolute_error: 0.0105 - val_loss: 9.5362e-04 - val_mean_absolute_error: 0.0240
# Epoch 113/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9764e-04 - mean_absolute_error: 0.0101 - val_loss: 9.1998e-04 - val_mean_absolute_error: 0.0234
# Epoch 114/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9849e-04 - mean_absolute_error: 0.0101 - val_loss: 9.2290e-04 - val_mean_absolute_error: 0.0234
# Epoch 115/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0325e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0011 - val_mean_absolute_error: 0.0264
# Epoch 116/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1703e-04 - mean_absolute_error: 0.0109 - val_loss: 9.3219e-04 - val_mean_absolute_error: 0.0236
# Epoch 117/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9622e-04 - mean_absolute_error: 0.0099 - val_loss: 9.3541e-04 - val_mean_absolute_error: 0.0236
# Epoch 118/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3062e-04 - mean_absolute_error: 0.0105 - val_loss: 9.4387e-04 - val_mean_absolute_error: 0.0238
# Epoch 119/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0340e-04 - mean_absolute_error: 0.0102 - val_loss: 9.2853e-04 - val_mean_absolute_error: 0.0235
# Epoch 120/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1621e-04 - mean_absolute_error: 0.0106 - val_loss: 9.4315e-04 - val_mean_absolute_error: 0.0238
# Epoch 121/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9688e-04 - mean_absolute_error: 0.0099 - val_loss: 9.1772e-04 - val_mean_absolute_error: 0.0233
# Epoch 122/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1793e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0015 - val_mean_absolute_error: 0.0316
# Epoch 123/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0360e-04 - mean_absolute_error: 0.0130 - val_loss: 9.2070e-04 - val_mean_absolute_error: 0.0234
# Epoch 124/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8695e-04 - mean_absolute_error: 0.0097 - val_loss: 9.1879e-04 - val_mean_absolute_error: 0.0234
# Epoch 125/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0719e-04 - mean_absolute_error: 0.0100 - val_loss: 9.4077e-04 - val_mean_absolute_error: 0.0237
# Epoch 126/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9842e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0011 - val_mean_absolute_error: 0.0268
# Epoch 127/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2395e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0011 - val_mean_absolute_error: 0.0268
# Epoch 128/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5345e-04 - mean_absolute_error: 0.0115 - val_loss: 9.3423e-04 - val_mean_absolute_error: 0.0236
# Epoch 129/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0593e-04 - mean_absolute_error: 0.0106 - val_loss: 9.9011e-04 - val_mean_absolute_error: 0.0245
# Epoch 130/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9831e-04 - mean_absolute_error: 0.0101 - val_loss: 9.3835e-04 - val_mean_absolute_error: 0.0237
# Epoch 131/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9791e-04 - mean_absolute_error: 0.0100 - val_loss: 9.9635e-04 - val_mean_absolute_error: 0.0246
# Epoch 132/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2973e-04 - mean_absolute_error: 0.0111 - val_loss: 9.3927e-04 - val_mean_absolute_error: 0.0236
# Epoch 133/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1312e-04 - mean_absolute_error: 0.0101 - val_loss: 9.3914e-04 - val_mean_absolute_error: 0.0237
# Epoch 134/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8523e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0010 - val_mean_absolute_error: 0.0250
# Epoch 135/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0627e-04 - mean_absolute_error: 0.0103 - val_loss: 9.6245e-04 - val_mean_absolute_error: 0.0241
# Epoch 136/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0220e-04 - mean_absolute_error: 0.0103 - val_loss: 9.3206e-04 - val_mean_absolute_error: 0.0235
# Epoch 137/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0972e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0011 - val_mean_absolute_error: 0.0256
# Epoch 138/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1025e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0011 - val_mean_absolute_error: 0.0257
# Epoch 139/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1185e-04 - mean_absolute_error: 0.0106 - val_loss: 9.5095e-04 - val_mean_absolute_error: 0.0238
# Epoch 140/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8290e-04 - mean_absolute_error: 0.0096 - val_loss: 9.2749e-04 - val_mean_absolute_error: 0.0234
# Epoch 141/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8925e-04 - mean_absolute_error: 0.0098 - val_loss: 9.3383e-04 - val_mean_absolute_error: 0.0236
# Epoch 142/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1622e-04 - mean_absolute_error: 0.0106 - val_loss: 9.6257e-04 - val_mean_absolute_error: 0.0240
# Epoch 143/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1100e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0011 - val_mean_absolute_error: 0.0257
# Epoch 144/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 3.0099e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0011 - val_mean_absolute_error: 0.0262
# Epoch 145/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.0089e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0011 - val_mean_absolute_error: 0.0254
# Epoch 146/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0174e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0010 - val_mean_absolute_error: 0.0246
# Epoch 147/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2458e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0010 - val_mean_absolute_error: 0.0252
# Epoch 148/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0620e-04 - mean_absolute_error: 0.0100 - val_loss: 9.3787e-04 - val_mean_absolute_error: 0.0236
# Epoch 149/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5429e-04 - mean_absolute_error: 0.0121 - val_loss: 9.5172e-04 - val_mean_absolute_error: 0.0239
# Epoch 150/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3976e-04 - mean_absolute_error: 0.0113 - val_loss: 9.2841e-04 - val_mean_absolute_error: 0.0235
# Epoch 151/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9649e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0010 - val_mean_absolute_error: 0.0248
# Epoch 152/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1756e-04 - mean_absolute_error: 0.0109 - val_loss: 9.3251e-04 - val_mean_absolute_error: 0.0235
# Epoch 153/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0256e-04 - mean_absolute_error: 0.0101 - val_loss: 9.3182e-04 - val_mean_absolute_error: 0.0236
# Epoch 154/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2228e-04 - mean_absolute_error: 0.0106 - val_loss: 9.7212e-04 - val_mean_absolute_error: 0.0243
# Epoch 155/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0764e-04 - mean_absolute_error: 0.0102 - val_loss: 9.3011e-04 - val_mean_absolute_error: 0.0235
# Epoch 156/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9797e-04 - mean_absolute_error: 0.0099 - val_loss: 9.2837e-04 - val_mean_absolute_error: 0.0235
# Epoch 157/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9394e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0011 - val_mean_absolute_error: 0.0257
# Epoch 158/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2536e-04 - mean_absolute_error: 0.0106 - val_loss: 9.3355e-04 - val_mean_absolute_error: 0.0236
# Epoch 159/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0352e-04 - mean_absolute_error: 0.0100 - val_loss: 9.3159e-04 - val_mean_absolute_error: 0.0235
# Epoch 160/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.9623e-04 - mean_absolute_error: 0.0101 - val_loss: 9.3966e-04 - val_mean_absolute_error: 0.0236
# Epoch 161/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7973e-04 - mean_absolute_error: 0.0093 - val_loss: 9.5010e-04 - val_mean_absolute_error: 0.0238
# Epoch 162/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9793e-04 - mean_absolute_error: 0.0101 - val_loss: 9.3061e-04 - val_mean_absolute_error: 0.0235
# Epoch 163/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9962e-04 - mean_absolute_error: 0.0097 - val_loss: 9.4550e-04 - val_mean_absolute_error: 0.0237
# Epoch 164/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8395e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0012 - val_mean_absolute_error: 0.0269
# Epoch 165/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.5262e-04 - mean_absolute_error: 0.0116 - val_loss: 9.3151e-04 - val_mean_absolute_error: 0.0236
# Epoch 166/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.2157e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0011 - val_mean_absolute_error: 0.0259
# Epoch 167/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2474e-04 - mean_absolute_error: 0.0109 - val_loss: 9.3757e-04 - val_mean_absolute_error: 0.0236
# Epoch 168/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1901e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0012 - val_mean_absolute_error: 0.0280
# Epoch 169/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1742e-04 - mean_absolute_error: 0.0103 - val_loss: 9.2790e-04 - val_mean_absolute_error: 0.0235
# Epoch 170/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9918e-04 - mean_absolute_error: 0.0100 - val_loss: 9.3531e-04 - val_mean_absolute_error: 0.0236
# Epoch 171/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1653e-04 - mean_absolute_error: 0.0106 - val_loss: 9.4830e-04 - val_mean_absolute_error: 0.0239
# Epoch 172/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0015e-04 - mean_absolute_error: 0.0103 - val_loss: 9.3455e-04 - val_mean_absolute_error: 0.0236
# Epoch 173/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8459e-04 - mean_absolute_error: 0.0098 - val_loss: 9.7233e-04 - val_mean_absolute_error: 0.0242
# Epoch 174/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0126e-04 - mean_absolute_error: 0.0103 - val_loss: 9.9138e-04 - val_mean_absolute_error: 0.0245
# Epoch 175/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5929e-04 - mean_absolute_error: 0.0120 - val_loss: 9.4464e-04 - val_mean_absolute_error: 0.0237
# Epoch 176/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1250e-04 - mean_absolute_error: 0.0103 - val_loss: 9.4246e-04 - val_mean_absolute_error: 0.0237
# Epoch 177/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9679e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0011 - val_mean_absolute_error: 0.0256
# Epoch 178/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1450e-04 - mean_absolute_error: 0.0107 - val_loss: 9.3811e-04 - val_mean_absolute_error: 0.0236
# Epoch 179/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8459e-04 - mean_absolute_error: 0.0097 - val_loss: 9.5684e-04 - val_mean_absolute_error: 0.0239
# Epoch 180/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3427e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0012 - val_mean_absolute_error: 0.0276
# Epoch 181/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.6657e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0010 - val_mean_absolute_error: 0.0252
# Epoch 182/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2765e-04 - mean_absolute_error: 0.0110 - val_loss: 9.9933e-04 - val_mean_absolute_error: 0.0246
# Epoch 183/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3223e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0010 - val_mean_absolute_error: 0.0249
# Epoch 184/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0393e-04 - mean_absolute_error: 0.0102 - val_loss: 9.9231e-04 - val_mean_absolute_error: 0.0245
# Epoch 185/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9444e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0011 - val_mean_absolute_error: 0.0255
# Epoch 186/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.2266e-04 - mean_absolute_error: 0.0109 - val_loss: 9.6682e-04 - val_mean_absolute_error: 0.0241
# Epoch 187/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1524e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0011 - val_mean_absolute_error: 0.0259
# Epoch 188/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0587e-04 - mean_absolute_error: 0.0110 - val_loss: 0.0010 - val_mean_absolute_error: 0.0251
# Epoch 189/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1757e-04 - mean_absolute_error: 0.0104 - val_loss: 9.5098e-04 - val_mean_absolute_error: 0.0238
# Epoch 190/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9755e-04 - mean_absolute_error: 0.0099 - val_loss: 9.4123e-04 - val_mean_absolute_error: 0.0237
# Epoch 191/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0980e-04 - mean_absolute_error: 0.0103 - val_loss: 0.0011 - val_mean_absolute_error: 0.0259
# Epoch 192/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 3.3633e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0011 - val_mean_absolute_error: 0.0259
# Epoch 193/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1897e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0015 - val_mean_absolute_error: 0.0313
# Epoch 194/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.5189e-04 - mean_absolute_error: 0.0114 - val_loss: 9.6055e-04 - val_mean_absolute_error: 0.0239
# Epoch 195/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9894e-04 - mean_absolute_error: 0.0100 - val_loss: 9.7309e-04 - val_mean_absolute_error: 0.0241
# Epoch 196/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.3644e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0010 - val_mean_absolute_error: 0.0246
# Epoch 197/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0379e-04 - mean_absolute_error: 0.0106 - val_loss: 9.5151e-04 - val_mean_absolute_error: 0.0238
# Epoch 198/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8740e-04 - mean_absolute_error: 0.0096 - val_loss: 9.4578e-04 - val_mean_absolute_error: 0.0238
# Epoch 199/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1456e-04 - mean_absolute_error: 0.0103 - val_loss: 9.5715e-04 - val_mean_absolute_error: 0.0240
# Epoch 200/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1442e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0011 - val_mean_absolute_error: 0.0256

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 239
# 250

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 2002176.2219492542
# RMSE: 1414.9827638346885
# MAE: 1068.7955102641213
# MAPE: 3.1972206080926164 %
#
# Model evalution on validate set
# MSE: 848206.7755655289
# RMSE: 920.981419772152
# MAE: 706.1429850260416
# MAPE: 1.8927034206605626 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step

# %%
y_pred_30_days
# Out:
# array([[41704.95 ],
#        [41153.742],
#        [41362.977],
#        [41549.367],
#        [41325.043],
#        [41455.484],
#        [41427.973],
#        [41396.316],
#        [41436.055],
#        [41412.625],
#        [41417.29 ],
#        [41422.875],
#        [41415.79 ],
#        [41419.938],
#        [41419.12 ],
#        [41418.12 ],
#        [41419.383],
#        [41418.65 ],
#        [41418.785],
#        [41418.973],
#        [41418.74 ],
#        [41418.883],
#        [41418.848],
#        [41418.81 ],
#        [41418.867],
#        [41418.83 ],
#        [41418.84 ],
#        [41418.848],
#        [41418.832],
#        [41418.84 ],
#        [41418.84 ]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Predict the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
