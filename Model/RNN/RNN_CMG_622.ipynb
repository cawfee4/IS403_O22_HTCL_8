# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: CMG - Test/Train/Vaildation: 60/20/20
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1323.7846141341936
# - MAE: 1019.1790183017928
# - MAPE: 3.1342184133521647 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 1  # 6 2 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((776, 10), (776,), (251, 10), (251,), (253, 10), (253,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_1 (SimpleRNN)        │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0059 - mean_absolute_error: 0.0554 - val_loss: 0.0019 - val_mean_absolute_error: 0.0365
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.5634e-04 - mean_absolute_error: 0.0140 - val_loss: 5.4882e-04 - val_mean_absolute_error: 0.0166
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.2466e-04 - mean_absolute_error: 0.0109 - val_loss: 4.6424e-04 - val_mean_absolute_error: 0.0154
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.1606e-04 - mean_absolute_error: 0.0108 - val_loss: 7.6423e-04 - val_mean_absolute_error: 0.0223
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.1349e-04 - mean_absolute_error: 0.0107 - val_loss: 5.8582e-04 - val_mean_absolute_error: 0.0200
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0575e-04 - mean_absolute_error: 0.0099 - val_loss: 5.2975e-04 - val_mean_absolute_error: 0.0178
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5645e-04 - mean_absolute_error: 0.0089 - val_loss: 4.9318e-04 - val_mean_absolute_error: 0.0171
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6000e-04 - mean_absolute_error: 0.0093 - val_loss: 3.5585e-04 - val_mean_absolute_error: 0.0141
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5936e-04 - mean_absolute_error: 0.0088 - val_loss: 3.3976e-04 - val_mean_absolute_error: 0.0131
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8139e-04 - mean_absolute_error: 0.0096 - val_loss: 3.7614e-04 - val_mean_absolute_error: 0.0140
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.8744e-04 - mean_absolute_error: 0.0101 - val_loss: 4.0783e-04 - val_mean_absolute_error: 0.0161
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2815e-04 - mean_absolute_error: 0.0081 - val_loss: 4.1582e-04 - val_mean_absolute_error: 0.0154
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2288e-04 - mean_absolute_error: 0.0076 - val_loss: 3.2692e-04 - val_mean_absolute_error: 0.0135
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4502e-04 - mean_absolute_error: 0.0085 - val_loss: 3.8104e-04 - val_mean_absolute_error: 0.0146
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2901e-04 - mean_absolute_error: 0.0080 - val_loss: 3.5172e-04 - val_mean_absolute_error: 0.0138
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3453e-04 - mean_absolute_error: 0.0080 - val_loss: 3.2370e-04 - val_mean_absolute_error: 0.0130
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1272e-04 - mean_absolute_error: 0.0073 - val_loss: 6.1815e-04 - val_mean_absolute_error: 0.0204
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7344e-04 - mean_absolute_error: 0.0094 - val_loss: 3.3655e-04 - val_mean_absolute_error: 0.0141
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4449e-04 - mean_absolute_error: 0.0087 - val_loss: 3.7355e-04 - val_mean_absolute_error: 0.0145
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1909e-04 - mean_absolute_error: 0.0076 - val_loss: 7.1562e-04 - val_mean_absolute_error: 0.0223
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2293e-04 - mean_absolute_error: 0.0080 - val_loss: 3.0807e-04 - val_mean_absolute_error: 0.0126
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0373e-04 - mean_absolute_error: 0.0071 - val_loss: 3.2471e-04 - val_mean_absolute_error: 0.0139
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3874e-04 - mean_absolute_error: 0.0084 - val_loss: 3.4907e-04 - val_mean_absolute_error: 0.0147
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.5419e-04 - mean_absolute_error: 0.0085 - val_loss: 2.9304e-04 - val_mean_absolute_error: 0.0124
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5205e-04 - mean_absolute_error: 0.0089 - val_loss: 3.2309e-04 - val_mean_absolute_error: 0.0131
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1203e-04 - mean_absolute_error: 0.0073 - val_loss: 2.8938e-04 - val_mean_absolute_error: 0.0123
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2793e-04 - mean_absolute_error: 0.0080 - val_loss: 5.5735e-04 - val_mean_absolute_error: 0.0192
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4034e-04 - mean_absolute_error: 0.0085 - val_loss: 4.1906e-04 - val_mean_absolute_error: 0.0160
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1892e-04 - mean_absolute_error: 0.0076 - val_loss: 2.8648e-04 - val_mean_absolute_error: 0.0122
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1334e-04 - mean_absolute_error: 0.0074 - val_loss: 3.3038e-04 - val_mean_absolute_error: 0.0136
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3439e-04 - mean_absolute_error: 0.0084 - val_loss: 3.0071e-04 - val_mean_absolute_error: 0.0132
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0720e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9534e-04 - val_mean_absolute_error: 0.0129
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0224e-04 - mean_absolute_error: 0.0069 - val_loss: 3.1030e-04 - val_mean_absolute_error: 0.0135
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2164e-04 - mean_absolute_error: 0.0077 - val_loss: 3.1832e-04 - val_mean_absolute_error: 0.0139
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1555e-04 - mean_absolute_error: 0.0073 - val_loss: 2.8778e-04 - val_mean_absolute_error: 0.0126
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2077e-04 - mean_absolute_error: 0.0080 - val_loss: 4.4682e-04 - val_mean_absolute_error: 0.0168
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0797e-04 - mean_absolute_error: 0.0071 - val_loss: 2.8951e-04 - val_mean_absolute_error: 0.0123
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0122e-04 - mean_absolute_error: 0.0070 - val_loss: 3.8124e-04 - val_mean_absolute_error: 0.0151
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1547e-04 - mean_absolute_error: 0.0074 - val_loss: 2.8379e-04 - val_mean_absolute_error: 0.0122
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.1999e-05 - mean_absolute_error: 0.0065 - val_loss: 5.0056e-04 - val_mean_absolute_error: 0.0181
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0262e-04 - mean_absolute_error: 0.0072 - val_loss: 3.0687e-04 - val_mean_absolute_error: 0.0135
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0879e-04 - mean_absolute_error: 0.0071 - val_loss: 3.6784e-04 - val_mean_absolute_error: 0.0154
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2218e-04 - mean_absolute_error: 0.0076 - val_loss: 3.3127e-04 - val_mean_absolute_error: 0.0143
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4750e-04 - mean_absolute_error: 0.0086 - val_loss: 4.3541e-04 - val_mean_absolute_error: 0.0164
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1733e-04 - mean_absolute_error: 0.0073 - val_loss: 2.9322e-04 - val_mean_absolute_error: 0.0127
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0685e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9909e-04 - val_mean_absolute_error: 0.0132
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0921e-04 - mean_absolute_error: 0.0071 - val_loss: 3.1069e-04 - val_mean_absolute_error: 0.0133
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0518e-04 - mean_absolute_error: 0.0070 - val_loss: 3.1845e-04 - val_mean_absolute_error: 0.0139
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.8090e-05 - mean_absolute_error: 0.0067 - val_loss: 2.7998e-04 - val_mean_absolute_error: 0.0124
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0667e-04 - mean_absolute_error: 0.0073 - val_loss: 4.1441e-04 - val_mean_absolute_error: 0.0162
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3745e-04 - mean_absolute_error: 0.0087 - val_loss: 3.5213e-04 - val_mean_absolute_error: 0.0149
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0327e-04 - mean_absolute_error: 0.0071 - val_loss: 3.1936e-04 - val_mean_absolute_error: 0.0139
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1346e-04 - mean_absolute_error: 0.0073 - val_loss: 2.8407e-04 - val_mean_absolute_error: 0.0126
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0269e-04 - mean_absolute_error: 0.0072 - val_loss: 3.1211e-04 - val_mean_absolute_error: 0.0134
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.8952e-05 - mean_absolute_error: 0.0071 - val_loss: 2.8388e-04 - val_mean_absolute_error: 0.0125
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1522e-04 - mean_absolute_error: 0.0076 - val_loss: 3.0512e-04 - val_mean_absolute_error: 0.0134
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0362e-04 - mean_absolute_error: 0.0071 - val_loss: 5.2263e-04 - val_mean_absolute_error: 0.0186
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1188e-04 - mean_absolute_error: 0.0077 - val_loss: 2.8895e-04 - val_mean_absolute_error: 0.0128
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.5372e-05 - mean_absolute_error: 0.0066 - val_loss: 2.9456e-04 - val_mean_absolute_error: 0.0130
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0900e-04 - mean_absolute_error: 0.0074 - val_loss: 3.0752e-04 - val_mean_absolute_error: 0.0135
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0781e-04 - mean_absolute_error: 0.0070 - val_loss: 2.7971e-04 - val_mean_absolute_error: 0.0124
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0933e-04 - mean_absolute_error: 0.0073 - val_loss: 3.0552e-04 - val_mean_absolute_error: 0.0134
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.4016e-05 - mean_absolute_error: 0.0067 - val_loss: 4.4181e-04 - val_mean_absolute_error: 0.0169
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1046e-04 - mean_absolute_error: 0.0076 - val_loss: 4.2233e-04 - val_mean_absolute_error: 0.0168
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1116e-04 - mean_absolute_error: 0.0077 - val_loss: 2.7568e-04 - val_mean_absolute_error: 0.0124
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0586e-04 - mean_absolute_error: 0.0072 - val_loss: 3.6647e-04 - val_mean_absolute_error: 0.0150
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.8871e-05 - mean_absolute_error: 0.0064 - val_loss: 2.8069e-04 - val_mean_absolute_error: 0.0125
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0773e-04 - mean_absolute_error: 0.0068 - val_loss: 2.8307e-04 - val_mean_absolute_error: 0.0126
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1149e-04 - mean_absolute_error: 0.0070 - val_loss: 2.8413e-04 - val_mean_absolute_error: 0.0126
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.7158e-05 - mean_absolute_error: 0.0064 - val_loss: 3.8842e-04 - val_mean_absolute_error: 0.0159
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0885e-04 - mean_absolute_error: 0.0073 - val_loss: 2.8586e-04 - val_mean_absolute_error: 0.0127
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.8309e-05 - mean_absolute_error: 0.0065 - val_loss: 3.0820e-04 - val_mean_absolute_error: 0.0135
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.5346e-05 - mean_absolute_error: 0.0067 - val_loss: 2.8136e-04 - val_mean_absolute_error: 0.0125
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0115e-04 - mean_absolute_error: 0.0073 - val_loss: 4.7081e-04 - val_mean_absolute_error: 0.0176
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1884e-04 - mean_absolute_error: 0.0080 - val_loss: 3.6525e-04 - val_mean_absolute_error: 0.0152
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1059e-04 - mean_absolute_error: 0.0073 - val_loss: 2.9143e-04 - val_mean_absolute_error: 0.0129
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.9385e-05 - mean_absolute_error: 0.0070 - val_loss: 3.9453e-04 - val_mean_absolute_error: 0.0160
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0047e-04 - mean_absolute_error: 0.0070 - val_loss: 2.9282e-04 - val_mean_absolute_error: 0.0129
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.2135e-05 - mean_absolute_error: 0.0067 - val_loss: 2.8627e-04 - val_mean_absolute_error: 0.0127
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.3098e-05 - mean_absolute_error: 0.0066 - val_loss: 3.0092e-04 - val_mean_absolute_error: 0.0132
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0285e-04 - mean_absolute_error: 0.0071 - val_loss: 2.8396e-04 - val_mean_absolute_error: 0.0126
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0775e-04 - mean_absolute_error: 0.0073 - val_loss: 3.0426e-04 - val_mean_absolute_error: 0.0133
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0997e-04 - mean_absolute_error: 0.0075 - val_loss: 2.8375e-04 - val_mean_absolute_error: 0.0126
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.3840e-05 - mean_absolute_error: 0.0064 - val_loss: 2.8812e-04 - val_mean_absolute_error: 0.0128
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.6127e-05 - mean_absolute_error: 0.0070 - val_loss: 3.6194e-04 - val_mean_absolute_error: 0.0150
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.6609e-05 - mean_absolute_error: 0.0068 - val_loss: 2.8483e-04 - val_mean_absolute_error: 0.0126
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.0184e-05 - mean_absolute_error: 0.0061 - val_loss: 3.7901e-04 - val_mean_absolute_error: 0.0154
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.2216e-05 - mean_absolute_error: 0.0066 - val_loss: 4.8579e-04 - val_mean_absolute_error: 0.0180
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3629e-04 - mean_absolute_error: 0.0087 - val_loss: 3.1742e-04 - val_mean_absolute_error: 0.0137
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0786e-04 - mean_absolute_error: 0.0071 - val_loss: 3.0767e-04 - val_mean_absolute_error: 0.0135
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.3920e-05 - mean_absolute_error: 0.0062 - val_loss: 2.9170e-04 - val_mean_absolute_error: 0.0129
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.3166e-05 - mean_absolute_error: 0.0066 - val_loss: 2.8837e-04 - val_mean_absolute_error: 0.0128
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.4226e-05 - mean_absolute_error: 0.0065 - val_loss: 2.9043e-04 - val_mean_absolute_error: 0.0128
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.9501e-05 - mean_absolute_error: 0.0066 - val_loss: 2.8633e-04 - val_mean_absolute_error: 0.0127
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0629e-05 - mean_absolute_error: 0.0064 - val_loss: 3.3973e-04 - val_mean_absolute_error: 0.0144
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0166e-04 - mean_absolute_error: 0.0070 - val_loss: 3.0541e-04 - val_mean_absolute_error: 0.0134
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0946e-04 - mean_absolute_error: 0.0070 - val_loss: 2.9343e-04 - val_mean_absolute_error: 0.0130
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.9019e-05 - mean_absolute_error: 0.0071 - val_loss: 3.0625e-04 - val_mean_absolute_error: 0.0133
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.5705e-05 - mean_absolute_error: 0.0068 - val_loss: 3.6050e-04 - val_mean_absolute_error: 0.0150
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0941e-04 - mean_absolute_error: 0.0076 - val_loss: 2.8883e-04 - val_mean_absolute_error: 0.0128
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.2368e-05 - mean_absolute_error: 0.0068 - val_loss: 3.3436e-04 - val_mean_absolute_error: 0.0142
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.9703e-05 - mean_absolute_error: 0.0073 - val_loss: 3.0022e-04 - val_mean_absolute_error: 0.0132
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.8646e-05 - mean_absolute_error: 0.0070 - val_loss: 3.0223e-04 - val_mean_absolute_error: 0.0132
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.4587e-05 - mean_absolute_error: 0.0068 - val_loss: 2.8908e-04 - val_mean_absolute_error: 0.0128
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.6518e-05 - mean_absolute_error: 0.0063 - val_loss: 4.0821e-04 - val_mean_absolute_error: 0.0162
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.0721e-04 - mean_absolute_error: 0.0072 - val_loss: 3.0751e-04 - val_mean_absolute_error: 0.0134
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4172e-04 - mean_absolute_error: 0.0085 - val_loss: 2.8973e-04 - val_mean_absolute_error: 0.0128
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0174e-04 - mean_absolute_error: 0.0068 - val_loss: 3.0501e-04 - val_mean_absolute_error: 0.0134
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.1829e-05 - mean_absolute_error: 0.0067 - val_loss: 3.5399e-04 - val_mean_absolute_error: 0.0148
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1200e-04 - mean_absolute_error: 0.0076 - val_loss: 3.1106e-04 - val_mean_absolute_error: 0.0135
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.0974e-04 - mean_absolute_error: 0.0074 - val_loss: 4.0287e-04 - val_mean_absolute_error: 0.0161
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1477e-04 - mean_absolute_error: 0.0072 - val_loss: 6.5757e-04 - val_mean_absolute_error: 0.0213
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.2641e-04 - mean_absolute_error: 0.0082 - val_loss: 2.8968e-04 - val_mean_absolute_error: 0.0128
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0448e-04 - mean_absolute_error: 0.0068 - val_loss: 3.0568e-04 - val_mean_absolute_error: 0.0134
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.2710e-05 - mean_absolute_error: 0.0064 - val_loss: 2.9170e-04 - val_mean_absolute_error: 0.0128
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0496e-04 - mean_absolute_error: 0.0069 - val_loss: 2.9019e-04 - val_mean_absolute_error: 0.0128
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.9352e-05 - mean_absolute_error: 0.0068 - val_loss: 2.9129e-04 - val_mean_absolute_error: 0.0129
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.2978e-05 - mean_absolute_error: 0.0065 - val_loss: 3.0446e-04 - val_mean_absolute_error: 0.0132
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.1134e-04 - mean_absolute_error: 0.0076 - val_loss: 2.9509e-04 - val_mean_absolute_error: 0.0130
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.8421e-05 - mean_absolute_error: 0.0068 - val_loss: 2.9350e-04 - val_mean_absolute_error: 0.0129
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.1209e-04 - mean_absolute_error: 0.0073 - val_loss: 4.2209e-04 - val_mean_absolute_error: 0.0165
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.8389e-05 - mean_absolute_error: 0.0068 - val_loss: 2.8970e-04 - val_mean_absolute_error: 0.0128
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0585e-04 - mean_absolute_error: 0.0070 - val_loss: 3.0154e-04 - val_mean_absolute_error: 0.0132
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.9959e-05 - mean_absolute_error: 0.0065 - val_loss: 2.9995e-04 - val_mean_absolute_error: 0.0131
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1993e-04 - mean_absolute_error: 0.0075 - val_loss: 2.9468e-04 - val_mean_absolute_error: 0.0129
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.0514e-04 - mean_absolute_error: 0.0070 - val_loss: 2.9082e-04 - val_mean_absolute_error: 0.0128
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.0701e-05 - mean_absolute_error: 0.0066 - val_loss: 4.3481e-04 - val_mean_absolute_error: 0.0169
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3218e-04 - mean_absolute_error: 0.0085 - val_loss: 4.8309e-04 - val_mean_absolute_error: 0.0180
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3014e-04 - mean_absolute_error: 0.0086 - val_loss: 3.0284e-04 - val_mean_absolute_error: 0.0133
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.1431e-05 - mean_absolute_error: 0.0063 - val_loss: 3.5969e-04 - val_mean_absolute_error: 0.0149
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0359e-04 - mean_absolute_error: 0.0073 - val_loss: 2.9757e-04 - val_mean_absolute_error: 0.0131
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1058e-04 - mean_absolute_error: 0.0072 - val_loss: 3.8589e-04 - val_mean_absolute_error: 0.0156
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0190e-04 - mean_absolute_error: 0.0073 - val_loss: 2.9948e-04 - val_mean_absolute_error: 0.0131
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1252e-04 - mean_absolute_error: 0.0071 - val_loss: 2.9436e-04 - val_mean_absolute_error: 0.0129
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.8923e-05 - mean_absolute_error: 0.0065 - val_loss: 3.0986e-04 - val_mean_absolute_error: 0.0134
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2949e-04 - mean_absolute_error: 0.0075 - val_loss: 2.9330e-04 - val_mean_absolute_error: 0.0129
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.1718e-05 - mean_absolute_error: 0.0066 - val_loss: 2.9936e-04 - val_mean_absolute_error: 0.0131
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.1861e-04 - mean_absolute_error: 0.0074 - val_loss: 2.9338e-04 - val_mean_absolute_error: 0.0129
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0643e-04 - mean_absolute_error: 0.0071 - val_loss: 3.4789e-04 - val_mean_absolute_error: 0.0146
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.8305e-05 - mean_absolute_error: 0.0071 - val_loss: 2.9527e-04 - val_mean_absolute_error: 0.0129
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.3941e-05 - mean_absolute_error: 0.0066 - val_loss: 2.9536e-04 - val_mean_absolute_error: 0.0130
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.7973e-05 - mean_absolute_error: 0.0067 - val_loss: 2.9574e-04 - val_mean_absolute_error: 0.0129
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.2616e-05 - mean_absolute_error: 0.0065 - val_loss: 2.9828e-04 - val_mean_absolute_error: 0.0131
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0997e-04 - mean_absolute_error: 0.0074 - val_loss: 3.0655e-04 - val_mean_absolute_error: 0.0133
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.4460e-05 - mean_absolute_error: 0.0063 - val_loss: 2.9989e-04 - val_mean_absolute_error: 0.0131
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0657e-04 - mean_absolute_error: 0.0070 - val_loss: 2.9654e-04 - val_mean_absolute_error: 0.0130
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.2456e-05 - mean_absolute_error: 0.0061 - val_loss: 2.9322e-04 - val_mean_absolute_error: 0.0129
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.0091e-05 - mean_absolute_error: 0.0066 - val_loss: 2.9403e-04 - val_mean_absolute_error: 0.0129
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.1931e-05 - mean_absolute_error: 0.0065 - val_loss: 3.2066e-04 - val_mean_absolute_error: 0.0138
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0170e-04 - mean_absolute_error: 0.0069 - val_loss: 2.9159e-04 - val_mean_absolute_error: 0.0129
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.9065e-05 - mean_absolute_error: 0.0071 - val_loss: 2.9404e-04 - val_mean_absolute_error: 0.0129
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.6274e-05 - mean_absolute_error: 0.0068 - val_loss: 3.1955e-04 - val_mean_absolute_error: 0.0137
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.1852e-05 - mean_absolute_error: 0.0063 - val_loss: 3.0668e-04 - val_mean_absolute_error: 0.0133
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0157e-04 - mean_absolute_error: 0.0067 - val_loss: 2.9304e-04 - val_mean_absolute_error: 0.0129
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.9252e-05 - mean_absolute_error: 0.0068 - val_loss: 3.4088e-04 - val_mean_absolute_error: 0.0144
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.6580e-05 - mean_absolute_error: 0.0068 - val_loss: 3.2189e-04 - val_mean_absolute_error: 0.0138
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1254e-04 - mean_absolute_error: 0.0071 - val_loss: 3.7990e-04 - val_mean_absolute_error: 0.0155
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2340e-04 - mean_absolute_error: 0.0079 - val_loss: 2.9530e-04 - val_mean_absolute_error: 0.0130
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 9.4913e-05 - mean_absolute_error: 0.0069 - val_loss: 3.0667e-04 - val_mean_absolute_error: 0.0134
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.6453e-05 - mean_absolute_error: 0.0070 - val_loss: 3.0873e-04 - val_mean_absolute_error: 0.0134
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.9531e-05 - mean_absolute_error: 0.0069 - val_loss: 3.2412e-04 - val_mean_absolute_error: 0.0138
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1638e-04 - mean_absolute_error: 0.0075 - val_loss: 2.9908e-04 - val_mean_absolute_error: 0.0131
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.0219e-05 - mean_absolute_error: 0.0063 - val_loss: 4.0291e-04 - val_mean_absolute_error: 0.0161
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.7600e-05 - mean_absolute_error: 0.0069 - val_loss: 3.1644e-04 - val_mean_absolute_error: 0.0136
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0539e-04 - mean_absolute_error: 0.0071 - val_loss: 3.0098e-04 - val_mean_absolute_error: 0.0131
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.8333e-05 - mean_absolute_error: 0.0068 - val_loss: 3.7221e-04 - val_mean_absolute_error: 0.0152
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.2256e-04 - mean_absolute_error: 0.0073 - val_loss: 4.3182e-04 - val_mean_absolute_error: 0.0167
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.4963e-05 - mean_absolute_error: 0.0070 - val_loss: 3.2916e-04 - val_mean_absolute_error: 0.0141
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.7332e-05 - mean_absolute_error: 0.0072 - val_loss: 3.1028e-04 - val_mean_absolute_error: 0.0134
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1060e-04 - mean_absolute_error: 0.0075 - val_loss: 2.9991e-04 - val_mean_absolute_error: 0.0131
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.0888e-04 - mean_absolute_error: 0.0074 - val_loss: 5.0377e-04 - val_mean_absolute_error: 0.0184
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4190e-04 - mean_absolute_error: 0.0090 - val_loss: 3.3387e-04 - val_mean_absolute_error: 0.0142
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0741e-04 - mean_absolute_error: 0.0072 - val_loss: 3.1001e-04 - val_mean_absolute_error: 0.0135
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0857e-04 - mean_absolute_error: 0.0073 - val_loss: 3.1978e-04 - val_mean_absolute_error: 0.0137
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0780e-04 - mean_absolute_error: 0.0073 - val_loss: 3.2037e-04 - val_mean_absolute_error: 0.0138
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0022e-04 - mean_absolute_error: 0.0067 - val_loss: 3.0381e-04 - val_mean_absolute_error: 0.0133
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0094e-04 - mean_absolute_error: 0.0070 - val_loss: 3.0368e-04 - val_mean_absolute_error: 0.0133
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.2525e-05 - mean_absolute_error: 0.0067 - val_loss: 3.0149e-04 - val_mean_absolute_error: 0.0132
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1761e-04 - mean_absolute_error: 0.0071 - val_loss: 3.1907e-04 - val_mean_absolute_error: 0.0137
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.0539e-04 - mean_absolute_error: 0.0071 - val_loss: 3.4923e-04 - val_mean_absolute_error: 0.0146
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.7608e-05 - mean_absolute_error: 0.0069 - val_loss: 3.4151e-04 - val_mean_absolute_error: 0.0144
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 8.8386e-05 - mean_absolute_error: 0.0064 - val_loss: 3.1141e-04 - val_mean_absolute_error: 0.0135
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0406e-04 - mean_absolute_error: 0.0070 - val_loss: 2.9937e-04 - val_mean_absolute_error: 0.0131
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0631e-04 - mean_absolute_error: 0.0067 - val_loss: 3.0448e-04 - val_mean_absolute_error: 0.0133
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0733e-04 - mean_absolute_error: 0.0073 - val_loss: 2.9521e-04 - val_mean_absolute_error: 0.0130
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0928e-04 - mean_absolute_error: 0.0068 - val_loss: 2.9811e-04 - val_mean_absolute_error: 0.0130
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.7868e-05 - mean_absolute_error: 0.0067 - val_loss: 3.0755e-04 - val_mean_absolute_error: 0.0134
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0247e-04 - mean_absolute_error: 0.0072 - val_loss: 4.0922e-04 - val_mean_absolute_error: 0.0163
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.7287e-05 - mean_absolute_error: 0.0074 - val_loss: 2.9705e-04 - val_mean_absolute_error: 0.0130
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.9827e-05 - mean_absolute_error: 0.0068 - val_loss: 3.5537e-04 - val_mean_absolute_error: 0.0148
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1276e-04 - mean_absolute_error: 0.0073 - val_loss: 2.9348e-04 - val_mean_absolute_error: 0.0129
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0078e-04 - mean_absolute_error: 0.0067 - val_loss: 2.9589e-04 - val_mean_absolute_error: 0.0130
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.6683e-05 - mean_absolute_error: 0.0069 - val_loss: 2.9817e-04 - val_mean_absolute_error: 0.0130
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.2191e-05 - mean_absolute_error: 0.0068 - val_loss: 2.9467e-04 - val_mean_absolute_error: 0.0130
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.6978e-05 - mean_absolute_error: 0.0068 - val_loss: 2.9666e-04 - val_mean_absolute_error: 0.0130
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.6338e-05 - mean_absolute_error: 0.0064 - val_loss: 3.5973e-04 - val_mean_absolute_error: 0.0149
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.9208e-05 - mean_absolute_error: 0.0071 - val_loss: 2.9721e-04 - val_mean_absolute_error: 0.0130
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0365e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9996e-04 - val_mean_absolute_error: 0.0131
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1401e-04 - mean_absolute_error: 0.0073 - val_loss: 3.8623e-04 - val_mean_absolute_error: 0.0157
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1089e-04 - mean_absolute_error: 0.0074 - val_loss: 3.9615e-04 - val_mean_absolute_error: 0.0159

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 1752405.704618416
# RMSE: 1323.7846141341936
# MAE: 1019.1790183017928
# MAPE: 3.1342184133521647 %
#
# Model evalution on validate set
# MSE: 2151582.179399332
# RMSE: 1466.8272493376076
# MAE: 1037.8358603013835
# MAPE: 2.4465678476206647 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 840ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step

# %%
y_pred_30_days
# Out:
# array([[63217.395],
#        [61883.332],
#        [62351.727],
#        [62750.812],
#        [62267.63 ],
#        [62526.46 ],
#        [62473.504],
#        [62409.707],
#        [62483.48 ],
#        [62442.71 ],
#        [62449.527],
#        [62459.67 ],
#        [62448.13 ],
#        [62454.355],
#        [62453.426],
#        [62451.797],
#        [62453.594],
#        [62452.645],
#        [62452.766],
#        [62453.035],
#        [62452.754],
#        [62452.9  ],
#        [62452.88 ],
#        [62452.84 ],
#        [62452.867],
#        [62452.86 ],
#        [62452.86 ],
#        [62452.867],
#        [62452.86 ],
#        [62452.86 ],
#        [62452.867]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Forecast Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Forecast the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
