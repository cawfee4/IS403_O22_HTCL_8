# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: CMG - Test/Train/Vaildation: 60/20/20
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1203.0627014459296
# - MAE: 877.4083820966135
# - MAPE: 2.684818745611117 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 1  # 6 2 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((776, 10), (776,), (251, 10), (251,), (253, 10), (253,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - loss: 0.0056 - mean_absolute_error: 0.0554 - val_loss: 0.0017 - val_mean_absolute_error: 0.0336
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 5.3884e-04 - mean_absolute_error: 0.0170 - val_loss: 8.4667e-04 - val_mean_absolute_error: 0.0216
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.3344e-04 - mean_absolute_error: 0.0133 - val_loss: 6.8066e-04 - val_mean_absolute_error: 0.0189
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.9404e-04 - mean_absolute_error: 0.0122 - val_loss: 7.8342e-04 - val_mean_absolute_error: 0.0219
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 3.0489e-04 - mean_absolute_error: 0.0127 - val_loss: 6.5130e-04 - val_mean_absolute_error: 0.0197
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.4550e-04 - mean_absolute_error: 0.0113 - val_loss: 8.0067e-04 - val_mean_absolute_error: 0.0228
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.6376e-04 - mean_absolute_error: 0.0119 - val_loss: 4.8872e-04 - val_mean_absolute_error: 0.0159
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2593e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0010 - val_mean_absolute_error: 0.0271
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.9603e-04 - mean_absolute_error: 0.0122 - val_loss: 4.6122e-04 - val_mean_absolute_error: 0.0155
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 2.3909e-04 - mean_absolute_error: 0.0107 - val_loss: 4.3459e-04 - val_mean_absolute_error: 0.0148
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8033e-04 - mean_absolute_error: 0.0091 - val_loss: 5.4181e-04 - val_mean_absolute_error: 0.0179
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0377e-04 - mean_absolute_error: 0.0099 - val_loss: 4.2910e-04 - val_mean_absolute_error: 0.0150
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 2.1623e-04 - mean_absolute_error: 0.0100 - val_loss: 4.4866e-04 - val_mean_absolute_error: 0.0156
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.8956e-04 - mean_absolute_error: 0.0098 - val_loss: 4.2144e-04 - val_mean_absolute_error: 0.0149
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6222e-04 - mean_absolute_error: 0.0087 - val_loss: 4.2367e-04 - val_mean_absolute_error: 0.0151
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8890e-04 - mean_absolute_error: 0.0096 - val_loss: 4.1505e-04 - val_mean_absolute_error: 0.0149
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9228e-04 - mean_absolute_error: 0.0098 - val_loss: 3.8399e-04 - val_mean_absolute_error: 0.0140
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6003e-04 - mean_absolute_error: 0.0088 - val_loss: 3.7917e-04 - val_mean_absolute_error: 0.0139
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.9928e-04 - mean_absolute_error: 0.0096 - val_loss: 8.7290e-04 - val_mean_absolute_error: 0.0250
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.9711e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0012 - val_mean_absolute_error: 0.0303
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.3608e-04 - mean_absolute_error: 0.0114 - val_loss: 4.3454e-04 - val_mean_absolute_error: 0.0156
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.1975e-04 - mean_absolute_error: 0.0107 - val_loss: 3.6895e-04 - val_mean_absolute_error: 0.0139
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7968e-04 - mean_absolute_error: 0.0093 - val_loss: 4.0694e-04 - val_mean_absolute_error: 0.0150
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.4755e-04 - mean_absolute_error: 0.0085 - val_loss: 5.8409e-04 - val_mean_absolute_error: 0.0199
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 2.2711e-04 - mean_absolute_error: 0.0110 - val_loss: 8.0671e-04 - val_mean_absolute_error: 0.0239
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.5865e-04 - mean_absolute_error: 0.0089 - val_loss: 3.4431e-04 - val_mean_absolute_error: 0.0132
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3524e-04 - mean_absolute_error: 0.0079 - val_loss: 6.1352e-04 - val_mean_absolute_error: 0.0207
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.9678e-04 - mean_absolute_error: 0.0101 - val_loss: 3.5608e-04 - val_mean_absolute_error: 0.0137
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6003e-04 - mean_absolute_error: 0.0089 - val_loss: 3.7156e-04 - val_mean_absolute_error: 0.0142
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4809e-04 - mean_absolute_error: 0.0090 - val_loss: 4.3979e-04 - val_mean_absolute_error: 0.0161
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3558e-04 - mean_absolute_error: 0.0082 - val_loss: 4.4601e-04 - val_mean_absolute_error: 0.0163
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2418e-04 - mean_absolute_error: 0.0080 - val_loss: 3.1912e-04 - val_mean_absolute_error: 0.0128
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.4858e-04 - mean_absolute_error: 0.0085 - val_loss: 3.1647e-04 - val_mean_absolute_error: 0.0127
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2415e-04 - mean_absolute_error: 0.0077 - val_loss: 3.2190e-04 - val_mean_absolute_error: 0.0129
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2279e-04 - mean_absolute_error: 0.0076 - val_loss: 5.7077e-04 - val_mean_absolute_error: 0.0200
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3636e-04 - mean_absolute_error: 0.0080 - val_loss: 3.1417e-04 - val_mean_absolute_error: 0.0131
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3432e-04 - mean_absolute_error: 0.0080 - val_loss: 4.0025e-04 - val_mean_absolute_error: 0.0153
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2458e-04 - mean_absolute_error: 0.0076 - val_loss: 3.3117e-04 - val_mean_absolute_error: 0.0133
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3166e-04 - mean_absolute_error: 0.0081 - val_loss: 3.8508e-04 - val_mean_absolute_error: 0.0156
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4575e-04 - mean_absolute_error: 0.0085 - val_loss: 3.2041e-04 - val_mean_absolute_error: 0.0129
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0664e-04 - mean_absolute_error: 0.0074 - val_loss: 3.6967e-04 - val_mean_absolute_error: 0.0146
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2530e-04 - mean_absolute_error: 0.0078 - val_loss: 3.0728e-04 - val_mean_absolute_error: 0.0131
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1548e-04 - mean_absolute_error: 0.0075 - val_loss: 3.0049e-04 - val_mean_absolute_error: 0.0128
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.7545e-05 - mean_absolute_error: 0.0067 - val_loss: 4.6435e-04 - val_mean_absolute_error: 0.0172
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1034e-04 - mean_absolute_error: 0.0074 - val_loss: 4.3320e-04 - val_mean_absolute_error: 0.0164
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.4382e-04 - mean_absolute_error: 0.0088 - val_loss: 3.1561e-04 - val_mean_absolute_error: 0.0136
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1952e-04 - mean_absolute_error: 0.0077 - val_loss: 2.9244e-04 - val_mean_absolute_error: 0.0124
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3436e-04 - mean_absolute_error: 0.0078 - val_loss: 3.9351e-04 - val_mean_absolute_error: 0.0154
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2854e-04 - mean_absolute_error: 0.0084 - val_loss: 2.9795e-04 - val_mean_absolute_error: 0.0126
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.1650e-04 - mean_absolute_error: 0.0073 - val_loss: 3.0025e-04 - val_mean_absolute_error: 0.0131
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3606e-04 - mean_absolute_error: 0.0077 - val_loss: 4.2939e-04 - val_mean_absolute_error: 0.0164
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1862e-04 - mean_absolute_error: 0.0079 - val_loss: 3.0260e-04 - val_mean_absolute_error: 0.0132
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0560e-04 - mean_absolute_error: 0.0071 - val_loss: 3.0363e-04 - val_mean_absolute_error: 0.0133
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1553e-04 - mean_absolute_error: 0.0076 - val_loss: 2.9194e-04 - val_mean_absolute_error: 0.0125
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1150e-04 - mean_absolute_error: 0.0074 - val_loss: 3.2538e-04 - val_mean_absolute_error: 0.0136
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1648e-04 - mean_absolute_error: 0.0074 - val_loss: 3.0152e-04 - val_mean_absolute_error: 0.0132
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0990e-04 - mean_absolute_error: 0.0070 - val_loss: 3.1428e-04 - val_mean_absolute_error: 0.0134
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.1901e-05 - mean_absolute_error: 0.0068 - val_loss: 2.8560e-04 - val_mean_absolute_error: 0.0126
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0161e-04 - mean_absolute_error: 0.0068 - val_loss: 2.8720e-04 - val_mean_absolute_error: 0.0126
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.6898e-05 - mean_absolute_error: 0.0069 - val_loss: 2.9600e-04 - val_mean_absolute_error: 0.0130
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0789e-04 - mean_absolute_error: 0.0073 - val_loss: 3.9877e-04 - val_mean_absolute_error: 0.0158
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1716e-04 - mean_absolute_error: 0.0076 - val_loss: 3.6179e-04 - val_mean_absolute_error: 0.0152
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2246e-04 - mean_absolute_error: 0.0077 - val_loss: 2.9088e-04 - val_mean_absolute_error: 0.0128
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0187e-04 - mean_absolute_error: 0.0071 - val_loss: 3.1001e-04 - val_mean_absolute_error: 0.0136
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1248e-04 - mean_absolute_error: 0.0073 - val_loss: 3.9254e-04 - val_mean_absolute_error: 0.0156
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2277e-04 - mean_absolute_error: 0.0079 - val_loss: 2.9306e-04 - val_mean_absolute_error: 0.0130
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.5145e-05 - mean_absolute_error: 0.0067 - val_loss: 3.3327e-04 - val_mean_absolute_error: 0.0143
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.7851e-05 - mean_absolute_error: 0.0069 - val_loss: 3.1516e-04 - val_mean_absolute_error: 0.0136
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1299e-04 - mean_absolute_error: 0.0076 - val_loss: 3.9100e-04 - val_mean_absolute_error: 0.0160
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1097e-04 - mean_absolute_error: 0.0072 - val_loss: 4.3614e-04 - val_mean_absolute_error: 0.0168
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.1409e-05 - mean_absolute_error: 0.0068 - val_loss: 2.8199e-04 - val_mean_absolute_error: 0.0125
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.6533e-05 - mean_absolute_error: 0.0067 - val_loss: 2.8998e-04 - val_mean_absolute_error: 0.0128
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.4309e-05 - mean_absolute_error: 0.0067 - val_loss: 4.3554e-04 - val_mean_absolute_error: 0.0171
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3473e-04 - mean_absolute_error: 0.0081 - val_loss: 2.8841e-04 - val_mean_absolute_error: 0.0128
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.4422e-05 - mean_absolute_error: 0.0065 - val_loss: 3.1713e-04 - val_mean_absolute_error: 0.0137
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.8874e-05 - mean_absolute_error: 0.0068 - val_loss: 2.8383e-04 - val_mean_absolute_error: 0.0126
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.0101e-04 - mean_absolute_error: 0.0071 - val_loss: 3.4250e-04 - val_mean_absolute_error: 0.0143
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1328e-04 - mean_absolute_error: 0.0073 - val_loss: 2.8557e-04 - val_mean_absolute_error: 0.0126
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.1967e-05 - mean_absolute_error: 0.0068 - val_loss: 2.7976e-04 - val_mean_absolute_error: 0.0124
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1635e-04 - mean_absolute_error: 0.0075 - val_loss: 2.8214e-04 - val_mean_absolute_error: 0.0125
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.1078e-05 - mean_absolute_error: 0.0068 - val_loss: 2.8585e-04 - val_mean_absolute_error: 0.0127
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1870e-04 - mean_absolute_error: 0.0075 - val_loss: 2.8027e-04 - val_mean_absolute_error: 0.0125
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.3474e-05 - mean_absolute_error: 0.0067 - val_loss: 3.6430e-04 - val_mean_absolute_error: 0.0151
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0324e-04 - mean_absolute_error: 0.0073 - val_loss: 2.8427e-04 - val_mean_absolute_error: 0.0126
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1323e-04 - mean_absolute_error: 0.0077 - val_loss: 2.8391e-04 - val_mean_absolute_error: 0.0126
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.9328e-05 - mean_absolute_error: 0.0068 - val_loss: 3.5778e-04 - val_mean_absolute_error: 0.0149
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.9468e-05 - mean_absolute_error: 0.0073 - val_loss: 3.1143e-04 - val_mean_absolute_error: 0.0136
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1090e-04 - mean_absolute_error: 0.0076 - val_loss: 2.9456e-04 - val_mean_absolute_error: 0.0130
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.2674e-05 - mean_absolute_error: 0.0066 - val_loss: 3.0650e-04 - val_mean_absolute_error: 0.0134
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0880e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9521e-04 - val_mean_absolute_error: 0.0130
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.1258e-04 - mean_absolute_error: 0.0072 - val_loss: 3.7255e-04 - val_mean_absolute_error: 0.0154
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0351e-04 - mean_absolute_error: 0.0072 - val_loss: 3.4858e-04 - val_mean_absolute_error: 0.0146
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.9201e-05 - mean_absolute_error: 0.0071 - val_loss: 2.9264e-04 - val_mean_absolute_error: 0.0129
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0175e-04 - mean_absolute_error: 0.0068 - val_loss: 2.9443e-04 - val_mean_absolute_error: 0.0131
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.7378e-05 - mean_absolute_error: 0.0064 - val_loss: 2.9009e-04 - val_mean_absolute_error: 0.0128
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.9533e-05 - mean_absolute_error: 0.0065 - val_loss: 3.5434e-04 - val_mean_absolute_error: 0.0148
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.8775e-05 - mean_absolute_error: 0.0071 - val_loss: 2.9240e-04 - val_mean_absolute_error: 0.0129
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.8324e-05 - mean_absolute_error: 0.0069 - val_loss: 4.4124e-04 - val_mean_absolute_error: 0.0171
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0168e-04 - mean_absolute_error: 0.0071 - val_loss: 2.9413e-04 - val_mean_absolute_error: 0.0129
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0325e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9290e-04 - val_mean_absolute_error: 0.0129
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.6765e-05 - mean_absolute_error: 0.0065 - val_loss: 3.5119e-04 - val_mean_absolute_error: 0.0146
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 8.8635e-05 - mean_absolute_error: 0.0068 - val_loss: 2.9102e-04 - val_mean_absolute_error: 0.0128
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.3993e-05 - mean_absolute_error: 0.0065 - val_loss: 2.8731e-04 - val_mean_absolute_error: 0.0127
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.5623e-05 - mean_absolute_error: 0.0067 - val_loss: 2.8803e-04 - val_mean_absolute_error: 0.0127
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.6779e-05 - mean_absolute_error: 0.0067 - val_loss: 3.0995e-04 - val_mean_absolute_error: 0.0135
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0221e-04 - mean_absolute_error: 0.0073 - val_loss: 3.2509e-04 - val_mean_absolute_error: 0.0139
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.1415e-04 - mean_absolute_error: 0.0074 - val_loss: 3.8749e-04 - val_mean_absolute_error: 0.0156
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1593e-04 - mean_absolute_error: 0.0076 - val_loss: 3.0771e-04 - val_mean_absolute_error: 0.0134
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.3081e-05 - mean_absolute_error: 0.0067 - val_loss: 2.8890e-04 - val_mean_absolute_error: 0.0128
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.9238e-05 - mean_absolute_error: 0.0071 - val_loss: 3.0746e-04 - val_mean_absolute_error: 0.0134
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1935e-04 - mean_absolute_error: 0.0074 - val_loss: 3.1165e-04 - val_mean_absolute_error: 0.0135
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1305e-04 - mean_absolute_error: 0.0078 - val_loss: 3.2673e-04 - val_mean_absolute_error: 0.0140
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 9.6140e-05 - mean_absolute_error: 0.0066 - val_loss: 2.9037e-04 - val_mean_absolute_error: 0.0128
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0051e-04 - mean_absolute_error: 0.0069 - val_loss: 2.9198e-04 - val_mean_absolute_error: 0.0128
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.6348e-05 - mean_absolute_error: 0.0067 - val_loss: 4.4152e-04 - val_mean_absolute_error: 0.0169
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.9747e-05 - mean_absolute_error: 0.0068 - val_loss: 3.0773e-04 - val_mean_absolute_error: 0.0133
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.5757e-05 - mean_absolute_error: 0.0068 - val_loss: 2.9110e-04 - val_mean_absolute_error: 0.0128
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 8.6018e-05 - mean_absolute_error: 0.0063 - val_loss: 3.0135e-04 - val_mean_absolute_error: 0.0132
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.1743e-05 - mean_absolute_error: 0.0066 - val_loss: 3.8620e-04 - val_mean_absolute_error: 0.0156
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0374e-04 - mean_absolute_error: 0.0071 - val_loss: 4.1153e-04 - val_mean_absolute_error: 0.0163
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0930e-04 - mean_absolute_error: 0.0074 - val_loss: 4.1507e-04 - val_mean_absolute_error: 0.0164
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0996e-04 - mean_absolute_error: 0.0072 - val_loss: 3.7730e-04 - val_mean_absolute_error: 0.0154
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.5682e-05 - mean_absolute_error: 0.0068 - val_loss: 2.9836e-04 - val_mean_absolute_error: 0.0130
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.1483e-05 - mean_absolute_error: 0.0064 - val_loss: 2.9235e-04 - val_mean_absolute_error: 0.0129
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 8.9250e-05 - mean_absolute_error: 0.0065 - val_loss: 3.6242e-04 - val_mean_absolute_error: 0.0150
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0386e-04 - mean_absolute_error: 0.0068 - val_loss: 3.0429e-04 - val_mean_absolute_error: 0.0133
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0847e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9721e-04 - val_mean_absolute_error: 0.0130
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0843e-04 - mean_absolute_error: 0.0071 - val_loss: 3.4091e-04 - val_mean_absolute_error: 0.0144
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.9629e-05 - mean_absolute_error: 0.0070 - val_loss: 2.9950e-04 - val_mean_absolute_error: 0.0131
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1856e-04 - mean_absolute_error: 0.0076 - val_loss: 3.2160e-04 - val_mean_absolute_error: 0.0139
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7803e-05 - mean_absolute_error: 0.0069 - val_loss: 4.5443e-04 - val_mean_absolute_error: 0.0173
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2240e-04 - mean_absolute_error: 0.0079 - val_loss: 3.0362e-04 - val_mean_absolute_error: 0.0132
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1235e-04 - mean_absolute_error: 0.0076 - val_loss: 4.7738e-04 - val_mean_absolute_error: 0.0178
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.6294e-04 - mean_absolute_error: 0.0092 - val_loss: 2.9284e-04 - val_mean_absolute_error: 0.0129
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2050e-04 - mean_absolute_error: 0.0077 - val_loss: 2.9248e-04 - val_mean_absolute_error: 0.0129
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.4337e-05 - mean_absolute_error: 0.0068 - val_loss: 2.9277e-04 - val_mean_absolute_error: 0.0129
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0112e-04 - mean_absolute_error: 0.0068 - val_loss: 3.1516e-04 - val_mean_absolute_error: 0.0137
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.3937e-05 - mean_absolute_error: 0.0064 - val_loss: 2.9471e-04 - val_mean_absolute_error: 0.0129
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.6280e-05 - mean_absolute_error: 0.0068 - val_loss: 3.7425e-04 - val_mean_absolute_error: 0.0153
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1188e-04 - mean_absolute_error: 0.0075 - val_loss: 2.9423e-04 - val_mean_absolute_error: 0.0129
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.6984e-05 - mean_absolute_error: 0.0066 - val_loss: 3.2401e-04 - val_mean_absolute_error: 0.0139
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.8146e-05 - mean_absolute_error: 0.0070 - val_loss: 3.1737e-04 - val_mean_absolute_error: 0.0137
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.6925e-05 - mean_absolute_error: 0.0066 - val_loss: 3.0037e-04 - val_mean_absolute_error: 0.0131
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.6814e-05 - mean_absolute_error: 0.0068 - val_loss: 2.9443e-04 - val_mean_absolute_error: 0.0129
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.5087e-05 - mean_absolute_error: 0.0066 - val_loss: 2.9286e-04 - val_mean_absolute_error: 0.0129
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.7496e-05 - mean_absolute_error: 0.0065 - val_loss: 3.0256e-04 - val_mean_absolute_error: 0.0132
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 9.9372e-05 - mean_absolute_error: 0.0069 - val_loss: 5.8403e-04 - val_mean_absolute_error: 0.0199
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3338e-04 - mean_absolute_error: 0.0086 - val_loss: 2.9308e-04 - val_mean_absolute_error: 0.0129
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0378e-04 - mean_absolute_error: 0.0071 - val_loss: 3.2030e-04 - val_mean_absolute_error: 0.0137
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0469e-04 - mean_absolute_error: 0.0068 - val_loss: 2.9713e-04 - val_mean_absolute_error: 0.0130
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.5142e-05 - mean_absolute_error: 0.0069 - val_loss: 2.9615e-04 - val_mean_absolute_error: 0.0131
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1560e-04 - mean_absolute_error: 0.0074 - val_loss: 3.0543e-04 - val_mean_absolute_error: 0.0133
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1015e-04 - mean_absolute_error: 0.0072 - val_loss: 3.1930e-04 - val_mean_absolute_error: 0.0138
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2021e-04 - mean_absolute_error: 0.0078 - val_loss: 3.8155e-04 - val_mean_absolute_error: 0.0155
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.9844e-05 - mean_absolute_error: 0.0073 - val_loss: 3.0777e-04 - val_mean_absolute_error: 0.0134
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0338e-04 - mean_absolute_error: 0.0069 - val_loss: 2.9485e-04 - val_mean_absolute_error: 0.0129
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0776e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9465e-04 - val_mean_absolute_error: 0.0130
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1331e-04 - mean_absolute_error: 0.0075 - val_loss: 3.4551e-04 - val_mean_absolute_error: 0.0145
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.5790e-05 - mean_absolute_error: 0.0068 - val_loss: 2.9725e-04 - val_mean_absolute_error: 0.0131
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.8625e-05 - mean_absolute_error: 0.0066 - val_loss: 3.8229e-04 - val_mean_absolute_error: 0.0155
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.2247e-04 - mean_absolute_error: 0.0082 - val_loss: 3.0989e-04 - val_mean_absolute_error: 0.0134
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.4416e-05 - mean_absolute_error: 0.0069 - val_loss: 3.0037e-04 - val_mean_absolute_error: 0.0131
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.8511e-05 - mean_absolute_error: 0.0068 - val_loss: 2.9487e-04 - val_mean_absolute_error: 0.0130
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.5005e-05 - mean_absolute_error: 0.0070 - val_loss: 3.1590e-04 - val_mean_absolute_error: 0.0137
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 9.9448e-05 - mean_absolute_error: 0.0069 - val_loss: 3.1869e-04 - val_mean_absolute_error: 0.0137
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1279e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9630e-04 - val_mean_absolute_error: 0.0130
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.3868e-05 - mean_absolute_error: 0.0066 - val_loss: 3.0304e-04 - val_mean_absolute_error: 0.0133
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0159e-04 - mean_absolute_error: 0.0071 - val_loss: 3.2989e-04 - val_mean_absolute_error: 0.0141
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2549e-04 - mean_absolute_error: 0.0081 - val_loss: 3.1723e-04 - val_mean_absolute_error: 0.0137
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1506e-04 - mean_absolute_error: 0.0076 - val_loss: 2.9678e-04 - val_mean_absolute_error: 0.0130
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1088e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9696e-04 - val_mean_absolute_error: 0.0131
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0872e-04 - mean_absolute_error: 0.0067 - val_loss: 3.1462e-04 - val_mean_absolute_error: 0.0137
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.7901e-05 - mean_absolute_error: 0.0066 - val_loss: 2.9594e-04 - val_mean_absolute_error: 0.0130
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1177e-04 - mean_absolute_error: 0.0073 - val_loss: 3.4919e-04 - val_mean_absolute_error: 0.0146
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1920e-04 - mean_absolute_error: 0.0080 - val_loss: 3.0027e-04 - val_mean_absolute_error: 0.0132
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.6040e-05 - mean_absolute_error: 0.0067 - val_loss: 3.4742e-04 - val_mean_absolute_error: 0.0146
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7784e-05 - mean_absolute_error: 0.0068 - val_loss: 2.9634e-04 - val_mean_absolute_error: 0.0130
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0405e-04 - mean_absolute_error: 0.0074 - val_loss: 3.6606e-04 - val_mean_absolute_error: 0.0151
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1252e-04 - mean_absolute_error: 0.0076 - val_loss: 3.1092e-04 - val_mean_absolute_error: 0.0135
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.7359e-05 - mean_absolute_error: 0.0069 - val_loss: 3.5451e-04 - val_mean_absolute_error: 0.0148
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.5149e-05 - mean_absolute_error: 0.0070 - val_loss: 3.0401e-04 - val_mean_absolute_error: 0.0133
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.5553e-05 - mean_absolute_error: 0.0066 - val_loss: 3.1163e-04 - val_mean_absolute_error: 0.0135
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0575e-04 - mean_absolute_error: 0.0071 - val_loss: 3.6607e-04 - val_mean_absolute_error: 0.0151
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0107e-04 - mean_absolute_error: 0.0071 - val_loss: 3.0100e-04 - val_mean_absolute_error: 0.0132
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.7002e-05 - mean_absolute_error: 0.0065 - val_loss: 4.3267e-04 - val_mean_absolute_error: 0.0167
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.4229e-05 - mean_absolute_error: 0.0068 - val_loss: 3.0124e-04 - val_mean_absolute_error: 0.0131
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.9700e-05 - mean_absolute_error: 0.0068 - val_loss: 3.0835e-04 - val_mean_absolute_error: 0.0133
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.4402e-05 - mean_absolute_error: 0.0063 - val_loss: 3.1528e-04 - val_mean_absolute_error: 0.0136
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0482e-04 - mean_absolute_error: 0.0072 - val_loss: 3.1058e-04 - val_mean_absolute_error: 0.0134
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 9.9859e-05 - mean_absolute_error: 0.0071 - val_loss: 3.7678e-04 - val_mean_absolute_error: 0.0153
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.0470e-04 - mean_absolute_error: 0.0072 - val_loss: 3.2404e-04 - val_mean_absolute_error: 0.0138
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.0939e-04 - mean_absolute_error: 0.0071 - val_loss: 2.9506e-04 - val_mean_absolute_error: 0.0129
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1098e-04 - mean_absolute_error: 0.0073 - val_loss: 3.0292e-04 - val_mean_absolute_error: 0.0133
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.2283e-05 - mean_absolute_error: 0.0068 - val_loss: 3.4914e-04 - val_mean_absolute_error: 0.0146
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.9551e-05 - mean_absolute_error: 0.0067 - val_loss: 2.9949e-04 - val_mean_absolute_error: 0.0131
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.5226e-05 - mean_absolute_error: 0.0065 - val_loss: 3.2097e-04 - val_mean_absolute_error: 0.0137
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.1317e-04 - mean_absolute_error: 0.0072 - val_loss: 3.0825e-04 - val_mean_absolute_error: 0.0134
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.4020e-05 - mean_absolute_error: 0.0063 - val_loss: 3.0366e-04 - val_mean_absolute_error: 0.0133
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.5374e-05 - mean_absolute_error: 0.0066 - val_loss: 3.0477e-04 - val_mean_absolute_error: 0.0133
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0072e-04 - mean_absolute_error: 0.0069 - val_loss: 2.9608e-04 - val_mean_absolute_error: 0.0130

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 116ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 1447359.8636103778
# RMSE: 1203.0627014459296
# MAE: 877.4083820966135
# MAPE: 2.684818745611117 %
#
# Model evalution on validate set
# MSE: 2278861.735591768
# RMSE: 1509.589922989607
# MAE: 927.8048804965415
# MAPE: 2.1334254044826086 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step

# %%
y_pred_30_days
# Out:
# array([[61464.715],
#        [60452.906],
#        [60811.77 ],
#        [61027.305],
#        [60717.14 ],
#        [60907.695],
#        [60855.44 ],
#        [60821.875],
#        [60871.684],
#        [60839.95 ],
#        [60848.38 ],
#        [60853.64 ],
#        [60845.543],
#        [60850.73 ],
#        [60849.33 ],
#        [60848.492],
#        [60849.812],
#        [60848.965],
#        [60849.203],
#        [60849.32 ],
#        [60849.113],
#        [60849.254],
#        [60849.227],
#        [60849.188],
#        [60849.24 ],
#        [60849.207],
#        [60849.207],
#        [60849.227],
#        [60849.215],
#        [60849.207],
#        [60849.227]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Predicted Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Prediction Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Predict the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
