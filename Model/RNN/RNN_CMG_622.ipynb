# %% [markdown]
# # Model: RNN (Recurrent Natural Network)  - Stock Token: CMG - Test/Train/Vaildation: 60/20/20
# - Dataset: 1313 rows x 7 column (01/03/2019 - 01/06/2024)
# - Window-slide: 10, epochs: 200, batch-size: 32
# ----
# ### Model evaluation (Test set)
# - RMSE: 1207.525439357576
# - MAE: 885.4989028261953
# - MAPE: 2.7098004208079707 %

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

# %% [markdown]
# ## 1. Data preprocessing

# %%
# Split: [0] = 70% 20% 10% | [1] = 60% 20% 20% | [2] = 80% 10% 10%
split_type = [[0.7, 0.2], [0.6, 0.2], [0.8, 0.1]]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 1  # 6 2 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.tail()
# Out:
#             close
# time
# 2024-05-27  59000
# 2024-05-28  62100
# 2024-05-29  60000
# 2024-05-30  59200
# 2024-05-31  60900

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using natural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set, validation set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split][0] * len(df_scaled))
test_size = int(split_type[split][1] * len(df_scaled))
val_size = len(df) - train_size - test_size

# %%
# Splitting data into train, test and validation set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size : train_size + test_size]
val_data = df_scaled[train_size + test_size :]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test and validate
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)
X_val, y_val = create_dataset(val_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_val.shape, y_val.shape
# Out:
# ((776, 10), (776,), (251, 10), (251,), (253, 10), (253,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_val = X_val.reshape(X_val.shape[0], X_val.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(100),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 100)            │        10,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,301 (40.24 KB)
#  Trainable params: 10,301 (40.24 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 0.0259 - mean_absolute_error: 0.1106 - val_loss: 0.0044 - val_mean_absolute_error: 0.0627
# Epoch 2/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.7395e-04 - mean_absolute_error: 0.0188 - val_loss: 6.3046e-04 - val_mean_absolute_error: 0.0191
# Epoch 3/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0388e-04 - mean_absolute_error: 0.0102 - val_loss: 4.6713e-04 - val_mean_absolute_error: 0.0157
# Epoch 4/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6264e-04 - mean_absolute_error: 0.0093 - val_loss: 4.2401e-04 - val_mean_absolute_error: 0.0152
# Epoch 5/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6673e-04 - mean_absolute_error: 0.0089 - val_loss: 4.1028e-04 - val_mean_absolute_error: 0.0145
# Epoch 6/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.7583e-04 - mean_absolute_error: 0.0096 - val_loss: 3.7034e-04 - val_mean_absolute_error: 0.0136
# Epoch 7/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4903e-04 - mean_absolute_error: 0.0087 - val_loss: 3.6094e-04 - val_mean_absolute_error: 0.0139
# Epoch 8/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4087e-04 - mean_absolute_error: 0.0083 - val_loss: 3.3722e-04 - val_mean_absolute_error: 0.0129
# Epoch 9/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5048e-04 - mean_absolute_error: 0.0084 - val_loss: 3.4303e-04 - val_mean_absolute_error: 0.0131
# Epoch 10/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3715e-04 - mean_absolute_error: 0.0083 - val_loss: 3.4895e-04 - val_mean_absolute_error: 0.0141
# Epoch 11/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.3003e-04 - mean_absolute_error: 0.0079 - val_loss: 3.2911e-04 - val_mean_absolute_error: 0.0128
# Epoch 12/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.3743e-04 - mean_absolute_error: 0.0081 - val_loss: 3.1880e-04 - val_mean_absolute_error: 0.0126
# Epoch 13/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3436e-04 - mean_absolute_error: 0.0080 - val_loss: 3.5446e-04 - val_mean_absolute_error: 0.0144
# Epoch 14/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.4645e-04 - mean_absolute_error: 0.0084 - val_loss: 3.6343e-04 - val_mean_absolute_error: 0.0148
# Epoch 15/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.3269e-04 - mean_absolute_error: 0.0080 - val_loss: 3.0348e-04 - val_mean_absolute_error: 0.0124
# Epoch 16/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.5056e-04 - mean_absolute_error: 0.0084 - val_loss: 3.2156e-04 - val_mean_absolute_error: 0.0133
# Epoch 17/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3081e-04 - mean_absolute_error: 0.0078 - val_loss: 3.4844e-04 - val_mean_absolute_error: 0.0138
# Epoch 18/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.3354e-04 - mean_absolute_error: 0.0082 - val_loss: 3.1465e-04 - val_mean_absolute_error: 0.0127
# Epoch 19/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.1618e-04 - mean_absolute_error: 0.0073 - val_loss: 3.0013e-04 - val_mean_absolute_error: 0.0124
# Epoch 20/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3652e-04 - mean_absolute_error: 0.0080 - val_loss: 2.9816e-04 - val_mean_absolute_error: 0.0123
# Epoch 21/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3729e-04 - mean_absolute_error: 0.0080 - val_loss: 3.0942e-04 - val_mean_absolute_error: 0.0130
# Epoch 22/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.2927e-04 - mean_absolute_error: 0.0075 - val_loss: 2.9692e-04 - val_mean_absolute_error: 0.0123
# Epoch 23/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.5706e-04 - mean_absolute_error: 0.0085 - val_loss: 2.9514e-04 - val_mean_absolute_error: 0.0123
# Epoch 24/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2288e-04 - mean_absolute_error: 0.0074 - val_loss: 6.3742e-04 - val_mean_absolute_error: 0.0215
# Epoch 25/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.8309e-04 - mean_absolute_error: 0.0093 - val_loss: 4.2782e-04 - val_mean_absolute_error: 0.0168
# Epoch 26/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3317e-04 - mean_absolute_error: 0.0081 - val_loss: 3.0126e-04 - val_mean_absolute_error: 0.0128
# Epoch 27/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3367e-04 - mean_absolute_error: 0.0079 - val_loss: 3.9878e-04 - val_mean_absolute_error: 0.0153
# Epoch 28/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.2459e-04 - mean_absolute_error: 0.0081 - val_loss: 3.9482e-04 - val_mean_absolute_error: 0.0152
# Epoch 29/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3141e-04 - mean_absolute_error: 0.0079 - val_loss: 3.2484e-04 - val_mean_absolute_error: 0.0132
# Epoch 30/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1071e-04 - mean_absolute_error: 0.0073 - val_loss: 2.9717e-04 - val_mean_absolute_error: 0.0123
# Epoch 31/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2170e-04 - mean_absolute_error: 0.0076 - val_loss: 2.9031e-04 - val_mean_absolute_error: 0.0122
# Epoch 32/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3464e-04 - mean_absolute_error: 0.0079 - val_loss: 3.2385e-04 - val_mean_absolute_error: 0.0132
# Epoch 33/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1993e-04 - mean_absolute_error: 0.0075 - val_loss: 3.2823e-04 - val_mean_absolute_error: 0.0134
# Epoch 34/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0479e-04 - mean_absolute_error: 0.0071 - val_loss: 3.3583e-04 - val_mean_absolute_error: 0.0142
# Epoch 35/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4103e-04 - mean_absolute_error: 0.0081 - val_loss: 3.2435e-04 - val_mean_absolute_error: 0.0139
# Epoch 36/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.3676e-04 - mean_absolute_error: 0.0082 - val_loss: 2.8956e-04 - val_mean_absolute_error: 0.0122
# Epoch 37/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1630e-04 - mean_absolute_error: 0.0073 - val_loss: 3.0409e-04 - val_mean_absolute_error: 0.0126
# Epoch 38/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1940e-04 - mean_absolute_error: 0.0075 - val_loss: 2.9390e-04 - val_mean_absolute_error: 0.0127
# Epoch 39/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.1808e-04 - mean_absolute_error: 0.0073 - val_loss: 2.8979e-04 - val_mean_absolute_error: 0.0123
# Epoch 40/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3492e-04 - mean_absolute_error: 0.0082 - val_loss: 2.9010e-04 - val_mean_absolute_error: 0.0124
# Epoch 41/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2193e-04 - mean_absolute_error: 0.0074 - val_loss: 3.3543e-04 - val_mean_absolute_error: 0.0137
# Epoch 42/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1133e-04 - mean_absolute_error: 0.0071 - val_loss: 3.2048e-04 - val_mean_absolute_error: 0.0138
# Epoch 43/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2099e-04 - mean_absolute_error: 0.0073 - val_loss: 3.9212e-04 - val_mean_absolute_error: 0.0160
# Epoch 44/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.3341e-04 - mean_absolute_error: 0.0081 - val_loss: 2.9297e-04 - val_mean_absolute_error: 0.0124
# Epoch 45/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.2464e-04 - mean_absolute_error: 0.0076 - val_loss: 2.8668e-04 - val_mean_absolute_error: 0.0122
# Epoch 46/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2702e-04 - mean_absolute_error: 0.0077 - val_loss: 2.8453e-04 - val_mean_absolute_error: 0.0123
# Epoch 47/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0911e-04 - mean_absolute_error: 0.0072 - val_loss: 3.2193e-04 - val_mean_absolute_error: 0.0134
# Epoch 48/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.0668e-04 - mean_absolute_error: 0.0069 - val_loss: 3.1437e-04 - val_mean_absolute_error: 0.0131
# Epoch 49/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0735e-04 - mean_absolute_error: 0.0071 - val_loss: 3.0161e-04 - val_mean_absolute_error: 0.0128
# Epoch 50/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0876e-04 - mean_absolute_error: 0.0071 - val_loss: 2.8254e-04 - val_mean_absolute_error: 0.0122
# Epoch 51/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3796e-04 - mean_absolute_error: 0.0084 - val_loss: 4.6921e-04 - val_mean_absolute_error: 0.0173
# Epoch 52/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3148e-04 - mean_absolute_error: 0.0083 - val_loss: 3.1351e-04 - val_mean_absolute_error: 0.0131
# Epoch 53/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1207e-04 - mean_absolute_error: 0.0075 - val_loss: 2.8340e-04 - val_mean_absolute_error: 0.0124
# Epoch 54/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2587e-04 - mean_absolute_error: 0.0079 - val_loss: 4.2760e-04 - val_mean_absolute_error: 0.0164
# Epoch 55/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0488e-04 - mean_absolute_error: 0.0072 - val_loss: 3.6725e-04 - val_mean_absolute_error: 0.0148
# Epoch 56/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3869e-04 - mean_absolute_error: 0.0082 - val_loss: 3.8888e-04 - val_mean_absolute_error: 0.0154
# Epoch 57/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1482e-04 - mean_absolute_error: 0.0074 - val_loss: 3.1855e-04 - val_mean_absolute_error: 0.0139
# Epoch 58/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1919e-04 - mean_absolute_error: 0.0077 - val_loss: 3.5350e-04 - val_mean_absolute_error: 0.0144
# Epoch 59/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2265e-04 - mean_absolute_error: 0.0077 - val_loss: 3.3845e-04 - val_mean_absolute_error: 0.0140
# Epoch 60/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0759e-04 - mean_absolute_error: 0.0069 - val_loss: 2.7797e-04 - val_mean_absolute_error: 0.0122
# Epoch 61/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2896e-04 - mean_absolute_error: 0.0077 - val_loss: 2.7836e-04 - val_mean_absolute_error: 0.0123
# Epoch 62/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.9057e-05 - mean_absolute_error: 0.0068 - val_loss: 4.1848e-04 - val_mean_absolute_error: 0.0162
# Epoch 63/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.2398e-04 - mean_absolute_error: 0.0076 - val_loss: 3.1133e-04 - val_mean_absolute_error: 0.0137
# Epoch 64/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0658e-04 - mean_absolute_error: 0.0071 - val_loss: 2.7894e-04 - val_mean_absolute_error: 0.0122
# Epoch 65/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0776e-04 - mean_absolute_error: 0.0071 - val_loss: 3.6286e-04 - val_mean_absolute_error: 0.0153
# Epoch 66/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2680e-04 - mean_absolute_error: 0.0080 - val_loss: 3.0554e-04 - val_mean_absolute_error: 0.0131
# Epoch 67/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0724e-04 - mean_absolute_error: 0.0071 - val_loss: 2.8625e-04 - val_mean_absolute_error: 0.0125
# Epoch 68/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0627e-04 - mean_absolute_error: 0.0070 - val_loss: 2.8481e-04 - val_mean_absolute_error: 0.0124
# Epoch 69/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0024e-04 - mean_absolute_error: 0.0067 - val_loss: 4.1020e-04 - val_mean_absolute_error: 0.0161
# Epoch 70/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1071e-04 - mean_absolute_error: 0.0078 - val_loss: 2.8229e-04 - val_mean_absolute_error: 0.0125
# Epoch 71/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0264e-04 - mean_absolute_error: 0.0070 - val_loss: 3.1586e-04 - val_mean_absolute_error: 0.0138
# Epoch 72/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1430e-04 - mean_absolute_error: 0.0077 - val_loss: 3.2780e-04 - val_mean_absolute_error: 0.0138
# Epoch 73/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.6532e-05 - mean_absolute_error: 0.0068 - val_loss: 2.7796e-04 - val_mean_absolute_error: 0.0123
# Epoch 74/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.3332e-05 - mean_absolute_error: 0.0067 - val_loss: 3.1505e-04 - val_mean_absolute_error: 0.0138
# Epoch 75/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0565e-04 - mean_absolute_error: 0.0072 - val_loss: 3.0430e-04 - val_mean_absolute_error: 0.0131
# Epoch 76/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0818e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9307e-04 - val_mean_absolute_error: 0.0128
# Epoch 77/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0286e-04 - mean_absolute_error: 0.0069 - val_loss: 2.8589e-04 - val_mean_absolute_error: 0.0126
# Epoch 78/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.2446e-05 - mean_absolute_error: 0.0066 - val_loss: 2.8018e-04 - val_mean_absolute_error: 0.0123
# Epoch 79/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 9.8883e-05 - mean_absolute_error: 0.0069 - val_loss: 2.7950e-04 - val_mean_absolute_error: 0.0123
# Epoch 80/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1621e-04 - mean_absolute_error: 0.0071 - val_loss: 2.8818e-04 - val_mean_absolute_error: 0.0128
# Epoch 81/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1439e-04 - mean_absolute_error: 0.0073 - val_loss: 3.5076e-04 - val_mean_absolute_error: 0.0145
# Epoch 82/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.5560e-05 - mean_absolute_error: 0.0068 - val_loss: 3.0185e-04 - val_mean_absolute_error: 0.0132
# Epoch 83/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0117e-04 - mean_absolute_error: 0.0069 - val_loss: 3.0886e-04 - val_mean_absolute_error: 0.0134
# Epoch 84/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.4814e-05 - mean_absolute_error: 0.0065 - val_loss: 2.8002e-04 - val_mean_absolute_error: 0.0124
# Epoch 85/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.2455e-05 - mean_absolute_error: 0.0064 - val_loss: 2.7891e-04 - val_mean_absolute_error: 0.0124
# Epoch 86/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0152e-04 - mean_absolute_error: 0.0068 - val_loss: 4.9258e-04 - val_mean_absolute_error: 0.0181
# Epoch 87/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.1134e-04 - mean_absolute_error: 0.0075 - val_loss: 2.8121e-04 - val_mean_absolute_error: 0.0125
# Epoch 88/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0782e-04 - mean_absolute_error: 0.0070 - val_loss: 2.7969e-04 - val_mean_absolute_error: 0.0124
# Epoch 89/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0393e-04 - mean_absolute_error: 0.0069 - val_loss: 4.0999e-04 - val_mean_absolute_error: 0.0161
# Epoch 90/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0511e-04 - mean_absolute_error: 0.0071 - val_loss: 2.9034e-04 - val_mean_absolute_error: 0.0129
# Epoch 91/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.8295e-05 - mean_absolute_error: 0.0070 - val_loss: 2.7964e-04 - val_mean_absolute_error: 0.0124
# Epoch 92/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.1790e-04 - mean_absolute_error: 0.0083 - val_loss: 2.7862e-04 - val_mean_absolute_error: 0.0125
# Epoch 93/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3177e-04 - mean_absolute_error: 0.0079 - val_loss: 2.8354e-04 - val_mean_absolute_error: 0.0126
# Epoch 94/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0644e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9547e-04 - val_mean_absolute_error: 0.0130
# Epoch 95/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.1193e-05 - mean_absolute_error: 0.0067 - val_loss: 3.1207e-04 - val_mean_absolute_error: 0.0136
# Epoch 96/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0536e-04 - mean_absolute_error: 0.0070 - val_loss: 3.2121e-04 - val_mean_absolute_error: 0.0138
# Epoch 97/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0449e-04 - mean_absolute_error: 0.0070 - val_loss: 3.1913e-04 - val_mean_absolute_error: 0.0137
# Epoch 98/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 9.2753e-05 - mean_absolute_error: 0.0067 - val_loss: 2.8078e-04 - val_mean_absolute_error: 0.0125
# Epoch 99/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2359e-04 - mean_absolute_error: 0.0078 - val_loss: 2.8685e-04 - val_mean_absolute_error: 0.0127
# Epoch 100/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.8292e-05 - mean_absolute_error: 0.0064 - val_loss: 2.8588e-04 - val_mean_absolute_error: 0.0127
# Epoch 101/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.1623e-05 - mean_absolute_error: 0.0067 - val_loss: 3.1369e-04 - val_mean_absolute_error: 0.0136
# Epoch 102/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1245e-04 - mean_absolute_error: 0.0074 - val_loss: 3.0736e-04 - val_mean_absolute_error: 0.0134
# Epoch 103/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.3226e-05 - mean_absolute_error: 0.0065 - val_loss: 2.8292e-04 - val_mean_absolute_error: 0.0126
# Epoch 104/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.3911e-05 - mean_absolute_error: 0.0067 - val_loss: 2.8785e-04 - val_mean_absolute_error: 0.0127
# Epoch 105/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.2698e-05 - mean_absolute_error: 0.0064 - val_loss: 2.8392e-04 - val_mean_absolute_error: 0.0126
# Epoch 106/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0450e-04 - mean_absolute_error: 0.0068 - val_loss: 2.9605e-04 - val_mean_absolute_error: 0.0130
# Epoch 107/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2167e-04 - mean_absolute_error: 0.0076 - val_loss: 3.3154e-04 - val_mean_absolute_error: 0.0142
# Epoch 108/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0058e-04 - mean_absolute_error: 0.0070 - val_loss: 2.8183e-04 - val_mean_absolute_error: 0.0125
# Epoch 109/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.4258e-05 - mean_absolute_error: 0.0067 - val_loss: 3.4928e-04 - val_mean_absolute_error: 0.0147
# Epoch 110/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.4711e-05 - mean_absolute_error: 0.0067 - val_loss: 3.2164e-04 - val_mean_absolute_error: 0.0138
# Epoch 111/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0140e-04 - mean_absolute_error: 0.0069 - val_loss: 3.6827e-04 - val_mean_absolute_error: 0.0151
# Epoch 112/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0113e-04 - mean_absolute_error: 0.0071 - val_loss: 2.8865e-04 - val_mean_absolute_error: 0.0128
# Epoch 113/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2002e-04 - mean_absolute_error: 0.0076 - val_loss: 3.2030e-04 - val_mean_absolute_error: 0.0138
# Epoch 114/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.3107e-04 - mean_absolute_error: 0.0082 - val_loss: 2.9382e-04 - val_mean_absolute_error: 0.0129
# Epoch 115/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2187e-04 - mean_absolute_error: 0.0078 - val_loss: 2.8552e-04 - val_mean_absolute_error: 0.0127
# Epoch 116/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0122e-04 - mean_absolute_error: 0.0068 - val_loss: 2.9394e-04 - val_mean_absolute_error: 0.0129
# Epoch 117/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.5842e-05 - mean_absolute_error: 0.0068 - val_loss: 2.8759e-04 - val_mean_absolute_error: 0.0128
# Epoch 118/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0116e-04 - mean_absolute_error: 0.0070 - val_loss: 2.8909e-04 - val_mean_absolute_error: 0.0128
# Epoch 119/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0152e-04 - mean_absolute_error: 0.0066 - val_loss: 2.9439e-04 - val_mean_absolute_error: 0.0129
# Epoch 120/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 9.1918e-05 - mean_absolute_error: 0.0066 - val_loss: 3.3442e-04 - val_mean_absolute_error: 0.0142
# Epoch 121/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1773e-04 - mean_absolute_error: 0.0077 - val_loss: 2.9366e-04 - val_mean_absolute_error: 0.0129
# Epoch 122/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.1649e-05 - mean_absolute_error: 0.0067 - val_loss: 3.9733e-04 - val_mean_absolute_error: 0.0159
# Epoch 123/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0626e-04 - mean_absolute_error: 0.0071 - val_loss: 2.8649e-04 - val_mean_absolute_error: 0.0127
# Epoch 124/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.0301e-04 - mean_absolute_error: 0.0068 - val_loss: 4.0231e-04 - val_mean_absolute_error: 0.0161
# Epoch 125/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.1677e-04 - mean_absolute_error: 0.0079 - val_loss: 2.9186e-04 - val_mean_absolute_error: 0.0129
# Epoch 126/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0073e-04 - mean_absolute_error: 0.0068 - val_loss: 2.8915e-04 - val_mean_absolute_error: 0.0127
# Epoch 127/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0781e-04 - mean_absolute_error: 0.0071 - val_loss: 3.2927e-04 - val_mean_absolute_error: 0.0141
# Epoch 128/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.9569e-05 - mean_absolute_error: 0.0069 - val_loss: 2.9009e-04 - val_mean_absolute_error: 0.0128
# Epoch 129/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1263e-04 - mean_absolute_error: 0.0078 - val_loss: 3.6151e-04 - val_mean_absolute_error: 0.0149
# Epoch 130/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.0320e-04 - mean_absolute_error: 0.0070 - val_loss: 2.8898e-04 - val_mean_absolute_error: 0.0127
# Epoch 131/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0715e-04 - mean_absolute_error: 0.0069 - val_loss: 3.2693e-04 - val_mean_absolute_error: 0.0140
# Epoch 132/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.1687e-05 - mean_absolute_error: 0.0066 - val_loss: 2.9740e-04 - val_mean_absolute_error: 0.0131
# Epoch 133/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 9.2792e-05 - mean_absolute_error: 0.0065 - val_loss: 2.9568e-04 - val_mean_absolute_error: 0.0130
# Epoch 134/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.8639e-05 - mean_absolute_error: 0.0067 - val_loss: 4.1010e-04 - val_mean_absolute_error: 0.0162
# Epoch 135/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2842e-04 - mean_absolute_error: 0.0082 - val_loss: 2.8902e-04 - val_mean_absolute_error: 0.0128
# Epoch 136/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0089e-04 - mean_absolute_error: 0.0072 - val_loss: 3.1496e-04 - val_mean_absolute_error: 0.0136
# Epoch 137/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1049e-04 - mean_absolute_error: 0.0074 - val_loss: 3.6326e-04 - val_mean_absolute_error: 0.0150
# Epoch 138/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0626e-04 - mean_absolute_error: 0.0071 - val_loss: 3.6509e-04 - val_mean_absolute_error: 0.0151
# Epoch 139/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.9179e-05 - mean_absolute_error: 0.0070 - val_loss: 3.0742e-04 - val_mean_absolute_error: 0.0133
# Epoch 140/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.1532e-04 - mean_absolute_error: 0.0075 - val_loss: 2.8958e-04 - val_mean_absolute_error: 0.0128
# Epoch 141/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.2467e-05 - mean_absolute_error: 0.0067 - val_loss: 3.8975e-04 - val_mean_absolute_error: 0.0157
# Epoch 142/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.1683e-04 - mean_absolute_error: 0.0076 - val_loss: 2.9337e-04 - val_mean_absolute_error: 0.0129
# Epoch 143/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.4491e-05 - mean_absolute_error: 0.0068 - val_loss: 3.4620e-04 - val_mean_absolute_error: 0.0145
# Epoch 144/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.1704e-05 - mean_absolute_error: 0.0066 - val_loss: 3.4021e-04 - val_mean_absolute_error: 0.0144
# Epoch 145/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.0231e-04 - mean_absolute_error: 0.0071 - val_loss: 3.5851e-04 - val_mean_absolute_error: 0.0149
# Epoch 146/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1524e-04 - mean_absolute_error: 0.0072 - val_loss: 3.2047e-04 - val_mean_absolute_error: 0.0138
# Epoch 147/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.1763e-05 - mean_absolute_error: 0.0068 - val_loss: 3.3999e-04 - val_mean_absolute_error: 0.0144
# Epoch 148/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0304e-04 - mean_absolute_error: 0.0069 - val_loss: 2.9009e-04 - val_mean_absolute_error: 0.0128
# Epoch 149/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1388e-04 - mean_absolute_error: 0.0076 - val_loss: 3.1328e-04 - val_mean_absolute_error: 0.0135
# Epoch 150/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.2321e-05 - mean_absolute_error: 0.0067 - val_loss: 4.0335e-04 - val_mean_absolute_error: 0.0160
# Epoch 151/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1235e-04 - mean_absolute_error: 0.0075 - val_loss: 2.9533e-04 - val_mean_absolute_error: 0.0130
# Epoch 152/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.8972e-05 - mean_absolute_error: 0.0065 - val_loss: 3.5189e-04 - val_mean_absolute_error: 0.0147
# Epoch 153/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2323e-04 - mean_absolute_error: 0.0075 - val_loss: 3.7774e-04 - val_mean_absolute_error: 0.0154
# Epoch 154/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.1283e-04 - mean_absolute_error: 0.0075 - val_loss: 3.0275e-04 - val_mean_absolute_error: 0.0132
# Epoch 155/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.7470e-05 - mean_absolute_error: 0.0068 - val_loss: 2.9473e-04 - val_mean_absolute_error: 0.0130
# Epoch 156/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 8.8927e-05 - mean_absolute_error: 0.0068 - val_loss: 2.9208e-04 - val_mean_absolute_error: 0.0128
# Epoch 157/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0239e-04 - mean_absolute_error: 0.0069 - val_loss: 3.2543e-04 - val_mean_absolute_error: 0.0139
# Epoch 158/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1809e-04 - mean_absolute_error: 0.0075 - val_loss: 3.3101e-04 - val_mean_absolute_error: 0.0141
# Epoch 159/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.0492e-04 - mean_absolute_error: 0.0068 - val_loss: 2.9692e-04 - val_mean_absolute_error: 0.0130
# Epoch 160/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 9.5267e-05 - mean_absolute_error: 0.0067 - val_loss: 2.9760e-04 - val_mean_absolute_error: 0.0132
# Epoch 161/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.9378e-05 - mean_absolute_error: 0.0072 - val_loss: 2.9400e-04 - val_mean_absolute_error: 0.0130
# Epoch 162/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.2731e-05 - mean_absolute_error: 0.0068 - val_loss: 3.2724e-04 - val_mean_absolute_error: 0.0139
# Epoch 163/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 9.6842e-05 - mean_absolute_error: 0.0066 - val_loss: 3.0396e-04 - val_mean_absolute_error: 0.0132
# Epoch 164/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 9.3675e-05 - mean_absolute_error: 0.0067 - val_loss: 3.2309e-04 - val_mean_absolute_error: 0.0138
# Epoch 165/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0995e-04 - mean_absolute_error: 0.0074 - val_loss: 3.0811e-04 - val_mean_absolute_error: 0.0135
# Epoch 166/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.4240e-05 - mean_absolute_error: 0.0067 - val_loss: 2.9183e-04 - val_mean_absolute_error: 0.0129
# Epoch 167/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.1534e-04 - mean_absolute_error: 0.0075 - val_loss: 4.5668e-04 - val_mean_absolute_error: 0.0173
# Epoch 168/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.0332e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9489e-04 - val_mean_absolute_error: 0.0129
# Epoch 169/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0817e-04 - mean_absolute_error: 0.0070 - val_loss: 2.9446e-04 - val_mean_absolute_error: 0.0130
# Epoch 170/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.1064e-04 - mean_absolute_error: 0.0070 - val_loss: 3.0787e-04 - val_mean_absolute_error: 0.0134
# Epoch 171/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.9698e-05 - mean_absolute_error: 0.0070 - val_loss: 3.1347e-04 - val_mean_absolute_error: 0.0135
# Epoch 172/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.8268e-05 - mean_absolute_error: 0.0069 - val_loss: 2.9193e-04 - val_mean_absolute_error: 0.0129
# Epoch 173/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.2314e-05 - mean_absolute_error: 0.0064 - val_loss: 3.0700e-04 - val_mean_absolute_error: 0.0134
# Epoch 174/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.2766e-05 - mean_absolute_error: 0.0067 - val_loss: 2.9266e-04 - val_mean_absolute_error: 0.0129
# Epoch 175/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0613e-04 - mean_absolute_error: 0.0073 - val_loss: 3.6074e-04 - val_mean_absolute_error: 0.0150
# Epoch 176/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1246e-04 - mean_absolute_error: 0.0073 - val_loss: 3.2870e-04 - val_mean_absolute_error: 0.0140
# Epoch 177/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.0166e-04 - mean_absolute_error: 0.0072 - val_loss: 2.9496e-04 - val_mean_absolute_error: 0.0129
# Epoch 178/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0956e-04 - mean_absolute_error: 0.0072 - val_loss: 4.4965e-04 - val_mean_absolute_error: 0.0170
# Epoch 179/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.7150e-05 - mean_absolute_error: 0.0070 - val_loss: 2.9500e-04 - val_mean_absolute_error: 0.0129
# Epoch 180/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.5189e-05 - mean_absolute_error: 0.0068 - val_loss: 3.1208e-04 - val_mean_absolute_error: 0.0136
# Epoch 181/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0947e-04 - mean_absolute_error: 0.0070 - val_loss: 2.9392e-04 - val_mean_absolute_error: 0.0130
# Epoch 182/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0192e-04 - mean_absolute_error: 0.0070 - val_loss: 3.2830e-04 - val_mean_absolute_error: 0.0141
# Epoch 183/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.5909e-05 - mean_absolute_error: 0.0068 - val_loss: 3.2078e-04 - val_mean_absolute_error: 0.0138
# Epoch 184/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.7415e-05 - mean_absolute_error: 0.0066 - val_loss: 3.2341e-04 - val_mean_absolute_error: 0.0140
# Epoch 185/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1166e-04 - mean_absolute_error: 0.0077 - val_loss: 3.9694e-04 - val_mean_absolute_error: 0.0159
# Epoch 186/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0878e-04 - mean_absolute_error: 0.0076 - val_loss: 3.1903e-04 - val_mean_absolute_error: 0.0137
# Epoch 187/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 9.9618e-05 - mean_absolute_error: 0.0068 - val_loss: 3.3198e-04 - val_mean_absolute_error: 0.0142
# Epoch 188/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0685e-04 - mean_absolute_error: 0.0071 - val_loss: 3.3717e-04 - val_mean_absolute_error: 0.0143
# Epoch 189/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.2216e-04 - mean_absolute_error: 0.0076 - val_loss: 2.9970e-04 - val_mean_absolute_error: 0.0131
# Epoch 190/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0772e-04 - mean_absolute_error: 0.0071 - val_loss: 2.9312e-04 - val_mean_absolute_error: 0.0129
# Epoch 191/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0745e-04 - mean_absolute_error: 0.0069 - val_loss: 3.0521e-04 - val_mean_absolute_error: 0.0133
# Epoch 192/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0317e-04 - mean_absolute_error: 0.0070 - val_loss: 4.6858e-04 - val_mean_absolute_error: 0.0176
# Epoch 193/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0869e-04 - mean_absolute_error: 0.0075 - val_loss: 3.9045e-04 - val_mean_absolute_error: 0.0157
# Epoch 194/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3219e-04 - mean_absolute_error: 0.0082 - val_loss: 3.2075e-04 - val_mean_absolute_error: 0.0138
# Epoch 195/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.2410e-05 - mean_absolute_error: 0.0068 - val_loss: 2.9273e-04 - val_mean_absolute_error: 0.0129
# Epoch 196/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.0675e-04 - mean_absolute_error: 0.0071 - val_loss: 3.3706e-04 - val_mean_absolute_error: 0.0143
# Epoch 197/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.6094e-05 - mean_absolute_error: 0.0069 - val_loss: 3.1574e-04 - val_mean_absolute_error: 0.0136
# Epoch 198/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 9.2871e-05 - mean_absolute_error: 0.0065 - val_loss: 3.2159e-04 - val_mean_absolute_error: 0.0138
# Epoch 199/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.2232e-04 - mean_absolute_error: 0.0080 - val_loss: 2.9679e-04 - val_mean_absolute_error: 0.0130
# Epoch 200/200
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 9.2115e-05 - mean_absolute_error: 0.0067 - val_loss: 2.9622e-04 - val_mean_absolute_error: 0.0130

# %% [markdown]
# ### Predicting with test set and validate set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)

y_pred_val = model.predict(X_val)
y_pred_val = scaler.inverse_transform(y_pred_val)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test and validation set again to evaluate, because i shaped the data between 0 and 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]
val_data1 = df[train_size + test_size :]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

X_val1 = np.array(val_data1.index).reshape(-1, 1)
y_val1 = np.array(val_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 251
# 262

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)

print("")
# Model evaluation on validate set
print("Model evalution on validate set")
evalute_model(y_val1, y_pred_val)
# Out:
# Model evalution on test set
# MSE: 1458117.6866957068
# RMSE: 1207.525439357576
# MAE: 885.4989028261953
# MAPE: 2.7098004208079707 %
#
# Model evalution on validate set
# MSE: 2107062.253700121
# RMSE: 1451.5723384317162
# MAE: 886.5521631052371
# MAPE: 2.039779884771438 %

# %% [markdown]
# ## 4. Predict the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(val_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step

# %%
y_pred_30_days
# Out:
# array([[62202.098],
#        [61077.324],
#        [61457.824],
#        [61737.727],
#        [61410.96 ],
#        [61596.977],
#        [61558.312],
#        [61521.12 ],
#        [61566.35 ],
#        [61541.043],
#        [61545.855],
#        [61551.06 ],
#        [61544.824],
#        [61548.24 ],
#        [61547.63 ],
#        [61546.9  ],
#        [61547.742],
#        [61547.29 ],
#        [61547.363],
#        [61547.465],
#        [61547.344],
#        [61547.42 ],
#        [61547.395],
#        [61547.395],
#        [61547.41 ],
#        [61547.402],
#        [61547.414],
#        [61547.395],
#        [61547.402],
#        [61547.402],
#        [61547.395]], dtype=float32)

# %% [markdown]
# ### Continute predict the next 60/90 days

# %%
y_pred_60_days = forecast(val_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step

# %%
y_pred_90_days = forecast(val_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")
    plt.plot(val_data1.index, val_data1, label="Validate")

    # Predict test and validate
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )
    plt.plot(
        val_data1.index[WINDOW_SIDE : len(y_pred_val) + WINDOW_SIDE],
        y_pred_val,
        label="Predicted Validate",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        val_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Forecast Next {days} Days",
        linestyle="--",
    )

    plt.title(f"{stock_name[stock]} Stock Closing Price Forecasting Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Forecast the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
