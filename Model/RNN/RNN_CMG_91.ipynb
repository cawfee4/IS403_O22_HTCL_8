# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, Dropout, Input

plt.style.use('default')

# %% [markdown]
# ## 1. Data preprocessing

# %%
split_type = [0.8,0.7,0.9]
# Stock [0] = FPT | [1] = CMG | [2] = ITD
stock_name = ["FPT", "CMG", "ITD"]

# %%
# Change stock and split to adjust between splitting type and stock
stock = 1  # CMG
split = 2

# %%
# Loading data
df = pd.read_csv(f"../../Dataset/{stock_name[stock]}_stock.csv")

df = df[["time", "close"]]
df["time"] = pd.to_datetime(df["time"])
df.set_index("time", inplace=True)

df.head()
# Out:
#             close
# time
# 2019-03-01  13480
# 2019-03-04  13970
# 2019-03-05  14460
# 2019-03-06  14060
# 2019-03-07  13830

# %%
df.shape
# Out:
# (1313, 1)

# %%
df.plot(figsize=(10, 5))
plt.ylabel("Closing price")
plt.xlabel("Date")
plt.show()

# %%
df = df.reset_index()["close"]
df
# Out:
# 0       13480
# 1       13970
# 2       14460
# 3       14060
# 4       13830
#         ...
# 1308    59000
# 1309    62100
# 1310    60000
# 1311    59200
# 1312    60900
# Name: close, Length: 1313, dtype: int64

# %%
# Normalize data between 0 and 1 because we using neural network model
scaler = MinMaxScaler(feature_range=(0, 1))
df_scaled = scaler.fit_transform(np.array(df).reshape(-1, 1))

# %% [markdown]
# ## 2. Model training

# %% [markdown]
# ### Create train set, test set and reshape them

# %%
# Defining the split size
train_size = int(split_type[split] * len(df_scaled))
test_size = len(df_scaled) - train_size

# %%
# Splitting data into train, test set
train_data = df_scaled[:train_size]
test_data = df_scaled[train_size:]

# %%
# Function to create dataset input and output, it will convert an array of values into a dataset matrix, use the sliding window with the time_step argument
def create_dataset(data, window_side):
    X, y = [], []

    for i in range(len(data) - window_side - 1):
        X.append(data[i : (i + window_side), 0])
        y.append(data[i + window_side, 0])

    return np.array(X), np.array(y)

# %%
# Define time step, it mean the model will take 10 days before to predict the closing price 'at that time'
WINDOW_SIDE = 10

# Create X, y for train, test set
X_train, y_train = create_dataset(train_data, WINDOW_SIDE)
X_test, y_test = create_dataset(test_data, WINDOW_SIDE)

X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((1170, 10), (1170,), (121, 10), (121,))

# %%
# Reshape the dataset to suit the RNN input
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %% [markdown]
# ### Start train model

# %%
UNITS = 64

# Initialize RNN:
model = Sequential(
    [
        Input((X_train.shape[1], 1)),
        SimpleRNN(UNITS),
        Dense(1),
    ]
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_1 (SimpleRNN)        │ (None, 64)             │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,289 (16.75 KB)
#  Trainable params: 4,289 (16.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the RNN
model.compile(
    loss="mse",
    optimizer="adam",
    metrics=["mean_absolute_error"],
)

# %%
EPOCHS = 200
BATCH_SIZE = 32
VERBOSE = 1

# Fit model with the train dataset
model.fit(
    X_train,
    y_train,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=VERBOSE,
)
# Out:
# Epoch 1/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0174 - mean_absolute_error: 0.0916
# Epoch 2/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 8.6296e-04 - mean_absolute_error: 0.0218
# Epoch 3/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - loss: 5.3208e-04 - mean_absolute_error: 0.0170
# Epoch 4/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 920us/step - loss: 4.3565e-04 - mean_absolute_error: 0.0154
# Epoch 5/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 3.2710e-04 - mean_absolute_error: 0.0131
# Epoch 6/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 3.0645e-04 - mean_absolute_error: 0.0125
# Epoch 7/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 2.7753e-04 - mean_absolute_error: 0.0117
# Epoch 8/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - loss: 2.4761e-04 - mean_absolute_error: 0.0111
# Epoch 9/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - loss: 2.7313e-04 - mean_absolute_error: 0.0112
# Epoch 10/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 961us/step - loss: 2.1715e-04 - mean_absolute_error: 0.0105
# Epoch 11/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1525e-04 - mean_absolute_error: 0.0102
# Epoch 12/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - loss: 2.1606e-04 - mean_absolute_error: 0.0102
# Epoch 13/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 948us/step - loss: 2.2384e-04 - mean_absolute_error: 0.0107
# Epoch 14/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 1.9570e-04 - mean_absolute_error: 0.0100
# Epoch 15/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 965us/step - loss: 2.0396e-04 - mean_absolute_error: 0.0101
# Epoch 16/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 856us/step - loss: 2.2153e-04 - mean_absolute_error: 0.0103
# Epoch 17/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step - loss: 2.0661e-04 - mean_absolute_error: 0.0100
# Epoch 18/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - loss: 1.9997e-04 - mean_absolute_error: 0.0100
# Epoch 19/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - loss: 2.2772e-04 - mean_absolute_error: 0.0106
# Epoch 20/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 905us/step - loss: 2.1642e-04 - mean_absolute_error: 0.0103
# Epoch 21/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 1.8605e-04 - mean_absolute_error: 0.0097
# Epoch 22/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 1.8165e-04 - mean_absolute_error: 0.0094
# Epoch 23/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7270e-04 - mean_absolute_error: 0.0092
# Epoch 24/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - loss: 2.4419e-04 - mean_absolute_error: 0.0113
# Epoch 25/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step - loss: 1.8150e-04 - mean_absolute_error: 0.0095
# Epoch 26/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - loss: 2.3208e-04 - mean_absolute_error: 0.0111
# Epoch 27/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - loss: 2.0795e-04 - mean_absolute_error: 0.0102
# Epoch 28/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - loss: 2.1996e-04 - mean_absolute_error: 0.0102
# Epoch 29/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 877us/step - loss: 1.8441e-04 - mean_absolute_error: 0.0092
# Epoch 30/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 914us/step - loss: 1.9120e-04 - mean_absolute_error: 0.0098
# Epoch 31/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 1.7962e-04 - mean_absolute_error: 0.0093
# Epoch 32/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - loss: 1.7232e-04 - mean_absolute_error: 0.0091
# Epoch 33/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - loss: 1.8296e-04 - mean_absolute_error: 0.0097
# Epoch 34/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - loss: 2.0289e-04 - mean_absolute_error: 0.0106
# Epoch 35/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.1355e-04 - mean_absolute_error: 0.0103
# Epoch 36/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - loss: 1.5189e-04 - mean_absolute_error: 0.0088
# Epoch 37/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 1.7187e-04 - mean_absolute_error: 0.0092
# Epoch 38/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 908us/step - loss: 1.7590e-04 - mean_absolute_error: 0.0093
# Epoch 39/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 1.9223e-04 - mean_absolute_error: 0.0096
# Epoch 40/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 1.4828e-04 - mean_absolute_error: 0.0082
# Epoch 41/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 1.6869e-04 - mean_absolute_error: 0.0088
# Epoch 42/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 1.6310e-04 - mean_absolute_error: 0.0091
# Epoch 43/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - loss: 1.6575e-04 - mean_absolute_error: 0.0093
# Epoch 44/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 2.0384e-04 - mean_absolute_error: 0.0102
# Epoch 45/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 886us/step - loss: 1.4122e-04 - mean_absolute_error: 0.0083
# Epoch 46/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - loss: 1.5848e-04 - mean_absolute_error: 0.0084
# Epoch 47/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - loss: 1.4059e-04 - mean_absolute_error: 0.0082
# Epoch 48/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 1.4795e-04 - mean_absolute_error: 0.0085
# Epoch 49/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7306e-04 - mean_absolute_error: 0.0095
# Epoch 50/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6453e-04 - mean_absolute_error: 0.0088
# Epoch 51/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 995us/step - loss: 1.6816e-04 - mean_absolute_error: 0.0091
# Epoch 52/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0117e-04 - mean_absolute_error: 0.0100
# Epoch 53/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3683e-04 - mean_absolute_error: 0.0080
# Epoch 54/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4843e-04 - mean_absolute_error: 0.0084
# Epoch 55/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6100e-04 - mean_absolute_error: 0.0090
# Epoch 56/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5762e-04 - mean_absolute_error: 0.0087
# Epoch 57/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6977e-04 - mean_absolute_error: 0.0094
# Epoch 58/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6511e-04 - mean_absolute_error: 0.0090
# Epoch 59/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 970us/step - loss: 1.4906e-04 - mean_absolute_error: 0.0084
# Epoch 60/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.0670e-04 - mean_absolute_error: 0.0104
# Epoch 61/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - loss: 1.4522e-04 - mean_absolute_error: 0.0087
# Epoch 62/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5019e-04 - mean_absolute_error: 0.0087
# Epoch 63/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3462e-04 - mean_absolute_error: 0.0080
# Epoch 64/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7903e-04 - mean_absolute_error: 0.0092
# Epoch 65/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - loss: 1.4939e-04 - mean_absolute_error: 0.0087
# Epoch 66/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 1.4879e-04 - mean_absolute_error: 0.0083
# Epoch 67/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 974us/step - loss: 1.5698e-04 - mean_absolute_error: 0.0088
# Epoch 68/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 988us/step - loss: 1.5530e-04 - mean_absolute_error: 0.0086
# Epoch 69/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 980us/step - loss: 1.6232e-04 - mean_absolute_error: 0.0087
# Epoch 70/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3417e-04 - mean_absolute_error: 0.0079
# Epoch 71/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 959us/step - loss: 1.4233e-04 - mean_absolute_error: 0.0083
# Epoch 72/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5300e-04 - mean_absolute_error: 0.0087
# Epoch 73/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3128e-04 - mean_absolute_error: 0.0078
# Epoch 74/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 967us/step - loss: 1.4918e-04 - mean_absolute_error: 0.0085
# Epoch 75/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - loss: 1.6731e-04 - mean_absolute_error: 0.0090
# Epoch 76/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - loss: 1.4594e-04 - mean_absolute_error: 0.0081
# Epoch 77/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 966us/step - loss: 1.3934e-04 - mean_absolute_error: 0.0082
# Epoch 78/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - loss: 1.6972e-04 - mean_absolute_error: 0.0087
# Epoch 79/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7927e-04 - mean_absolute_error: 0.0095
# Epoch 80/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5788e-04 - mean_absolute_error: 0.0088
# Epoch 81/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3851e-04 - mean_absolute_error: 0.0080
# Epoch 82/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6289e-04 - mean_absolute_error: 0.0093
# Epoch 83/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3692e-04 - mean_absolute_error: 0.0082
# Epoch 84/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3664e-04 - mean_absolute_error: 0.0079
# Epoch 85/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5110e-04 - mean_absolute_error: 0.0086
# Epoch 86/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5856e-04 - mean_absolute_error: 0.0086
# Epoch 87/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 969us/step - loss: 1.3265e-04 - mean_absolute_error: 0.0083
# Epoch 88/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - loss: 1.5481e-04 - mean_absolute_error: 0.0085
# Epoch 89/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4436e-04 - mean_absolute_error: 0.0082
# Epoch 90/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2579e-04 - mean_absolute_error: 0.0080
# Epoch 91/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6766e-04 - mean_absolute_error: 0.0092
# Epoch 92/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4912e-04 - mean_absolute_error: 0.0084
# Epoch 93/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6151e-04 - mean_absolute_error: 0.0088
# Epoch 94/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3548e-04 - mean_absolute_error: 0.0080
# Epoch 95/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4911e-04 - mean_absolute_error: 0.0084
# Epoch 96/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4286e-04 - mean_absolute_error: 0.0083
# Epoch 97/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5005e-04 - mean_absolute_error: 0.0085
# Epoch 98/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3512e-04 - mean_absolute_error: 0.0081
# Epoch 99/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step - loss: 1.8581e-04 - mean_absolute_error: 0.0096
# Epoch 100/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 977us/step - loss: 1.3971e-04 - mean_absolute_error: 0.0083
# Epoch 101/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - loss: 1.5613e-04 - mean_absolute_error: 0.0086
# Epoch 102/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 918us/step - loss: 1.5369e-04 - mean_absolute_error: 0.0087
# Epoch 103/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 1.4921e-04 - mean_absolute_error: 0.0086
# Epoch 104/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 1.5524e-04 - mean_absolute_error: 0.0087
# Epoch 105/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6239e-04 - mean_absolute_error: 0.0091
# Epoch 106/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6804e-04 - mean_absolute_error: 0.0094
# Epoch 107/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7074e-04 - mean_absolute_error: 0.0089
# Epoch 108/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5049e-04 - mean_absolute_error: 0.0087
# Epoch 109/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3763e-04 - mean_absolute_error: 0.0080
# Epoch 110/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5251e-04 - mean_absolute_error: 0.0088
# Epoch 111/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5737e-04 - mean_absolute_error: 0.0086
# Epoch 112/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4566e-04 - mean_absolute_error: 0.0084
# Epoch 113/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4967e-04 - mean_absolute_error: 0.0088
# Epoch 114/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5552e-04 - mean_absolute_error: 0.0087
# Epoch 115/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4631e-04 - mean_absolute_error: 0.0085
# Epoch 116/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4368e-04 - mean_absolute_error: 0.0083
# Epoch 117/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5607e-04 - mean_absolute_error: 0.0088
# Epoch 118/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4453e-04 - mean_absolute_error: 0.0083
# Epoch 119/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5007e-04 - mean_absolute_error: 0.0089
# Epoch 120/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4064e-04 - mean_absolute_error: 0.0083
# Epoch 121/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5597e-04 - mean_absolute_error: 0.0088
# Epoch 122/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4010e-04 - mean_absolute_error: 0.0083
# Epoch 123/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2441e-04 - mean_absolute_error: 0.0078
# Epoch 124/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7496e-04 - mean_absolute_error: 0.0091
# Epoch 125/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5662e-04 - mean_absolute_error: 0.0089
# Epoch 126/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2494e-04 - mean_absolute_error: 0.0078
# Epoch 127/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3831e-04 - mean_absolute_error: 0.0083
# Epoch 128/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4378e-04 - mean_absolute_error: 0.0086
# Epoch 129/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8182e-04 - mean_absolute_error: 0.0097
# Epoch 130/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4927e-04 - mean_absolute_error: 0.0088
# Epoch 131/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2638e-04 - mean_absolute_error: 0.0078
# Epoch 132/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2962e-04 - mean_absolute_error: 0.0079
# Epoch 133/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4039e-04 - mean_absolute_error: 0.0080
# Epoch 134/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5289e-04 - mean_absolute_error: 0.0087
# Epoch 135/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - loss: 1.4015e-04 - mean_absolute_error: 0.0081
# Epoch 136/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8853e-04 - mean_absolute_error: 0.0094
# Epoch 137/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3876e-04 - mean_absolute_error: 0.0082
# Epoch 138/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4759e-04 - mean_absolute_error: 0.0085
# Epoch 139/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4394e-04 - mean_absolute_error: 0.0082
# Epoch 140/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 957us/step - loss: 1.7575e-04 - mean_absolute_error: 0.0095
# Epoch 141/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6891e-04 - mean_absolute_error: 0.0094
# Epoch 142/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3923e-04 - mean_absolute_error: 0.0084
# Epoch 143/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4480e-04 - mean_absolute_error: 0.0086
# Epoch 144/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9898e-04 - mean_absolute_error: 0.0102
# Epoch 145/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5230e-04 - mean_absolute_error: 0.0088
# Epoch 146/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5267e-04 - mean_absolute_error: 0.0090
# Epoch 147/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 990us/step - loss: 1.3770e-04 - mean_absolute_error: 0.0080
# Epoch 148/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3248e-04 - mean_absolute_error: 0.0078
# Epoch 149/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5921e-04 - mean_absolute_error: 0.0089
# Epoch 150/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3546e-04 - mean_absolute_error: 0.0080
# Epoch 151/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4430e-04 - mean_absolute_error: 0.0085
# Epoch 152/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6041e-04 - mean_absolute_error: 0.0090
# Epoch 153/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4758e-04 - mean_absolute_error: 0.0085
# Epoch 154/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4185e-04 - mean_absolute_error: 0.0081
# Epoch 155/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3291e-04 - mean_absolute_error: 0.0080
# Epoch 156/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4280e-04 - mean_absolute_error: 0.0086
# Epoch 157/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5430e-04 - mean_absolute_error: 0.0084
# Epoch 158/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7485e-04 - mean_absolute_error: 0.0091
# Epoch 159/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4071e-04 - mean_absolute_error: 0.0083
# Epoch 160/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5993e-04 - mean_absolute_error: 0.0087
# Epoch 161/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4960e-04 - mean_absolute_error: 0.0087
# Epoch 162/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6646e-04 - mean_absolute_error: 0.0093
# Epoch 163/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - loss: 1.3079e-04 - mean_absolute_error: 0.0079
# Epoch 164/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7477e-04 - mean_absolute_error: 0.0097
# Epoch 165/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4439e-04 - mean_absolute_error: 0.0082
# Epoch 166/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - loss: 1.5799e-04 - mean_absolute_error: 0.0089
# Epoch 167/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4666e-04 - mean_absolute_error: 0.0084
# Epoch 168/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5431e-04 - mean_absolute_error: 0.0086
# Epoch 169/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.7189e-04 - mean_absolute_error: 0.0089
# Epoch 170/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - loss: 1.3731e-04 - mean_absolute_error: 0.0081
# Epoch 171/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4498e-04 - mean_absolute_error: 0.0083
# Epoch 172/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - loss: 1.4096e-04 - mean_absolute_error: 0.0085
# Epoch 173/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6266e-04 - mean_absolute_error: 0.0092
# Epoch 174/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7872e-04 - mean_absolute_error: 0.0099
# Epoch 175/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5750e-04 - mean_absolute_error: 0.0087
# Epoch 176/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6259e-04 - mean_absolute_error: 0.0089
# Epoch 177/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2946e-04 - mean_absolute_error: 0.0080
# Epoch 178/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 972us/step - loss: 1.5801e-04 - mean_absolute_error: 0.0085
# Epoch 179/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6183e-04 - mean_absolute_error: 0.0090
# Epoch 180/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.2918e-04 - mean_absolute_error: 0.0078
# Epoch 181/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4328e-04 - mean_absolute_error: 0.0085
# Epoch 182/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4195e-04 - mean_absolute_error: 0.0084
# Epoch 183/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3486e-04 - mean_absolute_error: 0.0079
# Epoch 184/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4546e-04 - mean_absolute_error: 0.0083
# Epoch 185/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3944e-04 - mean_absolute_error: 0.0080
# Epoch 186/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 998us/step - loss: 1.3928e-04 - mean_absolute_error: 0.0083
# Epoch 187/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3678e-04 - mean_absolute_error: 0.0085
# Epoch 188/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.6164e-04 - mean_absolute_error: 0.0087
# Epoch 189/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - loss: 1.4101e-04 - mean_absolute_error: 0.0083
# Epoch 190/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.8443e-04 - mean_absolute_error: 0.0095
# Epoch 191/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - loss: 1.3375e-04 - mean_absolute_error: 0.0081
# Epoch 192/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3962e-04 - mean_absolute_error: 0.0080
# Epoch 193/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4785e-04 - mean_absolute_error: 0.0086
# Epoch 194/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5191e-04 - mean_absolute_error: 0.0084
# Epoch 195/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 983us/step - loss: 1.3335e-04 - mean_absolute_error: 0.0080
# Epoch 196/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - loss: 1.4889e-04 - mean_absolute_error: 0.0086
# Epoch 197/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.4270e-04 - mean_absolute_error: 0.0081
# Epoch 198/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3946e-04 - mean_absolute_error: 0.0082
# Epoch 199/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.3398e-04 - mean_absolute_error: 0.0081
# Epoch 200/200
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.5254e-04 - mean_absolute_error: 0.0083

# %% [markdown]
# ### Predicting with test set

# %%
# Predict and convert the data back - because i reshaped between 0 and 1, so need to convert back
y_pred_test = model.predict(X_test)
y_pred_test = scaler.inverse_transform(y_pred_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step

# %% [markdown]
# ## 3. Model evaluation

# %%
# Splitting data into train, test set again to evaluate, because i shaped the data between 0 to 1 to suit the model
train_data1 = df[:train_size]
test_data1 = df[train_size : train_size + test_size]

X_test1 = np.array(test_data1.index).reshape(-1, 1)
y_test1 = np.array(test_data1)

# %%
print(len(y_test))
print(len(y_test1))
# Out:
# 121
# 132

# %%
# Evaluation
from sklearn.metrics import (
    mean_absolute_percentage_error as mape,
    mean_squared_error as mse,
    mean_absolute_error as mae,
)

def evalute_model(y, y_pred):
    # Because i use the sliding window with the time_step value, so the length of 'y' and 'y predict' will difference
    min_len = min(len(y), len(y_pred))
    y = y[-min_len:]
    y_pred = y_pred[-min_len:]

    print(f'MSE: {mse(y, y_pred)}')
    print(f'RMSE: {np.sqrt(mse(y, y_pred))}')
    print(f'MAE: {mae(y, y_pred)}')
    print(f'MAPE: {mape(y, y_pred) * 100} %')

# %%
# So the result will change every time RUN ALL (build model again), because the model will take random start number.
# But it dont change much, the MAPE will 1.47% ~ 1.8% (test set)
# Model evaluation on test set
print("Model evalution on test set")
evalute_model(y_test1, y_pred_test)
# Out:
# Model evalution on test set
# MSE: 3606284.3543240884
# RMSE: 1899.0219467726245
# MAE: 1241.6028215392562
# MAPE: 2.615753425454493 %

# %% [markdown]
# ## 4. Forecast the next 30/60/90 days

# %%
def forecast(data, window_side, forecast_days):
    # Get the last sequence_length days
    x_forecast = data[-window_side:]
    y_forecast = []

    for i in range(forecast_days + 1):
        # Reshape x_forecast to have the shape (1, window_side, num_features)
        x_forecast_reshaped = x_forecast.reshape(1, window_side, x_forecast.shape[1])
        # Predict the next day
        y = model.predict(x_forecast_reshaped)
        y_forecast.append(y[0][0])

        # Add the new prediction to the data
        x_forecast = np.insert(x_forecast, -1, y, axis=0)[1:]

    return y_forecast

# %%
y_pred_30_days = forecast(test_data, 5, 30)

# Assuming y_pred_30_days is a 1D array
y_pred_30_days = np.array(y_pred_30_days).reshape(-1, 1)

# Inverse transform y_pred_30_days
y_pred_30_days = scaler.inverse_transform(y_pred_30_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
y_pred_30_days
# Out:
# array([[61754.62 ],
#        [61486.27 ],
#        [61736.6  ],
#        [61654.38 ],
#        [61696.785],
#        [61681.586],
#        [61688.62 ],
#        [61685.81 ],
#        [61687.016],
#        [61686.527],
#        [61686.746],
#        [61686.652],
#        [61686.695],
#        [61686.67 ],
#        [61686.676],
#        [61686.69 ],
#        [61686.684],
#        [61686.69 ],
#        [61686.69 ],
#        [61686.69 ],
#        [61686.684],
#        [61686.69 ],
#        [61686.684],
#        [61686.684],
#        [61686.684],
#        [61686.69 ],
#        [61686.684],
#        [61686.676],
#        [61686.684],
#        [61686.676],
#        [61686.69 ]], dtype=float32)

# %% [markdown]
# ### Continue forecast the next 60/90 days

# %%
y_pred_60_days = forecast(test_data, 5, 60)
y_pred_60_days = np.array(y_pred_60_days).reshape(-1, 1)
y_pred_60_days = scaler.inverse_transform(y_pred_60_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
y_pred_90_days = forecast(test_data, 5, 90)
y_pred_90_days = np.array(y_pred_90_days).reshape(-1, 1)
y_pred_90_days = scaler.inverse_transform(y_pred_90_days)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %% [markdown]
# ### Plotting the data

# %%
def draw_plot(y_days_predict, days):
    plt.figure(figsize=(10, 6))
    plt.ylabel("Closing Price")

    # Raw data
    plt.plot(train_data1.index, train_data1, label="Train")
    plt.plot(test_data1.index, test_data1, label="Test")

    # Predict test set
    plt.plot(
        test_data1.index[
            WINDOW_SIDE : len(y_pred_test) + WINDOW_SIDE
        ],  # because using the sliding window (WINDOW_SIDE) -> the index of 2 dataset is difference
        y_pred_test,
        label="Predicted Test",
        linestyle="--",
    )

    # Predict the next 30/60/90 days
    plt.plot(
        test_data1.index[-1] + np.arange(1, len(y_days_predict) + 1),
        y_days_predict,
        label=f"Next {days} Days",
        linestyle="--",
    )

    plt.title(f"Forecast {stock_name[stock]} Stock Closing Price Using RNN")
    plt.legend()
    plt.show()

# %% [markdown]
# ### Forecast the closing price next 30/60/90 days

# %%
draw_plot(y_pred_30_days, 30)
draw_plot(y_pred_60_days, 60)
draw_plot(y_pred_90_days, 90)
